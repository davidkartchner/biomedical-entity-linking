# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pickle
import ujson
import sys
import os

import pandas as pd
import numpy as np

from tqdm import tqdm
from collections import defaultdict
from typing import Optional, Union

from bigbio.dataloader import BigBioConfigHelpers

sys.path.append('../../../..')
from umls_utils import UmlsMappings
from bigbio_utils import CUIS_TO_REMAP, CUIS_TO_EXCLUDE, DATASET_NAMES, VALIDATION_DOCUMENT_IDS
from bigbio_utils import dataset_to_documents, dataset_to_df, resolve_abbreviation, get_left_context, get_right_context

conhelps = BigBioConfigHelpers()
# Out:
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for an_em contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/an_em/an_em.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for anat_em contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/anat_em/anat_em.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for ask_a_patient contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/ask_a_patient/ask_a_patient.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for bc5cdr contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/bc5cdr/bc5cdr.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for bc7_litcovid contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/bc7_litcovid/bc7_litcovid.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for bio_sim_verb contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/bio_sim_verb/bio_sim_verb.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for bio_simlex contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/bio_simlex/bio_simlex.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for bioasq_2021_mesinesp contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/bioasq_2021_mesinesp/bioasq_2021_mesinesp.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for bioasq_task_b contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/bioasq_task_b/bioasq_task_b.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for bioasq_task_c_2017 contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/bioasq_task_c_2017/bioasq_task_c_2017.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for bioid contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/bioid/bioid.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for bioinfer contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/bioinfer/bioinfer.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for biology_how_why_corpus contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/biology_how_why_corpus/biology_how_why_corpus.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for biomrc contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/biomrc/biomrc.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for bionlp_shared_task_2009 contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/bionlp_shared_task_2009/bionlp_shared_task_2009.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for bionlp_st_2011_epi contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/bionlp_st_2011_epi/bionlp_st_2011_epi.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for bionlp_st_2011_ge contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/bionlp_st_2011_ge/bionlp_st_2011_ge.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for bionlp_st_2011_id contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/bionlp_st_2011_id/bionlp_st_2011_id.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for bionlp_st_2011_rel contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/bionlp_st_2011_rel/bionlp_st_2011_rel.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for bionlp_st_2013_cg contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/bionlp_st_2013_cg/bionlp_st_2013_cg.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for bionlp_st_2013_ge contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/bionlp_st_2013_ge/bionlp_st_2013_ge.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for bionlp_st_2013_gro contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/bionlp_st_2013_gro/bionlp_st_2013_gro.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for bionlp_st_2013_pc contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/bionlp_st_2013_pc/bionlp_st_2013_pc.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for bionlp_st_2019_bb contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/bionlp_st_2019_bb/bionlp_st_2019_bb.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for biored contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/biored/biored.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for biorelex contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/biorelex/biorelex.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for bioscope contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/bioscope/bioscope.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for biosses contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/biosses/biosses.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for blurb contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/blurb/blurb.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for bronco contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/bronco/bronco.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for cantemist contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/cantemist/cantemist.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for cardiode contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/cardiode/cardiode.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for cas contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/cas/cas.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for cellfinder contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/cellfinder/cellfinder.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for chebi_nactem contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/chebi_nactem/chebi_nactem.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for chemdner contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/chemdner/chemdner.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for chemprot contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/chemprot/chemprot.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for chia contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/chia/chia.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for citation_gia_test_collection contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/citation_gia_test_collection/citation_gia_test_collection.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for codiesp contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/codiesp/codiesp.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for cpi contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/cpi/cpi.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for ctebmsp contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/ctebmsp/ctebmsp.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for czi_drsm contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/czi_drsm/czi_drsm.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for ddi_corpus contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/ddi_corpus/ddi_corpus.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for distemist contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/distemist/distemist.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for drugprot contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/drugprot/drugprot.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for ebm_pico contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/ebm_pico/ebm_pico.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for ehr_rel contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/ehr_rel/ehr_rel.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for essai contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/essai/essai.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for euadr contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/euadr/euadr.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for evidence_inference contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/evidence_inference/evidence_inference.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for gad contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/gad/gad.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for genetag contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/genetag/genetag.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for genia_ptm_event_corpus contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/genia_ptm_event_corpus/genia_ptm_event_corpus.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for genia_relation_corpus contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/genia_relation_corpus/genia_relation_corpus.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for genia_term_corpus contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/genia_term_corpus/genia_term_corpus.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for geokhoj_v1 contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/geokhoj_v1/geokhoj_v1.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for ggponc2 contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/ggponc2/ggponc2.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for gnormplus contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/gnormplus/gnormplus.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for hallmarks_of_cancer contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/hallmarks_of_cancer/hallmarks_of_cancer.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for hprd50 contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/hprd50/hprd50.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for iepa contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/iepa/iepa.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for jnlpba contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/jnlpba/jnlpba.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for linnaeus contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/linnaeus/linnaeus.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for lll contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/lll/lll.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for mayosrs contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/mayosrs/mayosrs.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for med_qa contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/med_qa/med_qa.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for medal contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/medal/medal.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for meddialog contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/meddialog/meddialog.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for meddocan contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/meddocan/meddocan.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for medhop contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/medhop/medhop.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for medical_data contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/medical_data/medical_data.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for mediqa_nli contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/mediqa_nli/mediqa_nli.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for mediqa_qa contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/mediqa_qa/mediqa_qa.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for mediqa_rqe contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/mediqa_rqe/mediqa_rqe.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for medmentions contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/medmentions/medmentions.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for mednli contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/mednli/mednli.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for meqsum contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/meqsum/meqsum.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for minimayosrs contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/minimayosrs/minimayosrs.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for mirna contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/mirna/mirna.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for mlee contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/mlee/mlee.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for mqp contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/mqp/mqp.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for msh_wsd contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/msh_wsd/msh_wsd.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for muchmore contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/muchmore/muchmore.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for multi_xscience contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/multi_xscience/multi_xscience.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# ...
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for pcr contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/pcr/pcr.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for pdr contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/pdr/pdr.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for pharmaconer contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/pharmaconer/pharmaconer.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for pico_extraction contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/pico_extraction/pico_extraction.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for pmc_patients contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/pmc_patients/pmc_patients.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for progene contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/progene/progene.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for psytar contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/psytar/psytar.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for pubhealth contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/pubhealth/pubhealth.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for pubmed_qa contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/pubmed_qa/pubmed_qa.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for pubtator_central contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/pubtator_central/pubtator_central.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for quaero contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/quaero/quaero.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for scai_chemical contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/scai_chemical/scai_chemical.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for scai_disease contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/scai_disease/scai_disease.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for scicite contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/scicite/scicite.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for scielo contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/scielo/scielo.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for scifact contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/scifact/scifact.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for sciq contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/sciq/sciq.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for scitail contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/scitail/scitail.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for sem_eval_2024_task_2 contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/sem_eval_2024_task_2/sem_eval_2024_task_2.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for seth_corpus contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/seth_corpus/seth_corpus.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for spl_adr_200db contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/spl_adr_200db/spl_adr_200db.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for swedish_medical_ner contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/swedish_medical_ner/swedish_medical_ner.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for tmvar_v1 contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/tmvar_v1/tmvar_v1.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for tmvar_v2 contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/tmvar_v2/tmvar_v2.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for tmvar_v3 contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/tmvar_v3/tmvar_v3.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for twadrl contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/twadrl/twadrl.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for umnsrs contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/umnsrs/umnsrs.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# /nethome/cye73/conda_envs/arboel_2/lib/python3.9/site-packages/datasets/load.py:923: FutureWarning: The repository for verspoor_2013 contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at /home2/cye73/biomedical-entity-linking/biomedical/bigbio/hub/hub_repos/verspoor_2013/verspoor_2013.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(

# %%
from bioel.ontology import BiomedicalOntology

test_cases = [{'filepath': 'https://raw.githubusercontent.com/DiseaseOntology/HumanDiseaseOntology/main/src/ontology/doid.obo',
        'name': 'disease ontology',
        'prefix_to_keep': None,
        'entity_type': 'DISEASE',
        'abbrev': 'DOID'},
        {'filepath': 'http://purl.obolibrary.org/obo/cl.obo',
        'name': 'cell ontology',
        'prefix_to_keep': 'CL',
        'entity_type': 'CELL_TYPE',
        'abbrev': 'CL'},
        {'filepath': 'http://purl.obolibrary.org/obo/uberon.obo',
        'name': 'uberon',
        'prefix_to_keep': 'UBERON',
        'entity_type': 'TISSUE',
        'abbrev': 'UBERON'},
        {'filepath': 'http://purl.obolibrary.org/obo/obi.obo',
        'name': 'ontology of biological investigations',
        'prefix_to_keep': 'OBI',
        'entity_type': 'EXP_ASSAY',
        'abbrev': 'OBI'},
        {'filepath': 'https://ftp.expasy.org/databases/cellosaurus/cellosaurus.obo',
        'name': 'cellosaurus',
        'prefix_to_keep': None,
        'entity_type': 'CELL_LINE',
        'abbrev': 'CVCL'},
        {'filepath': 'http://purl.obolibrary.org/obo/go.obo',
        'name': 'gene ontology',
        'prefix_to_keep': None,
        'entity_type': 'SUBCELLULAR',
        'abbrev': 'GO'},
        {'filepath': 'http://purl.obolibrary.org/obo/po.obo',
        'name': 'plant ontology',
        'prefix_to_keep': "PO",
        'entity_type': 'TISSUE',
        'abbrev': 'PO'},
        {'filepath': 'http://purl.obolibrary.org/obo/chebi.obo',
        'name': 'ChEBI',
        'prefix_to_keep': None,
        'entity_type': 'SMALL_MOLECULE',
        'abbrev': 'CHEBI'},
        ]

for obo_dict in test_cases:
    ontology = BiomedicalOntology.load_obo(**obo_dict)
    display(ontology.entities[:10])

# %% [markdown]
# ## Get the ontology

# %%
from bioel.ontology import BiomedicalOntology

obo_dict = {'filepath': 'https://raw.githubusercontent.com/DiseaseOntology/HumanDiseaseOntology/main/src/ontology/doid.obo',
        'name': 'disease ontology',
        'prefix_to_keep': None,
        'entity_type': 'DISEASE',
        'abbrev': 'DOID'}

ontology = BiomedicalOntology.load_obo(**obo_dict)
# Out:
# [2024-04-01 14:51:14] [ontology.py] [INFO] Reading OBO ontology from https://raw.githubusercontent.com/DiseaseOntology/HumanDiseaseOntology/main/src/ontology/doid.obo
# 100%|██████████| 11537/11537 [00:00<00:00, 52108.79it/s]

# %%
ontology.entities[0]
# Out:
# BiomedicalEntity(cui='DOID:0001816', name='angiosarcoma', types=['DISEASE'], aliases=['hemangiosarcoma'], definition='A vascular cancer that derives_from the cells that line the walls of blood vessels or lymphatic vessels.', equivalant_cuis=['DOID:267', 'DOID:4508'], taxonomy=None, metadata=None)

# %%
ontology.entities[0].cui
# Out:
# 'DOID:0001816'

# %%
print("Attributes and Methods : ", dir(ontology))
# Out:
# Attributes and Methods :  ['__annotations__', '__class__', '__dataclass_fields__', '__dataclass_params__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'abbrev', 'entities', 'get_aliases', 'get_canonical_name', 'get_definition', 'get_types', 'load_csv', 'load_json', 'load_mesh', 'load_ncbi_taxon', 'load_obo', 'load_umls', 'metadata', 'name', 'types']

# %% [markdown]
# ## Get the entities in the ontology

# %%
ontology_entities = ontology.entities

# %%
display(ontology.entities[0])
# Out:
# BiomedicalEntity(cui='DOID:0001816', name='angiosarcoma', types=['DISEASE'], aliases=['hemangiosarcoma'], definition='A vascular cancer that derives_from the cells that line the walls of blood vessels or lymphatic vessels.', equivalant_cuis=['DOID:267', 'DOID:4508'], taxonomy=None, metadata=None)

# %%
# Create a list of dictionaries, each representing a row in the DataFrame
data = [{
    'cui': entity.cui,
    'name': entity.name,
    'types': entity.types,
    'aliases': entity.aliases if hasattr(entity, 'aliases') else [],
    'definition': entity.definition,
    'equivalent_cuis': entity.equivalent_cuis if hasattr(entity, 'equivalent_cuis') and entity.equivalent_cuis is not None else [],
    'taxonomy': entity.taxonomy,
    'metadata': entity.metadata
} for entity in ontology_entities]

# Create the pandas DataFrame
ontology_df = pd.DataFrame(data)

# Display the DataFrame
ontology_df.head()  # This prints the first few rows of the DataFrame
# Out:
#             cui                   name      types  \
# 0  DOID:0001816           angiosarcoma  [DISEASE]
# 1  DOID:0002116              pterygium  [DISEASE]
# 2  DOID:0014667  disease of metabolism  [DISEASE]
# 3  DOID:0040001         shrimp allergy  [DISEASE]
# 4  DOID:0040002        aspirin allergy  [DISEASE]
#
#                                        aliases  \
# 0                            [hemangiosarcoma]
# 1                               [surfer's eye]
# 2                          [metabolic disease]
# 3                                           []
# 4  [acetylsalicylic acid allergy, ASA allergy]
#
#                                           definition equivalent_cuis taxonomy  \
# 0  A vascular cancer that derives_from the cells ...              []     None
# 1  A corneal disease that is characterized by a t...              []     None
# 2  A disease that involving errors in metabolic p...              []     None
# 3  A crustacean allergy that has_allergic_trigger...              []     None
# 4  A drug allergy that has_allergic_trigger acety...              []     None
#
#   metadata
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None

# %% [markdown]
# ### Check if the dataset has any null definition

# %%
null_definitions = ontology_df['definition'].isnull()

# Get the index of rows with null definitions
null_definitions_indices = ontology_df[ontology_df['definition'].isnull()].index
print(f"Indices of rows with null definitions: {null_definitions_indices.tolist()}")
# Out:
# Indices of rows with null definitions: [5978, 5989, 5992, 6012, 6016, 6017, 6026, 6029, 6030, 6060, 6080, 6082, 6085, 6086, 6088, 6093, 6094, 6102, 6103, 6104, 6106, 6107, 6109, 6110, 6111, 6121, 6123, 6124, 6125, 6126, 6135, 6140, 6145, 6150, 6154, 6157, 6158, 6164, 6166, 6167, 6171, 6172, 6173, 6175, 6176, 6177, 6178, 6180, 6188, 6192, 6193, 6195, 6199, 6200, 6202, 6204, 6207, 6208, 6218, 6219, 6221, 6223, 6224, 6226, 6228, 6231, 6232, 6238, 6239, 6243, 6244, 6246, 6247, 6249, 6251, 6256, 6261, 6266, 6278, 6282, 6283, 6285, 6290, 6291, 6292, 6294, 6295, 6297, 6298, 6300, 6306, 6307, 6308, 6309, 6310, 6311, 6312, 6313, 6314, 6318, 6322, 6328, 6330, 6338, 6340, 6343, 6344, 6345, 6346, 6347, 6348, 6349, 6354, 6361, 6365, 6366, 6369, 6371, 6378, 6382, 6388, 6390, 6392, 6393, 6400, 6401, 6402, 6403, 6404, 6405, 6406, 6407, 6409, 6419, 6420, 6421, 6422, 6423, 6426, 6428, 6429, 6430, 6432, 6434, 6438, 6444, 6445, 6447, 6448, 6449, 6451, 6452, 6453, 6455, 6457, 6458, 6459, 6463, 6467, 6468, 6469, 6471, 6472, 6477, 6481, 6483, 6485, 6487, 6490, 6493, 6496, 6497, 6498, 6502, 6504, 6505, 6506, 6507, 6508, 6509, 6511, 6512, 6518, 6525, 6527, 6528, 6529, 6530, 6532, 6536, 6537, 6539, 6541, 6542, 6543, 6544, 6546, 6550, 6551, 6553, 6554, 6556, 6557, 6558, 6559, 6564, 6571, 6572, 6580, 6582, 6587, 6591, 6594, 6595, 6596, 6598, 6600, 6601, 6602, 6603, 6607, 6608, 6610, 6611, 6612, 6613, 6614, 6616, 6617, 6620, 6622, 6623, 6626, 6628, 6629, 6630, 6631, 6633, 6634, 6635, 6637, 6638, 6639, 6641, 6643, 6647, 6648, 6653, 6654, 6655, 6658, 6660, 6663, 6666, 6667, 6668, 6670, 6673, 6674, 6675, 6678, 6680, 6683, 6685, 6686, 6687, 6688, 6689, 6692, 6695, 6696, 6701, 6703, 6709, 6711, 6712, 6713, 6716, 6718, 6719, 6720, 6721, 6722, 6723, 6724, 6725, 6728, 6729, 6730, 6737, 6738, 6739, 6740, 6741, 6748, 6749, 6750, 6753, 6755, 6756, 6757, 6759, 6760, 6763, 6765, 6766, 6767, 6772, 6773, 6774, 6776, 6778, 6779, 6782, 6783, 6785, 6786, 6787, 6788, 6789, 6790, 6791, 6794, 6796, 6797, 6798, 6799, 6802, 6803, 6805, 6806, 6807, 6810, 6814, 6820, 6821, 6828, 6830, 6832, 6836, 6837, 6838, 6841, 6842, 6843, 6848, 6851, 6852, 6853, 6854, 6855, 6857, 6859, 6862, 6865, 6866, 6872, 6873, 6874, 6876, 6879, 6883, 6884, 6885, 6886, 6887, 6890, 6891, 6892, 6893, 6897, 6904, 6905, 6912, 6913, 6916, 6917, 6918, 6921, 6922, 6923, 6924, 6925, 6927, 6928, 6937, 6939, 6940, 6941, 6946, 6947, 6955, 6956, 6957, 6959, 6960, 6961, 6962, 6969, 6970, 6971, 6973, 6974, 6980, 6982, 6983, 6986, 6987, 6988, 6989, 6990, 6991, 6992, 6993, 6996, 6997, 7001, 7002, 7003, 7007, 7009, 7013, 7015, 7016, 7017, 7018, 7020, 7023, 7025, 7026, 7027, 7029, 7030, 7031, 7032, 7036, 7038, 7039, 7042, 7045, 7048, 7050, 7051, 7052, 7053, 7054, 7057, 7058, 7059, 7061, 7062, 7063, 7064, 7065, 7066, 7070, 7072, 7074, 7076, 7077, 7080, 7084, 7086, 7091, 7096, 7099, 7102, 7103, 7105, 7106, 7107, 7109, 7110, 7111, 7130, 7131, 7132, 7137, 7138, 7141, 7142, 7143, 7146, 7147, 7148, 7150, 7151, 7152, 7153, 7156, 7161, 7162, 7163, 7164, 7165, 7167, 7168, 7170, 7171, 7173, 7174, 7179, 7182, 7184, 7187, 7190, 7191, 7193, 7194, 7196, 7198, 7202, 7205, 7208, 7210, 7212, 7213, 7215, 7217, 7218, 7219, 7220, 7221, 7222, 7223, 7224, 7225, 7226, 7228, 7229, 7233, 7242, 7243, 7244, 7246, 7247, 7248, 7250, 7251, 7252, 7260, 7261, 7262, 7263, 7264, 7266, 7272, 7281, 7282, 7284, 7285, 7289, 7290, 7291, 7293, 7296, 7299, 7302, 7303, 7304, 7306, 7307, 7309, 7310, 7311, 7313, 7314, 7316, 7320, 7321, 7323, 7324, 7334, 7336, 7338, 7340, 7341, 7343, 7345, 7346, 7348, 7349, 7351, 7352, 7355, 7358, 7362, 7363, 7364, 7368, 7369, 7370, 7374, 7375, 7377, 7378, 7379, 7381, 7383, 7386, 7387, 7391, 7393, 7394, 7396, 7398, 7399, 7400, 7401, 7402, 7404, 7405, 7406, 7408, 7410, 7411, 7412, 7414, 7415, 7416, 7417, 7423, 7428, 7431, 7432, 7435, 7437, 7438, 7439, 7446, 7447, 7448, 7449, 7450, 7452, 7454, 7455, 7456, 7462, 7470, 7472, 7473, 7474, 7475, 7479, 7484, 7486, 7490, 7491, 7501, 7502, 7506, 7507, 7511, 7513, 7514, 7515, 7517, 7519, 7522,  ...

# %% [markdown]
# ### Get canonical name of entities in the ontology

# %%
def get_canonical_name(df):
    # Extract tuples of CUI and canonical names (aliases) from the DataFrame
    canonical_names = {row['cui']: row['name'] for index, row in df.iterrows()}
    return canonical_names

# %%
ontology_to_name = get_canonical_name(ontology_df)
print("\nThis mapping is a specific application of the canonical name concept within the context of UMLS, linking each unique concept (identified by its CUI) to its preferred term")
print('\nThe first 5 elements are:')
print(list(ontology_to_name.items())[:5])
# Out:
# This mapping is a specific application of the canonical name concept within the context of UMLS, linking each unique concept (identified by its CUI) to its preferred term
#
# The first 5 elements are:
# [('DOID:0001816', 'angiosarcoma'), ('DOID:0002116', 'pterygium'), ('DOID:0014667', 'disease of metabolism'), ('DOID:0040001', 'shrimp allergy'), ('DOID:0040002', 'aspirin allergy')]

# %% [markdown]
# ### Get aliases of entities in the ontology

# %%
def get_aliases(df):
    # aliases are collected into a flat list instead of a list of lists
    def flatten_aliases(alias_lists):
        # Flatten a list of lists into a single list
        return [alias for sublist in alias_lists for alias in sublist]
    
    # Group by 'cui', aggregate aliases into a list, and then flatten the list of lists
    grouped = df.groupby('cui')['aliases'].agg(flatten_aliases).to_dict()

    return grouped

# %%
ontology_to_alias = get_aliases(ontology_df)
print(list(ontology_to_alias.items())[:5])
# Out:
# [('DOID:0001816', ['hemangiosarcoma']), ('DOID:0002116', ["surfer's eye"]), ('DOID:0014667', ['metabolic disease']), ('DOID:0040001', []), ('DOID:0040002', ['acetylsalicylic acid allergy', 'ASA allergy'])]

# %% [markdown]
# ### Get definition of entities in the ontology

# %%
def get_definition(df):
    # Filter out rows where the definition column is null
    df_non_null_definitions = df.dropna(subset=['definition'])
    
    # Extract tuples of CUI and definition from the DataFrame
    definitions_dict = {row['cui']: row['definition'] for index, row in df_non_null_definitions.iterrows()}
    
    return definitions_dict

# %%
ontology_cui2definition = get_definition(ontology_df)
print('\nThe first 5 elements are:')
print(list(ontology_cui2definition.items())[:5])
# Out:
# The first 5 elements are:
# [('DOID:0001816', 'A vascular cancer that derives_from the cells that line the walls of blood vessels or lymphatic vessels.'), ('DOID:0002116', 'A corneal disease that is characterized by a triangular tissue growth located_in cornea of the eye that is the result of collagen degeneration and fibrovascular proliferation.'), ('DOID:0014667', 'A disease that involving errors in metabolic processes of building or degradation of molecules.'), ('DOID:0040001', 'A crustacean allergy that has_allergic_trigger shrimp.'), ('DOID:0040002', 'A drug allergy that has_allergic_trigger acetylsalicylic acid.')]

# %% [markdown]
# ### Get types of entities in the ontology

# %%
def get_types(df):
    '''
    Get type of entities in the ontology
    df: panda dataframe
    '''
    # Extract tuples of CUI and types from the DataFrame
    types = {row['cui']: row['types'] for index, row in df.iterrows()}
    return types

# %%
ontology_cui2tui = get_types(ontology_df)
print('\nThe first 5 elements are:')
print(list(ontology_cui2tui.items())[:5])
# Out:
# The first 5 elements are:
# [('DOID:0001816', ['DISEASE']), ('DOID:0002116', ['DISEASE']), ('DOID:0014667', ['DISEASE']), ('DOID:0040001', ['DISEASE']), ('DOID:0040002', ['DISEASE'])]

# %% [markdown]
# # Function

# %%
def process_obo_ontology(ontology, 
                     dataset,
                     model):
    '''
    This function prepares the entity data : dictionary.pickle
    
    Parameters 
    ----------
    - dataset : str
    Name of the dataset
    - ontology : str (only umls for now)
    Ontology associated with the dataset
    '''
    
    # Entities in the ontology
    ontology_entities = ontology.entities
    # Create a list of dictionaries, each representing a row in the DataFrame
    data = [{
    'cui': entity.cui,
    'name': entity.name,
    'types': entity.types,
    'aliases': entity.aliases if hasattr(entity, 'aliases') else [],
    'definition': entity.definition,
    'equivalent_cuis': entity.equivalent_cuis if hasattr(entity, 'equivalent_cuis') and entity.equivalent_cuis is not None else [],
    'taxonomy': entity.taxonomy,
    'metadata': entity.metadata
    } for entity in ontology_entities]

    # Create the pandas DataFrame
    ontology_df = pd.DataFrame(data)
    
    # Get canonical name of entities in the ontology
    ontology_to_name = get_canonical_name(ontology_df)
    # Get aliases of entities in the ontology
    ontology_to_alias = get_aliases(ontology_df)
    # Get definition of entities in the ontology
    ontology_cui2definition = get_definition(ontology_df)
    # Get types of entities in the ontology
    ontology_cui2tui = get_types(ontology_df)


    # Check if the directory exists, and create it if it does not
    directory_path = f'../data/{model}/{dataset}/'
    if not os.path.exists(directory_path):
        os.makedirs(directory_path)

    ontology_entities = []
    for cui, name in tqdm(ontology_to_name.items()):
        d = {}
        ent_type = ontology_cui2tui[cui]
        d['type'] = ent_type
        other_aliases = [x for x in ontology_to_alias[cui] if x != name]
        joined_aliases = ' ; '.join(other_aliases)
        # d['cui'] = f"ontology_name:{cui}"
        d['cui'] = f"ontology:{cui}"
        d['title'] = name
        if cui in ontology_cui2definition:
            definition = ontology_cui2definition[cui]
        else:
            definition = None

        if len(other_aliases) > 0:
            if definition is not None:
                d['description'] = f"{name} ( {ent_type} : {joined_aliases} ) [ {definition} ]"
            else:
                d['description'] = f"{name} ( {ent_type} : {joined_aliases} )"
        else:
            if definition is not None:
                d['description'] = f"{name} ( {ent_type} ) [ {definition} ]"
            else:
                d['description'] = f"{name} ( {ent_type} )"

        ontology_entities.append(d)

    pickle.dump(ontology_entities, open(f'../data/{model}/{dataset}/dictionary.pickle', 'wb'))
    entities = pickle.load(open(f'../data/{model}/{dataset}/dictionary.pickle', 'rb'))
    return entities

# %% [markdown]
# ## Test

# %%
obo_dict = {'filepath': 'https://raw.githubusercontent.com/DiseaseOntology/HumanDiseaseOntology/main/src/ontology/doid.obo',
        'name': 'disease ontology',
        'prefix_to_keep': None,
        'entity_type': 'DISEASE',
        'abbrev': 'DOID'}

obo_dict2 = {'filepath': 'http://purl.obolibrary.org/obo/chebi.obo',
        'name': 'ChEBI',
        'prefix_to_keep': None,
        'entity_type': 'SMALL_MOLECULE',
        'abbrev': 'CHEBI'}

obo_dict3 = {'filepath': 'http://purl.obolibrary.org/obo/po.obo',
        'name': 'plant ontology',
        'prefix_to_keep': "PO",
        'entity_type': 'TISSUE',
        'abbrev': 'PO'}
        
obo_dict4 = {'filepath': 'http://purl.obolibrary.org/obo/cl.obo',
        'name': 'cell ontology',
        'prefix_to_keep': 'CL',
        'entity_type': 'CELL_TYPE',
        'abbrev': 'CL'}

obo_dict5 = {'filepath': 'http://purl.obolibrary.org/obo/uberon.obo',
        'name': 'uberon',
        'prefix_to_keep': 'UBERON',
        'entity_type': 'TISSUE',
        'abbrev': 'UBERON'}

obo_dict6 = {'filepath': 'http://purl.obolibrary.org/obo/obi.obo',
        'name': 'ontology of biological investigations',
        'prefix_to_keep': 'OBI',
        'entity_type': 'EXP_ASSAY',
        'abbrev': 'OBI'}

obo_dict7 = {'filepath': 'https://ftp.expasy.org/databases/cellosaurus/cellosaurus.obo',
        'name': 'cellosaurus',
        'prefix_to_keep': None,
        'entity_type': 'CELL_LINE',
        'abbrev': 'CVCL'}

obo_dict8 = {'filepath': 'http://purl.obolibrary.org/obo/go.obo',
        'name': 'gene ontology',
        'prefix_to_keep': None,
        'entity_type': 'SUBCELLULAR',
        'abbrev': 'GO'}

# %%
ontology = BiomedicalOntology.load_obo(**obo_dict)
dataset = "test"
model = "test"
# Out:
# [2024-03-16 14:19:58] [ontology.py] [INFO] Reading OBO ontology from https://raw.githubusercontent.com/DiseaseOntology/HumanDiseaseOntology/main/src/ontology/doid.obo
# 100%|██████████| 11511/11511 [00:00<00:00, 263488.80it/s]

# %%
process_obo_ontology(ontology, 
                     dataset,
                     model)

entities = pickle.load(open(f'../data/{model}/{dataset}/dictionary.pickle', 'rb'))
# Out:
# 100%|██████████| 11511/11511 [00:00<00:00, 82474.60it/s]

# %%
entities
# Out:
# [{'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0001816',
#   'title': 'angiosarcoma',
#   'description': "angiosarcoma ( ['DISEASE'] : hemangiosarcoma ) [ A vascular cancer that derives_from the cells that line the walls of blood vessels or lymphatic vessels. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0002116',
#   'title': 'pterygium',
#   'description': "pterygium ( ['DISEASE'] : surfer's eye ) [ A corneal disease that is characterized by a triangular tissue growth located_in cornea of the eye that is the result of collagen degeneration and fibrovascular proliferation. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0014667',
#   'title': 'disease of metabolism',
#   'description': "disease of metabolism ( ['DISEASE'] : metabolic disease ) [ A disease that involving errors in metabolic processes of building or degradation of molecules. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040001',
#   'title': 'shrimp allergy',
#   'description': "shrimp allergy ( ['DISEASE'] ) [ A crustacean allergy that has_allergic_trigger shrimp. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040002',
#   'title': 'aspirin allergy',
#   'description': "aspirin allergy ( ['DISEASE'] : acetylsalicylic acid allergy ; ASA allergy ) [ A drug allergy that has_allergic_trigger acetylsalicylic acid. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040003',
#   'title': 'benzylpenicillin allergy',
#   'description': "benzylpenicillin allergy ( ['DISEASE'] : benzyl penicillin allergy ; penicillin G allergy ) [ A beta-lactam allergy that has_allergic_trigger benzylpenicillin. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040004',
#   'title': 'amoxicillin allergy',
#   'description': "amoxicillin allergy ( ['DISEASE'] ) [ A beta-lactam allergy that has_allergic_trigger amoxicillin. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040005',
#   'title': 'ceftriaxone allergy',
#   'description': "ceftriaxone allergy ( ['DISEASE'] : rocephin allergy ) [ A cephalosporin allergy that has_allergic_trigger ceftriaxone. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040006',
#   'title': 'carbamazepine allergy',
#   'description': "carbamazepine allergy ( ['DISEASE'] : carbamazepen allergy ; Tegretol allergy ) [ A drug allergy that has_allergic_trigger carbamazepine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040007',
#   'title': 'abacavir allergy',
#   'description': "abacavir allergy ( ['DISEASE'] : ABC allergy ) [ A drug allergy that has_allergic_trigger abacavir. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040008',
#   'title': 'isoniazide allergy',
#   'description': "isoniazide allergy ( ['DISEASE'] : INH allergy ; isonicotinylhydrazide allergy ) [ A drug allergy that has_allergic_trigger isoniazide. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040009',
#   'title': 'lidocaine allergy',
#   'description': "lidocaine allergy ( ['DISEASE'] : Lidoderm allergy ; lignocaine allergy ; xylocaine allergy ) [ A drug allergy that has_allergic_trigger lidocaine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040010',
#   'title': 'mepivacaine allergy',
#   'description': "mepivacaine allergy ( ['DISEASE'] : Carbocaine allergy ; Polocaine allergy ) [ A drug allergy that has_allergic_trigger mepivacaine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040011',
#   'title': 'phenobarbital allergy',
#   'description': "phenobarbital allergy ( ['DISEASE'] : Luminal allergy ; phenobarbitol allergy ; phenobarbitone allergy ) [ A drug allergy that has_allergic_trigger phenobarbital. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040012',
#   'title': 'phenytoin allergy',
#   'description': "phenytoin allergy ( ['DISEASE'] : Dilantin allergy ) [ A drug allergy that has_allergic_trigger phenytoin. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040013',
#   'title': 'ranitidine allergy',
#   'description': "ranitidine allergy ( ['DISEASE'] : Zantac allergy ) [ A drug allergy that has_allergic_trigger ranitidine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040014',
#   'title': 'corticosteroid allergy',
#   'description': "corticosteroid allergy ( ['DISEASE'] ) [ A drug allergy that has_allergic_trigger corticosteroid. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040015',
#   'title': 'sulfonamide allergy',
#   'description': "sulfonamide allergy ( ['DISEASE'] ) [ A drug allergy that has_allergic_trigger sulfonamide. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040016',
#   'title': 'sulfamethoxazole allergy',
#   'description': "sulfamethoxazole allergy ( ['DISEASE'] : SMX allergy ; SMZ allergy ; sulphamethoxazole allergy ) [ A drug allergy that has_allergic_trigger sulfamethoxazole. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040017',
#   'title': 'suprofen allergy',
#   'description': "suprofen allergy ( ['DISEASE'] : Profenal allergy ) [ A drug allergy that has_allergic_trigger suprofen. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040018',
#   'title': 'thiopental allergy',
#   'description': "thiopental allergy ( ['DISEASE'] : penthiobarbital allergy ; pentothiobarbital allergy ) [ A drug allergy that has_allergic_trigger thiopental. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040019',
#   'title': 'D-mannitol allergy',
#   'description': "D-mannitol allergy ( ['DISEASE'] : mannitol allergy ) [ A drug allergy that has_allergic_trigger D-mannitol. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040020',
#   'title': 'cefotaxime allergy',
#   'description': "cefotaxime allergy ( ['DISEASE'] ) [ A cephalosporin allergy that has_allergic_trigger cefotaxime. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040021',
#   'title': 'cephalosporin allergy',
#   'description': "cephalosporin allergy ( ['DISEASE'] ) [ A drug allergy that has_allergic_trigger cephalosporin. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040022',
#   'title': 'amodiaquine allergy',
#   'description': "amodiaquine allergy ( ['DISEASE'] : Camoquin allergy ; Flavoquine allergy ) [ A drug allergy that has_allergic_trigger amodiaquine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040023',
#   'title': 'cefaclor allergy',
#   'description': "cefaclor allergy ( ['DISEASE'] : Ceclor allergy ; cephaclor allergy ) [ A cephalosporin allergy that has_allergic_trigger cefaclor. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040024',
#   'title': 'ceftazidime allergy',
#   'description': "ceftazidime allergy ( ['DISEASE'] : Fortaz allergy ; Tazicef allergy ) [ A cephalosporin allergy that has_allergic_trigger ceftazidime. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040025',
#   'title': 'cefuroxime allergy',
#   'description': "cefuroxime allergy ( ['DISEASE'] : cephuroxime allergy ; Zinacef allergy ) [ A cephalosporin allergy that has_allergic_trigger cefuroxime. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040026',
#   'title': 'chlorhexidine allergy',
#   'description': "chlorhexidine allergy ( ['DISEASE'] ) [ A drug allergy that has_allergic_trigger chlorhexidine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040027',
#   'title': 'cyclophosphamide allergy',
#   'description': "cyclophosphamide allergy ( ['DISEASE'] : cytophosphane allergy ) [ A drug allergy that has_allergic_trigger cyclophosphamide. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040028',
#   'title': 'succinylcholine allergy',
#   'description': "succinylcholine allergy ( ['DISEASE'] : dicholine succinate allergy ; succinocholine allergy ; sux allergy ; suxamethonium allergy ) [ A drug allergy that has_allergic_trigger succinylcholine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040029',
#   'title': 'trimethoprim allergy',
#   'description': "trimethoprim allergy ( ['DISEASE'] : Primsol allergy ; proloprim allergy ; TMP allergy ) [ A drug allergy that has_allergic_trigger trimethoprim. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040030',
#   'title': 'cefixime allergy',
#   'description': "cefixime allergy ( ['DISEASE'] ) [ A cephalosporin allergy that has_allergic_trigger cefixime. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040031',
#   'title': 'diclofenac allergy',
#   'description': "diclofenac allergy ( ['DISEASE'] : Voltaren allergy ) [ A drug allergy that has_allergic_trigger diclofenac. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040032',
#   'title': 'carbapenem allergy',
#   'description': "carbapenem allergy ( ['DISEASE'] ) [ A drug allergy that has_allergic_trigger carbapenems. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040033',
#   'title': 'piperacillin allergy',
#   'description': "piperacillin allergy ( ['DISEASE'] ) [ A beta-lactam allergy that has_allergic_trigger piperacillin. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040034',
#   'title': 'rocuronium allergy',
#   'description': "rocuronium allergy ( ['DISEASE'] : Esmeron allergy ; Zemuron allergy ) [ A drug allergy that has_allergic_trigger rocuronium. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040035',
#   'title': 'sulfasalazine allergy',
#   'description': "sulfasalazine allergy ( ['DISEASE'] ) [ A drug allergy that has_allergic_trigger sulfasalazine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040036',
#   'title': 'tubocurarine allergy',
#   'description': "tubocurarine allergy ( ['DISEASE'] : DTC allergy ) [ A drug allergy that has_allergic_trigger tubocurarine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040037',
#   'title': 'aztreonam allergy',
#   'description': "aztreonam allergy ( ['DISEASE'] : Azactam allergy ; Primbactam allergy ) [ A beta-lactam allergy that has_allergic_trigger aztreonam. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040038',
#   'title': 'meropenem allergy',
#   'description': "meropenem allergy ( ['DISEASE'] : Merrem allergy ) [ An allergic asthma that has_allergic_trigger meropenem, a beta-lactam antibiotic. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040040',
#   'title': 'hexamethylene diisocyanate allergic asthma',
#   'description': "hexamethylene diisocyanate allergic asthma ( ['DISEASE'] : allergic asthma to HDI ; allergic asthma to HMDI ) [ An isocyanates allergic asthma that has_allergic_trigger hexamethylene diisocyanate. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040041',
#   'title': 'isocyanates allergic asthma',
#   'description': "isocyanates allergic asthma ( ['DISEASE'] ) [ An allergic asthma that has_allergic_trigger isocyanates. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040042',
#   'title': "diphenylmethane-4,4'-diisocyanate allergic asthma",
#   'description': "diphenylmethane-4,4'-diisocyanate allergic asthma ( ['DISEASE'] : allergic asthma to MDI ) [ An isocyanates allergic asthma that has_allergic_trigger diphenylmethane-4,4-diisocyanate. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040043',
#   'title': 'toluene meta-diisocyanate allergic asthma',
#   'description': "toluene meta-diisocyanate allergic asthma ( ['DISEASE'] : allergic asthma to TDI ) [ An isocyanates allergic asthma that has_allergic_trigger toluene meta-diisocyanate. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040044',
#   'title': 'methyl isocyanate allergic asthma',
#   'description': "methyl isocyanate allergic asthma ( ['DISEASE'] : allergic asthma to MIC ) [ An isocyanates allergic asthma that has_allergic_trigger methyl isocyanate. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040045',
#   'title': 'nickel allergic asthma',
#   'description': "nickel allergic asthma ( ['DISEASE'] : allergic asthma to Ni ) [ An allergic asthma that has_allergic_trigger nickel atom. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040046',
#   'title': 'nickel allergic contact dermatitis',
#   'description': "nickel allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to Ni ) [ An allergic contact dermatitis that has_allergic_trigger nickel atom. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040047',
#   'title': 'trimellitic anhydride allergic asthma',
#   'description': "trimellitic anhydride allergic asthma ( ['DISEASE'] : allergic asthma to TMA ) [ An allergic asthma that has_allergic_trigger trimellitic anhydride. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040048',
#   'title': 'phthalic anhydride allergic asthma',
#   'description': "phthalic anhydride allergic asthma ( ['DISEASE'] ) [ An allergic asthma that has_allergic_trigger phthalic anhydride. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040049',
#   'title': 'maleic anhydride allergic asthma',
#   'description': "maleic anhydride allergic asthma ( ['DISEASE'] : allergic asthma to MA ) [ An allergic asthma that has_allergic_trigger maleic anhydride. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040050',
#   'title': 'tetrachlorophthalic anhydride allergic asthma',
#   'description': "tetrachlorophthalic anhydride allergic asthma ( ['DISEASE'] ) [ An allergic asthma that has_allergic_trigger tetrachlorophthalic anhydride. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040051',
#   'title': 'hexahydrophthalic anhydride allergic asthma',
#   'description': "hexahydrophthalic anhydride allergic asthma ( ['DISEASE'] : allergic asthma to HHPA ) [ An allergic asthma that has_allergic_trigger hexahydrophthalic anhydride. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040052',
#   'title': "diphenylmethane-4,4'-diisocyanate allergic contact dermatitis",
#   'description': "diphenylmethane-4,4'-diisocyanate allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to MDI ) [ An allergic contact dermatitis that has_allergic_trigger diphenylmethane-4,4-diisocyanate. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040053',
#   'title': 'cobalt allergic contact dermatitis',
#   'description': "cobalt allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to Co ) [ An allergic contact dermatitis that has_allergic_trigger cobalt atom. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040054',
#   'title': 'cobalt allergic asthma',
#   'description': "cobalt allergic asthma ( ['DISEASE'] : Co allergic asthma ) [ An allergic asthma that has_allergic_trigger cobalt atom. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040055',
#   'title': 'palladium allergic contact dermatitis',
#   'description': "palladium allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to Pd ) [ An allergic contact dermatitis that has_allergic_trigger palladium. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040056',
#   'title': 'chromium allergic contact dermatitis',
#   'description': "chromium allergic contact dermatitis ( ['DISEASE'] ) [ An allergic contact dermatitis that has_allergic_trigger chromium atom. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040057',
#   'title': 'benzoic acid allergic contact dermatitis',
#   'description': "benzoic acid allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to benzoate ) [ An allergic contact dermatitis that has_allergic_trigger benzoic acid. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040058',
#   'title': '1,4-phenylenediamine allergic contact dermatitis',
#   'description': "1,4-phenylenediamine allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to p-phenylenediamine ; allergic contact dermatitis to PPD ) [ An allergic contact dermatitis that has_allergic_trigger 1,4-phenylenediamine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040059',
#   'title': 'potassium dichromate allergic contact dermatitis',
#   'description': "potassium dichromate allergic contact dermatitis ( ['DISEASE'] ) [ An allergic contact dermatitis that has_allergic_trigger potassium dichromate. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040060',
#   'title': 'ketoprofen photoallergic dermatitis',
#   'description': "ketoprofen photoallergic dermatitis ( ['DISEASE'] : photoallergic dermatitis to Orudis ) [ A photoallergic dermatitis that has_allergic_trigger ketoprofen. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040061',
#   'title': 'remazole black respiratory allergy',
#   'description': "remazole black respiratory allergy ( ['DISEASE'] : respiratory allergy to Reactive Black 5 ) [ A respiratory allergy that has_allergic_trigger remazole black-GR. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040062',
#   'title': 'chloramine T respiratory allergy',
#   'description': "chloramine T respiratory allergy ( ['DISEASE'] : respiratory allergy to Chloraseptin ; respiratory allergy to Chlorazol ; respiratory allergy to Trichlorol ) [ A respiratory allergy that has_allergic_trigger chloramine T. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040063',
#   'title': '4-vinylcyclohexene dioxide respiratory allergy',
#   'description': "4-vinylcyclohexene dioxide respiratory allergy ( ['DISEASE'] : respiratory allergy to vinyl cyclohexene diepoxide ) [ A respiratory allergy that has_allergic_trigger 4-vinylcyclohexene dioxide. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040064',
#   'title': 'carvone allergic contact dermatitis',
#   'description': "carvone allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to levo-carvone ) [ An allergic contact dermatitis that has_allergic_trigger (-)-carvone. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040065',
#   'title': 'quinidine allergy',
#   'description': "quinidine allergy ( ['DISEASE'] : Kinidin allergy ) [ A drug allergy that has_allergic_trigger quinidine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040066',
#   'title': 'melphalan allergy',
#   'description': "melphalan allergy ( ['DISEASE'] : Alkeran allergy ) [ A drug allergy that has_allergic_trigger melphalan. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040067',
#   'title': 'neomycin sulfate allergic contact dermatitis',
#   'description': "neomycin sulfate allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to neomycin sulphate ) [ An allergic contact dermatitis that has_allergic_trigger neomycin sulfate. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040068',
#   'title': '4-tert-butylphenol allergic contact dermatitis',
#   'description': "4-tert-butylphenol allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to butylphen ; allergic contact dermatitis to PTBP ) [ An allergic contact dermatitis that has_allergic_trigger 4-tert-butylphenol. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040069',
#   'title': '1-chloro-2,4-dinitrobenzene allergic contact dermatitis',
#   'description': "1-chloro-2,4-dinitrobenzene allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to dinitrochlorobenzene ; allergic contact dermatitis to DNCB ) [ An allergic contact dermatitis that has_allergic_trigger 1-chloro-2,4-dinitrobenzene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040070',
#   'title': 'co-trimoxazole allergy',
#   'description': "co-trimoxazole allergy ( ['DISEASE'] : Bactrim allergy ; cotrimoxazol allergy ; TMP/SMX allergy ; trimethoprim/sulfamethoxazole allergy ) [ A drug allergy that has_allergic_trigger co-trimoxazole. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040071',
#   'title': 'sodium aurothiomalate allergy',
#   'description': "sodium aurothiomalate allergy ( ['DISEASE'] : gold sodium thiomalate allergy ) [ A drug allergy that has_allergic_trigger sodium aurothiomalate. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040072',
#   'title': 'parthenolide allergic contact dermatitis',
#   'description': "parthenolide allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to feverfew ) [ An allergic contact dermatitis that has_allergic_trigger parthenolide. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040073',
#   'title': 'disodium cromoglycate allergy',
#   'description': "disodium cromoglycate allergy ( ['DISEASE'] : DSCG allergy ) [ A drug allergy that has_allergic_trigger disodium cromoglycate. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040074',
#   'title': 'formaldehyde allergic contact dermatitis',
#   'description': "formaldehyde allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to formalin ) [ An allergic contact dermatitis that has_allergic_trigger formaldehyde. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040075',
#   'title': 'benzo[d]isothiazol-3-one allergic contact dermatitis',
#   'description': "benzo[d]isothiazol-3-one allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to benzisothiazolone ; allergic contact dermatitis to BIT ) [ An allergic contact dermatitis that has_allergic_trigger benzo[d]isothiazol-3-one. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040076',
#   'title': 'phthalyl group allergy',
#   'description': "phthalyl group allergy ( ['DISEASE'] : phthalyl allergy ) [ A drug allergy that has_allergic_trigger phthalyl group. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040077',
#   'title': 'alcuronium bromide allergy',
#   'description': "alcuronium bromide allergy ( ['DISEASE'] ) [ A drug allergy that has_allergic_trigger alcuronium bromide. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040078',
#   'title': 'gallamine allergy',
#   'description': "gallamine allergy ( ['DISEASE'] ) [ A drug allergy that has_allergic_trigger gallamine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040079',
#   'title': '2,4-dinitrophenyl allergic contact dermatitis',
#   'description': "2,4-dinitrophenyl allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to DNP ) [ An allergic contact dermatitis that has_allergic_trigger 2,4-dinitrophenyl group. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040080',
#   'title': 'patent blue V allergy',
#   'description': "patent blue V allergy ( ['DISEASE'] ) [ A drug allergy that has_allergic_trigger patent blue V. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040081',
#   'title': 'acid anhydride respiratory allergy',
#   'description': "acid anhydride respiratory allergy ( ['DISEASE'] ) [ A respiratory allergy that has_allergic_trigger acid anhydride. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040082',
#   'title': 'oxirane allergy',
#   'description': "oxirane allergy ( ['DISEASE'] : ethylene oxide allergy ; ETO allergy ) [ A drug allergy that has_allergic_trigger oxirane. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040083',
#   'title': 'Chlamydia pneumonia',
#   'description': "Chlamydia pneumonia ( ['DISEASE'] ) [ A bacterial pneumonia has_material_basis_in Chlamydia pneumoniae. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040084',
#   'title': 'Streptococcus pneumonia',
#   'description': "Streptococcus pneumonia ( ['DISEASE'] ) [ A bacterial pneumonia has_material_basis_in Streptococcus pneumoniae. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040085',
#   'title': 'bacterial sepsis',
#   'description': "bacterial sepsis ( ['DISEASE'] ) [ A bacterial infectious disease has_material_basis_in Bacteria. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040086',
#   'title': 'Polyomavirus-associated nephropathy',
#   'description': "Polyomavirus-associated nephropathy ( ['DISEASE'] : polyomavirus associated nephropathy ; PVAN ) [ A viral infectious disease has_material_basis_in BK polyomavirus. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040087',
#   'title': 'autoimmune peripheral neuropathy',
#   'description': "autoimmune peripheral neuropathy ( ['DISEASE'] ) [ An autoimmune disease of peripheral nervous system that results in peripheral neuropathy. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040088',
#   'title': 'autoimmune uveitis',
#   'description': "autoimmune uveitis ( ['DISEASE'] ) [ An autoimmune disease of eyes, ear, nose and throat that is located_in the uvea. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040089',
#   'title': 'autoimmune optic neuritis',
#   'description': "autoimmune optic neuritis ( ['DISEASE'] ) [ An autoimmune disease of peripheral nervous system that is located_in the neuron projection bundle connecting eye with brain. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040090',
#   'title': 'autoimmune gastritis',
#   'description': "autoimmune gastritis ( ['DISEASE'] ) [ An autoimmune disease of gastrointestinal tract that is located_in the stomach. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040091',
#   'title': 'autoimmune pancreatitis',
#   'description': "autoimmune pancreatitis ( ['DISEASE'] ) [ An autoimmune disease of endocrine system that is located_in the pancreas. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040092',
#   'title': 'juvenile ankylosing spondylitis',
#   'description': "juvenile ankylosing spondylitis ( ['DISEASE'] ) [ An autoimmune disease of musculoskeletal system that is an ankylosing spondylitis with onset during childhood. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040093',
#   'title': 'drug-induced lupus erythematosus',
#   'description': "drug-induced lupus erythematosus ( ['DISEASE'] : DIL ; DILE ) [ A lupus erythematosus caused by chronic use of certain drugs. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040094',
#   'title': 'autoimmune glomerulonephritis',
#   'description': "autoimmune glomerulonephritis ( ['DISEASE'] ) [ An autoimmune disease of urogenital tract that is located_in the renal glomerulus. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040095',
#   'title': 'autoimmune cardiomyopathy',
#   'description': "autoimmune cardiomyopathy ( ['DISEASE'] ) [ An autoimmune disease of cardiovascular system that is characterized by deterioration of the function of the heart muscle. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040096',
#   'title': 'autoimmune atherosclerosis',
#   'description': "autoimmune atherosclerosis ( ['DISEASE'] ) [ An autoimmune disease of cardiovascular system that is characterized by a build up of plaque in the arteries. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040097',
#   'title': 'autoimmune vasculitis',
#   'description': "autoimmune vasculitis ( ['DISEASE'] ) [ An autoimmune disease of cardiovascular system that is characterized by inflammation of the blood vessels. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040098',
#   'title': 'pemphigus gestationis',
#   'description': "pemphigus gestationis ( ['DISEASE'] ) [ A pemphigus that is characterized by blistered skin as a result of self-reactive T and B cells that target BP180. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040099',
#   'title': 'livedoid vasculitis',
#   'description': "livedoid vasculitis ( ['DISEASE'] : livedoid vasculopathy ) [ A vasculitis with purpuric ulcers. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040100',
#   'title': 'Hirata disease',
#   'description': "Hirata disease ( ['DISEASE'] : insulin autoimmune syndrome ) [ An autoimmune disease of endocrine system characterized by hypoglycemia caused by antibodies to insulin. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040101',
#   'title': "N,N'-diphenylthiourea allergic contact dermatitis",
#   'description': "N,N'-diphenylthiourea allergic contact dermatitis ( ['DISEASE'] : neoprene allergy ) [ An allergic contact dermatitis that has_allergic_trigger N,N-diphenylthiourea. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040102',
#   'title': "N,N'-diethylthiourea allergic contact dermatitis",
#   'description': "N,N'-diethylthiourea allergic contact dermatitis ( ['DISEASE'] : neoprene allergy ) [ An allergic contact dermatitis that has_allergic_trigger N,N-diethylthiourea. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040103',
#   'title': 'cefotiam allergy',
#   'description': "cefotiam allergy ( ['DISEASE'] ) [ A cephalosporin allergy that has_allergic_trigger cefotiam. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0040104',
#   'title': 'toluene 2,4-diisocyanate allergic asthma',
#   'description': "toluene 2,4-diisocyanate allergic asthma ( ['DISEASE'] ) [ A toluene meta-diisocyanate allergic asthma that has_allergic_trigger toluene 2,4-diisocyanate. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050004',
#   'title': 'seminal vesicle acute gonorrhea',
#   'description': "seminal vesicle acute gonorrhea ( ['DISEASE'] ) [ A gonococcal seminal vesiculitis that is characterized by back pain, perineal pain, pain with ejaculation, hematospermia and voiding symptoms resulting from inflammation located_in the seminal vesicles caused by Neisseria gonorrhoeae infection. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050012',
#   'title': 'chikungunya',
#   'description': "chikungunya ( ['DISEASE'] : Chikungunya fever ) [ A viral infectious disease that results_in infection located_in joint, has_material_basis_in Chikungunya virus, which is transmitted_by Aedes mosquito bite. The infection has_symptom fever, has_symptom arthralgia, and has_symptom maculopapular rash. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050025',
#   'title': 'human granulocytic anaplasmosis',
#   'description': "human granulocytic anaplasmosis ( ['DISEASE'] : HGE ; human granulocytic ehrlichiosis ) [ An ehrlichiosis that results in infection located in granular leukocyte, has_material_basis_in Anaplasma phagocytophilum, which is transmitted by lone star tick (Amblyomma americanum). The infection has symptom headache, has symptom muscle aches, has symptom fatigue, has symptom fever and has symptom rash. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050026',
#   'title': 'human monocytic ehrlichiosis',
#   'description': "human monocytic ehrlichiosis ( ['DISEASE'] : Ehrlichiosis chafeensis ) [ An ehrlichiosis that results in infection located in monocyte or located in macrophage, has_material_basis_in Ehrlichia chaffeensis, which is transmitted by black-legged tick (Ixodes scapularis), transmitted by western black-legged tick (Ixodes pacificus) or transmitted by castor bean tick (Ixodes ricinus). The infection has symptom headache, has symptom muscle aches, has symptom fatigue, has symptom fever and has symptom rash. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050032',
#   'title': 'mineral metabolism disease',
#   'description': "mineral metabolism disease ( ['DISEASE'] ) [ An acquired metabolic disease that is characterized by abnormal mineral metabolism. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050035',
#   'title': 'African tick-bite fever',
#   'description': "African tick-bite fever ( ['DISEASE'] : Rickettsia africae spotted fever ; south african tick-bite fever ) [ A spotted fever that has_material_basis_in Rickettsia africae, which is transmitted_by ticks (Amblyomma hebraeum and Amblyomma variegatum). The infection has_symptom fever, has_symptom eschar and has_symptom maculopapular rash. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050041',
#   'title': 'Astrakhan spotted fever',
#   'description': "Astrakhan spotted fever ( ['DISEASE'] ) [ A spotted fever that has_material_basis_in Rickettsia conorii subsp caspia, which is transmitted_by ticks (Rhipicephalus pumilio and Rhipicephalus sanguineus). The infection has_symptom fever, has_symptom eschar (usually single), has_symptom regional adenopathy, has_symptom maculopapular rash on extremities. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050042',
#   'title': 'Indian tick typhus',
#   'description': "Indian tick typhus ( ['DISEASE'] ) [ A spotted fever that has_material_basis_in Rickettsia conorii subsp indica, which is transmitted_by ticks (Rhipicephalus sanguineus). The infection has_symptom fever, has_symptom eschar, has_symptom regional adenopathy, and has_symptom maculopapular rash on extremities. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050043',
#   'title': 'Israeli tick typhus',
#   'description': "Israeli tick typhus ( ['DISEASE'] : Israeli spotted fever ) [ A spotted fever that has_material_basis_in Rickettsia conorii subsp israelensis, which is transmitted_by ticks (Rhipicephalus sanguineus). The infection has_symptom fever, has_symptom eschar, has_symptom regional adenopathy, and has_symptom maculopapular rash on extremities. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050046',
#   'title': 'Far Eastern spotted fever',
#   'description': "Far Eastern spotted fever ( ['DISEASE'] : Rickettsia heilongjiangensis spotted fever ) [ A spotted fever that has_material_basis_in Rickettsia heilongjiangensis, which is transmitted_by ticks (Haemaphysalis concinna). The infection has_symptom fever, has_symptom eschar, has_symptom maculopapular rash, and has_symptom regional adenopathy. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050047',
#   'title': 'Flinders Island spotted fever',
#   'description': "Flinders Island spotted fever ( ['DISEASE'] : FISF ; Thai tick typhus ) [ A spotted fever that has_material_basis_in Rickettsia honei, which is transmitted_by cayenne ticks (Amblyomma cajennense). The infection has_symptom mild spotted fever, has_symptom eschar and has_symptom adenopathy. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050050',
#   'title': 'Japanese spotted fever',
#   'description': "Japanese spotted fever ( ['DISEASE'] : oriental spotted fever ; Rickettsia japonica spotted fever ) [ A spotted fever that has_material_basis_in Rickettsia japonica, which is transmitted_by ticks (Dermacentor taiwanensis and Haemaphysalis flava). The infection has_symptom fever, has_symptom eschars, has_symptom regional adenopathy, and has_symptom rash on extremities. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050051',
#   'title': 'Rickettsia parkeri spotted fever',
#   'description': "Rickettsia parkeri spotted fever ( ['DISEASE'] : maculatum infection ) [ A spotted fever that has_material_basis_in Rickettsia parkeri, which is transmitted_by Gulf Coast tick (Amblyomma maculatum). The infection has_symptom fever, has_symptom headache, has_symptom eschar, and has_symptom rash. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050052',
#   'title': 'Rocky Mountain spotted fever',
#   'description': "Rocky Mountain spotted fever ( ['DISEASE'] : Brazillian spotted ; Choix ; Exanthematic typhus of Sao Paulo ; Fiebre maculosa ; Fiebre manchada ; Sao Paulo typhus ; So Paulo fever ; Tick typhus ; Tobia fever ) [ A spotted fever that has_material_basis_in Rickettsia rickettsii, which is transmitted_by ticks (Dermacentor variabilis and Dermacentor andersoni). The infection has_symptom fever, has_symptom headache, has_symptom abdominal pain, and has_symptom maculopapular rash progressing into papular or petechial rash. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050059',
#   'title': 'oropharyngeal anthrax',
#   'description': "oropharyngeal anthrax ( ['DISEASE'] ) [ A gastrointestinal anthrax that results in infection located in mucosa of oropharynx, has_material_basis_in Bacillus anthracis, which is transmitted by ingestion of anthrax-infected meat. The infection has symptom lesions, has symptom vomiting of blood, has symptom severe diarrhea, has symptom loss of appetite. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050061',
#   'title': 'erysipeloid',
#   'description': "erysipeloid ( ['DISEASE'] ) [ A primary bacterial infectious disease that results_in infection located_in skin, has_material_basis_in Erysipelothrix rhusiopathiae, which is transmitted_by contact with infected animals. The infection has_symptom redness of skin, has_symptom tenderness of skin and has_symptom warmth of skin. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050072',
#   'title': 'adiaspiromycosis',
#   'description': "adiaspiromycosis ( ['DISEASE'] ) [ A primary systemic mycosis that is a fungal infection located_in lungs, or located_in skin, which results_in disseminated granulomatous pulmonary process and cutaneous infection in rodents, small wild mammals and humans, has_material_basis_in Chrysosporium parvum or Emmonsia crescens. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050073',
#   'title': 'invasive aspergillosis',
#   'description': "invasive aspergillosis ( ['DISEASE'] ) [ An aspergillosis that is a serious fungal infection of the lung with pneumonia caused by Aspergillus, which spreads to other parts of the body through bloodstream in patients with acute leukemia and recipients of tissue transplants. Clinical symptoms include pulmonary nodules and hemorrhage. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050083',
#   'title': 'Keshan disease',
#   'description': "Keshan disease ( ['DISEASE'] ) [ A nutritional deficiency that is disease characterized by a cardiomyopathy secondary to selenium deficiency. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050096',
#   'title': 'tinea barbae',
#   'description': "tinea barbae ( ['DISEASE'] : dermatophytosis of beard ) [ A dermatophytosis that results_in fungal infection which effects horny layer of epidermis of the bearded areas located_in face or located_in neck, has_material_basis_in Trichophyton mentagrophytes or has_material_basis_in Trichophyton verrucosum, which also effects hair, and effects nail and has_symptom inflammatory kerion-like plaques, and results_in_formation_of noninflammatory superficial perifollicular pustules. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050097',
#   'title': 'ectothrix infectious disease',
#   'description': "ectothrix infectious disease ( ['DISEASE'] ) [ A tinea capitis that results_in fungal infection located_in cuticle of hair, has_material_basis_in Microsporum canis, has_material_basis_in Microsporum gypseum, has_material_basis_in Trichophyton equinum, and has_material_basis_in Trichophyton verrucosum, which produce arthroconidia on the exterior of the hair shaft. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050105',
#   'title': 'endothrix infectious disease',
#   'description': "endothrix infectious disease ( ['DISEASE'] ) [ A tinea capitis that results_in fungal infection located_in hair, has_material_basis_in Ascomycota fungi that belong to a group called dermatophytes, which produce arthroconidia within the hair shaft only. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050116',
#   'title': 'tinea imbricata',
#   'description': "tinea imbricata ( ['DISEASE'] ) [ A tinea corporis that results_in fungal infection located_in skin, has_material_basis_in Trichophyton concentricum, which is characterized by ring-like growth in overlapping circles that may have an autosomal dominant genetic predisposition. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050117',
#   'title': 'disease by infectious agent',
#   'description': "disease by infectious agent ( ['DISEASE'] : infectious disease ) [ A disease that is the consequence of the presence of pathogenic microbial agents, including pathogenic viruses, pathogenic bacteria, fungi, protozoa, multicellular parasites, and aberrant proteins known as prions. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050118',
#   'title': 'La Crosse encephalitis',
#   'description': "La Crosse encephalitis ( ['DISEASE'] : California Encephalitis ; California virus encephalitis ; Neuroinvasive California encephalitis virus infection ) [ A viral infectious disease that results_in inflammation located_in brain, has_material_basis_in La Crosse virus, which is transmitted_by treehole mosquito, Ochlerotatus triseriatus. The infection has_symptom seizures, has_symptom headache, has_symptom fever, has_symptom coma, and has_symptom paralysis. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050120',
#   'title': 'hemophagocytic lymphohistiocytosis',
#   'description': "hemophagocytic lymphohistiocytosis ( ['DISEASE'] : haemophagocytic syndrome ) [ A lymphatic system disease that is characterized by an expansion of the monocyte-macrophage population and intense hemophagocytosis. It can occur de novo, but more often occurs in the setting of another disorder, usually an infection or a malignancy. A clinical picture of fever, hepatosplenomegaly, lymphadenopathy and peripheral pancytopenia. The morphologic hallmark of this syndrome is the phagocytosis of hematopoietic elements by morphologically normal macrophages. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050125',
#   'title': 'dengue shock syndrome',
#   'description': "dengue shock syndrome ( ['DISEASE'] : DSS ) [ A dengue disease that involves the most severe form of dengue fever, has_material_basis_in Dengue virus [NCBITaxon:12637] with four serotypes (Dengue virus 1, 2, 3 and 4), which are transmitted_by Aedes mosquito bite. The infection has_symptom easy bruising, has_symptom blood spots, has_symptom bleeding gums, and has_symptom nosebleeds. It is accompanied by circulatory collapse, involves hypotension, narrow pulse pressure (less than or equal to 20mm Hg), or frank shock. The shock occurs after two to six days of symptoms, followed by collapse, weak pulse, and blueness around the mouth. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050127',
#   'title': 'sinusitis',
#   'description': "sinusitis ( ['DISEASE'] ) [ A paranasal sinus disease involving inflammation of the paranasal sinuses resulting from bacterial, fungal, viral infection, allergic or autoimmune issues. Symptoms can include fever, weakness, fatigue, cough and congestion. There may also be mucus drainage in the back of the throat, called postnasal drip. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050129',
#   'title': 'secretory diarrhea',
#   'description': "secretory diarrhea ( ['DISEASE'] ) [ A diarrhea where there is an increase in the active secretion, or there is an inhibition of absorption causing little to no structural damage. The most common cause of this type of diarrhea is a cholera toxin that stimulates the secretion of anions, especially chloride ions. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050130',
#   'title': 'osmotic diarrhea',
#   'description': "osmotic diarrhea ( ['DISEASE'] ) [ A dirrhea that occurs when too much water is drawn into the bowels. This can be the result of maldigestion (e.g., pancreatic disease or Coeliac disease), in which the nutrients are left in the lumen to pull in water. Osmotic diarrhea can also be caused by osmotic laxatives (which work to alleviate constipation by drawing water into the bowels). In healthy individuals, too much magnesium or vitamin C or undigested lactose can produce osmotic diarrhea and distention of the bowel. A person who does not have lactose intolerance can have difficulty absorbing lactose after an extraordinarily high intake of dairy products. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050131',
#   'title': 'motility-related diarrhea',
#   'description': "motility-related diarrhea ( ['DISEASE'] ) [ A diarrhea which is caused by the rapid movement of food through the intestines (hypermotility). If the food moves too quickly through the GI tract, there is not enough time for sufficient nutrients and water to be absorbed. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050132',
#   'title': 'inflammatory diarrhea',
#   'description': "inflammatory diarrhea ( ['DISEASE'] ) [ A gastrointestinal system infectious disease involving diarrhea that occurs when there is damage to the mucosal lining or brush border, which leads to a passive loss of protein-rich fluids, and a decreased ability to absorb these lost fluids. It can be caused by bacterial infections, viral infections, parasitic infections, or autoimmune problems such as inflammatory bowel diseases. It can also be caused by tuberculosis, colon cancer, and enteritis. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050133',
#   'title': 'superficial mycosis',
#   'description': "superficial mycosis ( ['DISEASE'] : piedra ; Steroid-modified tinea infection ) [ A fungal infectious disease that results_in infection of the outermost layer located_in skin or located_in hair shaft, has_material_basis_in Fungi. No living tissue is invaded and there is no cellular response from the host. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050134',
#   'title': 'cutaneous mycosis',
#   'description': "cutaneous mycosis ( ['DISEASE'] ) [ A fungal infectious disease that results_in infection of the keratinized layers located_in skin, located_in hair or located_in nail, which extends deeper into the epidermis, has_material_basis_in Fungi and results_in_formation_of skin lesions. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050135',
#   'title': 'subcutaneous mycosis',
#   'description': "subcutaneous mycosis ( ['DISEASE'] ) [ A fungal infectious disease that results_in infection located_in skin or located_in subcutaneous tissue, has_material_basis_in Fungi, which penetrate the dermis or even deeper during or after a skin trauma. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050136',
#   'title': 'systemic mycosis',
#   'description': "systemic mycosis ( ['DISEASE'] ) [ A fungal infectious disease that results_in infection of internal organs and tissues located_in human body, has_material_basis_in Fungi, which enter the body via the respiratory tract, through the gut, paranasal sinuses or skin and spread through the bloodstream to multiple organs. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050138',
#   'title': 'podoconiosis',
#   'description': "podoconiosis ( ['DISEASE'] ) [ An elephantiasis that is characterized by lymphadema located_in the lower extremities caused by a genetically determined abnormal inflammatory reaction to mineral particles in irritant red clay soils derived from volcanic deposits. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050140',
#   'title': 'acute diarrhea',
#   'description': "acute diarrhea ( ['DISEASE'] ) [ A diarrhea that is of rapid onset and course characterized by frequent loose or liquid bowel movements. Acute diarrhea is a common cause of death in developing countries and the second most common cause of infant deaths worldwide. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050141',
#   'title': 'intestinal botulism',
#   'description': "intestinal botulism ( ['DISEASE'] ) [ A botulism that involves intoxication caused by botulinum neurotoxins (BoNTA, B, E and F) in adults, has_material_basis_in Clostridium botulinum A, has_material_basis_in Clostridium botulinum B, has_material_basis_in Clostridium botulinum E and has_material_basis_in Clostridium botulinum F, which are transmitted by ingestion of bacterial spores, which then grow in the intestine and release toxins. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050143',
#   'title': 'asymptomatic dengue',
#   'description': "asymptomatic dengue ( ['DISEASE'] ) [ A dengue disease that results_in infection, has_material_basis_in Dengue virus [NCBITaxon:12637] with four serotypes (Dengue virus 1, 2, 3 and 4), which are transmitted_by Aedes mosquito bite. The infection has no manifestations of symptoms. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050144',
#   'title': 'Kartagener syndrome',
#   'description': "Kartagener syndrome ( ['DISEASE'] : Kartagener's syndrome ) [ A primary ciliary dyskinesia that is characterized by sinusitis, bronchiectasis and situs inversus with dextrocardia resulting from dysfunction of the cilia during embryologic development. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050145',
#   'title': 'adenoiditis',
#   'description': "adenoiditis ( ['DISEASE'] : chronic adenoiditis ) [ An upper respiratory tract disease which involves inflammation, pain, and swelling of the adenoid tissue due to the infection by bacteria and viruses. It occurs primarily in children and may be secondary to an allergy, infection of nose or throat and an obstruction of the eustachian tube. The infection has symptom pain, has symptom redness, has symptom swelling, and has symptom difficulty swallowing. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050147',
#   'title': 'otomycosis',
#   'description': "otomycosis ( ['DISEASE'] : Singapore ear ) [ An otitis externa which is a disease of the ear produced by the growth of fungi in the external auditory canal. It is characterized by inflammation, pruritus, scaling and severe discomfort. The most common fungi are Aspergillus niger and Candida albicans. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0050148',
# ...
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060244',
#   'title': 'specific language impairment',
#   'description': "specific language impairment ( ['DISEASE'] ) [ A language disorder characterized by difficulty in language acquisition despite otherwise normal development and in the absence of any obvious explanatory factors. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060245',
#   'title': 'Mast syndrome',
#   'description': "Mast syndrome ( ['DISEASE'] : autosomal recessive spastic paraplegia 21 ; autosomal recessive spastic paraplegia type 21 ; hereditary spastic paraplegia 21 ; SPG21 ) [ A hereditary spastic paraplegia associated with dementia. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060246',
#   'title': 'MASA syndrome',
#   'description': "MASA syndrome ( ['DISEASE'] : CRASH syndrome ; Gareis-Mason syndrome ; hereditary spastic paraplegia 1 ; L1 syndrome ; SPG1 ; X-linked complicated hereditary spastic paraplegia type 1 ; X-linked corpus callosum agenesis ; X-linked spastic paraplegia 1 ) [ A hereditary spastic paraplegia that is characterized by hydrocephalus, spasticity of the lower limbs, adducted thumbs, aphasia, seizures, agenesis of the corpus callosum and intellectual disability in the mild to moderate range. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060247',
#   'title': 'Smith-McCort dysplasia',
#   'description': "Smith-McCort dysplasia ( ['DISEASE'] ) [ A Dyggve-Melchior-Clausen disease that is characterized by short limbs and a short trunk with a barrel-shaped chest. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060248',
#   'title': 'Simpson-Golabi-Behmel syndrome type 1',
#   'description': "Simpson-Golabi-Behmel syndrome type 1 ( ['DISEASE'] : bulldog syndrome ; DGSX Golabi-Rosen syndrome ; Golabi-Rosen syndrome ; Sara Angers syndrome ; SGB syndrome ; Simpson dysmorphia syndrome ; X-linked dysplasia gigantism syndrome ) [ A syndrome characterized by pre- and postnatal overgrowth and craniofacial, skeletal, cardiac and renal abnormalities and has_material_basis_in mutation in the gene encoding glypican-3 (GPC3) on chromosome Xq26. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060249',
#   'title': 'scoliosis',
#   'description': "scoliosis ( ['DISEASE'] ) [ A bone structure disease characterized by an appreciable lateral deviation in the normally straight vertical line of the spine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060250',
#   'title': 'idiopathic scoliosis',
#   'description': "idiopathic scoliosis ( ['DISEASE'] ) [ A scoliosis with no known cause. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060251',
#   'title': 'sclerosteosis',
#   'description': "sclerosteosis ( ['DISEASE'] ) [ A hyperostosis characterized by excessive bone formation most prominent in the skull, mandible, clavicle, ribs and diaphyses of long bones; bone formation occurs throughout life. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060252',
#   'title': 'sclerocornea',
#   'description': "sclerocornea ( ['DISEASE'] : isolated congenital sclerocornea ) [ A corneal disease in which the cornea blends with sclera, resulting in clouding of the cornea. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060253',
#   'title': 'scapuloperoneal myopathy',
#   'description': "scapuloperoneal myopathy ( ['DISEASE'] ) [ A muscular dystrophy which begins at the lower legs and affects the shoulder region earlier and more severely than distal arm. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060254',
#   'title': 'Robinow syndrome',
#   'description': "Robinow syndrome ( ['DISEASE'] : acral dysostosis with facial and genital abnormalities ; fetal face syndrome ; Robinow dwarfism ) [ A syndrome characterized by mild to moderate short stature due to growth delays after birth, distinctive craniofacial abnormalities, skeletal malformations and genital abnormalities. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060255',
#   'title': 'rippling muscle disease 2',
#   'description': "rippling muscle disease 2 ( ['DISEASE'] : autosomal dominant limb-girdle muscular dystrophy type 1C ) [ A muscle tissue disease characterized by mechanically triggered contractions of skeletal muscle and that has_material_basis_in mutation in the caveolin-3 gene (CAV3) on chromosome 3p25. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060256',
#   'title': 'Dowling-Degos disease',
#   'description': "Dowling-Degos disease ( ['DISEASE'] : dark dot disease ; reticular pigment anomaly of flexures ) [ A pigmentation disease characterized by a reticulate pattern of abnormally dark skin coloring, particularly in the body's folds and creases. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060257',
#   'title': 'dyschromatosis symmetrica hereditaria',
#   'description': "dyschromatosis symmetrica hereditaria ( ['DISEASE'] : reticulate acropigmentation of Dohi ) [ A pigmentation disease characterized by progressively pigmented and depigmented macules, often mixed in a reticulate pattern, concentrated on the dorsal extremities. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060258',
#   'title': 'reticulate acropigmentation of Kitamura',
#   'description': "reticulate acropigmentation of Kitamura ( ['DISEASE'] : RAPK ) [ A pigmentation disease characterized by lesions that initially arise as letiginous, hyperpigmented macules in a reticular pattern on the dorsal aspect of the hands and feet. Over time, lesions may spread proximally and may darken; palmoplantar pitting and dermatoglyphic disruption may also be present. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060259',
#   'title': 'renal-hepatic-pancreatic dysplasia',
#   'description': "renal-hepatic-pancreatic dysplasia ( ['DISEASE'] : Ivemark's syndrome ) [ A physical disorder characterized by pancreatic fibrosis, renal dysplasia and hepatic dysgenesis; it is usual fatal soon after birth. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060260',
#   'title': 'ptosis',
#   'description': "ptosis ( ['DISEASE'] : blepharoptosis ; drooping eyelid ) [ An eye disease characterized by the drooping or falling of the upper or lower eyelid. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060261',
#   'title': 'congenital ptosis',
#   'description': "congenital ptosis ( ['DISEASE'] ) [ A ptosis characterized by eyelid drop present at birth. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060262',
#   'title': 'gallbladder disease',
#   'description': "gallbladder disease ( ['DISEASE'] ) [ A gastrointestinal system disease that is located_in the gallbladder. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060263',
#   'title': 'porencephaly',
#   'description': "porencephaly ( ['DISEASE'] ) [ A brain disease that is characterized by encephalomalacia and cystic brain lesions. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060264',
#   'title': 'pontocerebellar hypoplasia',
#   'description': "pontocerebellar hypoplasia ( ['DISEASE'] : PCH ) [ A neurodegenerative disease that is characterized by underdevelopment of the pons and cerebellum. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060265',
#   'title': 'pontocerebellar hypoplasia type 1A',
#   'description': "pontocerebellar hypoplasia type 1A ( ['DISEASE'] ) [ A pontocerebellar hypoplasia that is characterized by central and peripheral motor dysfunction, hypotonia, spasticity and failure to thrive, has_material_basis_in homozygous or compound heterozygous mutation in the VRK1 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060266',
#   'title': 'pontocerebellar hypoplasia type 1B',
#   'description': "pontocerebellar hypoplasia type 1B ( ['DISEASE'] ) [ A severe pontocerebellar hypoplasia that is characterized by hypotonia, progressive microcephaly and developmental delay, has_material_basis_in autosomal recessive inheritance of mutation in the EXOSC3 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060267',
#   'title': 'pontocerebellar hypoplasia type 2A',
#   'description': "pontocerebellar hypoplasia type 2A ( ['DISEASE'] ) [ A severe pontocerebellar hypoplasia that is characterized by progressive microcephaly, chorea, epilepsy and hyperreflexia, has_material_basis_in autosomal recessive inheritance of mutation in the TSEN54 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060268',
#   'title': 'pontocerebellar hypoplasia type 2B',
#   'description': "pontocerebellar hypoplasia type 2B ( ['DISEASE'] ) [ A severe pontocerebellar hypoplasia that is characterized by progressive microcephaly, clonus, dysphagia and failure to thrive, has_material_basis_in autosomal recessive inheritance of mutation in the TSEN2 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060269',
#   'title': 'pontocerebellar hypoplasia type 2C',
#   'description': "pontocerebellar hypoplasia type 2C ( ['DISEASE'] ) [ A severe pontocerebellar hypoplasia that is characterized by progressive microcephaly, extrapyramidal dyskinesia, seizure and failure to thrive, has_material_basis_in autosomal recessive inheritance of mutation in the TSEN34 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060270',
#   'title': 'pontocerebellar hypoplasia type 2D',
#   'description': "pontocerebellar hypoplasia type 2D ( ['DISEASE'] ) [ A pontocerebellar hypoplasia that is characterized by progressive microcephaly, profound intellectual disability, spasticity and seizure, has_material_basis_in autosomal recessive inheritance of mutation in the SEPSECS gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060271',
#   'title': 'pontocerebellar hypoplasia type 2E',
#   'description': "pontocerebellar hypoplasia type 2E ( ['DISEASE'] ) [ A pontocerebellar hypoplasia that is characterized by progressive microcephaly, profound intellectual disability, spasticity and seizure, has_material_basis_in autosomal recessive inheritance of mutation in the VPS53 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060272',
#   'title': 'pontocerebellar hypoplasia type 3',
#   'description': "pontocerebellar hypoplasia type 3 ( ['DISEASE'] ) [ A pontocerebellar hypoplasia that is characterized by progressive microcephaly, hypotonia, dysmorphic features, profound intellectual disability and seizure, has_material_basis_in autosomal recessive inheritance of mutation in the PCLO gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060273',
#   'title': 'pontocerebellar hypoplasia type 4',
#   'description': "pontocerebellar hypoplasia type 4 ( ['DISEASE'] ) [ A pontocerebellar hypoplasia that is characterized by progressive microcephaly, hypertonia, myoclonus, seizure and early lethality, has_material_basis_in autosomal recessive inheritance of mutation in the TSEN54 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060274',
#   'title': 'pontocerebellar hypoplasia type 5',
#   'description': "pontocerebellar hypoplasia type 5 ( ['DISEASE'] ) [ A pontocerebellar hypoplasia that is characterized by severe olivopontocerebellar hypoplasia and degeneration leading to early lethality, has_material_basis_in autosomal recessive inheritance of mutation in the TSEN54 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060275',
#   'title': 'pontocerebellar hypoplasia type 6',
#   'description': "pontocerebellar hypoplasia type 6 ( ['DISEASE'] ) [ A pontocerebellar hypoplasia that is characterized by olivopontocerebellar hypoplasia and developmental delay, has_material_basis_in autosomal recessive inheritance of mutation in the RARS2 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060276',
#   'title': 'pontocerebellar hypoplasia type 7',
#   'description': "pontocerebellar hypoplasia type 7 ( ['DISEASE'] ) [ A pontocerebellar hypoplasia that is characterized by delayed psychomotor development, hypotonia, gonadal abnormalities and respiratory failure, has_material_basis_in autosomal recessive mutation in the TOE1 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060277',
#   'title': 'pontocerebellar hypoplasia type 8',
#   'description': "pontocerebellar hypoplasia type 8 ( ['DISEASE'] ) [ A pontocerebellar hypoplasia that is characterized by delayed psychomotor development, chorea, hypotonia, spasticity and visual defects, has_material_basis_in autosomal recessive inheritance of mutation in the CHMP1A gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060278',
#   'title': 'pontocerebellar hypoplasia type 9',
#   'description': "pontocerebellar hypoplasia type 9 ( ['DISEASE'] ) [ A pontocerebellar hypoplasia that is characterized by progressive microcephaly, spasticity, seizure and brain atrophy, has_material_basis_in autosomal recessive inheritance of mutation in the AMPD2 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060279',
#   'title': 'pontocerebellar hypoplasia type 10',
#   'description': "pontocerebellar hypoplasia type 10 ( ['DISEASE'] ) [ A pontocerebellar hypoplasia that is characterized by severe developmental delays, progressive microcephaly, spasticity and seizure, has_material_basis_in autosomal recessive inheritance of mutation in the CLP1 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060280',
#   'title': 'primary pigmented nodular adrenocortical disease',
#   'description': "primary pigmented nodular adrenocortical disease ( ['DISEASE'] ) [ An adrenal cortex disease characterized by small to normal sized adrenal glands containing multiple small cortical pigmented nodules. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060281',
#   'title': 'photosensitive epilepsy',
#   'description': "photosensitive epilepsy ( ['DISEASE'] : photogenic epilepsy ; photoparoxysmal response ) [ An epilepsy characterized by seizures triggered by visual stimuli that form patterns in space or time, such as flashing lights. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060282',
#   'title': 'persistent hyperplastic primary vitreous',
#   'description': "persistent hyperplastic primary vitreous ( ['DISEASE'] ) [ A developmental vitreous disease that is characterized by leukocoria, strabismus and vision loss, caused by failure of primary vitreous and hyaloid vasculature to regress during embryological development. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060283',
#   'title': 'peeling skin syndrome',
#   'description': "peeling skin syndrome ( ['DISEASE'] : deciduous skin ; familial continuous skin peeling syndrome ; keratosis exfoliativa congenita ; peeling skin disease ; PSS ) [ A skin disease that is characterized by the painless, continuous peeling of the top layer of skin. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060284',
#   'title': 'paroxysmal nocturnal hemoglobinuria',
#   'description': "paroxysmal nocturnal hemoglobinuria ( ['DISEASE'] ) [ An acquired hemolytic anemia that is characterized by abdominal pain, hematuria, esophageal dysmotility and thrombosis, has_material_basis_in defect in the cell membrane glycosyl phosphatidylinositols that protect red blood cells from the innate complement immune system. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060285',
#   'title': 'parietal foramina',
#   'description': "parietal foramina ( ['DISEASE'] : Caitlin marks ; enlarged parietal foramina ; hereditary cranium bifidum ) [ An inherited neural tube defect that is characterized by enlarged openings in the parietal bones of the skull, has_material_basis_in mutation in the ALX4 gene or MSX2 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060286',
#   'title': 'combined oxidative phosphorylation deficiency',
#   'description': "combined oxidative phosphorylation deficiency ( ['DISEASE'] ) [ A mitochondrial metabolism disease that is characterized by growth retardation, microcephaly, hypertonia, encephalopathy, cardiomyopathy and liver dysfunction. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'ontology:DOID:0060287',
#   'title': 'cornea plana',
#   'description': "cornea plana ( ['DISEASE'] : flat cornea ) [ A corneal disease that is characterized by a flat cornea where the radus of curvature is less than 43 D. ]"},
#  ...]

# %% [markdown]
# # REDO EVERYTHING BUT WITHOUT PANDA DATAFRAME

# %% [markdown]
# ## Get the ontology

# %%
from bioel.ontology import BiomedicalOntology

obo_dict = {'filepath': 'https://raw.githubusercontent.com/DiseaseOntology/HumanDiseaseOntology/main/src/ontology/doid.obo',
        'name': 'disease ontology',
        'prefix_to_keep': None,
        'entity_type': 'DISEASE',
        'abbrev': 'DOID'}

ontology = BiomedicalOntology.load_obo(**obo_dict)
# Out:
# [2024-03-11 20:27:08] [ontology.py] [INFO] Reading OBO ontology from https://raw.githubusercontent.com/DiseaseOntology/HumanDiseaseOntology/main/src/ontology/doid.obo
# 100%|██████████| 11511/11511 [00:00<00:00, 48925.32it/s]

# %% [markdown]
# ### list_entities

# %%
ontology_entities = ontology.entities
display(ontology.entities[0])
# Out:
# BiomedicalEntity(cui='DOID:0001816', name='angiosarcoma', types=['DISEASE'], aliases=['hemangiosarcoma'], definition='A vascular cancer that derives_from the cells that line the walls of blood vessels or lymphatic vessels.', equivalant_cuis=['DOID:267', 'DOID:4508'], taxonomy=None, metadata=None)

# %%
def entities2list(ontology):
    ontology_entities = ontology.entities
    # Create a list of dictionaries, each representing a row in the DataFrame
    data = [{
        'cui': entity.cui,
        'name': entity.name,
        'types': entity.types,
        'aliases': entity.aliases if hasattr(entity, 'aliases') else [],
        'definition': entity.definition,
        'equivalent_cuis': entity.equivalent_cuis if hasattr(entity, 'equivalent_cuis') and entity.equivalent_cuis is not None else [],
        'taxonomy': entity.taxonomy,
        'metadata': entity.metadata
    } for entity in ontology_entities]

    return data

# %%
data = entities2list(ontology)
data
# Out:
# [{'cui': 'DOID:0001816',
#   'name': 'angiosarcoma',
#   'types': ['DISEASE'],
#   'aliases': ['hemangiosarcoma'],
#   'definition': 'A vascular cancer that derives_from the cells that line the walls of blood vessels or lymphatic vessels.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0002116',
#   'name': 'pterygium',
#   'types': ['DISEASE'],
#   'aliases': ["surfer's eye"],
#   'definition': 'A corneal disease that is characterized by a triangular tissue growth located_in cornea of the eye that is the result of collagen degeneration and fibrovascular proliferation.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0014667',
#   'name': 'disease of metabolism',
#   'types': ['DISEASE'],
#   'aliases': ['metabolic disease'],
#   'definition': 'A disease that involving errors in metabolic processes of building or degradation of molecules.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040001',
#   'name': 'shrimp allergy',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A crustacean allergy that has_allergic_trigger shrimp.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040002',
#   'name': 'aspirin allergy',
#   'types': ['DISEASE'],
#   'aliases': ['acetylsalicylic acid allergy', 'ASA allergy'],
#   'definition': 'A drug allergy that has_allergic_trigger acetylsalicylic acid.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040003',
#   'name': 'benzylpenicillin allergy',
#   'types': ['DISEASE'],
#   'aliases': ['benzyl penicillin allergy', 'penicillin G allergy'],
#   'definition': 'A beta-lactam allergy that has_allergic_trigger benzylpenicillin.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040004',
#   'name': 'amoxicillin allergy',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A beta-lactam allergy that has_allergic_trigger amoxicillin.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040005',
#   'name': 'ceftriaxone allergy',
#   'types': ['DISEASE'],
#   'aliases': ['rocephin allergy'],
#   'definition': 'A cephalosporin allergy that has_allergic_trigger ceftriaxone.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040006',
#   'name': 'carbamazepine allergy',
#   'types': ['DISEASE'],
#   'aliases': ['carbamazepen allergy', 'Tegretol allergy'],
#   'definition': 'A drug allergy that has_allergic_trigger carbamazepine.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040007',
#   'name': 'abacavir allergy',
#   'types': ['DISEASE'],
#   'aliases': ['ABC allergy'],
#   'definition': 'A drug allergy that has_allergic_trigger abacavir.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040008',
#   'name': 'isoniazide allergy',
#   'types': ['DISEASE'],
#   'aliases': ['INH allergy', 'isonicotinylhydrazide allergy'],
#   'definition': 'A drug allergy that has_allergic_trigger isoniazide.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040009',
#   'name': 'lidocaine allergy',
#   'types': ['DISEASE'],
#   'aliases': ['Lidoderm allergy', 'lignocaine allergy', 'xylocaine allergy'],
#   'definition': 'A drug allergy that has_allergic_trigger lidocaine.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040010',
#   'name': 'mepivacaine allergy',
#   'types': ['DISEASE'],
#   'aliases': ['Carbocaine allergy', 'Polocaine allergy'],
#   'definition': 'A drug allergy that has_allergic_trigger mepivacaine.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040011',
#   'name': 'phenobarbital allergy',
#   'types': ['DISEASE'],
#   'aliases': ['Luminal allergy',
#    'phenobarbitol allergy',
#    'phenobarbitone allergy'],
#   'definition': 'A drug allergy that has_allergic_trigger phenobarbital.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040012',
#   'name': 'phenytoin allergy',
#   'types': ['DISEASE'],
#   'aliases': ['Dilantin allergy'],
#   'definition': 'A drug allergy that has_allergic_trigger phenytoin.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040013',
#   'name': 'ranitidine allergy',
#   'types': ['DISEASE'],
#   'aliases': ['Zantac allergy'],
#   'definition': 'A drug allergy that has_allergic_trigger ranitidine.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040014',
#   'name': 'corticosteroid allergy',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A drug allergy that has_allergic_trigger corticosteroid.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040015',
#   'name': 'sulfonamide allergy',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A drug allergy that has_allergic_trigger sulfonamide.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040016',
#   'name': 'sulfamethoxazole allergy',
#   'types': ['DISEASE'],
#   'aliases': ['SMX allergy', 'SMZ allergy', 'sulphamethoxazole allergy'],
#   'definition': 'A drug allergy that has_allergic_trigger sulfamethoxazole.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040017',
#   'name': 'suprofen allergy',
#   'types': ['DISEASE'],
#   'aliases': ['Profenal allergy'],
#   'definition': 'A drug allergy that has_allergic_trigger suprofen.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040018',
#   'name': 'thiopental allergy',
#   'types': ['DISEASE'],
#   'aliases': ['penthiobarbital allergy', 'pentothiobarbital allergy'],
#   'definition': 'A drug allergy that has_allergic_trigger thiopental.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040019',
#   'name': 'D-mannitol allergy',
#   'types': ['DISEASE'],
#   'aliases': ['mannitol allergy'],
#   'definition': 'A drug allergy that has_allergic_trigger D-mannitol.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040020',
#   'name': 'cefotaxime allergy',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A cephalosporin allergy that has_allergic_trigger cefotaxime.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040021',
#   'name': 'cephalosporin allergy',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A drug allergy that has_allergic_trigger cephalosporin.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040022',
#   'name': 'amodiaquine allergy',
#   'types': ['DISEASE'],
#   'aliases': ['Camoquin allergy', 'Flavoquine allergy'],
#   'definition': 'A drug allergy that has_allergic_trigger amodiaquine.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040023',
#   'name': 'cefaclor allergy',
#   'types': ['DISEASE'],
#   'aliases': ['Ceclor allergy', 'cephaclor allergy'],
#   'definition': 'A cephalosporin allergy that has_allergic_trigger cefaclor.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040024',
#   'name': 'ceftazidime allergy',
#   'types': ['DISEASE'],
#   'aliases': ['Fortaz allergy', 'Tazicef allergy'],
#   'definition': 'A cephalosporin allergy that has_allergic_trigger ceftazidime.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040025',
#   'name': 'cefuroxime allergy',
#   'types': ['DISEASE'],
#   'aliases': ['cephuroxime allergy', 'Zinacef allergy'],
#   'definition': 'A cephalosporin allergy that has_allergic_trigger cefuroxime.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040026',
#   'name': 'chlorhexidine allergy',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A drug allergy that has_allergic_trigger chlorhexidine.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040027',
#   'name': 'cyclophosphamide allergy',
#   'types': ['DISEASE'],
#   'aliases': ['cytophosphane allergy'],
#   'definition': 'A drug allergy that has_allergic_trigger cyclophosphamide.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040028',
#   'name': 'succinylcholine allergy',
#   'types': ['DISEASE'],
#   'aliases': ['dicholine succinate allergy',
#    'succinocholine allergy',
#    'sux allergy',
#    'suxamethonium allergy'],
#   'definition': 'A drug allergy that has_allergic_trigger succinylcholine.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040029',
#   'name': 'trimethoprim allergy',
#   'types': ['DISEASE'],
#   'aliases': ['Primsol allergy', 'proloprim allergy', 'TMP allergy'],
#   'definition': 'A drug allergy that has_allergic_trigger trimethoprim.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040030',
#   'name': 'cefixime allergy',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A cephalosporin allergy that has_allergic_trigger cefixime.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040031',
#   'name': 'diclofenac allergy',
#   'types': ['DISEASE'],
#   'aliases': ['Voltaren allergy'],
#   'definition': 'A drug allergy that has_allergic_trigger diclofenac.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040032',
#   'name': 'carbapenem allergy',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A drug allergy that has_allergic_trigger carbapenems.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040033',
#   'name': 'piperacillin allergy',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A beta-lactam allergy that has_allergic_trigger piperacillin.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040034',
#   'name': 'rocuronium allergy',
#   'types': ['DISEASE'],
#   'aliases': ['Esmeron allergy', 'Zemuron allergy'],
#   'definition': 'A drug allergy that has_allergic_trigger rocuronium.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040035',
#   'name': 'sulfasalazine allergy',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A drug allergy that has_allergic_trigger sulfasalazine.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040036',
#   'name': 'tubocurarine allergy',
#   'types': ['DISEASE'],
#   'aliases': ['DTC allergy'],
#   'definition': 'A drug allergy that has_allergic_trigger tubocurarine.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040037',
#   'name': 'aztreonam allergy',
#   'types': ['DISEASE'],
#   'aliases': ['Azactam allergy', 'Primbactam allergy'],
#   'definition': 'A beta-lactam allergy that has_allergic_trigger aztreonam.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040038',
#   'name': 'meropenem allergy',
#   'types': ['DISEASE'],
#   'aliases': ['Merrem allergy'],
#   'definition': 'An allergic asthma that has_allergic_trigger meropenem, a beta-lactam antibiotic.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040040',
#   'name': 'hexamethylene diisocyanate allergic asthma',
#   'types': ['DISEASE'],
#   'aliases': ['allergic asthma to HDI', 'allergic asthma to HMDI'],
#   'definition': 'An isocyanates allergic asthma that has_allergic_trigger hexamethylene diisocyanate.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040041',
#   'name': 'isocyanates allergic asthma',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'An allergic asthma that has_allergic_trigger isocyanates.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040042',
#   'name': "diphenylmethane-4,4'-diisocyanate allergic asthma",
#   'types': ['DISEASE'],
#   'aliases': ['allergic asthma to MDI'],
#   'definition': 'An isocyanates allergic asthma that has_allergic_trigger diphenylmethane-4,4-diisocyanate.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040043',
#   'name': 'toluene meta-diisocyanate allergic asthma',
#   'types': ['DISEASE'],
#   'aliases': ['allergic asthma to TDI'],
#   'definition': 'An isocyanates allergic asthma that has_allergic_trigger toluene meta-diisocyanate.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040044',
#   'name': 'methyl isocyanate allergic asthma',
#   'types': ['DISEASE'],
#   'aliases': ['allergic asthma to MIC'],
#   'definition': 'An isocyanates allergic asthma that has_allergic_trigger methyl isocyanate.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040045',
#   'name': 'nickel allergic asthma',
#   'types': ['DISEASE'],
#   'aliases': ['allergic asthma to Ni'],
#   'definition': 'An allergic asthma that has_allergic_trigger nickel atom.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040046',
#   'name': 'nickel allergic contact dermatitis',
#   'types': ['DISEASE'],
#   'aliases': ['allergic contact dermatitis to Ni'],
#   'definition': 'An allergic contact dermatitis that has_allergic_trigger nickel atom.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040047',
#   'name': 'trimellitic anhydride allergic asthma',
#   'types': ['DISEASE'],
#   'aliases': ['allergic asthma to TMA'],
#   'definition': 'An allergic asthma that has_allergic_trigger trimellitic anhydride.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040048',
#   'name': 'phthalic anhydride allergic asthma',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'An allergic asthma that has_allergic_trigger phthalic anhydride.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040049',
#   'name': 'maleic anhydride allergic asthma',
#   'types': ['DISEASE'],
#   'aliases': ['allergic asthma to MA'],
#   'definition': 'An allergic asthma that has_allergic_trigger maleic anhydride.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040050',
#   'name': 'tetrachlorophthalic anhydride allergic asthma',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'An allergic asthma that has_allergic_trigger tetrachlorophthalic anhydride.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040051',
#   'name': 'hexahydrophthalic anhydride allergic asthma',
#   'types': ['DISEASE'],
#   'aliases': ['allergic asthma to HHPA'],
#   'definition': 'An allergic asthma that has_allergic_trigger hexahydrophthalic anhydride.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040052',
#   'name': "diphenylmethane-4,4'-diisocyanate allergic contact dermatitis",
#   'types': ['DISEASE'],
#   'aliases': ['allergic contact dermatitis to MDI'],
#   'definition': 'An allergic contact dermatitis that has_allergic_trigger diphenylmethane-4,4-diisocyanate.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040053',
#   'name': 'cobalt allergic contact dermatitis',
#   'types': ['DISEASE'],
#   'aliases': ['allergic contact dermatitis to Co'],
#   'definition': 'An allergic contact dermatitis that has_allergic_trigger cobalt atom.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040054',
#   'name': 'cobalt allergic asthma',
#   'types': ['DISEASE'],
#   'aliases': ['Co allergic asthma'],
#   'definition': 'An allergic asthma that has_allergic_trigger cobalt atom.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040055',
#   'name': 'palladium allergic contact dermatitis',
#   'types': ['DISEASE'],
#   'aliases': ['allergic contact dermatitis to Pd'],
#   'definition': 'An allergic contact dermatitis that has_allergic_trigger palladium.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040056',
#   'name': 'chromium allergic contact dermatitis',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'An allergic contact dermatitis that has_allergic_trigger chromium atom.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040057',
#   'name': 'benzoic acid allergic contact dermatitis',
#   'types': ['DISEASE'],
#   'aliases': ['allergic contact dermatitis to benzoate'],
#   'definition': 'An allergic contact dermatitis that has_allergic_trigger benzoic acid.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040058',
#   'name': '1,4-phenylenediamine allergic contact dermatitis',
#   'types': ['DISEASE'],
#   'aliases': ['allergic contact dermatitis to p-phenylenediamine',
#    'allergic contact dermatitis to PPD'],
#   'definition': 'An allergic contact dermatitis that has_allergic_trigger 1,4-phenylenediamine.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040059',
#   'name': 'potassium dichromate allergic contact dermatitis',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'An allergic contact dermatitis that has_allergic_trigger potassium dichromate.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040060',
#   'name': 'ketoprofen photoallergic dermatitis',
#   'types': ['DISEASE'],
#   'aliases': ['photoallergic dermatitis to Orudis'],
#   'definition': 'A photoallergic dermatitis that has_allergic_trigger ketoprofen.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040061',
#   'name': 'remazole black respiratory allergy',
#   'types': ['DISEASE'],
#   'aliases': ['respiratory allergy to Reactive Black 5'],
#   'definition': 'A respiratory allergy that has_allergic_trigger remazole black-GR.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040062',
#   'name': 'chloramine T respiratory allergy',
#   'types': ['DISEASE'],
#   'aliases': ['respiratory allergy to Chloraseptin',
#    'respiratory allergy to Chlorazol',
#    'respiratory allergy to Trichlorol'],
#   'definition': 'A respiratory allergy that has_allergic_trigger chloramine T.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040063',
#   'name': '4-vinylcyclohexene dioxide respiratory allergy',
#   'types': ['DISEASE'],
#   'aliases': ['respiratory allergy to vinyl cyclohexene diepoxide'],
#   'definition': 'A respiratory allergy that has_allergic_trigger 4-vinylcyclohexene dioxide.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040064',
#   'name': 'carvone allergic contact dermatitis',
#   'types': ['DISEASE'],
#   'aliases': ['allergic contact dermatitis to levo-carvone'],
#   'definition': 'An allergic contact dermatitis that has_allergic_trigger (-)-carvone.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040065',
#   'name': 'quinidine allergy',
#   'types': ['DISEASE'],
#   'aliases': ['Kinidin allergy'],
#   'definition': 'A drug allergy that has_allergic_trigger quinidine.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040066',
#   'name': 'melphalan allergy',
#   'types': ['DISEASE'],
#   'aliases': ['Alkeran allergy'],
#   'definition': 'A drug allergy that has_allergic_trigger melphalan.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040067',
#   'name': 'neomycin sulfate allergic contact dermatitis',
#   'types': ['DISEASE'],
#   'aliases': ['allergic contact dermatitis to neomycin sulphate'],
#   'definition': 'An allergic contact dermatitis that has_allergic_trigger neomycin sulfate.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040068',
#   'name': '4-tert-butylphenol allergic contact dermatitis',
#   'types': ['DISEASE'],
#   'aliases': ['allergic contact dermatitis to butylphen',
#    'allergic contact dermatitis to PTBP'],
#   'definition': 'An allergic contact dermatitis that has_allergic_trigger 4-tert-butylphenol.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040069',
#   'name': '1-chloro-2,4-dinitrobenzene allergic contact dermatitis',
#   'types': ['DISEASE'],
#   'aliases': ['allergic contact dermatitis to dinitrochlorobenzene',
#    'allergic contact dermatitis to DNCB'],
#   'definition': 'An allergic contact dermatitis that has_allergic_trigger 1-chloro-2,4-dinitrobenzene.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040070',
#   'name': 'co-trimoxazole allergy',
#   'types': ['DISEASE'],
#   'aliases': ['Bactrim allergy',
#    'cotrimoxazol allergy',
#    'TMP/SMX allergy',
#    'trimethoprim/sulfamethoxazole allergy'],
#   'definition': 'A drug allergy that has_allergic_trigger co-trimoxazole.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040071',
#   'name': 'sodium aurothiomalate allergy',
#   'types': ['DISEASE'],
#   'aliases': ['gold sodium thiomalate allergy'],
#   'definition': 'A drug allergy that has_allergic_trigger sodium aurothiomalate.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040072',
#   'name': 'parthenolide allergic contact dermatitis',
#   'types': ['DISEASE'],
#   'aliases': ['allergic contact dermatitis to feverfew'],
#   'definition': 'An allergic contact dermatitis that has_allergic_trigger parthenolide.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040073',
#   'name': 'disodium cromoglycate allergy',
#   'types': ['DISEASE'],
#   'aliases': ['DSCG allergy'],
#   'definition': 'A drug allergy that has_allergic_trigger disodium cromoglycate.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040074',
#   'name': 'formaldehyde allergic contact dermatitis',
#   'types': ['DISEASE'],
#   'aliases': ['allergic contact dermatitis to formalin'],
#   'definition': 'An allergic contact dermatitis that has_allergic_trigger formaldehyde.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040075',
#   'name': 'benzo[d]isothiazol-3-one allergic contact dermatitis',
#   'types': ['DISEASE'],
#   'aliases': ['allergic contact dermatitis to benzisothiazolone',
#    'allergic contact dermatitis to BIT'],
#   'definition': 'An allergic contact dermatitis that has_allergic_trigger benzo[d]isothiazol-3-one.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040076',
#   'name': 'phthalyl group allergy',
#   'types': ['DISEASE'],
#   'aliases': ['phthalyl allergy'],
#   'definition': 'A drug allergy that has_allergic_trigger phthalyl group.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040077',
#   'name': 'alcuronium bromide allergy',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A drug allergy that has_allergic_trigger alcuronium bromide.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040078',
#   'name': 'gallamine allergy',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A drug allergy that has_allergic_trigger gallamine.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040079',
#   'name': '2,4-dinitrophenyl allergic contact dermatitis',
#   'types': ['DISEASE'],
#   'aliases': ['allergic contact dermatitis to DNP'],
#   'definition': 'An allergic contact dermatitis that has_allergic_trigger 2,4-dinitrophenyl group.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040080',
#   'name': 'patent blue V allergy',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A drug allergy that has_allergic_trigger patent blue V.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040081',
#   'name': 'acid anhydride respiratory allergy',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A respiratory allergy that has_allergic_trigger acid anhydride.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040082',
#   'name': 'oxirane allergy',
#   'types': ['DISEASE'],
#   'aliases': ['ethylene oxide allergy', 'ETO allergy'],
#   'definition': 'A drug allergy that has_allergic_trigger oxirane.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040083',
#   'name': 'Chlamydia pneumonia',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A bacterial pneumonia has_material_basis_in Chlamydia pneumoniae.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040084',
#   'name': 'Streptococcus pneumonia',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A bacterial pneumonia has_material_basis_in Streptococcus pneumoniae.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040085',
#   'name': 'bacterial sepsis',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A bacterial infectious disease has_material_basis_in Bacteria.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040086',
#   'name': 'Polyomavirus-associated nephropathy',
#   'types': ['DISEASE'],
#   'aliases': ['polyomavirus associated nephropathy', 'PVAN'],
#   'definition': 'A viral infectious disease has_material_basis_in BK polyomavirus.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040087',
#   'name': 'autoimmune peripheral neuropathy',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'An autoimmune disease of peripheral nervous system that results in peripheral neuropathy.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040088',
#   'name': 'autoimmune uveitis',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'An autoimmune disease of eyes, ear, nose and throat that is located_in the uvea.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040089',
#   'name': 'autoimmune optic neuritis',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'An autoimmune disease of peripheral nervous system that is located_in the neuron projection bundle connecting eye with brain.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040090',
#   'name': 'autoimmune gastritis',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'An autoimmune disease of gastrointestinal tract that is located_in the stomach.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040091',
#   'name': 'autoimmune pancreatitis',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'An autoimmune disease of endocrine system that is located_in the pancreas.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040092',
#   'name': 'juvenile ankylosing spondylitis',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'An autoimmune disease of musculoskeletal system that is an ankylosing spondylitis with onset during childhood.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040093',
#   'name': 'drug-induced lupus erythematosus',
#   'types': ['DISEASE'],
#   'aliases': ['DIL', 'DILE'],
#   'definition': 'A lupus erythematosus caused by chronic use of certain drugs.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040094',
#   'name': 'autoimmune glomerulonephritis',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'An autoimmune disease of urogenital tract that is located_in the renal glomerulus.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040095',
#   'name': 'autoimmune cardiomyopathy',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'An autoimmune disease of cardiovascular system that is characterized by deterioration of the function of the heart muscle.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040096',
#   'name': 'autoimmune atherosclerosis',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'An autoimmune disease of cardiovascular system that is characterized by a build up of plaque in the arteries.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040097',
#   'name': 'autoimmune vasculitis',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'An autoimmune disease of cardiovascular system that is characterized by inflammation of the blood vessels.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040098',
#   'name': 'pemphigus gestationis',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A pemphigus that is characterized by blistered skin as a result of self-reactive T and B cells that target BP180.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040099',
#   'name': 'livedoid vasculitis',
#   'types': ['DISEASE'],
#   'aliases': ['livedoid vasculopathy'],
#   'definition': 'A vasculitis with purpuric ulcers.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040100',
#   'name': 'Hirata disease',
#   'types': ['DISEASE'],
#   'aliases': ['insulin autoimmune syndrome'],
#   'definition': 'An autoimmune disease of endocrine system characterized by hypoglycemia caused by antibodies to insulin.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040101',
#   'name': "N,N'-diphenylthiourea allergic contact dermatitis",
#   'types': ['DISEASE'],
#   'aliases': ['neoprene allergy'],
#   'definition': 'An allergic contact dermatitis that has_allergic_trigger N,N-diphenylthiourea.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040102',
#   'name': "N,N'-diethylthiourea allergic contact dermatitis",
#   'types': ['DISEASE'],
#   'aliases': ['neoprene allergy'],
#   'definition': 'An allergic contact dermatitis that has_allergic_trigger N,N-diethylthiourea.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040103',
#   'name': 'cefotiam allergy',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A cephalosporin allergy that has_allergic_trigger cefotiam.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0040104',
#   'name': 'toluene 2,4-diisocyanate allergic asthma',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A toluene meta-diisocyanate allergic asthma that has_allergic_trigger toluene 2,4-diisocyanate.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0050004',
#   'name': 'seminal vesicle acute gonorrhea',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A gonococcal seminal vesiculitis that is characterized by back pain, perineal pain, pain with ejaculation, hematospermia and voiding symptoms resulting from inflammation located_in the seminal vesicles caused by Neisseria gonorrhoeae infection.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0050012',
#   'name': 'chikungunya',
#   'types': ['DISEASE'],
#   'aliases': ['Chikungunya fever'],
#   'definition': 'A viral infectious disease that results_in infection located_in joint, has_material_basis_in Chikungunya virus, which is transmitted_by Aedes mosquito bite. The infection has_symptom fever, has_symptom arthralgia, and has_symptom maculopapular rash.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0050025',
#   'name': 'human granulocytic anaplasmosis',
#   'types': ['DISEASE'],
#   'aliases': ['HGE', 'human granulocytic ehrlichiosis'],
#   'definition': 'An ehrlichiosis that results in infection located in granular leukocyte, has_material_basis_in Anaplasma phagocytophilum, which is transmitted by lone star tick (Amblyomma americanum). The infection has symptom headache, has symptom muscle aches, has symptom fatigue, has symptom fever and has symptom rash.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0050026',
#   'name': 'human monocytic ehrlichiosis',
#   'types': ['DISEASE'],
#   'aliases': ['Ehrlichiosis chafeensis'],
#   'definition': 'An ehrlichiosis that results in infection located in monocyte or located in macrophage, has_material_basis_in Ehrlichia chaffeensis, which is transmitted by black-legged tick (Ixodes scapularis), transmitted by western black-legged tick (Ixodes pacificus) or transmitted by castor bean tick (Ixodes ricinus). The infection has symptom headache, has symptom muscle aches, has symptom fatigue, has symptom fever and has symptom rash.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0050032',
#   'name': 'mineral metabolism disease',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'An acquired metabolic disease that is characterized by abnormal mineral metabolism.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0050035',
#   'name': 'African tick-bite fever',
#   'types': ['DISEASE'],
#   'aliases': ['Rickettsia africae spotted fever',
#    'south african tick-bite fever'],
#   'definition': 'A spotted fever that has_material_basis_in Rickettsia africae, which is transmitted_by ticks (Amblyomma hebraeum and Amblyomma variegatum). The infection has_symptom fever, has_symptom eschar and has_symptom maculopapular rash.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0050041',
#   'name': 'Astrakhan spotted fever',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A spotted fever that has_material_basis_in Rickettsia conorii subsp caspia, which is transmitted_by ticks (Rhipicephalus pumilio and Rhipicephalus sanguineus). The infection has_symptom fever, has_symptom eschar (usually single), has_symptom regional adenopathy, has_symptom maculopapular rash on extremities.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0050042',
#   'name': 'Indian tick typhus',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A spotted fever that has_material_basis_in Rickettsia conorii subsp indica, which is transmitted_by ticks (Rhipicephalus sanguineus). The infection has_symptom fever, has_symptom eschar, has_symptom regional adenopathy, and has_symptom maculopapular rash on extremities.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0050043',
#   'name': 'Israeli tick typhus',
#   'types': ['DISEASE'],
#   'aliases': ['Israeli spotted fever'],
#   'definition': 'A spotted fever that has_material_basis_in Rickettsia conorii subsp israelensis, which is transmitted_by ticks (Rhipicephalus sanguineus). The infection has_symptom fever, has_symptom eschar, has_symptom regional adenopathy, and has_symptom maculopapular rash on extremities.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0050046',
#   'name': 'Far Eastern spotted fever',
#   'types': ['DISEASE'],
#   'aliases': ['Rickettsia heilongjiangensis spotted fever'],
#   'definition': 'A spotted fever that has_material_basis_in Rickettsia heilongjiangensis, which is transmitted_by ticks (Haemaphysalis concinna). The infection has_symptom fever, has_symptom eschar, has_symptom maculopapular rash, and has_symptom regional adenopathy.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0050047',
#   'name': 'Flinders Island spotted fever',
#   'types': ['DISEASE'],
#   'aliases': ['FISF', 'Thai tick typhus'],
#   'definition': 'A spotted fever that has_material_basis_in Rickettsia honei, which is transmitted_by cayenne ticks (Amblyomma cajennense). The infection has_symptom mild spotted fever, has_symptom eschar and has_symptom adenopathy.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0050050',
#   'name': 'Japanese spotted fever',
#   'types': ['DISEASE'],
#   'aliases': ['oriental spotted fever', 'Rickettsia japonica spotted fever'],
#   'definition': 'A spotted fever that has_material_basis_in Rickettsia japonica, which is transmitted_by ticks (Dermacentor taiwanensis and Haemaphysalis flava). The infection has_symptom fever, has_symptom eschars, has_symptom regional adenopathy, and has_symptom rash on extremities.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0050051',
#   'name': 'Rickettsia parkeri spotted fever',
#   'types': ['DISEASE'],
#   'aliases': ['maculatum infection'],
#   'definition': 'A spotted fever that has_material_basis_in Rickettsia parkeri, which is transmitted_by Gulf Coast tick (Amblyomma maculatum). The infection has_symptom fever, has_symptom headache, has_symptom eschar, and has_symptom rash.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0050052',
#   'name': 'Rocky Mountain spotted fever',
#   'types': ['DISEASE'],
#   'aliases': ['Brazillian spotted',
#    'Choix',
#    'Exanthematic typhus of Sao Paulo',
#    'Fiebre maculosa',
#    'Fiebre manchada',
#    'Sao Paulo typhus',
#    'So Paulo fever',
#    'Tick typhus',
#    'Tobia fever'],
#   'definition': 'A spotted fever that has_material_basis_in Rickettsia rickettsii, which is transmitted_by ticks (Dermacentor variabilis and Dermacentor andersoni). The infection has_symptom fever, has_symptom headache, has_symptom abdominal pain, and has_symptom maculopapular rash progressing into papular or petechial rash.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0050059',
#   'name': 'oropharyngeal anthrax',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A gastrointestinal anthrax that results in infection located in mucosa of oropharynx, has_material_basis_in Bacillus anthracis, which is transmitted by ingestion of anthrax-infected meat. The infection has symptom lesions, has symptom vomiting of blood, has symptom severe diarrhea, has symptom loss of appetite.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0050061',
#   'name': 'erysipeloid',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A primary bacterial infectious disease that results_in infection located_in skin, has_material_basis_in Erysipelothrix rhusiopathiae, which is transmitted_by contact with infected animals. The infection has_symptom redness of skin, has_symptom tenderness of skin and has_symptom warmth of skin.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0050072',
#   'name': 'adiaspiromycosis',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A primary systemic mycosis that is a fungal infection located_in lungs, or located_in skin, which results_in disseminated granulomatous pulmonary process and cutaneous infection in rodents, small wild mammals and humans, has_material_basis_in Chrysosporium parvum or Emmonsia crescens.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0050073',
#   'name': 'invasive aspergillosis',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'An aspergillosis that is a serious fungal infection of the lung with pneumonia caused by Aspergillus, which spreads to other parts of the body through bloodstream in patients with acute leukemia and recipients of tissue transplants. Clinical symptoms include pulmonary nodules and hemorrhage.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0050083',
#   'name': 'Keshan disease',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A nutritional deficiency that is disease characterized by a cardiomyopathy secondary to selenium deficiency.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0050096',
#   'name': 'tinea barbae',
#   'types': ['DISEASE'],
#   'aliases': ['dermatophytosis of beard'],
#   'definition': 'A dermatophytosis that results_in fungal infection which effects horny layer of epidermis of the bearded areas located_in face or located_in neck, has_material_basis_in Trichophyton mentagrophytes or has_material_basis_in Trichophyton verrucosum, which also effects hair, and effects nail and has_symptom inflammatory kerion-like plaques, and results_in_formation_of noninflammatory superficial perifollicular pustules.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0050097',
#   'name': 'ectothrix infectious disease',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A tinea capitis that results_in fungal infection located_in cuticle of hair, has_material_basis_in Microsporum canis, has_material_basis_in Microsporum gypseum, has_material_basis_in Trichophyton equinum, and has_material_basis_in Trichophyton verrucosum, which produce arthroconidia on the exterior of the hair shaft.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0050105',
#   'name': 'endothrix infectious disease',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A tinea capitis that results_in fungal infection located_in hair, has_material_basis_in Ascomycota fungi that belong to a group called dermatophytes, which produce arthroconidia within the hair shaft only.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0050116',
#   'name': 'tinea imbricata',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A tinea corporis that results_in fungal infection located_in skin, has_material_basis_in Trichophyton concentricum, which is characterized by ring-like growth in overlapping circles that may have an autosomal dominant genetic predisposition.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0050117',
#   'name': 'disease by infectious agent',
#   'types': ['DISEASE'],
#   'aliases': ['infectious disease'],
#   'definition': 'A disease that is the consequence of the presence of pathogenic microbial agents, including pathogenic viruses, pathogenic bacteria, fungi, protozoa, multicellular parasites, and aberrant proteins known as prions.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0050118',
#   'name': 'La Crosse encephalitis',
#   'types': ['DISEASE'],
#   'aliases': ['California Encephalitis',
#    'California virus encephalitis',
#    'Neuroinvasive California encephalitis virus infection'],
#   'definition': 'A viral infectious disease that results_in inflammation located_in brain, has_material_basis_in La Crosse virus, which is transmitted_by treehole mosquito, Ochlerotatus triseriatus. The infection has_symptom seizures, has_symptom headache, has_symptom fever, has_symptom coma, and has_symptom paralysis.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0050120',
#   'name': 'hemophagocytic lymphohistiocytosis',
#   'types': ['DISEASE'],
#   'aliases': ['haemophagocytic syndrome'],
#   'definition': 'A lymphatic system disease that is characterized by an expansion of the monocyte-macrophage population and intense hemophagocytosis. It can occur de novo, but more often occurs in the setting of another disorder, usually an infection or a malignancy. A clinical picture of fever, hepatosplenomegaly, lymphadenopathy and peripheral pancytopenia. The morphologic hallmark of this syndrome is the phagocytosis of hematopoietic elements by morphologically normal macrophages.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0050125',
#   'name': 'dengue shock syndrome',
#   'types': ['DISEASE'],
#   'aliases': ['DSS'],
#   'definition': 'A dengue disease that involves the most severe form of dengue fever, has_material_basis_in Dengue virus [NCBITaxon:12637] with four serotypes (Dengue virus 1, 2, 3 and 4), which are transmitted_by Aedes mosquito bite. The infection has_symptom easy bruising, has_symptom blood spots, has_symptom bleeding gums, and has_symptom nosebleeds. It is accompanied by circulatory collapse, involves hypotension, narrow pulse pressure (less than or equal to 20mm Hg), or frank shock. The shock occurs after two to six days of symptoms, followed by collapse, weak pulse, and blueness around the mouth.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0050127',
#   'name': 'sinusitis',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A paranasal sinus disease involving inflammation of the paranasal sinuses resulting from bacterial, fungal, viral infection, allergic or autoimmune issues. Symptoms can include fever, weakness, fatigue, cough and congestion. There may also be mucus drainage in the back of the throat, called postnasal drip.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0050129',
#   'name': 'secretory diarrhea',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A diarrhea where there is an increase in the active secretion, or there is an inhibition of absorption causing little to no structural damage. The most common cause of this type of diarrhea is a cholera toxin that stimulates the secretion of anions, especially chloride ions.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0050130',
#   'name': 'osmotic diarrhea',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A dirrhea that occurs when too much water is drawn into the bowels. This can be the result of maldigestion (e.g., pancreatic disease or Coeliac disease), in which the nutrients are left in the lumen to pull in water. Osmotic diarrhea can also be caused by osmotic laxatives (which work to alleviate constipation by drawing water into the bowels). In healthy individuals, too much magnesium or vitamin C or undigested lactose can produce osmotic diarrhea and distention of the bowel. A person who does not have lactose intolerance can have difficulty absorbing lactose after an extraordinarily high intake of dairy products.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0050131',
#   'name': 'motility-related diarrhea',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A diarrhea which is caused by the rapid movement of food through the intestines (hypermotility). If the food moves too quickly through the GI tract, there is not enough time for sufficient nutrients and water to be absorbed.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0050132',
#   'name': 'inflammatory diarrhea',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A gastrointestinal system infectious disease involving diarrhea that occurs when there is damage to the mucosal lining or brush border, which leads to a passive loss of protein-rich fluids, and a decreased ability to absorb these lost fluids. It can be caused by bacterial infections, viral infections, parasitic infections, or autoimmune problems such as inflammatory bowel diseases. It can also be caused by tuberculosis, colon cancer, and enteritis.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0050133',
#   'name': 'superficial mycosis',
#   'types': ['DISEASE'],
#   'aliases': ['piedra', 'Steroid-modified tinea infection'],
#   'definition': 'A fungal infectious disease that results_in infection of the outermost layer located_in skin or located_in hair shaft, has_material_basis_in Fungi. No living tissue is invaded and there is no cellular response from the host.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0050134',
#   'name': 'cutaneous mycosis',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A fungal infectious disease that results_in infection of the keratinized layers located_in skin, located_in hair or located_in nail, which extends deeper into the epidermis, has_material_basis_in Fungi and results_in_formation_of skin lesions.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0050135',
#   'name': 'subcutaneous mycosis',
#   'types': ['DISEASE'],
#   'aliases': [],
# ...
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060247',
#   'name': 'Smith-McCort dysplasia',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A Dyggve-Melchior-Clausen disease that is characterized by short limbs and a short trunk with a barrel-shaped chest.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060248',
#   'name': 'Simpson-Golabi-Behmel syndrome type 1',
#   'types': ['DISEASE'],
#   'aliases': ['bulldog syndrome',
#    'DGSX Golabi-Rosen syndrome',
#    'Golabi-Rosen syndrome',
#    'Sara Angers syndrome',
#    'SGB syndrome',
#    'Simpson dysmorphia syndrome',
#    'X-linked dysplasia gigantism syndrome'],
#   'definition': 'A syndrome characterized by pre- and postnatal overgrowth and craniofacial, skeletal, cardiac and renal abnormalities and has_material_basis_in mutation in the gene encoding glypican-3 (GPC3) on chromosome Xq26.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060249',
#   'name': 'scoliosis',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A bone structure disease characterized by an appreciable lateral deviation in the normally straight vertical line of the spine.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060250',
#   'name': 'idiopathic scoliosis',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A scoliosis with no known cause.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060251',
#   'name': 'sclerosteosis',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A hyperostosis characterized by excessive bone formation most prominent in the skull, mandible, clavicle, ribs and diaphyses of long bones; bone formation occurs throughout life.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060252',
#   'name': 'sclerocornea',
#   'types': ['DISEASE'],
#   'aliases': ['isolated congenital sclerocornea'],
#   'definition': 'A corneal disease in which the cornea blends with sclera, resulting in clouding of the cornea.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060253',
#   'name': 'scapuloperoneal myopathy',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A muscular dystrophy which begins at the lower legs and affects the shoulder region earlier and more severely than distal arm.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060254',
#   'name': 'Robinow syndrome',
#   'types': ['DISEASE'],
#   'aliases': ['acral dysostosis with facial and genital abnormalities',
#    'fetal face syndrome',
#    'Robinow dwarfism'],
#   'definition': 'A syndrome characterized by mild to moderate short stature due to growth delays after birth, distinctive craniofacial abnormalities, skeletal malformations and genital abnormalities.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060255',
#   'name': 'rippling muscle disease 2',
#   'types': ['DISEASE'],
#   'aliases': ['autosomal dominant limb-girdle muscular dystrophy type 1C'],
#   'definition': 'A muscle tissue disease characterized by mechanically triggered contractions of skeletal muscle and that has_material_basis_in mutation in the caveolin-3 gene (CAV3) on chromosome 3p25.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060256',
#   'name': 'Dowling-Degos disease',
#   'types': ['DISEASE'],
#   'aliases': ['dark dot disease', 'reticular pigment anomaly of flexures'],
#   'definition': "A pigmentation disease characterized by a reticulate pattern of abnormally dark skin coloring, particularly in the body's folds and creases.",
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060257',
#   'name': 'dyschromatosis symmetrica hereditaria',
#   'types': ['DISEASE'],
#   'aliases': ['reticulate acropigmentation of Dohi'],
#   'definition': 'A pigmentation disease characterized by progressively pigmented and depigmented macules, often mixed in a reticulate pattern, concentrated on the dorsal extremities.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060258',
#   'name': 'reticulate acropigmentation of Kitamura',
#   'types': ['DISEASE'],
#   'aliases': ['RAPK'],
#   'definition': 'A pigmentation disease characterized by lesions that initially arise as letiginous, hyperpigmented macules in a reticular pattern on the dorsal aspect of the hands and feet. Over time, lesions may spread proximally and may darken; palmoplantar pitting and dermatoglyphic disruption may also be present.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060259',
#   'name': 'renal-hepatic-pancreatic dysplasia',
#   'types': ['DISEASE'],
#   'aliases': ["Ivemark's syndrome"],
#   'definition': 'A physical disorder characterized by pancreatic fibrosis, renal dysplasia and hepatic dysgenesis; it is usual fatal soon after birth.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060260',
#   'name': 'ptosis',
#   'types': ['DISEASE'],
#   'aliases': ['blepharoptosis', 'drooping eyelid'],
#   'definition': 'An eye disease characterized by the drooping or falling of the upper or lower eyelid.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060261',
#   'name': 'congenital ptosis',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A ptosis characterized by eyelid drop present at birth.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060262',
#   'name': 'gallbladder disease',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A gastrointestinal system disease that is located_in the gallbladder.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060263',
#   'name': 'porencephaly',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A brain disease that is characterized by encephalomalacia and cystic brain lesions.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060264',
#   'name': 'pontocerebellar hypoplasia',
#   'types': ['DISEASE'],
#   'aliases': ['PCH'],
#   'definition': 'A neurodegenerative disease that is characterized by underdevelopment of the pons and cerebellum.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060265',
#   'name': 'pontocerebellar hypoplasia type 1A',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A pontocerebellar hypoplasia that is characterized by central and peripheral motor dysfunction, hypotonia, spasticity and failure to thrive, has_material_basis_in homozygous or compound heterozygous mutation in the VRK1 gene.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060266',
#   'name': 'pontocerebellar hypoplasia type 1B',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A severe pontocerebellar hypoplasia that is characterized by hypotonia, progressive microcephaly and developmental delay, has_material_basis_in autosomal recessive inheritance of mutation in the EXOSC3 gene.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060267',
#   'name': 'pontocerebellar hypoplasia type 2A',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A severe pontocerebellar hypoplasia that is characterized by progressive microcephaly, chorea, epilepsy and hyperreflexia, has_material_basis_in autosomal recessive inheritance of mutation in the TSEN54 gene.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060268',
#   'name': 'pontocerebellar hypoplasia type 2B',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A severe pontocerebellar hypoplasia that is characterized by progressive microcephaly, clonus, dysphagia and failure to thrive, has_material_basis_in autosomal recessive inheritance of mutation in the TSEN2 gene.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060269',
#   'name': 'pontocerebellar hypoplasia type 2C',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A severe pontocerebellar hypoplasia that is characterized by progressive microcephaly, extrapyramidal dyskinesia, seizure and failure to thrive, has_material_basis_in autosomal recessive inheritance of mutation in the TSEN34 gene.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060270',
#   'name': 'pontocerebellar hypoplasia type 2D',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A pontocerebellar hypoplasia that is characterized by progressive microcephaly, profound intellectual disability, spasticity and seizure, has_material_basis_in autosomal recessive inheritance of mutation in the SEPSECS gene.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060271',
#   'name': 'pontocerebellar hypoplasia type 2E',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A pontocerebellar hypoplasia that is characterized by progressive microcephaly, profound intellectual disability, spasticity and seizure, has_material_basis_in autosomal recessive inheritance of mutation in the VPS53 gene.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060272',
#   'name': 'pontocerebellar hypoplasia type 3',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A pontocerebellar hypoplasia that is characterized by progressive microcephaly, hypotonia, dysmorphic features, profound intellectual disability and seizure, has_material_basis_in autosomal recessive inheritance of mutation in the PCLO gene.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060273',
#   'name': 'pontocerebellar hypoplasia type 4',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A pontocerebellar hypoplasia that is characterized by progressive microcephaly, hypertonia, myoclonus, seizure and early lethality, has_material_basis_in autosomal recessive inheritance of mutation in the TSEN54 gene.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060274',
#   'name': 'pontocerebellar hypoplasia type 5',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A pontocerebellar hypoplasia that is characterized by severe olivopontocerebellar hypoplasia and degeneration leading to early lethality, has_material_basis_in autosomal recessive inheritance of mutation in the TSEN54 gene.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060275',
#   'name': 'pontocerebellar hypoplasia type 6',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A pontocerebellar hypoplasia that is characterized by olivopontocerebellar hypoplasia and developmental delay, has_material_basis_in autosomal recessive inheritance of mutation in the RARS2 gene.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060276',
#   'name': 'pontocerebellar hypoplasia type 7',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A pontocerebellar hypoplasia that is characterized by delayed psychomotor development, hypotonia, gonadal abnormalities and respiratory failure, has_material_basis_in autosomal recessive mutation in the TOE1 gene.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060277',
#   'name': 'pontocerebellar hypoplasia type 8',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A pontocerebellar hypoplasia that is characterized by delayed psychomotor development, chorea, hypotonia, spasticity and visual defects, has_material_basis_in autosomal recessive inheritance of mutation in the CHMP1A gene.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060278',
#   'name': 'pontocerebellar hypoplasia type 9',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A pontocerebellar hypoplasia that is characterized by progressive microcephaly, spasticity, seizure and brain atrophy, has_material_basis_in autosomal recessive inheritance of mutation in the AMPD2 gene.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060279',
#   'name': 'pontocerebellar hypoplasia type 10',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A pontocerebellar hypoplasia that is characterized by severe developmental delays, progressive microcephaly, spasticity and seizure, has_material_basis_in autosomal recessive inheritance of mutation in the CLP1 gene.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060280',
#   'name': 'primary pigmented nodular adrenocortical disease',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'An adrenal cortex disease characterized by small to normal sized adrenal glands containing multiple small cortical pigmented nodules.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060281',
#   'name': 'photosensitive epilepsy',
#   'types': ['DISEASE'],
#   'aliases': ['photogenic epilepsy', 'photoparoxysmal response'],
#   'definition': 'An epilepsy characterized by seizures triggered by visual stimuli that form patterns in space or time, such as flashing lights.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060282',
#   'name': 'persistent hyperplastic primary vitreous',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A developmental vitreous disease that is characterized by leukocoria, strabismus and vision loss, caused by failure of primary vitreous and hyaloid vasculature to regress during embryological development.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060283',
#   'name': 'peeling skin syndrome',
#   'types': ['DISEASE'],
#   'aliases': ['deciduous skin',
#    'familial continuous skin peeling syndrome',
#    'keratosis exfoliativa congenita',
#    'peeling skin disease',
#    'PSS'],
#   'definition': 'A skin disease that is characterized by the painless, continuous peeling of the top layer of skin.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060284',
#   'name': 'paroxysmal nocturnal hemoglobinuria',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'An acquired hemolytic anemia that is characterized by abdominal pain, hematuria, esophageal dysmotility and thrombosis, has_material_basis_in defect in the cell membrane glycosyl phosphatidylinositols that protect red blood cells from the innate complement immune system.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060285',
#   'name': 'parietal foramina',
#   'types': ['DISEASE'],
#   'aliases': ['Caitlin marks',
#    'enlarged parietal foramina',
#    'hereditary cranium bifidum'],
#   'definition': 'An inherited neural tube defect that is characterized by enlarged openings in the parietal bones of the skull, has_material_basis_in mutation in the ALX4 gene or MSX2 gene.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060286',
#   'name': 'combined oxidative phosphorylation deficiency',
#   'types': ['DISEASE'],
#   'aliases': [],
#   'definition': 'A mitochondrial metabolism disease that is characterized by growth retardation, microcephaly, hypertonia, encephalopathy, cardiomyopathy and liver dysfunction.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  {'cui': 'DOID:0060287',
#   'name': 'cornea plana',
#   'types': ['DISEASE'],
#   'aliases': ['flat cornea'],
#   'definition': 'A corneal disease that is characterized by a flat cornea where the radus of curvature is less than 43 D.',
#   'equivalent_cuis': [],
#   'taxonomy': None,
#   'metadata': None},
#  ...]

# %% [markdown]
# ### Check if the dataset has any null definition

# %%
# Get the index of rows with null definitions
null_definitions_indices = [i for i, entity in enumerate(data) if entity.get('definition') is None]

print(f"Indices of rows with null definitions: {null_definitions_indices}")
# Out:
# Indices of rows with null definitions: [5978, 5989, 5992, 6012, 6016, 6017, 6026, 6029, 6030, 6060, 6080, 6082, 6085, 6086, 6088, 6093, 6094, 6102, 6103, 6104, 6106, 6107, 6109, 6110, 6111, 6121, 6123, 6124, 6125, 6126, 6135, 6140, 6145, 6150, 6154, 6157, 6158, 6164, 6166, 6167, 6171, 6172, 6173, 6175, 6176, 6177, 6178, 6180, 6188, 6192, 6193, 6195, 6199, 6200, 6202, 6204, 6207, 6208, 6218, 6219, 6221, 6223, 6224, 6226, 6228, 6231, 6232, 6238, 6239, 6243, 6244, 6246, 6247, 6249, 6251, 6256, 6261, 6266, 6278, 6282, 6283, 6285, 6290, 6291, 6292, 6294, 6295, 6297, 6298, 6300, 6306, 6307, 6308, 6309, 6310, 6311, 6312, 6313, 6314, 6318, 6322, 6328, 6330, 6338, 6340, 6343, 6344, 6345, 6346, 6347, 6348, 6349, 6354, 6361, 6365, 6366, 6369, 6371, 6378, 6382, 6388, 6390, 6392, 6393, 6400, 6401, 6402, 6403, 6404, 6405, 6406, 6407, 6409, 6419, 6420, 6421, 6422, 6423, 6426, 6428, 6429, 6430, 6432, 6434, 6438, 6444, 6445, 6447, 6448, 6449, 6451, 6452, 6453, 6455, 6457, 6458, 6459, 6463, 6467, 6468, 6469, 6471, 6472, 6477, 6481, 6483, 6485, 6487, 6490, 6493, 6496, 6497, 6498, 6502, 6504, 6505, 6506, 6507, 6508, 6509, 6511, 6512, 6518, 6525, 6527, 6528, 6529, 6530, 6532, 6536, 6537, 6539, 6541, 6542, 6543, 6544, 6546, 6550, 6551, 6553, 6554, 6556, 6557, 6558, 6559, 6564, 6571, 6572, 6580, 6582, 6587, 6591, 6594, 6595, 6596, 6598, 6600, 6601, 6602, 6603, 6607, 6608, 6610, 6611, 6612, 6613, 6614, 6616, 6617, 6620, 6622, 6623, 6626, 6628, 6629, 6630, 6631, 6633, 6634, 6635, 6637, 6638, 6639, 6641, 6643, 6647, 6648, 6653, 6654, 6655, 6658, 6660, 6663, 6666, 6667, 6668, 6670, 6673, 6674, 6675, 6678, 6680, 6683, 6685, 6686, 6687, 6688, 6689, 6692, 6695, 6696, 6701, 6703, 6709, 6711, 6712, 6713, 6716, 6718, 6719, 6720, 6721, 6722, 6723, 6724, 6725, 6728, 6729, 6730, 6737, 6738, 6739, 6740, 6741, 6748, 6749, 6750, 6753, 6755, 6756, 6757, 6759, 6760, 6763, 6765, 6766, 6767, 6772, 6773, 6774, 6776, 6778, 6779, 6782, 6783, 6785, 6786, 6787, 6788, 6789, 6790, 6791, 6794, 6796, 6797, 6798, 6799, 6802, 6803, 6805, 6806, 6807, 6810, 6814, 6820, 6821, 6828, 6830, 6832, 6836, 6837, 6838, 6841, 6842, 6843, 6848, 6851, 6852, 6853, 6854, 6855, 6857, 6859, 6862, 6865, 6866, 6872, 6873, 6874, 6876, 6879, 6883, 6884, 6885, 6886, 6887, 6890, 6891, 6892, 6893, 6897, 6904, 6905, 6912, 6913, 6916, 6917, 6918, 6921, 6922, 6923, 6924, 6925, 6927, 6928, 6937, 6939, 6940, 6941, 6946, 6947, 6955, 6956, 6957, 6959, 6960, 6961, 6962, 6969, 6970, 6971, 6973, 6974, 6980, 6982, 6983, 6986, 6987, 6988, 6989, 6990, 6991, 6992, 6993, 6996, 6997, 7001, 7002, 7003, 7007, 7009, 7013, 7015, 7016, 7017, 7018, 7020, 7023, 7025, 7026, 7027, 7029, 7030, 7031, 7032, 7036, 7038, 7039, 7042, 7045, 7048, 7050, 7051, 7052, 7053, 7054, 7057, 7058, 7059, 7061, 7062, 7063, 7064, 7065, 7066, 7070, 7072, 7074, 7076, 7077, 7080, 7084, 7086, 7091, 7096, 7099, 7102, 7103, 7105, 7106, 7107, 7109, 7110, 7111, 7130, 7131, 7132, 7137, 7138, 7141, 7142, 7143, 7146, 7147, 7148, 7150, 7151, 7152, 7153, 7156, 7161, 7162, 7163, 7164, 7165, 7167, 7168, 7170, 7171, 7173, 7174, 7179, 7182, 7184, 7187, 7190, 7191, 7193, 7194, 7196, 7198, 7202, 7205, 7208, 7210, 7212, 7213, 7215, 7217, 7218, 7219, 7220, 7221, 7222, 7223, 7224, 7225, 7226, 7228, 7229, 7233, 7242, 7243, 7244, 7246, 7247, 7248, 7250, 7251, 7252, 7260, 7261, 7262, 7263, 7264, 7266, 7272, 7281, 7282, 7284, 7285, 7289, 7290, 7291, 7293, 7296, 7299, 7302, 7303, 7304, 7306, 7307, 7309, 7310, 7311, 7313, 7314, 7316, 7320, 7321, 7323, 7324, 7334, 7336, 7338, 7340, 7341, 7343, 7345, 7346, 7348, 7349, 7351, 7352, 7355, 7358, 7362, 7363, 7364, 7368, 7369, 7370, 7374, 7375, 7377, 7378, 7379, 7381, 7383, 7386, 7387, 7391, 7393, 7394, 7396, 7398, 7399, 7400, 7401, 7402, 7404, 7405, 7406, 7408, 7410, 7411, 7412, 7414, 7415, 7416, 7417, 7423, 7428, 7431, 7432, 7435, 7437, 7438, 7439, 7446, 7447, 7448, 7449, 7450, 7452, 7454, 7455, 7456, 7462, 7470, 7472, 7473, 7474, 7475, 7479, 7484, 7486, 7490, 7491, 7501, 7502, 7506, 7507, 7511, 7513, 7514, 7515, 7517, 7519, 7522,  ...

# %% [markdown]
# ### Get canonical name of entities in the ontology

# %%
def get_canonical_name(data):
    '''
    Get name of entities in the ontology
    data: list of dict
    '''
    # Extract tuples of CUI and canonical names from the data
    canonical_names = {entity.get('cui'): entity.get('name') for entity in data}
    return canonical_names

# %%
entity_to_name = get_canonical_name(data)
print("\nThis mapping is a specific application of the canonical name concept within the context of UMLS, linking each unique concept (identified by its CUI) to its preferred term")
print('\nThe first 5 elements are:')
print(list(entity_to_name.items())[:5])
# Out:
# This mapping is a specific application of the canonical name concept within the context of UMLS, linking each unique concept (identified by its CUI) to its preferred term
#
# The first 5 elements are:
# [('DOID:0001816', 'angiosarcoma'), ('DOID:0002116', 'pterygium'), ('DOID:0014667', 'disease of metabolism'), ('DOID:0040001', 'shrimp allergy'), ('DOID:0040002', 'aspirin allergy')]

# %% [markdown]
# ### Get aliases of entities in the ontology

# %%
def get_aliases(data):
    '''
    Get aliases of entities in the ontology
    data: list of dict
    '''
    # Extract tuples of CUI and aliases from the Data
    aliases = {entity.get('cui'): entity.get('aliases') for entity in data}
    return aliases

# %%
entity_to_aliases = get_aliases(data)
print("\nThis mapping is a specific application of the canonical name concept within the context of UMLS, linking each unique concept (identified by its CUI) to its preferred term")
print('\nThe first 5 elements are:')
print(list(entity_to_aliases.items())[:5])
# Out:
# This mapping is a specific application of the canonical name concept within the context of UMLS, linking each unique concept (identified by its CUI) to its preferred term
#
# The first 5 elements are:
# [('DOID:0001816', ['hemangiosarcoma']), ('DOID:0002116', ["surfer's eye"]), ('DOID:0014667', ['metabolic disease']), ('DOID:0040001', []), ('DOID:0040002', ['acetylsalicylic acid allergy', 'ASA allergy'])]

# %% [markdown]
# ### Get definition of entities in the ontology

# %%
def get_definition(data):
    '''
    Get definition of entities in the ontology
    data: list of dict
    '''
    # Extract tuples of CUI and definition from the Data
    definitions_dict = {entity['cui']: entity['definition'] for entity in data if entity['definition'] is not None}
    return definitions_dict

# %%
cui2definition = get_definition(data)
print("\nThis mapping is a specific application of the canonical name concept within the context of UMLS, linking each unique concept (identified by its CUI) to its preferred term")
print('\nThe first 5 elements are:')
print(list(cui2definition.items())[:5])
# Out:
# This mapping is a specific application of the canonical name concept within the context of UMLS, linking each unique concept (identified by its CUI) to its preferred term
#
# The first 5 elements are:
# [('DOID:0001816', 'A vascular cancer that derives_from the cells that line the walls of blood vessels or lymphatic vessels.'), ('DOID:0002116', 'A corneal disease that is characterized by a triangular tissue growth located_in cornea of the eye that is the result of collagen degeneration and fibrovascular proliferation.'), ('DOID:0014667', 'A disease that involving errors in metabolic processes of building or degradation of molecules.'), ('DOID:0040001', 'A crustacean allergy that has_allergic_trigger shrimp.'), ('DOID:0040002', 'A drug allergy that has_allergic_trigger acetylsalicylic acid.')]

# %% [markdown]
# ### Get types of entities in the ontology

# %%
def get_types(data):
    '''
    Get type of entities in the ontology
    data: list of dict
    '''
    # Extract tuples of CUI and types from the Data
    types = {entity['cui']: entity['types'] for entity in data}
    return types

# %%
cui2tui = get_types(data)
print('\nThe first 5 elements are:')
print(list(cui2tui.items())[:5])
# Out:
# The first 5 elements are:
# [('DOID:0001816', ['DISEASE']), ('DOID:0002116', ['DISEASE']), ('DOID:0014667', ['DISEASE']), ('DOID:0040001', ['DISEASE']), ('DOID:0040002', ['DISEASE'])]

# %% [markdown]
# # BEST VERSION : process obo ontology

# %%
import os
import pickle
from tqdm import tqdm

def process_obo_ontology(ontology, data_path, obo_dict):
    '''
    This function prepares the entity data : dictionary.pickle
    
    Parameters 
    ----------
    - ontology : str (only umls for now)
        Ontology associated with the dataset
    - data_path : str
        Path where to load and save dictionary.pickle
    - obo_dict : dict
        dictionary with the parameter expected by load_obo method : 
        filepath, name, prefix_to_keep, entity_type, abbrev
    '''
    
    ontology = BiomedicalOntology.load_obo(**obo_dict)
    
    equivalent_cuis = False
    if ontology.entities[0].equivalant_cuis is not None : 
        equivalent_cuis = True
        
    'If dictionary already processed, load it else process and load it'
    entity_dictionary_pkl_path = os.path.join(data_path, 'dictionary.pickle')
    
    if os.path.isfile(entity_dictionary_pkl_path): 
        print("Loading stored processed entity dictionary...")
        with open(entity_dictionary_pkl_path, 'rb') as read_handle:
            entities = pickle.load(read_handle)
        
        return entities, equivalent_cuis
    
    ontology_entities = []
    for entity in tqdm(ontology.entities):      
        if entity.aliases != "":
            if entity.definition != "":
                new_entity = {
                    'type': entity.types,
                    'cui': entity.cui,
                    'title': entity.name,
                    'description': f"{entity.name} ( {entity.types} : {entity.aliases} ) [{entity.definition}]"
                }
            else : 
                new_entity = {
                    'type': entity.types,
                    'cui': entity.cui,
                    'title': entity.name,
                    'description': f"{entity.name} ( {entity.types} : {entity.aliases} )"
                }
                
        else : 
            if entity.definition != "":
                new_entity = {
                        'type': entity.types,
                        'cui': entity.cui,
                        'title': entity.name,
                        'description': f"{entity.name} ( {entity.types} ) [{entity.definition}]"
                    }
            else : 
                new_entity = {
                        'type': entity.types,
                        'cui': entity.cui,
                        'title': entity.name,
                        'description': f"{entity.name} ( {entity.types} )"
                    }
        ontology_entities.append(new_entity)
        
    # Check if the directory exists, and create it if it does not
    if not os.path.exists(data_path):
        os.makedirs(data_path)

    # Save entities to pickle file
    with open(os.path.join(data_path, "dictionary.pickle"), "wb") as f:
        pickle.dump(ontology_entities, f)

    entities = pickle.load(open(os.path.join(data_path, "dictionary.pickle"), "rb"))
    return entities, equivalent_cuis

# %%
from bioel.ontology import BiomedicalOntology

obo_dict = {'filepath': 'https://raw.githubusercontent.com/DiseaseOntology/HumanDiseaseOntology/main/src/ontology/doid.obo',
        'name': 'disease ontology',
        'prefix_to_keep': None,
        'entity_type': 'DISEASE',
        'abbrev': 'DOID'}

ontology = f"{obo_dict['name']}"
model = "arboel"
dataset = "random"
abs_path = "/home2/cye73/data"
data_path = os.path.join(abs_path, model, dataset)
print(data_path)

entities = process_obo_ontology(ontology = ontology,
                                    data_path= data_path,
                                    obo_dict = obo_dict, )
# Out:
# [2024-04-02 17:55:08] [ontology.py] [INFO] Reading OBO ontology from https://raw.githubusercontent.com/DiseaseOntology/HumanDiseaseOntology/main/src/ontology/doid.obo
# /home2/cye73/data/arboel/random
# 100%|██████████| 11537/11537 [00:00<00:00, 52864.51it/s]
# 100%|██████████| 11537/11537 [00:00<00:00, 515782.53it/s]

# %%
entities[0]
# Out:
# {'type': ['DISEASE'],
#  'cui': 'DOID:0001816',
#  'title': 'angiosarcoma',
#  'description': "angiosarcoma ( ['DISEASE'] : ['hemangiosarcoma'] ) [A vascular cancer that derives_from the cells that line the walls of blood vessels or lymphatic vessels.]"}

# %%
entities
# Out:
# [{'type': ['DISEASE'],
#   'cui': 'DOID:0001816',
#   'title': 'angiosarcoma',
#   'description': "angiosarcoma ( ['DISEASE'] : hemangiosarcoma ) [ A vascular cancer that derives_from the cells that line the walls of blood vessels or lymphatic vessels. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0002116',
#   'title': 'pterygium',
#   'description': "pterygium ( ['DISEASE'] : surfer's eye ) [ A corneal disease that is characterized by a triangular tissue growth located_in cornea of the eye that is the result of collagen degeneration and fibrovascular proliferation. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0014667',
#   'title': 'disease of metabolism',
#   'description': "disease of metabolism ( ['DISEASE'] : metabolic disease ) [ A disease that involving errors in metabolic processes of building or degradation of molecules. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040001',
#   'title': 'shrimp allergy',
#   'description': "shrimp allergy ( ['DISEASE'] ) [ A crustacean allergy that has_allergic_trigger shrimp. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040002',
#   'title': 'aspirin allergy',
#   'description': "aspirin allergy ( ['DISEASE'] : acetylsalicylic acid allergy ; ASA allergy ) [ A drug allergy that has_allergic_trigger acetylsalicylic acid. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040003',
#   'title': 'benzylpenicillin allergy',
#   'description': "benzylpenicillin allergy ( ['DISEASE'] : benzyl penicillin allergy ; penicillin G allergy ) [ A beta-lactam allergy that has_allergic_trigger benzylpenicillin. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040004',
#   'title': 'amoxicillin allergy',
#   'description': "amoxicillin allergy ( ['DISEASE'] ) [ A beta-lactam allergy that has_allergic_trigger amoxicillin. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040005',
#   'title': 'ceftriaxone allergy',
#   'description': "ceftriaxone allergy ( ['DISEASE'] : rocephin allergy ) [ A cephalosporin allergy that has_allergic_trigger ceftriaxone. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040006',
#   'title': 'carbamazepine allergy',
#   'description': "carbamazepine allergy ( ['DISEASE'] : carbamazepen allergy ; Tegretol allergy ) [ A drug allergy that has_allergic_trigger carbamazepine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040007',
#   'title': 'abacavir allergy',
#   'description': "abacavir allergy ( ['DISEASE'] : ABC allergy ) [ A drug allergy that has_allergic_trigger abacavir. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040008',
#   'title': 'isoniazide allergy',
#   'description': "isoniazide allergy ( ['DISEASE'] : INH allergy ; isonicotinylhydrazide allergy ) [ A drug allergy that has_allergic_trigger isoniazide. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040009',
#   'title': 'lidocaine allergy',
#   'description': "lidocaine allergy ( ['DISEASE'] : Lidoderm allergy ; lignocaine allergy ; xylocaine allergy ) [ A drug allergy that has_allergic_trigger lidocaine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040010',
#   'title': 'mepivacaine allergy',
#   'description': "mepivacaine allergy ( ['DISEASE'] : Carbocaine allergy ; Polocaine allergy ) [ A drug allergy that has_allergic_trigger mepivacaine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040011',
#   'title': 'phenobarbital allergy',
#   'description': "phenobarbital allergy ( ['DISEASE'] : Luminal allergy ; phenobarbitol allergy ; phenobarbitone allergy ) [ A drug allergy that has_allergic_trigger phenobarbital. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040012',
#   'title': 'phenytoin allergy',
#   'description': "phenytoin allergy ( ['DISEASE'] : Dilantin allergy ) [ A drug allergy that has_allergic_trigger phenytoin. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040013',
#   'title': 'ranitidine allergy',
#   'description': "ranitidine allergy ( ['DISEASE'] : Zantac allergy ) [ A drug allergy that has_allergic_trigger ranitidine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040014',
#   'title': 'corticosteroid allergy',
#   'description': "corticosteroid allergy ( ['DISEASE'] ) [ A drug allergy that has_allergic_trigger corticosteroid. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040015',
#   'title': 'sulfonamide allergy',
#   'description': "sulfonamide allergy ( ['DISEASE'] ) [ A drug allergy that has_allergic_trigger sulfonamide. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040016',
#   'title': 'sulfamethoxazole allergy',
#   'description': "sulfamethoxazole allergy ( ['DISEASE'] : SMX allergy ; SMZ allergy ; sulphamethoxazole allergy ) [ A drug allergy that has_allergic_trigger sulfamethoxazole. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040017',
#   'title': 'suprofen allergy',
#   'description': "suprofen allergy ( ['DISEASE'] : Profenal allergy ) [ A drug allergy that has_allergic_trigger suprofen. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040018',
#   'title': 'thiopental allergy',
#   'description': "thiopental allergy ( ['DISEASE'] : penthiobarbital allergy ; pentothiobarbital allergy ) [ A drug allergy that has_allergic_trigger thiopental. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040019',
#   'title': 'D-mannitol allergy',
#   'description': "D-mannitol allergy ( ['DISEASE'] : mannitol allergy ) [ A drug allergy that has_allergic_trigger D-mannitol. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040020',
#   'title': 'cefotaxime allergy',
#   'description': "cefotaxime allergy ( ['DISEASE'] ) [ A cephalosporin allergy that has_allergic_trigger cefotaxime. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040021',
#   'title': 'cephalosporin allergy',
#   'description': "cephalosporin allergy ( ['DISEASE'] ) [ A drug allergy that has_allergic_trigger cephalosporin. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040022',
#   'title': 'amodiaquine allergy',
#   'description': "amodiaquine allergy ( ['DISEASE'] : Camoquin allergy ; Flavoquine allergy ) [ A drug allergy that has_allergic_trigger amodiaquine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040023',
#   'title': 'cefaclor allergy',
#   'description': "cefaclor allergy ( ['DISEASE'] : Ceclor allergy ; cephaclor allergy ) [ A cephalosporin allergy that has_allergic_trigger cefaclor. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040024',
#   'title': 'ceftazidime allergy',
#   'description': "ceftazidime allergy ( ['DISEASE'] : Fortaz allergy ; Tazicef allergy ) [ A cephalosporin allergy that has_allergic_trigger ceftazidime. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040025',
#   'title': 'cefuroxime allergy',
#   'description': "cefuroxime allergy ( ['DISEASE'] : cephuroxime allergy ; Zinacef allergy ) [ A cephalosporin allergy that has_allergic_trigger cefuroxime. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040026',
#   'title': 'chlorhexidine allergy',
#   'description': "chlorhexidine allergy ( ['DISEASE'] ) [ A drug allergy that has_allergic_trigger chlorhexidine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040027',
#   'title': 'cyclophosphamide allergy',
#   'description': "cyclophosphamide allergy ( ['DISEASE'] : cytophosphane allergy ) [ A drug allergy that has_allergic_trigger cyclophosphamide. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040028',
#   'title': 'succinylcholine allergy',
#   'description': "succinylcholine allergy ( ['DISEASE'] : dicholine succinate allergy ; succinocholine allergy ; sux allergy ; suxamethonium allergy ) [ A drug allergy that has_allergic_trigger succinylcholine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040029',
#   'title': 'trimethoprim allergy',
#   'description': "trimethoprim allergy ( ['DISEASE'] : Primsol allergy ; proloprim allergy ; TMP allergy ) [ A drug allergy that has_allergic_trigger trimethoprim. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040030',
#   'title': 'cefixime allergy',
#   'description': "cefixime allergy ( ['DISEASE'] ) [ A cephalosporin allergy that has_allergic_trigger cefixime. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040031',
#   'title': 'diclofenac allergy',
#   'description': "diclofenac allergy ( ['DISEASE'] : Voltaren allergy ) [ A drug allergy that has_allergic_trigger diclofenac. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040032',
#   'title': 'carbapenem allergy',
#   'description': "carbapenem allergy ( ['DISEASE'] ) [ A drug allergy that has_allergic_trigger carbapenems. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040033',
#   'title': 'piperacillin allergy',
#   'description': "piperacillin allergy ( ['DISEASE'] ) [ A beta-lactam allergy that has_allergic_trigger piperacillin. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040034',
#   'title': 'rocuronium allergy',
#   'description': "rocuronium allergy ( ['DISEASE'] : Esmeron allergy ; Zemuron allergy ) [ A drug allergy that has_allergic_trigger rocuronium. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040035',
#   'title': 'sulfasalazine allergy',
#   'description': "sulfasalazine allergy ( ['DISEASE'] ) [ A drug allergy that has_allergic_trigger sulfasalazine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040036',
#   'title': 'tubocurarine allergy',
#   'description': "tubocurarine allergy ( ['DISEASE'] : DTC allergy ) [ A drug allergy that has_allergic_trigger tubocurarine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040037',
#   'title': 'aztreonam allergy',
#   'description': "aztreonam allergy ( ['DISEASE'] : Azactam allergy ; Primbactam allergy ) [ A beta-lactam allergy that has_allergic_trigger aztreonam. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040038',
#   'title': 'meropenem allergy',
#   'description': "meropenem allergy ( ['DISEASE'] : Merrem allergy ) [ An allergic asthma that has_allergic_trigger meropenem, a beta-lactam antibiotic. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040040',
#   'title': 'hexamethylene diisocyanate allergic asthma',
#   'description': "hexamethylene diisocyanate allergic asthma ( ['DISEASE'] : allergic asthma to HDI ; allergic asthma to HMDI ) [ An isocyanates allergic asthma that has_allergic_trigger hexamethylene diisocyanate. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040041',
#   'title': 'isocyanates allergic asthma',
#   'description': "isocyanates allergic asthma ( ['DISEASE'] ) [ An allergic asthma that has_allergic_trigger isocyanates. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040042',
#   'title': "diphenylmethane-4,4'-diisocyanate allergic asthma",
#   'description': "diphenylmethane-4,4'-diisocyanate allergic asthma ( ['DISEASE'] : allergic asthma to MDI ) [ An isocyanates allergic asthma that has_allergic_trigger diphenylmethane-4,4-diisocyanate. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040043',
#   'title': 'toluene meta-diisocyanate allergic asthma',
#   'description': "toluene meta-diisocyanate allergic asthma ( ['DISEASE'] : allergic asthma to TDI ) [ An isocyanates allergic asthma that has_allergic_trigger toluene meta-diisocyanate. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040044',
#   'title': 'methyl isocyanate allergic asthma',
#   'description': "methyl isocyanate allergic asthma ( ['DISEASE'] : allergic asthma to MIC ) [ An isocyanates allergic asthma that has_allergic_trigger methyl isocyanate. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040045',
#   'title': 'nickel allergic asthma',
#   'description': "nickel allergic asthma ( ['DISEASE'] : allergic asthma to Ni ) [ An allergic asthma that has_allergic_trigger nickel atom. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040046',
#   'title': 'nickel allergic contact dermatitis',
#   'description': "nickel allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to Ni ) [ An allergic contact dermatitis that has_allergic_trigger nickel atom. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040047',
#   'title': 'trimellitic anhydride allergic asthma',
#   'description': "trimellitic anhydride allergic asthma ( ['DISEASE'] : allergic asthma to TMA ) [ An allergic asthma that has_allergic_trigger trimellitic anhydride. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040048',
#   'title': 'phthalic anhydride allergic asthma',
#   'description': "phthalic anhydride allergic asthma ( ['DISEASE'] ) [ An allergic asthma that has_allergic_trigger phthalic anhydride. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040049',
#   'title': 'maleic anhydride allergic asthma',
#   'description': "maleic anhydride allergic asthma ( ['DISEASE'] : allergic asthma to MA ) [ An allergic asthma that has_allergic_trigger maleic anhydride. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040050',
#   'title': 'tetrachlorophthalic anhydride allergic asthma',
#   'description': "tetrachlorophthalic anhydride allergic asthma ( ['DISEASE'] ) [ An allergic asthma that has_allergic_trigger tetrachlorophthalic anhydride. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040051',
#   'title': 'hexahydrophthalic anhydride allergic asthma',
#   'description': "hexahydrophthalic anhydride allergic asthma ( ['DISEASE'] : allergic asthma to HHPA ) [ An allergic asthma that has_allergic_trigger hexahydrophthalic anhydride. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040052',
#   'title': "diphenylmethane-4,4'-diisocyanate allergic contact dermatitis",
#   'description': "diphenylmethane-4,4'-diisocyanate allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to MDI ) [ An allergic contact dermatitis that has_allergic_trigger diphenylmethane-4,4-diisocyanate. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040053',
#   'title': 'cobalt allergic contact dermatitis',
#   'description': "cobalt allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to Co ) [ An allergic contact dermatitis that has_allergic_trigger cobalt atom. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040054',
#   'title': 'cobalt allergic asthma',
#   'description': "cobalt allergic asthma ( ['DISEASE'] : Co allergic asthma ) [ An allergic asthma that has_allergic_trigger cobalt atom. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040055',
#   'title': 'palladium allergic contact dermatitis',
#   'description': "palladium allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to Pd ) [ An allergic contact dermatitis that has_allergic_trigger palladium. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040056',
#   'title': 'chromium allergic contact dermatitis',
#   'description': "chromium allergic contact dermatitis ( ['DISEASE'] ) [ An allergic contact dermatitis that has_allergic_trigger chromium atom. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040057',
#   'title': 'benzoic acid allergic contact dermatitis',
#   'description': "benzoic acid allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to benzoate ) [ An allergic contact dermatitis that has_allergic_trigger benzoic acid. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040058',
#   'title': '1,4-phenylenediamine allergic contact dermatitis',
#   'description': "1,4-phenylenediamine allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to p-phenylenediamine ; allergic contact dermatitis to PPD ) [ An allergic contact dermatitis that has_allergic_trigger 1,4-phenylenediamine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040059',
#   'title': 'potassium dichromate allergic contact dermatitis',
#   'description': "potassium dichromate allergic contact dermatitis ( ['DISEASE'] ) [ An allergic contact dermatitis that has_allergic_trigger potassium dichromate. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040060',
#   'title': 'ketoprofen photoallergic dermatitis',
#   'description': "ketoprofen photoallergic dermatitis ( ['DISEASE'] : photoallergic dermatitis to Orudis ) [ A photoallergic dermatitis that has_allergic_trigger ketoprofen. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040061',
#   'title': 'remazole black respiratory allergy',
#   'description': "remazole black respiratory allergy ( ['DISEASE'] : respiratory allergy to Reactive Black 5 ) [ A respiratory allergy that has_allergic_trigger remazole black-GR. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040062',
#   'title': 'chloramine T respiratory allergy',
#   'description': "chloramine T respiratory allergy ( ['DISEASE'] : respiratory allergy to Chloraseptin ; respiratory allergy to Chlorazol ; respiratory allergy to Trichlorol ) [ A respiratory allergy that has_allergic_trigger chloramine T. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040063',
#   'title': '4-vinylcyclohexene dioxide respiratory allergy',
#   'description': "4-vinylcyclohexene dioxide respiratory allergy ( ['DISEASE'] : respiratory allergy to vinyl cyclohexene diepoxide ) [ A respiratory allergy that has_allergic_trigger 4-vinylcyclohexene dioxide. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040064',
#   'title': 'carvone allergic contact dermatitis',
#   'description': "carvone allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to levo-carvone ) [ An allergic contact dermatitis that has_allergic_trigger (-)-carvone. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040065',
#   'title': 'quinidine allergy',
#   'description': "quinidine allergy ( ['DISEASE'] : Kinidin allergy ) [ A drug allergy that has_allergic_trigger quinidine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040066',
#   'title': 'melphalan allergy',
#   'description': "melphalan allergy ( ['DISEASE'] : Alkeran allergy ) [ A drug allergy that has_allergic_trigger melphalan. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040067',
#   'title': 'neomycin sulfate allergic contact dermatitis',
#   'description': "neomycin sulfate allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to neomycin sulphate ) [ An allergic contact dermatitis that has_allergic_trigger neomycin sulfate. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040068',
#   'title': '4-tert-butylphenol allergic contact dermatitis',
#   'description': "4-tert-butylphenol allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to butylphen ; allergic contact dermatitis to PTBP ) [ An allergic contact dermatitis that has_allergic_trigger 4-tert-butylphenol. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040069',
#   'title': '1-chloro-2,4-dinitrobenzene allergic contact dermatitis',
#   'description': "1-chloro-2,4-dinitrobenzene allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to dinitrochlorobenzene ; allergic contact dermatitis to DNCB ) [ An allergic contact dermatitis that has_allergic_trigger 1-chloro-2,4-dinitrobenzene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040070',
#   'title': 'co-trimoxazole allergy',
#   'description': "co-trimoxazole allergy ( ['DISEASE'] : Bactrim allergy ; cotrimoxazol allergy ; TMP/SMX allergy ; trimethoprim/sulfamethoxazole allergy ) [ A drug allergy that has_allergic_trigger co-trimoxazole. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040071',
#   'title': 'sodium aurothiomalate allergy',
#   'description': "sodium aurothiomalate allergy ( ['DISEASE'] : gold sodium thiomalate allergy ) [ A drug allergy that has_allergic_trigger sodium aurothiomalate. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040072',
#   'title': 'parthenolide allergic contact dermatitis',
#   'description': "parthenolide allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to feverfew ) [ An allergic contact dermatitis that has_allergic_trigger parthenolide. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040073',
#   'title': 'disodium cromoglycate allergy',
#   'description': "disodium cromoglycate allergy ( ['DISEASE'] : DSCG allergy ) [ A drug allergy that has_allergic_trigger disodium cromoglycate. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040074',
#   'title': 'formaldehyde allergic contact dermatitis',
#   'description': "formaldehyde allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to formalin ) [ An allergic contact dermatitis that has_allergic_trigger formaldehyde. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040075',
#   'title': 'benzo[d]isothiazol-3-one allergic contact dermatitis',
#   'description': "benzo[d]isothiazol-3-one allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to benzisothiazolone ; allergic contact dermatitis to BIT ) [ An allergic contact dermatitis that has_allergic_trigger benzo[d]isothiazol-3-one. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040076',
#   'title': 'phthalyl group allergy',
#   'description': "phthalyl group allergy ( ['DISEASE'] : phthalyl allergy ) [ A drug allergy that has_allergic_trigger phthalyl group. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040077',
#   'title': 'alcuronium bromide allergy',
#   'description': "alcuronium bromide allergy ( ['DISEASE'] ) [ A drug allergy that has_allergic_trigger alcuronium bromide. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040078',
#   'title': 'gallamine allergy',
#   'description': "gallamine allergy ( ['DISEASE'] ) [ A drug allergy that has_allergic_trigger gallamine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040079',
#   'title': '2,4-dinitrophenyl allergic contact dermatitis',
#   'description': "2,4-dinitrophenyl allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to DNP ) [ An allergic contact dermatitis that has_allergic_trigger 2,4-dinitrophenyl group. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040080',
#   'title': 'patent blue V allergy',
#   'description': "patent blue V allergy ( ['DISEASE'] ) [ A drug allergy that has_allergic_trigger patent blue V. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040081',
#   'title': 'acid anhydride respiratory allergy',
#   'description': "acid anhydride respiratory allergy ( ['DISEASE'] ) [ A respiratory allergy that has_allergic_trigger acid anhydride. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040082',
#   'title': 'oxirane allergy',
#   'description': "oxirane allergy ( ['DISEASE'] : ethylene oxide allergy ; ETO allergy ) [ A drug allergy that has_allergic_trigger oxirane. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040083',
#   'title': 'Chlamydia pneumonia',
#   'description': "Chlamydia pneumonia ( ['DISEASE'] ) [ A bacterial pneumonia has_material_basis_in Chlamydia pneumoniae. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040084',
#   'title': 'Streptococcus pneumonia',
#   'description': "Streptococcus pneumonia ( ['DISEASE'] ) [ A bacterial pneumonia has_material_basis_in Streptococcus pneumoniae. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040085',
#   'title': 'bacterial sepsis',
#   'description': "bacterial sepsis ( ['DISEASE'] ) [ A bacterial infectious disease has_material_basis_in Bacteria. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040086',
#   'title': 'Polyomavirus-associated nephropathy',
#   'description': "Polyomavirus-associated nephropathy ( ['DISEASE'] : polyomavirus associated nephropathy ; PVAN ) [ A viral infectious disease has_material_basis_in BK polyomavirus. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040087',
#   'title': 'autoimmune peripheral neuropathy',
#   'description': "autoimmune peripheral neuropathy ( ['DISEASE'] ) [ An autoimmune disease of peripheral nervous system that results in peripheral neuropathy. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040088',
#   'title': 'autoimmune uveitis',
#   'description': "autoimmune uveitis ( ['DISEASE'] ) [ An autoimmune disease of eyes, ear, nose and throat that is located_in the uvea. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040089',
#   'title': 'autoimmune optic neuritis',
#   'description': "autoimmune optic neuritis ( ['DISEASE'] ) [ An autoimmune disease of peripheral nervous system that is located_in the neuron projection bundle connecting eye with brain. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040090',
#   'title': 'autoimmune gastritis',
#   'description': "autoimmune gastritis ( ['DISEASE'] ) [ An autoimmune disease of gastrointestinal tract that is located_in the stomach. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040091',
#   'title': 'autoimmune pancreatitis',
#   'description': "autoimmune pancreatitis ( ['DISEASE'] ) [ An autoimmune disease of endocrine system that is located_in the pancreas. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040092',
#   'title': 'juvenile ankylosing spondylitis',
#   'description': "juvenile ankylosing spondylitis ( ['DISEASE'] ) [ An autoimmune disease of musculoskeletal system that is an ankylosing spondylitis with onset during childhood. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040093',
#   'title': 'drug-induced lupus erythematosus',
#   'description': "drug-induced lupus erythematosus ( ['DISEASE'] : DIL ; DILE ) [ A lupus erythematosus caused by chronic use of certain drugs. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040094',
#   'title': 'autoimmune glomerulonephritis',
#   'description': "autoimmune glomerulonephritis ( ['DISEASE'] ) [ An autoimmune disease of urogenital tract that is located_in the renal glomerulus. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040095',
#   'title': 'autoimmune cardiomyopathy',
#   'description': "autoimmune cardiomyopathy ( ['DISEASE'] ) [ An autoimmune disease of cardiovascular system that is characterized by deterioration of the function of the heart muscle. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040096',
#   'title': 'autoimmune atherosclerosis',
#   'description': "autoimmune atherosclerosis ( ['DISEASE'] ) [ An autoimmune disease of cardiovascular system that is characterized by a build up of plaque in the arteries. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040097',
#   'title': 'autoimmune vasculitis',
#   'description': "autoimmune vasculitis ( ['DISEASE'] ) [ An autoimmune disease of cardiovascular system that is characterized by inflammation of the blood vessels. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040098',
#   'title': 'pemphigus gestationis',
#   'description': "pemphigus gestationis ( ['DISEASE'] ) [ A pemphigus that is characterized by blistered skin as a result of self-reactive T and B cells that target BP180. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040099',
#   'title': 'livedoid vasculitis',
#   'description': "livedoid vasculitis ( ['DISEASE'] : livedoid vasculopathy ) [ A vasculitis with purpuric ulcers. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040100',
#   'title': 'Hirata disease',
#   'description': "Hirata disease ( ['DISEASE'] : insulin autoimmune syndrome ) [ An autoimmune disease of endocrine system characterized by hypoglycemia caused by antibodies to insulin. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040101',
#   'title': "N,N'-diphenylthiourea allergic contact dermatitis",
#   'description': "N,N'-diphenylthiourea allergic contact dermatitis ( ['DISEASE'] : neoprene allergy ) [ An allergic contact dermatitis that has_allergic_trigger N,N-diphenylthiourea. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040102',
#   'title': "N,N'-diethylthiourea allergic contact dermatitis",
#   'description': "N,N'-diethylthiourea allergic contact dermatitis ( ['DISEASE'] : neoprene allergy ) [ An allergic contact dermatitis that has_allergic_trigger N,N-diethylthiourea. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040103',
#   'title': 'cefotiam allergy',
#   'description': "cefotiam allergy ( ['DISEASE'] ) [ A cephalosporin allergy that has_allergic_trigger cefotiam. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040104',
#   'title': 'toluene 2,4-diisocyanate allergic asthma',
#   'description': "toluene 2,4-diisocyanate allergic asthma ( ['DISEASE'] ) [ A toluene meta-diisocyanate allergic asthma that has_allergic_trigger toluene 2,4-diisocyanate. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050004',
#   'title': 'seminal vesicle acute gonorrhea',
#   'description': "seminal vesicle acute gonorrhea ( ['DISEASE'] ) [ A gonococcal seminal vesiculitis that is characterized by back pain, perineal pain, pain with ejaculation, hematospermia and voiding symptoms resulting from inflammation located_in the seminal vesicles caused by Neisseria gonorrhoeae infection. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050012',
#   'title': 'chikungunya',
#   'description': "chikungunya ( ['DISEASE'] : Chikungunya fever ) [ A viral infectious disease that results_in infection located_in joint, has_material_basis_in Chikungunya virus, which is transmitted_by Aedes mosquito bite. The infection has_symptom fever, has_symptom arthralgia, and has_symptom maculopapular rash. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050025',
#   'title': 'human granulocytic anaplasmosis',
#   'description': "human granulocytic anaplasmosis ( ['DISEASE'] : HGE ; human granulocytic ehrlichiosis ) [ An ehrlichiosis that results in infection located in granular leukocyte, has_material_basis_in Anaplasma phagocytophilum, which is transmitted by lone star tick (Amblyomma americanum). The infection has symptom headache, has symptom muscle aches, has symptom fatigue, has symptom fever and has symptom rash. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050026',
#   'title': 'human monocytic ehrlichiosis',
#   'description': "human monocytic ehrlichiosis ( ['DISEASE'] : Ehrlichiosis chafeensis ) [ An ehrlichiosis that results in infection located in monocyte or located in macrophage, has_material_basis_in Ehrlichia chaffeensis, which is transmitted by black-legged tick (Ixodes scapularis), transmitted by western black-legged tick (Ixodes pacificus) or transmitted by castor bean tick (Ixodes ricinus). The infection has symptom headache, has symptom muscle aches, has symptom fatigue, has symptom fever and has symptom rash. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050032',
#   'title': 'mineral metabolism disease',
#   'description': "mineral metabolism disease ( ['DISEASE'] ) [ An acquired metabolic disease that is characterized by abnormal mineral metabolism. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050035',
#   'title': 'African tick-bite fever',
#   'description': "African tick-bite fever ( ['DISEASE'] : Rickettsia africae spotted fever ; south african tick-bite fever ) [ A spotted fever that has_material_basis_in Rickettsia africae, which is transmitted_by ticks (Amblyomma hebraeum and Amblyomma variegatum). The infection has_symptom fever, has_symptom eschar and has_symptom maculopapular rash. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050041',
#   'title': 'Astrakhan spotted fever',
#   'description': "Astrakhan spotted fever ( ['DISEASE'] ) [ A spotted fever that has_material_basis_in Rickettsia conorii subsp caspia, which is transmitted_by ticks (Rhipicephalus pumilio and Rhipicephalus sanguineus). The infection has_symptom fever, has_symptom eschar (usually single), has_symptom regional adenopathy, has_symptom maculopapular rash on extremities. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050042',
#   'title': 'Indian tick typhus',
#   'description': "Indian tick typhus ( ['DISEASE'] ) [ A spotted fever that has_material_basis_in Rickettsia conorii subsp indica, which is transmitted_by ticks (Rhipicephalus sanguineus). The infection has_symptom fever, has_symptom eschar, has_symptom regional adenopathy, and has_symptom maculopapular rash on extremities. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050043',
#   'title': 'Israeli tick typhus',
#   'description': "Israeli tick typhus ( ['DISEASE'] : Israeli spotted fever ) [ A spotted fever that has_material_basis_in Rickettsia conorii subsp israelensis, which is transmitted_by ticks (Rhipicephalus sanguineus). The infection has_symptom fever, has_symptom eschar, has_symptom regional adenopathy, and has_symptom maculopapular rash on extremities. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050046',
#   'title': 'Far Eastern spotted fever',
#   'description': "Far Eastern spotted fever ( ['DISEASE'] : Rickettsia heilongjiangensis spotted fever ) [ A spotted fever that has_material_basis_in Rickettsia heilongjiangensis, which is transmitted_by ticks (Haemaphysalis concinna). The infection has_symptom fever, has_symptom eschar, has_symptom maculopapular rash, and has_symptom regional adenopathy. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050047',
#   'title': 'Flinders Island spotted fever',
#   'description': "Flinders Island spotted fever ( ['DISEASE'] : FISF ; Thai tick typhus ) [ A spotted fever that has_material_basis_in Rickettsia honei, which is transmitted_by cayenne ticks (Amblyomma cajennense). The infection has_symptom mild spotted fever, has_symptom eschar and has_symptom adenopathy. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050050',
#   'title': 'Japanese spotted fever',
#   'description': "Japanese spotted fever ( ['DISEASE'] : oriental spotted fever ; Rickettsia japonica spotted fever ) [ A spotted fever that has_material_basis_in Rickettsia japonica, which is transmitted_by ticks (Dermacentor taiwanensis and Haemaphysalis flava). The infection has_symptom fever, has_symptom eschars, has_symptom regional adenopathy, and has_symptom rash on extremities. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050051',
#   'title': 'Rickettsia parkeri spotted fever',
#   'description': "Rickettsia parkeri spotted fever ( ['DISEASE'] : maculatum infection ) [ A spotted fever that has_material_basis_in Rickettsia parkeri, which is transmitted_by Gulf Coast tick (Amblyomma maculatum). The infection has_symptom fever, has_symptom headache, has_symptom eschar, and has_symptom rash. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050052',
#   'title': 'Rocky Mountain spotted fever',
#   'description': "Rocky Mountain spotted fever ( ['DISEASE'] : Brazillian spotted ; Choix ; Exanthematic typhus of Sao Paulo ; Fiebre maculosa ; Fiebre manchada ; Sao Paulo typhus ; So Paulo fever ; Tick typhus ; Tobia fever ) [ A spotted fever that has_material_basis_in Rickettsia rickettsii, which is transmitted_by ticks (Dermacentor variabilis and Dermacentor andersoni). The infection has_symptom fever, has_symptom headache, has_symptom abdominal pain, and has_symptom maculopapular rash progressing into papular or petechial rash. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050059',
#   'title': 'oropharyngeal anthrax',
#   'description': "oropharyngeal anthrax ( ['DISEASE'] ) [ A gastrointestinal anthrax that results in infection located in mucosa of oropharynx, has_material_basis_in Bacillus anthracis, which is transmitted by ingestion of anthrax-infected meat. The infection has symptom lesions, has symptom vomiting of blood, has symptom severe diarrhea, has symptom loss of appetite. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050061',
#   'title': 'erysipeloid',
#   'description': "erysipeloid ( ['DISEASE'] ) [ A primary bacterial infectious disease that results_in infection located_in skin, has_material_basis_in Erysipelothrix rhusiopathiae, which is transmitted_by contact with infected animals. The infection has_symptom redness of skin, has_symptom tenderness of skin and has_symptom warmth of skin. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050072',
#   'title': 'adiaspiromycosis',
#   'description': "adiaspiromycosis ( ['DISEASE'] ) [ A primary systemic mycosis that is a fungal infection located_in lungs, or located_in skin, which results_in disseminated granulomatous pulmonary process and cutaneous infection in rodents, small wild mammals and humans, has_material_basis_in Chrysosporium parvum or Emmonsia crescens. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050073',
#   'title': 'invasive aspergillosis',
#   'description': "invasive aspergillosis ( ['DISEASE'] ) [ An aspergillosis that is a serious fungal infection of the lung with pneumonia caused by Aspergillus, which spreads to other parts of the body through bloodstream in patients with acute leukemia and recipients of tissue transplants. Clinical symptoms include pulmonary nodules and hemorrhage. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050083',
#   'title': 'Keshan disease',
#   'description': "Keshan disease ( ['DISEASE'] ) [ A nutritional deficiency that is disease characterized by a cardiomyopathy secondary to selenium deficiency. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050096',
#   'title': 'tinea barbae',
#   'description': "tinea barbae ( ['DISEASE'] : dermatophytosis of beard ) [ A dermatophytosis that results_in fungal infection which effects horny layer of epidermis of the bearded areas located_in face or located_in neck, has_material_basis_in Trichophyton mentagrophytes or has_material_basis_in Trichophyton verrucosum, which also effects hair, and effects nail and has_symptom inflammatory kerion-like plaques, and results_in_formation_of noninflammatory superficial perifollicular pustules. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050097',
#   'title': 'ectothrix infectious disease',
#   'description': "ectothrix infectious disease ( ['DISEASE'] ) [ A tinea capitis that results_in fungal infection located_in cuticle of hair, has_material_basis_in Microsporum canis, has_material_basis_in Microsporum gypseum, has_material_basis_in Trichophyton equinum, and has_material_basis_in Trichophyton verrucosum, which produce arthroconidia on the exterior of the hair shaft. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050105',
#   'title': 'endothrix infectious disease',
#   'description': "endothrix infectious disease ( ['DISEASE'] ) [ A tinea capitis that results_in fungal infection located_in hair, has_material_basis_in Ascomycota fungi that belong to a group called dermatophytes, which produce arthroconidia within the hair shaft only. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050116',
#   'title': 'tinea imbricata',
#   'description': "tinea imbricata ( ['DISEASE'] ) [ A tinea corporis that results_in fungal infection located_in skin, has_material_basis_in Trichophyton concentricum, which is characterized by ring-like growth in overlapping circles that may have an autosomal dominant genetic predisposition. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050117',
#   'title': 'disease by infectious agent',
#   'description': "disease by infectious agent ( ['DISEASE'] : infectious disease ) [ A disease that is the consequence of the presence of pathogenic microbial agents, including pathogenic viruses, pathogenic bacteria, fungi, protozoa, multicellular parasites, and aberrant proteins known as prions. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050118',
#   'title': 'La Crosse encephalitis',
#   'description': "La Crosse encephalitis ( ['DISEASE'] : California Encephalitis ; California virus encephalitis ; Neuroinvasive California encephalitis virus infection ) [ A viral infectious disease that results_in inflammation located_in brain, has_material_basis_in La Crosse virus, which is transmitted_by treehole mosquito, Ochlerotatus triseriatus. The infection has_symptom seizures, has_symptom headache, has_symptom fever, has_symptom coma, and has_symptom paralysis. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050120',
#   'title': 'hemophagocytic lymphohistiocytosis',
#   'description': "hemophagocytic lymphohistiocytosis ( ['DISEASE'] : haemophagocytic syndrome ) [ A lymphatic system disease that is characterized by an expansion of the monocyte-macrophage population and intense hemophagocytosis. It can occur de novo, but more often occurs in the setting of another disorder, usually an infection or a malignancy. A clinical picture of fever, hepatosplenomegaly, lymphadenopathy and peripheral pancytopenia. The morphologic hallmark of this syndrome is the phagocytosis of hematopoietic elements by morphologically normal macrophages. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050125',
#   'title': 'dengue shock syndrome',
#   'description': "dengue shock syndrome ( ['DISEASE'] : DSS ) [ A dengue disease that involves the most severe form of dengue fever, has_material_basis_in Dengue virus [NCBITaxon:12637] with four serotypes (Dengue virus 1, 2, 3 and 4), which are transmitted_by Aedes mosquito bite. The infection has_symptom easy bruising, has_symptom blood spots, has_symptom bleeding gums, and has_symptom nosebleeds. It is accompanied by circulatory collapse, involves hypotension, narrow pulse pressure (less than or equal to 20mm Hg), or frank shock. The shock occurs after two to six days of symptoms, followed by collapse, weak pulse, and blueness around the mouth. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050127',
#   'title': 'sinusitis',
#   'description': "sinusitis ( ['DISEASE'] ) [ A paranasal sinus disease involving inflammation of the paranasal sinuses resulting from bacterial, fungal, viral infection, allergic or autoimmune issues. Symptoms can include fever, weakness, fatigue, cough and congestion. There may also be mucus drainage in the back of the throat, called postnasal drip. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050129',
#   'title': 'secretory diarrhea',
#   'description': "secretory diarrhea ( ['DISEASE'] ) [ A diarrhea where there is an increase in the active secretion, or there is an inhibition of absorption causing little to no structural damage. The most common cause of this type of diarrhea is a cholera toxin that stimulates the secretion of anions, especially chloride ions. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050130',
#   'title': 'osmotic diarrhea',
#   'description': "osmotic diarrhea ( ['DISEASE'] ) [ A dirrhea that occurs when too much water is drawn into the bowels. This can be the result of maldigestion (e.g., pancreatic disease or Coeliac disease), in which the nutrients are left in the lumen to pull in water. Osmotic diarrhea can also be caused by osmotic laxatives (which work to alleviate constipation by drawing water into the bowels). In healthy individuals, too much magnesium or vitamin C or undigested lactose can produce osmotic diarrhea and distention of the bowel. A person who does not have lactose intolerance can have difficulty absorbing lactose after an extraordinarily high intake of dairy products. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050131',
#   'title': 'motility-related diarrhea',
#   'description': "motility-related diarrhea ( ['DISEASE'] ) [ A diarrhea which is caused by the rapid movement of food through the intestines (hypermotility). If the food moves too quickly through the GI tract, there is not enough time for sufficient nutrients and water to be absorbed. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050132',
#   'title': 'inflammatory diarrhea',
#   'description': "inflammatory diarrhea ( ['DISEASE'] ) [ A gastrointestinal system infectious disease involving diarrhea that occurs when there is damage to the mucosal lining or brush border, which leads to a passive loss of protein-rich fluids, and a decreased ability to absorb these lost fluids. It can be caused by bacterial infections, viral infections, parasitic infections, or autoimmune problems such as inflammatory bowel diseases. It can also be caused by tuberculosis, colon cancer, and enteritis. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050133',
#   'title': 'superficial mycosis',
#   'description': "superficial mycosis ( ['DISEASE'] : piedra ; Steroid-modified tinea infection ) [ A fungal infectious disease that results_in infection of the outermost layer located_in skin or located_in hair shaft, has_material_basis_in Fungi. No living tissue is invaded and there is no cellular response from the host. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050134',
#   'title': 'cutaneous mycosis',
#   'description': "cutaneous mycosis ( ['DISEASE'] ) [ A fungal infectious disease that results_in infection of the keratinized layers located_in skin, located_in hair or located_in nail, which extends deeper into the epidermis, has_material_basis_in Fungi and results_in_formation_of skin lesions. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050135',
#   'title': 'subcutaneous mycosis',
#   'description': "subcutaneous mycosis ( ['DISEASE'] ) [ A fungal infectious disease that results_in infection located_in skin or located_in subcutaneous tissue, has_material_basis_in Fungi, which penetrate the dermis or even deeper during or after a skin trauma. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050136',
#   'title': 'systemic mycosis',
#   'description': "systemic mycosis ( ['DISEASE'] ) [ A fungal infectious disease that results_in infection of internal organs and tissues located_in human body, has_material_basis_in Fungi, which enter the body via the respiratory tract, through the gut, paranasal sinuses or skin and spread through the bloodstream to multiple organs. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050138',
#   'title': 'podoconiosis',
#   'description': "podoconiosis ( ['DISEASE'] ) [ An elephantiasis that is characterized by lymphadema located_in the lower extremities caused by a genetically determined abnormal inflammatory reaction to mineral particles in irritant red clay soils derived from volcanic deposits. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050140',
#   'title': 'acute diarrhea',
#   'description': "acute diarrhea ( ['DISEASE'] ) [ A diarrhea that is of rapid onset and course characterized by frequent loose or liquid bowel movements. Acute diarrhea is a common cause of death in developing countries and the second most common cause of infant deaths worldwide. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050141',
#   'title': 'intestinal botulism',
#   'description': "intestinal botulism ( ['DISEASE'] ) [ A botulism that involves intoxication caused by botulinum neurotoxins (BoNTA, B, E and F) in adults, has_material_basis_in Clostridium botulinum A, has_material_basis_in Clostridium botulinum B, has_material_basis_in Clostridium botulinum E and has_material_basis_in Clostridium botulinum F, which are transmitted by ingestion of bacterial spores, which then grow in the intestine and release toxins. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050143',
#   'title': 'asymptomatic dengue',
#   'description': "asymptomatic dengue ( ['DISEASE'] ) [ A dengue disease that results_in infection, has_material_basis_in Dengue virus [NCBITaxon:12637] with four serotypes (Dengue virus 1, 2, 3 and 4), which are transmitted_by Aedes mosquito bite. The infection has no manifestations of symptoms. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050144',
#   'title': 'Kartagener syndrome',
#   'description': "Kartagener syndrome ( ['DISEASE'] : Kartagener's syndrome ) [ A primary ciliary dyskinesia that is characterized by sinusitis, bronchiectasis and situs inversus with dextrocardia resulting from dysfunction of the cilia during embryologic development. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050145',
#   'title': 'adenoiditis',
#   'description': "adenoiditis ( ['DISEASE'] : chronic adenoiditis ) [ An upper respiratory tract disease which involves inflammation, pain, and swelling of the adenoid tissue due to the infection by bacteria and viruses. It occurs primarily in children and may be secondary to an allergy, infection of nose or throat and an obstruction of the eustachian tube. The infection has symptom pain, has symptom redness, has symptom swelling, and has symptom difficulty swallowing. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050147',
#   'title': 'otomycosis',
#   'description': "otomycosis ( ['DISEASE'] : Singapore ear ) [ An otitis externa which is a disease of the ear produced by the growth of fungi in the external auditory canal. It is characterized by inflammation, pruritus, scaling and severe discomfort. The most common fungi are Aspergillus niger and Candida albicans. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050148',
#   'title': 'laryngotracheitis',
#   'description': "laryngotracheitis ( ['DISEASE'] ) [ An upper respiratory tract disease involving inflammation of both larynx and trachea often caused by viral infection. The infection can close off the windpipe. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050150',
#   'title': 'Pontiac fever',
#   'description': "Pontiac fever ( ['DISEASE'] ) [ A legionellosis that involves a milder respiratory illness without pneumonia. Symptoms include fever, headache and muscle aches which last for 2 to 5 days. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050152',
#   'title': 'aspiration pneumonia',
#   'description': "aspiration pneumonia ( ['DISEASE'] ) [ A bacterial pneumonia which is an acute pulmonary inflammatory response that develops after the inhalation of colonized oropharyngeal material containing bacteria. It is seen in individuals with dysphagia and gastric dysmotility. The disease has_symptom tachypnea and has_symptom cough. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050153',
#   'title': 'pulmonary aspergilloma',
#   'description': "pulmonary aspergilloma ( ['DISEASE'] ) [ An aspergillosis that presents as a clump of tangled mass of Aspergillus fungus fibres, blood clots, and white blood cells, which exists in the cavities of the lungs that develop in an area of previous lung disease or lung scarring. ]"},
#  {'type': ['DISEASE'],
# ...
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060243',
#   'title': 'stuttering',
#   'description': "stuttering ( ['DISEASE'] : familial persistent stuttering ; stammering ) [ An articulation disorder characterized by involuntary sound repetition and disruption or blocking of speech. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060244',
#   'title': 'specific language impairment',
#   'description': "specific language impairment ( ['DISEASE'] ) [ A language disorder characterized by difficulty in language acquisition despite otherwise normal development and in the absence of any obvious explanatory factors. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060245',
#   'title': 'Mast syndrome',
#   'description': "Mast syndrome ( ['DISEASE'] : autosomal recessive spastic paraplegia 21 ; autosomal recessive spastic paraplegia type 21 ; hereditary spastic paraplegia 21 ; SPG21 ) [ A hereditary spastic paraplegia associated with dementia. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060246',
#   'title': 'MASA syndrome',
#   'description': "MASA syndrome ( ['DISEASE'] : CRASH syndrome ; Gareis-Mason syndrome ; hereditary spastic paraplegia 1 ; L1 syndrome ; SPG1 ; X-linked complicated hereditary spastic paraplegia type 1 ; X-linked corpus callosum agenesis ; X-linked spastic paraplegia 1 ) [ A hereditary spastic paraplegia that is characterized by hydrocephalus, spasticity of the lower limbs, adducted thumbs, aphasia, seizures, agenesis of the corpus callosum and intellectual disability in the mild to moderate range. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060247',
#   'title': 'Smith-McCort dysplasia',
#   'description': "Smith-McCort dysplasia ( ['DISEASE'] ) [ A Dyggve-Melchior-Clausen disease that is characterized by short limbs and a short trunk with a barrel-shaped chest. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060248',
#   'title': 'Simpson-Golabi-Behmel syndrome type 1',
#   'description': "Simpson-Golabi-Behmel syndrome type 1 ( ['DISEASE'] : bulldog syndrome ; DGSX Golabi-Rosen syndrome ; Golabi-Rosen syndrome ; Sara Angers syndrome ; SGB syndrome ; Simpson dysmorphia syndrome ; X-linked dysplasia gigantism syndrome ) [ A syndrome characterized by pre- and postnatal overgrowth and craniofacial, skeletal, cardiac and renal abnormalities and has_material_basis_in mutation in the gene encoding glypican-3 (GPC3) on chromosome Xq26. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060249',
#   'title': 'scoliosis',
#   'description': "scoliosis ( ['DISEASE'] ) [ A bone structure disease characterized by an appreciable lateral deviation in the normally straight vertical line of the spine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060250',
#   'title': 'idiopathic scoliosis',
#   'description': "idiopathic scoliosis ( ['DISEASE'] ) [ A scoliosis with no known cause. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060251',
#   'title': 'sclerosteosis',
#   'description': "sclerosteosis ( ['DISEASE'] ) [ A hyperostosis characterized by excessive bone formation most prominent in the skull, mandible, clavicle, ribs and diaphyses of long bones; bone formation occurs throughout life. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060252',
#   'title': 'sclerocornea',
#   'description': "sclerocornea ( ['DISEASE'] : isolated congenital sclerocornea ) [ A corneal disease in which the cornea blends with sclera, resulting in clouding of the cornea. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060253',
#   'title': 'scapuloperoneal myopathy',
#   'description': "scapuloperoneal myopathy ( ['DISEASE'] ) [ A muscular dystrophy which begins at the lower legs and affects the shoulder region earlier and more severely than distal arm. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060254',
#   'title': 'Robinow syndrome',
#   'description': "Robinow syndrome ( ['DISEASE'] : acral dysostosis with facial and genital abnormalities ; fetal face syndrome ; Robinow dwarfism ) [ A syndrome characterized by mild to moderate short stature due to growth delays after birth, distinctive craniofacial abnormalities, skeletal malformations and genital abnormalities. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060255',
#   'title': 'rippling muscle disease 2',
#   'description': "rippling muscle disease 2 ( ['DISEASE'] : autosomal dominant limb-girdle muscular dystrophy type 1C ) [ A muscle tissue disease characterized by mechanically triggered contractions of skeletal muscle and that has_material_basis_in mutation in the caveolin-3 gene (CAV3) on chromosome 3p25. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060256',
#   'title': 'Dowling-Degos disease',
#   'description': "Dowling-Degos disease ( ['DISEASE'] : dark dot disease ; reticular pigment anomaly of flexures ) [ A pigmentation disease characterized by a reticulate pattern of abnormally dark skin coloring, particularly in the body's folds and creases. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060257',
#   'title': 'dyschromatosis symmetrica hereditaria',
#   'description': "dyschromatosis symmetrica hereditaria ( ['DISEASE'] : reticulate acropigmentation of Dohi ) [ A pigmentation disease characterized by progressively pigmented and depigmented macules, often mixed in a reticulate pattern, concentrated on the dorsal extremities. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060258',
#   'title': 'reticulate acropigmentation of Kitamura',
#   'description': "reticulate acropigmentation of Kitamura ( ['DISEASE'] : RAPK ) [ A pigmentation disease characterized by lesions that initially arise as letiginous, hyperpigmented macules in a reticular pattern on the dorsal aspect of the hands and feet. Over time, lesions may spread proximally and may darken; palmoplantar pitting and dermatoglyphic disruption may also be present. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060259',
#   'title': 'renal-hepatic-pancreatic dysplasia',
#   'description': "renal-hepatic-pancreatic dysplasia ( ['DISEASE'] : Ivemark's syndrome ) [ A physical disorder characterized by pancreatic fibrosis, renal dysplasia and hepatic dysgenesis; it is usual fatal soon after birth. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060260',
#   'title': 'ptosis',
#   'description': "ptosis ( ['DISEASE'] : blepharoptosis ; drooping eyelid ) [ An eye disease characterized by the drooping or falling of the upper or lower eyelid. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060261',
#   'title': 'congenital ptosis',
#   'description': "congenital ptosis ( ['DISEASE'] ) [ A ptosis characterized by eyelid drop present at birth. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060262',
#   'title': 'gallbladder disease',
#   'description': "gallbladder disease ( ['DISEASE'] ) [ A gastrointestinal system disease that is located_in the gallbladder. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060263',
#   'title': 'porencephaly',
#   'description': "porencephaly ( ['DISEASE'] ) [ A brain disease that is characterized by encephalomalacia and cystic brain lesions. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060264',
#   'title': 'pontocerebellar hypoplasia',
#   'description': "pontocerebellar hypoplasia ( ['DISEASE'] : PCH ) [ A neurodegenerative disease that is characterized by underdevelopment of the pons and cerebellum. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060265',
#   'title': 'pontocerebellar hypoplasia type 1A',
#   'description': "pontocerebellar hypoplasia type 1A ( ['DISEASE'] ) [ A pontocerebellar hypoplasia that is characterized by central and peripheral motor dysfunction, hypotonia, spasticity and failure to thrive, has_material_basis_in homozygous or compound heterozygous mutation in the VRK1 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060266',
#   'title': 'pontocerebellar hypoplasia type 1B',
#   'description': "pontocerebellar hypoplasia type 1B ( ['DISEASE'] ) [ A severe pontocerebellar hypoplasia that is characterized by hypotonia, progressive microcephaly and developmental delay, has_material_basis_in autosomal recessive inheritance of mutation in the EXOSC3 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060267',
#   'title': 'pontocerebellar hypoplasia type 2A',
#   'description': "pontocerebellar hypoplasia type 2A ( ['DISEASE'] ) [ A severe pontocerebellar hypoplasia that is characterized by progressive microcephaly, chorea, epilepsy and hyperreflexia, has_material_basis_in autosomal recessive inheritance of mutation in the TSEN54 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060268',
#   'title': 'pontocerebellar hypoplasia type 2B',
#   'description': "pontocerebellar hypoplasia type 2B ( ['DISEASE'] ) [ A severe pontocerebellar hypoplasia that is characterized by progressive microcephaly, clonus, dysphagia and failure to thrive, has_material_basis_in autosomal recessive inheritance of mutation in the TSEN2 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060269',
#   'title': 'pontocerebellar hypoplasia type 2C',
#   'description': "pontocerebellar hypoplasia type 2C ( ['DISEASE'] ) [ A severe pontocerebellar hypoplasia that is characterized by progressive microcephaly, extrapyramidal dyskinesia, seizure and failure to thrive, has_material_basis_in autosomal recessive inheritance of mutation in the TSEN34 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060270',
#   'title': 'pontocerebellar hypoplasia type 2D',
#   'description': "pontocerebellar hypoplasia type 2D ( ['DISEASE'] ) [ A pontocerebellar hypoplasia that is characterized by progressive microcephaly, profound intellectual disability, spasticity and seizure, has_material_basis_in autosomal recessive inheritance of mutation in the SEPSECS gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060271',
#   'title': 'pontocerebellar hypoplasia type 2E',
#   'description': "pontocerebellar hypoplasia type 2E ( ['DISEASE'] ) [ A pontocerebellar hypoplasia that is characterized by progressive microcephaly, profound intellectual disability, spasticity and seizure, has_material_basis_in autosomal recessive inheritance of mutation in the VPS53 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060272',
#   'title': 'pontocerebellar hypoplasia type 3',
#   'description': "pontocerebellar hypoplasia type 3 ( ['DISEASE'] ) [ A pontocerebellar hypoplasia that is characterized by progressive microcephaly, hypotonia, dysmorphic features, profound intellectual disability and seizure, has_material_basis_in autosomal recessive inheritance of mutation in the PCLO gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060273',
#   'title': 'pontocerebellar hypoplasia type 4',
#   'description': "pontocerebellar hypoplasia type 4 ( ['DISEASE'] ) [ A pontocerebellar hypoplasia that is characterized by progressive microcephaly, hypertonia, myoclonus, seizure and early lethality, has_material_basis_in autosomal recessive inheritance of mutation in the TSEN54 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060274',
#   'title': 'pontocerebellar hypoplasia type 5',
#   'description': "pontocerebellar hypoplasia type 5 ( ['DISEASE'] ) [ A pontocerebellar hypoplasia that is characterized by severe olivopontocerebellar hypoplasia and degeneration leading to early lethality, has_material_basis_in autosomal recessive inheritance of mutation in the TSEN54 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060275',
#   'title': 'pontocerebellar hypoplasia type 6',
#   'description': "pontocerebellar hypoplasia type 6 ( ['DISEASE'] ) [ A pontocerebellar hypoplasia that is characterized by olivopontocerebellar hypoplasia and developmental delay, has_material_basis_in autosomal recessive inheritance of mutation in the RARS2 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060276',
#   'title': 'pontocerebellar hypoplasia type 7',
#   'description': "pontocerebellar hypoplasia type 7 ( ['DISEASE'] ) [ A pontocerebellar hypoplasia that is characterized by delayed psychomotor development, hypotonia, gonadal abnormalities and respiratory failure, has_material_basis_in autosomal recessive mutation in the TOE1 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060277',
#   'title': 'pontocerebellar hypoplasia type 8',
#   'description': "pontocerebellar hypoplasia type 8 ( ['DISEASE'] ) [ A pontocerebellar hypoplasia that is characterized by delayed psychomotor development, chorea, hypotonia, spasticity and visual defects, has_material_basis_in autosomal recessive inheritance of mutation in the CHMP1A gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060278',
#   'title': 'pontocerebellar hypoplasia type 9',
#   'description': "pontocerebellar hypoplasia type 9 ( ['DISEASE'] ) [ A pontocerebellar hypoplasia that is characterized by progressive microcephaly, spasticity, seizure and brain atrophy, has_material_basis_in autosomal recessive inheritance of mutation in the AMPD2 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060279',
#   'title': 'pontocerebellar hypoplasia type 10',
#   'description': "pontocerebellar hypoplasia type 10 ( ['DISEASE'] ) [ A pontocerebellar hypoplasia that is characterized by severe developmental delays, progressive microcephaly, spasticity and seizure, has_material_basis_in autosomal recessive inheritance of mutation in the CLP1 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060280',
#   'title': 'primary pigmented nodular adrenocortical disease',
#   'description': "primary pigmented nodular adrenocortical disease ( ['DISEASE'] ) [ An adrenal cortex disease characterized by small to normal sized adrenal glands containing multiple small cortical pigmented nodules. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060281',
#   'title': 'photosensitive epilepsy',
#   'description': "photosensitive epilepsy ( ['DISEASE'] : photogenic epilepsy ; photoparoxysmal response ) [ An epilepsy characterized by seizures triggered by visual stimuli that form patterns in space or time, such as flashing lights. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060282',
#   'title': 'persistent hyperplastic primary vitreous',
#   'description': "persistent hyperplastic primary vitreous ( ['DISEASE'] ) [ A developmental vitreous disease that is characterized by leukocoria, strabismus and vision loss, caused by failure of primary vitreous and hyaloid vasculature to regress during embryological development. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060283',
#   'title': 'peeling skin syndrome',
#   'description': "peeling skin syndrome ( ['DISEASE'] : deciduous skin ; familial continuous skin peeling syndrome ; keratosis exfoliativa congenita ; peeling skin disease ; PSS ) [ A skin disease that is characterized by the painless, continuous peeling of the top layer of skin. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060284',
#   'title': 'paroxysmal nocturnal hemoglobinuria',
#   'description': "paroxysmal nocturnal hemoglobinuria ( ['DISEASE'] ) [ An acquired hemolytic anemia that is characterized by abdominal pain, hematuria, esophageal dysmotility and thrombosis, has_material_basis_in defect in the cell membrane glycosyl phosphatidylinositols that protect red blood cells from the innate complement immune system. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060285',
#   'title': 'parietal foramina',
#   'description': "parietal foramina ( ['DISEASE'] : Caitlin marks ; enlarged parietal foramina ; hereditary cranium bifidum ) [ An inherited neural tube defect that is characterized by enlarged openings in the parietal bones of the skull, has_material_basis_in mutation in the ALX4 gene or MSX2 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060286',
#   'title': 'combined oxidative phosphorylation deficiency',
#   'description': "combined oxidative phosphorylation deficiency ( ['DISEASE'] ) [ A mitochondrial metabolism disease that is characterized by growth retardation, microcephaly, hypertonia, encephalopathy, cardiomyopathy and liver dysfunction. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060287',
#   'title': 'cornea plana',
#   'description': "cornea plana ( ['DISEASE'] : flat cornea ) [ A corneal disease that is characterized by a flat cornea where the radus of curvature is less than 43 D. ]"},
#  ...]

# %% [markdown]
# # THIRD VERSION : INTEGRATING WITH THE CLASS (look above for latest version)

# %%
def process_obo_ontology(ontology, 
                     data_path):
    '''
    This function prepares the entity data : dictionary.pickle
    
    Parameters 
    ----------
    - ontology : str (only umls for now)
    Ontology associated with the dataset
    - data_path : str
    Path where to load and save dictionary.pickle
    '''
    
    # Get canonical name of entities in the ontology
    cui2name = ontology.get_canonical_name()
    # Get aliases of entities in the ontology
    cui2alias = ontology.get_aliases()
    # Get definition of entities in the ontology
    cui2definition = ontology.get_definition()
    # Get types of entities in the ontology
    cui2tui = ontology.get_types()


    # Check if the directory exists, and create it if it does not
    if not os.path.exists(data_path):
        os.makedirs(data_path)

    ontology_entities = []
    for cui, name in tqdm(cui2name.items()):
        d = {}
        ent_type = cui2tui[cui]
        d['type'] = ent_type
        other_aliases = [x for x in cui2alias[cui] if x != name]
        joined_aliases = ' ; '.join(other_aliases)
        d['cui'] = f"{cui}"
        d['title'] = name
        if cui in cui2definition:
            definition = cui2definition[cui]
        else:
            definition = None

        if len(other_aliases) > 0:
            if definition is not None:
                d['description'] = f"{name} ( {ent_type} : {joined_aliases} ) [ {definition} ]"
            else:
                d['description'] = f"{name} ( {ent_type} : {joined_aliases} )"
        else:
            if definition is not None:
                d['description'] = f"{name} ( {ent_type} ) [ {definition} ]"
            else:
                d['description'] = f"{name} ( {ent_type} )"

        ontology_entities.append(d)

    pickle.dump(ontology_entities, open(os.path.join(data_path, 'dictionary.pickle'), 'wb'))
    entities = pickle.load(open(os.path.join(data_path, 'dictionary.pickle'), 'rb'))
    
    # pickle.dump(ontology_entities, open(f'../data/{model}/{dataset}/dictionary.pickle', 'wb'))
    # entities = pickle.load(open(f'../data/{model}/{dataset}/dictionary.pickle', 'rb'))
    return entities

# %%
ontology = BiomedicalOntology.load_obo(**obo_dict)
dataset = "test2"
model = "test2"
abs_path = "/home2/cye73/data"
data_path = os.path.join(abs_path, model, dataset)

entities = process_obo_ontology(
    ontology = ontology,
    data_path = data_path 
    )

entities
# Out:
# [2024-03-16 14:20:13] [ontology.py] [INFO] Reading OBO ontology from https://raw.githubusercontent.com/DiseaseOntology/HumanDiseaseOntology/main/src/ontology/doid.obo
# 100%|██████████| 11511/11511 [00:00<00:00, 262340.57it/s]
# 100%|██████████| 11511/11511 [00:00<00:00, 455258.63it/s]
# [{'type': ['DISEASE'],
#   'cui': 'DOID:0001816',
#   'title': 'angiosarcoma',
#   'description': "angiosarcoma ( ['DISEASE'] : hemangiosarcoma ) [ A vascular cancer that derives_from the cells that line the walls of blood vessels or lymphatic vessels. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0002116',
#   'title': 'pterygium',
#   'description': "pterygium ( ['DISEASE'] : surfer's eye ) [ A corneal disease that is characterized by a triangular tissue growth located_in cornea of the eye that is the result of collagen degeneration and fibrovascular proliferation. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0014667',
#   'title': 'disease of metabolism',
#   'description': "disease of metabolism ( ['DISEASE'] : metabolic disease ) [ A disease that involving errors in metabolic processes of building or degradation of molecules. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040001',
#   'title': 'shrimp allergy',
#   'description': "shrimp allergy ( ['DISEASE'] ) [ A crustacean allergy that has_allergic_trigger shrimp. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040002',
#   'title': 'aspirin allergy',
#   'description': "aspirin allergy ( ['DISEASE'] : acetylsalicylic acid allergy ; ASA allergy ) [ A drug allergy that has_allergic_trigger acetylsalicylic acid. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040003',
#   'title': 'benzylpenicillin allergy',
#   'description': "benzylpenicillin allergy ( ['DISEASE'] : benzyl penicillin allergy ; penicillin G allergy ) [ A beta-lactam allergy that has_allergic_trigger benzylpenicillin. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040004',
#   'title': 'amoxicillin allergy',
#   'description': "amoxicillin allergy ( ['DISEASE'] ) [ A beta-lactam allergy that has_allergic_trigger amoxicillin. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040005',
#   'title': 'ceftriaxone allergy',
#   'description': "ceftriaxone allergy ( ['DISEASE'] : rocephin allergy ) [ A cephalosporin allergy that has_allergic_trigger ceftriaxone. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040006',
#   'title': 'carbamazepine allergy',
#   'description': "carbamazepine allergy ( ['DISEASE'] : carbamazepen allergy ; Tegretol allergy ) [ A drug allergy that has_allergic_trigger carbamazepine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040007',
#   'title': 'abacavir allergy',
#   'description': "abacavir allergy ( ['DISEASE'] : ABC allergy ) [ A drug allergy that has_allergic_trigger abacavir. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040008',
#   'title': 'isoniazide allergy',
#   'description': "isoniazide allergy ( ['DISEASE'] : INH allergy ; isonicotinylhydrazide allergy ) [ A drug allergy that has_allergic_trigger isoniazide. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040009',
#   'title': 'lidocaine allergy',
#   'description': "lidocaine allergy ( ['DISEASE'] : Lidoderm allergy ; lignocaine allergy ; xylocaine allergy ) [ A drug allergy that has_allergic_trigger lidocaine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040010',
#   'title': 'mepivacaine allergy',
#   'description': "mepivacaine allergy ( ['DISEASE'] : Carbocaine allergy ; Polocaine allergy ) [ A drug allergy that has_allergic_trigger mepivacaine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040011',
#   'title': 'phenobarbital allergy',
#   'description': "phenobarbital allergy ( ['DISEASE'] : Luminal allergy ; phenobarbitol allergy ; phenobarbitone allergy ) [ A drug allergy that has_allergic_trigger phenobarbital. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040012',
#   'title': 'phenytoin allergy',
#   'description': "phenytoin allergy ( ['DISEASE'] : Dilantin allergy ) [ A drug allergy that has_allergic_trigger phenytoin. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040013',
#   'title': 'ranitidine allergy',
#   'description': "ranitidine allergy ( ['DISEASE'] : Zantac allergy ) [ A drug allergy that has_allergic_trigger ranitidine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040014',
#   'title': 'corticosteroid allergy',
#   'description': "corticosteroid allergy ( ['DISEASE'] ) [ A drug allergy that has_allergic_trigger corticosteroid. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040015',
#   'title': 'sulfonamide allergy',
#   'description': "sulfonamide allergy ( ['DISEASE'] ) [ A drug allergy that has_allergic_trigger sulfonamide. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040016',
#   'title': 'sulfamethoxazole allergy',
#   'description': "sulfamethoxazole allergy ( ['DISEASE'] : SMX allergy ; SMZ allergy ; sulphamethoxazole allergy ) [ A drug allergy that has_allergic_trigger sulfamethoxazole. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040017',
#   'title': 'suprofen allergy',
#   'description': "suprofen allergy ( ['DISEASE'] : Profenal allergy ) [ A drug allergy that has_allergic_trigger suprofen. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040018',
#   'title': 'thiopental allergy',
#   'description': "thiopental allergy ( ['DISEASE'] : penthiobarbital allergy ; pentothiobarbital allergy ) [ A drug allergy that has_allergic_trigger thiopental. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040019',
#   'title': 'D-mannitol allergy',
#   'description': "D-mannitol allergy ( ['DISEASE'] : mannitol allergy ) [ A drug allergy that has_allergic_trigger D-mannitol. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040020',
#   'title': 'cefotaxime allergy',
#   'description': "cefotaxime allergy ( ['DISEASE'] ) [ A cephalosporin allergy that has_allergic_trigger cefotaxime. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040021',
#   'title': 'cephalosporin allergy',
#   'description': "cephalosporin allergy ( ['DISEASE'] ) [ A drug allergy that has_allergic_trigger cephalosporin. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040022',
#   'title': 'amodiaquine allergy',
#   'description': "amodiaquine allergy ( ['DISEASE'] : Camoquin allergy ; Flavoquine allergy ) [ A drug allergy that has_allergic_trigger amodiaquine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040023',
#   'title': 'cefaclor allergy',
#   'description': "cefaclor allergy ( ['DISEASE'] : Ceclor allergy ; cephaclor allergy ) [ A cephalosporin allergy that has_allergic_trigger cefaclor. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040024',
#   'title': 'ceftazidime allergy',
#   'description': "ceftazidime allergy ( ['DISEASE'] : Fortaz allergy ; Tazicef allergy ) [ A cephalosporin allergy that has_allergic_trigger ceftazidime. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040025',
#   'title': 'cefuroxime allergy',
#   'description': "cefuroxime allergy ( ['DISEASE'] : cephuroxime allergy ; Zinacef allergy ) [ A cephalosporin allergy that has_allergic_trigger cefuroxime. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040026',
#   'title': 'chlorhexidine allergy',
#   'description': "chlorhexidine allergy ( ['DISEASE'] ) [ A drug allergy that has_allergic_trigger chlorhexidine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040027',
#   'title': 'cyclophosphamide allergy',
#   'description': "cyclophosphamide allergy ( ['DISEASE'] : cytophosphane allergy ) [ A drug allergy that has_allergic_trigger cyclophosphamide. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040028',
#   'title': 'succinylcholine allergy',
#   'description': "succinylcholine allergy ( ['DISEASE'] : dicholine succinate allergy ; succinocholine allergy ; sux allergy ; suxamethonium allergy ) [ A drug allergy that has_allergic_trigger succinylcholine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040029',
#   'title': 'trimethoprim allergy',
#   'description': "trimethoprim allergy ( ['DISEASE'] : Primsol allergy ; proloprim allergy ; TMP allergy ) [ A drug allergy that has_allergic_trigger trimethoprim. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040030',
#   'title': 'cefixime allergy',
#   'description': "cefixime allergy ( ['DISEASE'] ) [ A cephalosporin allergy that has_allergic_trigger cefixime. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040031',
#   'title': 'diclofenac allergy',
#   'description': "diclofenac allergy ( ['DISEASE'] : Voltaren allergy ) [ A drug allergy that has_allergic_trigger diclofenac. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040032',
#   'title': 'carbapenem allergy',
#   'description': "carbapenem allergy ( ['DISEASE'] ) [ A drug allergy that has_allergic_trigger carbapenems. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040033',
#   'title': 'piperacillin allergy',
#   'description': "piperacillin allergy ( ['DISEASE'] ) [ A beta-lactam allergy that has_allergic_trigger piperacillin. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040034',
#   'title': 'rocuronium allergy',
#   'description': "rocuronium allergy ( ['DISEASE'] : Esmeron allergy ; Zemuron allergy ) [ A drug allergy that has_allergic_trigger rocuronium. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040035',
#   'title': 'sulfasalazine allergy',
#   'description': "sulfasalazine allergy ( ['DISEASE'] ) [ A drug allergy that has_allergic_trigger sulfasalazine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040036',
#   'title': 'tubocurarine allergy',
#   'description': "tubocurarine allergy ( ['DISEASE'] : DTC allergy ) [ A drug allergy that has_allergic_trigger tubocurarine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040037',
#   'title': 'aztreonam allergy',
#   'description': "aztreonam allergy ( ['DISEASE'] : Azactam allergy ; Primbactam allergy ) [ A beta-lactam allergy that has_allergic_trigger aztreonam. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040038',
#   'title': 'meropenem allergy',
#   'description': "meropenem allergy ( ['DISEASE'] : Merrem allergy ) [ An allergic asthma that has_allergic_trigger meropenem, a beta-lactam antibiotic. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040040',
#   'title': 'hexamethylene diisocyanate allergic asthma',
#   'description': "hexamethylene diisocyanate allergic asthma ( ['DISEASE'] : allergic asthma to HDI ; allergic asthma to HMDI ) [ An isocyanates allergic asthma that has_allergic_trigger hexamethylene diisocyanate. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040041',
#   'title': 'isocyanates allergic asthma',
#   'description': "isocyanates allergic asthma ( ['DISEASE'] ) [ An allergic asthma that has_allergic_trigger isocyanates. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040042',
#   'title': "diphenylmethane-4,4'-diisocyanate allergic asthma",
#   'description': "diphenylmethane-4,4'-diisocyanate allergic asthma ( ['DISEASE'] : allergic asthma to MDI ) [ An isocyanates allergic asthma that has_allergic_trigger diphenylmethane-4,4-diisocyanate. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040043',
#   'title': 'toluene meta-diisocyanate allergic asthma',
#   'description': "toluene meta-diisocyanate allergic asthma ( ['DISEASE'] : allergic asthma to TDI ) [ An isocyanates allergic asthma that has_allergic_trigger toluene meta-diisocyanate. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040044',
#   'title': 'methyl isocyanate allergic asthma',
#   'description': "methyl isocyanate allergic asthma ( ['DISEASE'] : allergic asthma to MIC ) [ An isocyanates allergic asthma that has_allergic_trigger methyl isocyanate. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040045',
#   'title': 'nickel allergic asthma',
#   'description': "nickel allergic asthma ( ['DISEASE'] : allergic asthma to Ni ) [ An allergic asthma that has_allergic_trigger nickel atom. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040046',
#   'title': 'nickel allergic contact dermatitis',
#   'description': "nickel allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to Ni ) [ An allergic contact dermatitis that has_allergic_trigger nickel atom. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040047',
#   'title': 'trimellitic anhydride allergic asthma',
#   'description': "trimellitic anhydride allergic asthma ( ['DISEASE'] : allergic asthma to TMA ) [ An allergic asthma that has_allergic_trigger trimellitic anhydride. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040048',
#   'title': 'phthalic anhydride allergic asthma',
#   'description': "phthalic anhydride allergic asthma ( ['DISEASE'] ) [ An allergic asthma that has_allergic_trigger phthalic anhydride. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040049',
#   'title': 'maleic anhydride allergic asthma',
#   'description': "maleic anhydride allergic asthma ( ['DISEASE'] : allergic asthma to MA ) [ An allergic asthma that has_allergic_trigger maleic anhydride. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040050',
#   'title': 'tetrachlorophthalic anhydride allergic asthma',
#   'description': "tetrachlorophthalic anhydride allergic asthma ( ['DISEASE'] ) [ An allergic asthma that has_allergic_trigger tetrachlorophthalic anhydride. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040051',
#   'title': 'hexahydrophthalic anhydride allergic asthma',
#   'description': "hexahydrophthalic anhydride allergic asthma ( ['DISEASE'] : allergic asthma to HHPA ) [ An allergic asthma that has_allergic_trigger hexahydrophthalic anhydride. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040052',
#   'title': "diphenylmethane-4,4'-diisocyanate allergic contact dermatitis",
#   'description': "diphenylmethane-4,4'-diisocyanate allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to MDI ) [ An allergic contact dermatitis that has_allergic_trigger diphenylmethane-4,4-diisocyanate. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040053',
#   'title': 'cobalt allergic contact dermatitis',
#   'description': "cobalt allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to Co ) [ An allergic contact dermatitis that has_allergic_trigger cobalt atom. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040054',
#   'title': 'cobalt allergic asthma',
#   'description': "cobalt allergic asthma ( ['DISEASE'] : Co allergic asthma ) [ An allergic asthma that has_allergic_trigger cobalt atom. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040055',
#   'title': 'palladium allergic contact dermatitis',
#   'description': "palladium allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to Pd ) [ An allergic contact dermatitis that has_allergic_trigger palladium. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040056',
#   'title': 'chromium allergic contact dermatitis',
#   'description': "chromium allergic contact dermatitis ( ['DISEASE'] ) [ An allergic contact dermatitis that has_allergic_trigger chromium atom. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040057',
#   'title': 'benzoic acid allergic contact dermatitis',
#   'description': "benzoic acid allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to benzoate ) [ An allergic contact dermatitis that has_allergic_trigger benzoic acid. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040058',
#   'title': '1,4-phenylenediamine allergic contact dermatitis',
#   'description': "1,4-phenylenediamine allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to p-phenylenediamine ; allergic contact dermatitis to PPD ) [ An allergic contact dermatitis that has_allergic_trigger 1,4-phenylenediamine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040059',
#   'title': 'potassium dichromate allergic contact dermatitis',
#   'description': "potassium dichromate allergic contact dermatitis ( ['DISEASE'] ) [ An allergic contact dermatitis that has_allergic_trigger potassium dichromate. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040060',
#   'title': 'ketoprofen photoallergic dermatitis',
#   'description': "ketoprofen photoallergic dermatitis ( ['DISEASE'] : photoallergic dermatitis to Orudis ) [ A photoallergic dermatitis that has_allergic_trigger ketoprofen. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040061',
#   'title': 'remazole black respiratory allergy',
#   'description': "remazole black respiratory allergy ( ['DISEASE'] : respiratory allergy to Reactive Black 5 ) [ A respiratory allergy that has_allergic_trigger remazole black-GR. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040062',
#   'title': 'chloramine T respiratory allergy',
#   'description': "chloramine T respiratory allergy ( ['DISEASE'] : respiratory allergy to Chloraseptin ; respiratory allergy to Chlorazol ; respiratory allergy to Trichlorol ) [ A respiratory allergy that has_allergic_trigger chloramine T. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040063',
#   'title': '4-vinylcyclohexene dioxide respiratory allergy',
#   'description': "4-vinylcyclohexene dioxide respiratory allergy ( ['DISEASE'] : respiratory allergy to vinyl cyclohexene diepoxide ) [ A respiratory allergy that has_allergic_trigger 4-vinylcyclohexene dioxide. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040064',
#   'title': 'carvone allergic contact dermatitis',
#   'description': "carvone allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to levo-carvone ) [ An allergic contact dermatitis that has_allergic_trigger (-)-carvone. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040065',
#   'title': 'quinidine allergy',
#   'description': "quinidine allergy ( ['DISEASE'] : Kinidin allergy ) [ A drug allergy that has_allergic_trigger quinidine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040066',
#   'title': 'melphalan allergy',
#   'description': "melphalan allergy ( ['DISEASE'] : Alkeran allergy ) [ A drug allergy that has_allergic_trigger melphalan. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040067',
#   'title': 'neomycin sulfate allergic contact dermatitis',
#   'description': "neomycin sulfate allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to neomycin sulphate ) [ An allergic contact dermatitis that has_allergic_trigger neomycin sulfate. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040068',
#   'title': '4-tert-butylphenol allergic contact dermatitis',
#   'description': "4-tert-butylphenol allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to butylphen ; allergic contact dermatitis to PTBP ) [ An allergic contact dermatitis that has_allergic_trigger 4-tert-butylphenol. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040069',
#   'title': '1-chloro-2,4-dinitrobenzene allergic contact dermatitis',
#   'description': "1-chloro-2,4-dinitrobenzene allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to dinitrochlorobenzene ; allergic contact dermatitis to DNCB ) [ An allergic contact dermatitis that has_allergic_trigger 1-chloro-2,4-dinitrobenzene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040070',
#   'title': 'co-trimoxazole allergy',
#   'description': "co-trimoxazole allergy ( ['DISEASE'] : Bactrim allergy ; cotrimoxazol allergy ; TMP/SMX allergy ; trimethoprim/sulfamethoxazole allergy ) [ A drug allergy that has_allergic_trigger co-trimoxazole. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040071',
#   'title': 'sodium aurothiomalate allergy',
#   'description': "sodium aurothiomalate allergy ( ['DISEASE'] : gold sodium thiomalate allergy ) [ A drug allergy that has_allergic_trigger sodium aurothiomalate. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040072',
#   'title': 'parthenolide allergic contact dermatitis',
#   'description': "parthenolide allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to feverfew ) [ An allergic contact dermatitis that has_allergic_trigger parthenolide. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040073',
#   'title': 'disodium cromoglycate allergy',
#   'description': "disodium cromoglycate allergy ( ['DISEASE'] : DSCG allergy ) [ A drug allergy that has_allergic_trigger disodium cromoglycate. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040074',
#   'title': 'formaldehyde allergic contact dermatitis',
#   'description': "formaldehyde allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to formalin ) [ An allergic contact dermatitis that has_allergic_trigger formaldehyde. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040075',
#   'title': 'benzo[d]isothiazol-3-one allergic contact dermatitis',
#   'description': "benzo[d]isothiazol-3-one allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to benzisothiazolone ; allergic contact dermatitis to BIT ) [ An allergic contact dermatitis that has_allergic_trigger benzo[d]isothiazol-3-one. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040076',
#   'title': 'phthalyl group allergy',
#   'description': "phthalyl group allergy ( ['DISEASE'] : phthalyl allergy ) [ A drug allergy that has_allergic_trigger phthalyl group. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040077',
#   'title': 'alcuronium bromide allergy',
#   'description': "alcuronium bromide allergy ( ['DISEASE'] ) [ A drug allergy that has_allergic_trigger alcuronium bromide. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040078',
#   'title': 'gallamine allergy',
#   'description': "gallamine allergy ( ['DISEASE'] ) [ A drug allergy that has_allergic_trigger gallamine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040079',
#   'title': '2,4-dinitrophenyl allergic contact dermatitis',
#   'description': "2,4-dinitrophenyl allergic contact dermatitis ( ['DISEASE'] : allergic contact dermatitis to DNP ) [ An allergic contact dermatitis that has_allergic_trigger 2,4-dinitrophenyl group. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040080',
#   'title': 'patent blue V allergy',
#   'description': "patent blue V allergy ( ['DISEASE'] ) [ A drug allergy that has_allergic_trigger patent blue V. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040081',
#   'title': 'acid anhydride respiratory allergy',
#   'description': "acid anhydride respiratory allergy ( ['DISEASE'] ) [ A respiratory allergy that has_allergic_trigger acid anhydride. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040082',
#   'title': 'oxirane allergy',
#   'description': "oxirane allergy ( ['DISEASE'] : ethylene oxide allergy ; ETO allergy ) [ A drug allergy that has_allergic_trigger oxirane. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040083',
#   'title': 'Chlamydia pneumonia',
#   'description': "Chlamydia pneumonia ( ['DISEASE'] ) [ A bacterial pneumonia has_material_basis_in Chlamydia pneumoniae. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040084',
#   'title': 'Streptococcus pneumonia',
#   'description': "Streptococcus pneumonia ( ['DISEASE'] ) [ A bacterial pneumonia has_material_basis_in Streptococcus pneumoniae. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040085',
#   'title': 'bacterial sepsis',
#   'description': "bacterial sepsis ( ['DISEASE'] ) [ A bacterial infectious disease has_material_basis_in Bacteria. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040086',
#   'title': 'Polyomavirus-associated nephropathy',
#   'description': "Polyomavirus-associated nephropathy ( ['DISEASE'] : polyomavirus associated nephropathy ; PVAN ) [ A viral infectious disease has_material_basis_in BK polyomavirus. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040087',
#   'title': 'autoimmune peripheral neuropathy',
#   'description': "autoimmune peripheral neuropathy ( ['DISEASE'] ) [ An autoimmune disease of peripheral nervous system that results in peripheral neuropathy. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040088',
#   'title': 'autoimmune uveitis',
#   'description': "autoimmune uveitis ( ['DISEASE'] ) [ An autoimmune disease of eyes, ear, nose and throat that is located_in the uvea. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040089',
#   'title': 'autoimmune optic neuritis',
#   'description': "autoimmune optic neuritis ( ['DISEASE'] ) [ An autoimmune disease of peripheral nervous system that is located_in the neuron projection bundle connecting eye with brain. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040090',
#   'title': 'autoimmune gastritis',
#   'description': "autoimmune gastritis ( ['DISEASE'] ) [ An autoimmune disease of gastrointestinal tract that is located_in the stomach. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040091',
#   'title': 'autoimmune pancreatitis',
#   'description': "autoimmune pancreatitis ( ['DISEASE'] ) [ An autoimmune disease of endocrine system that is located_in the pancreas. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040092',
#   'title': 'juvenile ankylosing spondylitis',
#   'description': "juvenile ankylosing spondylitis ( ['DISEASE'] ) [ An autoimmune disease of musculoskeletal system that is an ankylosing spondylitis with onset during childhood. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040093',
#   'title': 'drug-induced lupus erythematosus',
#   'description': "drug-induced lupus erythematosus ( ['DISEASE'] : DIL ; DILE ) [ A lupus erythematosus caused by chronic use of certain drugs. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040094',
#   'title': 'autoimmune glomerulonephritis',
#   'description': "autoimmune glomerulonephritis ( ['DISEASE'] ) [ An autoimmune disease of urogenital tract that is located_in the renal glomerulus. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040095',
#   'title': 'autoimmune cardiomyopathy',
#   'description': "autoimmune cardiomyopathy ( ['DISEASE'] ) [ An autoimmune disease of cardiovascular system that is characterized by deterioration of the function of the heart muscle. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040096',
#   'title': 'autoimmune atherosclerosis',
#   'description': "autoimmune atherosclerosis ( ['DISEASE'] ) [ An autoimmune disease of cardiovascular system that is characterized by a build up of plaque in the arteries. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040097',
#   'title': 'autoimmune vasculitis',
#   'description': "autoimmune vasculitis ( ['DISEASE'] ) [ An autoimmune disease of cardiovascular system that is characterized by inflammation of the blood vessels. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040098',
#   'title': 'pemphigus gestationis',
#   'description': "pemphigus gestationis ( ['DISEASE'] ) [ A pemphigus that is characterized by blistered skin as a result of self-reactive T and B cells that target BP180. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040099',
#   'title': 'livedoid vasculitis',
#   'description': "livedoid vasculitis ( ['DISEASE'] : livedoid vasculopathy ) [ A vasculitis with purpuric ulcers. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040100',
#   'title': 'Hirata disease',
#   'description': "Hirata disease ( ['DISEASE'] : insulin autoimmune syndrome ) [ An autoimmune disease of endocrine system characterized by hypoglycemia caused by antibodies to insulin. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040101',
#   'title': "N,N'-diphenylthiourea allergic contact dermatitis",
#   'description': "N,N'-diphenylthiourea allergic contact dermatitis ( ['DISEASE'] : neoprene allergy ) [ An allergic contact dermatitis that has_allergic_trigger N,N-diphenylthiourea. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040102',
#   'title': "N,N'-diethylthiourea allergic contact dermatitis",
#   'description': "N,N'-diethylthiourea allergic contact dermatitis ( ['DISEASE'] : neoprene allergy ) [ An allergic contact dermatitis that has_allergic_trigger N,N-diethylthiourea. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040103',
#   'title': 'cefotiam allergy',
#   'description': "cefotiam allergy ( ['DISEASE'] ) [ A cephalosporin allergy that has_allergic_trigger cefotiam. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0040104',
#   'title': 'toluene 2,4-diisocyanate allergic asthma',
#   'description': "toluene 2,4-diisocyanate allergic asthma ( ['DISEASE'] ) [ A toluene meta-diisocyanate allergic asthma that has_allergic_trigger toluene 2,4-diisocyanate. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050004',
#   'title': 'seminal vesicle acute gonorrhea',
#   'description': "seminal vesicle acute gonorrhea ( ['DISEASE'] ) [ A gonococcal seminal vesiculitis that is characterized by back pain, perineal pain, pain with ejaculation, hematospermia and voiding symptoms resulting from inflammation located_in the seminal vesicles caused by Neisseria gonorrhoeae infection. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050012',
#   'title': 'chikungunya',
#   'description': "chikungunya ( ['DISEASE'] : Chikungunya fever ) [ A viral infectious disease that results_in infection located_in joint, has_material_basis_in Chikungunya virus, which is transmitted_by Aedes mosquito bite. The infection has_symptom fever, has_symptom arthralgia, and has_symptom maculopapular rash. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050025',
#   'title': 'human granulocytic anaplasmosis',
#   'description': "human granulocytic anaplasmosis ( ['DISEASE'] : HGE ; human granulocytic ehrlichiosis ) [ An ehrlichiosis that results in infection located in granular leukocyte, has_material_basis_in Anaplasma phagocytophilum, which is transmitted by lone star tick (Amblyomma americanum). The infection has symptom headache, has symptom muscle aches, has symptom fatigue, has symptom fever and has symptom rash. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050026',
#   'title': 'human monocytic ehrlichiosis',
#   'description': "human monocytic ehrlichiosis ( ['DISEASE'] : Ehrlichiosis chafeensis ) [ An ehrlichiosis that results in infection located in monocyte or located in macrophage, has_material_basis_in Ehrlichia chaffeensis, which is transmitted by black-legged tick (Ixodes scapularis), transmitted by western black-legged tick (Ixodes pacificus) or transmitted by castor bean tick (Ixodes ricinus). The infection has symptom headache, has symptom muscle aches, has symptom fatigue, has symptom fever and has symptom rash. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050032',
#   'title': 'mineral metabolism disease',
#   'description': "mineral metabolism disease ( ['DISEASE'] ) [ An acquired metabolic disease that is characterized by abnormal mineral metabolism. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050035',
#   'title': 'African tick-bite fever',
#   'description': "African tick-bite fever ( ['DISEASE'] : Rickettsia africae spotted fever ; south african tick-bite fever ) [ A spotted fever that has_material_basis_in Rickettsia africae, which is transmitted_by ticks (Amblyomma hebraeum and Amblyomma variegatum). The infection has_symptom fever, has_symptom eschar and has_symptom maculopapular rash. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050041',
#   'title': 'Astrakhan spotted fever',
#   'description': "Astrakhan spotted fever ( ['DISEASE'] ) [ A spotted fever that has_material_basis_in Rickettsia conorii subsp caspia, which is transmitted_by ticks (Rhipicephalus pumilio and Rhipicephalus sanguineus). The infection has_symptom fever, has_symptom eschar (usually single), has_symptom regional adenopathy, has_symptom maculopapular rash on extremities. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050042',
#   'title': 'Indian tick typhus',
#   'description': "Indian tick typhus ( ['DISEASE'] ) [ A spotted fever that has_material_basis_in Rickettsia conorii subsp indica, which is transmitted_by ticks (Rhipicephalus sanguineus). The infection has_symptom fever, has_symptom eschar, has_symptom regional adenopathy, and has_symptom maculopapular rash on extremities. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050043',
#   'title': 'Israeli tick typhus',
#   'description': "Israeli tick typhus ( ['DISEASE'] : Israeli spotted fever ) [ A spotted fever that has_material_basis_in Rickettsia conorii subsp israelensis, which is transmitted_by ticks (Rhipicephalus sanguineus). The infection has_symptom fever, has_symptom eschar, has_symptom regional adenopathy, and has_symptom maculopapular rash on extremities. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050046',
#   'title': 'Far Eastern spotted fever',
#   'description': "Far Eastern spotted fever ( ['DISEASE'] : Rickettsia heilongjiangensis spotted fever ) [ A spotted fever that has_material_basis_in Rickettsia heilongjiangensis, which is transmitted_by ticks (Haemaphysalis concinna). The infection has_symptom fever, has_symptom eschar, has_symptom maculopapular rash, and has_symptom regional adenopathy. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050047',
#   'title': 'Flinders Island spotted fever',
#   'description': "Flinders Island spotted fever ( ['DISEASE'] : FISF ; Thai tick typhus ) [ A spotted fever that has_material_basis_in Rickettsia honei, which is transmitted_by cayenne ticks (Amblyomma cajennense). The infection has_symptom mild spotted fever, has_symptom eschar and has_symptom adenopathy. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050050',
#   'title': 'Japanese spotted fever',
#   'description': "Japanese spotted fever ( ['DISEASE'] : oriental spotted fever ; Rickettsia japonica spotted fever ) [ A spotted fever that has_material_basis_in Rickettsia japonica, which is transmitted_by ticks (Dermacentor taiwanensis and Haemaphysalis flava). The infection has_symptom fever, has_symptom eschars, has_symptom regional adenopathy, and has_symptom rash on extremities. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050051',
#   'title': 'Rickettsia parkeri spotted fever',
#   'description': "Rickettsia parkeri spotted fever ( ['DISEASE'] : maculatum infection ) [ A spotted fever that has_material_basis_in Rickettsia parkeri, which is transmitted_by Gulf Coast tick (Amblyomma maculatum). The infection has_symptom fever, has_symptom headache, has_symptom eschar, and has_symptom rash. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050052',
#   'title': 'Rocky Mountain spotted fever',
#   'description': "Rocky Mountain spotted fever ( ['DISEASE'] : Brazillian spotted ; Choix ; Exanthematic typhus of Sao Paulo ; Fiebre maculosa ; Fiebre manchada ; Sao Paulo typhus ; So Paulo fever ; Tick typhus ; Tobia fever ) [ A spotted fever that has_material_basis_in Rickettsia rickettsii, which is transmitted_by ticks (Dermacentor variabilis and Dermacentor andersoni). The infection has_symptom fever, has_symptom headache, has_symptom abdominal pain, and has_symptom maculopapular rash progressing into papular or petechial rash. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050059',
#   'title': 'oropharyngeal anthrax',
#   'description': "oropharyngeal anthrax ( ['DISEASE'] ) [ A gastrointestinal anthrax that results in infection located in mucosa of oropharynx, has_material_basis_in Bacillus anthracis, which is transmitted by ingestion of anthrax-infected meat. The infection has symptom lesions, has symptom vomiting of blood, has symptom severe diarrhea, has symptom loss of appetite. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050061',
#   'title': 'erysipeloid',
#   'description': "erysipeloid ( ['DISEASE'] ) [ A primary bacterial infectious disease that results_in infection located_in skin, has_material_basis_in Erysipelothrix rhusiopathiae, which is transmitted_by contact with infected animals. The infection has_symptom redness of skin, has_symptom tenderness of skin and has_symptom warmth of skin. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050072',
#   'title': 'adiaspiromycosis',
#   'description': "adiaspiromycosis ( ['DISEASE'] ) [ A primary systemic mycosis that is a fungal infection located_in lungs, or located_in skin, which results_in disseminated granulomatous pulmonary process and cutaneous infection in rodents, small wild mammals and humans, has_material_basis_in Chrysosporium parvum or Emmonsia crescens. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050073',
#   'title': 'invasive aspergillosis',
#   'description': "invasive aspergillosis ( ['DISEASE'] ) [ An aspergillosis that is a serious fungal infection of the lung with pneumonia caused by Aspergillus, which spreads to other parts of the body through bloodstream in patients with acute leukemia and recipients of tissue transplants. Clinical symptoms include pulmonary nodules and hemorrhage. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050083',
#   'title': 'Keshan disease',
#   'description': "Keshan disease ( ['DISEASE'] ) [ A nutritional deficiency that is disease characterized by a cardiomyopathy secondary to selenium deficiency. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050096',
#   'title': 'tinea barbae',
#   'description': "tinea barbae ( ['DISEASE'] : dermatophytosis of beard ) [ A dermatophytosis that results_in fungal infection which effects horny layer of epidermis of the bearded areas located_in face or located_in neck, has_material_basis_in Trichophyton mentagrophytes or has_material_basis_in Trichophyton verrucosum, which also effects hair, and effects nail and has_symptom inflammatory kerion-like plaques, and results_in_formation_of noninflammatory superficial perifollicular pustules. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050097',
#   'title': 'ectothrix infectious disease',
#   'description': "ectothrix infectious disease ( ['DISEASE'] ) [ A tinea capitis that results_in fungal infection located_in cuticle of hair, has_material_basis_in Microsporum canis, has_material_basis_in Microsporum gypseum, has_material_basis_in Trichophyton equinum, and has_material_basis_in Trichophyton verrucosum, which produce arthroconidia on the exterior of the hair shaft. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050105',
#   'title': 'endothrix infectious disease',
#   'description': "endothrix infectious disease ( ['DISEASE'] ) [ A tinea capitis that results_in fungal infection located_in hair, has_material_basis_in Ascomycota fungi that belong to a group called dermatophytes, which produce arthroconidia within the hair shaft only. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050116',
#   'title': 'tinea imbricata',
#   'description': "tinea imbricata ( ['DISEASE'] ) [ A tinea corporis that results_in fungal infection located_in skin, has_material_basis_in Trichophyton concentricum, which is characterized by ring-like growth in overlapping circles that may have an autosomal dominant genetic predisposition. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050117',
#   'title': 'disease by infectious agent',
#   'description': "disease by infectious agent ( ['DISEASE'] : infectious disease ) [ A disease that is the consequence of the presence of pathogenic microbial agents, including pathogenic viruses, pathogenic bacteria, fungi, protozoa, multicellular parasites, and aberrant proteins known as prions. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050118',
#   'title': 'La Crosse encephalitis',
#   'description': "La Crosse encephalitis ( ['DISEASE'] : California Encephalitis ; California virus encephalitis ; Neuroinvasive California encephalitis virus infection ) [ A viral infectious disease that results_in inflammation located_in brain, has_material_basis_in La Crosse virus, which is transmitted_by treehole mosquito, Ochlerotatus triseriatus. The infection has_symptom seizures, has_symptom headache, has_symptom fever, has_symptom coma, and has_symptom paralysis. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050120',
#   'title': 'hemophagocytic lymphohistiocytosis',
#   'description': "hemophagocytic lymphohistiocytosis ( ['DISEASE'] : haemophagocytic syndrome ) [ A lymphatic system disease that is characterized by an expansion of the monocyte-macrophage population and intense hemophagocytosis. It can occur de novo, but more often occurs in the setting of another disorder, usually an infection or a malignancy. A clinical picture of fever, hepatosplenomegaly, lymphadenopathy and peripheral pancytopenia. The morphologic hallmark of this syndrome is the phagocytosis of hematopoietic elements by morphologically normal macrophages. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050125',
#   'title': 'dengue shock syndrome',
#   'description': "dengue shock syndrome ( ['DISEASE'] : DSS ) [ A dengue disease that involves the most severe form of dengue fever, has_material_basis_in Dengue virus [NCBITaxon:12637] with four serotypes (Dengue virus 1, 2, 3 and 4), which are transmitted_by Aedes mosquito bite. The infection has_symptom easy bruising, has_symptom blood spots, has_symptom bleeding gums, and has_symptom nosebleeds. It is accompanied by circulatory collapse, involves hypotension, narrow pulse pressure (less than or equal to 20mm Hg), or frank shock. The shock occurs after two to six days of symptoms, followed by collapse, weak pulse, and blueness around the mouth. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050127',
#   'title': 'sinusitis',
#   'description': "sinusitis ( ['DISEASE'] ) [ A paranasal sinus disease involving inflammation of the paranasal sinuses resulting from bacterial, fungal, viral infection, allergic or autoimmune issues. Symptoms can include fever, weakness, fatigue, cough and congestion. There may also be mucus drainage in the back of the throat, called postnasal drip. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050129',
#   'title': 'secretory diarrhea',
#   'description': "secretory diarrhea ( ['DISEASE'] ) [ A diarrhea where there is an increase in the active secretion, or there is an inhibition of absorption causing little to no structural damage. The most common cause of this type of diarrhea is a cholera toxin that stimulates the secretion of anions, especially chloride ions. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050130',
#   'title': 'osmotic diarrhea',
#   'description': "osmotic diarrhea ( ['DISEASE'] ) [ A dirrhea that occurs when too much water is drawn into the bowels. This can be the result of maldigestion (e.g., pancreatic disease or Coeliac disease), in which the nutrients are left in the lumen to pull in water. Osmotic diarrhea can also be caused by osmotic laxatives (which work to alleviate constipation by drawing water into the bowels). In healthy individuals, too much magnesium or vitamin C or undigested lactose can produce osmotic diarrhea and distention of the bowel. A person who does not have lactose intolerance can have difficulty absorbing lactose after an extraordinarily high intake of dairy products. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050131',
#   'title': 'motility-related diarrhea',
#   'description': "motility-related diarrhea ( ['DISEASE'] ) [ A diarrhea which is caused by the rapid movement of food through the intestines (hypermotility). If the food moves too quickly through the GI tract, there is not enough time for sufficient nutrients and water to be absorbed. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050132',
#   'title': 'inflammatory diarrhea',
#   'description': "inflammatory diarrhea ( ['DISEASE'] ) [ A gastrointestinal system infectious disease involving diarrhea that occurs when there is damage to the mucosal lining or brush border, which leads to a passive loss of protein-rich fluids, and a decreased ability to absorb these lost fluids. It can be caused by bacterial infections, viral infections, parasitic infections, or autoimmune problems such as inflammatory bowel diseases. It can also be caused by tuberculosis, colon cancer, and enteritis. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050133',
#   'title': 'superficial mycosis',
#   'description': "superficial mycosis ( ['DISEASE'] : piedra ; Steroid-modified tinea infection ) [ A fungal infectious disease that results_in infection of the outermost layer located_in skin or located_in hair shaft, has_material_basis_in Fungi. No living tissue is invaded and there is no cellular response from the host. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050134',
#   'title': 'cutaneous mycosis',
#   'description': "cutaneous mycosis ( ['DISEASE'] ) [ A fungal infectious disease that results_in infection of the keratinized layers located_in skin, located_in hair or located_in nail, which extends deeper into the epidermis, has_material_basis_in Fungi and results_in_formation_of skin lesions. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050135',
#   'title': 'subcutaneous mycosis',
#   'description': "subcutaneous mycosis ( ['DISEASE'] ) [ A fungal infectious disease that results_in infection located_in skin or located_in subcutaneous tissue, has_material_basis_in Fungi, which penetrate the dermis or even deeper during or after a skin trauma. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050136',
#   'title': 'systemic mycosis',
#   'description': "systemic mycosis ( ['DISEASE'] ) [ A fungal infectious disease that results_in infection of internal organs and tissues located_in human body, has_material_basis_in Fungi, which enter the body via the respiratory tract, through the gut, paranasal sinuses or skin and spread through the bloodstream to multiple organs. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050138',
#   'title': 'podoconiosis',
#   'description': "podoconiosis ( ['DISEASE'] ) [ An elephantiasis that is characterized by lymphadema located_in the lower extremities caused by a genetically determined abnormal inflammatory reaction to mineral particles in irritant red clay soils derived from volcanic deposits. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050140',
#   'title': 'acute diarrhea',
#   'description': "acute diarrhea ( ['DISEASE'] ) [ A diarrhea that is of rapid onset and course characterized by frequent loose or liquid bowel movements. Acute diarrhea is a common cause of death in developing countries and the second most common cause of infant deaths worldwide. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050141',
#   'title': 'intestinal botulism',
#   'description': "intestinal botulism ( ['DISEASE'] ) [ A botulism that involves intoxication caused by botulinum neurotoxins (BoNTA, B, E and F) in adults, has_material_basis_in Clostridium botulinum A, has_material_basis_in Clostridium botulinum B, has_material_basis_in Clostridium botulinum E and has_material_basis_in Clostridium botulinum F, which are transmitted by ingestion of bacterial spores, which then grow in the intestine and release toxins. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050143',
#   'title': 'asymptomatic dengue',
#   'description': "asymptomatic dengue ( ['DISEASE'] ) [ A dengue disease that results_in infection, has_material_basis_in Dengue virus [NCBITaxon:12637] with four serotypes (Dengue virus 1, 2, 3 and 4), which are transmitted_by Aedes mosquito bite. The infection has no manifestations of symptoms. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050144',
#   'title': 'Kartagener syndrome',
#   'description': "Kartagener syndrome ( ['DISEASE'] : Kartagener's syndrome ) [ A primary ciliary dyskinesia that is characterized by sinusitis, bronchiectasis and situs inversus with dextrocardia resulting from dysfunction of the cilia during embryologic development. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050145',
#   'title': 'adenoiditis',
#   'description': "adenoiditis ( ['DISEASE'] : chronic adenoiditis ) [ An upper respiratory tract disease which involves inflammation, pain, and swelling of the adenoid tissue due to the infection by bacteria and viruses. It occurs primarily in children and may be secondary to an allergy, infection of nose or throat and an obstruction of the eustachian tube. The infection has symptom pain, has symptom redness, has symptom swelling, and has symptom difficulty swallowing. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050147',
#   'title': 'otomycosis',
#   'description': "otomycosis ( ['DISEASE'] : Singapore ear ) [ An otitis externa which is a disease of the ear produced by the growth of fungi in the external auditory canal. It is characterized by inflammation, pruritus, scaling and severe discomfort. The most common fungi are Aspergillus niger and Candida albicans. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050148',
#   'title': 'laryngotracheitis',
#   'description': "laryngotracheitis ( ['DISEASE'] ) [ An upper respiratory tract disease involving inflammation of both larynx and trachea often caused by viral infection. The infection can close off the windpipe. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050150',
#   'title': 'Pontiac fever',
#   'description': "Pontiac fever ( ['DISEASE'] ) [ A legionellosis that involves a milder respiratory illness without pneumonia. Symptoms include fever, headache and muscle aches which last for 2 to 5 days. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050152',
#   'title': 'aspiration pneumonia',
#   'description': "aspiration pneumonia ( ['DISEASE'] ) [ A bacterial pneumonia which is an acute pulmonary inflammatory response that develops after the inhalation of colonized oropharyngeal material containing bacteria. It is seen in individuals with dysphagia and gastric dysmotility. The disease has_symptom tachypnea and has_symptom cough. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0050153',
#   'title': 'pulmonary aspergilloma',
# ...
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060243',
#   'title': 'stuttering',
#   'description': "stuttering ( ['DISEASE'] : familial persistent stuttering ; stammering ) [ An articulation disorder characterized by involuntary sound repetition and disruption or blocking of speech. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060244',
#   'title': 'specific language impairment',
#   'description': "specific language impairment ( ['DISEASE'] ) [ A language disorder characterized by difficulty in language acquisition despite otherwise normal development and in the absence of any obvious explanatory factors. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060245',
#   'title': 'Mast syndrome',
#   'description': "Mast syndrome ( ['DISEASE'] : autosomal recessive spastic paraplegia 21 ; autosomal recessive spastic paraplegia type 21 ; hereditary spastic paraplegia 21 ; SPG21 ) [ A hereditary spastic paraplegia associated with dementia. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060246',
#   'title': 'MASA syndrome',
#   'description': "MASA syndrome ( ['DISEASE'] : CRASH syndrome ; Gareis-Mason syndrome ; hereditary spastic paraplegia 1 ; L1 syndrome ; SPG1 ; X-linked complicated hereditary spastic paraplegia type 1 ; X-linked corpus callosum agenesis ; X-linked spastic paraplegia 1 ) [ A hereditary spastic paraplegia that is characterized by hydrocephalus, spasticity of the lower limbs, adducted thumbs, aphasia, seizures, agenesis of the corpus callosum and intellectual disability in the mild to moderate range. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060247',
#   'title': 'Smith-McCort dysplasia',
#   'description': "Smith-McCort dysplasia ( ['DISEASE'] ) [ A Dyggve-Melchior-Clausen disease that is characterized by short limbs and a short trunk with a barrel-shaped chest. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060248',
#   'title': 'Simpson-Golabi-Behmel syndrome type 1',
#   'description': "Simpson-Golabi-Behmel syndrome type 1 ( ['DISEASE'] : bulldog syndrome ; DGSX Golabi-Rosen syndrome ; Golabi-Rosen syndrome ; Sara Angers syndrome ; SGB syndrome ; Simpson dysmorphia syndrome ; X-linked dysplasia gigantism syndrome ) [ A syndrome characterized by pre- and postnatal overgrowth and craniofacial, skeletal, cardiac and renal abnormalities and has_material_basis_in mutation in the gene encoding glypican-3 (GPC3) on chromosome Xq26. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060249',
#   'title': 'scoliosis',
#   'description': "scoliosis ( ['DISEASE'] ) [ A bone structure disease characterized by an appreciable lateral deviation in the normally straight vertical line of the spine. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060250',
#   'title': 'idiopathic scoliosis',
#   'description': "idiopathic scoliosis ( ['DISEASE'] ) [ A scoliosis with no known cause. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060251',
#   'title': 'sclerosteosis',
#   'description': "sclerosteosis ( ['DISEASE'] ) [ A hyperostosis characterized by excessive bone formation most prominent in the skull, mandible, clavicle, ribs and diaphyses of long bones; bone formation occurs throughout life. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060252',
#   'title': 'sclerocornea',
#   'description': "sclerocornea ( ['DISEASE'] : isolated congenital sclerocornea ) [ A corneal disease in which the cornea blends with sclera, resulting in clouding of the cornea. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060253',
#   'title': 'scapuloperoneal myopathy',
#   'description': "scapuloperoneal myopathy ( ['DISEASE'] ) [ A muscular dystrophy which begins at the lower legs and affects the shoulder region earlier and more severely than distal arm. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060254',
#   'title': 'Robinow syndrome',
#   'description': "Robinow syndrome ( ['DISEASE'] : acral dysostosis with facial and genital abnormalities ; fetal face syndrome ; Robinow dwarfism ) [ A syndrome characterized by mild to moderate short stature due to growth delays after birth, distinctive craniofacial abnormalities, skeletal malformations and genital abnormalities. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060255',
#   'title': 'rippling muscle disease 2',
#   'description': "rippling muscle disease 2 ( ['DISEASE'] : autosomal dominant limb-girdle muscular dystrophy type 1C ) [ A muscle tissue disease characterized by mechanically triggered contractions of skeletal muscle and that has_material_basis_in mutation in the caveolin-3 gene (CAV3) on chromosome 3p25. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060256',
#   'title': 'Dowling-Degos disease',
#   'description': "Dowling-Degos disease ( ['DISEASE'] : dark dot disease ; reticular pigment anomaly of flexures ) [ A pigmentation disease characterized by a reticulate pattern of abnormally dark skin coloring, particularly in the body's folds and creases. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060257',
#   'title': 'dyschromatosis symmetrica hereditaria',
#   'description': "dyschromatosis symmetrica hereditaria ( ['DISEASE'] : reticulate acropigmentation of Dohi ) [ A pigmentation disease characterized by progressively pigmented and depigmented macules, often mixed in a reticulate pattern, concentrated on the dorsal extremities. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060258',
#   'title': 'reticulate acropigmentation of Kitamura',
#   'description': "reticulate acropigmentation of Kitamura ( ['DISEASE'] : RAPK ) [ A pigmentation disease characterized by lesions that initially arise as letiginous, hyperpigmented macules in a reticular pattern on the dorsal aspect of the hands and feet. Over time, lesions may spread proximally and may darken; palmoplantar pitting and dermatoglyphic disruption may also be present. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060259',
#   'title': 'renal-hepatic-pancreatic dysplasia',
#   'description': "renal-hepatic-pancreatic dysplasia ( ['DISEASE'] : Ivemark's syndrome ) [ A physical disorder characterized by pancreatic fibrosis, renal dysplasia and hepatic dysgenesis; it is usual fatal soon after birth. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060260',
#   'title': 'ptosis',
#   'description': "ptosis ( ['DISEASE'] : blepharoptosis ; drooping eyelid ) [ An eye disease characterized by the drooping or falling of the upper or lower eyelid. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060261',
#   'title': 'congenital ptosis',
#   'description': "congenital ptosis ( ['DISEASE'] ) [ A ptosis characterized by eyelid drop present at birth. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060262',
#   'title': 'gallbladder disease',
#   'description': "gallbladder disease ( ['DISEASE'] ) [ A gastrointestinal system disease that is located_in the gallbladder. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060263',
#   'title': 'porencephaly',
#   'description': "porencephaly ( ['DISEASE'] ) [ A brain disease that is characterized by encephalomalacia and cystic brain lesions. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060264',
#   'title': 'pontocerebellar hypoplasia',
#   'description': "pontocerebellar hypoplasia ( ['DISEASE'] : PCH ) [ A neurodegenerative disease that is characterized by underdevelopment of the pons and cerebellum. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060265',
#   'title': 'pontocerebellar hypoplasia type 1A',
#   'description': "pontocerebellar hypoplasia type 1A ( ['DISEASE'] ) [ A pontocerebellar hypoplasia that is characterized by central and peripheral motor dysfunction, hypotonia, spasticity and failure to thrive, has_material_basis_in homozygous or compound heterozygous mutation in the VRK1 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060266',
#   'title': 'pontocerebellar hypoplasia type 1B',
#   'description': "pontocerebellar hypoplasia type 1B ( ['DISEASE'] ) [ A severe pontocerebellar hypoplasia that is characterized by hypotonia, progressive microcephaly and developmental delay, has_material_basis_in autosomal recessive inheritance of mutation in the EXOSC3 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060267',
#   'title': 'pontocerebellar hypoplasia type 2A',
#   'description': "pontocerebellar hypoplasia type 2A ( ['DISEASE'] ) [ A severe pontocerebellar hypoplasia that is characterized by progressive microcephaly, chorea, epilepsy and hyperreflexia, has_material_basis_in autosomal recessive inheritance of mutation in the TSEN54 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060268',
#   'title': 'pontocerebellar hypoplasia type 2B',
#   'description': "pontocerebellar hypoplasia type 2B ( ['DISEASE'] ) [ A severe pontocerebellar hypoplasia that is characterized by progressive microcephaly, clonus, dysphagia and failure to thrive, has_material_basis_in autosomal recessive inheritance of mutation in the TSEN2 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060269',
#   'title': 'pontocerebellar hypoplasia type 2C',
#   'description': "pontocerebellar hypoplasia type 2C ( ['DISEASE'] ) [ A severe pontocerebellar hypoplasia that is characterized by progressive microcephaly, extrapyramidal dyskinesia, seizure and failure to thrive, has_material_basis_in autosomal recessive inheritance of mutation in the TSEN34 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060270',
#   'title': 'pontocerebellar hypoplasia type 2D',
#   'description': "pontocerebellar hypoplasia type 2D ( ['DISEASE'] ) [ A pontocerebellar hypoplasia that is characterized by progressive microcephaly, profound intellectual disability, spasticity and seizure, has_material_basis_in autosomal recessive inheritance of mutation in the SEPSECS gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060271',
#   'title': 'pontocerebellar hypoplasia type 2E',
#   'description': "pontocerebellar hypoplasia type 2E ( ['DISEASE'] ) [ A pontocerebellar hypoplasia that is characterized by progressive microcephaly, profound intellectual disability, spasticity and seizure, has_material_basis_in autosomal recessive inheritance of mutation in the VPS53 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060272',
#   'title': 'pontocerebellar hypoplasia type 3',
#   'description': "pontocerebellar hypoplasia type 3 ( ['DISEASE'] ) [ A pontocerebellar hypoplasia that is characterized by progressive microcephaly, hypotonia, dysmorphic features, profound intellectual disability and seizure, has_material_basis_in autosomal recessive inheritance of mutation in the PCLO gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060273',
#   'title': 'pontocerebellar hypoplasia type 4',
#   'description': "pontocerebellar hypoplasia type 4 ( ['DISEASE'] ) [ A pontocerebellar hypoplasia that is characterized by progressive microcephaly, hypertonia, myoclonus, seizure and early lethality, has_material_basis_in autosomal recessive inheritance of mutation in the TSEN54 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060274',
#   'title': 'pontocerebellar hypoplasia type 5',
#   'description': "pontocerebellar hypoplasia type 5 ( ['DISEASE'] ) [ A pontocerebellar hypoplasia that is characterized by severe olivopontocerebellar hypoplasia and degeneration leading to early lethality, has_material_basis_in autosomal recessive inheritance of mutation in the TSEN54 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060275',
#   'title': 'pontocerebellar hypoplasia type 6',
#   'description': "pontocerebellar hypoplasia type 6 ( ['DISEASE'] ) [ A pontocerebellar hypoplasia that is characterized by olivopontocerebellar hypoplasia and developmental delay, has_material_basis_in autosomal recessive inheritance of mutation in the RARS2 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060276',
#   'title': 'pontocerebellar hypoplasia type 7',
#   'description': "pontocerebellar hypoplasia type 7 ( ['DISEASE'] ) [ A pontocerebellar hypoplasia that is characterized by delayed psychomotor development, hypotonia, gonadal abnormalities and respiratory failure, has_material_basis_in autosomal recessive mutation in the TOE1 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060277',
#   'title': 'pontocerebellar hypoplasia type 8',
#   'description': "pontocerebellar hypoplasia type 8 ( ['DISEASE'] ) [ A pontocerebellar hypoplasia that is characterized by delayed psychomotor development, chorea, hypotonia, spasticity and visual defects, has_material_basis_in autosomal recessive inheritance of mutation in the CHMP1A gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060278',
#   'title': 'pontocerebellar hypoplasia type 9',
#   'description': "pontocerebellar hypoplasia type 9 ( ['DISEASE'] ) [ A pontocerebellar hypoplasia that is characterized by progressive microcephaly, spasticity, seizure and brain atrophy, has_material_basis_in autosomal recessive inheritance of mutation in the AMPD2 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060279',
#   'title': 'pontocerebellar hypoplasia type 10',
#   'description': "pontocerebellar hypoplasia type 10 ( ['DISEASE'] ) [ A pontocerebellar hypoplasia that is characterized by severe developmental delays, progressive microcephaly, spasticity and seizure, has_material_basis_in autosomal recessive inheritance of mutation in the CLP1 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060280',
#   'title': 'primary pigmented nodular adrenocortical disease',
#   'description': "primary pigmented nodular adrenocortical disease ( ['DISEASE'] ) [ An adrenal cortex disease characterized by small to normal sized adrenal glands containing multiple small cortical pigmented nodules. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060281',
#   'title': 'photosensitive epilepsy',
#   'description': "photosensitive epilepsy ( ['DISEASE'] : photogenic epilepsy ; photoparoxysmal response ) [ An epilepsy characterized by seizures triggered by visual stimuli that form patterns in space or time, such as flashing lights. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060282',
#   'title': 'persistent hyperplastic primary vitreous',
#   'description': "persistent hyperplastic primary vitreous ( ['DISEASE'] ) [ A developmental vitreous disease that is characterized by leukocoria, strabismus and vision loss, caused by failure of primary vitreous and hyaloid vasculature to regress during embryological development. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060283',
#   'title': 'peeling skin syndrome',
#   'description': "peeling skin syndrome ( ['DISEASE'] : deciduous skin ; familial continuous skin peeling syndrome ; keratosis exfoliativa congenita ; peeling skin disease ; PSS ) [ A skin disease that is characterized by the painless, continuous peeling of the top layer of skin. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060284',
#   'title': 'paroxysmal nocturnal hemoglobinuria',
#   'description': "paroxysmal nocturnal hemoglobinuria ( ['DISEASE'] ) [ An acquired hemolytic anemia that is characterized by abdominal pain, hematuria, esophageal dysmotility and thrombosis, has_material_basis_in defect in the cell membrane glycosyl phosphatidylinositols that protect red blood cells from the innate complement immune system. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060285',
#   'title': 'parietal foramina',
#   'description': "parietal foramina ( ['DISEASE'] : Caitlin marks ; enlarged parietal foramina ; hereditary cranium bifidum ) [ An inherited neural tube defect that is characterized by enlarged openings in the parietal bones of the skull, has_material_basis_in mutation in the ALX4 gene or MSX2 gene. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060286',
#   'title': 'combined oxidative phosphorylation deficiency',
#   'description': "combined oxidative phosphorylation deficiency ( ['DISEASE'] ) [ A mitochondrial metabolism disease that is characterized by growth retardation, microcephaly, hypertonia, encephalopathy, cardiomyopathy and liver dysfunction. ]"},
#  {'type': ['DISEASE'],
#   'cui': 'DOID:0060287',
#   'title': 'cornea plana',
#   'description': "cornea plana ( ['DISEASE'] : flat cornea ) [ A corneal disease that is characterized by a flat cornea where the radus of curvature is less than 43 D. ]"},
#  ...]

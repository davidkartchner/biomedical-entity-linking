# %%
import ujson

# Set up necessary variables/parameters
all_abbreviations = {}
min_confidence_cutoff = .95
omitted = 0
included = 0

# Read in data
filepath = '../data/raw_abbreviations.txt'
with open(filepath, 'r') as f:
    chunks = f.read().strip().split('\n\n')

# Get abbreviations from each article
for chunk in chunks:
    lines = chunk.split('\n')
    pmid = lines[0].split('|')[0].strip()
    abbrev_dict = {}
    for line in lines[1:]:
        abbrev, long_form, confidence_score = line.strip().split('|')
        confidence_score = float(confidence_score)
        if confidence_score > min_confidence_cutoff:
            abbrev_dict[abbrev] = long_form
            included += 1
        else:
            # print(abbrev, long_form, confidence_score)
            omitted += 1

    all_abbreviations[pmid] = abbrev_dict

with open('../data/abbreviations.json', 'w') as f:
    f.write(ujson.dumps(all_abbreviations, indent=2))

# %%
chunk.split('\n')[0].split('|')[0].strip()
# Out:
# '30202097'

# %%
all_abbreviations
# Out:
# {'25763772': {'Pa': 'Pseudomonas aeruginosa',
#   'CF': 'cystic fibrosis',
#   'CPA': 'chronic Pa infection',
#   'DCTN4': 'dynactin 4'},
#  '26316050': {},
#  '26406200': {'FRP': 'flexion - relaxation phenomenon'},
#  '26424709': {'VMMC': 'voluntary medical male circumcision'},
#  '26476440': {},
#  '26864880': {'EP': 'electrostatic powder'},
#  '26867927': {'CS': 'coronary sinus', 'AF': 'Atrial fibrillation'},
#  '26868132': {'FH2D': 'family history of type 2 diabetes',
#   'FH2D+': 'FH2D',
#   'FH2D-': 'FH2D',
#   'WC': 'waist circumference',
#   'FPG': 'fasting plasma glucose',
#   'RBP4': 'Retinol Binding Protein 4',
#   'CRP': 'C reactive protein',
#   'baPWV': 'Brachial-ankle pulse wave velocity',
#   'VFA': 'Visceral fat area',
#   'OGTT': 'oral glucose tolerance test',
#   'GIR': 'glucose infusing rate',
#   'SBP': 'systolic blood pressure',
#   'DBP': 'diastolic blood pressure'},
#  '26883265': {'LBP': 'low back pain',
#   'OA': 'osteoarthritis',
#   'THA': 'total hip arthroplasty',
#   'VAS': 'visual analog scale',
#   'RMDQ': 'Roland-Morris Disability Questionnaire',
#   'HHS': 'Harris Hip Score'},
#  '26944725': {'SCLM': 'synchronous liver metastases',
#   'TLA': 'totally laparoscopic approach'},
#  '27010511': {},
#  '27086366': {'IVA': 'insect venom allergy',
#   'CM': 'cutaneous mastocytosis',
#   'ISM': 'indolent systemic mastocytosis'},
#  '27093899': {},
#  '27113387': {'PA': 'protected area'},
#  '27121486': {'LDL-R': 'low-density lipoprotein receptor',
#   'IL-2': 'Interleukin-2',
#   'TC': 'total cholesterol'},
#  '27196563': {'BMD': 'bone mineral density'},
#  '27216824': {},
#  '27233260': {'CHIKV': 'Chikungunya virus'},
#  '27233466': {'CMF': 'Clinical Monitoring Form'},
#  '27233592': {},
#  '27234004': {'TKA': 'total knee arthroplasty', 'OKS': 'Oxford knee score'},
#  '27234031': {'NMDs': 'Neuromuscular diseases'},
#  '27235977': {'EPIT': 'epicutaneous allergen-specific immunotherapy',
#   'OVA': 'ovalbumin',
#   'SCIT': 'subcutaneous immunotherapy',
#   'AHR': 'airway hyperresponsivness',
#   'Treg': 'T-regulatory'},
#  '27235985': {},
#  '27236033': {'PCAD': 'premature CAD',
#   'PCR': 'polymerase chain reaction',
#   'multi-AMRS': 'multiplex amplification refractory mutation system',
#   'TC': 'total cholesterol'},
#  '27236596': {'TMDs': 'temporomandibular disorders',
#   'CG': 'control group',
#   'EG': 'education group',
#   'ESG': 'education and self-care group',
#   'MAM': 'mandibular movement'},
#  '27237979': {'EMT': 'epithelial mesenchymal transition'},
#  '27239953': {'CI': 'confidence interval', 'BMI': 'body mass index'},
#  '27240437': {'HIV': 'human immunodeficiency virus',
#   'HCV': 'hepatitis C virus'},
#  '27241087': {'dAVFs': 'dural arteriovenous fistulas',
#   'MMA': 'middle meningeal artery'},
#  '27242101': {},
#  '27242395': {'PNC': 'Philadelphia Neurodevelopmental Cohort'},
#  '27242865': {'SNPs': 'single nucleotide polymorphisms'},
#  '27243664': {'DON': 'deoxynivalenol', 'IACs': 'Immunoafﬁnity columns'},
#  '27244841': {'ASD': 'autism spectrum disorder',
#   'LC': 'learning collaborative'},
#  '27245100': {},
#  '27245303': {'VFAs': 'volatile fatty acids',
#   'GIT': 'gastrointestinal tract',
#   'NE': 'necrotic enteritis'},
#  '27245524': {'EDSs': 'Ehlers-Danlos syndromes'},
#  '27246120': {'EGC': 'early gastric cancer',
#   'SBD': 'sentinel basin dissection',
#   'DFS': 'disease-free survival'},
#  '27249024': {'T2D': 'type 2 diabetes', 'KARE': 'Korean Association REsource'},
#  '27249236': {},
#  '27250037': {},
#  '27250793': {'ACR': 'acrolein',
#   'CA': 'crotonaldehyde',
#   'MVK': 'methyl vinyl ketone',
#   'CSE': 'cigarette smoke extract'},
#  '27250949': {'LMP': 'lysosomal membrane permeabilization'},
#  '27251157': {'BMSCs': 'bone marrow stromal cells',
#   'CNLCs': 'cholinergic neuron-like cells'},
#  '27251364': {},
#  '27252099': {},
#  '27252416': {},
#  '27252474': {'sCVOs': 'sensory circumventricular organs',
#   'Na(+)': 'Nax is a sodium',
#   'TRPV': 'transient receptor potential vanilloid',
#   'icv': 'intracerebroventricular',
#   'AA': 'arachidonic acid'},
#  '27252817': {'NAFLD': 'Nonalcoholic Fatty Liver Disease',
#   'NASH': 'Nonalcoholic Steatohepatitis',
#   'TNF-α': 'tumor necrosis factor-alpha'},
#  '27252904': {'PAI-1': 'plasminogen activator inhibitor-1',
#   'NGAL': 'necoutrophil gelatinase-associated lipocalin',
#   'APACHE': 'acute physiology and chronic health evaluation',
#   'SOFA': 'sequential organ failure assessment'},
#  '27253877': {},
#  '27254091': {},
#  '27254783': {},
#  '27255214': {},
#  '27255399': {'SSNs': 'subsolid pulmonary nodules'},
#  '27255411': {'CTPI': 'computed tomography perfusion imaging',
#   'CAD': 'coronary artery disease',
#   'cCTA': 'coronary CT angiography',
#   'SD': 'standard deviation',
#   'MBF': 'myocardial blood flow',
#   'MBV': 'myocardial blood volume'},
#  '27255600': {},
#  '27256046': {},
#  '27256126': {},
#  '27256373': {},
#  '27256491': {'IVT': 'intravenous thrombolysis',
#   'AIS': 'acute ischemic stroke'},
#  '27257063': {'CTD': 'carboxyl-terminal domain'},
#  '27257207': {},
#  '27257836': {},
#  '27258136': {'VCD': '4-Vinylcyclohexene diepoxide'},
#  '27258690': {'MS': 'mass spectrometry'},
#  '27258956': {'MI': 'myocardial infarction'},
#  '27259186': {'FSP': 'fiber saturation point'},
#  '27259326': {'HCC': 'Hepatocellular carcinoma',
#   'NK': 'natural killer',
#   'TACE': 'transcatheter arterial chemoembolization',
#   'AHCS': 'argon-helium cryosurgery system',
#   'AFP': 'alpha-fetoprotein'},
#  '27259677': {'OCS': 'orbital compartment syndrome',
#   'CMF': 'craniomaxillofacial'},
#  '27260358': {'HEAM': 'human excreta and animal manure',
#   'ssRNA': 'single-stranded RNA',
#   'dsRNA': 'double-stranded RNA',
#   'ssDNA': 'single-stranded DNA',
#   'dsDNA': 'double-stranded DNA'},
#  '27260450': {},
#  '27261525': {'NMDAR': 'N-methyl d-aspartate glutamate receptor',
#   'CT': 'corticothalamic'},
#  '27262143': {},
#  '27262362': {'PICU': 'pediatric intensive care unit',
#   'CI': 'confidence interval',
#   'HR': 'hazard ratio'},
#  '27263085': {},
#  '27264279': {},
#  '27265179': {'PDO': 'protected designation of origin'},
#  '27266322': {'AGAS': 'aerobic granular activated sludge',
#   'FAS': 'flocculent activated sludge',
#   'AHL': 'acylated homoserine lactone'},
#  '27267054': {},
#  '27267338': {},
#  '27267388': {},
#  '27267564': {'EU': 'U-enriched uranium', 'MS': 'mass spectrometry'},
#  '27267962': {'FDP': 'fibrin degradation products',
#   'ROC': 'receiver operating characteristic'},
#  '27268023': {'MRR': 'Mortality rate ratios'},
#  '27270538': {'PI-RADS': 'Prostate Imaging Reporting and Data System',
#   'PCa': 'prostate cancer',
#   'PSA': 'prostate-specific antigen',
#   'T2WI': 'T2-weighted',
#   'DWI': 'diffusion-weighted'},
#  '27271087': {'PANSS': 'positive and negative syndrome scale'},
#  '27271775': {},
#  '27271951': {},
#  '27272523': {'uORFs': 'unique open reading frames',
#   'rRNAs': 'ribosomal RNAs',
#   'tRNAs': 'transfer RNAs'},
#  '27273075': {'DHF': 'dengue hemorrhagic fever',
#   'DSS': 'dengue shock syndrome'},
#  '27273918': {'FGM': 'female genital mutilation'},
#  '27274087': {'EMT': 'epithelial to mesenchymal transition'},
#  '27274417': {},
#  '27275025': {'CRD': 'Costa Rica Dome'},
#  '27275298': {},
#  '27275827': {'BMI': 'body mass index'},
#  '27275849': {},
#  '27279849': {'OHCA': 'out-of-hospital cardiac arrest',
#   'CPR': 'cardiopulmonary resuscitation',
#   'ROSC': 'return of spontaneous circulation'},
#  '27279981': {},
#  '27280485': {'HEV': 'hepatitis E virus'},
#  '27282214': {'SR': 'startle response',
#   'SRM': 'Startle modification',
#   'HRV': 'heart rate variability'},
#  '27282236': {'VR': 'virtual reality',
#   'PTCD': 'percutaneous transhepatic cholangio-drainage'},
#  '27282454': {'AT': 'Achilles tendon', 'CSA': 'Cross-sectional area'},
#  '27283081': {'SB': 'sodium butyrate', 'CaS': 'calcium sulfate'},
#  '27283994': {},
#  '27284118': {'OCD': 'Obsessive compulsive disorder'},
#  '27284491': {'CRCs': 'colorectal cancers',
#   'MSI': 'Microsatellite instability'},
#  '27284493': {'MDPV': '3,4-methylenedioxypyrovalerone',
#   'METH': 'methamphetamine'},
#  '27284958': {'ERBB2mut': 'ERBB2 mutations',
#   'IHC': 'immunohistochemistry',
#   'FISH': 'fluorescence in situ hybridization',
#   'mBC': 'advanced/metastatic breast cancers',
#   'FFPE': 'formalin-fixed paraffin-embedded',
#   'CGP': 'Comprehensive genomic profiling',
#   'ERBB2amp': 'ERBB2 amplifications',
#   'NOS': 'not otherwise specified',
#   'IDC': 'invasive ductal carcinoma',
#   'ILC': 'invasive lobular carcinoma',
#   'TP53': 'tumor protein 53',
#   'CCND1': 'cyclin D1 protein'},
#  '27285494': {'BHR': 'bronchial hyperresponsiveness',
#   'CI': 'confidence intervals'},
#  '27286333': {},
#  '27286759': {'DPD': 'drug poisoning death', 'UT': 'Utah'},
#  '27287100': {},
#  '27287247': {},
#  '27288403': {},
#  '27289224': {'GLRaV': 'grapevine leafroll-associated virus'},
#  '27292641': {},
#  '27293123': {},
#  '27293431': {'MALDI-MSI': 'Matrix-Assisted Laser Desorption/Ionisation-Mass Spectrometry Imaging'},
#  '27294314': {'Ser': 'serine'},
#  '27294436': {'VDs': 'verbal descriptors'},
#  '27294526': {'HIF1α': 'hypoxia-inducible factor 1α'},
#  '27294544': {'CAT-NP': 'catalytic nanoparticles'},
#  '27294781': {'BoNT/A1': 'Botulinum neurotoxin serotype A1'},
#  '27294858': {},
#  '27294935': {'FDR': 'frequency domain reflectometry'},
#  '27295294': {},
#  '27295651': {},
#  '27296867': {},
#  '27296942': {'WF-EMR': 'wide-field endoscopic mucosal resection',
#   'LSL': 'laterally spreading colorectal lesions',
#   'OR': 'odds ratio'},
#  '27297608': {'IA': 'Intra-articular',
#   'OA': 'osteoarthritis',
#   'MPA': 'methylprednisolone acetate'},
#  '27298004': {},
#  '27298653': {'IHD': 'intrahepatic bile duct',
#   'MRCP': 'magnetic resonance cholangio-pancreatography',
#   'RHD': 'right hepatic duct',
#   'RPSD': 'right posterior sectoral duct',
#   'LHD': 'left hepatic duct',
#   'CHD': 'common hepatic duct'},
#  '27298741': {'CSF': 'cerebrospinal fluid'},
#  '27299091': {},
#  '27299182': {'NO': 'nitric oxide'},
#  '27299289': {'CT': 'computed tomography'},
#  '27299522': {'PDE5': 'phosphodiesterase type 5', 'HRs': 'Hazard ratios'},
#  '27299763': {},
#  '27299886': {'Sdc1': 'Syndecan-1'},
#  '27300443': {},
#  '27300936': {'biPISA': 'bispectral pairwise interacting source analysis',
#   'EEG': 'electroencephalographic',
#   'MEG': 'magnetoencephalographic',
#   'PISA': 'pairwise interacting source analysis'},
#  '27301186': {'PGC': 'palmitoyl glycol chitosan'},
#  '27301553': {},
#  '27301853': {},
#  '27301949': {},
#  '27303047': {'TNAP': 'tissue-non-specific alkaline phosphatase',
#   'TKO': 'triple knockout'},
#  '27303795': {},
#  '27303808': {},
#  '27304655': {'VDD': 'vitamin D deficiency', 'D3': '25(OH)D3'},
#  '27305656': {'NCDS': 'National Chronic Disease Strategy',
#   'NPAPH': 'National Partnership Agreement on Preventive Health'},
#  '27305688': {'AD': "Alzheimer's disease"},
#  '27306062': {'IFN-β': 'interferon beta',
#   'MS': 'multiple sclerosis',
#   'NR': 'nonresponders'},
#  '27306621': {'LBBB': 'left bundle branch block',
#   'CRT': 'cardiac resynchronization treatment',
#   'CMR': 'cardiac magnetic resonance imaging',
#   'SF': 'septal flash',
#   'AR': 'apical rocking',
#   'LV': 'left-ventricular'},
#  '27306647': {},
#  '27308603': {},
#  '27310240': {'BD': 'bipolar disorder', 'SCZ': 'schizophrenia'},
#  '27310660': {},
#  '27310824': {'LPN': 'laparoscopic partial nephrectomy'},
#  '27311863': {'FCR': 'flexor carpi radialis'},
#  '27311930': {},
#  '27312152': {'CSX': 'cardiac syndrome X',
#   'TCC': 'terminal complement complex'},
#  '27312263': {},
#  '27312275': {'WAF': 'water-accommodated fractions',
#   'PAH': 'polycyclic aromatic hydrocarbon'},
#  '27312379': {'SHU': 'synthetic human urine',
#   'UTI': 'urinary tract infection',
#   'ABU': 'asymptomatic bacteriuria'},
#  '27312487': {'OPN': 'osteopontin', 'OSCC': 'oral squamous cell carcinoma'},
#  '27312729': {'TBI': 'traumatic brain injury',
#   'LFPI': 'lateral fluid percussion injury',
#   'PKC': 'protein kinase C'},
#  '27313537': {},
#  '27313614': {'TKIs': 'tyrosine kinase inhibitors'},
#  '27313637': {'SFC': 'steamed and fermented C. lanceolata',
#   'AChE': 'acetylcholinesterase',
#   'BDNF': 'brain-derived neurotrophic factor',
#   'CREB': 'cyclic AMP response element-binding protein',
#   'ERK': 'extracellular signal-regulated kinase',
#   'UPLC-Q-TOF-MS': 'Ultra Performance Liquid Chromatography-Quadrupole-Time-of-Flight Mass Spectrometry'},
#  '27313723': {'APL': 'Acute promyelocytic leukemia', 'ETV6': 'Ets variant 6'},
#  '27314527': {'VRFs': 'vascular risk factors'},
#  '27315396': {'lncRNAs': 'Long non-coding RNAs', 'OK': 'opossum kidney'},
#  '27315518': {'Ag NCs': 'Ag nanoclusters',
#   'QDs': 'quantum dots',
#   'PEC': 'photoelectrochemical',
#   'MB': 'molecular beacon'},
#  '27316920': {'DM': 'Diabetes mellitus',
#   'MRI': 'magnetic resonance imaging',
#   'HbA1c': 'hemoglobin A1c'},
#  '27317655': {},
#  '27318046': {'IVC': 'inferior vena cava', 'DVTs': 'deep vein thromboses'},
#  '27318131': {'IL-10R1': 'IL-10 receptor-1'},
#  '27319018': {},
#  '27320961': {'CYP': 'cytochrome P450'},
#  '27321599': {'SIR': 'standardized incidence ratio',
#   'CI': 'confidence interval'},
#  '27321745': {'BPA': 'Bisphenol-A'},
#  '27322135': {'SAXS': 'Small-Angle X-ray Scattering',
#   'CNTPs': 'Carbon nanotube porins'},
#  '27322774': {'PON2': 'Paraoxonase-2', 'OSCC': 'oral squamous cell cancer'},
#  '27323673': {},
#  '27324249': {},
#  '27325072': {},
#  '27326352': {},
#  '27326914': {'CTEPH': 'chronic thromboembolic pulmonary hypertension',
#   'PEA': 'pulmonary endarterectomy',
#   'PVR': 'pulmonary vascular resistance'},
#  '27328365': {},
#  '27329728': {'miRNAs': 'MicroRNAs',
#   'CRPC': 'castration resistant prostate cancer',
#   'ADPC': 'androgen dependent prostate cancer'},
#  '27330705': {'PDT': 'photodynamic therapy',
#   'PP': 'paper point',
#   'MB': 'methylene blue'},
#  '27330995': {'lncRNAs': 'long noncoding RNAs'},
#  '27331809': {},
#  '27332210': {'MISET': 'Mobile Information Support Evaluation Tool'},
#  '27332346': {},
#  '27332832': {'ACF': 'activated carbon fibre', 'AD': 'anaerobic digestion'},
#  '27333086': {'DO': 'dissolved oxygen'},
#  '27333594': {'NPC': 'nasopharyngeal carcinoma'},
#  '27335213': {'HUVECS': 'Human umbilical vein endothelial cells'},
#  '27336004': {'IBD': 'inflammatory bowel disease'},
#  '27336204': {'PFOA': 'Perfluorooctanoic acid',
#   'PAC': 'powdered activated carbon'},
#  '27336882': {'nAIGA': 'Neutralizing anti-interferon-γ autoantibody'},
#  '27337704': {},
#  '27337992': {},
#  '27338295': {'WMD': 'weighted mean differences',
#   'HDL': 'high density lipoprotein',
#   'LDL': 'low density lipoprotein'},
#  '27338347': {},
#  '27338437': {'FENO': 'fraction of exhaled nitrogen oxide'},
#  '27338800': {'HCC': 'hepatocellular carcinoma',
#   'VEGF-A': 'vascular endothelial growth factor-A'},
#  '27339000': {'PA': 'physical activity'},
#  '27339306': {},
#  '27340141': {'IG': 'inducing graft'},
#  '27340160': {'APC': 'adhesive precoated',
#   'SBS': 'shear bond strength',
#   'ARI': 'adhesive remnant index'},
#  '27340862': {'CSCs': 'cancer stem cells',
#   'CETCs': 'circulating epithelial tumor cells'},
#  '27340878': {'POAG': 'primary open-angle glaucoma',
#   'KNHANES': 'Korean National Health and Nutrition Examination Survey'},
#  '27341373': {},
#  '27342305': {'PAT': 'Psychosocial Assessment Tool'},
#  '27342342': {},
#  '27343757': {'PC': 'pancreatic cancer'},
#  '27344476': {},
#  '27344620': {'YFS': 'Young Finns Study',
#   'FLEED': 'Finnish Longitudinal Employer-Employee Data'},
#  '27345009': {'miRNAs': 'MicroRNAs'},
#  '27345138': {'HRP': 'horseradish peroxidase'},
#  '27347474': {'ACA': 'Affordable Care Act'},
#  '27347631': {},
#  '27347943': {'DBP': 'dibutyl phthalate', 'PAEs': 'phthalate esters'},
#  '27348135': {'HF': 'heart failure', 'CV': 'cardiovascular'},
#  '27348352': {},
#  '27348517': {'B1R': 'B1 receptor',
#   'B1R+': 'B1R-positive',
#   'B1R-': 'B1R-negative'},
#  '27348576': {},
#  '27348675': {},
#  '27349310': {'REST': 'repressor element-1 silencing transcription factor',
#   'GnRH': 'gonadotropin hormone releasing hormone'},
#  '27349321': {},
#  '27351590': {'VDR': 'Vitamin D receptor',
#   'RXR': 'retinoid X receptor',
#   'VDIR': 'VDR-interacting repressor'},
#  '27351941': {'DM': 'Diabetes mellitus',
#   'STZ': 'streptozotocin',
#   'COX-2': 'cyclooxygenase-2'},
#  '27352045': {},
#  '27352133': {'NRV': 'Natural Referent Vowel'},
#  '27352367': {'ACF': 'anterior cervical fusion',
#   'PCF': 'posterior cervical fusion',
#   'CSM': 'cervical spondylotic myelopathy',
#   'CI': 'confidence interval'},
#  '27353925': {},
#  '27354631': {'CyD': 'cytochalasin D'},
#  '27355258': {'DGCG': 'Danish gynaecological cancer group'},
#  '27356151': {},
#  '27356448': {},
#  '27356936': {},
#  '27357243': {'RCC': 'Renal cell carcinoma',
#   'ccRCC': 'clear cell RCC',
#   'PE': 'phosphatidylethanolamine'},
#  '27357530': {},
#  '27358560': {'nHAp': 'Nanohydroxyapatite',
#   'MWCNTs': 'multi-walled carbon nanotubes',
#   'GO': 'graphene oxide',
#   'TEM': 'transmission electron microscopy'},
#  '27358636': {'ADC': 'apparent diffusion coefficient'},
#  '27359086': {'IBPs': 'ice-binding proteins'},
#  '27359178': {'SNS': 'sympathetic nervous system',
#   'NZW': 'New Zealand white rabbits'},
#  '27359321': {'LTCs': 'long term conditions'},
#  '27362260': {'S': 'social', 'EPS': 'exopolysaccharides'},
#  '27363212': {'ARDS': 'acute respiratory distress syndrome'},
#  '27364994': {'FIB': 'faecal indicator bacteria',
#   'EPA': 'Environmental Protection Agency'},
#  '27365044': {},
#  '27367915': {},
#  '27371349': {},
#  '27371352': {},
#  '27371625': {'CHEER': 'Creating Healthcare Excellence through Education and Research'},
#  '27371818': {'PSIs': 'Patient-specific instruments',
#   'CT': 'computed tomography'},
#  '27371870': {'PVA': 'Poly(vinyl alcohol)'},
#  '27373648': {},
#  '27373689': {'pstA': 'prestalk A', 'omt12': 'o-methyl transferase 12 gene'},
#  '27373836': {},
#  '27373893': {'ACPA(+)/RF(+)': 'ACPA/RF double-seropositive'},
#  '27374109': {},
#  '27374326': {'TPC': 'total phenolic conten t',
#   'HPLC': 'high performance liquid chromatography'},
#  '27374484': {'PBL': 'Plasmablastic lymphoma',
#   'PCM': 'plasma cell myeloma',
#   'VCD': 'vincristine, cyclophosphamide, dexamethasone',
#   'IHC': 'Immunohistochemistry',
#   'ISH': 'in situ hybridization'},
#  '27374919': {},
#  '27375283': {},
#  '27375428': {'HP': 'hyperbaric pressure',
#   'HPNS': 'High Pressure Neurological Syndrome',
#   'CNS': 'central nervous system',
#   'NMDAR': 'N-methyl-D-aspartate receptor',
#   'ANOVA': 'analysis of variance'},
#  '27375491': {'MMP-9': 'matrix metalloproteinase-9',
#   'CAD': 'coronary artery disease',
#   'CIs': 'confidence intervals'},
#  '27376349': {'CAS': 'Concentrated agave sap'},
#  '27377502': {'GWAS': 'genome-wide association studies',
#   'T2DM': 'type 2 diabetes mellitus',
#   'SNPs': 'single nucleotide polymorphisms'},
#  '27378064': {},
#  '27379201': {'IR': 'ionizing radiation',
#   'DSBs': 'double strand breaks',
#   'CAs': 'chromosomal aberrations',
#   'TC-FISH': 'telomere / centromere - fluorescence in situ hybridization',
#   'RDE': 'relative dose effect "'},
#  '27380733': {'DCE-MRI': 'dynamic contrast-enhanced magnetic resonance imaging',
#   'RCC': 'renal cell carcinoma',
#   'ICCs': 'intra-class correlation coefficients',
#   'CoV': 'coefficient of variation'},
#  '27381582': {'CNPs': 'chitosan nanoparticles',
#   'STZ': 'streptozotocin',
#   'FTIR': 'Fourier Transform Infrared Spectroscopy',
#   'XRD': 'X-ray Diffraction',
#   'TEM': 'Transmission Electron Microscopy',
#   'DLS': 'Dynamic Light Scattering',
#   'SGOT': 'serum glutamic oxaloacetic transaminase',
#   'SGPT': 'serum glutamic pyruvic transaminase',
#   'ALP': 'alkaline phosphatases',
#   'CAT': 'catalase',
#   'SOD': 'superoxide dismutase'},
#  '27381890': {},
#  '27382354': {'TREK-2': 'TWIK-related K(+) channel-2',
#   'TRESK': 'TWIK-related spinal cord K(+)'},
#  '27382380': {'TBI': 'total-body γ irradiation'},
#  '27383484': {'DPPH': '1,1-diphenyl-2-picrylhydrazyl',
#   'TBA': 'thiobarbituric acid'},
#  '27383496': {},
#  '27383575': {'APP': 'Amyloid Precursor Proteins',
#   'AD': "Alzheimer's disease"},
#  '27384095': {},
#  '27384243': {'TNF': 'tumor necrosis factor'},
#  '27384421': {'PDAC': 'pancreatic ductal adenocarcinoma',
#   'PDX': 'patient-derived xenografts'},
#  '27385839': {},
#  '27386169': {},
#  '27387057': {'GDH': 'Glutamate dehydrogenase',
#   'HTS': 'high-throughput screening'},
#  '27387068': {},
#  '27387187': {'GCH': 'giant cavernous hemangiomas',
#   'RFA': 'radiofrequency ablation'},
#  '27389043': {},
#  '27389831': {'PD': "Parkinson's disease", 'DLB': 'Dementia with Lewy Bodies'},
#  '27390714': {},
#  '27391139': {},
#  '27391263': {'mCRPC': 'metastatic castration-resistant prostate cancer',
#   'CTCs': 'circulating tumor cells'},
#  '27391754': {},
#  '27392010': {},
#  '27392380': {'IC': 'indirect calorimeter',
#   'NCI': 'normal classroom instruction',
#   'ACI': 'active classroom instruction',
#   'EE': 'energy expenditure'},
#  '27392483': {'HCV': 'hepatitis C virus',
#   'SCD': 'stearoyl-CoA desaturase',
#   'LCMUFA': 'long-chain mono-unsaturated fatty acid'},
#  '27392509': {'MSI': 'myocardial salvage index',
#   'STEMI': 'ST-Segment Elevation Myocardial Infarction',
#   'LV': 'left ventricular',
#   'CK-MB': 'creatine kinase-MB',
#   'AUC': 'area under the curve',
#   'TnI': 'troponin I'},
#  '27393252': {'PD': "Parkinson's disease",
#   'STN': 'subthalamic nucleus',
#   'LFPs': 'local field potentials',
#   'EMGs': 'electromyograms',
#   'AR': 'akinetic-rigid',
#   'TD': 'tremor-dominant'},
#  '27393884': {},
#  '27394010': {'MIC': 'Minimum inhibitory concentration'},
#  '27394375': {'TSC': 'tuberous sclerosis complex'},
#  '27395220': {},
#  '27395784': {'HPA': 'hypothalamic pituitary adrenal',
#   'CRH': 'corticotropin releasing hormone',
#   'LH': 'lateral hypothalamus',
#   'PTZ': 'pentylenetetrazol',
#   'CRT': 'corticosterone'},
#  '27397797': {'GPA': 'Generalized procrustes analysis',
#   'PCA': 'principal component analysis',
#   'BMI': 'body mass index'},
#  '27398974': {'Hyal-2': 'hyaluronidase-2'},
#  '27399065': {'HBV': 'hepatitis B virus',
#   'HBeAg +': 'hepatitis B e antigen',
#   'CYP': 'cytochrome P450'},
#  '27399557': {'AVM': 'arteriovenous malformation',
#   'IQR': 'interquartile range'},
#  '27399732': {},
#  '27399843': {'RGCs': 'retinal ganglion cells',
#   'mTOR': 'mammalian target of rapamycin'},
#  '27399912': {'OSCC': 'Oral squamous cell carcinoma'},
#  '27400764': {'EMR': 'electronic medical records'},
#  '27404405': {'AM': 'antemortem'},
#  '27404466': {'DON': 'Dissolved organic nitrogen',
#   'N': 'nitrogen',
#   'DOM': 'dissolved organic matter',
#   'EEM': 'excitation-emission matrix',
#   'PARAFAC': 'parallel factor analysis',
#   'PCA': 'principle components analysis'},
#  '27405322': {'HRQoL': 'health-related quality of life',
#   'EORTC': 'European Organisation for Research and Treatment of Care'},
#  '27405584': {'ADC': 'apparent diffusion coefficient',
#   'PCa': 'prostate cancer',
#   'mpMRI': 'multiparametric magnetic resonance imaging'},
#  '27405997': {},
#  '27406386': {'RT-PCR': 'Reverse transcription polymerase chain reaction'},
#  '27406705': {'PGA': 'Polyglycolic acid'},
#  '27408447': {},
#  '27408908': {'hPTMs': 'histone post-translational modifications',
#   'FFPE': 'formalin-fixed paraffin-embedded'},
#  '27409644': {},
#  '27409657': {},
#  '27409663': {'HDACIs': 'Histone deacetylase inhibitors'},
#  '27410251': {'ICEP': 'Infant Caregiver and Engagement Phases',
#   'EPDS': 'Edinburgh Postnatal Depression Scale',
#   'STAI': 'State-Trait Anxiety Inventory',
#   'PSI-SF': 'Parenting Stress Index-Short Form'},
#  '27411238': {'FDA': 'Food and Drug Administration'},
#  '27411493': {'UCd': 'urinary cadmium',
#   'ILCR': 'incremental lifetime cancer risk',
#   'HQ': 'hazard quotient',
#   'OR': 'odds ratio',
#   'CI': 'confidence interval'},
#  '27411686': {},
#  '27412144': {'ESUS': 'embolic stroke of undetermined source'},
#  '27412526': {'OA': 'osteoarthritis',
#   'QST': 'quantitative sensory testing',
#   'CPM': 'conditioned pain modulation'},
#  '27412534': {'LDL': 'low-density lipoprotein'},
#  '27413146': {'CPP': 'centro-parietal positivity'},
#  '27413283': {'GI': 'gastrointestinal'},
#  '27413416': {'TRAP': 'traffic - related pollutants'},
#  '27414407': {},
#  '27415757': {'KT': 'knowledge translation'},
#  '27416524': {},
#  '27417537': {},
#  '27418869': {'DREEM': 'Dundee Ready Education Environment Measure',
#   'DASS': 'Depression Anxiety Stress Scale'},
#  '27420101': {'ABU': 'Asymptomatic bacteriuria',
#   'E. coli': 'Escherichia coli',
#   'Pol II': 'polymerase II',
#   'WT': 'wild type'},
#  '27421268': {'SWAT': 'Study Within A Trial'},
#  '27421843': {'SAC': 'Serrated colorectal adenocarcinoma',
#   'CRC': 'colorectal cancer',
#   'CRCs': 'carcinomas',
#   'VEGF': 'vascular endothelial growth factor',
#   'MVD': 'microvascular density',
#   'SPs': 'serrated polyps',
#   'NSAs': 'non-serrated adenomas',
#   'VHL': 'Von Hippel-Lindau'},
#  '27422009': {'AMA1': 'apical membrane antigen 1',
#   'RON2': 'rhoptry neck protein 2'},
#  '27422142': {'Hib': 'Haemophilus influenzae type b',
#   'CSF': 'cerebrospinal fluid'},
#  '27422367': {},
#  '27422746': {'LDL-C': 'low-density lipoprotein cholesterol',
#   'apo': 'apolipoprotein'},
#  '27423282': {'HNR': 'Harmonic to noise ratio',
#   'NNE': 'Normalized noise energy'},
#  '27423415': {'LAB': 'lactic acid bacteria',
#   'MS': 'mass spectrometry',
#   'L. plantarum': 'Lactobacillus plantarum'},
#  '27423449': {},
#  '27424514': {'D&A': 'Disrespect and abuse'},
#  '27426278': {'JSIM': 'Japanese Society of Internal Medicine'},
#  '27426713': {'PAHS': 'Patan Academy of Health Sciences',
#   'CBLE': 'community based learning and education',
#   'MSSC': 'Medical School Steering Committee',
#   'CHS': 'Community Health Sciences'},
#  '27426888': {},
#  '27429532': {'AIMF': 'Autoimmune myelofibrosis',
#   'SLE': 'systemic lupus erythematosus'},
#  '27430924': {},
#  '27431445': {},
#  '27431623': {},
#  '27432227': {'ALK': 'anaplastic lymphoma kinase'},
#  '27433916': {'IPMN': 'intraductal papillary mucinous neoplasms',
#   'NGS': 'next-generation sequencing',
#   'HGD': 'high-grade dysplasia'},
#  '27433933': {'KD': 'Kawasaki disease',
#   's-JIA': 'systemic juvenile idiopathic arthritis',
#   'IVIG': 'intravenous immunoglobulin',
#   'PE': 'plasma exchange'},
#  '27434112': {},
#  '27435336': {'HAV': 'hepatitis A virus', 'ssRNA': 'single-stranded RNA'},
#  '27435702': {'HIV': 'human immunodeficiency virus',
#   'SAEs': 'serious adverse events',
#   'RCR': 'replication competent retrovirus'},
#  '27435854': {'H2AX': 'γH2AX'},
#  '27436024': {'FA': 'fractal analysis',
#   'MRI': 'magnetic resonance imaging',
#   'CMD': 'coronary microvascular dysfunction',
#   'CAD': 'coronary artery disease'},
#  '27436292': {},
#  '27436508': {},
#  '27436784': {'BWS': 'Beckwith-Wiedemann syndrome', 'IC': 'imprinting center'},
#  '27437046': {'PHRs': 'Personal health records'},
#  '27437094': {},
#  '27438188': {'CMR': 'cardiac magnetic resonance'},
#  '27438230': {'IG-IMRT': 'image-guided intensity-modulated radiotherapy'},
#  '27438403': {'ECD': 'electronic circular dichroism'},
#  '27438523': {},
#  '27439307': {'MscL': 'mechanosensitive channels'},
#  '27439396': {'CIED': 'cardiac implantable electronic devices'},
#  '27439518': {'TIM-3': 'T cell Ig and mucin protein-3',
#   'DCs': 'dendritic cells'},
#  '27439969': {'SCFA': 'short-chain fatty acids',
#   'BMI': 'body mass index',
#   'PYY': 'peptide YY',
#   'TNF-α': 'tumour necrosis factor-α'},
#  '27440478': {},
#  '27441491': {'FB': 'foreign body'},
#  '27441911': {'SNR': 'signal-to-noise ratio'},
#  '27442261': {},
#  '27442448': {'MF': 'magnetic field',
#   'EGFR': 'epidermal growth factor receptor',
#   'ROS': 'reactive oxygen species'},
#  '27443244': {'NRPS': 'non-ribosomal peptide synthetase',
#   'AMPA': '3-amino-2-methylpropionic acid'},
#  '27443945': {},
#  '27445300': {'NIRS': 'near infrared spectroscopy'},
#  '27445319': {'SSF': 'solid state fermentation'},
#  '27445402': {},
#  '27445435': {'IFN-': 'Interferon-',
#   'CSU': 'chronic spontaneous urticaria',
#   'HC': 'healthy control',
#   'ICAM-': 'anti-intercellular adhesion molecule-'},
#  '27445865': {'AVHs': 'Auditory-verbal hallucinations',
#   'fMRI': 'functional magnetic resonance imaging'},
#  '27446048': {},
#  '27446224': {},
#  '27446232': {'DSA': 'digital subtraction angiography',
#   'CBF': 'cerebral blood flow',
#   'CBV': 'cerebral blood volume',
#   'MTT': 'mean transit time',
#   'TTP': 'time-to-peak',
#   'tPA': 'tissue plasminogen activator'},
#  '27446579': {'HE4': 'Human epididymis protein 4'},
#  '27446852': {},
#  '27446916': {'PCa': 'Prostate cancer',
#   'ECM': 'extracellular matrix',
#   'GEMM': 'genetically engineered mouse models',
#   'PDXs': 'patient derived xenografts',
#   'TICs': 'tumor initiating cells',
#   'HIS': 'human immune system',
#   'CAR': 'chimeric antigen receptor-'},
#  '27447000': {'FDPs': 'fixed dental prostheses'},
#  '27447421': {'WBV': 'Whole blood viscosity', 'RBC': 'red blood cell'},
#  '27447827': {'MDCT': 'multi detector computed tomography',
#   'FBP': 'filtered backprojection',
#   'SIR': 'statistical iterative reconstruction'},
#  '27449676': {},
#  '27449845': {},
#  '27450703': {'CFA': "complete Freund's adjuvant"},
#  '27451934': {},
#  '27452398': {'EGCG': 'epigallocatechin-3-gallate',
#   'EMT': 'epithelial mesenchymal transition',
#   'siRNA': 'small interfering RNA'},
#  '27452974': {'bTB': 'Bovine tuberculosis'},
#  '27453359': {'SPLCV': 'sweet potato leaf curl virus'},
#  '27453556': {},
#  '27454066': {'CPR': 'cardiopulmonary resuscitation',
#   'LV': 'left ventricular',
#   'CI': 'confidence interval'},
#  '27454252': {'SCD': 'Sudden cardiac death',
#   'ICD': 'implantable cardioverter-defibrillators',
#   'ECG': 'electrocardiogram',
#   'CHD': 'coronary heart disease'},
#  '27454379': {},
#  '27454637': {'CSA': 'Cross-sectional area'},
#  '27456016': {'FLC': 'Fibrolamellar carcinoma',
#   'HCC': 'hepatocellular carcinoma',
#   'AJCC': 'American Joint Committee on Cancer',
#   'OS': 'overall survival',
#   'RFS': 'recurrence-free survival'},
#  '27456062': {'sc': 'self-complementary'},
#  '27457924': {'pfu': 'plaque-forming units',
#   'IFV': 'influenza virus',
#   'BDD': 'boron-doped diamond'},
#  '27457997': {},
#  '27459060': {},
#  '27459296': {'HNSCC': 'head and neck squamous cell carcinoma'},
#  '27460729': {'READ': 'rectal adenocarcinoma',
#   'TCGA': 'The Cancer Genome Atlas',
#   'FDR': 'False discovery rate',
#   'DEGs': 'differentially expressed genes'},
#  '27461500': {},
#  '27461771': {'CCIP': 'Chelation competition induced polymerization'},
#  '27463423': {},
#  '27464574': {'OBVT': 'office-based vision therapy',
#   'CI': 'convergence insufficiency',
#   'CISS': 'Convergence Insufficiency Symptom Survey'},
#  '27464911': {'DARS': 'decade of action for road safety 2010-2020'},
#  '27465008': {'EDs': 'emergency departments'},
#  '27465497': {},
#  '27465939': {'ASC': 'Adipose-derived stromal cell',
#   'MSCs': 'mesenchymal stem cells',
#   'PCa': 'prostate cancer',
#   'miRNA': 'microRNA',
#   'CM': 'conditioned medium'},
#  '27466243': {},
#  '27467147': {'CE': 'Cystic Echinococcosis'},
#  '27467251': {},
#  '27467556': {'AmBd': 'amphotericin B deoxycholate',
#   'Hb': 'hemoglobin',
#   'Cr': 'creatinine'},
#  '27467766': {'BP': 'blood pressure'},
#  '27467869': {'FNA': 'fine-needle aspiration'},
#  '27468236': {'SSRIs': 'selective serotonin reuptake inhibitors'},
#  '27468821': {'MEPs': 'motor end plates', 'ESN': 'end-to-side neurorrhaphy'},
#  '27468990': {},
#  '27469526': {'EZ': 'epileptogenic zone',
#   'SEEG': 'stereoelectroencephalography',
#   'BTLE': 'bilateral mesial temporal lobe epilepsy',
#   'UTLE': 'unilateral mesial temporal lobe epilepsy'},
#  '27470706': {'HRQoL': 'health related quality of life',
#   'SF-36': 'short form-36'},
#  '27470998': {'EC': 'endometrial cancer'},
#  '27471103': {},
#  '27472704': {'CTO': 'chronic total occlusion',
#   'HR': 'hazard ratio',
#   'CI': 'confidence interval'},
#  '27473602': {},
#  '27474829': {},
#  '27475106': {'NMDAR': 'N-methyl-D-aspartate receptor',
#   'KMO': 'kynurenine-3-monooxygenase',
#   'ADE': 'alcohol deprivation effect'},
#  '27475688': {},
#  '27476158': {},
#  '27476625': {'JIA': 'juvenile idiopathic arthritis'},
#  '27476670': {},
#  '27476889': {},
#  '27478557': {},
#  '27479458': {},
#  '27479571': {'GlcCer': 'glucosylceramide',
#   'SdeA': 'sphingolipid Δ8-desaturase',
#   'GcsA': 'glucosylceramide synthase'},
#  '27479867': {},
#  '27479943': {},
#  '27480160': {},
#  '27480504': {'CHE': 'Chronic hand eczema',
#   'TSLP': 'thymic stromal lymphopoietin'},
#  '27480530': {},
#  '27481186': {'DDAC': 'didecyl dimethyl ammonium chloride',
#   'MIC': 'minimum inhibitory concentration',
#   'BC': 'benzalkonium chloride'},
#  '27481342': {},
#  '27481810': {},
#  '27481881': {},
#  '27481907': {'SSc': 'systemic sclerosis',
#   'ILD': 'interstitial lung disease',
#   'ESLD': 'endstage lung disease',
#   'FVC': 'forced vital capacity'},
#  '27482315': {'IJV': 'internal jugular vein',
#   'ESRD': 'end stage renal disease',
#   'CA': 'carotid artery',
#   'KT': 'kidney transplantation'},
#  '27482676': {'CO': 'corn oil',
#   'FFA': 'free fatty acids',
#   'AME': 'apparent ME'},
#  '27483491': {'HiAER': 'hierarchical address-event routing'},
#  '27484439': {},
#  '27484988': {'IMF': 'inframammary fold', 'VSS': 'Vancouver scar scale'},
#  '27485101': {'miRNAs': 'microRNAs',
#   'miR-26a': 'microRNA-26a',
#   'TAAC': 'transverse abdominal aortic constriction',
#   'Ang II': 'angiotensin II',
#   'CMs': 'cardiomyocytes',
#   'HW': 'heart weight',
#   'BW': 'body weight',
#   'ANF': 'atrial natriuretic factor',
#   'GATA4': 'GATA-binding protein 4',
#   'UTR': "3'-untranslated region"},
#  '27485594': {'cAMP': 'cyclic AMP',
#   'GPCR': 'G protein-coupled receptor',
#   'PKA': 'protein kinase A',
#   'PPIs': 'protein:protein interactions',
#   'PCA': 'protein-fragment complementation assay'},
#  '27485707': {'PSA': 'prostate-specific antigen',
#   'ROC': 'receiver operating characteristic'},
#  '27485749': {'REM': 'Rapid eye movement',
#   'OB': 'olfactory bulb',
#   'A2AR': 'A2A receptors'},
#  '27485947': {},
#  '27486082': {'XCI': 'X Chromosome inactivation',
#   'mESCs': 'mouse embryonic stem cells'},
#  '27486825': {},
#  '27486953': {'PNSC': 'psychogenic nonsyncopal collapse',
#   'PNES': 'psychogenic nonepileptic seizures'},
#  '27489089': {},
#  '27489143': {},
#  '27489312': {'ERF': 'ethylene responsive transcription factor'},
#  '27489713': {'EBUS-TBNA': 'endobronchial ultrasound with transbronchial needle aspiration'},
#  '27489735': {'PDE5i': 'phosphodiesterase type 5 inhibitor'},
#  '27490343': {},
#  '27490448': {'ADC': 'apparent diffusion coefficient'},
#  '27490927': {'APCs': 'antigen-presenting cells',
#   'TLR': 'Toll-like Receptors',
#   'NOD2': 'nucleotide-binding oligomerization domain-containing protein 2',
#   'ERAD': 'ER-associated degradation'},
#  '27491394': {},
#  '27492044': {'IA': 'image analysis',
#   'HP': 'hyperplastic polyps',
#   'TA': 'tubular adenomas',
#   'HGD': 'high-grade dysplasia',
#   'IFD': 'indefinite for dysplasia',
#   'LGD': 'low-grade dysplasia',
#   'PPC': 'positive pixel count'},
#  '27493011': {},
#  '27493840': {'AUC': 'area under the curve'},
#  '27493925': {'GTE': 'green tea extract'},
#  '27494870': {'TEM-1': 'Tumor Endothelial Marker-1',
#   'mAb': 'monoclonal antibody',
#   'ECD': 'extracellular domain',
#   'sEND': 'soluble endosialin/TEM-1'},
#  '27494903': {},
#  '27494906': {'FQ': 'fluoroquinolone'},
#  '27494907': {'ECC': 'Enterobacter cloacae complex'},
#  '27494909': {'BAP': 'bone-specific alkaline phosphatase'},
#  '27496388': {'EMTALA': 'Emergency Medical Treatment and Labor Act',
#   'ED': 'emergency department'},
#  '27496995': {'PCR': 'principal component regression',
#   'MLPCR': 'maximum likelihood PCR',
#   'iid': 'independently and identically distributed'},
#  '27498027': {'NF-Y': 'NUCLEAR FACTOR-Y'},
#  '27498099': {},
#  '27498545': {'PAC': 'patient cases',
#   'UC': 'urothelial carcinoma',
#   'PSA': 'prostate-specific antigen',
#   'PSMA': 'prostate-specific membrane antigen',
#   'PAP': 'prostate acid phosphatase',
#   'AMACR': 'and α-methylacyl coenzyme A racemase'},
#  '27498569': {},
#  '27499974': {'OSAS': 'obstructive sleep apnea syndrome',
#   'AHI': 'apnea-hypopnea index',
#   'RDI': 'Respiratory Disturbance Indexes'},
#  '27500005': {'ETA': 'Extradural temporopolar approach',
#   'SOF': 'trans-superior orbital fissure',
#   'CS': 'cavernous sinus',
#   'FR': 'foramen rotundum',
#   'FO': 'foramen ovale'},
#  '27500434': {'NSAIDs': 'Nonsteroidal anti-inflammatory drugs'},
#  '27501756': {'lncRNAs': 'long noncoding RNAs',
#   'NSCLC': 'non-small cell lung cancer',
#   'XIST': 'X inactivate-specific transcript',
#   'RIP': 'RNA immune-precipitation'},
#  '27502245': {'OA': 'osteoarthritis',
#   'MCM': 'macrophage conditioned medium',
#   'NO': 'nitric oxide',
#   'GAGs': 'glycosaminoglycans',
#   'MMP13': 'Matrix Metalloproteinase-13',
#   'ADAMTS5': 'A Disintegrin And Metalloproteinase with Thrombospondin Motifs-5',
#   'ACAN': 'aggrecan',
#   'SOCS1': 'Suppressor of cytokine signaling 1'},
#  '27503608': {'OCT': 'Optical Coherence Tomography'},
#  '27504260': {'miRNA': 'microRNA'},
#  '27504738': {'PEG-PLA': 'poly(ethylene glycol)2k-block-poly(d,l-lactide)2k'},
#  '27504849': {'SLN': 'sentinel lymph node', 'PBD': 'patent blue dye'},
#  '27505217': {'BMI': 'body mass index'},
#  '27505310': {},
#  '27505348': {},
#  '27505653': {},
#  '27506608': {'LTCF': 'long-term care facilities'},
#  '27507240': {'ACCase': 'acetyl-CoA carboxylase'},
#  '27508384': {'BC': 'Breast Cancer',
#   'SPB': 'serum protein biomarkers',
#   'TAAb': 'tumor associated autoantibodies',
#   'BBD': 'Benign Breast Disease'},
#  '27508468': {},
#  '27508512': {'IFX': 'infliximab', 'ADA': 'adalimumab'},
#  '27510556': {'MI': 'myocardial infarction'},
#  '27511214': {'TMD': 'temporomandibular disorders',
#   'RDC': 'research diagnostic criteria',
#   'SD': 'standard deviation'},
#  '27511635': {'COS': 'carbonyl sulfide'},
#  '27512256': {},
#  '27512352': {'MPV': 'mean platelet volume'},
#  '27512369': {'PANSS': 'Positive and Negative Syndrome Scale'},
#  '27512378': {},
#  '27513632': {'miR': 'MicroRNA',
#   'EMT': 'epithelial-mesenchymal transition',
#   'HMGA2': 'High mobility group AT-hook 2',
#   'IPF': 'idiopathic pulmonary fibrosis',
#   'HBE': 'human bronchial epithelium',
#   'TGF‑β1': 'transforming growth factor‑β1',
#   'BLM': 'bleomycin'},
#  '27514440': {'LCNF': 'lignocellulose nanofibers',
#   'OWP': 'Organosolv wheat pulp',
#   'KWP': 'Kraft wheat pulp',
#   'SWP': 'Soda wheat pulp'},
#  '27514572': {'BDNF': 'brain-derived neurotrophic growth factor',
#   'HPA': 'hypothalamic pituitary axis',
#   'OCDS': 'Obsessive and Compulsive Drinking Scale'},
#  '27514644': {'SCI': 'Spinal cord injury',
#   'PSMB4': 'Proteasome beta-4 subunit',
#   'MLKL': 'Mixed lineage kinase domain-like protein',
#   'TNF-α': 'Tumor necrosis factor-α'},
#  '27514764': {},
#  '27515243': {'ASL': 'Argininosuccinic acid lyase'},
#  '27515250': {},
#  '27515303': {'LS': 'levator scapulae', 'MR': 'magnetic resonance'},
#  '27515307': {'ESC': 'Endometrial stromal cells',
#   'MPA': 'medroxyprogesterone acetate',
#   'NETA': 'norethisterone acetate',
#   'DNG': 'dienogest',
#   'MCP': 'monocyte chemotactic protein'},
#  '27515958': {'IP': 'Intestinal Permeability', 'ALD': 'Alcohol Liver Disease'},
#  '27516253': {'MFA': 'monomethyl fumaric acid',
#   'EDC': '1-ethyl-3-(3-dimethylaminopropyl) carbodiimide',
#   'DMSO': 'dimethyl sulfoxide',
#   'DMF': 'dimethyl formamide'},
#  '27516356': {'TACE': 'transarterial chemoembolization',
#   'HCC': 'hepatocellular carcinoma',
#   'sPVTT': 'subsegmental portal vein tumour thrombus',
#   'OS': 'overall survival',
#   'SAEs': 'serious adverse events',
#   'IPTW': 'inverse probability of treatment weighting',
#   'BCLC': 'Barcelona Clinic Liver Cancer',
#   'HR': 'hazard ratio'},
#  '27516476': {'SAT': 'subcutaneous adipose tissue',
#   'mtDNA': 'mitochondrial DNA'},
#  '27518506': {},
#  '27519262': {'PITC': 'provider -initiated HIV testing and counseling',
#   'OPD': 'outpatient department'},
#  '27519675': {'ACL': 'anterior cruciate ligament',
#   'CPT': 'Current Procedural Terminology',
#   'ORs': 'odds ratios',
#   'NSAIDs': 'nonsteroidal anti-inflammatory drugs',
#   'NNH': 'number needed to harm'},
#  '27521295': {'POPs': 'persistent organic pollutants', 'OC': 'organochlorine'},
#  '27521418': {'MI': 'myocardial infarction',
#   'D': 'day',
#   'LV': 'left ventricle'},
#  '27521980': {},
#  '27522061': {'ELSA': 'English Longitudinal Study of Aging',
#   'HRS': 'Health and Retirement Study',
#   'MHAS': 'Mexican Health and Aging Study'},
#  '27522512': {},
#  '27524991': {},
#  '27528428': {'ABA': 'and by abscisic acid'},
#  '27528471': {'OR': 'odds ratio', 'CI': 'confidence interval'},
#  '27528862': {'CPB': 'cardiopulmonary bypass', 'MS': 'mass spectrometry'},
#  '27529866': {'CBG': 'cinobufagin',
#   'DCs': 'dendritic cells',
#   'AMPs': 'antimicrobial peptides'},
#  '27530243': {'OLVG': 'Onze Lieve Vrouwe Gasthuis'},
#  '27530333': {'CAD': 'coronary artery disease',
#   'Lp(a)': 'lipoprotein(a)',
#   'AAs': 'African-Americans',
#   'TCP': 'Total coronary plaque'},
#  '27530547': {},
#  '27531288': {},
#  '27532819': {'scCRISPR': 'Self-cloning CRISPR/Cas9'},
#  '27533056': {'ACS': 'acute coronary syndrome'},
#  '27533082': {'WT p53': 'wild type p53'},
#  '27533383': {},
#  '27533420': {},
#  '27534108': {},
#  '27534355': {},
#  '27534961': {},
#  '27535101': {},
#  '27536134': {},
#  '27536472': {},
#  '27537530': {'PE': 'pulmonary embolism'},
#  '27538344': {'CSAQ': "Children's Sleep Assessment Questionnaire"},
#  '27538473': {'TD': 'typically developed'},
#  '27539002': {},
#  '27542164': {},
#  '27543896': {'ICAWSs': 'intersection collision avoidance warning systems',
#   'RLR': 'red light running'},
#  '27544735': {'RGO': 'reduced graphene oxide'},
#  '27544871': {'QI': 'quality improvement'},
#  '27545082': {'TD': 'typically-developing',
#   'SCP': 'spastic cerebral palsy',
#   'MTU': 'musculo-tendinous unit'},
#  '27545399': {},
#  '27545685': {'PD': "Parkinson's disease",
#   'SNPs': 'single nucleotide polymorphisms'},
#  '27545829': {'hPP': 'Human pancreatic polypeptide',
#   'PEGs': 'polyethylene glycols',
#   'PEG': 'PEG22'},
#  '27546025': {'TDM': 'therapeutic drug monitoring'},
#  '27546724': {'SMC': 'subjective memory complaints'},
#  '27547341': {},
#  '27547432': {},
#  '27547536': {'FVEPs': 'Flash Visual Evoked Potentials'},
#  '27548784': {'WR': 'Wearable resistance',
#   'BM': 'body mass',
#   'F-v': 'force-velocity'},
#  '27548895': {'VI': 'visual impairment', 'IN': 'infantile nystagmus'},
#  '27550556': {'HLE': 'home literacy environment'},
#  '27551182': {},
#  '27551242': {'MS': 'multiple sclerosis',
#   'PSG': 'polysomnography',
#   'MSLT': 'multiple sleep latency testing',
#   'FSS': 'Fatigue Severity Scale',
#   'ESS': 'Epworth Sleepiness Scale',
#   'VAS-F': 'visual analogue scale for fatigue',
#   'HADS': 'Hospital Anxiety and Depression Scale'},
#  '27552486': {'CAA': 'consecutive alternating administration',
#   'EV': 'enterovirus',
#   'MST': 'mean survival time'},
#  '27553121': {'eCB': 'endocannabinoid',
#   'EPM': 'elevated plus maze',
#   'AEA': 'amygdalar eCB anandamide',
#   '2-AG': '2-arachidonoylglycerol'},
#  '27553588': {'iWOB': 'imposed work of breathing',
#   'CPAP': 'continuous positive airway pressure'},
#  '27554678': {'ROS': 'reactive oxygen species',
#   'HRW': 'hydrogen -rich water',
#   'GPX': 'glutathione peroxidase',
#   'WT': 'wide-type'},
#  '27555478': {'NHE1': 'Na(+)/H(+) exchanger isoform 1'},
#  '27555654': {'LBDNet': 'Latin American Biological Dosimetry Network'},
#  '27555975': {},
#  '27556293': {'TN': 'trigeminal neuralgia',
#   'MVD': 'microvascular decompression',
#   'SRS': 'stereotactic radiosurgery'},
#  '27556586': {'CVL': 'canine visceral leishmaniasis',
#   'VL': 'visceral leishmaniasis',
#   'TNF': 'tumor necrosis factor',
#   'IFN': 'interferon'},
#  '27557464': {'TMJDs': 'Temporomandibular joint disorders',
#   'TMJ': 'temporomandibular joint',
#   'Di': 'dysfunction',
#   'MRI': 'magnetic resonance imaging'},
#  '27558728': {'DCVs': 'Dense-core vesicles'},
#  '27559131': {},
#  '27559330': {'REM': 'rapid eye movement'},
#  '27559734': {},
#  '27560368': {},
#  '27560647': {'LCDs': 'low-carbohydrate diets'},
#  '27561345': {},
#  '27562210': {'HCV': 'Hepatitis C virus',
#   'DAAs': 'direct antiviral agents',
#   'PCDs': 'polyanionic carbosilane dendrimers'},
#  '27563006': {'FC': 'fluorocitrate',
#   'GFAP': 'Glial fibrillary acidic protein',
#   'GLT-1': 'glutamate transporter 1'},
#  '27563616': {'DPSCs': 'dental pulp stem cells',
#   'SVF': 'stromal vascular fraction',
#   'PRF': 'platelet-rich fibrin'},
#  '27565266': {'ACC': 'American College of Cardiology',
#   'AHA': 'American Heart Association'},
#  '27565870': {'APRIL': 'A proliferation inducing ligand',
#   'BCMA': 'B-cell maturation antigen',
#   'TACI': 'transmembrane activator and CAML interactor',
#   'ASC': 'adipose-derived stem cell',
#   'bp': 'base pairs'},
#  '27565913': {'LD-CT': 'low-dose computed tomography',
#   'AUC': 'area under the curve'},
#  '27565983': {'SSH': 'suppression subtraction hybridization'},
#  '27566320': {},
#  '27567226': {'SS': "Sjögren's syndrome",
#   'MSG': 'minor salivary gland',
#   'SGEC': 'salivary gland epithelial cell',
#   'pSS': 'primary SS'},
#  '27567951': {'MRI': 'magnetic resonance imaging',
#   'TACE': 'trans-arterial chemoembolization',
#   'RECIST': 'Response Evaluation Criteria in Solid Tumor',
#   'mRECIST': 'modified RECIST'},
#  '27568025': {},
#  '27568206': {'GBM': 'Glioblastoma',
#   'PI3K': 'pathways is phosphatidylinositol-3 kinases',
#   'mTOR': 'mTOR-complex',
#   'GSK3β': 'glycogen synthase kinase 3 β'},
#  '27568582': {},
#  '27568672': {'CT': 'computed tomography',
#   'FISH': 'fluorescence in-situ hybridization'},
#  '27569032': {'LPN': 'lipid-polymer hybrid nanocarrier'},
#  '27569995': {'mGlu': 'metabotropic glutamate',
#   'TST': 'tail suspension test',
#   'FST': 'forced swim test',
#   'MWM': 'Morris water maze',
#   'PCPA': 'para-chlorophenylalanine'},
#  '27570556': {'BLInCs': 'blinking nanocapsules'},
#  '27570685': {'MRI': 'Magnetic Resonance Imaging',
#   'FA': 'fractional anisotropy'},
#  '27570938': {},
#  '27570955': {'BPD': 'Borderline personality disorder',
#   'fMRI': 'functional magnetic resonance imaging',
#   'ROI': 'regions of interest'},
#  '27570972': {'CNS': 'central nervous system'},
#  '27571264': {'dsDNA': 'double-stranded DNA',
#   'SLE': 'Systemic Lupus Erythematosus',
#   'FIDA': 'flow-induced dispersion analysis',
#   'TDA': 'Taylor dispersion analysis',
#   'CE': 'capillary electrophoresis'},
#  '27571385': {'S': 'sensitivity',
#   'SP': 'specificity',
#   'ROC': 'receiver operating characteristic'},
#  '27572614': {'BTAI': 'blunt thoracic aortic injury',
#   'TEVAR': 'thoracic endovascular aortic repair',
#   'OR': 'open repair',
#   'NOM': 'non-operative management'},
#  '27573199': {},
#  '27573470': {'Angptl4': 'Angiopoietin-like protein 4',
#   'HFD': 'high‑fat‑diet',
#   'adv': 'adenovirus'},
#  '27574277': {},
#  '27574814': {},
#  '27575716': {'PCSK9': 'Proprotein convertase subtilisin/kexin type-9',
#   'LDL': 'low-density lipoprotein',
#   'LDL-C': 'LDL cholesterol'},
#  '27576906': {},
#  '27576941': {},
#  '27577517': {'CT': 'computed tomography',
#   'CTA': 'CT angiography',
#   'DIEP': 'deep inferior epigastric perforator',
#   'ED': 'effective dose',
#   'CNR': 'contrast to noise ratio',
#   'MIP': 'maximum intensity projection',
#   'VR': 'volume rendering'},
#  '27577581': {'CONV-R': 'conventionally raised',
#   'AngII': 'angiotensin II',
#   'MCP-1': 'monocyte chemoattractant protein 1',
#   'iNOS': 'inducible nitric oxide synthase',
#   'Rorγt': 'receptor-related orphan receptor gamma t'},
#  '27577957': {'ATP': 'adenosine triphosphate',
#   'HMEC': 'human mammary epithelial cells'},
#  '27578611': {'HD': 'hemodialysis', 'PG': 'pepsinogen'},
#  '27578894': {},
#  '27578983': {'EGFR-TKI': 'EGFR-tyrosine kinase inhibitor',
#   'SCCL': 'squamous cell carcinoma of the lung',
#   'ID': 'intracellular domain',
#   'ECOG': 'Eastern Cooperative Oncology Group',
#   'PS': 'performance status',
#   'HR': 'hazard ratio'},
#  '27579316': {'miRNA': 'microRNA',
#   'GO': 'Gene Ontology',
#   'KEGG': 'Kyoto Encyclopedia of Genes and Genomes'},
#  '27580090': {'IVUS': 'intravascular ultrasound',
#   'OR': 'odds ratio',
#   'CI': 'confidence interval'},
#  '27580610': {'SLE': 'Systemic lupus erythematosus',
#   'HADS': 'Hospital Anxiety and Depression Scale'},
#  '27580729': {},
#  '27581464': {'Th17': 'T-helper 17',
#   'MS': 'multiple sclerosis',
#   'miRNA-seq': 'miRNA sequencing',
#   'EAE': 'experimental autoimmune encephalomyelitis',
#   'FDA': 'Food and Drug Administration'},
#  '27582109': {'DCI': 'd-chiroinositol',
#   'IPG': 'inositolphosphoglycan',
#   'IR': 'insulin resistance',
#   'PCOS': 'Polycystic ovary syndrome',
#   'FSH': 'follicle-stimulating hormone',
#   'LH': 'luteinizing hormone',
#   'CYP19A1': 'cytochrome P450 family 19 subfamily A member 1',
#   'P450scc': 'P450 side-chain cleavage',
#   'hGCs': 'human granulosa cells',
#   'IGF-1R': 'insulin-like growth factor 1 receptor'},
#  '27582170': {'SES': 'socioeconomic status'},
#  '27582280': {},
#  '27583127': {'hPSCs': 'human pluripotent stem cells',
#   'ER-α': 'estrogen receptor alpha'},
#  '27583405': {'NGS': 'next-generation sequencing',
#   'SNHL': 'sensorineural hearing loss'},
#  '27585079': {},
#  '27585205': {'CVD': 'cardiovascular diseases'},
# ...
#  '27652718': {'FPG': 'fasting plasma glucose'},
#  '27653143': {},
#  '27653361': {},
#  '27653616': {'32R': '3D / 2D image registration'},
#  '27654398': {'VVS': 'vasovagal syncope',
#   'LBNP': 'lower body negative pressure',
#   'P-NE': 'plasma norepinephrine'},
#  '27654842': {'SEER': 'Surveillance, Epidemiology, and End Results',
#   'CAHPS': 'Consumer Assessment of Healthcare Providers and Systems'},
#  '27655516': {'CART': 'cocaine- and amphetamine-regulated transcript'},
#  '27655678': {'MDSCs': 'Myeloid-derived-suppressor cells'},
#  '27655704': {'MBC': 'male breast cancer',
#   'FBC': 'female breast cancer',
#   'SEER': 'Surveillance, Epidemiology, and End Results',
#   'OS': 'overall survival',
#   'BCSM': 'breast cancer-specific mortality',
#   'HER2': 'human epidermal growth factor receptor 2',
#   'TN': 'triple-negative',
#   'HoR': 'hormone receptor'},
#  '27655998': {'VWF': 'von Willebrand factor',
#   'HTN': 'hypertension',
#   'ASHD': 'atherosclerotic heart disease',
#   'VWD': 'von Willebrand disease',
#   'MI': 'myocardial infarction',
#   'OR': 'odds ratio'},
#  '27656399': {'BAT': 'brown adipose tissue', 'WAT': 'white adipose tissue'},
#  '27656565': {'IAN': 'Inferior Alveolar Nerve'},
#  '27656567': {'GCF': 'Gingival Crevicular Fluid',
#   'T2DM': 'Type 2 Diabetes Mellitus'},
#  '27657099': {'REHCT': 'rational emotive hospice care therapy'},
#  '27657150': {'VLED': 'Very low energy diets',
#   'RDI': 'Recommended Dietary Intake',
#   'AI': 'adequate intake'},
#  '27658949': {'MR': 'magnetic resonance', 'SIS': 'small intestinal submucosa'},
#  '27659457': {'BP': 'blood pressure',
#   'MPI': 'myocardial perfusion imaging',
#   'Rb-82': 'rubidium-82',
#   'PET': 'Positron Emission Tomography',
#   'rSBP': 'resting systolic BP',
#   'rDBP': 'resting diastolic BP'},
#  '27659794': {'ECG': 'electrocardiogram',
#   'CNTs': 'carbon nanotubes',
#   'aPDMS': 'adhesive polydimethylsiloxane'},
#  '27660087': {'NCDS': 'National Child Development Study'},
#  '27660323': {'TxA': 'tranexamic acid'},
#  '27660548': {'MG': 'myasthenia gravis',
#   'HUSM': 'Hospital Universiti Sains Malaysia'},
#  '27660667': {'GAPS': 'Guidelines for Adolescent Preventive Services',
#   'BMI': 'body mass index'},
#  '27660811': {},
#  '27660844': {'CKD': 'Chronic kidney disease'},
#  '27661391': {'PROMIS': 'Patient-Reported Outcomes Measurement Information System'},
#  '27662437': {'PWS': 'Prader-Willi syndrome',
#   'BMI': 'body mass index',
#   'UPD': 'uniparental disomy'},
#  '27663493': {},
#  '27664877': {'QE': 'qualifying examination',
#   'CE': 'certifying examination',
#   'CE prep': 'CE preparation educational program',
#   'ABSITE': 'American Board of Surgery In-Training Examination'},
#  '27665231': {},
#  '27665747': {'GPCRs': 'G protein‑coupled receptors',
#   'PKC': 'protein kinase C',
#   'ERKs': 'extracellular signal‑regulated kinases'},
#  '27665996': {'IL-1Ra': 'IL-1 receptor antagonist'},
#  '27666119': {'SHMT2': 'serine hydroxylmethyltransferase 2',
#   'IHC': 'immunohistochemistry',
#   'ER': 'estrogen receptor'},
#  '27666303': {'EoL': 'end of life'},
#  '27667368': {'WHO': 'World Health Organisation',
#   'CVD': 'cardiovascular disease'},
#  '27668006': {'LPS': 'lipopolysaccharide', 'IFN-': 'interferon-'},
#  '27668791': {'cVEMPs': 'cervical vestibular evoked myogenic potentials',
#   'MAV': 'migraine associated vertigo',
#   'PP': 'peak-to-peak'},
#  '27669157': {},
#  '27669294': {'M': 'median', 'ROC': 'receiver operating characteristic'},
#  '27669305': {'AFB₁': 'aflatoxin B₁',
#   'SSGL': 'sporoderm-broken spores of Ganoderma lucidum'},
#  '27669322': {'S. carnosus': 'Staphylococcus carnosus',
#   'PGN': 'peptidoglycan',
#   'S. aureus': 'Staphylococcus aureus',
#   'PBP2': 'penicillin-binding protein 2'},
#  '27670600': {'NSBB': 'non-selective beta-blockers',
#   'MELD': 'Model for end-stage liver disease',
#   'HR': 'hazard ratio',
#   'CI': 'confidence interval'},
#  '27670653': {'LE': 'lower extremity',
#   'PAD': 'peripheral artery disease',
#   'DM': 'diabetes mellitus',
#   'ED': 'emergency department'},
#  '27671016': {'PAMAM': 'Polyamidoamine'},
#  '27671656': {'MuV': 'Mumps virus'},
#  '27673404': {'EFs': 'executive functions',
#   'D-KEFS': 'Delis-Kaplan Executive Functions System',
#   'TMT': 'Trial Making Test',
#   'DFT': 'Design Fluency Test',
#   'CWIT': 'Color Word Interference Test',
#   'CST': 'Card Sorting Test'},
#  '27676379': {},
#  '27677165': {'GDM': 'gestational diabetes mellitus',
#   'CI': 'confidence interval'},
#  '27677346': {'IFN-β': 'β-interferon', 'RA': 'retinoic acid'},
#  '27677368': {'CO': 'Corn oil',
#   'EVOO': 'extra-virgin olive oil',
#   'UFA': 'unsaturated fatty acids',
#   'apo': 'apolipoprotein',
#   'LDL-C': 'low-density lipoprotein cholesterol',
#   'VLDL-C': 'very low-density lipoprotein cholesterol',
#   'non-HDL-C': 'non-high-density lipoprotein cholesterol'},
#  '27677398': {'NGS': 'Next Generation Sequencing',
#   'ddRADseq': 'digested Restriction Associated DNA sequencing'},
#  '27677676': {'proBNP': 'NT-proBNP'},
#  '27677861': {'RSBI': 'rapid shallow breathing index',
#   'RR': 'respiratory rate',
#   'DD': 'diaphragmatic displacement',
#   'SBT': 'spontaneous breathing trial',
#   'ROC': 'Receiver operator characteristic'},
#  '27678029': {'CBRC': 'Cross-border reproductive care',
#   'ART': 'assisted reproductive technology'},
#  '27680099': {},
#  '27680876': {'AAD': "Autoimmune Addison's disease",
#   'SNP': 'single nucleotide polymorphism',
#   'OR': 'odds ratio',
#   'CI': 'confidence interval'},
#  '27680974': {'ADHD': 'Attention-deficit hyperactivity disorder',
#   'MANOVA': 'multivariate analysis of variance'},
#  '27681017': {'DO': 'dissolved oxygen',
#   'OTE': 'oxygen transfer efficiency',
#   'LFFA': 'liquid-film-forming apparatus',
#   'AE': 'aeration efficiency'},
#  '27681182': {},
#  '27681813': {'HA': 'hyaluronic acid',
#   'OA': 'Osteoarthritis',
#   'AKSS': 'American Knee Society Score',
#   'VAS': 'visual analogue scale'},
#  '27682141': {'KAP': 'knowledge, attitudes, and practices',
#   'MCA': 'multiple correspondence analysis'},
#  '27682293': {'PQ': 'pronator quadratus'},
#  '27683067': {'MTA': 'mineral trioxide aggregate'},
#  '27683158': {},
#  '27683502': {'TTP': 'total testing process'},
#  '27683651': {'ESP': 'excretory/secretory product',
#   'TLP': 'Toxoplasma lysate product'},
#  '27683791': {},
#  '27683811': {},
#  '27684099': {'ART': 'antiretroviral treatment'},
#  '27685846': {},
#  '27686487': {},
#  '27687042': {'AD': "Alzheimer's disease",
#   'MnSOD': 'manganese superoxide dismutase',
#   'ICV': 'intracerebroventricular',
#   'STZ': 'streptozotocin',
#   'MWM': 'Morris Water Maze'},
#  '27687951': {'CODD': 'contagious ovine digital dermatitis',
#   'FR': 'footrot',
#   'ID': 'inter-digital dermatitis',
#   'TG': 'toe granuloma',
#   'TSO': 'test standard observer'},
#  '27688320': {},
#  '27688423': {},
#  '27688460': {},
#  '27688476': {'SIRT': 'selective internal radiotherapy',
#   'BPL': 'Bayesian penalized likelihood',
#   'OSEM': 'ordered-subset expectation maximization'},
#  '27688904': {'DSA': 'donor specific antibodies'},
#  '27689092': {'LncRNAs': 'Long noncoding RNAs',
#   'SCI': 'spinal cord injury',
#   'qRT-PCR': 'Quantitative real-time polymerase chain reaction',
#   'GO': 'Gene ontology',
#   'KEGG': 'Kyoto Encyclopedia of Genes and Genomes'},
#  '27689386': {'BRE': 'biorecognition element',
#   'HPMAA': 'N-(2-hydroxypropyl) methacrylamide',
#   'CBMAA': 'carboxybetaine methacrylamide',
#   'OEG': 'oligo(ethylene glycol)',
#   'AT SAMs': 'alkanethiolate self-assembled monolayers'},
#  '27689393': {'DNN': 'deep neural network',
#   'QSAR': 'quantitative-structure activity relationships'},
#  '27689542': {},
#  '27690079': {'l-Arg': 'l-arginine'},
#  '27690192': {},
#  '27691994': {},
#  '27692274': {'T1D': 'type 1 diabetes',
#   'MD': 'mean difference',
#   'CI': 'confidence interval',
#   'HbA1c': 'hemoglobin A1c',
#   'OSA': 'obstructive sleep apnea'},
#  '27692419': {},
#  '27692888': {'MIT': 'Methylisothiazolone',
#   'D. magna': 'Daphnia magna Straus'},
#  '27693393': {'LTP': 'long-term potentiation',
#   'DG': 'dentate gyrus',
#   'I/O': 'input-output'},
#  '27694049': {},
#  '27694287': {'AABCS': 'African American breast cancer survivors'},
#  '27694728': {'PCR': 'polymerase chain reaction'},
#  '27694930': {'SCFA': 'short-chain fatty acid',
#   'BAECs': 'bovine aortic endothelial cells'},
#  '27695342': {'MSTS': 'Musculoskeletal Tumor Society'},
#  '27695358': {},
#  '27696493': {'ACLF': 'Acute on chronic liver failure'},
#  '27696737': {'AD': 'antidepressant', 'ML': 'Machine Learning'},
#  '27697474': {'SD': 'standard deviation'},
#  '27697561': {'PHD': 'plant homeodomain'},
#  '27697674': {'CVD': 'Cardiovascular disease', 'T2D': 'type 2 diabetes'},
#  '27697751': {'RIBE': 'radiation-induced bystander effect',
#   'eNOS': 'endothelial nitric oxide synthase',
#   'NO': 'nitric oxide',
#   'TGF-β1': 'transforming growth factor β1'},
#  '27698061': {'Mnk1': 'mitogen-activated protein kinase-interacting kinase 1',
#   'ERK1/2': 'extracellular signal-regulated kinase 1/2',
#   'NRVMs': 'neonatal rat ventricular myocytes'},
#  '27698735': {},
#  '27698916': {'CRC': 'colorectal cancer'},
#  '27699251': {},
#  '27701245': {},
#  '27702924': {'HS': 'heat stress', 'C': 'control'},
#  '27703342': {'CCSP': 'club cell secretory protein'},
#  '27703402': {},
#  '27703571': {'CMT': 'Charcot-Marie-Tooth'},
#  '27703744': {},
#  '27704268': {'HR': 'hormone receptor',
#   'HER2': 'human epidermal growth factor receptor 2',
#   'IBC': 'inflammatory breast cancer',
#   'NAC': 'neoadjuvant chemotherapy',
#   'pCR': 'pathologic complete response',
#   'OS': 'Overall survival'},
#  '27704621': {},
#  '27706165': {'DRDR': 'drug resistance determining region'},
#  '27706576': {'COI': 'c oxidase subunit I'},
#  '27706773': {'MTHFR': 'methylenetetrahydrofolate reductase',
#   'BC': 'breast cancer'},
#  '27706911': {},
#  '27707823': {},
#  '27708714': {'CGH': 'comparative genomic hybridization',
#   'qPCR': 'quantitative PCR'},
#  '27708774': {},
#  '27708808': {},
#  '27709987': {'PDTRT': 'Personality Disorders: Theory, Research, and Treatment',
#   'BPD': 'borderline personality disorder'},
#  '27711225': {'TIC': 'tubule-initiating cells',
#   'KRT': 'keratin',
#   'BC': 'basal cells',
#   'LC': 'luminal cells'},
#  '27712131': {'SSNHL': 'sudden sensorineural hearing loss'},
#  '27712587': {'TNF-α': 'Tumor necrosis factor-α',
#   'EMT': 'epithelial-mesenchymal transition',
#   'PI3K': 'phosphatidylinositol 3-kinase'},
#  '27713123': {'GC': 'Gastric cancer',
#   'AREG': 'Amphiregulin',
#   'EGF': 'epidermal growth factor'},
#  '27714376': {},
#  '27714651': {'BTC': 'biliary tract carcinoma',
#   'DCR': 'disease control rate',
#   'PFS': 'progression free survival',
#   'OS': 'overall survival'},
#  '27714861': {},
#  '27715026': {'COS': 'Carbonyl sulfide', 'NTAs': 'N-thiocarboxyanhydrides'},
#  '27715398': {'IAP': 'inhibitor of apoptosis'},
#  '27716016': {'TLIF': 'transforaminal lumbar interbody fusion',
#   'RR': 'rod rotation',
#   'DLKS': 'degenerative lumbar kyphoscoliosis',
#   'SRS-22': 'Scoliosis Research Society Patient Questionnaire-22'},
#  '27716325': {'ICT': 'information communication technologies'},
#  '27717527': {'PSI': 'posterior shoulder instability',
#   'ASES': 'American Shoulder and Elbow Surgeons',
#   'SANE': 'Single Assessment Numeric Evaluation'},
#  '27718505': {'RNA-seq': 'RNA-sequencing'},
#  '27718772': {'FRC': 'frequent recreational cannabis',
#   'NHANES': 'National Health and Nutrition Examination Survey',
#   'PD': 'probing depth',
#   'AL': 'attachment loss',
#   'OR': 'odds ratio',
#   'CI': 'confidence interval',
#   'aOR': 'adjusted OR'},
#  '27719897': {},
#  '27719962': {'CGAs': 'chlorogenic acids',
#   '3-CQAL': '3-caffeoylquinic acid lactone',
#   '4-CQAL': '4- caffeoyl quinic acid lactone',
#   '4-FQAL': '4-feruloylquinic acid lactone',
#   'HLE': 'Hog liver esterase'},
#  '27720181': {'MRI': 'magnetic resonance imaging'},
#  '27720895': {'PSCs': 'pituitary stem cells'},
#  '27721550': {'L-Asp': 'L-asparaginase',
#   'ALL': 'acute lymphoblastic leukemia'},
#  '27721600': {'Hh': 'hedgehog',
#   'SHH': 'sonic Hh',
#   'OSCC': 'oral squamous cell carcinoma'},
#  '27721673': {'TI-Med': 'Trauma-Informed Medical Care',
#   'PCPs': 'Primary care providers'},
#  '27721721': {},
#  '27721784': {'VA': 'visual acuity'},
#  '27723444': {'TM': 'Transcendental Meditation'},
#  '27723749': {'ENO2': 'enolase 2',
#   'ENO1': 'enolase 1',
#   'PhAH': 'phosphonoacetohydroxamate'},
#  '27723905': {'PDAC': 'pancreatic ductal adenocarcinoma',
#   'OS': 'overall survival'},
#  '27725659': {'BD': 'Bipolar disorder'},
#  '27725792': {'MSTS': 'Musculoskeletal Tumor Society',
#   'IQR': 'interquartile range'},
#  '27725796': {},
#  '27726295': {'GBC': 'gallbladder cancer',
#   'S. Typhi': 'serovar Typhi',
#   'ORs': 'odds ratios',
#   'CIs': 'confidence intervals'},
#  '27726775': {'NLR': 'NOD-like receptor',
#   'IL-1β': 'interleukin-1β',
#   'PRRs': 'pattern recognition receptors',
#   'MAMPs': 'microbe-associated molecular patterns',
#   'DAMPs': 'danger-associated molecular patterns'},
#  '27727240': {'PFC': 'prefrontal cortical', 'ST': 'striatum'},
#  '27729000': {'CQDs': 'carbon quantum dots'},
#  '27729252': {},
#  '27729641': {'L': 'Leader', 'SAFV': 'Saffold virus'},
#  '27730636': {'LnT': 'Loch na Thull'},
#  '27731485': {'OHRQoL': 'Oral HealthRelated Quality of Life',
#   'OR': 'odds ratios'},
#  '27733154': {'5-FU': '5-fluorouracil'},
#  '27734182': {'NSC': 'neural stem cell',
#   'Ost': 'Osthole',
#   'CCK-8': 'cell counting kit-8',
#   'LDH': 'lactate dehydrogenase'},
#  '27734289': {},
#  '27734402': {'CTGF': 'connective tissue growth factor'},
#  '27734513': {'Pchlide': 'protochlorophyllide', 'Pchl': 'protochlorophyll'},
#  '27736157': {},
#  '27736701': {},
#  '27736955': {'GHRs': 'Glutathionyl-hydroquinone reductases'},
#  '27737333': {'LLNM': 'lateral lymph node metastasis',
#   'PTC': 'papillary thyroid carcinoma',
#   'ETE': 'extrathyroidal extension',
#   'CLNM': 'central lymph node metastases'},
#  '27737795': {'DON': 'Deoxynivalenol'},
#  '27737807': {'PYC': 'pycnogenol',
#   'TBI': 'traumatic brain injury',
#   'CCI': 'controlled cortical impact',
#   'MWM': 'Morris water maze',
#   'FJB': 'Fluoro-jade B'},
#  '27737923': {'ACC': '1-aminocyclopropane-1-carboxylate',
#   'ACO': 'ACC oxidase',
#   'TR-PT1': 'Trifolium repens PHOSPHATE TRANSPORTER 1'},
#  '27738051': {},
#  '27738068': {'AF': 'atrial fibrillation',
#   'PV': 'pulmonary vein',
#   'LA': 'left atrial'},
#  '27738460': {'EHIT': 'endovenous heat-induced thrombosis'},
#  '27741201': {'PROM': 'prelabor rupture of membranes', 'OR': 'odds ratio'},
#  '27741202': {},
#  '27741956': {'PBIs': 'performance-based incentives'},
#  '27742121': {},
#  '27742195': {},
#  '27742373': {'SAH': 'subarachnoid hemorrhage',
#   'SCU': 'Scutellarin',
#   'eNOS': 'endothelial nitric oxide synthase',
#   'p-Erk5': 'phosphorylated extracellular-regulated kinase 5',
#   'KLF2': 'Kruppel-like factor 2'},
#  '27742630': {},
#  '27742821': {'HieranoiDB': 'http://hieranoiDB.sbc.su.se'},
#  '27743718': {'NF': 'necrotizing fasciitis'},
#  '27743941': {'PD': "Parkinson's disease", 'DS': 'dorsal striatum'},
#  '27744105': {'LBP': 'low back pain'},
#  '27744233': {},
#  '27744500': {},
#  '27744574': {'TUDCA': 'tauroursodeoxycholic acid',
#   'TGFβ': 'transforming growth factor β',
#   'LPS': 'lipopolysaccharide',
#   'SBE': 'Smad-binding element'},
#  '27744641': {'CRF': 'corticotropin releasing factor',
#   'GABA': 'gamma-aminobutyric acid',
#   'DRN': 'dorsal raphe nucleus'},
#  '27744673': {},
#  '27746055': {'FEP': 'first-episode psychosis',
#   'CANTAB': 'Cambridge Neuropsychological Test Automated Battery'},
#  '27746068': {'PPBS': 'post prandial blood sugar',
#   'FBS': 'fasting blood sugar'},
#  '27746771': {'WLM': 'wine-like medium'},
#  '27746786': {'NMD': 'Nonsense-mediated mRNA decay'},
#  '27747996': {'TD': 'typically developing'},
#  '27748242': {'nTST': 'nighttime total sleep time',
#   'TST': 'total sleep time',
#   'WASO': 'wake after sleep onset',
#   'SE': 'sleep efficiency',
#   'CV': 'coefficient of variation'},
#  '27748824': {'CVD': 'cardiovascular disease'},
#  '27748842': {'HCC': 'Hepatocellular carcinoma',
#   'lncRNAs': 'long non‑coding RNAs',
#   'ZEB2‑AS1': 'zinc finger E‑box binding homeobox 2 antisense RNA 1',
#   'siRNAs': 'small interfering RNAs'},
#  '27749081': {},
#  '27749392': {},
#  '27749441': {'SPF': 'sun protection factor'},
#  '27749796': {'IV': 'intravenous', 'CI': 'confidence interval'},
#  ...}

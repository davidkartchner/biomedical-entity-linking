# %%
# %load_ext autoreload
# %autoreload 2

import sys
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
sns.set(style='whitegrid')

sys.path.append('..')
from dataset_consts import model_to_pretty_name, model_to_color
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
model_to_color
# Out:
# {'sapbert': '#fee08b',
#  'metamap': '#f46d43',
#  'krissbert': '#bbcb6b',
#  'scispacy': '#fdae61',
#  'medlinker': '#3288bd',
#  'arboel_biencoder': '#9e0142',
#  'arboel_crossencoder': '#d53e4f',
#  'biobart': '#abdda4',
#  'biogenel': '#66c2a5',
#  'Other Model': '#5e4fa2'}

# %%
df = pd.read_csv('../data/figure_data/runtimes.csv')
df['colors'] = df['Model'].map(model_to_color)
df
# Out:
#                  Model  Training Time  Evaluation Time  Accuracy   colors
# 0  arboel_crossencoder        1364516            13314     0.747  #d53e4f
# 1     arboel_biencoder         267494            10489     0.692  #9e0142
# 2              metamap             50              437     0.568  #f46d43
# 3            krissbert            334               37     0.548  #bbcb6b
# 4             scispacy            150               29     0.536  #fdae61
# 5              biobart           6340            14737     0.544  #abdda4
# 6             biogenel           6672            35258     0.562  #66c2a5
# 7              sapbert           5834             3218     0.637  #fee08b

# %%
df.plot.scatter(x='Training Time', y='Accuracy', logx=True, c='colors')
plt.savefig('../figures/230414_train_times.png')
# Out:
# /Users/davidkartchner/miniforge3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:1070: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
df.plot.scatter(x='Evaluation Time', y='Accuracy', logx=True, c='colors')
plt.savefig('../figures/230414_eval_times.png')

# %% [markdown]
# # Evaluation of BERN2 Entity Linking

# %%
import ujson
import pandas as pd
import os
import sys
from bigbio.dataloader import BigBioConfigHelpers
from tqdm.auto import tqdm
from umls_utils import UmlsMappings
from collections import defaultdict
from itertools import combinations

pd.set_option('display.max_rows', 200)

sys.path.append('../')
from bigbio_utils import dataset_to_df

AWS_S3_BUCKET = os.getenv("AWS_S3_BUCKET")
AWS_ACCESS_KEY_ID = os.getenv("AWS_ACCESS_KEY_ID")
AWS_SECRET_ACCESS_KEY = os.getenv("AWS_SECRET_ACCESS_KEY")
AWS_SESSION_TOKEN = os.getenv("AWS_SESSION_TOKEN")

conhelps = BigBioConfigHelpers()
tqdm.pandas()

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Get list of all needed PMIDs

# %%
all_pmids = set([])
for dataset in tqdm(['medmentions_full','medmentions_st21pv','bc5cdr','gnormplus','ncbi_disease','nlmchem']):
    data = conhelps.for_config_name(f"{dataset}_bigbio_kb").load_dataset()
    for split in data.keys():
        for doc in data[split]:
            pmid = doc["document_id"]
            all_pmids.add(pmid)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# Reusing dataset medmentions (/nethome/dkartchner3/.cache/huggingface/datasets/medmentions/medmentions_full_bigbio_kb/1.0.0/3fc6b8a3681d540ae6c7497c238636b543b90764247b5ff3642d243474000794)
#   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading and preparing dataset medmentions/medmentions_st21pv_bigbio_kb to /nethome/dkartchner3/.cache/huggingface/datasets/medmentions/medmentions_st21pv_bigbio_kb/1.0.0/3fc6b8a3681d540ae6c7497c238636b543b90764247b5ff3642d243474000794...
# Downloading data files:   0%|          | 0/4 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/5.10M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Dataset medmentions downloaded and prepared to /nethome/dkartchner3/.cache/huggingface/datasets/medmentions/medmentions_st21pv_bigbio_kb/1.0.0/3fc6b8a3681d540ae6c7497c238636b543b90764247b5ff3642d243474000794. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]
# Reusing dataset bc5cdr (/nethome/dkartchner3/.cache/huggingface/datasets/bc5cdr/bc5cdr_bigbio_kb/1.0.0/f01f16ea9b65ead985bedadf7335195c32297c8f1b09417fc607b102a6757d6f)
#   0%|          | 0/3 [00:00<?, ?it/s]
# Reusing dataset gnormplus (/nethome/dkartchner3/.cache/huggingface/datasets/gnormplus/gnormplus_bigbio_kb/1.0.0/a07d375cacec149beba70fa6c1ea3ac78628e6652dca5345f3478354e8c0ae96)
#   0%|          | 0/2 [00:00<?, ?it/s]
# Reusing dataset ncbi_disease (/nethome/dkartchner3/.cache/huggingface/datasets/ncbi_disease/ncbi_disease_bigbio_kb/1.0.0/91a4f7ea79a8b89806de2cefa4fcca8cd4a7495e2cfeb9c28a8d68c51f7eac8b)
#   0%|          | 0/3 [00:00<?, ?it/s]
# Reusing dataset nlmchem (/nethome/dkartchner3/.cache/huggingface/datasets/nlmchem/nlmchem_bigbio_kb/1.0.0/d91131823c66b7dd1162027991ea47c342e478209b37cf261c5f122d30409594)
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
# Load PMIDs from NLMGene and PlantNorm

# NLM Gene
for subset in ['Train','Test']:
    with open(f'/Users/david//Downloads/Pmidlist.{subset}.txt') as f:
        pmids = set(f.read().strip().split('\n'))
        all_pmids.update(pmids)
        # print(list(pmids)[:5])


# PlantNorm
for subset in ['training','test','development']:
    with open(f'/Users/david/Downloads/DMCB_plant_{subset}_corpus.txt', 'r', encoding='utf-8', errors='ignore') as f:
        all_text = f.read()
        abstracts = all_text.strip().split('\n\n')
        abstract_lines = [x.split('\n') for x in abstracts]
        for abs in abstract_lines:
            pmid = abs[0].split('|')[0]
            # print(pmid)
            all_pmids.add(pmid)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/dkartchner3/research/entity_linking/el-robustness-comparison/notebooks/bern2_evaluation.ipynb Cell 5 in <cell line: 4>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bmitch/home/dkartchner3/research/entity_linking/el-robustness-comparison/notebooks/bern2_evaluation.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> # Load PMIDs from NLMGene and PlantNorm
#       <a href='vscode-notebook-cell://ssh-remote%2Bmitch/home/dkartchner3/research/entity_linking/el-robustness-comparison/notebooks/bern2_evaluation.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>
#       <a href='vscode-notebook-cell://ssh-remote%2Bmitch/home/dkartchner3/research/entity_linking/el-robustness-comparison/notebooks/bern2_evaluation.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> # NLM Gene
#       <a href='vscode-notebook-cell://ssh-remote%2Bmitch/home/dkartchner3/research/entity_linking/el-robustness-comparison/notebooks/bern2_evaluation.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> for subset in ['Train','Test']:
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bmitch/home/dkartchner3/research/entity_linking/el-robustness-comparison/notebooks/bern2_evaluation.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>     with open(f'/Users/david//Downloads/Pmidlist.{subset}.txt') as f:
#       <a href='vscode-notebook-cell://ssh-remote%2Bmitch/home/dkartchner3/research/entity_linking/el-robustness-comparison/notebooks/bern2_evaluation.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>         pmids = set(f.read().strip().split('\n'))
#       <a href='vscode-notebook-cell://ssh-remote%2Bmitch/home/dkartchner3/research/entity_linking/el-robustness-comparison/notebooks/bern2_evaluation.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>         all_pmids.update(pmids)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/david//Downloads/Pmidlist.Train.txt'

# %%
with open('entity_linking_pmids.txt','w') as f:
    f.write('\n'.join([x for x in list(all_pmids) if x.strip() != '']))

# %% [markdown]
# ## Load Mappings

# %%
hgnc_to_entrez = {
    k: v
    for k, v in pd.read_csv(
        "../data/proteins.tsv",
        delimiter="\t",
        names=["source", "target"],
    )
    .set_index("source")
    .to_dict()["target"].items()
    if k.startswith("hgnc")
}

entrez_to_hgnc = {
    val: key for key, val in hgnc_to_entrez.items() if key.startswith("hgnc")
}

# %%
# chebi_to_mesh = {k:v for k,v in pd.read_csv('/Users/david/Downloads/identifiers', delimiter="\t",
#         names=["source", "target"],
#     )
#     .set_index("source")
#     .to_dict()["target"].items() if k.startswith('')}

# %%
umls = UmlsMappings(umls_dir='/mitchell/entity-linking/2022AA/META/', debug=False, force_reprocess=False)
# Out:
# Loading cached UMLS data from /mitchell/entity-linking/2022AA/META/.cached_df.feather

# %%
umls_to_mesh = umls.get_mapping('MSH', other_prefix='MESH')
mesh_to_umls = umls.get_mapping('MSH', reverse=True, other_prefix='MESH')
print(len(umls_to_mesh))
print(len(mesh_to_umls))

# Write to file
with open('../data/umls2mesh.json', 'w') as f:
    f.write(ujson.dumps(umls_to_mesh))
    
with open('../data/mesh2umls.json', 'w') as f:
    f.write(ujson.dumps(mesh_to_umls))
# Out:
# 455672
# 348733

# %%
umls_to_hgnc = {k:v.replace('HGNC','hgnc') for k, v in umls.get_mapping('HGNC', mapping_col='scui', ).items()}
hgnc_to_umls = {k.replace('HGNC','hgnc'):v  for k, v in umls.get_mapping('HGNC', mapping_col='scui', reverse=True).items()}
umls_to_entrez = {key: hgnc_to_entrez[val] for key, val in umls_to_hgnc.items() if val in hgnc_to_entrez}
entrez_to_umls = {v:k for k,v in umls_to_entrez.items()}
print(len(umls_to_hgnc))
print(len(hgnc_to_umls))

with open('../data/umls2entrez.json', 'w') as f:
    f.write(ujson.dumps(umls_to_entrez))
    
with open('../data/entrez2umls.json', 'w') as f:
    f.write(ujson.dumps(entrez_to_umls))
# Out:
# 42509
# 42514

# %%
# Check lengths of mappings to make sure we go in the right direction and avoid dropping keys
print(len(set(umls_to_hgnc.keys())))
print(len(set(umls_to_hgnc.values())))
print(len(set(entrez_to_hgnc.keys())))
print(len(set(entrez_to_hgnc.values())))
print(len(set(hgnc_to_entrez.keys())))
print(len(set(hgnc_to_entrez.values())))
# Out:
# 42509
# 42508
# 42305
# 42305
# 84109
# 42305

# %%
umls_to_ncbi = umls.get_mapping('NCBI', mapping_col='scui', other_prefix='NCBI')
ncbi_to_umls = umls.get_mapping('NCBI', reverse=True, mapping_col='scui', other_prefix='NCBI')
print(len(umls_to_ncbi))
print(len(ncbi_to_umls))
# Out:
# 1983467
# 1983785

# %%
umls_to_omim = umls.get_mapping('OMIM', other_prefix='OMIM')
omim_to_umls = umls.get_mapping('OMIM', reverse=True, other_prefix='OMIM')
print(len(umls_to_omim))
print(len(omim_to_umls))
# Out:
# 99542
# 101089

# %%
len(umls_to_omim)
# Out:
# 99542

# %%
mapping_dicts = [umls_to_omim, umls_to_mesh, umls_to_ncbi, umls_to_entrez,]
# names = ['omim','mesh','ncbitaxon','entrez']
# print(sum([len(x)  for x in mapping_dicts]))
# for (a,b) in combinations(range(len(mapping_dicts)), 2):
#     print(names[a], names[b])
#     d1, d2 = mapping_dicts[a], mapping_dicts[b]
#     print("Overlap:", len(set(d1.keys()).intersection(set(d2.keys()))))
#     print('\n')


# omnimap = defaultdict(str, {**umls_to_omim, **umls_to_mesh, **umls_to_ncbi, **umls_to_entrez,})
# print(len(omnimap))

omnimap_with_duplicates = defaultdict(set)
for d in mapping_dicts:
    for key, val in d.items():
        omnimap_with_duplicates[key].add(val)


umls_to_mesh_omim = defaultdict(set)
for d in [umls_to_mesh, umls_to_omim]:
    for key, val in d.items():
        umls_to_mesh_omim[key].add(val)

omnimap_with_duplicates = {key:list(val) for key, val in omnimap_with_duplicates}
umls_to_mesh_omim = {key:list(val) for key, val in umls_to_mesh_omim}

with open('../data/umls2entrez_mesh_omim_ncbi.json', 'w') as f:
    f.write(ujson.dumps(omnimap_with_duplicates))

with open('../data/umls2mesh_omim.json', 'w') as f:
    f.write(ujson.dumps(umls_to_mesh_omim))
# Out:
# 2486286

# %% [markdown]
# ## Take special care to resolve synonym sets with Entrez
# There is no mapping of proteins to corresponding genes.  This code is meant to be a partial remedy to that problem

# %%
umls_to_entrez = ujson.load(open('../data/umls2entrez.json', 'r'))
df = umls.umls[umls.umls.lang == 'ENG']
df['type'] = df.tui.map(lambda x: [umls.type2abbrev[y] for y in x])
df['entrez'] = df['cui'].progress_map(lambda x: umls_to_entrez[x] if x in umls_to_entrez else '')
df['has_entrez'] = df.entrez != ''
df['type_str'] = df['type'].progress_map(lambda x: ','.join(x))
subset = df.loc[df.entrez != '', ['cui','alias','type_str', 'entrez']].drop_duplicates()
agg = subset.groupby('alias').agg({'entrez':['nunique', lambda x: x]})

# Get blacklist of Entrez identifiers taht are not unique to a single gene CUI
blacklist_df = agg[agg[('entrez','nunique')] > 1]
blacklist = set([])
for x in blacklist_df[('entrez','<lambda_0>')]:
    for y in x:
        blacklist.add(y)
        
# Filter blacklisted entities
df.loc[df.entrez.isin(blacklist), 'has_entrez'] = False

# Get synonym sets that map to a single alias
grouped = df.groupby('alias')
entrez_agg = grouped.agg({'has_entrez': 'max',})
keep_aliases = set(entrez_agg[entrez_agg['has_entrez']].index.unique().tolist())

# Subset of unique ncbigene/entrez identifiers
subset = df[df.alias.isin(keep_aliases)]
subset_grouped = subset.groupby('alias')
gene_synset_agg = subset_grouped.agg({
                               'cui':lambda x: list(set(x)),
                               'group': lambda group_list: set([y for x in group_list for y in x]),
                               'type':lambda type_list: set([y for x in type_list for y in x]),
                               'entrez': lambda x: list(set([y for y in x if y != '']))[0],
                    })

synset_mapping = gene_synset_agg.groupby('entrez').agg({'cui':lambda cui_lists: list(set([y for x in cui_lists for y in x]))})

# Additional filtering of promiscuous CUIs
used_cuis = set([])
duplicate_cuis = set([])
for cui_list in synset_mapping['cui']:
    for cui in cui_list:
        if cui in used_cuis:
            duplicate_cuis.add(cui)
        else:
            used_cuis.add(cui)
            
            
# Use synonym sets to update entrez_to_umls mapping
for entrez_curie, cui_list in synset_mapping.to_dict()['cui'].items():
    for cui in cui_list:
        if cui not in duplicate_cuis:
            umls_to_entrez[cui] = entrez_curie
            
            
# Write to file
with open('../data/umls2entrez_with_synsets.json', 'w') as f:
    f.write(ujson.dumps(umls_to_entrez))

# %% [markdown]
# ## Load BERN2 Data

# %%
with open('/Users/david/Downloads/abstracts-entity-linking-pmids.json', 'r') as f:
    lines = f.read().strip().split('\n')
    abstracts = [ujson.loads(line) for line in lines]

# %%
abstracts[0]
# Out:
# {'_id': '2004',
#  'pmid': '2004',
#  'annotations': [{'id': ['OMIM:115000', 'MESH:D001145'],
#    'span': {'begin': 33, 'end': 52},
#    'obj': 'disease',
#    'is_neural_normalized': False,
#    'mention': 'cardiac arrhythmias',
#    'prob': 0.999992311000824},
#   {'id': ['MESH:D010640'],
#    'span': {'begin': 212, 'end': 226},
#    'obj': 'drug',
#    'is_neural_normalized': False,
#    'mention': 'phenothiazines',
#    'prob': 0.9991432428359985},
#   {'id': ['MESH:D013881'],
#    'span': {'begin': 310, 'end': 318},
#    'obj': 'drug',
#    'is_neural_normalized': False,
#    'mention': 'Mellaril',
#    'prob': 0.9977579712867737},
#   {'id': ['MESH:D013881'],
#    'span': {'begin': 320, 'end': 332},
#    'obj': 'drug',
#    'is_neural_normalized': False,
#    'mention': 'thioridazine',
#    'prob': 0.9996978044509888},
#   {'id': ['MESH:D017180'],
#    'span': {'begin': 379, 'end': 402},
#    'obj': 'disease',
#    'is_neural_normalized': False,
#    'mention': 'ventricular tachycardia',
#    'prob': 0.9999977946281433},
#   {'id': ['MESH:D013617'],
#    'span': {'begin': 451, 'end': 479},
#    'obj': 'disease',
#    'is_neural_normalized': False,
#    'mention': 'Supraventricular tachycardia',
#    'prob': 0.9999979734420776},
#   {'id': ['MESH:D002746'],
#    'span': {'begin': 515, 'end': 524},
#    'obj': 'drug',
#    'is_neural_normalized': False,
#    'mention': 'Thorazine',
#    'prob': 0.9989720582962036},
#   {'id': ['MESH:D002746'],
#    'span': {'begin': 526, 'end': 540},
#    'obj': 'drug',
#    'is_neural_normalized': False,
#    'mention': 'chlorpromazine',
#    'prob': 0.9992929697036743},
#   {'id': ['MESH:D009661'],
#    'span': {'begin': 543, 'end': 550},
#    'obj': 'drug',
#    'is_neural_normalized': False,
#    'mention': 'Aventyl',
#    'prob': 0.9993903636932373},
#   {'id': ['MESH:D009661'],
#    'span': {'begin': 552, 'end': 565},
#    'obj': 'drug',
#    'is_neural_normalized': False,
#    'mention': 'nortriptyline',
#    'prob': 0.9997335076332092},
#   {'id': ['MESH:D000639'],
#    'span': {'begin': 571, 'end': 577},
#    'obj': 'drug',
#    'is_neural_normalized': False,
#    'mention': 'Elavil',
#    'prob': 0.9991211295127869},
#   {'id': ['MESH:D000639'],
#    'span': {'begin': 579, 'end': 592},
#    'obj': 'drug',
#    'is_neural_normalized': False,
#    'mention': 'amitriptyline',
#    'prob': 0.9991124272346497},
#   {'id': ['MESH:D002037'],
#    'span': {'begin': 608, 'end': 632},
#    'obj': 'disease',
#    'is_neural_normalized': False,
#    'mention': 'left bundle branch block',
#    'prob': 0.9996938705444336},
#   {'id': ['MESH:D000077277'],
#    'span': {'begin': 678, 'end': 685},
#    'obj': 'disease',
#    'is_neural_normalized': True,
#    'mention': 'T and U',
#    'prob': 0.7814574241638184},
#   {'id': ['OMIM:115000', 'MESH:D001145'],
#    'span': {'begin': 740, 'end': 763},
#    'obj': 'disease',
#    'is_neural_normalized': True,
#    'mention': 'ventricular arrhythmias',
#    'prob': 0.9999877214431763},
#   {'id': ['MESH:D008012'],
#    'span': {'begin': 807, 'end': 816},
#    'obj': 'drug',
#    'is_neural_normalized': False,
#    'mention': 'lidocaine',
#    'prob': 0.9949262142181396},
#   {'id': ['MESH:D011433'],
#    'span': {'begin': 939, 'end': 950},
#    'obj': 'drug',
#    'is_neural_normalized': False,
#    'mention': 'propranolol',
#    'prob': 0.9909729957580566},
#   {'id': ['MESH:D013610'],
#    'span': {'begin': 996, 'end': 1012},
#    'obj': 'disease',
#    'is_neural_normalized': False,
#    'mention': 'tachyarrhythmias',
#    'prob': 0.9999924898147583},
#   {'id': ['MESH:D006331'],
#    'span': {'begin': 1187, 'end': 1200},
#    'obj': 'disease',
#    'is_neural_normalized': False,
#    'mention': 'heart disease',
#    'prob': 0.9999514222145081},
#   {'id': ['OMIM:115000', 'MESH:D001145'],
#    'span': {'begin': 1208, 'end': 1227},
#    'obj': 'disease',
#    'is_neural_normalized': False,
#    'mention': 'cardiac arrhythmias',
#    'prob': 0.9999704360961914},
#   {'id': ['MESH:D006331'],
#    'span': {'begin': 1271, 'end': 1284},
#    'obj': 'disease',
#    'is_neural_normalized': False,
#    'mention': 'heart disease',
#    'prob': 0.9999374747276306},
#   {'id': ['MESH:D005117'],
#    'span': {'begin': 1420, 'end': 1441},
#    'obj': 'disease',
#    'is_neural_normalized': True,
#    'mention': 'cardiac complications',
#    'prob': 0.8083474040031433},
#   {'id': ['MESH:D010640'],
#    'span': {'begin': 1464, 'end': 1478},
#    'obj': 'drug',
#    'is_neural_normalized': False,
#    'mention': 'phenothiazines',
#    'prob': 0.9992499947547913}],
#  'text': 'Electrocardiographic changes and cardiac arrhythmias in patients receiving psychotropic drugs. Eight patients had cardiac manifestations that were life-threatening in five while taking psychotropic drugs, either phenothiazines or tricyclic antidepressants. Although most patients were receiving several drugs, Mellaril (thioridazine) appeared to be responsible for five cases of ventricular tachycardia, one of which was fatal in a 35 year old woman. Supraventricular tachycardia developed in one patient receiving Thorazine (chlorpromazine). Aventyl (nortriptyline) and Elavil (amitriptyline) each produced left bundle branch block in a 73 year old woman. Electrocardiographic T and U wave abnormalities were present in most patients. The ventricular arrhythmias responded to intravenous administration of lidocaine and to direct current electric shock; ventricular pacing was required in some instances and intravenous administration of propranolol combined with ventricular pacing in one. The tachyarrhythmias generally subsided within 48 hours after administration of the drugs was stopped. Five of the eight patients were 50 years of age or younger; only one clearly had antecedent heart disease. Major cardiac arrhythmias are a potential hazard in patients without heart disease who are receiving customary therapeutic doses of psychotropic drugs. A prospective clinical trial is suggested to quantify the risk of cardiac complications to patients receiving phenothiazines or tricyclic antidepressant drugs.'}

# %%
all_entities = []
all_prefixes = set([])
for doc in tqdm(abstracts):
    pmid = doc['pmid']
    if 'annotations' not in doc.keys():
        print(doc)
        continue
    for an in doc['annotations']:
        for cui_list in an['id']:
            if type(cui_list) == list:
                cui_list = cui_list[0]
            if cui_list == 'CUI-less':
                continue
            for cui in cui_list.split(','):
                prefix = cui.split(':')[0].split('_')[0]
                if prefix[0].isdigit():
                    continue
                prob = 0.0
                if 'prob' not in an.keys():
                    if 'logit' in an.keys():
                        prob = an['logit']
                    else:
                       print(an) 
                else:
                    prob = an['prob']
                all_entities.append([pmid, cui, an['mention'],  an['obj'], an['span']['begin'], an['span']['end'], prob, prefix])
                all_prefixes.add(prefix)
# Out:
#   0%|          | 0/8099 [00:00<?, ?it/s]
# {'id': ['MESH:C498038'], 'span': {'begin': 509, 'end': 518}, 'obj': 'drug', 'is_neural_normalized': True, 'mention': 'Val509Ala'}
# {'id': ['MESH:C515730'], 'span': {'begin': 533, 'end': 542}, 'obj': 'drug', 'is_neural_normalized': True, 'mention': 'Cys672Tyr'}
# {'error_code': 1, 'error_message': 'Something went wrong. Try again.', 'pmid': '28054712', '_id': '28054712'}
# {'id': ['CHEBI:74801'], 'span': {'begin': 1022, 'end': 1029}, 'obj': 'drug', 'is_neural_normalized': True, 'mention': 'Ser5Ala'}

# %%
bern2_annotations = pd.DataFrame(all_entities, columns=['pmid','cui','text', 'type','start','end', 'prob', 'prefix'])

bern2_filtered = bern2_annotations[bern2_annotations.prefix.isin(['EntrezGene','MESH','NCBI','OMIM'])]
bern2_filtered.shape
# Out:
# (132719, 8)

# %%
bern2_filtered[['pmid','start','end']].drop_duplicates()
# Out:
#             pmid  start   end
# 0           2004     33    52
# 2           2004    212   226
# 3           2004    310   318
# 4           2004    320   332
# 5           2004    379   402
# ...          ...    ...   ...
# 143715  30991764   1349  1361
# 143716  30991764   1376  1380
# 143717  30991764   1392  1401
# 143718  30991764   1500  1508
# 143719  30991764   1513  1515
#
# [118312 rows x 3 columns]

# %%
bern2_filtered['cui'] = bern2_filtered.cui.map(lambda x: x.replace('txid','').replace('EntrezGene','ncbigene'))
bern2_filtered[bern2_filtered.prefix == 'EntrezGene']
# Out:
# /var/folders/9r/6d47z63d3jn1kgx93359_9rr0000gq/T/ipykernel_54731/4225061764.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bern2_filtered['cui'] = bern2_filtered.cui.map(lambda x: x.replace('txid','').replace('EntrezGene','ncbigene'))
#             pmid             cui       text  type  start   end      prob  \
# 38         23402   ncbigene:2539       G6PD  gene    814   818  0.950792
# 42         23402   ncbigene:2539       G6PD  gene   1228  1232  0.779835
# 75         28952   ncbigene:5972      renin  gene   1158  1163  0.991751
# 78         28952   ncbigene:5972      renin  gene   1212  1217  0.987656
# 82         28952   ncbigene:5972      renin  gene   1413  1418  0.994729
# ...          ...             ...        ...   ...    ...   ...       ...
# 143709  30991764   ncbigene:3569       IL-6  gene   1171  1175  0.933437
# 143710  30991764   ncbigene:7124       TNF-  gene   1181  1185  0.963428
# 143712  30991764    ncbigene:834  caspase-1  gene   1235  1244  0.985916
# 143716  30991764  ncbigene:85480       TSLP  gene   1376  1380  0.984251
# 143717  30991764    ncbigene:834  caspase-1  gene   1392  1401  0.978801
#
#             prefix
# 38      EntrezGene
# 42      EntrezGene
# 75      EntrezGene
# 78      EntrezGene
# 82      EntrezGene
# ...            ...
# 143709  EntrezGene
# 143710  EntrezGene
# 143712  EntrezGene
# 143716  EntrezGene
# 143717  EntrezGene
#
# [28736 rows x 8 columns]

# %%
all_prefixes
# Out:
# {'CHEBI', 'CL', 'CVCL', 'EntrezGene', 'MESH', 'NCBI', 'OMIM'}

# %% [markdown]
# ## Evaluate BERN2 on MedMentions_Full

# %% [markdown]
# ### Load Medmentions and convert to dataframe

# %%
mm_df = dataset_to_df(conhelps.for_config_name(f"medmentions_full_bigbio_kb").load_dataset())
mm_df['cui'] = mm_df['db_id'].map(omnimap)
mm_filtered = mm_df[mm_df.cui != '']
mm_filtered.shape
# Out:
# Reusing dataset med_mentions_dataset (/Users/david/.cache/huggingface/datasets/med_mentions_dataset/medmentions_full_bigbio_kb/1.0.0/b5c8691186d4701f9b18eddbe36d178ccf7e55761dcc6140c57f4410754511ac)
#   0%|          | 0/3 [00:00<?, ?it/s]
# (198282, 10)

# %%
mm_filtered.head(20)
# Out:
#         pmid mention_id                                      text  type  \
# 0   25763772          1                                     DCTN4  T116
# 1   25763772          2                                     DCTN4  T123
# 2   25763772          3  chronic Pseudomonas aeruginosa infection  T047
# 3   25763772          4                           cystic fibrosis  T047
# 4   25763772          5     Pseudomonas aeruginosa (Pa) infection  T047
# 5   25763772          6                           cystic fibrosis  T047
# 6   25763772          7                                        CF  T047
# 7   25763772          8                                  patients  T101
# 9   25763772         10                         pulmonary disease  T047
# 10  25763772         11                          shorter survival  T169
# 11  25763772         12                      chronic Pa infection  T047
# 12  25763772         13                                       CPA  T047
# 14  25763772         15               faster rate of lung decline  T033
# 17  25763772         18                          shorter survival  T169
# 18  25763772         19                          exome sequencing  T063
# 20  25763772         21                                  isoforms  T116
# 21  25763772         22                                dynactin 4  T116
# 22  25763772         23                                dynactin 4  T123
# 23  25763772         24                                     DCTN4  T116
# 24  25763772         25                                     DCTN4  T123
#
#    db_name     db_id  split  start  end              cui
# 0     UMLS  C4308010  train      0    5  MESH:C000606363
# 1     UMLS  C4308010  train      0    5  MESH:C000606363
# 2     UMLS  C0854135  train     23   63     MESH:D011552
# 3     UMLS  C0010674  train     67   82     MESH:D003550
# 4     UMLS  C0854135  train     83  120     MESH:D011552
# 5     UMLS  C0010674  train    124  139     MESH:D003550
# 6     UMLS  C0010674  train    141  143     MESH:D003550
# 7     UMLS  C0030705  train    145  153     MESH:D010361
# 9     UMLS  C0024115  train    189  206     MESH:D008171
# 10    UMLS  C0220921  train    211  227     MESH:Q000401
# 11    UMLS  C0854135  train    233  253     MESH:D011552
# 12    UMLS  C0854135  train    255  258     MESH:D011552
# 14    UMLS  C3160731  train    302  329      OMIM:608852
# 17    UMLS  C0220921  train    368  384     MESH:Q000401
# 18    UMLS  C3640077  train    395  411  MESH:D000073359
# 20    UMLS  C0597298  train    469  477     MESH:D020033
# 21    UMLS  C4308010  train    481  491  MESH:C000606363
# 22    UMLS  C4308010  train    481  491  MESH:C000606363
# 23    UMLS  C4308010  train    493  498  MESH:C000606363
# 24    UMLS  C4308010  train    493  498  MESH:C000606363

# %%
mm_dict = defaultdict(str, mm_filtered.set_index(['pmid','start','end'])['cui'].to_dict())

# %% [markdown]
# ### Compute overlap between BERN2 and MedMentions

# %%
# Helper Functions
# def iou(span1, span2):
def iou(b1, e1, b2, e2):
    '''
    Calculate intersection-over-union of two spans
    '''
    # b1 = span1[0]
    # e1 = span1[1]
    # b2 = span2[0]
    # e2 = span2[1]
    overlap = (min(e1, e2) - max(b1, b2))
    if overlap <= 0:
        return 0
    else:
        union = (max(e1, e2) - min(b1, b2)) 
        return overlap/union

# %%
def evaluate_bern2_bigbio(
    bern2_df,
    bigbio_df,
    bigbio_suffix,
    entity_types=["gene", "disease", "chemical", "drug", "species"],
    subsets=['train','test','dev','validation','training','valid'],
):
    bigbio_df = bigbio_df[bigbio_df['split'].isin(subsets)]

    # Merge datasets to find overlap
    merged = pd.merge(
        bern2_df[["pmid", "cui", "type", "start", "end", "prob"]],
        bigbio_df,
        how="outer",
        on="pmid",
        suffixes=["_bern2", f"_{bigbio_suffix}"],
    ).dropna()

    merged["iou"] = merged[
        ["start_bern2", "end_bern2", f"start_{bigbio_suffix}", f"end_{bigbio_suffix}"]
    ].progress_apply(lambda x: iou(*x), axis=1)

    iou_cutoff = 0.5
    confidence_cutoff = 0.99

    # Compute matches between BERN2 CUI and MedMentions CUI
    merged["match"] = merged["cui_bern2"] == merged[f"cui_{bigbio_suffix}"]
    print(
        "Initial candidate spans:",
        merged.query("iou > 0")[["pmid", "start_bern2", "end_bern2"]]
        .drop_duplicates()
        .shape[0],
    )
    filtered = merged.query("iou >= @iou_cutoff & prob > @confidence_cutoff")
    idx = (
        filtered.groupby(["pmid", f"start_{bigbio_suffix}", f"end_{bigbio_suffix}"])[
            "iou"
        ].transform(max)
        == filtered["iou"]
    )
    filtered = filtered[idx]

    # filtered['is_ncbigene']
    display(filtered.head())

    matches = filtered.groupby(
        ["pmid", f"start_{bigbio_suffix}", f"end_{bigbio_suffix}", ]
    ).agg(
        {
            "type_bern2": "first",
            f"type_{bigbio_suffix}": lambda x: x,
            "match": "max",
            'start_bern2':'first',
            'end_bern2':'first',
            'iou':'first', 
            'text':'first',
            'cui_bern2':lambda x: x,
            f'cui_{bigbio_suffix}': lambda x: x,

            # "is_ncbigene": "max",
        }
    )
    print("Filtered candidate spans:", matches.shape[0])
    print("Linking accuracy on matched spans (lower bound):", matches.mean()["match"])
    print(matches.groupby("type_bern2")['match'].mean())
    print("Filter to mentions of genes specifically")
    # print(matches[matches.is_ncbigene].groupby('type_bern2')['match'].mean())
    # print((matches.type_bern2 == 'gene').sum())
    # print(matches.is_ncbigene.sum())
    return matches

# %%
evaluate_bern2_bigbio(bern2_filtered, mm_filtered, "mm")
# Out:
#   0%|          | 0/3230696 [00:00<?, ?it/s]
# Initial candidate spans: 29870
#            pmid       cui_bern2 type_bern2  start_bern2  end_bern2      prob  \
# 64023  25763772  ncbigene:51164       gene          0.0        5.0  0.991746
# 64024  25763772  ncbigene:51164       gene          0.0        5.0  0.991746
# 64302  25763772     OMIM:219700    disease         67.0       82.0  0.999996
# 64394  25763772    MESH:D003550    disease         67.0       82.0  0.999996
# 65044  25763772    MESH:D008171    disease        211.0      228.0  0.997040
#
#       mention_id              text type_mm db_name     db_id  split  start_mm  \
# 64023          1             DCTN4    T116    UMLS  C4308010  train       0.0
# 64024          2             DCTN4    T123    UMLS  C4308010  train       0.0
# 64302          4   cystic fibrosis    T047    UMLS  C0010674  train      67.0
# 64394          4   cystic fibrosis    T047    UMLS  C0010674  train      67.0
# 65044         11  shorter survival    T169    UMLS  C0220921  train     211.0
#
#        end_mm           cui_mm       iou  match
# 64023     5.0  MESH:C000606363  1.000000  False
# 64024     5.0  MESH:C000606363  1.000000  False
# 64302    82.0     MESH:D003550  1.000000  False
# 64394    82.0     MESH:D003550  1.000000   True
# 65044   227.0     MESH:Q000401  0.941176  False
# Filtered candidate spans: 9386
# Linking accuracy on matched spans (lower bound): 0.5397400383549968
#                match
# type_bern2
# disease     0.577894
# drug        0.664594
# gene        0.167602
# species     0.252918
# Filter to mentions of genes specifically
# /var/folders/9r/6d47z63d3jn1kgx93359_9rr0000gq/T/ipykernel_14547/27914975.py:62: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print("Linking accuracy on matched spans (lower bound):", matches.mean()["match"])
#                          type_bern2             type_mm  match  \
# pmid     start_mm end_mm
# 25763772 0.0      5.0          gene        [T116, T123]  False
#          67.0     82.0      disease        [T047, T047]   True
#          211.0    227.0     disease                T169  False
#          1251.0   1259.0    species                T101  False
# 26867927 331.0    339.0     species                T101  False
# ...                             ...                 ...    ...
# 28549178 1390.0   1407.0    disease        [T047, T047]  False
# 28550154 16.0     20.0         drug  [T121, T130, T197]   True
# 28550165 1267.0   1272.0       gene        [T116, T123]  False
#          1341.0   1347.0       gene        [T116, T123]  False
#          1502.0   1508.0       gene        [T116, T123]  False
#
#                                        text
# pmid     start_mm end_mm
# 25763772 0.0      5.0                 DCTN4
#          67.0     82.0      cystic fibrosis
#          211.0    227.0    shorter survival
#          1251.0   1259.0           patients
# 26867927 331.0    339.0            patients
# ...                                     ...
# 28549178 1390.0   1407.0  dystrophic muscle
# 28550154 16.0     20.0                 H2O2
# 28550165 1267.0   1272.0              CLIP2
#          1341.0   1347.0             CLASP2
#          1502.0   1508.0             CLASP2
#
# [9386 rows x 4 columns]

# %% [markdown]
# ## Evaluate BERN2 on GNormPlus

# %%
gnorm_df = dataset_to_df(conhelps.for_config_name(f"gnormplus_bigbio_kb").load_dataset())
print(gnorm_df[['pmid','start','end']].drop_duplicates().shape[0])
gnorm_df['cui'] = 'ncbigene:' + gnorm_df.db_id.astype(str)
output = evaluate_bern2_bigbio(bern2_filtered, gnorm_df, "gnorm",)
# Out:
# Reusing dataset gnormplus_dataset (/Users/david/.cache/huggingface/datasets/gnormplus_dataset/gnormplus_bigbio_kb/1.0.0/1bb16f1b4abf9394b9180cac70edc575cc5e7d32c697f8b9f69ba2f643d2fc95)
#   0%|          | 0/2 [00:00<?, ?it/s]
# 6252
#   0%|          | 0/122409 [00:00<?, ?it/s]
# Initial candidate spans: 4463
#          pmid      cui_bern2 type_bern2  start_bern2  end_bern2      prob  \
# 1624  1281549  ncbigene:2263       gene          209        244  0.997139
# 1631  1281549  ncbigene:2263       gene          250        285  0.990651
# 1678  1281549  ncbigene:1845       gene         1063       1066  0.995078
# 2155  1317062   ncbigene:196       gene          116        127  0.996888
# 2168  1317062   ncbigene:196       gene          133        153  0.996580
#
#      mention_id                                 text type_gnorm db_name db_id  \
# 1624       1353  keratinocyte growth factor receptor       Gene    NCBI  2263
# 1631       1355  fibroblast growth factor receptor 2       Gene    NCBI  2263
# 1678       1362                                  VHR       Gene    NCBI  1845
# 2155       1368                          Ah receptor       Gene    NCBI   196
# 2168       1369                 Ah (dioxin) receptor       Gene    NCBI   196
#
#       split  start_gnorm  end_gnorm      cui_gnorm  iou  match
# 1624  train        209.0      244.0  ncbigene:2263  1.0   True
# 1631  train        250.0      285.0  ncbigene:2263  1.0   True
# 1678  train       1063.0     1066.0  ncbigene:1845  1.0   True
# 2155  train        116.0      127.0   ncbigene:196  1.0   True
# 2168  train        133.0      153.0   ncbigene:196  1.0   True
# Filtered candidate spans: 2204
# Linking accuracy on matched spans (lower bound): 0.911524500907441
#                match  start_bern2   end_bern2       iou
# type_bern2
# disease     0.000000   334.390244  352.585366  0.882529
# drug        0.000000   753.000000  763.800000  0.692408
# gene        0.935289   718.449255  726.489292  0.993177
# Filter to mentions of genes specifically
# /var/folders/9r/6d47z63d3jn1kgx93359_9rr0000gq/T/ipykernel_14547/3086248506.py:64: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print("Linking accuracy on matched spans (lower bound):", matches.mean()["match"])

# %% [markdown]
# ## Evaluate BERN2 on BC5CDR

# %%
bc5cdr_df = dataset_to_df(conhelps.for_config_name(f"bc5cdr_bigbio_kb").load_dataset())
print(bc5cdr_df[['pmid','start','end']].drop_duplicates().shape[0])
bc5cdr_df['cui'] = bc5cdr_df['db_name'] +':' + bc5cdr_df['db_id']
# bc5cdr_df['cui'] = 'ncbigene:' + bc5cdr_df.db_id.astype(str)
bc5cdr_output = evaluate_bern2_bigbio(bern2_filtered, bc5cdr_df, "bc5cdr", subsets=['test'])
# Out:
# Reusing dataset bc5cdr_dataset (/Users/david/.cache/huggingface/datasets/bc5cdr_dataset/bc5cdr_bigbio_kb/1.0.0/f01f16ea9b65ead985bedadf7335195c32297c8f1b09417fc607b102a6757d6f)
#   0%|          | 0/3 [00:00<?, ?it/s]
# 28888
#   0%|          | 0/228288 [00:00<?, ?it/s]
# Initial candidate spans: 6855
#       pmid     cui_bern2 type_bern2  start_bern2  end_bern2      prob  \
# 138  35781  MESH:D003000       drug          126        135  0.999151
# 172  35781  MESH:D009278       drug          137        148  0.999263
# 206  35781  MESH:C009695       drug          153        167  0.999446
# 241  35781  MESH:D003061       drug          202        209  0.998451
# 275  35781  MESH:D005283       drug          211        219  0.997851
#
#     mention_id            text type_bc5cdr db_name    db_id split  \
# 138       6840       clonidine    Chemical    MESH  D003000  test
# 172       6841     naphazoline    Chemical    MESH  D009278  test
# 206       6842  xylometazoline    Chemical    MESH  C009695  test
# 241       6844         codeine    Chemical    MESH  D003061  test
# 275       6845        fentanyl    Chemical    MESH  D005283  test
#
#      start_bc5cdr  end_bc5cdr    cui_bc5cdr  iou  match
# 138         126.0       135.0  MESH:D003000  1.0   True
# 172         137.0       148.0  MESH:D009278  1.0   True
# 206         153.0       167.0  MESH:C009695  1.0   True
# 241         202.0       209.0  MESH:D003061  1.0   True
# 275         211.0       219.0  MESH:D005283  1.0   True
# Filtered candidate spans: 5028
# Linking accuracy on matched spans (lower bound): 0.854813046937152
# type_bern2
# disease    0.798285
# drug       0.906127
# gene       0.000000
# species    0.000000
# Name: match, dtype: float64
# Filter to mentions of genes specifically
# /var/folders/9r/6d47z63d3jn1kgx93359_9rr0000gq/T/ipykernel_54731/107103882.py:64: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print("Linking accuracy on matched spans (lower bound):", matches.mean()["match"])

# %%
bc5cdr_output[~bc5cdr_output.match]
# Out:
#                                  type_bern2 type_bc5cdr  match  start_bern2  \
# pmid     start_bc5cdr end_bc5cdr
# 10087562 19.0         42.0          disease     Disease  False            0
#          392.0        415.0         disease     Disease  False          373
#          525.0        548.0         disease     Disease  False          506
#          782.0        792.0            drug    Chemical  False          782
# 10219427 518.0        525.0         disease     Disease  False          518
# ...                                     ...         ...    ...          ...
# 946593   1167.0       1198.0        disease     Disease  False         1167
# 9578276  809.0        830.0         disease     Disease  False          810
# 9646784  46.0         61.0          disease     Disease  False           34
#          463.0        481.0         disease     Disease  False          463
# 9782254  719.0        730.0         disease     Disease  False          719
#
#                                   end_bern2       iou  \
# pmid     start_bc5cdr end_bc5cdr
# 10087562 19.0         42.0               42  0.547619
#          392.0        415.0             415  0.547619
#          525.0        548.0             548  0.547619
#          782.0        792.0             792  1.000000
# 10219427 518.0        525.0             525  1.000000
# ...                                     ...       ...
# 946593   1167.0       1198.0           1198  1.000000
# 9578276  809.0        830.0             831  0.909091
# 9646784  46.0         61.0               61  0.555556
#          463.0        481.0             481  1.000000
# 9782254  719.0        730.0             730  1.000000
#
#                                                              text  \
# pmid     start_bc5cdr end_bc5cdr
# 10087562 19.0         42.0                ventricular tachycardia
#          392.0        415.0               ventricular tachycardia
#          525.0        548.0               ventricular tachycardia
#          782.0        792.0                            Dubutamine
# 10219427 518.0        525.0                               dyspnea
# ...                                                           ...
# 946593   1167.0       1198.0      central nervous system leukemia
# 9578276  809.0        830.0                 hyper- or hypotension
# 9646784  46.0         61.0                        thromboembolism
#          463.0        481.0                    allergic reactions
# 9782254  719.0        730.0                           dyskinesias
#
#                                      cui_bern2    cui_bc5cdr
# pmid     start_bc5cdr end_bc5cdr
# 10087562 19.0         42.0        MESH:D016171  MESH:D017180
#          392.0        415.0       MESH:D016171  MESH:D017180
#          525.0        548.0       MESH:D016171  MESH:D017180
#          782.0        792.0       MESH:C576824  MESH:D004280
# 10219427 518.0        525.0       MESH:D001049  MESH:D004417
# ...                                        ...           ...
# 946593   1167.0       1198.0      MESH:D016543  MESH:D002493
# 9578276  809.0        830.0       MESH:D007022  MESH:D006973
# 9646784  46.0         61.0        MESH:D019320  MESH:D013923
#          463.0        481.0       MESH:D006967  MESH:D004342
# 9782254  719.0        730.0       MESH:D020820  MESH:D004409
#
# [730 rows x 9 columns]

# %% [markdown]
# ## Evaluate on NCBI-Disease

# %%
ncbi_disease_df = dataset_to_df(conhelps.for_config_name(f"ncbi_disease_bigbio_kb").load_dataset())
ncbi_disease_df['db_name'] = ncbi_disease_df.db_name.map(lambda x: x.upper())
print(ncbi_disease_df[['pmid','start','end']].drop_duplicates().shape[0])
ncbi_disease_df['cui'] = ncbi_disease_df['db_name'] +':' + ncbi_disease_df['db_id']
# ncbi_disease_df['cui'] = 'ncbigene:' + ncbi_disease_df.db_id.astype(str)
output = evaluate_bern2_bigbio(bern2_filtered, ncbi_disease_df, "ncbi_disease")
# Out:
# Reusing dataset ncbi_disease_dataset (/Users/david/.cache/huggingface/datasets/ncbi_disease_dataset/ncbi_disease_bigbio_kb/1.0.0/10a393201e55b403e5d107701b719368f54f1bf3d3438a1233f99be0badeb034)
#   0%|          | 0/3 [00:00<?, ?it/s]
# 6881
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/david/entity_linking/el-robustness-comparison/notebooks/bern2_evaluation.ipynb Cell 41 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/Users/david/entity_linking/el-robustness-comparison/notebooks/bern2_evaluation.ipynb#ch0000040?line=3'>4</a> ncbi_disease_df['cui'] = ncbi_disease_df['db_name'] +':' + ncbi_disease_df['db_id']
#       <a href='vscode-notebook-cell:/Users/david/entity_linking/el-robustness-comparison/notebooks/bern2_evaluation.ipynb#ch0000040?line=4'>5</a> # ncbi_disease_df['cui'] = 'ncbigene:' + ncbi_disease_df.db_id.astype(str)
# ----> <a href='vscode-notebook-cell:/Users/david/entity_linking/el-robustness-comparison/notebooks/bern2_evaluation.ipynb#ch0000040?line=5'>6</a> output = evaluate_bern2_bigbio(bern2_filtered, ncbi_disease_df, "ncbi_disease")
#
# NameError: name 'bern2_filtered' is not defined

# %%
ncbi_disease_df[ncbi_disease_df.cui.map(lambda x: '|' in x and ':' in x)]
# Out:
#           pmid                                         mention_id  \
# 5     10192393                         10192393_D003110|D009369_5
# 33    10196379                         10196379_D001943|D010051_6
# 77    10090885                         10090885_D008232|D007154_3
# 218    8531967                          8531967_D001943|D010051_1
# 223    8531967                          8531967_D001943|D010051_6
# 225    8531967                          8531967_D001943|D010051_8
# 559    1682919                          1682919_D001943|D018307_4
# 657   10417286                         10417286_D002971|D002972_5
# 658   10417286                         10417286_D002971|D002972_6
# 665   10417286                        10417286_D002971|D002972_13
# 669   10417286                        10417286_D002971|D002972_17
# 706    3162536                          3162536_D020388|C537666_1
# 1083    102474                   102474_OMIM:610102|OMIM:612446_0
# 1084    102474                   102474_OMIM:610102|OMIM:612446_1
# 1416  10480348                         10480348_D020388|C537666_0
# 1417  10480348                         10480348_D020388|C537666_1
# 1511   3600794                          3600794_D020388|C537666_1
# 1513   3600794                          3600794_D020388|C537666_3
# 1542     23402                        23402_C535342|OMIM:116800_1
# 1544     23402                        23402_C535342|OMIM:116800_3
# 1706  10930571                 10930571_D019465|D017880|D014564_6
# 1817   1307253                          1307253_D020388|C537666_0
# 1836   7951315                          7951315_D019465|D009421_9
# 1843    409732                   409732_OMIM:610102|OMIM:217000_5
# 1959  10369860                     10369860_C535918|OMIM:115470_4
# 1976   1424237                      1424237_C535918|OMIM:115470_0
# 1977   1424237                      1424237_C535918|OMIM:115470_1
# 1978   1424237                      1424237_C535918|OMIM:115470_2
# 1979   1424237                      1424237_C535918|OMIM:115470_3
# 2004   3029599                          3029599_D009422|D001523_2
# 2178  10441329                         10441329_D008107|D009422_5
# 2304   7493024                          7493024_D001943|D010051_3
# 2331   7759076                          7759076_D001943|D061325_0
# 2358   1248000                 1248000_D010051|D013274|D001661_16
# 2363   1248000  1248000_D010190|D002280|D015179|D001943|D00258...
# 2496   8589721                          8589721_D001943|D010051_3
# 2497   8589721                          8589721_D001943|D010051_4
# 2498   8589721                          8589721_D003110|D008175_5
# 2509   7663517                          7663517_D001943|D010051_1
# 2525  10470286                         10470286_D001859|D012983_5
# 2645   7550349                          7550349_D010051|D001943_4
# 2648   7550349                          7550349_D010051|D001943_7
# 2671  10398279                         10398279_D001943|D010051_7
# 2764  10554035                         10554035_D010181|D010190_9
# 2783   7481765                          7481765_D001943|D010051_2
# 2852   7759075                          7759075_D001943|D010051_5
# 2855   7759075                          7759075_D001943|D010051_8
# 2933   7825586                          7825586_D001943|D010051_3
# 2935   7825586                          7825586_D001943|D010051_5
# 2948   4019732                          4019732_D002971|D002972_3
# 3057   7611277                          7611277_D010051|D001943_5
# 3058   7611277                          7611277_D001943|D011471_6
# 3073   3169738                          3169738_D020388|C537666_0
# 3074   3169738                          3169738_D020388|C537666_1
# 3098  10788334                         10788334_D001943|D010051_2
# 3100  10788334                         10788334_D001943|D010051_4
# 3105  10788334                         10788334_D001943|D010051_9
# 3224   1349199                          1349199_C536288|D007011_3
# 3237   7939630                          7939630_D001943|D010051_0
# 3242   7939630                          7939630_D001943|D010051_5
# 3244   7939630                          7939630_D001943|D010051_7
# 3247   7939630                         7939630_D001943|D010051_10
# 3277  10767326                 10767326_OMIM:602482|OMIM:153400_0
# 3377  10441573                         10441573_D001943|D010051_5
# 3378  10441573                         10441573_D001943|D010051_6
# 3543  10323740                         10323740_D002971|D002972_7
# 3550  10323740                        10323740_D002971|D002972_14
# 3557   2995231                          2995231_D020388|C537666_0
# 3637  10943845                         10943845_D010051|D001943_2
# 3684  10190331                        10190331_D034381|C537845_13
# 3825  10830910                 10830910_D052177|D010181|D013088_7
# 3920  10430930                         10430930_D011218|D017204_0
# 3949  10051005                 10051005_D010051|D016889|D015179_9
# 4256   6086495                          6086495_D020388|C537666_4
# 4318   1981994                          1981994_D000686|D010505_4
# 4324   1981994                         1981994_D000686|D010505_10
# 4435   8500791                          8500791_D006467|D002836_7
# 4436   8500791                          8500791_D006467|D002836_8
# 4437   8500791                          8500791_D006467|D002836_9
# 4511  10500204                         10500204_D020234|D001259_5
# 4542  10807385  10807385_OMIM:604370|OMIM:612555|OMIM:613399|D...
# 4554  10807385    10807385_OMIM:604370|OMIM:612555|OMIM:613399_12
# 4558  10807385                10807385_OMIM:604370|OMIM:612555_16
# 4566   3014348                          3014348_D020388|C537666_0
# 4653  10434119                         10434119_D002971|D002972_6
# 4656  10434119                         10434119_D002971|D002972_9
# 4896   2253937                          2253937_D020388|C537666_2
# 4913  10417280                         10417280_D011218|D017204_0
# 4931   8401501                          8401501_D001943|D061325_2
# 5097  10072428                         10072428_D015179|D013274_8
# 5102  10072428                        10072428_D015179|D009369_13
# 5104  10072428                        10072428_D015179|D013274_15
# 5118   7790377                  7790377_OMIM:202370|OMIM:214100_2
# 5351   9467011          9467011_D001943|D001932|D011471|D007680_5
# 5426   9506545                  9506545_OMIM:164400|OMIM:183090_3
# 5535   9400934                          9400934_D019572|D010871_2
# 5536   9400934                          9400934_D019572|D010871_3
# 5637   9585583     9585583_OMIM:101400|OMIM:123500|OMIM:101600_15
# 5718   9724771                          9724771_D018256|D015179_5
# 5731   9724771                         9724771_D018256|D015179_18
# 5735   9724771                         9724771_D018256|D015179_22
# 5817   9869602                         9869602_D009369|D015179_12
# 5838   9731533                 9731533_D001943|D015179|D009369_11
# 5961   9497246                          9497246_D010051|D009369_5
# 5963   9497246                          9497246_D018567|D001943_7
# 5970   9620771                      9620771_OMIM:201400|C535668_2
# 5974   9620771                      9620771_OMIM:201400|C535668_6
# 6088   9988281                          9988281_D001943|D010051_5
# 6118   8751855                          8751855_D001943|D010051_7
# 6123   8674108                          8674108_D001943|D010051_1
# 6136   9072974                  9072974_D001932|D001943|D011471_0
# 6304   8640236                          8640236_D001943|D010051_8
# 6415   9145677                          9145677_D001943|D010051_6
# 6418   9145677                          9145677_D001943|D010051_9
# 6517   9063749                          9063749_D001943|D010051_0
# 6522   9063749                          9063749_D001943|D010051_5
# 6523   9063749                          9063749_D001943|D010051_6
# 6590   8871666                  8871666_OMIM:612446|OMIM:610102_0
# 6591   8871666                  8871666_OMIM:612446|OMIM:610102_1
# 6592   8871666                  8871666_OMIM:612446|OMIM:610102_2
# 6593   8871666                  8871666_OMIM:612446|OMIM:610102_3
# 6624   8644702          8644702_D011471|D010190|D012878|D008175_7
# 6691   8968716                          8968716_D001943|D010051_0
# 6693   8968716                          8968716_D001943|D010051_2
# 6694   8968716                          8968716_D001943|D010051_3
# 6695   8968716                  8968716_D001943|D010051|D009369_4
# 6700   8968716                          8968716_D001943|D010051_9
# 6755   8733131                          8733131_D012175|D018325_3
#
#                                                    text              type  \
# 5                          colon and some other cancers  CompositeMention
# 33                             breast or ovarian cancer  CompositeMention
# 77    disorder of lymphocyte homeostasis and immunol...  CompositeMention
# 218                           breast and ovarian cancer  CompositeMention
# 223                            breast or ovarian cancer  CompositeMention
# 225                            breast or ovarian cancer  CompositeMention
# 559                  breast and squamous cell neoplasms  CompositeMention
# 657                                    cleft lip/palate   SpecificDisease
# 658                                                CL/P   SpecificDisease
# 665                                                CL/P   SpecificDisease
# 669                                              clefts      DiseaseClass
# 706               Duchenne or Becker muscular dystrophy  CompositeMention
# 1083           Combined genetic deficiency of C6 and C7  CompositeMention
# 1084                  sub-total deficiency of C6 and C7  CompositeMention
# 1416                 Duchenne/Becker muscular dystrophy  CompositeMention
# 1417             Duchenne and Becker muscular dystrophy  CompositeMention
# 1511  Duchenne and the milder Becker muscular dystro...  CompositeMention
# 1513                 Duchenne/Becker muscular dystrophy  CompositeMention
# 1542                                 lamellar cataracts   SpecificDisease
# 1544                       bilateral lamellar cataracts   SpecificDisease
# 1706             facial, limb and genital abnormalities  CompositeMention
# 1817             Duchenne and Becker muscular dystrophy          Modifier
# 1836    craniofacial and central nervous system defects  CompositeMention
# 1843                complement deficiencies (C2 and C7)  CompositeMention
# 1959                                   cat-eye syndrome   SpecificDisease
# 1976                                   cat eye syndrome   SpecificDisease
# 1977                                   cat eye syndrome   SpecificDisease
# 1978                                                CES   SpecificDisease
# 1979                                                CES   SpecificDisease
# 2004              neurological and behavioural disorder      DiseaseClass
# 2178            hepatic and neuro-logical abnormalities  CompositeMention
# 2304                           breast to ovarian cancer          Modifier
# 2331                   breast and breast-ovarian cancer          Modifier
# 2358    ovarian, gastric, and biliary system carcinomas  CompositeMention
# 2363  pancreatic, basal cell, colonic, breast, and c...  CompositeMention
# 2496                          breast and ovarian cancer  CompositeMention
# 2497                          breast and ovarian cancer          Modifier
# 2498                               colon or lung cancer          Modifier
# 2509                       breast and/or ovarian cancer          Modifier
# 2525                        bone and soft tissue tumors  CompositeMention
# 2645                           breast or ovarian cancer  CompositeMention
# 2648                       breast and/or ovarian cancer  CompositeMention
# 2671                         breast and ovarian cancers  CompositeMention
# 2764                        pancreatic cysts and tumors  CompositeMention
# 2783                          breast and ovarian cancer          Modifier
# 2852                       breast and/or ovarian cancer  CompositeMention
# 2855                       breast and/or ovarian cancer  CompositeMention
# 2933                   cancer of the breast and ovaries  CompositeMention
# 2935                          breast and ovarian cancer  CompositeMention
# 2948                                         oral cleft   SpecificDisease
# 3057                           ovarian or breast cancer  CompositeMention
# 3058                         breast and prostate cancer  CompositeMention
# 3073             Duchenne and Becker muscular dystrophy  CompositeMention
# 3074             Duchenne and Becker muscular dystrophy  CompositeMention
# 3098                           breast or ovarian cancer  CompositeMention
# 3100                         breast and ovarian cancers  CompositeMention
# 3105                          breast and ovarian cancer  CompositeMention
# 3224  aplasia or hypoplasia of the thymus and parath...  CompositeMention
# 3237                      breast and ovarian carcinomas  CompositeMention
# 3242                sporadic breast and ovarian cancers   SpecificDisease
# 3244                          breast and ovarian tumors  CompositeMention
# 3247                         breast and ovarian cancers  CompositeMention
# 3277  Haploinsufficiency of the transcription factor...  CompositeMention
# 3377                       breast and/or ovarian cancer  CompositeMention
# 3378                       breast and/or ovarian cancer  CompositeMention
# 3543                                   cleft lip/palate  CompositeMention
# 3550            syndromic forms of cleft lip and palate  CompositeMention
# 3557             Duchenne and Becker muscular dystrophy  CompositeMention
# 3637                         breast and ovarian cancers  CompositeMention
# 3684           syndromic and non-syndromic hearing loss  CompositeMention
# 3825      cysts in the kidney, pancreas, and epididymis  CompositeMention
# 3920                Prader-Willi and angelman syndromes  CompositeMention
# 3949       colorectal, endometrial, and ovarian cancers  CompositeMention
# 4256                    Becker and Duchenne dystrophies  CompositeMention
# 4318                                    MEF-amyloidosis   SpecificDisease
# 4324                                    MEF-amyloidosis          Modifier
# 4435                                         hemophilia          Modifier
# 4436                                         hemophilia   SpecificDisease
# 4437                                         hemophilia   SpecificDisease
# 4511                   progressive gait and limb ataxia  CompositeMention
# 4542            BRCA-linked and sporadic ovarian cancer  CompositeMention
# 4554         BRCA-associated hereditary ovarian cancers   SpecificDisease
# 4558         BRCA1-linked than for BRCA2-linked cancers  CompositeMention
# 4566             Becker and Duchenne muscular dystrophy  CompositeMention
# 4653                    clefts to the lip and/or palate  CompositeMention
# 4656                            cleft lip and/or palate          Modifier
# 4896              Duchenne or Becker muscular dystrophy  CompositeMention
# 4913                Prader-Willi and Angelman syndromes  CompositeMention
# 4931                   breast and breast-ovarian cancer          Modifier
# 5097                      gastric and colorectal cancer  CompositeMention
# 5102                       colorectal and other cancers      DiseaseClass
# 5104                     gastric and colorectal cancers  CompositeMention
# 5118                         PTS1 protein-import defect   SpecificDisease
# 5351  sporadic breast, brain, prostate and kidney ca...          Modifier
# 5426                    spinocerebellar ataxias 1 and 2  CompositeMention
# 5535                         pineal and retinal tumours  CompositeMention
# 5536                     retinal and the pineal tumours  CompositeMention
# 5637   Saethre-Chotzen, Crouzon, and Pfeiffer syndromes  CompositeMention
# 5718                  colorectal adenomas and carcinoma  CompositeMention
# 5731               colorectal adenomas and/or carcinoma  CompositeMention
# 5735                  colorectal adenomas and carcinoma  CompositeMention
# 5817                      colorectal, or other, cancers  CompositeMention
# 5838               colorectal, breast and other cancers  CompositeMention
# 5961                           ovarian or other cancers  CompositeMention
# 5963                      male and female breast cancer  CompositeMention
# 5970                                    ACTH deficiency   SpecificDisease
# 5974                                    ACTH deficiency   SpecificDisease
# 6088            non-familial breast and ovarian cancers  CompositeMention
# 6118                           breast or ovarian cancer          Modifier
# 6123                         breast and ovarian cancers  CompositeMention
# 6136                 brain, breast, and prostate cancer  CompositeMention
# 6304                sporadic breast and ovarian cancers  CompositeMention
# 6415                          breast and ovarian cancer  CompositeMention
# 6418                          breast and ovarian cancer  CompositeMention
# 6517                          breast and ovarian cancer  CompositeMention
# 6522                          breast and ovarian cancer  CompositeMention
# 6523                           breast or ovarian cancer          Modifier
# 6590        combined subtotal deficiencies of C6 and C7   SpecificDisease
# 6591                             C6 and C7 deficiencies  CompositeMention
# 6592          Combined subtotal deficiency of C6 and C7   SpecificDisease
# 6593                                C6 or C7 deficiency  CompositeMention
# 6624         prostatic, pancreas, skin, and lung cancer  CompositeMention
# 6691                          breast and ovarian cancer  CompositeMention
# 6693                          breast and ovarian cancer          Modifier
# 6694                       breast and 79 ovarian cancer          Modifier
# 6695                  breast, ovarian, or other cancers  CompositeMention
# 6700                         breast and ovarian cancers  CompositeMention
# 6755  retinal, cerebellar and spinal haemangioblastomas  CompositeMention
#
#      db_name                                        db_id       split  start  \
# 5       MESH                              D003110|D009369       train    670
# 33      MESH                              D001943|D010051       train    796
# 77      MESH                              D008232|D007154       train    145
# 218     MESH                              D001943|D010051       train    165
# 223     MESH                              D001943|D010051       train   1143
# 225     MESH                              D001943|D010051       train   1503
# 559     MESH                              D001943|D018307       train    742
# 657     MESH                              D002971|D002972       train    278
# 658     MESH                              D002971|D002972       train    296
# 665     MESH                              D002971|D002972       train    454
# 669     MESH                              D002971|D002972       train    593
# 706     MESH                              D020388|C537666       train    146
# 1083    OMIM                      OMIM:610102|OMIM:612446       train      0
# 1084    OMIM                      OMIM:610102|OMIM:612446       train    117
# 1416    MESH                              D020388|C537666       train      0
# 1417    MESH                              D020388|C537666       train    178
# 1511    MESH                              D020388|C537666       train    166
# 1513    MESH                              D020388|C537666       train    608
# 1542    OMIM                          C535342|OMIM:116800       train    137
# 1544    OMIM                          C535342|OMIM:116800       train    745
# 1706    MESH                      D019465|D017880|D014564       train    239
# 1817    MESH                              D020388|C537666       train    293
# 1836    MESH                              D019465|D009421       train    693
# 1843    OMIM                      OMIM:610102|OMIM:217000       train   1106
# 1959    OMIM                          C535918|OMIM:115470       train    247
# 1976    OMIM                          C535918|OMIM:115470       train     20
# 1977    OMIM                          C535918|OMIM:115470       train    128
# 1978    OMIM                          C535918|OMIM:115470       train    146
# 1979    OMIM                          C535918|OMIM:115470       train    188
# 2004    MESH                              D009422|D001523       train    141
# 2178    MESH                              D008107|D009422       train    443
# 2304    MESH                              D001943|D010051       train    560
# 2331    MESH                              D001943|D061325       train     32
# 2358    MESH                      D010051|D013274|D001661       train   1219
# 2363    MESH      D010190|D002280|D015179|D001943|D002583       train   1412
# 2496    MESH                              D001943|D010051       train    155
# 2497    MESH                              D001943|D010051       train    309
# 2498    MESH                              D003110|D008175       train    362
# 2509    MESH                              D001943|D010051       train    325
# 2525    MESH                              D001859|D012983       train    310
# 2645    MESH                              D010051|D001943       train    513
# 2648    MESH                              D010051|D001943       train   1260
# 2671    MESH                              D001943|D010051       train   1296
# 2764    MESH                              D010181|D010190       train    356
# 2783    MESH                              D001943|D010051       train    296
# 2852    MESH                              D001943|D010051       train    516
# 2855    MESH                              D001943|D010051       train   1068
# 2933    MESH                              D001943|D010051       train    184
# 2935    MESH                              D001943|D010051       train    466
# 2948    MESH                              D002971|D002972       train    325
# 3057    MESH                              D010051|D001943       train    586
# 3058    MESH                              D001943|D011471       train    960
# 3073    MESH                              D020388|C537666       train     30
# 3074    MESH                              D020388|C537666       train     95
# 3098    MESH                              D001943|D010051       train    321
# 3100    MESH                              D001943|D010051       train    474
# 3105    MESH                              D001943|D010051       train   1097
# 3224    MESH                              C536288|D007011       train    210
# 3237    MESH                              D001943|D010051       train     27
# 3242    MESH                              D001943|D010051       train    284
# 3244    MESH                              D001943|D010051       train    457
# 3247    MESH                              D001943|D010051       train    784
# 3277    OMIM                      OMIM:602482|OMIM:153400       train      0
# 3377    MESH                              D001943|D010051       train    655
# 3378    MESH                              D001943|D010051       train   1069
# 3543    MESH                              D002971|D002972       train    382
# 3550    MESH                              D002971|D002972       train   1176
# 3557    MESH                              D020388|C537666       train     60
# 3637    MESH                              D010051|D001943       train    187
# 3684    MESH                              D034381|C537845       train    843
# 3825    MESH                      D052177|D010181|D013088       train    326
# 3920    MESH                              D011218|D017204       train     78
# 3949    MESH                      D010051|D016889|D015179       train   1563
# 4256    MESH                              D020388|C537666       train    420
# 4318    MESH                              D000686|D010505       train    246
# 4324    MESH                              D000686|D010505       train    704
# 4435    MESH                              D006467|D002836       train   1336
# 4436    MESH                              D006467|D002836       train   1502
# 4437    MESH                              D006467|D002836       train   1582
# 4511    MESH                              D020234|D001259       train    259
# 4542    OMIM  OMIM:604370|OMIM:612555|OMIM:613399|D010051       train     30
# 4554    OMIM          OMIM:604370|OMIM:612555|OMIM:613399       train   2276
# 4558    OMIM                      OMIM:604370|OMIM:612555       train   2546
# 4566    MESH                              D020388|C537666       train     48
# 4653    MESH                              D002971|D002972       train    286
# 4656    MESH                              D002971|D002972       train    487
# 4896    MESH                              D020388|C537666       train    392
# 4913    MESH                              D011218|D017204       train     27
# 4931    MESH                              D001943|D061325       train    471
# 5097    MESH                              D015179|D013274       train   1027
# 5102    MESH                              D015179|D009369       train   1465
# 5104    MESH                              D015179|D013274       train   1684
# 5118    OMIM                      OMIM:202370|OMIM:214100       train   1391
# 5351    MESH              D001943|D001932|D011471|D007680        test    420
# 5426    OMIM                      OMIM:164400|OMIM:183090        test    304
# 5535    MESH                              D019572|D010871        test    199
# 5536    MESH                              D019572|D010871        test    350
# 5637    OMIM          OMIM:101400|OMIM:123500|OMIM:101600        test   1232
# 5718    MESH                              D018256|D015179        test    252
# 5731    MESH                              D018256|D015179        test   1041
# 5735    MESH                              D018256|D015179        test   1558
# 5817    MESH                              D009369|D015179        test   1285
# 5838    MESH                      D001943|D015179|D009369        test    880
# 5961    MESH                              D010051|D009369        test    424
# 5963    MESH                              D018567|D001943        test    810
# 5970    OMIM                          OMIM:201400|C535668        test    398
# 5974    OMIM                          OMIM:201400|C535668        test   1041
# 6088    MESH                              D001943|D010051        test    437
# 6118    MESH                              D001943|D010051  validation    786
# 6123    MESH                              D001943|D010051  validation    171
# 6136    MESH                      D001932|D001943|D011471  validation     68
# 6304    MESH                              D001943|D010051  validation    536
# 6415    MESH                              D001943|D010051  validation    908
# 6418    MESH                              D001943|D010051  validation   1077
# 6517    MESH                              D001943|D010051  validation     44
# 6522    MESH                              D001943|D010051  validation    763
# 6523    MESH                              D001943|D010051  validation   1270
# 6590    OMIM                      OMIM:612446|OMIM:610102  validation     19
# 6591    OMIM                      OMIM:612446|OMIM:610102  validation    104
# 6592    OMIM                      OMIM:612446|OMIM:610102  validation    128
# 6593    OMIM                      OMIM:612446|OMIM:610102  validation    965
# 6624    MESH              D011471|D010190|D012878|D008175  validation   1471
# 6691    MESH                              D001943|D010051  validation    120
# 6693    MESH                              D001943|D010051  validation    420
# 6694    MESH                              D001943|D010051  validation    720
# 6695    MESH                      D001943|D010051|D009369  validation    921
# 6700    MESH                              D001943|D010051  validation   1525
# 6755    MESH                              D012175|D018325  validation    303
#
#        end                                               cui
# 5      698                              MESH:D003110|D009369
# 33     820                              MESH:D001943|D010051
# 77     207                              MESH:D008232|D007154
# 218    190                              MESH:D001943|D010051
# 223   1167                              MESH:D001943|D010051
# 225   1527                              MESH:D001943|D010051
# 559    776                              MESH:D001943|D018307
# 657    294                              MESH:D002971|D002972
# 658    300                              MESH:D002971|D002972
# 665    458                              MESH:D002971|D002972
# 669    599                              MESH:D002971|D002972
# 706    183                              MESH:D020388|C537666
# 1083    40                      OMIM:OMIM:610102|OMIM:612446
# 1084   150                      OMIM:OMIM:610102|OMIM:612446
# 1416    34                              MESH:D020388|C537666
# 1417   216                              MESH:D020388|C537666
# 1511   217                              MESH:D020388|C537666
# 1513   642                              MESH:D020388|C537666
# 1542   155                          OMIM:C535342|OMIM:116800
# 1544   773                          OMIM:C535342|OMIM:116800
# 1706   277                      MESH:D019465|D017880|D014564
# 1817   331                              MESH:D020388|C537666
# 1836   740                              MESH:D019465|D009421
# 1843  1141                      OMIM:OMIM:610102|OMIM:217000
# 1959   263                          OMIM:C535918|OMIM:115470
# 1976    36                          OMIM:C535918|OMIM:115470
# 1977   144                          OMIM:C535918|OMIM:115470
# 1978   149                          OMIM:C535918|OMIM:115470
# 1979   191                          OMIM:C535918|OMIM:115470
# 2004   178                              MESH:D009422|D001523
# 2178   482                              MESH:D008107|D009422
# 2304   584                              MESH:D001943|D010051
# 2331    64                              MESH:D001943|D061325
# 2358  1266                      MESH:D010051|D013274|D001661
# 2363  1476      MESH:D010190|D002280|D015179|D001943|D002583
# 2496   180                              MESH:D001943|D010051
# 2497   334                              MESH:D001943|D010051
# 2498   382                              MESH:D003110|D008175
# 2509   353                              MESH:D001943|D010051
# 2525   337                              MESH:D001859|D012983
# 2645   537                              MESH:D010051|D001943
# 2648  1288                              MESH:D010051|D001943
# 2671  1322                              MESH:D001943|D010051
# 2764   383                              MESH:D010181|D010190
# 2783   321                              MESH:D001943|D010051
# 2852   544                              MESH:D001943|D010051
# 2855  1096                              MESH:D001943|D010051
# 2933   216                              MESH:D001943|D010051
# 2935   491                              MESH:D001943|D010051
# 2948   335                              MESH:D002971|D002972
# 3057   610                              MESH:D010051|D001943
# 3058   986                              MESH:D001943|D011471
# 3073    68                              MESH:D020388|C537666
# 3074   133                              MESH:D020388|C537666
# 3098   345                              MESH:D001943|D010051
# 3100   500                              MESH:D001943|D010051
# 3105  1122                              MESH:D001943|D010051
# 3224   268                              MESH:C536288|D007011
# 3237    56                              MESH:D001943|D010051
# 3242   319                              MESH:D001943|D010051
# 3244   482                              MESH:D001943|D010051
# 3247   810                              MESH:D001943|D010051
# 3277    63                      OMIM:OMIM:602482|OMIM:153400
# 3377   683                              MESH:D001943|D010051
# 3378  1097                              MESH:D001943|D010051
# 3543   398                              MESH:D002971|D002972
# 3550  1215                              MESH:D002971|D002972
# 3557    98                              MESH:D020388|C537666
# 3637   213                              MESH:D010051|D001943
# 3684   883                              MESH:D034381|C537845
# 3825   371                      MESH:D052177|D010181|D013088
# 3920   113                              MESH:D011218|D017204
# 3949  1607                      MESH:D010051|D016889|D015179
# 4256   451                              MESH:D020388|C537666
# 4318   261                              MESH:D000686|D010505
# 4324   719                              MESH:D000686|D010505
# 4435  1346                              MESH:D006467|D002836
# 4436  1512                              MESH:D006467|D002836
# 4437  1592                              MESH:D006467|D002836
# 4511   291                              MESH:D020234|D001259
# 4542    69  OMIM:OMIM:604370|OMIM:612555|OMIM:613399|D010051
# 4554  2318          OMIM:OMIM:604370|OMIM:612555|OMIM:613399
# 4558  2588                      OMIM:OMIM:604370|OMIM:612555
# 4566    86                              MESH:D020388|C537666
# 4653   317                              MESH:D002971|D002972
# 4656   510                              MESH:D002971|D002972
# 4896   429                              MESH:D020388|C537666
# 4913    62                              MESH:D011218|D017204
# 4931   503                              MESH:D001943|D061325
# 5097  1056                              MESH:D015179|D013274
# 5102  1493                              MESH:D015179|D009369
# 5104  1714                              MESH:D015179|D013274
# 5118  1417                      OMIM:OMIM:202370|OMIM:214100
# 5351   470              MESH:D001943|D001932|D011471|D007680
# 5426   335                      OMIM:OMIM:164400|OMIM:183090
# 5535   225                              MESH:D019572|D010871
# 5536   380                              MESH:D019572|D010871
# 5637  1280          OMIM:OMIM:101400|OMIM:123500|OMIM:101600
# 5718   285                              MESH:D018256|D015179
# 5731  1077                              MESH:D018256|D015179
# 5735  1591                              MESH:D018256|D015179
# 5817  1314                              MESH:D009369|D015179
# 5838   916                      MESH:D001943|D015179|D009369
# 5961   448                              MESH:D010051|D009369
# 5963   839                              MESH:D018567|D001943
# 5970   413                          OMIM:OMIM:201400|C535668
# 5974  1056                          OMIM:OMIM:201400|C535668
# 6088   476                              MESH:D001943|D010051
# 6118   810                              MESH:D001943|D010051
# 6123   197                              MESH:D001943|D010051
# 6136   102                      MESH:D001932|D001943|D011471
# 6304   571                              MESH:D001943|D010051
# 6415   933                              MESH:D001943|D010051
# 6418  1102                              MESH:D001943|D010051
# 6517    69                              MESH:D001943|D010051
# 6522   788                              MESH:D001943|D010051
# 6523  1294                              MESH:D001943|D010051
# 6590    62                      OMIM:OMIM:612446|OMIM:610102
# 6591   126                      OMIM:OMIM:612446|OMIM:610102
# 6592   169                      OMIM:OMIM:612446|OMIM:610102
# 6593   984                      OMIM:OMIM:612446|OMIM:610102
# 6624  1513              MESH:D011471|D010190|D012878|D008175
# 6691   145                              MESH:D001943|D010051
# 6693   445                              MESH:D001943|D010051
# 6694   748                              MESH:D001943|D010051
# 6695   954                      MESH:D001943|D010051|D009369
# 6700  1551                              MESH:D001943|D010051
# 6755   352                              MESH:D012175|D018325

# %% [markdown]
# # Elucidate error in NCBI-Disease Dataset

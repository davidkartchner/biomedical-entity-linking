# %% [markdown]
# # SciSpacy linking evaluation across datasets

# %%
import spacy
import numpy as np 
import pandas as pd
import ujson
import sys
import time
import pickle
import itertools

from tqdm import tqdm
from scispacy.abbreviation import AbbreviationDetector
from scispacy.linking import EntityLinker, CandidateGenerator
from scispacy.umls_utils import UmlsKnowledgeBase
from bigbio.dataloader import BigBioConfigHelpers
from typing import List, Optional
from collections import defaultdict
from matplotlib import pyplot as plt

sys.path.append('..')
from bigbio_utils import dataset_to_df, DATASET_NAMES, CUIS_TO_EXCLUDE, CUIS_TO_REMAP, resolve_abbreviation, dataset_to_documents


# %load_ext autoreload 
# %autoreload 2

# spacy.prefer_gpu()
# spacy.prefer_cpu()

conhelps = BigBioConfigHelpers()

def get_candidates(df, cg, k=50, db='UMLS'):
    '''
        df: pandas.dataframe produced by dataset_to_df()
        cg: SciSpacy candidate generator 
        k: int, number of candidates to generate
    '''
    # Get candidates from SciSpacy
    print("Generating candidates")
    if 'mention_text' not in df.columns:
        df['mention_text'] = df['text']
    candidates = cg(df['mention_text'].tolist(), k=k)

    print("Processing candidates")
    processed_candidates = [[(cand.concept_id, round(max(cand.similarities)), 5) for cand in sorted(cand_list, key=lambda x: round(max(x.similarities), 5), reverse=True)] for cand_list in candidates]
    grouped_candidates = []
    for cand_list in processed_candidates:
        grouped_sublist = []
        for k, g in itertools.groupby(cand_list, key=lambda x: x[1]):
            grouped_sublist.append(list(g))
        grouped_candidates.append(grouped_sublist)
        
    candidate_cuis = [[[f"{db}:{x[0]}" for x in group] for group in cand_list] for cand_list in grouped_candidates]
    candidate_scores = [[x[1] for x in cand_list] for cand_list in processed_candidates]
    df['candidates'] = candidate_cuis
    df['scores'] = candidate_scores


def min_hit_index(gold_cuis, candidates):
    '''
    Find index of first hit in candidates
    '''
    for i, c in enumerate(candidates):
        if c in gold_cuis:
            return i

    return 1000000

def recall_at_k(df, max_k: int=10, filter_null=False):
    '''
    Compute recall@k for all values of k < max_k
    '''

    # Filter rows wilt null values after CUI remapping
    if filter_null:
        before_row_count = df.shape[0]
        df = df[df.db_ids.map(lambda x: len(x) > 0)]
        after_row_count = df.shape[0]
        print(f"Dropped {before_row_count - after_row_count} rows with null db_ids")


    df['min_hit_index'] = df[['db_ids','candidates']].apply(lambda x: min_hit_index(x[0], x[1]), axis=1)

    recall_at_k_dict = {}
    for k in range(1, max_k + 1):
        recall_at_k_dict[k] = (df.min_hit_index < k).mean()

    return recall_at_k_dict


def plot_recall_at_k(recall_dict, max_k=10, legend_key=None):
    
    plt.plot(recall_dict.keys(), recall_dict.values(), marker='o', label=legend_key)
    if legend_key is not None:
        plt.legend()
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
# Your CPU supports instructions that this binary was not compiled to use: SSE3 SSE4.1 SSE4.2 AVX AVX2
# For maximum performance, you can install NMSLIB from sources
# pip install --no-binary :all: nmslib

# %%
kb = UmlsKnowledgeBase()

# %%
umls_cg = CandidateGenerator(name='umls', verbose=True)
mesh_cg = CandidateGenerator(name='mesh', verbose=True)
# Out:
# /nethome/dkartchner3/conda_envs/el-robustness/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator TfidfTransformer from version 0.20.3 when using version 1.1.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /nethome/dkartchner3/conda_envs/el-robustness/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 0.20.3 when using version 1.1.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /nethome/dkartchner3/conda_envs/el-robustness/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator TfidfTransformer from version 0.22.2.post1 when using version 1.1.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /nethome/dkartchner3/conda_envs/el-robustness/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 0.22.2.post1 when using version 1.1.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
# umls2entrez = ujson.load(open('../data/umls2entrez.json'))
umls2mesh_omim = ujson.load(open('../data/umls_2017/umls2mesh_omim.json'))
entrez2umls = ujson.load(open('../data/entrez2umls.json'))

updated_entrez2umls = defaultdict(set)
for key, val in entrez2umls.items():
    updated_entrez2umls[key.replace('ncbigene', 'NCBIGene')] = set([f'UMLS:{val}'])
    

mesh_omim2umls = defaultdict(set)
for key, val in umls2mesh_omim.items():
     for v in val:
        mesh_omim2umls[v].add(f'UMLS:{key}')


mapping_dicts = {"bc5cdr": None,
    "medmentions_full": None,
    "medmentions_st21pv": None,
    "gnormplus": updated_entrez2umls,
    "nlmchem": None,
    "nlm_gene": updated_entrez2umls,
    "ncbi_disease": mesh_omim2umls,}

dataset2cg = {
    "bc5cdr": mesh_cg,
    "medmentions_full": umls_cg,
    "medmentions_st21pv": umls_cg,
    "gnormplus": umls_cg,
    "nlmchem": mesh_cg,
    "nlm_gene": umls_cg,
    "ncbi_disease": umls_cg,
}

dataset2db = {
    "bc5cdr": 'MESH',
    "medmentions_full": 'UMLS',
    "medmentions_st21pv": 'UMLS',
    "gnormplus": 'UMLS',
    "nlmchem": 'MESH',
    "nlm_gene": 'UMLS',
    "ncbi_disease": 'UMLS',
} 

abbreviation_dict = ujson.load(open('../data/abbreviations.json'))

# %%
# name = DATASET_NAMES[-1]
results = {}
for name in DATASET_NAMES:
# for name in ['nlm_gene']:
    results[name] = []
    print(name)

    # Load dataset and deduplicate + remove deprecated identifiers
    dataset = conhelps.for_config_name(f'{name}_bigbio_kb').load_dataset(from_hub=False)
    exclude = CUIS_TO_EXCLUDE[name]
    remap = CUIS_TO_REMAP[name]
    df = dataset_to_df(dataset, cuis_to_exclude=exclude, entity_remapping_dict=remap)
    df = df.query("split == 'test'")
    display(df.head())

    # Get candidate generator and 
    linked_db = dataset2db[name]
    cg = dataset2cg[name]
    cui_map = mapping_dicts[name]

     # Remap identifiers if necessary (since SciSpacy doesn't link to external ids)
    if cui_map is not None:
        df['remapped_db_ids'] = df.db_ids.map(lambda x: list(set().union(*[cui_map[cui] for cui in x])))


    for resolve_abbrevs in [False, True]:
        # Resolve abbreviations
        if resolve_abbrevs:
            df["mention_text"] = df[["document_id", "text"]].apply(
                        lambda x: resolve_abbreviation(x[0], x[1], abbreviation_dict), axis=1
                    )
        else: 
            df['mention_text'] = df['text']

        start_time = time.time()
        # compute linking candidates
        get_candidates(df=df, cg=cg, db=linked_db)

        elapsed = time.time() - start_time
        print("Total time to compute candidates:", elapsed)

        # # Visualize results
        # recall_dict = recall_at_k(df)
        # plt.title(name)
        # plt.ylim(.5,1)
        # plot_recall_at_k(recall_dict, legend_key=f'no_null_filter, abbrev_res={resolve_abbrevs}')
        # if resolve_abbrevs:
        #     recall_dict['resolve_abbrevs'] = True

        # else:
        #     recall_dict['resolve_abbrevs'] = False

        # recall_dict['time'] = elapsed
        # results[name].append(recall_dict)
        # print(recall_dict)

        # nonull_recall_dict = recall_at_k(df, filter_null=True)
        # plot_recall_at_k(nonull_recall_dict, legend_key=f"after_null_filtering, abbrev_res={resolve_abbrevs}")

        # Remap column names
        if resolve_abbrevs:
            df = df.rename({'candidates':'scispacy_resolve_abbrev'}, axis=1)
        else:
            df = df.rename({'candidates':'scispacy'}, axis=1)

    # Save file
    # df.reset_index().to_feather(f'../results/scispacy/{name}_scispacy.feather')
    # display(df.head())

       

    # plt.show()

# with open('../results/scispacy_overall_results.json', 'w') as f:
#     f.write(ujson.dumps(results, indent=2))
# Out:
# Found cached dataset bc5cdr (/nethome/dkartchner3/.cache/huggingface/datasets/bc5cdr/bc5cdr_bigbio_kb/1.0.0/68f03988d9e501c974d9f9987183bf06474858d1318ed0d4e51cfc4584f0f51f)
# bc5cdr
#   0%|          | 0/3 [00:00<?, ?it/s]
#    document_id       offsets                      text        type  \
# 55    10087562     [[0, 18]]        Torsade de pointes   [Disease]
# 58    10087562    [[19, 42]]   ventricular tachycardia   [Disease]
# 70    10087562    [[72, 82]]                dobutamine  [Chemical]
# 56    10087562  [[111, 133]]    dilated cardiomyopathy   [Disease]
# 57    10087562  [[138, 162]]  congestive heart failure   [Disease]
#
#             db_ids split  mention_id
# 55  [MESH:D016171]  test  10087562.1
# 58  [MESH:D017180]  test  10087562.2
# 70  [MESH:D004280]  test  10087562.3
# 56  [MESH:D002311]  test  10087562.4
# 57  [MESH:D006333]  test  10087562.5
# Generating candidates
# Generating candidates for 9750 mentions
# Number of empty vectors: 82
# /nethome/dkartchner3/conda_envs/el-robustness/lib/python3.9/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /nethome/dkartchner3/conda_envs/el-robustness/lib/python3.9/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# Finding neighbors took 1.991395 seconds
# Processing candidates
# Total time to compute candidates: 3.866079092025757
# Generating candidates
# Generating candidates for 9750 mentions
# Number of empty vectors: 18
# /nethome/dkartchner3/conda_envs/el-robustness/lib/python3.9/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /nethome/dkartchner3/conda_envs/el-robustness/lib/python3.9/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# Finding neighbors took 0.97954 seconds
# Processing candidates
# Found cached dataset medmentions (/nethome/dkartchner3/.cache/huggingface/datasets/medmentions/medmentions_full_bigbio_kb/1.0.0/4ed5b6a69d807969022e559198c5a7386b9a978268a558758a090db6b451d6c4)
# Total time to compute candidates: 2.8138649463653564
# medmentions_full
#   0%|          | 0/3 [00:00<?, ?it/s]
#     document_id     offsets                      text    type  \
# 98     25847295   [[0, 24]]  Nonylphenol diethoxylate  [T131]
# 134    25847295  [[25, 33]]                  inhibits  [T052]
# 141    25847295  [[34, 43]]                 apoptosis  [T043]
# 147    25847295  [[44, 51]]                   induced  [T169]
# 154    25847295  [[55, 65]]                PC12 cells  [T025]
#
#               db_ids split  mention_id
# 98   [UMLS:C1254354]  test  25847295.1
# 134  [UMLS:C3463820]  test  25847295.2
# 141  [UMLS:C0162638]  test  25847295.3
# 147  [UMLS:C0205263]  test  25847295.4
# 154  [UMLS:C0085262]  test  25847295.5
# Generating candidates
# Generating candidates for 70359 mentions
# Number of empty vectors: 23
# /nethome/dkartchner3/conda_envs/el-robustness/lib/python3.9/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /nethome/dkartchner3/conda_envs/el-robustness/lib/python3.9/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# Finding neighbors took 18.311251 seconds
# Processing candidates
# Total time to compute candidates: 52.31352758407593
# Generating candidates
# Generating candidates for 70359 mentions
# Number of empty vectors: 22
# /nethome/dkartchner3/conda_envs/el-robustness/lib/python3.9/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /nethome/dkartchner3/conda_envs/el-robustness/lib/python3.9/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# Finding neighbors took 8.532194 seconds
# Processing candidates
# Found cached dataset medmentions (/nethome/dkartchner3/.cache/huggingface/datasets/medmentions/medmentions_st21pv_bigbio_kb/1.0.0/4ed5b6a69d807969022e559198c5a7386b9a978268a558758a090db6b451d6c4)
# Total time to compute candidates: 42.32234072685242
# medmentions_st21pv
#   0%|          | 0/3 [00:00<?, ?it/s]
#    document_id       offsets           text    type           db_ids split  \
# 82    25847295    [[34, 43]]      apoptosis  [T038]  [UMLS:C0162638]  test
# 87    25847295    [[55, 65]]     PC12 cells  [T017]  [UMLS:C0085262]  test
# 73    25847295  [[137, 144]]        present  [T033]  [UMLS:C0150312]  test
# 78    25847295  [[206, 219]]  toxic effects  [T037]  [UMLS:C0600688]  test
# 79    25847295  [[259, 268]]      Apoptosis  [T038]  [UMLS:C0162638]  test
#
#     mention_id
# 82  25847295.1
# 87  25847295.2
# 73  25847295.3
# 78  25847295.4
# 79  25847295.5
# Generating candidates
# Generating candidates for 40143 mentions
# Number of empty vectors: 19
# /nethome/dkartchner3/conda_envs/el-robustness/lib/python3.9/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /nethome/dkartchner3/conda_envs/el-robustness/lib/python3.9/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# Finding neighbors took 4.663302 seconds
# Processing candidates
# Total time to compute candidates: 28.869887828826904
# Generating candidates
# Generating candidates for 40143 mentions
# Number of empty vectors: 18
# /nethome/dkartchner3/conda_envs/el-robustness/lib/python3.9/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /nethome/dkartchner3/conda_envs/el-robustness/lib/python3.9/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# Finding neighbors took 4.13249 seconds
# Processing candidates
# Found cached dataset gnormplus (/nethome/dkartchner3/.cache/huggingface/datasets/gnormplus/gnormplus_bigbio_kb/1.0.0/97a2714b58185305591c949b067cea2febfca2447016096c3d08021d84bf7b69)
# Total time to compute candidates: 14.749157905578613
# gnormplus
#   0%|          | 0/2 [00:00<?, ?it/s]
#    document_id       offsets       text    type            db_ids split  \
# 0     10022127      [[0, 9]]  TIF1gamma  [Gene]  [NCBIGene:51592]  test
# 7     10022127  [[211, 220]]  TIF1gamma  [Gene]  [NCBIGene:51592]  test
# 8     10022127  [[233, 242]]  TIF1alpha  [Gene]   [NCBIGene:8805]  test
# 9     10022127  [[247, 255]]   TIF1beta  [Gene]  [NCBIGene:10155]  test
# 10    10022127  [[274, 282]]   TIF1beta  [Gene]  [NCBIGene:10155]  test
#
#     mention_id
# 0   10022127.1
# 7   10022127.2
# 8   10022127.3
# 9   10022127.4
# 10  10022127.5
# Generating candidates
# Generating candidates for 3222 mentions
# Number of empty vectors: 0
# /nethome/dkartchner3/conda_envs/el-robustness/lib/python3.9/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /nethome/dkartchner3/conda_envs/el-robustness/lib/python3.9/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# Finding neighbors took 0.350383 seconds
# Processing candidates
# Total time to compute candidates: 1.118152141571045
# Generating candidates
# Generating candidates for 3222 mentions
# Number of empty vectors: 0
# /nethome/dkartchner3/conda_envs/el-robustness/lib/python3.9/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /nethome/dkartchner3/conda_envs/el-robustness/lib/python3.9/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# Finding neighbors took 0.358304 seconds
# Processing candidates
# Found cached dataset nlmchem (/nethome/dkartchner3/.cache/huggingface/datasets/nlmchem/nlmchem_bigbio_kb/1.0.0/66bcefa38a4fe5d4ba1a0993a516040bad028699fbe3ef935f95532596668131)
# Total time to compute candidates: 1.193880558013916
# nlmchem
#   0%|          | 0/3 [00:00<?, ?it/s]
#     document_id           offsets              text        type  \
# 190     1325037    [[6667, 6676]]         67Gallium  [Chemical]
# 191     1325037    [[7086, 7097]]       CHOP regime  [Chemical]
# 184     1325037  [[11306, 11322]]  cyclophosphamide  [Chemical]
# 185     1325037  [[11324, 11336]]      daunorubicin  [Chemical]
# 186     1325037  [[11338, 11348]]        vincrstine  [Chemical]
#
#                                                 db_ids split mention_id
# 190                                     [MESH:D005710]  test  1325037.1
# 191  [MESH:D011239, MESH:D003520, MESH:D014750, MES...  test  1325037.2
# 184                                     [MESH:D003520]  test  1325037.3
# 185                                     [MESH:D003630]  test  1325037.4
# 186                                     [MESH:D014750]  test  1325037.5
# Generating candidates
# Generating candidates for 11624 mentions
# Number of empty vectors: 326
# /nethome/dkartchner3/conda_envs/el-robustness/lib/python3.9/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /nethome/dkartchner3/conda_envs/el-robustness/lib/python3.9/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# Finding neighbors took 0.79052 seconds
# Processing candidates
# Total time to compute candidates: 2.840824842453003
# Generating candidates
# Generating candidates for 11624 mentions
# Number of empty vectors: 307
# /nethome/dkartchner3/conda_envs/el-robustness/lib/python3.9/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /nethome/dkartchner3/conda_envs/el-robustness/lib/python3.9/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# Finding neighbors took 15.147075 seconds
# Processing candidates
# Found cached dataset nlm_gene (/nethome/dkartchner3/.cache/huggingface/datasets/nlm_gene/nlm_gene_bigbio_kb/1.0.0/92249f0c0c401d2d902c7a0af6d76ca2e535383a56c0c4d4099036c7c0dc9581)
# Total time to compute candidates: 17.53421664237976
# nlm_gene
#   0%|          | 0/2 [00:00<?, ?it/s]
#    document_id       offsets                                            text  \
# 69    12486105    [[70, 77]]                                         DEC-205
# 46    12486105  [[131, 171]]        major histocompatibility complex class I
# 58    12486105  [[196, 199]]                                             CD8
# 59    12486105  [[319, 365]]  major histocompatibility complex (MHC) class I
# 60    12486105  [[397, 404]]                                         DEC-205
#
#           type            db_ids split  mention_id
# 69   [GENERIF]  [NCBIGene:17076]  test  12486105.1
# 46  [STARGENE]  [NCBIGene:14972]  test  12486105.2
# 58      [Gene]  [NCBIGene:12526]  test  12486105.3
# 59  [STARGENE]  [NCBIGene:14972]  test  12486105.4
# 60   [GENERIF]  [NCBIGene:17076]  test  12486105.5
# Generating candidates
# Generating candidates for 2729 mentions
# Number of empty vectors: 5
# /nethome/dkartchner3/conda_envs/el-robustness/lib/python3.9/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /nethome/dkartchner3/conda_envs/el-robustness/lib/python3.9/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# Finding neighbors took 0.27962 seconds
# Processing candidates
# Total time to compute candidates: 0.9559614658355713
# Generating candidates
# Generating candidates for 2729 mentions
# Number of empty vectors: 5
# /nethome/dkartchner3/conda_envs/el-robustness/lib/python3.9/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /nethome/dkartchner3/conda_envs/el-robustness/lib/python3.9/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# Finding neighbors took 0.339645 seconds
# Processing candidates
# Found cached dataset ncbi_disease (/nethome/dkartchner3/.cache/huggingface/datasets/ncbi_disease/ncbi_disease_bigbio_kb/1.0.0/e6b217666a5647d5abc614785b2caad62f1d72a94d1631b86c0f615b75dcc865)
# Total time to compute candidates: 1.2165265083312988
# ncbi_disease
#   0%|          | 0/3 [00:00<?, ?it/s]
#      document_id       offsets                             text  \
# 5863     9288106    [[40, 61]]            ataxia-telangiectasia
# 5872     9288106    [[72, 97]]        sporadic T-cell leukaemia
# 5873     9288106   [[99, 120]]            Ataxia-telangiectasia
# 5849     9288106  [[122, 125]]                              A-T
# 5852     9288106  [[132, 163]]  recessive multi-system disorder
#
#                    type          db_ids split mention_id
# 5863         [Modifier]  [MESH:D001260]  test  9288106.1
# 5872  [SpecificDisease]  [MESH:D015458]  test  9288106.2
# 5873  [SpecificDisease]  [MESH:D001260]  test  9288106.3
# 5849  [SpecificDisease]  [MESH:D001260]  test  9288106.4
# 5852     [DiseaseClass]  [MESH:D030342]  test  9288106.5
# Generating candidates
# Generating candidates for 960 mentions
# Number of empty vectors: 0
# Finding neighbors took 0.135327 seconds
# /nethome/dkartchner3/conda_envs/el-robustness/lib/python3.9/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /nethome/dkartchner3/conda_envs/el-robustness/lib/python3.9/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# Processing candidates
# Total time to compute candidates: 0.5287775993347168
# Generating candidates
# Generating candidates for 960 mentions
# Number of empty vectors: 0
# Finding neighbors took 0.0938 seconds
# Processing candidates
# Total time to compute candidates: 0.2853991985321045
# /nethome/dkartchner3/conda_envs/el-robustness/lib/python3.9/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /nethome/dkartchner3/conda_envs/el-robustness/lib/python3.9/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]

# %%
data = [("apple", 5), ("banana", 2), ("cherry", 5), ("date", 3), ("elderberry", 1), ("fig", 5)]

# sort the list of tuples by the second element of each tuple
sorted_data = sorted(data, key=lambda x: x[1])

# group the sorted data by the same second element value
result = []
for k, g in itertools.groupby(sorted_data, key=lambda x: x[1]):
    result.append(list(g))

print(result)
# Out:
# [[('elderberry', 1)], [('banana', 2)], [('date', 3)], [('apple', 5), ('cherry', 5), ('fig', 5)]]

# %%
df
# Out:
#      document_id         offsets       text    type db_ids split  \
# 0       10022127        [[0, 9]]  TIF1gamma  [Gene]     []  test
# 7       10022127    [[211, 220]]  TIF1gamma  [Gene]     []  test
# 8       10022127    [[233, 242]]  TIF1alpha  [Gene]     []  test
# 9       10022127    [[247, 255]]   TIF1beta  [Gene]     []  test
# 10      10022127    [[274, 282]]   TIF1beta  [Gene]     []  test
# ...          ...             ...        ...     ...    ...   ...
# 6243     9932288    [[606, 609]]        XT3  [Gene]     []  test
# 6244     9932288    [[739, 742]]        XT2  [Gene]     []  test
# 6245     9932288    [[747, 750]]        XT3  [Gene]     []  test
# 6239     9932288  [[1139, 1142]]        XT2  [Gene]     []  test
# 6240     9932288  [[1147, 1150]]        XT3  [Gene]     []  test
#
#       first_offset  last_offset  mention_id mention_text  \
# 0                0            9  10022127.1    TIF1gamma
# 7              211          220  10022127.2    TIF1gamma
# 8              233          242  10022127.3    TIF1alpha
# 9              247          255  10022127.4     TIF1beta
# 10             274          282  10022127.5     TIF1beta
# ...            ...          ...         ...          ...
# 6243           606          609   9932288.3          XT3
# 6244           739          742   9932288.4          XT2
# 6245           747          750   9932288.5          XT3
# 6239          1139         1142   9932288.6          XT2
# 6240          1147         1150   9932288.7          XT3
#
#                                                scispacy  \
# 0     [UMLS:C1424158, UMLS:C3273663, UMLS:C1504843, ...
# 7     [UMLS:C1424158, UMLS:C3273663, UMLS:C1504843, ...
# 8     [UMLS:C0906566, UMLS:C3888335, UMLS:C0965644, ...
# 9     [UMLS:C1506870, UMLS:C1704839, UMLS:C1456422, ...
# 10    [UMLS:C1506870, UMLS:C1704839, UMLS:C1456422, ...
# ...                                                 ...
# 6243  [UMLS:C1429013, UMLS:C1619921, UMLS:C1414488, ...
# 6244  [UMLS:C1423547, UMLS:C1308965, UMLS:C0529768, ...
# 6245  [UMLS:C1429013, UMLS:C1619921, UMLS:C1414488, ...
# 6239  [UMLS:C1423547, UMLS:C1308965, UMLS:C0529768, ...
# 6240  [UMLS:C1429013, UMLS:C1619921, UMLS:C1414488, ...
#
#                                                  scores  min_hit_index  \
# 0     [1.0, 1.0, 0.8456882238388062, 0.8403988480567...        1000000
# 7     [1.0, 1.0, 0.8456882238388062, 0.8403988480567...        1000000
# 8     [1.0, 1.0, 0.7551559805870056, 0.6794222593307...        1000000
# 9     [0.8167135119438171, 0.8167135119438171, 0.806...        1000000
# 10    [0.8167135119438171, 0.8167135119438171, 0.806...        1000000
# ...                                                 ...            ...
# 6243  [1.0, 0.7857595086097717, 0.7801902890205383, ...        1000000
# 6244  [1.0, 0.7665935158729553, 0.7482038736343384, ...        1000000
# 6245  [1.0, 0.7857595086097717, 0.7801902890205383, ...        1000000
# 6239  [1.0, 0.7665935158729553, 0.7482038736343384, ...        1000000
# 6240  [1.0, 0.7857595086097717, 0.7801902890205383, ...        1000000
#
#                                 scispacy_resolve_abbrev
# 0     [UMLS:C1424158, UMLS:C3273663, UMLS:C1504843, ...
# 7     [UMLS:C1424158, UMLS:C3273663, UMLS:C1504843, ...
# 8     [UMLS:C0906566, UMLS:C3888335, UMLS:C0965644, ...
# 9     [UMLS:C1506870, UMLS:C1704839, UMLS:C1456422, ...
# 10    [UMLS:C1506870, UMLS:C1704839, UMLS:C1456422, ...
# ...                                                 ...
# 6243  [UMLS:C1429013, UMLS:C1619921, UMLS:C1414488, ...
# 6244  [UMLS:C1423547, UMLS:C1308965, UMLS:C0529768, ...
# 6245  [UMLS:C1429013, UMLS:C1619921, UMLS:C1414488, ...
# 6239  [UMLS:C1423547, UMLS:C1308965, UMLS:C0529768, ...
# 6240  [UMLS:C1429013, UMLS:C1619921, UMLS:C1414488, ...
#
# [3222 rows x 14 columns]

# %%
df.index
# Out:
# Int64Index([   55,    58,    70,    56,    57,    59,    60,    61,    62,
#                63,
#             ...
#             28749, 28750, 28751, 28753, 28754, 28734, 28735, 28737, 28738,
#             28739],
#            dtype='int64', length=9750)

# %%
df
# Out:
#      document_id         offsets                                     text  \
# 2       10021369      [[43, 76]]        adenomatous polyposis coli tumour
# 3       10021369     [[93, 132]]  adenomatous polyposis coli (APC) tumour
# 1       10021369    [[357, 372]]                          colon carcinoma
# 4       10021369    [[955, 970]]                          colon carcinoma
# 0       10021369  [[1090, 1096]]                                   cancer
# ...          ...             ...                                      ...
# 6804     9988281   [[996, 1015]]                      breast malignancies
# 6794     9988281  [[1123, 1147]]                 invasive lobular cancers
# 6795     9988281  [[1152, 1179]]              low-grade ductal carcinomas
# 6797     9988281  [[1269, 1286]]                        ductal carcinomas
# 6798     9988281  [[1387, 1410]]                  sporadic breast cancers
#
#                    type                                             db_ids  \
# 2            [Modifier]      [UMLS:C0032580, UMLS:C2713443, UMLS:C2713442]
# 3            [Modifier]      [UMLS:C0032580, UMLS:C2713443, UMLS:C2713442]
# 1            [Modifier]                     [UMLS:C0009375, UMLS:C0007102]
# 4            [Modifier]                     [UMLS:C0009375, UMLS:C0007102]
# 0     [SpecificDisease]  [UMLS:C0006826, UMLS:C0086692, UMLS:C4282132, ...
# ...                 ...                                                ...
# 6804  [SpecificDisease]  [UMLS:C1257930, UMLS:C1257931, UMLS:C1458155, ...
# 6794     [DiseaseClass]                                    [UMLS:C0206692]
# 6795  [SpecificDisease]                                    [UMLS:C1176475]
# 6797  [SpecificDisease]                                    [UMLS:C1176475]
# 6798  [SpecificDisease]  [UMLS:C1257930, UMLS:C1257931, UMLS:C1458155, ...
#
#       split  first_offset  last_offset  mention_id  \
# 2     train            43           76  10021369.1
# 3     train            93          132  10021369.2
# 1     train           357          372  10021369.3
# 4     train           955          970  10021369.4
# 0     train          1090         1096  10021369.5
# ...     ...           ...          ...         ...
# 6804   test           996         1015   9988281.7
# 6794   test          1123         1147   9988281.8
# 6795   test          1152         1179   9988281.9
# 6797   test          1269         1286  9988281.10
# 6798   test          1387         1410  9988281.11
#
#                                              candidates  \
# 2     [MESH:D011125, MESH:D025601, MESH:D017491, MES...
# 3     [MESH:D011125, MESH:D025601, MESH:D017491, MES...
# 1     [MESH:D002277, MESH:D015179, MESH:D018267, MES...
# 4     [MESH:D002277, MESH:D015179, MESH:D018267, MES...
# 0     [MESH:D009369, MESH:D001005, MESH:D009062, MES...
# ...                                                 ...
# 6804  [MESH:D001943, MESH:D019337, MESH:D009369, MES...
# 6794  [MESH:D002820, MESH:D058365, MESH:D000072742, ...
# 6795  [MESH:D044584, MESH:D002285, MESH:D018270, MES...
# 6797  [MESH:D044584, MESH:D002285, MESH:D018270, MES...
# 6798  [MESH:D001943, MESH:D018567, MESH:D019313, MES...
#
#                                                  scores  min_hit_index
# 2     [0.8481286764144897, 0.7981353998184204, 0.780...        1000000
# 3     [0.7652613520622253, 0.7201526761054993, 0.704...        1000000
# 1     [0.8241872191429138, 0.7547714114189148, 0.678...        1000000
# 4     [0.8241872191429138, 0.7547714114189148, 0.678...        1000000
# 0     [1.0, 0.8050955533981323, 0.7720818519592285, ...        1000000
# ...                                                 ...            ...
# 6804  [0.6743446588516235, 0.6187905073165894, 0.596...        1000000
# 6794  [0.565710723400116, 0.5440589189529419, 0.5105...        1000000
# 6795  [0.6658602356910706, 0.5461992025375366, 0.534...        1000000
# 6797  [0.8752213716506958, 0.7109460234642029, 0.703...        1000000
# 6798  [0.7133800983428955, 0.6205758452415466, 0.608...        1000000
#
# [6805 rows x 12 columns]

# %% [markdown]
# ### Load BigScience Biomedical dataset utils

# %%
df.text.tolist()[:1]
# Out:
# ['22-oxacalcitriol']

# %%
df.shape
df['scispacy_candidates'] = candidates

# %%
df.head()
# Out:
#    document_id       offsets                           text        type  \
# 0     10027919     [[0, 16]]               22-oxacalcitriol  [Chemical]
# 23    10027919    [[28, 57]]  secondary hyperparathyroidism   [Disease]
# 32    10027919    [[75, 92]]              low bone turnover   [Disease]
# 1     10027919  [[106, 119]]                  renal failure   [Disease]
# 5     10027919  [[133, 143]]                     Calcitriol  [Chemical]
#
#             db_ids       split  first_offset  last_offset  mention_id  \
# 0   [MESH:C051883]  validation             0           16  10027919.1
# 23  [MESH:D006962]  validation            28           57  10027919.2
# 32  [MESH:D001851]  validation            75           92  10027919.3
# 1   [MESH:D051437]  validation           106          119  10027919.4
# 5   [MESH:D002117]  validation           133          143  10027919.5
#
#                                   scispacy_candidates
# 0   [(C0006668, [Calcitrin], [0.48612040281295776]...
# 23  [(C0020502, [hyperparathyroidism, HYPERPARATHY...
# 32  [(C0031227, [turnover, turnovers], [0.80338394...
# 1   [(C0001623, [adrenal failure], [0.843946099281...
# 5   [(C0006668, [Calcitrin], [0.779952347278595]),...

# %%
get_candidates(df, mesh_cg)
# Out:
# Generating candidates for 28816 mentions
# Number of empty vectors: 192
# Finding neighbors took 1.486444 seconds

# %%
df
# Out:
#       document_id         offsets  \
# 0        10027919       [[0, 16]]
# 23       10027919      [[28, 57]]
# 32       10027919      [[75, 92]]
# 1        10027919    [[106, 119]]
# 5        10027919    [[133, 143]]
# ...           ...             ...
# 28802     9952311  [[1145, 1156]]
# 28803     9952311  [[1332, 1340]]
# 28804     9952311  [[1612, 1615]]
# 28807     9952311  [[1799, 1802]]
# 28808     9952311  [[1838, 1888]]
#
#                                                     text        type  \
# 0                                       22-oxacalcitriol  [Chemical]
# 23                         secondary hyperparathyroidism   [Disease]
# 32                                     low bone turnover   [Disease]
# 1                                          renal failure   [Disease]
# 5                                             Calcitriol  [Chemical]
# ...                                                  ...         ...
# 28802                                        bradycardia   [Disease]
# 28803                                           swelling   [Disease]
# 28804                                                ADR  [Chemical]
# 28807                                                ADR  [Chemical]
# 28808  mitochondrial structural and functional impair...   [Disease]
#
#                db_ids       split  first_offset  last_offset  mention_id  \
# 0      [MESH:C051883]  validation             0           16  10027919.1
# 23     [MESH:D006962]  validation            28           57  10027919.2
# 32     [MESH:D001851]  validation            75           92  10027919.3
# 1      [MESH:D051437]  validation           106          119  10027919.4
# 5      [MESH:D002117]  validation           133          143  10027919.5
# ...               ...         ...           ...          ...         ...
# 28802  [MESH:D001919]  validation          1145         1156  9952311.13
# 28803  [MESH:D004487]  validation          1332         1340  9952311.14
# 28804  [MESH:D004317]  validation          1612         1615  9952311.15
# 28807  [MESH:D004317]  validation          1799         1802  9952311.16
# 28808  [MESH:D028361]  validation          1838         1888  9952311.17
#
#                                      scispacy_candidates  \
# 0      [(C0006668, [Calcitrin], [0.48612040281295776]...
# 23     [(C0020502, [hyperparathyroidism, HYPERPARATHY...
# 32     [(C0031227, [turnover, turnovers], [0.80338394...
# 1      [(C0001623, [adrenal failure], [0.843946099281...
# 5      [(C0006668, [Calcitrin], [0.779952347278595]),...
# ...                                                  ...
# 28802  [(C0085610, [bradycardia sinus, Sinus Bradycar...
# 28803  [(C0013604, [SWELLING], [1.0]), (C0038999, [SW...
# 28804  [(C0013089, [ADR, adr], [1.0, 1.0]), (C0031831...
# 28807  [(C0013089, [ADR, adr], [1.0, 1.0]), (C0031831...
# 28808  [(C0026237, [Mitochondrial structure, Mitochon...
#
#                                               candidates  \
# 0      [D002117, D018167, D002116, D002762, D065668, ...
# 23     [D006962, D006961, D007037, D049950, D007011, ...
# 32     [D016723, D010563, D063269, D001851, D001842, ...
# 1      [D051437, D058186, D007676, D006333, D017093, ...
# 5      [D002117, D018167, D002116, D002762, D002119, ...
# ...                                                  ...
# 28802  [D001919, D002299, D013610, D009543, D009615, ...
# 28803  [D001929, D008933, D029743, D013546, D034241, ...
# 28804  [D003348, D000070780, D005039, D004837, D00547...
# 28807  [D003348, D000070780, D005039, D004837, D00547...
# 28808  [D063991, D063154, D024101, D050259, D063993, ...
#
#                                                   scores
# 0      [0.6363470554351807, 0.5304351449012756, 0.480...
# 23     [1.0, 0.8202486634254456, 0.7772029042243958, ...
# 32     [0.8778586983680725, 0.5458993315696716, 0.521...
# 1      [1.0, 0.8490089178085327, 0.7505104541778564, ...
# 5      [1.0, 0.8335597515106201, 0.7767539024353027, ...
# ...                                                  ...
# 28802  [1.0, 0.5819385647773743, 0.4919999837875366, ...
# 28803  [0.8281610608100891, 0.6587820649147034, 0.612...
# 28804  [0.37323009967803955, 0.36630523204803467, 0.3...
# 28807  [0.37323009967803955, 0.36630523204803467, 0.3...
# 28808  [0.5653169751167297, 0.49833691120147705, 0.47...
#
# [28816 rows x 12 columns]

# %%
[(cand.concept_id, max(cand.similarities)) for cand in sorted(c, key=lambda x: max(x.similarities), reverse=True)]
# Out:
# [('C0043872', 1.0),
#  ('C0654280', 0.68692547082901),
#  ('C0006674', 0.6379262804985046),
#  ('C2698951', 0.6379262804985046),
#  ('C3714610', 0.6379262804985046),
#  ('C3207494', 0.5465289950370789),
#  ('C3207493', 0.5359896421432495),
#  ('C3821496', 0.5242783427238464),
#  ('C2825373', 0.5113562941551208),
#  ('C0046706', 0.5093730688095093),
#  ('C4074702', 0.5073736310005188),
#  ('C5203521', 0.5073736310005188),
#  ('C0108082', 0.4992302656173706),
#  ('C3657722', 0.4992302656173706),
#  ('C3207492', 0.49131691455841064),
#  ('C0006668', 0.48612040281295776)]

# %%
conhelps = BigBioConfigHelpers()
print("found {} dataset configs from {} datasets".format(
    len(conhelps),
    len(conhelps.available_dataset_names)
))
# Out:
# found 453 dataset configs from 127 datasets

# %% [markdown]
# ### Load SciSpacy models and UMLS KB
#
# **Models considered**
# * SciSpacy Large
# * SciSpacy + SciBERT
#
# Depending on the dataset in question, we link entities to either MeSH or UMLS

# %%
nlp_lg = spacy.load("en_core_sci_lg")
nlp_scibert = spacy.load("en_core_sci_scibert")
nlp_lg.add_pipe("abbreviation_detector")
nlp_scibert.add_pipe("abbreviation_detector")

# %%
nlp_lg.add_pipe("scispacy_linker", config={"resolve_abbreviations": True, "linker_name": "umls", 'filter_for_definitions':False, "max_entities_per_mention":100, "no_definition_threshold":.7, "threshold":0.4})
nlp_scibert.add_pipe("scispacy_linker", config={"resolve_abbreviations": True, "linker_name": "umls", 'filter_for_definitions':False, "max_entities_per_mention":100, "no_definition_threshold":.7, "threshold":0.4})

# %%
lg_mesh = spacy.load("en_core_sci_lg")
lg_mesh.add_pipe("abbreviation_detector")
lg_mesh.add_pipe("scispacy_linker", config={"resolve_abbreviations": True, 
                                            "linker_name": "mesh", 
                                            'filter_for_definitions':False, 
                                            "max_entities_per_mention":100, 
                                            "no_definition_threshold":.7, "threshold":0.4})
scibert_mesh = spacy.load("en_core_sci_scibert")
scibert_mesh.add_pipe("abbreviation_detector")
scibert_mesh.add_pipe("scispacy_linker", config={"resolve_abbreviations": True, 
                                            "linker_name": "mesh", 
                                            'filter_for_definitions':False, 
                                            "max_entities_per_mention":100, 
                                            "no_definition_threshold":.7, "threshold":0.4})

# %% [markdown]
# ### Load UMLS semantic type mappings + tree

# %%
st21pv_types = {
    'T005': "Virus" ,
    'T007': "Bacterium",
    'T017': "Anatomical Structure",
    'T022': "Body System",
    'T031': "Body Substance",
    'T033': "Finding",
    'T037': "Injury or Poisoning",
    'T038': "Biologic Function",
    'T058': "Health Care Activity",
    'T062': "Research Activity",
    'T074': "Medical Device",
    'T082': "Spatial Concept",
    'T091': "Biomedical Occupation or Discipline",
    'T092': "Organization",
    'T097': "Professional or Occupational Group",
    'T098': "Population Group",
    'T103': "Chemical",
    'T168': "Food",
    'T170': "Intellectual Product",
    'T201': "Clinical Attribute",
    'T204': "Eukaryote",
}

tree = kb.semantic_type_tree

st21pv_subtypes = list(st21pv_types.keys())
for key in st21pv_types.keys():
    node = tree.get_node_from_id(key)
    st21pv_subtypes.extend([x.type_id for x in tree.get_children(node)])

with open('st21pv_subtypes.json', 'w') as f:
    f.write(ujson.dumps(st21pv_subtypes, indent=2))

type2name = {x.type_id:x.full_name for x in tree.flat_nodes}

# %%
# def get_semantic_type_hierarchy(umls_dir, tui)
umls_dir = '/mitchell/entity-linking/2017AA/META'

sem_network_cols = [
    "row_type",
    "tui",
    "name",
    "tree_index",
    "desc",
    "_1",
    "clarification",
    "_2",
    "abbrev",
    "inverse_relation",
    "_3",
]

semantic_network = pd.read_csv(
    os.path.join(umls_dir, "semantic_network/SRDEF"),
    sep="|",
    names=sem_network_cols,
    usecols=["row_type", "tui", "name", "tree_index"],
)

semantic_network = semantic_network.query('row_type == "STY"')

tree_index_to_name = semantic_network.set_index('tree_index')['name'].to_dict()

tree_index_to_parent = {x: '.'.join(x.split('.')[:-1]) for x in semantic_network.tree_index if len(x.split('.')) > 1}

tui_to_tree_index = semantic_network.set_index('tui')['tree_index'].to_dict()

tui_to_name = semantic_network.set_index('tui')['name'].to_dict()

name_to_tui

def get_tui_geneology(tui, min_level=1):
    types = []
    tree_index = tui_to_tree_index[tui]
    split_index = tree_index.split('.')
    for i in range(min_level, len(split_index) + 1):
        types.append(tree_index_to_name['.'.join(split_index[:i])])

    return types
    


tui_geneologies = {tui: get_tui_geneology(tui) for tui in tui_to_name.keys()}
tui_geneologies

with open('../data/tui2type_hierarchy.json', 'w') as f:
    f.write(ujson.dumps(tui_geneologies, indent=2))
# print(tui_to_name)

# %%
tui_geneologies['T170']
# Out:
# ['Conceptual Entity', 'Intellectual Product']

# %% [markdown]
# ### Helper functions for processing data

# %%
def filter_candidates(candidates, filter_types):
    final_candidates = [e for e in candidates if any([x in filter_types for x in kb.cui_to_entity[e['db_id'].split(':')[-1]].types])]
    return final_candidates

# %%
def process_abstract_scispacy(text: str,
                    model,
                    eps: float=1e-6, 
                    db_name: str='UMLS', 
                    filter_types: List=None):
    '''
    SciSpacy processing of a single abstract
    '''
    doc = model(text)
    ent_list = []
    for ent in doc.ents:
        offsets = [(ent.start_char, ent.end_char)]
        text = ent.text
        candidates = [{'db_id': db_name + ':'+e[0], 'score':e[1]} for e in ent._.kb_ents]

        # Filter to candidates of particular types when specified
        if filter_types is not None:
            candidates = filter_candidates(candidates, filter_types)
        if len(candidates) == 0:
            continue
        
        max_score = max([x['score'] for x in candidates])
        choice = np.random.choice([x['db_id'] for x in candidates if x['score'] > max_score - eps])
        ent_list.append({
            "offsets":offsets, 
            "text":text, 
            "candidates": candidates, 
            "normalized":[{'db_name': db_name, 'db_id': choice}]})
    return ent_list

# %%
dataset_names = ['medmentions_st21pv', 'bc5cdr','gnormplus','nlmchem','nlm_gene','medmentions_full',]
dataset_to_models = {'bc5cdr':{'scispacy_large':lg_mesh,
                               'scibert':scibert_mesh},
                     'medmentions_full':{'scispacy_large':nlp_lg,
                                         'scibert':nlp_scibert},
                     'medmentions_st21pv':{'scispacy_large':nlp_lg,
                                           'scibert':nlp_scibert},
                     'gnormplus':{'scispacy_large':nlp_lg,
                                  'scibert':nlp_scibert},
                     'nlmchem':{'scispacy_large':lg_mesh,
                                'scibert':scibert_mesh},
                     'nlm_gene':{'scispacy_large':nlp_lg,
                                 'scibert':nlp_scibert}
                    }

dataset_to_linked_ontology = {'bc5cdr':'MESH',
                              'medmentions_full':'UMLS',
                              'medmentions_st21pv':'UMLS',
                              'gnormplus':'UMLS',
                              'nlmchem':"MESH",
                              'nlm_gene':'UMLS'}

processed = {name:defaultdict(list) for name in dataset_names}
for dataset in tqdm(dataset_names):
    data = conhelps.for_config_name(f'{dataset}_bigbio_kb').load_dataset()
    for model_name, model in dataset_to_models[dataset].items():
#         for split in ['test','validation','train',]:
        for split in ['test']:
            if split not in data:
                print(f"No {split} found in {dataset}")
                continue
            for document in tqdm(data[split]):
                text = ' '.join([t for x in document['passages'] for t in x['text']])
                pmid = document['document_id']
                gold_entities = document['entities']
                
                filter_types = None
                if 'st21pv' in dataset:
                    filter_types = st21pv_subtypes
                
                scispacy_entities = process_abstract_scispacy(text, 
                                                              model, 
                                                              db_name=dataset_to_linked_ontology[dataset], 
                                                              filter_types=filter_types)
                processed[dataset][model_name].append({'pmid':pmid, 
                                  'text':text, 
                                  'dataset':dataset, 
                                  'split':split, 
                                  'gold_entities':gold_entities, 
                                  'predictions':scispacy_entities})
                
with open(f'scispacy_outputs.json', 'w') as f:
    f.write(ujson.dumps(processed, indent=2))
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# Reusing dataset med_mentions_dataset (/home/ubuntu/.cache/huggingface/datasets/med_mentions_dataset/medmentions_st21pv_bigbio_kb/1.0.0/3fc6b8a3681d540ae6c7497c238636b543b90764247b5ff3642d243474000794)
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/879 [00:00<?, ?it/s]
#   0%|          | 0/879 [00:00<?, ?it/s]
# Reusing dataset bc5cdr_dataset (/home/ubuntu/.cache/huggingface/datasets/bc5cdr_dataset/bc5cdr_bigbio_kb/1.0.0/f01f16ea9b65ead985bedadf7335195c32297c8f1b09417fc607b102a6757d6f)
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Reusing dataset gnormplus_dataset (/home/ubuntu/.cache/huggingface/datasets/gnormplus_dataset/gnormplus_bigbio_kb/1.0.0/a07d375cacec149beba70fa6c1ea3ac78628e6652dca5345f3478354e8c0ae96)
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/262 [00:00<?, ?it/s]
#   0%|          | 0/262 [00:00<?, ?it/s]
# Reusing dataset nlm_chem_dataset (/home/ubuntu/.cache/huggingface/datasets/nlm_chem_dataset/nlmchem_bigbio_kb/1.0.0/d91131823c66b7dd1162027991ea47c342e478209b37cf261c5f122d30409594)
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Reusing dataset nlm_gene_dataset (/home/ubuntu/.cache/huggingface/datasets/nlm_gene_dataset/nlm_gene_bigbio_kb/1.0.0/961ce939e0f3a3315d6a179b7afa33173e73bcb3d781a26c058484fbb1a944ca)
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Reusing dataset med_mentions_dataset (/home/ubuntu/.cache/huggingface/datasets/med_mentions_dataset/medmentions_full_bigbio_kb/1.0.0/3fc6b8a3681d540ae6c7497c238636b543b90764247b5ff3642d243474000794)
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/879 [00:00<?, ?it/s]
#   0%|          | 0/879 [00:00<?, ?it/s]

# %% [markdown]
# ## Helper functions for output evaluation

# %%
def _hit_at_k(gold_entity, candidate_entities, k, mode='strict'):
    '''
    Determine if correct entity link is in top k entity candidates
    '''
    gold_cuis = gold_entity['db_ids']
    top_candidates = sorted(candidate_entities, key=lambda x: x['score'])[::-1][:k]
    
    for x in top_candidates:
        if x['db_id'] in gold_cuis:
            return True

    return False
#     if gold_cui in [x['db_id'] for x in top_candidates]:
#         return True 
#     else:
#         return False
    


def hits_by_type(gold_lookup, model_lookup, ks=[1, 2, 4, 8, 16, 32, 64], custom_types=None):
    '''
    Get hits@k grouped by entity type.  

    By default, bases type annotations on 
    '''
    # Hits @ k
    hits_dict = {}
    entity_types = set([])
    for k in ks:
        hits = defaultdict(int)
        # Get hits @ k for each entity type
        for key, gold_entity in gold_lookup.items():
            ent_type = gold_entity['type']

            
            # This will break after recent code updates
            if custom_types is not None:
                cuis = [x.split(':')[-1] for x in gold_entity['db_id']]

                # Make sure CUI is in SciSpacy KB
                for cui in cuis:
                    if cui in kb.cui_to_entity:
                        pred_types = kb.cui_to_entity[cui].types
                        for group_name, vals in custom_types.items():
                            if any([x in vals for x in pred_types]):
                                # TODO: Handle case where an entity falls in more than 1 category in custom dict
                                ent_type = group_name
                                entity_types.add(ent_type)
                                break
            else:
                entity_types.add(ent_type)
            

            if key in model_lookup:
                hits[ent_type] += _hit_at_k(gold_entity, model_lookup[key]['candidates'], k)
                hits[ent_type + "_total"] += 1
            else:
                hits[ent_type + '_missing'] += 1

        overall_hits = sum(hits[x] for x in entity_types)/sum(hits[x + '_total'] for x in entity_types)
        overall_recall = sum(hits[x] for x in entity_types)/sum(hits[x + '_total'] + hits[x + '_missing'] for x in entity_types)
        hits['overall (exclude missing)'] = overall_hits
        hits['overall (include missing)'] = overall_recall
        hits_dict[k] = hits
        
    hits_dict['types'] = entity_types
    return hits_dict


def evaluate_linking(processed_data, model='scispacy', custom_types=None):
    '''
    Evaluate a number of metrics on entity linking models:
        * Hits@k for k = 1, 5, 10
    '''
    # preformat data into dict with keys of form (pmid, offset_start, offset_end) for faster access
    
    gold_lookup = {(doc['pmid'], x['offsets'][0][0], x['offsets'][0][1]): {'db_ids': [y['db_name'] + ':' + y['db_id'] for y in x['normalized']], 'type':x['type']} 
                        for doc in processed_data for x in doc['gold_entities'] if len(x['normalized']) > 0}
    model_lookup = {(doc['pmid'], x['offsets'][0][0], x['offsets'][0][1]): {'normalized': x['normalized'][0]['db_id'], 'candidates':x['candidates']} 
                        for doc in processed_data for x in doc['predictions']}

    # for doc in processed_data:
    #     pmid = doc['pmid']
    #     for x in doc['predictions']['model']

    hits_dict = hits_by_type(gold_lookup, model_lookup, custom_types=custom_types)

    return hits_dict
    

def format_output(hits_dict, type_to_name_mapping=type2name):
    '''
    Format entity linking results into pandas DataFrame
    '''
    entity_types = hits_dict['types']
    ks = [k for k in hits_dict.keys() if type(k) == int]
    rows = []
    for t in entity_types:
        if t not in type_to_name_mapping:
            name = t.upper()
        else:
            name = type_to_name_mapping[t]
        rows.append({**{'Semantic Type':name}, **{f'recall@{k}':hits_dict[k][t]/hits_dict[k][t + '_total'] for k in ks}, **{'Spans Matched':hits_dict[ks[0]][t + '_total'], 'Missing':hits_dict[ks[0]][t + '_missing']}})
    
    # Add overall scores
    rows.append({**{'Semantic Type':"**Overall**"}, **{f'recall@{k}':hits_dict[k]["overall (exclude missing)"] for k in ks}, **{'Spans Matched':np.sum([hits_dict[ks[0]][t + '_total'] for t in entity_types]), 'Missing':np.sum([hits_dict[ks[0]][t + '_missing'] for t in entity_types])}})
    rows.append({**{'Semantic Type':"**Overall (including missing spans)**"}, **{f'recall@{k}':hits_dict[k]["overall (include missing)"] for k in ks}, **{'Spans Matched':np.sum([hits_dict[ks[0]][t + '_total'] for t in entity_types]), 'Missing':np.sum([hits_dict[ks[0]][t + '_missing'] for t in entity_types])}})


    results = pd.DataFrame.from_records(rows)
    results['Total'] = results[['Spans Matched','Missing']].sum(axis=1)
    results['Missing Proportion'] = (results['Missing']/(results['Total']))
    return results.round(4)

# %%
processed['medmentions_st21pv']['scibert'][0]
# Out:
# {'pmid': '25847295',
#  'text': 'Nonylphenol diethoxylate inhibits apoptosis induced in PC12 cells Nonylphenol and short-chain nonylphenol ethoxylates such as NP2 EO are present in aquatic environment as wastewater contaminants, and their toxic effects on aquatic species have been reported. Apoptosis has been shown to be induced by serum deprivation or copper treatment. To understand the toxicity of nonylphenol diethoxylate, we investigated the effects of NP2 EO on apoptosis induced by serum deprivation and copper by using PC12 cell system. Nonylphenol diethoxylate itself showed no toxicity and recovered cell viability from apoptosis. In addition, nonylphenol diethoxylate decreased DNA fragmentation caused by apoptosis in PC12 cells. This phenomenon was confirmed after treating apoptotic PC12 cells with nonylphenol diethoxylate, whereas the cytochrome c release into the cytosol decreased as compared to that in apoptotic cells not treated with nonylphenol diethoxylate s. Furthermore, Bax contents in apoptotic cells were reduced after exposure to nonylphenol diethoxylate. Thus, nonylphenol diethoxylate has the opposite effect on apoptosis in PC12 cells compared to nonylphenol, which enhances apoptosis induced by serum deprivation. The difference in structure of the two compounds is hypothesized to be responsible for this phenomenon. These results indicated that nonylphenol diethoxylate has capability to affect cell differentiation and development and has potentially harmful effect on organisms because of its unexpected impact on apoptosis. © 2015 Wiley Periodicals, Inc. Environ Toxicol 31: 1389-1398, 2016.',
#  'dataset': 'medmentions_st21pv',
#  'split': 'test',
#  'gold_entities': [{'id': '1',
#    'type': 'T038',
#    'text': ['apoptosis'],
#    'offsets': [[34, 43]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0162638'}]},
#   {'id': '2',
#    'type': 'T017',
#    'text': ['PC12 cells'],
#    'offsets': [[55, 65]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0085262'}]},
#   {'id': '3',
#    'type': 'T033',
#    'text': ['present'],
#    'offsets': [[137, 144]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0150312'}]},
#   {'id': '4',
#    'type': 'T037',
#    'text': ['toxic effects'],
#    'offsets': [[206, 219]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0600688'}]},
#   {'id': '5',
#    'type': 'T038',
#    'text': ['Apoptosis'],
#    'offsets': [[259, 268]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0162638'}]},
#   {'id': '6',
#    'type': 'T031',
#    'text': ['serum'],
#    'offsets': [[301, 306]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0229671'}]},
#   {'id': '7',
#    'type': 'T103',
#    'text': ['copper'],
#    'offsets': [[322, 328]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0009968'}]},
#   {'id': '8',
#    'type': 'T038',
#    'text': ['apoptosis'],
#    'offsets': [[437, 446]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0162638'}]},
#   {'id': '9',
#    'type': 'T031',
#    'text': ['serum'],
#    'offsets': [[458, 463]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0229671'}]},
#   {'id': '10',
#    'type': 'T103',
#    'text': ['copper'],
#    'offsets': [[480, 486]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0009968'}]},
#   {'id': '11',
#    'type': 'T017',
#    'text': ['PC12 cell system'],
#    'offsets': [[496, 512]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0085262'}]},
#   {'id': '12',
#    'type': 'T038',
#    'text': ['cell viability'],
#    'offsets': [[579, 593]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0007620'}]},
#   {'id': '13',
#    'type': 'T038',
#    'text': ['apoptosis'],
#    'offsets': [[599, 608]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0162638'}]},
#   {'id': '14',
#    'type': 'T038',
#    'text': ['DNA fragmentation'],
#    'offsets': [[658, 675]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0376669'}]},
#   {'id': '15',
#    'type': 'T038',
#    'text': ['apoptosis'],
#    'offsets': [[686, 695]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0162638'}]},
#   {'id': '16',
#    'type': 'T017',
#    'text': ['PC12 cells'],
#    'offsets': [[699, 709]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0085262'}]},
#   {'id': '17',
#    'type': 'T017',
#    'text': ['PC12 cells'],
#    'offsets': [[766, 776]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0085262'}]},
#   {'id': '18',
#    'type': 'T103',
#    'text': ['cytochrome c'],
#    'offsets': [[820, 832]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0010749'}]},
#   {'id': '19',
#    'type': 'T017',
#    'text': ['cytosol'],
#    'offsets': [[850, 857]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C1383501'}]},
#   {'id': '20',
#    'type': 'T017',
#    'text': ['apoptotic cells'],
#    'offsets': [[891, 906]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0007634'}]},
#   {'id': '21',
#    'type': 'T103',
#    'text': ['Bax'],
#    'offsets': [[965, 968]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0219474'}]},
#   {'id': '22',
#    'type': 'T017',
#    'text': ['apoptotic cells'],
#    'offsets': [[981, 996]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0007634'}]},
#   {'id': '23',
#    'type': 'T038',
#    'text': ['apoptosis'],
#    'offsets': [[1112, 1121]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0162638'}]},
#   {'id': '24',
#    'type': 'T017',
#    'text': ['PC12 cells'],
#    'offsets': [[1125, 1135]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0085262'}]},
#   {'id': '25',
#    'type': 'T038',
#    'text': ['apoptosis'],
#    'offsets': [[1176, 1185]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0162638'}]},
#   {'id': '26',
#    'type': 'T031',
#    'text': ['serum'],
#    'offsets': [[1197, 1202]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0229671'}]},
#   {'id': '27',
#    'type': 'T082',
#    'text': ['structure'],
#    'offsets': [[1234, 1243]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0678594'}]},
#   {'id': '28',
#    'type': 'T103',
#    'text': ['compounds'],
#    'offsets': [[1255, 1264]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0220806'}]},
#   {'id': '29',
#    'type': 'T033',
#    'text': ['results'],
#    'offsets': [[1326, 1333]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C2825142'}]},
#   {'id': '30',
#    'type': 'T038',
#    'text': ['cell differentiation'],
#    'offsets': [[1399, 1419]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0007589'}]},
#   {'id': '31',
#    'type': 'T038',
#    'text': ['development'],
#    'offsets': [[1424, 1435]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0243107'}]},
#   {'id': '32',
#    'type': 'T037',
#    'text': ['harmful effect'],
#    'offsets': [[1456, 1470]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0600688'}]},
#   {'id': '33',
#    'type': 'T038',
#    'text': ['apoptosis'],
#    'offsets': [[1520, 1529]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0162638'}]}],
#  'predictions': [{'offsets': [(0, 11)],
#    'text': 'Nonylphenol',
#    'candidates': [{'db_id': 'UMLS:C0068946', 'score': 1.0},
#     {'db_id': 'UMLS:C0953814', 'score': 0.8478714227676392},
#     {'db_id': 'UMLS:C0953815', 'score': 0.8301727175712585},
#     {'db_id': 'UMLS:C0970196', 'score': 0.7795582413673401},
#     {'db_id': 'UMLS:C0097405', 'score': 0.767101526260376},
#     {'db_id': 'UMLS:C3857939', 'score': 0.757386326789856},
#     {'db_id': 'UMLS:C0953813', 'score': 0.7489328384399414},
#     {'db_id': 'UMLS:C4236359', 'score': 0.7475515604019165},
#     {'db_id': 'UMLS:C0132779', 'score': 0.7382228374481201}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0068946'}]},
#   {'offsets': [(25, 33)],
#    'text': 'inhibits',
#    'candidates': [{'db_id': 'UMLS:C0021467', 'score': 0.7524629831314087},
#     {'db_id': 'UMLS:C0021469', 'score': 0.7524629831314087},
#     {'db_id': 'UMLS:C0074775', 'score': 0.7493148446083069},
#     {'db_id': 'UMLS:C1999216', 'score': 0.7310131192207336},
#     {'db_id': 'UMLS:C0679144', 'score': 0.7032979726791382},
#     {'db_id': 'UMLS:C1418824', 'score': 0.7014464735984802}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0021467'}]},
#   {'offsets': [(34, 43)],
#    'text': 'apoptosis',
#    'candidates': [{'db_id': 'UMLS:C0162638', 'score': 1.0},
#     {'db_id': 'UMLS:C2247960', 'score': 0.8234089016914368},
#     {'db_id': 'UMLS:C1326202', 'score': 0.8038336038589478},
#     {'db_id': 'UMLS:C1332322', 'score': 0.7967405319213867},
#     {'db_id': 'UMLS:C1660771', 'score': 0.7909232378005981},
#     {'db_id': 'UMLS:C2610891', 'score': 0.7842937111854553},
#     {'db_id': 'UMLS:C4329354', 'score': 0.7827578186988831},
#     {'db_id': 'UMLS:C1326205', 'score': 0.7727738618850708},
#     {'db_id': 'UMLS:C1454645', 'score': 0.7598106861114502},
#     {'db_id': 'UMLS:C1539477', 'score': 0.7598106861114502},
#     {'db_id': 'UMLS:C1564881', 'score': 0.7557398080825806},
#     {'db_id': 'UMLS:C1148568', 'score': 0.7536895275115967},
#     {'db_id': 'UMLS:C4233500', 'score': 0.7531155943870544},
#     {'db_id': 'UMLS:C3269144', 'score': 0.7494465708732605},
#     {'db_id': 'UMLS:C2246411', 'score': 0.7446570992469788},
#     {'db_id': 'UMLS:C3266896', 'score': 0.7426552772521973},
#     {'db_id': 'UMLS:C1332323', 'score': 0.7344915270805359},
#     {'db_id': 'UMLS:C3269138', 'score': 0.7319819927215576}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0162638'}]},
#   {'offsets': [(44, 51)],
#    'text': 'induced',
#    'candidates': [{'db_id': 'UMLS:C0153122', 'score': 0.7563474178314209},
#     {'db_id': 'UMLS:C1428046', 'score': 0.7431603074073792},
#     {'db_id': 'UMLS:C1512710', 'score': 0.741400957107544},
#     {'db_id': 'UMLS:C0858744', 'score': 0.7410463690757751},
#     {'db_id': 'UMLS:C0235661', 'score': 0.7390875816345215},
#     {'db_id': 'UMLS:C0022875', 'score': 0.7339017987251282},
#     {'db_id': 'UMLS:C0259787', 'score': 0.7339017987251282},
#     {'db_id': 'UMLS:C1708502', 'score': 0.7186915874481201},
#     {'db_id': 'UMLS:C0269439', 'score': 0.7103714346885681},
#     {'db_id': 'UMLS:C0392535', 'score': 0.7103714346885681},
#     {'db_id': 'UMLS:C1704300', 'score': 0.7103714346885681},
#     {'db_id': 'UMLS:C2985288', 'score': 0.7042877078056335},
#     {'db_id': 'UMLS:C1427643', 'score': 0.7007309794425964}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0153122'}]},
#   {'offsets': [(55, 65)],
#    'text': 'PC12 cells',
#    'candidates': [{'db_id': 'UMLS:C0085262', 'score': 1.0}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0085262'}]},
#   {'offsets': [(66, 77)],
#    'text': 'Nonylphenol',
#    'candidates': [{'db_id': 'UMLS:C0068946', 'score': 1.0},
#     {'db_id': 'UMLS:C0953814', 'score': 0.8478714227676392},
#     {'db_id': 'UMLS:C0953815', 'score': 0.8301727175712585},
#     {'db_id': 'UMLS:C0970196', 'score': 0.7795582413673401},
#     {'db_id': 'UMLS:C0097405', 'score': 0.767101526260376},
#     {'db_id': 'UMLS:C3857939', 'score': 0.757386326789856},
#     {'db_id': 'UMLS:C0953813', 'score': 0.7489328384399414},
#     {'db_id': 'UMLS:C4236359', 'score': 0.7475515604019165},
#     {'db_id': 'UMLS:C0132779', 'score': 0.7382228374481201}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0068946'}]},
#   {'offsets': [(82, 117)],
#    'text': 'short-chain nonylphenol ethoxylates',
#    'candidates': [{'db_id': 'UMLS:C0132779', 'score': 0.7387117743492126}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0132779'}]},
#   {'offsets': [(126, 129)],
#    'text': 'NP2',
#    'candidates': [{'db_id': 'UMLS:C1417813', 'score': 1.0},
#     {'db_id': 'UMLS:C2698422', 'score': 1.0},
#     {'db_id': 'UMLS:C2698699', 'score': 1.0},
#     {'db_id': 'UMLS:C3446839', 'score': 0.7443797588348389},
#     {'db_id': 'UMLS:C1430346', 'score': 0.7097744941711426}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C2698699'}]},
#   {'offsets': [(130, 132)],
#    'text': 'EO',
#    'candidates': [{'db_id': 'UMLS:C0059403', 'score': 0.8363078236579895},
#     {'db_id': 'UMLS:C0059402', 'score': 0.70255446434021}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0059403'}]},
#   {'offsets': [(148, 167)],
#    'text': 'aquatic environment',
#    'candidates': [{'db_id': 'UMLS:C0014406', 'score': 0.7974847555160522},
#     {'db_id': 'UMLS:C0562522', 'score': 0.7349271774291992},
#     {'db_id': 'UMLS:C0557735', 'score': 0.7261036038398743},
#     {'db_id': 'UMLS:C0565954', 'score': 0.7142958045005798},
#     {'db_id': 'UMLS:C0557742', 'score': 0.7119547724723816},
#     {'db_id': 'UMLS:C0557745', 'score': 0.7098597288131714}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0014406'}]},
#   {'offsets': [(171, 181)],
#    'text': 'wastewater',
#    'candidates': [{'db_id': 'UMLS:C5107127', 'score': 0.7123866677284241},
#     {'db_id': 'UMLS:C0450237', 'score': 0.7096060514450073},
#     {'db_id': 'UMLS:C5107128', 'score': 0.7087265253067017},
#     {'db_id': 'UMLS:C5107129', 'score': 0.7066829204559326}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C5107127'}]},
#   {'offsets': [(206, 211)],
#    'text': 'toxic',
#    'candidates': [{'db_id': 'UMLS:C0600688', 'score': 1.0},
#     {'db_id': 'UMLS:C1256754', 'score': 0.8223487138748169},
#     {'db_id': 'UMLS:C0311393', 'score': 0.7934061884880066},
#     {'db_id': 'UMLS:C0599787', 'score': 0.7835650444030762},
#     {'db_id': 'UMLS:C0032101', 'score': 0.7765399217605591},
#     {'db_id': 'UMLS:C3726655', 'score': 0.7676068544387817},
#     {'db_id': 'UMLS:C1617068', 'score': 0.7586206197738647},
#     {'db_id': 'UMLS:C0444631', 'score': 0.7378132343292236},
#     {'db_id': 'UMLS:C0542243', 'score': 0.7300735116004944},
#     {'db_id': 'UMLS:C0815048', 'score': 0.7296077609062195},
#     {'db_id': 'UMLS:C0234382', 'score': 0.7254428863525391},
#     {'db_id': 'UMLS:C0267440', 'score': 0.7193804979324341},
#     {'db_id': 'UMLS:C0302332', 'score': 0.7124227285385132}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0600688'}]},
#   {'offsets': [(223, 238)],
#    'text': 'aquatic species',
#    'candidates': [{'db_id': 'UMLS:C0884441', 'score': 0.7617052793502808},
#     {'db_id': 'UMLS:C3948730', 'score': 0.7004141211509705}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0884441'}]},
#   {'offsets': [(259, 268)],
#    'text': 'Apoptosis',
#    'candidates': [{'db_id': 'UMLS:C0162638', 'score': 1.0},
#     {'db_id': 'UMLS:C2247960', 'score': 0.8234089016914368},
#     {'db_id': 'UMLS:C1326202', 'score': 0.8038336038589478},
#     {'db_id': 'UMLS:C1332322', 'score': 0.7967405319213867},
#     {'db_id': 'UMLS:C1660771', 'score': 0.7909232378005981},
#     {'db_id': 'UMLS:C2610891', 'score': 0.7842937111854553},
#     {'db_id': 'UMLS:C4329354', 'score': 0.7827578186988831},
#     {'db_id': 'UMLS:C1326205', 'score': 0.7727738618850708},
#     {'db_id': 'UMLS:C1454645', 'score': 0.7598106861114502},
#     {'db_id': 'UMLS:C1539477', 'score': 0.7598106861114502},
#     {'db_id': 'UMLS:C1564881', 'score': 0.7557398080825806},
#     {'db_id': 'UMLS:C1148568', 'score': 0.7536895275115967},
#     {'db_id': 'UMLS:C4233500', 'score': 0.7531155943870544},
#     {'db_id': 'UMLS:C3269144', 'score': 0.7494465708732605},
#     {'db_id': 'UMLS:C2246411', 'score': 0.7446570992469788},
#     {'db_id': 'UMLS:C3266896', 'score': 0.7426552772521973},
#     {'db_id': 'UMLS:C1332323', 'score': 0.7344915270805359},
#     {'db_id': 'UMLS:C3269138', 'score': 0.7319819927215576}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0162638'}]},
#   {'offsets': [(290, 297)],
#    'text': 'induced',
#    'candidates': [{'db_id': 'UMLS:C0153122', 'score': 0.7563474178314209},
#     {'db_id': 'UMLS:C1428046', 'score': 0.7431603074073792},
#     {'db_id': 'UMLS:C1512710', 'score': 0.741400957107544},
#     {'db_id': 'UMLS:C0858744', 'score': 0.7410463690757751},
#     {'db_id': 'UMLS:C0235661', 'score': 0.7390875816345215},
#     {'db_id': 'UMLS:C0022875', 'score': 0.7339017987251282},
#     {'db_id': 'UMLS:C0259787', 'score': 0.7339017987251282},
#     {'db_id': 'UMLS:C1708502', 'score': 0.7186915874481201},
#     {'db_id': 'UMLS:C0269439', 'score': 0.7103714346885681},
#     {'db_id': 'UMLS:C0392535', 'score': 0.7103714346885681},
#     {'db_id': 'UMLS:C1704300', 'score': 0.7103714346885681},
#     {'db_id': 'UMLS:C2985288', 'score': 0.7042877078056335},
#     {'db_id': 'UMLS:C1427643', 'score': 0.7007309794425964}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0153122'}]},
#   {'offsets': [(301, 318)],
#    'text': 'serum deprivation',
#    'candidates': [{'db_id': 'UMLS:C0599620', 'score': 0.7079419493675232}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0599620'}]},
#   {'offsets': [(322, 338)],
#    'text': 'copper treatment',
#    'candidates': [{'db_id': 'UMLS:C0087111', 'score': 0.7840341329574585},
#     {'db_id': 'UMLS:C1533734', 'score': 0.7840341329574585},
#     {'db_id': 'UMLS:C3161471', 'score': 0.7840341329574585},
#     {'db_id': 'UMLS:C3538994', 'score': 0.7840341329574585},
#     {'db_id': 'UMLS:C3887704', 'score': 0.7840341329574585},
#     {'db_id': 'UMLS:C0746919', 'score': 0.7215439081192017},
#     {'db_id': 'UMLS:C3275118', 'score': 0.7215439081192017},
#     {'db_id': 'UMLS:C0814472', 'score': 0.7151214480400085}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C3538994'}]},
#   {'offsets': [(358, 366)],
#    'text': 'toxicity',
#    'candidates': [{'db_id': 'UMLS:C0600688', 'score': 1.0},
#     {'db_id': 'UMLS:C1142072', 'score': 0.9041571021080017},
#     {'db_id': 'UMLS:C0595916', 'score': 0.8562463521957397},
#     {'db_id': 'UMLS:C0242890', 'score': 0.853233814239502},
#     {'db_id': 'UMLS:C1167791', 'score': 0.8336424827575684},
#     {'db_id': 'UMLS:C0745409', 'score': 0.8329271078109741},
#     {'db_id': 'UMLS:C0275012', 'score': 0.8204122185707092},
#     {'db_id': 'UMLS:C0948342', 'score': 0.8199789524078369},
#     {'db_id': 'UMLS:C0877104', 'score': 0.8178958296775818},
#     {'db_id': 'UMLS:C0013221', 'score': 0.8010424971580505},
#     {'db_id': 'UMLS:C0274848', 'score': 0.7909846305847168},
#     {'db_id': 'UMLS:C0275056', 'score': 0.7885827422142029},
#     {'db_id': 'UMLS:C0275067', 'score': 0.7882724404335022},
#     {'db_id': 'UMLS:C0348754', 'score': 0.785512387752533},
#     {'db_id': 'UMLS:C0344124', 'score': 0.7849006056785583}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0600688'}]},
#   {'offsets': [(370, 381)],
#    'text': 'nonylphenol',
#    'candidates': [{'db_id': 'UMLS:C0068946', 'score': 1.0},
#     {'db_id': 'UMLS:C0953814', 'score': 0.8478714227676392},
#     {'db_id': 'UMLS:C0953815', 'score': 0.8301727175712585},
#     {'db_id': 'UMLS:C0970196', 'score': 0.7795582413673401},
#     {'db_id': 'UMLS:C0097405', 'score': 0.767101526260376},
#     {'db_id': 'UMLS:C3857939', 'score': 0.757386326789856},
#     {'db_id': 'UMLS:C0953813', 'score': 0.7489328384399414},
#     {'db_id': 'UMLS:C4236359', 'score': 0.7475515604019165},
#     {'db_id': 'UMLS:C0132779', 'score': 0.7382228374481201}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0068946'}]},
#   {'offsets': [(399, 411)],
#    'text': 'investigated',
#    'candidates': [{'db_id': 'UMLS:C0220825', 'score': 0.8599081039428711},
#     {'db_id': 'UMLS:C1261322', 'score': 0.8599081039428711},
#     {'db_id': 'UMLS:C1552578', 'score': 0.8599081039428711},
#     {'db_id': 'UMLS:C0035173', 'score': 0.8376585841178894},
#     {'db_id': 'UMLS:C3245491', 'score': 0.8182322382926941},
#     {'db_id': 'UMLS:C1708251', 'score': 0.7388296127319336},
#     {'db_id': 'UMLS:C1710101', 'score': 0.7356106638908386},
#     {'db_id': 'UMLS:C2825164', 'score': 0.7356106638908386},
#     {'db_id': 'UMLS:C2827983', 'score': 0.7356106638908386},
#     {'db_id': 'UMLS:C0868646', 'score': 0.7280187010765076},
#     {'db_id': 'UMLS:C0013230', 'score': 0.7217698097229004},
#     {'db_id': 'UMLS:C0243095', 'score': 0.7197885513305664},
#     {'db_id': 'UMLS:C2826892', 'score': 0.7145398855209351},
#     {'db_id': 'UMLS:C2346570', 'score': 0.7096487879753113},
#     {'db_id': 'UMLS:C1883202', 'score': 0.7073023319244385}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C1261322'}]},
#   {'offsets': [(416, 423)],
#    'text': 'effects',
#    'candidates': [{'db_id': 'UMLS:C2945677', 'score': 0.914075493812561},
#     {'db_id': 'UMLS:C0543419', 'score': 0.8974418044090271},
#     {'db_id': 'UMLS:C1368999', 'score': 0.8974418044090271},
#     {'db_id': 'UMLS:C0877248', 'score': 0.8638460636138916},
#     {'db_id': 'UMLS:C0879626', 'score': 0.8638460636138916},
#     {'db_id': 'UMLS:C0161734', 'score': 0.8585611581802368},
#     {'db_id': 'UMLS:C0221500', 'score': 0.8525299429893494},
#     {'db_id': 'UMLS:C0872206', 'score': 0.8463888168334961},
#     {'db_id': 'UMLS:C3178735', 'score': 0.8214828968048096},
#     {'db_id': 'UMLS:C4277541', 'score': 0.8187500834465027},
#     {'db_id': 'UMLS:C1319171', 'score': 0.818490743637085},
#     {'db_id': 'UMLS:C4277511', 'score': 0.8172067403793335},
#     {'db_id': 'UMLS:C1383090', 'score': 0.8128247261047363},
#     {'db_id': 'UMLS:C0544721', 'score': 0.7989674806594849},
#     {'db_id': 'UMLS:C0870752', 'score': 0.7948921322822571},
#     {'db_id': 'UMLS:C0034525', 'score': 0.7937171459197998},
#     {'db_id': 'UMLS:C0034526', 'score': 0.7937171459197998}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C2945677'}]},
#   {'offsets': [(427, 430)],
#    'text': 'NP2',
#    'candidates': [{'db_id': 'UMLS:C1417813', 'score': 1.0},
#     {'db_id': 'UMLS:C2698422', 'score': 1.0},
#     {'db_id': 'UMLS:C2698699', 'score': 1.0},
#     {'db_id': 'UMLS:C3446839', 'score': 0.7443797588348389},
#     {'db_id': 'UMLS:C1430346', 'score': 0.7097744941711426}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C2698422'}]},
#   {'offsets': [(431, 433)],
#    'text': 'EO',
#    'candidates': [{'db_id': 'UMLS:C0059403', 'score': 0.8363078236579895},
#     {'db_id': 'UMLS:C0059402', 'score': 0.70255446434021}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0059403'}]},
#   {'offsets': [(437, 446)],
#    'text': 'apoptosis',
#    'candidates': [{'db_id': 'UMLS:C0162638', 'score': 1.0},
#     {'db_id': 'UMLS:C2247960', 'score': 0.8234089016914368},
#     {'db_id': 'UMLS:C1326202', 'score': 0.8038336038589478},
#     {'db_id': 'UMLS:C1332322', 'score': 0.7967405319213867},
#     {'db_id': 'UMLS:C1660771', 'score': 0.7909232378005981},
#     {'db_id': 'UMLS:C2610891', 'score': 0.7842937111854553},
#     {'db_id': 'UMLS:C4329354', 'score': 0.7827578186988831},
#     {'db_id': 'UMLS:C1326205', 'score': 0.7727738618850708},
#     {'db_id': 'UMLS:C1454645', 'score': 0.7598106861114502},
#     {'db_id': 'UMLS:C1539477', 'score': 0.7598106861114502},
#     {'db_id': 'UMLS:C1564881', 'score': 0.7557398080825806},
#     {'db_id': 'UMLS:C1148568', 'score': 0.7536895275115967},
#     {'db_id': 'UMLS:C4233500', 'score': 0.7531155943870544},
#     {'db_id': 'UMLS:C3269144', 'score': 0.7494465708732605},
#     {'db_id': 'UMLS:C2246411', 'score': 0.7446570992469788},
#     {'db_id': 'UMLS:C3266896', 'score': 0.7426552772521973},
#     {'db_id': 'UMLS:C1332323', 'score': 0.7344915270805359},
#     {'db_id': 'UMLS:C3269138', 'score': 0.7319819927215576}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0162638'}]},
#   {'offsets': [(447, 454)],
#    'text': 'induced',
#    'candidates': [{'db_id': 'UMLS:C0153122', 'score': 0.7563474178314209},
#     {'db_id': 'UMLS:C1428046', 'score': 0.7431603074073792},
#     {'db_id': 'UMLS:C1512710', 'score': 0.741400957107544},
#     {'db_id': 'UMLS:C0858744', 'score': 0.7410463690757751},
#     {'db_id': 'UMLS:C0235661', 'score': 0.7390875816345215},
#     {'db_id': 'UMLS:C0022875', 'score': 0.7339017987251282},
#     {'db_id': 'UMLS:C0259787', 'score': 0.7339017987251282},
#     {'db_id': 'UMLS:C1708502', 'score': 0.7186915874481201},
#     {'db_id': 'UMLS:C0269439', 'score': 0.7103714346885681},
#     {'db_id': 'UMLS:C0392535', 'score': 0.7103714346885681},
#     {'db_id': 'UMLS:C1704300', 'score': 0.7103714346885681},
#     {'db_id': 'UMLS:C2985288', 'score': 0.7042877078056335},
#     {'db_id': 'UMLS:C1427643', 'score': 0.7007309794425964}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0153122'}]},
#   {'offsets': [(458, 475)],
#    'text': 'serum deprivation',
#    'candidates': [{'db_id': 'UMLS:C0599620', 'score': 0.7079419493675232}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0599620'}]},
#   {'offsets': [(480, 486)],
#    'text': 'copper',
#    'candidates': [{'db_id': 'UMLS:C0009968', 'score': 0.9999999403953552},
#     {'db_id': 'UMLS:C0373587', 'score': 0.9999999403953552},
#     {'db_id': 'UMLS:C2348263', 'score': 0.9999999403953552},
#     {'db_id': 'UMLS:C0303182', 'score': 0.8258143067359924},
#     {'db_id': 'UMLS:C0056292', 'score': 0.8004307746887207},
#     {'db_id': 'UMLS:C1551716', 'score': 0.7947198152542114},
#     {'db_id': 'UMLS:C0268070', 'score': 0.7936380505561829},
#     {'db_id': 'UMLS:C1551717', 'score': 0.7570146322250366},
#     {'db_id': 'UMLS:C0201960', 'score': 0.7550140619277954},
#     {'db_id': 'UMLS:C0428576', 'score': 0.7550140619277954},
#     {'db_id': 'UMLS:C0599217', 'score': 0.745829164981842},
#     {'db_id': 'UMLS:C0858105', 'score': 0.7286819815635681},
#     {'db_id': 'UMLS:C0860994', 'score': 0.7285761833190918},
#     {'db_id': 'UMLS:C0589328', 'score': 0.7264619469642639},
#     {'db_id': 'UMLS:C0303189', 'score': 0.722392201423645},
#     {'db_id': 'UMLS:C0962035', 'score': 0.7200943827629089},
#     {'db_id': 'UMLS:C1148611', 'score': 0.7188345193862915},
#     {'db_id': 'UMLS:C0056603', 'score': 0.7175687551498413},
#     {'db_id': 'UMLS:C0303191', 'score': 0.7134490013122559},
#     {'db_id': 'UMLS:C0264456', 'score': 0.7103310227394104},
#     {'db_id': 'UMLS:C0303190', 'score': 0.7101002931594849},
#     {'db_id': 'UMLS:C0458049', 'score': 0.7100422382354736},
#     {'db_id': 'UMLS:C0860194', 'score': 0.7087116241455078}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C2348263'}]},
#   {'offsets': [(496, 512)],
#    'text': 'PC12 cell system',
#    'candidates': [{'db_id': 'UMLS:C0085262', 'score': 0.8442631363868713}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0085262'}]},
#   {'offsets': [(514, 525)],
#    'text': 'Nonylphenol',
#    'candidates': [{'db_id': 'UMLS:C0068946', 'score': 1.0},
#     {'db_id': 'UMLS:C0953814', 'score': 0.8478714227676392},
#     {'db_id': 'UMLS:C0953815', 'score': 0.8301727175712585},
#     {'db_id': 'UMLS:C0970196', 'score': 0.7795582413673401},
#     {'db_id': 'UMLS:C0097405', 'score': 0.767101526260376},
#     {'db_id': 'UMLS:C3857939', 'score': 0.757386326789856},
#     {'db_id': 'UMLS:C0953813', 'score': 0.7489328384399414},
#     {'db_id': 'UMLS:C4236359', 'score': 0.7475515604019165},
#     {'db_id': 'UMLS:C0132779', 'score': 0.7382228374481201}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0068946'}]},
#   {'offsets': [(556, 564)],
#    'text': 'toxicity',
#    'candidates': [{'db_id': 'UMLS:C0600688', 'score': 1.0},
#     {'db_id': 'UMLS:C1142072', 'score': 0.9041571021080017},
#     {'db_id': 'UMLS:C0595916', 'score': 0.8562463521957397},
#     {'db_id': 'UMLS:C0242890', 'score': 0.853233814239502},
#     {'db_id': 'UMLS:C1167791', 'score': 0.8336424827575684},
#     {'db_id': 'UMLS:C0745409', 'score': 0.8329271078109741},
#     {'db_id': 'UMLS:C0275012', 'score': 0.8204122185707092},
#     {'db_id': 'UMLS:C0948342', 'score': 0.8199789524078369},
#     {'db_id': 'UMLS:C0877104', 'score': 0.8178958296775818},
#     {'db_id': 'UMLS:C0013221', 'score': 0.8010424971580505},
#     {'db_id': 'UMLS:C0274848', 'score': 0.7909846305847168},
#     {'db_id': 'UMLS:C0275056', 'score': 0.7885827422142029},
#     {'db_id': 'UMLS:C0275067', 'score': 0.7882724404335022},
#     {'db_id': 'UMLS:C0348754', 'score': 0.785512387752533},
#     {'db_id': 'UMLS:C0344124', 'score': 0.7849006056785583}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0600688'}]},
#   {'offsets': [(569, 578)],
#    'text': 'recovered',
#    'candidates': [{'db_id': 'UMLS:C2004454', 'score': 0.8328160643577576},
#     {'db_id': 'UMLS:C1709863', 'score': 0.8071500062942505},
#     {'db_id': 'UMLS:C2826210', 'score': 0.7962479591369629},
#     {'db_id': 'UMLS:C4524578', 'score': 0.7919111847877502},
#     {'db_id': 'UMLS:C0140116', 'score': 0.773873507976532},
#     {'db_id': 'UMLS:C1419326', 'score': 0.773873507976532},
#     {'db_id': 'UMLS:C1546957', 'score': 0.755936324596405},
#     {'db_id': 'UMLS:C3686474', 'score': 0.7169649600982666},
#     {'db_id': 'UMLS:C1562582', 'score': 0.7056894898414612},
#     {'db_id': 'UMLS:C3242232', 'score': 0.7004424929618835}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C2004454'}]},
#   {'offsets': [(579, 593)],
#    'text': 'cell viability',
#    'candidates': [{'db_id': 'UMLS:C0007620', 'score': 1.0},
#     {'db_id': 'UMLS:C1516362', 'score': 0.8491372466087341},
#     {'db_id': 'UMLS:C0429848', 'score': 0.7368645668029785},
#     {'db_id': 'UMLS:C1261170', 'score': 0.7368645668029785},
#     {'db_id': 'UMLS:C1449936', 'score': 0.7288508415222168},
#     {'db_id': 'UMLS:C1300991', 'score': 0.7108904719352722}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0007620'}]},
#   {'offsets': [(599, 608)],
#    'text': 'apoptosis',
#    'candidates': [{'db_id': 'UMLS:C0162638', 'score': 1.0},
#     {'db_id': 'UMLS:C2247960', 'score': 0.8234089016914368},
#     {'db_id': 'UMLS:C1326202', 'score': 0.8038336038589478},
#     {'db_id': 'UMLS:C1332322', 'score': 0.7967405319213867},
#     {'db_id': 'UMLS:C1660771', 'score': 0.7909232378005981},
#     {'db_id': 'UMLS:C2610891', 'score': 0.7842937111854553},
#     {'db_id': 'UMLS:C4329354', 'score': 0.7827578186988831},
#     {'db_id': 'UMLS:C1326205', 'score': 0.7727738618850708},
#     {'db_id': 'UMLS:C1454645', 'score': 0.7598106861114502},
#     {'db_id': 'UMLS:C1539477', 'score': 0.7598106861114502},
#     {'db_id': 'UMLS:C1564881', 'score': 0.7557398080825806},
#     {'db_id': 'UMLS:C1148568', 'score': 0.7536895275115967},
#     {'db_id': 'UMLS:C4233500', 'score': 0.7531155943870544},
#     {'db_id': 'UMLS:C3269144', 'score': 0.7494465708732605},
#     {'db_id': 'UMLS:C2246411', 'score': 0.7446570992469788},
#     {'db_id': 'UMLS:C3266896', 'score': 0.7426552772521973},
#     {'db_id': 'UMLS:C1332323', 'score': 0.7344915270805359},
#     {'db_id': 'UMLS:C3269138', 'score': 0.7319819927215576}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0162638'}]},
#   {'offsets': [(623, 634)],
#    'text': 'nonylphenol',
#    'candidates': [{'db_id': 'UMLS:C0068946', 'score': 1.0},
#     {'db_id': 'UMLS:C0953814', 'score': 0.8478714227676392},
#     {'db_id': 'UMLS:C0953815', 'score': 0.8301727175712585},
#     {'db_id': 'UMLS:C0970196', 'score': 0.7795582413673401},
#     {'db_id': 'UMLS:C0097405', 'score': 0.767101526260376},
#     {'db_id': 'UMLS:C3857939', 'score': 0.757386326789856},
#     {'db_id': 'UMLS:C0953813', 'score': 0.7489328384399414},
#     {'db_id': 'UMLS:C4236359', 'score': 0.7475515604019165},
#     {'db_id': 'UMLS:C0132779', 'score': 0.7382228374481201}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0068946'}]},
#   {'offsets': [(648, 657)],
#    'text': 'decreased',
#    'candidates': [{'db_id': 'UMLS:C0442797', 'score': 1.0},
#     {'db_id': 'UMLS:C0728725', 'score': 0.874328076839447},
#     {'db_id': 'UMLS:C1168174', 'score': 0.8630114793777466},
#     {'db_id': 'UMLS:C4528292', 'score': 0.8499547243118286},
#     {'db_id': 'UMLS:C0855389', 'score': 0.8431493043899536},
#     {'db_id': 'UMLS:C0855618', 'score': 0.8337022066116333},
#     {'db_id': 'UMLS:C0860941', 'score': 0.832693338394165},
#     {'db_id': 'UMLS:C0580413', 'score': 0.8301555514335632},
#     {'db_id': 'UMLS:C0860904', 'score': 0.8251616954803467},
#     {'db_id': 'UMLS:C0151934', 'score': 0.8227338194847107},
#     {'db_id': 'UMLS:C0042798', 'score': 0.8145045042037964},
#     {'db_id': 'UMLS:C0558171', 'score': 0.8145045042037964},
#     {'db_id': 'UMLS:C3665347', 'score': 0.8145045042037964},
#     {'db_id': 'UMLS:C4553853', 'score': 0.8145045042037964},
#     {'db_id': 'UMLS:C0240174', 'score': 0.8134526610374451},
#     {'db_id': 'UMLS:C4528289', 'score': 0.8081247806549072},
#     {'db_id': 'UMLS:C3808947', 'score': 0.8066015243530273},
#     {'db_id': 'UMLS:C4229022', 'score': 0.8056118488311768},
#     {'db_id': 'UMLS:C1295689', 'score': 0.7989278435707092},
#     {'db_id': 'UMLS:C0239150', 'score': 0.7986975908279419},
#     {'db_id': 'UMLS:C0231299', 'score': 0.7983161211013794}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0442797'}]},
#   {'offsets': [(658, 675)],
#    'text': 'DNA fragmentation',
#    'candidates': [{'db_id': 'UMLS:C0376669', 'score': 1.0},
#     {'db_id': 'UMLS:C4525777', 'score': 0.8683043718338013},
#     {'db_id': 'UMLS:C3822536', 'score': 0.8623250126838684},
#     {'db_id': 'UMLS:C0332472', 'score': 0.8478021621704102},
#     {'db_id': 'UMLS:C1881708', 'score': 0.8478021621704102},
#     {'db_id': 'UMLS:C0684192', 'score': 0.8248363137245178},
#     {'db_id': 'UMLS:C0663605', 'score': 0.7994222640991211},
#     {'db_id': 'UMLS:C1749515', 'score': 0.7953270673751831},
#     {'db_id': 'UMLS:C0538150', 'score': 0.7647331953048706},
#     {'db_id': 'UMLS:C0185061', 'score': 0.7503781914710999},
#     {'db_id': 'UMLS:C3822534', 'score': 0.7387821674346924},
#     {'db_id': 'UMLS:C3822543', 'score': 0.7339321970939636},
#     {'db_id': 'UMLS:C3822542', 'score': 0.7151556611061096},
#     {'db_id': 'UMLS:C1505243', 'score': 0.7149497866630554},
#     {'db_id': 'UMLS:C0341444', 'score': 0.7048500180244446},
#     {'db_id': 'UMLS:C1413983', 'score': 0.703233540058136},
#     {'db_id': 'UMLS:C1504769', 'score': 0.703233540058136}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0376669'}]},
#   {'offsets': [(686, 695)],
#    'text': 'apoptosis',
#    'candidates': [{'db_id': 'UMLS:C0162638', 'score': 1.0},
#     {'db_id': 'UMLS:C2247960', 'score': 0.8234089016914368},
#     {'db_id': 'UMLS:C1326202', 'score': 0.8038336038589478},
#     {'db_id': 'UMLS:C1332322', 'score': 0.7967405319213867},
#     {'db_id': 'UMLS:C1660771', 'score': 0.7909232378005981},
#     {'db_id': 'UMLS:C2610891', 'score': 0.7842937111854553},
#     {'db_id': 'UMLS:C4329354', 'score': 0.7827578186988831},
#     {'db_id': 'UMLS:C1326205', 'score': 0.7727738618850708},
#     {'db_id': 'UMLS:C1454645', 'score': 0.7598106861114502},
#     {'db_id': 'UMLS:C1539477', 'score': 0.7598106861114502},
#     {'db_id': 'UMLS:C1564881', 'score': 0.7557398080825806},
#     {'db_id': 'UMLS:C1148568', 'score': 0.7536895275115967},
#     {'db_id': 'UMLS:C4233500', 'score': 0.7531155943870544},
#     {'db_id': 'UMLS:C3269144', 'score': 0.7494465708732605},
#     {'db_id': 'UMLS:C2246411', 'score': 0.7446570992469788},
#     {'db_id': 'UMLS:C3266896', 'score': 0.7426552772521973},
#     {'db_id': 'UMLS:C1332323', 'score': 0.7344915270805359},
#     {'db_id': 'UMLS:C3269138', 'score': 0.7319819927215576}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0162638'}]},
#   {'offsets': [(699, 709)],
#    'text': 'PC12 cells',
#    'candidates': [{'db_id': 'UMLS:C0085262', 'score': 1.0}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0085262'}]},
#   {'offsets': [(716, 726)],
#    'text': 'phenomenon',
#    'candidates': [{'db_id': 'UMLS:C0278216', 'score': 0.8370029926300049},
#     {'db_id': 'UMLS:C0853404', 'score': 0.8316740989685059},
#     {'db_id': 'UMLS:C0003907', 'score': 0.7908133268356323},
#     {'db_id': 'UMLS:C1532656', 'score': 0.7840670347213745},
#     {'db_id': 'UMLS:C0042795', 'score': 0.7757086157798767},
#     {'db_id': 'UMLS:C0233782', 'score': 0.7686787843704224},
#     {'db_id': 'UMLS:C1882532', 'score': 0.7685529589653015},
#     {'db_id': 'UMLS:C2350543', 'score': 0.7566008567810059},
#     {'db_id': 'UMLS:C0334147', 'score': 0.7540820837020874}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0278216'}]},
#   {'offsets': [(747, 755)],
#    'text': 'treating',
#    'candidates': [{'db_id': 'UMLS:C2985688', 'score': 0.7738416194915771}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C2985688'}]},
#   {'offsets': [(756, 765)],
#    'text': 'apoptotic',
#    'candidates': [{'db_id': 'UMLS:C3269134', 'score': 0.8495911359786987},
#     {'db_id': 'UMLS:C0162638', 'score': 0.8021917939186096},
#     {'db_id': 'UMLS:C1159821', 'score': 0.7703478336334229},
#     {'db_id': 'UMLS:C2986514', 'score': 0.7681089043617249},
#     {'db_id': 'UMLS:C1836846', 'score': 0.7600083351135254},
#     {'db_id': 'UMLS:C4234958', 'score': 0.7535989284515381},
#     {'db_id': 'UMLS:C2751835', 'score': 0.7304294109344482},
#     {'db_id': 'UMLS:C4231137', 'score': 0.714859127998352},
#     {'db_id': 'UMLS:C1523908', 'score': 0.7009235620498657}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C3269134'}]},
#   {'offsets': [(766, 776)],
#    'text': 'PC12 cells',
#    'candidates': [{'db_id': 'UMLS:C0085262', 'score': 1.0}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0085262'}]},
#   {'offsets': [(782, 793)],
#    'text': 'nonylphenol',
#    'candidates': [{'db_id': 'UMLS:C0068946', 'score': 1.0},
#     {'db_id': 'UMLS:C0953814', 'score': 0.8478714227676392},
#     {'db_id': 'UMLS:C0953815', 'score': 0.8301727175712585},
#     {'db_id': 'UMLS:C0970196', 'score': 0.7795582413673401},
#     {'db_id': 'UMLS:C0097405', 'score': 0.767101526260376},
#     {'db_id': 'UMLS:C3857939', 'score': 0.757386326789856},
#     {'db_id': 'UMLS:C0953813', 'score': 0.7489328384399414},
#     {'db_id': 'UMLS:C4236359', 'score': 0.7475515604019165},
#     {'db_id': 'UMLS:C0132779', 'score': 0.7382228374481201}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0068946'}]},
#   {'offsets': [(820, 832)],
#    'text': 'cytochrome c',
#    'candidates': [{'db_id': 'UMLS:C0010749', 'score': 1.0},
#     {'db_id': 'UMLS:C1153524', 'score': 1.0},
#     {'db_id': 'UMLS:C1426584', 'score': 1.0},
#     {'db_id': 'UMLS:C4318401', 'score': 1.0},
#     {'db_id': 'UMLS:C0010755', 'score': 0.965541422367096},
#     {'db_id': 'UMLS:C0056953', 'score': 0.9545375108718872},
#     {'db_id': 'UMLS:C0010798', 'score': 0.9255191683769226},
#     {'db_id': 'UMLS:C1325304', 'score': 0.9255191683769226},
#     {'db_id': 'UMLS:C0056946', 'score': 0.8928513526916504},
#     {'db_id': 'UMLS:C0056918', 'score': 0.8685439229011536},
#     {'db_id': 'UMLS:C1153528', 'score': 0.8685439229011536},
#     {'db_id': 'UMLS:C0010744', 'score': 0.8621929883956909},
#     {'db_id': 'UMLS:C0111799', 'score': 0.8510327935218811},
#     {'db_id': 'UMLS:C0215247', 'score': 0.8477939367294312},
#     {'db_id': 'UMLS:C0056960', 'score': 0.8392401337623596},
#     {'db_id': 'UMLS:C0056919', 'score': 0.8377947211265564},
#     {'db_id': 'UMLS:C0284507', 'score': 0.8337011933326721},
#     {'db_id': 'UMLS:C0056951', 'score': 0.8332878947257996},
#     {'db_id': 'UMLS:C0056961', 'score': 0.8249294757843018},
#     {'db_id': 'UMLS:C1621805', 'score': 0.8249294757843018},
#     {'db_id': 'UMLS:C0526110', 'score': 0.8240941762924194},
#     {'db_id': 'UMLS:C0010754', 'score': 0.8236024379730225},
#     {'db_id': 'UMLS:C3894813', 'score': 0.8221146464347839},
#     {'db_id': 'UMLS:C0010746', 'score': 0.8163187503814697},
#     {'db_id': 'UMLS:C0056944', 'score': 0.8150079846382141}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0010749'}]},
#   {'offsets': [(850, 857)],
#    'text': 'cytosol',
#    'candidates': [{'db_id': 'UMLS:C1383501', 'score': 1.0},
#     {'db_id': 'UMLS:C2752457', 'score': 0.8229812383651733},
#     {'db_id': 'UMLS:C4236623', 'score': 0.7813878059387207},
#     {'db_id': 'UMLS:C2328803', 'score': 0.7543310523033142},
#     {'db_id': 'UMLS:C2328628', 'score': 0.7269684076309204},
#     {'db_id': 'UMLS:C0230695', 'score': 0.7092211246490479},
#     {'db_id': 'UMLS:C2338345', 'score': 0.7046694159507751},
#     {'db_id': 'UMLS:C1820051', 'score': 0.7034279108047485},
#     {'db_id': 'UMLS:C1183509', 'score': 0.700153648853302}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C1383501'}]},
#   {'offsets': [(858, 867)],
#    'text': 'decreased',
#    'candidates': [{'db_id': 'UMLS:C0442797', 'score': 1.0},
#     {'db_id': 'UMLS:C0728725', 'score': 0.874328076839447},
#     {'db_id': 'UMLS:C1168174', 'score': 0.8630114793777466},
#     {'db_id': 'UMLS:C4528292', 'score': 0.8499547243118286},
#     {'db_id': 'UMLS:C0855389', 'score': 0.8431493043899536},
#     {'db_id': 'UMLS:C0855618', 'score': 0.8337022066116333},
#     {'db_id': 'UMLS:C0860941', 'score': 0.832693338394165},
#     {'db_id': 'UMLS:C0580413', 'score': 0.8301555514335632},
#     {'db_id': 'UMLS:C0860904', 'score': 0.8251616954803467},
#     {'db_id': 'UMLS:C0151934', 'score': 0.8227338194847107},
#     {'db_id': 'UMLS:C0042798', 'score': 0.8145045042037964},
#     {'db_id': 'UMLS:C0558171', 'score': 0.8145045042037964},
#     {'db_id': 'UMLS:C3665347', 'score': 0.8145045042037964},
#     {'db_id': 'UMLS:C4553853', 'score': 0.8145045042037964},
#     {'db_id': 'UMLS:C0240174', 'score': 0.8134526610374451},
#     {'db_id': 'UMLS:C4528289', 'score': 0.8081247806549072},
#     {'db_id': 'UMLS:C3808947', 'score': 0.8066015243530273},
#     {'db_id': 'UMLS:C4229022', 'score': 0.8056118488311768},
#     {'db_id': 'UMLS:C1295689', 'score': 0.7989278435707092},
#     {'db_id': 'UMLS:C0239150', 'score': 0.7986975908279419},
#     {'db_id': 'UMLS:C0231299', 'score': 0.7983161211013794}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0442797'}]},
#   {'offsets': [(891, 906)],
#    'text': 'apoptotic cells',
#    'candidates': [{'db_id': 'UMLS:C0162638', 'score': 0.7187338471412659},
#     {'db_id': 'UMLS:C1326202', 'score': 0.7120977640151978}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0162638'}]},
#   {'offsets': [(911, 923)],
#    'text': 'treated with',
#    'candidates': [{'db_id': 'UMLS:C0332293', 'score': 0.9999999403953552}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0332293'}]},
#   {'offsets': [(924, 935)],
#    'text': 'nonylphenol',
#    'candidates': [{'db_id': 'UMLS:C0068946', 'score': 1.0},
#     {'db_id': 'UMLS:C0953814', 'score': 0.8478714227676392},
#     {'db_id': 'UMLS:C0953815', 'score': 0.8301727175712585},
#     {'db_id': 'UMLS:C0970196', 'score': 0.7795582413673401},
#     {'db_id': 'UMLS:C0097405', 'score': 0.767101526260376},
#     {'db_id': 'UMLS:C3857939', 'score': 0.757386326789856},
#     {'db_id': 'UMLS:C0953813', 'score': 0.7489328384399414},
#     {'db_id': 'UMLS:C4236359', 'score': 0.7475515604019165},
#     {'db_id': 'UMLS:C0132779', 'score': 0.7382228374481201}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0068946'}]},
#   {'offsets': [(965, 968)],
#    'text': 'Bax',
#    'candidates': [{'db_id': 'UMLS:C0219474', 'score': 1.0},
#     {'db_id': 'UMLS:C0812198', 'score': 1.0},
#     {'db_id': 'UMLS:C1221086', 'score': 0.7818325161933899},
#     {'db_id': 'UMLS:C1047341', 'score': 0.7652437090873718},
#     {'db_id': 'UMLS:C1231045', 'score': 0.7199282050132751},
#     {'db_id': 'UMLS:C2918586', 'score': 0.7179879546165466}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0812198'}]},
#   {'offsets': [(969, 977)],
#    'text': 'contents',
#    'candidates': [{'db_id': 'UMLS:C1552853', 'score': 1.0},
#     {'db_id': 'UMLS:C0017177', 'score': 0.7861839532852173},
#     {'db_id': 'UMLS:C0426397', 'score': 0.7833443284034729},
#     {'db_id': 'UMLS:C0227406', 'score': 0.7750446796417236},
#     {'db_id': 'UMLS:C1300583', 'score': 0.7715583443641663},
#     {'db_id': 'UMLS:C0227363', 'score': 0.7628078460693359},
#     {'db_id': 'UMLS:C1300584', 'score': 0.7622144222259521},
#     {'db_id': 'UMLS:C0423896', 'score': 0.748690128326416},
#     {'db_id': 'UMLS:C0226893', 'score': 0.7479473352432251},
#     {'db_id': 'UMLS:C0426723', 'score': 0.7402256727218628},
#     {'db_id': 'UMLS:C0038352', 'score': 0.7379180192947388},
#     {'db_id': 'UMLS:C0227245', 'score': 0.7153414487838745},
#     {'db_id': 'UMLS:C1285982', 'score': 0.7096526622772217}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C1552853'}]},
#   {'offsets': [(981, 996)],
#    'text': 'apoptotic cells',
#    'candidates': [{'db_id': 'UMLS:C0162638', 'score': 0.7187338471412659},
#     {'db_id': 'UMLS:C1326202', 'score': 0.7120977640151978}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0162638'}]},
#   {'offsets': [(1002, 1009)],
#    'text': 'reduced',
#    'candidates': [{'db_id': 'UMLS:C0240291', 'score': 0.8951568007469177},
#     {'db_id': 'UMLS:C0728725', 'score': 0.8460635542869568},
#     {'db_id': 'UMLS:C0206008', 'score': 0.842868983745575},
#     {'db_id': 'UMLS:C1707814', 'score': 0.8184823393821716},
#     {'db_id': 'UMLS:C0853711', 'score': 0.7902964353561401},
#     {'db_id': 'UMLS:C0302583', 'score': 0.7849313616752625},
#     {'db_id': 'UMLS:C0042798', 'score': 0.7776346206665039},
#     {'db_id': 'UMLS:C0012167', 'score': 0.7621821165084839},
#     {'db_id': 'UMLS:C1855768', 'score': 0.7527686953544617},
#     {'db_id': 'UMLS:C1839025', 'score': 0.7523694038391113},
#     {'db_id': 'UMLS:C0018772', 'score': 0.7447023391723633},
#     {'db_id': 'UMLS:C1384666', 'score': 0.7447023391723633},
#     {'db_id': 'UMLS:C0018966', 'score': 0.7384268641471863},
#     {'db_id': 'UMLS:C4732780', 'score': 0.7348847985267639},
#     {'db_id': 'UMLS:C0404533', 'score': 0.7318421006202698},
#     {'db_id': 'UMLS:C2675900', 'score': 0.7261030077934265},
#     {'db_id': 'UMLS:C4726018', 'score': 0.7247804999351501},
#     {'db_id': 'UMLS:C4331236', 'score': 0.7197192311286926},
#     {'db_id': 'UMLS:C0744727', 'score': 0.7161843180656433},
#     {'db_id': 'UMLS:C4230744', 'score': 0.700935423374176}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0240291'}]},
#   {'offsets': [(1016, 1027)],
#    'text': 'exposure to',
#    'candidates': [{'db_id': 'UMLS:C0274281', 'score': 0.9262424111366272},
#     {'db_id': 'UMLS:C0239930', 'score': 0.858124852180481},
#     {'db_id': 'UMLS:C2220426', 'score': 0.8500612378120422},
#     {'db_id': 'UMLS:C2362603', 'score': 0.8452452421188354},
#     {'db_id': 'UMLS:C0149666', 'score': 0.8389102220535278},
#     {'db_id': 'UMLS:C0040537', 'score': 0.8381475210189819},
#     {'db_id': 'UMLS:C0681792', 'score': 0.8290051221847534},
#     {'db_id': 'UMLS:C4520513', 'score': 0.8261807560920715},
#     {'db_id': 'UMLS:C0238908', 'score': 0.8222136497497559},
#     {'db_id': 'UMLS:C0700522', 'score': 0.8185310959815979},
#     {'db_id': 'UMLS:C2732915', 'score': 0.8179871439933777},
#     {'db_id': 'UMLS:C0261749', 'score': 0.8137821555137634},
#     {'db_id': 'UMLS:C0240062', 'score': 0.8056401014328003},
#     {'db_id': 'UMLS:C2732914', 'score': 0.8037437796592712},
#     {'db_id': 'UMLS:C0015333', 'score': 0.8007833957672119},
#     {'db_id': 'UMLS:C0240323', 'score': 0.7903090119361877}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0274281'}]},
#   {'offsets': [(1028, 1039)],
#    'text': 'nonylphenol',
#    'candidates': [{'db_id': 'UMLS:C0068946', 'score': 1.0},
#     {'db_id': 'UMLS:C0953814', 'score': 0.8478714227676392},
#     {'db_id': 'UMLS:C0953815', 'score': 0.8301727175712585},
#     {'db_id': 'UMLS:C0970196', 'score': 0.7795582413673401},
#     {'db_id': 'UMLS:C0097405', 'score': 0.767101526260376},
#     {'db_id': 'UMLS:C3857939', 'score': 0.757386326789856},
#     {'db_id': 'UMLS:C0953813', 'score': 0.7489328384399414},
#     {'db_id': 'UMLS:C4236359', 'score': 0.7475515604019165},
#     {'db_id': 'UMLS:C0132779', 'score': 0.7382228374481201}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0068946'}]},
#   {'offsets': [(1060, 1084)],
#    'text': 'nonylphenol diethoxylate',
#    'candidates': [{'db_id': 'UMLS:C0132779', 'score': 0.8804130554199219},
#     {'db_id': 'UMLS:C0604118', 'score': 0.726760983467102},
#     {'db_id': 'UMLS:C0068946', 'score': 0.7034839391708374}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0132779'}]},
#   {'offsets': [(1102, 1108)],
#    'text': 'effect',
#    'candidates': [{'db_id': 'UMLS:C1518681', 'score': 1.0},
#     {'db_id': 'UMLS:C2945677', 'score': 0.8937566876411438},
#     {'db_id': 'UMLS:C2362743', 'score': 0.8869321942329407},
#     {'db_id': 'UMLS:C0543419', 'score': 0.8738999366760254},
#     {'db_id': 'UMLS:C1368999', 'score': 0.8738999366760254},
#     {'db_id': 'UMLS:C0879626', 'score': 0.8347170352935791},
#     {'db_id': 'UMLS:C0161734', 'score': 0.8286240100860596},
#     {'db_id': 'UMLS:C0221500', 'score': 0.821723461151123},
#     {'db_id': 'UMLS:C4086564', 'score': 0.8180662393569946},
#     {'db_id': 'UMLS:C0872206', 'score': 0.8146888613700867},
#     {'db_id': 'UMLS:C1567089', 'score': 0.8099912405014038},
#     {'db_id': 'UMLS:C5205845', 'score': 0.7933931350708008},
#     {'db_id': 'UMLS:C3274396', 'score': 0.7895260453224182},
#     {'db_id': 'UMLS:C3178735', 'score': 0.7864585518836975},
#     {'db_id': 'UMLS:C4277541', 'score': 0.7834433913230896},
#     {'db_id': 'UMLS:C1319171', 'score': 0.7831936478614807}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C1518681'}]},
#   {'offsets': [(1112, 1121)],
#    'text': 'apoptosis',
#    'candidates': [{'db_id': 'UMLS:C0162638', 'score': 1.0},
#     {'db_id': 'UMLS:C2247960', 'score': 0.8234089016914368},
#     {'db_id': 'UMLS:C1326202', 'score': 0.8038336038589478},
#     {'db_id': 'UMLS:C1332322', 'score': 0.7967405319213867},
#     {'db_id': 'UMLS:C1660771', 'score': 0.7909232378005981},
#     {'db_id': 'UMLS:C2610891', 'score': 0.7842937111854553},
#     {'db_id': 'UMLS:C4329354', 'score': 0.7827578186988831},
#     {'db_id': 'UMLS:C1326205', 'score': 0.7727738618850708},
#     {'db_id': 'UMLS:C1454645', 'score': 0.7598106861114502},
#     {'db_id': 'UMLS:C1539477', 'score': 0.7598106861114502},
#     {'db_id': 'UMLS:C1564881', 'score': 0.7557398080825806},
#     {'db_id': 'UMLS:C1148568', 'score': 0.7536895275115967},
#     {'db_id': 'UMLS:C4233500', 'score': 0.7531155943870544},
#     {'db_id': 'UMLS:C3269144', 'score': 0.7494465708732605},
#     {'db_id': 'UMLS:C2246411', 'score': 0.7446570992469788},
#     {'db_id': 'UMLS:C3266896', 'score': 0.7426552772521973},
#     {'db_id': 'UMLS:C1332323', 'score': 0.7344915270805359},
#     {'db_id': 'UMLS:C3269138', 'score': 0.7319819927215576}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0162638'}]},
#   {'offsets': [(1125, 1135)],
#    'text': 'PC12 cells',
#    'candidates': [{'db_id': 'UMLS:C0085262', 'score': 1.0}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0085262'}]},
#   {'offsets': [(1148, 1159)],
#    'text': 'nonylphenol',
#    'candidates': [{'db_id': 'UMLS:C0068946', 'score': 1.0},
#     {'db_id': 'UMLS:C0953814', 'score': 0.8478714227676392},
#     {'db_id': 'UMLS:C0953815', 'score': 0.8301727175712585},
#     {'db_id': 'UMLS:C0970196', 'score': 0.7795582413673401},
#     {'db_id': 'UMLS:C0097405', 'score': 0.767101526260376},
#     {'db_id': 'UMLS:C3857939', 'score': 0.757386326789856},
#     {'db_id': 'UMLS:C0953813', 'score': 0.7489328384399414},
#     {'db_id': 'UMLS:C4236359', 'score': 0.7475515604019165},
#     {'db_id': 'UMLS:C0132779', 'score': 0.7382228374481201}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0068946'}]},
#   {'offsets': [(1176, 1185)],
#    'text': 'apoptosis',
#    'candidates': [{'db_id': 'UMLS:C0162638', 'score': 1.0},
#     {'db_id': 'UMLS:C2247960', 'score': 0.8234089016914368},
#     {'db_id': 'UMLS:C1326202', 'score': 0.8038336038589478},
#     {'db_id': 'UMLS:C1332322', 'score': 0.7967405319213867},
#     {'db_id': 'UMLS:C1660771', 'score': 0.7909232378005981},
#     {'db_id': 'UMLS:C2610891', 'score': 0.7842937111854553},
#     {'db_id': 'UMLS:C4329354', 'score': 0.7827578186988831},
#     {'db_id': 'UMLS:C1326205', 'score': 0.7727738618850708},
#     {'db_id': 'UMLS:C1454645', 'score': 0.7598106861114502},
#     {'db_id': 'UMLS:C1539477', 'score': 0.7598106861114502},
#     {'db_id': 'UMLS:C1564881', 'score': 0.7557398080825806},
#     {'db_id': 'UMLS:C1148568', 'score': 0.7536895275115967},
#     {'db_id': 'UMLS:C4233500', 'score': 0.7531155943870544},
#     {'db_id': 'UMLS:C3269144', 'score': 0.7494465708732605},
#     {'db_id': 'UMLS:C2246411', 'score': 0.7446570992469788},
#     {'db_id': 'UMLS:C3266896', 'score': 0.7426552772521973},
#     {'db_id': 'UMLS:C1332323', 'score': 0.7344915270805359},
#     {'db_id': 'UMLS:C3269138', 'score': 0.7319819927215576}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0162638'}]},
#   {'offsets': [(1186, 1193)],
#    'text': 'induced',
#    'candidates': [{'db_id': 'UMLS:C0153122', 'score': 0.7563474178314209},
#     {'db_id': 'UMLS:C1428046', 'score': 0.7431603074073792},
#     {'db_id': 'UMLS:C1512710', 'score': 0.741400957107544},
#     {'db_id': 'UMLS:C0858744', 'score': 0.7410463690757751},
#     {'db_id': 'UMLS:C0235661', 'score': 0.7390875816345215},
#     {'db_id': 'UMLS:C0022875', 'score': 0.7339017987251282},
#     {'db_id': 'UMLS:C0259787', 'score': 0.7339017987251282},
#     {'db_id': 'UMLS:C1708502', 'score': 0.7186915874481201},
#     {'db_id': 'UMLS:C0269439', 'score': 0.7103714346885681},
#     {'db_id': 'UMLS:C0392535', 'score': 0.7103714346885681},
#     {'db_id': 'UMLS:C1704300', 'score': 0.7103714346885681},
#     {'db_id': 'UMLS:C2985288', 'score': 0.7042877078056335},
#     {'db_id': 'UMLS:C1427643', 'score': 0.7007309794425964}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0153122'}]},
#   {'offsets': [(1197, 1214)],
#    'text': 'serum deprivation',
#    'candidates': [{'db_id': 'UMLS:C0599620', 'score': 0.7079419493675232}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0599620'}]},
#   {'offsets': [(1234, 1243)],
#    'text': 'structure',
#    'candidates': [{'db_id': 'UMLS:C0678594', 'score': 1.0},
#     {'db_id': 'UMLS:C0003461', 'score': 0.870040774345398},
#     {'db_id': 'UMLS:C0220805', 'score': 0.8584968447685242},
#     {'db_id': 'UMLS:C1517495', 'score': 0.8573675155639648},
#     {'db_id': 'UMLS:C0262950', 'score': 0.8507021069526672},
#     {'db_id': 'UMLS:C0018563', 'score': 0.8341522216796875},
#     {'db_id': 'UMLS:C3714557', 'score': 0.8341522216796875},
#     {'db_id': 'UMLS:C1827394', 'score': 0.8337031602859497},
#     {'db_id': 'UMLS:C0230942', 'score': 0.8326903581619263},
#     {'db_id': 'UMLS:C0034896', 'score': 0.831636905670166},
#     {'db_id': 'UMLS:C0008114', 'score': 0.830575168132782},
#     {'db_id': 'UMLS:C0458563', 'score': 0.8300964832305908},
#     {'db_id': 'UMLS:C0013443', 'score': 0.829653263092041},
#     {'db_id': 'UMLS:C0015450', 'score': 0.8289763927459717},
#     {'db_id': 'UMLS:C0009368', 'score': 0.8251320123672485},
#     {'db_id': 'UMLS:C0043189', 'score': 0.8242087364196777}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0678594'}]},
#   {'offsets': [(1255, 1264)],
#    'text': 'compounds',
#    'candidates': [{'db_id': 'UMLS:C0010124', 'score': 0.9376974105834961},
#     {'db_id': 'UMLS:C0206446', 'score': 0.9222623705863953},
#     {'db_id': 'UMLS:C0002362', 'score': 0.8796977996826172},
#     {'db_id': 'UMLS:C0684279', 'score': 0.8591695427894592},
#     {'db_id': 'UMLS:C0303399', 'score': 0.8586146235466003},
#     {'db_id': 'UMLS:C0006031', 'score': 0.8556841015815735},
#     {'db_id': 'UMLS:C0303231', 'score': 0.8551028966903687},
#     {'db_id': 'UMLS:C0029036', 'score': 0.853862464427948},
#     {'db_id': 'UMLS:C0206105', 'score': 0.8471705913543701},
#     {'db_id': 'UMLS:C0003645', 'score': 0.8408780694007874},
#     {'db_id': 'UMLS:C0303186', 'score': 0.8379759788513184},
#     {'db_id': 'UMLS:C0007011', 'score': 0.8362987637519836},
#     {'db_id': 'UMLS:C0206445', 'score': 0.8338714838027954},
#     {'db_id': 'UMLS:C0032902', 'score': 0.8313434720039368},
#     {'db_id': 'UMLS:C0206102', 'score': 0.8306189179420471},
#     {'db_id': 'UMLS:C0206134', 'score': 0.8293891549110413},
#     {'db_id': 'UMLS:C3536918', 'score': 0.8293891549110413},
#     {'db_id': 'UMLS:C3825234', 'score': 0.8280723690986633},
#     {'db_id': 'UMLS:C0003038', 'score': 0.8230788111686707},
#     {'db_id': 'UMLS:C0029224', 'score': 0.8219588398933411},
#     {'db_id': 'UMLS:C0040493', 'score': 0.817894697189331}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0010124'}]},
#   {'offsets': [(1308, 1318)],
#    'text': 'phenomenon',
#    'candidates': [{'db_id': 'UMLS:C0278216', 'score': 0.8370029926300049},
#     {'db_id': 'UMLS:C0853404', 'score': 0.8316740989685059},
#     {'db_id': 'UMLS:C0003907', 'score': 0.7908133268356323},
#     {'db_id': 'UMLS:C1532656', 'score': 0.7840670347213745},
#     {'db_id': 'UMLS:C0042795', 'score': 0.7757086157798767},
#     {'db_id': 'UMLS:C0233782', 'score': 0.7686787843704224},
#     {'db_id': 'UMLS:C1882532', 'score': 0.7685529589653015},
#     {'db_id': 'UMLS:C2350543', 'score': 0.7566008567810059},
#     {'db_id': 'UMLS:C0334147', 'score': 0.7540820837020874}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0278216'}]},
#   {'offsets': [(1349, 1360)],
#    'text': 'nonylphenol',
#    'candidates': [{'db_id': 'UMLS:C0068946', 'score': 1.0},
#     {'db_id': 'UMLS:C0953814', 'score': 0.8478714227676392},
#     {'db_id': 'UMLS:C0953815', 'score': 0.8301727175712585},
#     {'db_id': 'UMLS:C0970196', 'score': 0.7795582413673401},
#     {'db_id': 'UMLS:C0097405', 'score': 0.767101526260376},
#     {'db_id': 'UMLS:C3857939', 'score': 0.757386326789856},
#     {'db_id': 'UMLS:C0953813', 'score': 0.7489328384399414},
#     {'db_id': 'UMLS:C4236359', 'score': 0.7475515604019165},
#     {'db_id': 'UMLS:C0132779', 'score': 0.7382228374481201}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0068946'}]},
#   {'offsets': [(1399, 1419)],
#    'text': 'cell differentiation',
#    'candidates': [{'db_id': 'UMLS:C0007589', 'score': 1.0},
#     {'db_id': 'UMLS:C1511002', 'score': 0.9546904563903809},
#     {'db_id': 'UMLS:C1155013', 'score': 0.9367268085479736},
#     {'db_id': 'UMLS:C1523325', 'score': 0.9155001044273376},
#     {'db_id': 'UMLS:C2753148', 'score': 0.9118021726608276},
#     {'db_id': 'UMLS:C1159884', 'score': 0.9075972437858582},
#     {'db_id': 'UMLS:C0598087', 'score': 0.9063172340393066},
#     {'db_id': 'UMLS:C2610521', 'score': 0.8996106386184692},
#     {'db_id': 'UMLS:C1753058', 'score': 0.8972442746162415},
#     {'db_id': 'UMLS:C1511938', 'score': 0.8948544263839722},
#     {'db_id': 'UMLS:C1326073', 'score': 0.8918853998184204},
#     {'db_id': 'UMLS:C1879542', 'score': 0.8916720747947693},
#     {'db_id': 'UMLS:C2752710', 'score': 0.887440025806427},
#     {'db_id': 'UMLS:C1326079', 'score': 0.8871363401412964},
#     {'db_id': 'UMLS:C2611086', 'score': 0.8871362209320068},
#     {'db_id': 'UMLS:C3271473', 'score': 0.884972095489502},
#     {'db_id': 'UMLS:C2755079', 'score': 0.8847876787185669},
#     {'db_id': 'UMLS:C2247990', 'score': 0.882519543170929}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0007589'}]},
#   {'offsets': [(1424, 1435)],
#    'text': 'development',
#    'candidates': [{'db_id': 'UMLS:C0678723', 'score': 1.0},
#     {'db_id': 'UMLS:C3272564', 'score': 1.0},
#     {'db_id': 'UMLS:C3151684', 'score': 0.9416382908821106},
#     {'db_id': 'UMLS:C2755041', 'score': 0.9281438589096069},
#     {'db_id': 'UMLS:C2246747', 'score': 0.9194554686546326},
#     {'db_id': 'UMLS:C0005939', 'score': 0.9063472747802734},
#     {'db_id': 'UMLS:C0599735', 'score': 0.9012060761451721},
#     {'db_id': 'UMLS:C1657984', 'score': 0.895642101764679},
#     {'db_id': 'UMLS:C0011435', 'score': 0.8910908699035645},
#     {'db_id': 'UMLS:C0028877', 'score': 0.8900448083877563},
#     {'db_id': 'UMLS:C1656421', 'score': 0.888776957988739},
#     {'db_id': 'UMLS:C0026527', 'score': 0.8886744976043701},
#     {'db_id': 'UMLS:C0815089', 'score': 0.8871542811393738},
#     {'db_id': 'UMLS:C2610452', 'score': 0.8870437741279602},
#     {'db_id': 'UMLS:C1817356', 'score': 0.886089026927948},
#     {'db_id': 'UMLS:C0011751', 'score': 0.885952353477478},
#     {'db_id': 'UMLS:C2753561', 'score': 0.8854342103004456},
#     {'db_id': 'UMLS:C0597252', 'score': 0.8835964798927307}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0678723'}]},
#   {'offsets': [(1444, 1463)],
#    'text': 'potentially harmful',
#    'candidates': [{'db_id': 'UMLS:C1628955', 'score': 0.7801739573478699},
#     {'db_id': 'UMLS:C1626903', 'score': 0.7486252188682556},
#     {'db_id': 'UMLS:C0013146', 'score': 0.7304976582527161}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C1628955'}]},
#   {'offsets': [(1474, 1483)],
#    'text': 'organisms',
#    'candidates': [{'db_id': 'UMLS:C0427964', 'score': 0.8073245882987976},
#     {'db_id': 'UMLS:C1318080', 'score': 0.8073245882987976},
#     {'db_id': 'UMLS:C0314734', 'score': 0.7824134230613708},
#     {'db_id': 'UMLS:C2936248', 'score': 0.7591969966888428},
#     {'db_id': 'UMLS:C0751338', 'score': 0.7552180886268616},
#     {'db_id': 'UMLS:C0002028', 'score': 0.7404270172119141},
#     {'db_id': 'UMLS:C0009054', 'score': 0.7303292155265808}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0427964'}]},
#   {'offsets': [(1510, 1516)],
#    'text': 'impact',
#    'candidates': [{'db_id': 'UMLS:C0726639', 'score': 0.9999999403953552},
#     {'db_id': 'UMLS:C1825598', 'score': 0.9999999403953552},
#     {'db_id': 'UMLS:C0040456', 'score': 0.8327757716178894},
#     {'db_id': 'UMLS:C0333124', 'score': 0.8327757716178894},
#     {'db_id': 'UMLS:C0491921', 'score': 0.8006371259689331},
#     {'db_id': 'UMLS:C0341034', 'score': 0.779595136642456},
#     {'db_id': 'UMLS:C0626004', 'score': 0.7518665194511414},
#     {'db_id': 'UMLS:C0399550', 'score': 0.746463418006897},
#     {'db_id': 'UMLS:C0391422', 'score': 0.7449589967727661},
#     {'db_id': 'UMLS:C0332714', 'score': 0.7444930076599121},
#     {'db_id': 'UMLS:C0626003', 'score': 0.7327052354812622},
#     {'db_id': 'UMLS:C0399551', 'score': 0.7221972346305847},
#     {'db_id': 'UMLS:C0021092', 'score': 0.7090995907783508},
#     {'db_id': 'UMLS:C1300130', 'score': 0.7029561996459961}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C1825598'}]},
#   {'offsets': [(1520, 1529)],
#    'text': 'apoptosis',
#    'candidates': [{'db_id': 'UMLS:C0162638', 'score': 1.0},
#     {'db_id': 'UMLS:C2247960', 'score': 0.8234089016914368},
#     {'db_id': 'UMLS:C1326202', 'score': 0.8038336038589478},
#     {'db_id': 'UMLS:C1332322', 'score': 0.7967405319213867},
#     {'db_id': 'UMLS:C1660771', 'score': 0.7909232378005981},
#     {'db_id': 'UMLS:C2610891', 'score': 0.7842937111854553},
#     {'db_id': 'UMLS:C4329354', 'score': 0.7827578186988831},
#     {'db_id': 'UMLS:C1326205', 'score': 0.7727738618850708},
#     {'db_id': 'UMLS:C1454645', 'score': 0.7598106861114502},
#     {'db_id': 'UMLS:C1539477', 'score': 0.7598106861114502},
#     {'db_id': 'UMLS:C1564881', 'score': 0.7557398080825806},
#     {'db_id': 'UMLS:C1148568', 'score': 0.7536895275115967},
#     {'db_id': 'UMLS:C4233500', 'score': 0.7531155943870544},
#     {'db_id': 'UMLS:C3269144', 'score': 0.7494465708732605},
#     {'db_id': 'UMLS:C2246411', 'score': 0.7446570992469788},
#     {'db_id': 'UMLS:C3266896', 'score': 0.7426552772521973},
#     {'db_id': 'UMLS:C1332323', 'score': 0.7344915270805359},
#     {'db_id': 'UMLS:C3269138', 'score': 0.7319819927215576}],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0162638'}]}]}

# %%
for dataset in dataset_names:
    for model in ['scibert','scispacy_large']:
        print(dataset, model)
        hits_dict = evaluate_linking(processed[dataset][model])
        display(format_output(hits_dict))
# Out:
# medmentions_st21pv scibert
#                             Semantic Type  recall@1  recall@2  recall@4  \
# 0                    Health Care Activity    0.4884    0.6209    0.7233
# 1                      Clinical Attribute    0.5388    0.7481    0.8450
# 2                                Chemical    0.4567    0.5994    0.7027
# 3                            Organization    0.6164    0.6681    0.7672
# 4                                   Virus    0.7107    0.8182    0.9421
# 5                                 Finding    0.4329    0.6164    0.7149
# 6                    Anatomical Structure    0.5967    0.7208    0.7988
# 7                     Injury or Poisoning    0.6625    0.7167    0.7792
# 8                               Bacterium    0.6517    0.7865    0.8390
# 9                         Spatial Concept    0.6373    0.7431    0.8075
# 10                         Medical Device    0.4671    0.6467    0.6826
# 11    Biomedical Occupation or Discipline    0.6378    0.7874    0.9134
# 12                         Body Substance    0.2587    0.2867    0.8462
# 13                              Eukaryote    0.5140    0.7319    0.8383
# 14                   Intellectual Product    0.4308    0.6417    0.7215
# 15                       Population Group    0.7331    0.8397    0.8713
# 16                      Biologic Function    0.5583    0.7137    0.8172
# 17                                   Food    0.4048    0.4762    0.5714
# 18                      Research Activity    0.6522    0.7204    0.8288
# 19     Professional or Occupational Group    0.7104    0.8533    0.8726
# 20                            Body System    0.3390    0.4915    0.7288
# 21                            **Overall**    0.5328    0.6762    0.7723
# 22  **Overall (including missing spans)**    0.3484    0.4422    0.5051
#
#     recall@8  recall@16  recall@32  recall@64  Spans Matched  Missing  Total  \
# 0     0.7931     0.8070     0.8080     0.8083           3094     1693   4787
# 1     0.8488     0.8605     0.8605     0.8605            258       65    323
# 2     0.7717     0.7954     0.8005     0.8027           5073     2334   7407
# 3     0.7716     0.7759     0.7759     0.7759            232      150    382
# 4     0.9421     0.9504     0.9504     0.9504            121       51    172
# 5     0.7537     0.7678     0.7704     0.7704           1908     1303   3211
# 6     0.8281     0.8376     0.8384     0.8389           2321     1452   3773
# 7     0.7958     0.8042     0.8042     0.8042            240      117    357
# 8     0.8390     0.8390     0.8390     0.8390            267      182    449
# 9     0.8558     0.8604     0.8604     0.8604           1304     1105   2409
# 10    0.7904     0.7964     0.7964     0.7964            167      188    355
# 11    0.9291     0.9606     0.9606     0.9606            127       69    196
# 12    0.8881     0.9021     0.9021     0.9021            143       69    212
# 13    0.8689     0.8723     0.8732     0.8732           1175      575   1750
# 14    0.7476     0.7573     0.7590     0.7590           1228     1137   2365
# 15    0.9378     0.9388     0.9388     0.9388            948      315   1263
# 16    0.8632     0.8769     0.8779     0.8779           5871     2242   8113
# 17    0.7738     0.7857     0.7857     0.7857            168      154    322
# 18    0.8397     0.8443     0.8544     0.8544           1291      556   1847
# 19    0.9112     0.9189     0.9189     0.9189            259      101    360
# 20    0.7288     0.8814     0.8814     0.8814             59       31     90
# 21    0.8204     0.8336     0.8358     0.8363          26254    13889  40143
# 22    0.5365     0.5452     0.5466     0.5470          26254    13889  40143
#
#     Missing Proportion
# 0               0.3537
# 1               0.2012
# 2               0.3151
# 3               0.3927
# 4               0.2965
# 5               0.4058
# 6               0.3848
# 7               0.3277
# 8               0.4053
# 9               0.4587
# 10              0.5296
# 11              0.3520
# 12              0.3255
# 13              0.3286
# 14              0.4808
# 15              0.2494
# 16              0.2763
# 17              0.4783
# 18              0.3010
# 19              0.2806
# 20              0.3444
# 21              0.3460
# 22              0.3460
# medmentions_st21pv scispacy_large
#                             Semantic Type  recall@1  recall@2  recall@4  \
# 0                    Health Care Activity    0.4891    0.6213    0.7241
# 1                      Clinical Attribute    0.5285    0.7529    0.8403
# 2                                Chemical    0.4656    0.6071    0.7095
# 3                            Organization    0.5944    0.6546    0.7510
# 4                                   Virus    0.6984    0.8175    0.9444
# 5                                 Finding    0.4352    0.6196    0.7138
# 6                    Anatomical Structure    0.5916    0.7186    0.7916
# 7                     Injury or Poisoning    0.6423    0.7000    0.7538
# 8                               Bacterium    0.6464    0.7714    0.8214
# 9                         Spatial Concept    0.6351    0.7344    0.7991
# 10                         Medical Device    0.4943    0.6420    0.6705
# 11    Biomedical Occupation or Discipline    0.6412    0.7863    0.9160
# 12                         Body Substance    0.2887    0.3099    0.8662
# 13                              Eukaryote    0.5025    0.7210    0.8303
# 14                   Intellectual Product    0.4195    0.6404    0.7257
# 15                       Population Group    0.7179    0.8255    0.8579
# 16                      Biologic Function    0.5542    0.7063    0.8079
# 17                                   Food    0.3889    0.4444    0.5556
# 18                      Research Activity    0.6524    0.7201    0.8217
# 19     Professional or Occupational Group    0.7059    0.8456    0.8676
# 20                            Body System    0.3636    0.5273    0.8000
# 21                            **Overall**    0.5311    0.6738    0.7686
# 22  **Overall (including missing spans)**    0.3554    0.4509    0.5143
#
#     recall@8  recall@16  recall@32  recall@64  Spans Matched  Missing  Total  \
# 0     0.7924     0.8059     0.8065     0.8069           3179     1608   4787
# 1     0.8441     0.8555     0.8555     0.8555            263       60    323
# 2     0.7778     0.7997     0.8051     0.8068           5243     2164   7407
# 3     0.7550     0.7590     0.7590     0.7590            249      133    382
# 4     0.9444     0.9524     0.9524     0.9524            126       46    172
# 5     0.7537     0.7696     0.7721     0.7721           1953     1258   3211
# 6     0.8204     0.8304     0.8312     0.8317           2299     1474   3773
# 7     0.7692     0.7808     0.7808     0.7808            260       97    357
# 8     0.8214     0.8214     0.8214     0.8214            280      169    449
# 9     0.8488     0.8518     0.8518     0.8518           1329     1080   2409
# 10    0.7727     0.7784     0.7784     0.7784            176      179    355
# 11    0.9313     0.9618     0.9618     0.9618            131       65    196
# 12    0.9085     0.9225     0.9225     0.9225            142       70    212
# 13    0.8588     0.8639     0.8655     0.8655           1190      560   1750
# 14    0.7480     0.7600     0.7616     0.7616           1254     1111   2365
# 15    0.9300     0.9310     0.9310     0.9310            957      306   1263
# 16    0.8521     0.8659     0.8669     0.8669           5996     2117   8113
# 17    0.7444     0.7556     0.7556     0.7556            180      142    322
# 18    0.8315     0.8360     0.8465     0.8465           1329      518   1847
# 19    0.9044     0.9118     0.9118     0.9118            272       88    360
# 20    0.8000     0.8727     0.8727     0.8727             55       35     90
# 21    0.8159     0.8289     0.8312     0.8316          26863    13280  40143
# 22    0.5460     0.5547     0.5562     0.5565          26863    13280  40143
#
#     Missing Proportion
# 0               0.3359
# 1               0.1858
# 2               0.2922
# 3               0.3482
# 4               0.2674
# 5               0.3918
# 6               0.3907
# 7               0.2717
# 8               0.3764
# 9               0.4483
# 10              0.5042
# 11              0.3316
# 12              0.3302
# 13              0.3200
# 14              0.4698
# 15              0.2423
# 16              0.2609
# 17              0.4410
# 18              0.2805
# 19              0.2444
# 20              0.3889
# 21              0.3308
# 22              0.3308
# bc5cdr scibert
#                            Semantic Type  recall@1  recall@2  recall@4  \
# 0                               CHEMICAL    0.8952    0.8986    0.8989
# 1                                DISEASE    0.8181    0.8669    0.8789
# 2                            **Overall**    0.8577    0.8832    0.8892
# 3  **Overall (including missing spans)**    0.4935    0.5082    0.5116
#
#    recall@8  recall@16  recall@32  recall@64  Spans Matched  Missing  Total  \
# 0    0.8989     0.8989     0.8989     0.8989           2909     2455   5364
# 1    0.8829     0.8861     0.8861     0.8861           2749     1720   4469
# 2    0.8911     0.8927     0.8927     0.8927           5658     4175   9833
# 3    0.5128     0.5137     0.5137     0.5137           5658     4175   9833
#
#    Missing Proportion
# 0              0.4577
# 1              0.3849
# 2              0.4246
# 3              0.4246
# bc5cdr scispacy_large
#                            Semantic Type  recall@1  recall@2  recall@4  \
# 0                               CHEMICAL    0.8931    0.8960    0.8960
# 1                                DISEASE    0.8201    0.8650    0.8767
# 2                            **Overall**    0.8588    0.8815    0.8869
# 3  **Overall (including missing spans)**    0.5091    0.5225    0.5258
#
#    recall@8  recall@16  recall@32  recall@64  Spans Matched  Missing  Total  \
# 0    0.8960     0.8960     0.8960     0.8960           3088     2276   5364
# 1    0.8807     0.8833     0.8833     0.8833           2741     1728   4469
# 2    0.8888     0.8900     0.8900     0.8900           5829     4004   9833
# 3    0.5269     0.5276     0.5276     0.5276           5829     4004   9833
#
#    Missing Proportion
# 0              0.4243
# 1              0.3867
# 2              0.4072
# 3              0.4072
# gnormplus scibert
#                            Semantic Type  recall@1  recall@2  recall@4  \
# 0                                   GENE       0.0       0.0       0.0
# 1                            **Overall**       0.0       0.0       0.0
# 2  **Overall (including missing spans)**       0.0       0.0       0.0
#
#    recall@8  recall@16  recall@32  recall@64  Spans Matched  Missing  Total  \
# 0       0.0        0.0        0.0        0.0           2148     1075   3223
# 1       0.0        0.0        0.0        0.0           2148     1075   3223
# 2       0.0        0.0        0.0        0.0           2148     1075   3223
#
#    Missing Proportion
# 0              0.3335
# 1              0.3335
# 2              0.3335
# gnormplus scispacy_large
#                            Semantic Type  recall@1  recall@2  recall@4  \
# 0                                   GENE       0.0       0.0       0.0
# 1                            **Overall**       0.0       0.0       0.0
# 2  **Overall (including missing spans)**       0.0       0.0       0.0
#
#    recall@8  recall@16  recall@32  recall@64  Spans Matched  Missing  Total  \
# 0       0.0        0.0        0.0        0.0           2266      957   3223
# 1       0.0        0.0        0.0        0.0           2266      957   3223
# 2       0.0        0.0        0.0        0.0           2266      957   3223
#
#    Missing Proportion
# 0              0.2969
# 1              0.2969
# 2              0.2969
# nlmchem scibert
#                            Semantic Type  recall@1  recall@2  recall@4  \
# 0                               CHEMICAL    0.7520    0.7586    0.7598
# 1                            **Overall**    0.7520    0.7586    0.7598
# 2  **Overall (including missing spans)**    0.2621    0.2644    0.2648
#
#    recall@8  recall@16  recall@32  recall@64  Spans Matched  Missing  Total  \
# 0    0.7598     0.7598     0.7598     0.7598           4064     7596  11660
# 1    0.7598     0.7598     0.7598     0.7598           4064     7596  11660
# 2    0.2648     0.2648     0.2648     0.2648           4064     7596  11660
#
#    Missing Proportion
# 0              0.6515
# 1              0.6515
# 2              0.6515
# nlmchem scispacy_large
#                            Semantic Type  recall@1  recall@2  recall@4  \
# 0                               CHEMICAL    0.7539    0.7614    0.7626
# 1                            **Overall**    0.7539    0.7614    0.7626
# 2  **Overall (including missing spans)**    0.2750    0.2778    0.2782
#
#    recall@8  recall@16  recall@32  recall@64  Spans Matched  Missing  Total  \
# 0    0.7626     0.7626     0.7626     0.7626           4254     7406  11660
# 1    0.7626     0.7626     0.7626     0.7626           4254     7406  11660
# 2    0.2782     0.2782     0.2782     0.2782           4254     7406  11660
#
#    Missing Proportion
# 0              0.6352
# 1              0.6352
# 2              0.6352
# nlm_gene scibert
#                            Semantic Type  recall@1  recall@2  recall@4  \
# 0                                GENERIF       0.0       0.0       0.0
# 1                                 DOMAIN       0.0       0.0       0.0
# 2                                   GENE       0.0       0.0       0.0
# 3                                  OTHER       0.0       0.0       0.0
# 4                               STARGENE       0.0       0.0       0.0
# 5                            **Overall**       0.0       0.0       0.0
# 6  **Overall (including missing spans)**       0.0       0.0       0.0
#
#    recall@8  recall@16  recall@32  recall@64  Spans Matched  Missing  Total  \
# 0       0.0        0.0        0.0        0.0            387      277    664
# 1       0.0        0.0        0.0        0.0              9        1     10
# 2       0.0        0.0        0.0        0.0           1087      648   1735
# 3       0.0        0.0        0.0        0.0              1       13     14
# 4       0.0        0.0        0.0        0.0            154      178    332
# 5       0.0        0.0        0.0        0.0           1638     1117   2755
# 6       0.0        0.0        0.0        0.0           1638     1117   2755
#
#    Missing Proportion
# 0              0.4172
# 1              0.1000
# 2              0.3735
# 3              0.9286
# 4              0.5361
# 5              0.4054
# 6              0.4054
# nlm_gene scispacy_large
#                            Semantic Type  recall@1  recall@2  recall@4  \
# 0                                GENERIF       0.0       0.0       0.0
# 1                                 DOMAIN       0.0       0.0       0.0
# 2                                   GENE       0.0       0.0       0.0
# 3                                  OTHER       0.0       0.0       0.0
# 4                               STARGENE       0.0       0.0       0.0
# 5                            **Overall**       0.0       0.0       0.0
# 6  **Overall (including missing spans)**       0.0       0.0       0.0
#
#    recall@8  recall@16  recall@32  recall@64  Spans Matched  Missing  Total  \
# 0       0.0        0.0        0.0        0.0            408      256    664
# 1       0.0        0.0        0.0        0.0              8        2     10
# 2       0.0        0.0        0.0        0.0           1114      621   1735
# 3       0.0        0.0        0.0        0.0              2       12     14
# 4       0.0        0.0        0.0        0.0            176      156    332
# 5       0.0        0.0        0.0        0.0           1708     1047   2755
# 6       0.0        0.0        0.0        0.0           1708     1047   2755
#
#    Missing Proportion
# 0              0.3855
# 1              0.2000
# 2              0.3579
# 3              0.8571
# 4              0.4699
# 5              0.3800
# 6              0.3800
# medmentions_full scibert
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Input In [68], in <cell line: 1>()
#       3 print(dataset, model)
#       4 hits_dict = evaluate_linking(processed[dataset][model])
# ----> 5 display(format_output(hits_dict))
#
# Input In [67], in format_output(hits_dict, type_to_name_mapping)
#     101     else:
#     102         name = type_to_name_mapping[t]
# --> 103     rows.append({**{'Semantic Type':name}, **{f'recall@{k}':hits_dict[k][t]/hits_dict[k][t + '_total'] for k in ks}, **{'Spans Matched':hits_dict[ks[0]][t + '_total'], 'Missing':hits_dict[ks[0]][t + '_missing']}})
#     105 # Add overall scores
#     106 rows.append({**{'Semantic Type':"**Overall**"}, **{f'recall@{k}':hits_dict[k]["overall (exclude missing)"] for k in ks}, **{'Spans Matched':np.sum([hits_dict[ks[0]][t + '_total'] for t in entity_types]), 'Missing':np.sum([hits_dict[ks[0]][t + '_missing'] for t in entity_types])}})
#
# Input In [67], in <dictcomp>(.0)
#     101     else:
#     102         name = type_to_name_mapping[t]
# --> 103     rows.append({**{'Semantic Type':name}, **{f'recall@{k}':hits_dict[k][t]/hits_dict[k][t + '_total'] for k in ks}, **{'Spans Matched':hits_dict[ks[0]][t + '_total'], 'Missing':hits_dict[ks[0]][t + '_missing']}})
#     105 # Add overall scores
#     106 rows.append({**{'Semantic Type':"**Overall**"}, **{f'recall@{k}':hits_dict[k]["overall (exclude missing)"] for k in ks}, **{'Spans Matched':np.sum([hits_dict[ks[0]][t + '_total'] for t in entity_types]), 'Missing':np.sum([hits_dict[ks[0]][t + '_missing'] for t in entity_types])}})
#
# ZeroDivisionError: division by zero

# %%
test_preds = ujson.load(open('scispacy_test_processed.json', 'r'))
train_preds = ujson.load(open('scispacy_train_processed.json', 'r'))
val_preds = ujson.load(open('scispacy_validation_processed.json', 'r'))

all_preds = [*train_preds, *test_preds, *val_preds]


all_hits_dict = evaluate_linking(all_preds)
format_output(all_hits_dict)
# Out:
#   0%|          | 0/203185 [00:00<?, ?it/s]
# /tmp/ipykernel_1091422/479955064.py:29: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   overall_hits = np.sum(hits[x] for x in entity_types)/np.sum(hits[x + '_total'] for x in entity_types)
# /tmp/ipykernel_1091422/479955064.py:30: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   overall_recall = np.sum(hits[x] for x in entity_types)/np.sum(hits[x + '_total'] + hits[x + '_missing'] for x in entity_types)
#   0%|          | 0/203185 [00:00<?, ?it/s]
#   0%|          | 0/203185 [00:00<?, ?it/s]
#   0%|          | 0/203185 [00:00<?, ?it/s]
#                             Semantic Type  Hits @ 1  Hits @ 5  Hits @ 10  \
# 0                                   Virus    0.6174    0.8558     0.8605
# 1                      Clinical Attribute    0.5312    0.8423     0.8466
# 2     Biomedical Occupation or Discipline    0.6103    0.8985     0.9074
# 3                            Organization    0.4584    0.7642     0.7739
# 4                                    Food    0.3409    0.6900     0.8105
# 5                       Research Activity    0.5476    0.7771     0.8113
# 6                    Intellectual Product    0.3659    0.7317     0.7559
# 7                    Anatomical Structure    0.5519    0.8104     0.8312
# 8                                Chemical    0.4342    0.7289     0.7770
# 9                               Bacterium    0.6066    0.8404     0.8468
# 10     Professional or Occupational Group    0.6312    0.7975     0.8200
# 11                         Medical Device    0.3911    0.6351     0.6697
# 12                        Spatial Concept    0.5821    0.8121     0.8463
# 13                              Eukaryote    0.5060    0.8365     0.8478
# 14                       Population Group    0.5642    0.8176     0.8850
# 15                                Finding    0.4199    0.7186     0.7510
# 16                            Body System    0.3432    0.7865     0.7973
# 17                         Body Substance    0.2782    0.8790     0.9059
# 18                   Health Care Activity    0.4202    0.7182     0.7887
# 19                    Injury or Poisoning    0.6075    0.7630     0.7822
# 20                      Biologic Function    0.4745    0.7949     0.8404
# 21                            **Overall**    0.4761    0.7690     0.8100
# 22  **Overall (including missing spans)**    0.3498    0.5650     0.5951
#
#     Hits @ 25  Spans Matched  Missing   Total  Missing Proportion
# 0      0.8616            860      238    1098              0.2168
# 1      0.8545           1395      377    1772              0.2128
# 2      0.9221            680      236     916              0.2576
# 3      0.7788           1442      701    2143              0.3271
# 4      0.8157            971      380    1351              0.2813
# 5      0.8265           6704     2463    9167              0.2687
# 6      0.7653           6076     4246   10322              0.4114
# 7      0.8407          14848     5640   20488              0.2753
# 8      0.7918          28490     8890   37380              0.2378
# 9      0.8475           1416      633    2049              0.3089
# 10     0.8269           1467      311    1778              0.1749
# 11     0.6749           1332      686    2018              0.3399
# 12     0.8573           8261     4230   12491              0.3386
# 13     0.8519           6373     2166    8539              0.2537
# 14     0.8882           5027     1119    6146              0.1821
# 15     0.7710          10779     5442   16221              0.3355
# 16     0.8351            370      125     495              0.2525
# 17     0.9204            967      288    1255              0.2295
# 18     0.8008          17437     6861   24298              0.2824
# 19     0.7904           1460      393    1853              0.2121
# 20     0.8578          32917     8488   41405              0.2050
# 21     0.8230         149272    53913  203185              0.2653
# 22     0.6047         149272    53913  203185              0.2653

# %%
hits_dict
# Out:
# {1: defaultdict(int,
#              {'T131_missing': 111,
#               'T052': 669,
#               'T052_total': 920,
#               'T043': 167,
#               'T043_total': 343,
#               'T169': 1379,
#               'T169_total': 2672,
#               'T025': 348,
#               'T025_total': 561,
#               'T131': 108,
#               'T131_total': 208,
#               'T033_missing': 1338,
#               'T067': 111,
#               'T067_total': 259,
#               'T069': 24,
#               'T069_total': 26,
#               'T167': 132,
#               'T167_total': 242,
#               'T037_missing': 118,
#               'T001': 59,
#               'T001_total': 149,
#               'T031_missing': 57,
#               'T080_missing': 2850,
#               'T196_missing': 149,
#               'T169_missing': 2002,
#               'T080': 1823,
#               'T080_total': 3503,
#               'T196': 56,
#               'T196_total': 236,
#               'T081': 956,
#               'T081_total': 2361,
#               'T044': 214,
#               'T044_total': 489,
#               'T126': 118,
#               'T126_total': 468,
#               'T026': 120,
#               'T026_total': 213,
#               'T123': 518,
#               'T123_total': 1415,
#               'T077': 172,
#               'T077_total': 346,
#               'T052_missing': 616,
#               'T082': 415,
#               'T082_total': 711,
#               'T103': 25,
#               'T103_total': 51,
#               'T078_missing': 760,
#               'T039': 41,
#               'T039_total': 116,
#               'T028': 264,
#               'T028_total': 565,
#               'T191': 229,
#               'T191_total': 709,
#               'T062': 683,
#               'T062_total': 1235,
#               'T049': 38,
#               'T049_total': 67,
#               'T028_missing': 360,
#               'T045': 148,
#               'T045_total': 510,
#               'T063': 90,
#               'T063_total': 141,
#               'T031': 32,
#               'T031_total': 156,
#               'T023_missing': 410,
#               'T191_missing': 225,
#               'T078': 435,
#               'T078_total': 1115,
#               'T079': 705,
#               'T079_total': 1205,
#               'T098': 615,
#               'T098_total': 985,
#               'T079_missing': 810,
#               'T061_missing': 661,
#               'T024': 86,
#               'T024_total': 150,
#               'T063_missing': 71,
#               'T067_missing': 172,
#               'T033': 634,
#               'T033_total': 1756,
#               'T081_missing': 1593,
#               'T114_missing': 43,
#               'T123_missing': 691,
#               'T099': 126,
#               'T099_total': 181,
#               'T047_missing': 421,
#               'T101': 888,
#               'T101_total': 1021,
#               'T097': 187,
#               'T097_total': 271,
#               'T047': 1000,
#               'T047_total': 1822,
#               'T170_missing': 1080,
#               'T041': 332,
#               'T041_total': 519,
#               'T058': 255,
#               'T058_total': 748,
#               'T101_missing': 86,
#               'T041_missing': 352,
#               'T097_missing': 108,
#               'T170': 427,
#               'T170_total': 1163,
#               'T057': 32,
#               'T057_total': 87,
#               'T062_missing': 522,
#               'T032': 292,
#               'T032_total': 606,
#               'T184': 129,
#               'T184_total': 245,
#               'T201_missing': 90,
#               'T200': 6,
#               'T200_total': 15,
#               'T200_missing': 4,
#               'T100_missing': 73,
#               'T122': 54,
#               'T122_total': 113,
#               'T082_missing': 665,
#               'T100': 190,
#               'T100_total': 427,
#               'T093': 90,
#               'T093_total': 206,
#               'T058_missing': 495,
#               'T121': 584,
#               'T121_total': 897,
#               'T125': 42,
#               'T125_total': 139,
#               'T096': 77,
#               'T096_total': 180,
#               'UnknownType': 73,
#               'UnknownType_total': 276,
#               'T125_missing': 51,
#               'T046': 259,
#               'T046_total': 511,
#               'T060': 264,
#               'T060_total': 500,
#               'T059': 297,
#               'T059_total': 574,
#               'T049_missing': 38,
#               'T201': 133,
#               'T201_total': 271,
#               'T061': 605,
#               'T061_total': 1449,
#               'T077_missing': 270,
#               'T098_missing': 306,
#               'T087_missing': 47,
#               'T007': 170,
#               'T007_total': 266,
#               'T126_missing': 214,
#               'T070': 138,
#               'T070_total': 265,
#               'T087': 11,
#               'T087_total': 39,
#               'T007_missing': 182,
#               'T044_missing': 263,
#               'T070_missing': 226,
#               'T086': 27,
#               'T086_total': 45,
#               'T086_missing': 65,
#               'T045_missing': 203,
#               'T059_missing': 413,
#               'T060_missing': 273,
#               'T185': 58,
#               'T185_total': 193,
#               'T046_missing': 178,
#               'T074': 86,
#               'T074_total': 199,
#               'T185_missing': 129,
#               'T121_missing': 389,
#               'T074_missing': 195,
#               'T023': 459,
#               'T023_total': 696,
#               'T054_missing': 93,
#               'T168': 48,
#               'T168_total': 178,
#               'T037': 155,
#               'T037_total': 242,
#               'T055': 61,
#               'T055_total': 138,
#               'T048': 294,
#               'T048_total': 449,
#               'T129': 88,
#               'T129_total': 348,
#               'T195': 100,
#               'T195_total': 126,
#               'T195_missing': 23,
#               'T130': 97,
#               'T130_total': 133,
#               'T040': 140,
#               'T040_total': 314,
#               'T042_missing': 107,
#               'T025_missing': 378,
#               'T040_missing': 160,
#               'T104': 22,
#               'T104_total': 61,
#               'T024_missing': 110,
#               'T017_missing': 9,
#               'T056_missing': 63,
#               'T016': 106,
#               'T016_total': 137,
#               'T056': 57,
#               'T056_total': 118,
#               'T029_missing': 106,
#               'T030_missing': 44,
#               'T192': 53,
#               'T192_total': 208,
#               'T039_missing': 93,
#               'T022': 18,
#               'T022_total': 60,
#               'T038_missing': 66,
#               'T184_missing': 107,
#               'T017': 1,
#               'T017_total': 4,
#               'T197': 93,
#               'T197_total': 199,
#               'T109': 213,
#               'T109_total': 334,
#               'T038': 43,
#               'T038_total': 98,
#               'T026_missing': 102,
#               'T034_missing': 63,
#               'T015_missing': 132,
#               'T032_missing': 225,
#               'UnknownType_missing': 300,
#               'T043_missing': 163,
#               'T015': 120,
#               'T015_total': 333,
#               'T168_missing': 159,
#               'T102_missing': 6,
#               'T073_missing': 199,
#               'T167_missing': 164,
#               'T073': 103,
#               'T073_total': 237,
#               'T068_missing': 29,
#               'T093_missing': 107,
#               'T190': 25,
#               'T190_total': 49,
#               'T129_missing': 124,
#               'T014': 10,
#               'T014_total': 17,
#               'T014_missing': 5,
#               'T053': 21,
#               'T053_total': 54,
#               'T022_missing': 31,
#               'T042': 80,
#               'T042_total': 189,
#               'T030': 23,
#               'T030_total': 51,
#               'T116': 46,
#               'T116_total': 137,
#               'T054': 86,
#               'T054_total': 122,
#               'T005': 82,
#               'T005_total': 125,
#               'T005_missing': 49,
#               'T109_missing': 179,
#               'T197_missing': 90,
#               'T071': 4,
#               'T071_total': 21,
#               'T104_missing': 54,
#               'T048_missing': 109,
#               'T096_missing': 62,
#               'T008': 33,
#               'T008_total': 78,
#               'T001_missing': 85,
#               'T091': 71,
#               'T091_total': 130,
#               'T029': 47,
#               'T029_total': 131,
#               'T083': 255,
#               'T083_total': 384,
#               'T102': 16,
#               'T102_total': 19,
#               'T068': 3,
#               'T068_total': 36,
#               'T190_missing': 27,
#               'T091_missing': 70,
#               'T083_missing': 217,
#               'T064_missing': 14,
#               'T050': 13,
#               'T050_total': 24,
#               'T008_missing': 18,
#               'T034': 27,
#               'T034_total': 67,
#               'T099_missing': 51,
#               'T053_missing': 39,
#               'T116_missing': 42,
#               'T090': 53,
#               'T090_total': 86,
#               'T016_missing': 21,
#               'T018_missing': 22,
#               'T002': 92,
#               'T002_total': 220,
#               'T204': 150,
#               'T204_total': 269,
#               'T204_missing': 131,
#               'T127': 13,
#               'T127_total': 34,
#               'T002_missing': 183,
#               'T051_missing': 26,
#               'T064': 5,
#               'T064_total': 13,
#               'T120': 14,
#               'T120_total': 25,
#               'T065': 15,
#               'T065_total': 70,
#               'T122_missing': 86,
#               'T072': 7,
#               'T072_total': 11,
#               'T103_missing': 21,
#               'T092_missing': 37,
#               'T090_missing': 69,
#               'T092': 30,
#               'T092_total': 42,
#               'T055_missing': 103,
#               'T065_missing': 57,
#               'T192_missing': 63,
#               'T071_missing': 8,
#               'T057_missing': 98,
#               'T004': 30,
#               'T004_total': 63,
#               'T004_missing': 57,
#               'T120_missing': 32,
#               'T051': 12,
#               'T051_total': 35,
#               'T075': 3,
#               'T075_total': 37,
#               'T075_missing': 58,
#               'T089_missing': 7,
#               'T089': 12,
#               'T089_total': 18,
#               'T066_missing': 27,
#               'T130_missing': 71,
#               'T171': 4,
#               'T171_total': 13,
#               'T069_missing': 8,
#               'T094_missing': 7,
#               'T020': 10,
#               'T020_total': 32,
#               'T019_missing': 28,
#               'T019': 33,
#               'T019_total': 54,
#               'T114': 40,
#               'T114_total': 73,
#               'T012_missing': 33,
#               'T020_missing': 19,
#               'T012': 23,
#               'T012_total': 52,
#               'T066': 14,
#               'T066_total': 27,
#               'T194': 2,
#               'T194_total': 3,
#               'T127_missing': 15,
#               'T013': 16,
#               'T013_total': 18,
#               'T050_missing': 21,
#               'T085': 1,
#               'T085_total': 5,
#               'T085_missing': 4,
#               'T018': 14,
#               'T018_total': 32,
#               'T095_missing': 4,
#               'T072_missing': 11,
#               'T171_missing': 2,
#               'T013_missing': 1,
#               'T094': 0,
#               'T094_total': 1,
#               'T095': 0,
#               'T095_total': 1,
#               'T021': 1,
#               'T021_total': 1,
#               'T010_missing': 1,
#               'T010': 0,
#               'T010_total': 0,
#               'T194_missing': 0,
#               'T021_missing': 0,
#               'overall (exclude missing)': 0.49451490099790507,
#               'overall (include missing)': 0.3119520270558311}),
#  2: defaultdict(int,
#              {'T131_missing': 111,
#               'T052': 779,
#               'T052_total': 920,
#               'T043': 245,
#               'T043_total': 343,
#               'T169': 1896,
#               'T169_total': 2672,
#               'T025': 432,
#               'T025_total': 561,
#               'T131': 144,
#               'T131_total': 208,
#               'T033_missing': 1338,
#               'T067': 144,
#               'T067_total': 259,
#               'T069': 24,
#               'T069_total': 26,
#               'T167': 174,
#               'T167_total': 242,
#               'T037_missing': 118,
#               'T001': 71,
#               'T001_total': 149,
#               'T031_missing': 57,
#               'T080_missing': 2850,
#               'T196_missing': 149,
#               'T169_missing': 2002,
#               'T080': 2382,
#               'T080_total': 3503,
#               'T196': 70,
#               'T196_total': 236,
#               'T081': 1483,
#               'T081_total': 2361,
#               'T044': 296,
#               'T044_total': 489,
#               'T126': 204,
#               'T126_total': 468,
#               'T026': 147,
#               'T026_total': 213,
#               'T123': 788,
#               'T123_total': 1415,
#               'T077': 197,
#               'T077_total': 346,
#               'T052_missing': 616,
#               'T082': 498,
#               'T082_total': 711,
#               'T103': 39,
#               'T103_total': 51,
#               'T078_missing': 760,
#               'T039': 62,
#               'T039_total': 116,
#               'T028': 333,
#               'T028_total': 565,
#               'T191': 333,
#               'T191_total': 709,
#               'T062': 821,
#               'T062_total': 1235,
#               'T049': 56,
#               'T049_total': 67,
#               'T028_missing': 360,
#               'T045': 210,
#               'T045_total': 510,
#               'T063': 101,
#               'T063_total': 141,
#               'T031': 39,
#               'T031_total': 156,
#               'T023_missing': 410,
#               'T191_missing': 225,
#               'T078': 647,
#               'T078_total': 1115,
#               'T079': 841,
#               'T079_total': 1205,
#               'T098': 754,
#               'T098_total': 985,
#               'T079_missing': 810,
#               'T061_missing': 661,
#               'T024': 114,
#               'T024_total': 150,
#               'T063_missing': 71,
#               'T067_missing': 172,
#               'T033': 861,
#               'T033_total': 1756,
#               'T081_missing': 1593,
#               'T114_missing': 43,
#               'T123_missing': 691,
#               'T099': 129,
#               'T099_total': 181,
#               'T047_missing': 421,
#               'T101': 897,
#               'T101_total': 1021,
#               'T097': 226,
#               'T097_total': 271,
#               'T047': 1408,
#               'T047_total': 1822,
#               'T170_missing': 1080,
#               'T041': 374,
#               'T041_total': 519,
#               'T058': 322,
#               'T058_total': 748,
#               'T101_missing': 86,
#               'T041_missing': 352,
#               'T097_missing': 108,
#               'T170': 643,
#               'T170_total': 1163,
#               'T057': 51,
#               'T057_total': 87,
#               'T062_missing': 522,
#               'T032': 392,
#               'T032_total': 606,
#               'T184': 157,
#               'T184_total': 245,
#               'T201_missing': 90,
#               'T200': 8,
#               'T200_total': 15,
#               'T200_missing': 4,
#               'T100_missing': 73,
#               'T122': 83,
#               'T122_total': 113,
#               'T082_missing': 665,
#               'T100': 360,
#               'T100_total': 427,
#               'T093': 111,
#               'T093_total': 206,
#               'T058_missing': 495,
#               'T121': 677,
#               'T121_total': 897,
#               'T125': 62,
#               'T125_total': 139,
#               'T096': 78,
#               'T096_total': 180,
#               'UnknownType': 81,
#               'UnknownType_total': 276,
#               'T125_missing': 51,
#               'T046': 425,
#               'T046_total': 511,
#               'T060': 316,
#               'T060_total': 500,
#               'T059': 338,
#               'T059_total': 574,
#               'T049_missing': 38,
#               'T201': 196,
#               'T201_total': 271,
#               'T061': 804,
#               'T061_total': 1449,
#               'T077_missing': 270,
#               'T098_missing': 306,
#               'T087_missing': 47,
#               'T007': 206,
#               'T007_total': 266,
#               'T126_missing': 214,
#               'T070': 177,
#               'T070_total': 265,
#               'T087': 12,
#               'T087_total': 39,
#               'T007_missing': 182,
#               'T044_missing': 263,
#               'T070_missing': 226,
#               'T086': 32,
#               'T086_total': 45,
#               'T086_missing': 65,
#               'T045_missing': 203,
#               'T059_missing': 413,
#               'T060_missing': 273,
#               'T185': 73,
#               'T185_total': 193,
#               'T046_missing': 178,
#               'T074': 110,
#               'T074_total': 199,
#               'T185_missing': 129,
#               'T121_missing': 389,
#               'T074_missing': 195,
#               'T023': 541,
#               'T023_total': 696,
#               'T054_missing': 93,
#               'T168': 80,
#               'T168_total': 178,
#               'T037': 168,
#               'T037_total': 242,
#               'T055': 81,
#               'T055_total': 138,
#               'T048': 317,
#               'T048_total': 449,
#               'T129': 122,
#               'T129_total': 348,
#               'T195': 108,
#               'T195_total': 126,
#               'T195_missing': 23,
#               'T130': 111,
#               'T130_total': 133,
#               'T040': 176,
#               'T040_total': 314,
#               'T042_missing': 107,
#               'T025_missing': 378,
#               'T040_missing': 160,
#               'T104': 23,
#               'T104_total': 61,
#               'T024_missing': 110,
#               'T017_missing': 9,
#               'T056_missing': 63,
#               'T016': 131,
#               'T016_total': 137,
#               'T056': 94,
#               'T056_total': 118,
#               'T029_missing': 106,
#               'T030_missing': 44,
#               'T192': 76,
#               'T192_total': 208,
#               'T039_missing': 93,
#               'T022': 30,
#               'T022_total': 60,
#               'T038_missing': 66,
#               'T184_missing': 107,
#               'T017': 2,
#               'T017_total': 4,
#               'T197': 117,
#               'T197_total': 199,
#               'T109': 252,
#               'T109_total': 334,
#               'T038': 60,
#               'T038_total': 98,
#               'T026_missing': 102,
#               'T034_missing': 63,
#               'T015_missing': 132,
#               'T032_missing': 225,
#               'UnknownType_missing': 300,
#               'T043_missing': 163,
#               'T015': 211,
#               'T015_total': 333,
#               'T168_missing': 159,
#               'T102_missing': 6,
#               'T073_missing': 199,
#               'T167_missing': 164,
#               'T073': 143,
#               'T073_total': 237,
#               'T068_missing': 29,
#               'T093_missing': 107,
#               'T190': 34,
#               'T190_total': 49,
#               'T129_missing': 124,
#               'T014': 10,
#               'T014_total': 17,
#               'T014_missing': 5,
#               'T053': 42,
#               'T053_total': 54,
#               'T022_missing': 31,
#               'T042': 115,
#               'T042_total': 189,
#               'T030': 30,
#               'T030_total': 51,
#               'T116': 49,
#               'T116_total': 137,
#               'T054': 101,
#               'T054_total': 122,
#               'T005': 99,
#               'T005_total': 125,
#               'T005_missing': 49,
#               'T109_missing': 179,
#               'T197_missing': 90,
#               'T071': 6,
#               'T071_total': 21,
#               'T104_missing': 54,
#               'T048_missing': 109,
#               'T096_missing': 62,
#               'T008': 69,
#               'T008_total': 78,
#               'T001_missing': 85,
#               'T091': 90,
#               'T091_total': 130,
#               'T029': 75,
#               'T029_total': 131,
#               'T083': 295,
#               'T083_total': 384,
#               'T102': 16,
#               'T102_total': 19,
#               'T068': 32,
#               'T068_total': 36,
#               'T190_missing': 27,
#               'T091_missing': 70,
#               'T083_missing': 217,
#               'T064_missing': 14,
#               'T050': 14,
#               'T050_total': 24,
#               'T008_missing': 18,
#               'T034': 33,
#               'T034_total': 67,
#               'T099_missing': 51,
#               'T053_missing': 39,
#               'T116_missing': 42,
#               'T090': 60,
#               'T090_total': 86,
#               'T016_missing': 21,
#               'T018_missing': 22,
#               'T002': 147,
#               'T002_total': 220,
#               'T204': 201,
#               'T204_total': 269,
#               'T204_missing': 131,
#               'T127': 21,
#               'T127_total': 34,
#               'T002_missing': 183,
#               'T051_missing': 26,
#               'T064': 7,
#               'T064_total': 13,
#               'T120': 14,
#               'T120_total': 25,
#               'T065': 16,
#               'T065_total': 70,
#               'T122_missing': 86,
#               'T072': 7,
#               'T072_total': 11,
#               'T103_missing': 21,
#               'T092_missing': 37,
#               'T090_missing': 69,
#               'T092': 33,
#               'T092_total': 42,
#               'T055_missing': 103,
#               'T065_missing': 57,
#               'T192_missing': 63,
#               'T071_missing': 8,
#               'T057_missing': 98,
#               'T004': 41,
#               'T004_total': 63,
#               'T004_missing': 57,
#               'T120_missing': 32,
#               'T051': 22,
#               'T051_total': 35,
#               'T075': 6,
#               'T075_total': 37,
#               'T075_missing': 58,
#               'T089_missing': 7,
#               'T089': 13,
#               'T089_total': 18,
#               'T066_missing': 27,
#               'T130_missing': 71,
#               'T171': 8,
#               'T171_total': 13,
#               'T069_missing': 8,
#               'T094_missing': 7,
#               'T020': 10,
#               'T020_total': 32,
#               'T019_missing': 28,
#               'T019': 43,
#               'T019_total': 54,
#               'T114': 47,
#               'T114_total': 73,
#               'T012_missing': 33,
#               'T020_missing': 19,
#               'T012': 33,
#               'T012_total': 52,
#               'T066': 20,
#               'T066_total': 27,
#               'T194': 2,
#               'T194_total': 3,
#               'T127_missing': 15,
#               'T013': 16,
#               'T013_total': 18,
#               'T050_missing': 21,
#               'T085': 2,
#               'T085_total': 5,
#               'T085_missing': 4,
#               'T018': 20,
#               'T018_total': 32,
#               'T095_missing': 4,
#               'T072_missing': 11,
#               'T171_missing': 2,
#               'T013_missing': 1,
#               'T094': 0,
#               'T094_total': 1,
#               'T095': 0,
#               'T095_total': 1,
#               'T021': 1,
#               'T021_total': 1,
#               'T010_missing': 1,
#               'T010': 0,
#               'T010_total': 0,
#               'T194_missing': 0,
#               'T021_missing': 0,
#               'overall (exclude missing)': 0.6459576960331583,
#               'overall (include missing)': 0.40748582552967755}),
#  4: defaultdict(int,
#              {'T131_missing': 111,
#               'T052': 824,
#               'T052_total': 920,
#               'T043': 267,
#               'T043_total': 343,
#               'T169': 2222,
#               'T169_total': 2672,
#               'T025': 460,
#               'T025_total': 561,
#               'T131': 149,
#               'T131_total': 208,
#               'T033_missing': 1338,
#               'T067': 165,
#               'T067_total': 259,
#               'T069': 24,
#               'T069_total': 26,
#               'T167': 189,
#               'T167_total': 242,
#               'T037_missing': 118,
#               'T001': 74,
#               'T001_total': 149,
#               'T031_missing': 57,
#               'T080_missing': 2850,
#               'T196_missing': 149,
#               'T169_missing': 2002,
#               'T080': 2816,
#               'T080_total': 3503,
#               'T196': 110,
#               'T196_total': 236,
#               'T081': 1795,
#               'T081_total': 2361,
#               'T044': 326,
#               'T044_total': 489,
#               'T126': 305,
#               'T126_total': 468,
#               'T026': 154,
#               'T026_total': 213,
#               'T123': 954,
#               'T123_total': 1415,
#               'T077': 237,
#               'T077_total': 346,
#               'T052_missing': 616,
#               'T082': 557,
#               'T082_total': 711,
#               'T103': 40,
#               'T103_total': 51,
#               'T078_missing': 760,
#               'T039': 90,
#               'T039_total': 116,
#               'T028': 386,
#               'T028_total': 565,
#               'T191': 539,
#               'T191_total': 709,
#               'T062': 953,
#               'T062_total': 1235,
#               'T049': 57,
#               'T049_total': 67,
#               'T028_missing': 360,
#               'T045': 304,
#               'T045_total': 510,
#               'T063': 114,
#               'T063_total': 141,
#               'T031': 110,
#               'T031_total': 156,
#               'T023_missing': 410,
#               'T191_missing': 225,
#               'T078': 943,
#               'T078_total': 1115,
#               'T079': 1067,
#               'T079_total': 1205,
#               'T098': 821,
#               'T098_total': 985,
#               'T079_missing': 810,
#               'T061_missing': 661,
#               'T024': 116,
#               'T024_total': 150,
#               'T063_missing': 71,
#               'T067_missing': 172,
#               'T033': 1036,
#               'T033_total': 1756,
#               'T081_missing': 1593,
#               'T114_missing': 43,
#               'T123_missing': 691,
#               'T099': 147,
#               'T099_total': 181,
#               'T047_missing': 421,
#               'T101': 906,
#               'T101_total': 1021,
#               'T097': 232,
#               'T097_total': 271,
#               'T047': 1590,
#               'T047_total': 1822,
#               'T170_missing': 1080,
#               'T041': 409,
#               'T041_total': 519,
#               'T058': 504,
#               'T058_total': 748,
#               'T101_missing': 86,
#               'T041_missing': 352,
#               'T097_missing': 108,
#               'T170': 774,
#               'T170_total': 1163,
#               'T057': 66,
#               'T057_total': 87,
#               'T062_missing': 522,
#               'T032': 534,
#               'T032_total': 606,
#               'T184': 179,
#               'T184_total': 245,
#               'T201_missing': 90,
#               'T200': 9,
#               'T200_total': 15,
#               'T200_missing': 4,
#               'T100_missing': 73,
#               'T122': 95,
#               'T122_total': 113,
#               'T082_missing': 665,
#               'T100': 389,
#               'T100_total': 427,
#               'T093': 140,
#               'T093_total': 206,
#               'T058_missing': 495,
#               'T121': 696,
#               'T121_total': 897,
#               'T125': 99,
#               'T125_total': 139,
#               'T096': 78,
#               'T096_total': 180,
#               'UnknownType': 92,
#               'UnknownType_total': 276,
#               'T125_missing': 51,
#               'T046': 453,
#               'T046_total': 511,
#               'T060': 358,
#               'T060_total': 500,
#               'T059': 381,
#               'T059_total': 574,
#               'T049_missing': 38,
#               'T201': 227,
#               'T201_total': 271,
#               'T061': 964,
#               'T061_total': 1449,
#               'T077_missing': 270,
#               'T098_missing': 306,
#               'T087_missing': 47,
#               'T007': 223,
#               'T007_total': 266,
#               'T126_missing': 214,
#               'T070': 191,
#               'T070_total': 265,
#               'T087': 12,
#               'T087_total': 39,
#               'T007_missing': 182,
#               'T044_missing': 263,
#               'T070_missing': 226,
#               'T086': 32,
#               'T086_total': 45,
#               'T086_missing': 65,
#               'T045_missing': 203,
#               'T059_missing': 413,
#               'T060_missing': 273,
#               'T185': 143,
#               'T185_total': 193,
#               'T046_missing': 178,
#               'T074': 132,
#               'T074_total': 199,
#               'T185_missing': 129,
#               'T121_missing': 389,
#               'T074_missing': 195,
#               'T023': 617,
#               'T023_total': 696,
#               'T054_missing': 93,
#               'T168': 99,
#               'T168_total': 178,
#               'T037': 185,
#               'T037_total': 242,
#               'T055': 115,
#               'T055_total': 138,
#               'T048': 348,
#               'T048_total': 449,
#               'T129': 200,
#               'T129_total': 348,
#               'T195': 108,
#               'T195_total': 126,
#               'T195_missing': 23,
#               'T130': 112,
#               'T130_total': 133,
#               'T040': 240,
#               'T040_total': 314,
#               'T042_missing': 107,
#               'T025_missing': 378,
#               'T040_missing': 160,
#               'T104': 30,
#               'T104_total': 61,
#               'T024_missing': 110,
#               'T017_missing': 9,
#               'T056_missing': 63,
#               'T016': 131,
#               'T016_total': 137,
#               'T056': 106,
#               'T056_total': 118,
#               'T029_missing': 106,
#               'T030_missing': 44,
#               'T192': 104,
#               'T192_total': 208,
#               'T039_missing': 93,
#               'T022': 44,
#               'T022_total': 60,
#               'T038_missing': 66,
#               'T184_missing': 107,
#               'T017': 4,
#               'T017_total': 4,
#               'T197': 137,
#               'T197_total': 199,
#               'T109': 274,
#               'T109_total': 334,
#               'T038': 74,
#               'T038_total': 98,
#               'T026_missing': 102,
#               'T034_missing': 63,
#               'T015_missing': 132,
#               'T032_missing': 225,
#               'UnknownType_missing': 300,
#               'T043_missing': 163,
#               'T015': 276,
#               'T015_total': 333,
#               'T168_missing': 159,
#               'T102_missing': 6,
#               'T073_missing': 199,
#               'T167_missing': 164,
#               'T073': 162,
#               'T073_total': 237,
#               'T068_missing': 29,
#               'T093_missing': 107,
#               'T190': 34,
#               'T190_total': 49,
#               'T129_missing': 124,
#               'T014': 10,
#               'T014_total': 17,
#               'T014_missing': 5,
#               'T053': 44,
#               'T053_total': 54,
#               'T022_missing': 31,
#               'T042': 129,
#               'T042_total': 189,
#               'T030': 39,
#               'T030_total': 51,
#               'T116': 77,
#               'T116_total': 137,
#               'T054': 105,
#               'T054_total': 122,
#               'T005': 114,
#               'T005_total': 125,
#               'T005_missing': 49,
#               'T109_missing': 179,
#               'T197_missing': 90,
#               'T071': 10,
#               'T071_total': 21,
#               'T104_missing': 54,
#               'T048_missing': 109,
#               'T096_missing': 62,
#               'T008': 71,
#               'T008_total': 78,
#               'T001_missing': 85,
#               'T091': 113,
#               'T091_total': 130,
#               'T029': 86,
#               'T029_total': 131,
#               'T083': 310,
#               'T083_total': 384,
#               'T102': 17,
#               'T102_total': 19,
#               'T068': 35,
#               'T068_total': 36,
#               'T190_missing': 27,
#               'T091_missing': 70,
#               'T083_missing': 217,
#               'T064_missing': 14,
#               'T050': 14,
#               'T050_total': 24,
#               'T008_missing': 18,
#               'T034': 36,
#               'T034_total': 67,
#               'T099_missing': 51,
#               'T053_missing': 39,
#               'T116_missing': 42,
#               'T090': 65,
#               'T090_total': 86,
#               'T016_missing': 21,
#               'T018_missing': 22,
#               'T002': 166,
#               'T002_total': 220,
#               'T204': 219,
#               'T204_total': 269,
#               'T204_missing': 131,
#               'T127': 29,
#               'T127_total': 34,
#               'T002_missing': 183,
#               'T051_missing': 26,
#               'T064': 8,
#               'T064_total': 13,
#               'T120': 15,
#               'T120_total': 25,
#               'T065': 32,
#               'T065_total': 70,
#               'T122_missing': 86,
#               'T072': 8,
#               'T072_total': 11,
#               'T103_missing': 21,
#               'T092_missing': 37,
#               'T090_missing': 69,
#               'T092': 35,
#               'T092_total': 42,
#               'T055_missing': 103,
#               'T065_missing': 57,
#               'T192_missing': 63,
#               'T071_missing': 8,
#               'T057_missing': 98,
#               'T004': 53,
#               'T004_total': 63,
#               'T004_missing': 57,
#               'T120_missing': 32,
#               'T051': 34,
#               'T051_total': 35,
#               'T075': 12,
#               'T075_total': 37,
#               'T075_missing': 58,
#               'T089_missing': 7,
#               'T089': 16,
#               'T089_total': 18,
#               'T066_missing': 27,
#               'T130_missing': 71,
#               'T171': 10,
#               'T171_total': 13,
#               'T069_missing': 8,
#               'T094_missing': 7,
#               'T020': 12,
#               'T020_total': 32,
#               'T019_missing': 28,
#               'T019': 45,
#               'T019_total': 54,
#               'T114': 53,
#               'T114_total': 73,
#               'T012_missing': 33,
#               'T020_missing': 19,
#               'T012': 46,
#               'T012_total': 52,
#               'T066': 23,
#               'T066_total': 27,
#               'T194': 2,
#               'T194_total': 3,
#               'T127_missing': 15,
#               'T013': 16,
#               'T013_total': 18,
#               'T050_missing': 21,
#               'T085': 2,
#               'T085_total': 5,
#               'T085_missing': 4,
#               'T018': 27,
#               'T018_total': 32,
#               'T095_missing': 4,
#               'T072_missing': 11,
#               'T171_missing': 2,
#               'T013_missing': 1,
#               'T094': 0,
#               'T094_total': 1,
#               'T095': 0,
#               'T095_total': 1,
#               'T021': 1,
#               'T021_total': 1,
#               'T010_missing': 1,
#               'T010': 0,
#               'T010_total': 0,
#               'T194_missing': 0,
#               'T021_missing': 0,
#               'overall (exclude missing)': 0.7613362467055617,
#               'overall (include missing)': 0.4802694215110909}),
#  8: defaultdict(int,
#              {'T131_missing': 111,
#               'T052': 830,
#               'T052_total': 920,
#               'T043': 284,
#               'T043_total': 343,
#               'T169': 2330,
#               'T169_total': 2672,
#               'T025': 487,
#               'T025_total': 561,
#               'T131': 150,
#               'T131_total': 208,
#               'T033_missing': 1338,
#               'T067': 197,
#               'T067_total': 259,
#               'T069': 24,
#               'T069_total': 26,
#               'T167': 209,
#               'T167_total': 242,
#               'T037_missing': 118,
#               'T001': 95,
#               'T001_total': 149,
#               'T031_missing': 57,
#               'T080_missing': 2850,
#               'T196_missing': 149,
#               'T169_missing': 2002,
#               'T080': 2971,
#               'T080_total': 3503,
#               'T196': 166,
#               'T196_total': 236,
#               'T081': 1841,
#               'T081_total': 2361,
#               'T044': 342,
#               'T044_total': 489,
#               'T126': 343,
#               'T126_total': 468,
#               'T026': 158,
#               'T026_total': 213,
#               'T123': 1057,
#               'T123_total': 1415,
#               'T077': 290,
#               'T077_total': 346,
#               'T052_missing': 616,
#               'T082': 601,
#               'T082_total': 711,
#               'T103': 40,
#               'T103_total': 51,
#               'T078_missing': 760,
#               'T039': 95,
#               'T039_total': 116,
#               'T028': 415,
#               'T028_total': 565,
#               'T191': 565,
#               'T191_total': 709,
#               'T062': 1001,
#               'T062_total': 1235,
#               'T049': 58,
#               'T049_total': 67,
#               'T028_missing': 360,
#               'T045': 316,
#               'T045_total': 510,
#               'T063': 118,
#               'T063_total': 141,
#               'T031': 127,
#               'T031_total': 156,
#               'T023_missing': 410,
#               'T191_missing': 225,
#               'T078': 1025,
#               'T078_total': 1115,
#               'T079': 1098,
#               'T079_total': 1205,
#               'T098': 901,
#               'T098_total': 985,
#               'T079_missing': 810,
#               'T061_missing': 661,
#               'T024': 123,
#               'T024_total': 150,
#               'T063_missing': 71,
#               'T067_missing': 172,
#               'T033': 1225,
#               'T033_total': 1756,
#               'T081_missing': 1593,
#               'T114_missing': 43,
#               'T123_missing': 691,
#               'T099': 174,
#               'T099_total': 181,
#               'T047_missing': 421,
#               'T101': 986,
#               'T101_total': 1021,
#               'T097': 243,
#               'T097_total': 271,
#               'T047': 1623,
#               'T047_total': 1822,
#               'T170_missing': 1080,
#               'T041': 430,
#               'T041_total': 519,
#               'T058': 540,
#               'T058_total': 748,
#               'T101_missing': 86,
#               'T041_missing': 352,
#               'T097_missing': 108,
#               'T170': 831,
#               'T170_total': 1163,
#               'T057': 69,
#               'T057_total': 87,
#               'T062_missing': 522,
#               'T032': 556,
#               'T032_total': 606,
#               'T184': 191,
#               'T184_total': 245,
#               'T201_missing': 90,
#               'T200': 15,
#               'T200_total': 15,
#               'T200_missing': 4,
#               'T100_missing': 73,
#               'T122': 98,
#               'T122_total': 113,
#               'T082_missing': 665,
#               'T100': 390,
#               'T100_total': 427,
#               'T093': 150,
#               'T093_total': 206,
#               'T058_missing': 495,
#               'T121': 707,
#               'T121_total': 897,
#               'T125': 125,
#               'T125_total': 139,
#               'T096': 78,
#               'T096_total': 180,
#               'UnknownType': 108,
#               'UnknownType_total': 276,
#               'T125_missing': 51,
#               'T046': 459,
#               'T046_total': 511,
#               'T060': 381,
#               'T060_total': 500,
#               'T059': 396,
#               'T059_total': 574,
#               'T049_missing': 38,
#               'T201': 230,
#               'T201_total': 271,
#               'T061': 1144,
#               'T061_total': 1449,
#               'T077_missing': 270,
#               'T098_missing': 306,
#               'T087_missing': 47,
#               'T007': 223,
#               'T007_total': 266,
#               'T126_missing': 214,
#               'T070': 210,
#               'T070_total': 265,
#               'T087': 13,
#               'T087_total': 39,
#               'T007_missing': 182,
#               'T044_missing': 263,
#               'T070_missing': 226,
#               'T086': 40,
#               'T086_total': 45,
#               'T086_missing': 65,
#               'T045_missing': 203,
#               'T059_missing': 413,
#               'T060_missing': 273,
#               'T185': 150,
#               'T185_total': 193,
#               'T046_missing': 178,
#               'T074': 149,
#               'T074_total': 199,
#               'T185_missing': 129,
#               'T121_missing': 389,
#               'T074_missing': 195,
#               'T023': 627,
#               'T023_total': 696,
#               'T054_missing': 93,
#               'T168': 133,
#               'T168_total': 178,
#               'T037': 190,
#               'T037_total': 242,
#               'T055': 119,
#               'T055_total': 138,
#               'T048': 359,
#               'T048_total': 449,
#               'T129': 233,
#               'T129_total': 348,
#               'T195': 108,
#               'T195_total': 126,
#               'T195_missing': 23,
#               'T130': 117,
#               'T130_total': 133,
#               'T040': 263,
#               'T040_total': 314,
#               'T042_missing': 107,
#               'T025_missing': 378,
#               'T040_missing': 160,
#               'T104': 30,
#               'T104_total': 61,
#               'T024_missing': 110,
#               'T017_missing': 9,
#               'T056_missing': 63,
#               'T016': 134,
#               'T016_total': 137,
#               'T056': 107,
#               'T056_total': 118,
#               'T029_missing': 106,
#               'T030_missing': 44,
#               'T192': 139,
#               'T192_total': 208,
#               'T039_missing': 93,
#               'T022': 44,
#               'T022_total': 60,
#               'T038_missing': 66,
#               'T184_missing': 107,
#               'T017': 4,
#               'T017_total': 4,
#               'T197': 154,
#               'T197_total': 199,
#               'T109': 275,
#               'T109_total': 334,
#               'T038': 79,
#               'T038_total': 98,
#               'T026_missing': 102,
#               'T034_missing': 63,
#               'T015_missing': 132,
#               'T032_missing': 225,
#               'UnknownType_missing': 300,
#               'T043_missing': 163,
#               'T015': 280,
#               'T015_total': 333,
#               'T168_missing': 159,
#               'T102_missing': 6,
#               'T073_missing': 199,
#               'T167_missing': 164,
#               'T073': 162,
#               'T073_total': 237,
#               'T068_missing': 29,
#               'T093_missing': 107,
#               'T190': 34,
#               'T190_total': 49,
#               'T129_missing': 124,
#               'T014': 15,
#               'T014_total': 17,
#               'T014_missing': 5,
#               'T053': 45,
#               'T053_total': 54,
#               'T022_missing': 31,
#               'T042': 141,
#               'T042_total': 189,
#               'T030': 40,
#               'T030_total': 51,
#               'T116': 87,
#               'T116_total': 137,
#               'T054': 105,
#               'T054_total': 122,
#               'T005': 114,
#               'T005_total': 125,
#               'T005_missing': 49,
#               'T109_missing': 179,
#               'T197_missing': 90,
#               'T071': 10,
#               'T071_total': 21,
#               'T104_missing': 54,
#               'T048_missing': 109,
#               'T096_missing': 62,
#               'T008': 72,
#               'T008_total': 78,
#               'T001_missing': 85,
#               'T091': 118,
#               'T091_total': 130,
#               'T029': 99,
#               'T029_total': 131,
#               'T083': 324,
#               'T083_total': 384,
#               'T102': 17,
#               'T102_total': 19,
#               'T068': 35,
#               'T068_total': 36,
#               'T190_missing': 27,
#               'T091_missing': 70,
#               'T083_missing': 217,
#               'T064_missing': 14,
#               'T050': 14,
#               'T050_total': 24,
#               'T008_missing': 18,
#               'T034': 41,
#               'T034_total': 67,
#               'T099_missing': 51,
#               'T053_missing': 39,
#               'T116_missing': 42,
#               'T090': 65,
#               'T090_total': 86,
#               'T016_missing': 21,
#               'T018_missing': 22,
#               'T002': 188,
#               'T002_total': 220,
#               'T204': 221,
#               'T204_total': 269,
#               'T204_missing': 131,
#               'T127': 33,
#               'T127_total': 34,
#               'T002_missing': 183,
#               'T051_missing': 26,
#               'T064': 8,
#               'T064_total': 13,
#               'T120': 16,
#               'T120_total': 25,
#               'T065': 41,
#               'T065_total': 70,
#               'T122_missing': 86,
#               'T072': 8,
#               'T072_total': 11,
#               'T103_missing': 21,
#               'T092_missing': 37,
#               'T090_missing': 69,
#               'T092': 35,
#               'T092_total': 42,
#               'T055_missing': 103,
#               'T065_missing': 57,
#               'T192_missing': 63,
#               'T071_missing': 8,
#               'T057_missing': 98,
#               'T004': 53,
#               'T004_total': 63,
#               'T004_missing': 57,
#               'T120_missing': 32,
#               'T051': 34,
#               'T051_total': 35,
#               'T075': 29,
#               'T075_total': 37,
#               'T075_missing': 58,
#               'T089_missing': 7,
#               'T089': 16,
#               'T089_total': 18,
#               'T066_missing': 27,
#               'T130_missing': 71,
#               'T171': 10,
#               'T171_total': 13,
#               'T069_missing': 8,
#               'T094_missing': 7,
#               'T020': 12,
#               'T020_total': 32,
#               'T019_missing': 28,
#               'T019': 47,
#               'T019_total': 54,
#               'T114': 55,
#               'T114_total': 73,
#               'T012_missing': 33,
#               'T020_missing': 19,
#               'T012': 50,
#               'T012_total': 52,
#               'T066': 24,
#               'T066_total': 27,
#               'T194': 2,
#               'T194_total': 3,
#               'T127_missing': 15,
#               'T013': 17,
#               'T013_total': 18,
#               'T050_missing': 21,
#               'T085': 2,
#               'T085_total': 5,
#               'T085_missing': 4,
#               'T018': 28,
#               'T018_total': 32,
#               'T095_missing': 4,
#               'T072_missing': 11,
#               'T171_missing': 2,
#               'T013_missing': 1,
#               'T094': 0,
#               'T094_total': 1,
#               'T095': 0,
#               'T095_total': 1,
#               'T021': 1,
#               'T021_total': 1,
#               'T010_missing': 1,
#               'T010': 0,
#               'T010_total': 0,
#               'T194_missing': 0,
#               'T021_missing': 0,
#               'overall (exclude missing)': 0.812155069492938,
#               'overall (include missing)': 0.5123271709320336}),
#  16: defaultdict(int,
#              {'T131_missing': 111,
#               'T052': 833,
#               'T052_total': 920,
#               'T043': 293,
#               'T043_total': 343,
#               'T169': 2352,
#               'T169_total': 2672,
#               'T025': 490,
#               'T025_total': 561,
#               'T131': 151,
#               'T131_total': 208,
#               'T033_missing': 1338,
#               'T067': 202,
#               'T067_total': 259,
#               'T069': 24,
#               'T069_total': 26,
#               'T167': 209,
# ...
#               'T090_total': 86,
#               'T016_missing': 21,
#               'T018_missing': 22,
#               'T002': 189,
#               'T002_total': 220,
#               'T204': 222,
#               'T204_total': 269,
#               'T204_missing': 131,
#               'T127': 33,
#               'T127_total': 34,
#               'T002_missing': 183,
#               'T051_missing': 26,
#               'T064': 8,
#               'T064_total': 13,
#               'T120': 22,
#               'T120_total': 25,
#               'T065': 41,
#               'T065_total': 70,
#               'T122_missing': 86,
#               'T072': 8,
#               'T072_total': 11,
#               'T103_missing': 21,
#               'T092_missing': 37,
#               'T090_missing': 69,
#               'T092': 35,
#               'T092_total': 42,
#               'T055_missing': 103,
#               'T065_missing': 57,
#               'T192_missing': 63,
#               'T071_missing': 8,
#               'T057_missing': 98,
#               'T004': 53,
#               'T004_total': 63,
#               'T004_missing': 57,
#               'T120_missing': 32,
#               'T051': 34,
#               'T051_total': 35,
#               'T075': 31,
#               'T075_total': 37,
#               'T075_missing': 58,
#               'T089_missing': 7,
#               'T089': 16,
#               'T089_total': 18,
#               'T066_missing': 27,
#               'T130_missing': 71,
#               'T171': 10,
#               'T171_total': 13,
#               'T069_missing': 8,
#               'T094_missing': 7,
#               'T020': 12,
#               'T020_total': 32,
#               'T019_missing': 28,
#               'T019': 48,
#               'T019_total': 54,
#               'T114': 55,
#               'T114_total': 73,
#               'T012_missing': 33,
#               'T020_missing': 19,
#               'T012': 52,
#               'T012_total': 52,
#               'T066': 25,
#               'T066_total': 27,
#               'T194': 2,
#               'T194_total': 3,
#               'T127_missing': 15,
#               'T013': 17,
#               'T013_total': 18,
#               'T050_missing': 21,
#               'T085': 2,
#               'T085_total': 5,
#               'T085_missing': 4,
#               'T018': 28,
#               'T018_total': 32,
#               'T095_missing': 4,
#               'T072_missing': 11,
#               'T171_missing': 2,
#               'T013_missing': 1,
#               'T094': 0,
#               'T094_total': 1,
#               'T095': 0,
#               'T095_total': 1,
#               'T021': 1,
#               'T021_total': 1,
#               'T010_missing': 1,
#               'T010': 0,
#               'T010_total': 0,
#               'T194_missing': 0,
#               'T021_missing': 0,
#               'overall (exclude missing)': 0.8362354425247224,
#               'overall (include missing)': 0.5275176559191735}),
#  64: defaultdict(int,
#              {'T131_missing': 111,
#               'T052': 833,
#               'T052_total': 920,
#               'T043': 295,
#               'T043_total': 343,
#               'T169': 2357,
#               'T169_total': 2672,
#               'T025': 490,
#               'T025_total': 561,
#               'T131': 151,
#               'T131_total': 208,
#               'T033_missing': 1338,
#               'T067': 202,
#               'T067_total': 259,
#               'T069': 24,
#               'T069_total': 26,
#               'T167': 209,
#               'T167_total': 242,
#               'T037_missing': 118,
#               'T001': 115,
#               'T001_total': 149,
#               'T031_missing': 57,
#               'T080_missing': 2850,
#               'T196_missing': 149,
#               'T169_missing': 2002,
#               'T080': 3151,
#               'T080_total': 3503,
#               'T196': 183,
#               'T196_total': 236,
#               'T081': 1866,
#               'T081_total': 2361,
#               'T044': 365,
#               'T044_total': 489,
#               'T126': 361,
#               'T126_total': 468,
#               'T026': 161,
#               'T026_total': 213,
#               'T123': 1125,
#               'T123_total': 1415,
#               'T077': 295,
#               'T077_total': 346,
#               'T052_missing': 616,
#               'T082': 607,
#               'T082_total': 711,
#               'T103': 40,
#               'T103_total': 51,
#               'T078_missing': 760,
#               'T039': 95,
#               'T039_total': 116,
#               'T028': 427,
#               'T028_total': 565,
#               'T191': 576,
#               'T191_total': 709,
#               'T062': 1022,
#               'T062_total': 1235,
#               'T049': 58,
#               'T049_total': 67,
#               'T028_missing': 360,
#               'T045': 435,
#               'T045_total': 510,
#               'T063': 120,
#               'T063_total': 141,
#               'T031': 129,
#               'T031_total': 156,
#               'T023_missing': 410,
#               'T191_missing': 225,
#               'T078': 1039,
#               'T078_total': 1115,
#               'T079': 1125,
#               'T079_total': 1205,
#               'T098': 904,
#               'T098_total': 985,
#               'T079_missing': 810,
#               'T061_missing': 661,
#               'T024': 123,
#               'T024_total': 150,
#               'T063_missing': 71,
#               'T067_missing': 172,
#               'T033': 1258,
#               'T033_total': 1756,
#               'T081_missing': 1593,
#               'T114_missing': 43,
#               'T123_missing': 691,
#               'T099': 176,
#               'T099_total': 181,
#               'T047_missing': 421,
#               'T101': 986,
#               'T101_total': 1021,
#               'T097': 245,
#               'T097_total': 271,
#               'T047': 1647,
#               'T047_total': 1822,
#               'T170_missing': 1080,
#               'T041': 439,
#               'T041_total': 519,
#               'T058': 567,
#               'T058_total': 748,
#               'T101_missing': 86,
#               'T041_missing': 352,
#               'T097_missing': 108,
#               'T170': 850,
#               'T170_total': 1163,
#               'T057': 70,
#               'T057_total': 87,
#               'T062_missing': 522,
#               'T032': 568,
#               'T032_total': 606,
#               'T184': 209,
#               'T184_total': 245,
#               'T201_missing': 90,
#               'T200': 15,
#               'T200_total': 15,
#               'T200_missing': 4,
#               'T100_missing': 73,
#               'T122': 98,
#               'T122_total': 113,
#               'T082_missing': 665,
#               'T100': 393,
#               'T100_total': 427,
#               'T093': 155,
#               'T093_total': 206,
#               'T058_missing': 495,
#               'T121': 714,
#               'T121_total': 897,
#               'T125': 125,
#               'T125_total': 139,
#               'T096': 113,
#               'T096_total': 180,
#               'UnknownType': 123,
#               'UnknownType_total': 276,
#               'T125_missing': 51,
#               'T046': 463,
#               'T046_total': 511,
#               'T060': 383,
#               'T060_total': 500,
#               'T059': 411,
#               'T059_total': 574,
#               'T049_missing': 38,
#               'T201': 233,
#               'T201_total': 271,
#               'T061': 1172,
#               'T061_total': 1449,
#               'T077_missing': 270,
#               'T098_missing': 306,
#               'T087_missing': 47,
#               'T007': 223,
#               'T007_total': 266,
#               'T126_missing': 214,
#               'T070': 218,
#               'T070_total': 265,
#               'T087': 17,
#               'T087_total': 39,
#               'T007_missing': 182,
#               'T044_missing': 263,
#               'T070_missing': 226,
#               'T086': 40,
#               'T086_total': 45,
#               'T086_missing': 65,
#               'T045_missing': 203,
#               'T059_missing': 413,
#               'T060_missing': 273,
#               'T185': 151,
#               'T185_total': 193,
#               'T046_missing': 178,
#               'T074': 151,
#               'T074_total': 199,
#               'T185_missing': 129,
#               'T121_missing': 389,
#               'T074_missing': 195,
#               'T023': 632,
#               'T023_total': 696,
#               'T054_missing': 93,
#               'T168': 137,
#               'T168_total': 178,
#               'T037': 193,
#               'T037_total': 242,
#               'T055': 120,
#               'T055_total': 138,
#               'T048': 404,
#               'T048_total': 449,
#               'T129': 249,
#               'T129_total': 348,
#               'T195': 119,
#               'T195_total': 126,
#               'T195_missing': 23,
#               'T130': 118,
#               'T130_total': 133,
#               'T040': 267,
#               'T040_total': 314,
#               'T042_missing': 107,
#               'T025_missing': 378,
#               'T040_missing': 160,
#               'T104': 34,
#               'T104_total': 61,
#               'T024_missing': 110,
#               'T017_missing': 9,
#               'T056_missing': 63,
#               'T016': 134,
#               'T016_total': 137,
#               'T056': 107,
#               'T056_total': 118,
#               'T029_missing': 106,
#               'T030_missing': 44,
#               'T192': 159,
#               'T192_total': 208,
#               'T039_missing': 93,
#               'T022': 53,
#               'T022_total': 60,
#               'T038_missing': 66,
#               'T184_missing': 107,
#               'T017': 4,
#               'T017_total': 4,
#               'T197': 157,
#               'T197_total': 199,
#               'T109': 276,
#               'T109_total': 334,
#               'T038': 81,
#               'T038_total': 98,
#               'T026_missing': 102,
#               'T034_missing': 63,
#               'T015_missing': 132,
#               'T032_missing': 225,
#               'UnknownType_missing': 300,
#               'T043_missing': 163,
#               'T015': 280,
#               'T015_total': 333,
#               'T168_missing': 159,
#               'T102_missing': 6,
#               'T073_missing': 199,
#               'T167_missing': 164,
#               'T073': 163,
#               'T073_total': 237,
#               'T068_missing': 29,
#               'T093_missing': 107,
#               'T190': 36,
#               'T190_total': 49,
#               'T129_missing': 124,
#               'T014': 15,
#               'T014_total': 17,
#               'T014_missing': 5,
#               'T053': 45,
#               'T053_total': 54,
#               'T022_missing': 31,
#               'T042': 148,
#               'T042_total': 189,
#               'T030': 40,
#               'T030_total': 51,
#               'T116': 89,
#               'T116_total': 137,
#               'T054': 107,
#               'T054_total': 122,
#               'T005': 115,
#               'T005_total': 125,
#               'T005_missing': 49,
#               'T109_missing': 179,
#               'T197_missing': 90,
#               'T071': 10,
#               'T071_total': 21,
#               'T104_missing': 54,
#               'T048_missing': 109,
#               'T096_missing': 62,
#               'T008': 73,
#               'T008_total': 78,
#               'T001_missing': 85,
#               'T091': 122,
#               'T091_total': 130,
#               'T029': 102,
#               'T029_total': 131,
#               'T083': 329,
#               'T083_total': 384,
#               'T102': 18,
#               'T102_total': 19,
#               'T068': 36,
#               'T068_total': 36,
#               'T190_missing': 27,
#               'T091_missing': 70,
#               'T083_missing': 217,
#               'T064_missing': 14,
#               'T050': 14,
#               'T050_total': 24,
#               'T008_missing': 18,
#               'T034': 42,
#               'T034_total': 67,
#               'T099_missing': 51,
#               'T053_missing': 39,
#               'T116_missing': 42,
#               'T090': 65,
#               'T090_total': 86,
#               'T016_missing': 21,
#               'T018_missing': 22,
#               'T002': 189,
#               'T002_total': 220,
#               'T204': 222,
#               'T204_total': 269,
#               'T204_missing': 131,
#               'T127': 33,
#               'T127_total': 34,
#               'T002_missing': 183,
#               'T051_missing': 26,
#               'T064': 8,
#               'T064_total': 13,
#               'T120': 22,
#               'T120_total': 25,
#               'T065': 41,
#               'T065_total': 70,
#               'T122_missing': 86,
#               'T072': 8,
#               'T072_total': 11,
#               'T103_missing': 21,
#               'T092_missing': 37,
#               'T090_missing': 69,
#               'T092': 35,
#               'T092_total': 42,
#               'T055_missing': 103,
#               'T065_missing': 57,
#               'T192_missing': 63,
#               'T071_missing': 8,
#               'T057_missing': 98,
#               'T004': 53,
#               'T004_total': 63,
#               'T004_missing': 57,
#               'T120_missing': 32,
#               'T051': 34,
#               'T051_total': 35,
#               'T075': 31,
#               'T075_total': 37,
#               'T075_missing': 58,
#               'T089_missing': 7,
#               'T089': 16,
#               'T089_total': 18,
#               'T066_missing': 27,
#               'T130_missing': 71,
#               'T171': 10,
#               'T171_total': 13,
#               'T069_missing': 8,
#               'T094_missing': 7,
#               'T020': 12,
#               'T020_total': 32,
#               'T019_missing': 28,
#               'T019': 48,
#               'T019_total': 54,
#               'T114': 55,
#               'T114_total': 73,
#               'T012_missing': 33,
#               'T020_missing': 19,
#               'T012': 52,
#               'T012_total': 52,
#               'T066': 25,
#               'T066_total': 27,
#               'T194': 2,
#               'T194_total': 3,
#               'T127_missing': 15,
#               'T013': 17,
#               'T013_total': 18,
#               'T050_missing': 21,
#               'T085': 2,
#               'T085_total': 5,
#               'T085_missing': 4,
#               'T018': 28,
#               'T018_total': 32,
#               'T095_missing': 4,
#               'T072_missing': 11,
#               'T171_missing': 2,
#               'T013_missing': 1,
#               'T094': 0,
#               'T094_total': 1,
#               'T095': 0,
#               'T095_total': 1,
#               'T021': 1,
#               'T021_total': 1,
#               'T010_missing': 1,
#               'T010': 0,
#               'T010_total': 0,
#               'T194_missing': 0,
#               'T021_missing': 0,
#               'overall (exclude missing)': 0.8364607032640281,
#               'overall (include missing)': 0.5276597558722805}),
#  'types': {'T001',
#   'T002',
#   'T004',
#   'T005',
#   'T007',
#   'T008',
#   'T010',
#   'T012',
#   'T013',
#   'T014',
#   'T015',
#   'T016',
#   'T017',
#   'T018',
#   'T019',
#   'T020',
#   'T021',
#   'T022',
#   'T023',
#   'T024',
#   'T025',
#   'T026',
#   'T028',
#   'T029',
#   'T030',
#   'T031',
#   'T032',
#   'T033',
#   'T034',
#   'T037',
#   'T038',
#   'T039',
#   'T040',
#   'T041',
#   'T042',
#   'T043',
#   'T044',
#   'T045',
#   'T046',
#   'T047',
#   'T048',
#   'T049',
#   'T050',
#   'T051',
#   'T052',
#   'T053',
#   'T054',
#   'T055',
#   'T056',
#   'T057',
#   'T058',
#   'T059',
#   'T060',
#   'T061',
#   'T062',
#   'T063',
#   'T064',
#   'T065',
#   'T066',
#   'T067',
#   'T068',
#   'T069',
#   'T070',
#   'T071',
#   'T072',
#   'T073',
#   'T074',
#   'T075',
#   'T077',
#   'T078',
#   'T079',
#   'T080',
#   'T081',
#   'T082',
#   'T083',
#   'T085',
#   'T086',
#   'T087',
#   'T089',
#   'T090',
#   'T091',
#   'T092',
#   'T093',
#   'T094',
#   'T095',
#   'T096',
#   'T097',
#   'T098',
#   'T099',
#   'T100',
#   'T101',
#   'T102',
#   'T103',
#   'T104',
#   'T109',
#   'T114',
#   'T116',
#   'T120',
#   'T121',
#   'T122',
#   'T123',
#   'T125',
#   'T126',
#   'T127',
#   'T129',
#   'T130',
#   'T131',
#   'T167',
#   'T168',
#   'T169',
#   'T170',
#   'T171',
#   'T184',
#   'T185',
#   'T190',
#   'T191',
#   'T192',
#   'T194',
#   'T195',
#   'T196',
#   'T197',
#   'T200',
#   'T201',
#   'T204',
#   'UnknownType'}}

# %%
hits_dict = evaluate_linking(test_preds)
format_output(hits_dict)
# Out:
#                             Semantic Type  Hits @ 1  Hits @ 5  Hits @ 10  \
# 0                    Intellectual Product    0.3485    0.7194     0.7410
# 1                            Organization    0.4858    0.7449     0.7530
# 2                      Clinical Attribute    0.4940    0.8606     0.8606
# 3                               Eukaryote    0.4828    0.8474     0.8629
# 4                                 Finding    0.3941    0.7076     0.7482
# 5                     Injury or Poisoning    0.6432    0.7759     0.7925
# 6                       Research Activity    0.5574    0.8019     0.8333
# 7                             Body System    0.2807    0.7368     0.7368
# 8                                   Virus    0.6356    0.9068     0.9068
# 9                                    Food    0.2460    0.6043     0.7380
# 10                       Population Group    0.6227    0.8479     0.9199
# 11                               Chemical    0.4488    0.7391     0.7822
# 12     Professional or Occupational Group    0.6957    0.8623     0.8949
# 13    Biomedical Occupation or Discipline    0.5484    0.9032     0.9194
# 14                   Anatomical Structure    0.5779    0.8055     0.8320
# 15                         Body Substance    0.2338    0.7922     0.8182
# 16                   Health Care Activity    0.4490    0.7186     0.7999
# 17                         Medical Device    0.4294    0.6949     0.7910
# 18                      Biologic Function    0.4883    0.8094     0.8593
# 19                        Spatial Concept    0.5861    0.8117     0.8529
# 20                              Bacterium    0.6292    0.8315     0.8315
# 21                            **Overall**    0.4853    0.7747     0.8193
# 22  **Overall (including missing spans)**    0.3188    0.5090     0.5383
#
#     Hits @ 25  Spans Matched  Missing  Total  Missing Proportion
# 0      0.7538           1251     1114   2365              0.4710
# 1      0.7571            247      135    382              0.3534
# 2      0.8725            251       72    323              0.2229
# 3      0.8681           1160      590   1750              0.3371
# 4      0.7667           1946     1265   3211              0.3940
# 5      0.8050            241      116    357              0.3249
# 6      0.8475           1272      575   1847              0.3113
# 7      0.8596             57       33     90              0.3667
# 8      0.9153            118       54    172              0.3140
# 9      0.7487            187      135    322              0.4193
# 10     0.9229            986      277   1263              0.2193
# 11     0.8018           5082     2325   7407              0.3139
# 12     0.9022            276       84    360              0.2333
# 13     0.9677            124       72    196              0.3673
# 14     0.8393           2303     1470   3773              0.3896
# 15     0.8312            154       58    212              0.2736
# 16     0.8099           3078     1709   4787              0.3570
# 17     0.7966            177      178    355              0.5014
# 18     0.8724           5886     2227   8113              0.2745
# 19     0.8582           1312     1097   2409              0.4554
# 20     0.8315            267      182    449              0.4053
# 21     0.8322          26375    13768  40143              0.3430
# 22     0.5468          26375    13768  40143              0.3430

# %%
p = preds[0]

# %%
p['predictions']['scispacy']
# Out:
# [{'offsets': [[0, 11]],
#   'text': 'Nonylphenol',
#   'candidates': [{'db_id': 'UMLS:C0068946', 'score': 1.0},
#    {'db_id': 'UMLS:C0953814', 'score': 0.8478714227676392},
#    {'db_id': 'UMLS:C0953815', 'score': 0.8301727175712585},
#    {'db_id': 'UMLS:C0970196', 'score': 0.7795582413673401},
#    {'db_id': 'UMLS:C0097405', 'score': 0.767101526260376},
#    {'db_id': 'UMLS:C3857939', 'score': 0.757386326789856},
#    {'db_id': 'UMLS:C0953813', 'score': 0.7489328384399414},
#    {'db_id': 'UMLS:C4236359', 'score': 0.7475515604019165},
#    {'db_id': 'UMLS:C0132779', 'score': 0.7382228374481201}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0068946'}]},
#  {'offsets': [[25, 33]],
#   'text': 'inhibits',
#   'candidates': [{'db_id': 'UMLS:C0021467', 'score': 0.7524629831314087},
#    {'db_id': 'UMLS:C0021469', 'score': 0.7524629831314087},
#    {'db_id': 'UMLS:C3463820', 'score': 0.7524629831314087},
#    {'db_id': 'UMLS:C0074775', 'score': 0.7493148446083069},
#    {'db_id': 'UMLS:C1999216', 'score': 0.7310131192207336},
#    {'db_id': 'UMLS:C0311403', 'score': 0.722744345664978},
#    {'db_id': 'UMLS:C0679144', 'score': 0.7032979726791382},
#    {'db_id': 'UMLS:C1418824', 'score': 0.7014464735984802}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0021467'}]},
#  {'offsets': [[34, 43]],
#   'text': 'apoptosis',
#   'candidates': [{'db_id': 'UMLS:C0162638', 'score': 1.0},
#    {'db_id': 'UMLS:C4759886', 'score': 1.0},
#    {'db_id': 'UMLS:C2247960', 'score': 0.8234089016914368},
#    {'db_id': 'UMLS:C1326202', 'score': 0.8038336038589478},
#    {'db_id': 'UMLS:C1332322', 'score': 0.7967405319213867},
#    {'db_id': 'UMLS:C1660771', 'score': 0.7909232378005981},
#    {'db_id': 'UMLS:C2610891', 'score': 0.7842937111854553},
#    {'db_id': 'UMLS:C4329354', 'score': 0.7827578186988831},
#    {'db_id': 'UMLS:C1326205', 'score': 0.7727738618850708},
#    {'db_id': 'UMLS:C1454645', 'score': 0.7598106861114502},
#    {'db_id': 'UMLS:C1539477', 'score': 0.7598106861114502},
#    {'db_id': 'UMLS:C1564881', 'score': 0.7557398080825806},
#    {'db_id': 'UMLS:C1148568', 'score': 0.7536895275115967},
#    {'db_id': 'UMLS:C4233500', 'score': 0.7531155943870544},
#    {'db_id': 'UMLS:C3269144', 'score': 0.7494465708732605},
#    {'db_id': 'UMLS:C2246411', 'score': 0.7446570992469788},
#    {'db_id': 'UMLS:C3266896', 'score': 0.7426552772521973},
#    {'db_id': 'UMLS:C1332323', 'score': 0.7344915270805359},
#    {'db_id': 'UMLS:C3269138', 'score': 0.7319819927215576}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C4759886'}]},
#  {'offsets': [[44, 51]],
#   'text': 'induced',
#   'candidates': [{'db_id': 'UMLS:C0205263', 'score': 1.0},
#    {'db_id': 'UMLS:C3898767', 'score': 0.7984579205513},
#    {'db_id': 'UMLS:C1707707', 'score': 0.7826897501945496},
#    {'db_id': 'UMLS:C0153122', 'score': 0.7563474178314209},
#    {'db_id': 'UMLS:C1428046', 'score': 0.7431603074073792},
#    {'db_id': 'UMLS:C1512710', 'score': 0.741400957107544},
#    {'db_id': 'UMLS:C0858744', 'score': 0.7410463690757751},
#    {'db_id': 'UMLS:C0235661', 'score': 0.7390875816345215},
#    {'db_id': 'UMLS:C0458082', 'score': 0.738723874092102},
#    {'db_id': 'UMLS:C0022875', 'score': 0.7339017987251282},
#    {'db_id': 'UMLS:C0259787', 'score': 0.7339017987251282},
#    {'db_id': 'UMLS:C1708502', 'score': 0.7186915874481201},
#    {'db_id': 'UMLS:C0269439', 'score': 0.7103714346885681},
#    {'db_id': 'UMLS:C0392535', 'score': 0.7103714346885681},
#    {'db_id': 'UMLS:C1704300', 'score': 0.7103714346885681},
#    {'db_id': 'UMLS:C2985288', 'score': 0.7042877078056335},
#    {'db_id': 'UMLS:C1427643', 'score': 0.7007309794425964}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0205263'}]},
#  {'offsets': [[55, 65]],
#   'text': 'PC12 cells',
#   'candidates': [{'db_id': 'UMLS:C0085262', 'score': 1.0}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0085262'}]},
#  {'offsets': [[66, 77]],
#   'text': 'Nonylphenol',
#   'candidates': [{'db_id': 'UMLS:C0068946', 'score': 1.0},
#    {'db_id': 'UMLS:C0953814', 'score': 0.8478714227676392},
#    {'db_id': 'UMLS:C0953815', 'score': 0.8301727175712585},
#    {'db_id': 'UMLS:C0970196', 'score': 0.7795582413673401},
#    {'db_id': 'UMLS:C0097405', 'score': 0.767101526260376},
#    {'db_id': 'UMLS:C3857939', 'score': 0.757386326789856},
#    {'db_id': 'UMLS:C0953813', 'score': 0.7489328384399414},
#    {'db_id': 'UMLS:C4236359', 'score': 0.7475515604019165},
#    {'db_id': 'UMLS:C0132779', 'score': 0.7382228374481201}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0068946'}]},
#  {'offsets': [[126, 129]],
#   'text': 'NP2',
#   'candidates': [{'db_id': 'UMLS:C1417813', 'score': 1.0},
#    {'db_id': 'UMLS:C2698422', 'score': 1.0},
#    {'db_id': 'UMLS:C2698699', 'score': 1.0},
#    {'db_id': 'UMLS:C3446839', 'score': 0.7443797588348389},
#    {'db_id': 'UMLS:C1430346', 'score': 0.7097744941711426}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C1417813'}]},
#  {'offsets': [[130, 132]],
#   'text': 'EO',
#   'candidates': [{'db_id': 'UMLS:C0332120', 'score': 1.0},
#    {'db_id': 'UMLS:C0059403', 'score': 0.8363078236579895},
#    {'db_id': 'UMLS:C0059402', 'score': 0.70255446434021}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0332120'}]},
#  {'offsets': [[148, 167]],
#   'text': 'aquatic environment',
#   'candidates': [{'db_id': 'UMLS:C0563034', 'score': 1.0},
#    {'db_id': 'UMLS:C0014406', 'score': 0.7974847555160522},
#    {'db_id': 'UMLS:C4724382', 'score': 0.7366118431091309},
#    {'db_id': 'UMLS:C0562522', 'score': 0.7349271774291992},
#    {'db_id': 'UMLS:C0557735', 'score': 0.7261036038398743},
#    {'db_id': 'UMLS:C0563028', 'score': 0.7192054986953735},
#    {'db_id': 'UMLS:C0241842', 'score': 0.7180752158164978},
#    {'db_id': 'UMLS:C0241922', 'score': 0.7172470688819885},
#    {'db_id': 'UMLS:C0565954', 'score': 0.7142958045005798},
#    {'db_id': 'UMLS:C0563027', 'score': 0.7121359705924988},
#    {'db_id': 'UMLS:C0442528', 'score': 0.7120060920715332},
#    {'db_id': 'UMLS:C0557742', 'score': 0.7119547724723816},
#    {'db_id': 'UMLS:C0557725', 'score': 0.7100232839584351},
#    {'db_id': 'UMLS:C0557745', 'score': 0.7098597288131714}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0563034'}]},
#  {'offsets': [[171, 181]],
#   'text': 'wastewater',
#   'candidates': [{'db_id': 'UMLS:C3494254', 'score': 1.0},
#    {'db_id': 'UMLS:C5197761', 'score': 0.7285564541816711},
#    {'db_id': 'UMLS:C5107127', 'score': 0.7123866677284241},
#    {'db_id': 'UMLS:C0450237', 'score': 0.7096060514450073},
#    {'db_id': 'UMLS:C5107128', 'score': 0.7087265253067017},
#    {'db_id': 'UMLS:C5107129', 'score': 0.7066829204559326}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C3494254'}]},
#  {'offsets': [[182, 194]],
#   'text': 'contaminants',
#   'candidates': [{'db_id': 'UMLS:C2827365', 'score': 0.8474574089050293}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C2827365'}]},
#  {'offsets': [[206, 219]],
#   'text': 'toxic effects',
#   'candidates': [{'db_id': 'UMLS:C0600688', 'score': 0.8785359263420105},
#    {'db_id': 'UMLS:C0235032', 'score': 0.8356348872184753},
#    {'db_id': 'UMLS:C0497010', 'score': 0.833986759185791},
#    {'db_id': 'UMLS:C1280500', 'score': 0.8066810965538025},
#    {'db_id': 'UMLS:C0520761', 'score': 0.8032691478729248},
#    {'db_id': 'UMLS:C2362743', 'score': 0.7840741276741028},
#    {'db_id': 'UMLS:C0161695', 'score': 0.7742311358451843},
#    {'db_id': 'UMLS:C0274869', 'score': 0.7729132771492004},
#    {'db_id': 'UMLS:C0554775', 'score': 0.7563756704330444},
#    {'db_id': 'UMLS:C0436114', 'score': 0.7452982664108276},
#    {'db_id': 'UMLS:C2945677', 'score': 0.7373673915863037},
#    {'db_id': 'UMLS:C0023176', 'score': 0.7370293140411377},
#    {'db_id': 'UMLS:C0274871', 'score': 0.7338089942932129},
#    {'db_id': 'UMLS:C0274902', 'score': 0.7335754632949829},
#    {'db_id': 'UMLS:C0040533', 'score': 0.7313705682754517},
#    {'db_id': 'UMLS:C0678772', 'score': 0.7313088178634644},
#    {'db_id': 'UMLS:C0274872', 'score': 0.730657696723938},
#    {'db_id': 'UMLS:C0375693', 'score': 0.7262157797813416},
#    {'db_id': 'UMLS:C0543419', 'score': 0.7239492535591125},
#    {'db_id': 'UMLS:C1368999', 'score': 0.7239492535591125},
#    {'db_id': 'UMLS:C0274848', 'score': 0.7211309671401978},
#    {'db_id': 'UMLS:C0161685', 'score': 0.7207448482513428},
#    {'db_id': 'UMLS:C0412971', 'score': 0.7183623909950256}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0600688'}]},
#  {'offsets': [[223, 238]],
#   'text': 'aquatic species',
#   'candidates': [{'db_id': 'UMLS:C0884441', 'score': 0.7617052793502808},
#    {'db_id': 'UMLS:C3948730', 'score': 0.7004141211509705}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0884441'}]},
#  {'offsets': [[259, 268]],
#   'text': 'Apoptosis',
#   'candidates': [{'db_id': 'UMLS:C0162638', 'score': 1.0},
#    {'db_id': 'UMLS:C4759886', 'score': 1.0},
#    {'db_id': 'UMLS:C2247960', 'score': 0.8234089016914368},
#    {'db_id': 'UMLS:C1326202', 'score': 0.8038336038589478},
#    {'db_id': 'UMLS:C1332322', 'score': 0.7967405319213867},
#    {'db_id': 'UMLS:C1660771', 'score': 0.7909232378005981},
#    {'db_id': 'UMLS:C2610891', 'score': 0.7842937111854553},
#    {'db_id': 'UMLS:C4329354', 'score': 0.7827578186988831},
#    {'db_id': 'UMLS:C1326205', 'score': 0.7727738618850708},
#    {'db_id': 'UMLS:C1454645', 'score': 0.7598106861114502},
#    {'db_id': 'UMLS:C1539477', 'score': 0.7598106861114502},
#    {'db_id': 'UMLS:C1564881', 'score': 0.7557398080825806},
#    {'db_id': 'UMLS:C1148568', 'score': 0.7536895275115967},
#    {'db_id': 'UMLS:C4233500', 'score': 0.7531155943870544},
#    {'db_id': 'UMLS:C3269144', 'score': 0.7494465708732605},
#    {'db_id': 'UMLS:C2246411', 'score': 0.7446570992469788},
#    {'db_id': 'UMLS:C3266896', 'score': 0.7426552772521973},
#    {'db_id': 'UMLS:C1332323', 'score': 0.7344915270805359},
#    {'db_id': 'UMLS:C3269138', 'score': 0.7319819927215576}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0162638'}]},
#  {'offsets': [[290, 297]],
#   'text': 'induced',
#   'candidates': [{'db_id': 'UMLS:C0205263', 'score': 1.0},
#    {'db_id': 'UMLS:C3898767', 'score': 0.7984579205513},
#    {'db_id': 'UMLS:C1707707', 'score': 0.7826897501945496},
#    {'db_id': 'UMLS:C0153122', 'score': 0.7563474178314209},
#    {'db_id': 'UMLS:C1428046', 'score': 0.7431603074073792},
#    {'db_id': 'UMLS:C1512710', 'score': 0.741400957107544},
#    {'db_id': 'UMLS:C0858744', 'score': 0.7410463690757751},
#    {'db_id': 'UMLS:C0235661', 'score': 0.7390875816345215},
#    {'db_id': 'UMLS:C0458082', 'score': 0.738723874092102},
#    {'db_id': 'UMLS:C0022875', 'score': 0.7339017987251282},
#    {'db_id': 'UMLS:C0259787', 'score': 0.7339017987251282},
#    {'db_id': 'UMLS:C1708502', 'score': 0.7186915874481201},
#    {'db_id': 'UMLS:C0269439', 'score': 0.7103714346885681},
#    {'db_id': 'UMLS:C0392535', 'score': 0.7103714346885681},
#    {'db_id': 'UMLS:C1704300', 'score': 0.7103714346885681},
#    {'db_id': 'UMLS:C2985288', 'score': 0.7042877078056335},
#    {'db_id': 'UMLS:C1427643', 'score': 0.7007309794425964}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0205263'}]},
#  {'offsets': [[301, 318]],
#   'text': 'serum deprivation',
#   'candidates': [{'db_id': 'UMLS:C0871712', 'score': 0.833910346031189},
#    {'db_id': 'UMLS:C0599620', 'score': 0.7079419493675232}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0871712'}]},
#  {'offsets': [[322, 328]],
#   'text': 'copper',
#   'candidates': [{'db_id': 'UMLS:C0009968', 'score': 0.9999999403953552},
#    {'db_id': 'UMLS:C0373587', 'score': 0.9999999403953552},
#    {'db_id': 'UMLS:C2348263', 'score': 0.9999999403953552},
#    {'db_id': 'UMLS:C0303182', 'score': 0.8258143067359924},
#    {'db_id': 'UMLS:C0056292', 'score': 0.8004307746887207},
#    {'db_id': 'UMLS:C1551716', 'score': 0.7947198152542114},
#    {'db_id': 'UMLS:C0268070', 'score': 0.7936380505561829},
#    {'db_id': 'UMLS:C1551717', 'score': 0.7570146322250366},
#    {'db_id': 'UMLS:C1551900', 'score': 0.7570146322250366},
#    {'db_id': 'UMLS:C0201960', 'score': 0.7550140619277954},
#    {'db_id': 'UMLS:C0428576', 'score': 0.7550140619277954},
#    {'db_id': 'UMLS:C0599217', 'score': 0.745829164981842},
#    {'db_id': 'UMLS:C0858105', 'score': 0.7286819815635681},
#    {'db_id': 'UMLS:C0860994', 'score': 0.7285761833190918},
#    {'db_id': 'UMLS:C0589328', 'score': 0.7264619469642639},
#    {'db_id': 'UMLS:C0303189', 'score': 0.722392201423645},
#    {'db_id': 'UMLS:C0962035', 'score': 0.7200943827629089},
#    {'db_id': 'UMLS:C1148611', 'score': 0.7188345193862915},
#    {'db_id': 'UMLS:C0056603', 'score': 0.7175687551498413},
#    {'db_id': 'UMLS:C0303191', 'score': 0.7134490013122559},
#    {'db_id': 'UMLS:C0264456', 'score': 0.7103310227394104},
#    {'db_id': 'UMLS:C0303190', 'score': 0.7101002931594849},
#    {'db_id': 'UMLS:C0458049', 'score': 0.7100422382354736},
#    {'db_id': 'UMLS:C0860194', 'score': 0.7087116241455078}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0009968'}]},
#  {'offsets': [[329, 338]],
#   'text': 'treatment',
#   'candidates': [{'db_id': 'UMLS:C0039798', 'score': 1.0},
#    {'db_id': 'UMLS:C0087111', 'score': 1.0},
#    {'db_id': 'UMLS:C1522326', 'score': 1.0},
#    {'db_id': 'UMLS:C1533734', 'score': 1.0},
#    {'db_id': 'UMLS:C1705169', 'score': 1.0},
#    {'db_id': 'UMLS:C3161471', 'score': 1.0},
#    {'db_id': 'UMLS:C3538994', 'score': 1.0},
#    {'db_id': 'UMLS:C3887704', 'score': 1.0},
#    {'db_id': 'UMLS:C4684449', 'score': 0.921918511390686},
#    {'db_id': 'UMLS:C0746919', 'score': 0.9202965497970581},
#    {'db_id': 'UMLS:C3275118', 'score': 0.9202965497970581},
#    {'db_id': 'UMLS:C1292734', 'score': 0.8668318390846252},
#    {'db_id': 'UMLS:C4085568', 'score': 0.8668318390846252},
#    {'db_id': 'UMLS:C0814472', 'score': 0.8636425137519836},
#    {'db_id': 'UMLS:C0203597', 'score': 0.8592899441719055},
#    {'db_id': 'UMLS:C1291732', 'score': 0.8541515469551086},
#    {'db_id': 'UMLS:C0599880', 'score': 0.8490040302276611},
#    {'db_id': 'UMLS:C0087112', 'score': 0.847922146320343},
#    {'db_id': 'UMLS:C0011331', 'score': 0.8455294966697693},
#    {'db_id': 'UMLS:C1562800', 'score': 0.8453541398048401},
#    {'db_id': 'UMLS:C1522541', 'score': 0.8452004790306091},
#    {'db_id': 'UMLS:C0021459', 'score': 0.840384304523468},
#    {'db_id': 'UMLS:C2945691', 'score': 0.8379275798797607},
#    {'db_id': 'UMLS:C0850168', 'score': 0.8371482491493225},
#    {'db_id': 'UMLS:C1548875', 'score': 0.8371482491493225},
#    {'db_id': 'UMLS:C0337950', 'score': 0.8336640000343323}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0039798'}]},
#  {'offsets': [[358, 366]],
#   'text': 'toxicity',
#   'candidates': [{'db_id': 'UMLS:C0040539', 'score': 1.0},
#    {'db_id': 'UMLS:C0600688', 'score': 1.0},
#    {'db_id': 'UMLS:C1142072', 'score': 0.9041571021080017},
#    {'db_id': 'UMLS:C0595916', 'score': 0.8562463521957397},
#    {'db_id': 'UMLS:C0242890', 'score': 0.853233814239502},
#    {'db_id': 'UMLS:C1167791', 'score': 0.8336424827575684},
#    {'db_id': 'UMLS:C0745409', 'score': 0.8329271078109741},
#    {'db_id': 'UMLS:C2826262', 'score': 0.8232153654098511},
#    {'db_id': 'UMLS:C0275012', 'score': 0.8204122185707092},
#    {'db_id': 'UMLS:C0948342', 'score': 0.8199789524078369},
#    {'db_id': 'UMLS:C0877104', 'score': 0.8178958296775818},
#    {'db_id': 'UMLS:C0013221', 'score': 0.8010424971580505},
#    {'db_id': 'UMLS:C0274848', 'score': 0.7909846305847168},
#    {'db_id': 'UMLS:C0275056', 'score': 0.7885827422142029},
#    {'db_id': 'UMLS:C0275067', 'score': 0.7882724404335022},
#    {'db_id': 'UMLS:C0348754', 'score': 0.785512387752533},
#    {'db_id': 'UMLS:C0344124', 'score': 0.7849006056785583}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0040539'}]},
#  {'offsets': [[370, 394]],
#   'text': 'nonylphenol diethoxylate',
#   'candidates': [{'db_id': 'UMLS:C0132779', 'score': 0.8804130554199219},
#    {'db_id': 'UMLS:C0604118', 'score': 0.726760983467102},
#    {'db_id': 'UMLS:C0068946', 'score': 0.7034839391708374}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0132779'}]},
#  {'offsets': [[399, 411]],
#   'text': 'investigated',
#   'candidates': [{'db_id': 'UMLS:C1292732', 'score': 1.0},
#    {'db_id': 'UMLS:C0220825', 'score': 0.8599081039428711},
#    {'db_id': 'UMLS:C1261322', 'score': 0.8599081039428711},
#    {'db_id': 'UMLS:C1552578', 'score': 0.8599081039428711},
#    {'db_id': 'UMLS:C0035173', 'score': 0.8376585841178894},
#    {'db_id': 'UMLS:C1517586', 'score': 0.8182322382926941},
#    {'db_id': 'UMLS:C3245491', 'score': 0.8182322382926941},
#    {'db_id': 'UMLS:C0449433', 'score': 0.7777749300003052},
#    {'db_id': 'UMLS:C1708251', 'score': 0.7388296127319336},
#    {'db_id': 'UMLS:C1710101', 'score': 0.7356106638908386},
#    {'db_id': 'UMLS:C2825164', 'score': 0.7356106638908386},
#    {'db_id': 'UMLS:C2827983', 'score': 0.7356106638908386},
#    {'db_id': 'UMLS:C0868646', 'score': 0.7280187010765076},
#    {'db_id': 'UMLS:C0337637', 'score': 0.7239245772361755},
#    {'db_id': 'UMLS:C0013230', 'score': 0.7217698097229004},
#    {'db_id': 'UMLS:C0243095', 'score': 0.7197885513305664},
#    {'db_id': 'UMLS:C2346577', 'score': 0.7196402549743652},
#    {'db_id': 'UMLS:C2826892', 'score': 0.7145398855209351},
#    {'db_id': 'UMLS:C3640849', 'score': 0.7124730944633484},
#    {'db_id': 'UMLS:C2346570', 'score': 0.7096487879753113},
#    {'db_id': 'UMLS:C1883202', 'score': 0.7073023319244385}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C1292732'}]},
#  {'offsets': [[416, 423]],
#   'text': 'effects',
#   'candidates': [{'db_id': 'UMLS:C1280500', 'score': 1.0},
#    {'db_id': 'UMLS:C2945677', 'score': 0.914075493812561},
#    {'db_id': 'UMLS:C0543419', 'score': 0.8974418044090271},
#    {'db_id': 'UMLS:C1368999', 'score': 0.8974418044090271},
#    {'db_id': 'UMLS:C0001688', 'score': 0.8638460636138916},
#    {'db_id': 'UMLS:C0877248', 'score': 0.8638460636138916},
#    {'db_id': 'UMLS:C0879626', 'score': 0.8638460636138916},
#    {'db_id': 'UMLS:C0161734', 'score': 0.8585611581802368},
#    {'db_id': 'UMLS:C0221500', 'score': 0.8525299429893494},
#    {'db_id': 'UMLS:C0872206', 'score': 0.8463888168334961},
#    {'db_id': 'UMLS:C3178735', 'score': 0.8214828968048096},
#    {'db_id': 'UMLS:C4277541', 'score': 0.8187500834465027},
#    {'db_id': 'UMLS:C1319171', 'score': 0.818490743637085},
#    {'db_id': 'UMLS:C4277511', 'score': 0.8172067403793335},
#    {'db_id': 'UMLS:C1383090', 'score': 0.8128247261047363},
#    {'db_id': 'UMLS:C0870961', 'score': 0.8118370175361633},
#    {'db_id': 'UMLS:C0009246', 'score': 0.8057023286819458},
#    {'db_id': 'UMLS:C0728866', 'score': 0.8048781156539917},
#    {'db_id': 'UMLS:C0018538', 'score': 0.8030292987823486},
#    {'db_id': 'UMLS:C0544721', 'score': 0.7989674806594849},
#    {'db_id': 'UMLS:C0870752', 'score': 0.7948921322822571},
#    {'db_id': 'UMLS:C0034525', 'score': 0.7937171459197998},
#    {'db_id': 'UMLS:C0034526', 'score': 0.7937171459197998},
#    {'db_id': 'UMLS:C4281532', 'score': 0.7937171459197998}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C1280500'}]},
#  {'offsets': [[427, 430]],
#   'text': 'NP2',
#   'candidates': [{'db_id': 'UMLS:C1417813', 'score': 1.0},
#    {'db_id': 'UMLS:C2698422', 'score': 1.0},
#    {'db_id': 'UMLS:C2698699', 'score': 1.0},
#    {'db_id': 'UMLS:C3446839', 'score': 0.7443797588348389},
#    {'db_id': 'UMLS:C1430346', 'score': 0.7097744941711426}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C1417813'}]},
#  {'offsets': [[431, 433]],
#   'text': 'EO',
#   'candidates': [{'db_id': 'UMLS:C0332120', 'score': 1.0},
#    {'db_id': 'UMLS:C0059403', 'score': 0.8363078236579895},
#    {'db_id': 'UMLS:C0059402', 'score': 0.70255446434021}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0332120'}]},
#  {'offsets': [[437, 446]],
#   'text': 'apoptosis',
#   'candidates': [{'db_id': 'UMLS:C0162638', 'score': 1.0},
#    {'db_id': 'UMLS:C4759886', 'score': 1.0},
#    {'db_id': 'UMLS:C2247960', 'score': 0.8234089016914368},
#    {'db_id': 'UMLS:C1326202', 'score': 0.8038336038589478},
#    {'db_id': 'UMLS:C1332322', 'score': 0.7967405319213867},
#    {'db_id': 'UMLS:C1660771', 'score': 0.7909232378005981},
#    {'db_id': 'UMLS:C2610891', 'score': 0.7842937111854553},
#    {'db_id': 'UMLS:C4329354', 'score': 0.7827578186988831},
#    {'db_id': 'UMLS:C1326205', 'score': 0.7727738618850708},
#    {'db_id': 'UMLS:C1454645', 'score': 0.7598106861114502},
#    {'db_id': 'UMLS:C1539477', 'score': 0.7598106861114502},
#    {'db_id': 'UMLS:C1564881', 'score': 0.7557398080825806},
#    {'db_id': 'UMLS:C1148568', 'score': 0.7536895275115967},
#    {'db_id': 'UMLS:C4233500', 'score': 0.7531155943870544},
#    {'db_id': 'UMLS:C3269144', 'score': 0.7494465708732605},
#    {'db_id': 'UMLS:C2246411', 'score': 0.7446570992469788},
#    {'db_id': 'UMLS:C3266896', 'score': 0.7426552772521973},
#    {'db_id': 'UMLS:C1332323', 'score': 0.7344915270805359},
#    {'db_id': 'UMLS:C3269138', 'score': 0.7319819927215576}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C4759886'}]},
#  {'offsets': [[447, 454]],
#   'text': 'induced',
#   'candidates': [{'db_id': 'UMLS:C0205263', 'score': 1.0},
#    {'db_id': 'UMLS:C3898767', 'score': 0.7984579205513},
#    {'db_id': 'UMLS:C1707707', 'score': 0.7826897501945496},
#    {'db_id': 'UMLS:C0153122', 'score': 0.7563474178314209},
#    {'db_id': 'UMLS:C1428046', 'score': 0.7431603074073792},
#    {'db_id': 'UMLS:C1512710', 'score': 0.741400957107544},
#    {'db_id': 'UMLS:C0858744', 'score': 0.7410463690757751},
#    {'db_id': 'UMLS:C0235661', 'score': 0.7390875816345215},
#    {'db_id': 'UMLS:C0458082', 'score': 0.738723874092102},
#    {'db_id': 'UMLS:C0022875', 'score': 0.7339017987251282},
#    {'db_id': 'UMLS:C0259787', 'score': 0.7339017987251282},
#    {'db_id': 'UMLS:C1708502', 'score': 0.7186915874481201},
#    {'db_id': 'UMLS:C0269439', 'score': 0.7103714346885681},
#    {'db_id': 'UMLS:C0392535', 'score': 0.7103714346885681},
#    {'db_id': 'UMLS:C1704300', 'score': 0.7103714346885681},
#    {'db_id': 'UMLS:C2985288', 'score': 0.7042877078056335},
#    {'db_id': 'UMLS:C1427643', 'score': 0.7007309794425964}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0205263'}]},
#  {'offsets': [[458, 475]],
#   'text': 'serum deprivation',
#   'candidates': [{'db_id': 'UMLS:C0871712', 'score': 0.833910346031189},
#    {'db_id': 'UMLS:C0599620', 'score': 0.7079419493675232}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0871712'}]},
#  {'offsets': [[480, 486]],
#   'text': 'copper',
#   'candidates': [{'db_id': 'UMLS:C0009968', 'score': 0.9999999403953552},
#    {'db_id': 'UMLS:C0373587', 'score': 0.9999999403953552},
#    {'db_id': 'UMLS:C2348263', 'score': 0.9999999403953552},
#    {'db_id': 'UMLS:C0303182', 'score': 0.8258143067359924},
#    {'db_id': 'UMLS:C0056292', 'score': 0.8004307746887207},
#    {'db_id': 'UMLS:C1551716', 'score': 0.7947198152542114},
#    {'db_id': 'UMLS:C0268070', 'score': 0.7936380505561829},
#    {'db_id': 'UMLS:C1551717', 'score': 0.7570146322250366},
#    {'db_id': 'UMLS:C1551900', 'score': 0.7570146322250366},
#    {'db_id': 'UMLS:C0201960', 'score': 0.7550140619277954},
#    {'db_id': 'UMLS:C0428576', 'score': 0.7550140619277954},
#    {'db_id': 'UMLS:C0599217', 'score': 0.745829164981842},
#    {'db_id': 'UMLS:C0858105', 'score': 0.7286819815635681},
#    {'db_id': 'UMLS:C0860994', 'score': 0.7285761833190918},
#    {'db_id': 'UMLS:C0589328', 'score': 0.7264619469642639},
#    {'db_id': 'UMLS:C0303189', 'score': 0.722392201423645},
#    {'db_id': 'UMLS:C0962035', 'score': 0.7200943827629089},
#    {'db_id': 'UMLS:C1148611', 'score': 0.7188345193862915},
#    {'db_id': 'UMLS:C0056603', 'score': 0.7175687551498413},
#    {'db_id': 'UMLS:C0303191', 'score': 0.7134490013122559},
#    {'db_id': 'UMLS:C0264456', 'score': 0.7103310227394104},
#    {'db_id': 'UMLS:C0303190', 'score': 0.7101002931594849},
#    {'db_id': 'UMLS:C0458049', 'score': 0.7100422382354736},
#    {'db_id': 'UMLS:C0860194', 'score': 0.7087116241455078}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C2348263'}]},
#  {'offsets': [[496, 512]],
#   'text': 'PC12 cell system',
#   'candidates': [{'db_id': 'UMLS:C0085262', 'score': 0.8442631363868713}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0085262'}]},
#  {'offsets': [[514, 538]],
#   'text': 'Nonylphenol diethoxylate',
#   'candidates': [{'db_id': 'UMLS:C0132779', 'score': 0.8804130554199219},
#    {'db_id': 'UMLS:C0604118', 'score': 0.726760983467102},
#    {'db_id': 'UMLS:C0068946', 'score': 0.7034839391708374}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0132779'}]},
#  {'offsets': [[556, 564]],
#   'text': 'toxicity',
#   'candidates': [{'db_id': 'UMLS:C0040539', 'score': 1.0},
#    {'db_id': 'UMLS:C0600688', 'score': 1.0},
#    {'db_id': 'UMLS:C1142072', 'score': 0.9041571021080017},
#    {'db_id': 'UMLS:C0595916', 'score': 0.8562463521957397},
#    {'db_id': 'UMLS:C0242890', 'score': 0.853233814239502},
#    {'db_id': 'UMLS:C1167791', 'score': 0.8336424827575684},
#    {'db_id': 'UMLS:C0745409', 'score': 0.8329271078109741},
#    {'db_id': 'UMLS:C2826262', 'score': 0.8232153654098511},
#    {'db_id': 'UMLS:C0275012', 'score': 0.8204122185707092},
#    {'db_id': 'UMLS:C0948342', 'score': 0.8199789524078369},
#    {'db_id': 'UMLS:C0877104', 'score': 0.8178958296775818},
#    {'db_id': 'UMLS:C0013221', 'score': 0.8010424971580505},
#    {'db_id': 'UMLS:C0274848', 'score': 0.7909846305847168},
#    {'db_id': 'UMLS:C0275056', 'score': 0.7885827422142029},
#    {'db_id': 'UMLS:C0275067', 'score': 0.7882724404335022},
#    {'db_id': 'UMLS:C0348754', 'score': 0.785512387752533},
#    {'db_id': 'UMLS:C0344124', 'score': 0.7849006056785583}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0600688'}]},
#  {'offsets': [[569, 578]],
#   'text': 'recovered',
#   'candidates': [{'db_id': 'UMLS:C0521108', 'score': 1.0},
#    {'db_id': 'UMLS:C2004454', 'score': 0.8328160643577576},
#    {'db_id': 'UMLS:C3858677', 'score': 0.8328160643577576},
#    {'db_id': 'UMLS:C0439844', 'score': 0.8285134434700012},
#    {'db_id': 'UMLS:C1999244', 'score': 0.8285134434700012},
#    {'db_id': 'UMLS:C1115804', 'score': 0.8071500062942505},
#    {'db_id': 'UMLS:C1709863', 'score': 0.8071500062942505},
#    {'db_id': 'UMLS:C2826210', 'score': 0.7962479591369629},
#    {'db_id': 'UMLS:C2827927', 'score': 0.7948501706123352},
#    {'db_id': 'UMLS:C4524578', 'score': 0.7919111847877502},
#    {'db_id': 'UMLS:C2827979', 'score': 0.7771905064582825},
#    {'db_id': 'UMLS:C0237820', 'score': 0.7740257978439331},
#    {'db_id': 'UMLS:C1555688', 'score': 0.7740257978439331},
#    {'db_id': 'UMLS:C0140116', 'score': 0.773873507976532},
#    {'db_id': 'UMLS:C1419326', 'score': 0.773873507976532},
#    {'db_id': 'UMLS:C1546957', 'score': 0.755936324596405},
#    {'db_id': 'UMLS:C0682155', 'score': 0.7381494045257568},
#    {'db_id': 'UMLS:C1555028', 'score': 0.7279551029205322},
#    {'db_id': 'UMLS:C3686474', 'score': 0.7169649600982666},
#    {'db_id': 'UMLS:C1562582', 'score': 0.7056894898414612},
#    {'db_id': 'UMLS:C3242232', 'score': 0.7004424929618835}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0521108'}]},
#  {'offsets': [[579, 593]],
#   'text': 'cell viability',
#   'candidates': [{'db_id': 'UMLS:C0007620', 'score': 1.0},
#    {'db_id': 'UMLS:C0443348', 'score': 0.869454026222229},
#    {'db_id': 'UMLS:C1516362', 'score': 0.8491372466087341},
#    {'db_id': 'UMLS:C1563773', 'score': 0.7493342757225037},
#    {'db_id': 'UMLS:C0429848', 'score': 0.7368645668029785},
#    {'db_id': 'UMLS:C1261170', 'score': 0.7368645668029785},
#    {'db_id': 'UMLS:C1449936', 'score': 0.7288508415222168},
#    {'db_id': 'UMLS:C1563772', 'score': 0.7197893261909485},
#    {'db_id': 'UMLS:C0015954', 'score': 0.7154755592346191},
#    {'db_id': 'UMLS:C1300991', 'score': 0.7108904719352722}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0007620'}]},
#  {'offsets': [[599, 608]],
#   'text': 'apoptosis',
#   'candidates': [{'db_id': 'UMLS:C0162638', 'score': 1.0},
#    {'db_id': 'UMLS:C4759886', 'score': 1.0},
#    {'db_id': 'UMLS:C2247960', 'score': 0.8234089016914368},
#    {'db_id': 'UMLS:C1326202', 'score': 0.8038336038589478},
#    {'db_id': 'UMLS:C1332322', 'score': 0.7967405319213867},
#    {'db_id': 'UMLS:C1660771', 'score': 0.7909232378005981},
#    {'db_id': 'UMLS:C2610891', 'score': 0.7842937111854553},
#    {'db_id': 'UMLS:C4329354', 'score': 0.7827578186988831},
#    {'db_id': 'UMLS:C1326205', 'score': 0.7727738618850708},
#    {'db_id': 'UMLS:C1454645', 'score': 0.7598106861114502},
#    {'db_id': 'UMLS:C1539477', 'score': 0.7598106861114502},
#    {'db_id': 'UMLS:C1564881', 'score': 0.7557398080825806},
#    {'db_id': 'UMLS:C1148568', 'score': 0.7536895275115967},
#    {'db_id': 'UMLS:C4233500', 'score': 0.7531155943870544},
#    {'db_id': 'UMLS:C3269144', 'score': 0.7494465708732605},
#    {'db_id': 'UMLS:C2246411', 'score': 0.7446570992469788},
#    {'db_id': 'UMLS:C3266896', 'score': 0.7426552772521973},
#    {'db_id': 'UMLS:C1332323', 'score': 0.7344915270805359},
#    {'db_id': 'UMLS:C3269138', 'score': 0.7319819927215576}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0162638'}]},
#  {'offsets': [[623, 634]],
#   'text': 'nonylphenol',
#   'candidates': [{'db_id': 'UMLS:C0068946', 'score': 1.0},
#    {'db_id': 'UMLS:C0953814', 'score': 0.8478714227676392},
#    {'db_id': 'UMLS:C0953815', 'score': 0.8301727175712585},
#    {'db_id': 'UMLS:C0970196', 'score': 0.7795582413673401},
#    {'db_id': 'UMLS:C0097405', 'score': 0.767101526260376},
#    {'db_id': 'UMLS:C3857939', 'score': 0.757386326789856},
#    {'db_id': 'UMLS:C0953813', 'score': 0.7489328384399414},
#    {'db_id': 'UMLS:C4236359', 'score': 0.7475515604019165},
#    {'db_id': 'UMLS:C0132779', 'score': 0.7382228374481201}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0068946'}]},
#  {'offsets': [[648, 657]],
#   'text': 'decreased',
#   'candidates': [{'db_id': 'UMLS:C0205216', 'score': 1.0},
#    {'db_id': 'UMLS:C0392756', 'score': 1.0},
#    {'db_id': 'UMLS:C0442797', 'score': 1.0},
#    {'db_id': 'UMLS:C0728725', 'score': 0.874328076839447},
#    {'db_id': 'UMLS:C1168174', 'score': 0.8630114793777466},
#    {'db_id': 'UMLS:C0547047', 'score': 0.8619338870048523},
#    {'db_id': 'UMLS:C4528292', 'score': 0.8499547243118286},
#    {'db_id': 'UMLS:C0855389', 'score': 0.8431493043899536},
#    {'db_id': 'UMLS:C0855618', 'score': 0.8337022066116333},
#    {'db_id': 'UMLS:C0860941', 'score': 0.832693338394165},
#    {'db_id': 'UMLS:C0580413', 'score': 0.8301555514335632},
#    {'db_id': 'UMLS:C0860904', 'score': 0.8251616954803467},
#    {'db_id': 'UMLS:C0151934', 'score': 0.8227338194847107},
#    {'db_id': 'UMLS:C0042798', 'score': 0.8145045042037964},
#    {'db_id': 'UMLS:C0558171', 'score': 0.8145045042037964},
#    {'db_id': 'UMLS:C3665347', 'score': 0.8145045042037964},
#    {'db_id': 'UMLS:C4553853', 'score': 0.8145045042037964},
#    {'db_id': 'UMLS:C0240174', 'score': 0.8134526610374451},
#    {'db_id': 'UMLS:C4528289', 'score': 0.8081247806549072},
#    {'db_id': 'UMLS:C3808947', 'score': 0.8066015243530273},
#    {'db_id': 'UMLS:C4229022', 'score': 0.8056118488311768},
#    {'db_id': 'UMLS:C1295689', 'score': 0.7989278435707092},
#    {'db_id': 'UMLS:C0239150', 'score': 0.7986975908279419},
#    {'db_id': 'UMLS:C0231299', 'score': 0.7983161211013794}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0205216'}]},
#  {'offsets': [[658, 675]],
#   'text': 'DNA fragmentation',
#   'candidates': [{'db_id': 'UMLS:C0376669', 'score': 1.0},
#    {'db_id': 'UMLS:C4525777', 'score': 0.8683043718338013},
#    {'db_id': 'UMLS:C3822536', 'score': 0.8623250126838684},
#    {'db_id': 'UMLS:C0332472', 'score': 0.8478021621704102},
#    {'db_id': 'UMLS:C1547179', 'score': 0.8478021621704102},
#    {'db_id': 'UMLS:C1881708', 'score': 0.8478021621704102},
#    {'db_id': 'UMLS:C0684192', 'score': 0.8248363137245178},
#    {'db_id': 'UMLS:C0663605', 'score': 0.7994222640991211},
#    {'db_id': 'UMLS:C1749515', 'score': 0.7953270673751831},
#    {'db_id': 'UMLS:C0538150', 'score': 0.7647331953048706},
#    {'db_id': 'UMLS:C0185061', 'score': 0.7503781914710999},
#    {'db_id': 'UMLS:C3822534', 'score': 0.7387821674346924},
#    {'db_id': 'UMLS:C3822543', 'score': 0.7339321970939636},
#    {'db_id': 'UMLS:C3822542', 'score': 0.7151556611061096},
#    {'db_id': 'UMLS:C1505243', 'score': 0.7149497866630554},
#    {'db_id': 'UMLS:C0341444', 'score': 0.7048500180244446},
#    {'db_id': 'UMLS:C1413983', 'score': 0.703233540058136},
#    {'db_id': 'UMLS:C1504769', 'score': 0.703233540058136}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0376669'}]},
#  {'offsets': [[686, 695]],
#   'text': 'apoptosis',
#   'candidates': [{'db_id': 'UMLS:C0162638', 'score': 1.0},
#    {'db_id': 'UMLS:C4759886', 'score': 1.0},
#    {'db_id': 'UMLS:C2247960', 'score': 0.8234089016914368},
#    {'db_id': 'UMLS:C1326202', 'score': 0.8038336038589478},
#    {'db_id': 'UMLS:C1332322', 'score': 0.7967405319213867},
#    {'db_id': 'UMLS:C1660771', 'score': 0.7909232378005981},
#    {'db_id': 'UMLS:C2610891', 'score': 0.7842937111854553},
#    {'db_id': 'UMLS:C4329354', 'score': 0.7827578186988831},
#    {'db_id': 'UMLS:C1326205', 'score': 0.7727738618850708},
#    {'db_id': 'UMLS:C1454645', 'score': 0.7598106861114502},
#    {'db_id': 'UMLS:C1539477', 'score': 0.7598106861114502},
#    {'db_id': 'UMLS:C1564881', 'score': 0.7557398080825806},
#    {'db_id': 'UMLS:C1148568', 'score': 0.7536895275115967},
#    {'db_id': 'UMLS:C4233500', 'score': 0.7531155943870544},
#    {'db_id': 'UMLS:C3269144', 'score': 0.7494465708732605},
#    {'db_id': 'UMLS:C2246411', 'score': 0.7446570992469788},
#    {'db_id': 'UMLS:C3266896', 'score': 0.7426552772521973},
#    {'db_id': 'UMLS:C1332323', 'score': 0.7344915270805359},
#    {'db_id': 'UMLS:C3269138', 'score': 0.7319819927215576}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C4759886'}]},
#  {'offsets': [[699, 709]],
#   'text': 'PC12 cells',
#   'candidates': [{'db_id': 'UMLS:C0085262', 'score': 1.0}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0085262'}]},
#  {'offsets': [[716, 726]],
#   'text': 'phenomenon',
#   'candidates': [{'db_id': 'UMLS:C1882365', 'score': 1.0},
#    {'db_id': 'UMLS:C0278216', 'score': 0.8370029926300049},
#    {'db_id': 'UMLS:C0853404', 'score': 0.8316740989685059},
#    {'db_id': 'UMLS:C2350474', 'score': 0.8202959299087524},
#    {'db_id': 'UMLS:C0852903', 'score': 0.8083322644233704},
#    {'db_id': 'UMLS:C0597237', 'score': 0.8017328381538391},
#    {'db_id': 'UMLS:C2350446', 'score': 0.8017328381538391},
#    {'db_id': 'UMLS:C2350469', 'score': 0.7973833680152893},
#    {'db_id': 'UMLS:C0003907', 'score': 0.7908133268356323},
#    {'db_id': 'UMLS:C2350457', 'score': 0.7844362258911133},
#    {'db_id': 'UMLS:C1532656', 'score': 0.7840670347213745},
#    {'db_id': 'UMLS:C0042795', 'score': 0.7757086157798767},
#    {'db_id': 'UMLS:C1254366', 'score': 0.7739800214767456},
#    {'db_id': 'UMLS:C0233782', 'score': 0.7686787843704224},
#    {'db_id': 'UMLS:C1882532', 'score': 0.7685529589653015},
#    {'db_id': 'UMLS:C0457405', 'score': 0.7676153779029846},
#    {'db_id': 'UMLS:C2350444', 'score': 0.7663942575454712},
#    {'db_id': 'UMLS:C2350543', 'score': 0.7566008567810059},
#    {'db_id': 'UMLS:C0334147', 'score': 0.7540820837020874},
#    {'db_id': 'UMLS:C0005520', 'score': 0.7522609233856201}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C1882365'}]},
#  {'offsets': [[747, 755]],
#   'text': 'treating',
#   'candidates': [{'db_id': 'UMLS:C1522326', 'score': 1.0},
#    {'db_id': 'UMLS:C2985688', 'score': 0.7738416194915771}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C1522326'}]},
#  {'offsets': [[756, 765]],
#   'text': 'apoptotic',
#   'candidates': [{'db_id': 'UMLS:C1516044', 'score': 1.0},
#    {'db_id': 'UMLS:C3269134', 'score': 0.8495911359786987},
#    {'db_id': 'UMLS:C0162638', 'score': 0.8021917939186096},
#    {'db_id': 'UMLS:C4331984', 'score': 0.8001664876937866},
#    {'db_id': 'UMLS:C1159821', 'score': 0.7703478336334229},
#    {'db_id': 'UMLS:C2986514', 'score': 0.7681089043617249},
#    {'db_id': 'UMLS:C1836846', 'score': 0.7600083351135254},
#    {'db_id': 'UMLS:C4234958', 'score': 0.7535989284515381},
#    {'db_id': 'UMLS:C2751835', 'score': 0.7304294109344482},
#    {'db_id': 'UMLS:C4231137', 'score': 0.714859127998352},
#    {'db_id': 'UMLS:C1523908', 'score': 0.7009235620498657}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C1516044'}]},
#  {'offsets': [[766, 776]],
#   'text': 'PC12 cells',
#   'candidates': [{'db_id': 'UMLS:C0085262', 'score': 1.0}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0085262'}]},
#  {'offsets': [[782, 806]],
#   'text': 'nonylphenol diethoxylate',
#   'candidates': [{'db_id': 'UMLS:C0132779', 'score': 0.8804130554199219},
#    {'db_id': 'UMLS:C0604118', 'score': 0.726760983467102},
#    {'db_id': 'UMLS:C0068946', 'score': 0.7034839391708374}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0132779'}]},
#  {'offsets': [[820, 832]],
#   'text': 'cytochrome c',
#   'candidates': [{'db_id': 'UMLS:C0010749', 'score': 1.0},
#    {'db_id': 'UMLS:C1153524', 'score': 1.0},
#    {'db_id': 'UMLS:C1426584', 'score': 1.0},
#    {'db_id': 'UMLS:C4318401', 'score': 1.0},
#    {'db_id': 'UMLS:C0010755', 'score': 0.965541422367096},
#    {'db_id': 'UMLS:C0056953', 'score': 0.9545375108718872},
#    {'db_id': 'UMLS:C0010798', 'score': 0.9255191683769226},
#    {'db_id': 'UMLS:C1325304', 'score': 0.9255191683769226},
#    {'db_id': 'UMLS:C0056946', 'score': 0.8928513526916504},
#    {'db_id': 'UMLS:C0056918', 'score': 0.8685439229011536},
#    {'db_id': 'UMLS:C1153528', 'score': 0.8685439229011536},
#    {'db_id': 'UMLS:C0010744', 'score': 0.8621929883956909},
#    {'db_id': 'UMLS:C0111799', 'score': 0.8510327935218811},
#    {'db_id': 'UMLS:C0215247', 'score': 0.8477939367294312},
#    {'db_id': 'UMLS:C0056960', 'score': 0.8392401337623596},
#    {'db_id': 'UMLS:C0056919', 'score': 0.8377947211265564},
#    {'db_id': 'UMLS:C0284507', 'score': 0.8337011933326721},
#    {'db_id': 'UMLS:C0056951', 'score': 0.8332878947257996},
#    {'db_id': 'UMLS:C0056961', 'score': 0.8249294757843018},
#    {'db_id': 'UMLS:C1621805', 'score': 0.8249294757843018},
#    {'db_id': 'UMLS:C0526110', 'score': 0.8240941762924194},
#    {'db_id': 'UMLS:C0010754', 'score': 0.8236024379730225},
#    {'db_id': 'UMLS:C3894813', 'score': 0.8221146464347839},
#    {'db_id': 'UMLS:C0010746', 'score': 0.8163187503814697},
#    {'db_id': 'UMLS:C0056944', 'score': 0.8150079846382141}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0010749'}]},
#  {'offsets': [[850, 857]],
#   'text': 'cytosol',
#   'candidates': [{'db_id': 'UMLS:C1383501', 'score': 1.0},
#    {'db_id': 'UMLS:C2752457', 'score': 0.8229812383651733},
#    {'db_id': 'UMLS:C4236623', 'score': 0.7813878059387207},
#    {'db_id': 'UMLS:C2328803', 'score': 0.7543310523033142},
#    {'db_id': 'UMLS:C2328628', 'score': 0.7269684076309204},
#    {'db_id': 'UMLS:C0230695', 'score': 0.7092211246490479},
#    {'db_id': 'UMLS:C2338345', 'score': 0.7046694159507751},
#    {'db_id': 'UMLS:C1820051', 'score': 0.7034279108047485},
#    {'db_id': 'UMLS:C1183509', 'score': 0.700153648853302}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C1383501'}]},
#  {'offsets': [[858, 867]],
#   'text': 'decreased',
#   'candidates': [{'db_id': 'UMLS:C0205216', 'score': 1.0},
#    {'db_id': 'UMLS:C0392756', 'score': 1.0},
#    {'db_id': 'UMLS:C0442797', 'score': 1.0},
#    {'db_id': 'UMLS:C0728725', 'score': 0.874328076839447},
#    {'db_id': 'UMLS:C1168174', 'score': 0.8630114793777466},
#    {'db_id': 'UMLS:C0547047', 'score': 0.8619338870048523},
#    {'db_id': 'UMLS:C4528292', 'score': 0.8499547243118286},
#    {'db_id': 'UMLS:C0855389', 'score': 0.8431493043899536},
#    {'db_id': 'UMLS:C0855618', 'score': 0.8337022066116333},
#    {'db_id': 'UMLS:C0860941', 'score': 0.832693338394165},
#    {'db_id': 'UMLS:C0580413', 'score': 0.8301555514335632},
#    {'db_id': 'UMLS:C0860904', 'score': 0.8251616954803467},
#    {'db_id': 'UMLS:C0151934', 'score': 0.8227338194847107},
#    {'db_id': 'UMLS:C0042798', 'score': 0.8145045042037964},
#    {'db_id': 'UMLS:C0558171', 'score': 0.8145045042037964},
#    {'db_id': 'UMLS:C3665347', 'score': 0.8145045042037964},
#    {'db_id': 'UMLS:C4553853', 'score': 0.8145045042037964},
#    {'db_id': 'UMLS:C0240174', 'score': 0.8134526610374451},
#    {'db_id': 'UMLS:C4528289', 'score': 0.8081247806549072},
#    {'db_id': 'UMLS:C3808947', 'score': 0.8066015243530273},
#    {'db_id': 'UMLS:C4229022', 'score': 0.8056118488311768},
#    {'db_id': 'UMLS:C1295689', 'score': 0.7989278435707092},
#    {'db_id': 'UMLS:C0239150', 'score': 0.7986975908279419},
#    {'db_id': 'UMLS:C0231299', 'score': 0.7983161211013794}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0442797'}]},
#  {'offsets': [[891, 906]],
#   'text': 'apoptotic cells',
#   'candidates': [{'db_id': 'UMLS:C1516044', 'score': 0.7900826930999756},
#    {'db_id': 'UMLS:C0162638', 'score': 0.7187338471412659},
#    {'db_id': 'UMLS:C1326202', 'score': 0.7120977640151978}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C1516044'}]},
#  {'offsets': [[911, 923]],
#   'text': 'treated with',
#   'candidates': [{'db_id': 'UMLS:C0332293', 'score': 0.9999999403953552},
#    {'db_id': 'UMLS:C1522326', 'score': 0.9999999403953552}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C1522326'}]},
#  {'offsets': [[924, 948]],
#   'text': 'nonylphenol diethoxylate',
#   'candidates': [{'db_id': 'UMLS:C0132779', 'score': 0.8804130554199219},
#    {'db_id': 'UMLS:C0604118', 'score': 0.726760983467102},
#    {'db_id': 'UMLS:C0068946', 'score': 0.7034839391708374}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0132779'}]},
#  {'offsets': [[965, 968]],
#   'text': 'Bax',
#   'candidates': [{'db_id': 'UMLS:C0219474', 'score': 1.0},
#    {'db_id': 'UMLS:C0812198', 'score': 1.0},
#    {'db_id': 'UMLS:C1221086', 'score': 0.7818325161933899},
#    {'db_id': 'UMLS:C1047341', 'score': 0.7652437090873718},
#    {'db_id': 'UMLS:C1231045', 'score': 0.7199282050132751},
#    {'db_id': 'UMLS:C2918586', 'score': 0.7179879546165466}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0219474'}]},
#  {'offsets': [[969, 977]],
#   'text': 'contents',
#   'candidates': [{'db_id': 'UMLS:C0456205', 'score': 1.0},
#    {'db_id': 'UMLS:C1552853', 'score': 1.0},
#    {'db_id': 'UMLS:C0017177', 'score': 0.7861839532852173},
#    {'db_id': 'UMLS:C0426397', 'score': 0.7833443284034729},
#    {'db_id': 'UMLS:C0227406', 'score': 0.7750446796417236},
#    {'db_id': 'UMLS:C1300583', 'score': 0.7715583443641663},
#    {'db_id': 'UMLS:C0227363', 'score': 0.7628078460693359},
#    {'db_id': 'UMLS:C1300584', 'score': 0.7622144222259521},
#    {'db_id': 'UMLS:C0423896', 'score': 0.748690128326416},
#    {'db_id': 'UMLS:C1550605', 'score': 0.748690128326416},
#    {'db_id': 'UMLS:C0226893', 'score': 0.7479473352432251},
#    {'db_id': 'UMLS:C0426723', 'score': 0.7402256727218628},
#    {'db_id': 'UMLS:C1285529', 'score': 0.7392043471336365},
#    {'db_id': 'UMLS:C0038352', 'score': 0.7379180192947388},
#    {'db_id': 'UMLS:C1135899', 'score': 0.7340301275253296},
#    {'db_id': 'UMLS:C0227245', 'score': 0.7153414487838745},
#    {'db_id': 'UMLS:C1285982', 'score': 0.7096526622772217}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0456205'}]},
#  {'offsets': [[981, 996]],
#   'text': 'apoptotic cells',
#   'candidates': [{'db_id': 'UMLS:C1516044', 'score': 0.7900826930999756},
#    {'db_id': 'UMLS:C0162638', 'score': 0.7187338471412659},
#    {'db_id': 'UMLS:C1326202', 'score': 0.7120977640151978}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C1516044'}]},
#  {'offsets': [[1002, 1009]],
#   'text': 'reduced',
#   'candidates': [{'db_id': 'UMLS:C0392756', 'score': 1.0},
#    {'db_id': 'UMLS:C0240291', 'score': 0.8951568007469177},
#    {'db_id': 'UMLS:C0728725', 'score': 0.8460635542869568},
#    {'db_id': 'UMLS:C0206008', 'score': 0.842868983745575},
#    {'db_id': 'UMLS:C1707814', 'score': 0.8184823393821716},
#    {'db_id': 'UMLS:C0853711', 'score': 0.7902964353561401},
#    {'db_id': 'UMLS:C0302583', 'score': 0.7849313616752625},
#    {'db_id': 'UMLS:C0042798', 'score': 0.7776346206665039},
#    {'db_id': 'UMLS:C0012167', 'score': 0.7621821165084839},
#    {'db_id': 'UMLS:C1855768', 'score': 0.7527686953544617},
#    {'db_id': 'UMLS:C1839025', 'score': 0.7523694038391113},
#    {'db_id': 'UMLS:C0018772', 'score': 0.7447023391723633},
#    {'db_id': 'UMLS:C1384666', 'score': 0.7447023391723633},
#    {'db_id': 'UMLS:C0018966', 'score': 0.7384268641471863},
#    {'db_id': 'UMLS:C4732780', 'score': 0.7348847985267639},
#    {'db_id': 'UMLS:C0404533', 'score': 0.7318421006202698},
#    {'db_id': 'UMLS:C2675900', 'score': 0.7261030077934265},
#    {'db_id': 'UMLS:C4726018', 'score': 0.7247804999351501},
#    {'db_id': 'UMLS:C4331236', 'score': 0.7197192311286926},
#    {'db_id': 'UMLS:C0744727', 'score': 0.7161843180656433},
#    {'db_id': 'UMLS:C5205676', 'score': 0.7032947540283203},
#    {'db_id': 'UMLS:C4230744', 'score': 0.700935423374176}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0392756'}]},
#  {'offsets': [[1016, 1027]],
#   'text': 'exposure to',
#   'candidates': [{'db_id': 'UMLS:C0332157', 'score': 1.0},
#    {'db_id': 'UMLS:C0274281', 'score': 0.9262424111366272},
#    {'db_id': 'UMLS:C0728853', 'score': 0.9262424111366272},
#    {'db_id': 'UMLS:C1704625', 'score': 0.9262424111366272},
#    {'db_id': 'UMLS:C0239930', 'score': 0.858124852180481},
#    {'db_id': 'UMLS:C1689916', 'score': 0.852121889591217},
#    {'db_id': 'UMLS:C2220426', 'score': 0.8500612378120422},
#    {'db_id': 'UMLS:C2362603', 'score': 0.8452452421188354},
#    {'db_id': 'UMLS:C0149666', 'score': 0.8389102220535278},
#    {'db_id': 'UMLS:C0040537', 'score': 0.8381475210189819},
#    {'db_id': 'UMLS:C0681792', 'score': 0.8290051221847534},
#    {'db_id': 'UMLS:C4520513', 'score': 0.8261807560920715},
#    {'db_id': 'UMLS:C0238908', 'score': 0.8222136497497559},
#    {'db_id': 'UMLS:C0700522', 'score': 0.8185310959815979},
#    {'db_id': 'UMLS:C2732915', 'score': 0.8179871439933777},
#    {'db_id': 'UMLS:C0261749', 'score': 0.8137821555137634},
#    {'db_id': 'UMLS:C0240062', 'score': 0.8056401014328003},
#    {'db_id': 'UMLS:C4316579', 'score': 0.8046712279319763},
#    {'db_id': 'UMLS:C2732914', 'score': 0.8037437796592712},
#    {'db_id': 'UMLS:C4048187', 'score': 0.8030974864959717},
#    {'db_id': 'UMLS:C0015333', 'score': 0.8007833957672119},
#    {'db_id': 'UMLS:C2826651', 'score': 0.7996249794960022},
#    {'db_id': 'UMLS:C0240323', 'score': 0.7903090119361877}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0332157'}]},
#  {'offsets': [[1028, 1052]],
#   'text': 'nonylphenol diethoxylate',
#   'candidates': [{'db_id': 'UMLS:C0132779', 'score': 0.8804130554199219},
#    {'db_id': 'UMLS:C0604118', 'score': 0.726760983467102},
#    {'db_id': 'UMLS:C0068946', 'score': 0.7034839391708374}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0132779'}]},
#  {'offsets': [[1060, 1084]],
#   'text': 'nonylphenol diethoxylate',
#   'candidates': [{'db_id': 'UMLS:C0132779', 'score': 0.8804130554199219},
#    {'db_id': 'UMLS:C0604118', 'score': 0.726760983467102},
#    {'db_id': 'UMLS:C0068946', 'score': 0.7034839391708374}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0132779'}]},
#  {'offsets': [[1102, 1108]],
#   'text': 'effect',
#   'candidates': [{'db_id': 'UMLS:C1280500', 'score': 1.0},
#    {'db_id': 'UMLS:C1518681', 'score': 1.0},
#    {'db_id': 'UMLS:C2348382', 'score': 1.0},
#    {'db_id': 'UMLS:C1301751', 'score': 0.9179566502571106},
#    {'db_id': 'UMLS:C2945677', 'score': 0.8937566876411438},
#    {'db_id': 'UMLS:C2362743', 'score': 0.8869321942329407},
#    {'db_id': 'UMLS:C1883473', 'score': 0.8800250291824341},
#    {'db_id': 'UMLS:C0543419', 'score': 0.8738999366760254},
#    {'db_id': 'UMLS:C1368999', 'score': 0.8738999366760254},
#    {'db_id': 'UMLS:C0879626', 'score': 0.8347170352935791},
#    {'db_id': 'UMLS:C4543203', 'score': 0.8290087580680847},
#    {'db_id': 'UMLS:C4722001', 'score': 0.8290087580680847},
#    {'db_id': 'UMLS:C0161734', 'score': 0.8286240100860596},
#    {'db_id': 'UMLS:C0221500', 'score': 0.821723461151123},
#    {'db_id': 'UMLS:C4086564', 'score': 0.8180662393569946},
#    {'db_id': 'UMLS:C0872206', 'score': 0.8146888613700867},
#    {'db_id': 'UMLS:C1567089', 'score': 0.8099912405014038},
#    {'db_id': 'UMLS:C1280519', 'score': 0.8016491532325745},
#    {'db_id': 'UMLS:C1704419', 'score': 0.8016491532325745},
#    {'db_id': 'UMLS:C5205845', 'score': 0.7933931350708008},
#    {'db_id': 'UMLS:C3274396', 'score': 0.7895260453224182},
#    {'db_id': 'UMLS:C3178735', 'score': 0.7864585518836975},
#    {'db_id': 'UMLS:C4277541', 'score': 0.7834433913230896},
#    {'db_id': 'UMLS:C1319171', 'score': 0.7831936478614807}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C2348382'}]},
#  {'offsets': [[1112, 1121]],
#   'text': 'apoptosis',
#   'candidates': [{'db_id': 'UMLS:C0162638', 'score': 1.0},
#    {'db_id': 'UMLS:C4759886', 'score': 1.0},
#    {'db_id': 'UMLS:C2247960', 'score': 0.8234089016914368},
# ...
#    {'db_id': 'UMLS:C3269144', 'score': 0.7494465708732605},
#    {'db_id': 'UMLS:C2246411', 'score': 0.7446570992469788},
#    {'db_id': 'UMLS:C3266896', 'score': 0.7426552772521973},
#    {'db_id': 'UMLS:C1332323', 'score': 0.7344915270805359},
#    {'db_id': 'UMLS:C3269138', 'score': 0.7319819927215576}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0162638'}]},
#  {'offsets': [[1186, 1193]],
#   'text': 'induced',
#   'candidates': [{'db_id': 'UMLS:C0205263', 'score': 1.0},
#    {'db_id': 'UMLS:C3898767', 'score': 0.7984579205513},
#    {'db_id': 'UMLS:C1707707', 'score': 0.7826897501945496},
#    {'db_id': 'UMLS:C0153122', 'score': 0.7563474178314209},
#    {'db_id': 'UMLS:C1428046', 'score': 0.7431603074073792},
#    {'db_id': 'UMLS:C1512710', 'score': 0.741400957107544},
#    {'db_id': 'UMLS:C0858744', 'score': 0.7410463690757751},
#    {'db_id': 'UMLS:C0235661', 'score': 0.7390875816345215},
#    {'db_id': 'UMLS:C0458082', 'score': 0.738723874092102},
#    {'db_id': 'UMLS:C0022875', 'score': 0.7339017987251282},
#    {'db_id': 'UMLS:C0259787', 'score': 0.7339017987251282},
#    {'db_id': 'UMLS:C1708502', 'score': 0.7186915874481201},
#    {'db_id': 'UMLS:C0269439', 'score': 0.7103714346885681},
#    {'db_id': 'UMLS:C0392535', 'score': 0.7103714346885681},
#    {'db_id': 'UMLS:C1704300', 'score': 0.7103714346885681},
#    {'db_id': 'UMLS:C2985288', 'score': 0.7042877078056335},
#    {'db_id': 'UMLS:C1427643', 'score': 0.7007309794425964}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0205263'}]},
#  {'offsets': [[1197, 1214]],
#   'text': 'serum deprivation',
#   'candidates': [{'db_id': 'UMLS:C0871712', 'score': 0.833910346031189},
#    {'db_id': 'UMLS:C0599620', 'score': 0.7079419493675232}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0871712'}]},
#  {'offsets': [[1234, 1243]],
#   'text': 'structure',
#   'candidates': [{'db_id': 'UMLS:C0678594', 'score': 1.0},
#    {'db_id': 'UMLS:C0003461', 'score': 0.870040774345398},
#    {'db_id': 'UMLS:C0220805', 'score': 0.8584968447685242},
#    {'db_id': 'UMLS:C1517495', 'score': 0.8573675155639648},
#    {'db_id': 'UMLS:C0262950', 'score': 0.8507021069526672},
#    {'db_id': 'UMLS:C0018563', 'score': 0.8341522216796875},
#    {'db_id': 'UMLS:C3714557', 'score': 0.8341522216796875},
#    {'db_id': 'UMLS:C1827394', 'score': 0.8337031602859497},
#    {'db_id': 'UMLS:C0230942', 'score': 0.8326903581619263},
#    {'db_id': 'UMLS:C0034896', 'score': 0.831636905670166},
#    {'db_id': 'UMLS:C0086582', 'score': 0.8310412764549255},
#    {'db_id': 'UMLS:C0008114', 'score': 0.830575168132782},
#    {'db_id': 'UMLS:C0458563', 'score': 0.8300964832305908},
#    {'db_id': 'UMLS:C0013443', 'score': 0.829653263092041},
#    {'db_id': 'UMLS:C0015450', 'score': 0.8289763927459717},
#    {'db_id': 'UMLS:C0009368', 'score': 0.8251320123672485},
#    {'db_id': 'UMLS:C0043189', 'score': 0.8242087364196777}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0678594'}]},
#  {'offsets': [[1255, 1264]],
#   'text': 'compounds',
#   'candidates': [{'db_id': 'UMLS:C0010124', 'score': 0.9376974105834961},
#    {'db_id': 'UMLS:C0206446', 'score': 0.9222623705863953},
#    {'db_id': 'UMLS:C0002362', 'score': 0.8796977996826172},
#    {'db_id': 'UMLS:C0684279', 'score': 0.8591695427894592},
#    {'db_id': 'UMLS:C0303399', 'score': 0.8586146235466003},
#    {'db_id': 'UMLS:C0006031', 'score': 0.8556841015815735},
#    {'db_id': 'UMLS:C0303231', 'score': 0.8551028966903687},
#    {'db_id': 'UMLS:C0029036', 'score': 0.853862464427948},
#    {'db_id': 'UMLS:C0206105', 'score': 0.8471705913543701},
#    {'db_id': 'UMLS:C0003645', 'score': 0.8408780694007874},
#    {'db_id': 'UMLS:C0303186', 'score': 0.8379759788513184},
#    {'db_id': 'UMLS:C0007011', 'score': 0.8362987637519836},
#    {'db_id': 'UMLS:C0206445', 'score': 0.8338714838027954},
#    {'db_id': 'UMLS:C0032902', 'score': 0.8313434720039368},
#    {'db_id': 'UMLS:C0206102', 'score': 0.8306189179420471},
#    {'db_id': 'UMLS:C0206134', 'score': 0.8293891549110413},
#    {'db_id': 'UMLS:C3536918', 'score': 0.8293891549110413},
#    {'db_id': 'UMLS:C3825234', 'score': 0.8280723690986633},
#    {'db_id': 'UMLS:C0003038', 'score': 0.8230788111686707},
#    {'db_id': 'UMLS:C0029224', 'score': 0.8219588398933411},
#    {'db_id': 'UMLS:C0040493', 'score': 0.817894697189331}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0010124'}]},
#  {'offsets': [[1308, 1318]],
#   'text': 'phenomenon',
#   'candidates': [{'db_id': 'UMLS:C1882365', 'score': 1.0},
#    {'db_id': 'UMLS:C0278216', 'score': 0.8370029926300049},
#    {'db_id': 'UMLS:C0853404', 'score': 0.8316740989685059},
#    {'db_id': 'UMLS:C2350474', 'score': 0.8202959299087524},
#    {'db_id': 'UMLS:C0852903', 'score': 0.8083322644233704},
#    {'db_id': 'UMLS:C0597237', 'score': 0.8017328381538391},
#    {'db_id': 'UMLS:C2350446', 'score': 0.8017328381538391},
#    {'db_id': 'UMLS:C2350469', 'score': 0.7973833680152893},
#    {'db_id': 'UMLS:C0003907', 'score': 0.7908133268356323},
#    {'db_id': 'UMLS:C2350457', 'score': 0.7844362258911133},
#    {'db_id': 'UMLS:C1532656', 'score': 0.7840670347213745},
#    {'db_id': 'UMLS:C0042795', 'score': 0.7757086157798767},
#    {'db_id': 'UMLS:C1254366', 'score': 0.7739800214767456},
#    {'db_id': 'UMLS:C0233782', 'score': 0.7686787843704224},
#    {'db_id': 'UMLS:C1882532', 'score': 0.7685529589653015},
#    {'db_id': 'UMLS:C0457405', 'score': 0.7676153779029846},
#    {'db_id': 'UMLS:C2350444', 'score': 0.7663942575454712},
#    {'db_id': 'UMLS:C2350543', 'score': 0.7566008567810059},
#    {'db_id': 'UMLS:C0334147', 'score': 0.7540820837020874},
#    {'db_id': 'UMLS:C0005520', 'score': 0.7522609233856201}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C1882365'}]},
#  {'offsets': [[1326, 1333]],
#   'text': 'results',
#   'candidates': [{'db_id': 'UMLS:C0456984', 'score': 0.8586957454681396},
#    {'db_id': 'UMLS:C3244125', 'score': 0.8375580310821533},
#    {'db_id': 'UMLS:C0428323', 'score': 0.8352590799331665},
#    {'db_id': 'UMLS:C1827234', 'score': 0.8333916068077087},
#    {'db_id': 'UMLS:C0459422', 'score': 0.8211048245429993},
#    {'db_id': 'UMLS:C4684761', 'score': 0.8177402019500732},
#    {'db_id': 'UMLS:C1548163', 'score': 0.8075570464134216},
#    {'db_id': 'UMLS:C4704700', 'score': 0.8002589344978333},
#    {'db_id': 'UMLS:C1548201', 'score': 0.7956295013427734},
#    {'db_id': 'UMLS:C0850567', 'score': 0.7895456552505493},
#    {'db_id': 'UMLS:C3897271', 'score': 0.7778463959693909},
#    {'db_id': 'UMLS:C0429339', 'score': 0.7746437191963196},
#    {'db_id': 'UMLS:C0683954', 'score': 0.7742103934288025},
#    {'db_id': 'UMLS:C1881460', 'score': 0.7720661163330078},
#    {'db_id': 'UMLS:C1549566', 'score': 0.763214111328125},
#    {'db_id': 'UMLS:C0851020', 'score': 0.7520100474357605},
#    {'db_id': 'UMLS:C0849541', 'score': 0.7506641745567322},
#    {'db_id': 'UMLS:C1556077', 'score': 0.7475569844245911},
#    {'db_id': 'UMLS:C3897272', 'score': 0.7360531687736511},
#    {'db_id': 'UMLS:C0459424', 'score': 0.7331796288490295},
#    {'db_id': 'UMLS:C4684762', 'score': 0.7278311252593994},
#    {'db_id': 'UMLS:C3858831', 'score': 0.7268150448799133},
#    {'db_id': 'UMLS:C0042284', 'score': 0.7259818315505981},
#    {'db_id': 'UMLS:C1881051', 'score': 0.725926399230957}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0456984'}]},
#  {'offsets': [[1349, 1373]],
#   'text': 'nonylphenol diethoxylate',
#   'candidates': [{'db_id': 'UMLS:C0132779', 'score': 0.8804130554199219},
#    {'db_id': 'UMLS:C0604118', 'score': 0.726760983467102},
#    {'db_id': 'UMLS:C0068946', 'score': 0.7034839391708374}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0132779'}]},
#  {'offsets': [[1378, 1388]],
#   'text': 'capability',
#   'candidates': [{'db_id': 'UMLS:C2698977', 'score': 1.0}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C2698977'}]},
#  {'offsets': [[1399, 1419]],
#   'text': 'cell differentiation',
#   'candidates': [{'db_id': 'UMLS:C0007589', 'score': 1.0},
#    {'db_id': 'UMLS:C1511002', 'score': 0.9546904563903809},
#    {'db_id': 'UMLS:C1155013', 'score': 0.9367268085479736},
#    {'db_id': 'UMLS:C1523325', 'score': 0.9155001044273376},
#    {'db_id': 'UMLS:C2753148', 'score': 0.9118021726608276},
#    {'db_id': 'UMLS:C1159884', 'score': 0.9075972437858582},
#    {'db_id': 'UMLS:C0598087', 'score': 0.9063172340393066},
#    {'db_id': 'UMLS:C2610521', 'score': 0.8996106386184692},
#    {'db_id': 'UMLS:C1753058', 'score': 0.8972442746162415},
#    {'db_id': 'UMLS:C1511938', 'score': 0.8948544263839722},
#    {'db_id': 'UMLS:C2945687', 'score': 0.8948544263839722},
#    {'db_id': 'UMLS:C1326073', 'score': 0.8918853998184204},
#    {'db_id': 'UMLS:C1879542', 'score': 0.8916720747947693},
#    {'db_id': 'UMLS:C2752710', 'score': 0.887440025806427},
#    {'db_id': 'UMLS:C1326079', 'score': 0.8871363401412964},
#    {'db_id': 'UMLS:C2611086', 'score': 0.8871362209320068},
#    {'db_id': 'UMLS:C3271473', 'score': 0.884972095489502},
#    {'db_id': 'UMLS:C2755079', 'score': 0.8847876787185669},
#    {'db_id': 'UMLS:C2247990', 'score': 0.882519543170929}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0007589'}]},
#  {'offsets': [[1424, 1435]],
#   'text': 'development',
#   'candidates': [{'db_id': 'UMLS:C0243107', 'score': 1.0},
#    {'db_id': 'UMLS:C0678723', 'score': 1.0},
#    {'db_id': 'UMLS:C1527148', 'score': 1.0},
#    {'db_id': 'UMLS:C3272564', 'score': 1.0},
#    {'db_id': 'UMLS:C4521286', 'score': 1.0},
#    {'db_id': 'UMLS:C3151684', 'score': 0.9416382908821106},
#    {'db_id': 'UMLS:C2755041', 'score': 0.9281438589096069},
#    {'db_id': 'UMLS:C2246747', 'score': 0.9194554686546326},
#    {'db_id': 'UMLS:C0005939', 'score': 0.9063472747802734},
#    {'db_id': 'UMLS:C0458003', 'score': 0.905533492565155},
#    {'db_id': 'UMLS:C0599735', 'score': 0.9012060761451721},
#    {'db_id': 'UMLS:C1657984', 'score': 0.895642101764679},
#    {'db_id': 'UMLS:C0011435', 'score': 0.8910908699035645},
#    {'db_id': 'UMLS:C0028877', 'score': 0.8900448083877563},
#    {'db_id': 'UMLS:C1656421', 'score': 0.888776957988739},
#    {'db_id': 'UMLS:C0026527', 'score': 0.8886744976043701},
#    {'db_id': 'UMLS:C0815089', 'score': 0.8871542811393738},
#    {'db_id': 'UMLS:C2610452', 'score': 0.8870437741279602},
#    {'db_id': 'UMLS:C1817356', 'score': 0.886089026927948},
#    {'db_id': 'UMLS:C1331475', 'score': 0.8860425353050232},
#    {'db_id': 'UMLS:C0011751', 'score': 0.885952353477478},
#    {'db_id': 'UMLS:C2753561', 'score': 0.8854342103004456},
#    {'db_id': 'UMLS:C0597252', 'score': 0.8835964798927307}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C1527148'}]},
#  {'offsets': [[1464, 1470]],
#   'text': 'effect',
#   'candidates': [{'db_id': 'UMLS:C1280500', 'score': 1.0},
#    {'db_id': 'UMLS:C1518681', 'score': 1.0},
#    {'db_id': 'UMLS:C2348382', 'score': 1.0},
#    {'db_id': 'UMLS:C1301751', 'score': 0.9179566502571106},
#    {'db_id': 'UMLS:C2945677', 'score': 0.8937566876411438},
#    {'db_id': 'UMLS:C2362743', 'score': 0.8869321942329407},
#    {'db_id': 'UMLS:C1883473', 'score': 0.8800250291824341},
#    {'db_id': 'UMLS:C0543419', 'score': 0.8738999366760254},
#    {'db_id': 'UMLS:C1368999', 'score': 0.8738999366760254},
#    {'db_id': 'UMLS:C0879626', 'score': 0.8347170352935791},
#    {'db_id': 'UMLS:C4543203', 'score': 0.8290087580680847},
#    {'db_id': 'UMLS:C4722001', 'score': 0.8290087580680847},
#    {'db_id': 'UMLS:C0161734', 'score': 0.8286240100860596},
#    {'db_id': 'UMLS:C0221500', 'score': 0.821723461151123},
#    {'db_id': 'UMLS:C4086564', 'score': 0.8180662393569946},
#    {'db_id': 'UMLS:C0872206', 'score': 0.8146888613700867},
#    {'db_id': 'UMLS:C1567089', 'score': 0.8099912405014038},
#    {'db_id': 'UMLS:C1280519', 'score': 0.8016491532325745},
#    {'db_id': 'UMLS:C1704419', 'score': 0.8016491532325745},
#    {'db_id': 'UMLS:C5205845', 'score': 0.7933931350708008},
#    {'db_id': 'UMLS:C3274396', 'score': 0.7895260453224182},
#    {'db_id': 'UMLS:C3178735', 'score': 0.7864585518836975},
#    {'db_id': 'UMLS:C4277541', 'score': 0.7834433913230896},
#    {'db_id': 'UMLS:C1319171', 'score': 0.7831936478614807}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C2348382'}]},
#  {'offsets': [[1474, 1483]],
#   'text': 'organisms',
#   'candidates': [{'db_id': 'UMLS:C0029235', 'score': 0.9999998807907104},
#    {'db_id': 'UMLS:C1518032', 'score': 0.8452619314193726},
#    {'db_id': 'UMLS:C0599383', 'score': 0.8439635038375854},
#    {'db_id': 'UMLS:C0314735', 'score': 0.8263697624206543},
#    {'db_id': 'UMLS:C2347015', 'score': 0.8082912564277649},
#    {'db_id': 'UMLS:C0427964', 'score': 0.8073245882987976},
#    {'db_id': 'UMLS:C1318080', 'score': 0.8073245882987976},
#    {'db_id': 'UMLS:C2347159', 'score': 0.8006826639175415},
#    {'db_id': 'UMLS:C0445623', 'score': 0.8002191781997681},
#    {'db_id': 'UMLS:C0314734', 'score': 0.7824134230613708},
#    {'db_id': 'UMLS:C4277542', 'score': 0.7786311507225037},
#    {'db_id': 'UMLS:C2746012', 'score': 0.7692866325378418},
#    {'db_id': 'UMLS:C2936248', 'score': 0.7591969966888428},
#    {'db_id': 'UMLS:C0751338', 'score': 0.7552180886268616},
#    {'db_id': 'UMLS:C2348776', 'score': 0.7519285678863525},
#    {'db_id': 'UMLS:C0969756', 'score': 0.7517004013061523},
#    {'db_id': 'UMLS:C0002028', 'score': 0.7404270172119141},
#    {'db_id': 'UMLS:C3824831', 'score': 0.7382503151893616},
#    {'db_id': 'UMLS:C0596121', 'score': 0.7379470467567444},
#    {'db_id': 'UMLS:C0009054', 'score': 0.7303292155265808},
#    {'db_id': 'UMLS:C0450254', 'score': 0.7297879457473755}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0029235'}]},
#  {'offsets': [[1510, 1516]],
#   'text': 'impact',
#   'candidates': [{'db_id': 'UMLS:C0726639', 'score': 0.9999999403953552},
#    {'db_id': 'UMLS:C1825598', 'score': 0.9999999403953552},
#    {'db_id': 'UMLS:C4049986', 'score': 0.9999999403953552},
#    {'db_id': 'UMLS:C0040456', 'score': 0.8327757716178894},
#    {'db_id': 'UMLS:C0333124', 'score': 0.8327757716178894},
#    {'db_id': 'UMLS:C0333125', 'score': 0.8056636452674866},
#    {'db_id': 'UMLS:C0491921', 'score': 0.8006371259689331},
#    {'db_id': 'UMLS:C0341034', 'score': 0.779595136642456},
#    {'db_id': 'UMLS:C0626004', 'score': 0.7518665194511414},
#    {'db_id': 'UMLS:C0399550', 'score': 0.746463418006897},
#    {'db_id': 'UMLS:C0162468', 'score': 0.7461677193641663},
#    {'db_id': 'UMLS:C0391422', 'score': 0.7449589967727661},
#    {'db_id': 'UMLS:C0332714', 'score': 0.7444930076599121},
#    {'db_id': 'UMLS:C0626003', 'score': 0.7327052354812622},
#    {'db_id': 'UMLS:C0399551', 'score': 0.7221972346305847},
#    {'db_id': 'UMLS:C0021092', 'score': 0.7090995907783508},
#    {'db_id': 'UMLS:C1300130', 'score': 0.7029561996459961}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C4049986'}]},
#  {'offsets': [[1520, 1529]],
#   'text': 'apoptosis',
#   'candidates': [{'db_id': 'UMLS:C0162638', 'score': 1.0},
#    {'db_id': 'UMLS:C4759886', 'score': 1.0},
#    {'db_id': 'UMLS:C2247960', 'score': 0.8234089016914368},
#    {'db_id': 'UMLS:C1326202', 'score': 0.8038336038589478},
#    {'db_id': 'UMLS:C1332322', 'score': 0.7967405319213867},
#    {'db_id': 'UMLS:C1660771', 'score': 0.7909232378005981},
#    {'db_id': 'UMLS:C2610891', 'score': 0.7842937111854553},
#    {'db_id': 'UMLS:C4329354', 'score': 0.7827578186988831},
#    {'db_id': 'UMLS:C1326205', 'score': 0.7727738618850708},
#    {'db_id': 'UMLS:C1454645', 'score': 0.7598106861114502},
#    {'db_id': 'UMLS:C1539477', 'score': 0.7598106861114502},
#    {'db_id': 'UMLS:C1564881', 'score': 0.7557398080825806},
#    {'db_id': 'UMLS:C1148568', 'score': 0.7536895275115967},
#    {'db_id': 'UMLS:C4233500', 'score': 0.7531155943870544},
#    {'db_id': 'UMLS:C3269144', 'score': 0.7494465708732605},
#    {'db_id': 'UMLS:C2246411', 'score': 0.7446570992469788},
#    {'db_id': 'UMLS:C3266896', 'score': 0.7426552772521973},
#    {'db_id': 'UMLS:C1332323', 'score': 0.7344915270805359},
#    {'db_id': 'UMLS:C3269138', 'score': 0.7319819927215576}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C4759886'}]},
#  {'offsets': [[1562, 1577]],
#   'text': 'Environ Toxicol',
#   'candidates': [{'db_id': 'UMLS:C0563028', 'score': 0.7334117293357849},
#    {'db_id': 'UMLS:C0178621', 'score': 0.7156506180763245}],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'UMLS:C0563028'}]}]

# %%
p['gold_entities'][0]['normalized']
# Out:
# [{'db_name': 'UMLS', 'db_id': 'UMLS:C0162638'}]

# %%
PLANT_CATEGORIES = [
    'T096',  # Group
    'T002',  # Plant
]

DISEASE_CATEGORIES = [
    'T020',  # Acquired abnormality
    'T190',  # Anatomical abnormaility
    'T049',  # Cell or Molecular dysfunction
    'T019',  # Congential abnormality
    'T047',  # Disease or Syndrome
    # 'T037',  # Injury or Poising
    'T048',  # Mental or behavioural dysfunction
    'T191',  # Neoplastic process
    'T046',  # Pathologic function
    'T184',  # Sign or Symptom
]

PROTEIN_CATEGORIES = [
    'T192',  # Receptor
    'T126',  # Enzyme
    'T116',  # Amino acid, peptide, protein
]

PROCESS_CATEGORIES = [
    'T038',  # Biological process
    'T043',  # Cell function
    'T044',  # Molecular function
    'T039',  # Physiological function
]

categories = {'plant_categories':PLANT_CATEGORIES, 'disease_categories':DISEASE_CATEGORIES, 'protein_categories':PROTEIN_CATEGORIES, 'process_categories':PROCESS_CATEGORIES}


in_mmst21pv = {}
not_in_mmst21pv = {}
for key, val in categories.items():
    in_mmst21pv[key.upper()] = {x: tree.get_canonical_name(x) for x in val if x in st21pv_subtypes}
    not_in_mmst21pv[key] = {x: tree.get_canonical_name(x) for x in val if x not in st21pv_subtypes}

print("Our Categories covered by MedMentions ST21PV")
display(in_mmst21pv)

print("Our Categories NOT covered by MedMentions ST21PV")
display(not_in_mmst21pv)
# Out:
# Our Categories covered by MedMentions ST21PV
# {'PLANT_CATEGORIES': {'T002': 'Plant'},
#  'DISEASE_CATEGORIES': {'T020': 'Acquired Abnormality',
#   'T190': 'Anatomical Abnormality',
#   'T049': 'Cell or Molecular Dysfunction',
#   'T019': 'Congenital Abnormality',
#   'T047': 'Disease or Syndrome',
#   'T048': 'Mental or Behavioral Dysfunction',
#   'T191': 'Neoplastic Process',
#   'T046': 'Pathologic Function',
#   'T184': 'Sign or Symptom'},
#  'PROTEIN_CATEGORIES': {'T192': 'Receptor',
#   'T126': 'Enzyme',
#   'T116': 'Amino Acid, Peptide, or Protein'},
#  'PROCESS_CATEGORIES': {'T038': 'Biologic Function',
#   'T043': 'Cell Function',
#   'T044': 'Molecular Function',
#   'T039': 'Physiologic Function'}}
# Our Categories NOT covered by MedMentions ST21PV
# {'plant_categories': {'T096': 'Group'},
#  'disease_categories': {},
#  'protein_categories': {},
#  'process_categories': {}}

# %%
test_preds = ujson.load(open('/efs/davidkartchner/el-robustness-comparison/output/scispacy_test_processed.json', 'r'))
# train_preds = ujson.load(open('/efs/davidkartchner/el-robustness-comparison/output/scispacy_train_processed.json', 'r'))
# val_preds = ujson.load(open('/efs/davidkartchner/el-robustness-comparison/output/scispacy_validation_processed.json', 'r'))
# all_preds = [*train_preds, *test_preds, *val_preds]

# %%
all_hits_dict = evaluate_linking(all_preds, custom_types=categories)
format_output(all_hits_dict)
# Out:
#   0%|          | 0/203185 [00:00<?, ?it/s]
# /tmp/ipykernel_1103133/1775149890.py:51: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   overall_hits = np.sum(hits[x] for x in entity_types)/np.sum(hits[x + '_total'] for x in entity_types)
# /tmp/ipykernel_1103133/1775149890.py:52: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   overall_recall = np.sum(hits[x] for x in entity_types)/np.sum(hits[x + '_total'] + hits[x + '_missing'] for x in entity_types)
#   0%|          | 0/203185 [00:00<?, ?it/s]
#   0%|          | 0/203185 [00:00<?, ?it/s]
#   0%|          | 0/203185 [00:00<?, ?it/s]
#                            Semantic Type  Hits @ 1  Hits @ 5  Hits @ 10  \
# 0                       PLANT_CATEGORIES    0.5542    0.8074     0.8287
# 1                     PROCESS_CATEGORIES    0.4062    0.6955     0.7476
# 2                     DISEASE_CATEGORIES    0.5291    0.8572     0.8878
# 3                     PROTEIN_CATEGORIES    0.2628    0.6627     0.7440
# 4                            **Overall**    0.4343    0.7747     0.8229
# 5  **Overall (including missing spans)**    0.3465    0.6181     0.6566
#
#    Hits @ 25  Spans Matched  Missing  Total  Missing Proportion
# 0     0.8340           1319      612   1931              0.3169
# 1     0.7732           6137     2192   8329              0.2632
# 2     0.9033          20966     3942  24908              0.1583
# 3     0.7664          11513     3370  14883              0.2264
# 4     0.8415          39935    10116  50051              0.2021
# 5     0.6715          39935    10116  50051              0.2021

# %%
format_output(all_hits_dict)
# Out:
#                             Semantic Type  Hits @ 1  Hits @ 5  Hits @ 10  \
# 0                               Eukaryote    0.4932    0.8438     0.8525
# 1                      DISEASE_CATEGORIES    0.5291    0.8572     0.8878
# 2                        Population Group    0.5642    0.8176     0.8850
# 3                        PLANT_CATEGORIES    0.5542    0.8074     0.8287
# 4                     Injury or Poisoning    0.6077    0.7634     0.7819
# 5     Biomedical Occupation or Discipline    0.6103    0.8985     0.9074
# 6                    Anatomical Structure    0.5507    0.8114     0.8327
# 7                                Chemical    0.5505    0.7738     0.7995
# 8                                   Virus    0.6174    0.8558     0.8605
# 9                      PROCESS_CATEGORIES    0.4062    0.6955     0.7476
# 10                      Research Activity    0.5476    0.7771     0.8113
# 11                     PROTEIN_CATEGORIES    0.2628    0.6627     0.7440
# 12                         Medical Device    0.3911    0.6351     0.6697
# 13                      Biologic Function    0.4123    0.7031     0.7878
# 14                              Bacterium    0.6066    0.8404     0.8468
# 15                           Organization    0.4584    0.7642     0.7739
# 16                   Health Care Activity    0.4202    0.7182     0.7888
# 17                     Clinical Attribute    0.5312    0.8423     0.8466
# 18                                Finding    0.3928    0.7093     0.7319
# 19                                   Food    0.3409    0.6900     0.8105
# 20     Professional or Occupational Group    0.6312    0.7975     0.8200
# 21                        Spatial Concept    0.5821    0.8121     0.8463
# 22                   Intellectual Product    0.3658    0.7318     0.7561
# 23                            **Overall**    0.4777    0.7683     0.8094
# 24  **Overall (including missing spans)**    0.3509    0.5642     0.5944
#
#     Hits @ 25  Spans Matched  Missing   Total  Missing Proportion
# 0      0.8562           5057     1563    6620              0.2361
# 1      0.9033          20966     3942   24908              0.1583
# 2      0.8882           5027     1119    6146              0.1821
# 3      0.8340           1319      612    1931              0.3169
# 4      0.7901           1458      390    1848              0.2110
# 5      0.9221            680      236     916              0.2576
# 6      0.8420          14234     5471   19705              0.2776
# 7      0.8090          16979     5520   22499              0.2453
# 8      0.8616            860      238    1098              0.2168
# 9      0.7732           6137     2192    8329              0.2632
# 10     0.8265           6704     2463    9167              0.2687
# 11     0.7664          11513     3370   14883              0.2264
# 12     0.6749           1332      686    2018              0.3399
# 13     0.8151           8059     2921   10980              0.2660
# 14     0.8475           1416      633    2049              0.3089
# 15     0.7788           1442      701    2143              0.3271
# 16     0.8008          17435     6861   24296              0.2824
# 17     0.8545           1395      377    1772              0.2128
# 18     0.7425           9153     5047   14200              0.3554
# 19     0.8157            971      380    1351              0.2813
# 20     0.8269           1467      311    1778              0.1749
# 21     0.8573           8261     4230   12491              0.3386
# 22     0.7654           6071     4237   10308              0.4110
# 23     0.8224         147936    53500  201436              0.2656
# 24     0.6040         147936    53500  201436              0.2656

# %%
# test_hits_dict = evaluate_linking(test_preds, custom_types=categories)

# scispacy_results = format_output(test_hits_dict)
# scispacy_results['Model'] = 'Scispacy_en_sm'
# cols = ['Semantic Type'] + [col for col in scispacy_results.columns if col.startswith('recall')] + ['Total','Missing', 'Model']
scispacy_results[cols].to_pickle('/efs/davidkartchner/el-robustness-comparison/output/scispacy_custom_categories.pickle')

# %%
test_hits_dict = evaluate_linking(test_preds)
scispacy_results = format_output(test_hits_dict)
scispacy_results['Model'] = 'Scispacy_en_sm'
cols = ['Semantic Type'] + [col for col in scispacy_results.columns if col.startswith('recall')] + ['Total','Missing', 'Model']
scispacy_results[cols].to_pickle('/efs/davidkartchner/el-robustness-comparison/output/scispacy_output.pickle')
# Out:
#   0%|          | 0/40143 [00:00<?, ?it/s]
# /tmp/ipykernel_7439/1154498453.py:51: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   overall_hits = np.sum(hits[x] for x in entity_types)/np.sum(hits[x + '_total'] for x in entity_types)
# /tmp/ipykernel_7439/1154498453.py:52: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   overall_recall = np.sum(hits[x] for x in entity_types)/np.sum(hits[x + '_total'] + hits[x + '_missing'] for x in entity_types)
#   0%|          | 0/40143 [00:00<?, ?it/s]
#   0%|          | 0/40143 [00:00<?, ?it/s]
#   0%|          | 0/40143 [00:00<?, ?it/s]
#   0%|          | 0/40143 [00:00<?, ?it/s]
#   0%|          | 0/40143 [00:00<?, ?it/s]

# %%
# !pip install --upgrade pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: pandas in /efs/davidkartchner/mambaforge/lib/python3.9/site-packages (1.4.2)
# Collecting pandas
#   Downloading pandas-1.4.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 78.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: pytz>=2020.1 in /efs/davidkartchner/mambaforge/lib/python3.9/site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.18.5 in /efs/davidkartchner/mambaforge/lib/python3.9/site-packages (from pandas) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in /efs/davidkartchner/mambaforge/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /efs/davidkartchner/mambaforge/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.4.2
#     Uninstalling pandas-1.4.2:
#       Successfully uninstalled pandas-1.4.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyenveda 0.0.6 requires statsmodels, which is not installed.
# Successfully installed pandas-1.4.3

# %%
scispacy_results
# Out:
#                            Semantic Type  recall@1  recall@2  recall@4  \
# 0                     PROCESS_CATEGORIES    0.4513    0.6430    0.7302
# 1                     PROTEIN_CATEGORIES    0.2623    0.4179    0.6223
# 2                     DISEASE_CATEGORIES    0.5220    0.7260    0.8535
# 3                       PLANT_CATEGORIES    0.4455    0.6818    0.7727
# 4                            **Overall**    0.4364    0.6260    0.7683
# 5  **Overall (including missing spans)**    0.3163    0.4537    0.5569
#
#    recall@8  recall@16  recall@32  Spans Matched  Missing  Total  \
# 0    0.7759     0.8002     0.8063            986      542   1528
# 1    0.7392     0.7814     0.7916           1967      845   2812
# 2    0.8809     0.9069     0.9074           3803     1071   4874
# 3    0.8409     0.8455     0.8455            220      191    411
# 4    0.8248     0.8545     0.8585           6976     2649   9625
# 5    0.5978     0.6193     0.6222           6976     2649   9625
#
#    Missing Proportion           Model
# 0              0.3547  Scispacy_en_sm
# 1              0.3005  Scispacy_en_sm
# 2              0.2197  Scispacy_en_sm
# 3              0.4647  Scispacy_en_sm
# 4              0.2752  Scispacy_en_sm
# 5              0.2752  Scispacy_en_sm

# %%
test_hits_dict = evaluate_linking(test_preds)
format_output(test_hits_dict)
# Out:
#   0%|          | 0/40143 [00:00<?, ?it/s]
# /tmp/ipykernel_7439/1154498453.py:51: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   overall_hits = np.sum(hits[x] for x in entity_types)/np.sum(hits[x + '_total'] for x in entity_types)
# /tmp/ipykernel_7439/1154498453.py:52: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   overall_recall = np.sum(hits[x] for x in entity_types)/np.sum(hits[x + '_total'] + hits[x + '_missing'] for x in entity_types)
#   0%|          | 0/40143 [00:00<?, ?it/s]
#   0%|          | 0/40143 [00:00<?, ?it/s]
#   0%|          | 0/40143 [00:00<?, ?it/s]
#   0%|          | 0/40143 [00:00<?, ?it/s]
#   0%|          | 0/40143 [00:00<?, ?it/s]
#                             Semantic Type  recall@1  recall@2  recall@4  \
# 0                            Organization    0.4858    0.5911    0.7085
# 1                                Chemical    0.4488    0.5911    0.7041
# 2                               Eukaryote    0.4828    0.7129    0.8328
# 3                                 Finding    0.3941    0.5329    0.6331
# 4                          Body Substance    0.2338    0.2857    0.7143
# 5                                   Virus    0.6356    0.7881    0.9068
# 6                          Medical Device    0.4294    0.5706    0.6893
# 7                     Injury or Poisoning    0.6432    0.7012    0.7676
# 8                               Bacterium    0.6292    0.7640    0.8315
# 9                    Anatomical Structure    0.5779    0.7191    0.7929
# 10                   Health Care Activity    0.4490    0.5608    0.7034
# 11                       Population Group    0.6227    0.7606    0.8296
# 12                      Research Activity    0.5574    0.6871    0.7964
# 13     Professional or Occupational Group    0.6957    0.8333    0.8551
# 14                                   Food    0.2460    0.4385    0.5508
# 15                        Spatial Concept    0.5861    0.7096    0.7858
# 16                     Clinical Attribute    0.4940    0.7410    0.8486
# 17    Biomedical Occupation or Discipline    0.5484    0.7097    0.8871
# 18                   Intellectual Product    0.3485    0.5332    0.6930
# 19                      Biologic Function    0.4883    0.6735    0.7997
# 20                            Body System    0.2807    0.4912    0.7368
# 21                            **Overall**    0.4853    0.6372    0.7518
# 22  **Overall (including missing spans)**    0.3188    0.4187    0.4939
#
#     recall@8  recall@16  recall@32  Spans Matched  Missing  Total  \
# 0     0.7530     0.7530     0.7571            247      135    382
# 1     0.7713     0.7957     0.8024           5082     2325   7407
# 2     0.8629     0.8681     0.8698           1160      590   1750
# 3     0.7446     0.7631     0.7667           1946     1265   3211
# 4     0.8182     0.8312     0.8312            154       58    212
# 5     0.9068     0.9153     0.9153            118       54    172
# 6     0.7910     0.7966     0.7966            177      178    355
# 7     0.7925     0.8050     0.8050            241      116    357
# 8     0.8315     0.8315     0.8315            267      182    449
# 9     0.8276     0.8380     0.8393           2303     1470   3773
# 10    0.7885     0.8080     0.8099           3078     1709   4787
# 11    0.9189     0.9229     0.9229            986      277   1263
# 12    0.8325     0.8365     0.8475           1272      575   1847
# 13    0.8949     0.8986     0.9022            276       84    360
# 14    0.7326     0.7487     0.7487            187      135    322
# 15    0.8476     0.8582     0.8582           1312     1097   2409
# 16    0.8606     0.8725     0.8725            251       72    323
# 17    0.9194     0.9194     0.9677            124       72    196
# 18    0.7394     0.7490     0.7538           1251     1114   2365
# 19    0.8301     0.8692     0.8724           5886     2227   8113
# 20    0.7368     0.8596     0.8596             57       33     90
# 21    0.8083     0.8286     0.8324          26375    13768  40143
# 22    0.5311     0.5444     0.5469          26375    13768  40143
#
#     Missing Proportion
# 0               0.3534
# 1               0.3139
# 2               0.3371
# 3               0.3940
# 4               0.2736
# 5               0.3140
# 6               0.5014
# 7               0.3249
# 8               0.4053
# 9               0.3896
# 10              0.3570
# 11              0.2193
# 12              0.3113
# 13              0.2333
# 14              0.4193
# 15              0.4554
# 16              0.2229
# 17              0.3673
# 18              0.4710
# 19              0.2745
# 20              0.3667
# 21              0.3430
# 22              0.3430

# %%
ujson.loads('"Identification of APC2, a homologue of the START adenomatous polyposis coli tumour END"')
# Out:
# 'Identification of APC2, a homologue of the START adenomatous polyposis coli tumour END'

# %%
import sys
import ujson
import pickle
import pandas as pd
import numpy as np

from tqdm import tqdm
from collections import defaultdict

from bigbio.dataloader import BigBioConfigHelpers

sys.path.append('..')
from bigbio_utils import dataset_to_df


conhelps = BigBioConfigHelpers()

# %%
dataset = conhelps.for_config_name('ncbi_disease_bigbio_kb').load_dataset()
df = dataset_to_df(dataset)
all_cuis = set([y for x in df.db_ids for y in x])
all_cuis
# Out:
# Found cached dataset ncbi_disease (/home/dkartchner3/.cache/huggingface/datasets/ncbi_disease/ncbi_disease_bigbio_kb/1.0.0/cb155244edb3e586c0105202613da9f02c1baf3de0550919e638775c31469221)
#   0%|          | 0/3 [00:00<?, ?it/s]
# {'MESH:C531603',
#  'MESH:C531604',
#  'MESH:C531609',
#  'MESH:C531610',
#  'MESH:C531652',
#  'MESH:C531732',
#  'MESH:C531844',
#  'MESH:C535331',
#  'MESH:C535342',
#  'MESH:C535395',
#  'MESH:C535464',
#  'MESH:C535468',
#  'MESH:C535504',
#  'MESH:C535506',
#  'MESH:C535662',
#  'MESH:C535668',
#  'MESH:C535679',
#  'MESH:C535700',
#  'MESH:C535733',
#  'MESH:C535764',
#  'MESH:C535804',
#  'MESH:C535884',
#  'MESH:C535916',
#  'MESH:C535918',
#  'MESH:C535944',
#  'MESH:C535964',
#  'MESH:C536016',
#  'MESH:C536106',
#  'MESH:C536170',
#  'MESH:C536183',
#  'MESH:C536185',
#  'MESH:C536210',
#  'MESH:C536245',
#  'MESH:C536252',
#  'MESH:C536277',
#  'MESH:C536288',
#  'MESH:C536309',
#  'MESH:C536353',
#  'MESH:C536399',
#  'MESH:C536438',
#  'MESH:C536456',
#  'MESH:C536528',
#  'MESH:C536575',
#  'MESH:C536587',
#  'MESH:C536648',
#  'MESH:C536852',
#  'MESH:C536903',
#  'MESH:C537022',
#  'MESH:C537034',
#  'MESH:C537181',
#  'MESH:C537182',
#  'MESH:C537207',
#  'MESH:C537209',
#  'MESH:C537243',
#  'MESH:C537277',
#  'MESH:C537346',
#  'MESH:C537356',
#  'MESH:C537369',
#  'MESH:C537502',
#  'MESH:C537627',
#  'MESH:C537666',
#  'MESH:C537750',
#  'MESH:C537775',
#  'MESH:C537845',
#  'MESH:C537849',
#  'MESH:C537884',
#  'MESH:C537966',
#  'MESH:C538007',
#  'MESH:C538037',
#  'MESH:C538065',
#  'MESH:C538068',
#  'MESH:C538098',
#  'MESH:C538138',
#  'MESH:C538219',
#  'MESH:C538225',
#  'MESH:C538243',
#  'MESH:C538249',
#  'MESH:C538265',
#  'MESH:C538273',
#  'MESH:C538320',
#  'MESH:C538333',
#  'MESH:C538392',
#  'MESH:C538445',
#  'MESH:C538554',
#  'MESH:C548028',
#  'MESH:D000008',
#  'MESH:D000012',
#  'MESH:D000013',
#  'MESH:D000015',
#  'MESH:D000224',
#  'MESH:D000236',
#  'MESH:D000257',
#  'MESH:D000303',
#  'MESH:D000307',
#  'MESH:D000309',
#  'MESH:D000312',
#  'MESH:D000326',
#  'MESH:D000347',
#  'MESH:D000435',
#  'MESH:D000474',
#  'MESH:D000544',
#  'MESH:D000567',
#  'MESH:D000592',
#  'MESH:D000686',
#  'MESH:D000740',
#  'MESH:D000743',
#  'MESH:D000745',
#  'MESH:D000746',
#  'MESH:D000757',
#  'MESH:D000782',
#  'MESH:D000794',
#  'MESH:D000795',
#  'MESH:D000799',
#  'MESH:D000848',
#  'MESH:D000853',
#  'MESH:D000857',
#  'MESH:D001008',
#  'MESH:D001019',
#  'MESH:D001112',
#  'MESH:D001145',
#  'MESH:D001168',
#  'MESH:D001172',
#  'MESH:D001249',
#  'MESH:D001259',
#  'MESH:D001260',
#  'MESH:D001284',
#  'MESH:D001304',
#  'MESH:D001321',
#  'MESH:D001327',
#  'MESH:D001405',
#  'MESH:D001424',
#  'MESH:D001523',
#  'MESH:D001661',
#  'MESH:D001714',
#  'MESH:D001745',
#  'MESH:D001763',
#  'MESH:D001766',
#  'MESH:D001768',
#  'MESH:D001847',
#  'MESH:D001848',
#  'MESH:D001859',
#  'MESH:D001927',
#  'MESH:D001932',
#  'MESH:D001941',
#  'MESH:D001943',
#  'MESH:D002051',
#  'MESH:D002277',
#  'MESH:D002278',
#  'MESH:D002280',
#  'MESH:D002292',
#  'MESH:D002296',
#  'MESH:D002311',
#  'MESH:D002312',
#  'MESH:D002318',
#  'MESH:D002386',
#  'MESH:D002471',
#  'MESH:D002493',
#  'MESH:D002524',
#  'MESH:D002526',
#  'MESH:D002583',
#  'MESH:D002607',
#  'MESH:D002609',
#  'MESH:D002658',
#  'MESH:D002819',
#  'MESH:D002836',
#  'MESH:D002869',
#  'MESH:D002908',
#  'MESH:D002971',
#  'MESH:D002972',
#  'MESH:D003025',
#  'MESH:D003072',
#  'MESH:D003093',
#  'MESH:D003095',
#  'MESH:D003110',
#  'MESH:D003111',
#  'MESH:D003117',
#  'MESH:D003123',
#  'MESH:D003141',
#  'MESH:D003286',
#  'MESH:D003294',
#  'MESH:D003317',
#  'MESH:D003318',
#  'MESH:D003323',
#  'MESH:D003327',
#  'MESH:D003398',
#  'MESH:D003409',
#  'MESH:D003456',
#  'MESH:D003537',
#  'MESH:D003586',
#  'MESH:D003638',
#  'MESH:D003643',
#  'MESH:D003645',
#  'MESH:D003681',
#  'MESH:D003704',
#  'MESH:D003711',
#  'MESH:D003866',
#  'MESH:D003876',
#  'MESH:D003919',
#  'MESH:D003920',
#  'MESH:D003922',
#  'MESH:D003924',
#  'MESH:D003967',
#  'MESH:D004062',
#  'MESH:D004194',
#  'MESH:D004401',
#  'MESH:D004406',
#  'MESH:D004421',
#  'MESH:D004422',
#  'MESH:D004427',
#  'MESH:D004485',
#  'MESH:D004535',
#  'MESH:D004646',
#  'MESH:D004660',
#  'MESH:D004673',
#  'MESH:D004700',
#  'MESH:D004701',
#  'MESH:D004806',
#  'MESH:D004814',
#  'MESH:D004827',
#  'MESH:D004829',
#  'MESH:D004938',
#  'MESH:D005076',
#  'MESH:D005124',
#  'MESH:D005146',
#  'MESH:D005171',
#  'MESH:D005185',
#  'MESH:D005221',
#  'MESH:D005234',
#  'MESH:D005235',
#  'MESH:D005236',
#  'MESH:D005313',
#  'MESH:D005317',
#  'MESH:D005334',
#  'MESH:D005355',
#  'MESH:D005402',
#  'MESH:D005530',
#  'MESH:D005532',
#  'MESH:D005600',
#  'MESH:D005621',
#  'MESH:D005693',
#  'MESH:D005736',
#  'MESH:D005776',
#  'MESH:D005832',
#  'MESH:D005834',
#  'MESH:D005879',
#  'MESH:D005901',
#  'MESH:D005909',
#  'MESH:D005910',
#  'MESH:D005921',
#  'MESH:D005955',
#  'MESH:D006042',
#  'MESH:D006058',
#  'MESH:D006059',
#  'MESH:D006069',
#  'MESH:D006106',
#  'MESH:D006130',
#  'MESH:D006222',
#  'MESH:D006223',
#  'MESH:D006226',
#  'MESH:D006319',
#  'MESH:D006323',
#  'MESH:D006327',
#  'MESH:D006330',
#  'MESH:D006331',
#  'MESH:D006402',
#  'MESH:D006417',
#  'MESH:D006432',
#  'MESH:D006456',
#  'MESH:D006457',
#  'MESH:D006461',
#  'MESH:D006463',
#  'MESH:D006467',
#  'MESH:D006474',
#  'MESH:D006501',
#  'MESH:D006521',
#  'MESH:D006527',
#  'MESH:D006528',
#  'MESH:D006529',
#  'MESH:D006618',
#  'MESH:D006623',
#  'MESH:D006689',
#  'MESH:D006816',
#  'MESH:D006849',
#  'MESH:D006932',
#  'MESH:D006937',
#  'MESH:D006946',
#  'MESH:D006949',
#  'MESH:D006951',
#  'MESH:D006961',
#  'MESH:D006963',
#  'MESH:D006965',
#  'MESH:D006972',
#  'MESH:D006995',
#  'MESH:D007011',
#  'MESH:D007022',
#  'MESH:D007027',
#  'MESH:D007057',
#  'MESH:D007105',
#  'MESH:D007153',
#  'MESH:D007154',
#  'MESH:D007239',
#  'MESH:D007246',
#  'MESH:D007248',
#  'MESH:D007249',
#  'MESH:D007499',
#  'MESH:D007565',
#  'MESH:D007567',
#  'MESH:D007569',
#  'MESH:D007571',
#  'MESH:D007573',
#  'MESH:D007592',
#  'MESH:D007642',
#  'MESH:D007645',
#  'MESH:D007674',
#  'MESH:D007680',
#  'MESH:D007690',
#  'MESH:D007759',
#  'MESH:D007863',
#  'MESH:D007890',
#  'MESH:D007926',
#  'MESH:D007938',
#  'MESH:D007945',
#  'MESH:D007960',
#  'MESH:D007965',
#  'MESH:D007966',
#  'MESH:D007967',
#  'MESH:D008047',
#  'MESH:D008052',
#  'MESH:D008067',
#  'MESH:D008103',
#  'MESH:D008107',
#  'MESH:D008113',
#  'MESH:D008133',
#  'MESH:D008175',
#  'MESH:D008179',
#  'MESH:D008180',
#  'MESH:D008206',
#  'MESH:D008223',
#  'MESH:D008228',
#  'MESH:D008232',
#  'MESH:D008268',
#  'MESH:D008288',
#  'MESH:D008527',
#  'MESH:D008538',
#  'MESH:D008545',
#  'MESH:D008581',
#  'MESH:D008585',
#  'MESH:D008586',
#  'MESH:D008589',
#  'MESH:D008607',
#  'MESH:D008637',
#  'MESH:D008654',
#  'MESH:D008659',
#  'MESH:D008661',
#  'MESH:D008831',
#  'MESH:D008881',
#  'MESH:D009059',
#  'MESH:D009069',
#  'MESH:D009078',
#  'MESH:D009085',
#  'MESH:D009120',
#  'MESH:D009123',
#  'MESH:D009128',
#  'MESH:D009133',
#  'MESH:D009135',
#  'MESH:D009136',
#  'MESH:D009139',
#  'MESH:D009157',
#  'MESH:D009202',
#  'MESH:D009216',
#  'MESH:D009222',
#  'MESH:D009223',
#  'MESH:D009224',
#  'MESH:D009260',
#  'MESH:D009358',
#  'MESH:D009362',
#  'MESH:D009369',
#  'MESH:D009377',
#  'MESH:D009386',
#  'MESH:D009393',
#  'MESH:D009396',
#  'MESH:D009410',
#  'MESH:D009421',
#  'MESH:D009422',
#  'MESH:D009436',
#  'MESH:D009447',
#  'MESH:D009456',
#  'MESH:D009461',
#  'MESH:D009468',
#  'MESH:D009759',
#  'MESH:D009765',
#  'MESH:D009794',
#  'MESH:D009800',
#  'MESH:D009810',
#  'MESH:D009837',
#  'MESH:D009896',
#  'MESH:D010009',
#  'MESH:D010016',
#  'MESH:D010033',
#  'MESH:D010051',
#  'MESH:D010181',
#  'MESH:D010190',
#  'MESH:D010214',
#  'MESH:D010264',
#  'MESH:D010282',
#  'MESH:D010292',
#  'MESH:D010505',
#  'MESH:D010510',
#  'MESH:D010518',
#  'MESH:D010523',
#  'MESH:D010534',
#  'MESH:D010554',
#  'MESH:D010661',
#  'MESH:D010673',
#  'MESH:D010859',
#  'MESH:D010871',
#  'MESH:D010900',
#  'MESH:D011014',
#  'MESH:D011115',
#  'MESH:D011125',
#  'MESH:D011127',
#  'MESH:D011218',
#  'MESH:D011471',
#  'MESH:D011507',
#  'MESH:D011565',
#  'MESH:D012004',
#  'MESH:D012008',
#  'MESH:D012021',
#  'MESH:D012141',
#  'MESH:D012162',
#  'MESH:D012163',
#  'MESH:D012164',
#  'MESH:D012174',
#  'MESH:D012175',
#  'MESH:D012216',
#  'MESH:D012257',
#  'MESH:D012509',
#  'MESH:D012512',
#  'MESH:D012514',
#  'MESH:D012516',
#  'MESH:D012600',
#  'MESH:D012607',
#  'MESH:D012700',
#  'MESH:D012734',
#  'MESH:D012859',
#  'MESH:D012878',
#  'MESH:D012883',
#  'MESH:D012983',
#  'MESH:D013088',
#  'MESH:D013118',
#  'MESH:D013122',
#  'MESH:D013132',
#  'MESH:D013163',
#  'MESH:D013166',
#  'MESH:D013167',
#  'MESH:D013274',
#  'MESH:D013568',
#  'MESH:D013576',
#  'MESH:D013585',
#  'MESH:D013661',
#  'MESH:D013789',
#  'MESH:D013921',
#  'MESH:D013927',
#  'MESH:D013945',
#  'MESH:D013953',
#  'MESH:D013959',
#  'MESH:D013964',
#  'MESH:D014071',
#  'MESH:D014202',
#  'MESH:D014402',
#  'MESH:D014564',
#  'MESH:D014606',
#  'MESH:D014652',
#  'MESH:D014657',
#  'MESH:D014693',
#  'MESH:D014842',
#  'MESH:D014849',
#  'MESH:D014923',
#  'MESH:D014947',
#  'MESH:D014973',
#  'MESH:D015179',
#  'MESH:D015210',
#  'MESH:D015211',
#  'MESH:D015212',
#  'MESH:D015223',
#  'MESH:D015228',
#  'MESH:D015324',
#  'MESH:D015451',
#  'MESH:D015458',
#  'MESH:D015461',
#  'MESH:D015470',
#  'MESH:D015499',
#  'MESH:D015535',
#  'MESH:D015658',
#  'MESH:D015783',
#  'MESH:D015785',
#  'MESH:D015794',
#  'MESH:D015821',
#  'MESH:D015826',
#  'MESH:D015834',
#  'MESH:D015862',
#  'MESH:D016109',
#  'MESH:D016111',
#  'MESH:D016116',
#  'MESH:D016135',
#  'MESH:D016388',
#  'MESH:D016393',
#  'MESH:D016399',
#  'MESH:D016464',
#  'MESH:D016472',
#  'MESH:D016512',
#  'MESH:D016537',
#  'MESH:D016538',
#  'MESH:D016757',
#  'MESH:D016864',
#  'MESH:D016870',
#  'MESH:D016889',
#  'MESH:D016920',
#  'MESH:D017034',
#  'MESH:D017042',
#  'MESH:D017093',
#  'MESH:D017094',
#  'MESH:D017202',
#  'MESH:D017204',
#  'MESH:D017445',
#  'MESH:D017488',
#  'MESH:D017496',
#  'MESH:D017511',
#  'MESH:D017573',
#  'MESH:D017599',
#  'MESH:D017624',
#  'MESH:D017825',
#  'MESH:D017827',
#  'MESH:D017880',
#  'MESH:D018149',
#  'MESH:D018197',
#  'MESH:D018198',
#  'MESH:D018205',
#  'MESH:D018222',
#  'MESH:D018232',
#  'MESH:D018239',
#  'MESH:D018256',
#  'MESH:D018268',
#  'MESH:D018275',
#  'MESH:D018284',
#  'MESH:D018292',
#  'MESH:D018296',
#  'MESH:D018302',
#  'MESH:D018307',
#  'MESH:D018319',
#  'MESH:D018322',
#  'MESH:D018325',
#  'MESH:D018335',
#  'MESH:D018366',
#  'MESH:D018376',
#  'MESH:D018455',
#  'MESH:D018567',
#  'MESH:D018771',
#  'MESH:D018798',
#  'MESH:D018813',
#  'MESH:D018901',
#  'MESH:D018908',
#  'MESH:D019042',
#  'MESH:D019189',
#  'MESH:D019190',
#  'MESH:D019214',
#  'MESH:D019282',
#  'MESH:D019294',
#  'MESH:D019337',
#  'MESH:D019465',
#  'MESH:D019572',
#  'MESH:D019636',
#  'MESH:D019767',
#  'MESH:D019851',
#  'MESH:D019954',
#  'MESH:D019957',
#  'MESH:D019964',
#  'MESH:D020022',
#  'MESH:D020031',
#  'MESH:D020141',
#  'MESH:D020143',
#  'MESH:D020158',
#  'MESH:D020162',
#  'MESH:D020234',
#  'MESH:D020246',
#  'MESH:D020271',
#  'MESH:D020279',
#  'MESH:D020288',
#  'MESH:D020325',
#  'MESH:D020371',
#  'MESH:D020388',
#  'MESH:D020389',
#  'MESH:D020417',
#  'MESH:D020518',
#  'MESH:D020754',
#  'MESH:D020790',
#  'MESH:D020821',
#  'MESH:D020886',
#  'MESH:D020936',
#  'MESH:D020964',
#  'MESH:D020966',
#  'MESH:D024182',
#  'MESH:D024741',
#  'MESH:D025063',
#  'MESH:D025861',
#  'MESH:D028227',
#  'MESH:D028361',
#  'MESH:D030321',
#  'MESH:D030342',
#  'MESH:D030981',
#  'MESH:D033461',
#  'MESH:D034381',
#  'MESH:D034721',
#  'MESH:D035583',
#  'MESH:D036821',
#  'MESH:D038901',
#  'MESH:D040181',
#  'MESH:D041441',
#  'MESH:D043171',
#  'MESH:D044483',
#  'MESH:D044584',
#  'MESH:D046349',
#  'MESH:D048629',
#  'MESH:D049288',
#  'MESH:D049932',
#  'MESH:D049950',
#  'MESH:D050197',
#  'MESH:D051346',
#  'MESH:D051359',
#  'MESH:D051437',
#  'MESH:D052159',
#  'MESH:D052177',
#  'MESH:D052456',
#  'MESH:D052476',
#  'MESH:D052919',
#  'MESH:D053421',
#  'MESH:D053632',
#  'MESH:D053840',
#  'MESH:D053842',
#  'MESH:D054067',
#  'MESH:D054098',
#  'MESH:D054119',
#  'MESH:D054508',
#  'MESH:D054880',
#  'MESH:D055036',
#  'MESH:D056725',
#  'MESH:D056728',
#  'MESH:D056729',
#  'MESH:D056732',
#  'MESH:D056735',
#  'MESH:D056769',
#  'MESH:D056784',
#  'MESH:D057130',
#  'MESH:D057215',
#  'MESH:D057772',
#  'MESH:D058405',
#  'MESH:D058456',
#  'MESH:D058490',
#  'MESH:D058495',
#  'MESH:D058499',
#  'MESH:D058566',
#  'MESH:D058670',
#  'MESH:D059352',
#  'MESH:D061325',
#  'OMIM:101400',
#  'OMIM:101600',
#  'OMIM:102600',
#  'OMIM:103600',
#  'OMIM:106210',
#  'OMIM:109150',
#  'OMIM:115080',
#  'OMIM:115470',
#  'OMIM:116800',
#  'OMIM:119500',
#  'OMIM:119530',
#  'OMIM:123500',
#  'OMIM:125370',
#  'OMIM:125700',
#  'OMIM:125852',
#  'OMIM:131100',
#  'OMIM:132400',
#  'OMIM:136520',
#  'OMIM:136880',
#  'OMIM:143470',
#  'OMIM:145001',
#  'OMIM:153400',
#  'OMIM:160800',
#  'OMIM:160900',
#  'OMIM:164160',
#  'OMIM:164400',
#  'OMIM:174810',
#  'OMIM:180020',
#  'OMIM:183086',
#  'OMIM:183090',
#  'OMIM:190350',
#  'OMIM:200100',
#  'OMIM:201400',
#  'OMIM:202370',
#  'OMIM:208900',
#  'OMIM:213700',
#  'OMIM:214100',
#  'OMIM:215600',
#  'OMIM:217000',
#  'OMIM:222300',
#  'OMIM:222600',
#  'OMIM:226900',
#  'OMIM:230400',
#  'OMIM:238600',
#  'OMIM:245200',
#  'OMIM:253000',
#  'OMIM:255125',
#  'OMIM:255800',
#  'OMIM:260350',
#  'OMIM:261600',
#  'OMIM:262400',
#  'OMIM:274400',
#  'OMIM:300100',
#  'OMIM:300194',
#  'OMIM:300323',
#  'OMIM:300624',
#  'OMIM:300755',
#  'OMIM:300842',
#  'OMIM:304500',
#  'OMIM:310200',
#  'OMIM:312080',
#  'OMIM:312920',
#  'OMIM:313900',
#  'OMIM:314250',
#  'OMIM:600204',
#  'OMIM:600698',
#  'OMIM:600791',
#  'OMIM:602482',
#  'OMIM:604370',
#  'OMIM:604391',
#  'OMIM:605253',
#  'OMIM:606824',
#  'OMIM:607834',
#  'OMIM:609536',
#  'OMIM:609814',
#  'OMIM:610102',
#  'OMIM:610170',
#  'OMIM:610743',
#  'OMIM:612336',
#  'OMIM:612446',
#  'OMIM:612555',
#  'OMIM:613399',
#  'OMIM:613779',
#  'OMIM:613825',
#  'OMIM:614379'}

# %%
def read_examples(filepath):
    # Read file
    with open(filepath, 'r') as f:
        lines = f.read().split('\n')

    # Construct dict mapping each CURIE to a list of aliases
    umls_dict = {} 
    for line in tqdm(lines):
        cui, name = line.split("||")
        if cui in umls_dict:
            umls_dict[cui].append(name)
        else:
            umls_dict[cui] = [name]

    return umls_dict

mesh_omim_dict = read_examples('../data/umls_2017/mesh_and_omim_to_alias.txt')

mesh_omim_cuis = set(mesh_omim_dict.keys())

# ujson.load(open('../data/mesh_and_omim_to_alias.txt'))
# Out:
# 100%|██████████| 1193815/1193815 [00:01<00:00, 816117.27it/s]

# %%
mesh_omim_dict
# Out:
# {'MESH:C000002': ['bevonium',
#   '2-(hydroxymethyl)-n,n-dimethylpiperidinium benzilate',
#   'cg 201',
#   'acabel',
#   'bevonium sulfate (1:1)',
#   'bevonium methyl sulfate',
#   'piribenzil methyl sulfate',
#   'bevonium methylsulfate',
#   'bevonium metilsulfate'],
#  'MESH:C000006': ['insulin, neutral',
#   'neutral insulin',
#   'insulin, 8a-l-threonine-10a-l-isoleucine-',
#   'actrapid insulin',
#   'novo mc insulin',
#   'insulin pork',
#   'insulin (pork)',
#   'insulin (swine)',
#   'insulin (ox), 8(a)-l-threonine-10(a)-l-isoleucine-'],
#  'MESH:C000009': ['asparaginylglucosamine',
#   'aspartylglucosamine',
#   'aspartylglucosylamine',
#   'aspartylglycosamine',
#   'n-acetylglucosaminylasparagine',
#   '2-acetamido-1-(beta-l-aspartamido)-1,2-dideoxy-beta-d-glucose',
#   "2-acetamido-1-n-(4'-l-aspartyl)-2-deoxy-beta-d-glucopyranosylamine",
#   'n(4)-(2-acetamido-2-deoxy-beta-d-glucopyranosyl)-l-asparagine',
#   '4-n-2-acetamido-2-deoxy-beta-d-glucopyranosyl-l-asparagine',
#   'aadg',
#   'acetylglucosaminylasparagine',
#   'l-asparagine, n-(2-acetylamino)-2-deoxy-beta-d-glucopyranosyl-',
#   'n-(2-acetylamino)-2-deoxy-beta-d-glucopyranosyl-l-asparagine',
#   'n(4)-(2-acetamido-2-deoxyglucopyranosyl)asparagine',
#   'n-adgp-asn'],
#  'MESH:C000011': ['5-(n-acetaminophenylazo)-8-oxyquinoline',
#   '5-(p-acetamidophenylazo)-8-hydroxyquinoline'],
#  'MESH:C000015': ['acetyl arginine',
#   'n-acetyl-l-arginine',
#   'n-alpha-acetylarginine'],
#  'MESH:C000020': ['n-acetylneuraminoyllactose',
#   'acetylneuraminyllactose',
#   'n-acetylneuramin lactose',
#   'n-acetylneuraminyllactose',
#   'sialyl-lactose',
#   'sialyl(alpha2,3)lactose',
#   'sialyllactose',
#   'n-acetylneuraminyl-2-3-lactose',
#   'neuraminlactose'],
#  'MESH:C000021': ['acetylnovadral'],
#  'MESH:C000022': ['n-acetyl-4-nitrophenylserinol',
#   'n-acetyl-p-nitrophenylserinol',
#   'corynecin i',
#   'n-acetyl-4-nitrophenylserinol, (l-threo)-isomer',
#   'n-acetyl-4-nitrophenylserinol, (d-threo)-isomer'],
#  'MESH:C000024': ['flavophosphine',
#   '3-amino-9-(p-aminophenyl)-7-methylacridine'],
#  'MESH:C000025': ['ethosuximide - quinacrine',
#   '2,5-pyrrolidinedione, 3-ethyl-3-methyl-, mixt. with n(4)-(6-chloro-2-methoxy-9-acridinyl)-n(1),n(1)-diethyl-1,4-pentanediamine dihydrochloride',
#   'acrisuxine',
#   'ethosuximide, quinacrine drug combination'],
#  'MESH:C000027': ['cyprodenate',
#   'cyprodemanol',
#   'dimethylamino- 2-ethyl-beta-cyclohexylpropionic acid maleate',
#   'actebral',
#   'lb 125'],
#  'MESH:C000028': ['carboxyphosphamide',
#   '2-carboxyethyl-n,n-bis(2-chloroethyl)phosphorodiamidate',
#   'carboxycyclophosphamide',
#   'carboxyphosphamide, (r)-isomer',
#   'carboxyphosphamide, (s)-isomer'],
#  'MESH:C000032': ['adenosine arabinose'],
#  'MESH:C000038': ['adrenoglomerulotropin',
#   '1-methyl-6-methoxy-tetrahydro-beta-carboline',
#   '1-me-6-mthbc',
#   '1-methyl-6-methoxy-1,2,3,4-tetrahydro-2- carboline',
#   '6-methoxy-1-methyl-1,2,3,4-tetrahydro-beta-carboline'],
#  'MESH:C000039': ['alpha-amino-4-isothiazolylacetic acid',
#   '4-isothiazoleacetic acid, alpha-amino-'],
#  'MESH:C000045': ['4-cinnamylphenol',
#   'obtusastyrene',
#   'obtusastyrene, (e)-isomer'],
#  'MESH:C000047': ['albitocin'],
#  'MESH:C000050': ['alisol a'],
#  'MESH:C000055': ['alloclamide',
#   '2-allyloxy-4-chloro-n-(2-diethylaminoethyl)benzamide',
#   'hexacol',
#   '264 ce',
#   'alloclamide hydrochloride'],
#  'MESH:C000056': ['264 cp',
#   '2-allyloxy-4-chloro-n-(2-piperidinoethyl)benzamide'],
#  'MESH:C000058': ['alytesin',
#   'pgly-arg-leu-gly-thr-gln-trp-ala-val-gly-his-leu-met-nh2'],
#  'MESH:C000059': ['ametohepazone',
#   '2(1h)-cycloheptimidazolone, 1-(2-(dimethylamino)ethyl)-'],
#  'MESH:C000060': ['9-(3-(aden-9-yl)propyl)-2-dimethylaminopurin-6-one'],
#  'MESH:C000061': ['allysine',
#   '2-aminoadipate semialdehyde',
#   'alpha-aminoadipic semialdehyde',
#   'alpha-aasa',
#   'alpha-aminoadipate semialdehyde',
#   '2-aminoadipic semialdehyde'],
#  'MESH:C000062': ['2-aminobenzaldehyde',
#   'ortho aminobenzaldehyde',
#   'o-aminobenzaldehyde'],
#  'MESH:C000063': ['thiozamin',
#   "p-(p'-aminobenzenesulfonyl)benzaldehyde thiosemicarbazone"],
#  'MESH:C000064': ['putreanine', 'n-(4-aminobutyl)-3-aminopropionic acid'],
#  'MESH:C000066': ['aminocinnamonitrile'],
#  'MESH:C000075': ['agr 307',
#   '2-amino-(isothioureyl methylene)-4-thiazole dihydrochloride',
#   'agr 307, dihydrochloride',
#   'agr 307, monohydrochloride'],
#  'MESH:C000076': ['2-amino-5-hydroxyacetophenone'],
#  'MESH:C000077': ['amylosubtilin g10x'],
#  'MESH:C000078': ['9-ama', '9-aminomethylacridan'],
#  'MESH:C000080': ['phenpentermine', '2-amino-2-methyl-3-phenylbutane'],
#  'MESH:C000081': ['4-methylaminorex',
#   '2-amino-4-methyl- 5-phenyloxazoline',
#   '4,5-dihydro-4-methyl-5-phenyl-2-oxazolamine',
#   'u4euh',
#   '4-methyl-5-phenyl-4,5-dihydro-1,3-oxazol-2-amine',
#   '4-methylaminorex, (4s-trans)-isomer',
#   '4-methylaminorex, (4s,5s)-',
#   '4-methylaminorex, cis-(+-)-isomer',
#   '4-methylaminorex, cis-(+,-)-',
#   '4-methylaminorex, monohydrobromide salt, (z)-(+-)-isomer',
#   '4-methylaminorex, (4s-cis)-isomer',
#   '4-methylaminorex, (4s,5r)-',
#   'mcn 822',
#   'mcn-822'],
#  'MESH:C000082': ['alanosine',
#   'l-2-amino-3-(n-nitroso)hydroxylaminopropionic acid',
#   'l-alanosine',
#   'nsc 153,353',
#   'nsc 153353',
#   'sdx 102',
#   'sdx-102',
#   'sdx102'],
#  'MESH:C000085': ['ab-15',
#   'ab 15',
#   '1-(m-aminophenyl)-2-cyclopropylaminoethanol.2hcl',
#   '3-amino-alpha-((cyclopropylamino)methyl)benzenemethanol, dihydrochloride'],
#  'MESH:C000086': ['aminotridecane adipate'],
#  'MESH:C000088': ['alpha-amino-2-xylene', 'alpha-amino-o-xylene'],
#  'MESH:C000089': ['ammeline', '4,6-diamino-1,3,5-triazin-2(1h)-one'],
#  'MESH:C000090': ['galactaric acid',
#   'mucic acid',
#   'strontium galactarate mono-hydrate',
#   'galactaric acid, sodium salt'],
#  'MESH:C000096': ['1,5-anhydroglucitol-6-phosphate'],
#  'MESH:C000097': ['anticapsin'],
#  'MESH:C000100': ['aquayamycin',
#   "9-(tetrahydro-4',5'-dihydroxy-6'-methyl-2'h-pyran-2'-yl)-3,4,4a,12b-tetrahydro-3,4a,8,12b-tetrahydroxy-3-methyl-benz(a)anthracene-1,7,12(2h)-trione"],
#  'MESH:C000101': ['ara-atp',
#   'ara atp',
#   "9 beta-d-arabinofuranosyladenine 5'-triphosphate",
#   '9h-purin-6-amine, 9-(5-o-(hydroxy(hydroxy(phosphonooxy)phosphinyl)phosphinyl)-beta-d-arabinofuranosyl)-',
#   'arabinofuranosyladenine triphosphate'],
#  'MESH:C000102': ['arachin'],
#  'MESH:C000105': ['arylid', "4',5-dichlorosalicylanilide"],
#  'MESH:C000106': ['ascumist',
#   'ascorbic acid, copper sulfate, sodium percarbonate drug combination',
#   'ascorbic acid - copper sulfate - sodium percarbonate'],
#  'MESH:C000107': ['aspartic acid-beta-4-nitroanilide, sodium salt',
#   'suosan',
#   'aspartic acid-beta-4-nitroanilide',
#   "n-(4-nitrophenyl)-n'-(carboxyethyl)urea",
#   'aspartic acid-beta-p-nitroanilide'],
#  'MESH:C000108': ['astonilin',
#   '7h-benz(g)indolo(2,3-a)quinolizin-6-ium, 8,13-dihydro-11-methoxy-1-(methoxycarbonyl)-',
#   'alstoniline'],
#  'MESH:C000109': ['azabicyclane', 'azabicyclane citrate'],
#  'MESH:C000110': ['2-azacyclooctanone',
#   'oenantholactam',
#   'cyclo-aha',
#   'cyclo-omega-heptanoic acid'],
#  'MESH:C000111': ['azaleucine', '2-amino-3-dimethylaminopropionic acid'],
#  'MESH:C000115': ['jaligonic acid',
#   '(2 beta,3 beta,4 alpha,20 beta)-2,3,23-trihydroxy- olean-12-ene-28,29-dioic acid'],
#  'MESH:C000119': ['bactoprenylpyrophosphate',
#   'diphosphoric acid, mono(3,7,11,15,19,23,27,31,35,39,43-undecamethyl-6,10,14,18,22,26,30,34,38,42-tetratetracontadecaenyl) ester'],
#  'MESH:C000121': ['pipoxolan',
#   '5,5-diphenyl-2-(beta-n-piperidinoethyl)-1,3-dioxolan-4-one',
#   'br 18',
#   'br-18',
#   'rowapraxin',
#   'pipoxolan monohydrochloride'],
#  'MESH:C000123': ['bendazac',
#   'bendazolic acid',
#   '1-benzylindazole-3-oxyacetic acid',
#   'bindazac',
#   'bendazolic acid, sodium salt'],
#  'MESH:C000124': ['benfurodil',
#   '2-(1-succinyloxyethyl)-3-methyl-5-(2-oxo-2,5-dihydro-4-furyl)benzo(b)furan',
#   'cb 4091',
#   'eucilat',
#   'eudilat',
#   'benfurodil hemisuccinate'],
#  'MESH:C000128': ['rubiflavin'],
#  'MESH:C000132': ['pseudourea',
#   "2,2'-(9,10-anthrylenedimethylene)bis(2-thiopseudourea)",
#   'nsc-56054'],
#  'MESH:C000133': ['y 3506',
#   'y-3506',
#   '1-thia-4,8-diazaspiro(4.5)decan-3-one, 8-(1,4-benzodioxan-2-ylmethyl)-, (z)-2-butenedioate (1:1)',
#   '8-((1,4-benzodioxan-2-yl)methyl)-3-oxo-1-thia-4,8-diazaspiro(4,5)decane maleate'],
#  'MESH:C000134': ['benzofurylethylidine-methyl-triphenylphosphonium iodide',
#   'sh-24',
#   'sh 24'],
#  'MESH:C000136': ['benzo-tepa',
#   'benzotef',
#   'n-(bis(1-aziridinyl)phosphinyl)benzamide'],
#  'MESH:C000137': ['paraflutizide',
#   '6-chloro-3-(p-fluorobenzyl)-3,4-dihydro-2h-1,2,4- benzothiadiazine-7-sulfonamide, 1,1-dioxide'],
#  'MESH:C000140': ['hm 197', 'hm-197', '5-benzoyl-2-iminohexahydropyrimidine'],
#  'MESH:C000143': ['1-(3-aminophenyl)flavazole',
#   '1-(m-aminophenyl)-1h-pyrazolo(3,4-b)quinoxaline',
#   '1-(m-aminophenyl)flavazole'],
#  'MESH:C000144': ['avcothane',
#   'cardiothane',
#   'avcothane 51',
#   'avcothane-51',
#   'cardiothane 51'],
#  'MESH:C000146': ['bactoprenol'],
#  'MESH:C000147': ['cafedrine - theodrenaline',
#   '1h-purine-2,6-dione, 3,7-dihydro-7-(2-((2-hydroxy-1-methyl-2-phenylethyl)amino)ethyl)-1,3-dimethyl-, monohydrochloride, (r-(r*,s*))-, mixt. with 7-(2-((2-(3,4-dihydroxyphenyl)-2-hydroxyethyl)amino)ethyl)-3,7-dihydro-1,3-dimethyl-1h-purine-2,6-dione monohydrochloride',
#   'cafedrine, theodrenaline drug combination',
#   'h-835',
#   'praxinor',
#   'akrinor',
#   'acrinor'],
#  'MESH:C000148': ['4-aminotetrolic acid', '4-aminobut-2-ynoic acid'],
#  'MESH:C000149': ['8-azahypoxanthine'],
#  'MESH:C000150': ['2-azacyclononanone'],
#  'MESH:C000152': ['androsta-5,16-dien-3 beta-ol',
#   '5,16-androstadien-3 beta-ol',
#   'andien-beta',
#   'androstadienol'],
#  'MESH:C000153': ['amylopectin sulfate', 'gastramyl', 'sn-263'],
#  'MESH:C000154': ['alpinumisoflavone',
#   '5-hydroxy-7-(p-hydroxyphenyl)-2,2-dimethyl-2h-6h-benzodipyran-6-one'],
#  'MESH:C000156': ['n-acetylglucosaminuronic acid',
#   'd-glucuronic acid, 2-(acetylamino)-2-deoxy-'],
#  'MESH:C000162': ['benzyldihydronicotinamide',
#   '1-benzyl-3-carbamido-1,4-dihydropyridine'],
#  'MESH:C000164': ['1-benzylindole'],
#  'MESH:C000165': ['ex-10-542a',
#   '5-benzyl-11-(4-n-methyl piperidylene)-5,6-dihydromorphanthridine hydrogen maleate'],
#  'MESH:C000166': ['benzylthioguanosine'],
#  'MESH:C000167': ['s-benzylthioisothiourea',
#   'carbamo(dithioperox)imidic acid, phenylmethyl ester'],
#  'MESH:C000168': ['benzyltrimethylammonium',
#   'benzenemethanaminium, n,n,n-trimethyl-',
#   'benzyltrimethylammonium bromide',
#   'benzyltrimethylammonium hydroxide',
#   'benzyltrimethylammonium methoxide',
#   'benzyltrimethylammonium acetate',
#   'benzyltrimethylammonium iodide',
#   'benzyltrimethylammonium chloride',
#   'benzyltrimethylammonium formate',
#   'benzyltrimethylammonium propanoate',
#   'benzyltrimethylammonium pentanoate',
#   'benzyltrimethylammonium hexanoate',
#   'benzyltrimethylammonium heptanoate',
#   'benzyltrimethylammonium octanoate',
#   'benzyltrimethylammonium nonanoate',
#   'benzyltrimethylammonium butanoate',
#   'benzyltrimethylammonium hexafluorophosphate (1-)',
#   'benzyltrimethylammonium carbonate (2:1)'],
#  'MESH:C000170': ['ferric ferrocyanide',
#   'ferrocin',
#   'berlin blue',
#   'ferrihexacyanoferrate',
#   'ferrotsin',
#   'prussian blue'],
#  'MESH:C000171': ['dixanthogen',
#   'bisethylxanthogen',
#   'diethyl dithiobis(thionoformate)',
#   'ethyl xanthogen disulfide',
#   'o,o-diethyl dithiobis(thioformate)',
#   'o,o-diethyl dithiobisthioformate',
#   'diexanthogen',
#   'auligen',
#   'bexide',
#   'exd',
#   'herbisan',
#   'sulfasan'],
#  'MESH:C000174': ['ici 58301',
#   'ici-58301',
#   '3-acetamido-6-methyl-8-n-propyl-s-triazolo(4,3 alpha)pyrazine'],
#  'MESH:C000179': ['n-acetylaspartate',
#   'n-acetyl-l-aspartate',
#   'n-acetyl aspartate',
#   'n-acetylaspartic acid',
#   'n-acetylaspartate, monopotassium salt',
#   'acetyl aspartic acid'],
#  'MESH:C000182': ['n-acetyldehydrophenylalanylproline diketopiperazine',
#   'pyrrolo(1,2-a)pyrazine-1,4-dione, 2-acetylhexahydro-3-(phenylmethylene)-',
#   'n-acetyldehydro-phe-pro diketopiperazine',
#   'n-acetyldehydrophenylalanyl-l-proline diketopiperazine'],
#  'MESH:C000183': ['alpha-acetylthiol-3-toluenediazonium',
#   'benzenediazonium, 3-((acetylthio)methyl)-',
#   'alpha-acetylthio-m-toluenediazonium'],
#  'MESH:C000185': ['acrofol', '3-chloro-2-ene-propionic acid'],
#  'MESH:C000188': ['alachlor',
#   '2-chloro-n-(2,6-diethylphenyl)-n-(methoxymethyl)acetamide',
#   'metachlor'],
#  'MESH:C000190': ['allerglobulin'],
#  'MESH:C000192': ['valofane',
#   '2-allophenyl-2-allyl-gamma-valerolactone',
#   '3-furancarboxamide, n-(aminocarbonyl)tetrahydro-5-methyl-2-oxo-3-(2-propenyl)-',
#   'allophanyl allyl valerolactone',
#   'allophanyl-1-allyl-1-valero-3-lactone',
#   'alpha-allyl-alpha-allophanyl-gamma-valerolactone',
#   'alpha-allophanyl-alpha-allyl-gamma-valerolactone',
#   'valofan',
#   'hh 10018',
#   'valofane, (trans)-isomer',
#   'valofane, (cis)-isomer'],
#  'MESH:C000194': ['vufb 7319',
#   'vufb-7319',
#   'n(1)-allylthiocarbamoyl-n(2)-methylthiocarbamoylhydrazine',
#   "1,2-hydrazinedicarbothioamide, n-methyl-n'-2-propenyl-"],
#  'MESH:C000196': ['amadinone',
#   '6-chloro-17-acetoxy-19-norpregnane-4,6-diene-3,20-dione'],
#  'MESH:C000197': ['3-aminobenzotrifluoride',
#   'm-aminobenzotrifluoride',
#   '3-trifluoromethylaniline'],
#  'MESH:C000198': ['2-amino-3-benzyl-5-(p-hydroxyphenyl)pyrazine',
#   'phenol, 4-(5-amino-6-(phenylmethyl)pyrazinyl)-',
#   'af 350',
#   'af-350',
#   'af350'],
#  'MESH:C000199': ['nsc 86047',
#   'nsc-86047',
#   '4-amino-n-butyl-1,1,2,5-selenadiazole-3-carboxamide'],
#  'MESH:C000200': ['2-amino-4-carbamyl-6-methoxy-4-methyltetralin',
#   '1-naphthalenecarboxamide, 3-amino-1,2,3,4-tetrahydro-7-methoxy-1-methyl-',
#   'acmmt'],
#  'MESH:C000201': ['a16886a',
#   '5-thia-1-azabicyclo(4.2.0)oct-2-ene-2-carboxylic acid, 3-(((aminocarbonyl)oxy)methyl)-7-((5-amino-5-carboxy-1-oxopentyl)amino)-8-oxo-, (6r-(6alpha,7beta(r*)))-',
#   '(7-(5-amino-5-carboxyvaleramido)-3-carbamoyloxymethyl-3-cephem-4-carboxylic acid)'],
#  'MESH:C000202': ['2-amino-4-chlorobenzenethiol'],
#  'MESH:C000203': ['deoxyaminopteroic acid',
#   '4-deoxy-4-amino-n(10)-methylpteroic acid',
#   '4-amino-4-deoxy-n-10-methylpteroic acid',
#   '4-amino-4-deoxy-n 10-methylpteroic acid',
#   '2,4-diamino-n(10)-methylpteroic acid',
#   '4-(((2,4-diamino-6-pteridinyl)methyl)methylamino)benzoic acid',
#   '2,4-diamino-n10-methylpteroic acid',
#   'n-10-methyl-4-deoxy-4-aminopteroate',
#   '4-amino-4-deoxy-n-10-methylpteroic acid hydrochloride (2:1)'],
#  'MESH:C000204': ['s-2-aminoethyl cysteine',
#   'aminoethylcysteine',
#   's-(2-aminoethyl)-l-cysteine',
#   's-beta-aminoethyl cysteine',
#   'thialysine',
#   'thiosine',
#   'gamma-thia-lys',
#   'gamma-thialysine',
#   '4-thialysine',
#   's-2-aminoethyl cysteine hydrochloride',
#   's-2-aminoethyl cysteine monohydrochloride',
#   's-2-aminoethyl cysteine dihydrochloride',
#   '4-thia-l-lysine'],
#  'MESH:C000205': ['l-alpha-amino-gamma-guanidinobutyrate'],
#  'MESH:C000206': ['uvitex swn', '8-amino-4-methylcoumarin', 'swn'],
#  'MESH:C000207': ['2-amino-4-methyl-5-hexenoic acid',
#   'l-2-amino-4-methyl-5-hexenoic acid'],
#  'MESH:C000209': ['3-amino-2-oxazolidinone', '3-amino-2-oxazolidone'],
#  'MESH:C000210': ['2-amino-4-phenylsulfonylbenzenesulfonamide', 'nsd 3004'],
#  'MESH:C000211': ['2-amino-3-phosphonopropionic acid',
#   '2-amino-3-phosprop',
#   'alanine, 3-phosphono-',
#   '2-amino-3-phosphono-propionic acid',
#   '2-amino-3-phosphopropionic acid',
#   '2-amino-3-phosphonopropionate',
#   'l-ap3',
#   '2-ap3',
#   'phosphonoalanine',
#   '2-amino-3-phosphonopropionic acid, (dl)-isomer',
#   '2-amino-3-phosphonopropionic acid, sodium salt',
#   '3-phosphonoalanine',
#   '3-phosphono-l-alanine'],
#  'MESH:C000212': ['ammoniacal silver'],
#  'MESH:C000213': ['amyloxycarbonyl tetrapeptide',
#   'amyloxycarbonyltetrapeptide'],
#  'MESH:C000214': ['androst-16-en-3-one',
#   '5 alpha-androst-16-en-3-one',
#   '5alpha-androst-16-en-3-one',
#   'aeon steroid',
#   'androst-16-en-3-one, (5beta)-isomer'],
#  'MESH:C000215': ['angustibalin'],
#  'MESH:C000217': ['antagosan', 'antagosin'],
#  'MESH:C000218': ['antradion',
#   'benzoic acid, 2-(((4-butyl-3,5-dioxo-1,2-diphenyl-4-pyrazolidinyl)phenylmethyl)amino)-',
#   '1,2-diphenyl-4h-butyl-(4-orthocarboxyanilinobenzyl)-3,5-pyrazolidinedione',
#   'anthradion'],
#  'MESH:C000219': ['anthranilamide',
#   '2-aminobenzamide',
#   'ortho-aminobenzamide'],
#  'MESH:C000225': ['argininic acid'],
#  'MESH:C000226': ['arglecin',
#   '6-(3-guanidino-propyl)-3-isobutyl-2-(1h)- pyrazinone'],
#  'MESH:C000227': ['mild silver protein',
#   'mild silver proteinate',
#   'silver vitellinate',
#   'argyrol'],
#  'MESH:C000228': ['aristolochic acid i',
#   '8-methoxy-6-nitrophenanthro(3,4-d)-1,3-dioxole-5-carboxylic acid',
#   'aristolochic acid',
#   'aristolochic acid a',
#   'tardolyt',
#   'aristolochic acid i, sodium salt',
#   'sodium aristolochate'],
#  'MESH:C000229': ['tyrosine-4-azobenzenearsonate',
#   'aba-t',
#   'arsanilazotyrosine',
#   'l-tyrosine, 3-((4-arsonophenyl)azo)-',
#   'l-tyrosine-4-azobenzenearsonate',
#   'l-tyrosine-p-azobenzenearsonate',
#   'azobenzenarsonate-tyrosine'],
#  'MESH:C000231': ['azacrin',
#   '2-methoxy-7-chloro-10-(4-(diethylamino-1-methyl)butylamino)pyrido(3,2-b)quinoline'],
#  'MESH:C000232': ['azalomycin-f', 'azalomycin f'],
#  'MESH:C000234': ['azobenzenearsonate-n-acetyl-l-tyrosine',
#   'aba-nat',
#   'l-tyrosine, n-acetyl-3-((4-arsonophenyl)azo)-'],
#  'MESH:C000236': ['methylglyoxal-ascorbate',
#   'mgx-asc',
#   'methylglyoxal-ascorbate condensation complex',
#   'methylglyoxal-ascorbate condensation product'],
#  'MESH:C000240': ['nsc 84963',
#   'nsc-84963',
#   '4-amino-1,2,5-selenadiazole-3-carboxamide'],
#  'MESH:C000241': ['carbanolate',
#   '2-chloro-4,5-dimethylphenyl-n-methylcarbamate',
#   'banol'],
#  'MESH:C000242': ['bendigon',
#   'bay mc 4540',
#   'inositol nicotinate, mefruside, reserpine drug combination',
#   'inositol nicotinate - mefruside - reserpine'],
#  'MESH:C000245': ['n-(4-(2-benzimidazolyl)phenyl)maleimide',
#   '1h-pyrrole-2,5-dione, 1-(4-(1h-benzimidazol-2-yl)phenyl)-',
#   'bp-mal',
#   'n-(p-(2-benzimidazolyl)phenyl)maleimide',
#   'n-(p-(benzimidazol-2-yl)phenyl)maleimide',
#   'acetylethyleneimine',
#   'bipm cpd'],
#  'MESH:C000249': ['benzylsuccinic acid'],
#  'MESH:C000250': ['1-benzyl-2-thio-5,6-dihydrouracil'],
#  'MESH:C000252': ['betalamic acid'],
#  'MESH:C000253': ['bicyclophenamine',
#   '2-phenylbicyclo(2.2.1)heptane-2-carboxylic acid beta-pyrrolidinoethyl ester'],
#  'MESH:C000257': ['polymacon',
#   'soflens',
#   'spheron 300',
#   'polyhydroxyethyl methacrylate hydrogels',
#   'polyhydroxyethylmethacrylate hydrogel',
#   '2-hydroxyethyl methacrylate, n-vinyl pyrrolidone and 4-tertiary butyl-2-hydroxycyclohexyl methacrylate hydrogel'],
#  'MESH:C000259': ['orazamide',
#   '1,2,3,6-tetrahydro-2,6-dioxo-4-pyrimidinecarboxylic acid cpd with 5-amino-1h-imidazole-4-carboxamide',
#   '4(5)-aminoimidazole-5(4)-carboxamide orotic acid salt',
#   'aica orotate',
#   'orazamid',
#   'aicamine'],
#  'MESH:C000261': ['n-acetylethyleneimine'],
#  'MESH:C000263': ['s-adchnon',
#   'adrenochrome monoaminoguanidine methanesulfonate',
#   'adrenochrome monoguanylhydrazone methanesulfonate',
#   'adrenochrome derivative (amm)'],
#  'MESH:C000264': ['2-amino-4-methoxy-3-butenoic acid',
#   'l-2-amino-4-methoxy-trans-3-butenoic acid',
#   '2-amino-4-methoxy-3-butenoic acid, (e)-isomer'],
#  'MESH:C000265': ['beta-amyrin acetate', '(3beta)-olean-12-en-3-yl acetate'],
#  'MESH:C000266': ['arabinosone',
#   'd-erythro-pentos-2-ulose',
#   'd-arabinosone',
#   'arabinosone, (l)-isomer'],
#  'MESH:C000269': ['bikaverin',
#   '7,10-dihydro-6,11-dihydroxy-3,8-dimethoxy-1-methyl-12h-benzo(b)xanthene-7,10,12-trione'],
#  'MESH:C000272': ["n,n'-bis(4-aminophenyl)-n,n'-dimethylethylenediamine",
#   "1,4-benzenediamine, n,n''-1,2-ethanediylbis(n-methyl-)"],
#  'MESH:C000273': ["n,n'-bis(4-aminophenyl)-1,3-xylylenediamine",
#   "1,3-benzenedimethanamine, n,n'-bis(4-aminophenyl)-",
#   "n,n'-bis(4-aminophenyl)-1,3-xylylene-diamine"],
#  'MESH:C000275': ["n,n'-bis(gamma-aminopropyl)diaminoethane"],
#  'MESH:C000277': ['el 241',
#   'el-241',
#   'alpha-alpha-bis(p-chlorophenyl)-3-pyridine methanol'],
#  'MESH:C000278': ["1,1'-bis(l-alpha,beta-diaminopropionic acid)actinomycin d",
#   "(di(1'-l-alpha,beta-diaminopropionic acid))actinomycin d",
#   "(di(1'-l-alpha,beta-diaminopionic acid))actinomycin d"],
#  'MESH:C000279': ['diazan', '1,2-bis(diazoacetyl)ethane', 'diazane'],
#  'MESH:C000283': ['1,2-bis(3,5-dioxopiperazin-1-yl)ethane',
#   'icrf 154',
#   'icrf-154'],
#  'MESH:C000287': ['bis(3-hydroxypropyl)trisulfide'],
#  'MESH:C000288': ['ritrosulfan',
#   "1,4-bis(2'-mesyloxyethylamino)-1,4-dideoxy-meso-erythritol",
#   'dimesylerythritol',
#   'lycurim',
#   'lykurim',
#   'ritosulfan',
#   'r-74',
#   'ritrosulfan, dihydrochloride, (r*,s*)-isomer',
#   'ritrosulfan, dimethanesulfonate, (r*,s*)-isomer',
#   'ritrosulfan, (r*,s*)-isomer, 14c-labeled'],
#  'MESH:C000290': ['ro 8-2580',
#   '1,3-bis(4-(p-methoxyphenyl)piperazinyl)-2-propanol'],
#  'MESH:C000291': ["n,n'-bis(1-naphthylmethyl)-1,4-cyclohexanebis(methylamine).2hcl",
#   'ay 9928',
#   'ay-9928',
#   "1,4-cyclohexanedimethanamine, n,n'-bis(1-naphthalenylmethyl)-, dihydrochloride",
#   'ay 9928, dihydrochloride, (cis)-isomer',
#   'ay 9928, dihydrochloride, (trans)-isomer'],
#  'MESH:C000293': ['bisnoryangonin', '4-hydroxy-6-(4-hydroxystyryl)-2-pyrone'],
#  'MESH:C000294': ['hexachloro-4-xylene',
#   '1,4-bis(trichloromethyl)benzene',
#   'chloxyl',
#   'hexachloro-p-xylene',
#   'hexachloroparaxylol',
#   'hetol'],
#  'MESH:C000295': ['bis-q',
#   "3,3'-bis(alpha-(trimethylammonium)methyl)azobenzene",
#   'bis-q dibromide',
#   "trans-3,3'-bis(alpha-(trimethylammonium)methyl)azobenzene dibromide",
#   'bis-q dibromide, (e)-isomer',
#   'bis-q, (e)-isomer',
#   'bis-q dibromide, (z)-isomer',
#   'bis-q, (z)-isomer'],
#  'MESH:C000296': ['1,5-bis(4-trimethylammoniumphenyl)pentan-3-one diiodide',
#   '1,5-bis(4-trimethylammoniumphenyl)pentan-3-one',
#   'btapp-3'],
#  'MESH:C000297': ['bithionol sulfoxide',
#   'bis(2-hydroxy-3,5-dichlorophenyl)sulfoxide',
#   'bis(3,5-dichloro-2-hydroxyphenyl)sulfoxide',
#   'bitin-s',
#   'bithionol sulfoxide, monosodium salt'],
#  'MESH:C000298': ['c.i.(1956) no. 28440',
#   'brilliant black 1',
#   '2-(4-(p-sulfophenylazo)-7-sulfo-1-naphthylazo)-8-acetamido-1-naphthol-3,5-di-sulonic acid, tetrasodium salt',
#   'black pn',
#   'brilliant black bn'],
#  'MESH:C000299': ['blankophor fbo'],
#  'MESH:C000301': ['borgal',
#   'ro 6-2153',
#   'trimethoprim, sulfadoxine drug combination',
#   'trimethoprim-sulfadoxine drug combination',
#   'tridoxine',
#   'trimethoprim-sulfadoxine',
#   'trimethoprim - sulfadoxine'],
#  'MESH:C000302': ['boromycin'],
#  'MESH:C000307': ['broadcillin',
#   '4-thia-1-azabicyclo(3.2.0)heptane-2-carboxylic acid, 6-((aminophenylacetyl)amino)-3,3-dimethyl-7-oxo-, (2s-(2alpha,5alpha,6beta(s*)))-, mixt. with (2s-(2alpha,5alpha,6beta))-3,3-dimethyl-6-(((5-methyl-3-phenyl-4-isoxazolyl)carbonyl)amino)-7-oxo-4-thia-1-azabicyclo(3.2.0)heptane-2-carboxylic acid',
#   'ampiox'],
#  'MESH:C000309': ['2-bromoacetamide-4-nitrophenol'],
#  'MESH:C000310': ['3-bromoacetonyl trimethylammonium',
#   'bromo acetonyl trimethylammonium',
#   'bromoacetonyl trimethylammonium',
#   '3-bromoacetonyl trimethylammonium bromide'],
#  'MESH:C000311': ['16 alpha-bromoacetoxyprogesterone',
#   '16alpha-bromoacetoxyprogesterone'],
#  'MESH:C000312': ['4-bromobenzylisothiocyanate',
#   '4-bromobenzyl-isothiocyanate'],
#  'MESH:C000314': ['alpha-bromo-beta-(5-imidazolyl)propionic acid',
#   'alpha-bromo-beta-(5-imidazolyl) propionic acid',
#   'alpha-bromo-beta-(5-imidazolyl)-propionic acid',
#   'd,l-alpha-bromo-beta-(5-imidazolyl)propionic acid',
#   '2-bromo-3-(5-imidazolyl)propionate'],
#  'MESH:C000316': ['1-bromomercuri-2-hydroxypropane',
#   'bromomercurihydroxypropane',
#   'bmhp',
#   '1-bromomercuri-2-hydroxypropane, 197hg-labeled',
#   '1-bromomercuri-2-hydroxypropane, 203hg-labeled'],
#  'MESH:C000317': ['4-bromomethyl-7-methoxycoumarin',
#   '4-bromomethyl-7-methoxy-2-oxo-2h-benzopyran',
#   '4-(bromomethyl)-7-methoxy-2-oxo-2h-benzopyran'],
#  'MESH:C000318': ['4-bromopyrazole'],
#  'MESH:C000320': ['2-bromostearic acid',
#   '2-bromostearate',
#   '2-bromostearic acid, potassium salt',
#   '2-bromostearic acid, 77br-labeled'],
#  'MESH:C000323': ['bromotubercidin', '5-bromotubericidin'],
#  'MESH:C000324': ['brown fk', 'brown-fk'],
#  'MESH:C000325': ['brufacaine',
#   'glycerol-1-(2-diethylaminoethyl ether)-3-(2-methoxyphenyl ether).hcl',
#   'brufacaine hydrochloride'],
#  'MESH:C000327': ['atropine, pralidoxime iodide, trichlorofon drug combination',
#   'atropine - pralidoxime iodide - trichlorofon',
#   'bubulin'],
#  'MESH:C000329': ['bufeniode',
#   '1-(4-hydroxy-3,5-diiodophenyl)-2-(1-methyl-3-phenylpropylamino)propanol',
#   'diiodobufenine',
#   'diiodobuphenine',
#   'proclival'],
#  'MESH:C000330': ['bulbiformin'],
#  'MESH:C000334': ['butanediol divinylether'],
#  'MESH:C000335': ['butanesultone', '1,4-butane sultone'],
#  'MESH:C000336': ['ls 701',
#   'ls-701',
#   'butazidamine',
#   '3h-pyrazol-3-one, 4-butyl-1,2-dihydro-5-hydroxy-1,2-diphenyl-, compd. with 3-(3-(dimethylamino)propoxy)-1-(phenylmethyl)-1h-indazole (1:1)',
#   '4-butyl-1,2-diphenyl-5-hydroxy-3-oxo-pyrazolidine compd. with 1-benzyl-3,3-(dimethylamino)propoxy-1h-indazole'],
#  'MESH:C000339': ['wr 10488',
#   'wr-10488',
#   '2-n-butoxy-7,10-dichloropyrido(3,2-b)quinoline',
#   'wr 10,488'],
#  'MESH:C000343': ['n-t-butyl-5-methyl isoxazolium perchlorate',
#   'n,t-butyl-5-methyl isoxazolium perchlorate'],
#  'MESH:C000345': ['t-butyloxycarbonyl group',
#   'boc group',
#   'butyloxycarbonyl group'],
#  'MESH:C000347': ['ap-237',
#   'ap 237',
#   '1-n-butyryl-4-cinnamylpiperazine',
#   '1-n-butyryl-4-cinnamylpiperazine hydrochloride',
#   'bucinnazine hydrochloride',
#   '1-(1-oxobutyl)-4-(3-phenyl-2-propenyl)piperazine hydrochloride'],
#  'MESH:C000349': ['buffencarb'],
#  'MESH:C000352': ['elenolic acid',
#   '3-formyl-3,4-dihydro-5-(methoxycarbonyl)-2-methyl-2h-pyran-4-acetic acid',
#   'calcium elenolate',
#   'elenolic acid, calcium (2:1) salt, (2s-(2alpha,3alpha,4beta))-isomer',
#   'elenolic acid ca salt, (2s-(2alpha,3alpha,4beta))-isomer'],
#  'MESH:C000353': ['calcium lignosulfonate',
#   'calcium lignin sulfonate',
#   'calcium lignosulfonate (2000 mw)'],
#  'MESH:C000354': ['bifidus factor', 'calcium d-pantotheine-s-sulfonate'],
#  'MESH:C000357': ['cannabivarin'],
#  'MESH:C000360': ['caproamide', 'hexanamide'],
#  'MESH:C000361': ['caprogen'],
#  'MESH:C000362': ['capron',
#   'poly(hexahydro-2h-azepin-2-one)',
#   'polycaprolactam'],
#  'MESH:C000363': ['cycloheptanone'],
#  'MESH:C000364': ['captostibone (g)',
#   'sodium 2-(carboxymethylmercapto)benzene stibonate'],
#  'MESH:C000366': ['o-carbamylserine',
#   'o-carbamyl-d-serine',
#   'o-carbamylserine, (l)-isomer'],
#  'MESH:C000375': ['3-carboxy-4-ferrocenylphenyl isothiocyanate'],
#  'MESH:C000380': ['fosfosal',
#   '2-carboxyphenylphosphoric acid',
#   '2-phosphonoxybenzoic acid',
#   'benzoic acid, 2-(phosphonooxy)-',
#   'o-carboxyphenylphosphate',
#   'o-carboxyphenylphosphoric acid',
#   'o-carboxyphenyl phosphate',
#   'o-cpp cpd',
#   'aydolid',
#   'disdolen',
#   'protalgia'],
#  'MESH:C000384': ['carinamide',
#   'p-(benzylsulfamido)benzoic acid',
#   "4'-carboxyphenylmethanesulfonanilide"],
#  'MESH:C000387': ['carminagel'],
#  'MESH:C000390': ['carnitylcholine'],
#  'MESH:C000392': ['caulerpin'],
#  'MESH:C000393': ['cedrene', 'cedrone', 'alpha-cedrene', 'beta-cedrene'],
#  'MESH:C000395': ['cephachlomezine',
#   '7-(m-chlorophenylacetamido)-3-(4,4-dimethylpiperazinium-1-thiocarbonyl-thiomethyl)-3-cephem-4-carboxylate'],
#  'MESH:C000400': ['chelocardin',
#   '2-decarboxamido-2-acetyl-4-dedimethylamino-4-epiamino-9- methyl-5a,6-anhydrotetracycline',
#   'cetocycline',
#   'cetotetrine',
#   'abbott 40728',
#   'chelocardin, (4alpha,4abeta,12abeta)-isomer',
#   'chelocardin, hydrochloride, (4r-(4alpha,4abeta,12abeta))-isomer',
#   'chelocardin, monosodium salt, (4r-(4alpha,4abeta,12abeta))-isomer'],
#  'MESH:C000402': ['chinophene'],
#  'MESH:C000403': ['1-chloro-benzotriazole'],
#  'MESH:C000404': ['2-chloro-4-acetotoluidine', '2-chloro-p-acetotoluidide'],
#  'MESH:C000405': ['bw 63-307',
#   'bw-63-307',
#   '2-chloro-4-acetylaminobenzonitrile'],
#  'MESH:C000406': ['chlorohexamide',
#   'chlorobenzenesulfonylcyclohexylcarbamide',
#   'oradian'],
#  'MESH:C000407': ['4-chlorobenzenesulfonylglycolic acid amide',
#   'p-chlorobenzenesulfonylglycolic acid amide'],
#  'MESH:C000408': ['4-chlorobenzenesulfonylglycolic acid nitrile',
#   'p-chlorobenzenesulfonylglycolic acid nitrile'],
#  'MESH:C000409': ['landromil',
#   'ticlatone',
#   '6-chloro-1,2-benzisothiazolone',
#   'tiklaton',
#   'fer 1443',
#   'fer-1443'],
#  'MESH:C000410': ['1-(4-chlorobenzoyl)-5-dimethylamino-2-methylindole acetic acid',
#   '1h-indole-3-acetic acid, 1-(4-chlorobenzoyl)-5-(dimethylamino)-2-methyl-',
#   '1-(p-chlorobenzoyl)-5-dimethylamino-2-methylindole acetic acid',
#   '1-(4-chlorobenzoyl)-5-dimethylamino-2-methylindole-3-acetic acid'],
#  'MESH:C000411': ['bw 392c60',
#   'bw-392c60',
#   "n-(o-chlorobenzyl)-n',n''-dimethylguanidine sulfate",
#   'bw 392c60, monohydroiodide',
#   'bw 392c60 sulfate (2:1)'],
#  'MESH:C000413': ['1-(4-chlorobenzylidine)-5-methoxy-2-methyl-3-indeneacetic acid',
#   '1-p-chlorobenzylidine-5-methoxy-2-methyl-3-indeneacetic acid',
#   '1-(4-chlorobenzylidine)-5-methoxy-2-methyl-3-indeneacetic acid, sodium salt'],
#  'MESH:C000414': ["5-chloro-3-tert-butyl-2'-nitrososalicylanilide"],
#  'MESH:C000415': ["2'-chloro-2'-cyanoethyl-1-thio-beta-d-galactopyranoside",
#   'propanenitrile, 2-chloro-3-(beta-d-galactopyranosylthio)-'],
#  'MESH:C000417': ['ro 5-5807',
#   '7-chloro-2,3-dihydro-n-methyl-2-oxo-5- phenyl-lh-1-benzodiazepin-1-acetamide'],
#  'MESH:C000419': ['4-chloro-3,5-dinitrophenacylbromide',
#   '4-chloro-3,5-dinitrophenacyl bromide'],
#  'MESH:C000423': ['2-((2-chloroethyl)methylamino)ethyl-4-ethoxybenzoate',
#   '2-((2-chloroethyl)methylamino)ethyl-4-ethoxybenzoate hydrochloride'],
#  'MESH:C000425': ['oxazolam',
#   '10-chloro-2,3,7,11b-tetrahydro-2-methyl-11b-phenylbenzo(6,7)(1,4)diazepino(5,4-b) oxazol-6-one',
#   'oxazolazepam',
#   'oxazolam, (trans)-isomer'],
#  'MESH:C000426': ['5-chloro-8-hydroxy-3,4-dihydro-3-methylisocoumarin-7-carboxylic acid',
#   'ochratoxin alpha',
#   '5-chloro-8-hydroxy-3,4-dihydro-3-methylisocoumarin-7-carboxylic acid, (r)-isomer'],
#  'MESH:C000428': ['ici 42464',
#   'ici-42464',
#   '2-(gamma-chloro-beta-isopropylamino)ethylnaphthalene.hcl'],
#  'MESH:C000430': ['turinabol-oral',
#   'oral turinabol',
#   'd-4-chloro-17 beta-hydroxy-3-oxo-17 alpha-methylandrosta-1,4-diene',
#   '4-chloro-17 alpha-methyl-17 beta-hydroxy-1,4- androstadiene-3-one',
#   '4-chloro-methandienone',
#   'cdmt',
#   'dehydrochlormethyltestosterone'],
#  'MESH:C000433': ['3-chloroperbenzoic acid',
#   '3-chloroperoxybenzoic acid',
#   'm-chloroperbenzoic acid',
#   'mcpba',
#   'meta-chloroperoxybenzoic acid',
#   'm-cpba'],
#  'MESH:C000434': ['lilly 51641',
#   'lilly-51641',
#   'ly 51641',
#   'n-(2-(2-chlorophenoxy)ethyl)cyclopropylamine',
#   'n-((beta-chlorophenoxy)ethyl)cyclopropylamine',
#   'lilly 51641monohydrochloride'],
#  'MESH:C000435': ['famotine',
#   '1-(p-chlorophenoxymethyl)-3,4-dihydroisoquinoline',
#   'famotine hydrochloride'],
#  'MESH:C000436': ['3-chlorophenylacetamidocephalosporanic acid',
#   'm-chlorophenylacetamidocephalosporanic acid'],
#  'MESH:C000438': ['1-(3-(4-(p-chlorophenyl-azo)-5,6,7,8-tetrahydro-1- naphthylamino)propyl)piperidine',
#   'abt 29666',
#   'abt-29666'],
#  'MESH:C000439': ['1-(4-chlorophenyl)-2,2-dimethyl-1,3-propanediol-3-carbamate',
#   '1-(p-chlorophenyl)-2,2-dimethyl-1,3-propanediol-3-carbamate',
#   'l-(p-chlorophenyl)-2,2-dimethyl-l,3-propanediol 3-carbamate'],
#  'MESH:C000440': ['su-13197',
#   'su 13197',
#   '3-(chlorophenyl)-2-imidazolin-2-yl-methyl-2,3,4,5- tetrahydro-1-benzazepine.hcl'],
#  'MESH:C000441': ['4-chlorophenyl-n-methylcarbamate',
#   'p-chlorophenyl-n-methylcarbamate'],
#  'MESH:C000442': ['2-chloro-6-phenylphenoxyethylamine'],
#  'MESH:C000443': ['1-(4-chlorophenyl)-1-phenyl-2-propynylcarbamate',
#   '1-(4-chlorophenyl)-1-phenyl-2-propynyl carbamate'],
#  'MESH:C000446': ['ba 41799',
#   'ba-41,799',
#   'ba 41,799',
#   '2-(p-chlorophenyl)-2-(piperidyl)tetrahydrofuran',
#   '4-((4-chlorophenyl)tetrahydro-2-furanyl)piperidine',
#   'ba 41799 hydrochloride'],
#  'MESH:C000449': ['3-chlorocarpipramine',
#   '3-chloro-5-(3-(4-piperidino-4- carbamoylpiperidino)propyl)-10,11-dihydro-5h- dibenz(b,f)azepine dihydrochloride monohydrate',
#   'clocapramine',
#   'y-4153',
#   '3-chlorocarpipramine dihydrochloride',
#   '3-chlorocarpipramine dihydrochloride monohydrate'],
#  'MESH:C000450': ['mefenorex',
#   'chloropropylamphetamine',
#   'n-(3-chloropropyl)-alpha-methylphenethylamine',
#   'ro 4-5282',
#   'mefenorex hydrochloride',
#   'mefenorex, (+-)-isomer',
#   'pondinil',
#   'incital'],
#  'MESH:C000451': ['chlorothricin'],
#  'MESH:C000455': ['5-chlorouridine'],
#  'MESH:C000458': ['n-acetyllactosamine', 'acetyl lactosamine'],
#  'MESH:C000459': ['4,8-anhydro-3-deoxy-octulosonic acid'],
#  'MESH:C000461': ['n-bromoacetazolamide'],
#  'MESH:C000462': ['calcemic fraction a'],
#  'MESH:C000465': ['chainin',
#   '2-(n-butyl)-16-methyl-3,5,7,9,11,13,15,26,27-nonahydroxyoctacosa-16,18,20,22,24-pentaenoic acid, 27-lactone'],
#  'MESH:C000467': ['chelidimerine', '1,3-bis(11-hydrosanquinarinyl)acetone'],
#  'MESH:C000468': ['deoxypipradrol',
#   'deoxypipradrol, hydrochloride, (r)-isomer',
#   'deoxypipradrol, hydrochloride, (s)-isomer'],
#  'MESH:C000469': ['diazobenzenesulfonic acid',
#   'dabs',
#   '4-sulphodiazobenzene',
#   'benzenediazonium, 4-sulfo-',
#   'dasa',
#   'diazosulfanilic acid',
#   'p-diazoniumbenzenesulfonic acid',
#   "pauly's reagent",
#   'diazobenzene sulfonate',
#   'diazobenzenesulphonate',
#   'diazobenzenesulfonate',
#   'sulfanilic acid, diazonium salt',
#   'diazobenzenesulfonic acid, hydroxide',
#   'diazobenzenesulfonic acid, chloride',
#   'diazobenzenesulfonic acid, hydroxy inner salt'],
#  'MESH:C000470': ['eedq',
#   '2-ethoxy-1(2h)-quinolinecarboxylic acid, ethyl ester',
#   'n-carbethoxy-2-ethoxy-1,2-dihydroquinoline',
#   'n-ethoxycarbonyl-2-ethoxy-1,2-dihydroquinoline',
#   '2-ethoxy-1-ethoxycarbonyl-1,2-dihydroquinoline',
#   'bc 681'],
#  'MESH:C000471': ['chlorzolamide',
#   '1,3,4-thiadiazole-2-sulfonamide, 5-(2-chlorophenyl)-',
#   '2-(o-chlorophenyl)thiadiazole-5-sulfonamide',
#   'cl 13,580',
#   'cl-13580',
#   'cl 13580'],
#  'MESH:C000472': ['uranyl formate'],
#  'MESH:C000473': ['choleglobin'],
#  'MESH:C000474': ['cholestane-3,5,6-triol',
#   'cholestane-3,5,6-triol, (3beta, 5alpha, 6beta)-isomer',
#   'cholestane-3 beta,5 alpha,6 beta-triol',
#   '5alpha-cholestane-3beta,5,6beta-triol',
#   'cholestane-3,5,6-triol, (3beta, 5alpha, 6alpha)-isomer',
#   'cholestane-3,5,6-triol, (3beta)-isomer',
#   'cholestane-3,5,6-triol, (3beta, 6beta)-isomer',
#   'cholestane-3,5,6-triol, (3beta, 5beta, 6beta)-isomer'],
#  'MESH:C000475': ['cholest-4-en-3-one', '4-cholesten-3-one'],
#  'MESH:C000480': ['cibacron blue-amylose'],
#  'MESH:C000481': ['cinerubine a'],
#  'MESH:C000482': ['cinerubine b'],
#  'MESH:C000483': ['cinnabarinic acid',
#   '2-amino-3h-phenoxazin-one-1,9-dicarboxylic acid'],
#  'MESH:C000485': ['cinnamycin'],
#  'MESH:C000486': ['citiolone',
#   'cythiolone',
#   'n-(tetrahydro-2-oxo-3-thienyl)acetamide',
#   'n-acetylhomocysteine thiolactone',
#   'reducdyn',
#   'thioxidrene',
#   'citiolone, (+-)-isomer'],
#  'MESH:C000487': ['citromycin'],
#  'MESH:C000488': ['cladosporin',
#   '3,4-dihydro-6,8-dihydroxy-3-(6-methyltetrahydropyran- 2-ylmethyl)isocoumarin',
#   '3,4-dihydro-6,8-dihydroxy-3-(tetrahydro-6- methyl-2h-pyran-2-yl)methylisocoumarin',
#   'asperentin',
#   'isocladosporin'],
#  'MESH:C000489': ['clindamycin palmitate',
#   '7-chloro-7-deoxylincomycin palmitate',
#   '7-chlorolincomycin palmitate',
#   'clindamycin palmitate hydrochloride',
#   'cleocin palmitate'],
#  'MESH:C000490': ['clobenzorex',
#   'n-(o-chlorobenzyl)-alpha-methylphenethylamine',
#   'clobenzorex hydrochloride',
#   'clobenzorex, (+-)-isomer'],
#  'MESH:C000491': ['clomegestone acetate',
#   '6-chloro-17-acetoxy-16 alpha-methylpregna-4,6- diene-3,20-dione'],
#  'MESH:C000493': ['2-bromopentane', '2-amyl bromide', '2-pentyl bromide'],
#  'MESH:C000498': ['coherin', 'coherin a', 'coherin b'],
#  'MESH:C000499': ['ferric oxide',
#   'colcothar',
#   'iron oxide',
#   'red iron oxide',
#   'ferric oxide red',
#   'hematite',
#   'ferric oxide monohydrate',
#   'c.i. 77491',
#   'supraparamagnetic iron oxide',
#   'spio',
#   'lepidocrocite',
#   'gamma-ferric oxide',
#   'maghemite',
#   'ferric oxide hydrate'],
#  'MESH:C000501': ['combipres',
#   'combipresan',
#   'combipresan 75',
#   'clonidine, chlorthalidone drug combination',
#   'clonidine - chlorthalidone - drug combination'],
#  'MESH:C000502': ['conarachin i protein, peanut'],
#  'MESH:C000503': ['conductase',
#   '2-oxo-5-hydroxycarbonylpentanoate pyridoxine',
#   'pyridoxine-2-oxoglutarate',
#   'pyridoxine-alpha-ketoglutarate'],
#  'MESH:C000505': ['convallatoxin',
#   'corglycon',
#   'corglycone',
#   'korglycon',
#   'strophanthidin-alpha-l-rhamnoside'],
#  'MESH:C000506': ['cuprimyxin',
#   'copper myxin',
#   '6-methoxy-1-phenazinol-5,10-dioxide, cupric complex',
#   '6-methoxy-1-phenazinol 5,10-dioxide cupric complex',
#   'unitop'],
#  'MESH:C000507': ['copiamycin'],
#  'MESH:C000509': ['corchoroside b'],
#  'MESH:C000510': ['coriamyrtine', 'coriamyrtin'],
#  'MESH:C000511': ['cornin iridoid', 'verbenalin'],
#  'MESH:C000513': ['amyorel',
#   'benzenemethanamine, 2-amino-3,5-dibromo-n-cyclohexyl-n-methyl-, monohydrochloride, mixt. with n,n-dimethyl-3-((1-(phenylmethyl)-1h-indazol-3-yl)oxy)-1-propanamine monohydrochloride'],
#  'MESH:C000515': ['cremophor el', 'cremophore el', 'polyoxyl 35 castor oil'],
#  'MESH:C000516': ['2-(2-cresyl)-4h-1-3-2-benzodioxaphosphorin-2-oxide',
#   '0-tosylsaligenin phosphate',
#   '2-(o-cresyl)-4h-1-3-2-benzodioxaphosphorin-2-oxide',
#   '2-tolylsaligenin phosphate',
#   '2-tosylsaligenin phosphate',
#   '2-tslph',
#   '4h-1,3,2-benzodioxaphosphorin, 2-(2-methylphenoxy)-, 2-oxide',
#   'cbdp',
#   'o-tsp',
#   'saligenin cyclic-3-tolylphosphate',
#   'scotp',
#   'cresylsaligenin phosphate'],
#  'MESH:C000517': ['crotarbital',
#   '5-ethyl-5-crotylbarbituric acid',
#   'calypnon',
#   'crotylbarbital',
#   'krotylbarbital',
#   'crotarbital, (e)-isomer',
#   'crotarbital, sodium salt'],
#  'MESH:C000518': ['crotoxyphos',
#   'alpha-methylbenzyl 3-(dimethoxyphosphinyloxy)-cis-crotonate',
#   'ciodrin'],
#  'MESH:C000519': ['cryogenine', 'vertine', 'cryogenine, (10alpha)-isomer'],
#  'MESH:C000520': ['cuprous oxide',
#   'copper(i) oxide',
#   'copper oxide (cu2o)',
#   'perenox'],
#  'MESH:C000521': ['cutin', 'cutin'],
#  'MESH:C000522': ['cyanoacetaldehyde'],
#  'MESH:C000524': ['cyanuric fluoride', '2,4,6-trifluoro-sym-triazine'],
#  'MESH:C000528': ['cycloglutamate',
#   '1-amino-1,3-cyclohexanedicarboxylic acid',
#   'cycloglutamate, (cis)-(+-)-isomer'],
#  'MESH:C000531': ['cycloheptamycin'],
#  'MESH:C000533': ['cyclohexadiene-1,2-diol-1-carboxylic acid'],
#  'MESH:C000535': ['lv 267',
#   'cicliomenol',
#   '2-cyclohexyl-4-iodo-3,5-dimethylphenol'],
#  'MESH:C000536': ['cyclohexylisocyanate'],
#  'MESH:C000538': ['1-cyclohexyluracil'],
#  'MESH:C000539': ['cyclonerodiol'],
#  'MESH:C000540': ['cyclooctylamine',
#   'sk&f 23880a',
#   'sk&f-23880a',
#   'skf 23880a'],
#  'MESH:C000541': ['cyclopamine'],
#  'MESH:C000542': ['n-cyclopentylbutanephrine',
#   'n-cyclopentylbutanefrine',
#   'n-cyclopentylbutanephrine, (+-)-isomer',
#   'n-cyclopentylbutanephrine hydrochloride'],
#  'MESH:C000543': ['cyclopiazonic acid', 'cyclopyazonic acid'],
#  'MESH:C000545': ['cygerol',
#   'cyclohexyl-4,9-dimethyl-4,8-decadienoic acid',
#   '2-cyclohexyl-2-geranylacetic acid',
#   'cigerol'],
#  'MESH:C000546': ['cymarol', 'strophanthidol-d-cymaroside'],
#  'MESH:C000552': ['rubrosterone'],
#  'MESH:C000553': ['9-(3-(cytos-1-yl)propyl)-2-dimethylaminopurin-6-one'],
#  'MESH:C000562': ['rumalon', 'rumalone', 'arumalon'],
#  'MESH:C000577': ['17 alpha-chlorethinyl-3-methoxyestra-1,3,5(10)-trien-17 beta-ol',
#   'bdh 2398',
#   'bdh-2398',
#   '19-norpregna-1,3,5(10)-trien-20-yn-17-ol, 21-chloro-3-methoxy-, (17 alpha)-'],
#  'MESH:C000578': ['exo-bicyclo(3.1.0)hexane-6-carboxylic acid'],
#  'MESH:C000588423': ['acaca protein, human',
#   'acac protein, human',
#   'acetyl-coa carboxylase 1 protein, human',
#   'acc protein, human',
#   'acc1 protein, human',
#   'acetyl-coa carboxylase alpha protein, human'],
#  'MESH:C000588424': ['31-kda antigen, angiostrongylus cantonensis'],
#  'MESH:C000588427': ['ceramicine b'],
#  'MESH:C000588428': ['aspeverin'],
#  'MESH:C000588432': ["8-chalconyl-2'-deoxyguanosine"],
#  'MESH:C000588435': ['variabine a'],
#  'MESH:C000588436': ['variabine b'],
#  'MESH:C000588437': ['setd5 protein, human',
#   'set domain containing 5 protein, human'],
#  'MESH:C000588439': ['kiz protein, human',
#   'kizuna centrosomal protein, human'],
#  'MESH:C000588440': ['wnk10 protein, arabidopsis'],
#  'MESH:C000588441': ["4'-o-beta-d-glucopyranosyl-3',4-dimethoxychalcone"],
#  'MESH:C000588442': ['znf154 protein, human',
#   'zinc finger protein 154, human'],
#  'MESH:C000588443': ['dactylorhin a'],
#  'MESH:C000588444': ['goshonoside-f5'],
#  'MESH:C000588446': ['creld1 protein, mouse'],
#  'MESH:C000588447': ["n(2),3-etheno-2'-isopropyl-1-methylguanine"],
#  'MESH:C000588448': ['n(2),3-ethenoguanine (5-methyl-7-isopropyl-4,5-dihydroimidazo(2,1-b)purine)',
#   'n(2),3-ethenoguanine(5-methyl-7-isopropyl-4,5-dihydroimidazo(2,1-b)purine)'],
#  'MESH:C000588452': ['2-hydroxyarachidonic acid', '2oaa compound'],
#  'MESH:C000588453': ['esrp1 protein, mouse',
#   'epithelial splicing regulatory protein 1, mouse'],
#  'MESH:C000588454': ['cyclomontanin b'],
#  'MESH:C000588455': ['yk-3-237'],
#  'MESH:C000588457': ['1,4-anhydro-1-(4-chloro-5-(4-ethylbenzyl)-2-methoxyphenyl)glucitol'],
#  'MESH:C000588458': ['n-(4-chlorophenyl)-2-(5-methoxy-3-((2-tosylhydrazono)methyl)-1h-indol-1-yl)acetamide'],
#  'MESH:C000588459': ['fluororasagiline', '(18f)fluororasagiline-d2'],
#  'MESH:C000588460': ['n-((2-(cyclohexylthio)-6-(trifluoromethyl)pyridin-3-yl)methyl)-2-(3-fluoro-4-(methylsulfonamido)phenyl)propanamide'],
#  'MESH:C000588461': ['n1-(4-(5-bromo-1,3,4-thiadiazol-2-ylamino)-3-hydroxy-4-oxo-1-phenylbutan-2-yl)-5-(n-methylmethanesulfonamido)-n3-(1-phenylethyl)isophthalamide',
#   'kmi-1764'],
#  'MESH:C000588462': ['n1,n1,n12,n12-tetraethyl-n1,n12-bis(2-((1,7,7-trimethylbicyclo(2.2.1)heptan-2-ylidene)amino)ethyl)dodecane-1,12-diaminium',
#   'n1,n1,n12,n12-tetraethyl-n1,n12-bis(2-((1,7,7-trimethylbicyclo(2.2.1)heptan-2-ylidene)amino)ethyl)dodecane-1,12-diaminium bromide'],
#  'MESH:C000588464': ['3-(((2,6-difluorophenyl)amino)methyl)-5-(2,3-dihydrobenzo(b)(1,4)dioxin-6-yl)-1,3,4-oxadiazole-2(3h)-thione'],
#  'MESH:C000588466': ["2-(3'-hydroxy-4'-methoxyphenyl)-3-(3'',4'',5''-trimethoxybenzoyl)-6-methoxyindole",
#   'oxi8006'],
#  'MESH:C000588467': ['8-(3-(4-(diethylamino)phenyl)acryloyl)-2,2-dimethyl-2h-chromen-5-yl propionate'],
#  'MESH:C000588468': ['t808 compound', '(18f)-t808'],
#  'MESH:C000588469': ['lu af58801'],
#  'MESH:C000588470': ['shemamruthaa'],
#  'MESH:C000588471': ['tox hmb-box protein, mouse'],
#  'MESH:C000588473': ['aic246', 'letermovir', 'prevymis'],
#  'MESH:C000588474': ['venturicidin c'],
#  'MESH:C000588475': ['pedopeptin a'],
#  'MESH:C000588476': ['pedopeptin b'],
#  'MESH:C000588477': ['pedopeptin c'],
#  'MESH:C000588478': ['mangromicin a'],
#  'MESH:C000588479': ['mangromicin b'],
#  'MESH:C000588480': ['mbj-0003'],
#  'MESH:C000588481': ['eryngiolide a'],
#  'MESH:C000588482': ['mono-6(a)-(2-hydroxyethyl-1-ammonium)-6(a)-beta-cyclodextrin chloride'],
#  'MESH:C000588484': ['spz3 protein, drosophila',
#   'spatzle 3 protein, drosophila'],
#  'MESH:C000588485': ['tollo protein, drosophila'],
#  'MESH:C000588486': ['glycine propionyl carnitine',
#   'gplc compound',
#   'glycine propionyl l-carnitine'],
#  'MESH:C000588489': ['f2pal-12 pepducin', 'pepducin f2pal-12'],
#  'MESH:C000588490': ['4-aminobutanamide', '4-abad'],
#  'MESH:C000588491': ["tricin 4'-o-(threo-beta-guaiacylglyceryl) ether"],
#  'MESH:C000588494': ["tricin 4'-o-(erythro-beta-guaiacylglyceryl) ether"],
#  'MESH:C000588495': ['suchengbeisine'],
#  'MESH:C000588496': ['teasperol'],
#  'MESH:C000588497': ['teasperin'],
#  'MESH:C000588503': ['7alpha,8beta-dihydroxydeepoxysarcophine'],
#  'MESH:C000588505': ['apicidin h'],
#  'MESH:C000588506': ['apicidin i'],
#  'MESH:C000588507': ['scutebata s'],
#  'MESH:C000588508': ['scutebata t'],
#  'MESH:C000588509': ['apicidin g'],
#  'MESH:C000588510': ["quercetin-3-o-(2'-o-tigloyl)-alpha-l-rhamnopyranoside"],
#  'MESH:C000588511': ["quercetin-3-o-(3'-o-tigloyl)-alpha-l-rhamnopyranoside"],
#  'MESH:C000588512': ['suspensaside c'],
#  'MESH:C000588513': ['2,3,5,6-tetrahydro-jacaranone-4-o-beta-d-glucopyranoside'],
#  'MESH:C000588514': ['episesaminone'],
#  'MESH:C000588517': ["kaempferol-3-o-alpha-l-rhamnosyl-(1''-6')-o-beta-d-galactopyranosyl-7-o-beta-d-apiofuranoside"],
#  'MESH:C000588518': ['n7-(2,3,4-trihydroxybut-1-yl)-guanine',
#   'n-7-(2,3,4-trihydroxybut-1-yl)guanine',
#   'thb-gua'],
#  'MESH:C000588519': ['syringic acid 4-o-beta-d-glucopyranosyl-(1-5)-alpha-l-rhamnopyranoside'],
#  'MESH:C000588520': ['benzo(a)pyrene-7,8-catechol'],
#  'MESH:C000588521': ['6-hydroxy-8,11,11-trimethyl-bicyclo(7.2.0)undec-4-ene-4-carboxylic acid:',
#   '6-hydroxy-8,11,11-trimethyl-bicyclo(7.2.0)undec-4-ene-4-carboxylic acid'],
#  'MESH:C000588522': ['periplogulcoside'],
#  'MESH:C000588523': ['cymosic acid'],
#  'MESH:C000588524': ['iriflophenone'],
#  'MESH:C000588525': ['2,3-dihydroxy-4-oxo-n-((r)-1-phenylethyl)-4-(pyrrolidin-1-yl)butanamide',
#   'mbet306'],
#  'MESH:C000588526': ['5-(2,3-dihydrobenzo(b)(1,4)dioxin-6-yl)-3-(((3,4,5-trifluorophenyl)amino)methyl)-1,3,4-oxadiazole-2(3h)-thione'],
#  'MESH:C000588527': ['alpha-tert-butyl aspartate'],
#  'MESH:C000588528': ['verrillin'],
#  'MESH:C000588529': ['phyllanthoid a'],
#  'MESH:C000588530': ['phyllanthoid b'],
#  'MESH:C000588531': ['lycospidine a'],
#  'MESH:C000588542': ['28-o-(6-rhamnopyranosyl)-r1-barrigenol'],
#  'MESH:C000588543': ['4-ethylphenylcobalamin',
#   'etphcbl',
#   'cobeta-4-ethylphenylcob(iii)alamin'],
#  'MESH:C000588544': ['acam2000'],
#  'MESH:C000588546': ['4-(2-biphenyl)-1-(2-(3-methoxyphenyl)ethyl)piperidine'],
#  'MESH:C000588547': ['1-(2-biphenyl)-4-(2-(3-methoxyphenyl)ethyl)piperazine'],
#  'MESH:C000588548': ['ged0301', 'mongersen'],
#  'MESH:C000588549': ['jiaotai'],
#  'MESH:C000588550': ['asante calcium red-1', 'acr-1 compound'],
#  'MESH:C000588551': ['sycp1 protein, zebrafish',
#   'synaptonemal complex protein 1, zebrafish'],
#  'MESH:C000588552': ['atg17 protein, drosophila',
#   'cg1347 protein, drosophila',
#   'fip200 protein, drosophila',
#   'autophagy-related 17 protein, drosophila'],
#  'MESH:C000588553': ['d-512 compound'],
#  'MESH:C000588554': ['d-440 compound'],
#  'MESH:C000588555': ['dr6 protein, human herpesvirus 6b',
#   'direct repeat 6 protein, hhv-6b'],
#  'MESH:C000588556': ['4-(4-cyanophenyl)-2-(2-cyclopentylidenehydrazinyl)thiazole',
#   'remodelin'],
#  'MESH:C000588557': ['3-(4-aminophenyl)-2-methoxypropionic acid',
#   'ged-0507-34l'],
#  'MESH:C000588558': ['pdx1.2 protein, arabidopsis',
#   'at3g16050 protein, arabidopsis'],
#  'MESH:C000588559': ['phf20l1 protein, human',
#   'phd finger protein 20-like 1 protein, human',
#   'phd finger protein 20 like 1 protein, human',
#   'phf20l1a protein, human',
#   'phf20l1b protein, human',
#   'phf20l1c protein, human'],
#  'MESH:C000588560': ['1,4-bis(5-(naphthalen-1-yl)thiophen-2-yl)naphthalene'],
#  'MESH:C000588561': ['tris(4-methyl-1-pyrazolyl)borohydride',
#   'ktp(4-me) compound'],
#  'MESH:C000588562': ['cyclopropylsterol-cycloisomerase, arabidopsis',
#   'cyclopropylsterol cycloisomerase, arabidopsis',
#   'cp1 protein, arabidopsis',
#   'cyclopropyl sterol isomerase, arabidopsis',
#   'at5g50375 protein, arabidopsis',
#   'cycloeucalenol cycloisomerase, arabidopsis'],
#  'MESH:C000588563': ['methionine sulfoxide reductase b3, mouse',
#   'msrb3 protein, mouse'],
#  'MESH:C000588564': ['slc6a20a protein, mouse', 'imino transporter, mouse'],
#  'MESH:C000588565': ['puros'],
#  'MESH:C000588566': ['exla2 protein, arabidopsis',
#   'at4g38400 protein, arabidopsis',
#   'expansin-like a2 protein, arabidopsis'],
#  'MESH:C000588567': ["4,4'-diallyl-5,5'-dimethoxy-(1,1'-biphenyl)-2,2'-diol",
#   'biseugenol a'],
#  'MESH:C000588568': ["2,2'-oxybis(4-allyl-1-methoxybenzene)", 'biseugenol b'],
#  'MESH:C000588569': ['myristoyl-glycyl-methionyl-arginyl-prolyl-tyrosyl-aspartyl-alanyl-asparagyl-lysyl-argininamide',
#   'myristoyl-gmrpydankr-nh2',
#   'krx-725'],
#  'MESH:C000588570': ['fzl protein, arabidopsis',
#   'fzo-like protein, arabidopsis',
#   'at1g03160 protein, arabidopsis'],
#  'MESH:C000588571': ['hb17 protein, arabidopsis',
#   'athb17 protein, arabidopsis',
#   'at2g01430 protein, arabidopsis'],
#  'MESH:C000588572': ['ucp0045037'],
# ...
#  'MESH:C000588990': ['nrarp protein, human',
#   'notch-regulated ankyrin repeat protein, human'],
#  'MESH:C000588991': ['mirn592 microrna, human',
#   'microrna-592, human',
#   'mir-592, human',
#   'hsa-mir-592'],
#  'MESH:C000588992': ['mirn552 microrna, human',
#   'microrna-552, human',
#   'mir-552, human',
#   'hsa-mir-552'],
#  'MESH:C000588993': ['rn486',
#   '6-cyclopropyl-8-fluoro-2-(2-hydroxymethyl-3-(1-methyl-5-(5-(4-methyl-piperazin-1-yl)-pyridin-2-ylamino)-6-oxo-1,6-dihydro-pyridin-3-yl)-phenyl)-2h-isoquinolin-1-one'],
#  'MESH:C000588994': ['znf385d protein, human',
#   'znf659 protein, human',
#   'zinc finger protein 385d, human'],
#  'MESH:C000588995': ['fbp1 protein, rat',
#   'far upstream element binding protein 1, rat'],
#  'MESH:C000588996': ['2,3-cyclopropanated abscisic acid'],
#  'MESH:C000588997': ['aucuparin'],
#  'MESH:C000588998': ['cenpj protein, zebrafish', 'cpap protein, zebrafish'],
#  'MESH:C000588999': ["3',4'-dimethoxy-7-(gamma,gamma-dimethylallyloxy)flavonol"],
#  'MESH:C000589000': ['10-hydroxyverbenone ester'],
#  'MESH:C000589001': ["3-o-beta-d-glucopyranoside-6'-(o-4'-hydroxybenzoate)"],
#  'MESH:C000589002': ['afoxolaner',
#   '4-(5-(3-chloro-5-(trifluoromethyl)-phenyl)-4,5-dihydro-5-(trifluoromethyl)-3-isoxazolyl)-n-(2- oxo-2-((2,2,2-trifluoroethyl)amino)ethyl-1-naphthalenecarboxamide'],
#  'MESH:C000589003': ["6'-o-p-hydroxybenzoyl-gardoside"],
#  'MESH:C000589004': ['petroacetylene'],
#  'MESH:C000589005': ['montiporic acid d'],
#  'MESH:C000589006': ['racemosolone'],
#  'MESH:C000589007': ['xpo7 protein, human', 'ranbp16 protein, human'],
#  'MESH:C000589008': ['exo70b1 protein, arabidopsis'],
#  'MESH:C000589009': ['rau protein, drosophila', 'cg8965 protein, drosophila'],
#  'MESH:C000589011': ['mirn490 microrna, mouse',
#   'mir-490, mouse',
#   'microrna-490, mouse',
#   'mmu-mir-490',
#   'mir-490-3p, mouse'],
#  'MESH:C000589012': ['cofj protein, e coli'],
#  'MESH:C000589013': ['marcfortine c'],
#  'MESH:C000589014': ['esl1 protein, s cerevisiae',
#   'yil151c protein, s cerevisiae'],
#  'MESH:C000589015': ['mesp1 protein, human'],
#  'MESH:C000589016': ['ncapg2 protein, human', 'n-capg2 protein, human'],
#  'MESH:C000589017': ['cwf10 protein, s pombe'],
#  'MESH:C000589018': ['isocorypalmine'],
#  'MESH:C000589019': ['aeruginosin-865', 'aer-865'],
#  'MESH:C000589020': ['mirn2909 microrna, human',
#   'microrna-2909, human',
#   'mir-2909, human',
#   'hsa-mir-2909'],
#  'MESH:C000589021': ['pyrimethinal'],
#  'MESH:C000589022': ['mirn628 microrna, human',
#   'mir-628, human',
#   'microrna-628, human',
#   'hsa-mir-628',
#   'mir-628-5p, human'],
#  'MESH:C000589023': ['sp8 protein, xenopus',
#   'specificity protein 8, xenopus',
#   'sp8.l protein, xenopus',
#   'sp8.s protein, xenopus'],
#  'MESH:C000589024': ['mirn450 microrna, human',
#   'mir-450, human',
#   'microrna-450, human',
#   'hsa-mir-450',
#   'mir-450b-5p, human'],
#  'MESH:C000589025': ['fn1-8 compound'],
#  'MESH:C000589026': ['nrros protein, mouse',
#   'negative regulator of ros, mouse'],
#  'MESH:C000589027': ['slc15a3 protein, mouse'],
#  'MESH:C000589028': ['7-(4-(tert-butyl)benzyl)-1,3-dimethyl-1h-purine-2,6(3h,7h)-dione',
#   'vu0071063'],
#  'MESH:C000589029': ['ru24858', 'ru 24858', 'ru-24858'],
#  'MESH:C000589030': ['ru24782'],
#  'MESH:C000589031': ['pde4dip protein, mouse',
#   'phosphodiesterase 4d-interacting protein, mouse'],
#  'MESH:C000589032': ['gue1654'],
#  'MESH:C000589033': ['pxylp1 protein, human',
#   '2-phosphoxylose phosphatase, human',
#   '2-phosphoxylose phosphatase 1 protein, human'],
#  'MESH:C000589034': ['2-(4-phenylphenoxy)-3-phenylpropanoic acid', 'lt175'],
#  'MESH:C000589035': ['yaha protein, e coli'],
#  'MESH:C000589036': ['tbph protein, drosophila',
#   'tar dna-binding protein 43, drosophila',
#   'tdp-43 protein, drosophila'],
#  'MESH:C000589037': ['tsp-2 protein, schistosoma mansoni',
#   'sm-tsp-2 protein, schistosoma mansoni'],
#  'MESH:C000589038': ['pmca4 protein, mouse',
#   'plasma membrane ca2+ atpase-4, mouse',
#   'atp2b4 protein, mouse'],
#  'MESH:C000589039': ['sj7170 protein, scorpiops jendeki'],
#  'MESH:C000589040': ['pi-1840'],
#  'MESH:C000589041': ['jph2 protein, human',
#   'junctophilin-2 protein, human',
#   'junctophilin 2 protein, human',
#   'jp2 protein, human'],
#  'MESH:C000589042': ['junctophilin-2 protein, mouse', 'jp2 protein, mouse'],
#  'MESH:C000589043': ['mirn365 microrna, mouse',
#   'mmu-mir-365',
#   'mir-365, mouse',
#   'microrna-365, mouse',
#   'mir-365a, mouse'],
#  'MESH:C000589044': ['cilp protein, mouse',
#   'cartilage intermediate layer protein, mouse'],
#  'MESH:C000589045': ['mirn663 microrna, mouse',
#   'mir-663, mouse',
#   'mmu-mir-663',
#   'microrna-663, mouse'],
#  'MESH:C000589046': ['angptl3 protein, zebrafish',
#   'angiopoietin-like 3, zebrafish'],
#  'MESH:C000589047': ['slc5a10 protein, human',
#   'hsglt5 protein,human',
#   'sglt5 protein, human',
#   'solute carrier family 5 member 10 protein, human'],
#  'MESH:C000589049': ['thyminenol', 'trans-thyminenol', 'cis-thyminenol'],
#  'MESH:C000589050': ['decoroside a'],
#  'MESH:C000589051': ['decoroside b'],
#  'MESH:C000589052': ['coumacassia'],
#  'MESH:C000589053': ['macrocalactone'],
#  'MESH:C000589054': ['3-deoxycardiobutanolide'],
#  'MESH:C000589055': ['isocorilagin'],
#  'MESH:C000589057': ['rhodochlorin dimethyl ester'],
#  'MESH:C000589058': ['3,6-dimethoxy-8-methyl-1h,6h-benzo(de)isochromene-1,9-dione'],
#  'MESH:C000589059': ['3-hydroxy-1,6,10-trimethoxy-8-methyl-1h,3h-benzo(de)isochromen-9-one'],
#  'MESH:C000589060': ['5-hydroxy-2,7-dimethoxy-8-methylnaphthoquinone'],
#  'MESH:C000589061': ['desmethylnobiletin'],
#  'MESH:C000589063': ['pannokin a'],
#  'MESH:C000589065': ['pannokin b'],
#  'MESH:C000589066': ['citruscridone'],
#  'MESH:C000589067': ['pannokin c'],
#  'MESH:C000589068': ["3,3'-dimethoxy-2'-oxychromone"],
#  'MESH:C000589069': ["3,3'-dihydroxy-2,2'-oxychromone"],
#  'MESH:C000589072': ['rutaecarpine-10-o-beta-d-glucopyranoside'],
#  'MESH:C000589073': ['17-desacetoxyvinblastine n-oxide'],
#  'MESH:C000589074': ["20'-deoxyvinblastine n-oxide"],
#  'MESH:C000589075': ["5,7,4',5'',3'',4''-hexahydroxy-3'-o-beta-glucosyl-3',7'-o-biflavone"],
#  'MESH:C000589076': ['loasin a'],
#  'MESH:C000589077': ['loasin b'],
#  'MESH:C000589078': ['tca 11a'],
#  'MESH:C000589080': ['lrrc8a protein, mouse',
#   'leucine rich repeat containing 8 family, member a, mouse',
#   'swell1 protein, mouse'],
#  'MESH:C000589093': ['botryosphaerin f'],
#  'MESH:C000589094': ['alpha-hydroxytomentolide a'],
#  'MESH:C000589095': ['4-(methoxymethyl)-7-methoxy-6-methyl-1(3h)-isobenzofuranone'],
#  'MESH:C000589096': ['2-thioxo-imidazolidine-4-one'],
#  'MESH:C000589097': ['2-((5,6,7,8-tetrahydronaphthalen-2-yl)oxy)acetohydrazide'],
#  'MESH:C000589099': ['20-hydroxyecdysone dioxolane'],
#  'MESH:C000589100': ['indeno(1,2-b)indole-10-one'],
#  'MESH:C000589101': ['(z)-1-((naphthalen-2-ylamino)methylene)naphthalen-2(1h)-one'],
#  'MESH:C000589102': ['1-(4-chloro-phenyl)-3-phenyl-succinimide'],
#  'MESH:C000589103': ['n-(2-hydroxybenzylidene)acetohydrazide'],
#  'MESH:C000589105': ['8-hydroxy quinolinium 4-nitrobenzoate 4-nitrobenzoic acid'],
#  'MESH:C000589106': ['2,4-bis(2-methoxyphenyl)-1-phenylanthracene-9,10-dione'],
#  'MESH:C000589107': ['2-amino-4-methyl-3-nitropyridinium hydrogen oxalate'],
#  'MESH:C000589109': ['rwa1 protein, arabidopsis'],
#  'MESH:C000589111': ['rwa3 protein, arabidopsis'],
#  'MESH:C000589113': ['fatty acyl reductase4, arabidopsis',
#   'far4 protein, arabidopsis'],
#  'MESH:C000589114': ['fatty acyl reductase5 protein, arabidopsis',
#   'far5 protein, arabidopsis'],
#  'MESH:C000589116': ['atp sulfurylase 1, arabidopsis'],
#  'MESH:C000589117': ['d-3-phosphoglycerate dehydrogenase, arabidopsis',
#   'pgdh protein, arabidopsis'],
#  'MESH:C000589119': ['sweet16 protein, arabidopsis',
#   'atsweet16 protein, arabidopsis'],
#  'MESH:C000589120': ['isa1 protein, arabidopsis'],
#  'MESH:C000589121': ['isa2 protein, arabidopsis'],
#  'MESH:C000589122': ['trx1 protein, arabidopsis'],
#  'MESH:C000589123': ['trx2 protein, arabidopsis'],
#  'MESH:C000589124': ['abcc1 protein, arabidopsis'],
#  'MESH:C000589125': ['abcc2 protein, arabidopsis'],
#  'MESH:C000589126': ['clorin-e(6) trimethyl ester'],
#  'MESH:C000589127': ['anthrahydroquinone-2,6-disulfonate'],
#  'MESH:C000589128': ['bola1 protein, arabidopsis',
#   'at1g55805 protein, arabidopsis',
#   'bola4 protein, arabidopsis',
#   'at5g17560 protein, arabidopsis',
#   'bola2 protein, arabidopsis',
#   'at5g09830 protein, arabidopsis',
#   'bola protein, arabidopsis'],
#  'MESH:C000589129': ['at4g28590 protein, arabidopsis',
#   'atecb1 protein, arabidopsis',
#   'mrl7 protein, arabidopsis',
#   'early chloroplast biogenesis 1 protein, arabidopsis',
#   'ecb1 protein, arabidopsis',
#   'suppression of variegation 4 protein, arabidopsis',
#   'svr4 protein, arabidopsis',
#   'rcb protein, arabidopsis'],
#  'MESH:C000589130': ['2-(1h-imidazo(4,5-f)(1,10)phenanthrolin-2-yl)phenol'],
#  'MESH:C000589131': ['ahdc1 protein, human',
#   'at hook dna binding motif containing 1 protein, human',
#   'dj159a19.3 protein, human',
#   'rp1-159a19.1 protein, human'],
#  'MESH:C000589132': ['piezo2 protein, human',
#   'piezo-type mechanosensitive ion channel component 2 protein, human'],
#  'MESH:C000589133': ['4-(3-(3-(3,5-4-(3-(3-(3,5-dibromo-4-hydroxyphenyl)-propylamino)phenyl)butyric acid'],
#  'MESH:C000589134': ['nedd4-binding protein 3, rat', 'n4bp3 protein, rat'],
#  'MESH:C000589135': ['3-(3,5-dibromo-4-hydroxyphenyl)-propylamino-acetamidobenzoic acid'],
#  'MESH:C000589136': ['(e)-methyl 2-(7-chloroquinolin-4-ylthio)-3-(4-hydroxyphenyl)acrylate'],
#  'MESH:C000589137': ['2-(3,4,5-triacetoxybenzoylamino)benzo(d)thiazole'],
#  'MESH:C000589138': ['tcf7l2 protein, zebrafish'],
#  'MESH:C000589140': ['2-(galloylamino)benzo(d)thiazole'],
#  'MESH:C000589141': ['9-(2,4-dinitrophenyloxy)-3,3,8-trimethyl-1,5-dihydro-(1,3)dioxepino(5,6-c)pyridine'],
#  'MESH:C000589142': ['rng8 protein, s pombe'],
#  'MESH:C000589143': ['rng9 protein, s pombe'],
#  'MESH:C000589145': ['ndufa12 protein, human',
#   'nadh dehydrogenase (ubiquinone) 1 alpha subcomplex, 12, human'],
#  'MESH:C000589146': ['hs6st3 protein, human',
#   'heparan sulfate 6-o-sulfotransferase 3, human'],
#  'MESH:C000589147': ['basic red 51',
#   '2-(((4-dimethylamino)phenyl)azo)-1,3-dimethyl-1h-imidazolium chloride'],
#  'MESH:C000589148': ['pyrrocidine c'],
#  'MESH:C000589149': ['stewartiiside'],
#  'MESH:C000589150': ['swietephragmin h'],
#  'MESH:C000589151': ['swietephragmin i'],
#  'MESH:C000589152': ['11-hydroxyswietephragmin b'],
#  'MESH:C000589153': ['1-spiro(4.5)dec-7-en-7-yl-4-pent-1-one'],
#  'MESH:C000589154': ['2-cyclohexyl-1,6-heptadien-3-one'],
#  'MESH:C000589155': ['1-(3,3-dimethylcyclohexyl)ethan-1-one'],
#  'MESH:C000589156': ['methyl-2,6,10-trimethylcyclododeca-2,5,9-trien-1-yl ketone'],
#  'MESH:C000589157': ['1-(5,5-dimethylcyclohexen-1-yl)pent-4-en-1-one'],
#  'MESH:C000589158': ['mirn146 microrna, zebrafish',
#   'microrna-146, zebrafish',
#   'mir146b, zebrafish',
#   'mir146a, zebrafish',
#   'dre-mir-146',
#   'mir-146, zebrafish'],
#  'MESH:C000589159': ['emindole sb beta-mannoside'],
#  'MESH:C000589160': ['27-o-methylasporyzin c'],
#  'MESH:C000589161': ['eurycomalide c'],
#  'MESH:C000589162': ['frangulin a'],
#  'MESH:C000589164': ['glucofrangulin a'],
#  'MESH:C000589165': ['glucofrangulin b'],
#  'MESH:C000589166': ['altersolanol p'],
#  'MESH:C000589182': ['ypsilanogenin'],
#  'MESH:C000589183': ['nhea protein, bacillus cereus'],
#  'MESH:C000589184': ['n2,n4-bis(2-methyl-1h-indol-5-yl)pyrimidine-2,4-diamine'],
#  'MESH:C000589185': ['sectm1a protein, mouse',
#   'secreted and transmembrane 1a protein, mouse'],
#  'MESH:C000589186': ['sectm1b protein, mouse',
#   'secreted and transmembrane 1b protein, mouse'],
#  'MESH:C000589187': ['jakmip3 protein, rat',
#   'necc2 protein, rat',
#   'neuroendocrine long coiled-coil protein 2, rat'],
#  'MESH:C000589188': ['psma1 protein, human'],
#  'MESH:C000589189': ['5-(6-isopropyl-2-methylaminopyridin-3-yl)-(n-(1-ethyl)propyl)-3-methoxy-6-methylpyrazine-2-amine',
#   'ngd 9002'],
#  'MESH:C000589190': ['mirn-4437 microrna, human',
#   'mir-4437, human',
#   'microrna-4437, human',
#   'hsa-mir-4437'],
#  'MESH:C000589191': ['mirn4674 microrna, human',
#   'microrna-4674, human',
#   'mir-4674, human',
#   'hsa-mir-4674'],
#  'MESH:C000589192': ['mzt1 protein, s pombe', 'tam4 protein, s pombe'],
#  'MESH:C000589193': ['mzt1 protein, human',
#   'mozart1 protein, human',
#   'mitotic spindle organizing protein 1, human'],
#  'MESH:C000589194': ['dyrk2 protein, zebrafish',
#   'dual-specificity tyrosine phosphorylated and regulated kinase 2, zebrafish'],
#  'MESH:C000589195': ['leptosin o'],
#  'MESH:C000589196': ['(bipyridine)(morpholine dithiocarbamate)platinum(ii)',
#   'bipyridine morpholine dithiocarbamate pt(ii) nitrate'],
#  'MESH:C000589197': ['ginkgo biloba extract 1212', 'egb1212'],
#  'MESH:C000589198': ['n-isobutyl-11-(4-chlorophenyl)undeca-2,4,9-trienamide'],
#  'MESH:C000589199': ['hassallidin c'],
#  'MESH:C000589200': ['hassallidin d'],
#  'MESH:C000589201': ['rv3903 protein, mycobacterium tuberculosis',
#   'cpnt protein, mycobacterium tuberculosis',
#   'channel protein with necrosis-inducing toxin, mycobacterium tuberculosis'],
#  'MESH:C000589202': ['rcor2 protein, human'],
#  'MESH:C000589203': ['clp1 protein, zebrafish',
#   'cleavage and polyadenylation factor i subunit 1, zebrafish'],
#  'MESH:C000589204': ['piezo2 protein, rat', 'fam38b protein, rat'],
#  'MESH:C000589205': ['curcusone d'],
#  'MESH:C000589206': ['rhododendroside a'],
#  'MESH:C000589207': ['enrofloxacin-trimethoprim combination'],
#  'MESH:C000589212': ['1-(3,3-dimethylcyclohexyl)pent-4-en-1-one'],
#  'MESH:C000589213': ['3-methyl-5-(2,2,3-trimethyl-3-cyclopenten-1-yl)pent-3-en-2-one'],
#  'MESH:C000589214': ['1-(2,4-dimethyl-3-cyclohexenyl)-2,2-dimethylpropan-1-one'],
#  'MESH:C000589215': ['1-(2,4,4,5,5-pentamethyl-1-cyclopenten-1-yl)ethan-1-one'],
#  'MESH:C000589216': ['1-(3,5,6-trimethyl-3-cyclohexen-1-yl)ethan-1-one'],
#  'MESH:C000589217': ['1-(3,3-dimethylbicyclo(2.2.1)hept-2-yl)ethane-1-one'],
#  'MESH:C000589219': ['1-(para-menthen-6-yl)-1-propanone'],
#  'MESH:C000589222': ['dop protein, drosophila',
#   'drop out protein, drosophila'],
#  'MESH:C000589223': ['mob1a protein, arabidopsis thaliana',
#   'at5g45550 protein, arabidopsis'],
#  'MESH:C000589226': ['asnidin, aspergillus nidulans'],
#  'MESH:C000589227': ['b-98 compound'],
#  'MESH:C000589228': ['glycyl-histidyl-serine', 'gly-his-ser'],
#  'MESH:C000589229': ["6'-o-linoleyl sucrose"],
#  'MESH:C000589230': ['esi-05'],
#  'MESH:C000589231': ['wdpcp protein, mouse'],
#  'MESH:C000589232': ['arhgap42 protein, human',
#   'graf3 protein, human',
#   'rho gtpase activating protein 42, human'],
#  'MESH:C000589233': ['graf3 protein, mouse'],
#  'MESH:C000589234': ['dmpd protein, drosophila',
#   'cg11866 protein, drosophila',
#   'dampened protein, drosophila'],
#  'MESH:C000589235': ['1-(2,5,5-trimethylcycloheptyl)ethan-1-one'],
#  'MESH:C000589236': ['chromomoric acid c-i'],
#  'MESH:C000589237': ['1-(2,6,6-trimethyl-2-cyclohexen-1-yl)pent-1-en-3-one'],
#  'MESH:C000589239': ['ring finger protein 112, human',
#   'rnf112 protein, human',
#   'zinc finger protein 112, human',
#   'znf179 protein, human'],
#  'MESH:C000589241': ['4-(4-(2-adamantylcarbamoyl)-5-tert-butyl-pyrazol-1-yl)benzoic acid',
#   '4-(4-(2-adamantylcarbamoyl)-5-tert-butylpyrazol-1-yl)benzoic acid',
#   'azd8329'],
#  'MESH:C000589243': ['callophycin a'],
#  'MESH:C000589244': ['au816', '2-desmethylpretubulysin au816'],
#  'MESH:C000589245': ['jb337', 'phenylpretubulysin jb337'],
#  'MESH:C000589248': ['ll-202', 'll202', 'll202 flavonoid'],
#  'MESH:C000589249': ['lychnopholic acid'],
#  'MESH:C000589250': ['mirn712 microrna, human',
#   'mir-712, human',
#   'hsa-mir-712',
#   'microrna-712, human'],
#  'MESH:C000589251': ['mirn712 microrna, mouse',
#   'mir-712, mouse',
#   'microrna-712, mouse',
#   'mmu-mir-712'],
#  'MESH:C000589252': ['gne-783'],
#  'MESH:C000589253': ['bay 80-6946',
#   'copanlisib',
#   '2-amino-n-(7-methoxy-8-(3-morpholinopropoxy)-2,3-dihydroimidazo(1,2-c)quinazolin-4-yl)pyrimidine-5-carboxamide',
#   'aliqopa'],
#  'MESH:C000589254': ['unc569'],
#  'MESH:C000589255': ['sk-216'],
#  'MESH:C000589256': ['n-ethyl-4-(6-methylbenzo(d)thiazol-2-yl)aniline',
#   'thio-2 compound'],
#  'MESH:C000589257': ['vpc-3033'],
#  ...}

# %%
# for x in (all_cuis - mesh_omim_cuis):
#     # print(x.split(':')[-1])
#     print(x)
deprecated_cuis = list(all_cuis - mesh_omim_cuis)
with open('../data/ncbi_disease_deprecated_cuis.json', 'w') as f:
    f.write(ujson.dumps(deprecated_cuis))

# %%
col_names = "Disease_Name   Disease_ID       Alt_Disease_IDs   Definition      Parent_IDs       Tree_Numbers     Parent_Tree_Numbers       Synonyms        Slim_Mappings".lower().split()

medic = pd.read_csv("../data/CTD_diseases.tsv", comment='#', names=col_names, delimiter='\t', na_filter=False, usecols=['disease_name','disease_id','alt_disease_ids','definition','synonyms'])
medic
# Out:
#                            disease_name    disease_id  \
# 0       10p Deletion Syndrome (Partial)  MESH:C538288
# 1                 13q deletion syndrome  MESH:C535484
# 2                   15q24 Microdeletion  MESH:C579849
# 3             16p11.2 Deletion Syndrome  MESH:C579850
# 4      17,20-Lyase Deficiency, Isolated  MESH:C567076
# ...                                 ...           ...
# 13184   Zunich neuroectodermal syndrome  MESH:C536729
# 13185                   Zuska's Disease  MESH:C536730
# 13186                     Zygodactyly 1  MESH:C565223
# 13187               Zygomatic Fractures  MESH:D015051
# 13188                       Zygomycosis  MESH:D020096
#
#                    alt_disease_ids  \
# 0
# 1
# 2                  DO:DOID:0060395
# 3
# 4
# ...                            ...
# 13184  DO:DOID:0112152|OMIM:280000
# 13185
# 13186  DO:DOID:0111820|OMIM:609815
# 13187
# 13188
#
#                                               definition  \
# 0
# 1
# 2
# 3
# 4
# ...                                                  ...
# 13184
# 13185
# 13186
# 13187                           Fractures of the zygoma.
# 13188  Infection in humans and animals caused by fung...
#
#                                                 synonyms
# 0      Chromosome 10, 10p- Partial|Chromosome 10, mon...
# 1      Chromosome 13q deletion|Chromosome 13q deletio...
# 2      15q24 Deletion|15q24 Microdeletion Syndrome|In...
# 3
# 4      17-Alpha-Hydroxylase-17,20-Lyase Deficiency, C...
# ...                                                  ...
# 13184  CHIME|CHIME syndrome|COLOBOMA, CONGENITAL HEAR...
# 13185  Lactation and squamous metaplasia of lactifero...
# 13186                                                ZD1
# 13187  Fractures, Zygomatic|Fracture, Zygomatic|Zygom...
# 13188  Entomophthoramycoses|Entomophthoramycosis|Phyc...
#
# [13189 rows x 5 columns]

# %%
col_names = "Disease_Name   Disease_ID       Alt_Disease_IDs   Definition      Parent_IDs       Tree_Numbers     Parent_Tree_Numbers       Synonyms        Slim_Mappings".lower().split()

medic = pd.read_csv("../data/CTD_diseases.tsv", comment='#', names=col_names, delimiter='\t', na_filter=False, usecols=['disease_name','disease_id','alt_disease_ids','definition','synonyms'])
for col in medic.columns:
    medic[col] = medic[col].map(lambda x: x.strip())
medic.alt_disease_ids = medic.alt_disease_ids.map(lambda x: x.split('|'))
medic.synonyms = medic.synonyms.map(lambda x: x.split('|'))
medic['all_names'] = medic[['disease_name','synonyms']].apply(lambda x: [x[0]] + x[1], axis=1)
medic['all_ids'] = medic[['disease_id','alt_disease_ids']].apply(lambda x: [x[0]] + x[1], axis=1)

medic_arboel_entities = []
for x in medic.to_dict(orient='records'):
    joined_aliases = ' ; '.join([y for y in x['synonyms'] if y != ''])
    definition = x['definition'].strip()
    if len(definition) > 0:
        description = f"{x['disease_name']} ( Disease : {joined_aliases} ) [ {definition} ]"
    else:
        description = f"{x['disease_name']} ( Disease : {joined_aliases} )"

    d = {'type':'Disease', 
        'cui':x['disease_id'], 
        'title':x['disease_name'], 
        'cuis': [y for y in x['all_ids'] if y != '' and not y.startswith('DO:')], 
        'description': description,
        }
    medic_arboel_entities.append(d)

pickle.dump(medic_arboel_entities, open('../data/arboel/ncbi_disease/dictionary.pickle', 'wb'), protocol=pickle.HIGHEST_PROTOCOL)
    


# Make synonym list from medic dictionary
medic_cui2synonyms = defaultdict(set)
for x in medic[['all_names','all_ids']].values:
    for y in x[1]:
        if y == '' or y.startswith('DO:'):
            continue
        medic_cui2synonyms[y].update([z for z in x[0] if z != ''])


# # Add as many missing identifiers as we can from current UMLS
# for x in all_cuis - set(medic_cui2synonyms.keys()):
#     if x in mesh_omim_dict:
#         medic_cui2synonyms[x] = mesh_omim_dict[x]


# Write to file
medic_dict = {key: list(val) for key, val in medic_cui2synonyms.items()}
with open("../data/ncbi_disease_dict.json",'w') as f:
    f.write(ujson.dumps(medic_dict))

# Write in standard pipe-delimited format
with open('../data/alias_mappings/ncbi_disease_aliases.txt', 'w') as f:
    f.write('\n'.join([f"{key}||{v}" for key, val in medic_dict.items() for v in val]))

# len(all_cuis - set(medic_cui2synonyms.keys()))

# %%
medic_cui2synonyms
# Out:
# defaultdict(set,
#             {'MESH:D052159': ['frasier syndrome', 'syndrome, frasier'],
#              'MESH:D016864': ['li-fraumeni syndrome', 'li fraumeni syndrome'],
#              'MESH:D012175': ['retinoblastoma',
#               'retinoblastomas',
#               'glioblastoma, retinal',
#               'glioblastomas, retinal',
#               'retinal glioblastomas',
#               'retinal glioblastoma',
#               'glioma, retinal',
#               'gliomas, retinal',
#               'retinal gliomas',
#               'retinal glioma',
#               'neuroblastoma, retinal',
#               'neuroblastomas, retinal',
#               'retinal neuroblastomas',
#               'retinal neuroblastoma',
#               'eye cancer, retinoblastoma',
#               'cancers, retinoblastoma eye',
#               'eye cancers, retinoblastoma',
#               'retinoblastoma eye cancers',
#               'cancer, retinoblastoma eye',
#               'retinoblastoma eye cancer',
#               'familial retinoblastoma',
#               'familial retinoblastomas',
#               'retinoblastomas, familial',
#               'retinoblastoma, familial',
#               'hereditary retinoblastoma',
#               'hereditary retinoblastomas',
#               'retinoblastomas, hereditary',
#               'retinoblastoma, hereditary',
#               'sporadic retinoblastoma',
#               'retinoblastomas, sporadic',
#               'sporadic retinoblastomas',
#               'retinoblastoma, sporadic'],
#              'MESH:D009765': ['obesity'],
#              'MESH:D003123': ['hereditary nonpolyposis colorectal neoplasms',
#               'colorectal neoplasms, hereditary nonpolyposis',
#               'familial nonpolyposis colon cancer',
#               'hereditary nonpolyposis colorectal neopl',
#               'colorectal neopl hereditary nonpolyposis',
#               'hereditary nonpolyposis colorectal cancer',
#               'colorectal cancer hereditary nonpolyposis',
#               'hereditary nonpolyposis colon cancer',
#               'hnpcc',
#               'colon cancer, familial nonpolyposis',
#               'hereditary nonpolyposis colorectal cancer type 1',
#               'colorectal cancer, hereditary nonpolyposis, type 1',
#               'lynch syndrome i',
#               'lynch cancer family syndrome i',
#               'familial nonpolyposis colon cancer type 1',
#               'colon cancer, familial nonpolyposis, type 1',
#               'lynch syndrome',
#               'syndrome, lynch'],
#              'MESH:D010051': ['neoplasm, ovarian',
#               'ovarian neoplasm',
#               'neoplasms, ovarian',
#               'ovarian neoplasms',
#               'ovary neoplasms',
#               'neoplasm, ovary',
#               'ovary neoplasm',
#               'neoplasms, ovary',
#               'ovarian neopl',
#               'neopl ovarian',
#               'ovary neopl',
#               'ovarian cancer',
#               'cancers, ovarian',
#               'ovarian cancers',
#               'cancer, ovarian',
#               'ovary cancer',
#               'cancer of ovary',
#               'cancer of the ovary',
#               'cancers, ovary',
#               'ovary cancers',
#               'cancer, ovary'],
#              'MESH:D016920': ['meningitis, bacterial',
#               'bacterial meningitides',
#               'meningitides, bacterial',
#               'bacterial meningitis',
#               'bact meningitides',
#               'bact meningitis',
#               'meningitis bact',
#               'meningitides bact'],
#              'MESH:D004660': ['encephalitis',
#               'inflammation, brain',
#               'brain inflammations',
#               'brain inflammation',
#               'enceph',
#               'brain inflamm',
#               'inflamm brain',
#               'rasmussen syndrome',
#               "rasmussen's syndrome",
#               'rasmussen encephalitis',
#               'encephalitis, rasmussen',
#               'enceph rasmussen',
#               'rasmussen enceph'],
#              'MESH:D054067': ['dihydropyrimidine dehydrogenase deficiency',
#               'deficiencies, dihydropyrimidine dehydrogenase',
#               'dehydrogenase deficiencies, dihydropyrimidine',
#               'dihydropyrimidine dehydrogenase deficiencies',
#               'deficiency, dihydropyrimidine dehydrogenase',
#               'dehydrogenase deficiency, dihydropyrimidine',
#               'dpd deficiency',
#               'dpd deficiencies',
#               'deficiencies, dpd',
#               'deficiency, dpd',
#               'pyrimidinemia, familial',
#               'familial pyrimidinemias',
#               'pyrimidinemias, familial',
#               'familial pyrimidinemia',
#               'hereditary thymine-uraciluria',
#               'hereditary thymine uraciluria',
#               'hereditary thymine-uracilurias',
#               'thymine-uracilurias, hereditary',
#               'thymine uraciluria, hereditary',
#               'thymine-uraciluria, hereditary',
#               'familial pyrimidemia',
#               'familial pyrimidemias',
#               'pyrimidemias, familial',
#               'pyrimidemia, familial',
#               'dihydropyrimidinuria',
#               'dihydropyrimidinurias'],
#              'MESH:D001523': ['behavior disorders',
#               'behavior dis',
#               'mental disorders',
#               'mental disorder',
#               'psychiatric disorders',
#               'psychiatric disorder',
#               'mental illness',
#               'mental illnesses',
#               'illness, mental',
#               'psychiatric illness',
#               'psychiatric illnesses',
#               'psychiatric diseases',
#               'psychiatric disease',
#               'mental dis',
#               'diagnosis, psychiatric',
#               'psychiatric diagnosis',
#               'psychiatric diag',
#               'diag psychiatric',
#               'mental disorders, severe',
#               'mental disorder, severe',
#               'severe mental disorder',
#               'severe mental disorders'],
#              'MESH:D001424': ['bacterial infections',
#               'bacterial infection',
#               'infection, bacterial',
#               'infections, bacterial',
#               'bacterial disease',
#               'bacterial diseases',
#               'bact infect',
#               'infect bact'],
#              'MESH:C536575': ['borjeson-forssman-lehmann syndrome',
#               'borjeson syndrome',
#               'mental deficiency, epilepsy and endocrine disorders',
#               'mental deficiency, epilepsy, and endocrine disorders'],
#              'MESH:D005146': ['asymmetry, facial',
#               'facial asymmetry',
#               'asymmetries, facial',
#               'facial asymmetries'],
#              'MESH:D000745': ['anemia, hemolytic, congenital',
#               'anemias, congenital hemolytic',
#               'congenital hemolytic anemias',
#               'hemolytic anemias, congenital',
#               'anemia, congenital hemolytic',
#               'congenital hemolytic anemia',
#               'hemolytic anemia, congenital',
#               'anemia, hemolytic, hereditary',
#               'anemias, hereditary hemolytic',
#               'hemolytic anemias, hereditary',
#               'hereditary hemolytic anemias',
#               'anemia, hereditary hemolytic',
#               'hemolytic anemia, hereditary',
#               'hereditary hemolytic anemia',
#               'hemolytic anemia congen',
#               'anemia hemolytic congen',
#               'congen hemolytic anemia'],
#              'MESH:D000309': ['hypofunction, adrenal gland',
#               'adrenal gland hypofunction',
#               'adrenal insufficiency',
#               'adrenal insufficiencies',
#               'hypoadrenalism'],
#              'MESH:D012141': ['respiratory tract infections',
#               'infection, respiratory tract',
#               'respiratory tract infection',
#               'infections, respiratory tract',
#               'infections, respiratory',
#               'respiratory infections',
#               'respiratory tract infect',
#               'infect respiratory tract',
#               'infect respiratory',
#               'respiratory infect',
#               'upper respiratory infections',
#               'respiratory infection, upper',
#               'infections, upper respiratory',
#               'upper respiratory tract infections',
#               'upper respiratory tract infection',
#               'infections, upper respiratory tract',
#               'upper respiratory infect',
#               'infect upper respiratory'],
#              'OMIM:613825': ['c9 deficiency',
#               'complement component 9 deficiency',
#               'c9d'],
#              'OMIM:109150': ['machado-joseph disease',
#               'spinopontine atrophy',
#               'spinocerebellar ataxia 3',
#               'sca3',
#               'mjd',
#               'nigrospinodentatal degeneration',
#               'azorean neurologic disease',
#               'spinocerebellar atrophy iii'],
#              'OMIM:255125': ['myopathy with exercise intolerance, swedish type',
#               'hml',
#               'myopathy with deficiency of succinate dehydrogenase and aconitase',
#               'myopathy with lactic acidosis, hereditary',
#               'myoglobinuria due to abnormal glycolysis'],
#              'MESH:D008586': ['meningitis, pneumococcal',
#               'pneumococcal meningitides',
#               'pneumococcal meningitis',
#               'meningitis, streptococcus pneumoniae',
#               'meningitides, streptococcus pneumoniae',
#               'streptococcus pneumoniae meningitides',
#               'streptococcus pneumoniae meningitis',
#               'experimental pneumococcal meningitis',
#               'experimental pneumococcal meningitides',
#               'pneumococcal meningitides, experimental',
#               'meningitis, experimental pneumococcal',
#               'meningitis, pneumococcal, experimental',
#               'pneumococcal meningitis, experimental',
#               'exper pneumococcal meningitis',
#               'meningitis pneumococcal exper',
#               'meningitis, pneumococcal, penicillin-resistant',
#               'meningitis, pneumococcal, recurrent'],
#              'MESH:C538445': ['clear-cell metastatic renal cell carcinoma'],
#              'MESH:D053842': ['microsatellite instability',
#               'instability, microsatellite',
#               'replication error phenotype',
#               'error phenotypes, replication',
#               'phenotypes, replication error',
#               'replication error phenotypes',
#               'error phenotype, replication',
#               'phenotype, replication error'],
#              'MESH:C531844': ['von willebrand factor, deficiency'],
#              'MESH:C537277': ['glycosylphosphatidylinositol deficiency'],
#              'MESH:D058499': ['retinal dystrophies',
#               'dystrophy, retinal',
#               'retinal dystrophy',
#               'dystrophies, retinal'],
#              'MESH:D001941': ['breast diseases',
#               'breast disease',
#               'disease, breast',
#               'diseases, breast',
#               'breast dis',
#               'endocrine breast diseases',
#               'breast disease, endocrine',
#               'disease, endocrine breast',
#               'endocrine breast disease',
#               'breast diseases, endocrine',
#               'diseases, endocrine breast',
#               'endocrine breast dis'],
#              'MESH:D009078': ['mucocele', 'mucoceles'],
#              'MESH:D019190': ['iron overload', 'overload, iron'],
#              'MESH:D007645': ['meleda disease',
#               'disease, meleda',
#               'mal de meleda',
#               'meleda, mal de',
#               'de meleda, mal',
#               'meleda dis',
#               'keratosis palmoplantaris transgradiens of siemens',
#               'keratoderma, palmoplantar',
#               'keratodermas, palmoplantar',
#               'palmoplantar keratodermas',
#               'palmoplantar keratoderma',
#               'hyperkeratosis palmaris et plantaris',
#               'keratosis palmaris et plantaris',
#               'keratosis, palmoplantar',
#               'keratoses, palmoplantar',
#               'palmoplantar keratoses',
#               'palmoplantar keratosis'],
#              'OMIM:145001': ['hyperparathyroidism 2 with jaw tumors',
#               'hpt-jt',
#               'hrpt2',
#               'hyperparathyroidism-jaw tumor syndrome, hereditary',
#               'hyperparathyroidism, familial primary, with multiple ossifying jaw fibromas',
#               'parathyroid adenomatosis, familial cystic'],
#              'MESH:D017034': ['epilepsy, frontal lobe',
#               'frontal lobe epilepsies',
#               'frontal lobe epilepsy',
#               'frontal epilepsy, benign, childhood',
#               'benign frontal childhood epilepsy',
#               'childhood benign frontal epilepsy',
#               'epilepsy, benign frontal, childhood',
#               'epilepsy, supplementary motor',
#               'epilepsies, supplementary motor',
#               'supplementary motor epilepsies',
#               'supplementary motor epilepsy',
#               'epilepsy, cingulate',
#               'cingulate epilepsies',
#               'epilepsies, cingulate',
#               'cingulate epilepsy',
#               'epilepsy, opercular',
#               'opercular epilepsies',
#               'opercular epilepsy',
#               'epilepsy, anterior fronto-polar',
#               'anterior fronto-polar epilepsies',
#               'epilepsies, anterior fronto-polar',
#               'epilepsy, anterior fronto polar',
#               'anterior fronto-polar epilepsy',
#               'epilepsy, orbito-frontal',
#               'epilepsies, orbito-frontal',
#               'epilepsy, orbito frontal',
#               'orbito-frontal epilepsies',
#               'orbito-frontal epilepsy'],
#              'MESH:D009410': ['nerve degeneration',
#               'degenerations, nerve',
#               'nerve degenerations',
#               'degeneration, nerve',
#               'neuron degeneration',
#               'degenerations, neuron',
#               'neuron degenerations',
#               'degeneration, neuron'],
#              'OMIM:261600': ['phenylketonuria, maternal',
#               'phenylketonuria',
#               'pku',
#               'phenylalanine hydroxylase deficiency',
#               'pah deficiency',
#               'oligophrenia phenylpyruvica',
#               'folling disease',
#               'hyperphenylalaninemia, non-pku mild',
#               'hpa, non-pku mild'],
#              'MESH:D007965': ['leukodystrophy, globoid cell',
#               'cell leukodystrophy, globoid',
#               'globoid cell leukodystrophy',
#               'globoid cell leukodystrophies',
#               'leukodystrophies, globoid cell',
#               'cell leukodystrophies, globoid',
#               'globoid leukodystrophy',
#               'globoid leukodystrophies',
#               'leukodystrophies, globoid',
#               'leukodystrophy, globoid',
#               'krabbe disease',
#               "krabbe's disease",
#               'krabbes disease',
#               'diffuse globoid body sclerosis',
#               'globoid body sclerosis, diffuse',
#               'galactosylceramide lipidosis',
#               "krabbe's leukodystrophy",
#               'krabbe leukodystrophy',
#               'krabbes leukodystrophy',
#               'leukodystrophy, krabbe',
#               "leukodystrophy, krabbe's",
#               'galactosylceramide beta-galactosidase deficiency',
#               'deficiencies, galactosylceramide beta-galactosidase',
#               'galactosylceramide beta galactosidase deficiency',
#               'galactosylceramide beta-galactosidase deficiencies',
#               'beta-galactosidase deficiencies, galactosylceramide',
#               'deficiency, galactosylceramide beta-galactosidase',
#               'beta-galactosidase deficiency, galactosylceramide',
#               'galactosylcerebrosidase deficiency',
#               'galactosylceramide-beta-galactosidase deficiency disease',
#               'deficiency diseases, galactosylceramide-beta-galactosidase',
#               'diseases, galactosylceramide-beta-galactosidase deficiency',
#               'galactosylceramide beta galactosidase deficiency disease',
#               'galactosylceramide-beta-galactosidase deficiency diseases',
#               'deficiency disease, galactosylceramide-beta-galactosidase',
#               'disease, galactosylceramide-beta-galactosidase deficiency',
#               'galactosylceramidase deficiency disease',
#               'deficiency diseases, galactosylceramidase',
#               'diseases, galactosylceramidase deficiency',
#               'galactosylceramidase deficiency diseases',
#               'deficiency disease, galactosylceramidase',
#               'disease, galactosylceramidase deficiency',
#               'galactocerebrosidase deficiency',
#               'deficiencies, galactocerebrosidase',
#               'galactocerebrosidase deficiencies',
#               'deficiency, galactocerebrosidase',
#               'galactosylsphingosine lipidosis',
#               'psychosine lipidosis',
#               'krabbe dis',
#               'krabbes dis',
#               'globoid cell leukoencephalopathy',
#               'cell leukoencephalopathies, globoid',
#               'globoid cell leukoencephalopathies',
#               'leukoencephalopathies, globoid cell',
#               'cell leukoencephalopathy, globoid',
#               'leukoencephalopathy, globoid cell',
#               'galc deficiency',
#               'deficiencies, galc',
#               'galc deficiencies',
#               'deficiency, galc',
#               'galactosylceramidase defic dis',
#               'late-onset globoid cell leukodystrophy',
#               'late onset globoid cell leukodystrophy',
#               'leukodystrophy, globoid cell, late-onset',
#               'infantile globoid cell leukodystrophy',
#               'leukodystrophy, globoid cell, infantile',
#               'early-onset globoid cell leukodystrophy',
#               'early onset globoid cell leukodystrophy',
#               'leukodystrophy, globoid cell, early-onset',
#               'leukodystrophy, globoid cell, classic',
#               'classic globoid cell leukodystrophy'],
#              'MESH:D009837': ['oligodendroglioma',
#               'oligodendrogliomas',
#               'adult oligodendroglioma',
#               'adult oligodendrogliomas',
#               'oligodendrogliomas, adult',
#               'oligodendroglioma, adult',
#               'childhood oligodendroglioma',
#               'childhood oligodendrogliomas',
#               'oligodendrogliomas, childhood',
#               'oligodendroglioma, childhood',
#               'mixed oligodendroglioma-astrocytoma',
#               'mixed oligodendroglioma astrocytoma',
#               'mixed oligodendroglioma-astrocytomas',
#               'oligodendroglioma-astrocytomas, mixed',
#               'oligodendroglioma-astrocytoma, mixed',
#               'anaplastic oligodendroglioma',
#               'anaplastic oligodendrogliomas',
#               'oligodendrogliomas, anaplastic',
#               'oligodendroglioma, anaplastic',
#               'oligodendroblastoma',
#               'oligodendroblastomas',
#               'mixed oligodendroglioma-ependymoma',
#               'mixed oligodendroglioma ependymoma',
#               'mixed oligodendroglioma-ependymomas',
#               'oligodendroglioma-ependymomas, mixed',
#               'oligodendroglioma-ependymoma, mixed',
#               'well differentiated oligodendroglioma',
#               'well-differentiated oligodendroglioma',
#               'oligodendrogliomas, well-differentiated',
#               'well-differentiated oligodendrogliomas',
#               'oligodendroglioma, well differentiated',
#               'oligodendroglioma, well-differentiated',
#               'oligodendroglioma well differ',
#               'well differ oligodendroglioma'],
#              'MESH:D009421': ['cranioschisis',
#               'cranioschises',
#               'nervous system abnormalities',
#               'abnormality, nervous system',
#               'nervous system abnormality',
#               'abnormalities, nervous system',
#               'congenital anomalies, nervous system',
#               'nervous system congenital malformations',
#               'congenital malformations, nervous system',
#               'malformations, nervous system, congenital',
#               'nervous system malformations, congenital',
#               'nervous system anomalies',
#               'anomaly, nervous system',
#               'nervous system anomaly',
#               'anomalies, nervous system',
#               'nervous system congenital abnormalities',
#               'abnormalities, congenital, nervous system',
#               'congenital abnormalities, nervous system',
#               'nervous system malformations',
#               'malformation, nervous system',
#               'nervous system malformation',
#               'malformations, nervous system',
#               'congen anomalies nervous system',
#               'congen abnorm nervous system',
#               'nervous system congen abnorm',
#               'abnorm congen nervous system',
#               'congen malformations nervous system',
#               'malformations nervous system congen',
#               'nervous system congen malformations',
#               'nervous system malformations congen',
#               'nervous system abnorm',
#               'abnorm nervous system'],
#              'MESH:D015834': ['cochlear diseases',
#               'cochlear disease',
#               'disease, cochlear',
#               'diseases, cochlear',
#               'cochlear dis'],
#              'MESH:D049288': ['muscular dystrophies, limb-girdle',
#               'limb-girdle muscular dystrophy',
#               'muscular dystrophy, limb girdle',
#               'muscular dystrophy, limb-girdle',
#               'limb girdle muscular dystrophy',
#               'muscular dystrophies, limb girdle',
#               'limb-girdle muscular dystrophies',
#               'limb girdle muscular dystrophies',
#               'myopathic limb-girdle syndrome',
#               'limb-girdle syndrome'],
#              'MESH:D003318': ['corneal opacity',
#               'corneal opacities',
#               'opacities, corneal',
#               'opacity, corneal',
#               'leukoma',
#               'leukomas'],
#              'MESH:D028361': ['mitochondrial diseases',
#               'mitochondrial disease',
#               'disease, mitochondrial',
#               'mitochondrial disorders',
#               'mitochondrial disorder',
#               'disorder, mitochondrial',
#               'disorders, mitochondrial',
#               'mitochondrial dis',
#               'electron transport chain deficiencies, mitochondrial',
#               'mitochondrial electron transport chain deficiencies',
#               'electron transport chain defic mitochondrial',
#               'mitochondrial electron transport chain defic',
#               'oxidative phosphorylation deficiencies',
#               'deficiency, oxidative phosphorylation',
#               'oxidative phosphorylation deficiency',
#               'phosphorylation deficiency, oxidative',
#               'deficiencies, oxidative phosphorylation',
#               'phosphorylation deficiencies, oxidative',
#               'ox phos defic',
#               'mitochondrial respiratory chain deficiencies',
#               'respiratory chain deficiencies, mitochondrial',
#               'deficiencies, respiratory chain',
#               'deficiency, respiratory chain',
#               'respiratory chain deficiency',
#               'respiratory chain defic mitochondrial'],
#              'MESH:D000853': ['anophthalmos', 'anophthalmia', 'anophthalmias'],
#              'MESH:D010510': ['periodontal diseases',
#               'disease, periodontal',
#               'periodontal disease',
#               'diseases, periodontal',
#               'parodontosis',
#               'parodontoses',
#               'periodontal dis',
#               'pyorrhea alveolaris'],
#              'MESH:D011115': ['polyneuropathy',
#               'polyneuropathies',
#               'polyneuropathy, motor',
#               'motor polyneuropathies',
#               'polyneuropathies, motor',
#               'motor polyneuropathy',
#               'polyneuropathy, critical illness',
#               'critical illness polyneuropathies',
#               'polyneuropathies, critical illness',
#               'critical illness polyneuropathy',
#               'polyneuropathy, familial',
#               'familial polyneuropathies',
#               'polyneuropathies, familial',
#               'familial polyneuropathy',
#               'polyneuropathy, inherited',
#               'inherited polyneuropathies',
#               'polyneuropathies, inherited',
#               'inherited polyneuropathy',
#               'acquired polyneuropathy',
#               'acquired polyneuropathies',
#               'polyneuropathies, acquired',
#               'polyneuropathy, acquired'],
#              'MESH:D013166': ['spondylitis', 'spondylitides'],
#              'MESH:D003922': ['diabetes mellitus, insulin-dependent',
#               'diabetes mellitus, insulin dependent',
#               'insulin-dependent diabetes mellitus',
#               'diabetes mellitus, juvenile-onset',
#               'diabetes mellitus, juvenile onset',
#               'juvenile-onset diabetes mellitus',
#               'diabetes mellitus, type 1',
#               'type 1 diabetes mellitus',
#               'iddm',
#               'diabetes mellitus, type i',
#               'diabetes mellitus, sudden-onset',
#               'diabetes mellitus, sudden onset',
#               'sudden-onset diabetes mellitus',
#               'type 1 diabetes',
#               'diabetes, type 1',
#               'juvenile-onset diabetes',
#               'juvenile onset diabetes',
#               'diabetes, juvenile-onset',
#               'diabetes mellitus, insulin-dependent, 1',
#               'insulin dependent diabetes mellitus 1',
#               'insulin-dependent diabetes mellitus 1',
#               'diabetes mellitus type 01',
#               'diabetes, autoimmune',
#               'autoimmune diabetes',
#               'diabetes mellitus, brittle',
#               'brittle diabetes mellitus',
#               'diabetes mellitus, ketosis-prone',
#               'diabetes mellitus, ketosis prone',
#               'ketosis-prone diabetes mellitus'],
#              'MESH:D001019': ['aortic rupture',
#               'aortic ruptures',
#               'ruptures, aortic',
#               'rupture, aortic',
#               'aortic aneurysm, ruptured',
#               'aneurysms, ruptured aortic',
#               'aortic aneurysms, ruptured',
#               'ruptured aortic aneurysms',
#               'aneurysm, ruptured aortic',
#               'ruptured aortic aneurysm'],
#              'MESH:D001304': ['auditory diseases, central',
#               'auditory disease, central',
#               'central auditory disease',
#               'central auditory diseases',
#               'auditory dysfunction, central',
#               'dysfunctions, central auditory',
#               'central auditory dysfunction',
#               'dysfunction, central auditory',
#               'central auditory pathway disorders',
#               'auditory pathway disorders, central',
#               'auditory dis central',
#               'central auditory dis',
#               'auditory pathway dis central',
#               'central auditory pathway dis',
#               'auditory cortex disorder',
#               'auditory cortex disorders',
#               'cortex disorders, auditory',
#               'cortex disorder, auditory',
#               'auditory cortex dis'],
#              'MESH:D017496': ['hypopigmentation',
#               'hypomelanosis',
#               'hypomelanoses'],
#              'OMIM:202370': ['peroxisome biogenesis disorder 2b', 'pbd2b'],
#              'MESH:D016464': ['lysosomal storage diseases',
#               'disease, lysosomal storage',
#               'lysosomal storage disease',
#               'diseases, lysosomal storage',
#               'lysosomal enzyme disorders',
#               'disorder, lysosomal enzyme',
#               'enzyme disorder, lysosomal',
#               'lysosomal enzyme disorder',
#               'disorders, lysosomal enzyme',
#               'enzyme disorders, lysosomal',
#               'lysosomal enzyme dis',
#               'lysosomal storage dis'],
#              'OMIM:300100': ['adrenoleukodystrophy',
#               'ald',
#               'bronze schilder disease',
#               'siemerling-creutzfeldt disease',
#               'melanodermic leukodystrophy',
#               'addison disease and cerebral sclerosis',
#               'adrenomyeloneuropathy',
#               'amn'],
#              'MESH:D006222': ['hamartoma', 'hamartomas'],
#              'MESH:D007573': ['jaw neoplasms',
#               'jaw neoplasm',
#               'neoplasm, jaw',
#               'neoplasms, jaw',
#               'jaw neopl',
#               'neopl jaw',
#               'cancer of jaw',
#               'cancer of the jaw',
#               'cancers, jaw',
#               'jaw cancer',
#               'jaw cancers',
#               'cancer, jaw'],
#              'MESH:D012700': ['serositis', 'serositides'],
#              'MESH:C535964': ['collagenopathy, type 2 alpha 1',
#               'cartilage collagen'],
#              'MESH:D007154': ['immune system diseases',
#               'diseases of immune system',
#               'immune system disease',
#               'disease, immune system',
#               'immunologic diseases',
#               'disease, immunologic',
#               'immunologic disease',
#               'immune system disorders',
#               'disorder, immune system',
#               'immune system disorder',
#               'immunological diseases',
#               'disease, immunological',
#               'immunological disease',
#               'immune disorders',
#               'immune disorder',
#               'immune diseases',
#               'disease, immune',
#               'immune disease',
#               'immunological dis',
#               'immunol dis',
#               'dis immune system',
#               'immune system dis'],
#              'MESH:D000567': ['amelogenesis imperfecta',
#               'congenital enamel hypoplasia'],
#              'MESH:D012516': ['osteosarcoma',
#               'osteosarcomas',
#               'sarcoma, osteogenic',
#               'osteogenic sarcomas',
#               'sarcomas, osteogenic',
#               'osteogenic sarcoma',
#               'osteosarcoma tumor',
#               'osteosarcoma tumors',
#               'tumors, osteosarcoma',
#               'tumor, osteosarcoma'],
#              'MESH:D005124': ['eye abnormalities',
#               'abnormality, eye',
#               'eye abnormality',
#               'abnormalities, eye',
#               'eye abnorm'],
#              'MESH:D006946': ['hyperinsulinism',
#               'hyperinsulinemia',
#               'endogenous hyperinsulinism',
#               'hyperinsulinism, endogenous',
#               'exogenous hyperinsulinism',
#               'hyperinsulinism, exogenous',
#               'compensatory hyperinsulinemia',
#               'hyperinsulinemia, compensatory'],
#              'OMIM:164160': ['leptin',
#               'ob',
#               'lep',
#               'obese, mouse, homolog of',
#               'leptin deficiency',
#               'leptin dysfunction'],
#              'MESH:C537775': ['anterior segment mesenchymal dysgenesis',
#               'anterior segment ocular dysgenesis'],
#              'OMIM:153400': ['lymphedema-distichiasis syndrome',
#               'lphdst',
#               'lymphedema with distichiasis',
#               'lymphedema-distichiasis syndrome with renal disease and diabetes mellitus'],
#              'MESH:D020821': ['dystonia disorders',
#               'dystonia disorder',
#               'dystonic disorders',
#               'dystonic disorder',
#               'dystonic dis',
#               'dystonia dis',
#               'dystonia, idiopathic familial',
#               'familial dystonia, idiopathic',
#               'idiopathic familial dystonia',
#               'dystonias, idiopathic familial',
#               'familial dystonias, idiopathic',
#               'idiopathic familial dystonias',
#               'focal dystonia',
#               'dystonias, focal',
#               'focal dystonias',
#               'dystonia, focal',
#               'adult-onset dystonias',
#               'adult-onset dystonia',
#               'dystonia, adult-onset',
#               'adult onset dystonias',
#               'dystonias, adult-onset',
#               'adult-onset idiopathic focal dystonias',
#               'adult onset idiopathic focal dystonias',
#               'adult-onset idiopathic torsion dystonias',
#               'adult onset idiopathic torsion dystonias',
#               'autosomal dominant familial dystonia',
#               'familial dystonia, autosomal dominant',
#               'autosomal recessive familial dystonia',
#               'familial dystonia, autosomal recessive',
#               'childhood onset dystonias',
#               'childhood onset dystonia',
#               'dystonia, childhood onset',
#               'dystonias, childhood onset',
#               'dystonia, primary',
#               'dystonias, primary',
#               'primary dystonias',
#               'primary dystonia',
#               'dystonia, secondary',
#               'dystonias, secondary',
#               'secondary dystonias',
#               'secondary dystonia',
#               'dystonia second',
#               'second dystonia',
#               'dystonias, sporadic',
#               'dystonia, sporadic',
#               'sporadic dystonia',
#               'sporadic dystonias',
#               'familial dystonia',
#               'dystonias, familial',
#               'familial dystonias',
#               'dystonia, familial',
#               'dystonia, hereditary',
#               'dystonias, hereditary',
#               'hereditary dystonias',
#               'hereditary dystonia',
#               'pseudodystonia',
#               'dystonia, psychogenic',
#               'dystonias, psychogenic',
#               'psychogenic dystonias',
#               'psychogenic dystonia',
#               'pseudodystonias',
#               "writer's cramp",
#               'writer cramp',
#               'writers cramp'],
#              'MESH:D000326': ['adrenoleukodystrophy',
#               'schilder-addison complex',
#               'schilder addison complex',
#               'bronze schilder disease',
#               'siemerling-creutzfeldt disease',
#               'siemerling creutzfeldt disease',
#               'x-ald (x-linked adrenoleukodystrophy)',
#               'x ald (x linked adrenoleukodystrophy)',
#               'x-ald',
#               'x ald',
#               'ald (adrenoleukodystrophy)',
#               'x-linked adrenoleukodystrophy',
#               'x linked adrenoleukodystrophy',
#               'adrenoleukodystrophy, x-linked',
#               'melanodermic leukodystrophy',
#               'leukodystrophies, melanodermic',
#               'leukodystrophy, melanodermic',
#               'addison disease and cerebral sclerosis',
#               'adrenomyeloneuropathy'],
#              'MESH:D014071': ['tooth abnormalities',
#               'abnormality, tooth',
#               'tooth abnormality',
#               'abnormalities, teeth',
#               'abnormality, teeth',
#               'teeth abnormalities',
#               'teeth abnormality',
#               'abnormalities, tooth',
#               'tooth abnorm',
#               'teeth abnorm',
#               'abnorm teeth',
#               'abnorm tooth',
#               'odontome',
#               'odontomes'],
#              'OMIM:314250': ['dystonia 3, torsion, x-linked',
#               'dystonia-parkinsonism, x-linked',
#               'xdp',
#               'dyt3',
#               'torsion dystonia-parkinsonism, filipino type'],
#              'MESH:D015223': ['wolman disease',
#               "wolman's disease",
#               'wolmans disease',
#               "disease, wolman's",
#               'disease, wolman',
#               'xanthomatosis, familial',
#               'familial xanthomatoses',
#               'xanthomatoses, familial',
#               'familial xanthomatosis',
#               "xanthomatosis, wolman's",
#               'xanthomatosis, wolman',
#               'xanthomatosis, wolmans',
#               "wolman's xanthomatosis",
#               'acid lipase deficiency',
#               'liposomal acid lipase deficiency, wolman type',
#               'wolman dis',
#               'wolmans dis',
#               'acid cholesteryl ester hydrolase deficiency, wolman type'],
#              'MESH:D008581': ['meningitis',
#               'meningitides',
#               'pachymeningitis',
#               'pachymeningitides'],
#              'OMIM:103600': ['hyperthyroxinemia, familial dysalbuminemic',
#               'albumin',
#               'alb',
#               'proalbumin takefu',
#               'albumin blenheim',
#               'albumin nagasaki 3',
#               'albumin yanomama 2',
#               'albumin nagoya',
#               'albumin castel di sangro',
#               'albumin tagliacozzo',
#               'albumin hiroshima 1',
#               'albumin coari i',
#               'albumin naskapi',
#               'albumin nagasaki 2',
#               'albumin roma',
#               'albumin rugby park',
#               'albumin redhill',
#               'albumin dublin',
#               'albumin herborn',
#               'albumin niigata',
#               'albumin ortonovo',
#               'albumin parklands',
#               'proalbumin lille',
#               'proalbumin christchurch',
#               'albumin tochigi',
#               'albumin hiroshima 2',
#               'albumin vancouver',
#               'albumin maku',
#               'albumin mexico 2',
#               'albumin fukuoka 1',
#               'albumin osaka 1',
#               'albumin b',
#               'albumin milano fast',
#               'albumin vanves',
#               'analbuminemia vancouver',
#               'albumin venezia',
#               'proalbumin malmo',
#               'proalbumin jaffna',
#               'albumin catania',
#               'albumin torino',
#               'albumin vibo valentia',
#               'albumin casebrook',
#               'albumin iowa city 1',
#               'albumin komagome 2',
#               'analbuminemia roma',
#               'albumin larino',
#               'albumin tradate 2',
#               'albumin caserta',
#               'albumin bazzano',
#               'albumin asola',
#               'albumin malmo-95',
#               'albumin hawkes bay',
#               'albumin malmo-47',
#               'albumin sondria',
#               'albumin malmo-5',
#               'analbuminemia baghdad',
#               'albumin malmo-10',
#               'analbuminemia ghazaouet',
#               'hypertriiodothyroninemia, familial dysalbuminemic',
#               'analbuminemia codogno',
#               'analbuminemia bethesda',
#               'analbuminemia canadian'],
#              'OMIM:313900': ['thc',
#               'xlt',
#               'thrombocytopenia 1',
#               'thrombocytopenia, x-linked',
#               'thc1',
#               'thrombocytopenia, x-linked, 1',
#               'thrombocytopenia, x-linked, intermittent'],
#              'MESH:D005355': ['fibrosis', 'fibroses', 'cirrhosis'],
#              'MESH:D012600': ['scoliosis', 'scolioses'],
#              'MESH:D006474': ['hemorrhagic disorders',
#               'disorder, hemorrhagic',
#               'hemorrhagic disorder',
#               'disorders, hemorrhagic',
#               'hemorrhagic diathesis',
#               'diatheses, hemorrhagic',
#               'hemorrhagic diatheses',
#               'diathesis, hemorrhagic',
#               'hemorrhagic dis'],
#              'MESH:D002607': ['charcot-marie-tooth disease',
#               'charcot marie tooth disease',
#               'charcot-marie disease',
#               'charcot marie disease',
#               'peroneal muscular atrophy',
#               'atrophies, peroneal muscular',
#               'muscular atrophies, peroneal',
#               'peroneal muscular atrophies',
#               'atrophy, muscular, peroneal',
#               'atrophy, peroneal muscular',
#               'muscular atrophy, peroneal',
#               'charcot-marie-tooth syndrome',
#               'charcot marie tooth syndrome',
#               'syndrome, charcot-marie-tooth',
#               'charcot-marie-tooth hereditary neuropathy',
#               'charcot marie tooth hereditary neuropathy',
#               'hereditary neuropathy, charcot-marie-tooth',
#               'charcot marie tooth dis',
#               'charcot marie dis',
#               'hereditary areflexic dystasia',
#               'areflexic dystasia, hereditary',
#               'dystasia, hereditary areflexic',
#               'roussy-levy syndrome',
#               'roussy levy syndrome',
#               'syndrome, roussy-levy',
#               'roussy levy hereditary areflexic dystasia',
#               'roussy-levy hereditary areflexic dystasia',
#               'areflexic dystasias, hereditary',
#               'dystasias, hereditary areflexic',
#               'hereditary areflexic dystasias',
#               'roussy-levy disease',
#               'roussy levy disease',
#               'charcot-marie-tooth disease, type ia',
#               'charcot marie tooth disease, type ia',
#               'charcot-marie-tooth disease, demyelinating, type 1a',
#               'hereditary motor and sensory neuropathy ia',
#               'charcot-marie-tooth disease, autosomal dominant, with focally folded myelin sheaths, type 1a',
#               'charcot-marie-tooth neuropathy, type 1a',
#               'charcot marie tooth neuropathy, type 1a',
#               'hmsn ia',
#               'charcot-marie-tooth disease, type 1a',
#               'charcot marie tooth disease, type 1a',
#               'hmsn1a',
#               'hmsn 1a',
#               'hereditary motor and sensory neuropathy 1a',
#               'charcot marie tooth disease, type ib',
#               'charcot-marie-tooth disease, type ib',
#               'charcot-marie-tooth disease, autosomal dominant, with focally folded myelin sheaths, type 1b',
#               'hmsn ib',
#               'charcot-marie-tooth disease, type 1b',
#               'charcot marie tooth disease, type 1b',
#               'charcot-marie-tooth neuropathy, type 1b',
#               'charcot marie tooth neuropathy, type 1b',
#               'hereditary motor and sensory neuropathy ib',
#               'charcot-marie-tooth disease, demyelinating, type 1b',
#               'charcot-marie-tooth disease, slow nerve conduction type, linked to duffy',
#               'hmsn1b',
#               'hereditary motor and sensory neuropathy 1b',
#               'hmsn 1b',
#               'hereditary motor and sensory-neuropathy type ii',
#               'hereditary motor and sensory neuropathy type ii',
#               'hereditary motor sensory type ii neuropathy',
#               'neuropathy type ii hereditary motor sensory',
#               'neuropathy, type ii hereditary motor and sensory',
#               'hmsn type ii',
#               'charcot-marie-tooth disease, type ii',
#               'charcot marie tooth disease, type ii',
#               'hmsn ii',
#               'charcot marie tooth dis type ii',
#               'hereditary motor, and sensory neuropathy type i',
#               'hereditary type i motor sensory neuropathy',
#               'neuropathy type i hereditary motor sensory',
#               'hereditary motor sensory type i neuropathy',
#               'hereditary type i motor and sensory neuropathy',
#               'neuropathy, type i hereditary motor and sensory',
#               'hmn distal type i',
#               'hmsn type i',
#               'charcot-marie-tooth disease, type i',
#               'charcot marie tooth disease, type i',
#               'hmsn i',
#               'charcot marie tooth dis type i'],
#              'MESH:D012021': ['reflex, abnormal',
#               'abnormal reflexes',
#               'reflexes, abnormal',
#               'abnormal reflex',
#               'reflex abnorm',
#               'reflexes abnorm',
#               'abnorm reflexes',
#               'abnorm reflex',
#               'reflex, corneal, decreased',
#               'hyporeflexia',
#               'reflex, decreased',
#               'decreased reflex',
#               'hyperreflexia',
#               'reflex, absent',
#               'absent reflex',
#               'reflex, gag, absent',
#               'reflex, deep tendon, absent',
#               "hoffman's reflex",
#               "reflex, hoffman's",
#               'reflex, pendular',
#               'pendular reflex',
#               'reflex, corneal, absent',
#               'reflex, acoustic, abnormal',
#               'reflex acoustic abnorm',
#               'reflex, ankle, absent',
#               'reflex, triceps, absent',
#               'reflex, biceps, absent',
#               'reflex, anal, absent',
#               'abnormal deep tendon reflex',
#               'reflex, deep tendon, abnormal',
#               'abnorm deep tendon reflex',
#               'bulbocavernosus reflex, decreased',
#               'decreased bulbocavernosus reflex',
#               'reflex, decreased bulbocavernosus',
#               'bulbocavernousus reflex absent',
#               'reflex absent, bulbocavernousus',
#               'palmo-mental reflex',
#               'palmo mental reflex',
#               'reflex, palmo-mental',
#               'reflex, anal, decreased',
#               'reflex, ankle, abnormal',
#               'reflex ankle abnorm',
#               'reflex, ankle, decreased',
#               'reflex, biceps, abnormal',
#               'reflex biceps abnorm',
#               'reflex, biceps, decreased',
#               'reflex, gag, decreased',
#               'reflex, knee, abnormal',
#               'reflex knee abnorm',
#               'reflex, knee, decreased',
#               'reflex, moro, asymmetric',
#               'reflex, triceps, abnormal',
#               'reflex triceps abnorm',
#               'reflex, triceps, decreased'],
#              'MESH:D054508': ['acute radiation syndrome',
#               'acute radiation syndromes',
#               'radiation syndromes, acute',
#               'radiation syndrome, acute'],
#              'MESH:D000307': ['adrenal gland diseases',
#               'adrenal gland disease',
#               'gland disease, adrenal',
#               'disease, adrenal gland',
#               'diseases, adrenal gland',
#               'gland diseases, adrenal',
#               'adrenal gland dis'],
#              'MESH:D033461': ['hyperuricemia'],
#              'MESH:D056769': ['alstrom syndrome',
#               "alstrom's syndrome",
#               'alstroms syndrome',
#               "syndrome, alstrom's",
#               'alström syndrome',
#               'syndrome, alström',
#               'syndrome, alstrom',
#               'alstrom-hallgren syndrome',
#               'alstrom hallgren syndrome',
#               'syndrome, alstrom-hallgren'],
#              'MESH:C535884': ['joint laxity, familial',
#               'familial joint instability syndrome',
#               'articular hypermobility syndrome',
#               'joint instability syndrome'],
#              'MESH:D012514': ['kaposi sarcoma',
#               "kaposi's sarcoma",
#               "sarcoma, kaposi's",
#               'kaposis sarcoma',
#               'sarcoma, kaposi',
#               'multiple idiopathic pigmented hemangiosarcoma'],
#              'MESH:D009396': ['nephroblastoma',
#               'nephroblastomas',
#               'wilms tumor',
#               'wilm tumor',
#               "wilm's tumor",
#               "wilms' tumor",
#               "tumor, wilms'",
#               'tumor, wilms',
#               'wilms tumor 1',
#               'bilateral wilms tumor',
#               'tumor, bilateral wilms',
#               'wilms tumor, bilateral'],
#              'MESH:D011127': ['polyps', 'polyp'],
#              'MESH:D016870': ['neisseriaceae infections',
#               'infection, neisseriaceae',
#               'neisseriaceae infection',
#               'infections, neisseriaceae',
#               'infect neisseriaceae',
#               'neisseriaceae infect'],
# ...
#               'ebv infect',
#               'infect ebv',
#               'epstein barr virus infect',
#               'infect epstein barr virus',
#               'herpesvirus 4 infect human',
#               'human herpesvirus 4 infect',
#               'human herpes virus 4 infect'],
#              'MESH:D018908': ['muscle weakness',
#               'muscle weaknesses',
#               'weaknesses, muscle',
#               'weakness, muscle',
#               'muscular weakness',
#               'muscular weaknesses',
#               'weaknesses, muscular',
#               'weakness, muscular'],
#              'MESH:D000224': ['addison disease',
#               "addison's disease",
#               'addisons disease',
#               'disease, addison',
#               'primary adrenal insufficiency',
#               'adrenal insufficiency, primary',
#               'primary adrenocortical insufficiency',
#               'insufficiencies, primary adrenocortical',
#               'primary adrenocortical insufficiencies',
#               'adrenocortical insufficiencies, primary',
#               'insufficiency, primary adrenocortical',
#               'adrenocortical insufficiency, primary',
#               'primary hypoadrenalism',
#               'hypoadrenalism, primary',
#               'hypoadrenalisms, primary',
#               'addison dis',
#               'addisons dis'],
#              'MESH:D018376': ['cardiovascular abnormalities',
#               'abnormality, cardiovascular',
#               'cardiovascular abnormality',
#               'abnormalities, cardiovascular',
#               'cardiovasc abnorm',
#               'abnorm cardiovasc'],
#              'MESH:D018455': ['protein s deficiency',
#               'deficiencies, protein s',
#               'protein s deficiencies',
#               'deficiency, protein s',
#               'hereditary thrombophilia due to protein s deficiency',
#               'defic protein s',
#               'protein s defic'],
#              'MESH:D052919': ['refsum disease, infantile',
#               "infantile refsum's disease",
#               'infantile refsums disease',
#               "refsum's disease, infantile",
#               'refsums disease, infantile',
#               "disease, infantile refsum's",
#               'infantile refsum disease',
#               'disease, infantile refsum',
#               'infantile phytanic acid storage disease',
#               'refsum disease, infantile form',
#               'infantile refsum dis',
#               'infantile refsums dis',
#               'refsums dis infantile',
#               'refsum dis infantile',
#               'infantile phytanic acid storage dis',
#               'infantile form of phytanic acid storage disease'],
#              'MESH:D006963': ['hyperphagia',
#               'overeating',
#               'polyphagia',
#               'polyphagias'],
#              'MESH:D009468': ["oppenheim's disease",
#               'oppenheim disease',
#               'oppenheims disease',
#               'amyotonia congenita',
#               'amyotonia congen',
#               'oppenheim dis',
#               'oppenheims dis',
#               'neuromuscular diseases',
#               'neuromuscular disease',
#               'neuromuscular dis',
#               'foley-denny-brown syndrome',
#               'foley denny brown syndrome',
#               'syndrome, foley-denny-brown',
#               'fasciculation-cramp syndrome, benign',
#               'benign fasciculation-cramp syndromes',
#               'fasciculation cramp syndrome, benign',
#               'fasciculation-cramp syndromes, benign',
#               'benign fasciculation-cramp syndrome',
#               'cramp-fasciculation syndrome',
#               'cramp fasciculation syndrome',
#               'cramp-fasciculation syndromes',
#               'syndromes, cramp-fasciculation',
#               'syndrome, cramp-fasciculation'],
#              'MESH:D008589': ['meningococcal infections',
#               'infection, meningococcal',
#               'meningococcal infection',
#               'infections, meningococcal',
#               'meningococcal disease',
#               'meningococcal diseases',
#               'meningococcal infect',
#               'infect meningococcal'],
#              'MESH:C535662': ['acromicric dysplasia',
#               'acmicd',
#               'acromicric skeletal dysplasia',
#               'geleophysic dysplasia',
#               'geleophysic dwarfism'],
#              'OMIM:612446': ['complement component 6 deficiency',
#               'c6 deficiency',
#               'c6d',
#               'c6 deficiency, subtotal',
#               'complement component 6 deficiency, subtotal'],
#              'MESH:D007759': ['labyrinth diseases',
#               'labyrinth disease',
#               'inner ear disease',
#               'ear diseases, inner',
#               'inner ear diseases',
#               'ear disease, inner',
#               'labyrinth dis'],
#              'MESH:D018232': ['rhabdomyosarcoma, alveolar',
#               'alveolar rhabdomyosarcoma',
#               'alveolar rhabdomyosarcomas',
#               'rhabdomyosarcomas, alveolar',
#               'rhabdomyosarcoma 2'],
#              'OMIM:262400': ['pituitary dwarfism i',
#               'sexual ateleiotic dwarfism',
#               'primordial dwarfism',
#               'illig-type growth hormone deficiency',
#               'growth hormone deficiency, isolated, autosomal recessive',
#               'ighd ia',
#               'isolated growth hormone deficiency, type ia',
#               'ighd1a'],
#              'MESH:D018813': ['multiple endocrine neoplasia type 2a',
#               'neoplasia, multiple endocrine type 2a',
#               'mea ii',
#               'men ii',
#               'sipple syndrome',
#               'men 2',
#               'neoplasms, multiple endocrine type 2a',
#               'multiple endocrine neoplasms type 2a',
#               'men 2a',
#               'mea 2a',
#               'men iia',
#               'mea iia',
#               'men2a',
#               'multiple endocrine neoplasia type 2',
#               'men-2a syndrome',
#               'men 2a syndrome',
#               'men-2a syndromes',
#               'pheochromocytoma and amyloid-producing medullary thyroid carcinoma',
#               'pheochromocytoma and amyloid producing medullary thyroid carcinoma',
#               'multiple endocrine neoplasia, type iia',
#               'men 002',
#               'neoplasms multiple endocrine type 002 a',
#               'multiple endocrine neopl type 2a',
#               'neopl multiple endocrine type 2a',
#               'neoplasia multiple endocrine type 002 a',
#               'men 002 a'],
#              'MESH:D003681': ['dehydration', 'water stress', 'stress, water'],
#              'MESH:D046349': ['hereditary coproporphyria',
#               'coproporphyria, hereditary',
#               'coproporphyrinogen oxidase deficiency',
#               'deficiency, coproporphyrinogen oxidase',
#               'coproporphyrinogen oxidase defic'],
#              'MESH:D018335': ['rhabdoid tumor',
#               'rhabdoid tumors',
#               'tumors, rhabdoid',
#               'tumor, rhabdoid'],
#              'MESH:D009120': ['limb cramp',
#               'cramps, limb',
#               'limb cramps',
#               'cramp, limb',
#               'muscle cramp',
#               'cramps, muscle',
#               'muscle cramps',
#               'cramp, muscle',
#               'cramp',
#               'cramps',
#               'muscular cramp',
#               'cramps, muscular',
#               'muscular cramps',
#               'cramp, muscular'],
#              'MESH:D002296': ['carcinosarcoma', 'carcinosarcomas'],
#              'MESH:D013945': ['thymoma',
#               'thymomas',
#               'thymic carcinoma',
#               'carcinomas, thymic',
#               'thymic carcinomas',
#               'carcinoma, thymic'],
#              'MESH:D017827': ['machado-joseph disease',
#               'machado joseph disease',
#               'disease, machado-joseph',
#               'azorean disease',
#               'disease, azorean',
#               'joseph azorean disease',
#               'disease, joseph azorean',
#               'joseph disease',
#               'disease, joseph',
#               '3s, spinocerebellar ataxia',
#               'ataxia 3s, spinocerebellar',
#               'spinocerebellar ataxia 3s',
#               'azorean ataxia',
#               'spinocerebellar ataxia 3',
#               'spinocerebellar ataxia-3',
#               'ataxia 3, spinocerebellar',
#               'spinocerebellar ataxia type 3',
#               'type 3 spinocerebellar ataxia',
#               'striatonigral degeneration, autosomal dominant',
#               'autosomal dominant striatonigral degeneration',
#               'azorean disease (machado-joseph)',
#               'azorean disease (machado joseph)',
#               'disease, machado-joseph azorean',
#               'machado joseph azorean disease',
#               'machado-joseph azorean disease',
#               'disease, azorean (machado-joseph)',
#               'nervous system azorean disease',
#               'azorean disease, nervous system',
#               'machado joseph dis',
#               'nigrospinodentatal degeneration',
#               'degenerations, nigrospinodentatal',
#               'nigrospinodentatal degenerations',
#               'degeneration, nigrospinodentatal',
#               'azorean neurologic disease',
#               'disease, azorean neurologic',
#               'neurologic disease, azorean',
#               'spinocerebellar atrophy iii',
#               'atrophy iiis, spinocerebellar',
#               'spinocerebellar atrophy iiis',
#               'atrophy iii, spinocerebellar',
#               'iii, spinocerebellar atrophy',
#               'joseph dis',
#               'azorean dis machado joseph',
#               'machado joseph azorean dis',
#               'azorean dis nervous system',
#               'nervous system azorean dis',
#               'spinocerebellar ataxia type 003',
#               'joseph azorean dis',
#               'azorean dis',
#               'spinocerebellar atrophy type 3',
#               'machado-joseph disease type i',
#               'machado joseph disease type i',
#               'type i machado-joseph disease',
#               'type i machado joseph disease',
#               'machado joseph dis type i',
#               'type i machado joseph dis',
#               'machado-joseph disease type ii',
#               'machado joseph disease type ii',
#               'type ii machado-joseph disease',
#               'type ii machado joseph disease',
#               'machado joseph dis type ii',
#               'type ii machado joseph dis',
#               'machado-joseph disease type iii',
#               'machado joseph disease type iii',
#               'type iii machado-joseph disease',
#               'type iii machado joseph disease',
#               'machado joseph dis type iii',
#               'type iii machado joseph dis',
#               'machado-joseph disease type iv',
#               'machado joseph disease type iv',
#               'type iv machado-joseph disease',
#               'type iv machado joseph disease',
#               'machado joseph dis type iv',
#               'type iv machado joseph dis'],
#              'OMIM:222600': ['diastrophic dysplasia',
#               'dtd',
#               'dd',
#               'diastrophic dysplasia, broad bone-platyspondylic variant'],
#              'MESH:D001284': ['atrophy', 'atrophies'],
#              'MESH:D020886': ['impairment, light touch sensation',
#               'light touch sensation impairment',
#               'pain sensation diminished',
#               'diminished, pain sensation',
#               'sensation diminished, pain',
#               'diminisheds, pain sensation',
#               'pain sensation diminisheds',
#               'sensation diminisheds, pain',
#               'pinprick sensation diminished',
#               'diminished, pinprick sensation',
#               'sensation diminished, pinprick',
#               'diminisheds, pinprick sensation',
#               'pinprick sensation diminisheds',
#               'sensation diminisheds, pinprick',
#               'position sense disorders',
#               'position sense disorder',
#               'sense disorder, position',
#               'sense disorders, position',
#               'position sense dis',
#               'proprioceptive disorders',
#               'proprioceptive disorder',
#               'proprioceptive dis',
#               'thermal sensation disorders',
#               'sensation disorder, thermal',
#               'thermal sensation disorder',
#               'sensation disorders, thermal',
#               'thermal sensation dis',
#               'somatosensory disorders',
#               'somatosensory disorder',
#               'somatic sensation disorders',
#               'sensation disorder, somatic',
#               'somatic sensation disorder',
#               'sensation disorders, somatic',
#               'somatosensory dis',
#               'somatic sensation dis'],
#              'MESH:D024741': ['obstructive asymmetric septal hypertrophy',
#               'hypertrophic subaortic stenosis, idiopathic',
#               'cardiomyopathy, hypertrophic, familial',
#               'cardiomyopathies, familial hypertrophic',
#               'familial hypertrophic cardiomyopathies',
#               'hypertrophic cardiomyopathies, familial',
#               'cardiomyopathy, familial hypertrophic',
#               'familial hypertrophic cardiomyopathy',
#               'hypertrophic cardiomyopathy, familial',
#               'asymmetric septal hypertrophy, familial',
#               'ventricular hypertrophy, familial',
#               'familial ventricular hypertrophies',
#               'ventricular hypertrophies, familial',
#               'familial ventricular hypertrophy',
#               'hypertrophy, familial ventricular',
#               'hereditary ventricular hypertrophy',
#               'hereditary ventricular hypertrophies',
#               'hypertrophies, hereditary ventricular',
#               'ventricular hypertrophies, hereditary',
#               'hypertrophy, hereditary ventricular',
#               'ventricular hypertrophy, hereditary'],
#              'MESH:D017094': ['porphyrias, hepatic',
#               'hepatic porphyria',
#               'porphyria, hepatic',
#               'hepatic porphyrias'],
#              'MESH:C538273': ['autoimmune enteropathy'],
#              'MESH:D002311': ['cardiomyopathy, dilated',
#               'cardiomyopathies, dilated',
#               'dilated cardiomyopathies',
#               'dilated cardiomyopathy',
#               'cardiomyopathy, familial idiopathic',
#               'cardiomyopathies, familial idiopathic',
#               'familial idiopathic cardiomyopathies',
#               'idiopathic cardiomyopathies, familial',
#               'familial idiopathic cardiomyopathy',
#               'idiopathic cardiomyopathy, familial',
#               'cardiomyopathy, congestive',
#               'cardiomyopathies, congestive',
#               'congestive cardiomyopathies',
#               'congestive cardiomyopathy',
#               'cardiomyopathy, idiopathic dilated',
#               'cardiomyopathies, idiopathic dilated',
#               'dilated cardiomyopathies, idiopathic',
#               'idiopathic dilated cardiomyopathies',
#               'idiopathic dilated cardiomyopathy',
#               'dilated cardiomyopathy, idiopathic',
#               'cardiomyopathy, dilated, cmd1a',
#               'cardiomyopathy, dilated, with conduction deffect1',
#               'cardiomyopathy, dilated, lmna',
#               'cardiomyopathy, dilated, autosomal recessive',
#               'cardiomyopathy, dilated, 1a',
#               'cardiomyopathy, dilated, with conduction defect 1'],
#              'MESH:D008288': ['malaria',
#               'plasmodium infections',
#               'infection, plasmodium',
#               'plasmodium infection',
#               'infections, plasmodium',
#               'remittent fever',
#               'fever, remittent',
#               'paludism',
#               'marsh fever',
#               'fever, marsh',
#               'plasmodium infect',
#               'infect plasmodium']})

# %%
all_medic_ids = [y for x in medic.all_ids for y in x]
print(len(all_medic_ids))
print(len(set(all_medic_ids)))
# Out:
# 28857
# 22182

# %%
set([z for z in all_medic_ids if 'DO' not in z]) - mesh_omim_cuis
# Out:
# {'',
#  'MESH:C',
#  'MESH:C000721267',
#  'MESH:C000721268',
#  'MESH:C000721288',
#  'MESH:C000721289',
#  'MESH:C000721322',
#  'MESH:C000721324',
#  'MESH:C000721327',
#  'MESH:C000721349',
#  'MESH:C000721350',
#  'MESH:C000721352',
#  'MESH:C000721353',
#  'MESH:C000721355',
#  'MESH:C000721367',
#  'MESH:C000721389',
#  'MESH:C000721391',
#  'MESH:C000721392',
#  'MESH:C000721407',
#  'MESH:C000721427',
#  'MESH:C000721429',
#  'MESH:C000721448',
#  'MESH:C000721467',
#  'MESH:C000721827',
#  'MESH:C000721847',
#  'MESH:C000721848',
#  'MESH:C000722495',
#  'MESH:C000722498',
#  'MESH:C000722847',
#  'MESH:C000722848',
#  'MESH:C000722978',
#  'MESH:C000722979',
#  'MESH:C000723354',
#  'MESH:C000723468',
#  'MESH:C000723471',
#  'MESH:C000723487',
#  'MESH:C000723647'}

# %%
medic[medic.disease_id.isin(['MESH:C',
 'MESH:C000721267',
 'MESH:C000721268',
 'MESH:C000721288',
 'MESH:C000721289',
 'MESH:C000721322',
 'MESH:C000721324',
 'MESH:C000721327',
 'MESH:C000721349',
 'MESH:C000721350',
 'MESH:C000721352',
 'MESH:C000721353',
 'MESH:C000721355',
 'MESH:C000721367',
 'MESH:C000721389',
 'MESH:C000721391',
 'MESH:C000721392',
 'MESH:C000721407',
 'MESH:C000721427',
 'MESH:C000721429',
 'MESH:C000721448',
 'MESH:C000721467',
 'MESH:C000721827',
 'MESH:C000721847',
 'MESH:C000721848',
 'MESH:C000722495',
 'MESH:C000722498',
 'MESH:C000722847',
 'MESH:C000722848',
 'MESH:C000722978',
 'MESH:C000722979',
 'MESH:C000723354',
 'MESH:C000723468',
 'MESH:C000723471',
 'MESH:C000723487',
 'MESH:C000723647'])]
# Out:
#                                             disease_name       disease_id  \
# 395                                    Air crescent sign  MESH:C000721349
# 2074                       cell-associated neurotoxicity  MESH:C000722498
# 2194                           Chapare hemorrhagic fever  MESH:C000723468
# 2685                                        Cleft eyelid  MESH:C000721288
# 2714                              Coarse facial features  MESH:C000721322
# 3020                           Continuous diaphragm sign  MESH:C000721367
# 3144                                    COVID-19 rebound  MESH:C000722978
# 3145                                COVID-19 reinfection  MESH:C000722979
# 3210                                Crazy paving pattern  MESH:C000721427
# 3547                 deficiency of adenosine deaminase 2  MESH:C000723487
# 3831                                      Digital ulcers  MESH:C000721267
# 3857                                            Diseases           MESH:C
# 4131                                 Egg and banana sign  MESH:C000721407
# 4193                                    Empty delta sign  MESH:C000721352
# 6132                         hypoglycemic encephalopathy  MESH:C000721848
# 6643                                       Iris flocculi  MESH:C000721429
# 6670                     Isolated left subclavian artery  MESH:C000721268
# 7064                              Lemon and banana signs  MESH:C000721327
# 7234   limbic-predominant age-related TDP-43 encephal...  MESH:C000723354
# 7277                                             lip tie  MESH:C000723647
# 7339                              Loss of reflex tearing  MESH:C000721448
# 7356                              Lujo hemorrhagic fever  MESH:C000723471
# 7532                                    Malar hypoplasia  MESH:C000721289
# 9504                            Pacific coast tick fever  MESH:C000722847
# 10942                                 Reversed halo sign  MESH:C000721353
# 11009                    Right-sided bronchial isomerism  MESH:C000721324
# 11085                                  Sagging rope sign  MESH:C000721355
# 11139                                    Savant syndrome  MESH:C000721847
# 11397                                    Silhouette sign  MESH:C000721350
# 11518              Southern tick-associated rash illness  MESH:C000722848
# 11519              spaceflight-induced visual impairment  MESH:C000722495
# 12452                              Tram track sign brain  MESH:C000721391
# 12453                              Tram track sign chest  MESH:C000721392
# 12454                        tram track sign optic nerve  MESH:C000721389
# 12469                   Transurethral resection syndrome  MESH:C000721827
# 12889                                     VEXAS syndrome  MESH:C000721467
#
#       alt_disease_ids definition  \
# 395                []
# 2074               []
# 2194               []
# 2685               []
# 2714               []
# 3020               []
# 3144               []
# 3145               []
# 3210               []
# 3547               []
# 3831               []
# 3857               []
# 4131               []
# 4193               []
# 6132               []
# 6643               []
# 6670               []
# 7064               []
# 7234               []
# 7277               []
# 7339               []
# 7356               []
# 7532               []
# 9504               []
# 10942              []
# 11009              []
# 11085              []
# 11139              []
# 11397              []
# 11518              []
# 11519              []
# 12452              []
# 12453              []
# 12454              []
# 12469              []
# 12889              []
#
#                                                 synonyms  \
# 395    [Air-crescent sign, Pulmonary air crescent sig...
# 2074   [immune effector cell-associated neurotoxicity...
# 2194                           [Chapare virus infection]
# 2685               [Coloboma of eyelid, Eyelid coloboma]
# 2714     [Coarce facies, Coarse face, Pugilistic facies]
# 3020                                                  []
# 3144          [COVID-19 recrudescence, COVID-19 relapse]
# 3145                             [COVID-19 re-infection]
# 3210   [Crazy paving appearance, Crazy-paving pattern...
# 3547   [ADA2 deficiency, DADA2 deficiency of adenosin...
# 3831     [Acral ulceration, Acral ulcers, Finger ulcers]
# 3857                                                  []
# 4131                               [Egg-and-banana sign]
# 4193                                                  []
# 6132                           [diabetic encephalopathy]
# 6643                                                  []
# 6670           [Isolation of the left subclavian artery]
# 7064                           [banana sign, lemon sign]
# 7234   [LATE limbic-predominant age-related TDP-43 en...
# 7277                                     [upper lip tie]
# 7339                               [Reflex tearing loss]
# 7356                              [Lujo virus infection]
# 7532   [Hypoplasia of zygomatic bone, Malar flattenin...
# 9504   [364D rickettsiosis, Rickettsia 364D infection...
# 10942         [Atoll sign, pulmonary, Reverse halo sign]
# 11009  [Bilateral right bronchi, Right bronchial isom...
# 11085                                [Hanging rope sign]
# 11139  [autistic savant syndrome, idiot savant syndrome]
# 11397                                                 []
# 11518  [Masters disease, STARI Southern tick-associat...
# 11519  [SANS spaceflight-associated neuro-ocular synd...
# 12452                            [Brain tram track sign]
# 12453                            [Chest tram track sign]
# 12454  [Optic nerve tram track sign, tram track sign ...
# 12469                                                 []
# 12889  [vacuoles, E1 enzyme, X-linked, autoinflammato...
#
#                                                all_names              all_ids
# 395    [Air crescent sign, Air-crescent sign, Pulmona...  [MESH:C000721349, ]
# 2074   [cell-associated neurotoxicity, immune effecto...  [MESH:C000722498, ]
# 2194   [Chapare hemorrhagic fever, Chapare virus infe...  [MESH:C000723468, ]
# 2685   [Cleft eyelid, Coloboma of eyelid, Eyelid colo...  [MESH:C000721288, ]
# 2714   [Coarse facial features, Coarce facies, Coarse...  [MESH:C000721322, ]
# 3020                       [Continuous diaphragm sign, ]  [MESH:C000721367, ]
# 3144   [COVID-19 rebound, COVID-19 recrudescence, COV...  [MESH:C000722978, ]
# 3145       [COVID-19 reinfection, COVID-19 re-infection]  [MESH:C000722979, ]
# 3210   [Crazy paving pattern, Crazy paving appearance...  [MESH:C000721427, ]
# 3547   [deficiency of adenosine deaminase 2, ADA2 def...  [MESH:C000723487, ]
# 3831   [Digital ulcers, Acral ulceration, Acral ulcer...  [MESH:C000721267, ]
# 3857                                        [Diseases, ]           [MESH:C, ]
# 4131          [Egg and banana sign, Egg-and-banana sign]  [MESH:C000721407, ]
# 4193                                [Empty delta sign, ]  [MESH:C000721352, ]
# 6132   [hypoglycemic encephalopathy, diabetic encepha...  [MESH:C000721848, ]
# 6643                                   [Iris flocculi, ]  [MESH:C000721429, ]
# 6670   [Isolated left subclavian artery, Isolation of...  [MESH:C000721268, ]
# 7064   [Lemon and banana signs, banana sign, lemon sign]  [MESH:C000721327, ]
# 7234   [limbic-predominant age-related TDP-43 encepha...  [MESH:C000723354, ]
# 7277                            [lip tie, upper lip tie]  [MESH:C000723647, ]
# 7339       [Loss of reflex tearing, Reflex tearing loss]  [MESH:C000721448, ]
# 7356      [Lujo hemorrhagic fever, Lujo virus infection]  [MESH:C000723471, ]
# 7532   [Malar hypoplasia, Hypoplasia of zygomatic bon...  [MESH:C000721289, ]
# 9504   [Pacific coast tick fever, 364D rickettsiosis,...  [MESH:C000722847, ]
# 10942  [Reversed halo sign, Atoll sign, pulmonary, Re...  [MESH:C000721353, ]
# 11009  [Right-sided bronchial isomerism, Bilateral ri...  [MESH:C000721324, ]
# 11085             [Sagging rope sign, Hanging rope sign]  [MESH:C000721355, ]
# 11139  [Savant syndrome, autistic savant syndrome, id...  [MESH:C000721847, ]
# 11397                                [Silhouette sign, ]  [MESH:C000721350, ]
# 11518  [Southern tick-associated rash illness, Master...  [MESH:C000722848, ]
# 11519  [spaceflight-induced visual impairment, SANS s...  [MESH:C000722495, ]
# 12452     [Tram track sign brain, Brain tram track sign]  [MESH:C000721391, ]
# 12453     [Tram track sign chest, Chest tram track sign]  [MESH:C000721392, ]
# 12454  [tram track sign optic nerve, Optic nerve tram...  [MESH:C000721389, ]
# 12469               [Transurethral resection syndrome, ]  [MESH:C000721827, ]
# 12889  [VEXAS syndrome, vacuoles, E1 enzyme, X-linked...  [MESH:C000721467, ]

# %%
deprecated_cuis = all_cuis - set(all_medic_ids)
deprecated_cuis
# Out:
# {'MESH:C531603',
#  'MESH:C531610',
#  'MESH:C531652',
#  'MESH:C535804',
#  'MESH:C537666',
#  'MESH:C538138',
#  'MESH:C538219',
#  'MESH:C538392',
#  'MESH:C538554',
#  'MESH:D001405',
#  'OMIM:102600',
#  'OMIM:103600',
#  'OMIM:164160',
#  'OMIM:600698'}

# %%
medic[medic.all_ids.map(lambda x: '' in x)]
# Out:
#                            disease_name    disease_id alt_disease_ids  \
# 0       10p Deletion Syndrome (Partial)  MESH:C538288              []
# 1                 13q deletion syndrome  MESH:C535484              []
# 3             16p11.2 Deletion Syndrome  MESH:C579850              []
# 4      17,20-Lyase Deficiency, Isolated  MESH:C567076              []
# 7               22q11 Deletion Syndrome  MESH:D058165              []
# ...                                 ...           ...             ...
# 13182               Zoster Sine Herpete  MESH:D031368              []
# 13183                     ZTTK SYNDROME   OMIM:617140              []
# 13185                   Zuska's Disease  MESH:C536730              []
# 13187               Zygomatic Fractures  MESH:D015051              []
# 13188                       Zygomycosis  MESH:D020096              []
#
#                                               definition  \
# 0
# 1
# 3
# 4
# 7      Condition with a variable constellation of phe...
# ...                                                  ...
# 13182  HERPES ZOSTER but without eruption of vesicles...
# 13183
# 13185
# 13187                           Fractures of the zygoma.
# 13188  Infection in humans and animals caused by fung...
#
#                                                 synonyms  \
# 0      [Chromosome 10, 10p- Partial, Chromosome 10, m...
# 1      [Chromosome 13q deletion, Chromosome 13q delet...
# 3                                                     []
# 4      [17-Alpha-Hydroxylase-17,20-Lyase Deficiency, ...
# 7      [22q11 Deletion Syndromes, Deletion Syndrome, ...
# ...                                                  ...
# 13182                            [Zoster Sine Eruptione]
# 13183  [ZHU-TOKITA-TAKENOUCHI-KIM SYNDROME, ZTTK MULT...
# 13185  [Lactation and squamous metaplasia of lactifer...
# 13187  [Fractures, Zygomatic, Fracture, Zygomatic, Zy...
# 13188  [Entomophthoramycoses, Entomophthoramycosis, P...
#
#                                                all_names           all_ids
# 0      [10p Deletion Syndrome (Partial), Chromosome 1...  [MESH:C538288, ]
# 1      [13q deletion syndrome, Chromosome 13q deletio...  [MESH:C535484, ]
# 3                          [16p11.2 Deletion Syndrome, ]  [MESH:C579850, ]
# 4      [17,20-Lyase Deficiency, Isolated, 17-Alpha-Hy...  [MESH:C567076, ]
# 7      [22q11 Deletion Syndrome, 22q11 Deletion Syndr...  [MESH:D058165, ]
# ...                                                  ...               ...
# 13182       [Zoster Sine Herpete, Zoster Sine Eruptione]  [MESH:D031368, ]
# 13183  [ZTTK SYNDROME, ZHU-TOKITA-TAKENOUCHI-KIM SYND...   [OMIM:617140, ]
# 13185  [Zuska's Disease, Lactation and squamous metap...  [MESH:C536730, ]
# 13187  [Zygomatic Fractures, Fractures, Zygomatic, Fr...  [MESH:D015051, ]
# 13188  [Zygomycosis, Entomophthoramycoses, Entomophth...  [MESH:D020096, ]
#
# [6443 rows x 7 columns]

# %%
medic_cui2synonyms
# Out:
# defaultdict(set,
#             {'MESH:C538288': {'10p Deletion Syndrome (Partial)',
#               'Chromosome 10, 10p- Partial',
#               'Chromosome 10, Partial Deletion (short arm)',
#               'Chromosome 10, monosomy 10p',
#               'Monosomy 10p'},
#              '': {'Necrosis, Submassive Hepatic',
#               'Short Stature, Mental Retardation, Callosal Agenesis, Heminasal Hypoplasia, Microphthalmia, And Atypical Clefting',
#               'CAFE-AU-LAIT SPOTS WITH PULMONIC STENOSIS',
#               'Cells, Neoplasm Circulating',
#               'Arnold Chiari Malformation, Type I',
#               'T LGL Leukemia',
#               'Spiral Fracture',
#               'Clinical Deterioration',
#               'Lowry Wood syndrome',
#               'Arterial Inflammation',
#               'Fungal Lung Diseases',
#               'Limb Deformity, Congenital',
#               'Pyogenic Brain Abscesses',
#               'Keloid, Acne',
#               'Syndrome, Eisenmenger',
#               'Choristoma',
#               'LEUKOENCEPHALOPATHY WITH DYSTONIA AND MOTOR NEUROPATHY',
#               'Aphonias, Functional',
#               'Intravascular Hemolyses',
#               'Primary Immune Deficiency Syndromes',
#               'Recessive aplasia cutis congenita of the limbs',
#               'Alcoholic Hepatitis, Chronic',
#               'Infection, Hookworm',
#               'Auditory Perceptual Disorders',
#               'Infections, Parasitic',
#               'Large-Cell Lymphomas, Anaplastic',
#               'Post Traumatic Myelopathy',
#               'Disease, Infectious',
#               'long-COVID',
#               'Indian Childhood Cirrhosis',
#               'Cutaneous Syphilis',
#               'Congenital Arthromyodysplasia',
#               'Primary Taste Disorder',
#               'Michelin tire baby syndrome',
#               'Ataxia, Deafness, and Cardiomyopathy',
#               'Laryngeal Nerve Injury',
#               'Bone Stress Reaction',
#               'Hallucinations, Dissociative',
#               'Bilateral Sciaticas',
#               'Tibial Meniscus Injury',
#               'Duplication 4q25 qter',
#               'Anti-HIV Positivities',
#               'EHLERS-DANLOS SYNDROME, KYPHOSCOLIOTIC TYPE, 2',
#               'Second Primary Cancers',
#               'Cone-Rod Degeneration',
#               'Neoplasms Histological Types',
#               'Verloes Van Maldergem Marneffe syndrome',
#               'Chromosome Breakage',
#               'Seizure, Alcohol Withdrawal',
#               'Hemorrhages, Brain',
#               'Stab Wounds',
#               'Chromosome 9, partial trisomy 9p',
#               'Chorioretinopathies, Central Serous',
#               'Comas, Hyperosmolar Nonketotic',
#               'Hyperferritinemia',
#               'Deletion 12p13',
#               'Carcinomas, Skin Appendage',
#               'Trisomy 14q proximal',
#               'Dystrophy, Animal Muscular',
#               'Newborn Transient Tachypnea',
#               'Deafness-Oligodontia Syndrome',
#               'Hypoparathyroidism Lymphedema syndrome',
#               'Muscular Dystrophy, Congenital, Producing Arthrogryposis',
#               'Chronic Renal Disease',
#               'Epidural Hematoma, Cranial',
#               'Veterinary Abortion',
#               'Alcohol-Induced Dysmnesic Syndrome',
#               'Spondylothoracic Dysostosis, Autosomal Dominant',
#               'Primary Night Terrors',
#               'Ectromelia',
#               'Ki-1 Lymphoma',
#               'Encephalopathy, Metabolic',
#               'Abnormalities, Jaw',
#               'Sialadenitis, xanthogranulomatous',
#               'VAIHS vasculitis, autoinflammation, immunodeficiency, and hematologic defects syndrome',
#               'Syndromes, Naffziger',
#               'Hernandez Aguirre-Negrete syndrome',
#               'XK-aprosencephaly syndrome',
#               'Pain, Postsurgical',
#               'Sepsis, Neonatal',
#               'Reactive Lymphoid Hyperplasia',
#               'Infection, Desulfovibrio',
#               'Tumor, Unknown Primary',
#               'Gait, Cerebellar',
#               'Starts, Somnolescent',
#               'Abnormal Nails',
#               'Cysts, Ganglion',
#               'Hemangiomatosis, Disseminated',
#               'Encapsulating Peritoneal Sclerosis',
#               'Bronchospasm, Exercise-Induced',
#               'PVS (Persistent Vegetative State)',
#               'Malunions, Fracture',
#               'Familial Hyperaldosteronism',
#               'Oculomotor Neuropathies, Traumatic',
#               'Carotid Artery-Cavernous Sinus Fistula',
#               'Tooth Avulsion',
#               'Gastrointestinal Hemorrhages',
#               'Motor Neuron Disease with Dementia and Ophthalmoplegia',
#               'Hematological Pregnancy Complications',
#               'Erythema Palmare Hereditarium',
#               'Pseudocomas',
#               'Sleep, Insufficient',
#               'Seizure Disorder, Post-Traumatic',
#               'Atrophy of Periodontium',
#               'Common Bile Duct Gallstone',
#               'Disease, Dog',
#               'Vertex Headache',
#               'HEPATIC LIPASE DEFICIENCY',
#               'Hyperplasias, Thymic',
#               'Injuries, Penetrating Head',
#               'Pyogenic Brain Abscess',
#               'Epilepsies, Refractory',
#               'Brain Hemorrhages, Traumatic',
#               'Microcephaly microcornea syndrome Seemanova type',
#               'Chronic Diseases',
#               'HIV Seropositivity',
#               '46,XX SEX REVERSAL WITH DYSGENESIS OF KIDNEYS, ADRENALS, AND LUNGS',
#               'Disorders, Psychotic Affective',
#               'Cancers, Genitourinary',
#               'Diastasis, Bone',
#               'Congenital sternal cleft',
#               'Postpartum Sterility',
#               'Immersion Foot',
#               'Semirhythmic Tremor',
#               'Hand Deformity, Congenital',
#               'Edemas, Laryngeal',
#               'Egg and banana sign',
#               'Spasm, Bronchial',
#               'MRXSSB',
#               'Pouchitis',
#               'Thromboses, Deep Vein',
#               'Marek Disease',
#               'Anemias, Iron-Deficiency',
#               "Alzheimer's disease without Tau pathology",
#               'Habronemiasis',
#               'Sillence syndrome',
#               'Blindness-Deafness',
#               'limbic-predominant age-related TDP-43 encephalopathy neuropathological changes',
#               'Cognitive Complications, Postoperative',
#               'Mild autosomal recessive form of osteopetrosis',
#               'Hdl Deficiency, Type 2',
#               'Melanoma-Associated Retinopathy',
#               'Persistent Cyclodialysis Cleft',
#               'Pityriasis Lichenoides',
#               'Decapitations',
#               'Polydipsia',
#               'Smith-Strang Disease',
#               'Reno-Cardiac Syndromes',
#               'Cole-Hughes syndrome',
#               'Transient Hypertonias',
#               'Environmental Sleep Disorders',
#               'Crystalline Arthropathy',
#               'Second Primary Neoplasms, Metachronous',
#               'Pneumococcal Disease',
#               'Cranium Bifidums',
#               'Nonpenetrating Injury',
#               'Infection, Bifidobacteriales',
#               'Intractable Headaches',
#               'HIP DYSPLASIA, DEVELOPMENTAL',
#               'Ring chromosome 19',
#               'Hemangioendotheliomas, Epithelioid',
#               'Sign, Battle',
#               'Left Ventricular Apical Ballooning Syndrome',
#               'Heat Illness',
#               'Sudden Hearing Loss',
#               'Medial Calcific Scleroses',
#               'Cystic dilatation of renal collecting tubes',
#               'Intraepithelial Neoplasm, Prostatic',
#               'Camptodactyly, myopia, and fibrosis of the medial rectus muscle of eye',
#               'Patterson Stevenson syndrome',
#               'Trochlear Nerve Avulsion',
#               'Multiple Arthrogryposis, Congenital',
#               'Juvenile-Onset Still Disease',
#               'Cardiomyopathy, Stress',
#               'Depressive Disorder, Treatment-Resistant',
#               'Encephalocele',
#               'Asthma-COPD Overlap Syndrome',
#               'Spasms',
#               'Spinal Subdural Hematoma, Traumatic',
#               'Coughs',
#               'Disease, Caprine',
#               'N acetyltransferase deficiency',
#               'Carcinoma, Noninfiltrating Intraductal',
#               'Post-Lumbar Puncture Headache',
#               'Arachnoid Diverticula',
#               'Microcephaly seizures genital hypoplasia',
#               'Incisor Protrusions',
#               'Acute Symptom Flare',
#               'Abdominal chemodectomas with cutaneous angiolipomas',
#               'Cleido rhizomelic syndrome',
#               'Chromosome 4, monosomy 4p14 p16',
#               'Keratosis pilaris',
#               'Polyopsias',
#               'Pterygium colli medianum',
#               'Syndrome, Broken Heart',
#               'Oroantral Fistulas',
#               'Atrial Extrasystoles',
#               'Disease, Chronic Renal',
#               'Disease, Foodborne',
#               'Infections, Spirurida',
#               'Injury, Facial',
#               'Catatonias, Organic',
#               'Rosai-Dorfman Disease',
#               'Stomatognathic System Abnormalities',
#               'BMND12',
#               'Posttransfusion Purpura',
#               'Transient Myeloproliferative Disorder of Down Syndrome',
#               'Hyperactivity, Motor',
#               'Cancer, Therapy-Associated',
#               'Nerve Trauma, Trigeminal',
#               'Bunions',
#               'Cancers, Second Primary',
#               'Chitayat Moore Del Bigio syndrome',
#               'Injuries, Blast',
#               'Aphasias, Psychosensory',
#               'Micrognathias',
#               'Odontogenic Dysplasia',
#               'CFEOM3C',
#               'MMCAT',
#               'Treatment Resistant Depressions',
#               'Uterine Hemorrhages',
#               'Tumor Embolism',
#               'Left-sided gallbladder',
#               'Cone-Rod Retinal Dystrophies',
#               'Focal segmental glomerulosclerosis 1',
#               'Hypoglossal Nerve Traumas',
#               'Injuries, Repetitive Stress',
#               'Ichthyosis mental retardation-epilepsy hypogonadism syndrome',
#               'Dermatoses, Linear IgA',
#               'Teeth, Permanent, Absence of',
#               'NGPS',
#               "Aujeszky's Disease",
#               'Injuries, Needle-Stick',
#               'Malignant Carcinoid Syndrome',
#               'Mammary Neoplasm',
#               'Injuries, Overuse',
#               'Primary Exertional Headache',
#               'Partial deletion of the long arm of the Y chromosome',
#               'Sclerotic bones with dentin dysplasia',
#               'Ascites, Chylous',
#               'Oropharynx Cancers',
#               'Renal Vein Entrapment Syndrome',
#               'Retrognathisms',
#               'Traumatic Dental Occlusions',
#               'Fibers, Atriohisian',
#               'Palpebral Coloboma-Lipoma Syndrome',
#               'Adrenal Insufficiency',
#               'Hyperammonemia',
#               'Laryngospasm',
#               'Diabetes and deafness, maternally inherited',
#               'Fracture, Insufficiency',
#               'Stresses, Workplace',
#               'Intermittent Diplopias',
#               'Urinary Incontinence, Urge',
#               'Herpetic Stomatitides',
#               'Cranial Nerve II Injuries',
#               'Palsy, Traumatic Twelfth-Nerve',
#               'Wrist Injury',
#               'Metabolic Bone Disease',
#               'Respiratory papillomatosis',
#               'Sheep Disease',
#               'Fever Blisters',
#               'ALAZAMI-YUAN SYNDROME',
#               'Aberration, Corneal Wavefront',
#               'DSDs, Sex Chromosome',
#               'Edema, Cardiac',
#               'Ankle Injury',
#               'Impairment, Cognitive',
#               'Enlarged Liver',
#               'Unerupted Tooth',
#               'Accessory Atrioventricular Pathway',
#               'Paroxysmal Nerve Pains',
#               'Ekbom Delusional Parasitoses',
#               'Nocturnal Myoclonus',
#               'Long Qt Syndrome 2-3',
#               'Gdi1 Duplication Syndrome',
#               'Giant tongue',
#               'Medication Overuse Headache',
#               'Synovial Cysts',
#               'Toes, Mallet',
#               'Factors VIII, IX And XI, Combined Deficiency of',
#               'Cytomegalic inclusion body disease',
#               'Battered Child Syndromes',
#               'Infections, Burkholderia',
#               'Central Nervous System Viral Infections',
#               'Diverticulum, Esophagopharyngeal',
#               'Congenital Coxa Valga',
#               'Familial renal carcinoma',
#               'Picornavirus Infections',
#               'Left Ventricular Noncompaction, Isolated, Autosomal Dominant',
#               'Chromosome 11, Partial Trisomy 11q23-qter',
#               'Disease, Respiratory Tract',
#               'Al Gazali Hirschsprung syndrome',
#               'S erythrospora infections',
#               'Pneumonia, Necrotizing',
#               'Patellar Dislocation',
#               'Influenza, Swine',
#               'Tachycardia, Atrioventricular Nodal Reentry',
#               'RETINAL DYSTROPHY AND OBESITY',
#               'Muscle Spasm, Masseter',
#               'Infection, Burkholderia',
#               'Second Primary Neoplasm',
#               'Post-Concussive Symptom',
#               'Fourth-Nerve Palsies, Traumatic',
#               'Predispositions, Genetic',
#               'Chromosome 7, monosomy 7q2',
#               'Gigantism',
#               'Infarcts, Lacunar',
#               'Disorder, Urination',
#               'Fetal Growth Retardation',
#               'Arthritis, Crystal',
#               '6q24-Tndm',
#               'FTDMND',
#               'Migraine, Familial Basilar',
#               'Brain Hemorrhage, Cerebral, Traumatic',
#               'Neurofibromatosis, variant form(s) of',
#               'Deformity, Acquired Ear',
#               'Respiration, Non Therapeutic Positive Pressure',
#               'Vicarious Traumas',
#               'Infections, Soft Tissue',
#               'Polyneuropathies, Lead-Induced',
#               'IgG4 Related Sclerosing Disease',
#               'Breast Neoplasm, Triple-Negative',
#               'Absent Eyebrows and Eyelashes with Mental Retardation',
#               'Habit Spasms',
#               'T-CELL IMMUNODEFICIENCY, RECURRENT INFECTIONS, AND AUTOIMMUNITY WITH OR WITHOUT CARDIAC MALFORMATIONS',
#               'Lymphoid Hypophysitides',
#               'Abducens Nerve Injury',
#               'Gland Hyperplasia, Thymus',
#               'Infection, Enterobacteriaceae',
#               'Pai Levkoff syndrome',
#               'Tapetoretinal Degeneration with Ataxia',
#               'Olfactory Nerve Contusions',
#               'Post operative Pain',
#               'Fungal Aneurysm',
#               'Crystalline Arthritides',
#               'Bacterial Eye Infections',
#               'Atrial Contraction, Premature',
#               'Intraductal Papillary Mucinous Neoplasms of the Pancreas',
#               'Carcinomatosis, Peritoneal',
#               'Nutrition Disorder, Infant',
#               'Back Injuries',
#               'Spasticity, Muscle',
#               'Auditory Cortex Disorders',
#               'Medication Induced Dyskinesia',
#               'Wasting Syndromes',
#               'Papillary Fibroelastomas',
#               'Necrobiotic Disorders',
#               'Prata Liberal Goncalves syndrome',
#               'Hemorrhage, Choroid',
#               'Triphalangeal Thumb-Polysyndactyly Syndrome',
#               'Rigidity, Cogwheel',
#               'Opiate Overdoses',
#               'Hemorrhage, Gingival',
#               'Compound Depressed Skull Fracture',
#               'ER-Negative PR-Negative HER2-Negative Breast Cancer',
#               'Sensations, Reduced',
#               'Cardiorenal Syndrome',
#               'Infections, Mesomycetozoea',
#               'Ghost Teeth',
#               'Labor Complications',
#               'Impaired Olfaction',
#               'Neoplasms, Second Primary',
#               'Disc, Slipped',
#               'Pseudomonas aeruginosa Infections',
#               'Refractory Epilepsies',
#               'MIGRAINE WITH OR WITHOUT AURA, SUSCEPTIBILITY TO, 2',
#               'Verminophobia',
#               'Vagus Nerve Transections',
#               'Neutrophil Chemotactic Response, Abnormal',
#               'Epiphyseal Dysplasia, Fairbank Type',
#               'Hemorrhage, Brain Stem, Traumatic',
#               'GLOBAL DEVELOPMENTAL DELAY, ABSENT OR HYPOPLASTIC CORPUS CALLOSUM, AND DYSMORPHIC FACIES',
#               'Vidian Neuralgias',
#               'Cranium, Bifid',
#               'Harding-Passey Melanoma',
#               'Seizure, Pyrexial',
#               'Disease, Cattle',
#               'Diffuse cystic renal dysplasia',
#               'Sarcopenias',
#               'Fracture, Sprain',
#               'Anophthalmia plus syndrome',
#               'Injury, Sports',
#               'Sepsis',
#               'Epilepsy, familial temporal lobe',
#               'Blue Tongue',
#               'Neoplasms, Nasal',
#               'Lymphoid Structures, Tertiary',
#               'Anterior Cervical Pains',
#               'Reticular Dystrophy Of Retinal Pigment Epithelium',
#               'Obesity, Childhood',
#               'Overuse Headache, Medication',
#               'Foot Deformities, Acquired',
#               'Mosquito-Borne Disease',
#               'Leaks, Perigraft',
#               'Infection, Ureaplasma',
#               'Smell Disorder',
#               'Amyloidoses, Hereditary',
#               'Myotoxicities',
#               'Rodent Disease',
#               'Multinodular Goiter-Cystic Renal Disease-Digital Anomalies',
#               'MRT49, FORMERLY',
#               'Bordetella pertussis Infection, Respiratory',
#               'Out of Hospital Cardiac Arrest',
#               'X chromosome, monosomy Xq28',
#               'HTLV-II Infection',
#               'Vein of Galen aneurysm',
#               'Vein Of Galen Malformation',
#               'Prolapse, Urinary Bladder',
#               'Late Post-Traumatic Seizure',
#               'Tinnitus, Spontaneous Oto-Acoustic Emission',
#               'Chromosome Instability Syndrome',
#               'Traumas, Vestibulocochlear Nerve',
#               'Foot Ulcer, Diabetic',
#               'Neurolathyrism',
#               'Discoloration, Tooth',
#               'Enteritis, Infectious, of Mink',
#               'Ectasias, Precalyceal Canalicular',
#               'Disorder, Bodily Distress',
#               'Hyperalgia, Mechanical',
#               'Cancer, Oropharyngeal',
#               'Speech or Language, Developmental Disorder',
#               'Syndrome, Adrenogenital',
#               'Vascular Malformations',
#               'Arachnodactyly, abnormal ossification and mental retardation',
#               'Dental Fissures',
#               'Mental Deterioration',
#               'Radiation-Induced Leukemias',
#               'Syndrome of opticoacoustic nerve atrophy with dementia',
#               'Dysmnesic Syndromes, Alcohol-Induced',
#               'Congenital Surfactant Protein-B Deficiency',
#               'Leukocytosis',
#               'Wegener-Like Granulomatosis',
#               'Inclusion Disease',
#               'Pains, Right Flank',
#               'Echogenic Bowels',
#               'Vasculitide, ANCA-Associated',
#               'Rieger Syndrome, Type 2',
#               'GPIBD13',
#               'SAH (Subarachnoid Hemorrhage)',
#               'Tremor, Darkness',
#               'Nerve Contusions, Trigeminal',
#               'Malalignment, Bone',
#               'Dyssegmental Dysplasia with Glaucoma',
#               'FAMILIAL MULTIPLE COAGULATION FACTOR DEFICIENCY I',
#               'Congenital contractures with major involvement of the hands and feet',
#               'Convulsions benign familial neonatal dominant form',
#               'Encephalopathies, Arsenic',
#               'Palmoplantar Keratoderma, Vorner Type',
#               'Hepatic Fibrosis, Congenital',
#               'Hemorrhage, Traumatic Medullary',
#               'Monosomy 1q4',
#               'Nerve Traumas, Trigeminal',
#               'Myokymias',
#               'Fracture, Pathological',
#               'Infections, Fungal, Central Nervous System',
#               'Desmin-Related Myopathy with Arrhythmogenic Right Ventricular Cardiomyopathy',
#               'Congenital trichofolliculoma',
#               'Catheter Associated Infections',
#               'Pechet Factor Deficiency',
#               'Disc, Herniated',
#               'Allergies, Pollen',
#               'Lacunar Infarction',
#               'Peanut and Nut Allergies',
#               'During Infancies, Hyperbilirubinemia',
#               'Night Terrors, Childhood',
#               'Mycobacterium Infection',
#               'Canaliculitis',
#               'Non-Radiographic Axial Spondyloarthritis',
#               'Diseases, Dental',
#               'Abnormality, Drug-Induced',
#               'Personality Disorders, Passive Aggressive',
#               'Type V Familial Amyloid Polyneuropathy',
#               'Delusions, Ekbom Dermatozoic',
#               'Breakthrough Pains',
#               'Primary Stabbing Headache',
#               'Paralysis, Unilateral, Vocal Cord',
#               'Hypoxia-Ischemia, Cerebral',
#               'Valve Atresia, Pulmonary',
#               'A V Dissociation',
#               'Odontomes',
#               'Xpg-Cs',
#               "Sclerosis, Monckeberg's",
#               '46,Xy Gonadal Dysgenesis, Complete, Sry-Related',
#               'Concussive Convulsions',
#               'Delayed Cranial Ossification due to CBFB Haploinsufficiency',
#               'Myopathy, congenital nonprogressive with Moebius and Robin sequences',
#               'Infections, Respiratory',
#               'Cranial Nerve VII Injuries',
#               'Infection, Rickettsia',
#               'Chapare virus infection',
#               'Mental Nerve Injuries',
#               'Bilateral Hearing Losses',
#               'Congenital Multiple Arthrogryposes',
#               'Balamuthia mandrillaris Meningoencephalitides',
#               'Arterial Dissection with Lentiginosis',
#               'Coarce facies',
#               'Hypophysitides, Autoimmune',
#               'Gastrocutaneous syndrome',
#               'Osteonecrosis of the Jaws, Bisphosphonate-Induced',
#               'Fetal Shoulder Dystocia',
#               'Generalized Epilepsy With Febrile Seizures Plus, Type 5',
#               'Osteogenesis imperfecta, type 2B',
#               'Blepharophimosis syndrome type 2',
#               'Post-Traumatic Cerebrospinal Fluid Rhinorrhea',
#               'Indeterminate Tuberculoids',
#               'Posttraumatic Hypersomnias',
#               'Disease, Zoonotic Infectious',
#               'Arsenical Neurotoxicity Syndromes',
#               'Artery Stenosis, Pulmonary',
#               'Pathological Neovascularization',
#               'Traumatic Subdural Hematoma',
#               'Diastases, Symphysis Pubis',
#               'TSHQTL1',
#               'PROGERIA SYNDROME, CHILDHOOD-ONSET, WITH OSTEOLYSIS',
#               'Disease, Sexually Transmitted',
#               'Diseases, Cattle',
#               'Transurethral resection syndrome',
#               'Dysgeneses, Corpus Callosum',
#               'Neuralgia, Perineal',
#               'Solitary Fibrous Tumors',
#               'Syndrome X, Cardiac',
#               'Dwarfism, Low-Birth-Weight Type, with Unresponsiveness to Growth Hormone',
#               'Manifestations, Muscle Disease',
#               'Fetal Shoulder Dystocias',
#               'Neuropathy, Traumatic Trochlear',
#               'Pain, Procedural',
#               'Cephalalgias, Trigeminal Autonomic',
#               'Trajectories, Weight Gain',
#               'Hypodynamia',
#               'Kallmann Syndrome 2 with Bimanual Synkinesia',
#               'Fetomaternal Transfusion',
#               '47 XYY syndrome',
#               'Blood-Borne Infections',
#               'Retroposition, Maxillary',
#               'BCG Infection, Generalized Familial',
#               'Abscess, Intra-Abdominal',
#               'Megalodactyly of the hand',
#               'Encephalopathy, Metabolic, Acquired',
#               'Hib Infections',
#               'COVID-19 serotherapy',
#               'Dermatitides, Eczematous',
#               'Ulna hypoplasia',
#               'Php2',
#               'Lymphopenic Hypergammaglobulinemia, Antibody Deficiency, Autoimmune Hemolytic Anemia, and Glomerulonephritis',
#               'First-Nerve Trauma',
#               'Absent accessory pancreatic duct of Santorini',
#               'Lemierres Syndrome',
#               'OFDS XV',
#               'Multiple Brain Abscess',
#               'Kennerknecht Vogel syndrome',
#               'Dysreflexias, Autonomic',
#               'Trisomy 3p25',
#               'Traumatic Carotid Arteriopathy',
#               'Subarachnoid Hemorrhages, Traumatic',
#               'Alaninuria with Microcephaly, Dwarfism, Enamel Hypoplasia, and Diabetes Mellitus',
#               'Harding Passey Melanoma',
#               'Tachycardia, Paroxysmal Reciprocal',
#               'Chylous Peritonitis',
#               'Pulmonary aplasia and triphalangia of the thumb',
#               'Phocomelia, Thrombocytopenia, Encephalocele, Urogenital Malformations',
#               'Cerebellar Ataxia and Neurosensory Deafness',
#               'Choroidal Osteoma, Bilateral',
#               'Infections, Surgical Wound',
#               'Injury, Craniocerebral',
#               'Dermatitis Exfoliative Generalised',
#               'Eruptions, Acneiform',
#               'Intraepithelial Neoplasms, Prostatic',
#               'Male Urogenital Diseases',
#               "Dupre's Syndrome",
#               'Pain Sensation Diminisheds',
#               'Fractures, Open',
#               'Dentophobia',
#               'Central Nervous System Toxoplasmosis',
#               'Gm2-Gangliosidosis, Adult Chronic Type',
#               'NK-LGL Leukemias',
#               'Coxa Valgus, Developmental',
#               'Lisker Garcia Ramos syndrome',
#               'Myotonic Myopathy with Cylindrical Spirals',
#               'Choroidal Neovascularizations',
#               'CHOPS',
#               'Herpesvirus 4 Infections, Human',
#               'Jejunal Disease',
#               'Dislocation, Tooth',
#               'Hypotonia, Unilateral',
#               'COXSACKIEVIRUS B3 SUSCEPTIBILITY',
#               'Epidermolysis Bullosa Simplex Superficialis',
#               'Alkalosis',
#               'Fibrous Dysplasias, Monostotic',
#               'MYOPATHY DUE TO MYOADENYLATE DEAMINASE DEFICIENCY',
#               'Arachnodactyly',
#               'Conducted Energy Weapon Injuries',
#               'Post Concussive Syndrome',
#               'Palsies, Traumatic Fourth-Nerve',
#               'Hematomas, Intracranial Epidural',
#               'Triploids',
#               'Coagulation Disorder, Hereditary',
#               'Tapeworm Infections',
#               'Dysfunction, Ventricular',
#               'Ring 20 Syndrome',
#               'Rupture, Traumatic Heart',
#               'Malignancies, Post Traumatic',
#               'Cerebral Concussion',
#               'Surgical Tools, Retained',
#               'Rosai Dorfman Disease',
#               'Tumors, Unknown Primary',
#               'Allergy, Rubber Latex',
#               'Generalized Spasm',
#               'ACETABULAR DYSPLASIA',
#               'Syndromes, Drug Hypersensitivity',
#               'Ocular Infection, Fungal',
#               'Vestibular Insufficiency, Bilateral',
#               'CNS Venous Angiomas',
#               'Inherited Immunodeficiency Disease',
#               'Cytokine Storm',
#               'Circulating Cells, Neoplasm',
#               'Chiari Malformation Type II',
#               'Adenomas, Adrenal Cortical',
#               'Dysfunctions, Left Ventricular',
#               'Traumatic Intracranial Hemorrhages',
#               'Opitz-Frias syndrome',
#               'Syncopal Episode',
#               'Transneuronal Retrograde Degenerations',
#               'EVEN-PLUS SYNDROME',
#               'Abdominal Cramp',
#               'Fibroepithelial Neoplasm',
#               'Therapy-Related Cancers',
#               'Block, Left Bundle-Branch',
#               'Symptom Flaring Up',
#               'Kidney Disease, Diabetic',
#               'Immunodeficiency, Partial Combined, with Absence of HLA Determinants and Beta-2-Microglobulin from Lymphocytes',
#               'Duct Stones, Salivary',
#               'Ulcer, Venous Stasis',
#               'Keloid Acnes, Nuchal',
#               "Syndromes, Gardner's",
#               'Burning Pain',
#               'Rash, Diaper',
#               'Psychotic Disorder, Shared',
#               'Ventilator Induced Lung Injury',
#               'Amyloid Neuropathy, Secondary',
#               'Thoracic Cysts',
#               'Extradural Hemorrhage, Cranial',
#               'Tollner Horst Manzke syndrome',
#               'Inversions, Chromosomal',
#               'Smoke Inhalation Injuries',
#               'Delta-Beta Thalassemia',
#               'Disease, Protein Folding',
#               'Ventricular Hypertrophy, Left',
#               'Hypoplastic right-sided heart complex',
#               '9q22 Deletion Syndrome',
#               'ASC-H Atypical Squamous Cells, Cannot Rule Out High-Grade Squamous Intra-epithelial Lesion',
#               'Emery-Dreifuss Muscular Dystrophy, Atypical, Autosomal Recessive',
#               'Spinal Muscular Atrophy, Segmental',
#               'Enzootic Calf Pneumonia',
#               'Atresia of External Auditory Canal and Conduction Deafness',
#               'Diseases, Protein Folding',
#               'Aortopulmonary fistula',
#               'Hydroceles, Scrotal',
#               'Fibrous Dysplasia, Craniomaxillofacial',
#               'Convulsions, Benign Familial Neonatal, Autosomal Recessive',
#               'Trochlear Nerve Contusions',
#               'Congenital Hand Deformity',
#               'Syndrome, Cervical-Rib-Cervical-Band',
#               'Fulminant Liver Failures',
#               'Viral Cell Transformation',
#               'Chemically Induced Disorders',
#               'Hair Ball',
#               'Cell, Circulating Neoplastic',
#               'Infection, Aphasmidia',
#               'Noncompaction of Left Ventricular Myocardium, Familial Isolated, Autosomal Dominant 2',
#               'ASPLENIA, ISOLATED CONGENITAL',
#               'Valgus, Coxa',
#               'Microcephaly seizures mental retardation heart disorders',
#               'Addiction, Oncogenic',
#               'alpha-Chain Disease',
#               'Neurolymphomatoses, Primary',
#               'Palmoplantar hyperkeratosis and alopecia',
#               'Microphthalmia, Isolated, with Cataract 4',
#               'Syndromes, Cracked Tooth',
#               'Multicystic Renal Dysplasias',
#               'Fundus Dystrophy, Pseudoinflammatory, Recessive Form',
#               'Levels, High Cholesterol',
#               'Infectious Diseases',
#               'Injuries, Spinal Cord',
#               'Cysts, Branchial',
#               'Optic Nerve Contusion',
#               'Ataxia-Telangiectasia Variant',
#               'Dissecting Aneurysm',
#               'Aortic arch anomaly with peculiar facies and mental retardation',
#               'Dismemberments, Cadaver',
#               'BREAST-OVARIAN CANCER, FAMILIAL, SUSCEPTIBILITY TO, 4',
#               'Traumatic Stress Disorder',
#               'Septal Ruptures, Ventricular',
#               'Belchings',
#               'Melanoma, B16',
#               'Alcohol Withdrawal Induced Major Motor Seizure',
#               'Tears, SLAP',
#               'Bare Lymphocyte Syndrome, Type II, Complementation Group C',
#               'GGO and reticulation',
#               'Convulsion, Febrile',
#               'Progeroid Short Stature with Pigmented Nevi',
#               'Partial lissencephaly',
#               'Oropouche Orthobunyavirus Infection',
#               'Ventricle Remodelings, Left',
#               'ANCA-Associated Vasculitide',
#               'Fibroatheroma',
#               'Meningoencephalitis, Herpes Zoster',
#               'Littoral cell angioma of the spleen',
#               'Neoplasm-Related Pain',
#               'Fibrosis, Radiation-Induced',
#               'Deletion 6q16 q21',
#               'Infection, CNS Fungal',
#               'Consciousness, Level Depressed',
#               'Disorders, Late-Onset',
#               'Tibial Meniscus Tears',
#               'Hepatic Abscess, Pyogenic',
#               'Carbon Tetrachloride Poisonings',
#               'Periodontal Cysts, Apical',
#               'Abnormality, Cardiovascular',
#               'Lymphoid Formations, Ectopic',
#               'Trauma, Head',
#               'Cystinuria, Type A',
#               'Eyebrows duplication of, with stretchable skin and syndactyly',
#               "Puffy Tumor, Pott's",
#               'Hemophilia A with Vascular Abnormality',
#               'Child Development Disorders',
#               'ASTHMA-RELATED TRAITS, SUSCEPTIBILITY TO, 6',
#               'Myocardial Remodelings, Ventricular',
#               'Survival, Prosthesis',
#               'Tuberculosis, Ocular',
#               'Nephrosis with deafness and urinary tract and digital malformations',
#               'Electric Burns',
#               'NSGCT Nonseminomatous germ cell tumor',
#               'EOMD',
#               'Abdominal Fibromatosis',
#               'Monosomy 2p22',
#               'Neoplasm, Urogenital',
#               'Congenital agenesis of the tricuspid valve',
#               'MRKH anomaly',
#               '22q11 Deletion Syndrome',
#               'Polysaccharide, Storage of Unusual',
#               "Pediatric onset Crohn's disease",
#               'Disease, Avian',
#               'Anetoderma, Secondary',
#               'Low Back Pain, Posterior Compartment',
#               'Injuries, Trochlear Nerve',
#               'Jorgenson Lenz syndrome',
#               'Neurotoxicity Syndrome, Lead, Childhood',
#               'Neurocoenurosis',
#               'Fibroodontoma',
#               'Immune hemolytic anemia, paroxysmal cold',
#               'Bunyavirus Infections',
#               'Sidransky Feinstein Goodman syndrome',
#               'Pain, Widespread Chronic',
#               'Spastic Lower Extremity Weakness',
#               'Ischemia Hypoxia, Brain',
#               'MUCOPOLYSACCHARIDOSIS-PLUS SYNDROME',
#               'EBS6',
#               'Cramp, Muscle',
#               'Chromosome 7, terminal 7p deletion (del 7p21-p22)',
#               'Postcataract Aphakic Eye',
#               'Carinatums, Chondrogladiolar Pectus',
#               'Chromophobia',
#               'Velopharyngeal Insufficiency',
#               'Dissociation, Atrioventricular',
#               'Tumor Lysis Syndromes',
#               'Herpes Simplex, Oral',
#               'Peroneal nerve, accessory deep',
#               'PELVISCAPULAR DYSPLASIA',
#               'Allesthesia',
#               'Vertebrogenic Pain Syndrome',
#               'Roundworm Encephalitides, Raccoon',
#               'Peste-des-Petits-Ruminants',
#               'Embolism, Gas',
#               'Syndromes, Tumour Lysis',
#               'Animal Toxoplasmosis',
#               'Injuries, Hypoglossal Nerve',
#               'Agrammatic Broca Aphasias',
#               'Coronary Artery Disease, Development of, in HIV',
#               'Cancers, Post-Traumatic',
#               'EPKHE',
#               'Incarcerated Retroverted Uterus',
#               'Post Treatment Lyme Disease',
#               'Piscirickettsiaceae Infection',
#               'Scedosporium prolificans infection',
#               'Neurolymphomatoses',
#               'Hamartomas',
#               'Recurrent Miscarriage',
#               'Infection, Hendra Virus',
#               'FSHSMA',
#               'Adenoma, alpha-Cell',
#               'Dermal Duct Tumor',
#               'Alzheimer Disease 3, Early-Onset',
#               'Milk Fever, Animal',
#               'Anonychia-onychodystrophy with brachydactyly type B and ectrodactyly',
#               'Sarcoma 180, Crocker',
#               'RETINITIS PIGMENTOSA 79',
#               'Blood Poisonings',
#               'Feline Agranulocytoses',
#               'Occult Positive-Pressure Respiration',
#               'Cyst, Periapical',
#               'Intracranial Arachnoid Cyst',
#               'Uterine Hemorrhage',
#               'Femoral dysgenesis, bilateral-Robin anomaly',
#               'Headache, Intractable',
#               'Phobia, color black',
#               'Schizencephalies',
#               'ASRT1',
#               'Leukemia L 1210',
#               'Paroxysmal Dystonias, Nocturnal',
#               'Prenatal Exposure Delayed Effects',
#               'Leukoencephalopathy with Vanishing White Matter',
#               'Hernia, Paraduodenal',
#               'Intracranial Subdural Hematomas',
#               'Hypoxic-Ischemic Encephalopathy',
#               'Disorders, Auditory Comprehension',
#               'Diseases, Viral Skin',
#               'Dermatitides, Radiation Recall',
#               'Hyponatremias',
#               'Migraine Syndrome, Ophthalmoplegic',
#               'Multiple diaphyseal sclerosis',
#               'Pericaecal Hernia',
#               'Telangiectasias, Pontine Capillary',
#               'GEMSS syndrome',
#               'Auto PEEP',
#               'Ventricular Tunnels, Aortic-Left',
#               'Hypoventilations',
#               'Acute Lung Injuries',
#               'Heavy Metal Poisoning',
#               'Protozoal Infection, Cerebral',
#               'Lesions, Osseous Bankart',
#               'Ki 1 Lymphoma',
#               'Bilateral Superior Vena Cava',
#               'Granuloma, Laryngeal',
#               'Laryngeal Neuropathies, Traumatic',
#               'Intrauterine Device Migrations',
#               'Macroamylasemia',
#               'Residual Neuromuscular Blockades',
#               'Hypercytokinemia',
#               'Holoprosencephaly with Fetal Akinesia-Hypokinesia Sequence',
#               'Right-sided bronchial isomerism',
#               'Circoviridae Infection',
#               'Pain, Eye',
#               'Loss of Consciousness',
#               'Infarctions, Lacunar',
#               'Lung Parasitic Infections',
#               'ASC Atypical Squamous Cells',
#               'Ptosis, prognathism, microcephaly, radio-ulnar synostosis, short stature-dwarfism',
#               'Needle-Sticks',
#               'Encephalopathy, Hypoxic-Ischemic',
#               'Liver Abscess, Pyogenic',
#               'Nodular Glomerulosclerosis',
#               'Aspergillus niger infection, pulmonary',
#               'Arthrogryposis, Distal, with Mental Retardation and Characteristic Facies',
#               'Paraganglioma, Carotid Body',
#               'Fistula, Digestive System',
#               'T Cell Lymphoma, Enteropathy Associated',
#               'Toes, Hammer',
#               'Costens Syndrome',
#               'Spastic Gait',
#               'Nystagmus, Infantile Periodic Alternating, X-Linked',
#               'Chemotherapy-Induced Acral Erythemas',
#               'CCl4 Poisoning',
#               'Gaucher-like disease',
#               'Dyserythropoiesis, Congenital, with Internuclear Chromatin Bridges and Ultrastructurally Normal Erythroblast Heterochromatin',
#               'Recurrent Fever, Hereditary',
#               "Paget's Disease of the Nipple and Areola",
#               'Laryngeal web, congenital heart disease and low stature',
#               'Mercury Psychosis',
#               'Bronchial Hyperreactivity',
#               'Craniocele',
#               'Disorders of the Autonomic Nervous System',
#               'Mortons Neuroma',
#               "Syndrome, Patterson's",
#               'Rubral Tremors',
#               'Morton Neuroma',
#               'Strain',
#               'Pagets Disease, Breast',
#               'Feminization',
#               'Niemann-Pick Disease, Intermediate, With Visceral Involvement And Rapid Progression',
#               'Contusions, Vestibulocochlear Nerve',
#               'Nipple Adenoma',
#               'T-LGL Leukemias',
#               'Obesity, Adolescent',
#               'Embryonic Artery, Persistent, Cerebral',
#               'Surgical Hemorrhages',
#               'Pregnancy Losses, Early',
#               'Post operative Pain, Chronic',
#               'Alcohol Induced Dysmnesic Psychosis',
#               'Gastrointestinal Disorder, Functional',
#               'Cone rod dystrophy amelogenesis imperfecta',
#               'MSSGM',
#               'Transections, Olfactory Nerve',
#               'Pelvic Neoplasm',
#               'Vascular Rarefaction',
#               'Syndrome, Tumor Lysis',
#               'Kohlmeier-Degos Disease',
#               'Neuroectodermal Dysplasia Syndromes',
#               'Encephalopathies, Hypoxic-Ischemic',
#               'Pneumoperitoneum',
#               'Delayed Awakening, Post-Anesthesia',
#               'Kininogen Deficiency, High Molecular Weight and Low Molecular Weight',
#               'Temporomandibular ankylosis',
#               'MRKH, Type II',
#               'Permanent, Deafness',
#               'Traumatic Fourth Nerve Palsy',
#               'Infectious Diseases, Reemerging',
#               'Cerebral Hematomas, Traumatic',
#               'Mastocytic enterocolitis',
#               'Osteonecrosis, Bisphosphonate',
#               'F5F8D2',
#               'Virus Infection, Mayaro',
#               'Cell, Polyploid',
#               'Ice-Pick Headaches',
#               'Decline, Postoperative',
#               'Chromosome 6, monosomy 6q',
#               'Manz syndrome',
#               'Pointes, Torsade de',
#               'Contractures, Equinus',
#               'Breaks, Chromosome',
#               'CLF',
#               'Neuralgia, Vidian',
#               'unicuspid aortic valve',
#               'Carcinomatous Meningitides',
#               'Syndrome, Ectopic ACTH',
#               'LMNA-Linked Disease',
#               'LCCS6',
#               'Cyst, Sacral Perineural',
#               'Polyposis, Gastric',
#               'Bullous papular urticaria - type',
#               'Tremors, Static',
#               'Mallory-Weiss Syndrome',
#               'Craniodigital syndrome-mental retardation, Scott type',
#               'Patterson Brown Kelly Syndrome',
#               'Transections, Oculomotor Nerve',
#               'Recurrence, Locoregional Neoplasm',
#               'Mouth Cancers',
#               'Lymphosarcomas, Bovine',
#               'Pneumocystis Infection',
#               'Paranoid Disorders, Shared',
#               'Primary Immunodeficiency Syndrome',
#               'Bone Malpositions',
#               'Tumors, Meningeal',
#               'Cardiac Death',
#               'Diabetes Mellitus, Type II, With Deafness',
#               'Sex Reversal, Female, With Dysgenesis Of Kidneys, Adrenals, And Lungs',
#               'Tachyarrhythmias',
#               'Theodor Hertz Goodman syndrome',
#               'Suxamethonium Sensitivity',
#               "Syndrome, Costen's",
#               'Injuries, Lightning',
#               'Optic-Spinal Multiple Sclerosis',
#               'Degenerations, Trans-Synaptic',
#               'Radiation-Induced Leukemia',
#               'Extensor Rigidity',
#               'Generalized erythroderma, diarrhea, and failure to thrive',
#               'Tumor, Blood Vessel',
#               'Transmissible Venereal Tumor',
#               'Hepatic Entamoebiases',
#               'Female Pseudohermaphroditism',
#               'Ochronosis, hereditary',
#               'Townes-Brocks-Branchiootorenal-Like Syndrome',
#               'Bony Bankart Lesions',
#               'Al Awadi Teebi Farag syndrome',
#               "Syndrome, Mesulam's",
#               'Invasive Fungal Infection',
#               'Hemorrhagic Syndrome, Bovine',
#               'Mioses, Persistent',
#               'Syndromes, Congenital Rubella',
#               'Post-operative Pain, Acute',
#               'Progressive External Ophthalmoplegia With Hypogonadism',
#               'Neoplasms, Genitourinary',
#               'Optic nerve tram track sign',
#               'Neglect, Hemisensory',
#               'ICF syndrome',
#               'Disorders, Childhood-Onset Fluency',
#               'Diffuse mesangial sclerosis',
#               'Primary Immune Deficiency Disorder',
#               'Conjunctivitis, Viral',
#               'Fecalith',
#               'Lipoblastomas',
#               'Infectious Ectromelia',
#               'Choreas, Habit',
#               'Blindness, Monocular, Transient',
#               'Ciliopathy',
#               'Brachycephaly, Deafness, Cataract, Microstomia, And Mental Retardation',
#               'Tachycardia, Reciprocating',
#               'Mal de debarquement',
#               'Atonic-Astatic Syndrome of Foerster',
#               'Infection, Rhabditida',
#               'Familial primary biliary cirrhosis',
#               'Traumatization, Vicarious',
#               'Hand Deformities, Congenital',
#               'Dentin dysplasia sclerotic bones',
#               'Ladda Zonana Ramer syndrome',
#               'Neurasthenic Neuroses',
#               'ACID-LABILE SUBUNIT DEFICIENCY',
#               'PNS Disease',
#               'Endocrine Tuberculosis',
#               'Psychoses, Affective',
#               ...},
#              'MESH:C535484': {'13q deletion syndrome',
#               'Chromosome 13q deletion',
#               'Chromosome 13q deletion syndrome',
#               'Chromosome 13q monosomy',
#               'Chromosome 13q syndrome',
#               'Deletion 13q',
#               'Deletion 13q syndrome',
#               'Monosomy 13q',
#               'Monosomy 13q syndrome',
#               'Orbeli syndrome',
#               "Orbeli's syndrome"},
#              'MESH:C579849': {'15q24 Deletion',
#               '15q24 Microdeletion',
#               '15q24 Microdeletion Syndrome',
#               'Interstitial Deletion of Chromosome 15q24'},
#              'DO:DOID:0060395': {'15q24 Deletion',
#               '15q24 Microdeletion',
#               '15q24 Microdeletion Syndrome',
#               'CHROMOSOME 15q24 DELETION SYNDROME, INCLUDED',
#               'CHROMOSOME 15q24 DUPLICATION SYNDROME, INCLUDED',
#               'Interstitial Deletion of Chromosome 15q24',
#               'WITKOS',
#               'WITTEVEEN-KOLK SYNDROME'},
#              'MESH:C579850': {'16p11.2 Deletion Syndrome'},
#              'MESH:C567076': {'17,20-Lyase Deficiency, Isolated',
#               '17-Alpha-Hydroxylase-17,20-Lyase Deficiency, Combined Complete',
#               '17-Alpha-Hydroxylase-17,20-Lyase Deficiency, Combined Partial'},
#              'MESH:C537805': {'17 Beta-hydroxysteroid dehydrogenase deficiency',
#               '17 alpha ketosteroid reductase deficiency of testis',
#               '17-Beta Hydroxysteroid Dehydrogenase 3 Deficiency',
#               '17-Beta Hydroxysteroid Dehydrogenase III Deficiency',
#               '17-Hydroxysteroid Dehydrogenase Deficiency',
#               '17-Ketosteroid Reductase Deficiency Of Testis',
#               '17-Ksr Deficiency',
#               'Male pseudohermaphroditism with gynecomastia',
#               'Neutral 17 beta-hydroxysteroid oxidoreductase deficiency',
#               'Neutral 17-Beta-Hydroxysteroid Oxidoreductase Deficiency',
#               'PSEUDOHERMAPHRODITISM, MALE, WITH GYNECOMASTIA POLYCYSTIC OVARY SYNDROME DUE TO 17-KETOSTEROID REDUCTASE DEFICIENCY, INCLUDED',
#               'Pseudohermaphroditism, Male, with Gynecomastia'},
#              'OMIM:264300': {'17 Beta-hydroxysteroid dehydrogenase deficiency',
#               '17 alpha ketosteroid reductase deficiency of testis',
#               '17-Beta Hydroxysteroid Dehydrogenase 3 Deficiency',
#               '17-Beta Hydroxysteroid Dehydrogenase III Deficiency',
#               '17-Hydroxysteroid Dehydrogenase Deficiency',
#               '17-Ketosteroid Reductase Deficiency Of Testis',
#               '17-Ksr Deficiency',
#               'Male pseudohermaphroditism with gynecomastia',
#               'Neutral 17 beta-hydroxysteroid oxidoreductase deficiency',
#               'Neutral 17-Beta-Hydroxysteroid Oxidoreductase Deficiency',
#               'PSEUDOHERMAPHRODITISM, MALE, WITH GYNECOMASTIA POLYCYSTIC OVARY SYNDROME DUE TO 17-KETOSTEROID REDUCTASE DEFICIENCY, INCLUDED',
#               'Pseudohermaphroditism, Male, with Gynecomastia'},
#              'MESH:C537806': {'18-HYDROXYLASE DEFICIENCY',
#               '18-Hydroxylase deficiency',
#               '18-Oxidase Deficiency',
#               '18-alpha hydroxylase deficiency',
# ...
#              'MESH:C562879': {'AI1B',
#               'AIH2',
#               'Amelogenesis Imperfecta, Hypoplastic Local, Autosomal Dominant',
#               'Amelogenesis Imperfecta, Type IB',
#               'Enamel Hypoplasia, Hereditary Localized'},
#              'OMIM:104500': {'AI1B',
#               'AIH2',
#               'Amelogenesis Imperfecta, Hypoplastic Local, Autosomal Dominant',
#               'Amelogenesis Imperfecta, Type IB',
#               'Enamel Hypoplasia, Hereditary Localized'},
#              'MESH:C567147': {'AI1C',
#               'AMELOGENESIS IMPERFECTA, HYPOPLASTIC, WITH OR WITHOUT OPEN-BITE MALOCCLUSION, AUTOSOMAL RECESSIVE',
#               'Amelogenesis Imperfecta, Hypoplastic, With Or Without Openbite Malocclusion, Autosomal Recessive',
#               'Amelogenesis Imperfecta, Local Hypoplastic Type, Autosomal Recessive',
#               'Amelogenesis Imperfecta, Type Ic'},
#              'OMIM:204650': {'AI1C',
#               'AMELOGENESIS IMPERFECTA, HYPOPLASTIC, WITH OR WITHOUT OPEN-BITE MALOCCLUSION, AUTOSOMAL RECESSIVE',
#               'Amelogenesis Imperfecta, Hypoplastic, With Or Without Openbite Malocclusion, Autosomal Recessive',
#               'Amelogenesis Imperfecta, Local Hypoplastic Type, Autosomal Recessive',
#               'Amelogenesis Imperfecta, Type Ic'},
#              'OMIM:616270': {'AI1F',
#               'AMELOGENESIS IMPERFECTA, HYPOPLASTIC TYPE IF',
#               'AMELOGENESIS IMPERFECTA, TYPE IF'},
#              'DO:DOID:0110065': {'AI1F',
#               'AMELOGENESIS IMPERFECTA, HYPOPLASTIC TYPE IF',
#               'AMELOGENESIS IMPERFECTA, TYPE IF'},
#              'OMIM:204690': {'AI1G',
#               'AIGFS',
#               'AMELOGENESIS IMPERFECTA AND GINGIVAL FIBROMATOSIS SYNDROME',
#               'AMELOGENESIS IMPERFECTA, HYPOPLASTIC, WITH NEPHROCALCINOSIS',
#               'AMELOGENESIS IMPERFECTA, TYPE IG',
#               'ENAMEL-RENAL SYNDROME',
#               'ENAMEL-RENAL-GINGIVAL SYNDROME',
#               'ERS'},
#              'DO:DOID:0110066': {'AI1G',
#               'AIGFS',
#               'AMELOGENESIS IMPERFECTA AND GINGIVAL FIBROMATOSIS SYNDROME',
#               'AMELOGENESIS IMPERFECTA, HYPOPLASTIC, WITH NEPHROCALCINOSIS',
#               'AMELOGENESIS IMPERFECTA, TYPE IG',
#               'ENAMEL-RENAL SYNDROME',
#               'ENAMEL-RENAL-GINGIVAL SYNDROME',
#               'ERS'},
#              'OMIM:616221': {'AI1H', 'AMELOGENESIS IMPERFECTA, TYPE IH'},
#              'DO:DOID:0110064': {'AI1H', 'AMELOGENESIS IMPERFECTA, TYPE IH'},
#              'MESH:C562880': {'ADHCAI',
#               'AI3',
#               'AI3A',
#               'AMELOGENESIS IMPERFECTA, TYPE III',
#               'AMELOGENESIS IMPERFECTA, TYPE IIIA',
#               'Amelogenesis Imperfecta, Hypocalcification Type, Autosomal Dominant',
#               'Amelogenesis Imperfecta, Hypomineralization Type',
#               'Amelogenesis Imperfecta, Type III'},
#              'DO:DOID:0111721': {'ADHCAI',
#               'AI3',
#               'AI3A',
#               'AMELOGENESIS IMPERFECTA, TYPE III',
#               'AMELOGENESIS IMPERFECTA, TYPE IIIA',
#               'Amelogenesis Imperfecta, Hypocalcification Type, Autosomal Dominant',
#               'Amelogenesis Imperfecta, Hypomineralization Type',
#               'Amelogenesis Imperfecta, Type III'},
#              'OMIM:130900': {'ADHCAI',
#               'AI3',
#               'AI3A',
#               'AMELOGENESIS IMPERFECTA, TYPE III',
#               'AMELOGENESIS IMPERFECTA, TYPE IIIA',
#               'Amelogenesis Imperfecta, Hypocalcification Type, Autosomal Dominant',
#               'Amelogenesis Imperfecta, Hypomineralization Type',
#               'Amelogenesis Imperfecta, Type III'},
#              'OMIM:617297': {'AI1J', 'AMELOGENESIS IMPERFECTA, TYPE IJ'},
#              'DO:DOID:0080953': {'AI1J', 'AMELOGENESIS IMPERFECTA, TYPE IJ'},
#              'MESH:C566293': {'AI4',
#               'AIHHT',
#               'Amelogenesis Imperfecta, Hypomaturation-Hypoplastic Type, with Taurodontism',
#               'Amelogenesis Imperfecta, Type IV'},
#              'OMIM:104510': {'AI4',
#               'AIHHT',
#               'Amelogenesis Imperfecta, Hypomaturation-Hypoplastic Type, with Taurodontism',
#               'Amelogenesis Imperfecta, Type IV'},
#              'MESH:C538245': {'Ameloonychohypohidrotic syndrome',
#               'Hypocalcified-hypoplastic enamel, onycholysis with subungual hyperkeratosis, and hypohidrosis'},
#              'MESH:D000568': {'Amenorrhea',
#               'Amenorrhea, Postpartum',
#               'Postpartum Amenorrhea',
#               'Postpartum Amenorrheas'},
#              'DO:DOID:13938': {'Amenorrhea',
#               'Amenorrhea, Postpartum',
#               'Postpartum Amenorrhea',
#               'Postpartum Amenorrheas'},
#              'MESH:D000592': {'Amino Acid Metabolism Disorders, Inborn',
#               'Amino Acid Metabolism, Inborn Error',
#               'Amino Acid Metabolism, Inborn Errors',
#               'Amino Acid Metabolism, Inherited Disorders',
#               'Amino Acidopathies, Congenital',
#               'Amino Acidopathies, Inborn',
#               'Amino Acidopathy, Congenital',
#               'Amino Acidopathy, Inborn',
#               'Congenital Amino Acidopathies',
#               'Congenital Amino Acidopathy',
#               'Inborn Amino Acidopathies',
#               'Inborn Amino Acidopathy',
#               'Inborn Errors, Amino Acid Metabolism',
#               'Inherited Errors of Amino Acid Metabolism'},
#              'DO:DOID:9252': {'Amino Acid Metabolism Disorders, Inborn',
#               'Amino Acid Metabolism, Inborn Error',
#               'Amino Acid Metabolism, Inborn Errors',
#               'Amino Acid Metabolism, Inherited Disorders',
#               'Amino Acidopathies, Congenital',
#               'Amino Acidopathies, Inborn',
#               'Amino Acidopathy, Congenital',
#               'Amino Acidopathy, Inborn',
#               'Congenital Amino Acidopathies',
#               'Congenital Amino Acidopathy',
#               'Inborn Amino Acidopathies',
#               'Inborn Amino Acidopathy',
#               'Inborn Errors, Amino Acid Metabolism',
#               'Inherited Errors of Amino Acid Metabolism'},
#              'MESH:D020157': {'Amino Acid Transport Disorders, Inborn',
#               'Inborn Transport Disorders, Amino Acid',
#               'Inherited Amino Acid Transport Disorders',
#               'Transport Disorders, Amino Acid, Inborn'},
#              'MESH:C565960': {'Amino Aciduria with Mental Deficiency, Dwarfism, Muscular Dystrophy, Osteoporosis, and Acidosis'},
#              'MESH:C538246': {'ACY1D',
#               'Aminoacylase 1 deficiency',
#               'Deficiency of the aminoacylase-1 enzyme'},
#              'OMIM:609924': {'ACY1D',
#               'Aminoacylase 1 deficiency',
#               'Deficiency of the aminoacylase-1 enzyme'},
#              'MESH:C563799': {'AMISH INFANTILE EPILEPSY SYNDROME',
#               'Amish Infantile Epilepsy Syndrome',
#               'Epilepsy Syndrome, Infantile-Onset Symptomatic',
#               'GM3 Synthase Deficiency',
#               'SALT AND PEPPER DEVELOPMENTAL REGRESSION SYNDROME',
#               'SALT AND PEPPER MENTAL RETARDATION SYNDROME',
#               'SPDRS'},
#              'OMIM:609056': {'AMISH INFANTILE EPILEPSY SYNDROME',
#               'Amish Infantile Epilepsy Syndrome',
#               'Epilepsy Syndrome, Infantile-Onset Symptomatic',
#               'GM3 Synthase Deficiency',
#               'SALT AND PEPPER DEVELOPMENTAL REGRESSION SYNDROME',
#               'SALT AND PEPPER MENTAL RETARDATION SYNDROME',
#               'SPDRS'},
#              'MESH:C538247': {'AMISH LETHAL MICROCEPHALY',
#               'Amish Microcephaly',
#               'Amish lethal microcephaly',
#               'MCPHA',
#               'Microcephaly, Amish type',
#               'THIAMINE METABOLISM DYSFUNCTION SYNDROME 3 (MICROCEPHALY TYPE)',
#               'THMD3'},
#              'OMIM:607196': {'AMISH LETHAL MICROCEPHALY',
#               'Amish Microcephaly',
#               'Amish lethal microcephaly',
#               'MCPHA',
#               'Microcephaly, Amish type',
#               'THIAMINE METABOLISM DYSFUNCTION SYNDROME 3 (MICROCEPHALY TYPE)',
#               'THMD3'},
#              'MESH:D000647': {'Amnesia',
#               'Amnesia Memory Loss',
#               'Amnesia, Dissociative',
#               'Amnesia, Global',
#               'Amnesia, Hysterical',
#               'Amnesia, Tactile',
#               'Amnesia, Temporary',
#               'Amnesia-Memory Loss',
#               'Amnesia-Memory Losses',
#               'Amnesias',
#               'Amnesias, Dissociative',
#               'Amnesias, Global',
#               'Amnesias, Hysterical',
#               'Amnesias, Tactile',
#               'Amnesias, Temporary',
#               'Amnestic State',
#               'Amnestic States',
#               'Dissociative Amnesia',
#               'Dissociative Amnesias',
#               'Global Amnesia',
#               'Global Amnesias',
#               'Hysterical Amnesia',
#               'Hysterical Amnesias',
#               'State, Amnestic',
#               'States, Amnestic',
#               'Tactile Amnesia',
#               'Tactile Amnesias',
#               'Temporary Amnesia',
#               'Temporary Amnesias'},
#              'DO:DOID:10914': {'Amnesia',
#               'Amnesia Memory Loss',
#               'Amnesia, Dissociative',
#               'Amnesia, Global',
#               'Amnesia, Hysterical',
#               'Amnesia, Tactile',
#               'Amnesia, Temporary',
#               'Amnesia-Memory Loss',
#               'Amnesia-Memory Losses',
#               'Amnesias',
#               'Amnesias, Dissociative',
#               'Amnesias, Global',
#               'Amnesias, Hysterical',
#               'Amnesias, Tactile',
#               'Amnesias, Temporary',
#               'Amnestic State',
#               'Amnestic States',
#               'Dissociative Amnesia',
#               'Dissociative Amnesias',
#               'Global Amnesia',
#               'Global Amnesias',
#               'Hysterical Amnesia',
#               'Hysterical Amnesias',
#               'State, Amnestic',
#               'States, Amnestic',
#               'Tactile Amnesia',
#               'Tactile Amnesias',
#               'Temporary Amnesia',
#               'Temporary Amnesias'},
#              'DO:DOID:11037': {'Amnesia',
#               'Amnesia Memory Loss',
#               'Amnesia, Dissociative',
#               'Amnesia, Global',
#               'Amnesia, Hysterical',
#               'Amnesia, Tactile',
#               'Amnesia, Temporary',
#               'Amnesia-Memory Loss',
#               'Amnesia-Memory Losses',
#               'Amnesias',
#               'Amnesias, Dissociative',
#               'Amnesias, Global',
#               'Amnesias, Hysterical',
#               'Amnesias, Tactile',
#               'Amnesias, Temporary',
#               'Amnestic State',
#               'Amnestic States',
#               'Dissociative Amnesia',
#               'Dissociative Amnesias',
#               'Global Amnesia',
#               'Global Amnesias',
#               'Hysterical Amnesia',
#               'Hysterical Amnesias',
#               'State, Amnestic',
#               'States, Amnestic',
#               'Tactile Amnesia',
#               'Tactile Amnesias',
#               'Temporary Amnesia',
#               'Temporary Amnesias'},
#              'MESH:D020324': {'Amnesia, Anterograde',
#               'Amnesia, Post Ictal',
#               'Amnesia, Post-Ictal',
#               'Amnesias, Anterograde',
#               'Amnesias, Post-Ictal',
#               'Anterograde Amnesia',
#               'Anterograde Amnesias',
#               'Anterograde Memory Loss',
#               'Anterograde Memory Losses',
#               'Loss, Post-Ictal Memory',
#               'Losses, Post-Ictal Memory',
#               'Memory Loss, Anterograde',
#               'Memory Loss, Post-Ictal',
#               'Memory Losses, Anterograde',
#               'Memory Losses, Post-Ictal',
#               'Post Ictal Memory Loss',
#               'Post-Ictal Amnesia',
#               'Post-Ictal Amnesias',
#               'Post-Ictal Memory Loss',
#               'Post-Ictal Memory Losses'},
#              'DO:DOID:5340': {'Amnesia, Anterograde',
#               'Amnesia, Post Ictal',
#               'Amnesia, Post-Ictal',
#               'Amnesias, Anterograde',
#               'Amnesias, Post-Ictal',
#               'Anterograde Amnesia',
#               'Anterograde Amnesias',
#               'Anterograde Memory Loss',
#               'Anterograde Memory Losses',
#               'Loss, Post-Ictal Memory',
#               'Losses, Post-Ictal Memory',
#               'Memory Loss, Anterograde',
#               'Memory Loss, Post-Ictal',
#               'Memory Losses, Anterograde',
#               'Memory Losses, Post-Ictal',
#               'Post Ictal Memory Loss',
#               'Post-Ictal Amnesia',
#               'Post-Ictal Amnesias',
#               'Post-Ictal Memory Loss',
#               'Post-Ictal Memory Losses'},
#              'MESH:D000648': {'Amnesia, Pre Ictal',
#               'Amnesia, Pre-Ictal',
#               'Amnesia, Retrograde',
#               'Amnesias, Pre-Ictal',
#               'Amnesias, Retrograde',
#               'Memory Loss, Pre-Ictal',
#               'Memory Loss, Retrograde',
#               'Memory Losses, Pre-Ictal',
#               'Memory Losses, Retrograde',
#               'Pre Ictal Memory Loss',
#               'Pre-Ictal Amnesia',
#               'Pre-Ictal Amnesias',
#               'Pre-Ictal Memory Loss',
#               'Pre-Ictal Memory Losses',
#               'Retrograde Amnesia',
#               'Retrograde Amnesias',
#               'Retrograde Memory Loss',
#               'Retrograde Memory Losses'},
#              'DO:DOID:4543': {'Amnesia, Pre Ictal',
#               'Amnesia, Pre-Ictal',
#               'Amnesia, Retrograde',
#               'Amnesias, Pre-Ictal',
#               'Amnesias, Retrograde',
#               'Memory Loss, Pre-Ictal',
#               'Memory Loss, Retrograde',
#               'Memory Losses, Pre-Ictal',
#               'Memory Losses, Retrograde',
#               'Pre Ictal Memory Loss',
#               'Pre-Ictal Amnesia',
#               'Pre-Ictal Amnesias',
#               'Pre-Ictal Memory Loss',
#               'Pre-Ictal Memory Losses',
#               'Retrograde Amnesia',
#               'Retrograde Amnesias',
#               'Retrograde Memory Loss',
#               'Retrograde Memory Losses'},
#              'MESH:D020236': {'Amnesia, Transient Global',
#               'Global Amnesia, Transient',
#               'TGA (Transient Global Amnesia)',
#               'TGAs (Transient Global Amnesia)',
#               'Transient Global Amnesia'},
#              'DO:DOID:13027': {'Amnesia, Transient Global',
#               'Global Amnesia, Transient',
#               'TGA (Transient Global Amnesia)',
#               'TGAs (Transient Global Amnesia)',
#               'Transient Global Amnesia'},
#              'MESH:C531614': {'Amniotic Band Sequence',
#               'Amniotic bands sequence',
#               'Congenital constricting bands',
#               'Constricting Bands, Congenital',
#               'Familial amniotic bands',
#               'Streeter anomaly'},
#              'MESH:D000652': {'Amniotic Band',
#               'Amniotic Band Syndrome',
#               'Amniotic Bands',
#               'Amputation, Intrauterine',
#               'Amputations, Intrauterine',
#               'Annular Groove',
#               'Annular Grooves',
#               'Band, Amniotic',
#               'Bands, Amniotic',
#               'Constriction, Intrauterine Ring',
#               'Constrictions, Intrauterine Ring',
#               'Groove, Annular',
#               'Grooves, Annular',
#               'Intrauterine Amputation',
#               'Intrauterine Amputations',
#               'Intrauterine Ring Constriction',
#               'Intrauterine Ring Constrictions',
#               'Ring Constriction, Intrauterine',
#               'Ring Constrictions, Intrauterine',
#               'Streeter Syndrome',
#               'Syndrome, Amniotic Band',
#               'Syndrome, Streeter'},
#              ...})

# %%
gnormplus_dict = ujson.load(open('../data/entrez_to_alias_gnormplus.json'))
# Write in standard pipe-delimited format
with open('../data/alias_mappings/gnormplus_aliases.txt', 'w') as f:
    f.write('\n'.join([f"{key}||{v}" for key, val in gnormplus_dict.items() for v in val.split('|')]))

nlm_gene_dict = ujson.load(open('../data/entrez_to_alias_nlm_gene.json'))
with open('../data/alias_mappings/nlm_gene_aliases.txt', 'w') as f:
    f.write('\n'.join([f"{key}||{v}" for key, val in nlm_gene_dict.items() for v in val.split('|')]))

# %%
gnormplus_dict
# Out:
# {'NCBIGene:814629': 'AT2G01050|zinc ion binding / nucleic acid binding protein|F23H14.2|F23H14_2',
#  'NCBIGene:814630': 'AT2G01060|F23H14.3|F23H14_3|myb-like HTH transcriptional regulator family protein',
#  'NCBIGene:814631': 'AT2G01031',
#  'NCBIGene:814636': 'F23H14.5|F23H14_5|Late embryogenesis abundant (LEA) hydroxyproline-rich glycoprotein family|AT2G01080',
#  'NCBIGene:814637': 'F23H14.4|F23H14_4|Lung seven transmembrane receptor family protein|AT2G01070',
#  'NCBIGene:814638': 'Ubiquinol-cytochrome C reductase hinge protein|F23H14.6|F23H14_6|AT2G01090',
#  'NCBIGene:814639': 'F23H14.7|F23H14_7|FAM133-like protein|AT2G01100',
#  'NCBIGene:814640': 'Sec-independent periplasmic protein translocase|APG2|ALBINO AND PALE GREEN 2|F23H14.8|F23H14_8|PGA2|TATC|TWIN-ARGININE TRANSLOCATION C|UNE3|unfertilized embryo sac 3',
#  'NCBIGene:814641': 'ATORC4|F23H14.9|F23H14_9|ORIGIN RECOGNITION COMPLEX SUBUNIT 4|origin recognition complex subunit 4|ORC4|origin recognition complex subunit 4|ORC4 (Arabidopsis thaliana)',
#  'NCBIGene:814642': 'DEA(D/H)-box RNA helicase family protein|AT2G01130|F10A8.28',
#  'NCBIGene:814643': 'AtFBA3|FBA3|PIGMENT DEFECTIVE 345|fructose-bisphosphate aldolase 3|Aldolase superfamily protein|PDE345',
#  'NCBIGene:814644': 'RHA2B|RING-H2 finger protein 2B|F10A8.3|F10A8_3|RING-H2 FINGER PROTEIN RHA2B|RING-H2 finger protein 2B',
#  'NCBIGene:814645': 'BAT1|bidirectional amino acid transporter 1|AtGABP|GABA permease|GABP|bidirectional amino acid transporter 1|BAT1 (Arabidopsis thaliana)',
#  'NCBIGene:814646': 'phosphatidic acid phosphatase 1|PAP1|PAP1 (Arabidopsis thaliana)|ATLPP1|ATPAP1|F10A8.6|F10A8_6|LIPID PHOSPHATE PHOSPHATASE 1|LPP1|phosphatidic acid phosphatase 1',
#  'NCBIGene:814647': 'Octicosapeptide/Phox/Bem1p family protein|F10A8.7|F10A8_7|PIGMENT DEFECTIVE 331|PDE331',
#  'NCBIGene:814648': 'F10A8.8|F10A8_8|MEE10|indole-3-acetic acid inducible 32|maternal effect embryo arrest 10|IAA32|indole-3-acetic acid inducible 32',
#  'NCBIGene:814649': 'AT2G01210|F10A8.9|F10A8_9|Leucine-rich repeat protein kinase family protein',
#  'NCBIGene:814650': 'AT2G01220|Nucleotidylyl transferase superfamily protein|AT2G01230|F10A8.10|F10A8_10',
#  'NCBIGene:814651': 'reticulon-like protein B15|F10A8.12|F10A8_12|AT2G01240',
#  'NCBIGene:814652': 'F10A8.13|F10A8_13|Ribosomal protein L30/L7 family protein|AT2G01250',
#  'NCBIGene:814653': 'AT2G01260|hypothetical protein (DUF789)|F10A8.14|F10A8_14',
#  'NCBIGene:814654': 'QSOX2 (Arabidopsis thaliana)|QSOX2|AtQSOX2|F10A8.15|F10A8_15|quiescin-sulfhydryl oxidase 2|quiescin-sulfhydryl oxidase 2',
#  'NCBIGene:814655': 'AT2G01275|RING/FYVE/PHD zinc finger superfamily protein',
#  'NCBIGene:814656': 'MEE65|F10A8.16|F10A8_16|maternal effect embryo arrest 65|Cyclin/Brf1-like TBP-binding protein',
#  'NCBIGene:814657': 'RPI2|F10A8.17|F10A8_17|ribose-5-phosphate isomerase 2|ribose-5-phosphate isomerase 2',
#  'NCBIGene:814658': 'F10A8.18|F10A8_18|mediator of RNA polymerase II transcription subunit|AT2G01300',
#  'NCBIGene:814660': 'ABC-2 type transporter family protein|ATP-binding cassette G7|F10A8.20|F10A8_20|ABCG7',
#  'NCBIGene:814661': 'F10A8.21|F10A8_21|nucleotide binding protein|AT2G01330',
#  'NCBIGene:814662': 'plastid movement impaired protein|At17.1|F10A8.22|F10A8_22',
#  'NCBIGene:814663': 'QPT|quinolinate phoshoribosyltransferase|F10A8.23|F10A8_23|quinolinate phoshoribosyltransferase',
#  'NCBIGene:814664': 'pentatricopeptide (PPR) repeat protein|F10A8.24|F10A8_24|AT2G01360',
#  'NCBIGene:814665': 'F10A8.25|F10A8_25|DNA-binding storekeeper protein-related transcriptional regulator|AT2G01370',
#  'NCBIGene:814667': 'EMBRYO DEFECTIVE 3111|F10A8.29|EMB3111|Tetratricopeptide repeat (TPR)-like superfamily protein',
#  'NCBIGene:814668': 'uncharacterized protein|F10A8.4|AT2G01400',
#  'NCBIGene:814669': 'F10A8.30|NHL domain-containing protein|AT2G01410',
#  'NCBIGene:814670': 'PIN4 (Arabidopsis thaliana)|Auxin efflux carrier family protein|PIN4|ARABIDOPSIS PIN-FORMED 4|ATPIN4|AUXIN TRANSPORTER SPLICE VARIANT B|F10A8.27|PIN-FORMED 4',
#  'NCBIGene:814671': 'homeobox-leucine zipper protein 17|ARABIDOPSIS THALIANA HOMEOBOX-LEUCINE ZIPPER PROTEIN 17|ATHB-17|ATHB17|F2I9.5|F2I9_5|homeobox-leucine zipper protein 17|HB17',
#  'NCBIGene:814672': 'AT2G01440|F2I9.6|F2I9_6|DEAD/DEAH box RNA helicase family protein',
#  'NCBIGene:814673': 'MPK17|MAP kinase 17|ATMPK17|F2I9.7|F2I9_7|MAP kinase 17',
#  'NCBIGene:814674': 'AT2G01460|P-loop containing nucleoside triphosphate hydrolases superfamily protein|F2I9.8|F2I9_8',
#  'NCBIGene:814675': 'SEC12P-like 2 protein|ATSEC12|F2I9.9|F2I9_9|SEC12P-like 2 protein|STL2P',
#  'NCBIGene:814676': 'AT2G01480|F2I9.10|F2I9_10|O-fucosyltransferase family protein',
#  'NCBIGene:814677': 'PAHX|F2I9.11|F2I9_11|phytanoyl-CoA 2-hydroxylase|phytanoyl-CoA dioxygenase (PhyH) family protein',
#  'NCBIGene:814678': 'Homeodomain-like superfamily protein|PFS2 (Arabidopsis thaliana)|PFS2|F2I9.12|F2I9_12|HIGH EXPRESSION OF OSMOTICALLY RESPONSIVE GENE 9|HOS9|PRETTY FEW SEEDS 2|WOX6|WUSCHEL RELATED HOMEOBOX 6',
#  'NCBIGene:814680': 'AT2G01510|F2I9.13|F2I9_13|Tetratricopeptide repeat (TPR)-like superfamily protein',
#  'NCBIGene:814681': 'MLP328|MLP-like protein 328|(Zusammen-CA)-enhanced 1|F2I9.14|F2I9_14|MLP-like protein 328|ZCE1',
#  'NCBIGene:814682': 'MLP329|(Zusammen-CA)-enhanced 2|F2I9.15|F2I9_15|MLP-like protein 329|ZCE2|MLP-like protein 329',
#  'NCBIGene:814683': 'Calcium-dependent lipid-binding (CaLB domain) family protein|F2I9.16|F2I9_16|AT2G01540',
#  'NCBIGene:814685': 'AT2G01560|F2I9.18|F2I9_18|Plant protein 1589 of unknown function',
#  'NCBIGene:814686': 'F2I9.19|F2I9_19|REPRESSOR OF GA|REPRESSOR OF GA1-3 1|RGA|RGA1|RGA1 (Arabidopsis thaliana)|GRAS family transcription factor family protein',
#  'NCBIGene:814687': 'AT2G01580|uncharacterized protein|F2I9.20|F2I9_20',
#  'NCBIGene:814688': 'CRR3|chlororespiratory reduction 3|CHLORORESPIRATORY REDUCTION 3|F2I9.21|F2I9_21',
#  'NCBIGene:814689': 'ENTH/ANTH/VHS superfamily protein|F2I9.22|F2I9_22|AT2G01600',
#  'NCBIGene:814690': 'AT2G01610|Plant invertase/pectin methylesterase inhibitor superfamily protein|T8O11.22|T8O11_22',
#  'NCBIGene:814691': 'MEE11|T8O11.21|T8O11_21|maternal effect embryo arrest 11|RNI-like superfamily protein',
#  'NCBIGene:814692': 'O-Glycosyl hydrolases family 17 protein|T8O11.20|T8O11_20|AT2G01630',
#  'NCBIGene:814693': 'AT2G01640|T8O11.19|T8O11_19|ribosome biogenesis protein',
#  'NCBIGene:814694': 'plant UBX domain-containing protein 2|T8O11.18|T8O11_18|plant UBX domain-containing protein 2|PUX2',
#  'NCBIGene:814695': 'PDLP6|T8O11.17|T8O11_17|plasmodesmata-located protein 6|plasmodesmata-located protein 6',
#  'NCBIGene:814696': 'NUDT17|nudix hydrolase homolog 17|T8O11.16|T8O11_16|atnudt17|nudix hydrolase homolog 17|NUDT17 (Arabidopsis thaliana)',
#  'NCBIGene:814697': 'AT2G01680|Ankyrin repeat family protein|T8O11.15|T8O11_15',
#  'NCBIGene:814698': 'AT2G01690|ARM repeat superfamily protein|T8O11.14|T8O11_14',
#  'NCBIGene:814699': 'AT2G01700|T8O11.13|T8O11_13',
#  'NCBIGene:814700': 'AT2G01710|T8O11.12|T8O11_12|Chaperone DnaJ-domain superfamily protein',
#  'NCBIGene:814701': 'Ribophorin I|AT2G01720|T8O11.11|T8O11_11',
#  'NCBIGene:814702': 'cleavage and polyadenylation specificity factor 73 kDa subunit-II|ATCPSF73-II|CLEAVAGE AND POLYADENYLATION SPECIFICITY FACTOR 73 KDA SUBUNIT-II|EDA26|T8O11.10|T8O11_10|cleavage and polyadenylation specificity factor 73 kDa subunit-II|embryo sac development arrest 26|CPSF73-II',
#  'NCBIGene:814703': 'RING-finger protein for embryogenesis|RIE1|RING-finger protein for embryogenesi|RIE1 (Arabidopsis thaliana)',
#  'NCBIGene:814704': 'T8O11.9|T8O11_9|AT2G01740|Tetratricopeptide repeat (TPR)-like superfamily protein',
#  'NCBIGene:814705': 'MAP70-3|microtubule-associated proteins 70-3|ATMAP70-3|T8O11.8|T8O11_8|microtubule-associated proteins 70-3',
#  'NCBIGene:814706': 'uncharacterized protein|AT2G01755',
#  'NCBIGene:814707': 'response regulator 14|ARR14|T8O11.7|T8O11_7|response regulator 14|RR14',
#  'NCBIGene:814708': 'ATVIT1|T8O11.6|T8O11_6|vacuolar iron transporter 1|VIT1|vacuolar iron transporter 1',
#  'NCBIGene:814709': 'AT2G01780|T8O11.5|T8O11_5|Curculin-like (mannose-binding) lectin family protein',
#  'NCBIGene:814710': 'TRAF-like family protein|T8O11.4|T8O11_4|AT2G01790',
#  'NCBIGene:814711': 'AT2G01800|T8O11.3|T8O11_3|COP1-interacting protein-like protein',
#  'NCBIGene:814712': 'T8O11.2|T8O11_2|RING/FYVE/PHD zinc finger superfamily protein|AT2G01810',
#  'NCBIGene:814713': 'AT2G01820|Leucine-rich repeat protein kinase family protein|T23K3.1|T23K3_1',
#  'NCBIGene:814714': 'AHK4|ARABIDOPSIS HISTIDINE KINASE 4|ATCRE1|CRE1|CYTOKININ RESPONSE 1|T23K3.2|T23K3_2|WOL1|WOODEN LEG|WOODEN LEG 1|WOL|CHASE domain containing histidine kinase protein',
#  'NCBIGene:814716': 'ATXTH27|T23K3.4|T23K3_4|XTH27|XYLOGLUCAN ENDOTRANSGLUCOSYLASE/HYDROLASE 27|endoxyloglucan transferase A3|endoxyloglucan transferase A3|EXGT-A3',
#  'NCBIGene:814717': 'EMBRYO DEFECTIVE 975|T23K3.5|T23K3_5|EMB975|Tetratricopeptide repeat (TPR)-like superfamily protein',
#  'NCBIGene:814718': 'uncharacterized protein|T23K3.6|T23K3_6|AT2G01870',
#  'NCBIGene:814719': 'PAP7|purple acid phosphatase 7|ATPAP7|PURPLE ACID PHOSPHATASE 7|T23K3.7|T23K3_7|purple acid phosphatase 7',
#  'NCBIGene:814720': 'purple acid phosphatase 8|PAP8|ATPAP8|PURPLE ACID PHOSPHATASE 8|T23K3.8|T23K3_8|purple acid phosphatase 8',
#  'NCBIGene:814721': 'DNAse I-like superfamily protein|AT2G01900|T23K3.9|T23K3_9',
#  'NCBIGene:814722': 'ATMAP65-6|MAP65-6|T23K3.10|T23K3_10|Microtubule associated protein (MAP65/ASE1) family protein',
#  'NCBIGene:814723': 'F23I14.1|F23I14_1|ENTH/VHS/GAT family protein|AT2G01920',
#  'NCBIGene:814724': 'ATBPC1|BASIC PENTACYSTEINE1|BBR|F23I14.2|F23I14_2|basic pentacysteine1|basic pentacysteine1|BPC1',
#  'NCBIGene:814725': 'C2H2-like zinc finger protein|SGR5|ARABIDOPSIS THALIANA INDETERMINATE(ID)-DOMAIN 15|ATIDD15|F14H20.1|F14H20_1|IDD15|INDETERMINATE(ID)-DOMAIN 15|SHOOT GRAVITROPISM 5',
#  'NCBIGene:814726': 'BRL2|BRI1-like 2|F14H20.2|F14H20_2|VASCULAR HIGHWAY 1|VH1|BRI1-like 2',
#  'NCBIGene:814727': 'tetraspanin14|F14H20.3|F14H20_3|tetraspanin14|TET14',
#  'NCBIGene:814728': 'F14H20.4|F14H20_4|AT2G01970|Endomembrane protein 70 protein family',
#  'NCBIGene:814729': 'sodium proton exchanger, putative (NHX7) (SOS1)|SOS1|SOS1 (Arabidopsis thaliana)|ARABIDOPSIS NA+/H+ ANTIPORTER 7|ARABIDOPSIS SALT OVERLY SENSITIVE 1|ATNHX7|ATSOS1|F14H20.5|F14H20_5|SALT OVERLY SENSITIVE 1',
#  'NCBIGene:814730': 'AT2G01990|F14H20.6|F14H20_6|XRI1-like protein',
#  'NCBIGene:814731': 'GAD3|F14H20.7|F14H20_7|glutamate decarboxylase 3|glutamate decarboxylase 3',
#  'NCBIGene:814732': 'glutamate decarboxylase 4|F14H20.8|F14H20_8|glutamate decarboxylase 4|GAD4',
#  'NCBIGene:814733': 'AtNPF8.4|AtPTR4|F14H20.9|F14H20_9|NPF8.4|NRT1/ PTR family 8.4|peptide transporter 4|PTR4|Major facilitator superfamily protein',
#  'NCBIGene:814734': 'AT2G02030|F14H20.10|F14H20_10|F-box family protein',
#  'NCBIGene:814735': 'ARABIDOPSIS THALIANA PEPTIDE TRANSPORTER 2|ATPTR2|ATPTR2-B|AtNPF8.3|F14H20.11|F14H20_11|HISTIDINE TRANSPORT PROTEIN|NITRATE TRANSPORTER 1|NPF8.3|NRT1/ PTR family 8.3|NTR1|PTR2-B|peptide transporter 2|PTR2 (Arabidopsis thaliana)|PTR2|peptide transporter 2',
#  'NCBIGene:814736': 'AT2G02050|NADH-ubiquinone oxidoreductase B18 subunit',
#  'NCBIGene:814737': 'Homeodomain-like superfamily protein|AT2G02060|F14H20.13',
#  'NCBIGene:814738': 'AtIDD5|F5O4.16|F5O4_16|indeterminate(ID)-domain 5|IDD5|indeterminate(ID)-domain 5',
#  'NCBIGene:814739': 'IDD4|indeterminate(ID)-domain 4|AtIDD4|F5O4.15|F5O4_15|indeterminate(ID)-domain 4',
#  'NCBIGene:814740': 'CHA19|CHR19|CHROMATIN REMODELING 19|F5O4.14|F5O4_14|SNF2 domain-containing protein / helicase domain-containing protein|ETL1',
#  'NCBIGene:814741': 'F5O4.13|F5O4_13|PDF2.2|low-molecular-weight cysteine-rich 69|LCR69|low-molecular-weight cysteine-rich 69',
#  'NCBIGene:814743': 'Scorpion toxin-like knottin superfamily protein|F5O4.11|F5O4_11|LCR70|LOW-MOLECULAR-WEIGHT CYSTEINE-RICH 70|PDF2.1',
#  'NCBIGene:814744': 'F5O4.10|F5O4_10|PDF2.3|low-molecular-weight cysteine-rich 68|LCR68|low-molecular-weight cysteine-rich 68',
#  'NCBIGene:814745': 'low-molecular-weight cysteine-rich 72|LCR72|F5O4.9|F5O4_9|PDF2.6|low-molecular-weight cysteine-rich 72',
#  'NCBIGene:814746': 'EMB2794|EMBRYO DEFECTIVE 2794|F5O4.8|F5O4_8|Tetratricopeptide repeat (TPR)-like superfamily protein',
#  'NCBIGene:814747': 'CCCH-type zinc finger family protein|AT2G02160|F5O4.7|F5O4_7',
#  'NCBIGene:814748': 'Remorin family protein|AT2G02170|F5O4.6|F5O4_6',
#  'NCBIGene:814749': 'F5O4.5|F5O4_5|tobamovirus multiplication protein 3|TOM3|tobamovirus multiplication protein 3',
#  'NCBIGene:814753': 'PSKR1|ATPSKR1|PHYTOSULFOKIN RECEPTOR|PHYTOSULFOKIN RECEPTOR 1|PSK RECEPTOR 1|phytosulfokin receptor 1|phytosulfokin receptor 1',
#  'NCBIGene:814754': 'phloem protein 2-B1|PP2-B1|AtPP2-B1|T16F16.2|T16F16_2|phloem protein 2-B1',
#  'NCBIGene:814755': 'MEE66|F-box family protein|T16F16.3|maternal effect embryo arrest 66',
#  'NCBIGene:814756': 'phloem protein 2-B2|AtPP2-B2|T16F16.4|T16F16_4|phloem protein 2-B2|PP2-B2',
#  'NCBIGene:814759': 'PP2-B4|phloem protein 2-B4|AtPP2-B4|T16F16.7|T16F16_7|phloem protein 2-B4',
#  'NCBIGene:814760': 'T16F16.8|T16F16_8|Haloacid dehalogenase-like hydrolase (HAD) superfamily protein|AT2G02290',
#  'NCBIGene:814761': 'phloem protein 2-B5|AtPP2-B5|T16F16.9|T16F16_9|phloem protein 2-B5|PP2-B5',
#  'NCBIGene:814762': 'phloem protein 2-B6|AtPP2-B6|T16F16.10|T16F16_10|phloem protein 2-B6|PP2-B6',
#  'NCBIGene:814763': 'AtPP2-B7|T16F16.11|T16F16_11|phloem protein 2-B7|PP2-B7|phloem protein 2-B7',
#  'NCBIGene:814765': 'phloem protein 2-B8|PP2-B8|AtPP2-B8|T16F16.13|T16F16_13|phloem protein 2-B8',
#  'NCBIGene:814766': 'ATPP2-B9|AtPP2-B9|Phloem protein 2-B9|SKP1 interacting partner 3|T16F16.14|T16F16_14|SKIP3|SKP1 interacting partner 3',
#  'NCBIGene:814767': 'PP2-B10|AtPP2-B10|T16F16.15|T16F16_15|phloem protein 2-B10|phloem protein 2-B10',
#  'NCBIGene:814768': 'T16F16.16|T16F16_16|AT2G02370|SNARE associated Golgi protein family',
#  'NCBIGene:814769': 'glutathione S-transferase (class zeta) 2|ATGSTZ2|T16F16.17|T16F16_17|glutathione S-transferase (class zeta) 2|GSTZ2',
#  'NCBIGene:814770': 'ATGSTZ1|AtMAAI|GLUTATHIONE S-TRANSFERASE 18|GST18|MAAI|T16F16.18|T16F16_18|glutathione S-transferase zeta 1|maleylacetoacetate isomerase|GSTZ1 (Arabidopsis thaliana)|GSTZ1|glutathione S-transferase zeta 1',
#  'NCBIGene:814771': 'T16F16.19|T16F16_19|NAD(P)-binding Rossmann-fold superfamily protein|AT2G02400',
#  'NCBIGene:814772': 'AT2G02420|T16F16.20|T16F16_20|yacP-like NYN domain protein|AT2G02410',
#  'NCBIGene:814774': 'uncharacterized protein|AT2G02440|T16F16.23|T16F16_23',
#  'NCBIGene:814775': 'NAC domain containing protein 35|ANAC034|ANAC035|Arabidopsis NAC domain containing protein 34|AtLOV1|LONG VEGETATIVE PHASE 1|NAC domain containing protein 35|NAC035|anac034|LOV1|LOV1 (Arabidopsis thaliana)',
#  'NCBIGene:814776': 'T16F16.26|T16F16_26|alfin-like 6|AL6|alfin-like 6',
#  'NCBIGene:814777': 'STI|AAA-type ATPase family protein|DNA POLYMERASE III-LIKE PROTEIN|GAMMA SUBUNIT|STICHEL|T8K22.22|T8K22_22',
#  'NCBIGene:814778': 'uncharacterized protein|T8K22.21|T8K22_21|AT2G02490',
#  'NCBIGene:814779': 'ISPD|ISPD (Arabidopsis thaliana)|Nucleotide-diphospho-sugar transferases superfamily protein|2-C-METHYL-D-ERYTHRITOL 4-PHOSPHATE CYTIDYLTRANSFERASE|4-DIPHOSPHOCYTIDYL-2C-METHYL-D-ERYTHRITOL SYNTHASE|ATMEPCT|MCT|T8K22.20|T8K22_20',
#  'NCBIGene:814780': 'AT2G02510|T8K22.19|T8K22_19|NADH dehydrogenase (ubiquinone)s',
#  'NCBIGene:814781': 'uncharacterized protein|AT2G02515',
#  'NCBIGene:814782': 'AT2G02520|T8K22.18|T8K22_18|RNA-directed DNA polymerase (reverse transcriptase)-related family protein',
#  'NCBIGene:814784': 'ATHB21|T8K22.16|T8K22_16|ZFHD4|ZHD3|ZINC FINGER HOMEODOMAIN 3|ZINC FINGER HOMEODOMAIN 4|homeobox protein 21|homeobox protein 21|HB21|HB21 (Arabidopsis thaliana)',
#  'NCBIGene:814785': 'T8K22.15|T8K22_15|AT2G02550|PIN domain-like family protein',
#  'NCBIGene:814786': 'ATCAND1|CULLIN-ASSOCIATED AND NEDDYLATION DISSOCIATED 1|ETA2|HEMIVENATA|HVE|T8K22.14|T8K22_14|TIP120|cullin-associated and neddylation dissociated|CAND1 (Arabidopsis thaliana)|CAND1|cullin-associated and neddylation dissociated',
#  'NCBIGene:814787': 'T8K22.13|T8K22_13|nucleic acid binding/RNA binding protein|AT2G02570',
#  'NCBIGene:814788': "''cytochrome P450|T8K22.12|T8K22_12|cytochrome P450|family 71|polypeptide 9|polypeptide 9''|subfamily B|CYP71B9|cytochrome P450, family 71, subfamily B, polypeptide 9",
#  'NCBIGene:814789': 'small multi-drug export protein|AT2G02590|T8K22.11|T8K22_11',
#  'NCBIGene:814790': 'AT2G02610|Cysteine/Histidine-rich C1 domain family protein|T8K22.9|T8K22_9',
#  'NCBIGene:814791': 'Cysteine/Histidine-rich C1 domain family protein|T8K22.8|T8K22_8|AT2G02620',
#  'NCBIGene:814792': 'AT2G02630|Cysteine/Histidine-rich C1 domain family protein|T8K22.7|T8K22_7',
#  'NCBIGene:814793': 'AT2G02640|Cysteine/Histidine-rich C1 domain family protein|T8K22.6|T8K22_6',
#  'NCBIGene:814794': 'T8K22.5|T8K22_5|AT2G02650|Ribonuclease H-like superfamily protein',
#  'NCBIGene:814795': 'T8K22.4|T8K22_4|F-box associated ubiquitination effector family protein|AT2G02660',
#  'NCBIGene:814797': 'Cysteine/Histidine-rich C1 domain family protein|AT2G02680|T8K22.2|T8K22_2',
#  'NCBIGene:814798': 'AT2G02690|Cysteine/Histidine-rich C1 domain family protein',
#  'NCBIGene:814799': 'AT2G02700|T20F6.16|T20F6_16|Cysteine/Histidine-rich C1 domain family protein',
#  'NCBIGene:814800': 'PLPB|PAS/LOV protein B|PAS/LOV PROTEIN|PAS/LOV PROTEIN A|PAS/LOV PROTEIN C|PAS/LOV protein B|PLP|PLPA|PLPC|T20F6.15|T20F6_15',
#  'NCBIGene:814801': 'Pectate lyase family protein|AT2G02720|T20F6.14|T20F6_14',
#  'NCBIGene:814802': 'AT2G02730|GRIP/coiled-coil protein, putative (DUF1664)|T20F6.13|T20F6_13',
#  'NCBIGene:814803': 'ssDNA-binding transcriptional regulator|WHY3|A. THALIANA WHIRLY 3|ATWHY3|PLASTID TRANSCRIPTIONALLY ACTIVE11|PTAC11|T20F6.12|T20F6_12|WHIRLY 3',
#  'NCBIGene:814804': 'T20F6.11|T20F6_11|Pentatricopeptide repeat (PPR) superfamily protein|AT2G02750',
#  'NCBIGene:814805': 'ubiquiting-conjugating enzyme 2|UBC2|ATUBC2|T20F6.10|T20F6_10|ubiquitin-conjugating enzyme 2|ubiquiting-conjugating enzyme 2',
#  'NCBIGene:814806': 'AT2G02765|L-aminoadipate-semialdehyde dehydrogenase-phosphopantetheinyl transferase',
#  'NCBIGene:814807': 'Leucine-rich repeat protein kinase family protein|AT2G02780|T20F6.8|T20F6_8',
#  'NCBIGene:814808': 'IQ-domain 29|IQD29 (Arabidopsis thaliana)|IQ-domain 29|T20F6.7|T20F6_7|IQD29',
#  'NCBIGene:814810': 'APK2B|protein kinase 2B|Kin2|PROTEIN KINASE 2B|T20F6.6|T20F6_6|kinase 2|protein kinase 2B',
#  'NCBIGene:814811': 'UDP-galactose transporter 1|UTR1|ATUTR1|T20F6.5|T20F6_5|UDP-GALACTOSE TRANSPORTER 1|UDP-galactose transporter 1|UTR1 (Arabidopsis thaliana)',
#  'NCBIGene:814812': 'MYB88|AtMYB88|T20F6.4|T20F6_4|myb domain protein 88|myb domain protein 88',
#  'NCBIGene:814814': 'nucleic acid/zinc ion-binding protein|AT2G02835',
#  'NCBIGene:814815': 'AT2G02840|nucleic acid/zinc ion-binding protein|T17M13.1',
#  'NCBIGene:814816': 'ARPN|T17M13.2|T17M13_2|plantacyanin|plantacyanin',
#  'NCBIGene:814817': 'SUT2 (Arabidopsis thaliana)|ARABIDOPSIS THALIANA SUCROSE TRANSPORTER 3|ATSUC3|ATSUT2|SUC3|SUCROSE TRANSPORTER 3|T17M13.3|T17M13_3|sucrose transporter 2|SUT2|sucrose transporter 2',
#  'NCBIGene:814818': 'Galactose oxidase/kelch repeat superfamily protein|T17M13.4|T17M13_4|AT2G02870',
#  'NCBIGene:814819': 'AT2G02880|T17M13.5|T17M13_5|mucin-like protein',
#  'NCBIGene:814820': 'F-box family protein|AT2G02890|T17M13.6|T17M13_6',
#  'NCBIGene:814821': 'AT2G02910|T17M13.8|T17M13_8|transmembrane protein (DUF616)',
#  'NCBIGene:814822': 'GSTF3|glutathione S-transferase F3|ATGSTF3|GLUTATHIONE S-TRANSFERASE 16|GST16|T17M13.10|T17M13_10|glutathione S-transferase F3',
#  'NCBIGene:814823': 'PHYTOCHROME KINASE SUBSTRATE 1|T17M13.12|T17M13_12|phytochrome kinase substrate 1|phytochrome kinase substrate 1|PKS1',
#  'NCBIGene:814824': 'MEE12|maternal effect embryo arrest 12',
#  'NCBIGene:814825': 'AT2G02960|T17M13.13|T17M13_13|RING/FYVE/PHD zinc finger superfamily protein',
#  'NCBIGene:814826': 'GDA1/CD39 nucleoside phosphatase family protein|APY6|AtAPY6|T17M13.14|T17M13_14|apyrase 6|AT2G02970',
#  'NCBIGene:814827': 'Pentatricopeptide repeat (PPR) superfamily protein|ORGANELLE TRANSCRIPT PROCESSING 85|T17M13.15|T17M13_15|OTP85',
#  'NCBIGene:814828': 'ribonuclease 1|RNS1|ATRNS1|RIBONUCLEASE 1|T17M13.16|T17M13_16|ribonuclease 1',
#  'NCBIGene:814829': 'T17M13.17|T17M13_17|RING/U-box superfamily protein|AT2G03000',
#  'NCBIGene:814830': 'AT2G03010|T17M13.18|T17M13_18|hypothetical protein (DUF577)',
#  'NCBIGene:814831': 'Heat shock protein HSP20/alpha crystallin family|AT2G03020|T17M13.19|T17M13_19',
#  'NCBIGene:814832': 'T17M13.20|T17M13_20|Toll-Interleukin-Resistance (TIR) domain family protein|AT2G03030',
#  'NCBIGene:814833': 'AT2G03040|T17M13.21|T17M13_21|emp24/gp25L/p24 family/GOLD family protein',
#  'NCBIGene:814834': 'EMB93|Mitochondrial transcription termination factor family protein|EMBRYO DEFECTIVE 93|SINGLET OXYGEN-LINKED DEATH ACTIVATOR 10|SOLDAT10|T17M13.22|T17M13_22',
#  'NCBIGene:814835': 'AGAMOUS-like 30|AGL30|AGAMOUS-like 30|T17M13.23|T17M13_23',
#  'NCBIGene:814836': 'mediator subunit 8|T17M13.24|T17M13_24|mediator subunit 8|MED8|MED8 (Arabidopsis thaliana)',
#  'NCBIGene:814838': 'expansin A15|ATEXP15|ATEXPA15|ATHEXP ALPHA 1.3|EXP15|EXPANSIN 15|T17M13.26|T17M13_26|expansin A15|EXPA15',
#  'NCBIGene:814840': 'T18E12.22|T18E12_22|putative RNA-binding protein|AT2G03110',
#  'NCBIGene:814841': 'ATSPP|T18E12.21|T18E12_21|signal peptide peptidase|signal peptide peptidase|SPP|SPP (Arabidopsis thaliana)',
#  'NCBIGene:814842': 'AT2G03130|Ribosomal protein L12/ ATP-dependent Clp protease adaptor protein ClpS family protein|T18E12.20|T18E12_20',
#  'NCBIGene:814843': 'T18E12.19|T18E12_19|alpha/beta-Hydrolases superfamily protein|AT2G03140',
#  'NCBIGene:814844': 'RSA1|SHORT ROOT IN SALT MEDIUM 1|T18E12.18|T18E12_18|embryo defective 1579|ATP/GTP-binding protein family|emb1579',
#  'NCBIGene:814845': 'SKP1-like 19|SK19|ASK19|SKP1-like 19|T18E12.17|T18E12_17',
#  'NCBIGene:814846': 'ASK14|SKP1-like 14|T18E12.16|T18E12_16|SKP1-like 14|SK14',
#  'NCBIGene:814847': 'uncharacterized protein|T18E12.15|T18E12_15|AT2G03180',
#  'NCBIGene:814848': 'ASK16|SKP1-like 16|T18E12.14|T18E12_14|SKP1-like 16|SK16',
#  'NCBIGene:814849': 'Eukaryotic aspartyl protease family protein|AT2G03200|T18E12.13|T18E12_13',
#  'NCBIGene:814850': 'FUT2|fucosyltransferase 2|FUT2 (Arabidopsis thaliana)|ATFUT2|T18E12.12|T18E12_12|fucosyltransferase 2',
#  'NCBIGene:814851': 'FT1|2)-FUCOSYLTRANSFERASE|A-(1|ARABIDOPSIS THALIANA FUCOSYLTRANSFERASE 1|ATFT1|ATFUT1|FUT1|MUR2|MURUS 2|T18E12.11|T18E12_11|XYLOGLUCAN FUCOSYLTRANSFERASE|fucosyltransferase 1|fucosyltransferase 1',
#  'NCBIGene:814852': 'T18E12.10|T18E12_10|GCK domain-containing protein|AT2G03230',
#  'NCBIGene:814853': 'T18E12.9|T18E12_9|EXS (ERD1/XPR1/SYG1) family protein|AT2G03240',
#  'NCBIGene:814854': 'EXS (ERD1/XPR1/SYG1) family protein|AT2G03250|T18E12.8|T18E12_8',
#  'NCBIGene:814855': 'EXS (ERD1/XPR1/SYG1) family protein|AT2G03260|T18E12.7|T18E12_7',
#  'NCBIGene:814856': 'DNA-binding protein|T4M8.30|T4M8_30|AT2G03270',
#  'NCBIGene:814857': 'AT2G03280|T4M8.29|T4M8_29|O-fucosyltransferase family protein',
#  'NCBIGene:814858': 'AT2G03290|emp24/gp25L/p24 family/GOLD family protein|T4M8.28|T4M8_28',
#  'NCBIGene:814859': 'Toll-Interleukin-Resistance (TIR) domain family protein|T4M8.27|T4M8_27|AT2G03300',
#  'NCBIGene:814860': 'uncharacterized protein|T4M8.26|T4M8_26|AT2G03310',
#  'NCBIGene:814861': 'uncharacterized protein|T4M8.25|T4M8_25|AT2G03320',
#  'NCBIGene:814862': 'uncharacterized protein|AT2G03330|T4M8.24|T4M8_24',
#  'NCBIGene:814863': 'WRKY3|WRKY3 (Arabidopsis thaliana)|WRKY DNA-binding protein 3|T4M8.23|T4M8_23|WRKY DNA-binding protein 3',
#  'NCBIGene:814864': 'T4M8.22|T4M8_22|DUF538 family protein (Protein of unknown function, DUF538)|AT2G03350',
#  'NCBIGene:814865': 'T4M8.21|T4M8_21|Glycosyltransferase family 61 protein|AT2G03360',
#  'NCBIGene:814866': 'T4M8.20|T4M8_20|AT2G03370|O-linked-mannose beta-1,4-N-acetylglucosaminyltransferase-like protein',
#  'NCBIGene:814867': 'AT2G03380|T4M8.19|T4M8_19|Pentatricopeptide repeat (PPR) superfamily protein',
#  'NCBIGene:814868': 'AT2G03390|uvrB/uvrC motif-containing protein|T4M8.18|T4M8_18',
#  'NCBIGene:814870': 'AT2G03410|T4M8.16|T4M8_16|Mo25 family protein',
#  'NCBIGene:814871': 'uncharacterized protein|T4M8.15|T4M8_15|AT2G03420',
#  'NCBIGene:814872': 'Ankyrin repeat family protein|T4M8.14|T4M8_14|AT2G03430',
#  'NCBIGene:814873': 'NRP1 (Arabidopsis thaliana)|ATNRP1|T4M8.13|T4M8_13|nodulin-related protein 1|NRP1|nodulin-related protein 1',
#  'NCBIGene:814874': 'ATPAP9|PURPLE ACID PHOSPHATASE 9|T4M8.12|T4M8_12|purple acid phosphatase 9|PAP9|purple acid phosphatase 9',
#  'NCBIGene:814875': 'Galactose oxidase/kelch repeat superfamily protein|AT2G03460|T4M8.11|T4M8_11',
#  'NCBIGene:814876': 'T4M8.10|T4M8_10|ELM2 domain-containing protein|AT2G03470',
#  'NCBIGene:814877': 'QUASIMODO2 LIKE 2|QUASIMODO2 LIKE 2|T4M8.9|T4M8_9|QUL2',
#  'NCBIGene:814878': 'Homeodomain-like superfamily protein|EARLY FLOWERING MYB PROTEIN|EFM|T4M8.7|T4M8_7|AT2G03500',
#  'NCBIGene:814879': 'AT2G03505|Carbohydrate-binding X8 domain superfamily protein',
#  'NCBIGene:814880': 'SPFH/Band 7/PHB domain-containing membrane-associated protein family|AT2G03510|T4M8.5|T4M8_5',
#  'NCBIGene:814881': 'UPS4|ureide permease 4|ATUPS4|T4M8.4|T4M8_4|ureide permease 4',
#  'NCBIGene:814882': 'ureide permease 2|UPS2 (Arabidopsis thaliana)|UPS2|ARABIDOPSIS THALIANA UREIDE PERMEASE 2|ATUPS2|T4M8.3|T4M8_3|ureide permease 2',
#  'NCBIGene:814883': 'AT2G03540|T4M8.2|T4M8_2',
#  'NCBIGene:814884': 'alpha/beta-Hydrolases superfamily protein|T4M8.1|T4M8_1|AT2G03550',
#  'NCBIGene:814885': 'AT2G03560|F19B11.1|F19B11_1|F-box only protein (DUF295)',
#  'NCBIGene:814886': 'AT2G03570|uncharacterized protein|F19B11.2|F19B11_2',
#  'NCBIGene:814887': 'F19B11.3|F19B11_3|F-box family protein-like protein|AT2G03580',
#  'NCBIGene:814888': 'ureide permease 1|ATUPS1|F19B11.4|F19B11_4|ureide permease 1|UPS1|UPS1 (Arabidopsis thaliana)',
#  'NCBIGene:814889': 'UPS3 (Arabidopsis thaliana)|ureide permease 3|ATUPS3|F19B11.5|F19B11_5|ureide permease 3|UPS3',
#  'NCBIGene:814890': 'F19B11.6|F19B11_6|F-box family protein|AT2G03610',
#  'NCBIGene:814891': 'MGT3|AtMGT3|AtMRS2-5|F19B11.7|F19B11_7|MRS2-5|magnesium transporter 3|magnesium transporter 3',
#  'NCBIGene:814892': 'suppressor SRP40-like protein|AT2G03630|F19B11.8|F19B11_8',
#  'NCBIGene:814893': 'Nuclear transport factor 2 (NTF2) family protein with RNA binding (RRM-RBD-RNP motifs) domain-containing protein|AT2G03640|F19B11.9|F19B11_9',
#  'NCBIGene:814895': 'cell division cycle 48B|CDC48B|F19B11.12|F19B11_12|T4D2.160|cell division cycle 48B',
#  'NCBIGene:814896': 'SPR1 (Arabidopsis thaliana)|F19B11.13|F19B11_13|SKU6|SPIRAL1|spiral1|SPR1',
#  'NCBIGene:814897': 'coenzyme Q biosynthesis Coq4 family protein / ubiquinone biosynthesis Coq4 family protein|F19B11.14|F19B11_14|AT2G03690',
#  'NCBIGene:814898': 'K-box region and MADS-box transcription factor family protein|SEP4|AGAMOUS-like 3|AGL3|F19B11.16|F19B11_16|MADS BOX PROTEIN|SEPALLATA 4',
#  'NCBIGene:814899': 'MRH6|F19B11.17|F19B11_17|morphogenesis of root hair 6|Adenine nucleotide alpha hydrolases-like superfamily protein',
#  'NCBIGene:814900': 'ACR5|ACT domain repeat 5|F19B11.18|F19B11_18|ACT domain repeat 5',
#  'NCBIGene:814901': 'AT2G03740|F19B11.19|F19B11_19|late embryogenesis abundant domain-containing protein / LEA domain-containing protein',
#  'NCBIGene:814902': 'F19B11.20|F19B11_20|AT2G03750|P-loop containing nucleoside triphosphate hydrolases superfamily protein',
#  'NCBIGene:814903': 'sulfotransferase 12|ARABIDOPSIS THALIANA SULFOTRANSFERASE 1|ATST1|AtSOT1|AtSOT12|AtSULT202A1|RAR047|SOT1|ST|ST1|SULFOTRANSFERASE|SULFOTRANSFERASE 1|SULFURTRANSFERASE|SULT202A1|sulfotransferase 202A1|sulphotransferase 1|sulphotransferase 12|SOT12',
#  'NCBIGene:814904': 'AtSULT202E1|F19B11.22|F19B11_22|SULT202E1|sulfotransferase 202E1|AT2G03770|P-loop containing nucleoside triphosphate hydrolases superfamily protein',
#  'NCBIGene:814905': 'Translin family protein|F19B11.23|F19B11_23|AT2G03780',
#  'NCBIGene:814906': 'F19B11.25|F19B11_25|GEKO1|D-aminoacyl-tRNA deacylase|GEK1',
#  'NCBIGene:814907': 'AT2G03810|18S pre-ribosomal assembly protein gar2-like protein|T18C20.1|T18C20_1',
#  'NCBIGene:814908': 'NMD3|NMD3 (Arabidopsis thaliana)|AtNMD3|Nonsense-Mediated mRNA Decay 3|T18C20.2|T18C20_2|nonsense-mediated mRNA decay NMD3 family protein',
#  'NCBIGene:814909': 'root meristem growth factor|RGF8|GLV6|GOLVEN 6|T18C20.3|T18C20_3|root meristem growth factor 8',
#  'NCBIGene:814910': 'T18C20.4|T18C20_4|tetraspanin13|tetraspanin13|TET13',
#  'NCBIGene:814911': 'Late embryogenesis abundant protein (LEA) family protein|AT2G03850|T18C20.5|T18C20_5',
#  'NCBIGene:814913': 'EMB2816|Small nuclear ribonucleoprotein family protein|EMBRYO DEFECTIVE 2816|LSM7|SM-like 7|T18C20.7|T18C20_7',
#  'NCBIGene:814914': 'T18C20.8|T18C20_8|required for efficiency of mitochondrial editing 1|REME1|Pentatricopeptide repeat (PPR) superfamily protein',
#  'NCBIGene:814915': 'ATPI4K GAMMA 7|T18C20.9|T18C20_9|UBDK GAMMA 7|UBIQUITIN-LIKE DOMAIN KINASE GAMMA 7|phosphoinositide 4-kinase gamma 7|phosphoinositide 4-kinase gamma 7|PI4K GAMMA 7',
#  'NCBIGene:814919': 'AT2G03930|hypothetical protein (DUF239)',
#  'NCBIGene:814924': 'F3C11.9|F3C11_9|GDSL-like Lipase/Acylhydrolase superfamily protein|AT2G03980',
#  'NCBIGene:814926': 'F3C11.11|F3C11_11|AT2G04000',
#  'NCBIGene:814928': 'GDSL-like Lipase/Acylhydrolase superfamily protein|F3C11.13|F3C11_13|AT2G04020',
#  'NCBIGene:814929': 'RGF3|root meristem growth factor|F3C11.1|F3C11_1|GLV7|GOLVEN 7|root meristem growth factor 3',
#  'NCBIGene:814930': 'CR88|Chaperone protein htpG family protein|AtHsp90.5|AtHsp90C|EMB1956|EMBRYO DEFECTIVE 1956|F3C11.14|F3C11_14|HEAT SHOCK PROTEIN 88.1|HEAT SHOCK PROTEIN 90.5|HSP90.5|Hsp88.1',
#  'NCBIGene:814931': 'ZIP7|F3L12.21|zinc transporter 7 precursor|zinc transporter 7 precursor',
#  'NCBIGene:814933': 'AT2G04037|ECA1 gametogenesis family protein (DUF784)',
#  'NCBIGene:814934': 'AT2G04041|ECA1 gametogenesis family protein (DUF784)',
#  'NCBIGene:814936': 'AtbZIP48|F3L12.14|F3L12_14|basic leucine-zipper 48|basic leucine-zipper 48|bZIP48',
#  'NCBIGene:814937': 'F3L12.11|F3L12_11|DUF2996 family protein|AT2G04039',
#  'NCBIGene:814938': 'DTX1|DTX1 (Arabidopsis thaliana)|MATE efflux family protein|ATDTX1|F3L12.13|F3L12_13|TX1|detoxification 1',
#  'NCBIGene:814939': 'F3L12.12|F3L12_12|AT2G04050|MATE efflux family protein',
#  'NCBIGene:814940': 'F3L12.16|F3L12_16|glycosyl hydrolase family 35 protein|AT2G04060',
#  'NCBIGene:814941': 'glycine-rich protein|AT2G04063|F3L12.1|F3L12_1',
#  'NCBIGene:814942': 'AT2G04066|F3L12.17|F3L12_17|MATE efflux family protein',
#  'NCBIGene:814943': 'F3L12.10|F3L12_10|MATE efflux family protein|AT2G04070',
#  'NCBIGene:814944': 'AT2G04080|F3L12.9|F3L12_9|MATE efflux family protein',
#  'NCBIGene:814945': 'AT2G04090|F3L12.8|F3L12_8|MATE efflux family protein',
#  'NCBIGene:814946': 'F3L12.7|F3L12_7|AT2G04100|MATE efflux family protein',
#  'NCBIGene:814950': 'AT2G04135',
#  'NCBIGene:814953': 'Subtilisin-like serine endopeptidase family protein|AIR3|AUXIN-INDUCED IN ROOT CULTURES 3',
#  'NCBIGene:814954': 'TRAF-like family protein|AT2G04170|T16B23.2|T16B23_2',
#  'NCBIGene:814956': 'T16B23.4|T16B23_4|TRAF-like family protein|AT2G04190',
#  'NCBIGene:814959': 'AT2G04220|T23O15.16|DUF868 family protein (DUF868)',
#  'NCBIGene:814960': 'T23O15.15|T23O15_15|FBD, F-box and Leucine Rich Repeat domains containing protein|AT2G04230',
#  'NCBIGene:814961': 'uncharacterized protein|AT2G04235',
#  'NCBIGene:814962': 'XERICO|RING/U-box superfamily protein',
#  'NCBIGene:814965': 'RNAse E/G-like|RNE|RNase E|T23O15.10|T23O15_10|RNAse E/G-like protein|RNEE/G',
#  'NCBIGene:814966': 'calcium ion-binding protein|AT2G04280|T23O15.9|T23O15_9',
#  'NCBIGene:814968': 'T23O15.8|T23O15_8|AT2G04300|Leucine-rich repeat protein kinase family protein',
#  'NCBIGene:814969': 'AT2G04305|Magnesium transporter CorA-like family protein|T23O15.7|T23O15_7',
#  'NCBIGene:814971': 'T23O15.5|T23O15_5|AT2G04320',
#  'NCBIGene:814972': 'AT2G04330|T23O15.4',
#  'NCBIGene:814973': 'cytoplasmic dynein 2 light intermediate chain|AT2G04340|T23O15.19',
#  'NCBIGene:814974': 'LACS8|T23O15.3|T23O15_3|long-chain acyl-CoA synthetase 8|AMP-dependent synthetase and ligase family protein',
#  'NCBIGene:814975': 'uncharacterized protein|T23O15.18|AT2G04360',
#  'NCBIGene:814977': 'uncharacterized protein|T1O3.21|T1O3_21|AT2G04380',
#  'NCBIGene:814978': 'Ribosomal S17 family protein|AT2G04390|T1O3.20|T1O3_20',
#  'NCBIGene:814979': 'AT2G04395|Nucleic acid-binding, OB-fold-like protein',
#  'NCBIGene:814980': 'AT2G04400|Aldolase-type TIM barrel family protein',
#  'NCBIGene:814981': 'RPM1-interacting protein 4 (RIN4) family protein|T1O3.18|T1O3_18|AT2G04410',
#  'NCBIGene:814982': 'T1O3.17|T1O3_17|AT2G04420|Polynucleotidyl transferase, ribonuclease H-like superfamily protein',
#  'NCBIGene:814983': 'NUDT5 (Arabidopsis thaliana)|nudix hydrolase homolog 5|T1O3.16|T1O3_16|atnudt5|nudix hydrolase homolog 5|NUDT5',
#  'NCBIGene:814984': 'MutT/nudix family protein|AT2G04440|T1O3.15|T1O3_15',
#  'NCBIGene:814985': 'NUDT6 (Arabidopsis thaliana)|nudix hydrolase homolog 6|ATNUDT6|ATNUDX6|Arabidopsis thaliana nucleoside diphosphate linked to  some moiety X 6|Arabidopsis thaliana nucleoside diphosphate linked to some moiety X 6|NUDX6|T1O3.14|T1O3_14|nucleoside diphosphates linked to  some moiety X 6|nucleoside diphosphates linked to some moiety X 6|nudix hydrolase homolog 6|NUDT6',
#  'NCBIGene:814986': 'AT2G04460|T1O3.13|T1O3_13',
#  'NCBIGene:814988': 'AT2G04480|uncharacterized protein|T1O3.11|T1O3_11',
#  'NCBIGene:814990': 'uncharacterized protein|AT2G04495',
#  'NCBIGene:814991': 'AT2G04500|Cysteine/Histidine-rich C1 domain family protein|T1O3.9|T1O3_9',
#  'NCBIGene:814993': 'uncharacterized protein|AT2G04515',
#  'NCBIGene:814994': 'T1O3.7|T1O3_7|Nucleic acid-binding, OB-fold-like protein|AT2G04520',
#  'NCBIGene:814995': 'T1O3.6|T1O3_6|TRNASE Z 2|TRZ2|Metallo-hydrolase/oxidoreductase superfamily protein|CPZ (Arabidopsis thaliana)|CPZ',
#  'NCBIGene:814996': 'T1O3.5|T1O3_5|AT2G04540|Beta-ketoacyl synthase',
#  'NCBIGene:814997': 'indole-3-butyric acid response 5|DSPTP1E|DUAL SPECIFICITY PROTEIN PHOSPHATASE 1E|T1O3.4|T1O3_4|indole-3-butyric acid response 5|IBR5',
#  'NCBIGene:814998': 'AtLpxB|T1O3.3|T1O3_3|lipid X B|transferases, transferring glycosyl groups|LpxB',
#  'NCBIGene:814999': 'GDSL-like Lipase/Acylhydrolase superfamily protein|T1O3.2|T1O3_2|AT2G04570',
#  'NCBIGene:815000': 'AT2G04580|T1O3.1|T1O3_1',
#  'NCBIGene:815002': 'F7D11.4|F7D11_4|AT2G04600',
#  'NCBIGene:815004': 'AT2G04620|F7D11.2|F7D11_2|zinc transporter-like protein',
#  'NCBIGene:815006': 'RNA polymerase Rpb6|F28I8.33|F28I8_33|NRPE6B|NRPB6B',
#  'NCBIGene:815007': 'ADP-glucose pyrophosphorylase family protein|AT2G04650|F28I8.31|F28I8_31',
#  'NCBIGene:815008': 'APC2 (Arabidopsis thaliana)|F28I8.30|F28I8_30|anaphase-promoting complex/cyclosome 2|anaphase-promoting complex/cyclosome 2|APC2',
#  'NCBIGene:815010': 'uncharacterized protein|AT2G04675',
#  'NCBIGene:815011': 'Cysteine/Histidine-rich C1 domain family protein|F28I8.28|F28I8_28|AT2G04680',
#  'NCBIGene:815012': "F28I8.27|F28I8_27|Pyridoxamine 5'-phosphate oxidase family protein|AT2G04690",
#  'NCBIGene:815013': 'ferredoxin thioredoxin reductase catalytic beta chain family protein|F28I8.26|F28I8_26|AT2G04700',
#  'NCBIGene:815017': 'ankyrin repeat family protein|AT2G04740|F28I8.22|F28I8_22',
#  'NCBIGene:815018': 'AT2G04750|Actin binding Calponin homology (CH) domain-containing protein|F28I8.21|F28I8_21',
#  'NCBIGene:815021': 'FASCICLIN-like arabinoogalactan 7|FLA7|F28I8.18|F28I8_18|FASCICLIN-like arabinoogalactan 7',
#  'NCBIGene:815022': 'PTB domain engulfment adapter|AT2G04790|F28I8.17|F28I8_17',
#  'NCBIGene:815023': 'uncharacterized protein|AT2G04795',
#  'NCBIGene:815024': 'uncharacterized protein|AT2G04800|F28I8.16|F28I8_16',
#  'NCBIGene:815025': 'AT2G04810|F28I8.15|F28I8_15|F-box only protein (DUF295)',
#  'NCBIGene:815027': 'F-box only protein (DUF295)|F28I8.13|F28I8_13|AT2G04830',
#  'NCBIGene:815028': 'F-box only protein (DUF295)|F28I8.12|F28I8_12|AT2G04840',
#  'NCBIGene:815029': 'threonyl-tRNA synthetase, putative / threonine-tRNA ligase|EMBRYO DEFECTIVE 2761|EMB2761',
#  'NCBIGene:815030': 'Acyl-CoA N-acyltransferases (NAT) superfamily protein|AT2G04845',
#  'NCBIGene:815031': 'Auxin-responsive family protein|F28I8.9|F28I8_9|AT2G04850',
#  'NCBIGene:815032': 'AT2G04860|Tetratricopeptide repeat (TPR)-like superfamily protein|F28I8.8|F28I8_8',
#  'NCBIGene:815033': 'AT2G04865|MAIL2|MAIN-LIKE 2|Aminotransferase-like, plant mobile domain family protein',
#  'NCBIGene:815034': 'uncharacterized protein|AT2G04870|F28I8.6|F28I8_6',
#  'NCBIGene:815035': 'ZAP1 (Arabidopsis thaliana)|ZAP1|zinc-dependent activator protein-1|ATWRKY1|F1O13.1|F1O13_1|WRKY1|zinc-dependent activator protein-1',
#  'NCBIGene:815036': 'SCARECROW-like 21|SCL21|F1O13.2|F1O13_2|SCARECROW-like 21',
#  'NCBIGene:815037': 'uncharacterized protein|F1O13.3|AT2G04900',
#  'NCBIGene:815038': 'AT2G04910|F1O13.4|F1O13_4|Carbohydrate-binding X8 domain superfamily protein',
#  'NCBIGene:815039': 'F1O13.5|F1O13_5|AT2G04920|F-box and associated interaction domains-containing protein',
#  'NCBIGene:815040': 'Haloacid dehalogenase-like hydrolase (HAD) superfamily protein|F1O13.6|F1O13_6|AT2G04930',
#  'NCBIGene:815041': 'scramblase-like protein|AT2G04940|F1O13.7|F1O13_7',
#  'NCBIGene:815044': 'F1O13.10|F1O13_10|AT2G04970',
#  'NCBIGene:815047': 'AT2G05000|F1O13.13|F1O13_13',
#  'NCBIGene:815051': 'F1O13.16|F1O13_16|AT2G05030',
#  'NCBIGene:815054': 'Protein kinase superfamily protein|AT2G05060|F1O13.19|F1O13_19',
#  'NCBIGene:815055': 'F1O13.20|F1O13_20|LHCB2|LIGHT-HARVESTING CHLOROPHYLL B-BINDING 2|photosystem II light harvesting complex gene 2.2|LHCB2.2|photosystem II light harvesting complex protein 2.2',
#  'NCBIGene:815056': 'F1O13.21|F1O13_21|AT2G05080',
#  'NCBIGene:815057': 'F1O13.22|F1O13_22|AT2G05090',
#  'NCBIGene:815058': 'LHCB2.1|photosystem II light harvesting complex protein 2.1|F15L11.2|F15L11_2|LHCB2|LIGHT-HARVESTING CHLOROPHYLL B-BINDING 2|photosystem II light harvesting complex gene 2.1',
#  'NCBIGene:815060': 'F5G3.2|F5G3_2|AT2G05120|Nucleoporin, Nup133/Nup155-like protein',
#  'NCBIGene:815062': 'phosphoribosylaminoimidazole carboxylase family protein / AIR carboxylase family protein|AT2G05140|F5G3.4|F5G3_4',
#  'NCBIGene:815064': 'AT2G05160|CCCH-type zinc fingerfamily protein with RNA-binding domain-containing protein|F5G3.6|F5G3_6',
#  'NCBIGene:815065': 'VPS11|ATVPS11|F5G3.7|F5G3_7|vacuolar protein sorting 11|VPS11 (Arabidopsis thaliana)|vacuolar protein sorting 11',
#  'NCBIGene:815066': "CYP705A6|cytochrome P450, family 705, subfamily A, polypeptide 6|''cytochrome P450|F5G3.8|F5G3_8|cytochrome P450|family 705|polypeptide 6|polypeptide 6''|subfamily A",
#  'NCBIGene:815069': 'Nucleic acid-binding, OB-fold-like protein|ATPOT1|F5G3.11|F5G3_11|Protection of Telomeres 1a|AtPOT1a',
#  'NCBIGene:815070': 'Ribosomal S17 family protein|F5G3.12|F5G3_12|AT2G05220',
#  'NCBIGene:815071': 'DNAJ heat shock N-terminal domain-containing protein|AT2G05230|F5G3.13|F5G3_13',
#  'NCBIGene:815073': 'DNAJ heat shock N-terminal domain-containing protein|AT2G05250|F5G3.15',
#  'NCBIGene:815074': 'alpha/beta-Hydrolases superfamily protein|AT2G05260|F5G3.16|F5G3_16',
#  'NCBIGene:815075': 'uncharacterized protein|F5G3.17|F5G3_17|AT2G05270',
#  'NCBIGene:815077': 'AT2G05290|F5G3.19|F5G3_19',
#  'NCBIGene:815078': 'F5G3.20|F5G3_20|AT2G05300',
#  'NCBIGene:815079': 'uncharacterized protein|AT2G05310|F5G3.21|F5G3_21',
#  'NCBIGene:815080': 'AT2G05320|beta-1,2-N-acetylglucosaminyltransferase II|F5G3.22|F5G3_22',
#  'NCBIGene:815081': 'BTB/POZ domain-containing protein|F5G3.23|F5G3_23|AT2G05330',
#  'NCBIGene:815083': 'uncharacterized protein|F16J10.10|F16J10_10|AT2G05350',
#  'NCBIGene:815084': 'F16J10.9|F16J10_9|AT2G05360|F-box associated ubiquitination effector family protein',
#  'NCBIGene:815085': 'AT2G05370|F16J10.8|F16J10_8|RNA-dependent RNA polymerase-like protein',
#  'NCBIGene:815086': 'glycine-rich protein 3 short isoform|F16J10.7|F16J10_7|glycine-rich protein 3 short isoform|GRP3S',
#  'NCBIGene:815088': 'AT2G05400|Ubiquitin-specific protease family C19-related protein|F16J10.5|F16J10_5',
#  'NCBIGene:815089': 'MATH domain/coiled-coil protein|F16J10.4|F16J10_4|AT2G05410',
#  'NCBIGene:815090': 'TRAF-like family protein|F16J10.3|F16J10_3|AT2G05420',
#  'NCBIGene:815091': 'F16J10.2|F16J10_2|AT2G05430|Ubiquitin-specific protease family C19-related protein',
#  'NCBIGene:815093': 'GLYCINE RICH PROTEIN 9|ARABIDOPSIS GLYCINE RICH PROTEIN 9|ATGRP9|GLYCINE RICH PROTEIN 9|T20G20.21|T20G20_21|GRP9',
#  'NCBIGene:815097': 'AT2G05480|T20G20.17|T20G20_17',
#  'NCBIGene:815100': 'Glycine-rich protein family|T20G20.14|T20G20_14|AT2G05510',
#  'NCBIGene:815101': 'GRP-3|glycine-rich protein 3|ARABIDOPSIS GLYCINE RICH PROTEIN 3|ATGRP-3|ATGRP3|GLYCINE-RICH PROTEIN 3|GRP3|T20G20.13|T20G20_13|glycine-rich protein 3',
#  'NCBIGene:815102': 'Glycine-rich protein family|T20G20.12|T20G20_12|AT2G05530',
#  'NCBIGene:815103': 'AT2G05540|Glycine-rich protein family|T20G20.11|T20G20_11',
#  'NCBIGene:815108': 'T20G20.6|T20G20_6|TLD-domain containing nucleolar protein|AT2G05590',
#  'NCBIGene:815109': 'AT2G05600|F-box associated ubiquitination effector family protein|T20G20.5|T20G20_5',
#  'NCBIGene:815111': 'AtPGR5|T20G20.3|T20G20_3|proton gradient regulation 5|PGR5|proton gradient regulation 5',
#  'NCBIGene:815112': 'ATG8D|T20G20.2|T20G20_2|Ubiquitin-like superfamily protein',
#  'NCBIGene:815113': 'AT2G05645|uncharacterized protein',
#  'NCBIGene:815120': 'ACO3|aconitase 3|T3P4.5|T3P4_5|aconitase 3',
#  'NCBIGene:815121': 'AT2G05720|Transducin/WD40 repeat-like superfamily protein|T3P4.4|T3P4_4',
#  'NCBIGene:815125': 'uncharacterized protein|AT2G05752',
#  'NCBIGene:815126': 'AT2G05755|Nodulin MtN21 /EamA-like transporter family protein',
#  'NCBIGene:815127': 'AT2G05760|NAT1|T25M19.4|T25M19_4|nucleobase ascorbate transporter 1|Xanthine/uracil permease family protein',
#  'NCBIGene:815130': 'O-Glycosyl hydrolases family 17 protein|T25M19.1|T25M19_1|AT2G05790',
#  'NCBIGene:815132': 'T17C22.4|T17C22_4|ARM repeat superfamily protein|AT2G05810',
#  'NCBIGene:815134': 'NagB/RpiA/CoA transferase-like superfamily protein|5-METHYLTHIORIBOSE KINASE 1|MTI1|T6P5.3|T6P5_3|AT2G05830',
#  'NCBIGene:815135': '20S proteasome subunit PAA2|T6P5.4|T6P5_4|PAA2 (Arabidopsis thaliana)|PAA2|20S proteasome subunit PAA2',
#  'NCBIGene:815137': 'serine carboxypeptidase-like 38|scpl38|T6P5.5|T6P5_5|serine carboxypeptidase-like 38',
#  'NCBIGene:815138': 'AT2G05860|T6P5.6|T6P5_6',
#  'NCBIGene:815139': 'AT2G05870|T6P5.7|T6P5_7',
#  'NCBIGene:815140': 'T6P5.8|T6P5_8|AT2G05880',
#  'NCBIGene:815141': 'AT2G05890|T6P5.9|T6P5_9',
#  'NCBIGene:815142': 'SDG11|SET domain protein 11|SU(VAR)3-9 HOMOLOG 10|SUVH10|T6P5.10|T6P5_10|SET domain protein 11',
#  'NCBIGene:815143': 'LURP-one-like protein (DUF567)|AT2G05910|T6P5.11|T6P5_11',
#  'NCBIGene:815144': 'uncharacterized protein|AT2G05915',
#  'NCBIGene:815145': 'T6P5.12|T6P5_12|Subtilase family protein|AT2G05920',
#  'NCBIGene:815147': 'Protein kinase superfamily protein|RIPK|RPM1-induced protein kinase|T6P5.14|T6P5_14',
#  'NCBIGene:815148': 'T6P5.15|T6P5_15|AT2G05950',
#  'NCBIGene:815150': 'F-box protein (DUF295)|T6P5.17|T6P5_17|AT2G05970',
#  'NCBIGene:815152': 'NAD(P)-binding Rossmann-fold superfamily protein|ENOYL-ACP REDUCTASE|ENOYL-ACP REDUCTASE 1|ENR1|MOSAIC DEATH 1|T6P5.19|T6P5_19|MOD1',
#  'NCBIGene:815153': 'AT2G06000|T6P5.20|T6P5_20|Pentatricopeptide repeat (PPR) superfamily protein',
#  'NCBIGene:815154': 'FIP1 (Arabidopsis thaliana)|FRIGIDA interacting protein 1|FIP1',
#  'NCBIGene:815155': 'OBP3-responsive protein 4 (ORG4)|F5K7.23|F5K7_23|OBP3-responsive gene 4|ORG4',
#  'NCBIGene:815156': 'F5K7.22|F5K7_22|Homeodomain-like superfamily protein|AT2G06020',
#  'NCBIGene:815157': 'Acyl-CoA N-acyltransferases (NAT) superfamily protein|AT2G06025',
#  'NCBIGene:815159': 'F5K7.20|F5K7_20|F-box/LRR protein|AT2G06040',
#  'NCBIGene:815160': 'OPR3|11-REDUCTASE|12-OXO-PHYTODIENOATE REDUCTASE|12-OXOPHYTODIENOATE-10|AtOPR3|DDE1|DELAYED DEHISCENCE 1|F5K7.19|F5K7_19|oxophytodienoate-reductase 3|oxophytodienoate-reductase 3',
#  'NCBIGene:815164': 'AT2G06090|Plant self-incompatibility protein S1 family|F5K7.15|F5K7_15',
#  'NCBIGene:815165': 'uncharacterized protein|AT2G06095',
#  'NCBIGene:815168': 'AT2G06120|F5K7.12|F5K7_12',
#  'NCBIGene:815170': 'AT2G06140|F5K7.10|F5K7_10',
#  'NCBIGene:815176': 'GRF6|growth-regulating factor 6|GRF6 (Arabidopsis thaliana)|AtGRF6|F5K7.4|F5K7_4|growth-regulating factor 6',
#  'NCBIGene:815177': 'EARLY FLOWERING 8|F5K7.3|F5K7_3|VERNALIZATION INDEPENDENCE 6|VIP6|binding protein|ELF8',
#  'NCBIGene:815179': 'F18P14.2|F18P14_2|AT2G06230',
#  'NCBIGene:815182': 'ELF4-L3|ELF4-like 3',
#  'NCBIGene:815197': 'F18P14.18|F18P14_18|AT2G06390',
#  'NCBIGene:815200': 'AT2G06420|F28N16.1|F28N16_1|En/Spm-like transposon, putative (DUF1985)',
#  'NCBIGene:815206': 'T12H3.3|T12H3_3|AT2G06480',
#  'NCBIGene:815208': 'AT2G06500|hAT family dimerization domain-containing protein|T12H3.5|T12H3_5',
#  'NCBIGene:815209': 'replication protein A 1A|RPA1A|ARABIDOPSIS THALIANA REPLICATION PROTEIN A 1A|ARABIDOPSIS THALIANA RPA70-KDA SUBUNIT A|ATRPA1A|ATRPA70A|RPA70-KDA SUBUNIT A|RPA70A|T12H3.6|T12H3_6|replication protein A 1A',
#  'NCBIGene:815210': 'PSII-X|T12H3.7|T12H3_7|photosystem II subunit X|photosystem II subunit X|PSBX',
#  'NCBIGene:815211': 'T12H3.8|T12H3_8|VPS2|SNF7 family protein|VPS2.1',
#  'NCBIGene:815214': 'uncharacterized protein|AT2G06555',
#  'NCBIGene:815216': 'AT2G06570|uncharacterized protein|T12H3.12|T12H3_12',
#  'NCBIGene:815220': 'T12H3.16|T12H3_16|AT2G06610',
#  'NCBIGene:815221': 'T14A4.22|AT2G06620',
#  'NCBIGene:815222': 'AT2G06630|T14A4.21|T14A4_21',
#  'NCBIGene:815224': 'uncharacterized protein|AT2G06645|T14A4.1',
#  'NCBIGene:815229': 'T14A4.15|T14A4_15|AT2G06690',
#  'NCBIGene:815230': 'AT2G06700|T14A4.14|T14A4_14',
#  'NCBIGene:815236': 'T14A4.9|T14A4_9|AT2G06750',
#  'NCBIGene:815239': 'AT2G06775',
#  'NCBIGene:815244': 'T9F8.1|T9F8_1|AT2G06820',
#  'NCBIGene:815246': 'AT2G06845|Beta-galactosidase related protein',
#  'NCBIGene:815247': 'XTH4|ENDOXYLOGLUCAN TRANSFERASE|EXGT-A1|EXT|T9F8.4|T9F8_4|endoxyloglucan transferase A1|xyloglucan endotransglucosylase/hydrolase 4|xyloglucan endotransglucosylase/hydrolase 4',
#  'NCBIGene:815248': 'T9F8.5|T9F8_5|AT2G06860',
#  'NCBIGene:815255': 'AT2G06904|nucleic acid / zinc ion binding protein',
#  'NCBIGene:815256': 'uncharacterized protein|AT2G06906',
#  'NCBIGene:815257': 'uncharacterized protein|AT2G06908',
#  'NCBIGene:815261': 'PLA2-ALPHA|Phospholipase A2 family protein|ATSPLA2-ALPHA|PHOSPHOLIPASE A2-ALPHA',
#  'NCBIGene:815265': 'AT2G06960|2-oxoglutarate (2OG) and Fe(II)-dependent oxygenase superfamily protein|T4E14.7|T4E14_7',
#  'NCBIGene:815269': 'HEN2|T4E14.10|T4E14_10|hua enhancer 2|RNA helicase, ATP-dependent, SK12/DOB1 protein',
#  'NCBIGene:815270': 'uncharacterized protein|T4E14.11|T4E14_11|AT2G07000',
#  'NCBIGene:815272': 'T4E14.13|T4E14_13|AT2G07020|kinase with adenine nucleotide alpha hydrolases-like domain-containing protein',
#  'NCBIGene:815274': 'PRK2A|Leucine-rich repeat protein kinase family protein|ATPRK2A|AtPRK2|PRK2|T4E14.15|T4E14_15|pollen receptor like kinase 2',
#  'NCBIGene:815275': 'cycloartenol synthase 1|CYCLOARTENOL SYNTHASE 1|T4E14.16|T4E14_16|cycloartenol synthase 1|CAS1',
#  'NCBIGene:815276': 'T4E14.17|T4E14_17|AT2G07070',
#  'NCBIGene:815278': 'T25N22.5|T25N22_5|AT2G07090',
#  'NCBIGene:815280': 'AT2G07110|exosome complex exonuclease RRP46-like protein|T25N22.7|T25N22_7',
#  'NCBIGene:815281': 'T25N22.8|T25N22_8|F-box associated ubiquitination effector family protein|AT2G07120',
#  'NCBIGene:815283': 'F-box and associated interaction domains-containing protein|AT2G07140|T25N22.10|T25N22_10',
#  'NCBIGene:815286': 'T25N22.13|T25N22_13|ARM repeat superfamily protein|AT2G07170',
#  'NCBIGene:815287': 'Protein kinase superfamily protein|AT2G07180|T25N22.14|T25N22_14',
#  'NCBIGene:815288': 'T25N22.15|T25N22_15|AT2G07190|transmembrane protein, putative (DUF1985)',
#  'NCBIGene:815291': 'uncharacterized protein|AT2G07215',
# ...
#  'NCBIGene:816157': 'mucin|AT2G16575',
#  'NCBIGene:816158': 'AT2G16580|F1P15.4|F1P15_4|SAUR8|SMALL AUXIN UPREGULATED RNA 8|SAUR-like auxin-responsive protein family',
#  'NCBIGene:816160': 'Translocon-associated protein (TRAP), alpha subunit|AT2G16595',
#  'NCBIGene:816161': 'AtCYP19-1|CYCLOPHILIN|CYP19|T24I21.1|T24I21_1|cyclophilin 19|rotamase CYP 3|ROC3|rotamase CYP 3',
#  'NCBIGene:816163': 'T24I21.3|T24I21_3|Protein kinase superfamily protein|AT2G16620',
#  'NCBIGene:816164': 'T24I21.4|T24I21_4|AT2G16630|Pollen Ole e 1 allergen and extensin family protein',
#  'NCBIGene:816165': 'multimeric translocon complex in the outer envelope membrane 132|TOC132|ATTOC132|MULTIMERIC TRANSLOCON COMPLEX IN THE OUTER ENVELOPE MEMBRANE 132|T24I21.5|T24I21_5|multimeric translocon complex in the outer envelope membrane 132',
#  'NCBIGene:816166': 'proteinaceous RNase P 2|T24I21.6|T24I21_6|proteinaceous RNase P 2|PRORP2',
#  'NCBIGene:816167': 'T24I21.7|T24I21_7|Major facilitator superfamily protein|AT2G16660',
#  'NCBIGene:816170': 'T24I21.10|T24I21_10|AT2G16690',
#  'NCBIGene:816171': 'actin depolymerizing factor 5|ADF5|ACTIN DEPOLYMERIZING FACTOR 5|ATADF5|T24I21.11|T24I21_11|actin depolymerizing factor 5',
#  'NCBIGene:816172': 'T24I21.12|T24I21_12|AT2G16710|Iron-sulfur cluster biosynthesis family protein',
#  'NCBIGene:816173': 'ARABIDOPSIS THALIANA MYB DOMAIN PROTEIN 7|ATMYB7|ATY49|T24I21.13|T24I21_13|myb domain protein 7|myb domain protein 7|MYB7',
#  'NCBIGene:816174': 'BGAL13|T24I21.14|T24I21_14|beta-galactosidase 13|glycosyl hydrolase family 35 protein|AT2G16730',
#  'NCBIGene:816175': 'ubiquitin-conjugating enzyme 29|UBC29|T24I21.15|T24I21_15|ubiquitin-conjugating enzyme 29',
#  'NCBIGene:816176': 'kinase with adenine nucleotide alpha hydrolases-like domain-containing protein|AT2G16750|T24I21.16|T24I21_16',
#  'NCBIGene:816177': 'Calcium-dependent phosphotriesterase superfamily protein|T24I21.17|T24I21_17|AT2G16760',
#  'NCBIGene:816178': 'bZIP23|Basic-leucine zipper (bZIP) transcription factor family protein|T24I21.18|T24I21_18',
#  'NCBIGene:816179': 'MSI02|MULTICOPY SUPPRESSOR OF IRA1 2|NFC02|NFC2|NUCLEOSOME/CHROMATIN ASSEMBLY FACTOR GROUP C 2|T24I21.19|T24I21_19|Transducin family protein / WD-40 repeat family protein|MSI2 (Arabidopsis thaliana)|MSI2',
#  'NCBIGene:816180': 'AT2G16790|T24I21.20|T24I21_20|P-loop containing nucleoside triphosphate hydrolases superfamily protein',
#  'NCBIGene:816181': 'high-affinity nickel-transport family protein|AT2G16800|T24I21.21|T24I21_21',
#  'NCBIGene:816182': 'F-box and associated interaction domains-containing protein|T24I21.22|T24I21_22|AT2G16810',
#  'NCBIGene:816183': 'AT2G16820|T24I21.23|T24I21_23',
#  'NCBIGene:816185': 'Aquaporin-like superfamily protein|AT2G16835|F12A24.1',
#  'NCBIGene:816186': 'plasma membrane intrinsic protein 2;8|F12A24.3|F12A24_3|PIP3B|PLASMA MEMBRANE INTRINSIC PROTEIN 3B|plasma membrane intrinsic protein 2;8|PIP2;8',
#  'NCBIGene:816187': 'AT2G16860|GCIP-interacting family protein|F12A24.4|F12A24_4',
#  'NCBIGene:816188': 'AT2G16870|F12A24.5|F12A24_5|Disease resistance protein (TIR-NBS-LRR class) family',
#  'NCBIGene:816189': 'F12A24.6|F12A24_6|Pentatricopeptide repeat (PPR) superfamily protein|AT2G16880',
#  'NCBIGene:816190': 'F12A24.7|F12A24_7|AT2G16890|UDP-Glycosyltransferase superfamily protein',
#  'NCBIGene:816192': 'phospholipase-like protein (PEARLI 4) family protein|F12A24.8|F12A24_8|AT2G16900',
#  'NCBIGene:816194': 'AMS|ABORTED MICROSPORES|F12A24.9|F12A24_9|basic helix-loop-helix (bHLH) DNA-binding superfamily protein',
#  'NCBIGene:816195': 'F12A24.10|F12A24_10|PFU2|PHO2 FAMILY UBIQUITIN CONJUGATION ENZYME 2|ubiquitin-conjugating enzyme 23|UBC23|ubiquitin-conjugating enzyme 23',
#  'NCBIGene:816196': 'AT2G16930|F12A24.11|F12A24_11|Ribosomal protein L27 family protein',
#  'NCBIGene:816197': 'AT2G16940|Splicing factor, CC1-like protein|F12A24.12|F12A24_12',
#  'NCBIGene:816198': 'TRN1|ATTRN1|F12A24.13|F12A24_13|TRANSPORTIN 1|transportin 1|transportin 1|TRN1 (Arabidopsis thaliana)',
#  'NCBIGene:816199': 'F12A24.14|F12A24_14|ARM repeat superfamily protein|AT2G16960',
#  'NCBIGene:816200': 'F12A24.15|F12A24_15|maternal effect embryo arrest 15|Major facilitator superfamily protein|MEE15',
#  'NCBIGene:816201': 'F12A24.16|F12A24_16|Major facilitator superfamily protein|AT2G16980',
#  'NCBIGene:816202': 'AT2G16990|Major facilitator superfamily protein|F6P23.2|F6P23_2',
#  'NCBIGene:816203': 'Mechanosensitive ion channel family protein|F6P23.16|F6P23_16|AT2G17000',
#  'NCBIGene:816204': 'Mechanosensitive ion channel family protein|AT2G17010|F6P23.17|F6P23_17',
#  'NCBIGene:816205': 'AT2G17020|F6P23.18|F6P23_18|F-box/RNI-like superfamily protein',
#  'NCBIGene:816206': 'F6P23.19|F6P23_19|AT2G17030|F-box SKIP23-like protein (DUF295)',
#  'NCBIGene:816207': 'AT2G17033|pentatricopeptide (PPR) repeat-containing protein',
#  'NCBIGene:816208': 'F-box SKIP23-like protein (DUF295)|AT2G17036',
#  'NCBIGene:816209': 'NAC036|F6P23.7|F6P23_7|NAC domain containing protein 36|anac036|NAC domain containing protein 36',
#  'NCBIGene:816210': 'F6P23.20|F6P23_20|AT2G17050|disease resistance protein (TIR-NBS-LRR class)',
#  'NCBIGene:816211': 'Disease resistance protein (TIR-NBS-LRR class) family|F6P23.21|F6P23_21|AT2G17060',
#  'NCBIGene:816212': 'AT2G17070|F6P23.22|F6P23_22|hypothetical protein (DUF241)',
#  'NCBIGene:816213': 'F6P23.10|F6P23_10|AT2G17080|hypothetical protein (DUF241)',
#  'NCBIGene:816214': 'BSK12|F6P23.23|F6P23_23|SHORT SUSPENSOR|brassinosteroid-signaling kinase 12|kinase with tetratricopeptide repeat domain-containing protein|SSP',
#  'NCBIGene:816215': 'AT2G17110|DNA-directed RNA polymerase subunit beta, putative (DUF630 and DUF632)|F6P23.12|F6P23_12',
#  'NCBIGene:816217': 'CEBiP-like 1|CL-1|F6P23.25|F6P23_25|LYP1|LysM-containing receptor protein 1|lysM domain GPI-anchored protein 2 precursor|lysm domain GPI-anchored protein 2 precursor|LYM2|lysm domain GPI-anchored protein 2 precursor',
#  'NCBIGene:816218': 'IDH2 (Arabidopsis thaliana)|IDH2|F6P23.14|F6P23_14|IDH-II|NAD+ DEPENDENT ISOCITRATE DEHYDROGENASE SUBUNIT 2|isocitrate dehydrogenase II|isocitrate dehydrogenase subunit 2|isocitrate dehydrogenase subunit 2',
#  'NCBIGene:816219': 'AT2G17140|F6P23.26|F6P23_26|Pentatricopeptide repeat (PPR) superfamily protein',
#  'NCBIGene:816220': 'F6P23.15|F6P23_15|NIN-like protein 1|NLP1|AT2G17150|Plant regulator RWP-RK family protein',
#  'NCBIGene:816221': 'T23A1.2|T23A1_2|AT2G17160|Interleukin-1 receptor-associated kinase 4 protein',
#  'NCBIGene:816222': 'Protein kinase superfamily protein|T23A1.3|T23A1_3|AT2G17170',
#  'NCBIGene:816223': 'DAZ1|DAZ1 (Arabidopsis thaliana)|C2H2-like zinc finger protein|DUO1-ACTIVATED ZINC FINGER 1|T23A1.4|T23A1_4',
#  'NCBIGene:816224': 'AT2G17190|ubiquitin family protein|DSK2a|T23A1.5|T23A1_5',
#  'NCBIGene:816225': 'DSK2b|T23A1.6|T23A1_6|ubiquitin family protein|DSK2|DSK2 (Arabidopsis thaliana)',
#  'NCBIGene:816226': 'AT2G17210|T23A1.7|T23A1_7|Tetratricopeptide repeat (TPR)-like superfamily protein',
#  'NCBIGene:816227': 'T23A1.8|T23A1_8|kinase 3|Protein kinase superfamily protein|Kin3',
#  'NCBIGene:816228': 'EXORDIUM like 5|T23A1.9|T23A1_9|EXORDIUM like 5|EXL5',
#  'NCBIGene:816229': 'AT2G17240|arginine/serine-rich-like splicing factor|T23A1.10|T23A1_10',
#  'NCBIGene:816230': 'CCAAT-binding factor|EMBRYO DEFECTIVE 2762|NOC4|NucleOlar Complex associated 4|T23A1.11|T23A1_11|EMB2762',
#  'NCBIGene:816231': 'glutamate receptor 2|GLR2|ATGLR2|ATGLR3.1|F5J6.2|F5J6_2|GLR3.1|GLUTAMATE RECEPTOR 2|glutamate receptor 2',
#  'NCBIGene:816232': 'DMR1|DOWNY MILDEW RESISTANT 1|F5J6.24|F5J6_24|HOMOSERINE KINASE|homoserine kinase|HSK|homoserine kinase',
#  'NCBIGene:816233': 'PHT3;3|F5J6.3|F5J6_3|MPT1|mitochondrial phosphate transporter 1|phosphate transporter 3;3|phosphate transporter 3;3',
#  'NCBIGene:816234': 'F5J6.4|F5J6_4|AT2G17280|Phosphoglycerate mutase family protein',
#  'NCBIGene:816235': 'CPK6|ARABIDOPSIS THALIANA CALCIUM-DEPENDENT PROTEIN KINASE 6|ARABIDOPSIS THALIANA CALMODULIN-DOMAIN PROTEIN KINASE 3|ATCDPK3|ATCPK6|CALCIUM-DEPENDENT PROTEIN KINASE 6|CALMODULIN-DOMAIN PROTEIN KINASE 3|F5J6.13|F5J6_13|calcium dependent protein kinase 6|Calcium-dependent protein kinase family protein',
#  'NCBIGene:816236': 'uncharacterized protein|F5J6.6|F5J6_6|AT2G17300',
#  'NCBIGene:816237': 'AT2G17305|F-box/LRR protein',
#  'NCBIGene:816238': 'F-box and associated interaction domains-containing protein|F5J6.7|F5J6_7|SUPPRESSOR OF NIM1-1 1|SON1',
#  'NCBIGene:816239': 'pantothenate kinase|F5J6.8|F5J6_8|AT2G17320',
#  'NCBIGene:816241': 'pantothenate kinase|AT2G17340|F5J6.10|F5J6_10',
#  'NCBIGene:816242': 'AT2G17350|beta-mannosyltransferase-like protein|F5J6.11|F5J6_11',
#  'NCBIGene:816243': 'Ribosomal protein S4 (RPS4A) family protein|AT2G17360|F5J6.12|F5J6_12',
#  'NCBIGene:816244': 'HMG2|HMG2 (Arabidopsis thaliana)|3-hydroxy-3-methylglutaryl-CoA reductase 2|3-HYDROXY-3-METHYLGLUTARYL-COENZYME A REDUCTASE 2|3-hydroxy-3-methylglutaryl-CoA reductase 2|F5J6.1|F5J6_1|HMGR2',
#  'NCBIGene:816245': 'AP19|associated protein 19|CLATHRIN ASSEMBLY PROTEIN AP19|F5J6.14|F5J6_14|associated protein 19',
#  'NCBIGene:816246': 'AKR2B|ankyrin repeat-containing 2B|F5J6.15|F5J6_15|ankyrin repeat-containing 2B',
#  'NCBIGene:816247': 'AT2G17400|F5J6.17|F5J6_17|ARID/BRIGHT DNA-binding domain-containing protein|AT2G17410',
#  'NCBIGene:816248': 'NTRA|ATNTRA|F5J6.18|F5J6_18|NADPH-DEPENDENT THIOREDOXIN REDUCTASE 2|NADPH-dependent thioredoxin reductase A|NTR2|THIOREDOXIN REDUCTASE A|NADPH-dependent thioredoxin reductase A',
#  'NCBIGene:816249': 'ATMLO7|F5J6.19|F5J6_19|MILDEW RESISTANCE LOCUS O 7|NORTIA|NTA|Seven transmembrane MLO family protein|MLO7',
#  'NCBIGene:816250': 'plant intracellular ras group-related LRR 5|PIRL5|F5J6.20|F5J6_20|plant intracellular ras group-related LRR 5',
#  'NCBIGene:816251': 'RING-H2 finger A3A|F5J6.22|RING-H2 FINGER PROTEIN RHA3A|RING-H2 finger A3A|RHA3A',
#  'NCBIGene:816253': 'ALMT6|ALMT6 (Arabidopsis thaliana)|ALuminium activated Malate Transporter 6|AtALMT6|F5J6.5|aluminum activated malate transporter family protein',
#  'NCBIGene:816254': 'Seven transmembrane MLO family protein|MLO8|ATMLO8|F5J6.21|MILDEW RESISTANCE LOCUS O 8',
#  'NCBIGene:816256': 'Auxin efflux carrier family protein|AT2G17500|MJB20.6|MJB20_6|PILS5|PIN-LIKES 5',
#  'NCBIGene:816257': 'AtRRP44A|EMBRYO DEFECTIVE 2763|MJB20.7|MJB20_7|RRP44A|Rrp44 homolog A|EMB2763|ribonuclease II family protein',
#  'NCBIGene:816258': 'ARABIDOPSIS THALIANA INOSITOL REQUIRING 1-2|ATIRE1-2|AtIRE1A|INOSITOL REQUIRING 1-2|IRE1-2|MJB20.8|MJB20_8|TRANSMEMBRANE PROTEIN KINASE/RIBONUCLEASE|Endoribonuclease/protein kinase IRE1-like protein|IRE1A',
#  'NCBIGene:816259': 'AT2G17525|Pentatricopeptide repeat (PPR) superfamily protein',
#  'NCBIGene:816260': 'Protein kinase superfamily protein|MJB20.9|MJB20_9|AT2G17530',
#  'NCBIGene:816261': 'AT2G17540|uncharacterized protein|MJB20.10|MJB20_10',
#  'NCBIGene:816262': 'MJB20.11|MJB20_11|TON1 Recruiting Motif 26|RB1-inducible coiled-coil protein|TRM26',
#  'NCBIGene:816263': 'high mobility group B4|MJB20.12|MJB20_12|NFD04|NFD4|NUCLEOSOME/CHROMATIN ASSEMBLY FACTOR|NUCLEOSOME/CHROMATIN ASSEMBLY FACTOR D4|high mobility group B4|HMGB4 (Arabidopsis thaliana)|HMGB4',
#  'NCBIGene:816264': 'AtcPT1|MJB20.13|MJB20_13|cis-prenyltransferase 1|Undecaprenyl pyrophosphate synthetase family protein|cPT1',
#  'NCBIGene:816265': 'AGS1|MJB20.14|MJB20_14|ahg2-1 suppressor 1|AT2G17580|Polynucleotide adenylyltransferase family protein',
#  'NCBIGene:816266': 'Cysteine/Histidine-rich C1 domain family protein|AT2G17590|MJB20.15|MJB20_15',
#  'NCBIGene:816267': 'Cysteine/Histidine-rich C1 domain family protein|AT2G17600|MJB20.16|MJB20_16',
#  'NCBIGene:816269': 'CYCB2;1|Cyclin B2;1|T19E12.4|T19E12_4|Cyclin B2;1',
#  'NCBIGene:816270': 'AT2G17630|Pyridoxal phosphate (PLP)-dependent transferases superfamily protein|PSAT2|T19E12.3|T19E12_3|phosphoserine aminotransferase 2',
#  'NCBIGene:816271': 'Trimeric LpxA-like enzymes superfamily protein|SAT-106|SERINE ACETYLTRANSFERASE 106|T17A5.1|T17A5_1|ATSERAT3;1',
#  'NCBIGene:816272': 'AT2G17650|T17A5.12|T17A5_12|AMP-dependent synthetase and ligase family protein',
#  'NCBIGene:816273': 'RPM1-interacting protein 4 (RIN4) family protein|AT2G17660',
#  'NCBIGene:816274': 'T17A5.11|T17A5_11|Tetratricopeptide repeat (TPR)-like superfamily protein|AT2G17670',
#  'NCBIGene:816275': 'DUF241 domain protein, putative (DUF241)|AT2G17680|T17A5.19|T17A5_19',
#  'NCBIGene:816276': 'SDC|SUPPRESSOR OF DRM1 DRM2 CMT3|T17A5.18|T17A5_18|ascorbic acid mannose pathway regulator, putative (DUF295)',
#  'NCBIGene:816277': 'outer envelope protein|AT2G17695',
#  'NCBIGene:816278': 'T17A5.2|T17A5_2|serine/threonine/tyrosine kinase 8|STY8|ACT-like protein tyrosine kinase family protein',
#  'NCBIGene:816279': 'AT2G17705|methionine-S-oxide reductase',
#  'NCBIGene:816280': 'AT2G17710|Big1|T17A5.17|T17A5_17',
#  'NCBIGene:816281': 'P4H5|2-oxoglutarate (2OG) and Fe(II)-dependent oxygenase superfamily protein|T17A5.10|T17A5_10|prolyl 4-hydroxylase 5',
#  'NCBIGene:816282': 'NEP-interacting protein 2|T17A5.9|T17A5_9|NIP2|NEP-interacting protein 2',
#  'NCBIGene:816283': 'T17A5.16|T17A5_16|Cysteine/Histidine-rich C1 domain family protein|AT2G17740',
#  'NCBIGene:816284': 'NIP1|NIP1 (Arabidopsis thaliana)|NEP-interacting protein 1|T17A5.3|T17A5_3|NEP-interacting protein 1',
#  'NCBIGene:816285': 'Eukaryotic aspartyl protease family protein|T17A5.8|T17A5_8|AT2G17760',
#  'NCBIGene:816286': 'BZIP27|ATBZIP27|FD PARALOG|FDP|T17A5.15|T17A5_15|basic region/leucine zipper motif 27|BZIP27 (Arabidopsis thaliana)|basic region/leucine zipper motif 27',
#  'NCBIGene:816287': 'MCA2|PLAC8 family protein|T17A5.4|T17A5_4|mid1-complementing activity 2',
#  'NCBIGene:816288': 'AT2G17785|zinc-binding protein-like protein',
#  'NCBIGene:816289': 'VPS35A|T17A5.7|T17A5_7|VPS35 homolog A|ZIG suppressor 3|ZIP3|vacuolar protein sorting-associated 35A-like protein',
#  'NCBIGene:816290': 'RAC-like 1|ARAC1|ATGP2|ATRAC1|ATROP3|Arabidopsis RAC-like 1|RHO-RELATED GTPASES FROM PLANTS 3|ROP3|T17A5.14|T17A5_14',
#  'NCBIGene:816291': 'HK1|AHK1|ATHK1|T13L16.16|T13L16_16|histidine kinase 1|histidine kinase 1|HK1 (Arabidopsis thaliana)',
#  'NCBIGene:816292': 'F-box and associated interaction domains-containing protein|T13L16.15|T13L16_15|AT2G17830',
#  'NCBIGene:816293': 'Senescence/dehydration-associated protein-like protein|ERD7|EARLY-RESPONSIVE TO DEHYDRATION 7|T13L16.14|T13L16_14',
#  'NCBIGene:816294': 'NAD(P)-binding Rossmann-fold superfamily protein|AT2G17845',
#  'NCBIGene:816295': 'Rhodanese/Cell cycle control phosphatase superfamily protein|T13L16.13|T13L16_13|AT2G17850',
#  'NCBIGene:816296': 'T13L16.12|T13L16_12|AT2G17860|Pathogenesis-related thaumatin superfamily protein',
#  'NCBIGene:816297': 'ARABIDOPSIS COLD SHOCK DOMAIN PROTEIN 3|ATCSP3|T13L16.11|T13L16_11|cold shock domain protein 3|CSP3|cold shock domain protein 3|CSP3 (Arabidopsis thaliana)',
#  'NCBIGene:816298': 'AT2G17880|DJC24|DNA J protein C24|T13L16.10|T13L16_10|Chaperone DnaJ-domain superfamily protein',
#  'NCBIGene:816299': 'CPK16|calcium-dependent protein kinase 16|AtCDPK16|CDPK16|T13L16.9|T13L16_9|calcium-dependent protein kinase 16',
#  'NCBIGene:816300': 'ASH1-related 1|ASHR1|SET DOMAIN GROUP 37|SET domain group 37|T13L16.8|T13L16_8|SDG37|SET domain group 37',
#  'NCBIGene:816302': 'nucleic acid binding / zinc ion binding protein|T13L16.6|T13L16_6|AT2G17920',
#  'NCBIGene:816303': 'AT2G17930|Phosphatidylinositol 3- and 4-kinase family protein with FAT domain-containing protein|T13L16.5|T13L16_5',
#  'NCBIGene:816304': 'T27K22.19|T27K22_19|AT2G17940|WEB family protein (DUF827)',
#  'NCBIGene:816305': 'PGA6|T27K22.18|T27K22_18|WUS1|WUSCHEL|WUSCHEL 1|WUS|Homeodomain-like superfamily protein',
#  'NCBIGene:816306': 'uncharacterized protein|AT2G17960|T27K22.17|T27K22_17',
#  'NCBIGene:816307': 'T27K22.16|T27K22_16|AT2G17970|2-oxoglutarate (2OG) and Fe(II)-dependent oxygenase superfamily protein',
#  'NCBIGene:816308': 'uncharacterized protein|AT2G17972',
#  'NCBIGene:816309': 'AT2G17975|zinc finger (Ran-binding) family protein|T27K22.20',
#  'NCBIGene:816310': 'T27K22.15|T27K22_15|ATSLY1|Sec1/munc18-like (SM) proteins superfamily',
#  ...}

# %%
'abc def '.split(' ')
# Out:
# ['abc', 'def', '']

# %%
# %load_ext autoreload
# %autoreload 2

import pickle
import ujson
import sys
import os

import pandas as pd
import numpy as np

from tqdm import tqdm
from collections import defaultdict

from bigbio.dataloader import BigBioConfigHelpers


sys.path.append('..')
from umls_utils import UmlsMappings
from bigbio_utils import CUIS_TO_REMAP, CUIS_TO_EXCLUDE, DATASET_NAMES, VALIDATION_DOCUMENT_IDS
from bigbio_utils import dataset_to_documents, dataset_to_df, resolve_abbreviation

conhelps = BigBioConfigHelpers()

# %% [markdown]
# # Make dictionary of possible entity links

# %% [markdown]
# ## Process UMLS into dictionary
#
# For each entity:
# * Get canonical name
# * Get GCD of types (if possible)
# * Get definition
#
# Then output dictionary of entities

# %%
def get_type_gcd(types, type2geneology, cached_types: dict = None):
    '''
    Find the most granular single parent type for an entity with multiple types

    If an entity is assigned multiple types with disjoint type hierarchies

    
    '''
    if len(types) == 1:
        t = types[0]
        if t not in cached_types:
            cached_types[t] = type2geneology[t][-1]
        return cached_types[t]

    type_tuple = tuple(sorted(types))
    if type_tuple in cached_types:
        return cached_types[type_tuple]
    else:
        geneologies = [type2geneology[t] for t in types]
        min_len = min([len(x) for x in geneologies])
        arr = np.array([gen[:min_len] for gen in geneologies])
        unique_types = np.unique(arr[:,0])
        if len(unique_types) > 1:
            output_types = ', '.join(list(set([x[-1] for x in geneologies])))
            cached_types[type_tuple] = output_types
            return output_types
        else:
            for i in np.arange(1, arr.shape[1]):
                curr_unique = np.unique(arr[:,i])

                if len(curr_unique) > 1 or i >= 3:
                    cached_types[type_tuple] = unique_types[0]
                    return unique_types[0]
                else:
                    unique_types = curr_unique


type2geneology = ujson.load(open('../data/tui2type_hierarchy.json'))
cached_types = {}
# umls.umls.tui.map(lambda x: get_type_gcd(x, type2geneology, cached_types)).values

# %%
umls_dir="/mitchell/entity-linking/2017AA/META/"

sem_groups = pd.read_csv(
            os.path.join(umls_dir, "SemGroups.txt"),
            sep="|",
            usecols=[0, 1, 2],
            names=["group", "name", "tui"],
        )

group2name = sem_groups[['group','name']].drop_duplicates().set_index('group').name.to_dict()

with open('../data/group2name.json','w') as f:
    f.write(ujson.dumps(group2name))

umls = UmlsMappings(
    umls_dir=umls_dir, debug=False, force_reprocess=False, 
)
# Out:
# Loading cached UMLS data from /mitchell/entity-linking/2017AA/META/.cached_df.feather

# %%
umls.umls.head()
# Out:
#         cui lang ispref        aui      scui     sdui  sab  tty  \
# 0  C0000005  ENG      Y  A26634265  M0019694  D012711  MSH  PEP
# 1  C0000074  ENG      Y  A26606894  M0016680  D010742  MSH  PEP
# 2  C0000132  ENG      Y  A26665454  M0004272  D002787  MSH  PEP
# 3  C0000137  ENG      Y  A26650280  M0019173  D012335  MSH  PEP
# 4  C0000151  ENG      Y  A26647507  M0020412  D013196  MSH  PEP
#
#                                     alias  rank                 tui   group  \
# 0          (131)I-Macroaggregated Albumin     4  [T116, T121, T130]  [CHEM]
# 1            1-Alkyl-2-Acylphosphatidates     4              [T109]  [CHEM]
# 2          15-Ketosteryl Oleate Hydrolase     4        [T116, T126]  [CHEM]
# 3                                 15S RNA     4        [T114, T123]  [CHEM]
# 4  17 beta-Hydroxy-5 beta-Androstan-3-One     4        [T109, T121]  [CHEM]
#
#     def
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None

# %%
lowercase=False

# Full UMLS Canonical Names
print("Getting Names")
umls_to_name = umls.get_canonical_name(ontologies_to_include="all",
    use_umls_curies=True,
    lowercase=lowercase,)
# Out:
# Getting Names
# /nvme/home/dkartchner3/research/entity_linking/el-robustness-comparison/notebooks/../umls_utils.py:206: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["identifier"] = df["cui"]

# %%
all_umls_df = umls.umls.query('lang == "ENG"').groupby('cui').agg({'alias': lambda x: list(set(x)), 'tui':'first', 'group': 'first', 'def':'first'}).reset_index()
all_umls_df['name'] = all_umls_df.cui.map(umls_to_name)
all_umls_df['alias'] = all_umls_df[['name','alias']].apply(lambda x: list(set(x[1]) - set([x[0]])) , axis=1)
all_umls_df['cui'] = all_umls_df['cui'].map(lambda x: 'UMLS' + x)
all_umls_df['has_definition'] = all_umls_df['def'].map(lambda x: x is not None)
all_umls_df['num_aliases'] = all_umls_df['alias'].map(lambda x: len(x))
all_umls_df.head()
# Out:
#             cui                                              alias  \
# 0  UMLSC0000005                                       [(131)I-MAA]
# 1  UMLSC0000039  [1,2 Dipalmitoyl Glycerophosphocholine, Dipalm...
# 2  UMLSC0000052  [1,4-Alpha glucan branching enzyme, Branching ...
# 3  UMLSC0000074                     [1 Alkyl 2 Acylphosphatidates]
# 4  UMLSC0000084  [gamma Carboxyglutamic Acid, 3-Amino-1,1,3-pro...
#
#                   tui   group  \
# 0  [T116, T121, T130]  [CHEM]
# 1        [T109, T121]  [CHEM]
# 2        [T116, T126]  [CHEM]
# 3              [T109]  [CHEM]
# 4        [T116, T123]  [CHEM]
#
#                                                  def  \
# 0                                               None
# 1  Synthetic phospholipid used in liposomes and l...
# 2  In glycogen or amylopectin synthesis, the enzy...
# 3                                               None
# 4  Found in various tissues, particularly in four...
#
#                                  name  has_definition  num_aliases
# 0      (131)I-Macroaggregated Albumin           False            1
# 1  1,2-Dipalmitoylphosphatidylcholine            True           15
# 2   1,4-alpha-Glucan Branching Enzyme            True           22
# 3        1-Alkyl-2-Acylphosphatidates           False            1
# 4              1-Carboxyglutamic Acid            True            7

# %%
# Out:
# 0          UMLSC0000005
# 1          UMLSC0000039
# 2          UMLSC0000052
# 3          UMLSC0000074
# 4          UMLSC0000084
#                ...
# 3465002    UMLSC4316761
# 3465003    UMLSC4316762
# 3465004    UMLSC4316763
# 3465005    UMLSC4316764
# 3465006    UMLSC4316765
# Name: cui, Length: 3465007, dtype: object

# %%
all_umls_df.head()
# Out:
#         cui                                              alias  \
# 0  C0000005                                       [(131)I-MAA]
# 1  C0000039  [Phosphatidylcholine, Dipalmitoyl, 1,2 Dipalmi...
# 2  C0000052  [1,4-Alpha glucan branching enzyme, 1,4-alpha-...
# 3  C0000074                     [1 Alkyl 2 Acylphosphatidates]
# 4  C0000084  [3-Amino-1,1,3-propanetricarboxylic Acid, gamm...
#
#                   tui   group  \
# 0  [T116, T121, T130]  [CHEM]
# 1        [T109, T121]  [CHEM]
# 2        [T116, T126]  [CHEM]
# 3              [T109]  [CHEM]
# 4        [T116, T123]  [CHEM]
#
#                                                  def  \
# 0                                               None
# 1  Synthetic phospholipid used in liposomes and l...
# 2  In glycogen or amylopectin synthesis, the enzy...
# 3                                               None
# 4  Found in various tissues, particularly in four...
#
#                                  name
# 0      (131)I-Macroaggregated Albumin
# 1  1,2-Dipalmitoylphosphatidylcholine
# 2   1,4-alpha-Glucan Branching Enzyme
# 3        1-Alkyl-2-Acylphosphatidates
# 4              1-Carboxyglutamic Acid

# %%
# Out:
#         cui                                              alias  \
# 0  C0000005                                       [(131)I-MAA]
# 1  C0000039  [Phosphatidylcholine, Dipalmitoyl, 1,2 Dipalmi...
# 2  C0000052  [1,4-Alpha glucan branching enzyme, 1,4-alpha-...
# 3  C0000074                     [1 Alkyl 2 Acylphosphatidates]
# 4  C0000084  [3-Amino-1,1,3-propanetricarboxylic Acid, gamm...
#
#                   tui   group  \
# 0  [T116, T121, T130]  [CHEM]
# 1        [T109, T121]  [CHEM]
# 2        [T116, T126]  [CHEM]
# 3              [T109]  [CHEM]
# 4        [T116, T123]  [CHEM]
#
#                                                  def  \
# 0                                               None
# 1  Synthetic phospholipid used in liposomes and l...
# 2  In glycogen or amylopectin synthesis, the enzy...
# 3                                               None
# 4  Found in various tissues, particularly in four...
#
#                                  name  has_definition  num_aliases
# 0      (131)I-Macroaggregated Albumin           False            1
# 1  1,2-Dipalmitoylphosphatidylcholine            True           15
# 2   1,4-alpha-Glucan Branching Enzyme            True           22
# 3        1-Alkyl-2-Acylphosphatidates           False            1
# 4              1-Carboxyglutamic Acid            True            7

# %%
lowercase=False

# Full UMLS Canonical Names
print("Getting Names")
umls_to_name = umls.get_canonical_name(ontologies_to_include="all",
    use_umls_curies=True,
    lowercase=lowercase,)

# Full aliases
print("Geting aliases")
umls_to_alias = umls.get_aliases(
    ontologies_to_include="all",
    use_umls_curies=True,
    lowercase=lowercase,
)
# Out:
# Getting Names
# /nvme/home/dkartchner3/research/entity_linking/el-robustness-comparison/notebooks/../umls_utils.py:206: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["identifier"] = df["cui"]
# Geting aliases

# %%
umls_cui2types = umls.umls.groupby('cui').tui.first().to_dict()

# %%
print("Getting types")
type2geneology = ujson.load(open('../data/tui2type_hierarchy.json'))
cached_types = {}
cui2types = {}
for cui, types in tqdm(umls_cui2types.items()):
    cui2types[cui] = get_type_gcd(types, type2geneology, cached_types)
# Out:
# Getting types
# 100%|██████████| 3465486/3465486 [00:03<00:00, 1075809.41it/s]

# %%
umls_definitions = pd.read_csv(
            os.path.join(umls_dir, "MRDEF.RRF"),
            sep="|",
            usecols=[0,1,4,5,],
            names=["cui", "aui", "sab", 'def',],
        )
umls_definitions.aui.value_counts()
# Out:
# A24110393    6
# A7570204     5
# A7572881     5
# A7573153     5
# A7569947     5
#             ..
# A24360400    1
# A1703321     1
# A1703324     1
# A1701895     1
# A27782058    1
# Name: aui, Length: 244685, dtype: int64

# %%
umls_definitions
# Out:
#              cui        aui          sab  \
# 0       C0000039   A0016515          MSH
# 1       C0000052   A0016535          MSH
# 2       C0000084   A0016576          MSH
# 3       C0000096   A0526764          MSH
# 4       C0000097   A0016587          MSH
# ...          ...        ...          ...
# 269271  C4305359  A27765928  SNOMEDCT_US
# 269272  C4305375  A27778477  SNOMEDCT_US
# 269273  C4305376  A27776098  SNOMEDCT_US
# 269274  C4305378  A27782528  SNOMEDCT_US
# 269275  C4305579  A27782058  SNOMEDCT_US
#
#                                                       def
# 0       Synthetic phospholipid used in liposomes and l...
# 1       In glycogen or amylopectin synthesis, the enzy...
# 2       Found in various tissues, particularly in four...
# 3       A potent cyclic nucleotide phosphodiesterase i...
# 4       A dopaminergic neurotoxic compound which produ...
# ...                                                   ...
# 269271  Potential for trauma to skin or mucous membran...
# 269272  A platelet granule disorder with manifestation...
# 269273  A rare and isolated orofacial defect with mani...
# 269274  An exceedingly rare autosomal recessive neurol...
# 269275  An extremely rare form of corneal dystrophy wi...
#
# [269276 rows x 4 columns]

# %%
len(umls_definitions.cui.unique())
# Out:
# 195998

# %%
cui2definition = umls.get_definition(
    ontologies_to_include="all",
    use_umls_curies=True,
    lowercase=lowercase,
)
# Out:
# Filtering by ontologies
# Removing null definitions

# %%
cui2definition
# Out:
# {'C0000039': 'Synthetic phospholipid used in liposomes and lipid bilayers to study biological membranes. It is also a major constituent of PULMONARY SURFACTANTS.',
#  'C0000052': 'In glycogen or amylopectin synthesis, the enzyme that catalyzes the transfer of a segment of a 1,4-alpha-glucan chain to a primary hydroxy group in a similar glucan chain. EC 2.4.1.18.',
#  'C0000084': 'Found in various tissues, particularly in four blood-clotting proteins including prothrombin, in kidney protein, in bone protein, and in the protein present in various ectopic calcifications.',
#  'C0000096': 'A potent cyclic nucleotide phosphodiesterase inhibitor; due to this action, the compound increases cyclic AMP and cyclic GMP in tissue and thereby activates CYCLIC NUCLEOTIDE-REGULATED PROTEIN KINASES',
#  'C0000097': 'A dopaminergic neurotoxic compound which produces irreversible clinical, chemical, and pathological alterations that mimic those found in Parkinson disease.',
#  'C0000098': 'An active neurotoxic metabolite of 1-METHYL-4-PHENYL-1,2,3,6-TETRAHYDROPYRIDINE. The compound reduces dopamine levels, inhibits the biosynthesis of catecholamines, depletes cardiac norepinephrine and inactivates tyrosine hydroxylase. These and other toxic effects lead to cessation of oxidative phosphorylation, ATP depletion, and cell death. The compound, which is related to PARAQUAT, has also been used as an herbicide.',
#  'C0000102': 'A suspected industrial carcinogen (and listed as such by OSHA). Its N-hydroxy metabolite is strongly carcinogenic and mutagenic.',
#  'C0000103': 'A tool for the study of liver damage which causes bile stasis and hyperbilirubinemia acutely and bile duct hyperplasia and biliary cirrhosis chronically, with changes in hepatocyte function. It may cause skin and kidney damage.',
#  'C0000107': 'An ANGIOTENSIN II analog which acts as a highly specific inhibitor of ANGIOTENSIN TYPE 1 RECEPTOR.',
#  'C0000119': 'A group of corticosteroids bearing a hydroxy group at the 11-position.',
#  'C0000139': 'A synthetic prostaglandin E analog that protects the gastric mucosa, prevents ulceration, and promotes the healing of peptic ulcers. The protective effect is independent of acid inhibition. It is also a potent inhibitor of pancreatic function and growth of experimental tumors.',
#  'C0000163': 'A group of hydroxycorticosteroids bearing a hydroxy group at the 17-position. Urinary excretion of these compounds is used as an index of adrenal function. They are used systemically in the free alcohol form, but with esterification of the hydroxy groups, topical effectiveness is increased.',
#  'C0000165': 'A class of enzymes that catalyzes the oxidation of 17-hydroxysteroids to 17-ketosteroids. EC 1.1.-.',
#  'C0000167': 'Steroids that contain a ketone group at position 17.',
#  'C0000172': '11 beta,18,21-Trihydroxypregn-4-ene-3,20-dione.',
#  'C0000173': 'An analog of desoxycorticosterone which is substituted by a hydroxyl group at the C-18 position.',
#  'C0000176': "19-Iodocholest-5-en-3 beta-ol. A cholesterol derivative usually substituted with radioactive iodine in the 19 position. The compound is an adrenal cortex scanning agent used in the assessment of patients suspected of having Cushing's syndrome, hyperaldosteronism, pheochromocytoma and adrenal remnants following total adrenalectomy.",
#  'C0000184': "Nucleoside-2',3'-cyclic phosphate nucleotidohydrolase. Enzymes that catalyze the hydrolysis of the 2'- or 3'- phosphate bonds of 2',3'-cyclic nucleotides. Also hydrolyzes nucleoside monophosphates. Includes EC 3.1.4.16 and EC 3.1.4.37. EC 3.1.4.-.",
#  'C0000189': "An enzyme that catalyzes the conversion of ATP into a series of (2'-5') linked oligoadenylates and pyrophosphate in the presence of double-stranded RNA. These oligonucleotides activate an endoribonuclease (RNase L) which cleaves single-stranded RNA. Interferons can act as inducers of these reactions.",
#  'C0000194': 'A reagent used for the determination of iron.',
#  'C0000204': 'Metabolite of ASCORBIC ACID and the oxidized form of the lactone DEHYDROASCORBIC ACID.',
#  'C0000215': 'An herbicide with strong irritant properties. Use of this compound on rice fields, orchards, sugarcane, rangeland, and other noncrop sites was terminated by the EPA in 1985. (From Merck Index, 11th ed)',
#  'C0000220': 'An herbicide with irritant effects on the eye and the gastrointestinal system.',
#  'C0000232': 'A dye used as a reagent in the determination of vitamin C.',
#  'C0000246': 'An enzyme involved in the biosynthesis of isoleucine and valine. It converts 2-acetolactate into 3-hydroxy-2-oxo-isovalerate. Also acts on 2-hydroxy-2-acetobutyrate to form 2-hydroxy-2-oxo-3-methylvalerate. EC 5.4.99.3.',
#  'C0000248': 'A hepatic carcinogen whose mechanism of activation involves N-hydroxylation to the aryl hydroxamic acid followed by enzymatic sulfonation to sulfoxyfluorenylacetamide. It is used to study the carcinogenicity and mutagenicity of aromatic amines.',
#  'C0000254': 'The D-enantiomer is a potent and specific antagonist of NMDA glutamate receptors (RECEPTORS, N-METHYL-D-ASPARTATE). The L form is inactive at NMDA receptors but may affect the AP4 (2-amino-4-phosphonobutyrate; APB) excitatory amino acid receptors.',
#  'C0000257': 'A metabolite in the principal biochemical pathway of lysine. It antagonizes neuroexcitatory activity modulated by the glutamate receptor, N-METHYL-D-ASPARTATE; (NMDA).',
#  'C0000263': 'A purine that is an isomer of ADENINE (6-aminopurine).',
#  'C0000275': '2-Chloroadenosine. A metabolically stable analog of adenosine which acts as an adenosine receptor agonist. The compound has a potent effect on the peripheral and central nervous system.',
#  'C0000287': "A chemical reagent that reacts with and modifies chemically the tryptophan portion of protein molecules. Used for 'active site' enzyme studies and other protein studies. Sometimes referred to as Koshland's reagent.",
#  'C0000289': 'Simple amine found in the brain. It may be modulator of sympathetic functions. Its derivatives are adrenergic agonists and antagonists. It is also used in chemical industry.',
#  'C0000291': 'An enzyme that catalyzes the first step in the biosynthetic pathway to LEUCINE, forming isopropyl malate from acetyl-CoA and alpha-ketoisovaleric acid. This enzyme was formerly listed as EC 4.1.3.12.',
#  'C0000294': 'A sulfhydryl compound used to prevent urothelial toxicity by inactivating metabolites from ANTINEOPLASTIC AGENTS, such as IFOSFAMIDE or CYCLOPHOSPHAMIDE.',
#  'C0000300': 'A naphthalene derivative with carcinogenic action.',
#  'C0000324': 'A group of enzymes that catalyze the reversible reduction-oxidation reaction of 20-hydroxysteroids, such as from a 20-ketosteroid to a 20-alpha-hydroxysteroid (EC 1.1.1.149) or to a 20-beta-hydroxysteroid (EC 1.1.1.53).',
#  'C0000325': 'A polycyclic aromatic hydrocarbon that consists of five fused rings with carcinogenic activity. 20-Methylcholanthrene is often used in experimental cancer studies.',
#  'C0000334': 'A physiologically active metabolite of VITAMIN D. The compound is involved in the regulation of calcium metabolism, alkaline phosphatase activity, and enhances the calcemic effect of CALCITRIOL.',
#  'C0000340': 'A mitochondrial cytochrome P450 enzyme that catalyzes the 1-alpha-hydroxylation of 25-hydroxyvitamin D3 (also known as 25-hydroxycholecalciferol) in the presence of molecular oxygen and NADPH-FERRIHEMOPROTEIN REDUCTASE. This enzyme, encoded by CYP27B1 gene, converts 25-hydroxyvitamin D3 to 1-alpha,25-dihydroxyvitamin D3 which is the active form of VITAMIN D in regulating bone growth and calcium metabolism. This enzyme is also active on plant 25-hydroxyvitamin D2 (ergocalciferol).',
#  'C0000343': '9,10-Secoergosta-5,7,10(19),22-tetraene-3,25-diol. Biologically active metabolite of vitamin D2 which is more active in curing rickets than its parent. The compound is believed to attach to the same receptor as vitamin D2 and 25-hydroxyvitamin D3.',
#  'C0000359': "Enzymes that catalyze the hydrolysis of CYCLIC AMP to form adenosine 5'-phosphate. The enzymes are widely distributed in animal tissue and control the level of intracellular cyclic AMP. Many specific enzymes classified under this heading demonstrate additional spcificity for 3',5'-cyclic IMP and CYCLIC GMP.",
#  'C0000360': "Enzymes that catalyze the hydrolysis of cyclic GMP to yield guanosine-5'-phosphate.",
#  'C0000370': 'A material used in the manufacture of azo dyes that is toxic to skin and carcinogenic in several species.',
#  'C0000376': 'A deaminated metabolite of LEVODOPA.',
#  'C0000378': "A precursor of noradrenaline that is used in the treatment of parkinsonism. The racemic form (DL-threo-3,4-dihydroxyphenylserine) has also been used, and has been investigated in the treatment of orthostatic hypotension. There is a deficit of noradrenaline as well as of dopamine in Parkinson's disease and it has been proposed that this underlies the sudden transient freezing seen usually in advanced disease. Administration of DL-threo-3,4-dihydroxyphenylserine has been claimed to result in an improvement in this phenomenon but controlled studies have failed to demonstrate improvement. (Reynolds JEF(Ed): Martindale: The Extra Pharmacopoeia (electronic version). Micromedex, Inc, Englewood, CO, 1995)",
#  'C0000379': 'An amphetamine derivative that inhibits uptake of catecholamine neurotransmitters. It is a hallucinogen. It is less toxic than its methylated derivative but in sufficient doses may still destroy serotonergic neurons and has been used for that purpose experimentally.',
#  'C0000392': 'An amino acid formed in vivo by the degradation of dihydrouracil and carnosine. Since neuronal uptake and neuronal receptor sensitivity to beta-alanine have been demonstrated, the compound may be a false transmitter replacing GAMMA-AMINOBUTYRIC ACID. A rare genetic disorder, hyper-beta-alaninemia, has been reported.',
#  'C0000399': '4-Hydroxy-1-(beta-D-ribofuranosyl)-2-pyridinone. Analog of uridine lacking a ring-nitrogen in the 3-position. Functions as an antineoplastic agent.',
#  'C0000402': 'An antilipemic agent which lowers cholesterol, triglycerides, serum beta-lipoproteins and phospholipids. It acts by interfering with the enzymatic steps involved in the conversion of acetate to hydroxymethylglutaryl coenzyme A as well as inhibiting the activity of HYDROXYMETHYLGLUTARYL COA REDUCTASES which is the rate limiting enzyme in the biosynthesis of cholesterol.',
#  'C0000404': 'Enzymes that reversibly catalyze the oxidation of a 3-hydroxyacyl CoA to 3-ketoacyl CoA in the presence of NAD. They are key enzymes in the oxidation of fatty acids and in mitochondrial fatty acid synthesis.',
#  'C0000407': 'An oxidation product of tryptophan metabolism. It may be a free radical scavenger and a carcinogen.',
#  'C0000413': 'Catalyze the oxidation of 3-hydroxysteroids to 3-ketosteroids.',
#  'C0000424': 'An inhibitor of glutamate decarboxylase. It decreases the GAMMA-AMINOBUTYRIC ACID concentration in the brain, thereby causing convulsions.',
#  'C0000427': 'Metabolite of serotonin and norepinephrine.',
#  'C0000435': 'An enzyme of long-chain fatty acid synthesis, that adds a two-carbon unit from malonyl-(acyl carrier protein) to another molecule of fatty acyl-(acyl carrier protein), giving a beta-ketoacyl-(acyl carrier protein) with the release of carbon dioxide. EC 2.3.1.41.',
#  'C0000473': 'An aminobenzoic acid isomer that combines with pteridine and GLUTAMIC ACID to form FOLIC ACID. The fact that 4-aminobenzoic acid absorbs light throughout the UVB range has also resulted in its use as an ingredient in SUNSCREENS.',
#  'C0000477': 'One of the POTASSIUM CHANNEL BLOCKERS, with secondary effect on calcium currents, which is used mainly as a research tool and to characterize channel subtypes.',
#  'C0000481': 'One of the FURANS with a carbonyl thereby forming a cyclic lactone. It is an endogenous compound made from gamma-aminobutyrate and is the precursor of gamma-hydroxybutyrate. It is also used as a pharmacological agent and solvent.',
#  'C0000498': 'A potent mutagen and carcinogen. It is a reduction product of 4-NITROQUINOLINE-1-OXIDE. It binds with nucleic acids and inactivates both bacteria and bacteriophage.',
#  'C0000500': 'A flavoprotein that catalyzes the synthesis of protocatechuic acid from 4-hydroxybenzoate in the presence of molecular oxygen. EC 1.14.13.2.',
#  'C0000503': 'hydroxy derivative of butyric acid substituted at the gamma, or 4 position; intermediate in the metabolism of gamma-aminobutyric acid (GABA).',
#  'C0000506': 'Substances found in many plants, containing the 4-hydroxycoumarin radical. They interfere with vitamin K and the blood clotting mechanism, are tightly protein-bound, inhibit mitochondrial and microsomal enzymes, and are used as oral anticoagulants.',
#  'C0000507': 'An enzyme that catalyzes the conversion of 4-hydroxyphenylpyruvate plus oxygen to homogentisic acid and carbon dioxide. EC 1.13.11.27.',
#  'C0000511': 'A potent mutagen and carcinogen. This compound and its metabolite 4-HYDROXYAMINOQUINOLINE-1-OXIDE bind to nucleic acids. It inactivates bacteria but not bacteriophage.',
#  'C0000530': "A glycoprotein enzyme present in various organs and in many cells. The enzyme catalyzes the hydrolysis of a 5'-ribonucleotide to a ribonucleoside and orthophosphate in the presence of water. It is cation-dependent and exists in a membrane-bound and soluble form. EC 3.1.3.5.",
#  'C0000543': 'Tryptamine substituted with two hydroxyl groups in positions 5 and 6. It is a neurotoxic serotonin analog that destroys serotonergic neurons preferentially and is used in neuropharmacologic research.',
#  'C0000544': 'Tryptamine substituted with two hydroxyl groups in positions 5 and 7. It is a neurotoxic serotonin analog that destroys serotonergic neurons preferentially and is used in neuropharmacology as a tool.',
#  'C0000545': 'Important polyunsaturated fatty acid found in fish oils. It serves as the precursor for the prostaglandin-3 and thromboxane-3 families. A diet rich in eicosapentaenoic acid lowers serum lipid concentration, reduces incidence of cardiovascular disorders, prevents platelet aggregation, and inhibits arachidonic acid conversion into the thromboxane-2 and prostaglandin-2 families.',
#  'C0000546': 'A 20-carbon unsaturated fatty acid containing 4 alkyne bonds. It inhibits the enzymatic conversion of arachidonic acid to prostaglandins E(2) and F(2a).',
#  'C0000551': 'The unspecified form of the steroid, normally a major metabolite of TESTOSTERONE with androgenic activity. It has been implicated as a regulator of gonadotropin secretion.',
#  'C0000578': 'The immediate precursor in the biosynthesis of SEROTONIN from tryptophan. It is used as an antiepileptic and antidepressant.',
#  'C0000588': 'major of two hallucinogenic components of Teonanacatl, the sacred mushroom of Mexico, the other component being psilocin.',
#  'C0000589': 'Serotonin derivative proposed as potentiator for hypnotics and sedatives.',
#  'C0000598': 'The hydrochloride salt form of ticlopidine, a thienopyridine derivative with anticoagulant property. Ticlopidine hydrochloride irreversibly inhibits adenosine-diphosphate (ADP)-induced platelet-fibrinogen binding by binding to the glycoprotein (GP) IIb/IIIA complex, one of the two purinergic receptors activated by ADP. Inhibition of the receptor activation causes the inhibition of adenylyl cyclase, results in decreased levels of cyclic adenosine monophosphate and thereby interferes with platelet membrane function and subsequent, platelet-platelet interaction, release of platelet granule constituents and prolongation of bleeding time.',
#  'C0000608': 'An antifibrinolytic agent that acts by inhibiting plasminogen activators which have fibrinolytic properties.',
#  'C0000610': 'A vitamin antagonist which has teratogenic effects.',
#  'C0000617': 'The physiologically active and stable hydrolysis product of EPOPROSTENOL. Found in nearly all mammalian tissue.',
#  'C0000618': 'An antimetabolite antineoplastic agent with immunosuppressant properties. It interferes with nucleic acid synthesis by inhibiting purine metabolism and is used, usually in combination with other drugs, in the treatment of or in remission maintenance programs for leukemia.',
#  'C0000641': '7,8,8a,9a-Tetrahydrobenzo(10,11)chryseno (3,4-b)oxirene-7,8-diol. A benzopyrene derivative with carcinogenic and mutagenic activity.',
#  'C0000644': 'A drug-metabolizing enzyme found in the hepatic, placental and intestinal microsomes that metabolizes 7-alkoxycoumarin to 7-hydroxycoumarin. The enzyme is cytochrome P-450- dependent.',
#  'C0000656': 'A stable peptide fragment originating from the N-terminal domain of collagen type IV.',
#  'C0000658': 'A 20-carbon-chain fatty acid, unsaturated at positions 8, 11, and 14. It differs from arachidonic acid, 5,8,11,14-eicosatetraenoic acid, only at position 5.',
#  'C0000661': 'A long-acting derivative of cyclic AMP. It is an activator of cyclic AMP-dependent protein kinase, but resistant to degradation by cyclic AMP phosphodiesterase.',
#  'C0000665': 'An antiseptic with mild fungistatic, bacteriostatic, anthelmintic, and amebicidal action. It is also used as a reagent and metal chelator, as a carrier for radio-indium for diagnostic purposes, and its halogenated derivatives are used in addition as topical anti-infective agents and oral antiamebics.',
#  'C0000677': '7,12-Dimethylbenzanthracene. Polycyclic aromatic hydrocarbon found in tobacco smoke that is a potent carcinogen.',
#  'C0000696': 'Type A fibers are the myelinated fibers ranging from 1-22 um in diameter with NEURAL CONDUCTION rates of 5-120 m/sec. They are the typical myelinated fibers of spinal nerves. Type A fibers are further subdivided into alpha, beta, gamma, and delta fibers.',
#  'C0000697': 'A type of gamma-globin encoded by the A gamma globin gene on CHROMOSOME 11.',
#  'C0000699': 'An ionophorous, polyether antibiotic from Streptomyces chartreusensis. It binds and transports CALCIUM and other divalent cations across membranes and uncouples oxidative phosphorylation while inhibiting ATPase of rat liver mitochondria. The substance is used mostly as a biochemical tool to study the role of divalent cations in various biological systems.',
#  'C0000702': 'An isoform of DNA that occurs in an environment rich in SODIUM and POTASSIUM ions. It is a right-handed helix with 11 base pairs per turn, a pitch of 0.256 nm per base pair and a helical diameter of 2.3 nm.',
#  'C0000714': 'An organothiophosphate insecticide.',
#  'C0000715': 'Places where animals are slaughtered and dressed for market.',
#  'C0000722': 'Classification system for assessing impact injury severity developed and published by the American Association for Automotive Medicine. It is the system of choice for coding single injuries and is the foundation for methods assessing multiple injuries or for assessing cumulative effects of more than one injury. These include Maximum AIS (MAIS), Injury Severity Score (ISS), and Probability of Death Score (PODS).',
#  'C0000723': 'Works consisting of lists of shortened forms of written words or phrases used for brevity. Acronyms are included here.',
#  'C0000726': 'That portion of the body that lies between the THORAX and the PELVIS.',
#  'C0000727': 'A clinical syndrome with acute abdominal pain that is severe, localized, and rapid in onset. Acute abdomen may be caused by a variety of disorders, injuries, or diseases.',
#  'C0000729': 'An involuntary muscular contraction involving a muscle of the abdomen or of a hollow organ within the abdomen.',
#  'C0000731': 'Distention of the abdomen. [HPO:probinson]',
#  'C0000734': 'An abnormal growth in the abdomen.',
#  'C0000735': 'New abnormal growth of tissue in the ABDOMEN.',
#  'C0000737': 'Sensation of discomfort, distress, or agony in the abdominal region.',
#  'C0000739': 'Muscles forming the ABDOMINAL WALL including RECTUS ABDOMINIS; ABDOMINAL OBLIQUE MUSCLES, transversus abdominis, pyramidalis muscles and quadratus abdominis.',
#  'C0000741': 'The 6th cranial nerve which originates in the ABDUCENS NUCLEUS of the PONS and sends motor fibers to the lateral rectus muscles of the EYE. Damage to the nerve or its nucleus disrupts horizontal eye movement control.',
#  'C0000742': 'A replication-defective strain of Murine leukemia virus (LEUKEMIA VIRUS, MURINE) capable of transforming lymphoid cells and producing a rapidly progressing lymphoid leukemia after superinfection with FRIEND MURINE LEUKEMIA VIRUS; MOLONEY MURINE LEUKEMIA VIRUS; or RAUSCHER VIRUS.',
#  'C0000744': 'An autosomal recessive disorder of lipid metabolism. It is caused by mutation of the microsomal triglyceride transfer protein that catalyzes the transport of lipids (TRIGLYCERIDES; CHOLESTEROL ESTERS; PHOSPHOLIPIDS) and is required in the secretion of BETA-LIPOPROTEINS (low density lipoproteins or LDL). Features include defective intestinal lipid absorption, very low serum cholesterol level, and near absent LDL.',
#  'C0000768': 'Malformations of organs or body parts during development in utero.',
#  'C0000769': 'Used with organs for congenital defects producing changes in the morphology of the organ. It is used also for abnormalities in animals.',
#  'C0000771': 'Congenital abnormalities caused by medicinal substances or drugs of abuse given to or taken by the mother, or to which she is inadvertently exposed during the manufacture of such substances. The concept excludes abnormalities resulting from exposure to non-medicinal chemicals in the environment.',
#  'C0000772': 'Congenital abnormalities that affect more than one organ or body structure.',
#  'C0000773': 'Congenital changes in the morphology of organs produced by exposure to ionizing or non-ionizing radiation.',
#  'C0000778': 'The major human blood type system which depends on the presence or absence of two antigens A and B. Type O occurs when neither A nor B is present and AB when both are present. A and B are genetic factors that determine the presence of enzymes for the synthesis of certain glycoproteins mainly in the red cell membrane.',
#  'C0000780': 'The fourth stomach of ruminating animals. It is also called the "true" stomach. It is an elongated pear-shaped sac lying on the floor of the abdomen, on the right-hand side, and roughly between the seventh and twelfth ribs. It leads to the beginning of the small intestine. (From Black\'s Veterinary Dictionary, 17th ed)',
#  'C0000781': 'A mammalian fetus expelled by INDUCED ABORTION or SPONTANEOUS ABORTION.',
#  'C0000782': 'Chemical substances that interrupt pregnancy after implantation.',
#  'C0000783': 'Non-steroidal chemical compounds with abortifacient activity.',
#  'C0000784': 'Steroidal compounds with abortifacient activity.',
#  'C0000786': 'Expulsion of the product of FERTILIZATION before completing the term of GESTATION and without deliberate interference.',
#  'C0000788': 'Individuals requesting induced abortions.',
#  'C0000804': 'Illegal termination of pregnancy.',
#  'C0000806': 'Abortion performed because of possible fetal defects.',
#  'C0000809': 'Three or more consecutive spontaneous abortions.',
#  'C0000810': 'Premature loss of PREGNANCY in which not all the products of CONCEPTION have been expelled.',
#  'C0000812': 'Termination of pregnancy under conditions allowed under local laws. (POPLINE Thesaurus, 1991)',
#  'C0000814': 'The retention in the UTERUS of a dead FETUS two months or more after its DEATH.',
#  'C0000817': 'Any type of abortion, induced or spontaneous, that is associated with infection of the UTERUS and its appendages. It is characterized by FEVER, uterine tenderness, and foul discharge.',
#  'C0000820': 'Abortion induced to save the life or health of a pregnant woman. (From Dorland, 28th ed)',
#  'C0000821': 'UTERINE BLEEDING from a GESTATION of less than 20 weeks without any CERVICAL DILATATION. It is characterized by vaginal bleeding, lower back discomfort, or midline pelvic cramping and a risk factor for MISCARRIAGE.',
#  'C0000823': 'Premature expulsion of the FETUS in animals.',
#  'C0000828': 'A process in psychotherapy in which the patient is "desensitized" to emotionally painful, often forgotten (repressed) memories by recalling and reacting to them in the "safety" of the treatment setting.',
#  'C0000829': 'A toxic lectin from the seeds of jequirity, Abrus precatorius L. Very active poison. Five different proteins have so far been isolated: Abrus agglutinin, the component responsible for: hemagglutinating activity, & abrins a-d, the toxic principals each consisting of two peptide chains are held together by disulfide bonds.',
#  'C0000832': 'Premature separation of the normally implanted PLACENTA from the UTERUS. Signs of varying degree of severity include UTERINE BLEEDING, uterine MUSCLE HYPERTONIA, and FETAL DISTRESS or FETAL DEATH.',
#  'C0000833': 'Accumulation of purulent material in tissues, organs, or circumscribed spaces, usually associated with signs of infection.',
#  'C0000843': 'Abscission-accelerating plant growth substance isolated from young cotton fruit, leaves of sycamore, birch, and other plants, and from potatoes, lemons, avocados, and other fruits.',
#  'C0000846': 'A congenital abnormality resulting in the absence of an anatomical structure.',
#  'C0000849': 'Chronic absence from work or other duty.',
#  'C0000850': 'A genus of zygomycetous fungi, family Mucoraceae, order MUCORALES, which sometimes causes infection in humans.',
#  'C0000853': 'A noninvasive method for assessing BODY COMPOSITION. It is based on the differential absorption of X-RAYS (or GAMMA RAYS) by different tissues such as bone, fat and other soft tissues. The source of (X-ray or gamma-ray) photon beam is generated either from radioisotopes such as GADOLINIUM 153, IODINE 125, or Americanium 241 which emit GAMMA RAYS in the appropriate range; or from an X-ray tube which produces X-RAYS in the desired range. It is primarily used for quantitating BONE MINERAL CONTENT, especially for the diagnosis of OSTEOPOROSIS, and also in measuring BONE MINERALIZATION.',
#  'C0000854': 'The physical or physiological processes by which substances, tissue, cells, etc. take up or take in other substances or energy.',
#  'C0000857': 'The process of creating a summary of the main points of an article, argument, or theory.',
#  'C0000858': 'Activities performed to identify concepts and aspects of published information and research reports.',
#  'C0000866': 'Natural teeth or teeth roots used as anchorage for a fixed or removable denture or other prosthesis (such as an implant) serving the same purpose.',
#  'C0000869': 'A plant genus of the family FABACEAE. The gums and tanning agents obtained from Acacia are called GUM ARABIC. The common name of catechu is more often used for Areca catechu (ARECA).',
#  'C0000872': 'Medical complexes consisting of medical school, hospitals, clinics, libraries, administrative facilities, etc.',
#  'C0000877': 'Organizations representing specialized fields which are accepted as authoritative; may be non-governmental, university or an independent research organization, e.g., National Academy of Sciences, Brookings Institution, etc.',
#  'C0000879': 'A genus of free-living soil amoebae that produces no flagellate stage. Its organisms are pathogens for several infections in humans and have been found in the eye, bone, brain, and respiratory tract.',
#  'C0000880': 'Infection of the cornea by an ameboid protozoan which may cause corneal ulceration leading to blindness.',
#  'C0000881': 'A phylum of parasitic worms, closely related to tapeworms and containing two genera: Moniliformis, which sometimes infects man, and Macracanthorhynchus, which infects swine.',
#  'C0000886': 'Erythrocytes with protoplasmic projections giving the cell a thorny appearance.',
#  'C0000887': 'Separation of the prickle cells of the stratum spinosum of the epidermis, resulting in atrophy of the prickle cell layer. It is seen in diseases such as pemphigus vulgaris (see PEMPHIGUS) and DARIER DISEASE.',
#  'C0000889': 'A circumscribed melanosis consisting of a brown-pigmented, velvety verrucosity or fine papillomatosis appearing in the axillae and other body folds. It occurs in association with endocrine disorders, underlying malignancy, administration of certain drugs, or as in inherited disorder.',
#  'C0000890': 'A large, subclass of arachnids comprising the MITES and TICKS, including parasites of plants, animals, and humans, as well as several important disease vectors.',
#  'C0000894': 'An increase in the rate of speed.',
#  'C0000905': 'The 11th cranial nerve which originates from NEURONS in the MEDULLA and in the CERVICAL SPINAL CORD. It has a cranial root, which joins the VAGUS NERVE (10th cranial) and sends motor fibers to the muscles of the LARYNX, and a spinal root, which sends motor fibers to the TRAPEZIUS and the sternocleidomastoid muscles.',
#  'C0000918': 'Efforts and designs to reduce the incidence of unexpected undesirable events in various environments and situations.',
#  'C0000919': 'Tendency toward involvement in accidents. Implies certain personality characteristics which predispose to accidents.',
#  'C0000921': 'Falls due to slipping or tripping which may result in injury.',
#  'C0000924': 'Unexpected and unintentional events, typically resulting in damage or injury.',
#  'C0000925': 'A wound or cleft resulted from tissue separation into parts or laid open or penetrated with a sharp edge or instrument.',
#  'C0000928': 'Unanticipated events associated with AIRCRAFT.',
#  'C0000929': 'ACCIDENTS which occur within the home.',
#  'C0000930': 'An accident taking place on the site of a commercial enterprise.',
#  'C0000931': 'Unforeseen occurrences, especially injuries in the course of work-related activities.',
#  'C0000932': 'Accidents on streets, roads, and highways involving drivers, passengers, pedestrians, or vehicles. Traffic accidents refer to AUTOMOBILES (passenger cars, buses, and trucks), BICYCLING, and MOTORCYCLES but not OFF-ROAD MOTOR VEHICLES; RAILROADS nor snowmobiles.',
#  'C0000934': 'Adaptation to a new environment or to a change in the old.',
#  'C0000936': 'The dioptric adjustment of the EYE (to attain maximal sharpness of retinal imagery for an object of regard) referring to the ability, to the mechanism, or to the process. Ocular accommodation is the effecting of refractive changes by changes in the shape of the CRYSTALLINE LENS. Loosely, it refers to ocular adjustments for VISION, OCULAR at various distances. (Cline et al., Dictionary of Visual Science, 4th ed)',
#  'C0000938': 'System of recording financial transactions.',
#  'C0000940': 'Short-term debt obligations and assets occurring in the regular course of operational transactions.',
#  'C0000941': 'Certification as complying with a standard set by non-governmental organizations, applied for by institutions, programs, and facilities on a voluntary basis.',
#  'C0000943': 'Process of cultural change in which one group or members of a group assimilate various cultural patterns from another.',
#  'C0000946': 'A cardioselective beta-1 adrenergic antagonist with little effect on the bronchial receptors. The drug has stabilizing and quinidine-like effects on cardiac rhythm, as well as weak inherent sympathomimetic action.',
#  'C0000949': 'Acetylated sulfone that is slowly metabolized to give long-term, low blood levels of DAPSONE. It has antimicrobial and antimalarial action, but is mainly used as a depot leprostatic agent.',
#  'C0000954': 'Tricyclic ethylene-bridged naphthalene derivatives. They are found in petroleum residues and coal tar and used as dye intermediates, in the manufacture of plastics, and in insecticides and fungicides.',
#  'C0000956': 'A coumarin that is used as an anticoagulant. Its actions and uses are similar to those of WARFARIN. (From Martindale, The Extra Pharmacopoeia, 30th ed, p233)',
#  'C0000959': 'A phenothiazine that is used in the treatment of PSYCHOSES.',
#  'C0000960': 'The maleate salt of acepromazine, a phenothiazine derivative with depressant effect on the central nervous system. Acepromazine acts as a dopamine receptor antagonist in the CNS, thereby causing sedation, muscular relaxation and a reduction in spontaneous activity. Its fast-acting neuroleptic effect with low toxicity is of particular value in veterinary medicine.',
#  'C0000961': 'A genus of green algae found in the Mediterranean and other warm seas.',
#  'C0000962': 'The part of the pelvis that comprises the pelvic socket where the head of FEMUR joins to form HIP JOINT (acetabulofemoral joint).',
#  'C0000966': 'A colorless, flammable liquid used in the manufacture of acetic acid, perfumes, and flavors. It is also an intermediate in the metabolism of alcohol. It has a general narcotic action and also causes irritation of mucous membranes. Large doses may cause death from respiratory paralysis.',
#  'C0000967': "Diethers with the structure -C(OR'')(OR'''), where R'' and R''' are not hydrogen. Mixed acetals have R'' and R''' groups which differ.",
#  'C0000968': 'Derivatives of acetamide that are used as solvents, as mild irritants, and in organic synthesis.',
#  'C0000970': 'Analgesic antipyretic derivative of acetanilide. It has weak anti-inflammatory properties and is used as a common analgesic, but may cause liver, blood cell, and kidney damage.',
#  'C0000974': 'Compounds based on N-phenylacetamide, that are similar in structure to 2-PHENYLACETAMIDES. They are precursors of many other compounds. They were formerly used as ANALGESICS and ANTIPYRETICS, but often caused lethal METHEMOGLOBINEMIA.',
#  'C0000975': 'a chemical substance name',
#  'C0000977': 'An enzyme that catalyzes reversibly the phosphorylation of acetate in the presence of a divalent cation and ATP with the formation of acetylphosphate and ADP. It is important in the glycolysis process. EC 2.7.2.1.',
#  'C0000979': 'Derivatives of ACETIC ACID. Included under this heading are a broad variety of acid forms, salts, esters, and amides that contain the carboxymethane structure.',
#  'C0000981': 'One of the CARBONIC ANHYDRASE INHIBITORS that is sometimes effective against absence seizures. It is sometimes useful also as an adjunct in the treatment of tonic-clonic, myoclonic, and atonic seizures, particularly in women whose seizures occur or are exacerbated at specific times in the menstrual cycle. However, its usefulness is transient often because of rapid development of tolerance. Its antiepileptic effect may be due to its inhibitory effect on brain carbonic anhydrase, which leads to an increased transneuronal chloride gradient, increased chloride current, and increased inhibition. (From Smith and Reynard, Textbook of Pharmacology, 1991, p337)',
#  'C0000983': 'Product of the oxidation of ethanol and of the destructive distillation of wood. It is used locally, occasionally internally, as a counterirritant and also as a reagent. (Stedman, 26th ed)',
#  'C0000987': 'Compounds used extensively as acetylation, oxidation and dehydrating agents and in the modification of proteins and enzymes.',
#  'C0000988': 'Salts and derivatives of acetoacetic acid.',
#  'C0000990': 'A species of gram-negative bacteria of the family ACETOBACTERACEAE found in FLOWERS and FRUIT. Cells are ellipsoidal to rod-shaped and straight or slightly curved.',
#  'C0000992': 'A sulfonylurea hypoglycemic agent that is metabolized in the liver to 1-hydrohexamide.',
#  'C0000996': 'A product of fermentation. It is a component of the butanediol cycle in microorganisms. In mammals it is oxidized to carbon dioxide.',
#  'C0000997': 'An enzyme that catalyzes the conversion of acetoin to diacetyl in the presence of NAD.',
#  'C0000999': 'A flavoprotein enzyme that catalyzes the formation of acetolactate from 2 moles of PYRUVATE in the biosynthesis of VALINE and the formation of acetohydroxybutyrate from pyruvate and alpha-ketobutyrate in the biosynthesis of ISOLEUCINE. This enzyme was formerly listed as EC 4.1.3.18.',
#  'C0001002': 'A colorless liquid used as a solvent and an antiseptic. It is one of the ketone bodies produced during ketoacidosis.',
#  'C0001004': 'Compounds in which a methyl group is attached to the cyano moiety.',
#  'C0001011': 'An alkylating agent that forms DNA ADDUCTS at the C-8 position in GUANINE, resulting in single strand breaks. It has demonstrated carcinogenic action.',
#  'C0001017': 'An iodinated radiographic contrast medium used as acetrizoate sodium in HYSTEROSALPINGOGRAPHY.',
#  'C0001019': 'An enzyme that catalyzes the formation of acetoacetyl-CoA from two molecules of ACETYL COA. Some enzymes called thiolase or thiolase-I have referred to this activity or to the activity of ACETYL-COA C-ACYLTRANSFERASE.',
#  'C0001021': 'Enzyme that catalyzes the final step of fatty acid oxidation in which ACETYL COA is released and the CoA ester of a fatty acid two carbons shorter is formed.',
#  'C0001022': 'A carboxylating enzyme that catalyzes the conversion of ATP, acetyl-CoA, and HCO3- to ADP, orthophosphate, and malonyl-CoA. It is a biotinyl-protein that also catalyzes transcarboxylation. The plant enzyme also carboxylates propanoyl-CoA and butanoyl-CoA (From Enzyme Nomenclature, 1992) EC 6.4.1.2.',
#  'C0001024': 'An enzyme that catalyzes reversibly the hydrolysis of acetyl-CoA to yield CoA and acetate. The enzyme is involved in the oxidation of fatty acids. EC 3.1.2.1.',
#  'C0001026': 'Acetyl CoA participates in the biosynthesis of fatty acids and sterols, in the oxidation of fatty acids and in the metabolism of many amino acids. It also acts as a biological acetylating agent.',
#  'C0001028': 'An enzyme that catalyzes the formation of CoA derivatives from ATP, acetate, and CoA to form AMP, pyrophosphate, and acetyl CoA. It acts also on propionates and acrylates. EC 6.2.1.1.',
#  'C0001034': 'hepatic carcinogen whose mechanism of activation involves N-hydroxylation to the arylhydroxamic acid followed by enzymatic sulfonation to sulfoxyfluorenylacetamide; used to study the carcinogenicity and mutagenicity of aromatic amines.',
#  'C0001038': 'Formation of an acetyl derivative. (Stedman, 25th ed)',
#  'C0001040': 'An acetic acid ester of CARNITINE that facilitates movement of ACETYL COA into the matrices of mammalian MITOCHONDRIA during the oxidation of FATTY ACIDS.',
#  'C0001041': 'A neurotransmitter found at neuromuscular junctions, autonomic ganglia, parasympathetic effector junctions, a subset of sympathetic effector junctions, and at many sites in the central nervous system.',
#  'C0001044': 'An enzyme that catalyzes the hydrolysis of ACETYLCHOLINE to CHOLINE and acetate. In the CNS, this enzyme plays a role in the function of peripheral neuromuscular junctions. EC 3.1.1.7.',
#  'C0001046': 'Any substance that inhibits acetylcholinesterase (AchE), an enzyme that breaks down acetylcholine (Ach) in the synaptic cleft. Inhibition of acetylcholinesterase results in an increase in the level and duration of action of acetylcholine.',
#  'C0001047': 'The N-acetyl derivative of CYSTEINE. It is used as a mucolytic agent to reduce the viscosity of mucous secretions. It has also been shown to have antiviral effects in patients with HIV due to inhibition of viral stimulation by reactive oxygen intermediates.',
#  'C0001049': 'Cardioactive derivatives of lanatoside A or of DIGITOXIN. They are used for fast digitalization in congestive heart failure.',
#  'C0001050': 'Alpha- or beta-acetyl derivatives of DIGOXIN or lanatoside C from Digitalis lanata. They are better absorbed and longer acting than digoxin and are used in congestive heart failure.',
#  'C0001052': 'The simplest two carbon alkyne with the formula HCCH.',
#  'C0001053': 'An enzyme that catalyzes the conversion of acetate esters and water to alcohols and acetate. EC 3.1.1.6.',
#  'C0001055': 'The N-acetyl derivative of galactosamine.',
#  'C0001056': 'The N-acetyl derivative of glucosamine.',
#  'C0001057': 'A beta-N-Acetylhexosaminidase that catalyzes the hydrolysis of terminal, non-reducing 2-acetamido-2-deoxy-beta-glucose residues in chitobiose and higher analogs as well as in glycoproteins. Has been used widely in structural studies on bacterial cell walls and in the study of diseases such as MUCOLIPIDOSIS and various inflammatory disorders of muscle and connective tissue.',
#  'C0001060': 'Peptidoglycan immunoadjuvant originally isolated from bacterial cell wall fragments; also acts as pyrogen and may cause arthritis; stimulates both humoral and cellular immunity.',
#  'C0001061': 'A major metabolite of PROCAINAMIDE. Its anti-arrhythmic action may cause cardiac toxicity in kidney failure.',
#  'C0001064': 'An enzyme that catalyzes the transfer of a methyl group from S-adenosylmethionine to N-acetylserotonin to form N-acetyl-5-methoxytryptamine (MELATONIN).',
#  'C0001066': 'An agent used as a substrate in assays for cholinesterases, especially to discriminate among enzyme types.',
#  'C0001068': 'Enzymes catalyzing the transfer of an acetyl group, usually from acetyl coenzyme A, to another compound. EC 2.3.1.',
#  'C0001072': 'Success in bringing an effort to the desired end; the degree or level of success attained in some specified area (esp. scholastic) or in general.',
#  'C0001074': 'Tendon that connects the muscles in the back of the calf to the HEEL BONE.',
#  'C0001075': 'A lack of HYDROCHLORIC ACID in GASTRIC JUICE despite stimulation of gastric secretion.',
#  'C0001076': 'A genus of gram-negative organisms including saprophytic and parasitic or pathogenic species.',
#  'C0001077': 'An organism originally isolated from sewage, manure, humus, and soil, but recently found as a parasite in mammals and birds.',
#  'C0001078': 'Gram-negative organisms including apparently free-living saphrophytes as well as mammalian and avian parasites, and possibly pathogens.',
#  'C0001079': 'A rare group of disorders characterized by defective development of bones and cartilage.',
#  'C0001080': 'An autosomal dominant disorder that is the most frequent form of short-limb dwarfism. Affected individuals exhibit short stature caused by rhizomelic shortening of the limbs, characteristic facies with frontal bossing and mid-face hypoplasia, exaggerated lumbar lordosis, limitation of elbow extension, GENU VARUM, and trident hand. (Online Mendelian Inheritance in Man, http://www.ncbi.nlm.nih.gov/Omim, MIM#100800, April 20, 2001)',
#  'C0001084': 'A genus of gram-negative, strictly aerobic, non-spore forming rods. Soil and water are regarded as the natural habitat. They are sometimes isolated from a hospital environment and humans.',
#  'C0001100': 'Preparation of TOOTH surfaces and DENTAL MATERIALS with etching agents, usually phosphoric acid, to roughen the surface to increase adhesion or osteointegration.',
#  'C0001109': 'An enzyme that catalyzes the conversion of an orthophosphoric monoester and water to an alcohol and orthophosphate. EC 3.1.3.2.',
#  'C0001111': 'Acidic water usually pH 2.5 to 4.5, which poisons the ecosystem and adversely affects plants, fishes, and mammals. It is caused by industrial pollutants, mainly sulfur oxides and nitrogen oxides, emitted into the atmosphere and returning to earth in the form of acidic rain water.',
#  'C0001117': 'The balance between acids and bases in the BODY FLUIDS. The pH (HYDROGEN-ION CONCENTRATION) of the arterial BLOOD provides an index for the total body acid-base balance.',
#  'C0001118': 'Disturbances in the ACID-BASE EQUILIBRIUM of the body.',
#  'C0001122': 'A pathologic condition of acid accumulation or depletion of base in the body. The two main types are RESPIRATORY ACIDOSIS and metabolic acidosis, due to metabolic acid build up.',
#  'C0001125': 'Acidosis caused by accumulation of lactic acid more rapidly than it can be metabolized. It may occur spontaneously or in association with diseases such as DIABETES MELLITUS; LEUKEMIA; or LIVER FAILURE.',
#  'C0001126': 'A group of genetic disorders of the KIDNEY TUBULES characterized by the accumulation of metabolically produced acids with elevated plasma chloride, hyperchloremic metabolic ACIDOSIS. Defective renal acidification of URINE (proximal tubules) or low renal acid excretion (distal tubules) can lead to complications such as HYPOKALEMIA, hypercalcinuria with NEPHROLITHIASIS and NEPHROCALCINOSIS, and RICKETS.',
#  'C0001127': 'Respiratory retention of carbon dioxide. It may be chronic or acute.',
#  'C0001128': "Chemical compounds which yield hydrogen ions or protons when dissolved in water, whose hydrogen can be replaced by metals or basic radicals, or which react with bases to form salts and water (neutralization). An extension of the term includes substances dissolved in media other than water. (Grant & Hackh's Chemical Dictionary, 5th ed)",
#  'C0001129': 'Carboxylic acids that have open-chain molecular structures as opposed to ring-shaped structures.',
#  'C0001130': 'Dicarboxylic acids in which one of the carboxyl groups (-COOH) has been replaced by an aldehyde group (-CHO).',
#  'C0001131': 'Carboxylic acids that have a homocyclic ring structure in which all the ring atoms are carbon.',
#  'C0001132': 'A class of acids containing a ring structure in which at least one atom other than CARBON is incorporated.',
#  'C0001133': 'Inorganic acids with a non metal, other than carbon, attached to hydrogen, or an acid radical containing no carbon.',
#  'C0001134': 'A sodium fluoride solution, paste or powder, which has been acidulated to pH 3 to 4 and buffered with a phosphate. It is used in the prevention of dental caries.',
#  'C0001138': 'A genus of gram-negative bacteria of the family MORAXELLACEAE, found in soil and water and of uncertain pathogenicity.',
#  'C0001139': 'Infections with bacteria of the genus ACINETOBACTER.',
#  'C0001143': 'An anthracycline produced by Streptomyces galilaeus. It has potent antineoplastic activity.',
#  'C0001144': 'A chronic disorder of the pilosebaceous apparatus associated with an increase in sebum secretion. It is characterized by open comedones (blackheads), closed comedones (whiteheads), and pustular nodules. The cause is unknown, but heredity and age are predisposing factors.',
#  'C0001145': 'A type of acneiform disorder in which secondary pyogenic infection in and around pilosebaceous structures ends in keloidal scarring. It manifests as persistent folliculitis of the back of the neck associated with occlusion of the follicular orifices. It is most often encountered in black or Asian men.',
#  'C0001156': 'An enzyme that catalyzes the reversible hydration of cis-aconitate to yield citrate or isocitrate. It is one of the citric acid cycle enzymes. EC 4.2.1.3.',
#  'C0001157': 'Dried root of Aconitum napellus.',
#  'C0001158': 'A tricarboxylic acid with the formula (COOH)-CH2-C(COOH)=CH-COOH.',
#  'C0001159': 'A C19 norditerpenoid alkaloid (DITERPENES) from the root of ACONITUM plants. It activates VOLTAGE-GATED SODIUM CHANNELS. It has been used to induce ARRHYTHMIAS in experimental animals and it has antiinflammatory and antineuralgic properties.',
#  'C0001161': 'Objective tests of middle ear function based on the difficulty (impedance) or ease (admittance) of sound flow through the middle ear. These include static impedance and dynamic impedance (i.e., tympanometry and impedance tests in conjunction with intra-aural muscle reflex elicitation). This term is used also for various components of impedance and admittance (e.g., compliance, conductance, reactance, resistance, susceptance).',
#  'C0001162': "The 8th cranial nerve. The vestibulocochlear nerve has a cochlear part (COCHLEAR NERVE) which is concerned with hearing and a vestibular part (VESTIBULAR NERVE) which mediates the sense of balance and head position. The fibers of the cochlear nerve originate from neurons of the SPIRAL GANGLION and project to the cochlear nuclei (COCHLEAR NUCLEUS). The fibers of the vestibular nerve arise from neurons of Scarpa's ganglion and project to the VESTIBULAR NUCLEI.",
#  'C0001163': 'Pathological processes of the VESTIBULOCOCHLEAR NERVE, including the branches of COCHLEAR NERVE and VESTIBULAR NERVE. Common examples are VESTIBULAR NEURITIS, cochlear neuritis, and ACOUSTIC NEUROMA. Clinical signs are varying degree of HEARING LOSS; VERTIGO; and TINNITUS.',
# ...
#  'C0002911': 'Injection of an anesthetic into the nerves to inhibit nerve transmission in a specific part of the body.',
#  'C0002912': 'A range of methods used to reduce pain and anxiety during dental procedures.',
#  'C0002913': 'Procedure in which an anesthetic is injected into the epidural space.',
#  'C0002915': 'Procedure in which patients are induced into an unconscious state through use of various medications so that they do not feel pain during surgery.',
#  'C0002917': 'Anesthesia caused by the breathing of anesthetic gases or vapors or by insufflating anesthetic gases or vapors into the respiratory tract.',
#  'C0002919': 'Procedure in which an anesthetic such as a gas or mixture of gases is inhaled through a tube into the lungs.',
#  'C0002920': 'Process of administering an anesthetic through injection directly into the bloodstream.',
#  'C0002921': 'A blocking of nerve conduction to a specific area by an injection of an anesthetic agent.',
#  'C0002922': 'A variety of anesthetic methods such as EPIDURAL ANESTHESIA used to control the pain of childbirth.',
#  'C0002924': 'Procedure involving the instillation of an anesthetic into the rectum.',
#  'C0002928': 'Procedure in which an anesthetic is injected directly into the spinal cord.',
#  'C0002930': 'A specialty concerned with the study of anesthetics and anesthesia.',
#  'C0002932': 'Agents that are capable of inducing a total or partial loss of sensation, especially tactile sensation and pain. They may act to induce general ANESTHESIA, in which an unconscious state is achieved, or may act locally to induce numbness or lack of sensation at a targeted site.',
#  'C0002933': "Intravenous anesthetics that induce a state of sedation, immobility, amnesia, and marked analgesia. Subjects may experience a strong feeling of dissociation from the environment. The condition produced is similar to NEUROLEPTANALGESIA, but is brought about by the administration of a single drug. (From Gilman et al., Goodman and Gilman's The Pharmacological Basis of Therapeutics, 8th ed)",
#  'C0002934': "Drugs that block nerve conduction when applied locally to nerve tissue in appropriate concentrations. They act on any part of the nervous system and on every type of nerve fiber. In contact with a nerve trunk, these anesthetics can cause both sensory and motor paralysis in the innervated area. Their action is completely reversible. (From Gilman AG, et. al., Goodman and Gilman's The Pharmacological Basis of Therapeutics, 8th ed) Nearly all local anesthetics act by reducing the tendency of voltage-dependent sodium channels to activate.",
#  'C0002935': 'A state of sexual inactivity in female animals exhibiting no ESTROUS CYCLE. Causes of anestrus include pregnancy, presence of offspring, season, stress, and pathology.',
#  'C0002937': 'Choleretic used to allay dry mouth and constipation due to tranquilizers.',
#  'C0002938': 'The chromosomal constitution of cells which deviate from the normal by the addition or subtraction of CHROMOSOMES, chromosome pairs, or chromosome fragments. In a normally diploid cell (DIPLOIDY) the loss of a chromosome pair is termed nullisomy (symbol: 2N-2), the loss of a single chromosome is MONOSOMY (symbol: 2N-1), the addition of a chromosome pair is tetrasomy (symbol: 2N+2), the addition of a single chromosome is TRISOMY (symbol: 2N+1).',
#  'C0002940': 'Pathological outpouching or sac-like dilatation in the wall of any blood vessel (ARTERIES or VEINS) or the heart (HEART ANEURYSM). It indicates a thin and weakened area in the wall which may later rupture. Aneurysms are classified by location, etiology, or other characteristics.',
#  'C0002949': 'An aneurysm caused by a tear in the TUNICA INTIMA of a blood vessel leading to interstitial HEMORRHAGE, and splitting (dissecting) of the vessel wall, often involving the AORTA. Dissection between the tunica intima and TUNICA MEDIA causes luminal occlusion. Dissection at the media, or between the media and the outer ADVENTITIA causes aneurismal dilation.',
#  'C0002950': 'Aneurysm due to growth of microorganisms in the arterial wall, or infection arising within preexisting arteriosclerotic aneurysms.',
#  'C0002957': 'A strong emotional feeling of displeasure aroused by being interfered with, injured or threatened.',
#  'C0002962': 'The symptom of paroxysmal pain consequent to MYOCARDIAL ISCHEMIA usually of distinctive character, location and radiation. It is thought to be provoked by a transient stressful situation during which the oxygen requirements of the MYOCARDIUM exceed that supplied by the CORONARY CIRCULATION.',
#  'C0002963': 'A clinical syndrome characterized by the development of CHEST PAIN at rest with concomitant transient ST segment elevation in the ELECTROCARDIOGRAM, but with preserved exercise capacity.',
#  'C0002965': 'Precordial pain at rest, which may precede a MYOCARDIAL INFARCTION.',
#  'C0002971': 'Radiography of the heart and great vessels after injection of a contrast medium.',
#  'C0002976': 'group of agents that induce or stimulate the physiologic angiogenesis process.',
#  'C0002978': 'Radiography of blood vessels after injection of a contrast medium.',
#  'C0002979': 'A method of delineating blood vessels by subtracting a tissue background image from an image of tissue plus intravascular contrast material that attenuates the X-ray photons. The background image is determined from a digitized image taken a few moments before injection of the contrast material. The resulting angiogram is a high-contrast image of the vessel. This subtraction technique allows extraction of a high-intensity signal from the superimposed background information. The image is thus the result of the differential absorption of X-rays by different tissues.',
#  'C0002982': 'Small breaks in the elastin-filled tissue of the retina.',
#  'C0002985': 'A vascular, horny neoplasm of the skin characterized by TELANGIECTASIS and secondary epithelial changes including acanthosis and hyperkeratosis.',
#  'C0002986': 'An X-linked inherited metabolic disease caused by a deficiency of lysosomal ALPHA-GALACTOSIDASE A. It is characterized by intralysosomal accumulation of globotriaosylceramide and other GLYCOSPHINGOLIPIDS in blood vessels throughout the body leading to multi-system complications including renal, cardiac, cerebrovascular, and skin disorders.',
#  'C0002989': 'Solitary or multiple benign cutaneous nodules comprised of immature and mature vascular structures intermingled with endothelial cells and a varied infiltrate of eosinophils, histiocytes, lymphocytes, and mast cells.',
#  'C0002991': 'A slowly growing benign skin nodule consisting of poorly demarcated cellular fibrous tissue enclosing collapsed CAPILLARIES with scattered HEMOSIDERIN-pigmented and lipid MACROPHAGES. They are common, usually about 1 cm in diameter and occur in the DERMIS. (From Stedman, 25th ed; DeVita Jr et al., Cancer: Principles & Practice of Oncology, 3d ed, p1356)',
#  'C0002992': 'A condition with multiple tumor-like lesions caused either by congenital or developmental malformations of BLOOD VESSELS, or reactive vascular proliferations, such as in bacillary angiomatosis. Angiomatosis is considered non-neoplastic.',
#  'C0002994': 'Swelling involving the deep DERMIS, subcutaneous, or submucosal tissues, representing localized EDEMA. Angioedema often occurs in the face, lips, tongue, and larynx.',
#  'C0002996': 'Use of a balloon catheter for dilation of an occluded artery. It is used in treatment of arterial occlusive diseases, including renal artery stenosis and arterial occlusions in the leg. For the specific technique of BALLOON DILATION in coronary arteries, ANGIOPLASTY, BALLOON, CORONARY is available.',
#  'C0002997': 'Dilation of an occluded coronary artery (or arteries) by means of a balloon catheter to restore myocardial blood supply.',
#  'C0003001': 'The octapeptide amide of bovine angiotensin II used to increase blood pressure by vasoconstriction.',
#  'C0003006': 'A decapeptide that is cleaved from precursor angiotensinogen by RENIN. Angiotensin I has limited biological activity. It is converted to angiotensin II, a potent vasoconstrictor, after the removal of two amino acids at the C-terminal by ANGIOTENSIN CONVERTING ENZYME.',
#  'C0003009': 'An octapeptide that is a potent but labile vasoconstrictor. It is produced from angiotensin I after the removal of two amino acids at the C-terminal by ANGIOTENSIN CONVERTING ENZYME. The amino acid in position 5 varies in different species. To block VASOCONSTRICTION and HYPERTENSION effect of angiotensin II, patients are often treated with ACE INHIBITORS or with ANGIOTENSIN II TYPE 1 RECEPTOR BLOCKERS.',
#  'C0003012': 'A heptapeptide formed from ANGIOTENSIN II after the removal of an amino acid at the N-terminal by AMINOPEPTIDASE A. Angiotensin III has the same efficacy as ANGIOTENSIN II in promoting ALDOSTERONE secretion and modifying renal blood flow, but less vasopressor activity (about 40%).',
#  'C0003015': 'A class of drugs whose main indications are the treatment of hypertension and heart failure. They exert their hemodynamic effect mainly by inhibiting the renin-angiotensin system. They also modulate sympathetic nervous system activity and increase prostaglandin synthesis. They cause mainly vasodilation and mild natriuresis without affecting heart rate and contractility.',
#  'C0003017': 'An alpha-globulin of about 453 amino acids, depending on the species. It is produced by the liver and secreted into blood circulation. Angiotensinogen is the inactive precursor of natural angiotensins. Upon successive enzyme cleavages, angiotensinogen yields angiotensin I, II, and III with amino acids numbered at 10, 8, and 7, respectively.',
#  'C0003018': 'Oligopeptides which are important in the regulation of blood pressure (VASOCONSTRICTION) and fluid homeostasis via the RENIN-ANGIOTENSIN SYSTEM. These include angiotensins derived naturally from precursor ANGIOTENSINOGEN, and those synthesized.',
#  'C0003023': 'A republic in southern Africa, southwest of DEMOCRATIC REPUBLIC OF THE CONGO and west of ZAMBIA. Its capital is Luanda.',
#  'C0003025': 'A genus in the Family Anguillidae, Order Anguilliformes, that includes fresh water eels.',
#  'C0003028': 'Inability to sweat. [HPO:probinson]',
#  'C0003030': 'Chemical compounds derived from acids by the elimination of a molecule of water.',
#  'C0003035': 'Any aromatic amide obtained by acylation of aniline.',
#  'C0003036': 'Dye and chemical solution stains for medical purposes are mixtures of synthetic or natural dyes or nondye chemicals in solutions used in staining cells and tissues for diagnostic histopathology, cytopathology, or hematology.',
#  'C0003038': 'Compounds that include the aminobenzene structure.',
#  'C0003039': 'A drug-metabolizing, cytochrome P-450 enzyme which catalyzes the hydroxylation of aniline to hydroxyaniline in the presence of reduced flavoprotein and molecular oxygen. EC 1.14.14.-.',
#  'C0003040': 'Alkylating anti-neoplastic agent.',
#  'C0003042': 'A class of organic compounds which contain an anilino (phenylamino) group linked to a salt or ester of naphthalenesulfonic acid. They are frequently used as fluorescent dyes and sulfhydryl reagents.',
#  'C0003044': "<p>Wild animals usually avoid people. They might attack, however, if they feel threatened, are sick, or are protecting their young or territory. Attacks by pets are more common. Animal bites rarely are life-threatening, but if they become infected, you can develop serious medical problems. </p> <p>To prevent animal bites and complications from bites</p> <ul> <li> Never pet, handle, or feed unknown animals </li> <li> Leave snakes alone</li> <li> Watch your children closely around animals</li> <li> Vaccinate your cats, ferrets, and dogs against <a href='https://medlineplus.gov/rabies.html'>rabies</a></li> <li> Spay or neuter your dog to make it less aggressive</li> <li> Get a <a href='https://medlineplus.gov/tetanus.html'>tetanus</a> booster if you have not had one recently</li> <li> Wear boots and long pants when you are in areas with venomous snakes</li> </ul> <p>If an animal bites you, clean the wound with soap and water as soon as possible. Get medical attention if necessary.</p> <p >Centers for Disease Control and Prevention</p>",
#  'C0003045': 'Institutional committees established to protect the welfare of animals used in research and education. The 1971 NIH Guide for the Care and Use of Laboratory Animals introduced the policy that institutions using warm-blooded animals in projects supported by NIH grants either be accredited by a recognized professional laboratory animal accrediting body or establish its own committee to evaluate animal care; the Public Health Service adopted a policy in 1979 requiring such committees; and the 1985 amendments to the Animal Welfare Act mandate review and approval of federally funded research with animals by a formally designated Institutional Animal Care and Use Committee (IACUC).',
#  'C0003046': 'Communication between animals involving the giving off by one individual of some chemical or physical signal, that, on being received by another, influences its behavior.',
#  'C0003047': 'Diseases that occur in VERTEBRATE animals.',
#  'C0003048': 'The use of animals as investigational subjects.',
#  'C0003050': 'Foodstuff used especially for domestic and laboratory animals, or livestock.',
#  'C0003052': 'The science of breeding, feeding and care of domestic animals; includes housing and nutrition.',
#  'C0003053': 'Procedures for recognizing individual animals and certain identifiable characteristics pertaining to them; includes computerized methods, ear tags, etc.',
#  'C0003057': 'The moral and ethical bases of the protection of animals from cruelty and abuse. The rights are extended to domestic animals, laboratory animals, and wild animals.',
#  'C0003058': 'Organs and other anatomical structures of non-human vertebrate and invertebrate animals.',
#  'C0003059': 'Procedures, such as TISSUE CULTURE TECHNIQUES; mathematical models; etc., when used or advocated for use in place of the use of animals in research or diagnostic laboratories.',
#  'C0003060': 'An animal pathogen that is a virus.',
#  'C0003061': 'The protection of animals in laboratories or other specific environments by promoting their health through better nutrition, housing, and care.',
#  'C0003062': 'Unicellular or multicellular, heterotrophic organisms, that have sensation and the power of voluntary movement. Under the older five kingdom paradigm, Animalia was one of the kingdoms. Under the modern three domain model, Animalia represents one of the many groups in the domain EUKARYOTA.',
#  'C0003063': 'Animals which have become adapted through breeding in captivity to a life intimately associated with humans. They include animals domesticated by humans to live and breed in a tame condition on farms or ranches for economic reasons, including LIVESTOCK (specifically CATTLE; SHEEP; HORSES; etc.), POULTRY; and those raised or kept for pleasure and companionship, e.g., PETS; or specifically DOGS; CATS; etc.',
#  'C0003064': 'Animals used or intended for use in research, testing, or teaching',
#  'C0003065': 'Refers to animals in the period of time just after birth.',
#  'C0003067': 'Animal population groups that produce BIOLOGICAL TOXINS.',
#  'C0003068': 'Young, unweaned mammals. Refers to nursing animals whether nourished by their biological mother, foster mother, or bottle fed.',
#  'C0003069': 'Animals, or the offspring of such animals, into which cloned genetic material has been experimentally transferred by microinjection of foreign DNA, either directly or into embryos or differentiated cell types.',
#  'C0003070': 'Animals considered to be wild or feral or not adapted for domestic use. It does not include wild animals in zoos for which ANIMALS, ZOO is available.',
#  'C0003071': 'Animal population groups or individual animals that reside in captivity at a zoological park.',
#  ...}

# %%
umls_entities = []
for cui, name in tqdm(umls_to_name.items()):
    d = {}
    ent_type = cui2types[cui]
    other_aliases = [x for x in umls_to_alias[cui] if x != name]
    joined_aliases = ' ; '.join(other_aliases)
    d['cui'] = f"UMLS:{cui}"
    d['title'] = name
    d['type'] = ent_type
    if cui in cui2definition:
        definition = cui2definition[cui]
    else:
        definition = None

    if len(other_aliases) > 0:
        if definition is not None:
            d['description'] = f"{name} ( {ent_type} : {joined_aliases} ) [ {definition} ]"
        else:
            d['description'] = f"{name} ( {ent_type} : {joined_aliases} )"
    else:
        if definition is not None:
            d['description'] = f"{name} ( {ent_type} ) [ {definition} ]"
        else:
            d['description'] = f"{name} ( {ent_type} )"

    umls_entities.append(d)

pickle.dump(umls_entities, open('../data/arboel/medmentions_full/dictionary.pickle', 'wb'))
# Out:
# 100%|██████████| 3465007/3465007 [00:08<00:00, 412181.68it/s]

# %%
umls_entities[7]
# Out:
# {'cui': 'UMLS:C0000098',
#  'title': '1-Methyl-4-phenylpyridinium',
#  'type': 'Chemical',
#  'description': '1-Methyl-4-phenylpyridinium ( Chemical : 1-Methyl-4-phenylpyridinium Ion ; Cyperquat ; N-Methyl-4-phenylpyridine ; 1-Methyl-4-phenylpyridine ; N-Methyl-4-phenylpyridinium ; 1-Methyl-4-phenylpyridinium ; 1 Methyl 4 phenylpyridinium ; 1 Methyl 4 phenylpyridinium Ion ; N Methyl 4 phenylpyridine ; 1 Methyl 4 phenylpyridine ; Pyridinium, 1-methyl-4-phenyl- ; N METHYL 4 PHENYLPYRIDINIUM ; METHYLPHENYLPYRIDINIUM 01 04 ; 1-Methyl-4-phenylpyridinium [Chemical/Ingredient] ; MPP+ ; An active neurotoxic metabolite of 1-METHYL-4-PHENYL-1,2,3,6-TETRAHYDROPYRIDINE. The compound reduces dopamine levels, inhibits the biosynthesis of catecholamines, depletes cardiac norepinephrine and inactivates tyrosine hydroxylase. These and other toxic effects lead to cessation of oxidative phosphorylation, ATP depletion, and cell death. The compound, which is related to PARAQUAT, has also been used as an herbicide. )'}

# %% [markdown]
# ## Process dict for MedMentions ST21PV

# %%
st21pv_vocabs = [
        "MSH",
        "CPT",
        "FMA",
        "GO",
        "HGNC",
        "HPO",
        "ICD10",
        "ICD10CM",
        "ICD9CM",
        "MDR",
        "MTH",
        "NCBI",
        "NCI",
        "NDDF",
        # "MED-RT",
        "NDFRT",
        "OMIM",
        "RXNORM",
        "SNOMEDCT_US",
    ]
with open('../data/st21pv_vocabs.json', 'w') as f:
    f.write(ujson.dumps(st21pv_vocabs))

unique_vocabs = umls.umls.sab.unique()
for x in st21pv_vocabs:
    if x not in unique_vocabs:
        print(x)
        print(unique_vocabs)
    assert x in unique_vocabs

st21pv_types = ujson.load(open("../data/st21pv_subtypes.json", "r"))


print("Getting ST21PV Aliases")
st21pv_to_alias = umls.get_aliases(
    ontologies_to_include=st21pv_vocabs,
    types_to_include=st21pv_types,
    use_umls_curies=True,
    lowercase=lowercase,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 23
#       1 st21pv_vocabs = [
#       2         "MSH",
#       3         "CPT",
#    (...)
#      20         "SNOMEDCT_US",
#      21     ]
#      22 with open('../data/st21pv_vocabs.json', 'w') as f:
# ---> 23     f.write(ujson.dumps(st21pv_vocabs))
#      25 unique_vocabs = umls.umls.sab.unique()
#      26 for x in st21pv_vocabs:
#
# NameError: name 'ujson' is not defined

# %%
st21pv_entities = []
for cui, aliases in tqdm(st21pv_to_alias.items()):
    d = {}
    ent_type = cui2types[cui]
    name = umls_to_name[cui]
    other_aliases = [x for x in aliases if x != name]
    joined_aliases = ' ; '.join(other_aliases)
    
    d['cui'] = f"UMLS:{cui}"
    d['title'] = umls_to_name[cui]
    d['type'] = ent_type
    if cui in cui2definition:
        definition = cui2definition[cui]
    else:
        definition = None

    if len(other_aliases) > 0:
        if definition is not None:
            d['description'] = f"{name} ( {ent_type} : {joined_aliases} ) [ {definition} ]"
        else:
            d['description'] = f"{name} ( {ent_type} : {joined_aliases} )"
    else:
        if definition is not None:
            d['description'] = f"{name} ( {ent_type} ) [ {definition} ]"
        else:
            d['description'] = f"{name} ( {ent_type} )"
        
    st21pv_entities.append(d)

pickle.dump(st21pv_entities, open('../data/arboel/medmentions_st21pv/dictionary.pickle', 'wb'))
# Out:
# 100%|██████████| 2369483/2369483 [00:05<00:00, 416522.84it/s]

# %% [markdown]
# ## Process dict for BC5CDR

# %%
lowercase = False

mesh_to_alias = umls.get_aliases(
        ontologies_to_include=["MSH"],
        use_umls_curies=False,
        mapping_cols={"MSH": "sdui"},
        prefixes={"MSH": "MESH"},
        lowercase=lowercase,
    )

mesh_to_name = umls.get_canonical_name(
        ontologies_to_include=["MSH"],
        use_umls_curies=False,
        mapping_cols={"MSH": "sdui"},
        prefixes={"MSH": "MESH"},
        lowercase=lowercase,)

mesh_to_types, mesh_to_groups = umls.get_types_and_groups(
        ontologies_to_include=["MSH"],
        use_umls_curies=False,
        mapping_cols={"MSH": "sdui"},
        prefixes={"MSH": "MESH"},
        lowercase=lowercase,
)

# %%
mesh2definition = umls.get_definition(
    ontologies_to_include=['MSH'],
    use_umls_curies=False,
    mapping_cols={"MSH": "sdui"},
        prefixes={"MSH": "MESH"},
    lowercase=lowercase,
)
# Out:
# Filtering by ontologies
# Removing null definitions

# %%
bc5cdr_entities = []
for cui, aliases in tqdm(mesh_to_alias.items()):
    d = {}
    ent_type = mesh_to_groups[cui][0]
    type_string = ' , '.join([group2name[x] for x in mesh_to_groups[cui]])
    name = mesh_to_name[cui]
    other_aliases = [x for x in aliases if x != name]
    joined_aliases = ' ; '.join(other_aliases)
    
    d['cui'] = cui
    d['title'] = mesh_to_name[cui]
    d['type'] = ent_type
    if cui in mesh2definition:
        definition = mesh2definition[cui]
    else:
        definition = None

    if len(other_aliases) > 0:
        if definition is not None:
            d['description'] = f"{name} ( {ent_type} : {joined_aliases} ) [ {definition} ]"
        else:
            d['description'] = f"{name} ( {ent_type} : {joined_aliases} )"
    else:
        if definition is not None:
            d['description'] = f"{name} ( {ent_type} ) [ {definition} ]"
        else:
            d['description'] = f"{name} ( {ent_type} )"

    bc5cdr_entities.append(d)

pickle.dump(bc5cdr_entities, open('../data/arboel/bc5cdr/dictionary.pickle', 'wb'))
# Out:
# 100%|██████████| 268162/268162 [00:00<00:00, 323996.80it/s]

# %%
bc5cdr_entities
# Out:
# [{'cui': 'MESH:C000002',
#   'title': 'bevonium',
#   'type': 'CHEM',
#   'description': 'bevonium ( CHEM : 2-(hydroxymethyl)-N,N-dimethylpiperidinium benzilate ; piribenzil methyl sulfate ; bevonium methylsulfate ; bevonium metilsulfate ; CG 201 ; Acabel ; bevonium sulfate (1:1) ; bevonium methyl sulfate )'},
#  {'cui': 'MESH:C000006',
#   'title': 'insulin, neutral',
#   'type': 'CHEM',
#   'description': 'insulin, neutral ( CHEM : Insulin, 8A-L-threonine-10A-L-isoleucine- ; neutral insulin ; insulin pork ; insulin (pork) ; insulin (swine) ; insulin (ox), 8(A)-L-threonine-10(A)-L-isoleucine- ; Actrapid insulin ; Novo MC insulin )'},
#  {'cui': 'MESH:C000009',
#   'title': 'N-acetylglucosaminylasparagine',
#   'type': 'CHEM',
#   'description': "N-acetylglucosaminylasparagine ( CHEM : L-Asparagine, N-(2-acetylamino)-2-deoxy-beta-D-glucopyranosyl- ; aspartylglucosylamine ; aspartylglycosamine ; 2-acetamido-1-(beta-L-aspartamido)-1,2-dideoxy-beta-D-glucose ; 2-acetamido-1-N-(4'-L-aspartyl)-2-deoxy-beta-D-glucopyranosylamine ; N(4)-(2-acetamido-2-deoxy-beta-D-glucopyranosyl)-L-asparagine ; 4-N-2-acetamido-2-deoxy-beta-D-glucopyranosyl-L-asparagine ; AADG ; acetylglucosaminylasparagine ; N-(2-acetylamino)-2-deoxy-beta-D-glucopyranosyl-L-asparagine ; N(4)-(2-acetamido-2-deoxyglucopyranosyl)asparagine ; N-ADGP-Asn ; asparaginylglucosamine ; aspartylglucosamine )"},
#  {'cui': 'MESH:C000011',
#   'title': '5-(n-acetaminophenylazo)-8-oxyquinoline',
#   'type': 'CHEM',
#   'description': '5-(n-acetaminophenylazo)-8-oxyquinoline ( CHEM : 5-(p-acetamidophenylazo)-8-hydroxyquinoline )'},
#  {'cui': 'MESH:C000015',
#   'title': 'N-acetyl-L-arginine',
#   'type': 'CHEM',
#   'description': 'N-acetyl-L-arginine ( CHEM : N-alpha-acetylarginine ; acetyl arginine )'},
#  {'cui': 'MESH:C000020',
#   'title': 'N-acetylneuraminoyllactose',
#   'type': 'CHEM',
#   'description': 'N-acetylneuraminoyllactose ( CHEM : acetylneuraminyllactose ; N-acetylneuramin lactose ; N-acetylneuraminyllactose ; sialyl-lactose ; sialyl(alpha2,3)lactose ; sialyllactose ; N-acetylneuraminyl-2-3-lactose ; neuraminlactose )'},
#  {'cui': 'MESH:C000021',
#   'title': 'acetylnovadral',
#   'type': 'CHEM',
#   'description': 'acetylnovadral ( CHEM )'},
#  {'cui': 'MESH:C000022',
#   'title': 'N-acetyl-4-nitrophenylserinol',
#   'type': 'CHEM',
#   'description': 'N-acetyl-4-nitrophenylserinol ( CHEM : N-acetyl-p-nitrophenylserinol ; corynecin I ; N-acetyl-4-nitrophenylserinol, (L-threo)-isomer ; N-acetyl-4-nitrophenylserinol, (D-threo)-isomer )'},
#  {'cui': 'MESH:C000024',
#   'title': 'flavophosphine',
#   'type': 'CHEM',
#   'description': 'flavophosphine ( CHEM : 3-amino-9-(p-aminophenyl)-7-methylacridine )'},
#  {'cui': 'MESH:C000025',
#   'title': 'ethosuximide, quinacrine drug combination',
#   'type': 'CHEM',
#   'description': 'ethosuximide, quinacrine drug combination ( CHEM : 2,5-Pyrrolidinedione, 3-ethyl-3-methyl-, mixt. with N(4)-(6-chloro-2-methoxy-9-acridinyl)-N(1),N(1)-diethyl-1,4-pentanediamine dihydrochloride ; ethosuximide - quinacrine ; acrisuxine )'},
#  {'cui': 'MESH:C000027',
#   'title': 'cyprodenate',
#   'type': 'CHEM',
#   'description': 'cyprodenate ( CHEM : dimethylamino- 2-ethyl-beta-cyclohexylpropionic acid maleate ; cyprodemanol ; Actebral ; LB 125 )'},
#  {'cui': 'MESH:C000028',
#   'title': 'carboxyphosphamide',
#   'type': 'CHEM',
#   'description': 'carboxyphosphamide ( CHEM : 2-carboxyethyl-N,N-bis(2-chloroethyl)phosphorodiamidate ; carboxycyclophosphamide ; carboxyphosphamide, (R)-isomer ; carboxyphosphamide, (S)-isomer )'},
#  {'cui': 'MESH:C000032',
#   'title': 'adenosine arabinose',
#   'type': 'CHEM',
#   'description': 'adenosine arabinose ( CHEM )'},
#  {'cui': 'MESH:C000038',
#   'title': 'adrenoglomerulotropin',
#   'type': 'CHEM',
#   'description': 'adrenoglomerulotropin ( CHEM : 1-methyl-6-methoxy-1,2,3,4-tetrahydro-2- carboline ; 1-methyl-6-methoxy-tetrahydro-beta-carboline ; 1-Me-6-MTHBC ; 6-methoxy-1-methyl-1,2,3,4-tetrahydro-beta-carboline )'},
#  {'cui': 'MESH:C000039',
#   'title': 'alpha-amino-4-isothiazolylacetic acid',
#   'type': 'CHEM',
#   'description': 'alpha-amino-4-isothiazolylacetic acid ( CHEM : 4-Isothiazoleacetic acid, alpha-amino- )'},
#  {'cui': 'MESH:C000045',
#   'title': 'obtusastyrene',
#   'type': 'CHEM',
#   'description': 'obtusastyrene ( CHEM : 4-cinnamylphenol ; obtusastyrene, (E)-isomer )'},
#  {'cui': 'MESH:C000047',
#   'title': 'albitocin',
#   'type': 'CHEM',
#   'description': 'albitocin ( CHEM )'},
#  {'cui': 'MESH:C000049',
#   'title': 'algivant',
#   'type': 'CHEM',
#   'description': 'algivant ( CHEM )'},
#  {'cui': 'MESH:C000050',
#   'title': 'alisol A',
#   'type': 'CHEM',
#   'description': 'alisol A ( CHEM )'},
#  {'cui': 'MESH:C000051',
#   'title': '2-alkylaminobenzothiazole',
#   'type': 'CHEM',
#   'description': '2-alkylaminobenzothiazole ( CHEM )'},
#  {'cui': 'MESH:C000052',
#   'title': '2-alkylaminobenzoxazole',
#   'type': 'CHEM',
#   'description': '2-alkylaminobenzoxazole ( CHEM )'},
#  {'cui': 'MESH:C000055',
#   'title': 'alloclamide',
#   'type': 'CHEM',
#   'description': 'alloclamide ( CHEM : 2-allyloxy-4-chloro-N-(2-diethylaminoethyl)benzamide ; Hexacol ; 264 CE ; alloclamide hydrochloride )'},
#  {'cui': 'MESH:C000056',
#   'title': '264 CP',
#   'type': 'CHEM',
#   'description': '264 CP ( CHEM : 2-allyloxy-4-chloro-N-(2-piperidinoethyl)benzamide )'},
#  {'cui': 'MESH:C000058',
#   'title': 'alytesin',
#   'type': 'CHEM',
#   'description': 'alytesin ( CHEM : pGly-Arg-Leu-Gly-Thr-Gln-Trp-Ala-Val-Gly-His-Leu-Met-NH2 )'},
#  {'cui': 'MESH:C000059',
#   'title': 'ametohepazone',
#   'type': 'CHEM',
#   'description': 'ametohepazone ( CHEM : 2(1H)-Cycloheptimidazolone, 1-(2-(dimethylamino)ethyl)- )'},
#  {'cui': 'MESH:C000060',
#   'title': '9-(3-(aden-9-yl)propyl)-2-dimethylaminopurin-6-one',
#   'type': 'CHEM',
#   'description': '9-(3-(aden-9-yl)propyl)-2-dimethylaminopurin-6-one ( CHEM )'},
#  {'cui': 'MESH:C000061',
#   'title': 'allysine',
#   'type': 'CHEM',
#   'description': 'allysine ( CHEM : alpha-aminoadipic semialdehyde ; 2-aminoadipate semialdehyde ; alpha-AASA ; alpha-aminoadipate semialdehyde ; 2-aminoadipic semialdehyde )'},
#  {'cui': 'MESH:C000062',
#   'title': '2-aminobenzaldehyde',
#   'type': 'CHEM',
#   'description': '2-aminobenzaldehyde ( CHEM : ortho aminobenzaldehyde )'},
#  {'cui': 'MESH:C000063',
#   'title': 'thiozamin',
#   'type': 'CHEM',
#   'description': "thiozamin ( CHEM : p-(p'-aminobenzenesulfonyl)benzaldehyde thiosemicarbazone )"},
#  {'cui': 'MESH:C000064',
#   'title': 'putreanine',
#   'type': 'CHEM',
#   'description': 'putreanine ( CHEM : N-(4-aminobutyl)-3-aminopropionic acid )'},
#  {'cui': 'MESH:C000065',
#   'title': '6-aminochromane',
#   'type': 'CHEM',
#   'description': '6-aminochromane ( CHEM )'},
#  {'cui': 'MESH:C000066',
#   'title': 'aminocinnamonitrile',
#   'type': 'CHEM',
#   'description': 'aminocinnamonitrile ( CHEM )'},
#  {'cui': 'MESH:C000075',
#   'title': 'Agr 307',
#   'type': 'CHEM',
#   'description': 'Agr 307 ( CHEM : 2-amino-(isothioureyl methylene)-4-thiazole dihydrochloride ; Agr 307, dihydrochloride ; Agr 307, monohydrochloride )'},
#  {'cui': 'MESH:C000076',
#   'title': '2-amino-5-hydroxyacetophenone',
#   'type': 'CHEM',
#   'description': '2-amino-5-hydroxyacetophenone ( CHEM )'},
#  {'cui': 'MESH:C000077',
#   'title': 'amylosubtilin G10x',
#   'type': 'CHEM',
#   'description': 'amylosubtilin G10x ( CHEM )'},
#  {'cui': 'MESH:C000078',
#   'title': '9-AMA',
#   'type': 'CHEM',
#   'description': '9-AMA ( CHEM : 9-aminomethylacridan )'},
#  {'cui': 'MESH:C000080',
#   'title': 'phenpentermine',
#   'type': 'CHEM',
#   'description': 'phenpentermine ( CHEM : 2-amino-2-methyl-3-phenylbutane )'},
#  {'cui': 'MESH:C000081',
#   'title': '4-methylaminorex',
#   'type': 'CHEM',
#   'description': '4-methylaminorex ( CHEM : 2-amino-4-methyl- 5-phenyloxazoline ; 4,5-dihydro-4-methyl-5-phenyl-2-oxazolamine ; U4EuH ; McN-822 ; 4-methylaminorex, (4s-trans)-isomer ; 4-methylaminorex, cis-(+-)-isomer ; 4-methylaminorex, monohydrobromide salt, (Z)-(+-)-isomer ; 4-methylaminorex, (4S-cis)-isomer ; McN 822 )'},
#  {'cui': 'MESH:C000082',
#   'title': 'alanosine',
#   'type': 'CHEM',
#   'description': 'alanosine ( CHEM : L-2-amino-3-(N-nitroso)hydroxylaminopropionic acid ; L-alanosine ; NSC 153353 ; SDX-102 ; SDX102 ; NSC 153,353 ; SDX 102 )'},
#  {'cui': 'MESH:C000085',
#   'title': '1-(m-aminophenyl)-2-cyclopropylaminoethanol.2HCl',
#   'type': 'CHEM',
#   'description': '1-(m-aminophenyl)-2-cyclopropylaminoethanol.2HCl ( CHEM : 3-amino-alpha-((cyclopropylamino)methyl)benzenemethanol, dihydrochloride ; AB 15 ; AB-15 )'},
#  {'cui': 'MESH:C000086',
#   'title': 'aminotridecane adipate',
#   'type': 'CHEM',
#   'description': 'aminotridecane adipate ( CHEM )'},
#  {'cui': 'MESH:C000088',
#   'title': 'alpha-amino-2-xylene',
#   'type': 'CHEM',
#   'description': 'alpha-amino-2-xylene ( CHEM : alpha-amino-o-xylene )'},
#  {'cui': 'MESH:C000089',
#   'title': 'ammeline',
#   'type': 'CHEM',
#   'description': 'ammeline ( CHEM : 4,6-diamino-1,3,5-triazin-2(1H)-one )'},
#  {'cui': 'MESH:C000090',
#   'title': 'galactaric acid',
#   'type': 'CHEM',
#   'description': 'galactaric acid ( CHEM : mucic acid ; strontium galactarate mono-hydrate ; galactaric acid, sodium salt )'},
#  {'cui': 'MESH:C000092',
#   'title': '1-hydroxyindoloquinoxaline',
#   'type': 'CHEM',
#   'description': '1-hydroxyindoloquinoxaline ( CHEM )'},
#  {'cui': 'MESH:C000096',
#   'title': '1,5-anhydroglucitol-6-phosphate',
#   'type': 'CHEM',
#   'description': '1,5-anhydroglucitol-6-phosphate ( CHEM )'},
#  {'cui': 'MESH:C000097',
#   'title': 'anticapsin',
#   'type': 'CHEM',
#   'description': 'anticapsin ( CHEM )'},
#  {'cui': 'MESH:C000100',
#   'title': 'aquayamycin',
#   'type': 'CHEM',
#   'description': "aquayamycin ( CHEM : 9-(tetrahydro-4',5'-dihydroxy-6'-methyl-2'H-pyran-2'-yl)-3,4,4a,12b-tetrahydro-3,4a,8,12b-tetrahydroxy-3-methyl-benz(a)anthracene-1,7,12(2H)-trione )"},
#  {'cui': 'MESH:C000101',
#   'title': 'ara-ATP',
#   'type': 'CHEM',
#   'description': "ara-ATP ( CHEM : 9H-purin-6-amine, 9-(5-O-(hydroxy(hydroxy(phosphonooxy)phosphinyl)phosphinyl)-beta-D-arabinofuranosyl)- ; ara ATP ; 9 beta-D-arabinofuranosyladenine 5'-triphosphate ; arabinofuranosyladenine triphosphate )"},
#  {'cui': 'MESH:C000102',
#   'title': 'Arachin',
#   'type': 'CHEM',
#   'description': 'Arachin ( CHEM )'},
#  {'cui': 'MESH:C000105',
#   'title': 'arylid',
#   'type': 'CHEM',
#   'description': "arylid ( CHEM : 4',5-dichlorosalicylanilide )"},
#  {'cui': 'MESH:C000106',
#   'title': 'ascorbic acid, copper sulfate, sodium percarbonate drug combination',
#   'type': 'CHEM',
#   'description': 'ascorbic acid, copper sulfate, sodium percarbonate drug combination ( CHEM : ascorbic acid - copper sulfate - sodium percarbonate ; Ascumist )'},
#  {'cui': 'MESH:C000107',
#   'title': 'aspartic acid-beta-4-nitroanilide',
#   'type': 'CHEM',
#   'description': "aspartic acid-beta-4-nitroanilide ( CHEM : suosan ; N-(4-nitrophenyl)-N'-(carboxyethyl)urea ; aspartic acid-beta-p-nitroanilide ; aspartic acid-beta-4-nitroanilide, sodium salt )"},
#  {'cui': 'MESH:C000108',
#   'title': 'astonilin',
#   'type': 'CHEM',
#   'description': 'astonilin ( CHEM : 7H-Benz(g)indolo(2,3-a)quinolizin-6-ium, 8,13-dihydro-11-methoxy-1-(methoxycarbonyl)- ; alstoniline )'},
#  {'cui': 'MESH:C000109',
#   'title': 'azabicyclane',
#   'type': 'CHEM',
#   'description': 'azabicyclane ( CHEM : azabicyclane citrate )'},
#  {'cui': 'MESH:C000110',
#   'title': '2-azacyclooctanone',
#   'type': 'CHEM',
#   'description': '2-azacyclooctanone ( CHEM : oenantholactam ; cyclo-Aha ; cyclo-omega-heptanoic acid )'},
#  {'cui': 'MESH:C000111',
#   'title': 'azaleucine',
#   'type': 'CHEM',
#   'description': 'azaleucine ( CHEM : 2-amino-3-dimethylaminopropionic acid )'},
#  {'cui': 'MESH:C000115',
#   'title': 'jaligonic acid',
#   'type': 'CHEM',
#   'description': 'jaligonic acid ( CHEM : (2 beta,3 beta,4 alpha,20 beta)-2,3,23-trihydroxy- olean-12-ene-28,29-dioic acid )'},
#  {'cui': 'MESH:C000119',
#   'title': 'bactoprenylpyrophosphate',
#   'type': 'CHEM',
#   'description': 'bactoprenylpyrophosphate ( CHEM : Diphosphoric acid, mono(3,7,11,15,19,23,27,31,35,39,43-undecamethyl-6,10,14,18,22,26,30,34,38,42-tetratetracontadecaenyl) ester )'},
#  {'cui': 'MESH:C000121',
#   'title': 'pipoxolan',
#   'type': 'CHEM',
#   'description': 'pipoxolan ( CHEM : 5,5-diphenyl-2-(beta-N-piperidinoethyl)-1,3-dioxolan-4-one ; BR-18 ; BR 18 ; Rowapraxin ; pipoxolan monohydrochloride )'},
#  {'cui': 'MESH:C000123',
#   'title': 'bendazac',
#   'type': 'CHEM',
#   'description': 'bendazac ( CHEM : 1-benzylindazole-3-oxyacetic acid ; bendazolic acid ; bindazac ; bendazolic acid, sodium salt )'},
#  {'cui': 'MESH:C000124',
#   'title': 'benfurodil',
#   'type': 'CHEM',
#   'description': 'benfurodil ( CHEM : 2-(1-succinyloxyethyl)-3-methyl-5-(2-oxo-2,5-dihydro-4-furyl)benzo(b)furan ; Eudilat ; CB 4091 ; Eucilat ; benfurodil hemisuccinate )'},
#  {'cui': 'MESH:C000128',
#   'title': 'rubiflavin',
#   'type': 'CHEM',
#   'description': 'rubiflavin ( CHEM )'},
#  {'cui': 'MESH:C000132',
#   'title': 'pseudourea',
#   'type': 'CHEM',
#   'description': "pseudourea ( CHEM : 2,2'-(9,10-anthrylenedimethylene)bis(2-thiopseudourea) ; NSC-56054 )"},
#  {'cui': 'MESH:C000133',
#   'title': 'Y 3506',
#   'type': 'CHEM',
#   'description': 'Y 3506 ( CHEM : 1-thia-4,8-diazaspiro(4.5)decan-3-one, 8-(1,4-benzodioxan-2-ylmethyl)-, (Z)-2-butenedioate (1:1) ; Y-3506 ; 8-((1,4-benzodioxan-2-yl)methyl)-3-oxo-1-thia-4,8-diazaspiro(4,5)decane maleate )'},
#  {'cui': 'MESH:C000134',
#   'title': 'SH-24',
#   'type': 'CHEM',
#   'description': 'SH-24 ( CHEM : SH 24 ; benzofurylethylidine-methyl-triphenylphosphonium iodide )'},
#  {'cui': 'MESH:C000136',
#   'title': 'benzo-tepa',
#   'type': 'CHEM',
#   'description': 'benzo-tepa ( CHEM : N-(bis(1-aziridinyl)phosphinyl)benzamide ; Benzotef )'},
#  {'cui': 'MESH:C000137',
#   'title': 'paraflutizide',
#   'type': 'CHEM',
#   'description': 'paraflutizide ( CHEM : 6-chloro-3-(p-fluorobenzyl)-3,4-dihydro-2H-1,2,4- benzothiadiazine-7-sulfonamide, 1,1-dioxide )'},
#  {'cui': 'MESH:C000140',
#   'title': 'HM 197',
#   'type': 'CHEM',
#   'description': 'HM 197 ( CHEM : 5-benzoyl-2-iminohexahydropyrimidine ; HM-197 )'},
#  {'cui': 'MESH:C000143',
#   'title': '1-(3-aminophenyl)flavazole',
#   'type': 'CHEM',
#   'description': '1-(3-aminophenyl)flavazole ( CHEM : 1-(m-aminophenyl)-1H-pyrazolo(3,4-b)quinoxaline ; 1-(m-aminophenyl)flavazole )'},
#  {'cui': 'MESH:C000144',
#   'title': 'Avcothane',
#   'type': 'CHEM',
#   'description': 'Avcothane ( CHEM : cardiothane ; Avcothane-51 ; Avcothane 51 ; Cardiothane 51 )'},
#  {'cui': 'MESH:C000146',
#   'title': 'bactoprenol',
#   'type': 'CHEM',
#   'description': 'bactoprenol ( CHEM )'},
#  {'cui': 'MESH:C000147',
#   'title': 'cafedrine, theodrenaline drug combination',
#   'type': 'CHEM',
#   'description': 'cafedrine, theodrenaline drug combination ( CHEM : 1H-purine-2,6-dione, 3,7-dihydro-7-(2-((2-hydroxy-1-methyl-2-phenylethyl)amino)ethyl)-1,3-dimethyl-, monohydrochloride, (R-(R*,S*))-, mixt. with 7-(2-((2-(3,4-dihydroxyphenyl)-2-hydroxyethyl)amino)ethyl)-3,7-dihydro-1,3-dimethyl-1H-purine-2,6-dione monohydrochloride ; cafedrine - theodrenaline ; acrinor ; H-835 ; praxinor ; Akrinor )'},
#  {'cui': 'MESH:C000148',
#   'title': '4-aminotetrolic acid',
#   'type': 'CHEM',
#   'description': '4-aminotetrolic acid ( CHEM : 4-aminobut-2-ynoic acid )'},
#  {'cui': 'MESH:C000149',
#   'title': '8-azahypoxanthine',
#   'type': 'CHEM',
#   'description': '8-azahypoxanthine ( CHEM )'},
#  {'cui': 'MESH:C000150',
#   'title': '2-azacyclononanone',
#   'type': 'CHEM',
#   'description': '2-azacyclononanone ( CHEM )'},
#  {'cui': 'MESH:C000152',
#   'title': 'androsta-5,16-dien-3 beta-ol',
#   'type': 'CHEM',
#   'description': 'androsta-5,16-dien-3 beta-ol ( CHEM : 5,16-androstadien-3 beta-ol ; andien-beta ; androstadienol )'},
#  {'cui': 'MESH:C000153',
#   'title': 'amylopectin sulfate',
#   'type': 'CHEM',
#   'description': 'amylopectin sulfate ( CHEM : Gastramyl ; SN-263 )'},
#  {'cui': 'MESH:C000154',
#   'title': 'alpinumisoflavone',
#   'type': 'CHEM',
#   'description': 'alpinumisoflavone ( CHEM : 5-hydroxy-7-(p-hydroxyphenyl)-2,2-dimethyl-2H-6H-benzodipyran-6-one )'},
#  {'cui': 'MESH:C000156',
#   'title': 'N-acetylglucosaminuronic acid',
#   'type': 'CHEM',
#   'description': 'N-acetylglucosaminuronic acid ( CHEM : D-Glucuronic acid, 2-(acetylamino)-2-deoxy- )'},
#  {'cui': 'MESH:C000162',
#   'title': 'benzyldihydronicotinamide',
#   'type': 'CHEM',
#   'description': 'benzyldihydronicotinamide ( CHEM : 1-benzyl-3-carbamido-1,4-dihydropyridine )'},
#  {'cui': 'MESH:C000163',
#   'title': 'benzylideneglucosamine',
#   'type': 'CHEM',
#   'description': 'benzylideneglucosamine ( CHEM )'},
#  {'cui': 'MESH:C000164',
#   'title': '1-benzylindole',
#   'type': 'CHEM',
#   'description': '1-benzylindole ( CHEM )'},
#  {'cui': 'MESH:C000165',
#   'title': 'EX-10-542A',
#   'type': 'CHEM',
#   'description': 'EX-10-542A ( CHEM : 5-benzyl-11-(4-n-methyl piperidylene)-5,6-dihydromorphanthridine hydrogen maleate )'},
#  {'cui': 'MESH:C000166',
#   'title': 'benzylthioquanosine',
#   'type': 'CHEM',
#   'description': 'benzylthioquanosine ( CHEM )'},
#  {'cui': 'MESH:C000167',
#   'title': 'S-benzylthioisothiourea',
#   'type': 'CHEM',
#   'description': 'S-benzylthioisothiourea ( CHEM : Carbamo(dithioperox)imidic acid, phenylmethyl ester )'},
#  {'cui': 'MESH:C000168',
#   'title': 'benzyltrimethylammonium',
#   'type': 'CHEM',
#   'description': 'benzyltrimethylammonium ( CHEM : benzyltrimethylammonium bromide ; benzyltrimethylammonium hydroxide ; benzyltrimethylammonium methoxide ; benzyltrimethylammonium acetate ; benzyltrimethylammonium iodide ; benzyltrimethylammonium chloride ; benzyltrimethylammonium formate ; benzyltrimethylammonium propanoate ; benzyltrimethylammonium pentanoate ; benzyltrimethylammonium hexanoate ; benzyltrimethylammonium heptanoate ; benzyltrimethylammonium octanoate ; benzyltrimethylammonium nonanoate ; benzyltrimethylammonium butanoate ; benzyltrimethylammonium hexafluorophosphate (1-) ; benzyltrimethylammonium carbonate (2:1) )'},
#  {'cui': 'MESH:C000170',
#   'title': 'ferric ferrocyanide',
#   'type': 'CHEM',
#   'description': 'ferric ferrocyanide ( CHEM : ferrocin ; Berlin blue ; ferrihexacyanoferrate ; ferrotsin ; Prussian blue )'},
#  {'cui': 'MESH:C000171',
#   'title': 'dixanthogen',
#   'type': 'CHEM',
#   'description': 'dixanthogen ( CHEM : diethyl dithiobis(thionoformate) ; bisethylxanthogen ; ethyl xanthogen disulfide ; Auligen ; Bexide ; EXD ; Herbisan ; Sulfasan )'},
#  {'cui': 'MESH:C000174',
#   'title': 'ICI 58301',
#   'type': 'CHEM',
#   'description': 'ICI 58301 ( CHEM : ICI-58301 ; 3-acetamido-6-methyl-8-n-propyl-s-triazolo(4,3 alpha)pyrazine )'},
#  {'cui': 'MESH:C000175',
#   'title': '4-N-acetamido-2,2,6,6-tetramethylpiperidine-N-oxide',
#   'type': 'CHEM',
#   'description': '4-N-acetamido-2,2,6,6-tetramethylpiperidine-N-oxide ( CHEM )'},
#  {'cui': 'MESH:C000178',
#   'title': '3-acetoxy-5-indoldiazonium',
#   'type': 'CHEM',
#   'description': '3-acetoxy-5-indoldiazonium ( CHEM )'},
#  {'cui': 'MESH:C000179',
#   'title': 'N-acetylaspartate',
#   'type': 'CHEM',
#   'description': 'N-acetylaspartate ( CHEM : N-acetyl-L-aspartate ; N-acetyl aspartate ; N-acetylaspartic acid ; N-acetylaspartate, monopotassium salt )'},
#  {'cui': 'MESH:C000182',
#   'title': 'N-acetyldehydrophenylalanylproline diketopiperazine',
#   'type': 'CHEM',
#   'description': 'N-acetyldehydrophenylalanylproline diketopiperazine ( CHEM : Pyrrolo(1,2-a)pyrazine-1,4-dione, 2-acetylhexahydro-3-(phenylmethylene)- ; N-acetyldehydro-Phe-Pro diketopiperazine ; N-acetyldehydrophenylalanyl-L-proline diketopiperazine )'},
#  {'cui': 'MESH:C000183',
#   'title': 'alpha-acetylthio-3-toluenediazonium',
#   'type': 'CHEM',
#   'description': 'alpha-acetylthio-3-toluenediazonium ( CHEM : Benzenediazonium, 3-((acetylthio)methyl)- ; alpha-acetylthio-m-toluenediazonium )'},
#  {'cui': 'MESH:C000185',
#   'title': 'Acrofol',
#   'type': 'CHEM',
#   'description': 'Acrofol ( CHEM : 3-chloro-2-ene-propionic acid )'},
#  {'cui': 'MESH:C000188',
#   'title': 'alachlor',
#   'type': 'CHEM',
#   'description': 'alachlor ( CHEM : 2-chloro-N-(2,6-diethylphenyl)-N-(methoxymethyl)acetamide ; metachlor ; Lasso )'},
#  {'cui': 'MESH:C000190',
#   'title': 'allerglobulin',
#   'type': 'CHEM',
#   'description': 'allerglobulin ( CHEM )'},
#  {'cui': 'MESH:C000192',
#   'title': 'valofane',
#   'type': 'CHEM',
#   'description': 'valofane ( CHEM : 3-furancarboxamide, N-(aminocarbonyl)tetrahydro-5-methyl-2-oxo-3-(2-propenyl)- ; 2-allophenyl-2-allyl-gamma-valerolactone ; allophanyl allyl valerolactone ; allophanyl-1-allyl-1-valero-3-lactone ; alpha-allyl-alpha-allophanyl-gamma-valerolactone ; alpha-allophanyl-alpha-allyl-gamma-valerolactone ; valofan ; HH 10018 ; valofane, (trans)-isomer ; valofane, (cis)-isomer )'},
#  {'cui': 'MESH:C000194',
#   'title': 'N(1)-allylthiocarbamoyl-N(2)-methylthiocarbamoylhydrazine',
#   'type': 'CHEM',
#   'description': "N(1)-allylthiocarbamoyl-N(2)-methylthiocarbamoylhydrazine ( CHEM : 1,2-hydrazinedicarbothioamide, N-methyl-N'-2-propenyl- ; VUFB-7319 ; VUFB 7319 )"},
#  {'cui': 'MESH:C000196',
#   'title': 'amadinone',
#   'type': 'CHEM',
#   'description': 'amadinone ( CHEM : 6-chloro-17-acetoxy-19-norpregnane-4,6-diene-3,20-dione )'},
#  {'cui': 'MESH:C000197',
#   'title': '3-aminobenzotrifluoride',
#   'type': 'CHEM',
#   'description': '3-aminobenzotrifluoride ( CHEM : m-aminobenzotrifluoride ; 3-trifluoromethylaniline )'},
#  {'cui': 'MESH:C000198',
#   'title': '2-amino-3-benzyl-5-(p-hydroxyphenyl)pyrazine',
#   'type': 'CHEM',
#   'description': '2-amino-3-benzyl-5-(p-hydroxyphenyl)pyrazine ( CHEM : Phenol, 4-(5-amino-6-(phenylmethyl)pyrazinyl)- ; AF-350 ; AF350 ; AF 350 )'},
#  {'cui': 'MESH:C000199',
#   'title': 'NSC 86047',
#   'type': 'CHEM',
#   'description': 'NSC 86047 ( CHEM : 4-amino-N-butyl-1,1,2,5-selenadiazole-3-carboxamide ; NSC-86047 )'},
#  {'cui': 'MESH:C000200',
#   'title': '2-amino-4-carbamyl-6-methoxy-4-methyltetralin',
#   'type': 'CHEM',
#   'description': '2-amino-4-carbamyl-6-methoxy-4-methyltetralin ( CHEM : 1-Naphthalenecarboxamide, 3-amino-1,2,3,4-tetrahydro-7-methoxy-1-methyl- ; ACMMT )'},
#  {'cui': 'MESH:C000201',
#   'title': 'A16886A',
#   'type': 'CHEM',
#   'description': 'A16886A ( CHEM : 5-Thia-1-azabicyclo(4.2.0)oct-2-ene-2-carboxylic acid, 3-(((aminocarbonyl)oxy)methyl)-7-((5-amino-5-carboxy-1-oxopentyl)amino)-8-oxo-, (6R-(6alpha,7beta(R*)))- ; (7-(5-amino-5-carboxyvaleramido)-3-carbamoyloxymethyl-3-cephem-4-carboxylic acid) )'},
#  {'cui': 'MESH:C000202',
#   'title': '2-amino-4-chlorobenzenethiol',
#   'type': 'CHEM',
#   'description': '2-amino-4-chlorobenzenethiol ( CHEM )'},
#  {'cui': 'MESH:C000203',
#   'title': 'deoxyaminopteroic acid',
#   'type': 'CHEM',
#   'description': 'deoxyaminopteroic acid ( CHEM : 4-(((2,4-diamino-6-pteridinyl)methyl)methylamino)benzoic acid ; 4-deoxy-4-amino-N(10)-methylpteroic acid ; 4-amino-4-deoxy-N-10-methylpteroic acid ; 2,4-diamino-N(10)-methylpteroic acid ; N-10-methyl-4-deoxy-4-aminopteroate ; 4-amino-4-deoxy-N-10-methylpteroic acid hydrochloride (2:1) )'},
#  {'cui': 'MESH:C000204',
#   'title': 'S-2-aminoethyl cysteine',
#   'type': 'CHEM',
#   'description': 'S-2-aminoethyl cysteine ( CHEM : S-(2-aminoethyl)-L-cysteine ; aminoethylcysteine ; S-beta-aminoethyl cysteine ; thialysine ; thiosine ; gamma-thia-Lys ; gamma-thialysine ; 4-thialysine ; S-2-aminoethyl cysteine hydrochloride ; S-2-aminoethyl cysteine monohydrochloride ; S-2-aminoethyl cysteine dihydrochloride ; 4-thia-L-lysine )'},
#  {'cui': 'MESH:C000205',
#   'title': 'L-alpha-amino-gamma-guanidinobutyrate',
#   'type': 'CHEM',
#   'description': 'L-alpha-amino-gamma-guanidinobutyrate ( CHEM )'},
#  {'cui': 'MESH:C000206',
#   'title': 'Uvitex SWN',
#   'type': 'CHEM',
#   'description': 'Uvitex SWN ( CHEM : 8-amino-4-methylcoumarin ; SWN )'},
#  {'cui': 'MESH:C000207',
#   'title': '2-amino-4-methyl-5-hexenoic acid',
#   'type': 'CHEM',
#   'description': '2-amino-4-methyl-5-hexenoic acid ( CHEM )'},
#  {'cui': 'MESH:C000209',
#   'title': '3-amino-2-oxazolidinone',
#   'type': 'CHEM',
#   'description': '3-amino-2-oxazolidinone ( CHEM : 3-amino-2-oxazolidone )'},
#  {'cui': 'MESH:C000210',
#   'title': '2-amino-4-phenylsulfonylbenzenesulfonamide',
#   'type': 'CHEM',
#   'description': '2-amino-4-phenylsulfonylbenzenesulfonamide ( CHEM : NSD 3004 )'},
#  {'cui': 'MESH:C000211',
#   'title': '2-amino-3-phosphonopropionic acid',
#   'type': 'CHEM',
#   'description': '2-amino-3-phosphonopropionic acid ( CHEM : Alanine, 3-phosphono- ; 2-amino-3-PHOSPROP ; 2-amino-3-phosphono-propionic acid ; 2-amino-3-phosphopropionic acid ; 2-amino-3-phosphonopropionate ; L-AP3 ; 2-amino-3-phosphonopropionic acid, (DL)-isomer ; 2-amino-3-phosphonopropionic acid, sodium salt )'},
#  {'cui': 'MESH:C000212',
#   'title': 'ammoniacal silver',
#   'type': 'CHEM',
#   'description': 'ammoniacal silver ( CHEM )'},
#  {'cui': 'MESH:C000213',
#   'title': 'amyloxycarbonyltetrapeptide',
#   'type': 'CHEM',
#   'description': 'amyloxycarbonyltetrapeptide ( CHEM )'},
#  {'cui': 'MESH:C000214',
#   'title': 'androst-16-en-3-one',
#   'type': 'CHEM',
#   'description': 'androst-16-en-3-one ( CHEM : 5alpha-androst-16-en-3-one ; AEON steroid ; 5 alpha-androst-16-en-3-one ; androst-16-en-3-one, (5beta)-isomer )'},
#  {'cui': 'MESH:C000215',
#   'title': 'angustibalin',
#   'type': 'CHEM',
#   'description': 'angustibalin ( CHEM )'},
#  {'cui': 'MESH:C000217',
#   'title': 'Antagosan',
#   'type': 'CHEM',
#   'description': 'Antagosan ( CHEM : antagosin )'},
#  {'cui': 'MESH:C000218',
#   'title': 'antradion',
#   'type': 'CHEM',
#   'description': 'antradion ( CHEM : Benzoic acid, 2-(((4-butyl-3,5-dioxo-1,2-diphenyl-4-pyrazolidinyl)phenylmethyl)amino)- ; 1,2-diphenyl-4H-butyl-(4-orthocarboxyanilinobenzyl)-3,5-pyrazolidinedione ; anthradion )'},
#  {'cui': 'MESH:C000219',
#   'title': 'anthranilamide',
#   'type': 'CHEM',
#   'description': 'anthranilamide ( CHEM : 2-aminobenzamide ; ortho-aminobenzamide )'},
#  {'cui': 'MESH:C000225',
#   'title': 'argininic acid',
#   'type': 'CHEM',
#   'description': 'argininic acid ( CHEM )'},
#  {'cui': 'MESH:C000226',
#   'title': 'arglecin',
#   'type': 'CHEM',
#   'description': 'arglecin ( CHEM : 6-(3-guanidino-propyl)-3-isobutyl-2-(1H)- pyrazinone )'},
#  {'cui': 'MESH:C000227',
#   'title': 'mild silver protein',
#   'type': 'CHEM',
#   'description': 'mild silver protein ( CHEM : mild silver proteinate ; silver vitellinate ; Argyrol )'},
#  {'cui': 'MESH:C000228',
#   'title': 'aristolochic acid I',
#   'type': 'CHEM',
#   'description': 'aristolochic acid I ( CHEM : 8-methoxy-6-nitrophenanthro(3,4-d)-1,3-dioxole-5-carboxylic acid ; aristolochic acid ; aristolochic acid A ; sodium aristolochate ; Tardolyt ; aristolochic acid I, sodium salt )'},
#  {'cui': 'MESH:C000229',
#   'title': 'tyrosine-4-azobenzenearsonate',
#   'type': 'CHEM',
#   'description': 'tyrosine-4-azobenzenearsonate ( CHEM : L-Tyrosine, 3-((4-arsonophenyl)azo)- ; ABA-T ; arsanilazotyrosine ; L-tyrosine-4-azobenzenearsonate ; L-tyrosine-p-azobenzenearsonate ; azobenzenarsonate-tyrosine )'},
#  {'cui': 'MESH:C000231',
#   'title': 'azacrin',
#   'type': 'CHEM',
#   'description': 'azacrin ( CHEM : 2-methoxy-7-chloro-10-(4-(diethylamino-1-methyl)butylamino)pyrido(3,2-b)quinoline )'},
#  {'cui': 'MESH:C000232',
#   'title': 'azalomycin-F',
#   'type': 'CHEM',
#   'description': 'azalomycin-F ( CHEM : azalomycin F )'},
#  {'cui': 'MESH:C000234',
#   'title': 'azobenzenearsonate-N-acetyl-L-tyrosine',
#   'type': 'CHEM',
#   'description': 'azobenzenearsonate-N-acetyl-L-tyrosine ( CHEM : L-Tyrosine, N-acetyl-3-((4-arsonophenyl)azo)- ; ABA-NAT )'},
#  {'cui': 'MESH:C000236',
#   'title': 'methylglyoxal-ascorbate',
#   'type': 'CHEM',
#   'description': 'methylglyoxal-ascorbate ( CHEM : MGX-ASC ; methylglyoxal-ascorbate condensation complex ; methylglyoxal-ascorbate condensation product )'},
#  {'cui': 'MESH:C000240',
#   'title': 'NSC 84963',
#   'type': 'CHEM',
#   'description': 'NSC 84963 ( CHEM : 4-amino-1,2,5-selenadiazole-3-carboxamide ; NSC-84963 )'},
#  {'cui': 'MESH:C000241',
#   'title': 'carbanolate',
#   'type': 'CHEM',
#   'description': 'carbanolate ( CHEM : 2-chloro-4,5-dimethylphenyl-N-methylcarbamate ; Banol )'},
#  {'cui': 'MESH:C000242',
#   'title': 'inositol nicotinate, mefruside, reserpine drug combination',
#   'type': 'CHEM',
#   'description': 'inositol nicotinate, mefruside, reserpine drug combination ( CHEM : inositol nicotinate - mefruside - reserpine ; Bendigon ; Bay Mc 4540 )'},
#  {'cui': 'MESH:C000245',
#   'title': 'N-(4-(2-benzimidazolyl)phenyl)maleimide',
#   'type': 'CHEM',
#   'description': 'N-(4-(2-benzimidazolyl)phenyl)maleimide ( CHEM : 1H-Pyrrole-2,5-dione, 1-(4-(1H-benzimidazol-2-yl)phenyl)- ; BP-MAL ; N-(p-(2-benzimidazolyl)phenyl)maleimide ; N-(p-(benzimidazol-2-yl)phenyl)maleimide ; BIPM cpd )'},
#  {'cui': 'MESH:C000249',
#   'title': 'benzylsuccinic acid',
#   'type': 'CHEM',
#   'description': 'benzylsuccinic acid ( CHEM )'},
#  {'cui': 'MESH:C000250',
#   'title': '1-benzyl-2-thio-5,6-dihydrouracil',
#   'type': 'CHEM',
#   'description': '1-benzyl-2-thio-5,6-dihydrouracil ( CHEM )'},
#  {'cui': 'MESH:C000252',
#   'title': 'betalamic acid',
#   'type': 'CHEM',
#   'description': 'betalamic acid ( CHEM )'},
#  {'cui': 'MESH:C000253',
#   'title': 'bicyclophenamine',
#   'type': 'CHEM',
#   'description': 'bicyclophenamine ( CHEM : 2-phenylbicyclo(2.2.1)heptane-2-carboxylic acid beta-pyrrolidinoethyl ester )'},
#  {'cui': 'MESH:C000257',
#   'title': 'polyhydroxyethyl methacrylate hydrogels',
#   'type': 'CHEM',
#   'description': 'polyhydroxyethyl methacrylate hydrogels ( CHEM : polyhydroxyethylmethacrylate hydrogel ; polymacon ; Soflens ; Spheron 300 ; 2-hydroxyethyl methacrylate, N-vinyl pyrrolidone and 4-tertiary butyl-2-hydroxycyclohexyl methacrylate hydrogel )'},
#  {'cui': 'MESH:C000259',
#   'title': 'orazamide',
#   'type': 'CHEM',
#   'description': 'orazamide ( CHEM : 1,2,3,6-tetrahydro-2,6-dioxo-4-pyrimidinecarboxylic acid cpd with 5-amino-1H-imidazole-4-carboxamide ; 4(5)-aminoimidazole-5(4)-carboxamide orotic acid salt ; AICA orotate ; orazamid ; Aicamine )'},
#  {'cui': 'MESH:C000261',
#   'title': 'N-acetylethyleneimine',
#   'type': 'CHEM',
#   'description': 'N-acetylethyleneimine ( CHEM )'},
#  {'cui': 'MESH:C000263',
#   'title': 'S-Adchnon',
#   'type': 'CHEM',
#   'description': 'S-Adchnon ( CHEM : adrenochrome monoguanylhydrazone methanesulfonate ; adrenochrome derivative (AMM) ; adrenochrome monoaminoguanidine methanesulfonate )'},
#  {'cui': 'MESH:C000264',
#   'title': '2-amino-4-methoxy-3-butenoic acid',
#   'type': 'CHEM',
#   'description': '2-amino-4-methoxy-3-butenoic acid ( CHEM : L-2-amino-4-methoxy-trans-3-butenoic acid ; 2-amino-4-methoxy-3-butenoic acid, (E)-isomer )'},
#  {'cui': 'MESH:C000265',
#   'title': 'amyrin acetate',
#   'type': 'CHEM',
#   'description': 'amyrin acetate ( CHEM : urs-12-en-3 beta-ol(acetate) ; beta-amyrin acetate ; alpha-amyrin acetate )'},
#  {'cui': 'MESH:C000266',
#   'title': 'arabinosone',
#   'type': 'CHEM',
#   'description': 'arabinosone ( CHEM : d-arabinosone ; D-erythro-pentos-2-ulose ; arabinosone, (L)-isomer )'},
#  {'cui': 'MESH:C000269',
#   'title': 'bikaverin',
#   'type': 'CHEM',
#   'description': 'bikaverin ( CHEM : 7,10-dihydro-6,11-dihydroxy-3,8-dimethoxy-1-methyl-12H-benzo(b)xanthene-7,10,12-trione )'},
#  {'cui': 'MESH:C000272',
#   'title': "N,N'-bis(4-aminophenyl)-N,N'-dimethylethylenediamine",
#   'type': 'CHEM',
#   'description': "N,N'-bis(4-aminophenyl)-N,N'-dimethylethylenediamine ( CHEM : 1,4-Benzenediamine, N,N''-1,2-ethanediylbis(N-methyl-) )"},
#  {'cui': 'MESH:C000273',
#   'title': "N,N'-bis(4-aminophenyl)-1,3-xylylenediamine",
#   'type': 'CHEM',
#   'description': "N,N'-bis(4-aminophenyl)-1,3-xylylenediamine ( CHEM : 1,3-Benzenedimethanamine, N,N'-bis(4-aminophenyl)- )"},
#  {'cui': 'MESH:C000275',
#   'title': "N,N'-bis(gamma-aminopropyl)diaminoethane",
#   'type': 'CHEM',
#   'description': "N,N'-bis(gamma-aminopropyl)diaminoethane ( CHEM )"},
#  {'cui': 'MESH:C000277',
#   'title': 'EL 241',
#   'type': 'CHEM',
#   'description': 'EL 241 ( CHEM : alpha-alpha-bis(p-chlorophenyl)-3-pyridine methanol ; EL-241 )'},
#  {'cui': 'MESH:C000278',
#   'title': "1,1'-bis(L-alpha,beta-diaminopropionic acid)actinomycin D",
#   'type': 'CHEM',
#   'description': "1,1'-bis(L-alpha,beta-diaminopropionic acid)actinomycin D ( CHEM : (di(1'-L-alpha,beta-diaminopropionic acid))actinomycin D )"},
#  {'cui': 'MESH:C000279',
#   'title': 'diazan',
#   'type': 'CHEM',
#   'description': 'diazan ( CHEM : 1,2-bis(diazoacetyl)ethane ; diazane )'},
#  {'cui': 'MESH:C000283',
#   'title': '1,2-bis(3,5-dioxopiperazin-1-yl)ethane',
#   'type': 'CHEM',
#   'description': '1,2-bis(3,5-dioxopiperazin-1-yl)ethane ( CHEM : ICRF-154 ; ICRF 154 )'},
#  {'cui': 'MESH:C000286',
#   'title': 'N-bis(2-fluoroethyl)triazene',
#   'type': 'CHEM',
#   'description': 'N-bis(2-fluoroethyl)triazene ( CHEM )'},
#  {'cui': 'MESH:C000287',
#   'title': 'bis(3-hydroxypropyl)trisulfide',
#   'type': 'CHEM',
#   'description': 'bis(3-hydroxypropyl)trisulfide ( CHEM )'},
#  {'cui': 'MESH:C000288',
#   'title': 'ritrosulfan',
#   'type': 'CHEM',
#   'description': "ritrosulfan ( CHEM : 1,4-bis(2'-mesyloxyethylamino)-1,4-dideoxy-meso-erythritol ; dimesylerythritol ; lycurim ; lykurim ; ritosulfan ; R-74 ; ritrosulfan, dihydrochloride, (R*,S*)-isomer ; ritrosulfan, dimethanesulfonate, (R*,S*)-isomer ; ritrosulfan, (R*,S*)-isomer, 14C-labeled )"},
#  {'cui': 'MESH:C000290',
#   'title': 'Ro 8-2580',
#   'type': 'CHEM',
#   'description': 'Ro 8-2580 ( CHEM : 1,3-bis(4-(p-methoxyphenyl)piperazinyl)-2-propanol )'},
#  {'cui': 'MESH:C000291',
#   'title': 'AY 9928',
#   'type': 'CHEM',
#   'description': "AY 9928 ( CHEM : 1,4-cyclohexanedimethanamine, N,N'-bis(1-naphthalenylmethyl)-, dihydrochloride ; AY-9928 ; N,N'-bis(1-naphthylmethyl)-1,4-cyclohexanebis(methylamine).2HCl ; AY 9928, dihydrochloride, (cis)-isomer ; AY 9928, dihydrochloride, (trans)-isomer )"},
#  {'cui': 'MESH:C000293',
#   'title': 'bisnoryangonin',
#   'type': 'CHEM',
#   'description': 'bisnoryangonin ( CHEM : 4-hydroxy-6-(4-hydroxystyryl)-2-pyrone )'},
#  {'cui': 'MESH:C000294',
#   'title': 'hexachloro-4-xylene',
#   'type': 'CHEM',
#   'description': 'hexachloro-4-xylene ( CHEM : 1,4-bis(trichloromethyl)benzene ; chloxyl ; hexachloro-p-xylene ; hexachloroparaxylol ; Hetol )'},
#  {'cui': 'MESH:C000295',
#   'title': 'Bis-Q',
#   'type': 'CHEM',
#   'description': "Bis-Q ( CHEM : 3,3'-bis(alpha-(trimethylammonium)methyl)azobenzene ; trans-3,3'-bis(alpha-(trimethylammonium)methyl)azobenzene dibromide ; Bis-Q dibromide ; Bis-Q dibromide, (E)-isomer ; Bis-Q, (E)-isomer ; Bis-Q dibromide, (Z)-isomer ; Bis-Q, (Z)-isomer )"},
#  {'cui': 'MESH:C000296',
#   'title': '1,5-bis(4-trimethylammoniumphenyl)pentan-3-one',
#   'type': 'CHEM',
#   'description': '1,5-bis(4-trimethylammoniumphenyl)pentan-3-one ( CHEM : BTAPP-3 ; 1,5-bis(4-trimethylammoniumphenyl)pentan-3-one diiodide )'},
#  {'cui': 'MESH:C000297',
#   'title': 'bithionol sulfoxide',
#   'type': 'CHEM',
#   'description': 'bithionol sulfoxide ( CHEM : bis(2-hydroxy-3,5-dichlorophenyl)sulfoxide ; bis(3,5-dichloro-2-hydroxyphenyl)sulfoxide ; Bitin-S ; bithionol sulfoxide, monosodium salt )'},
#  {'cui': 'MESH:C000298',
#   'title': 'brilliant black 1',
#   'type': 'CHEM',
#   'description': 'brilliant black 1 ( CHEM : 2-(4-(p-sulfophenylazo)-7-sulfo-1-naphthylazo)-8-acetamido-1-naphthol-3,5-di-sulonic acid, tetrasodium salt ; Black PN ; brilliant black BN ; C.I.(1956) No. 28440 )'},
#  {'cui': 'MESH:C000299',
#   'title': 'Blankophor FBO',
#   'type': 'CHEM',
#   'description': 'Blankophor FBO ( CHEM )'},
#  {'cui': 'MESH:C000301',
#   'title': 'trimethoprim, sulfadoxine drug combination',
#   'type': 'CHEM',
#   'description': 'trimethoprim, sulfadoxine drug combination ( CHEM : trimethoprim-sulfadoxine drug combination ; tridoxine ; trimethoprim-sulfadoxine ; trimethoprim - sulfadoxine ; Borgal ; Ro 6-2153 )'},
#  {'cui': 'MESH:C000302',
#   'title': 'boromycin',
#   'type': 'CHEM',
#   'description': 'boromycin ( CHEM )'},
#  {'cui': 'MESH:C000307',
#   'title': 'broadcillin',
#   'type': 'CHEM',
#   'description': 'broadcillin ( CHEM : 4-Thia-1-azabicyclo(3.2.0)heptane-2-carboxylic acid, 6-((aminophenylacetyl)amino)-3,3-dimethyl-7-oxo-, (2S-(2alpha,5alpha,6beta(S*)))-, mixt. with (2S-(2alpha,5alpha,6beta))-3,3-dimethyl-6-(((5-methyl-3-phenyl-4-isoxazolyl)carbonyl)amino)-7-oxo-4-thia-1-azabicyclo(3.2.0)heptane-2-carboxylic acid ; ampiox )'},
#  {'cui': 'MESH:C000309',
#   'title': '2-bromoacetamide-4-nitrophenol',
#   'type': 'CHEM',
#   'description': '2-bromoacetamide-4-nitrophenol ( CHEM )'},
#  {'cui': 'MESH:C000310',
#   'title': '3-bromoacetonyl trimethylammonium',
#   'type': 'CHEM',
#   'description': '3-bromoacetonyl trimethylammonium ( CHEM : 3-bromoacetonyl trimethylammonium bromide )'},
#  {'cui': 'MESH:C000311',
#   'title': '16 alpha-bromoacetoxyprogesterone',
#   'type': 'CHEM',
#   'description': '16 alpha-bromoacetoxyprogesterone ( CHEM )'},
#  {'cui': 'MESH:C000312',
#   'title': '4-bromobenzylisothiocyanate',
#   'type': 'CHEM',
#   'description': '4-bromobenzylisothiocyanate ( CHEM : 4-bromobenzyl-isothiocyanate )'},
#  {'cui': 'MESH:C000314',
#   'title': 'alpha-bromo-beta-(5-imidazolyl)propionic acid',
#   'type': 'CHEM',
#   'description': 'alpha-bromo-beta-(5-imidazolyl)propionic acid ( CHEM : 2-bromo-3-(5-imidazolyl)propionate )'},
#  {'cui': 'MESH:C000316',
#   'title': '1-bromomercuri-2-hydroxypropane',
#   'type': 'CHEM',
#   'description': '1-bromomercuri-2-hydroxypropane ( CHEM : bromomercurihydroxypropane ; BMHP ; 1-bromomercuri-2-hydroxypropane, 197Hg-labeled ; 1-bromomercuri-2-hydroxypropane, 203Hg-labeled )'},
#  {'cui': 'MESH:C000317',
#   'title': '4-bromomethyl-7-methoxycoumarin',
#   'type': 'CHEM',
#   'description': '4-bromomethyl-7-methoxycoumarin ( CHEM : 4-bromomethyl-7-methoxy-2-oxo-2H-benzopyran ; 4-(bromomethyl)-7-methoxy-2-oxo-2H-benzopyran )'},
#  {'cui': 'MESH:C000318',
#   'title': '4-bromopyrazole',
#   'type': 'CHEM',
#   'description': '4-bromopyrazole ( CHEM )'},
#  {'cui': 'MESH:C000319',
#   'title': '6-bromoquinazolone',
#   'type': 'CHEM',
#   'description': '6-bromoquinazolone ( CHEM )'},
#  {'cui': 'MESH:C000320',
#   'title': '2-bromostearic acid',
#   'type': 'CHEM',
#   'description': '2-bromostearic acid ( CHEM : 2-bromostearate ; 2-bromostearic acid, potassium salt ; 2-bromostearic acid, 77Br-labeled )'},
#  {'cui': 'MESH:C000323',
#   'title': 'bromotubercidin',
#   'type': 'CHEM',
#   'description': 'bromotubercidin ( CHEM : 5-bromotubericidin )'},
#  {'cui': 'MESH:C000324',
#   'title': 'Brown FK',
#   'type': 'CHEM',
#   'description': 'Brown FK ( CHEM : Brown-FK )'},
#  {'cui': 'MESH:C000325',
#   'title': 'brufacaine',
#   'type': 'CHEM',
#   'description': 'brufacaine ( CHEM : glycerol-1-(2-diethylaminoethyl ether)-3-(2-methoxyphenyl ether).HCl ; brufacaine hydrochloride )'},
#  {'cui': 'MESH:C000327',
#   'title': 'atropine, pralidoxime iodide, trichlorofon drug combination',
#   'type': 'CHEM',
#   'description': 'atropine, pralidoxime iodide, trichlorofon drug combination ( CHEM : atropine - pralidoxime iodide - trichlorofon ; Bubulin )'},
#  {'cui': 'MESH:C000329',
#   'title': 'bufeniode',
#   'type': 'CHEM',
#   'description': 'bufeniode ( CHEM : 1-(4-hydroxy-3,5-diiodophenyl)-2-(1-methyl-3-phenylpropylamino)propanol ; diiodobufenine ; diiodobuphenine ; Proclival )'},
#  {'cui': 'MESH:C000330',
#   'title': 'bulbiformin',
#   'type': 'CHEM',
#   'description': 'bulbiformin ( CHEM )'},
#  {'cui': 'MESH:C000334',
#   'title': 'butanediol divinylether',
#   'type': 'CHEM',
#   'description': 'butanediol divinylether ( CHEM )'},
#  {'cui': 'MESH:C000335',
#   'title': 'butanesultone',
#   'type': 'CHEM',
#   'description': 'butanesultone ( CHEM )'},
#  {'cui': 'MESH:C000336',
#   'title': 'butazidamine',
#   'type': 'CHEM',
#   'description': 'butazidamine ( CHEM : 3H-Pyrazol-3-one, 4-butyl-1,2-dihydro-5-hydroxy-1,2-diphenyl-, compd. with 3-(3-(dimethylamino)propoxy)-1-(phenylmethyl)-1H-indazole (1:1) ; LS-701 ; 4-butyl-1,2-diphenyl-5-hydroxy-3-oxo-pyrazolidine compd. with 1-benzyl-3,3-(dimethylamino)propoxy-1H-indazole ; LS 701 )'},
#  {'cui': 'MESH:C000337',
#   'title': 'butabarbital, hydrochlorothiazide, reserpine drug combination',
#   'type': 'CHEM',
#   'description': 'butabarbital, hydrochlorothiazide, reserpine drug combination ( CHEM : butabarbital - hydrochlorothiazide - reserpine ; butiserpazide )'},
#  {'cui': 'MESH:C000339',
#   'title': 'WR 10488',
#   'type': 'CHEM',
#   'description': 'WR 10488 ( CHEM : 2-N-butoxy-7,10-dichloropyrido(3,2-b)quinoline ; WR-10488 ; WR 10,488 )'},
#  {'cui': 'MESH:C000342',
#   'title': '4-(4-tert-butylbenzoyl)-3-methyl-1-phenyl-2-pyrazolin-5-one',
#   'type': 'CHEM',
#   'description': '4-(4-tert-butylbenzoyl)-3-methyl-1-phenyl-2-pyrazolin-5-one ( CHEM : 4-(p-tert-butylbenzoyl)-3-methyl-1-phenyl-2-pyrazolin-5-one )'},
#  {'cui': 'MESH:C000343',
#   'title': 'N-t-butyl-5-methyl isoxazolium perchlorate',
#   'type': 'CHEM',
#   'description': 'N-t-butyl-5-methyl isoxazolium perchlorate ( CHEM )'},
#  {'cui': 'MESH:C000345',
#   'title': 't-butyloxycarbonyl group',
#   'type': 'CHEM',
#   'description': 't-butyloxycarbonyl group ( CHEM : BOC group ; butyloxycarbonyl group )'},
#  {'cui': 'MESH:C000347',
#   'title': '1-N-butyryl-4-cinnamylpiperazine',
#   'type': 'CHEM',
#   'description': '1-N-butyryl-4-cinnamylpiperazine ( CHEM : AP 237 ; BUCINNAZINE HYDROCHLORIDE ; 1-(1-oxobutyl)-4-(3-phenyl-2-propenyl)piperazine hydrochloride ; AP-237 ; 1-N-butyryl-4-cinnamylpiperazine hydrochloride )'},
#  {'cui': 'MESH:C000349',
#   'title': 'buffencarb',
#   'type': 'CHEM',
#   'description': 'buffencarb ( CHEM )'},
#  {'cui': 'MESH:C000352',
#   'title': 'elenolic acid',
#   'type': 'CHEM',
#   'description': 'elenolic acid ( CHEM : 3-formyl-3,4-dihydro-5-(methoxycarbonyl)-2-methyl-2H-pyran-4-acetic acid ; calcium elenolate ; elenolic acid, calcium (2:1) salt, (2S-(2alpha,3alpha,4beta))-isomer ; elenolic acid Ca salt, (2S-(2alpha,3alpha,4beta))-isomer )'},
#  {'cui': 'MESH:C000353',
#   'title': 'calcium lignosulfonate',
#   'type': 'CHEM',
#   'description': 'calcium lignosulfonate ( CHEM : calcium lignin sulfonate ; calcium lignosulfonate (2000 MW) )'},
#  {'cui': 'MESH:C000354',
#   'title': 'bifidus factor',
#   'type': 'CHEM',
#   'description': 'bifidus factor ( CHEM : calcium D-pantotheine-S-sulfonate )'},
#  {'cui': 'MESH:C000357',
#   'title': 'cannabivarin',
#   'type': 'CHEM',
#   'description': 'cannabivarin ( CHEM )'},
#  {'cui': 'MESH:C000360',
#   'title': 'caproamide',
#   'type': 'CHEM',
#   'description': 'caproamide ( CHEM : hexanamide )'},
#  {'cui': 'MESH:C000361',
#   'title': 'caprogen',
#   'type': 'CHEM',
#   'description': 'caprogen ( CHEM )'},
#  {'cui': 'MESH:C000362',
#   'title': 'capron',
#   'type': 'CHEM',
#   'description': 'capron ( CHEM : poly(hexahydro-2H-azepin-2-one) ; polycaprolactam )'},
#  {'cui': 'MESH:C000363',
#   'title': 'cycloheptanone',
#   'type': 'CHEM',
#   'description': 'cycloheptanone ( CHEM )'},
#  {'cui': 'MESH:C000364',
#   'title': 'Captostibone (g)',
#   'type': 'CHEM',
#   'description': 'Captostibone (g) ( CHEM : sodium 2-(carboxymethylmercapto)benzene stibonate )'},
#  {'cui': 'MESH:C000366',
#   'title': 'O-carbamylserine',
#   'type': 'CHEM',
#   'description': 'O-carbamylserine ( CHEM : O-carbamyl-D-serine ; O-carbamylserine, (L)-isomer )'},
#  {'cui': 'MESH:C000375',
#   'title': '3-carboxy-4-ferrocenylphenyl isothiocyanate',
#   'type': 'CHEM',
#   'description': '3-carboxy-4-ferrocenylphenyl isothiocyanate ( CHEM )'},
#  {'cui': 'MESH:C000380',
#   'title': 'fosfosal',
#   'type': 'CHEM',
#   'description': 'fosfosal ( CHEM : Benzoic acid, 2-(phosphonooxy)- ; 2-carboxyphenylphosphoric acid ; 2-phosphonoxybenzoic acid ; o-carboxyphenylphosphate ; o-carboxyphenylphosphoric acid ; o-carboxyphenyl phosphate ; o-cpp cpd ; Aydolid ; Disdolen ; Protalgia )'},
#  {'cui': 'MESH:C000381',
#   'title': "7-carboxy-delta'-tetrahydrocannabinol",
#   'type': 'CHEM',
#   'description': "7-carboxy-delta'-tetrahydrocannabinol ( CHEM )"},
#  {'cui': 'MESH:C000382',
#   'title': 'carcinoegresin',
#   'type': 'CHEM',
#   'description': 'carcinoegresin ( CHEM )'},
#  {'cui': 'MESH:C000383',
#   'title': 'digoxin, etamivan, etofylline, hexobendine drug combination',
#   'type': 'CHEM',
#   'description': 'digoxin, etamivan, etofylline, hexobendine drug combination ( CHEM : digoxin - etamivan - etofylline - hexobendine ; Card-Instenon )'},
#  {'cui': 'MESH:C000384',
#   'title': 'carinamide',
#   'type': 'CHEM',
#   'description': "carinamide ( CHEM : p-(benzylsulfamido)benzoic acid ; 4'-carboxyphenylmethanesulfonanilide )"},
#  {'cui': 'MESH:C000387',
#   'title': 'Carminagel',
#   'type': 'CHEM',
#   'description': 'Carminagel ( CHEM )'},
#  {'cui': 'MESH:C000390',
#   'title': 'carnitylcholine',
#   'type': 'CHEM',
#   'description': 'carnitylcholine ( CHEM )'},
#  {'cui': 'MESH:C000392',
#   'title': 'caulerpin',
#   'type': 'CHEM',
#   'description': 'caulerpin ( CHEM )'},
#  {'cui': 'MESH:C000393',
#   'title': 'cedrene',
#   'type': 'CHEM',
#   'description': 'cedrene ( CHEM : cedrone ; alpha-cedrene ; beta-cedrene )'},
#  {'cui': 'MESH:C000395',
#   'title': 'cephachlomezine',
#   'type': 'CHEM',
#   'description': 'cephachlomezine ( CHEM : 7-(m-chlorophenylacetamido)-3-(4,4-dimethylpiperazinium-1-thiocarbonyl-thiomethyl)-3-cephem-4-carboxylate )'},
#  {'cui': 'MESH:C000398',
#   'title': 'ceramide monohexoside sulfate',
#   'type': 'CHEM',
#   'description': 'ceramide monohexoside sulfate ( CHEM )'},
#  {'cui': 'MESH:C000400',
#   'title': 'chelocardin',
#   'type': 'CHEM',
#   'description': 'chelocardin ( CHEM : 2-decarboxamido-2-acetyl-4-dedimethylamino-4-epiamino-9- methyl-5a,6-anhydrotetracycline ; cetocycline ; cetotetrine ; Abbott 40728 ; chelocardin, (4alpha,4abeta,12abeta)-isomer ; chelocardin, hydrochloride, (4R-(4alpha,4abeta,12abeta))-isomer ; chelocardin, monosodium salt, (4R-(4alpha,4abeta,12abeta))-isomer )'},
#  {'cui': 'MESH:C000402',
#   'title': 'chinophene',
#   'type': 'CHEM',
#   'description': 'chinophene ( CHEM )'},
#  {'cui': 'MESH:C000403',
#   'title': '1-chloro-benzotriazole',
#   'type': 'CHEM',
#   'description': '1-chloro-benzotriazole ( CHEM )'},
#  {'cui': 'MESH:C000404',
#   'title': '2-chloro-4-acetotoluidine',
#   'type': 'CHEM',
#   'description': '2-chloro-4-acetotoluidine ( CHEM : 2-chloro-p-acetotoluidide )'},
#  {'cui': 'MESH:C000405',
#   'title': 'BW 63-307',
#   'type': 'CHEM',
#   'description': 'BW 63-307 ( CHEM : 2-chloro-4-acetylaminobenzonitrile ; BW-63-307 )'},
#  {'cui': 'MESH:C000406',
#   'title': 'chlorohexamide',
#   'type': 'CHEM',
#   'description': 'chlorohexamide ( CHEM : chlorobenzenesulfonylcyclohexylcarbamide ; Oradian )'},
#  {'cui': 'MESH:C000407',
#   'title': '4-chlorobenzenesulfonylglycolic acid amide',
#   'type': 'CHEM',
#   'description': '4-chlorobenzenesulfonylglycolic acid amide ( CHEM : p-chlorobenzenesulfonylglycolic acid amide )'},
#  {'cui': 'MESH:C000408',
#   'title': '4-chlorobenzenesulfonylglycolic acid nitrile',
#   'type': 'CHEM',
#   'description': '4-chlorobenzenesulfonylglycolic acid nitrile ( CHEM : p-chlorobenzenesulfonylglycolic acid nitrile )'},
#  {'cui': 'MESH:C000409',
#   'title': 'ticlatone',
#   'type': 'CHEM',
#   'description': 'ticlatone ( CHEM : 6-chloro-1,2-benzisothiazolone ; tiklaton ; FER-1443 ; Landromil ; FER 1443 )'},
#  {'cui': 'MESH:C000410',
#   'title': '1-(4-chlorobenzoyl)-5-dimethylamino-2-methylindole acetic acid',
#   'type': 'CHEM',
#   'description': '1-(4-chlorobenzoyl)-5-dimethylamino-2-methylindole acetic acid ( CHEM : 1H-Indole-3-acetic acid, 1-(4-chlorobenzoyl)-5-(dimethylamino)-2-methyl- ; 1-(p-chlorobenzoyl)-5-dimethylamino-2-methylindole acetic acid )'},
#  {'cui': 'MESH:C000411',
#   'title': 'BW 392C60',
#   'type': 'CHEM',
#   'description': "BW 392C60 ( CHEM : BW-392C60 ; N-(o-chlorobenzyl)-N',N''-dimethylguanidine sulfate ; BW 392C60, monohydroiodide ; BW 392C60 sulfate (2:1) )"},
#  {'cui': 'MESH:C000413',
#   'title': '1-(4-chlorobenzylidine)-5-methoxy-2-methyl-3-indeneacetic acid',
#   'type': 'CHEM',
#   'description': '1-(4-chlorobenzylidine)-5-methoxy-2-methyl-3-indeneacetic acid ( CHEM : 1-p-chlorobenzylidine-5-methoxy-2-methyl-3-indeneacetic acid ; 1-(4-chlorobenzylidine)-5-methoxy-2-methyl-3-indeneacetic acid, sodium salt )'},
#  {'cui': 'MESH:C000414',
#   'title': "5-chloro-3-tert-butyl-2'-nitrososalicylanilide",
#   'type': 'CHEM',
#   'description': "5-chloro-3-tert-butyl-2'-nitrososalicylanilide ( CHEM )"},
#  {'cui': 'MESH:C000415',
#   'title': "2'-chloro-2'-cyanoethyl-1-thio-beta-D-galactopyranoside",
#   'type': 'CHEM',
#   'description': "2'-chloro-2'-cyanoethyl-1-thio-beta-D-galactopyranoside ( CHEM : Propanenitrile, 2-chloro-3-(beta-D-galactopyranosylthio)- )"},
#  {'cui': 'MESH:C000417',
#   'title': 'Ro 5-5807',
#   'type': 'CHEM',
#   'description': 'Ro 5-5807 ( CHEM : 7-chloro-2,3-dihydro-N-methyl-2-oxo-5- phenyl-lH-1-benzodiazepin-1-acetamide )'},
#  {'cui': 'MESH:C000419',
# ...
#   'type': 'CHEM',
#   'description': 'N-(2-hydroxybenzylidene)acetohydrazide ( CHEM )'},
#  {'cui': 'MESH:C000589105',
#   'title': '8-hydroxy quinolinium 4-nitrobenzoate 4-nitrobenzoic acid',
#   'type': 'CHEM',
#   'description': '8-hydroxy quinolinium 4-nitrobenzoate 4-nitrobenzoic acid ( CHEM )'},
#  {'cui': 'MESH:C000589106',
#   'title': '2,4-bis(2-methoxyphenyl)-1-phenylanthracene-9,10-dione',
#   'type': 'CHEM',
#   'description': '2,4-bis(2-methoxyphenyl)-1-phenylanthracene-9,10-dione ( CHEM )'},
#  {'cui': 'MESH:C000589107',
#   'title': '2-amino-4-methyl-3-nitropyridinium hydrogen oxalate',
#   'type': 'CHEM',
#   'description': '2-amino-4-methyl-3-nitropyridinium hydrogen oxalate ( CHEM )'},
#  {'cui': 'MESH:C000589109',
#   'title': 'RWA1 protein, Arabidopsis',
#   'type': 'CHEM',
#   'description': 'RWA1 protein, Arabidopsis ( CHEM )'},
#  {'cui': 'MESH:C000589111',
#   'title': 'RWA3 protein, Arabidopsis',
#   'type': 'CHEM',
#   'description': 'RWA3 protein, Arabidopsis ( CHEM )'},
#  {'cui': 'MESH:C000589113',
#   'title': 'FATTY ACYL REDUCTASE4, Arabidopsis',
#   'type': 'CHEM',
#   'description': 'FATTY ACYL REDUCTASE4, Arabidopsis ( CHEM : FAR4 protein, Arabidopsis )'},
#  {'cui': 'MESH:C000589114',
#   'title': 'FATTY ACYL REDUCTASE5 protein, Arabidopsis',
#   'type': 'CHEM',
#   'description': 'FATTY ACYL REDUCTASE5 protein, Arabidopsis ( CHEM : FAR5 protein, Arabidopsis )'},
#  {'cui': 'MESH:C000589116',
#   'title': 'ATP sulfurylase 1, Arabidopsis',
#   'type': 'CHEM',
#   'description': 'ATP sulfurylase 1, Arabidopsis ( CHEM )'},
#  {'cui': 'MESH:C000589117',
#   'title': 'D-3-phosphoglycerate dehydrogenase, Arabidopsis',
#   'type': 'CHEM',
#   'description': 'D-3-phosphoglycerate dehydrogenase, Arabidopsis ( CHEM : PGDH protein, Arabidopsis )'},
#  {'cui': 'MESH:C000589119',
#   'title': 'SWEET16 protein, Arabidopsis',
#   'type': 'CHEM',
#   'description': 'SWEET16 protein, Arabidopsis ( CHEM : AtSWEET16 protein, Arabidopsis )'},
#  {'cui': 'MESH:C000589120',
#   'title': 'ISA1 protein, Arabidopsis',
#   'type': 'CHEM',
#   'description': 'ISA1 protein, Arabidopsis ( CHEM )'},
#  {'cui': 'MESH:C000589121',
#   'title': 'ISA2 protein, Arabidopsis',
#   'type': 'CHEM',
#   'description': 'ISA2 protein, Arabidopsis ( CHEM )'},
#  {'cui': 'MESH:C000589122',
#   'title': 'TRX1 protein, Arabidopsis',
#   'type': 'CHEM',
#   'description': 'TRX1 protein, Arabidopsis ( CHEM )'},
#  {'cui': 'MESH:C000589123',
#   'title': 'TRX2 protein, Arabidopsis',
#   'type': 'CHEM',
#   'description': 'TRX2 protein, Arabidopsis ( CHEM )'},
#  {'cui': 'MESH:C000589124',
#   'title': 'ABCC1 protein, Arabidopsis',
#   'type': 'CHEM',
#   'description': 'ABCC1 protein, Arabidopsis ( CHEM )'},
#  {'cui': 'MESH:C000589125',
#   'title': 'ABCC2 protein, Arabidopsis',
#   'type': 'CHEM',
#   'description': 'ABCC2 protein, Arabidopsis ( CHEM )'},
#  {'cui': 'MESH:C000589126',
#   'title': 'clorin-e(6) trimethyl ester',
#   'type': 'CHEM',
#   'description': 'clorin-e(6) trimethyl ester ( CHEM )'},
#  {'cui': 'MESH:C000589127',
#   'title': 'anthrahydroquinone-2,6-disulfonate',
#   'type': 'CHEM',
#   'description': 'anthrahydroquinone-2,6-disulfonate ( CHEM )'},
#  {'cui': 'MESH:C000589128',
#   'title': 'BolA protein, Arabidopsis',
#   'type': 'CHEM',
#   'description': 'BolA protein, Arabidopsis ( CHEM : At1g55805 protein, Arabidopsis ; At5g17560 protein, Arabidopsis ; At5g09830 protein, Arabidopsis ; BolA1 protein, Arabidopsis ; BolA4 protein, Arabidopsis ; BolA2 protein, Arabidopsis )'},
#  {'cui': 'MESH:C000589129',
#   'title': 'ECB1 protein, Arabidopsis',
#   'type': 'CHEM',
#   'description': 'ECB1 protein, Arabidopsis ( CHEM : AtECB1 protein, Arabidopsis ; MRL7 protein, Arabidopsis ; early chloroplast biogenesis 1 protein, Arabidopsis ; At4g28590 protein, Arabidopsis ; SUPPRESSION OF VARIEGATION 4 protein, Arabidopsis ; SVR4 protein, Arabidopsis )'},
#  {'cui': 'MESH:C000589130',
#   'title': '2-(1H-imidazo(4,5-f)(1,10)phenanthrolin-2-yl)phenol',
#   'type': 'CHEM',
#   'description': '2-(1H-imidazo(4,5-f)(1,10)phenanthrolin-2-yl)phenol ( CHEM : 2-(1H-Imidazo(4,5-ƒ)(1,10)phenanthrolin-2-yl)phenol )'},
#  {'cui': 'MESH:C000589131',
#   'title': 'AHDC1 protein, human',
#   'type': 'CHEM',
#   'description': 'AHDC1 protein, human ( CHEM : AT hook DNA binding motif containing 1 protein, human ; DJ159A19.3 protein, human ; RP1-159A19.1 protein, human )'},
#  {'cui': 'MESH:C000589132',
#   'title': 'PIEZO2 protein, human',
#   'type': 'CHEM',
#   'description': 'PIEZO2 protein, human ( CHEM : piezo-type mechanosensitive ion channel component 2 protein, human )'},
#  {'cui': 'MESH:C000589133',
#   'title': '4-(3-(3-(3,5-4-(3-(3-(3,5-dibromo-4-hydroxyphenyl)-propylamino)phenyl)butyric acid',
#   'type': 'CHEM',
#   'description': '4-(3-(3-(3,5-4-(3-(3-(3,5-dibromo-4-hydroxyphenyl)-propylamino)phenyl)butyric acid ( CHEM )'},
#  {'cui': 'MESH:C000589134',
#   'title': 'Nedd4-binding protein 3, rat',
#   'type': 'CHEM',
#   'description': 'Nedd4-binding protein 3, rat ( CHEM : N4BP3 protein, rat )'},
#  {'cui': 'MESH:C000589135',
#   'title': '3-(3,5-dibromo-4-hydroxyphenyl)-propylamino-acetamidobenzoic acid',
#   'type': 'CHEM',
#   'description': '3-(3,5-dibromo-4-hydroxyphenyl)-propylamino-acetamidobenzoic acid ( CHEM )'},
#  {'cui': 'MESH:C000589136',
#   'title': '(E)-methyl 2-(7-chloroquinolin-4-ylthio)-3-(4-hydroxyphenyl)acrylate',
#   'type': 'CHEM',
#   'description': '(E)-methyl 2-(7-chloroquinolin-4-ylthio)-3-(4-hydroxyphenyl)acrylate ( CHEM )'},
#  {'cui': 'MESH:C000589137',
#   'title': '2-(3,4,5-triacetoxybenzoylamino)benzo(d)thiazole',
#   'type': 'CHEM',
#   'description': '2-(3,4,5-triacetoxybenzoylamino)benzo(d)thiazole ( CHEM )'},
#  {'cui': 'MESH:C000589138',
#   'title': 'TCF7L2 protein, zebrafish',
#   'type': 'CHEM',
#   'description': 'TCF7L2 protein, zebrafish ( CHEM )'},
#  {'cui': 'MESH:C000589140',
#   'title': '2-(galloylamino)benzo(d)thiazole',
#   'type': 'CHEM',
#   'description': '2-(galloylamino)benzo(d)thiazole ( CHEM )'},
#  {'cui': 'MESH:C000589141',
#   'title': '9-(2,4-dinitrophenyloxy)-3,3,8-trimethyl-1,5-dihydro-(1,3)dioxepino(5,6-c)pyridine',
#   'type': 'CHEM',
#   'description': '9-(2,4-dinitrophenyloxy)-3,3,8-trimethyl-1,5-dihydro-(1,3)dioxepino(5,6-c)pyridine ( CHEM )'},
#  {'cui': 'MESH:C000589142',
#   'title': 'Rng8 protein, S pombe',
#   'type': 'CHEM',
#   'description': 'Rng8 protein, S pombe ( CHEM )'},
#  {'cui': 'MESH:C000589143',
#   'title': 'Rng9 protein, S pombe',
#   'type': 'CHEM',
#   'description': 'Rng9 protein, S pombe ( CHEM )'},
#  {'cui': 'MESH:C000589145',
#   'title': 'NDUFA12 protein, human',
#   'type': 'CHEM',
#   'description': 'NDUFA12 protein, human ( CHEM : NADH dehydrogenase (ubiquinone) 1 alpha subcomplex, 12, human )'},
#  {'cui': 'MESH:C000589146',
#   'title': 'HS6ST3 protein, human',
#   'type': 'CHEM',
#   'description': 'HS6ST3 protein, human ( CHEM : heparan sulfate 6-O-sulfotransferase 3, human )'},
#  {'cui': 'MESH:C000589147',
#   'title': 'Basic Red 51',
#   'type': 'CHEM',
#   'description': 'Basic Red 51 ( CHEM : 2-(((4-dimethylamino)phenyl)azo)-1,3-dimethyl-1H-imidazolium chloride )'},
#  {'cui': 'MESH:C000589148',
#   'title': 'pyrrocidine C',
#   'type': 'CHEM',
#   'description': 'pyrrocidine C ( CHEM )'},
#  {'cui': 'MESH:C000589149',
#   'title': 'stewartiiside',
#   'type': 'CHEM',
#   'description': 'stewartiiside ( CHEM )'},
#  {'cui': 'MESH:C000589150',
#   'title': 'swietephragmin H',
#   'type': 'CHEM',
#   'description': 'swietephragmin H ( CHEM )'},
#  {'cui': 'MESH:C000589151',
#   'title': 'swietephragmin I',
#   'type': 'CHEM',
#   'description': 'swietephragmin I ( CHEM )'},
#  {'cui': 'MESH:C000589152',
#   'title': '11-hydroxyswietephragmin B',
#   'type': 'CHEM',
#   'description': '11-hydroxyswietephragmin B ( CHEM )'},
#  {'cui': 'MESH:C000589153',
#   'title': '1-spiro(4.5)dec-7-en-7-yl-4-pent-1-one',
#   'type': 'CHEM',
#   'description': '1-spiro(4.5)dec-7-en-7-yl-4-pent-1-one ( CHEM )'},
#  {'cui': 'MESH:C000589154',
#   'title': '2-cyclohexyl-1,6-heptadien-3-one',
#   'type': 'CHEM',
#   'description': '2-cyclohexyl-1,6-heptadien-3-one ( CHEM )'},
#  {'cui': 'MESH:C000589155',
#   'title': '1-(3,3-dimethylcyclohexyl)ethan-1-one',
#   'type': 'CHEM',
#   'description': '1-(3,3-dimethylcyclohexyl)ethan-1-one ( CHEM )'},
#  {'cui': 'MESH:C000589156',
#   'title': 'methyl-2,6,10-trimethylcyclododeca-2,5,9-trien-1-yl ketone',
#   'type': 'CHEM',
#   'description': 'methyl-2,6,10-trimethylcyclododeca-2,5,9-trien-1-yl ketone ( CHEM )'},
#  {'cui': 'MESH:C000589157',
#   'title': '1-(5,5-dimethylcyclohexen-1-yl)pent-4-en-1-one',
#   'type': 'CHEM',
#   'description': '1-(5,5-dimethylcyclohexen-1-yl)pent-4-en-1-one ( CHEM )'},
#  {'cui': 'MESH:C000589158',
#   'title': 'MIRN146 microRNA, zebrafish',
#   'type': 'CHEM',
#   'description': 'MIRN146 microRNA, zebrafish ( CHEM : microRNA-146, zebrafish ; mir146b, zebrafish ; mir146a, zebrafish ; dre-mir-146 ; miR-146, zebrafish )'},
#  {'cui': 'MESH:C000589159',
#   'title': 'emindole SB beta-mannoside',
#   'type': 'CHEM',
#   'description': 'emindole SB beta-mannoside ( CHEM )'},
#  {'cui': 'MESH:C000589160',
#   'title': '27-O-methylasporyzin C',
#   'type': 'CHEM',
#   'description': '27-O-methylasporyzin C ( CHEM )'},
#  {'cui': 'MESH:C000589161',
#   'title': 'eurycomalide C',
#   'type': 'CHEM',
#   'description': 'eurycomalide C ( CHEM )'},
#  {'cui': 'MESH:C000589162',
#   'title': 'frangulin A',
#   'type': 'CHEM',
#   'description': 'frangulin A ( CHEM )'},
#  {'cui': 'MESH:C000589164',
#   'title': 'glucofrangulin A',
#   'type': 'CHEM',
#   'description': 'glucofrangulin A ( CHEM )'},
#  {'cui': 'MESH:C000589165',
#   'title': 'glucofrangulin B',
#   'type': 'CHEM',
#   'description': 'glucofrangulin B ( CHEM )'},
#  {'cui': 'MESH:C000589166',
#   'title': 'altersolanol P',
#   'type': 'CHEM',
#   'description': 'altersolanol P ( CHEM )'},
#  {'cui': 'MESH:C000589182',
#   'title': 'ypsilanogenin',
#   'type': 'CHEM',
#   'description': 'ypsilanogenin ( CHEM )'},
#  {'cui': 'MESH:C000589183',
#   'title': 'NheA protein, Bacillus cereus',
#   'type': 'CHEM',
#   'description': 'NheA protein, Bacillus cereus ( CHEM )'},
#  {'cui': 'MESH:C000589184',
#   'title': 'N2,N4-bis(2-methyl-1H-indol-5-yl)pyrimidine-2,4-diamine',
#   'type': 'CHEM',
#   'description': 'N2,N4-bis(2-methyl-1H-indol-5-yl)pyrimidine-2,4-diamine ( CHEM )'},
#  {'cui': 'MESH:C000589185',
#   'title': 'SECTM1A protein, mouse',
#   'type': 'CHEM',
#   'description': 'SECTM1A protein, mouse ( CHEM : secreted and transmembrane 1A protein, mouse )'},
#  {'cui': 'MESH:C000589186',
#   'title': 'SECTM1B protein, mouse',
#   'type': 'CHEM',
#   'description': 'SECTM1B protein, mouse ( CHEM : secreted and transmembrane 1B protein, mouse )'},
#  {'cui': 'MESH:C000589187',
#   'title': 'NECC2 protein, rat',
#   'type': 'CHEM',
#   'description': 'NECC2 protein, rat ( CHEM : neuroendocrine long coiled-coil protein 2, rat )'},
#  {'cui': 'MESH:C000589188',
#   'title': 'PSMA1 protein, human',
#   'type': 'CHEM',
#   'description': 'PSMA1 protein, human ( CHEM )'},
#  {'cui': 'MESH:C000589189',
#   'title': '5-(6-isopropyl-2-methylaminopyridin-3-yl)-(N-(1-ethyl)propyl)-3-methoxy-6-methylpyrazine-2-amine',
#   'type': 'CHEM',
#   'description': '5-(6-isopropyl-2-methylaminopyridin-3-yl)-(N-(1-ethyl)propyl)-3-methoxy-6-methylpyrazine-2-amine ( CHEM : NGD 9002 )'},
#  {'cui': 'MESH:C000589190',
#   'title': 'MIRN-4437 microRNA, human',
#   'type': 'CHEM',
#   'description': 'MIRN-4437 microRNA, human ( CHEM : miR-4437, human ; microRNA-4437, human ; hsa-mir-4437 )'},
#  {'cui': 'MESH:C000589191',
#   'title': 'MIRN4674 microRNA, human',
#   'type': 'CHEM',
#   'description': 'MIRN4674 microRNA, human ( CHEM : microRNA-4674, human ; miR-4674, human ; hsa-mir-4674 )'},
#  {'cui': 'MESH:C000589192',
#   'title': 'Mzt1 protein, S pombe',
#   'type': 'CHEM',
#   'description': 'Mzt1 protein, S pombe ( CHEM : Tam4 protein, S pombe )'},
#  {'cui': 'MESH:C000589193',
#   'title': 'MOZART1 protein, human',
#   'type': 'CHEM',
#   'description': 'MOZART1 protein, human ( CHEM )'},
#  {'cui': 'MESH:C000589194',
#   'title': 'Dyrk2 protein, zebrafish',
#   'type': 'CHEM',
#   'description': 'Dyrk2 protein, zebrafish ( CHEM : dual-specificity tyrosine phosphorylated and regulated kinase 2, zebrafish )'},
#  {'cui': 'MESH:C000589195',
#   'title': 'leptosin O',
#   'type': 'CHEM',
#   'description': 'leptosin O ( CHEM )'},
#  {'cui': 'MESH:C000589196',
#   'title': '(bipyridine)(morpholine dithiocarbamate)platinum(II)',
#   'type': 'CHEM',
#   'description': '(bipyridine)(morpholine dithiocarbamate)platinum(II) ( CHEM : bipyridine morpholine dithiocarbamate Pt(II) nitrate )'},
#  {'cui': 'MESH:C000589197',
#   'title': 'Ginkgo biloba extract 1212',
#   'type': 'CHEM',
#   'description': 'Ginkgo biloba extract 1212 ( CHEM : EGB1212 )'},
#  {'cui': 'MESH:C000589198',
#   'title': 'N-isobutyl-11-(4-chlorophenyl)undeca-2,4,9-trienamide',
#   'type': 'CHEM',
#   'description': 'N-isobutyl-11-(4-chlorophenyl)undeca-2,4,9-trienamide ( CHEM )'},
#  {'cui': 'MESH:C000589199',
#   'title': 'hassallidin C',
#   'type': 'CHEM',
#   'description': 'hassallidin C ( CHEM )'},
#  {'cui': 'MESH:C000589200',
#   'title': 'hassallidin D',
#   'type': 'CHEM',
#   'description': 'hassallidin D ( CHEM )'},
#  {'cui': 'MESH:C000589201',
#   'title': 'Rv3903 protein, Mycobacterium tuberculosis',
#   'type': 'CHEM',
#   'description': 'Rv3903 protein, Mycobacterium tuberculosis ( CHEM : CpnT protein, Mycobacterium tuberculosis ; channel protein with necrosis-inducing toxin, Mycobacterium tuberculosis )'},
#  {'cui': 'MESH:C000589202',
#   'title': 'Rcor2 protein, human',
#   'type': 'CHEM',
#   'description': 'Rcor2 protein, human ( CHEM )'},
#  {'cui': 'MESH:C000589203',
#   'title': 'CLP1 protein, zebrafish',
#   'type': 'CHEM',
#   'description': 'CLP1 protein, zebrafish ( CHEM : cleavage and polyadenylation factor I subunit 1, zebrafish )'},
#  {'cui': 'MESH:C000589204',
#   'title': 'piezo2 protein, rat',
#   'type': 'CHEM',
#   'description': 'piezo2 protein, rat ( CHEM : FAM38B protein, rat )'},
#  {'cui': 'MESH:C000589205',
#   'title': 'curcusone D',
#   'type': 'CHEM',
#   'description': 'curcusone D ( CHEM )'},
#  {'cui': 'MESH:C000589206',
#   'title': 'rhododendroside A',
#   'type': 'CHEM',
#   'description': 'rhododendroside A ( CHEM )'},
#  {'cui': 'MESH:C000589207',
#   'title': 'enrofloxacin-trimethoprim combination',
#   'type': 'CHEM',
#   'description': 'enrofloxacin-trimethoprim combination ( CHEM )'},
#  {'cui': 'MESH:C000589212',
#   'title': '1-(3,3-dimethylcyclohexyl)pent-4-en-1-one',
#   'type': 'CHEM',
#   'description': '1-(3,3-dimethylcyclohexyl)pent-4-en-1-one ( CHEM )'},
#  {'cui': 'MESH:C000589213',
#   'title': '3-methyl-5-(2,2,3-trimethyl-3-cyclopenten-1-yl)pent-3-en-2-one',
#   'type': 'CHEM',
#   'description': '3-methyl-5-(2,2,3-trimethyl-3-cyclopenten-1-yl)pent-3-en-2-one ( CHEM )'},
#  {'cui': 'MESH:C000589214',
#   'title': '1-(2,4-dimethyl-3-cyclohexenyl)-2,2-dimethylpropan-1-one',
#   'type': 'CHEM',
#   'description': '1-(2,4-dimethyl-3-cyclohexenyl)-2,2-dimethylpropan-1-one ( CHEM )'},
#  {'cui': 'MESH:C000589215',
#   'title': '1-(2,4,4,5,5-pentamethyl-1-cyclopenten-1-yl)ethan-1-one',
#   'type': 'CHEM',
#   'description': '1-(2,4,4,5,5-pentamethyl-1-cyclopenten-1-yl)ethan-1-one ( CHEM )'},
#  {'cui': 'MESH:C000589216',
#   'title': '1-(3,5,6-trimethyl-3-cyclohexen-1-yl)ethan-1-one',
#   'type': 'CHEM',
#   'description': '1-(3,5,6-trimethyl-3-cyclohexen-1-yl)ethan-1-one ( CHEM )'},
#  {'cui': 'MESH:C000589217',
#   'title': '1-(3,3-dimethylbicyclo(2.2.1)hept-2-yl)ethane-1-one',
#   'type': 'CHEM',
#   'description': '1-(3,3-dimethylbicyclo(2.2.1)hept-2-yl)ethane-1-one ( CHEM )'},
#  {'cui': 'MESH:C000589219',
#   'title': '1-(para-menthen-6-yl)-1-propanone',
#   'type': 'CHEM',
#   'description': '1-(para-menthen-6-yl)-1-propanone ( CHEM )'},
#  {'cui': 'MESH:C000589222',
#   'title': 'Drop out protein, Drosophila',
#   'type': 'CHEM',
#   'description': 'Drop out protein, Drosophila ( CHEM : Dop protein, Drosophila )'},
#  {'cui': 'MESH:C000589223',
#   'title': 'Mob1A protein, Arabidopsis thaliana',
#   'type': 'CHEM',
#   'description': 'Mob1A protein, Arabidopsis thaliana ( CHEM : At5g45550 protein, Arabidopsis )'},
#  {'cui': 'MESH:C000589224',
#   'title': 'IMP3 protein, zebrafish',
#   'type': 'CHEM',
#   'description': 'IMP3 protein, zebrafish ( CHEM : insulin-like growth factor 2 mRNA-binding protein 3, zebrafish )'},
#  ...]

# %% [markdown]
# ## Process dict for NLMChem

# %%
umls_dir="/mitchell/entity-linking/2022AA/META/"

umls = UmlsMappings(
    umls_dir=umls_dir, debug=False, force_reprocess=False, 
)

lowercase = False

mesh_to_alias = umls.get_aliases(
        ontologies_to_include=["MSH"],
        use_umls_curies=False,
        mapping_cols={"MSH": "sdui"},
        prefixes={"MSH": "MESH"},
        lowercase=lowercase,
    )

mesh_to_name = umls.get_canonical_name(
        ontologies_to_include=["MSH"],
        use_umls_curies=False,
        mapping_cols={"MSH": "sdui"},
        prefixes={"MSH": "MESH"},
        lowercase=lowercase,)

mesh_to_types, mesh_to_groups = umls.get_types_and_groups(
        ontologies_to_include=["MSH"],
        use_umls_curies=False,
        mapping_cols={"MSH": "sdui"},
        prefixes={"MSH": "MESH"},
        lowercase=lowercase,
)
# Out:
# Loading cached UMLS data from /mitchell/entity-linking/2022AA/META/.cached_df.feather

# %%
mesh2definition = umls.get_definition(
    ontologies_to_include=['MSH'],
    use_umls_curies=False,
    mapping_cols={"MSH": "sdui"},
        prefixes={"MSH": "MESH"},
    lowercase=lowercase,
)
# Out:
# Filtering by ontologies
# Removing null definitions

# %%
nlmchem_entities = []
for cui, aliases in tqdm(mesh_to_alias.items()):
    d = {}
    ent_type = mesh_to_groups[cui][0]
    type_string = ' , '.join([group2name[x] for x in mesh_to_groups[cui]])
    name = mesh_to_name[cui]
    other_aliases = [x for x in aliases if x != name]
    joined_aliases = ' ; '.join(other_aliases)
    d['cui'] = cui
    d['title'] = mesh_to_name[cui]
    d['type'] = ent_type
    if cui in mesh2definition:
        definition = mesh2definition[cui]
    else:
        definition = None

    if len(other_aliases) > 0:
        if definition is not None:
            d['description'] = f"{name} ( {ent_type} : {joined_aliases} ) [ {definition} ]"
        else:
            d['description'] = f"{name} ( {ent_type} : {joined_aliases} )"
    else:
        if definition is not None:
            d['description'] = f"{name} ( {ent_type} ) [ {definition} ]"
        else:
            d['description'] = f"{name} ( {ent_type} )"

    nlmchem_entities.append(d)

pickle.dump(nlmchem_entities, open('../data/arboel/nlmchem/dictionary.pickle', 'wb'))
# Out:
# 100%|██████████| 348733/348733 [00:01<00:00, 270043.35it/s]

# %%
nlmchem_entities[0]
# Out:
# {'cui': 'MESH:C000002',
#  'title': 'bevonium',
#  'type': 'CHEM',
#  'description': 'bevonium ( CHEM : 2-(hydroxymethyl)-N,N-dimethylpiperidinium benzilate ; piribenzil methyl sulfate ; bevonium methylsulfate ; bevonium metilsulfate ; CG 201 ; Acabel ; bevonium sulfate (1:1) ; bevonium methyl sulfate )'}

# %%
nlmchem_entities[100300]
# Out:
# {'cui': 'MESH:C005894',
#  'title': 'xylamidine',
#  'type': 'CHEM',
#  'description': 'xylamidine ( CHEM : N-(2-(3-methoxyphenoxy)propyl)-m-tolylacetamidine tosylate ; XYLAMIDINE TOSYLATE ANHYDROUS ; xylamidine tosylate )'}

# %% [markdown]
# ## Process Entrez for GNormPlus and NLM-Gene

# %%
entrez = pd.read_csv(
    "../data/gene_info.tsv",
    delimiter="\t",
    usecols=[
        "#tax_id",
        "GeneID",
        "Symbol",
        "Synonyms",
        "Symbol_from_nomenclature_authority",
        "Full_name_from_nomenclature_authority",
        "Other_designations",
        "type_of_gene",
        "description",
        "dbXrefs"
    ],
    na_filter=False,
    low_memory=False,
).rename(
    {
        "Symbol_from_nomenclature_authority": "official_symbol",
        "Full_name_from_nomenclature_authority": "official_name",
        '#tax_id':'tax_id'
    }, axis=1,
)
entrez.columns = [x.lower() for x in entrez.columns]

# %%
entrez.to_feather('../data/ncbigene.feather')

# %%
entrez.tax_id.value_counts()
# Out:
# 4565      155756
# 9606      141472
# 3708      123229
# 3818      109241
# 106335    106304
#            ...
# 28896          1
# 566546         1
# 568076         1
# 568703         1
# 7              1
# Name: tax_id, Length: 41110, dtype: int64

# %%
pd.read_feather('../data/ncbigene.feather')
# Out:
#            tax_id    geneid     symbol synonyms dbxrefs  \
# 0               7   5692769   NEWENTRY        -       -
# 1               9   2827857   NEWENTRY        -       -
# 2              11  10823747   NEWENTRY        -       -
# 3              14   6951813   NEWENTRY        -       -
# 4              19   3758873   NEWENTRY        -       -
# ...           ...       ...        ...      ...     ...
# 41456246  2998809   2935004  OrniCt014        -       -
# 41456247  2998809   2935005  OrniCt017        -       -
# 41456248  2998809   3276630      rps12        -       -
# 41456249  2998809   4036376  OrniCt037        -       -
# 41456250  2998809   4036377  OrniCt038        -       -
#
#                                                 description    type_of_gene  \
# 0         Record to support submission of GeneRIFs for a...           other
# 1         Record to support submission of GeneRIFs for a...           other
# 2         Record to support submission of GeneRIFs for a...           other
# 3         Record to support submission of GeneRIFs for a...           other
# 4         Record to support submission of GeneRIFs for a...           other
# ...                                                     ...             ...
# 41456246                                           tRNA-Ser            tRNA
# 41456247                                           tRNA-Phe            tRNA
# 41456248                              ribosomal protein S12  protein-coding
# 41456249                                           tRNA-Ile            tRNA
# 41456250                                           tRNA-Leu            tRNA
#
#          official_symbol official_name     other_designations
# 0                      -             -                      -
# 1                      -             -                      -
# 2                      -             -                      -
# 3                      -             -                      -
# 4                      -             -                      -
# ...                  ...           ...                    ...
# 41456246               -             -                      -
# 41456247               -             -                      -
# 41456248               -             -  ribosomal protein S12
# 41456249               -             -                      -
# 41456250               -             -                      -
#
# [41456251 rows x 10 columns]

# %%
tax2name = ujson.load(open('../data/tax2name.json', 'r'))
# for dataset in ['gnormplus','nlm_gene']:
for dataset in  ['gnormplus', 'nlm_gene']:
    print("filter by taxa")
    taxa = ujson.load(open(f'../data/taxonomy_subsets/{dataset}.json'))
    print(len(taxa))
    taxa_mask = (entrez.tax_id.isin(taxa)) & (~entrez.type_of_gene.isin(['unknown','tRNA','biological-region'])) & (entrez.description != 'hypothetical protein') & (~entrez.official_name.map(lambda x: x.lower().startswith("predicted"))) 
    filtered = entrez[taxa_mask]

    # Find duplicated symbols
    print("Dedup")
    symbols = filtered.symbol.value_counts()
    duplicated_symbols = symbols[symbols > 1].index.tolist()


    # Add additional canonical symbol for symbols that are repeated across different organisms
    duplicated_symbol_mask = filtered.symbol.isin(duplicated_symbols)

    filtered['canonical_symbol'] = filtered['symbol']
    # filtered.loc[duplicated_symbol_mask, 'canonical_symbol'] = filtered.loc[duplicated_symbol_mask, ['tax_id','symbol']].apply(lambda x: f"{x[1]} ({tax2name[x[0]]})", axis=1)


    # Complie list of all symbols (except primary name)
    print("Complilng symbols")
    filtered['all_symbols'] = filtered[['symbol','synonyms','official_symbol','official_name','other_designations', 'canonical_symbol']].progress_apply(lambda x: '|'.join(list(set([i for i in x if i.strip() != '-']))), axis=1)
    # filtered['all_symbols'] = filtered[['synonyms','official_symbol','official_name','other_designations', 'canonical_symbol']].progress_apply(lambda x: '|'.join(list(set([i.strip() for i in x if i.strip() != '-']))), axis=1)

    filtered['geneid'] = filtered.geneid.map(lambda x: f"NCBIGene:{x}")

    geneid2synonym = filtered.set_index('geneid')['all_symbols'].to_dict()

    all_records = []
    for d in tqdm(filtered.to_dict(orient='records')):
        entity_dict = {}
        entity_dict['cui'] = d['geneid']
        entity_dict['title'] = d['symbol']
        dedup_symbols = list(set([x for x in d['all_symbols'].split('|') if x != d['symbol']]))
        # print(dedup_symbols)
        joined_aliases = ' ; '.join(dedup_symbols)
        ent_desc = d['description']
        if len(dedup_symbols) > 0:
            if ent_desc not in ['-', ''] and ent_desc not in dedup_symbols:
                entity_dict['description'] = f"{d['symbol']} ( {tax2name[str(d['tax_id'])]}, {d['type_of_gene']} : {joined_aliases} ) [ {d['description']} ]"
            else:
                entity_dict['description'] = f"{d['symbol']} ( {tax2name[str(d['tax_id'])]}, {d['type_of_gene']} : {joined_aliases} )"
        else:
            if ent_desc not in ['-', ''] and ent_desc not in dedup_symbols:
                entity_dict['description'] = f"{d['symbol']} ( {tax2name[str(d['tax_id'])]}, {d['type_of_gene']} ) [ {d['description']} ]"
            else:
                entity_dict['description'] = f"{d['symbol']} ( {tax2name[str(d['tax_id'])]}, {d['type_of_gene']} )"
        
        entity_dict['type'] = d['type_of_gene']
        all_records.append(entity_dict)

    # with open(f'../data/arboel/{dataset}/dictionary.pickle', 'wb') as f:
    #     pickle.dump(all_records, f)
        

    with open(f"../data/entrez_to_alias_{dataset}.json",'w') as f:
        f.write(ujson.dumps(geneid2synonym))
# Out:
# filter by taxa
# 22
# Dedup
# Complilng symbols
# /tmp/ipykernel_26982/2917889860.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['canonical_symbol'] = filtered['symbol']
# 100%|██████████| 549545/549545 [00:02<00:00, 192612.50it/s]
# /tmp/ipykernel_26982/2917889860.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['all_symbols'] = filtered[['symbol','synonyms','official_symbol','official_name','other_designations', 'canonical_symbol']].progress_apply(lambda x: '|'.join(list(set([i for i in x if i.strip() != '-']))), axis=1)
# /tmp/ipykernel_26982/2917889860.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['geneid'] = filtered.geneid.map(lambda x: f"NCBIGene:{x}")
# 100%|██████████| 549545/549545 [00:01<00:00, 340452.05it/s]
# filter by taxa
# 26
# Dedup
# /tmp/ipykernel_26982/2917889860.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['canonical_symbol'] = filtered['symbol']
# Complilng symbols
# 100%|██████████| 704575/704575 [00:03<00:00, 191155.72it/s]
# /tmp/ipykernel_26982/2917889860.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['all_symbols'] = filtered[['symbol','synonyms','official_symbol','official_name','other_designations', 'canonical_symbol']].progress_apply(lambda x: '|'.join(list(set([i for i in x if i.strip() != '-']))), axis=1)
# /tmp/ipykernel_26982/2917889860.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['geneid'] = filtered.geneid.map(lambda x: f"NCBIGene:{x}")
# 100%|██████████| 704575/704575 [00:02<00:00, 340062.16it/s]

# %%
all_records[19935]
# Out:
# {'cui': 'NCBIGene:817469',
#  'title': 'PUM1',
#  'description': 'PUM1 ( Arabidopsis thaliana, protein-coding : APUM1 ; F16P2_42 ; pumilio 1 ; F16P2.42 )',
#  'type': 'protein-coding'}

# %% [markdown]
# # Convert dataset to examples

# %%
sample_data = pd.read_json('../arboel/data/medmentions/processed/sample.jsonl', lines=True)
sample_data.head()
# Out:
#                                     mention  mention_id  \
# 0                                dynactin 4  25763772.1
# 1  chronic Pseudomonas aeruginosa infection  25763772.2
# 2                           cystic fibrosis  25763772.3
# 3          Pseudomonas aeruginosa infection  25763772.4
# 4                           cystic fibrosis  25763772.5
#
#                                         context_left  \
# 0
# 1                        dynactin 4 as a modifier of
# 2  dynactin 4 as a modifier of chronic Pseudomona...
# 3  dynactin 4 as a modifier of chronic Pseudomona...
# 4  dynactin 4 as a modifier of chronic Pseudomona...
#
#                                        context_right  context_doc_id  type  \
# 0  as a modifier of chronic Pseudomonas aeruginos...        25763772  T103
# 1  in cystic fibrosis Pseudomonas aeruginosa infe...        25763772  T038
# 2  Pseudomonas aeruginosa infection in cystic fib...        25763772  T038
# 3  in cystic fibrosis patients is associated with...        25763772  T038
# 4  patients is associated with worse long - term ...        25763772  T038
#
#    label_id                                              label  \
# 0  C4308010  DCTN4 protein , human ( Chemical : dynactin p6...
# 1  C0854135  Pseudomonas aeruginosa infection ( Biologic Fu...
# 2  C0010674  Cystic Fibrosis ( Biologic Function , CF , cys...
# 3  C0854135  Pseudomonas aeruginosa infection ( Biologic Fu...
# 4  C0010674  Cystic Fibrosis ( Biologic Function , CF , cys...
#
#                         label_title
# 0             DCTN4 protein , human
# 1  Pseudomonas aeruginosa infection
# 2                   Cystic Fibrosis
# 3  Pseudomonas aeruginosa infection
# 4                   Cystic Fibrosis

# %%
np.random.choice([{1,2,3}, {'a','b','c'}, 'steven'])
# Out:
# {1, 2, 3}

# %%
resolve_abbrevs=True
abbrev_dict = ujson.load(open('../data/abbreviations.json'))

# for name in DATASET_NAMES:
for name in ['ncbi_disease']:

# for name in ['ncbi_disease']:
    print(name)
    # if name == 'ncbi_disease':
    #     continue
    x
    entities = pickle.load(open(f'../data/arboel/{name}/dictionary.pickle', 'rb'))
    entity_dictionary = {d['cui']:d for d in tqdm(entities)}

    if name == 'ncbi_disease':
        # Need to redo this since we have multiple synonymous CUIs for ncbi_disease
        entity_dictionary = {cui:d for d in tqdm(entities) for cui in d['cuis']}
        cui_synsets = {}
        for subdict in tqdm(entities): 
            for cui in subdict['cuis']:
                if cui in subdict:
                    print(cui, cui_synsets[cui], subdict['cuis'])
                cui_synsets[cui] = subdict['cuis'] 

        with open('../data/arboel/ncbi_disease/cui_synsets.json', 'w') as f:
            f.write(ujson.dumps(cui_synsets, indent=2))

    if name in VALIDATION_DOCUMENT_IDS:
        validation_pmids = VALIDATION_DOCUMENT_IDS[name]
    else:
        print("ERROR!!!")
    df = dataset_to_df(data, entity_remapping_dict=remap, cuis_to_exclude=exclude, val_split_ids=validation_pmids)
    docs = dataset_to_documents(data)
    label_len = df['db_ids'].map(lambda x: len(x)).max()
    print("Max labels on one doc:", label_len)

    for split in df.split.unique():
        print(split)

        ents_in_split = []
        for d in tqdm(df.query("split == @split").to_dict(orient='records')):
            abbrev_resolved = False
            offsets = d['offsets']
            doc_id = d['document_id']
            doc = docs[doc_id]
            mention = d['text']
            
            # Resolve abbreviaions if desired
            if resolve_abbrevs and abbrev_dict is not None:
                deabbreviated_mention = resolve_abbreviation(doc_id, mention, abbrev_dict)
                abbrev_resolved = True

            # Get offsets and context
            start = offsets[0][0]
            end = offsets[-1][-1]
            before_context = doc[:start]
            after_context = doc[end:]
            
            
            # ArboEL can't handle multi-labels, so we randomly choose one.
            

            if len(d['db_ids']) == 1:
                label_id = d['db_ids'][0]

            # ncbi_disease is a special case that requires extra care
            elif name == 'ncbi_disease':
                labels = []
                used_cuis = set([])
                choosable_ids = []
                for db_id in d['db_ids']:
                    if db_id in used_cuis:
                        continue
                    else:
                        used_cuis.update(set(entity_dictionary[db_id]['cuis']))
                    choosable_ids.append(db_id)

                label_id = np.random.choice(choosable_ids)
            
            else:
                label_id = np.random.choice(d['db_ids'])

            # Check if we missed something
            if label_id not in entity_dictionary:
                print(label_id)
                continue
            

            
            output = [{
                'mention': mention, 
                'mention_id': d['mention_id'],
                'context_left': before_context,
                'context_right': after_context, 
                'context_doc_id': doc_id,
                'type': d['type'][0],
                'label_id': label_id,
                'label': entity_dictionary[label_id]['description'],
                'label_title': entity_dictionary[label_id]['title'],
            }]

            if abbrev_resolved:
                output.append({
                'mention': deabbreviated_mention, 
                'mention_id': d['mention_id']+'.abbr_resolved',
                'context_left': before_context,
                'context_right': after_context, 
                'context_doc_id': doc_id,
                'type': d['type'][0],
                'label_id': label_id,
                'label': entity_dictionary[label_id]['description'],
                'label_title': entity_dictionary[label_id]['title'],
            })

            # else:
            #     labels = []
            #     for db_id in d['db_ids']:
            #         labels.append({
            #         'label': entity_dictionary[db_id]['description'],
            #         'label_title':  entity_dictionary[db_id]['title'],
            #         'label_id': db_id,
            #         })
            #     output = {
            #         'mention': mention, 
            #         'mention_id': d['mention_id'],
            #         'context_left': before_context,
            #         'context_right': after_context, 
            #         'context_doc_id': doc_id,
            #         'type': d['type'][0],
            #         'labels': labels,
            #     }

            ents_in_split.extend(output)

        split_name = split
        if split =='validation':
            split_name = 'valid'
        with open(f'../data/arboel/{name}/{split_name}.jsonl', 'w') as f:
            f.write('\n'.join([ujson.dumps(x) for x in ents_in_split]))

        # print(split, len(ents_in_split))
# Out:
# Found cached dataset ncbi_disease (/nethome/dkartchner3/.cache/huggingface/datasets/ncbi_disease/ncbi_disease_bigbio_kb/1.0.0/e6b217666a5647d5abc614785b2caad62f1d72a94d1631b86c0f615b75dcc865)
# ncbi_disease
#   0%|          | 0/3 [00:00<?, ?it/s]
# 100%|██████████| 13189/13189 [00:00<00:00, 3156737.93it/s]
# 100%|██████████| 13189/13189 [00:00<00:00, 2632342.40it/s]
# 100%|██████████| 13189/13189 [00:00<00:00, 1720161.56it/s]
# Max labels on one doc: 5
# train
# 100%|██████████| 5065/5065 [00:00<00:00, 188433.22it/s]
# validation
# 100%|██████████| 780/780 [00:00<00:00, 167505.87it/s]
# test
# 100%|██████████| 960/960 [00:00<00:00, 206668.99it/s]

# %%
# name = 'ncbi_disease'
# data = conhelps.for_config_name(f'{name}_bigbio_kb').load_dataset()
# exclude = CUIS_TO_EXCLUDE[name]
# remap = CUIS_TO_REMAP[name]
# entities = pickle.load(open(f'../data/arboel/{name}/dictionary.pickle', 'rb'))

# # Need to redo this since we have multiple synonymous CUIs for ncbi_disease
# entity_dictionary = {cui:d for d in tqdm(entities) for cui in d['cuis']}
# cui_synsets = {}
# for d in tqdm(entities): 
#     for cui in d['cuis']:
#         if cui in d:
#             print(cui, cui_synsets[cui], d['cuis'])
#         cui_synsets[cui] = d['cuis'] 

# with open('../data/arboel/ncbi_disease/cui_synsets.json', 'w') as f:
#     f.write(ujson.dumps(cui_synsets, indent=2))



# df = dataset_to_df(data, entity_remapping_dict=remap, cuis_to_exclude=exclude)
# docs = dataset_to_documents(data)
# label_len = df['db_ids'].map(lambda x: len(x)).max()
# print("Max labels on one doc:", label_len)

# for split in df.split.unique():

#     ents_in_split = []
#     for d in tqdm(df.query("split == @split").to_dict(orient='records')):
#         offsets = d['offsets']
#         doc_id = d['document_id']
#         doc = docs[doc_id]
#         mention = d['text']
        
#         # Resolve abbreviaions if desired
#         if resolve_abbrevs and abbrev_dict is not None:
#             mention = resolve_abbreviation(doc_id, mention, abbrev_dict)

#         start = offsets[0][0]
#         end = offsets[-1][-1]
#         before_context = doc[:start]
#         after_context = doc[end:]
        

#         labels = []
#         used_cuis = set([])
#         for db_id in d['db_ids']:
#             if db_id in used_cuis:
#                 continue
#             else:
#                 used_cuis.update(set(entity_dictionary[db_id]['cuis']))
#             labels.append({
#             'label': entity_dictionary[db_id]['description'],
#             'label_title':  entity_dictionary[db_id]['title'],
#             'label_id': entity_dictionary[db_id]['cui'],
#             })
#         output = {
#             'mention': mention, 
#             'mention_id': d['mention_id'],
#             'context_left': before_context,
#             'context_right': after_context, 
#             'context_doc_id': doc_id,
#             'type': d['type'][0],
#             'labels': labels,
#         }

#         ents_in_split.append(output)

#     split_name = split
#     if split =='validation':
#         split_name = 'valid'
#     with open(f'../data/arboel/{name}/{split_name}.jsonl', 'w') as f:
#         f.write('\n'.join([ujson.dumps(x) for x in ents_in_split]))
# Out:
# Found cached dataset ncbi_disease (/home/dkartchner3/.cache/huggingface/datasets/ncbi_disease/ncbi_disease_bigbio_kb/1.0.0/cb155244edb3e586c0105202613da9f02c1baf3de0550919e638775c31469221)
#   0%|          | 0/3 [00:00<?, ?it/s]
# 100%|██████████| 13189/13189 [00:00<00:00, 2073957.76it/s]
# 100%|██████████| 13189/13189 [00:00<00:00, 1732715.51it/s]
# Max labels on one doc: 5
# 100%|██████████| 5065/5065 [00:00<00:00, 213758.25it/s]
# 100%|██████████| 780/780 [00:00<00:00, 202811.80it/s]
# 100%|██████████| 960/960 [00:00<00:00, 250624.41it/s]

# %%
cui_synsets
# Out:
# {'MESH:C538288': ['MESH:C538288'],
#  'MESH:C535484': ['MESH:C535484'],
#  'MESH:C579849': ['MESH:C579849'],
#  'MESH:C579850': ['MESH:C579850'],
#  'MESH:C567076': ['MESH:C567076'],
#  'MESH:C537805': ['MESH:C537805', 'OMIM:264300'],
#  'OMIM:264300': ['MESH:C537805', 'OMIM:264300'],
#  'MESH:C537806': ['MESH:C537806', 'OMIM:203400', 'OMIM:610600'],
#  'OMIM:203400': ['MESH:C537806', 'OMIM:203400', 'OMIM:610600'],
#  'OMIM:610600': ['MESH:C537806', 'OMIM:203400', 'OMIM:610600'],
#  'MESH:D058165': ['MESH:D058165'],
#  'MESH:C565624': ['MESH:C565624', 'OMIM:616034'],
#  'OMIM:616034': ['MESH:C565624', 'OMIM:616034'],
#  'MESH:C535305': ['MESH:C535305'],
#  'MESH:C535306': ['MESH:C535306',
#   'OMIM:236792',
#   'OMIM:600721',
#   'OMIM:613657',
#   'OMIM:615182'],
#  'OMIM:236792': ['MESH:C535306',
#   'OMIM:236792',
#   'OMIM:600721',
#   'OMIM:613657',
#   'OMIM:615182'],
#  'OMIM:600721': ['MESH:C535306',
#   'OMIM:236792',
#   'OMIM:600721',
#   'OMIM:613657',
#   'OMIM:615182'],
#  'OMIM:613657': ['MESH:C535306',
#   'OMIM:236792',
#   'OMIM:600721',
#   'OMIM:613657',
#   'OMIM:615182'],
#  'OMIM:615182': ['MESH:C535306',
#   'OMIM:236792',
#   'OMIM:600721',
#   'OMIM:613657',
#   'OMIM:615182'],
#  'MESH:C535307': ['MESH:C535307'],
#  'MESH:C566487': ['MESH:C566487', 'OMIM:610006'],
#  'OMIM:610006': ['MESH:C566487', 'OMIM:610006'],
#  'MESH:C535313': ['MESH:C535313', 'OMIM:220210', 'OMIM:300963'],
#  'OMIM:220210': ['MESH:C535313', 'OMIM:220210', 'OMIM:300963'],
#  'OMIM:300963': ['MESH:C535313', 'OMIM:220210', 'OMIM:300963'],
#  'MESH:C538324': ['MESH:C538324', 'OMIM:246450'],
#  'OMIM:246450': ['MESH:C538324', 'OMIM:246450'],
#  'MESH:C567784': ['MESH:C567784', 'OMIM:605911'],
#  'OMIM:605911': ['MESH:C567784', 'OMIM:605911'],
#  'MESH:C535310': ['MESH:C535310', 'OMIM:231530'],
#  'OMIM:231530': ['MESH:C535310', 'OMIM:231530'],
#  'MESH:C535312': ['MESH:C535312'],
#  'MESH:C535308': ['MESH:C535308', 'OMIM:210200'],
#  'OMIM:210200': ['MESH:C535308', 'OMIM:210200'],
#  'MESH:C535309': ['MESH:C535309', 'OMIM:210210'],
#  'OMIM:210210': ['MESH:C535309', 'OMIM:210210'],
#  'MESH:C579867': ['MESH:C579867'],
#  'MESH:C562801': ['MESH:C562801', 'OMIM:250950'],
#  'OMIM:250950': ['MESH:C562801', 'OMIM:250950'],
#  'MESH:C565393': ['MESH:C565393'],
#  'MESH:C565706': ['MESH:C565706', 'OMIM:610198'],
#  'OMIM:610198': ['MESH:C565706', 'OMIM:610198'],
#  'OMIM:616271': ['OMIM:616271'],
#  'OMIM:617248': ['OMIM:617248'],
#  'OMIM:614739': ['OMIM:614739'],
#  'MESH:D058489': ['MESH:D058489'],
#  'MESH:C535316': ['MESH:C535316'],
#  'MESH:C567597': ['MESH:C567597'],
#  'OMIM:400045': ['OMIM:400045'],
#  'OMIM:278850': ['OMIM:278850'],
#  'OMIM:300833': ['OMIM:300833'],
#  'OMIM:611812': ['OMIM:611812'],
#  'MESH:D058531': ['MESH:D058531'],
#  'MESH:C536769': ['MESH:C536769'],
#  'MESH:C565537': ['MESH:C565537', 'OMIM:233420'],
#  'OMIM:233420': ['MESH:C565537', 'OMIM:233420'],
#  'MESH:C567574': ['MESH:C567574'],
#  'MESH:C567773': ['MESH:C567773', 'OMIM:607080'],
#  'OMIM:607080': ['MESH:C567773', 'OMIM:607080'],
#  'OMIM:400044': ['OMIM:400044'],
#  'OMIM:616425': ['OMIM:616425'],
#  'MESH:C567887': ['MESH:C567887', 'OMIM:154230'],
#  'OMIM:154230': ['MESH:C567887', 'OMIM:154230'],
#  'MESH:C567766': ['MESH:C567766', 'OMIM:613080'],
#  'OMIM:613080': ['MESH:C567766', 'OMIM:613080'],
#  'OMIM:613762': ['OMIM:613762'],
#  'OMIM:616067': ['OMIM:616067'],
#  'MESH:C567575': ['MESH:C567575'],
#  'MESH:C535317': ['MESH:C535317'],
#  'MESH:C535319': ['MESH:C535319'],
#  'MESH:C535315': ['MESH:C535315'],
#  'MESH:C531667': ['MESH:C531667'],
#  'OMIM:143460': ['OMIM:143460'],
#  'MESH:C535321': ['MESH:C535321'],
#  'MESH:C535322': ['MESH:C535322', 'OMIM:260005'],
#  'OMIM:260005': ['MESH:C535322', 'OMIM:260005'],
#  'MESH:C566803': ['MESH:C566803'],
#  'MESH:C535325': ['MESH:C535325', 'OMIM:261640'],
#  'OMIM:261640': ['MESH:C535325', 'OMIM:261640'],
#  'MESH:C579872': ['MESH:C579872'],
#  'MESH:C537810': ['MESH:C537810'],
#  'MESH:C537818': ['MESH:C537818'],
#  'MESH:C579873': ['MESH:C579873'],
#  'MESH:C000718787': ['MESH:C000718787'],
#  'MESH:C535330': ['MESH:C535330', 'OMIM:214900'],
#  'OMIM:214900': ['MESH:C535330', 'OMIM:214900'],
#  'MESH:C535331': ['MESH:C535331', 'OMIM:305400'],
#  'OMIM:305400': ['MESH:C535331', 'OMIM:305400'],
#  'OMIM:100050': ['OMIM:100050'],
#  'MESH:C535332': ['MESH:C535332'],
#  'MESH:C538442': ['MESH:C538442'],
#  'MESH:C579754': ['MESH:C579754'],
#  'MESH:C535334': ['MESH:C535334', 'OMIM:600501'],
#  'OMIM:600501': ['MESH:C535334', 'OMIM:600501'],
#  'MESH:C535335': ['MESH:C535335'],
#  'MESH:D000006': ['MESH:D000006'],
#  'MESH:D018784': ['MESH:D018784'],
#  'MESH:C535552': ['MESH:C535552'],
#  'MESH:C535553': ['MESH:C535553'],
#  'MESH:D000007': ['MESH:D000007'],
#  'MESH:D000008': ['MESH:D000008'],
#  'MESH:C535554': ['MESH:C535554'],
#  'OMIM:605552': ['OMIM:605552'],
#  'OMIM:615812': ['OMIM:615812'],
#  'MESH:D015746': ['MESH:D015746'],
#  'MESH:D020434': ['MESH:D020434'],
#  'MESH:D020222': ['MESH:D020222'],
#  'MESH:D058739': ['MESH:D058739'],
#  'MESH:C535555': ['MESH:C535555'],
#  'MESH:D000012': ['MESH:D000012', 'OMIM:200100'],
#  'OMIM:200100': ['MESH:D000012', 'OMIM:200100'],
#  'MESH:C540309': ['MESH:C540309'],
#  'MESH:C535556': ['MESH:C535556', 'OMIM:300262'],
#  'OMIM:300262': ['MESH:C535556', 'OMIM:300262'],
#  'MESH:C535557': ['MESH:C535557', 'OMIM:200110'],
#  'OMIM:200110': ['MESH:C535557', 'OMIM:200110'],
#  'MESH:C536375': ['MESH:C536375'],
#  'MESH:D000014': ['MESH:D000014'],
#  'MESH:D000015': ['MESH:D000015'],
#  'MESH:D000016': ['MESH:D000016'],
#  'MESH:D009008': ['MESH:D009008'],
#  'MESH:D059786': ['MESH:D059786'],
#  'MESH:D000026': ['MESH:D000026'],
#  'MESH:D000027': ['MESH:D000027'],
#  'MESH:D000030': ['MESH:D000030'],
#  'MESH:D000031': ['MESH:D000031'],
#  'MESH:D000022': ['MESH:D000022'],
#  'MESH:D000033': ['MESH:D000033'],
#  'MESH:D000034': ['MESH:D000034'],
#  'MESH:C535558': ['MESH:C535558'],
#  'MESH:D000037': ['MESH:D000037'],
#  'MESH:C535559': ['MESH:C535559', 'OMIM:302905'],
#  'OMIM:302905': ['MESH:C535559', 'OMIM:302905'],
#  'MESH:D000038': ['MESH:D000038'],
#  'MESH:C535562': ['MESH:C535562'],
#  'MESH:C535563': ['MESH:C535563', 'OMIM:275220'],
#  'OMIM:275220': ['MESH:C535563', 'OMIM:275220'],
#  'MESH:C535564': ['MESH:C535564', 'OMIM:188740'],
#  'OMIM:188740': ['MESH:C535564', 'OMIM:188740'],
#  'MESH:C535566': ['MESH:C535566', 'OMIM:242840'],
#  'OMIM:242840': ['MESH:C535566', 'OMIM:242840'],
#  'MESH:C535567': ['MESH:C535567'],
#  'MESH:C563111': ['MESH:C563111'],
#  'MESH:C535568': ['MESH:C535568', 'OMIM:168860'],
#  'OMIM:168860': ['MESH:C535568', 'OMIM:168860'],
#  'MESH:C536940': ['MESH:C536940', 'OMIM:274000'],
#  'OMIM:274000': ['MESH:C536940', 'OMIM:274000'],
#  'MESH:C000656947': ['MESH:C000656947'],
#  'MESH:C535569': ['MESH:C535569'],
#  'MESH:D042101': ['MESH:D042101'],
#  'MESH:C535570': ['MESH:C535570'],
#  'MESH:D015823': ['MESH:D015823'],
#  'MESH:D063485': ['MESH:D063485'],
#  'MESH:D000051': ['MESH:D000051'],
#  'MESH:D049309': ['MESH:D049309'],
#  'MESH:D000052': ['MESH:D000052'],
#  'MESH:C536000': ['MESH:C536000'],
#  'MESH:D020642': ['MESH:D020642', 'OMIM:614097'],
#  'OMIM:614097': ['MESH:D020642', 'OMIM:614097'],
#  'MESH:D016170': ['MESH:D016170'],
#  'MESH:D058606': ['MESH:D058606'],
#  'MESH:C536001': ['MESH:C536001'],
#  'MESH:C536002': ['MESH:C536002'],
#  'MESH:D020436': ['MESH:D020436'],
#  'MESH:D061227': ['MESH:D061227'],
#  'MESH:C536003': ['MESH:C536003'],
#  'MESH:D000081084': ['MESH:D000081084'],
#  'MESH:C535670': ['MESH:C535670'],
#  'MESH:C536006': ['MESH:C536006'],
#  'MESH:C562678': ['MESH:C562678', 'OMIM:613933'],
#  'OMIM:613933': ['MESH:C562678', 'OMIM:613933'],
#  'MESH:C536008': ['MESH:C536008', 'OMIM:231550'],
#  'OMIM:231550': ['MESH:C536008', 'OMIM:231550'],
#  'MESH:C536011': ['MESH:C536011', 'OMIM:200400'],
#  'OMIM:200400': ['MESH:C536011', 'OMIM:200400'],
#  'MESH:C536010': ['MESH:C536010'],
#  'MESH:C536012': ['MESH:C536012'],
#  'MESH:C536013': ['MESH:C536013'],
#  'MESH:C536014': ['MESH:C536014', 'OMIM:200500'],
#  'OMIM:200500': ['MESH:C536014', 'OMIM:200500'],
#  'MESH:D000126': ['MESH:D000126'],
#  'MESH:C566750': ['MESH:C566750'],
#  'MESH:C579878': ['MESH:C579878'],
#  'MESH:C536015': ['MESH:C536015', 'OMIM:200600'],
#  'OMIM:200600': ['MESH:C536015', 'OMIM:200600'],
#  'MESH:C536016': ['MESH:C536016', 'OMIM:600972'],
#  'OMIM:600972': ['MESH:C536016', 'OMIM:600972'],
#  'MESH:C536017': ['MESH:C536017', 'OMIM:200610'],
#  'OMIM:200610': ['MESH:C536017', 'OMIM:200610'],
#  'MESH:C536018': ['MESH:C536018'],
#  'MESH:C536019': ['MESH:C536019'],
#  'MESH:D000130': ['MESH:D000130', 'OMIM:100800', 'OMIM:616482'],
#  'OMIM:100800': ['MESH:D000130', 'OMIM:100800', 'OMIM:616482'],
#  'OMIM:616482': ['MESH:D000130', 'OMIM:100800', 'OMIM:616482'],
#  'MESH:C536020': ['MESH:C536020'],
#  'MESH:C531599': ['MESH:C531599'],
#  'MESH:C536021': ['MESH:C536021'],
#  'MESH:C536128': ['MESH:C536128', 'OMIM:216900'],
#  'OMIM:216900': ['MESH:C536128', 'OMIM:216900'],
#  'MESH:C536129': ['MESH:C536129', 'OMIM:262300'],
#  'OMIM:262300': ['MESH:C536129', 'OMIM:262300'],
#  'MESH:C564206': ['MESH:C564206', 'OMIM:613856'],
#  'OMIM:613856': ['MESH:C564206', 'OMIM:613856'],
#  'MESH:C567759': ['MESH:C567759'],
#  'OMIM:616517': ['OMIM:616517'],
#  'MESH:C538165': ['MESH:C538165'],
#  'MESH:D000137': ['MESH:D000137'],
#  'MESH:C538167': ['MESH:C538167', 'OMIM:243500'],
#  'OMIM:243500': ['MESH:C538167', 'OMIM:243500'],
#  'OMIM:615961': ['OMIM:615961'],
#  'MESH:D000138': ['MESH:D000138'],
#  'MESH:D000140': ['MESH:D000140'],
#  'MESH:D000141': ['MESH:D000141', 'OMIM:179800'],
#  'OMIM:179800': ['MESH:D000141', 'OMIM:179800'],
#  'MESH:D000142': ['MESH:D000142'],
#  'MESH:C562645': ['MESH:C562645', 'OMIM:200950'],
#  'OMIM:200950': ['MESH:C562645', 'OMIM:200950'],
#  'MESH:D000151': ['MESH:D000151'],
#  'MESH:C538169': ['MESH:C538169'],
#  'MESH:C538170': ['MESH:C538170'],
#  'MESH:C565791': ['MESH:C565791'],
#  'MESH:D000069316': ['MESH:D000069316'],
#  'MESH:D017486': ['MESH:D017486'],
#  'MESH:D000153': ['MESH:D000153'],
#  'MESH:D000152': ['MESH:D000152'],
#  'MESH:C538171': ['MESH:C538171'],
#  'MESH:C538172': ['MESH:C538172'],
#  'MESH:C538173': ['MESH:C538173'],
#  'MESH:C538481': ['MESH:C538481'],
#  'MESH:D020083': ['MESH:D020083'],
#  'MESH:C538174': ['MESH:C538174'],
#  'MESH:C538175': ['MESH:C538175'],
#  'MESH:D000163': ['MESH:D000163'],
#  'MESH:C567077': ['MESH:C567077'],
#  'MESH:C538176': ['MESH:C538176'],
#  'MESH:D055673': ['MESH:D055673', 'OMIM:200990'],
#  'OMIM:200990': ['MESH:D055673', 'OMIM:200990'],
#  'MESH:C538177': ['MESH:C538177'],
#  'MESH:C564334': ['MESH:C564334', 'OMIM:607778'],
#  'OMIM:607778': ['MESH:C564334', 'OMIM:607778'],
#  'MESH:C573722': ['MESH:C573722'],
#  'MESH:C563187': ['MESH:C563187', 'OMIM:201000', 'OMIM:614976'],
#  'OMIM:201000': ['MESH:C563187', 'OMIM:201000', 'OMIM:614976'],
#  'OMIM:614976': ['MESH:C563187', 'OMIM:201000', 'OMIM:614976'],
#  'MESH:D000168': ['MESH:D000168', 'OMIM:101200', 'OMIM:101400'],
#  'OMIM:101200': ['MESH:D000168', 'OMIM:101200', 'OMIM:101400'],
#  'OMIM:101400': ['MESH:D000168', 'OMIM:101200', 'OMIM:101400'],
#  'MESH:D000169': ['MESH:D000169'],
#  'MESH:C538178': ['MESH:C538178', 'OMIM:201100'],
#  'OMIM:201100': ['MESH:C538178', 'OMIM:201100'],
#  'MESH:D000170': ['MESH:D000170'],
#  'MESH:C538179': ['MESH:C538179', 'OMIM:101800', 'OMIM:614613'],
#  'OMIM:101800': ['MESH:C538179', 'OMIM:101800', 'OMIM:614613'],
#  'OMIM:614613': ['MESH:C538179', 'OMIM:101800', 'OMIM:614613'],
#  'MESH:C538180': ['MESH:C538180'],
#  'MESH:C538181': ['MESH:C538181'],
#  'MESH:C538182': ['MESH:C538182'],
#  'OMIM:616462': ['OMIM:616462'],
#  'MESH:C538184': ['MESH:C538184', 'OMIM:154400'],
#  'OMIM:154400': ['MESH:C538184', 'OMIM:154400'],
#  'MESH:C538185': ['MESH:C538185'],
#  'MESH:C538183': ['MESH:C538183'],
#  'MESH:C538186': ['MESH:C538186'],
#  'MESH:C538187': ['MESH:C538187'],
#  'MESH:C566323': ['MESH:C566323'],
#  'MESH:C535653': ['MESH:C535653'],
#  'MESH:C566322': ['MESH:C566322'],
#  'MESH:C535655': ['MESH:C535655'],
#  'MESH:C535656': ['MESH:C535656', 'OMIM:606049'],
#  'OMIM:606049': ['MESH:C535656', 'OMIM:606049'],
#  'MESH:D000172': ['MESH:D000172'],
#  'MESH:C566345': ['MESH:C566345', 'OMIM:603671'],
#  'OMIM:603671': ['MESH:C566345', 'OMIM:603671'],
#  'MESH:C535657': ['MESH:C535657'],
#  'MESH:C535658': ['MESH:C535658'],
#  'OMIM:201250': ['OMIM:201250'],
#  'MESH:C535659': ['MESH:C535659'],
#  'MESH:C535661': ['MESH:C535661', 'OMIM:602875'],
#  'OMIM:602875': ['MESH:C535661', 'OMIM:602875'],
#  'MESH:C535662': ['MESH:C535662', 'OMIM:102370', 'OMIM:231050', 'OMIM:614185'],
#  'OMIM:102370': ['MESH:C535662', 'OMIM:102370', 'OMIM:231050', 'OMIM:614185'],
#  'OMIM:231050': ['MESH:C535662', 'OMIM:102370', 'OMIM:231050', 'OMIM:614185'],
#  'OMIM:614185': ['MESH:C535662', 'OMIM:102370', 'OMIM:231050', 'OMIM:614185'],
#  'MESH:D030981': ['MESH:D030981'],
#  'MESH:C535663': ['MESH:C535663'],
#  'MESH:C564866': ['MESH:C564866'],
#  'MESH:C535664': ['MESH:C535664', 'OMIM:605967'],
#  'OMIM:605967': ['MESH:C535664', 'OMIM:605967'],
#  'OMIM:102510': ['OMIM:102510'],
#  'MESH:C566319': ['MESH:C566319'],
#  'MESH:C000719188': ['MESH:C000719188'],
#  'MESH:C535665': ['MESH:C535665'],
#  'MESH:C563159': ['MESH:C563159'],
#  'MESH:C535666': ['MESH:C535666'],
#  'MESH:D018250': ['MESH:D018250'],
#  'MESH:C562707': ['MESH:C562707', 'OMIM:201400'],
#  'OMIM:201400': ['MESH:C562707', 'OMIM:201400'],
#  'MESH:C565662': ['MESH:C565662', 'OMIM:219080', 'OMIM:615954'],
#  'OMIM:219080': ['MESH:C565662', 'OMIM:219080', 'OMIM:615954'],
#  'OMIM:615954': ['MESH:C565662', 'OMIM:219080', 'OMIM:615954'],
#  'MESH:D049913': ['MESH:D049913', 'OMIM:219090'],
#  'OMIM:219090': ['MESH:D049913', 'OMIM:219090'],
#  'MESH:D000182': ['MESH:D000182'],
#  'MESH:C579880': ['MESH:C579880'],
#  'MESH:C535669': ['MESH:C535669'],
#  'MESH:C566780': ['MESH:C566780'],
#  'MESH:D000187': ['MESH:D000187'],
#  'MESH:D000189': ['MESH:D000189'],
#  'MESH:D000193': ['MESH:D000193'],
#  'MESH:D000196': ['MESH:D000196'],
#  'MESH:D000197': ['MESH:D000197'],
#  'MESH:C585640': ['MESH:C585640'],
#  'MESH:D020016': ['MESH:D020016'],
#  'MESH:C538620': ['MESH:C538620'],
#  'MESH:C531689': ['MESH:C531689'],
#  'MESH:D056586': ['MESH:D056586'],
#  'MESH:C535672': ['MESH:C535672'],
#  'MESH:D054058': ['MESH:D054058'],
#  'MESH:D000208': ['MESH:D000208'],
#  'MESH:C535673': ['MESH:C535673'],
#  'MESH:C537957': ['MESH:C537957'],
#  'MESH:D000071072': ['MESH:D000071072'],
#  'MESH:C000629404': ['MESH:C000629404'],
#  'MESH:D056150': ['MESH:D056150'],
#  'MESH:D058186': ['MESH:D058186'],
#  'MESH:D055371': ['MESH:D055371'],
#  'MESH:C531736': ['MESH:C531736'],
#  'MESH:D065290': ['MESH:D065290'],
#  'MESH:D059787': ['MESH:D059787'],
#  'MESH:D000210': ['MESH:D000210'],
#  'MESH:D054508': ['MESH:D054508'],
#  'MESH:D000071297': ['MESH:D000071297'],
#  'MESH:C538407': ['MESH:C538407'],
#  'MESH:C564356': ['MESH:C564356'],
#  'MESH:C538223': ['MESH:C538223'],
#  'MESH:C567006': ['MESH:C567006', 'OMIM:611126'],
#  'OMIM:611126': ['MESH:C567006', 'OMIM:611126'],
#  'MESH:C562417': ['MESH:C562417'],
#  'MESH:D050398': ['MESH:D050398'],
#  'MESH:C538224': ['MESH:C538224'],
#  'MESH:C538225': ['MESH:C538225',
#   'OMIM:100300',
#   'OMIM:614219',
#   'OMIM:614814',
#   'OMIM:615297',
#   'OMIM:616028',
#   'OMIM:616589'],
#  'OMIM:100300': ['MESH:C538225',
#   'OMIM:100300',
#   'OMIM:614219',
#   'OMIM:614814',
#   'OMIM:615297',
#   'OMIM:616028',
#   'OMIM:616589'],
#  'OMIM:614219': ['MESH:C538225',
#   'OMIM:100300',
#   'OMIM:614219',
#   'OMIM:614814',
#   'OMIM:615297',
#   'OMIM:616028',
#   'OMIM:616589'],
#  'OMIM:614814': ['MESH:C538225',
#   'OMIM:100300',
#   'OMIM:614219',
#   'OMIM:614814',
#   'OMIM:615297',
#   'OMIM:616028',
#   'OMIM:616589'],
#  'OMIM:615297': ['MESH:C538225',
#   'OMIM:100300',
#   'OMIM:614219',
#   'OMIM:614814',
#   'OMIM:615297',
#   'OMIM:616028',
#   'OMIM:616589'],
#  'OMIM:616028': ['MESH:C538225',
#   'OMIM:100300',
#   'OMIM:614219',
#   'OMIM:614814',
#   'OMIM:615297',
#   'OMIM:616028',
#   'OMIM:616589'],
#  'OMIM:616589': ['MESH:C538225',
#   'OMIM:100300',
#   'OMIM:614219',
#   'OMIM:614814',
#   'OMIM:615297',
#   'OMIM:616028',
#   'OMIM:616589'],
#  'MESH:D000219': ['MESH:D000219'],
#  'MESH:D000224': ['MESH:D000224'],
#  'MESH:C562949': ['MESH:C562949'],
#  'MESH:C566309': ['MESH:C566309'],
#  'MESH:C538228': ['MESH:C538228', 'OMIM:614723'],
#  'OMIM:614723': ['MESH:C538228', 'OMIM:614723'],
#  'MESH:C538229': ['MESH:C538229'],
#  'MESH:C538230': ['MESH:C538230'],
#  'MESH:D000230': ['MESH:D000230'],
#  'MESH:D002282': ['MESH:D002282'],
#  'MESH:D018262': ['MESH:D018262'],
#  'MESH:D018263': ['MESH:D018263'],
#  'MESH:D065311': ['MESH:D065311'],
#  'MESH:D002288': ['MESH:D002288'],
#  'MESH:C562730': ['MESH:C562730'],
#  'MESH:D000077192': ['MESH:D000077192'],
#  'MESH:D000231': ['MESH:D000231'],
#  'MESH:D002293': ['MESH:D002293'],
#  'MESH:D018266': ['MESH:D018266'],
#  'MESH:D000232': ['MESH:D000232'],
#  'MESH:D000235': ['MESH:D000235'],
#  'MESH:D000236': ['MESH:D000236'],
#  'MESH:D000239': ['MESH:D000239'],
#  'MESH:D000237': ['MESH:D000237'],
#  'MESH:D002759': ['MESH:D002759'],
#  'MESH:D000238': ['MESH:D000238'],
#  'MESH:D007516': ['MESH:D007516'],
#  'MESH:D018248': ['MESH:D018248'],
#  'MESH:D018249': ['MESH:D018249'],
#  'MESH:D008949': ['MESH:D008949'],
#  'MESH:D006607': ['MESH:D006607'],
#  'MESH:D018254': ['MESH:D018254'],
#  'MESH:D018255': ['MESH:D018255'],
#  'MESH:D011125': ['MESH:D011125', 'OMIM:175100', 'OMIM:616415', 'OMIM:617100'],
#  'OMIM:175100': ['MESH:D011125', 'OMIM:175100', 'OMIM:616415', 'OMIM:617100'],
#  'OMIM:616415': ['MESH:D011125', 'OMIM:175100', 'OMIM:616415', 'OMIM:617100'],
#  'OMIM:617100': ['MESH:D011125', 'OMIM:175100', 'OMIM:616415', 'OMIM:617100'],
#  'MESH:C566778': ['MESH:C566778'],
#  'MESH:D018256': ['MESH:D018256'],
#  'MESH:D018253': ['MESH:D018253'],
#  'MESH:D055331': ['MESH:D055331'],
#  'MESH:D018194': ['MESH:D018194'],
#  'MESH:D062788': ['MESH:D062788'],
#  'MESH:D017188': ['MESH:D017188'],
#  'MESH:D018195': ['MESH:D018195'],
#  'MESH:C538232': ['MESH:C538232'],
#  'MESH:C566314': ['MESH:C566314'],
#  'MESH:C538234': ['MESH:C538234'],
#  'MESH:C566311': ['MESH:C566311'],
#  'MESH:C566310': ['MESH:C566310', 'OMIM:102900'],
#  'OMIM:102900': ['MESH:C566310', 'OMIM:102900'],
#  'MESH:D000257': ['MESH:D000257'],
#  'MESH:D000258': ['MESH:D000258'],
#  'MESH:C567228': ['MESH:C567228', 'OMIM:612631'],
#  'OMIM:612631': ['MESH:C567228', 'OMIM:612631'],
#  'MESH:C538235': ['MESH:C538235', 'OMIM:103050'],
#  'OMIM:103050': ['MESH:C538235', 'OMIM:103050'],
#  'MESH:C000656784': ['MESH:C000656784'],
#  'MESH:D000270': ['MESH:D000270'],
#  'OMIM:606770': ['OMIM:606770'],
#  'OMIM:606771': ['OMIM:606771'],
#  'MESH:D000274': ['MESH:D000274'],
#  'MESH:D000275': ['MESH:D000275'],
#  'MESH:D000291': ['MESH:D000291'],
#  'MESH:D000303': ['MESH:D000303'],
#  'MESH:D000306': ['MESH:D000306'],
#  'MESH:D000307': ['MESH:D000307'],
#  'MESH:D000310': ['MESH:D000310'],
#  'MESH:C538236': ['MESH:C538236', 'OMIM:201810'],
#  'OMIM:201810': ['MESH:C538236', 'OMIM:201810'],
#  'MESH:D000312': ['MESH:D000312'],
#  'MESH:C538237': ['MESH:C538237', 'OMIM:202110'],
#  'OMIM:202110': ['MESH:C538237', 'OMIM:202110'],
#  'MESH:C565976': ['MESH:C565976'],
#  'MESH:C564568': ['MESH:C564568'],
#  'MESH:C538238': ['MESH:C538238'],
#  'MESH:D000309': ['MESH:D000309'],
#  'MESH:C566130': ['MESH:C566130'],
#  'MESH:C566131': ['MESH:C566131', 'OMIM:613743'],
#  'OMIM:613743': ['MESH:C566131', 'OMIM:613743'],
#  'MESH:D000314': ['MESH:D000314'],
#  'MESH:D018246': ['MESH:D018246'],
#  'MESH:D018268': ['MESH:D018268'],
#  'MESH:C565972': ['MESH:C565972', 'OMIM:202300'],
#  'OMIM:202300': ['MESH:C565972', 'OMIM:202300'],
#  'MESH:C565973': ['MESH:C565973'],
#  'MESH:D000308': ['MESH:D000308'],
#  'MESH:C562711': ['MESH:C562711'],
#  'MESH:C565971': ['MESH:C565971'],
#  'MESH:C535668': ['MESH:C535668'],
#  'MESH:D047808': ['MESH:D047808'],
#  'MESH:D000326': ['MESH:D000326', 'OMIM:300100'],
#  'OMIM:300100': ['MESH:D000326', 'OMIM:300100'],
#  'MESH:C538051': ['MESH:C538051'],
#  'MESH:C566214': ['MESH:C566214'],
#  'MESH:C000718087': ['MESH:C000718087'],
#  'MESH:C538053': ['MESH:C538053', 'OMIM:603471'],
#  'OMIM:603471': ['MESH:C538053', 'OMIM:603471'],
#  'MESH:C565789': ['MESH:C565789', 'OMIM:604348', 'OMIM:615224', 'OMIM:616882'],
#  'OMIM:604348': ['MESH:C565789', 'OMIM:604348', 'OMIM:615224', 'OMIM:616882'],
#  'OMIM:615224': ['MESH:C565789', 'OMIM:604348', 'OMIM:615224', 'OMIM:616882'],
#  'OMIM:616882': ['MESH:C565789', 'OMIM:604348', 'OMIM:615224', 'OMIM:616882'],
#  'MESH:C538054': ['MESH:C538054'],
#  'MESH:D000334': ['MESH:D000334'],
#  'MESH:C000719189': ['MESH:C000719189'],
#  'MESH:D000341': ['MESH:D000341'],
#  'MESH:D000343': ['MESH:D000343'],
#  'MESH:D000347': ['MESH:D000347', 'OMIM:202400'],
#  'OMIM:202400': ['MESH:D000347', 'OMIM:202400'],
#  'MESH:C579887': ['MESH:C579887'],
#  'MESH:D000355': ['MESH:D000355'],
#  'MESH:D000357': ['MESH:D000357'],
#  'MESH:D000361': ['MESH:D000361',
#   'OMIM:601495',
#   'OMIM:612692',
#   'OMIM:613500',
#   'OMIM:613501',
#   'OMIM:613502',
#   'OMIM:613506',
#   'OMIM:616941'],
#  'OMIM:601495': ['MESH:D000361',
#   'OMIM:601495',
#   'OMIM:612692',
#   'OMIM:613500',
#   'OMIM:613501',
#   'OMIM:613502',
#   'OMIM:613506',
#   'OMIM:616941'],
#  'OMIM:612692': ['MESH:D000361',
#   'OMIM:601495',
#   'OMIM:612692',
#   'OMIM:613500',
#   'OMIM:613501',
#   'OMIM:613502',
#   'OMIM:613506',
#   'OMIM:616941'],
#  'OMIM:613500': ['MESH:D000361',
#   'OMIM:601495',
#   'OMIM:612692',
#   'OMIM:613500',
#   'OMIM:613501',
#   'OMIM:613502',
#   'OMIM:613506',
#   'OMIM:616941'],
#  'OMIM:613501': ['MESH:D000361',
#   'OMIM:601495',
#   'OMIM:612692',
#   'OMIM:613500',
#   'OMIM:613501',
#   'OMIM:613502',
#   'OMIM:613506',
#   'OMIM:616941'],
#  'OMIM:613502': ['MESH:D000361',
#   'OMIM:601495',
#   'OMIM:612692',
#   'OMIM:613500',
#   'OMIM:613501',
#   'OMIM:613502',
#   'OMIM:613506',
#   'OMIM:616941'],
#  'OMIM:613506': ['MESH:D000361',
#   'OMIM:601495',
#   'OMIM:612692',
#   'OMIM:613500',
#   'OMIM:613501',
#   'OMIM:613502',
#   'OMIM:613506',
#   'OMIM:616941'],
#  'OMIM:616941': ['MESH:D000361',
#   'OMIM:601495',
#   'OMIM:612692',
#   'OMIM:613500',
#   'OMIM:613501',
#   'OMIM:613502',
#   'OMIM:613506',
#   'OMIM:616941'],
#  'OMIM:615214': ['OMIM:615214'],
#  'MESH:C538055': ['MESH:C538055'],
#  'MESH:C538056': ['MESH:C538056'],
#  'MESH:C563305': ['MESH:C563305'],
#  'MESH:C538057': ['MESH:C538057', 'OMIM:300310'],
#  'OMIM:300310': ['MESH:C538057', 'OMIM:300310'],
#  'MESH:C538058': ['MESH:C538058'],
#  'MESH:C536293': ['MESH:C536293', 'OMIM:213300'],
#  'OMIM:213300': ['MESH:C536293', 'OMIM:213300'],
#  'MESH:D061085': ['MESH:D061085'],
#  'MESH:C567305': ['MESH:C567305', 'OMIM:612448'],
#  'OMIM:612448': ['MESH:C567305', 'OMIM:612448'],
#  'MESH:D000370': ['MESH:D000370'],
#  'MESH:D010520': ['MESH:D010520', 'OMIM:170650'],
#  'OMIM:170650': ['MESH:D010520', 'OMIM:170650'],
#  'MESH:D019588': ['MESH:D019588'],
#  'MESH:C538059': ['MESH:C538059'],
#  'MESH:D000377': ['MESH:D000377'],
#  'MESH:C563429': ['MESH:C563429'],
#  'MESH:D000379': ['MESH:D000379'],
#  'MESH:D000380': ['MESH:D000380'],
#  'MESH:D000381': ['MESH:D000381'],
#  'MESH:D000382': ['MESH:D000382'],
#  'MESH:C535607': ['MESH:C535607',
#   'OMIM:225750',
#   'OMIM:610181',
#   'OMIM:615010',
#   'OMIM:615846',
#   'OMIM:617397'],
#  'OMIM:225750': ['MESH:C535607',
#   'OMIM:225750',
#   'OMIM:610181',
#   'OMIM:615010',
#   'OMIM:615846',
#   'OMIM:617397'],
#  'OMIM:610181': ['MESH:C535607',
#   'OMIM:225750',
#   'OMIM:610181',
#   'OMIM:615010',
#   'OMIM:615846',
#   'OMIM:617397'],
#  'OMIM:615010': ['MESH:C535607',
#   'OMIM:225750',
#   'OMIM:610181',
#   'OMIM:615010',
#   'OMIM:615846',
#   'OMIM:617397'],
#  'OMIM:615846': ['MESH:C535607',
#   'OMIM:225750',
#   'OMIM:610181',
#   'OMIM:615010',
#   'OMIM:615846',
#   'OMIM:617397'],
#  'OMIM:617397': ['MESH:C535607',
#   'OMIM:225750',
#   'OMIM:610181',
#   'OMIM:615010',
#   'OMIM:615846',
#   'OMIM:617397'],
#  'MESH:C563683': ['MESH:C563683', 'OMIM:610329'],
#  'OMIM:610329': ['MESH:C563683', 'OMIM:610329'],
#  'MESH:C563681': ['MESH:C563681', 'OMIM:610333'],
#  'OMIM:610333': ['MESH:C563681', 'OMIM:610333'],
#  'MESH:C535608': ['MESH:C535608', 'OMIM:612952'],
#  'OMIM:612952': ['MESH:C535608', 'OMIM:612952'],
#  'MESH:D058540': ['MESH:D058540', 'OMIM:304050'],
#  'OMIM:304050': ['MESH:D058540', 'OMIM:304050'],
#  'MESH:C563876': ['MESH:C563876', 'OMIM:608688'],
#  'OMIM:608688': ['MESH:C563876', 'OMIM:608688'],
#  'MESH:D020943': ['MESH:D020943'],
#  'MESH:D016263': ['MESH:D016263'],
#  'MESH:D015526': ['MESH:D015526'],
#  'MESH:D000386': ['MESH:D000386'],
#  'MESH:C554498': ['MESH:C554498'],
#  'MESH:D017088': ['MESH:D017088'],
#  'MESH:D000387': ['MESH:D000387'],
#  'MESH:C000721349': ['MESH:C000721349'],
#  'MESH:D000402': ['MESH:D000402'],
#  'MESH:D056151': ['MESH:D056151'],
#  'MESH:C535609': ['MESH:C535609'],
#  'MESH:D017109': ['MESH:D017109'],
#  'MESH:C535610': ['MESH:C535610'],
#  'MESH:D000405': ['MESH:D000405'],
#  'MESH:C535611': ['MESH:C535611'],
#  'MESH:C562827': ['MESH:C562827'],
#  'OMIM:615510': ['OMIM:615510'],
#  'MESH:C566307': ['MESH:C566307'],
#  'MESH:D016738': ['MESH:D016738', 'OMIM:118450', 'OMIM:610205'],
#  'OMIM:118450': ['MESH:D016738', 'OMIM:118450', 'OMIM:610205'],
#  'OMIM:610205': ['MESH:D016738', 'OMIM:118450', 'OMIM:610205'],
#  'MESH:C562664': ['MESH:C562664', 'OMIM:300600'],
#  'OMIM:300600': ['MESH:C562664', 'OMIM:300600'],
#  'MESH:C565968': ['MESH:C565968'],
#  'MESH:C535612': ['MESH:C535612', 'OMIM:276820'],
#  'OMIM:276820': ['MESH:C535612', 'OMIM:276820'],
#  'OMIM:615071': ['OMIM:615071'],
#  'OMIM:617126': ['OMIM:617126'],
#  'MESH:D000417': ['MESH:D000417'],
#  'MESH:C537042': ['MESH:C537042', 'OMIM:300700'],
#  'OMIM:300700': ['MESH:C537042', 'OMIM:300700'],
#  'MESH:C537044': ['MESH:C537044'],
#  'MESH:D016117': ['MESH:D016117'],
#  'MESH:C537043': ['MESH:C537043', 'OMIM:300650'],
#  'OMIM:300650': ['MESH:C537043', 'OMIM:300650'],
#  'MESH:D016115': ['MESH:D016115'],
#  'MESH:C564645': ['MESH:C564645'],
#  'OMIM:615179': ['OMIM:615179'],
#  'MESH:C538539': ['MESH:C538539', 'OMIM:203300'],
#  'OMIM:203300': ['MESH:C538539', 'OMIM:203300'],
#  'MESH:D000419': ['MESH:D000419'],
#  'MESH:D000425': ['MESH:D000425'],
#  'MESH:C576203': ['MESH:C576203'],
#  'MESH:D000435': ['MESH:D000435'],
#  'MESH:D000076042': ['MESH:D000076042'],
#  'MESH:D020269': ['MESH:D020269'],
#  'MESH:D020751': ['MESH:D020751'],
#  'MESH:D020268': ['MESH:D020268'],
#  'MESH:C538669': ['MESH:C538669'],
#  'MESH:D000437': ['MESH:D000437', 'OMIM:103780'],
#  'OMIM:103780': ['MESH:D000437', 'OMIM:103780'],
#  'MESH:D019973': ['MESH:D019973'],
#  'OMIM:610251': ['OMIM:610251'],
#  'MESH:D000430': ['MESH:D000430'],
#  'MESH:D020270': ['MESH:D020270'],
#  'MESH:C537046': ['MESH:C537046'],
#  'MESH:D000071064': ['MESH:D000071064'],
#  'MESH:D000453': ['MESH:D000453'],
#  'MESH:D038261': ['MESH:D038261', 'OMIM:203450'],
#  'OMIM:203450': ['MESH:D038261', 'OMIM:203450'],
#  'MESH:C531607': ['MESH:C531607'],
#  'MESH:D020237': ['MESH:D020237'],
#  'MESH:C535613': ['MESH:C535613'],
#  'MESH:C535615': ['MESH:C535615'],
#  'MESH:C535616': ['MESH:C535616'],
#  'MESH:C535617': ['MESH:C535617'],
#  'MESH:C536817': ['MESH:C536817'],
#  'MESH:D062026': ['MESH:D062026'],
#  'MESH:D055964': ['MESH:D055964'],
#  'MESH:D059707': ['MESH:D059707'],
#  'MESH:D000471': ['MESH:D000471'],
#  'MESH:D000472': ['MESH:D000472'],
#  'MESH:D000474': ['MESH:D000474', 'OMIM:203500'],
#  'OMIM:203500': ['MESH:D000474', 'OMIM:203500'],
#  'MESH:C531762': ['MESH:C531762'],
#  'MESH:C537047': ['MESH:C537047', 'OMIM:300523'],
#  'OMIM:300523': ['MESH:C537047', 'OMIM:300523'],
#  'MESH:C537048': ['MESH:C537048'],
#  'MESH:D066190': ['MESH:D066190'],
#  'MESH:C537049': ['MESH:C537049'],
#  'MESH:D000505': ['MESH:D000505', 'OMIM:109200'],
#  'OMIM:109200': ['MESH:D000505', 'OMIM:109200'],
#  'MESH:C567473': ['MESH:C567473', 'OMIM:300710'],
#  'OMIM:300710': ['MESH:C567473', 'OMIM:300710'],
#  'MESH:C567317': ['MESH:C567317', 'OMIM:612421'],
#  'OMIM:612421': ['MESH:C567317', 'OMIM:612421'],
#  'MESH:D000506': ['MESH:D000506'],
#  'MESH:C566303': ['MESH:C566303', 'OMIM:104000'],
#  'OMIM:104000': ['MESH:C566303', 'OMIM:104000'],
#  'MESH:C565186': ['MESH:C565186', 'OMIM:610753'],
#  'OMIM:610753': ['MESH:C565186', 'OMIM:610753'],
#  'MESH:C537050': ['MESH:C537050'],
#  'MESH:C537051': ['MESH:C537051'],
#  'MESH:C537052': ['MESH:C537052'],
#  'MESH:C537057': ['MESH:C537057'],
#  'MESH:C566301': ['MESH:C566301'],
#  'MESH:C537053': ['MESH:C537053'],
#  'OMIM:613930': ['OMIM:613930'],
#  'MESH:C563668': ['MESH:C563668', 'OMIM:610422'],
#  'OMIM:610422': ['MESH:C563668', 'OMIM:610422'],
#  'MESH:C563370': ['MESH:C563370'],
#  'MESH:C567425': ['MESH:C567425', 'OMIM:612079'],
#  'OMIM:612079': ['MESH:C567425', 'OMIM:612079'],
#  'MESH:C537055': ['MESH:C537055', 'OMIM:203655'],
#  'OMIM:203655': ['MESH:C537055', 'OMIM:203655'],
#  'MESH:C563920': ['MESH:C563920'],
#  'MESH:C537056': ['MESH:C537056'],
#  'MESH:D019896': ['MESH:D019896', 'OMIM:613490'],
#  'OMIM:613490': ['MESH:D019896', 'OMIM:613490'],
#  'MESH:C566273': ['MESH:C566273'],
#  'MESH:C565963': ['MESH:C565963'],
#  'MESH:C566304': ['MESH:C566304', 'OMIM:614036'],
#  'OMIM:614036': ['MESH:C566304', 'OMIM:614036'],
#  'OMIM:204750': ['OMIM:204750'],
#  'MESH:C563848': ['MESH:C563848', 'OMIM:608810'],
#  'OMIM:608810': ['MESH:C563848', 'OMIM:608810'],
#  'MESH:C563849': ['MESH:C563849'],
#  'MESH:C563691': ['MESH:C563691', 'OMIM:609889'],
#  'OMIM:609889': ['MESH:C563691', 'OMIM:609889'],
#  'MESH:C566300': ['MESH:C566300', 'OMIM:615969'],
#  'OMIM:615969': ['MESH:C566300', 'OMIM:615969'],
#  'MESH:C536582': ['MESH:C536582', 'OMIM:203740'],
#  'OMIM:203740': ['MESH:C536582', 'OMIM:203740'],
#  'MESH:D008363': ['MESH:D008363', 'OMIM:248500'],
#  'OMIM:248500': ['MESH:D008363', 'OMIM:248500'],
#  'MESH:C536584': ['MESH:C536584'],
#  'MESH:C536585': ['MESH:C536585'],
#  'MESH:C565418': ['MESH:C565418'],
#  'MESH:C565768': ['MESH:C565768', 'OMIM:614307'],
#  'OMIM:614307': ['MESH:C565768', 'OMIM:614307'],
#  'MESH:D017085': ['MESH:D017085', 'OMIM:604131', 'OMIM:613978'],
#  'OMIM:604131': ['MESH:D017085', 'OMIM:604131', 'OMIM:613978'],
#  'OMIM:613978': ['MESH:D017085', 'OMIM:604131', 'OMIM:613978'],
#  'MESH:C563050': ['MESH:C563050', 'OMIM:141750'],
#  'OMIM:141750': ['MESH:C563050', 'OMIM:141750'],
#  'MESH:C563023': ['MESH:C563023', 'OMIM:300448'],
#  'OMIM:300448': ['MESH:C563023', 'OMIM:300448'],
#  'MESH:D018354': ['MESH:D018354'],
#  'OMIM:301050': ['OMIM:301050'],
#  'MESH:C536586': ['MESH:C536586', 'OMIM:104200'],
#  'OMIM:104200': ['MESH:C536586', 'OMIM:104200'],
#  'MESH:C562890': ['MESH:C562890'],
#  'MESH:C564570': ['MESH:C564570', 'OMIM:300194'],
#  'OMIM:300194': ['MESH:C564570', 'OMIM:300194'],
#  'MESH:C536587': ['MESH:C536587', 'OMIM:203780'],
#  'OMIM:203780': ['MESH:C536587', 'OMIM:203780'],
#  'OMIM:616459': ['OMIM:616459'],
#  'MESH:C536588': ['MESH:C536588'],
#  'MESH:D056769': ['MESH:D056769', 'OMIM:203800'],
#  'OMIM:203800': ['MESH:D056769', 'OMIM:203800'],
#  'MESH:D060487': ['MESH:D060487'],
#  'MESH:C536589': ['MESH:C536589', 'OMIM:104290', 'OMIM:614820'],
#  'OMIM:104290': ['MESH:C536589', 'OMIM:104290', 'OMIM:614820'],
#  'OMIM:614820': ['MESH:C536589', 'OMIM:104290', 'OMIM:614820'],
#  'MESH:D000532': ['MESH:D000532'],
#  'MESH:D016301': ['MESH:D016301'],
#  'MESH:C536590': ['MESH:C536590', 'OMIM:265380'],
#  'OMIM:265380': ['MESH:C536590', 'OMIM:265380'],
#  'MESH:C536591': ['MESH:C536591'],
#  'MESH:D000542': ['MESH:D000542'],
#  'MESH:C536593': ['MESH:C536593'],
#  'MESH:D000544': ['MESH:D000544', 'OMIM:104300'],
#  'OMIM:104300': ['MESH:D000544', 'OMIM:104300'],
#  'MESH:C566465': ['MESH:C566465', 'OMIM:609636'],
#  'OMIM:609636': ['MESH:C566465', 'OMIM:609636'],
#  'MESH:C565228': ['MESH:C565228', 'OMIM:609790'],
#  'OMIM:609790': ['MESH:C565228', 'OMIM:609790'],
#  'MESH:C567022': ['MESH:C567022', 'OMIM:611073'],
#  'OMIM:611073': ['MESH:C567022', 'OMIM:611073'],
#  'MESH:C567000': ['MESH:C567000', 'OMIM:611152'],
#  'OMIM:611152': ['MESH:C567000', 'OMIM:611152'],
#  'MESH:C566999': ['MESH:C566999', 'OMIM:611154'],
#  'OMIM:611154': ['MESH:C566999', 'OMIM:611154'],
#  'MESH:C566998': ['MESH:C566998', 'OMIM:604154'],
#  'OMIM:604154': ['MESH:C566998', 'OMIM:604154'],
#  'MESH:C567463': ['MESH:C567463', 'OMIM:300756'],
#  'OMIM:300756': ['MESH:C567463', 'OMIM:300756'],
#  'OMIM:615590': ['OMIM:615590'],
#  'OMIM:615711': ['OMIM:615711'],
#  'MESH:C566578': ['MESH:C566578', 'OMIM:602096'],
#  'OMIM:602096': ['MESH:C566578', 'OMIM:602096'],
#  'MESH:C565325': ['MESH:C565325', 'OMIM:605526'],
#  'OMIM:605526': ['MESH:C565325', 'OMIM:605526'],
#  'MESH:C565251': ['MESH:C565251', 'OMIM:606187'],
#  'OMIM:606187': ['MESH:C565251', 'OMIM:606187'],
#  'MESH:C564622': ['MESH:C564622', 'OMIM:607116'],
#  'OMIM:607116': ['MESH:C564622', 'OMIM:607116'],
#  'MESH:C563834': ['MESH:C563834', 'OMIM:608907'],
#  'OMIM:608907': ['MESH:C563834', 'OMIM:608907'],
#  'MESH:C566299': ['MESH:C566299'],
#  'MESH:C566298': ['MESH:C566298'],
#  'MESH:C564330': ['MESH:C564330', 'OMIM:607822'],
#  'OMIM:607822': ['MESH:C564330', 'OMIM:607822'],
#  'MESH:C564329': ['MESH:C564329'],
#  'MESH:C565728': ['MESH:C565728'],
#  'MESH:C536598': ['MESH:C536598'],
#  'MESH:C536594': ['MESH:C536594'],
#  'MESH:C536595': ['MESH:C536595', 'OMIM:104310'],
#  'OMIM:104310': ['MESH:C536595', 'OMIM:104310'],
#  'MESH:C536596': ['MESH:C536596', 'OMIM:606889'],
#  'OMIM:606889': ['MESH:C536596', 'OMIM:606889'],
#  'MESH:C536599': ['MESH:C536599'],
#  'MESH:C562989': ['MESH:C562989'],
#  'MESH:C566295': ['MESH:C566295'],
#  'MESH:C536600': ['MESH:C536600', 'OMIM:204000'],
#  'OMIM:204000': ['MESH:C536600', 'OMIM:204000'],
#  'MESH:C536601': ['MESH:C536601', 'OMIM:204100'],
#  'OMIM:204100': ['MESH:C536601', 'OMIM:204100'],
#  'MESH:C536602': ['MESH:C536602', 'OMIM:604537'],
#  'OMIM:604537': ['MESH:C536602', 'OMIM:604537'],
#  'MESH:C536603': ['MESH:C536603', 'OMIM:608553'],
#  'OMIM:608553': ['MESH:C536603', 'OMIM:608553'],
#  'MESH:D020757': ['MESH:D020757'],
#  'MESH:C536604': ['MESH:C536604', 'OMIM:217080'],
#  'OMIM:217080': ['MESH:C536604', 'OMIM:217080'],
#  'MESH:D000550': ['MESH:D000550'],
#  'MESH:C536605': ['MESH:C536605', 'OMIM:145701'],
#  'OMIM:145701': ['MESH:C536605', 'OMIM:145701'],
#  'MESH:D000090004': ['MESH:D000090004'],
#  'MESH:D000562': ['MESH:D000562'],
#  'MESH:C566294': ['MESH:C566294'],
#  'MESH:C563338': ['MESH:C563338'],
#  'MESH:D000564': ['MESH:D000564'],
#  'MESH:D000567': ['MESH:D000567'],
#  'MESH:C536606': ['MESH:C536606'],
#  'MESH:C567146': ['MESH:C567146'],
#  'MESH:C567279': ['MESH:C567279', 'OMIM:612529'],
#  'OMIM:612529': ['MESH:C567279', 'OMIM:612529'],
#  'MESH:C567706': ['MESH:C567706', 'OMIM:613211'],
#  'OMIM:613211': ['MESH:C567706', 'OMIM:613211'],
#  'OMIM:614832': ['OMIM:614832'],
#  'OMIM:615887': ['OMIM:615887'],
#  'OMIM:617217': ['OMIM:617217'],
#  'MESH:C564463': ['MESH:C564463'],
#  'MESH:C538243': ['MESH:C538243', 'OMIM:301200'],
#  'OMIM:301200': ['MESH:C538243', 'OMIM:301200'],
#  'OMIM:301201': ['OMIM:301201'],
#  'MESH:C538240': ['MESH:C538240', 'OMIM:104530'],
#  'OMIM:104530': ['MESH:C538240', 'OMIM:104530'],
#  'MESH:C538241': ['MESH:C538241'],
#  'MESH:C538242': ['MESH:C538242', 'OMIM:204700'],
#  'OMIM:204700': ['MESH:C538242', 'OMIM:204700'],
#  'MESH:C562879': ['MESH:C562879', 'OMIM:104500'],
#  'OMIM:104500': ['MESH:C562879', 'OMIM:104500'],
#  'MESH:C567147': ['MESH:C567147', 'OMIM:204650'],
#  'OMIM:204650': ['MESH:C567147', 'OMIM:204650'],
#  'OMIM:616270': ['OMIM:616270'],
#  'OMIM:204690': ['OMIM:204690'],
#  'OMIM:616221': ['OMIM:616221'],
#  'MESH:C562880': ['MESH:C562880', 'OMIM:130900'],
#  'OMIM:130900': ['MESH:C562880', 'OMIM:130900'],
#  'OMIM:617297': ['OMIM:617297'],
#  'MESH:C566293': ['MESH:C566293', 'OMIM:104510'],
#  'OMIM:104510': ['MESH:C566293', 'OMIM:104510'],
#  'MESH:C538245': ['MESH:C538245'],
#  'MESH:D000568': ['MESH:D000568'],
#  'MESH:D000592': ['MESH:D000592'],
#  'MESH:D020157': ['MESH:D020157'],
#  'MESH:C565960': ['MESH:C565960'],
#  'MESH:C538246': ['MESH:C538246', 'OMIM:609924'],
#  'OMIM:609924': ['MESH:C538246', 'OMIM:609924'],
#  'MESH:C563799': ['MESH:C563799', 'OMIM:609056'],
#  'OMIM:609056': ['MESH:C563799', 'OMIM:609056'],
#  'MESH:C538247': ['MESH:C538247', 'OMIM:607196'],
#  'OMIM:607196': ['MESH:C538247', 'OMIM:607196'],
#  'MESH:D000647': ['MESH:D000647'],
#  'MESH:D020324': ['MESH:D020324'],
#  'MESH:D000648': ['MESH:D000648'],
#  'MESH:D020236': ['MESH:D020236'],
#  'MESH:C531614': ['MESH:C531614'],
#  'MESH:D000652': ['MESH:D000652'],
#  'MESH:C565959': ['MESH:C565959'],
#  'MESH:C531613': ['MESH:C531613'],
#  'MESH:C539067': ['MESH:C539067'],
#  'MESH:C000654764': ['MESH:C000654764'],
#  'MESH:D019969': ['MESH:D019969'],
#  'MESH:C565682': ['MESH:C565682'],
#  'MESH:D000673': ['MESH:D000673'],
#  'MESH:C565965': ['MESH:C565965', 'OMIM:203650'],
#  'OMIM:203650': ['MESH:C565965', 'OMIM:203650'],
#  'MESH:C538248': ['MESH:C538248'],
#  'MESH:D017772': ['MESH:D017772'],
#  'MESH:D028227': ['MESH:D028227'],
#  'MESH:C531615': ['MESH:C531615'],
#  'MESH:D000686': ['MESH:D000686'],
#  'MESH:C535800': ['MESH:C535800'],
#  'MESH:C537944': ['MESH:C537944', 'OMIM:605714'],
#  'OMIM:605714': ['MESH:C537944', 'OMIM:605714'],
#  'MESH:C562644': ['MESH:C562644'],
#  'MESH:D028226': ['MESH:D028226'],
#  'MESH:C538249': ['MESH:C538249', 'OMIM:105200'],
#  'OMIM:105200': ['MESH:C538249', 'OMIM:105200'],
#  'MESH:C567782': ['MESH:C567782', 'OMIM:105210'],
#  'OMIM:105210': ['MESH:C567782', 'OMIM:105210'],
#  'MESH:C562643': ['MESH:C562643', 'OMIM:105250'],
#  'OMIM:105250': ['MESH:C562643', 'OMIM:105250'],
#  'MESH:C565958': ['MESH:C565958'],
#  'MESH:C562642': ['MESH:C562642', 'OMIM:613955'],
#  'OMIM:613955': ['MESH:C562642', 'OMIM:613955'],
#  'MESH:C538250': ['MESH:C538250'],
#  'MESH:C566292': ['MESH:C566292'],
#  'MESH:D000690': ['MESH:D000690'],
#  'MESH:C531617': ['MESH:C531617', 'OMIM:105400'],
#  'OMIM:105400': ['MESH:C531617', 'OMIM:105400'],
#  'MESH:C567429': ['MESH:C567429', 'OMIM:612069'],
#  'OMIM:612069': ['MESH:C567429', 'OMIM:612069'],
#  'MESH:C567244': ['MESH:C567244', 'OMIM:612577'],
#  'OMIM:612577': ['MESH:C567244', 'OMIM:612577'],
#  'OMIM:613435': ['OMIM:613435'],
#  'OMIM:300857': ['OMIM:300857'],
#  'OMIM:614373': ['OMIM:614373'],
#  'OMIM:614808': ['OMIM:614808'],
#  'OMIM:615515': ['OMIM:615515'],
#  'OMIM:615426': ['OMIM:615426'],
#  'OMIM:616208': ['OMIM:616208'],
#  'MESH:C565957': ['MESH:C565957', 'OMIM:205100'],
#  'OMIM:205100': ['MESH:C565957', 'OMIM:205100'],
#  'MESH:C564688': ['MESH:C564688', 'OMIM:606640'],
#  'OMIM:606640': ['MESH:C564688', 'OMIM:606640'],
#  'MESH:C566550': ['MESH:C566550', 'OMIM:602433'],
#  'OMIM:602433': ['MESH:C566550', 'OMIM:602433'],
#  'MESH:C566576': ['MESH:C566576', 'OMIM:602099'],
#  'OMIM:602099': ['MESH:C566576', 'OMIM:602099'],
#  'MESH:C567699': ['MESH:C567699', 'OMIM:608030'],
#  'OMIM:608030': ['MESH:C567699', 'OMIM:608030'],
#  'MESH:C564300': ['MESH:C564300', 'OMIM:608031'],
#  'OMIM:608031': ['MESH:C564300', 'OMIM:608031'],
#  'MESH:C563895': ['MESH:C563895', 'OMIM:608627'],
#  'OMIM:608627': ['MESH:C563895', 'OMIM:608627'],
#  'MESH:C567499': ['MESH:C567499', 'OMIM:611895'],
#  'OMIM:611895': ['MESH:C567499', 'OMIM:611895'],
#  'MESH:C566290': ['MESH:C566290'],
#  'MESH:C565956': ['MESH:C565956'],
#  'OMIM:105500': ['OMIM:105500'],
#  'MESH:C538251': ['MESH:C538251'],
#  'MESH:C565955': ['MESH:C565955'],
#  'MESH:C538253': ['MESH:C538253'],
#  'MESH:C566526': ['MESH:C566526'],
#  'MESH:C563020': ['MESH:C563020', 'OMIM:105580'],
#  'OMIM:105580': ['MESH:C563020', 'OMIM:105580'],
#  'MESH:D000694': ['MESH:D000694'],
#  'MESH:C538254': ['MESH:C538254', 'OMIM:105563'],
#  'OMIM:105563': ['MESH:C538254', 'OMIM:105563'],
#  'MESH:C566287': ['MESH:C566287'],
#  'MESH:D000707': ['MESH:D000707'],
#  'MESH:D000708': ['MESH:D000708'],
#  'MESH:D000711': ['MESH:D000711'],
#  'MESH:D000712': ['MESH:D000712'],
#  'MESH:C538255': ['MESH:C538255'],
#  'MESH:D057868': ['MESH:D057868'],
#  'MESH:C538256': ['MESH:C538256', 'OMIM:607095', 'OMIM:617396'],
#  'OMIM:607095': ['MESH:C538256', 'OMIM:607095', 'OMIM:617396'],
#  'OMIM:617396': ['MESH:C538256', 'OMIM:607095', 'OMIM:617396'],
#  'MESH:C538433': ['MESH:C538433'],
#  'MESH:D000724': ['MESH:D000724'],
#  'MESH:D050030': ['MESH:D050030', 'OMIM:170390'],
#  'OMIM:170390': ['MESH:D050030', 'OMIM:170390'],
#  'MESH:C537588': ['MESH:C537588'],
#  'MESH:D013734': ['MESH:D013734', 'OMIM:300068', 'OMIM:312300'],
#  'OMIM:300068': ['MESH:D013734', 'OMIM:300068', 'OMIM:312300'],
#  'OMIM:312300': ['MESH:D013734', 'OMIM:300068', 'OMIM:312300'],
#  'MESH:C564545': ['MESH:C564545'],
#  'MESH:D000740': ['MESH:D000740'],
#  'MESH:D000741': ['MESH:D000741', 'OMIM:609135'],
#  'OMIM:609135': ['MESH:D000741', 'OMIM:609135'],
#  'MESH:C565796': ['MESH:C565796'],
#  'MESH:D029503': ['MESH:D029503', 'OMIM:105650'],
#  'OMIM:105650': ['MESH:D029503', 'OMIM:105650'],
#  'MESH:C536130': ['MESH:C536130', 'OMIM:606129'],
#  'OMIM:606129': ['MESH:C536130', 'OMIM:606129'],
#  'MESH:C536355': ['MESH:C536355', 'OMIM:610629'],
#  'OMIM:610629': ['MESH:C536355', 'OMIM:610629'],
#  'MESH:D000742': ['MESH:D000742',
#   'OMIM:105600',
#   'OMIM:224100',
#   'OMIM:224120',
#   'OMIM:613673',
#   'OMIM:615631'],
#  'OMIM:105600': ['MESH:D000742',
#   'OMIM:105600',
#   'OMIM:224100',
#   'OMIM:224120',
#   'OMIM:613673',
#   'OMIM:615631'],
#  'OMIM:224100': ['MESH:D000742',
#   'OMIM:105600',
#   'OMIM:224100',
#   'OMIM:224120',
#   'OMIM:613673',
#   'OMIM:615631'],
#  'OMIM:224120': ['MESH:D000742',
#   'OMIM:105600',
#   'OMIM:224100',
#   'OMIM:224120',
#   'OMIM:613673',
#   'OMIM:615631'],
#  'OMIM:613673': ['MESH:D000742',
#   'OMIM:105600',
#   'OMIM:224100',
#   'OMIM:224120',
#   'OMIM:613673',
#   'OMIM:615631'],
#  'OMIM:615631': ['MESH:D000742',
#   'OMIM:105600',
#   'OMIM:224100',
#   'OMIM:224120',
#   'OMIM:613673',
#   'OMIM:615631'],
#  'MESH:D000743': ['MESH:D000743'],
#  'MESH:D000744': ['MESH:D000744', 'OMIM:205700'],
#  'OMIM:205700': ['MESH:D000744', 'OMIM:205700'],
#  'MESH:D000745': ['MESH:D000745'],
#  'MESH:D000746': ['MESH:D000746'],
#  'MESH:C536356': ['MESH:C536356'],
#  'MESH:D000747': ['MESH:D000747'],
#  'MESH:C536357': ['MESH:C536357'],
#  'MESH:C567144': ['MESH:C567144', 'OMIM:206100', 'OMIM:615234'],
#  'OMIM:206100': ['MESH:C567144', 'OMIM:206100', 'OMIM:615234'],
#  'OMIM:615234': ['MESH:C567144', 'OMIM:206100', 'OMIM:615234'],
#  'MESH:D029502': ['MESH:D029502'],
#  'MESH:D018798': ['MESH:D018798'],
#  'MESH:D000748': ['MESH:D000748'],
#  'MESH:D000749': ['MESH:D000749'],
#  'MESH:D000750': ['MESH:D000750'],
#  'MESH:D000751': ['MESH:D000751'],
#  'MESH:C565953': ['MESH:C565953'],
#  'MESH:C567533': ['MESH:C567533'],
#  'OMIM:300908': ['OMIM:300908'],
#  'MESH:C565952': ['MESH:C565952'],
#  'MESH:D000752': ['MESH:D000752'],
#  'MESH:D000753': ['MESH:D000753'],
#  'MESH:D000754': ['MESH:D000754'],
#  'MESH:D000755': ['MESH:D000755', 'OMIM:603903'],
#  'OMIM:603903': ['MESH:D000755', 'OMIM:603903'],
#  'MESH:D000756': ['MESH:D000756', 'OMIM:182170'],
#  'OMIM:182170': ['MESH:D000756', 'OMIM:182170'],
#  'MESH:C567160': ['MESH:C567160'],
#  'MESH:C567145': ['MESH:C567145', 'OMIM:205950', 'OMIM:616860'],
#  'OMIM:205950': ['MESH:C567145', 'OMIM:205950', 'OMIM:616860'],
#  'OMIM:616860': ['MESH:C567145', 'OMIM:205950', 'OMIM:616860'],
#  'MESH:C565954': ['MESH:C565954'],
#  'MESH:C536358': ['MESH:C536358', 'OMIM:301310'],
#  'OMIM:301310': ['MESH:C536358', 'OMIM:301310'],
#  'OMIM:300835': ['OMIM:300835'],
#  'MESH:C564429': ['MESH:C564429'],
#  'MESH:D000757': ['MESH:D000757', 'OMIM:206500'],
#  'OMIM:206500': ['MESH:D000757', 'OMIM:206500'],
#  'MESH:C536359': ['MESH:C536359'],
#  'MESH:D057088': ['MESH:D057088'],
#  'MESH:D000782': ['MESH:D000782'],
#  'MESH:D000783': ['MESH:D000783'],
#  'MESH:D000784': ['MESH:D000784'],
#  'MESH:D017541': ['MESH:D017541'],
#  'MESH:D000785': ['MESH:D000785'],
#  'MESH:C566284': ['MESH:C566284', 'OMIM:105800'],
#  'OMIM:105800': ['MESH:C566284', 'OMIM:105800'],
#  'MESH:C567237': ['MESH:C567237', 'OMIM:612587'],
#  'OMIM:612587': ['MESH:C567237', 'OMIM:612587'],
#  'MESH:C536360': ['MESH:C536360', 'OMIM:608542'],
#  'OMIM:608542': ['MESH:C536360', 'OMIM:608542'],
#  'MESH:C563792': ['MESH:C563792', 'OMIM:609122'],
#  'OMIM:609122': ['MESH:C563792', 'OMIM:609122'],
#  'MESH:C565700': ['MESH:C565700', 'OMIM:610213'],
#  'OMIM:610213': ['MESH:C565700', 'OMIM:610213'],
#  'MESH:C563670': ['MESH:C563670'],
#  'MESH:C567500': ['MESH:C567500', 'OMIM:611892'],
#  'OMIM:611892': ['MESH:C567500', 'OMIM:611892'],
#  'MESH:C567406': ['MESH:C567406', 'OMIM:612161'],
#  'OMIM:612161': ['MESH:C567406', 'OMIM:612161'],
#  'MESH:C567405': ['MESH:C567405', 'OMIM:612162'],
#  'OMIM:612162': ['MESH:C567405', 'OMIM:612162'],
#  'MESH:C567238': ['MESH:C567238', 'OMIM:612586'],
#  'OMIM:612586': ['MESH:C567238', 'OMIM:612586'],
#  'MESH:C563239': ['MESH:C563239'],
#  'MESH:D017542': ['MESH:D017542'],
#  'MESH:D017204': ['MESH:D017204', 'OMIM:105830'],
#  'OMIM:105830': ['MESH:D017204', 'OMIM:105830'],
#  'MESH:C536361': ['MESH:C536361'],
#  'MESH:D000787': ['MESH:D000787'],
#  'MESH:D000788': ['MESH:D000788'],
#  'MESH:D060050': ['MESH:D060050'],
#  'MESH:D000789': ['MESH:D000789'],
#  'MESH:D016888': ['MESH:D016888'],
#  'MESH:D000799': ['MESH:D000799'],
#  'OMIM:300909': ['OMIM:300909'],
#  'MESH:D054179': ['MESH:D054179', 'OMIM:106100'],
#  'OMIM:106100': ['MESH:D054179', 'OMIM:106100'],
#  'MESH:D018322': ['MESH:D018322'],
#  'MESH:C536362': ['MESH:C536362'],
#  'MESH:D000793': ['MESH:D000793'],
#  'MESH:D000794': ['MESH:D000794'],
#  'MESH:C563940': ['MESH:C563940'],
#  'MESH:D018206': ['MESH:D018206'],
#  'MESH:C565951': ['MESH:C565951'],
#  'MESH:D000796': ['MESH:D000796'],
#  'MESH:C536364': ['MESH:C536364'],
#  'MESH:C536365': ['MESH:C536365'],
#  'MESH:C536366': ['MESH:C536366', 'OMIM:300652'],
#  'OMIM:300652': ['MESH:C536366', 'OMIM:300652'],
#  'MESH:D000798': ['MESH:D000798'],
#  'MESH:D016917': ['MESH:D016917'],
#  'MESH:C536367': ['MESH:C536367'],
#  'MESH:D018207': ['MESH:D018207'],
#  'MESH:D018229': ['MESH:D018229'],
#  'MESH:C567088': ['MESH:C567088', 'OMIM:611773'],
#  'OMIM:611773': ['MESH:C567088', 'OMIM:611773'],
#  'MESH:C536368': ['MESH:C536368'],
#  'MESH:C536369': ['MESH:C536369'],
#  'MESH:D059445': ['MESH:D059445'],
#  'OMIM:106190': ['OMIM:106190'],
#  'MESH:D000820': ['MESH:D000820'],
#  'MESH:D015783': ['MESH:D015783', 'OMIM:106210', 'OMIM:617141', 'OMIM:617142'],
#  'OMIM:106210': ['MESH:D015783', 'OMIM:106210', 'OMIM:617141', 'OMIM:617142'],
#  'OMIM:617141': ['MESH:D015783', 'OMIM:106210', 'OMIM:617141', 'OMIM:617142'],
#  'OMIM:617142': ['MESH:D015783', 'OMIM:106210', 'OMIM:617141', 'OMIM:617142'],
#  'MESH:C566281': ['MESH:C566281'],
#  'MESH:C536370': ['MESH:C536370', 'OMIM:206700'],
#  'OMIM:206700': ['MESH:C536370', 'OMIM:206700'],
#  'MESH:C566280': ['MESH:C566280'],
#  'MESH:C000632444': ['MESH:C000632444'],
#  'MESH:C536372': ['MESH:C536372'],
#  'MESH:D017129': ['MESH:D017129'],
#  'MESH:D000839': ['MESH:D000839'],
#  'MESH:D015875': ['MESH:D015875'],
#  ...}

# %%
pickle_data = pickle.load(open('../arboel/models/trained/ncbi_disease/valid_processed_data.pickle', 'rb'))
len(pickle_data)
# Out:
# 1444

# %%
name = 'medmentions_st21pv'
data = conhelps.for_config_name(f'{name}_bigbio_kb').load_dataset()
exclude = CUIS_TO_EXCLUDE[name]
remap = CUIS_TO_REMAP[name]



df = dataset_to_df(data, entity_remapping_dict=remap, cuis_to_exclude=exclude)
docs = dataset_to_documents(data)

df['label_len'] = df['db_ids'].map(lambda x: len(x))

df[df.label_len == df.label_len.max()]
# Out:
# Found cached dataset medmentions (/home/dkartchner3/.cache/huggingface/datasets/medmentions/medmentions_st21pv_bigbio_kb/1.0.0/3fc6b8a3681d540ae6c7497c238636b543b90764247b5ff3642d243474000794)
#   0%|          | 0/3 [00:00<?, ?it/s]
#        document_id         offsets              text          type  \
# 64613     27655319    [[462, 468]]            detect  [T058, T033]
# 72785     27708774  [[2036, 2052]]  antral follicles        [T017]
# 87101     27801847    [[496, 500]]              Ldlr  [T103, T017]
# 111221    27979025    [[100, 104]]              food  [T038, T168]
# 189426    28464073  [[2110, 2112]]                HS  [T038, T037]
# 199085    28526565  [[1372, 1377]]             ICOAS  [T058, T201]
# 202565    28548949  [[1809, 1812]]               XPA  [T017, T103]
#
#                                 db_ids  split   mention_id  label_len
# 64613   [UMLS:C1511790, UMLS:C0442726]   test  27655319.17          2
# 72785   [UMLS:C0600225, UMLS:C1135971]  train  27708774.75          2
# 87101   [UMLS:C1366529, UMLS:C0034821]  train  27801847.22          2
# 111221  [UMLS:C0016452, UMLS:C0016470]  train   27979025.4          2
# 189426  [UMLS:C0282498, UMLS:C0282507]  train  28464073.47          2
# 199085  [UMLS:C1456627, UMLS:C0087111]  train  28526565.38          2
# 202565  [UMLS:C1506534, UMLS:C1337030]  train  28548949.75          2

# %%
df = pd.read_json('../data/arboel/ncbi_disease/train.jsonl', lines=True)

# %%
pd.set_option('display.max_rows', 200)

df[319:483]

# %% [markdown]
# # Data Dictionary Checks

# %%
entity_dict = pickle.load(open('../data/arboel/medmentions_st21pv/dictionary.pickle', 'rb'))

# %%
entity_dict[0]
# Out:
# {'cui': 'UMLS:C0000005',
#  'title': '(131)I-Macroaggregated Albumin',
#  'type': 'Chemical',
#  'description': '(131)I-Macroaggregated Albumin ( Chemical : (131)I-Macroaggregated Albumin ; (131)I-MAA )'}

# %%
entity_dict[np.random.choice(2369483)]
# Out:
# {'cui': 'UMLS:C3828178',
#  'title': 'SGRQ-C - Coughing Disturbs My Sleep',
#  'type': 'Intellectual Product',
#  'description': "SGRQ-C - Coughing Disturbs My Sleep ( Intellectual Product : SGRQ-C - Coughing Disturbs My Sleep ) [ St. George's Respiratory Questionnaire for COPD Patients (SGRQ-C) Some more questions about your cough and breathlessness: My coughing or breathing disturbs my sleep. ]"}

# %%
mm_dict = pickle.load(open('../arboel/data/medmentions/processed/dictionary.pickle', 'rb'))

# %%
len(mm_dict)
# Out:
# 2327239

# %%
mm_dict[np.random.choice(2327239)]
# Out:
# {'cui': 'C3944496',
#  'title': 'Eleutherochir opercularis',
#  'description': 'Eleutherochir opercularis ( Eukaryote : Eleutherochir opercularis ( Valenciennes , 1837 ) ; Callionymus opercularis ; Callionymus opercularis Valenciennes , 1837 )',
#  'type': 'T204'}

# %%
# %load_ext autoreload
# %autoreload 2

import sys
import ujson
import pandas as pd
import numpy as np

from tqdm import tqdm
from collections import defaultdict
from sklearn.model_selection import train_test_split

from bigbio.dataloader import BigBioConfigHelpers

sys.path.append('..')
from bigbio_utils import dataset_to_df, DATASET_NAMES, CUIS_TO_EXCLUDE, CUIS_TO_REMAP, VALIDATION_DOCUMENT_IDS


conhelps = BigBioConfigHelpers()

def read_examples(filepath):
    # Read file
    with open(filepath, 'r') as f:
        lines = f.read().split('\n')

    # Construct dict mapping each CURIE to a list of aliases
    umls_dict = {} 
    for line in tqdm(lines):
        if len(line.split('||')) != 2:
            print(line)
            continue
        cui, name = line.split("||")
        if cui in umls_dict:
            umls_dict[cui].append(name)
        else:
            umls_dict[cui] = [name]

    return umls_dict
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dataset = conhelps.for_config_name('bc5cdr_bigbio_kb').load_dataset()
df = dataset_to_df(dataset)
all_cuis = set([y for x in df.db_ids for y in x])
len(all_cuis)
# Out:
# Found cached dataset bc5cdr (/nethome/dkartchner3/.cache/huggingface/datasets/bc5cdr/bc5cdr_bigbio_kb/1.0.0/f01f16ea9b65ead985bedadf7335195c32297c8f1b09417fc607b102a6757d6f)
#   0%|          | 0/3 [00:00<?, ?it/s]
# 2351

# %%
for key in dataset.keys():
    print(len(dataset[key]))
# Out:
# 500
# 500
# 500

# %%
mesh_dict = read_examples('../data/umls_2017/mesh_to_alias.txt')
# Out:
# 100%|██████████| 1006992/1006992 [00:01<00:00, 900870.91it/s]

# %%
len(all_cuis - set(mesh_dict.keys()))
# for x in all_cuis - set(mesh_dict.keys()):
#     print(x.split(':')[-1])
# Out:
# 82

# %%
all_cuis - set(mesh_dict.keys())
# Out:
# {'MESH:-1',
#  'MESH:C000873',
#  'MESH:C005435',
#  'MESH:C008281',
#  'MESH:C009250',
#  'MESH:C010845',
#  'MESH:C012052',
#  'MESH:C014347',
#  'MESH:C019248',
#  'MESH:C022189',
#  'MESH:C026098',
#  'MESH:C030852',
#  'MESH:C032171',
#  'MESH:C032302',
#  'MESH:C034930',
#  'MESH:C035133',
#  'MESH:C036006',
#  'MESH:C037663',
#  'MESH:C039726',
#  'MESH:C040029',
#  'MESH:C041359',
#  'MESH:C043211',
#  'MESH:C043265',
#  'MESH:C044650',
#  'MESH:C045645',
#  'MESH:C047047',
#  'MESH:C047426',
#  'MESH:C047781',
#  'MESH:C048833',
#  'MESH:C049430',
#  'MESH:C051890',
#  'MESH:C052342',
#  'MESH:C055162',
#  'MESH:C059262',
#  'MESH:C061870',
#  'MESH:C063008',
#  'MESH:C064276',
#  'MESH:C065179',
#  'MESH:C065180',
#  'MESH:C065757',
#  'MESH:C067311',
#  'MESH:C067431',
#  'MESH:C069541',
#  'MESH:C071741',
#  'MESH:C076029',
#  'MESH:C076946',
#  'MESH:C081309',
#  'MESH:C081489',
#  'MESH:C084178',
#  'MESH:C085143',
#  'MESH:C086816',
#  'MESH:C090450',
#  'MESH:C094645',
#  'MESH:C096918',
#  'MESH:C098010',
#  'MESH:C099041',
#  'MESH:C102006',
#  'MESH:C105934',
#  'MESH:C107135',
#  'MESH:C108606',
#  'MESH:C110904',
#  'MESH:C118667',
#  'MESH:C400082',
#  'MESH:C413408',
#  'MESH:C418563',
#  'MESH:C422649',
#  'MESH:C422923',
#  'MESH:C467567',
#  'MESH:C471405',
#  'MESH:C473478',
#  'MESH:C476217',
#  'MESH:C476513',
#  'MESH:C476756',
#  'MESH:C492458',
#  'MESH:C531616',
#  'MESH:C531767',
#  'MESH:C537630',
#  'MESH:C542870',
#  'MESH:C562386',
#  'MESH:C562388',
#  'MESH:C562729',
#  'MESH:C562750'}

# %%
mesh_dict['MESH:C000002']
# Out:
# ['bevonium',
#  '2-(hydroxymethyl)-n,n-dimethylpiperidinium benzilate',
#  'cg 201',
#  'acabel',
#  'bevonium sulfate (1:1)',
#  'bevonium methyl sulfate',
#  'piribenzil methyl sulfate',
#  'bevonium methylsulfate',
#  'bevonium metilsulfate']

# %%
biogenel_bc5cdr_database = ujson.load(open('../../biogenel_datasets/bc5cdr/target_kb.json','r'))

# %%
len(set([x.split(':')[-1] for x in all_cuis]) - set(biogenel_bc5cdr_database.keys()))
# Out:
# 22

# %% [markdown]
# # NLM Chem Checks

# %%
nlm_chem_dataset = conhelps.for_config_name('nlmchem_bigbio_kb').load_dataset()
nlm_chem_df = dataset_to_df(nlm_chem_dataset)
nlm_chem_cuis = set([y for x in nlm_chem_df.db_ids for y in x])
len(nlm_chem_cuis)
# Out:
# Found cached dataset nlmchem (/home/dkartchner3/.cache/huggingface/datasets/nlmchem/nlmchem_bigbio_kb/1.0.0/d91131823c66b7dd1162027991ea47c342e478209b37cf261c5f122d30409594)
#   0%|          | 0/3 [00:00<?, ?it/s]
# 1810

# %%
nlm_chem_dict = read_examples('../data/mesh_to_alias.txt')
chemicals = set(nlm_chem_dict.keys())
# Out:
# 100%|██████████| 1006992/1006992 [00:01<00:00, 895795.79it/s]

# %%
len(nlm_chem_cuis - chemicals)

for x in nlm_chem_cuis - chemicals:
    print(x.split(':')[-1])
# Out:
# C015329
# C067134
# C061870
# C000603933
# C004322
# C059514
# C551994
# C000612088
# C419708
# C522924
# D000073878
# D000069463
# C490728
# C089032

# %%
df = dataset_to_df(dataset, name='nlmchem')

# %% [markdown]
# # UMLS quality checks

# %%
dataset = conhelps.for_config_name('medmentions_full_bigbio_kb').load_dataset()
df = dataset_to_df(dataset)
all_umls_cuis = set([y for x in df.db_ids for y in x])
len(all_umls_cuis)
# Out:
# Found cached dataset medmentions (/home/dkartchner3/.cache/huggingface/datasets/medmentions/medmentions_full_bigbio_kb/1.0.0/3fc6b8a3681d540ae6c7497c238636b543b90764247b5ff3642d243474000794)
#   0%|          | 0/3 [00:00<?, ?it/s]
# 34724

# %%
dataset = conhelps.for_config_name('medmentions_st21pv_bigbio_kb').load_dataset()
df = dataset_to_df(dataset)
all_st21pv_cuis = set([y for x in df.db_ids for y in x])
len(all_st21pv_cuis)
# Out:
# Found cached dataset medmentions (/home/dkartchner3/.cache/huggingface/datasets/medmentions/medmentions_st21pv_bigbio_kb/1.0.0/3fc6b8a3681d540ae6c7497c238636b543b90764247b5ff3642d243474000794)
#   0%|          | 0/3 [00:00<?, ?it/s]
# 25419

# %%
umls_dict = read_examples('../data/umls_2017/umls_to_alias.txt')
print(len(umls_dict))
# Out:
#  32%|███▏      | 2529085/7935792 [00:02<00:04, 1194647.27it/s]
# C0851160|ENG|S|L0026543|VO|S0782321|Y|A0842456||||RCD|OP|XM1W1|Morning after pill
# 100%|██████████| 7935792/7935792 [00:19<00:00, 415045.86it/s]
# 3463453

# %%
st21pv_dict = read_examples('../data/umls_2017/st21pv_to_alias.txt')
print(len(st21pv_dict))
# Out:
#  35%|███▍      | 1670632/4796447 [00:01<00:02, 1265088.37it/s]
# C0851160|ENG|S|L0026543|VO|S0782321|Y|A0842456||||RCD|OP|XM1W1|Morning after pill
# 100%|██████████| 4796447/4796447 [00:04<00:00, 1176969.41it/s]
# 2368501

# %%
umls_missed = list(all_umls_cuis - set(umls_dict.keys()))
print(umls_missed)
st21pv_missed = list(all_st21pv_cuis -  set(st21pv_dict.keys()))
print(st21pv_missed)
# Out:
# ['UMLS:C4300640', 'UMLS:C4300518']
# ['UMLS:C0683939']

# %%
umls_keys = set([x.split(':')[-1] for x in umls_dict.keys()])
st21pv_keys = set([x.split(':')[-1] for x in st21pv_dict.keys()])

# %%
len(st21pv_missed)
# Out:
# 166

# %%
umls = ujson.load(open('../data/medlinker/umls.2017AA.active.full.json'))

# %%
st21pv = ujson.load(open('../data/medlinker/umls.2017AA.active.st21pv.json'))

# %%
count = 0
for x, y in umls.items():
    if x not in umls_keys:
        count += 1
        umls_dict[f'UMLS:{x}'] = [y['Name']] + y['STR']

print(count)


count = 0
for x, y in st21pv.items():
    if x not in st21pv_keys:
        count += 1
        st21pv_dict[f'UMLS:{x}'] = [y['Name']] + y['STR']

print(count)
# Out:
# 1554
# 980

# %%
len(umls_dict)
# Out:
# 3465007

# %%
umls_dict
# Out:
# {'UMLS:C0000005': ['(131)I-Macroaggregated Albumin', '(131)I-MAA'],
#  'UMLS:C0000039': ['1,2-Dipalmitoylphosphatidylcholine',
#   '1,2 Dipalmitoylphosphatidylcholine',
#   '1,2-Dihexadecyl-sn-Glycerophosphocholine',
#   '1,2 Dihexadecyl sn Glycerophosphocholine',
#   '1,2-Dipalmitoyl-Glycerophosphocholine',
#   '1,2 Dipalmitoyl Glycerophosphocholine',
#   'Dipalmitoylphosphatidylcholine',
#   'Dipalmitoylglycerophosphocholine',
#   'Dipalmitoyllecithin',
#   '3,5,9-Trioxa-4-phosphapentacosan-1-aminium, 4-hydroxy-N,N,N-trimethyl-10-oxo-7-((1-oxohexadecyl)oxy)-, inner salt, 4-oxide',
#   'Dipalmitoylphosphatidylcholine (substance)',
#   'Dipalmitoyl Phosphatidylcholine',
#   'Phosphatidylcholine, Dipalmitoyl',
#   'DPPC',
#   'DIPALMITOYLPHOSPHATIDYLCHOLINE 0102',
#   '1,2-Dipalmitoylphosphatidylcholine [Chemical/Ingredient]'],
#  'UMLS:C0000052': ['1,4-alpha-Glucan Branching Enzyme',
#   '1,4-alpha-Glucan branching enzyme',
#   '1,4-Alpha glucan branching enzyme',
#   '1,4 alpha Glucan Branching Enzyme',
#   'Branching Enzyme, 1,4-alpha-Glucan',
#   'Enzyme, 1,4-alpha-Glucan Branching',
#   'Branching Enzyme',
#   'Branching enzyme',
#   'Enzyme, Branching',
#   'Branching Glycosyltransferase',
#   'Glycosyltransferase, Branching',
#   'Starch Branching Enzyme',
#   'Branching Enzyme, Starch',
#   'Enzyme, Starch Branching',
#   '1,4-alpha-D-Glucan:1,4-alpha-D-glucan 6-alpha-D-(1,4-alpha-D-glucano)-transferase',
#   'Amylo-(1,4,6)-transglycosylase',
#   'Amylo-(1,4->,6)-transglycosylase',
#   'alpha-Glucan-branching glycosyltransferase',
#   'Amylo (1-4 to 1-6)-transglucosidase',
#   '1,4-alpha-Glucan branching enzyme (substance)',
#   'GLUCAN BRANCHING ENZYME',
#   'ALPHA GLUCAN BRANCHING ENZYME 01 04',
#   '1,4-alpha-Glucan Branching Enzyme [Chemical/Ingredient]'],
#  'UMLS:C0000074': ['1-Alkyl-2-Acylphosphatidates',
#   '1 Alkyl 2 Acylphosphatidates'],
#  'UMLS:C0000084': ['1-Carboxyglutamic Acid',
#   '1 Carboxyglutamic Acid',
#   'gamma-Carboxyglutamic Acid',
#   'gamma Carboxyglutamic Acid',
#   '3-Amino-1,1,3-propanetricarboxylic Acid',
#   '1,1,3-Propanetricarboxylic acid, 3-amino-',
#   'CARBOXYGLUTAMIC ACID 01',
#   '1-Carboxyglutamic Acid [Chemical/Ingredient]'],
#  'UMLS:C0000096': ['1-Methyl-3-isobutylxanthine',
#   '1 Methyl 3 isobutylxanthine',
#   '3-Isobutyl-1-methylxanthine',
#   '3 Isobutyl 1 methylxanthine',
#   'IBMX',
#   'Isobutyltheophylline',
#   '1H-Purine-2,6-dione, 3,7-dihydro-1-methyl-3-(2-methylpropyl)-',
#   'MIBX',
#   'ISOBUTYLMETHYLXANTHINE 03 01',
#   'METHYLISOBUTYLXANTHINE 01 03',
#   '1-Methyl-3-isobutylxanthine [Chemical/Ingredient]'],
#  'UMLS:C0000097': ['1-Methyl-4-phenyl-1,2,3,6-tetrahydropyridine',
#   'MPTP',
#   'mptp',
#   'N-Methyl-4-phenyl-1,2,3,6-tetrahydropyridine',
#   'Pyridine, 1,2,3,6-tetrahydro-1-methyl-4-phenyl-',
#   'Methylphenyltetrahydropyridine',
#   'methylphenyltetrahydropyridine',
#   'Methylphenyltetrahydropyridine (substance)',
#   'METHYLPHENYLTETRAHYDROPYRIDINE 01 04 01 02 03 06',
#   '1-Methyl-4-phenyl-1,2,3,6-tetrahydropyridine [Chemical/Ingredient]',
#   '1-Methyl-4-Phenyl-1,2,3,6-Tetrahydropyridine (MPTP)'],
#  'UMLS:C0000098': ['1-Methyl-4-phenylpyridinium',
#   '1 Methyl 4 phenylpyridinium',
#   '1-Methyl-4-phenylpyridinium Ion',
#   '1 Methyl 4 phenylpyridinium Ion',
#   'Cyperquat',
#   'MPP+',
#   'N-Methyl-4-phenylpyridine',
#   'N Methyl 4 phenylpyridine',
#   '1-Methyl-4-phenylpyridine',
#   '1 Methyl 4 phenylpyridine',
#   'N-Methyl-4-phenylpyridinium',
#   'N METHYL 4 PHENYLPYRIDINIUM',
#   'Pyridinium, 1-methyl-4-phenyl-',
#   'METHYLPHENYLPYRIDINIUM 01 04',
#   '1-Methyl-4-phenylpyridinium [Chemical/Ingredient]'],
#  'UMLS:C0000102': ['1-Naphthylamine',
#   '1-naphthylamine',
#   '1 Naphthylamine',
#   'alpha-Naphthylamine',
#   'alpha-naphthylamine',
#   'alpha Naphthylamine',
#   'Naphthalidine',
#   '8-Aminonaphthalene',
#   '8 Aminonaphthalene',
#   '1-Aminonaphthalene',
#   '1 Aminonaphthalene',
#   '1-Naphthalenamine',
#   '1-Naththylamine',
#   'a- Naphthylamine',
#   'a-Naphthylamine',
#   '1-Naththylamine (substance)',
#   'AMINONAPHTHALENE 01',
#   'NAPHTHYLAMINE 01',
#   '1-Naphthylamine [Chemical/Ingredient]'],
#  'UMLS:C0000103': ['1-Naphthylisothiocyanate',
#   '1 Naphthylisothiocyanate',
#   'alpha-Naphthylisothiocyanate',
#   'alpha Naphthylisothiocyanate',
#   'Naphthalene, 1-isothiocyanato-',
#   'NAPHTHYLISOTHIOCYANATE 01',
#   '1-Naphthylisothiocyanate [Chemical/Ingredient]'],
#  'UMLS:C0000107': ['1-Sarcosine-8-Isoleucine Angiotensin II',
#   '1 Sarcosine 8 Isoleucine Angiotensin II',
#   'Angiotensin II, 1-Sarcosine-8-Isoleucine',
#   '1-Sar-8-Ile Angiotensin II',
#   '1 Sar 8 Ile Angiotensin II',
#   'Angiotensin II, 1-Sar-8-Ile',
#   '1-(N-Methylglycine)-8-L-Isoleucine-Angiotensin II',
#   'Angiotensin II, 1-(N-methylglycine)-8-L-isoleucine-',
#   'Sarile',
#   'SAR ISO ANG',
#   'SARCOSINEISOLEUCINEANGIOTENSIN 02 01 08',
#   'SAR ILE ANGIOTENSIN 02 01 08',
#   '1-Sarcosine-8-Isoleucine Angiotensin II [Chemical/Ingredient]'],
#  'UMLS:C0000119': ['11-Hydroxycorticosteroids',
#   '11 Hydroxycorticosteroids',
#   'HYDROXYCORTICOSTEROIDS A 11',
#   '11-Hydroxycorticosteroids [Chemical/Ingredient]'],
#  'UMLS:C0000120': ['synthetic 11-hydroxycorticosteroids'],
#  'UMLS:C0000132': ['15-Ketosteryl Oleate Hydrolase',
#   '15 Ketosteryl Oleate Hydrolase',
#   'Hydrolase, 15-Ketosteryl Oleate'],
#  'UMLS:C0000137': ['15S RNA', 'RNA, 15S'],
#  'UMLS:C0000139': ['16,16-Dimethylprostaglandin E2',
#   '16,16 Dimethylprostaglandin E2',
#   'E2, 16,16-Dimethylprostaglandin',
#   '16,16-Dimethyl-PGE2',
#   '16,16 Dimethyl PGE2',
#   'Prosta-5,13-dien-1-oic acid, 11,15-dihydroxy-16,16-dimethyl-9-oxo-, (5Z,11alpha,13E,15R)-',
#   'DIMETHYLPGE2',
#   'DIMETHYLPROSTAGLANDIN E 02 16 16',
#   '16,16-Dimethylprostaglandin E2 [Chemical/Ingredient]'],
#  'UMLS:C0000151': ['17 beta-Hydroxy-5 beta-Androstan-3-One',
#   '17 beta Hydroxy 5 beta Androstan 3 One',
#   'beta-Hydroxy-5 beta-Androstan-3-One, 17'],
#  'UMLS:C0000152': ['17 beta-Hydroxysteroid Dehydrogenases',
#   '17 beta Hydroxysteroid Dehydrogenases',
#   'Dehydrogenases, 17 beta-Hydroxysteroid',
#   'BETA HYDROXYSTEROID DEHYDROGENASES A 17'],
#  'UMLS:C0000163': ['17-Hydroxycorticosteroids',
#   '17-hydroxycorticosteroids',
#   '17-Hydroxycorticosteroid',
#   '17 Hydroxycorticosteroids',
#   '17 hydroxycorticosteroid',
#   '17-hydroxycorticosteroid',
#   '17-Hydrocorticosteroid',
#   '17-Hydrocorticosteroids',
#   '17-hydrocorticosteroids',
#   '17-Hydroxycorticoid',
#   '17-Hydroxycorticoids',
#   '17-Hydroxycorticoids, NOS',
#   '17 hydroxycorticoids',
#   '17-Ketogenic steroids',
#   '17-Ketogenic steroids, NOS',
#   '17-ketogenic steroid',
#   '17-Ketogenic steroid',
#   '17-Oxogenic steroids',
#   '17-Oxogenic steroid',
#   '17KGS - 17-Ketogenic steroids',
#   '17-Hydroxycorticosteroid -RETIRED-',
#   '17-Hydroxycorticosteroid (substance)',
#   '17-Ketogenic steroid (substance)',
#   'HYDROXYCORTICOSTEROIDS A 17',
#   '17-Hydroxycorticosteroids [Chemical/Ingredient]'],
#  'UMLS:C0000165': ['17-Hydroxysteroid Dehydrogenases',
#   'HYDROXYSTEROID DEHYDROGENASES 17',
#   '17 Hydroxysteroid Dehydrogenases',
#   '17-hydroxysteroid dehydrogenase',
#   'Dehydrogenases, 17-Hydroxysteroid',
#   '17-Ketosteroid Reductases',
#   '17 Ketosteroid Reductases',
#   'Reductases, 17-Ketosteroid',
#   '17-Hydroxysteroid Dehydrogenases [Chemical/Ingredient]'],
#  'UMLS:C0000167': ['17-Ketosteroids',
#   'KETOSTEROIDS 17',
#   '17 ketosteroids',
#   '17-ketosteroids',
#   '17 Ketosteroids',
#   '17-Ketosteroids, NOS',
#   '17 ketosteroid',
#   '17-ketosteroid',
#   '17-Ketosteroid',
#   '17-Oxosteroids',
#   'OXOSTEROIDS 17',
#   '17-oxosteroids',
#   '17 Oxosteroids',
#   '17-Oxosteroid',
#   '17-Ketosteroid (substance)',
#   '17-Oxosteroid (substance)',
#   '17-Oxosteroids (substance)',
#   '17-Ketosteroids [Chemical/Ingredient]'],
#  'UMLS:C0000172': ['18-Hydroxycorticosterone',
#   'HYDROXYCORTICOSTERONE 18',
#   '18-hydroxycorticosterone',
#   '18 Hydroxycorticosterone',
#   'Hydroxycorticosterone, 18',
#   '18-Hydrocorticosterone',
#   'HYDROCORTICOSTERONE 18',
#   '18 Hydrocorticosterone',
#   'Pregn-4-ene-3,20-dione, 11,18,21-trihydroxy-, (11beta)-',
#   '11-beta,18,21-Trihydroxypregn-4-ene-3,20-dione',
#   '18-Hydroxycorticosterone (substance)',
#   '18-Hydroxycorticosterone [Chemical/Ingredient]'],
#  'UMLS:C0000173': ['18-Hydroxydesoxycorticosterone',
#   'HYDROXYDESOXYCORTICOSTERONE 18',
#   '18 Hydroxydesoxycorticosterone',
#   'Hydroxydesoxycorticosterone, 18',
#   '18-Hydroxy-11-Desoxycorticosterone',
#   '18 Hydroxy 11 Desoxycorticosterone',
#   '18-Hydroxy-11-Deoxycorticosterone',
#   '18 Hydroxy 11 Deoxycorticosterone',
#   '18-Hydroxydesoxycorticosterone [Chemical/Ingredient]'],
#  'UMLS:C0000176': ['19-Iodocholesterol',
#   'IODOCHOLESTEROL 19',
#   '19 Iodocholesterol',
#   'Cholest-5-en-3-ol, 19-(iodo-125I)-, (3beta)-',
#   '19-Iodocholesterol [Chemical/Ingredient]'],
#  'UMLS:C0000184': ["2',3'-Cyclic-Nucleotide Phosphodiesterases",
#   "2',3' Cyclic Nucleotide Phosphodiesterase",
#   "2',3' Cyclic Nucleotide Phosphodiesterases",
#   "2',3'-Cyclic Nucleotide Phosphodiesterase",
#   "2',3'-Cyclic Nucleotide Phosphodiesterases",
#   '2,3 Cyclic Nucleotide Phosphodiesterase',
#   '2,3 Cyclic Nucleotide Phosphodiesterases',
#   '2,3-Cyclic Nucleotide Phosphodiesterase',
#   '2,3-Cyclic Nucleotide Phosphodiesterases',
#   "2'3' cyclic nucleotide phosphodiesterase",
#   "Nucleotide Phosphodiesterase, 2',3'-Cyclic",
#   'Nucleotide Phosphodiesterase, 2,3-Cyclic',
#   "Phosphodiesterase, 2',3'-Cyclic Nucleotide",
#   'Phosphodiesterase, 2,3-Cyclic Nucleotide',
#   "cyclic 2',3'-nucleotide phosphodiesterase",
#   "Nucleotide Phosphodiesterases, 2',3'-Cyclic",
#   "Phosphodiesterases, 2',3'-Cyclic Nucleotide",
#   "Phosphodiesterases, 2',3'-Cyclic-Nucleotide",
#   'Phosphodiesterases, 2,3-Cyclic Nucleotide',
#   'Nucleotide Phosphodiesterases, 2,3-Cyclic',
#   'CNPase',
#   '2 3 CYCL NPD',
#   'CYCLIC NUCLEOTIDE PHOSPHODIESTERASES 02 03',
#   '2 3 CYCL NUCLEOTIDE PHOSPHODIESTERASE',
#   "2',3'-Cyclic-Nucleotide Phosphodiesterases [Chemical/Ingredient]"],
#  'UMLS:C0000189': ['2-5A Synthetase',
#   "2',5'-Oligoadenylate Synthetase",
#   '2,5 Oligoadenylate Synthetase',
#   "2',5' Oligoadenylate Synthetase",
#   'Oligoadenylate Synthetase, 2,5',
#   'Synthetase, 2,5 Oligoadenylate',
#   "Synthetase, 2',5'-Oligoadenylate",
#   "2',5'-Oligoadenylate Polymerase",
#   '2,5 Oligoadenylate Polymerase',
#   "2',5' Oligoadenylate Polymerase",
#   'Oligoadenylate Polymerase, 2,5',
#   "Polymerase, 2',5'-Oligoadenylate",
#   'Polymerase, 2,5 Oligoadenylate',
#   "ATP-(2'-5')oligo(A)adenylyltransferase",
#   "2',5'-Oligo(A) Synthetase",
#   "2',5'-Oligo(A) Polymerase",
#   "(2'-5')An Polymerase",
#   'OLIGOADENYLATE SYNTHETASE 02 05',
#   'SYNTHETASE 02 05A',
#   'OLIGOADENYLATE POLYMERASE 02 05',
#   "2',5'-Oligoadenylate Synthetase [Chemical/Ingredient]"],
#  'UMLS:C0000190': ["2'-CMP", "2' CMP"],
#  'UMLS:C0000194': ["2,2'-Dipyridyl",
#   '2,2 Dipyridyl',
#   "2,2' Dipyridyl",
#   '2,2-Dipyridyl',
#   'Dipyridyl, 2,2',
#   "Dipyridyl, 2,2'",
#   '2,2-Bipyridine',
#   "2,2'-Bipyridine",
#   '2,2 Bipyridine',
#   "2,2' Bipyridine",
#   '2,2-Bipyridyl',
#   '2,2 Bipyridyl',
#   'alpha,alpha-Dipyridyl',
#   'alpha,alpha Dipyridyl',
#   'DIPYRIDYL',
#   'BIPYRIDINE 02 02',
#   'DIPYRIDYL 02 02',
#   "2,2'-Dipyridyl [Chemical/Ingredient]"],
#  'UMLS:C0000204': ['2,3-Diketogulonic Acid',
#   '2,3 Diketogulonic Acid',
#   'Acid, 2,3-Diketogulonic',
#   'threo-2,3-Hexodiulosonic acid',
#   'DIKETOGULONIC ACID 02 03',
#   '2,3-Diketogulonic Acid [Chemical/Ingredient]'],
#  'UMLS:C0000215': ['2,4,5-Trichlorophenoxyacetic Acid',
#   '2,4,5-Trichlorophenoxyacetic acid',
#   '2,4,5-T',
#   '2,4,5 T',
#   'Trichlorophenoxyacetic acid',
#   'Acetic acid, (2,4,5-trichlorophenoxy)-',
#   '2,4,5-T - 2,4,5-Trichlorophenoxyacetic acid',
#   '2,4,5-Trichlorophenoxacet acid',
#   '2,4,5T - Trichlphenxacetc acid',
#   '2,4,5-Trichlorophenoxyacetic acid -RETIRED-',
#   '2,4,5-Trichlorophenoxyacetic acid (substance)',
#   '2,4,5-trichloroacetophenol (substance)',
#   '2,4,5-trichloroacetophenol',
#   'TRICHLOROPHENOXYACETIC ACID 020405',
#   'T A 02 04 05',
#   '2,4,5-Trichlorophenoxyacetic Acid [Chemical/Ingredient]'],
#  'UMLS:C0000220': ['2,4-Dichlorophenoxyacetic Acid',
#   '2, 4-Dichlorophenoxyacetic acid',
#   '2,4-Dichlorophenoxyacetic acid',
#   '2,4 Dichlorophenoxyacetic Acid',
#   '2,4-D',
#   '2, 4-D',
#   'Acetic acid, (2,4-dichlorophenoxy)-',
#   '2,4-D-2,4-Dichlphenoxacetc acd',
#   '2,4-D - 2,4-Dichlorophenoxyacetic acid',
#   '2,4-Dichlorophenoxyacetic acid (substance)',
#   'DICHLOROPHENOXYACETIC ACID 0204',
#   'D A 002 004',
#   '2,4-Dichlorophenoxyacetic Acid [Chemical/Ingredient]'],
#  'UMLS:C0000232': ['2,6-Dichloroindophenol',
#   '2,6 Dichloroindophenol',
#   'Dichloroindophenol, 2,6',
#   '2,6-Dichlorobenzenoneindophenol Dye',
#   '2,6 Dichlorobenzenoneindophenol Dye',
#   'Dye, 2,6-Dichlorobenzenoneindophenol',
#   '2,6-Dichlorophenolindophenol',
#   '2,6 Dichlorophenolindophenol',
#   'Dichlorophenolindophenol',
#   '2,5-Cyclohexadien-1-one, 2,6-dichloro-4-((4-hydroxyphenyl)imino)-',
#   'Dichlorophenol Indophenol',
#   'Indophenol, Dichlorophenol',
#   'DICHLOROINDOPHENOL 02 06',
#   'DICHLOROPHENOLINDOPHENOL O2 O6',
#   '2,6-Dichloroindophenol [Chemical/Ingredient]'],
#  'UMLS:C0000246': ['2-Acetolactate Mutase',
#   '2-Acetolactate mutase',
#   '2 Acetolactate Mutase',
#   'Mutase, 2-Acetolactate',
#   '2-Acetohydroxy-3-Ketoacid Isomeroreductase',
#   'ACETOHYDROXY KETOACID ISOMEROREDUCTASE 2 3',
#   '2 Acetohydroxy 3 Ketoacid Isomeroreductase',
#   'Isomeroreductase, 2-Acetohydroxy-3-Ketoacid',
#   'Acetohydroxy Acid Reductoisomerase',
#   'Acid Reductoisomerase, Acetohydroxy',
#   'Reductoisomerase, Acetohydroxy Acid',
#   '2-Acetolactate methylmutase',
#   '2-Acetolactate mutase (substance)',
#   'ACETOLACTATE MUTASE 02',
#   '2-Acetolactate Mutase [Chemical/Ingredient]'],
#  'UMLS:C0000248': ['2-Acetylaminofluorene',
#   '2-ACETYLAMINOFLUORENE',
#   '2 Acetylaminofluorene',
#   '2-AAF',
#   '2-Acetamidofluorene',
#   '2 Acetamidofluorene',
#   'Fluoren-2-ylacetamide',
#   'Fluoren 2 ylacetamide',
#   'N-2-Fluorenylacetamide',
#   'N-2-fluorenylacetamide',
#   'N 2 Fluorenylacetamide',
#   '2-Fluorenylacetamide',
#   '2 Fluorenylacetamide',
#   'Acetamide, N-9H-fluoren-2-yl-',
#   '2-FAA',
#   'N-9h-fluoren-2-ylacetamide',
#   'N-Acetyl-2-Aminofluorene',
#   'N Acetyl 2 Aminofluorene',
#   'AAF, Aminofluorene',
#   'Aminofluorene AAF',
#   'ACETAMIDOFLUORENE 02',
#   'FLUORENYLACETAMIDE 02',
#   'ACETYLAMINOFLUORENE 02',
#   '2-Acetylaminofluorene [Chemical/Ingredient]'],
#  'UMLS:C0000254': ['2-Amino-5-phosphonovalerate',
#   '2 Amino 5 phosphonovalerate',
#   '2-Amino-5-phosphonopentanoate',
#   '2 Amino 5 phosphonopentanoate',
#   '2-Amino-5-phosphonopentanoic Acid',
#   '2 Amino 5 phosphonopentanoic Acid',
#   '2-Amino-5-phosphonovaleric Acid',
#   '2 Amino 5 phosphonovaleric Acid',
#   '2-APV',
#   '2 APV',
#   '5-Phosphononorvaline',
#   '5 Phosphononorvaline',
#   'Norvaline, 5-phosphono-',
#   'AMINOPHOSPHONOPENTANOIC ACID 0205',
#   'AMINOPHOSPHONOVALERATE 0205',
#   'AMINOPHOSPHONOVALERIC ACID 0205',
#   '2-Amino-5-phosphonovalerate [Chemical/Ingredient]'],
#  'UMLS:C0000257': ['2-Aminoadipic Acid',
#   '2-Aminoadipic acid',
#   '2 Aminoadipic Acid',
#   'Acid, 2 Aminoadipic',
#   'Acid, 2-Aminoadipic',
#   'Aminoadipic Acid, 2',
#   '2-Aminohexanedioic Acid',
#   '2 Aminohexanedioic Acid',
#   'Acid, 2-Aminohexanedioic',
#   'alpha-Aminoadipic Acid',
#   'alpha-Aminoadipic acid',
#   'Alpha-Aminoadipic Acid',
#   'alpha Aminoadipic Acid',
#   'Acid, alpha-Aminoadipic',
#   'Hexanedioic acid, 2-amino-',
#   'Hexanedioic Acid, 2-Amino-',
#   'Alpha-amino Adipic Acid',
#   'alpha-Aminoadipic acid (substance)',
#   'AMINOADIPIC ACID 02',
#   '2-Aminoadipic Acid [Chemical/Ingredient]'],
#  'UMLS:C0000263': ['2-Aminopurine',
#   '2-aminopurine',
#   '2 Aminopurine',
#   'aminopurine',
#   '1H-Purin-2-amine',
#   'AMINOPURINE 02',
#   '2-Aminopurine [Chemical/Ingredient]'],
#  'UMLS:C0000266': ['Parlodel', 'parlodel'],
#  'UMLS:C0000268': ['2-bromolysergic acid diethylamide',
#   '2 bromolysergic acid diethylamide',
#   '2-bromolysergic diethylamide',
#   'bromo-LSD',
#   'BOL',
#   'bol',
#   'Ergoline-8-carboxamide, 2-bromo-9,10-didehydro-N,N-diethyl-6-methyl-, (8beta)-'],
#  'UMLS:C0000275': ['2-Chloroadenosine',
#   '2 Chloroadenosine',
#   'Adenosine, 2-chloro-',
#   'CHLOROADENOSINE 02',
#   '2-Chloroadenosine [Chemical/Ingredient]'],
#  'UMLS:C0000287': ['2-Hydroxy-5-nitrobenzyl Bromide',
#   '2 Hydroxy 5 nitrobenzyl Bromide',
#   "Koshland's Reagent I",
#   'Koshland Reagent I',
#   'Koshlands Reagent I',
#   "Reagent I, Koshland's",
#   'Koshlands Reagent',
#   'Koshland Reagent',
#   'Reagent, Koshland',
#   'Reagent, Koshlands',
#   'Phenol, 2-(bromomethyl)-4-nitro-',
#   'KOSHLANDS REAGENT 01',
#   'HYDROXYNITROBENZYL BROMIDE 02 05',
#   '2-Hydroxy-5-nitrobenzyl Bromide [Chemical/Ingredient]'],
#  'UMLS:C0000289': ['2-Hydroxyphenethylamine',
#   '2 Hydroxyphenethylamine',
#   '2-Phenylethanolamine',
#   '2 Phenylethanolamine',
#   'beta-Hydroxyphenethylamine',
#   'beta Hydroxyphenethylamine',
#   'beta-Phenylethanolamine',
#   'beta Phenylethanolamine',
#   'Bisnorephedrine',
#   'Benzenemethanol, alpha-(aminomethyl)-',
#   'HYDROXYPHENETHYLAMINE 02',
#   'PHENYLETHANOLAMINE A 02',
#   '2-Hydroxyphenethylamine [Chemical/Ingredient]'],
#  'UMLS:C0000291': ['2-Isopropylmalate Synthase',
#   '2-Isopropylmalate synthase',
#   '2 Isopropylmalate Synthase',
#   'Synthase, 2-Isopropylmalate',
#   'alpha-Isopropylmalate Synthase',
#   'alpha Isopropylmalate Synthase',
#   'Synthase, alpha-Isopropylmalate',
#   '3-Carboxy-3-hydroxy-4-methylpentanoate 3-methyl-2-oxobutanoate-lyase (CoA-acetylating)',
#   '2-Isopropylmalate synthase (substance)',
#   'ISOPROPYLMALATE SYNTHASE 02',
#   '2-Isopropylmalate Synthase [Chemical/Ingredient]'],
#  'UMLS:C0000294': ['Mesna',
#   'mesna',
#   'MESNA',
#   'Ethanesulfonic acid, 2-mercapto-, monosodium salt',
#   'Sodium 2-Mercaptoethanesulphonate',
#   '2-Mercaptoethanesulphonate, Sodium',
#   '2-mercaptoethane sulfonate Na',
#   'Mesna (product)',
#   'Mesna (substance)',
#   'MSA',
#   '2-Mercaptoethanesulfonic Acid Sodium Salt',
#   '2-Mercaptoethanesulfonate, Sodium Salt',
#   'Sodium 2-Mercaptoethane Sulfonate',
#   'mesna (medication)',
#   'Mesna [Chemical/Ingredient]'],
#  'UMLS:C0000300': ['2-Naphthylamine',
#   '2 Naphthylamine',
#   '2-Aminonaphthalene',
#   '2 Aminonaphthalene',
#   'beta-Naphthylamine',
#   'Beta-naphthylamine',
#   'beta Naphthylamine',
#   '2-Naphthalenamine',
#   'b- Naphthylamine',
#   'b-Naphthylamine',
#   '2-Naphthylamine (substance)',
#   'Fast Scarlet Base B',
#   'NAPHTHYLAMINE 02',
#   'AMINONAPHTHALENE 02',
#   '2-Naphthylamine [Chemical/Ingredient]'],
#  'UMLS:C0000324': ['20-Hydroxysteroid Dehydrogenases',
#   'HYDROXYSTEROID DEHYDROGENASES 20',
#   '20 Hydroxysteroid Dehydrogenases',
#   'Dehydrogenases, 20 Hydroxysteroid',
#   'Dehydrogenases, 20-Hydroxysteroid',
#   'Hydroxysteroid Dehydrogenases, 20',
#   '20-Hydroxysteroid Dehydrogenases [Chemical/Ingredient]'],
#  'UMLS:C0000325': ['20-Methylcholanthrene',
#   '20 Methylcholanthrene',
#   'Methylcholanthrene',
#   'MCA',
#   '3-Methylcholanthrene',
#   '3 Methylcholanthrene',
#   '1,2-Dihydro-3-methyl-benz(j)aceanthrylene'],
#  'UMLS:C0000334': ['24,25-Dihydroxyvitamin D 3',
#   '24 25 DIHYDROXYVITAMIN D 3',
#   '24,25 Dihydroxyvitamin D 3',
#   '24,25-Dihydroxyvitamin D>3<',
#   '24,25-Dihydroxyvitamin D3',
#   'DIHYDROXYVITAMIN D3 24 25',
#   '24,25 Dihydroxyvitamin D3',
#   'Dihydroxyvitamin D3, 24,25',
#   '24,25-Dihydroxycholecalciferol',
#   '24,25 Dihydroxycholecalciferol',
#   '9,10-Secocholesta-5,7,10(19)-triene-3,24,25-triol, (3beta,5Z,7E)-',
#   '(3beta,5Z,7E)-9,10-Secocholesta-5,7,10(19)-Triene-3,24,25-Triol',
#   '24,25-Dihydroxy cholecalciferol',
#   '24, 25-Dihydroxy cholecalciferol',
#   '24,25-DHCC - 24,25-Dihydroxycholecalciferol',
#   '24,25-DHCC-24,25-DiOHcholecalc',
#   '24,25-diOHCCC - 24,25-Dihydroxycholecalciferol',
#   '24,25diOHCCC-2425DiOHcholecalc',
#   '24R-Dihydroxycalcidiol',
#   '24,25(OH)2 D3',
#   '24,25-Dihydroxyvitamin D',
#   '24,25-Hydroxy Vitamin D3',
#   '9,10-Secocholesta-5,7,10(19)-Triene-3,24,25-Triol, (3-beta,5Z,7E)-',
#   '24,25(OH)(2)D',
#   '24,25-Dihydroxyvitamin D<sub>3</sub>',
#   '24,25-Dihydroxy cholecalciferol (substance)',
#   '24,25-Dihydroxyvitamin D3 (substance)',
#   'DIHYDROXYCHOLECALCIFEROL 024 025',
#   '24,25-Dihydroxyvitamin D 3 [Chemical/Ingredient]'],
#  'UMLS:C0000340': ['Calcidiol 1-Monooxygenase',
#   'Calcidiol 1-monooxygenase',
#   'Calcidiol 1 Monooxygenase',
#   '25-Hydroxycholecalciferol 1-Hydroxylase',
#   '25 Hydroxycholecalciferol-1-hydroxylase',
#   '25-Hydroxycholecalciferol 1-hydroxylase',
#   '25 Hydroxycholecalciferol 1 Hydroxylase',
#   '25-Hydroxycholecalciferol-1-Hydroxylase',
#   '25-Hydroxyvitamin D(3) 1 alpha-Hydroxylase',
#   '25-Hydroxyvitamin D2 1-hydroxylase',
#   '25 Hydroxyvitamin D2 1 hydroxylase',
#   '1-hydroxylase, 25-Hydroxyvitamin D2',
#   '25-Hydroxyvitamin D3 1-alpha-Hydroxylase',
#   '25 Hydroxyvitamin D3 1 alpha Hydroxylase',
#   'Calcidiol,NADPH:oxygen oxidoreductase (1-hydroxylating)',
#   '25-Hydroxycholecalciferol 1-mono-oxygenase',
#   'Cytochrome P-450 CYP27B1',
#   'Cytochrome P 450 CYP27B1',
#   'CYP27B1',
#   '25-Hydroxyvitamin D 1-alpha-Hydroxylase',
#   '25 Hydroxyvitamin D 1 alpha Hydroxylase',
#   '1-alpha-Hydroxylase, 25-Hydroxyvitamin D',
#   '25-Hydroxyergocalciferol 1-alpha-Hydroxylase',
#   '25 Hydroxyergocalciferol 1 alpha Hydroxylase',
#   '1-alpha-Hydroxylase, 25-Hydroxyergocalciferol',
#   'Calcidiol 1-monooxygenase (substance)',
#   'CALCIDIOL MONOOXYGENASE 01',
#   'CYP 027 B 001',
#   'HYDROXYVITAMIN D 03 25 HYDROXYLASE 01 ALPHA',
#   'CYTOCHROME P 450 CYP 027 B 001',
#   'HYDROXYCHOLECALCIFEROL HYDROXYLASE 25 01',
#   '25-Hydroxyvitamin D3 1-alpha-Hydroxylase [Chemical/Ingredient]'],
#  'UMLS:C0000343': ['25-Hydroxyvitamin D 2',
#   '25 Hydroxyvitamin D 2',
#   '25-Hydroxyvitamin D>2<',
#   '25-Hydroxycalciferol',
#   '25 Hydroxycalciferol',
#   '25-Hydroxyergocalciferol',
#   '25 Hydroxyergocalciferol',
#   '9,10-Secoergosta-5,7,10(19),22-tetraene-3 beta,25-diol',
#   'Ercalcidiol',
#   '25-Hydroxyvitamin D2',
#   '25 Hydroxyvitamin D2',
#   '9,10-Secoergosta-5,7,10(19),22-tetraene-3,25-diol, (3beta,5Z,7E,22E)-',
#   '25-Hydroxy ergocalciferol',
#   '25-Hydroxyvitamin D<sub>2</sub>',
#   '25-Hydroxy ergocalciferol (substance)',
#   'HYDROXYERGOCALCIFEROL 025',
#   'HYDROXYVITAMIN D 02 25',
#   '25-Hydroxyvitamin D 2 [Chemical/Ingredient]'],
#  'UMLS:C0000353': ['3 alpha,20 beta Hydroxysteroid Dehydrogenase'],
#  'UMLS:C0000359': ["3',5'-Cyclic-Nucleotide Phosphodiesterase",
#   "3',5'-Cyclic-nucleotide phosphodiesterase",
#   "3'5' cyclic nucleotide phosphodiesterase",
#   "3',5'-Cyclic Nucleotide Phosphodiesterase",
#   "3',5' Cyclic Nucleotide Phosphodiesterase",
#   "Nucleotide Phosphodiesterase, 3',5'-Cyclic",
#   "Phosphodiesterase, 3',5'-Cyclic Nucleotide",
#   "Phosphodiesterase, 3',5'-Cyclic-Nucleotide",
#   "3',5'-Cyclic AMP 5'-Nucleotidohydrolase",
#   '3,5 Cyclic AMP 5 Nucleotidohydrolase',
#   '3,5-Cyclic AMP 5-Nucleotidohydrolase',
#   "3',5' Cyclic AMP 5' Nucleotidohydrolase",
#   "5'-Nucleotidohydrolase, 3',5'-Cyclic AMP",
#   '5-Nucleotidohydrolase, 3,5-Cyclic AMP',
#   "AMP 5'-Nucleotidohydrolase, 3',5'-Cyclic",
#   'AMP 5-Nucleotidohydrolase, 3,5-Cyclic',
#   "3',5'-Cyclic-AMP Phosphodiesterases",
#   "3',5' Cyclic AMP Phosphodiesterase",
#   "3',5'-Cyclic AMP Phosphodiesterase",
#   '3,5 Cyclic AMP Phosphodiesterase',
#   '3,5-Cyclic AMP Phosphodiesterase',
#   "3',5'-Cyclic-AMP Phosphodiesterase",
#   "AMP Phosphodiesterase, 3',5'-Cyclic",
#   'AMP Phosphodiesterase, 3,5-Cyclic',
#   "Phosphodiesterase, 3',5'-Cyclic AMP",
#   'Phosphodiesterase, 3,5-Cyclic AMP',
#   "Phosphodiesterase, 3',5'-Cyclic-AMP",
#   "3',5' Cyclic AMP Phosphodiesterases",
#   "Phosphodiesterases, 3',5'-Cyclic-AMP",
#   "3',5'-Nucleotide Phosphodiesterase",
#   "3',5' Nucleotide Phosphodiesterase",
#   "Phosphodiesterase, 3',5'-Nucleotide",
#   'CAMP Phosphodiesterase',
#   'Phosphodiesterase, CAMP',
#   "3',5'-Cyclic-nucleotide 5'-nucleotidohydrolase",
#   "3',5'-Cyclic-nucleotide phosphodiesterase (substance)",
#   'CYCL AMP PHOSPHODIESTERASE',
#   'CYCLIC AMP NUCLEOTIDOHYDROLASE 03 05 05',
#   '3 5 CYCL NPD',
#   'CYCLIC NUCLEOTIDE PHOSPHODIESTERASE 03 05',
#   'CYCLIC AMP PHOSPHODIESTERASE 03 05',
#   "3',5'-Cyclic-AMP Phosphodiesterases [Chemical/Ingredient]"],
#  'UMLS:C0000360': ["3',5'-Cyclic-GMP Phosphodiesterases",
#   "3',5' Cyclic GMP Phosphodiesterase",
#   "3',5'-Cyclic GMP Phosphodiesterase",
#   '3,5 Cyclic GMP Phosphodiesterase',
#   '3,5-Cyclic GMP Phosphodiesterase',
#   "3',5'-Cyclic-GMP Phosphodiesterase",
#   "3',5'-Cyclic-GMP phosphodiesterase",
#   "Phosphodiesterase, 3',5'-Cyclic GMP",
#   "Phosphodiesterase, 3',5'-Cyclic-GMP",
#   'Phosphodiesterase, 3,5-Cyclic GMP',
#   "GMP Phosphodiesterase, 3',5'-Cyclic",
#   'GMP Phosphodiesterase, 3,5-Cyclic',
#   "3',5' Cyclic GMP Phosphodiesterases",
#   "Phosphodiesterases, 3',5'-Cyclic-GMP",
#   "3',5'-Cyclic GMP 5'-Nucleotidohydrolase",
#   "3',5'-Cyclic-GMP 5'-nucleotidohydrolase",
#   '3,5 Cyclic GMP 5 Nucleotidohydrolase',
#   '3,5-Cyclic GMP 5-Nucleotidohydrolase',
#   "3',5' Cyclic GMP 5' Nucleotidohydrolase",
#   '5-Nucleotidohydrolase, 3,5-Cyclic GMP',
#   "GMP 5'-Nucleotidohydrolase, 3',5'-Cyclic",
#   'GMP 5-Nucleotidohydrolase, 3,5-Cyclic',
#   "5'-Nucleotidohydrolase, 3',5'-Cyclic GMP",
#   "3',5'-cyclic-guanosine monophosphate phosphodiesterase (substance)",
#   "3',5'-cyclic-guanosine monophosphate phosphodiesterase",
#   "3',5'-Cyclic-GMP phosphodiesterase (substance)",
#   'CYCL GMP PHOSPHODIESTERASE',
#   'CYCLIC GMP NUCLEOTIDOHYDROLASE 03 05 05',
#   'CYCLIC GMP PHOSPHODIESTERASES 03 05',
#   "3',5'-Cyclic-GMP Phosphodiesterases [Chemical/Ingredient]"],
#  'UMLS:C0000364': ["3'-CMP", "3' CMP"],
#  'UMLS:C0000368': ["3,3'-Diaminobenzidine",
#   '3,3 Diaminobenzidine',
#   "3,3' Diaminobenzidine",
#   '3,3-Diaminobenzidine',
#   'Diaminobenzidine, 3,3',
#   "Diaminobenzidine, 3,3'",
#   "(1,1'-Biphenyl)-3,3',4,4'-tetramine",
#   'DIAMINOBENZIDINE 03 03',
#   "3,3'-Diaminobenzidine [Chemical/Ingredient]"],
#  'UMLS:C0000370': ['3,3-Dichlorobenzidine',
#   "3,3'-DICHLOROBENZIDINE",
#   '3,3 Dichlorobenzidine',
#   "3,3' Dichlorobenzidine",
#   "3,3'-Dichlorobenzidine",
#   "3-3'Dichlorobenzidine",
#   "(1,1'-Biphenyl)-4,4'-diamine, 3,3'-dichloro-",
#   '3,3-Dichloro-(1,1-Biphenyl)-4,4-Diamine',
#   'DCB',
#   "3-3'Dichlorobenzidine (substance)",
#   'Curithane C126',
#   "3-3' Dichloro benzidine",
#   'DICHLOROBENZIDINE 03 03',
#   "3,3'-Dichlorobenzidine [Chemical/Ingredient]"],
#  'UMLS:C0000376': ['3,4-Dihydroxyphenylacetic Acid',
#   '3,4-dihydroxyphenylacetic acid',
#   '3,4 Dihydroxyphenylacetic Acid',
#   'DOPAC',
#   'Homoprotocatechuic Acid',
#   'homoprotocatechuic acid',
#   'Benzeneacetic acid, 3,4-dihydroxy-',
#   'Dihydroxyphenylacetic acid',
#   'Dihydroxyphenylacetic Acid',
#   'dihydroxyphenylacetic acid',
#   'DOPAC - Dihydroxyphenylacetic acid',
#   'Dihydroxyphenylacetic acid (substance)',
#   'DIHYDROXYPHENYLACETIC ACID 03 04',
#   '3,4-Dihydroxyphenylacetic Acid [Chemical/Ingredient]'],
#  'UMLS:C0000378': ['Droxidopa',
#   'droxidopa',
#   'DROXIDOPA',
#   '3,4-threo-DOPS',
#   '3,4 threo DOPS',
#   'DL-threo-3,4-Dihydroxyphenylserine',
#   'DL threo 3,4 Dihydroxyphenylserine',
#   'DOPS',
#   'threo-DOPS',
#   'threo DOPS',
#   'L-Tyrosine, beta,3-dihydroxy-, threo-',
#   'vasopressors droxidopa',
#   'Droxidopa (medication)',
#   'L-Dihydroxyphenylserine',
#   'L-threo 3,4 dihydroxyphenylserine',
#   'L-threo-dihydroxyphenylserine',
#   'Droxidopa (product)',
#   'Droxidopa (substance)',
#   'Droxidopa [Chemical/Ingredient]',
#   '(-)-(2S,3R)-2-amino-3-(3,4-dihydroxyphenyl)-3-hydroxypropanoic Acid',
#   'L-DOPS'],
#  'UMLS:C0000379': ['3,4-Methylenedioxyamphetamine',
#   '3,4 methylenedioxyamphetamine',
#   '3,4-methylenedioxyamphetamine',
#   '3,4 Methylenedioxyamphetamine',
#   'MDA',
#   'mda',
#   'Methylenedioxyamphetamine',
#   'methylenedioxyamphetamine',
#   '1,3-Benzodioxole-5-ethanamine, alpha-methyl-',
#   'Alpha-Methyl-1,3-benzodioxole-5-ethanamine',
#   'Methylenedioxyamphetamine (substance)',
#   'METHYLENEDIOXYAMPHETAMINE 03 04',
#   '3,4-Methylenedioxyamphetamine [Chemical/Ingredient]',
#   'Tenamfetamine',
#   'TENAMFETAMINE',
#   '3,4-Methylenedioxyamphetamine (MDA)'],
#  'UMLS:C0000392': ['beta-Alanine',
#   'beta alanine',
#   'beta-alanine',
#   'BETA-ALANINE',
#   'Beta-Alanine',
#   'Beta alanine',
#   'beta Alanine',
#   '3-Aminopropionic Acid',
#   '3 Aminopropionic Acid',
#   'beta Alanine (substance)',
#   'AMINOPROPIONIC ACID 03',
#   'beta-Alanine [Chemical/Ingredient]'],
#  'UMLS:C0000399': ['3-Deazauridine',
#   '3-deazauridine',
#   '3-DEAZAURIDINE',
#   '3 Deazauridine',
#   '4-Hydroxy-1-(beta-D-Ribopentofuranosyl)-2-Pyridone',
#   '4-hydroxy-1-(beta-D-ribopentofuranosyl)-2-pyridone',
#   '2(1H)-Pyridinone, 4-hydroxy-1-beta-D-ribofuranosyl-',
#   '2(1H)-pyridinone, 4-hydroxy-1-beta-D-ribofuranosyl',
#   'deazauridine',
#   'Deazauridine',
#   'DAU',
#   'DEAZAURIDINE 03',
#   '3-Deazauridine [Chemical/Ingredient]'],
#  'UMLS:C0000402': ['Meglutol',
#   'meglutol',
#   '3-Hydroxy-3-methylglutaric Acid',
#   '3 Hydroxy 3 methylglutaric Acid',
#   'Acid, 3-Hydroxy-3-methylglutaric',
#   'Pentanedioic acid, 3-hydroxy-3-methyl-',
#   'beta-Hydroxy-beta-Methylglutarate',
#   'beta Hydroxy beta Methylglutarate',
#   '3-Hydroxy-3-methylpentanedioic Acid',
#   '3 Hydroxy 3 methylpentanedioic Acid',
#   'Acid, 3-Hydroxy-3-methylpentanedioic',
#   'HYDROXYMETHYLGLUTARIC ACID 03 03',
#   'Meglutol [Chemical/Ingredient]'],
#  'UMLS:C0000403': ['3-Hydroxy-N-methylmorphinan',
#   '3 Hydroxy N methylmorphinan'],
#  'UMLS:C0000404': ['3-Hydroxyacyl CoA Dehydrogenases',
#   '3 Hydroxyacyl CoA Dehydrogenases',
#   '3-Hydroxyacyl-CoA Dehydrogenase',
#   '3-Hydroxyacyl CoA Dehydrogenase',
#   'CoA Dehydrogenases, 3-Hydroxyacyl',
#   'Dehydrogenases, 3-Hydroxyacyl CoA',
#   'Beta--Hydroxyacyl CoA Dehydrogenase',
#   'Beta-Hydroxyacyl CoA Dehydrogenase',
#   'beta-Hydroxyacyl Dehydrogenases',
#   'beta Hydroxyacyl Dehydrogenases',
#   'Beta--Hydroxyacyl Dehydrogenase',
#   'Beta-Hydroxyacyl Dehydrogenase',
#   'Dehydrogenases, beta-Hydroxyacyl',
#   'Beta--Keto-Reductase',
#   'Beta-Keto-Reductase',
#   'Beta--Ketoacyl-CoA Reductase',
#   'Beta-Ketoacyl-CoA Reductase',
#   '3-Hydroxyisobutyryl-CoA Dehydrogenase',
#   '(S)-3-Hydroxyacyl-CoA:NAD+ Oxidoreductase',
#   '3-Hydroxybutyryl-CoA Dehydrogenase',
#   '3-Hydroxyacyl Coenzyme A Dehydrogenase',
#   '3-Hydroxyacetyl-Coenzyme A Dehydrogenase',
#   'L-3-Hydroxyacyl Coenzyme A Dehydrogenase',
#   'Beta--Hydroxyacylcoenzyme A Dehydrogenase',
#   'Beta-Hydroxyacylcoenzyme A Dehydrogenase',
#   '3Beta--Hydroxyacyl Coenzyme A Dehydrogenase',
#   '3Beta-Hydroxyacyl Coenzyme A Dehydrogenase',
#   'Beta--Hydroxyacyl-Coenzyme A Synthetase',
#   'Beta-Hydroxyacyl-Coenzyme A Synthetase',
#   '1-Specific DPN-Linked Beta--Hydroxybutyric Dehydrogenase',
#   '3-L-Hydroxyacyl-CoA Dehydrogenase',
#   'L-3-Hydroxyacyl CoA Dehydrogenase',
#   '3-Hydroxyl-Co-A Dehydrogenase',
#   '3-Keto Reductase',
#   'Beta--Hydroxy Acid Dehydrogenase',
#   'Beta-Hydroxy Acid Dehydrogenase',
#   'Beta--Hydroxybutyrylcoenzyme A Dehydrogenase',
#   'Beta-Hydroxybutyrylcoenzyme A Dehydrogenase',
#   'EC 1.1.1.35',
#   '3-Hydroxyacyl CoA Dehydrogenases [Chemical/Ingredient]'],
#  'UMLS:C0000407': ['3-Hydroxyanthranilic Acid',
#   '3-Hydroxyanthranilic acid',
#   '3 Hydroxyanthranilic Acid',
#   'Acid, 3-Hydroxyanthranilic',
#   'Benzoic acid, 2-amino-3-hydroxy-',
#   'HYDROXYANTHRANILIC ACID 03',
#   '3-Hydroxyanthranilic Acid [Chemical/Ingredient]'],
#  'UMLS:C0000412': ['3-hydroxyproline', '3-Hydroxyproline'],
#  'UMLS:C0000413': ['3-Hydroxysteroid Dehydrogenases',
#   '3 Hydroxysteroid Dehydrogenases',
#   '3-hydroxysteroid dehydrogenase',
#   'Dehydrogenases, 3 Hydroxysteroid',
#   'Dehydrogenases, 3-Hydroxysteroid',
#   'Hydroxysteroid Dehydrogenases, 3',
#   '3-beta-Hydroxysteroid Dehydrogenase',
#   '3-Beta Hydroxysteroid dehydrogenase',
#   '3 beta Hydroxysteroid Dehydrogenase',
#   'Dehydrogenase, 3-beta-Hydroxysteroid',
#   'BETA HYDROXYSTEROID DEHYDROGENASE A 03',
#   'HYDROXYSTEROID DEHYDROGENASES 03',
#   '3-Hydroxysteroid Dehydrogenases [Chemical/Ingredient]'],
#  'UMLS:C0000424': ['3-Mercaptopropionic Acid',
#   '3 Mercaptopropionic Acid',
#   'Acid, 3-Mercaptopropionic',
#   '3-Mercaptopropanoic Acid',
#   '3 Mercaptopropanoic Acid',
#   'Acid, 3-Mercaptopropanoic',
#   'Propanoic acid, 3-mercapto-',
#   'MERCAPTOPROPIONIC ACID 03',
#   'MERCAPTOPROPANOIC ACID 03',
#   '3-Mercaptopropionic Acid [Chemical/Ingredient]'],
#  'UMLS:C0000427': ['3-Methoxy-4-hydroxyphenylethanol',
#   '3 Methoxy 4 hydroxyphenylethanol',
#   'Hydroxymethoxyphenethyl Alcohol',
#   'Alcohol, Hydroxymethoxyphenethyl',
#   'MHPE',
#   'MOPET',
#   'Methoxyhydroxyphenylethanol',
#   'Benzeneethanol, 4-hydroxy-3-methoxy-',
#   'METHOXYHYDROXYPHENYLETHANOL 03 04',
#   '3-Methoxy-4-hydroxyphenylethanol [Chemical/Ingredient]'],
#  'UMLS:C0000435': ['3-Oxoacyl-(Acyl-Carrier-Protein) Synthase',
#   '3-Oxoacyl-acyl-carrier-protein synthase',
#   '3 Oxoacyl (Acyl Carrier Protein) Synthase',
#   '3-Oxoacyl (Acyl Carrier Protein) Synthase',
#   '3-Keto-ACP Synthase',
#   '3 Keto ACP Synthase',
#   'Synthase, 3-Keto-ACP',
#   '3-Oxoacyl Synthetase',
#   '3 Oxoacyl Synthetase',
#   'Synthetase, 3-Oxoacyl',
#   'beta Keto Acyl Synthetase',
#   'Acyl-Malonyl-ACP Condensing Enzyme',
#   'Acyl Malonyl ACP Condensing Enzyme',
#   'Condensing Enzyme, Acyl-Malonyl-ACP',
#   'beta Ketoacyl ACP Synthase',
#   'Acyl-(acyl carrier protein):malonyl-(acyl-carrier-protein) C-acyltransferase (decarboxylating)',
#   'beta-Ketoacyl-Coenzyme A (CoA) Synthase',
#   '3-Oxoacyl-acyl-carrier-protein synthase (substance)',
#   'OXOACYL ACP SYNTHASE',
#   'OXOACYL ACYL CARRIER PROTEIN SYNTHASE 03',
#   '3-Oxoacyl-(Acyl-Carrier-Protein) Synthase [Chemical/Ingredient]'],
#  'UMLS:C0000464': ['Docosahexaenoate'],
#  'UMLS:C0000473': ['4-Aminobenzoic Acid',
#   '4-Aminobenzoic acid',
#   '4-aminobenzoic acid',
#   '4 Aminobenzoic Acid',
#   'Aminobenzoic acid',
#   'Aminobenzoic Acid',
#   'AMINOBENZOIC ACID',
#   'aminobenzoic acid',
#   'p-Aminobenzoic Acid',
#   'AMINOBENZOIC ACID P',
#   'p-Aminobenzoic acid',
#   'p-aminobenzoic acid',
#   'p Aminobenzoic Acid',
#   'PABA',
#   'paba',
#   'para-Aminobenzoic Acid',
#   'Para-aminobenzoic acid',
#   'PARA-AMINOBENZOIC ACID',
#   'para aminobenzoic acid',
#   'Para-Aminobenzoic Acid',
#   'para-aminobenzoic acid',
#   'para Aminobenzoic Acid',
#   'Benzoic acid, 4-amino-',
#   'Anticanitic vitamin',
#   'Chromotrichia factor',
#   'Trichochromogenic factor',
#   'Aminobenzoic Acid (USP)',
#   'Vitamin B>x<',
#   'Vitamin B x',
#   'Para-aminobenzoic acid (product)',
#   'para-aminobenzoic acid product',
#   'Para-aminobenzoic acid (substance)',
#   'Vitamin B<sub>x</sub>',
#   'paraaminobenzoic acid',
#   'AMINOBENZOIC ACID A 04',
#   'aminobenzoic acid (Pabirin)',
#   '4-Aminobenzoic Acid [Chemical/Ingredient]',
#   'aminobenzoic acid (medication)'],
#  'UMLS:C0000477': ['dalfampridine',
#   'Dalfampridine',
#   'DALFAMPRIDINE',
#   '4-Aminopyridine',
#   '4 aminopyridine',
#   '4-aminopyridine',
#   '4 Aminopyridine',
#   'Pymadine',
#   '4-Pyridinamine',
#   'dalfampridine (medication)',
#   'P-Aminopyridine',
#   'gamma-Aminopyridine',
#   'Fampridina',
#   '4-Pyridylamine',
#   'Fampridinum',
#   'FAMPRIDINE (4-AMINOPYRIDINE)',
#   '4-Aminopyridine (substance)',
#   '4-Aminopyridine (product)',
#   'Fampridine',
#   'fampridine',
#   'FAMPRIDINE',
#   '4-AP',
#   'AMINOPYRIDINE 04',
#   '4-Aminopyridine [Chemical/Ingredient]',
#   'cns stimulants dalfampridine'],
#  'UMLS:C0000481': ['4-Butyrolactone',
#   '4 Butyrolactone',
#   '1,4-Butanolide',
#   '1,4 Butanolide',
#   '4-Hydroxybutyric Acid Lactone',
#   '4 Hydroxybutyric Acid Lactone',
#   'Lactone, 4-Hydroxybutyric Acid',
#   'gamma-Butyrolactone',
#   'gamma butyrolactone',
#   'gamma-butyrolactone',
#   'gamma Butyrolactone',
#   'Dihydro-2(3H)-furanone',
#   '2(3H)-Furanone, dihydro-',
#   'Furanone, tetrahydro-2-',
#   'Furanone, tetrahydro 2',
#   'BUTYROLACTONE 04',
#   'BUTANOLIDE 01 04',
#   'HYDROXYBUTYRIC ACID LACTONE 04',
#   '4-Butyrolactone [Chemical/Ingredient]'],
#  'UMLS:C0000488': ['4-Epitetracycline', '4 Epitetracycline'],
#  'UMLS:C0000490': ['4-Fluorophenylalanine', '4 Fluorophenylalanine'],
#  'UMLS:C0000498': ['4-Hydroxyaminoquinoline-1-oxide',
#   '4 Hydroxyaminoquinoline 1 oxide',
#   '4-Hydroxyaminoquinoline-N-oxide',
#   '4 Hydroxyaminoquinoline N oxide',
#   '4-Quinolinamine, N-hydroxy-, 1-oxide',
#   'HYDROXYAMINOQUINOLINE N OXIDE 04',
#   'HYDROXYAMINOQUINOLINE A OXIDE 04 01',
#   '4-Hydroxyaminoquinoline-1-oxide [Chemical/Ingredient]'],
#  'UMLS:C0000500': ['4-Hydroxybenzoate 3-monooxygenase',
#   '4 Hydroxybenzoate 3 Monooxygenase',
#   '4-Hydroxybenzoate-3-Monooxygenase',
#   'para-Hydroxybenzoate Hydroxylase',
#   'para Hydroxybenzoate Hydroxylase',
#   'Hydroxylase, para-Hydroxybenzoate',
#   '4-hydroxybenzoate 3-hydroxylase',
#   'p-Hydroxybenzoate Hydroxylase',
#   'HYDROXYBENZOATE HYDROXYLASE P',
#   'p-Hydroxybenzoate hydroxylase',
#   'p Hydroxybenzoate Hydroxylase',
#   'Hydroxylase, p-Hydroxybenzoate',
#   '4-Hydroxybenzoate,NADPH:oxygen oxidoreductase (3-hydroxylating)',
#   '4-hydroxybenzoate 3-monooxygenase (reduced nicotinamide adenine dinucleotide phosphate) (substance)',
#   '4-hydroxybenzoate 3-monooxygenase (reduced nicotinamide adenine dinucleotide phosphate)',
#   '4-hydroxybenzoate 3-monooxygenase (NAD(P)H)',
#   '4-hydroxybenzoate 3-monooxygenase (NAD(P)H) (substance)',
#   '4-Hydroxybenzoate 3-monooxygenase (substance)',
#   'HYDROXYBENZOATE MONOOXYGENASE 04 03',
#   '4-Hydroxybenzoate-3-Monooxygenase [Chemical/Ingredient]'],
#  'UMLS:C0000503': ['gamma hydroxybutyrate',
#   'gamma-Hydroxybutyrate',
#   'gamma Hydroxybutyrate',
#   'Gamma-hydroxybutyrate',
#   'Gamma hydroxybutyrate',
#   'gamma-hydroxybutyrate',
#   '4-Hydroxybutyrate',
#   '4-hydroxybutyrate',
#   '4-hydroxybutanoate',
#   '4-Hydroxybutanoate',
#   '4-Hydroxybutyrate (substance)',
#   'gamma-Hydroxybutyrate (substance)',
#   'GHB',
#   'ghb'],
#  'UMLS:C0000506': ['4-Hydroxycoumarins',
#   '4-hydroxycoumarins',
#   '4 Hydroxycoumarins',
#   'HYDROXYCOUMARINS 04',
#   '4-Hydroxycoumarins [Chemical/Ingredient]'],
#  'UMLS:C0000507': ['4-Hydroxyphenylpyruvate Dioxygenase',
#   '4 hydroxyphenylpyruvate dioxygenase',
#   '4-Hydroxyphenylpyruvate dioxygenase',
#   'Dioxygenase, 4-Hydroxyphenylpyruvate',
#   'para-Hydroxyphenylpyruvate Hydroxylase',
#   'para Hydroxyphenylpyruvate Hydroxylase',
#   'Hydroxylase, para-Hydroxyphenylpyruvate',
#   'para-Hydroxyphenylpyruvate Oxidase',
#   'para Hydroxyphenylpyruvate Oxidase',
#   'Oxidase, para-Hydroxyphenylpyruvate',
#   'P-Hydroxyphenylpyruvate Hydroxylase',
#   'HYDROXYPHENYLPYRUVATE HYDROXYLASE P',
#   'P Hydroxyphenylpyruvate Hydroxylase',
#   'Hydroxylase, P-Hydroxyphenylpyruvate',
#   'P-Hydroxyphenylpyruvate Oxidase',
#   'HYDROXYPHENYLPYRUVATE OXIDASE P',
#   'p-Hydroxyphenylpyruvate oxidase',
#   'P Hydroxyphenylpyruvate Oxidase',
#   'Oxidase, P-Hydroxyphenylpyruvate',
#   '4-Hydroxyphenylpyruvate:oxygen oxidoreductase (hydroxylating, decarboxylating)',
#   '4-Hydroxyphenylpyruvate dioxygenase (substance)',
#   'HYDROXYPHENYLPYRUVATE DIOXYGENASE 04',
#   '4-Hydroxyphenylpyruvate Dioxygenase [Chemical/Ingredient]'],
#  'UMLS:C0000511': ['4-Nitroquinoline-1-oxide',
#   '4-nitroquinoline 1-oxide',
#   '4-Nitroquinoline-1-Oxide',
#   '4 Nitroquinoline 1 oxide',
#   '4-Nitroquinoline-N-oxide',
#   '4 nitroquinoline N oxide',
#   '4 Nitroquinoline N oxide',
#   '4-Nitroquinoline N-oxide',
#   'Quinoline, 4-nitro-, 1-oxide',
#   'NITROQUINOLINE A OXIDE 04 01',
#   'NITROQUINOLINE N OXIDE 04',
#   '4-Nitroquinoline-1-oxide [Chemical/Ingredient]',
#   '4-NQO'],
#  'UMLS:C0000523': ['5 beta-Dihydrotestosterone', '5 beta Dihydrotestosterone'],
#  'UMLS:C0000530': ["5'-NUCLEOTIDASE",
#   "5' Nucleotidase",
#   "5'-Nucleotidase",
#   "5' nucleotidase",
#   '5-Nucleotidase',
#   "5'-nucleotidase",
#   '5 nucleotidase',
#   '5-nucleotidase',
#   "5'-AMP Nucleotidase",
#   "5' AMP Nucleotidase",
#   "5'-Nucleotidase Phosphoribolase",
#   "5' Nucleotidase Phosphoribolase",
#   'Adenylate Phosphatase',
#   'AMP Phosphatase',
#   'Cytidylate Phosphatase',
#   "Ecto-5'-Nucleotidase",
#   "Ecto-5'-nucleotidase",
#   "Ecto 5' Nucleotidase",
#   'IMP Nucleotidase',
#   'IMP Phosphatase',
#   'IMPase',
#   'Inosinate Phosphatase',
#   "Pyrimidine 5'-Nucleotidase",
#   "Pyrimidine 5' nucleotidase",
#   "Pyrimidine-5'-nucleotidase",
#   "Pyrimidine 5'-nucleotidase",
#   'PYRIMIDINE 5 NUCLEOTIDASE',
#   "Pyrimidine 5' Nucleotidase",
#   "Pyrimidine-5'-Nucleotidase",
#   'Thymidine Phosphatase',
#   "Uridylate 5'-Nucleotidase",
#   "Uridylate 5' Nucleotidase",
#   'CD73 Antigens',
#   'Antigen, CD73',
#   'CD73 Antigen',
#   'Antigens, CD73',
#   "5'-Ribonucleotide phosphohydrolase",
#   "5' ribonucleotide phosphohydrolase",
#   'Lymphocyte antigen CD73',
#   'CD73',
#   'CD73 - Cluster of diff ag 73',
#   'CD73 - Cluster of differentiation antigen 73',
#   'Cluster of diff antigen 73',
#   'Cluster of differentiation antigen 73',
#   "5' Nucleotidase Family",
#   "Pyrimidine-5'-nucleotidase (substance)",
#   "5'-Nucleotidase (substance)",
#   'Lymphocyte antigen CD73 (substance)',
#   "5'-N'Tase",
#   "5'-NT",
#   'NUCLEOTIDASE 05',
#   'URIDYLATE NUCLEOTIDASE 05',
#   'AMP NUCLEOTIDASE 05',
#   'ECTO NUCLEOTIDASE 05',
#   'CD 073 ANTIGENS',
#   'ANTIGENS CD 073',
#   'PYRIMIDINE NUCLEOTIDASE 05',
#   "5'-Nucleotidase [Chemical/Ingredient]"],
#  'UMLS:C0000534': ['5,12-diHETE',
#   '5,12 diHETE',
#   '5,12-HETE',
#   '5,12 HETE',
#   'DIHETE 05 12',
#   'HETE 005 012'],
#  'UMLS:C0000543': ['5,6-Dihydroxytryptamine',
#   '5,6 Dihydroxytryptamine',
#   '3-(2-Aminoethyl)indole-5,6-diol',
#   '1H-Indole-5,6-diol, 3-(2-aminoethyl)-',
#   'DIHYDROXYTRYPTAMINE 05 06',
#   '5,6-Dihydroxytryptamine [Chemical/Ingredient]'],
#  'UMLS:C0000544': ['5,7-Dihydroxytryptamine',
#   '5,7 Dihydroxytryptamine',
#   '3-(2-Aminoethyl)-1H-indole-5,7-diol',
#   '1H-Indole-5,7-diol, 3-(2-aminoethyl)-',
#   'DIHYDROXYTRYPTAMINE 05 07',
#   '5,7-Dihydroxytryptamine [Chemical/Ingredient]'],
#  'UMLS:C0000545': ['Eicosapentaenoic Acid',
#   'acid eicosapentaenoic',
#   'eicosapentaenoic acid',
#   'EICOSAPENTAENOIC ACID',
#   'Eicosapentaenoic acid',
#   '5,8,11,14,17-Eicosapentaenoic Acid',
#   '5,8,11,14,17-Eicosapentaenoic acid',
#   '5,8,11,14,17-EICOSAPENTAENOIC acid',
#   'omega-3-Eicosapentaenoic Acid',
#   'omega 3 Eicosapentaenoic Acid',
#   'Timnodonic Acid',
#   'timnodonic acid',
#   'Timnodonic acid',
#   '5,8,11,14,17-Icosapentaenoic Acid',
#   '5,8,11,14,17-Icosapentaenoic acid',
#   'Eicosapentanoic Acid',
#   'Eicosapentanoic acid',
#   'Acid, Eicosapentanoic',
#   'EPA - Eicosapentanoic acid',
#   'EPA - Eicosapentaenoic acid',
#   'Eicosapentaenoic acid (substance)',
#   'cis, cis, cis, cis, cis-Eicosa-5,8,11,14,17-pentaenoic acid',
#   '(5Z,8Z,11Z,14Z,17Z)-Eicosapentaenoate',
#   'Icosapentum',
#   'cis-delta(5,8,11,14,17)-Eicosapentaenoic acid',
#   '(all-Z)-5,8,11,14,17-Eicosapentaenoic acid',
#   '(5Z,8Z,11Z,14Z,17Z)-Icosapentaenoic acid',
#   'Icosapento',
#   'all-cis-5,8,11,14,17-icosapentaenoic acid',
#   '(5Z,8Z,11Z,14Z,17Z)-5,8,11,14,17-Eicosapentaenoic acid',
#   '(5Z,8Z,11Z,14Z,17Z)-Eicosapentaenoic acid',
#   'cis-5,8,11,14,17-EPA',
#   'Eicosapentanoic acid (substance)',
#   'EPA',
#   'IPA',
#   'EICOSAPENTAENOIC ACID 05 08 11 14 17',
#   'Icosapentaenoic acid',
#   'Icosapentaenoic Acid',
#   'all-cis-5,8,11,14,17-eicosapentaenoic acid',
#   'All cis-5,8,11,14,17-Eicosapentaenoic Acid',
#   'Eicosapentaenoic Acid [Chemical/Ingredient]',
#   'Icosapentaenoic Acid n-3',
#   'Eicosapentaenoic Acid n-3',
#   'all-cis-icosa-5,8,11,14,17-pentaenoic acid',
#   'All-cis-icosa-5,8,11,14,17-pentaenoic acid',
#   'Fatty Acid 20:5',
#   'Fatty Acid 20:5 n-3',
#   'cis-5,8,11,14,17-Eicosapentaenoic acid',
#   'cis-5,8,11,14,17-Eicosapentaenoic Acid',
#   'Icosapent',
#   'ICOSAPENT',
#   'icosapent'],
#  'UMLS:C0000546': ['5,8,11,14-Eicosatetraynoic Acid',
#   '5,8,11,14-Eicosatetraynoic acid',
#   '5,8,11,14 Eicosatetraynoic Acid',
#   'ETYA',
#   'EICOSATETRAYNOIC ACID 05 08 11 14',
#   '5,8,11,14-Eicosatetraynoic Acid [Chemical/Ingredient]'],
#  'UMLS:C0000551': ['Androstane-3,17-diol',
#   'Androstane 3,17 diol',
#   '5-Androstane-3,17-diol',
#   '5 Androstane 3,17 diol',
#   'ANDROSTANEDIOL 03 17',
#   'Androstane-3,17-diol [Chemical/Ingredient]'],
#  'UMLS:C0000562': ["5-Fluoro-2'-deoxyuridine Phosphorylase",
#   "5 Fluoro 2' deoxyuridine Phosphorylase",
#   "Phosphorylase, 5-Fluoro-2'-deoxyuridine"],
#  'UMLS:C0000578': ['5-Hydroxytryptophan',
#   '5 hydroxytryptophan',
#   '5-hydroxytryptophan',
#   '5 Hydroxytryptophan',
#   'Hydroxytryptophan (5-)',
#   '5-HTP',
#   '5 htp',
#   '5-htp',
#   'Hydroxytryptophan',
#   'hydroxytryptophan',
#   'HYDROXYTRYPTOPHAN',
#   'Oxitriptan',
#   'oxitriptan',
#   'OXITRIPTAN',
#   'Oxytryptophan',
#   'Tryptophan, 5-Hydroxy-',
#   '5-Hydroxy tryptophan',
#   '5 hydroxy tryptophan',
#   '5-hydroxy tryptophan',
#   'Tryptophan, 5 Hydroxy',
#   '5-Hydroxy- Tryptophan',
#   'Tript-OH',
#   '5-Hydroxy tryptophan (substance)',
#   '2-Amino-3-(5-hydroxy-1-H-indol-3-yl)propionic Acid',
#   '2-amino-3-(5-hydroxy-1H-indol-3-yl)propanoic acid',
#   'HYDROXYTRYPTOPHAN 05',
#   'HTP 05',
#   '5-Hydroxytryptophan [Chemical/Ingredient]'],
#  'UMLS:C0000588': ['Methylbufotenin',
#   '5-Methoxy-N,N-Dimethyltryptamine',
#   '5 methoxy N,N dimethyltryptamine',
#   '5 Methoxy N,N Dimethyltryptamine',
#   'N,N-Dimethyl-5-Methoxytryptamine',
#   'N,N Dimethyl 5 Methoxytryptamine'],
#  'UMLS:C0000589': ['5-Methoxytryptamine',
#   '5 methoxytryptamine',
#   '5-methoxytryptamine',
#   '5-METHOXYTRYPTAMINE',
#   '5 Methoxytryptamine',
#   'Methoxytryptamine',
#   'Mexamine',
#   'Meksamine',
#   'meksamine',
#   '1H-Indole-3-ethanamine, 5-methoxy-',
#   'METHOXYTRYPTAMINE 05',
#   '5-Methoxytryptamine [Chemical/Ingredient]'],
#  'UMLS:C0000598': ['Ticlopidine Hydrochloride',
#   'ticlopidine hydrochloride',
#   'TICLOPIDINE HYDROCHLORIDE',
#   'Ticlopidine hydrochloride',
#   'Hydrochloride, Ticlopidine',
#   'antiplatelet ticlopidine hcl',
#   'Ticlopidine HCl (medication)',
#   'ticlopidine HCl',
#   'ticlopidine hcl',
#   'Ticlopidine HCl',
#   'Ticlopidine hydrochloride (substance)',
#   'Ticlopidine hydrochloride (product)',
#   'Thieno(3,2-c)pyridine, 5-((2-chlorophenyl)methyl)-4,5,6,7-tetrahydro-, Hydrochloride',
#   '5-(o-Chlorobenzyl)-4,5,6,7-tetrahydrothieno(3,2-c)pyridinium Chloride',
#   'Ticlopidine Hydrochloride [Chemical/Ingredient]'],
#  'UMLS:C0000601': ['5 alpha-Androstane-3 beta,17 alpha-diol',
#   '5 alpha Androstane 3 beta,17 alpha diol',
#   '5alpha-Androstane-3beta,17alpha-diol',
#   '5alpha Androstane 3beta,17alpha diol'],
#  'UMLS:C0000608': ['6-Aminocaproic Acid',
#   '6-Aminocaproic acid',
#   '6 Aminocaproic Acid',
#   '6-Aminohexanoic Acid',
#   '6-aminohexanoic acid',
#   '6 Aminohexanoic Acid',
#   'Aminocaproic Acid',
#   'acid aminocaproic',
#   'Aminocaproic acid',
#   'AMINOCAPROIC ACID',
#   'aminocaproic acid',
#   'epsilon-Aminocaproic Acid',
#   'epsilon aminocaproic acid',
#   'epsilon-aminocaproic acid',
#   'Epsilon-Aminocaproic Acid',
#   'epsilon Aminocaproic Acid',
#   'Hexanoic acid, 6-amino-',
#   'E-amino-N-caproic acid',
#   'Z',
#   'Aminohexanoic acid',
#   'Acide aminocaproque',
#   'Acidum Aminocaproicum',
#   'Aminocapronsäure',
#   'Ácido aminocapróico',
#   'AMINOCAPROIC',
#   'Acide aminocaproïque',
#   'Epsilcapramine',
#   'epsilon-Aminohexanoic acid',
#   'EACA',
#   'Eaca',
#   'epsilon-Ahx',
#   'Aminocaproic acid - chemical',
#   'Aminocaproic acid - chemical (product)',
#   'Aminocaproic acid - chemical (substance)',
#   'Aminocaproic acid (product)',
#   'Aminocaproic acid (substance)',
#   'Epsilon S',
#   'Ahx',
#   'AMINOCAPROIC ACID 06',
#   'AMINOHEXANOIC ACID 06',
#   'aminocaproic acid (medication)',
#   'Aminocaproic Acid [Chemical/Ingredient]'],
#  'UMLS:C0000610': ['6-Aminonicotinamide',
#   '6 aminonicotinamide',
#   '6 Aminonicotinamide',
#   '6-AN',
#   '3-Pyridinecarboxamide, 6-amino-',
#   'Aminonicotinamide',
#   'AMINONICOTINAMIDE 06',
#   '6-Aminonicotinamide [Chemical/Ingredient]'],
#  'UMLS:C0000617': ['6-Ketoprostaglandin F1 alpha',
#   '6 Ketoprostaglandin F1 alpha',
#   'alpha, 6-Ketoprostaglandin F1',
#   'F1 alpha, 6-Ketoprostaglandin',
#   '6-Keto-PGF1 alpha',
#   '6 Keto PGF1 alpha',
#   'alpha, 6-Keto-PGF1',
#   '6-Oxo-PGF1 alpha',
#   '6 Oxo PGF1 alpha',
#   'alpha, 6-Oxo-PGF1',
#   '6-Oxoprostaglandin F1 alpha',
#   '6 Oxoprostaglandin F1 alpha',
#   'alpha, 6-Oxoprostaglandin F1',
#   'F1 alpha, 6-Oxoprostaglandin',
#   'Prost-13-en-1-oic acid, 9,11,15-trihydroxy-6-oxo-, (9alpha,11alpha,13E,15S)-',
#   'KETO PGF 01 06 ALPHA',
#   'KETOPROSTAGLANDIN F 01 06 ALPHA',
#   'OXOPROSTAGLANDIN F 01 06 ALPHA',
#   'OXOPGF 01 06 ALPHA',
#   '6-Ketoprostaglandin F1 alpha [Chemical/Ingredient]'],
#  'UMLS:C0000618': ['mercaptopurine',
#   'Mercaptopurine',
#   'MERCAPTOPURINE',
#   '6-Mercaptopurine',
#   '6-mercaptopurine',
#   '6 mercaptopurine',
#   '6- mercaptopurine',
#   '6 Mercaptopurine',
#   '6-Thiohypoxanthine',
#   '6 Thiohypoxanthine',
#   '6-Thiopurine',
#   '6 thiopurine',
#   '6-thiopurine',
#   '6 Thiopurine',
#   '1,7-Dihydro-6H-purine-6-thione',
#   '6H-Purine-6-thione, 1,7-dihydro-',
#   '6-MP',
#   '6-mp',
#   '6 MP',
#   '6MP',
#   '6MP - Mercaptopurine',
#   'Mercaptopurine (product)',
#   'Mercaptopurine (substance)',
#   'MP',
#   '7-Mercapto-1,3,4,6-tetrazaindene',
#   '6H-Purine-6-thione, 1,7-dihydro- (9CI)',
#   '3H-Purine-6-thiol',
#   'Purine-6-thiol (8CI)',
#   'Mercapto-6-purine',
#   'Purine, 6-mercapto-',
#   '6-Purinethiol',
#   '6-Thioxopurine',
#   'Mercaptopurina',
#   'mercaptopurinum',
#   'Mercapurin',
#   'Mern',
#   'MERCAPTOPURINE A 06',
#   '6-mercaptopurine (medication)',
# ...
#   'Aluminum hydroxide (in vac)',
#   'Aluminum hydroxide (in vaccine)',
#   'ALUMINUM (AS HYDROXIDE)',
#   'Aluminum hydroxide [antacid] (product)',
#   'Aluminum hydroxide [antacid] (substance)',
#   'Aluminum hydroxide - chemical (substance)',
#   'Aluminum hydroxide [nutritional use] (product)',
#   'Aluminum hydroxide [nutritional use] (substance)',
#   'Aluminum hydroxide (substance)',
#   'Aluminum hydroxide (in vaccine) (substance)',
#   'Aluminum Hydroxide [Chemical/Ingredient]',
#   'aluminum hydroxide (medication)'],
#  'UMLS:C0002372': ['Aluminum Hydroxide Gel',
#   'aluminum hydroxide gel',
#   'ALUMINUM HYDROXIDE GEL',
#   'Algeldrate',
#   'algeldrate',
#   'ALGELDRATE',
#   'Algeldrate [Chemical/Ingredient]',
#   'Aluminum Hydroxide Hydrate'],
#  'UMLS:C0002373': ['Aluminum Nitrilotriacetate',
#   'Nitrilotriacetate, Aluminum'],
#  'UMLS:C0002374': ['Aluminum Oxide',
#   'Aluminum oxide',
#   'aluminum oxide',
#   'ALUMINUM OXIDE',
#   'Oxide, Aluminum',
#   'Aluminum oxide (Al2O3)',
#   'Alumina',
#   'alumina',
#   'Aluminium oxide',
#   'aluminium oxide',
#   'Aluminum oxide - chemical',
#   'Alumina / aluminum oxide',
#   'alumina/aluminum oxide',
#   'Aluminium oxide - chemical',
#   'Aluminum oxide (substance)',
#   'aluminum lake',
#   'Aluminum Lake',
#   'Aluminum oxide (product)',
#   'Aluminum Oxide [Chemical/Ingredient]',
#   'Aluminium oxide - chemical (substance)',
#   'Activated Aluminum Oxide'],
#  'UMLS:C0002377': ['Aluminum Silicates',
#   'Aluminum silicates',
#   'Aluminum silicate',
#   'Silicates, Aluminum',
#   'Aluminum Silicates [Chemical/Ingredient]'],
#  'UMLS:C0002382': ['Alveolar Bone Loss',
#   'alveolar bone loss',
#   'Alveolar bone loss',
#   'Alveolar Bone Losses',
#   'Bone Loss, Alveolar',
#   'Bone Loss, Periodontal',
#   'periodontal bone loss',
#   'Bone Losses, Periodontal',
#   'Periodontal Bone Losses',
#   'Periodontal Bone Loss',
#   'Alveolar Resorption',
#   'Alveolar Resorptions',
#   'Resorptions, Alveolar',
#   'Resorption, Alveolar',
#   'Periodontal Resorption',
#   'periodontal resorption',
#   'Periodontal Resorptions',
#   'Resorption, Periodontal',
#   'Alveolar bone loss (disorder)',
#   'Alveolar Process Atrophy',
#   'atrophy; alveolar process',
#   'process; alveolar, atrophy',
#   'Alveolar Process Atrophies',
#   'Alveolar Bone Loss [Disease/Finding]',
#   'Alveolar Bone Atrophy',
#   'Alveolar Bone Atrophies',
#   'Bone Atrophies, Alveolar',
#   'Bone Atrophy, Alveolar'],
#  'UMLS:C0002386': ['Alveolar Process',
#   'Alveolar process',
#   'alveolar process',
#   'Alveolar Processes',
#   'Processes, Alveolar',
#   'alveolar processes',
#   'Process, Alveolar',
#   'Alveolar process (body structure)',
#   'Structure of alveolar process (body structure)',
#   'Structure of alveolar process'],
#  'UMLS:C0002387': ['Alveolar Ridge Augmentation',
#   'Alveolar Ridge Augmentations',
#   'Augmentations, Alveolar Ridge',
#   'Ridge Augmentations, Alveolar',
#   'Augmentation of alveolar ridge',
#   'Augmentation, Alveolar Ridge',
#   'Ridge Augmentation, Alveolar',
#   'Augmentation of alveolar ridge (procedure)'],
#  'UMLS:C0002388': ['Alveolectomy',
#   'alveolectomy',
#   'Alveolectomies',
#   'alveolectomies',
#   'Alveolectomy, dental',
#   'surgery dentoalveolar structures alveolectomy',
#   'alveolectomy (treatment)'],
#  'UMLS:C0002390': ['Extrinsic allergic alveolitis',
#   'Allergic Alveolitis, Extrinsic',
#   'Alveolitis, Extrinsic Allergic',
#   'ALVEOLITIS, EXTRINSIC ALLERGIC',
#   'Alveolitis extrinsic allergic',
#   'Extrinsic Allergic Alveolitis',
#   'extrinsic allergic alveolitis',
#   'Allergic Alveolitides, Extrinsic',
#   'Alveolitides, Extrinsic Allergic',
#   'Extrinsic Allergic Alveolitides',
#   'Extrinsic allergic alveolitis, NOS',
#   'Allergic extrinsic alveolitis NOS',
#   'Allergic alveolitis (extrinsic) NOS',
#   'Extrinsic alveolitis, allergic',
#   'Allergic alveolitis',
#   'Alveolitis, allergic',
#   'ALVEOLITIS ALLERGIC',
#   'alveolitis allergic',
#   'Alveolitis allergic',
#   'Alveolitis - allergic',
#   'alveolitis; allergic',
#   'Allergic Alveolitis',
#   'allergic alveolitis',
#   'allergic; alveolitis',
#   'Allergic alveolitis, NOS',
#   'Allergic pneumonitis',
#   'PNEUMONITIS ALLERGIC',
#   'Pneumonitis allergic',
#   'allergic pneumonitis',
#   'Allergic Pneumonitis',
#   'Allergic pneumonitis, NOS',
#   'Pneumonitis, allergic NOS',
#   'Pneumonitis, Hypersensitivity',
#   'HYPERSENSITIVITY PNEUMONITIS',
#   'Hypersensitivity pneumonitis',
#   'hypersensitivity pneumonitis',
#   'hypersensitivity; pneumonitis',
#   'PNEUMONITIS, HYPERSENSITIVITY',
#   'Pneumonitis hypersensitivity',
#   'pneumonitis; hypersensitivity',
#   'Hypersensitivity Pneumonitides',
#   'Pneumonitides, Hypersensitivity',
#   'Hypersensitivity pneumonitis, NOS',
#   'Hypersensitivity pneumonitis NOS',
#   'Hypersensitivity Pneumonitis',
#   'Unspecified allergic alveolitis and pneumonitis',
#   'Allerg alveol/pneum NOS',
#   'Allergic interstitial pneumonitis',
#   'PNEUMONITIS, ALLERGIC INTERSTITIAL',
#   'Allergic interstitial pneumonitis, NOS',
#   'Extrinsic allergic bronchiolo-alveolitis',
#   'Extrinsic allergic bronchiolo-alveolitis, NOS',
#   'Hypersensitivity pneumonia',
#   'hypersensitivity pneumonia',
#   'Hypersensitivity pneumonia, NOS',
#   'EAA - Extr allergic alveolitis',
#   'EAA - Extrinsic allergic alveolitis',
#   'Allergic extr.alveolitis NOS',
#   'Hypersensit.pneumonitis NOS',
#   'Baggasosis',
#   'Extrinsic allergic alveolitis (disorder)',
#   'Allergic extrinsic alveolitis NOS (disorder)',
#   'Hypersensitivity pneumonitis NOS (disorder)',
#   'hypersensitivity pneumonitis (diagnosis)',
#   'Alveolitis, Extrinsic Allergic [Disease/Finding]'],
#  'UMLS:C0002393': ['Alveoloplasty',
#   'alveoloplasty',
#   'Alveoloplasties',
#   'alveoloplasties',
#   'surgery alveoloplasty',
#   'alveoloplasty (treatment)'],
#  'UMLS:C0002395': ["Alzheimer's Disease",
#   "ALZHEIMER'S DISEASE",
#   "Alzheimer's disease",
#   "alzheimer's disease",
#   'Alzheimer Disease',
#   'Alzheimers Disease',
#   'Disease, Alzheimer',
#   'ALZHEIMER DISEASE',
#   "Alzheimer's disease, NOS",
#   'alzheimer diseases',
#   "alzheimer's diseases",
#   'alzheimers disease',
#   'Alzheimer disease',
#   'Disease;Alzheimers',
#   'Alzheimers disease',
#   "Disease, Alzheimer's",
#   'Primary Senile Degenerative Dementia',
#   'Dementia, Primary Senile Degenerative',
#   'Dementia, Senile',
#   'senile dementia',
#   'Senile Dementia',
#   'Senile Dementia, Alzheimer Type',
#   'SENILE DEMENTIA OF THE ALZHEIMER TYPE',
#   'senile dementia of the Alzheimer type',
#   'Alzheimer Type Senile Dementia',
#   'Dementia, Alzheimer Type',
#   'Alzheimer-type dementia',
#   'DEMENTIA OF THE ALZHEIMER TYPE',
#   "Dementia Alzheimer's type",
#   "Dementia of the Alzheimer's type NOS",
#   'dementia of the Alzheimer type',
#   'Dementia of Alzheimers Type',
#   "Dementia of the Alzheimer's type",
#   'Alzheimer Type Dementia',
#   'dats',
#   'DAT',
#   'SDAT',
#   'AD',
#   "AD - Alzheimer's disease",
#   'Alzheimer disease (AD)',
#   "DAT - Dementia Alzheimer's type",
#   'DAT - Dementia Alzheimer type',
#   'dementia of the Alzheimer type (DAT)',
#   "Dementia in Alzheimer's dis",
#   "Dementia in Alzheimer's disease",
#   'senile dementia of the Alzheimer type (SDAT)',
#   "Alzheimer's disease, unspecified",
#   'Alzheimer-Type Dementia (ATD)',
#   'Alzheimer Type Dementia (ATD)',
#   'Dementia, Alzheimer-Type (ATD)',
#   "Alzheimer's disease (diagnosis)",
#   'simple senile dementia',
#   'Alzheimer Dementia (AD)',
#   'Alzheimer dementia (AD)',
#   'Dementia, Alzheimer (AD)',
#   'Alzheimer-type dementia (ADT)',
#   'Alzheimer Sclerosis',
#   'sclerosis; Alzheimer',
#   'Alzheimer sclerosis',
#   'Alzheimer; sclerosis',
#   'Sclerosis, Alzheimer',
#   'Alzheimer Syndrome',
#   'Alzheimer syndrome',
#   'Syndrome, Alzheimer',
#   'alzheimers dementia',
#   'Alzheimers dementia',
#   'DEMENTIA ALZHEIMER',
#   'Alzheimer dementia',
#   "Alzheimer's Dementia",
#   'dementia alzheimers',
#   "Alzheimer's disease (disorder)",
#   'dementia; Alzheimer (etiology)',
#   'Alzheimer; dementia (etiology)',
#   'Alzheimer',
#   'dementia; Alzheimer (manifestation)',
#   'Alzheimer; dementia (manifestation)',
#   'ALZHEIMER DIS',
#   'ALZHEIMERS DIS',
#   'Alzheimer Disease [Disease/Finding]'],
#  'UMLS:C0002401': ['Amanita',
#   'amanita',
#   'Amanita, NOS',
#   'Amanita (organism)',
#   'Amanitas'],
#  'UMLS:C0002402': ['Amanitins',
#   'amanitins',
#   'amanitin',
#   'Amanitine',
#   'amanitine',
#   'Amanitotoxin',
#   'Amanitine (substance)',
#   'Amanitins [Chemical/Ingredient]'],
#  'UMLS:C0002403': ['Amantadine',
#   'amantadine',
#   'AMANTADINE',
#   'Amantidine',
#   '1-Aminoadamantane',
#   '1-aminoadamantane',
#   '1 Aminoadamantane',
#   'Adamantylamine',
#   'Tricyclo(3.3.1.13,7)decan-1-amine',
#   'Amatadine',
#   'amatadine',
#   '1-adamantanamine',
#   'Amantadina',
#   'Amantadinum',
#   'Aminoadamantane',
#   'Tricyclo[3.3.1.1(3,7)]decane-1-amine',
#   '1-adamantylamine',
#   'Tricyclo[3.3.1.1(3,7)]decan-1-amine',
#   'Tricyclo[3.3.1.1(3,7)]decan-1-ylamine',
#   'Amantadine (product)',
#   'Amantadine (substance)',
#   'Amantadine [Chemical/Ingredient]'],
#  'UMLS:C0002404': ['Amantadine Sulfate',
#   'amantadine sulfate',
#   'Amantadine sulfate',
#   'AMANTADINE SULFATE',
#   'Amantadine sulphate',
#   'Sulfate, Amantadine',
#   'Amantadine sulfate (substance)'],
#  'UMLS:C0002405': ['Amapari virus',
#   'Amapar mammarenavirus',
#   'Amapari mammarenavirus',
#   'Amapari arenavirus',
#   'Amapari virus (organism)'],
#  'UMLS:C0002406': ['Amaranth Dye',
#   'Amaranth dye',
#   'amaranth dye',
#   'Dye, Amaranth',
#   'Amaranth',
#   'amaranth',
#   'AMARANTH',
#   'amaranths',
#   'Amaranths',
#   '2,7-Naphthalenedisulfonic acid, 3-hydroxy-4-((4-sulfo-1-naphthalenyl)azo)-, trisodium salt',
#   'Azorubin S',
#   'Naphthol red S',
#   'Naphthylamine red',
#   '3-hydroxy-4-(2-(4-sulfo-1-naphthalenyl)diazenyl)-2,7-naphthalenedisulfonic Acid Sodium Salt (1:3)',
#   'Trisodium 3-hydroxy-4-((e)-(4-sulfonato-1-naphthyl)diazenyl)naphthalene-2,7-disulfonate',
#   'C.I. Food Red 9',
#   'Red No. 2',
#   '1-(4-sulfo-1-naphthylazo)-2-naphthol-3,6-disulfonic Acid Trisodium Salt',
#   'Azorubin S (substance)',
#   'Azorubin S stain',
#   'Azorubin S stain (substance)',
#   'Amaranth (product)',
#   'Amaranth (substance)',
#   'C.I. 16185',
#   'Amaranth Dye [Chemical/Ingredient]'],
#  'UMLS:C0002412': ['Ambenonium',
#   'ambenonium',
#   'AMBENONIUM',
#   'Ambenonum',
#   'Ambenonium base',
#   'Ambenonium (product)',
#   'Ambenonium (substance)',
#   "Benzenemethanaminium, N,N'-((1,2-dioxo-1,2-ethanediyl)bis(imino-2,1-ethanediyl))bis(2-chloro-N,N-diethyl)-"],
#  'UMLS:C0002413': ['Ambenonium Chloride',
#   'Ambenonium chloride',
#   'ambenonium chloride',
#   'AMBENONIUM CHLORIDE',
#   'Chloride, Ambenonium',
#   "Benzenemethanaminium, N,N'-((1,2-dioxo-1,2-ethanediyl)bis(imino-2,1-ethanediyl))bis(2-chloro-N,N-diethyl)-, dichloride",
#   "N,N'-((1,2-Dioxo-1,2-ethanediyl)bis(imino-2,1-ethanediyl))bis(2-chloro-N,N-diethyl-benzenemethanaminium), Dichloride",
#   'Ambestigmine chloride',
#   'Ambenonium chloride (substance)',
#   'Win 8077',
#   '(Oxalylbis(iminoethylene))bis((o-chlorobenzyl)diethyl-ammonium), Dichloride',
#   'Misuran',
#   'Oxazyl',
#   'ambenonium chloride (medication)',
#   'Ambenonium Chloride [Chemical/Ingredient]'],
#  'UMLS:C0002416': ['Ambidexterity',
#   'ambidexterity',
#   'Ambidextrous',
#   'ambidextrous',
#   'Ambidextrous (finding)'],
#  'UMLS:C0002418': ['Amblyopia',
#   'AMBLYOPIA',
#   'amblyopia',
#   'Amblyopias',
#   'Amblyopia, NOS',
#   'Amblyopia NOS',
#   'Amblyopia, unspecified',
#   'Unspecified amblyopia',
#   'Amblyopic',
#   'amblyopic',
#   'Lazy eye',
#   'Lazy Eye',
#   'Wandering eyes',
#   'Wandering eye',
#   'Amblyopia (disorder)',
#   'Unspecified amblyopia (disorder)',
#   'amblyopia (diagnosis)',
#   'Amblyopia [Disease/Finding]'],
#  'UMLS:C0002419': ['Tobacco amblyopia',
#   'Amblyopia, tobacco',
#   'Amblyopia tobacco',
#   'amblyopia; tobacco',
#   'tobacco; amblyopia',
#   "Smoker's blindness",
#   'Tobacco amblyopia (disorder)'],
#  'UMLS:C0002421': ['Ambroxol',
#   'ambroxol',
#   'AMBROXOL',
#   'Bromhexine Metabolite VIII',
#   'Bromhexine metabolite vIII',
#   'Bromhexine-metabolite vIII',
#   'Metabolite VIII, Bromhexine',
#   '4-(((2-Amino-3,5-dibromophenyl)methyl)amino)cyclohexanol',
#   'Cyclohexanol, 4-(((2-amino-3,5-dibromophenyl)methyl)amino)-, trans-',
#   'Ambroxol (substance)',
#   'Ambroxol (product)',
#   'trans-4-((2-Amino-3,5-dibromobenzyl)amine)cyclohexanol',
#   'N-(2-Amino-3,4-dibromocyclohexyl)-trans-4-aminocyclohexanol',
#   'Ambroxolum',
#   'N-(2-Amino-3,4-dibromociclohexil)-trans-4-aminociclohexanol',
#   'trans-4-((2-Amino-3,5-dibromobencil)amino)ciclohexanol',
#   'trans-4-((2-Amino-3,5-dibromobenzyl)amino)cyclohexanol',
#   'Cyclohexanol, 4-((2-amino-3,5-dibromobenzyl)amino)- (E)-',
#   'Bisolvon metabolite vIII',
#   'BROMHEXINE METABOLITE 08',
#   'Ambroxol [Chemical/Ingredient]'],
#  'UMLS:C0002422': ['Ambulances',
#   'ambulances',
#   'Ambulance',
#   'Ambulance, NOS',
#   'ambulance',
#   'Transportation Services; Ambulance',
#   'Ambulance, device (physical object)',
#   'Ambulance, device'],
#  'UMLS:C0002423': ['ambulatory care services',
#   'Ambulatory Care',
#   'care ambulatory',
#   'ambulatory care',
#   'Ambulatory care',
#   'Care, Ambulatory',
#   'Outpatient Care',
#   'care outpatient',
#   'outpatient care',
#   'Care, Outpatient',
#   'Outpatient Services',
#   'Outpatient services',
#   'Outpatient Treatment',
#   'outpatient treatment',
#   'outpatients treatment',
#   'nonresidential treatment'],
#  'UMLS:C0002426': ['Clinics, Free-Standing',
#   'FREE-STANDING CLINICS',
#   'Clinic, Free-Standing',
#   'Clinics, Free Standing',
#   'Free-Standing Clinic',
#   'Free-standing clinic, NOS',
#   'Free-standing clinic',
#   'Free-Standing Clinics',
#   'Ambulatory Care Facilities, Nonhospital',
#   'Free-standing health center',
#   'Free-standing health center, NOS',
#   'Free-standing health centre',
#   '83 FREE-STANDING CLINICS',
#   'Free-standing clinic (environment)',
#   'Ambulatory Care Facilities, Non Hospital',
#   'Ambulatory Care Facilities, Non-Hospital',
#   'AMBULATORY CARE FACILITIES NON HOSP',
#   'AMBULATORY CARE FACILITIES NONHOSP'],
#  'UMLS:C0002427': ['Ambulatory Care Data Management Information Systems',
#   'Information Systems, Data Management, Ambulatory Care',
#   'Ambulatory Care Information Systems, Data Management',
#   'Ambulatory Care Information Systems',
#   'Information Systems, Ambulatory Care',
#   'Ambulatory Care Data Management Systems'],
#  'UMLS:C0002428': ['Ambulatory Surgical Procedures',
#   'ambulatory procedures surgical',
#   'Ambulatory Surgical Procedure',
#   'Procedure, Ambulatory Surgical',
#   'Surgical Procedure, Ambulatory',
#   'Procedures, Ambulatory Surgical',
#   'Surgical Procedures, Ambulatory',
#   'Ambulatory Surgery',
#   'surgery ambulatory',
#   'ambulatory surgery',
#   'Ambulatory surgery',
#   'Ambulatory Surgeries',
#   'Surgeries, Ambulatory',
#   'ambulatory surgeries',
#   'Surgery, Ambulatory',
#   'Surgery, Outpatient',
#   'outpatient surgery',
#   'Outpatient Surgeries',
#   'Surgeries, Outpatient',
#   'Outpatient Surgery',
#   'Ambulatory surgery (procedure)',
#   'AMBULATORY SURG',
#   'SURG AMBULATORY',
#   'OUTPATIENT SURG',
#   'SURG OUTPATIENT',
#   'PROCEDURE AMBULATORY SURG',
#   'PROCEDURES AMBULATORY SURG',
#   'SURG PROCEDURES AMBULATORY',
#   'AMBULATORY SURG PROCEDURES',
#   'SURG PROCEDURE AMBULATORY',
#   'AMBULATORY SURG PROCEDURE'],
#  'UMLS:C0002429': ['Ambystoma',
#   'ambystoma',
#   'axolotl',
#   'Mole salamanders',
#   'Amblystoma',
#   'amblystoma',
#   'Amblystomas',
#   'Ambystomas',
#   'big salamanders',
#   'Genus Ambystoma',
#   'Genus Ambystoma (organism)'],
#  'UMLS:C0002430': ['Ambystoma mexicanum',
#   'Ambystoma mexicanums',
#   'mexicanums, Ambystoma',
#   'Axolotl',
#   'Axolotls',
#   'Ambystoma mexicanum (organism)',
#   'Ambystoma mexicanum (Shaw & Nodder, 1798)',
#   'Mexican Salamander',
#   'Salamander, Mexican'],
#  'UMLS:C0002431': ['Ambystomatidae',
#   'Family Ambystomidae',
#   'FAMILY AMBYSTOMIDAE',
#   'Family ambystomidae',
#   'B04 FAMILY AMBYSTOMIDAE',
#   'Family Ambystomidae (organism)',
#   'Family ambystomidae (organism)'],
#  'UMLS:C0002435': ['Amdinocillin',
#   'amdinocillin',
#   'AMDINOCILLIN',
#   'Mecillinam',
#   'mecillinam',
#   'Penicillin Hx',
#   'Penicillin HX',
#   '4-Thia-1-azabicyclo(3.2.0)heptane-2-carboxylic acid, 6-(((hexahydro-1H-azepin-1-yl)methylene)amino)-3,3-dimethyl-7-oxo-, (2S-(2alpha,5alpha,6beta))-',
#   'Amdinocillin (product)',
#   'Amdinocillin (substance)',
#   'amdinocillin (medication)',
#   'Amdinocillin [Chemical/Ingredient]'],
#  ...}

# %%
len(st21pv_dict)
# Out:
# 2369481

# %%
umls_output = [f'{key}||{x}' for key, val in umls_dict.items() for x in val]
# with open('../data/umls_2017/umls_updated_to_alias.txt', 'w') as f:
with open('../biogenel/src/bigbio_/data/medmentions_full/medmentions_full_aliases.txt', 'w') as f:
    f.write('\n'.join(umls_output))

st21pv_output = [f'{key}||{x}' for key, val in st21pv_dict.items() for x in val]
# with open('../data/umls_2017/st21pv_updated_to_alias.txt', 'w') as f:
with open('../biogenel/src/bigbio_/data/medmentions_st21pv/medmentions_st21pv_aliases.txt', 'w') as f:
    f.write('\n'.join(st21pv_output))

# %%
umls_output = []
for key, val in tqdm(umls.items()):
    umls_output.append(f'UMLS:{key}||{val["Name"]}')
    for alias in val['STR']:
        umls_output.append(f'UMLS:{key}||{alias}')
with open('../data/umls_2017/umls_to_alias.txt', 'w') as f:
    f.write('\n'.join(umls_output))


st21pv_output = []
for key, val in tqdm(st21pv.items()):
    st21pv_output.append(f'UMLS:{key}||{val["Name"]}')
    for alias in val['STR']:
        st21pv_output.append(f'UMLS:{key}||{alias}')
with open('../data/umls_2017/st21pv_to_alias.txt', 'w') as f:
    f.write('\n'.join(st21pv_output))

# %% [markdown]
# # Make test set for GNormPlus and NLM-Gene

# %%
name = 'gnormplus'
dataset = conhelps.for_config_name(f'{name}_bigbio_kb').load_dataset()
exclude = CUIS_TO_EXCLUDE[name]
remap = CUIS_TO_REMAP[name]
valid_pmids = VALIDATION_DOCUMENT_IDS[name]
df = dataset_to_df(dataset, cuis_to_exclude=exclude, entity_remapping_dict=remap, val_split_ids=valid_pmids)
df.groupby('split').agg({'document_id':'nunique'})
# Out:
# Found cached dataset gnormplus (/home/dkartchner3/.cache/huggingface/datasets/bigbio___gnormplus/gnormplus_bigbio_kb/1.0.0/97a2714b58185305591c949b067cea2febfca2447016096c3d08021d84bf7b69)
#   0%|          | 0/2 [00:00<?, ?it/s]
# <class 'str'> <class 'str'>
#             document_id
# split
# test                254
# train               353
# validation           63

# %%
seed = 0
for name in ['gnormplus','nlm_gene']:
# for name in ['gnormplus']:
    print(name)
    dataset = conhelps.for_config_name(f'{name}_bigbio_kb').load_dataset()
    exclude = CUIS_TO_EXCLUDE[name]
    remap = CUIS_TO_REMAP[name]
    df = dataset_to_df(dataset, cuis_to_exclude=exclude, entity_remapping_dict=remap)

    all_train_pmids = df.query("split == 'train'").document_id.unique()
    print(type(all_train_pmids))
    train_pmids, validation_pmids = train_test_split(all_train_pmids, test_size=0.15, random_state=seed)
    with open(f'../data/validation_split_ids/{name}.txt', 'w') as f:
        f.write('\n'.join(validation_pmids))
# Out:
# gnormplus
# Found cached dataset gnormplus (/home/dkartchner3/.cache/huggingface/datasets/bigbio___gnormplus/gnormplus_bigbio_kb/1.0.0/97a2714b58185305591c949b067cea2febfca2447016096c3d08021d84bf7b69)
#   0%|          | 0/2 [00:00<?, ?it/s]
# <class 'numpy.ndarray'>

# %% [markdown]
# # Final Quality Checks

# %%
for name in DATASET_NAMES:
    print(name)
    dataset = conhelps.for_config_name(f'{name}_bigbio_kb').load_dataset()
    print(dataset.keys())
    ontology = read_examples(f'../data/alias_mappings/{name}_aliases.txt')
    exclude = CUIS_TO_EXCLUDE[name]
    remap = CUIS_TO_REMAP[name]
    df = dataset_to_df(dataset, cuis_to_exclude=exclude, entity_remapping_dict=remap)
    all_cuis = set([y for x in df.db_ids for y in x])
    for x in all_cuis:
        if x not in ontology:
            print(x)

    print("**********************************")
# Out:
# Found cached dataset nlmchem (/nethome/dkartchner3/.cache/huggingface/datasets/nlmchem/nlmchem_bigbio_kb/1.0.0/d91131823c66b7dd1162027991ea47c342e478209b37cf261c5f122d30409594)
# nlmchem
#   0%|          | 0/3 [00:00<?, ?it/s]
# dict_keys(['train', 'test', 'validation'])
# 100%|██████████| 1006992/1006992 [00:01<00:00, 811475.42it/s]
# Found cached dataset nlm_gene (/nethome/dkartchner3/.cache/huggingface/datasets/nlm_gene/nlm_gene_bigbio_kb/1.0.0/eccd5e8295a7e199d672750806ac201aaa31d87ae12168a51b63a80e8cbb9d61)
# **********************************
# nlm_gene
#   0%|          | 0/2 [00:00<?, ?it/s]
# dict_keys(['train', 'test'])
# 100%|██████████| 2507059/2507059 [00:02<00:00, 859331.32it/s]
# Found cached dataset gnormplus (/nethome/dkartchner3/.cache/huggingface/datasets/gnormplus/gnormplus_bigbio_kb/1.0.0/c0080d95f482a3af78d8a39ad95daa2ec310687cba3c308d34c64811ee862a60)
# **********************************
# gnormplus
#   0%|          | 0/2 [00:00<?, ?it/s]
# dict_keys(['train', 'test'])
# 100%|██████████| 2114393/2114393 [00:02<00:00, 938288.27it/s]
# **********************************

# %%
import obonet
import ujson
import sys
import logging
import pandas as pd

from tqdm.auto import tqdm
from collections import defaultdict
from bigbio.dataloader import BigBioConfigHelpers


sys.path.insert(0, '..')
from umls_utils import UmlsMappings
from bigbio_utils import dataset_to_df



logger = logging.getLogger()
logger.setLevel(logging.INFO)

tqdm.pandas()
pd.set_option('display.max_rows', 200)

conhelps = BigBioConfigHelpers()

# %load_ext autoreload
# %autoreload 2

# %%
data = conhelps.for_config_name(f"nlm_gene_bigbio_kb").load_dataset(from_hub=False)
df = dataset_to_df(data)
all_nlmgene_entities = set([])
for normalizations in df['db_ids']:
    if any([x for x in normalizations if x.endswith(':') ]):
        print(normalizations)
    elif any([x for x in normalizations if ',' in x]):
        print(normalizations)

    all_nlmgene_entities.update([x for x in normalizations])
# Out:
# Downloading and preparing dataset nlm_gene/nlm_gene_bigbio_kb to /home/dkartchner3/.cache/huggingface/datasets/nlm_gene/nlm_gene_bigbio_kb/1.0.0/92249f0c0c401d2d902c7a0af6d76ca2e535383a56c0c4d4099036c7c0dc9581...
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Dataset nlm_gene downloaded and prepared to /home/dkartchner3/.cache/huggingface/datasets/nlm_gene/nlm_gene_bigbio_kb/1.0.0/92249f0c0c401d2d902c7a0af6d76ca2e535383a56c0c4d4099036c7c0dc9581. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
def extract_synonyms(data):
    if 'synonym' in data:
        return [syn.split('"')[1]for syn in data['synonym']]
    else:
        # print(data)
        return []
        
def term_to_synonyms(graph):
    node_dict = {}
    for curie, data in tqdm(graph.nodes(data=True)):
        synonyms = [data['name']] + extract_synonyms(data)
        node_dict[curie] = synonyms

    return node_dict

# %%
url = 'http://purl.obolibrary.org/obo/chebi.obo'
graph = obonet.read_obo(url)
synonyms = term_to_synonyms(graph)
# Out:
#   0%|          | 0/163657 [00:00<?, ?it/s]

# %%
# for curie, data in enumerate(tqdm(graph.nodes(data=True))):
#     if curie < 10:
#         print(data)

# %% [markdown]
# ## Get MeSH synonyms

# %%
# # 2022 UMLS
umls = UmlsMappings(umls_dir='/mitchell/entity-linking/2022AA/META/', debug=False, force_reprocess=False)

# 2017 UMLS
# umls_2017 = UmlsMappings(umls_dir='/mitchell/entity-linking/2022AA/META/', debug=False, force_reprocess=False)
# Out:
# Loading cached UMLS data from /mitchell/entity-linking/2022AA/META/.cached_df.feather

# %%
umls.umls.columns
# Out:
# Index(['cui', 'lang', 'scui', 'sdui', 'sab', 'alias', 'tui', 'group'], dtype='object')

# %%
mesh_to_alias = umls.get_aliases(ontologies_to_include=['MSH'],
                        use_umls_curies=False,
                        mapping_cols={'MSH':'sdui'},
                        prefixes={"MSH":"MESH"},
                        lowercase=True,
                        )

alias_to_mesh = umls.get_aliases(ontologies_to_include=['MSH'],
                        use_umls_curies=False,
                        mapping_cols={'MSH':'sdui'},
                        prefixes={"MSH":"MESH"},
                        reverse=True,
                        lowercase=True,
                        )


mesh_to_alias_chem_only = umls.get_aliases(ontologies_to_include=['MSH'],
                        groups_to_include=['CHEM'],
                        use_umls_curies=False,
                        mapping_cols={'MSH':'sdui'},
                        prefixes={"MSH":"MESH"},
                        lowercase=True,
                        )

# %%
with open('../data/mesh_to_alias.txt', 'w') as f:
    f.write('\n'.join([curie + '||' + alias for curie, alias_list in mesh_to_alias.items() for alias in alias_list]))

with open('../data/mesh_to_alias_chem_only.txt', 'w') as f:
    f.write('\n'.join([curie + '||' + alias for curie, alias_list in mesh_to_alias_chem_only.items() for alias in alias_list]))

with open('../data/alias_to_mesh.txt', 'w') as f:
    f.write('\n'.join([alias + '||' + '|'.join(curie) for alias, curie in alias_to_mesh.items()]))

# %% [markdown]
# ## Get OMIM Aliases

# %%
# OMIM
omim_to_alias = umls.get_aliases(ontologies_to_include=['OMIM'],
                        use_umls_curies=False,
                        mapping_cols={'OMIM':'sdui'},
                        prefixes={"OMIM":"OMIM"},
                        lowercase=True,
                        )

alias_to_omim = umls.get_aliases(ontologies_to_include=['OMIM'],
                        use_umls_curies=False,
                        mapping_cols={'OMIM':'sdui'},
                        prefixes={"OMIM":"OMIM"},
                        reverse=True,
                        lowercase=True,
                        )

                        
with open("../data/omim_to_alias.txt", "w") as f:
    f.write(
        "\n".join(
            [
                curie + "||" + alias
                for curie, alias_list in omim_to_alias.items()
                for alias in alias_list
            ]
        )
    )

with open('../data/alias_to_omim.txt', 'w') as f:
    f.write('\n'.join([alias + '||' + '|'.join(curie) for alias, curie in alias_to_omim.items()]))

# %% [markdown]
# ## Combine MeSH and OMIM for NCBI-Disease

# %%
# # Combine MeSH and OMIM for NCBI-Disease corpus
# alias_to_mesh_and_omim = defaultdict(list)
# for alias, curie_list in alias_to_mesh.items():
#     alias_to_mesh_and_omim[alias] = curie_list

# for alias, curie_list in alias_to_omim.items():
#     alias_to_mesh_and_omim[alias].extend(curie_list)

mesh_and_omim_to_alias_disease_only = umls.get_aliases(ontologies_to_include=['MSH','OMIM'],
                        # groups_to_include=['DISO'],
                        use_umls_curies=False,
                        mapping_cols={'MSH':'sdui', 'OMIM': 'sdui'},
                        prefixes={"MSH":"MESH", 'OMIM':'OMIM'},
                        lowercase=True,
                        )

# mesh_and_omim_to_alias_disease_only = umls_2017.get_aliases(ontologies_to_include=['MSH','OMIM'],
#                         # groups_to_include=['DISO'],
#                         use_umls_curies=False,
#                         mapping_cols={'MSH':'sdui', 'OMIM': 'sdui'},
#                         prefixes={"MSH":"MESH", 'OMIM':'OMIM'},
#                         lowercase=True,
#                         )

# with open('../data/mesh_and_omim_to_alias_disease_only.txt', 'w') as f:
#     f.write('\n'.join([curie + '||' + alias for curie, alias_list in mesh_and_omim_to_alias_disease_only.items() for alias in alias_list]))

with open('../data/mesh_and_omim_to_alias.txt', 'w') as f:
    f.write('\n'.join([curie + '||' + alias for curie, alias_list in mesh_and_omim_to_alias_disease_only.items() for alias in alias_list]))

# %% [markdown]
# ## UMLS Full Aliases

# %%
# Full UMLS
umls_to_alias = umls.get_aliases(ontologies_to_include='all',
                        use_umls_curies=True,
                        lowercase=True,
                        )

alias_to_umls = umls.get_aliases(ontologies_to_include='all',
                        use_umls_curies=True,
                        reverse=True,
                        lowercase=True,
                        )

with open("../data/umls_to_alias.txt", "w") as f:
    f.write(
        "\n".join(
            [
                curie + "||" + alias
                for curie, alias_list in umls_to_alias.items()
                for alias in alias_list
            ]
        )
    )

with open('../data/alias_to_umls.txt', 'w') as f:
    f.write('\n'.join([alias + '||' + '|'.join(curie) for alias, curie in alias_to_umls.items()]))

# %% [markdown]
# ## UMLS ST21PV Aliases

# %%
# ST21PV
st21pv_vocabs = ['MSH','CPT','FMA','GO', 'HGNC','HPO','ICD10','ICD10CM','ICD9CM','MDR','MTH','NCBI','NCI','NDDF','MED-RT','OMIM','RXNORM','SNOMEDCT_US']
unique_vocabs = umls.umls.sab.unique()
for x in st21pv_vocabs:
    if x not in unique_vocabs:
        print(x)
    assert x in unique_vocabs

st21pv_types = ujson.load(open('../data/st21pv_subtypes.json','r'))


st21pv_to_alias = umls.get_aliases(ontologies_to_include=st21pv_vocabs,
                        types_to_include=st21pv_types,
                        use_umls_curies=True,
                        lowercase=True,
                        )

alias_to_st21pv = umls.get_aliases(ontologies_to_include=st21pv_vocabs,
                        types_to_include=st21pv_types,
                        use_umls_curies=True,
                        reverse=True,
                        lowercase=True,
                        )


with open("../data/st21pv_to_alias.txt", "w") as f:
    f.write(
        "\n".join(
            [
                curie + "||" + alias
                for curie, alias_list in st21pv_to_alias.items()
                for alias in alias_list
            ]
        )
    )

with open('../data/alias_to_st21pv.txt', 'w') as f:
    f.write('\n'.join([alias + '||' + '|'.join(curie) for alias, curie in alias_to_st21pv.items()]))

# %% [markdown]
# ## Parse NCBI Taxonomy

# %%
ncbi = pd.read_csv('../data/ncbi_taxonomy_names.txt', delimiter='|', na_filter=False, index_col=False, names=['tax_id','name','unique_name','name_class'])
for col in ncbi.columns:
    if ncbi[col].dtype not in [int, float]:
        ncbi[col] = ncbi[col].map(lambda x: x.strip())
        
ncbi_scientific_names = ncbi.query('name_class == "scientific name"')
tax2name = ncbi_scientific_names.set_index('tax_id')['name'].to_dict()

with open('../data/tax2name.json','w') as f:
    f.write(ujson.dumps(tax2name, indent=2))

# %%
# Keep only name classes that encode useful information about aliases
ncbi = ncbi[ncbi.name_class.isin(['synonym','scientific name','blast name','equivalent name','genbank common name','common name','acronym','genbank acronym'])]
ncbi['tax_id'] = ncbi['tax_id'].map(lambda x: f'NCBI:{x}')

ncbi2alias = ncbi.groupby('tax_id').agg({'name':lambda x: list(set(x))}).to_dict()['name']

with open('../data/ncbi_to_alias.json','w') as f:
    f.write(ujson.dumps(ncbi2alias))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /nethome/dkartchner3/research/entity_linking/el-robustness-comparison/notebooks/obonet_curie_to_synonym.ipynb Cell 21 in <cell line: 5>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bmitch/nethome/dkartchner3/research/entity_linking/el-robustness-comparison/notebooks/obonet_curie_to_synonym.ipynb#X63sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> ncbi = ncbi[ncbi.name_class.isin(['synonym','scientific name','blast name','equivalent name','genbank common name','common name','acronym','genbank acronym'])]
#       <a href='vscode-notebook-cell://ssh-remote%2Bmitch/nethome/dkartchner3/research/entity_linking/el-robustness-comparison/notebooks/obonet_curie_to_synonym.ipynb#X63sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> ncbi['tax_id'] = ncbi['tax_id'].map(lambda x: f'NCBI:{x}')
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bmitch/nethome/dkartchner3/research/entity_linking/el-robustness-comparison/notebooks/obonet_curie_to_synonym.ipynb#X63sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> ncbi2alias = ncbi.groupby('tax_id').agg({'name':lambda x: list(set(x))}).to_dict()['name']
#       <a href='vscode-notebook-cell://ssh-remote%2Bmitch/nethome/dkartchner3/research/entity_linking/el-robustness-comparison/notebooks/obonet_curie_to_synonym.ipynb#X63sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> with open('../data/ncbi_to_alias.json','w') as f:
#       <a href='vscode-notebook-cell://ssh-remote%2Bmitch/nethome/dkartchner3/research/entity_linking/el-robustness-comparison/notebooks/obonet_curie_to_synonym.ipynb#X63sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>     f.write(ujson.dumps(ncbi2alias))
#
# File ~/conda_envs/el-robustness/lib/python3.9/site-packages/pandas/core/groupby/generic.py:890, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     887 func = maybe_mangle_lambdas(func)
#     889 op = GroupByApply(self, func, args, kwargs)
# --> 890 result = op.agg()
#     891 if not is_dict_like(func) and result is not None:
#     892     return result
#
# File ~/conda_envs/el-robustness/lib/python3.9/site-packages/pandas/core/apply.py:169, in Apply.agg(self)
#     166     return self.apply_str()
#     168 if is_dict_like(arg):
# --> 169     return self.agg_dict_like()
#     170 elif is_list_like(arg):
#     171     # we require a list, but not a 'str'
#     172     return self.agg_list_like()
#
# File ~/conda_envs/el-robustness/lib/python3.9/site-packages/pandas/core/apply.py:486, in Apply.agg_dict_like(self)
#     483     results = {key: colg.agg(how) for key, how in arg.items()}
#     484 else:
#     485     # key used for column selection and output
# --> 486     results = {
#     487         key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     488     }
#     490 # set the final keys
#     491 keys = list(arg.keys())
#
# File ~/conda_envs/el-robustness/lib/python3.9/site-packages/pandas/core/apply.py:487, in <dictcomp>(.0)
#     483     results = {key: colg.agg(how) for key, how in arg.items()}
#     484 else:
#     485     # key used for column selection and output
#     486     results = {
# --> 487         key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     488     }
#     490 # set the final keys
#     491 keys = list(arg.keys())
#
# File ~/conda_envs/el-robustness/lib/python3.9/site-packages/pandas/core/groupby/generic.py:298, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     295     return self._python_agg_general(func, *args, **kwargs)
#     297 try:
# --> 298     return self._python_agg_general(func, *args, **kwargs)
#     299 except KeyError:
#     300     # TODO: KeyError is raised in _python_agg_general,
#     301     #  see test_groupby.test_basic
#     302     result = self._aggregate_named(func, *args, **kwargs)
#
# File ~/conda_envs/el-robustness/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1665, in GroupBy._python_agg_general(self, func, raise_on_typeerror, *args, **kwargs)
#    1661 name = obj.name
#    1663 try:
#    1664     # if this function is invalid for this dtype, we will ignore it.
# -> 1665     result = self.grouper.agg_series(obj, f)
#    1666 except TypeError:
#    1667     if raise_on_typeerror:
#
# File ~/conda_envs/el-robustness/lib/python3.9/site-packages/pandas/core/groupby/ops.py:1082, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#    1079     preserve_dtype = True
#    1081 else:
# -> 1082     result = self._aggregate_series_pure_python(obj, func)
#    1084 npvalues = lib.maybe_convert_objects(result, try_float=False)
#    1085 if preserve_dtype:
#
# File ~/conda_envs/el-robustness/lib/python3.9/site-packages/pandas/core/groupby/ops.py:1104, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#    1101 # equiv: splitter = self._get_splitter(obj, axis=0)
#    1102 splitter = get_splitter(obj, ids, ngroups, axis=0)
# -> 1104 for i, group in enumerate(splitter):
#    1105     res = func(group)
#    1106     res = libreduction.extract_result(res)
#
# File ~/conda_envs/el-robustness/lib/python3.9/site-packages/pandas/core/groupby/ops.py:1333, in DataSplitter.__iter__(self)
#    1330 starts, ends = lib.generate_slices(self.slabels, self.ngroups)
#    1332 for start, end in zip(starts, ends):
# -> 1333     yield self._chop(sdata, slice(start, end))
#
# File ~/conda_envs/el-robustness/lib/python3.9/site-packages/pandas/core/groupby/ops.py:1348, in SeriesSplitter._chop(self, sdata, slice_obj)
#    1346 mgr = sdata._mgr.get_slice(slice_obj)
#    1347 ser = sdata._constructor(mgr, name=sdata.name, fastpath=True)
# -> 1348 return ser.__finalize__(sdata, method="groupby")
#
# File ~/conda_envs/el-robustness/lib/python3.9/site-packages/pandas/core/generic.py:5873, in NDFrame.__finalize__(self, other, method, **kwargs)
#    5870 for name in other.attrs:
#    5871     self.attrs[name] = other.attrs[name]
# -> 5873 self.flags.allows_duplicate_labels = other.flags.allows_duplicate_labels
#    5874 # For subclasses using _metadata.
#    5875 for name in set(self._metadata) & set(other._metadata):
#
# File ~/conda_envs/el-robustness/lib/python3.9/site-packages/pandas/core/flags.py:85, in Flags.allows_duplicate_labels(self, value)
#      55     """
#      56     Whether this object allows duplicate labels.
#      57
#    (...)
#      81     a        [0, 1]
#      82     """
#      83     return self._allows_duplicate_labels
# ---> 85 @allows_duplicate_labels.setter
#      86 def allows_duplicate_labels(self, value: bool) -> None:
#      87     value = bool(value)
#      88     obj = self._obj()
#
# KeyboardInterrupt:

# %%
ncbi.name_class.value_counts()
# Out:
# scientific name        2477980
# authority               651869
# synonym                 237259
# type material           203828
# includes                 71506
# equivalent name          55937
# genbank common name      30240
# common name              14610
# acronym                   2081
# in-part                    678
# blast name                 230
# genbank acronym             25
# Name: name_class, dtype: int64

# %% [markdown]
# ## Parsem Entrez (NCBI-Gene) Ontology

# %%
# taxa_used = [9606, 10090, 10116, 559292, 7227, 3702, 6239, 7955, 8355, 9940]
entrez = pd.read_csv(
    "../data/gene_info.tsv",
    delimiter="\t",
    usecols=[
        "#tax_id",
        "GeneID",
        "Symbol",
        "Synonyms",
        "Symbol_from_nomenclature_authority",
        "Full_name_from_nomenclature_authority",
        "Other_designations",
        "type_of_gene",
        "description",
        "dbXrefs"
    ],
    na_filter=False,
    low_memory=False,
).rename(
    {
        "Symbol_from_nomenclature_authority": "official_symbol",
        "Full_name_from_nomenclature_authority": "official_name",
        '#tax_id':'tax_id'
    }, axis=1,
)
entrez.columns = [x.lower() for x in entrez.columns]
# entrez = entrez[entrez.tax_id.isin(taxa_used)]

entrez
# Out:
#            tax_id    geneid     symbol synonyms dbxrefs  \
# 0               7   5692769   NEWENTRY        -       -
# 1               9   2827857   NEWENTRY        -       -
# 2              11  10823747   NEWENTRY        -       -
# 3              14   6951813   NEWENTRY        -       -
# 4              19   3758873   NEWENTRY        -       -
# ...           ...       ...        ...      ...     ...
# 41456246  2998809   2935004  OrniCt014        -       -
# 41456247  2998809   2935005  OrniCt017        -       -
# 41456248  2998809   3276630      rps12        -       -
# 41456249  2998809   4036376  OrniCt037        -       -
# 41456250  2998809   4036377  OrniCt038        -       -
#
#                                                 description    type_of_gene  \
# 0         Record to support submission of GeneRIFs for a...           other
# 1         Record to support submission of GeneRIFs for a...           other
# 2         Record to support submission of GeneRIFs for a...           other
# 3         Record to support submission of GeneRIFs for a...           other
# 4         Record to support submission of GeneRIFs for a...           other
# ...                                                     ...             ...
# 41456246                                           tRNA-Ser            tRNA
# 41456247                                           tRNA-Phe            tRNA
# 41456248                              ribosomal protein S12  protein-coding
# 41456249                                           tRNA-Ile            tRNA
# 41456250                                           tRNA-Leu            tRNA
#
#          official_symbol official_name     other_designations
# 0                      -             -                      -
# 1                      -             -                      -
# 2                      -             -                      -
# 3                      -             -                      -
# 4                      -             -                      -
# ...                  ...           ...                    ...
# 41456246               -             -                      -
# 41456247               -             -                      -
# 41456248               -             -  ribosomal protein S12
# 41456249               -             -                      -
# 41456250               -             -                      -
#
# [41456251 rows x 10 columns]

# %%
# Make DB xref dictionary
xref_df = entrez.query("dbxrefs != '-'")
xref_df = xref_df[['geneid','dbxrefs']]
xref_df['xref_list'] = xref_df.dbxrefs.map(lambda x: x.split('|'))
hgnc_omim_mask = xref_df.xref_list.map(lambda x: any([('MIM' in z.split(':')) or ('HGNC' in z.split(':')) for z in x]))



filtered = xref_df[hgnc_omim_mask]
filtered['filtered_xrefs'] = filtered.xref_list.map(lambda x: [':'.join(y.split(':')[-2:]) for y in x if (y.startswith('MIM') or y.startswith('HGNC'))])
filtered.geneid = filtered.geneid.map(lambda x: f'NCBIGene:{x}')
filtered = filtered.set_index("geneid")
entrez_to_hgnc_omim = filtered.filtered_xrefs.to_dict()

hgnc_omim_to_entrez = defaultdict(set)
for key, value in entrez_to_hgnc_omim.items():
    for x in value:
        hgnc_omim_to_entrez[x].add(key)

if max([len(x) for x in hgnc_omim_to_entrez.values()]) == 1:
    hgnc_omim_to_entrez = {key: list(val)[0] for key, val in hgnc_omim_to_entrez.items()}
else:
    hgnc_omim_to_entrez = {key: list(val) for key, val in hgnc_omim_to_entrez.items()}

# with open('../data/hgnc_omim2entrez.json','w') as f:
#     f.write(ujson.dumps(hgnc_omim_to_entrez))

# with open('../data/entrez2hgnc_omim.json','w') as f:
#     f.write(ujson.dumps(entrez_to_hgnc_omim))
# Out:
# /tmp/ipykernel_39621/1488975254.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['filtered_xrefs'] = filtered.xref_list.map(lambda x: [':'.join(y.split(':')[-2:]) for y in x if (y.startswith('MIM') or y.startswith('HGNC'))])
# /tmp/ipykernel_39621/1488975254.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered.geneid = filtered.geneid.map(lambda x: f'NCBIGene:{x}')

# %%
# Unique entities in NLM-Gene or GNormPlus
nlm_gene_data = conhelps.for_config_name(f"nlm_gene_bigbio_kb").load_dataset(from_hub=False)
df = dataset_to_df(nlm_gene_data)
all_nlm_gene_entities = set([])
for doc_id, normalizations in df[['document_id','db_ids']].values:
    if any([x for x in normalizations if x.endswith(':') ]):
        print(doc_id, normalizations)
    elif any([x for x in normalizations if ',' in x]):
        print(normalizations)
    all_nlm_gene_entities.update([x for x in normalizations])

# Unique entities in GNormPlus
gnormplus_data = conhelps.for_config_name(f"gnormplus_bigbio_kb").load_dataset(from_hub=False)
df = dataset_to_df(gnormplus_data)
all_gnormplus_entities = set([])
for normalizations in df['db_ids']:
    if any([x for x in normalizations if x.endswith(')') ]):
        print(normalizations)
    elif any([x for x in normalizations if ',' in x]):
        print(normalizations)
    all_gnormplus_entities.update([x for x in normalizations])
# Out:
# Found cached dataset nlm_gene (/home/dkartchner3/.cache/huggingface/datasets/nlm_gene/nlm_gene_bigbio_kb/1.0.0/92249f0c0c401d2d902c7a0af6d76ca2e535383a56c0c4d4099036c7c0dc9581)
#   0%|          | 0/2 [00:00<?, ?it/s]
# Found cached dataset gnormplus (/home/dkartchner3/.cache/huggingface/datasets/gnormplus/gnormplus_bigbio_kb/1.0.0/97a2714b58185305591c949b067cea2febfca2447016096c3d08021d84bf7b69)
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# Identify updated/discontinued entities in NLM-Gene
nlm_gene_ids = set([int(x.split(':')[-1]) for x in all_nlm_gene_entities])
nlm_gene_entity_mask = entrez.geneid.isin(nlm_gene_ids)
missing_nlm_gene_ids = nlm_gene_ids - set(entrez.loc[nlm_gene_entity_mask, 'geneid'].tolist())

# Find updated/discontinued entities in GNormPlus
gnormplus_ids = set([int(x.split(':')[-1]) for x in all_gnormplus_entities])
gnormplus_entity_mask = entrez.geneid.isin(gnormplus_ids)
missing_gnormplus_ids = gnormplus_ids - set(entrez.loc[gnormplus_entity_mask, 'geneid'].tolist())


# Mappings to correct missing ids
updated_nlm_gene_ids = {
    139: -1,
    502: 498,
    1651: 4137,
    7899: 392255,
    8097: 26353,
    22529: 108394,
    26916: 110253,
    38105: -1,
    38853: -1,
    47925: -1,
    55473: -1,
    98561: 59125,
    100934: 16826,
    113718: 284167,
    128039: -1,
    130505: -1,
    155841: -1,
    267370: -1,
    723788: 8412,
    3654564: -1,
    100911597: 25745,
}

updated_gnormplus_ids = {
    2087: -1,
    4197: 2122,
    4276: 100507436,
    6686: 123606,
    7330: 283556,
    3637603: -1,
    5692362: -1,
    7683036: -1,
    17494192: -1,
}

# Mappings to correct missing ids
updated_ids = {
    139: -1,
    502: 498,
    1651: 4137,
    2087: -1,
    7899: 392255,
    8097: 26353,
    22529: 108394,
    26916: 110253,
    38105: -1,
    38853: -1,
    47925: -1,
    55473: -1,
    98561: 59125,
    100934: 16826,
    113718: 284167,
    128039: -1,
    130505: -1,
    155841: -1,
    267370: -1,
    723788: 8412,
    3654564: -1,
    100911597: 25745,
    4197: 2122,
    4276: 100507436,
    6686: 123606,
    7330: 283556,
    3637603: -1,
    5692362: -1,
    7683036: -1,
    17494192: -1,
}

# %%
missing_gnormplus_ids
# Out:
# {2087, 4197, 4276, 6686, 7330, 3637603, 5692362, 7683036, 17494192}

# %%
# Fix missing ids
nlm_gene_ids |= set([x for x in updated_nlm_gene_ids.values() if x > 0])
nlm_gene_ids -= set(updated_nlm_gene_ids.keys())
all_nlm_gene_entities |= set([f'NCBIGene:{x}' for x in updated_nlm_gene_ids.values() if x > 0])
all_nlm_gene_entities -= set([f'NCBIGene:{x}' for x in updated_nlm_gene_ids.keys()])

gnormplus_ids |= set([x for x in updated_gnormplus_ids.values() if x > 0])
gnormplus_ids -= set(updated_gnormplus_ids.keys())
all_gnormplus_entities |= set([f'NCBIGene:{x}' for x in updated_gnormplus_ids.values() if x > 0])
all_gnormplus_entities -= set([f'NCBIGene:{x}' for x in updated_gnormplus_ids.keys()])

# %%
# Get subsets of taxonomy coresponding to each data subset
nlm_gene_entity_mask = entrez.geneid.isin(nlm_gene_ids)
nlm_gene_taxa = entrez[nlm_gene_entity_mask].tax_id.unique().tolist()
with open('../data/taxonomy_subsets/nlm_gene.json', 'w') as f:
    f.write(ujson.dumps(nlm_gene_taxa))


gnormplus_entity_mask = entrez.geneid.isin(gnormplus_ids)
gnormplus_taxa = entrez[gnormplus_entity_mask].tax_id.unique().tolist()
with open('../data/taxonomy_subsets/gnormplus.json', 'w') as f:
    f.write(ujson.dumps(gnormplus_taxa))

print(len(gnormplus_taxa))
# Out:
# 22

# %%
# Filter to only include genes from the taxonomies linked to by NLM-Gene and GNormPlus
# Filter out genes of type "unkonwn" and "tRNA" because they have large numbers of non-unique gene symbols
# Also filter out "NEWENTRY" entities (for adding new genes) and hypothetical proteins
nlm_gene_taxa_mask = (entrez.tax_id.isin(nlm_gene_taxa)) & (~entrez.type_of_gene.isin(['unknown','tRNA','biological-region'])) & (entrez.description != 'hypothetical protein') & (~entrez.official_name.map(lambda x: x.lower().startswith("predicted"))) #& (entrez.symbol != 'NEWENTRY')
gnormplus_taxa_mask = (entrez.tax_id.isin(gnormplus_taxa)) & (~entrez.type_of_gene.isin(['unknown','tRNA', 'biological-region'])) & (entrez.description != 'hypothetical protein') & (~entrez.official_name.map(lambda x: x.lower().startswith("predicted"))) #& (entrez.symbol != 'NEWENTRY')

print(nlm_gene_taxa_mask.sum())
print(gnormplus_taxa_mask.sum())
# Out:
# 704575
# 549545

# %%
# for mask in [nlm_gene_entity_mask, gnormplus_entity_mask]:
mask = nlm_gene_entity_mask | gnormplus_entity_mask
subset = entrez[mask]
display(pd.DataFrame(subset.type_of_gene.value_counts()))
display(subset[subset.type_of_gene=='unknown'])



all_dbs = [y for x in subset.dbxrefs.map(lambda x: [a for b in x.split('|') for a in b.split(':')] ) for y in x]
pd.Series(all_dbs).value_counts()[:30]
# Out:
#                 type_of_gene
# protein-coding          4416
# ncRNA                    103
# other                     22
# pseudo                    11
# unknown                    4
# miscRNA                    1
#           tax_id  geneid    symbol synonyms  \
# 5884075     7227  252643        Si        -
# 10180658    9606    6022      RMD1        -
# 11987771   10090   98285  AI255230        -
# 11993122   10090  114737      Iba1        -
#
#                                                     dbxrefs  \
# 5884075   FLYBASE:FBgn0003404|AllianceGenome:FB:FBgn0003404
# 10180658                                         MIM:600332
# 11987771                                    MGI:MGI:2138180
# 11993122                                    MGI:MGI:2149992
#
#                               description type_of_gene official_symbol  \
# 5884075                               Ski      unknown               -
# 10180658        rippling muscle disease 1      unknown               -
# 11987771      expressed sequence AI255230      unknown        AI255230
# 11993122  induction of brown adipocytes 1      unknown            Iba1
#
#                             official_name other_designations
# 5884075                                 -                  -
# 10180658                                -                  -
# 11987771      expressed sequence AI255230                  -
# 11993122  induction of brown adipocytes 1                  -
# HGNC              7145
# AllianceGenome    4250
# Ensembl           3981
# MGI               3299
# MIM               2350
# RGD                814
# SGD                302
# ZFIN               114
# FB                 110
# FLYBASE            110
# miRBase             88
# TAIR                80
# Araport             80
# WB                  58
# WormBase            58
# Xenbase             57
# -                   57
# EnsemblRapid        48
# VGNC                28
# IMGT/GENE-DB        13
# CGNC                 9
# BGD                  9
# ECOCYC               9
# ASAP                 9
# 3282                 4
# 2319                 4
# 3647                 4
# 2711                 4
# 3573                 4
# 2888                 4
# dtype: int64

# %%
# # Unique entities in NLM-Gene or GNormPlus
# nlm_gene_data = conhelps.for_config_name(f"nlm_gene_bigbio_kb").load_dataset()
# df = dataset_to_df(nlm_gene_data)
# all_nlm_gene_entities = set([])
# for normalizations in df['db_ids']:
#     # if any([x for x in normalizations if x.endswith(':') ]):
#     #     print(normalizations)
#     # elif any([x for x in normalizations if ',' in x]):
#     #     print(normalizations)
#     all_nlm_gene_entities.update([x for x in normalizations])

# # Identify updated/discontinued entities in NLM-Gene
# nlm_gene_ids = set([int(x.split(':')[-1]) for x in all_nlm_gene_entities])
# nlm_gene_entity_mask = entrez.geneid.isin(nlm_gene_ids)
# missing_nlm_gene_ids = nlm_gene_ids - set(entrez.loc[nlm_gene_entity_mask, 'geneid'].tolist())

# Filter Entrez to entities used in dataset
nlm_gene_filtered = entrez[nlm_gene_taxa_mask]

# Find duplicated symbols
nlm_gene_symbols = nlm_gene_filtered.symbol.value_counts()
nlm_gene_duplicated_symbols = nlm_gene_symbols[nlm_gene_symbols > 1].index.tolist()


# Add additional canonical symbol for symbols that are repeated across different organisms
nlm_gene_duplicated_symbol_mask = nlm_gene_filtered.symbol.isin(nlm_gene_duplicated_symbols)

nlm_gene_filtered['canonical_symbol'] = nlm_gene_filtered['symbol']
nlm_gene_filtered.loc[nlm_gene_duplicated_symbol_mask, 'canonical_symbol'] = nlm_gene_filtered.loc[nlm_gene_duplicated_symbol_mask, ['tax_id','symbol']].apply(lambda x: f"{x[1]} ({tax2name[x[0]]})", axis=1)


# Complie list of all symbols
nlm_gene_filtered['all_symbols'] = nlm_gene_filtered[['symbol','synonyms','official_symbol','official_name','other_designations', 'canonical_symbol']].progress_apply(lambda x: '|'.join(list(set([i for i in x if i.strip() != '-']))), axis=1)
nlm_gene_filtered['geneid'] = nlm_gene_filtered.geneid.map(lambda x: f"NCBIGene:{x}")
nlm_gene_geneid2synonym = nlm_gene_filtered.set_index('geneid')['all_symbols'].to_dict()

with open("../data/entrez_to_alias_nlm_gene.json",'w') as f:
    f.write(ujson.dumps(nlm_gene_geneid2synonym))
# Out:
# /tmp/ipykernel_13435/1668877624.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nlm_gene_filtered['canonical_symbol'] = nlm_gene_filtered['symbol']
#   0%|          | 0/704575 [00:00<?, ?it/s]
# /tmp/ipykernel_13435/1668877624.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nlm_gene_filtered['all_symbols'] = nlm_gene_filtered[['symbol','synonyms','official_symbol','official_name','other_designations', 'canonical_symbol']].progress_apply(lambda x: '|'.join(list(set([i for i in x if i.strip() != '-']))), axis=1)
# /tmp/ipykernel_13435/1668877624.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nlm_gene_filtered['geneid'] = nlm_gene_filtered.geneid.map(lambda x: f"NCBIGene:{x}")

# %%
# Filter Entrez to entities used in dataset
gnormplus_filtered = entrez[gnormplus_taxa_mask]

# Find duplicated symbols
gnormplus_symbols = gnormplus_filtered.symbol.value_counts()
gnormplus_duplicated_symbols = gnormplus_symbols[gnormplus_symbols > 1].index.tolist()


# Add additional canonical symbol for symbols that are repeated across different organisms
gnormplus_duplicated_symbol_mask = gnormplus_filtered.symbol.isin(gnormplus_duplicated_symbols)

gnormplus_filtered['canonical_symbol'] = gnormplus_filtered['symbol']
gnormplus_filtered.loc[gnormplus_duplicated_symbol_mask, 'canonical_symbol'] = gnormplus_filtered.loc[gnormplus_duplicated_symbol_mask, ['tax_id','symbol']].apply(lambda x: f"{x[1]} ({tax2name[x[0]]})", axis=1)


# Complie list of all symbols
gnormplus_filtered['all_symbols'] = gnormplus_filtered[['symbol','synonyms','official_symbol','official_name','other_designations', 'canonical_symbol']].progress_apply(lambda x: '|'.join(list(set([i for i in x if i.strip() != '-']))), axis=1)
gnormplus_filtered['geneid'] = gnormplus_filtered.geneid.map(lambda x: f"NCBIGene:{x}")
gnormplus_geneid2synonym = gnormplus_filtered.set_index('geneid')['all_symbols'].to_dict()

with open("../data/entrez_to_alias_gnormplus.json",'w') as f:
    f.write(ujson.dumps(gnormplus_geneid2synonym))
# Out:
# /tmp/ipykernel_13435/561726824.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gnormplus_filtered['canonical_symbol'] = gnormplus_filtered['symbol']
#   0%|          | 0/549545 [00:00<?, ?it/s]
# /tmp/ipykernel_13435/561726824.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gnormplus_filtered['all_symbols'] = gnormplus_filtered[['symbol','synonyms','official_symbol','official_name','other_designations', 'canonical_symbol']].progress_apply(lambda x: '|'.join(list(set([i for i in x if i.strip() != '-']))), axis=1)
# /tmp/ipykernel_13435/561726824.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gnormplus_filtered['geneid'] = gnormplus_filtered.geneid.map(lambda x: f"NCBIGene:{x}")

# %%
nlm_gene_filtered[['symbol','synonyms','official_symbol','official_name','other_designations','description','all_symbols']].sample(100)
# Out:
#                      symbol  \
# 9078218              MRPS27
# 9077413               PLCH1
# 8422001               pnn.L
# 11679835       LOC127490866
# 21575016         LOC9314147
# 10322912           MAPK8IP2
# 11985656      C030026M15Rik
# 33158216               NOP6
# 12071296             Tuba1a
# 1723690           AT4G07917
# 1732300           AT5G54043
# 21572953         LOC9311681
# 11557878              LMNB1
# 1723882           AT4G09480
# 21591108       LOC110226171
# 1730302                U6-1
# 4541511            C04C11.9
# 6908176            kiaa0040
# 12080637              Gstcd
# 8490089        LOC116408447
# 4499699              bigr-1
# 10331708            OR52AB4
# 12103754       LOC120095438
# 12097724            Sh2d1b2
# 1727061           AT1G04003
# 9068313               NR1H3
# 12110002       LOC120101686
# 4039221                sdh2
# 11665344       LOC103345267
# 5160201        LOC113799498
# 11461466              H3C10
# 4539803             T06F4.6
# 21587296         LOC9328762
# 8426051           LOC444844
# 21572059         LOC9310525
# 8483836        LOC101732611
# 1722840           AT3G31905
# 10243380       LOC124902757
# 10355101       LOC119868734
# 21571241         LOC9309575
# 10364729       LOC119878362
# 10192922             TXNRD3
# 10318952              WDR86
# 11449718             ZNF217
# 8424175              cbr4.L
# 11948748       LOC110298786
# 10196559          LINC00592
# 11660421       LOC100353722
# 10177973           B4GALNT1
# 33161169               REV1
# 21586208         LOC9327517
# 1723419           AT4G04140
# 4521954           21ur-8908
# 12096560       LOC102552104
# 21567443         LOC9305190
# 8482759               peds1
# 9068353             ALDH1A1
# 11290644               RAC2
# 10195615          LINC00504
# 17961415       NECAME_17790
# 11674497       LOC127485528
# 11999822      E530011L22Rik
# 11497771       LOC112446145
# 6889919               dmtf1
# 9090407        LOC112529972
# 4509573            F42E11.3
# 9091193        LOC112531843
# 10222395       LOC105376010
# 11815012              Lcn12
# 1081163   CHLRE_15g639000v5
# 11298404       LOC102167132
# 11650849       LOC100342323
# 11946669       LOC110296676
# 10205391              PGDP2
# 11590357       LOC121819492
# 21567438         LOC9305185
# 21585505         LOC9326652
# 10325889              SALL4
# 1066855   CHLRE_04g228650v5
# 8432871        LOC108695541
# 8461829        LOC121400564
# 10187630              EIF3L
# 6885351            atp6v1g1
# 10180117              PLOD2
# 17959581       NECAME_15955
# 5159067        LOC113798364
# 6909842        LOC101884596
# 21584572         LOC9325643
# 11453724              NOL11
# 11651034       LOC100342543
# 4522537            T19E7.23
# 1695239           AT2G17160
# 6906422             col5a3a
# 11966397             Adam12
# 11492561       LOC107133003
# 5891444                 Tmc
# 8424480             gskip.L
# 1710547           AT5G39900
# 11584934       LOC114115961
# 12013367            Trbj1-6
#
#                                                    synonyms official_symbol  \
# 9078218                                                   -          MRPS27
# 9077413                                         PLCD4|PLCL3           PLCH1
# 8422001     drs|drsp|mema|pinin|pnn|pnn-a|pnn-b|sdk2-a|sdk3           pnn.L
# 11679835                                                  -               -
# 21575016                                                  -               -
# 10322912                                                  -        MAPK8IP2
# 11985656                                                  -   C030026M15Rik
# 33158216                                                  -               -
# 12071296                                              Tuba1          Tuba1a
# 1723690                                                   -               -
# 1732300                                                   -               -
# 21572953                                                  -               -
# 11557878                                                  -               -
# 1723882                               T15G18.100|T15G18_100               -
# 21591108                                                  -               -
# 1730302      60477.SNRNA00001|U6 small nucleolar RNA1|U6.1*               -
# 4541511                                                   -               -
# 6908176                                                   -               -
# 12080637                                         RGD1311822           Gstcd
# 8490089                                                   -               -
# 4499699                                                   -               -
# 10331708                                                  -         OR52AB4
# 12103754                                                 U1    LOC120095438
# 12097724                                                  -         Sh2d1b2
# 1727061                                                   -               -
# 9068313                                            LXR|LXRA           NR1H3
# 12110002                                                  -    LOC120101686
# 4039221                                                   -               -
# 11665344                                                  -               -
# 5160201                                                   -               -
# 11461466                                                  -           H3C10
# 4539803                                                   -               -
# 21587296                                                  -               -
# 8426051                                                   -               -
# 21572059                                                  -               -
# 8483836                                                   -               -
# 1722840                                            T1O13.10               -
# 10243380                                                  -               -
# 10355101                                                  -               -
# 21571241                                                  -               -
# 10364729                                                  -               -
# 10192922  TGR|TR2|TR2IT1|TRXR3|TXNRD3IT1|TXNRD3NB|TXNRD3NT1          TXNRD3
# 10318952                                                  -           WDR86
# 11449718                                                  -          ZNF217
# 8424175                                                cbr4          cbr4.L
# 11948748                                                  -               -
# 10196559                                                  -       LINC00592
# 11660421                                              RPL12               -
# 10177973                       GALGT|GALNACT|GalNAc-T|SPG26        B4GALNT1
# 33161169                                                  -               -
# 21586208                                                  -               -
# 1723419                                   T24H24.6|T24H24_6               -
# 4521954                                                   -               -
# 12096560                                                  -    LOC102552104
# 21567443                                             ATXDH1               -
# 8482759                                         kua|tmem189           peds1
# 9068353                                              GGADHR         ALDH1A1
# 11290644                                                  -            RAC2
# 10195615                                                  -       LINC00504
# 17961415                                                  -               -
# 11674497                                                  -               -
# 11999822                                                  -   E530011L22Rik
# 11497771                                                  -               -
# 6889919                                           zgc:92448           dmtf1
# 9090407                                                   -    LOC112529972
# 4509573                                                   -               -
# 9091193                                                   -    LOC112531843
# 10222395                                                  -               -
# 11815012                                                  -               -
# 1081163                                                   -               -
# 11298404                                                  -               -
# 11650849                                             ALOXE3               -
# 11946669                                                  -               -
# 10205391                                                  -           PGDP2
# 11590357                                                  -               -
# 21567438                                             BGAL11               -
# 21585505                                                  -               -
# 10325889                                                  -           SALL4
# 1066855                                   CHLREDRAFT_145881               -
# 8432871                                                   -               -
# 8461829                                                   -               -
# 10187630   EIF3EIP|EIF3S11|EIF3S6IP|HSPC021|HSPC025|MSTP005           EIF3L
# 6885351                     wu:fa12a02|wu:fq38h02|zgc:73282        atp6v1g1
# 10180117                                      BRKS2|LH2|TLH           PLOD2
# 17959581                                                  -               -
# 5159067                                                   -               -
# 6909842                                                   -               -
# 21584572                                                  -               -
# 11453724                                                  -           NOL11
# 11651034                                                  -               -
# 4522537                                                   -               -
# 1695239                                     T23A1.2|T23A1_2               -
# 6906422                           col11a1|col5a3|wu:fb54e07         col5a3a
# 11966397                                              Mltna          Adam12
# 11492561                                                  -               -
# 5891444   CG14177|CG3280|CG46121|DmTMC|Dmel\CG46121|Dmel...             Tmc
# 8424480                                     c14orf129|gskip         gskip.L
# 1710547                                   MYH19.60|MYH19_60               -
# 11584934                                                  -               -
# 12013367                                            Gm16651         Trbj1-6
#
#                                               official_name  \
# 9078218                 mitochondrial ribosomal protein S27
# 9077413                               phospholipase C eta 1
# 8422001      pinin, desmosome associated protein L homeolog
# 11679835                                                  -
# 21575016                                                  -
# 10322912  mitogen-activated protein kinase 8 interacting...
# 11985656                         RIKEN cDNA C030026M15 gene
# 33158216                                                  -
# 12071296                                  tubulin, alpha 1A
# 1723690                                                   -
# 1732300                                                   -
# 21572953                                                  -
# 11557878                                                  -
# 1723882                                                   -
# 21591108                                                  -
# 1730302                                                   -
# 4541511                                                   -
# 6908176                                                   -
# 12080637  glutathione S-transferase, C-terminal domain c...
# 8490089                                                   -
# 4499699                                                   -
# 10331708  olfactory receptor family 52 subfamily AB memb...
# 12103754                                U1 spliceosomal RNA
# 12097724                          SH2 domain containing 1B2
# 1727061                                                   -
# 9068313       nuclear receptor subfamily 1 group H member 3
# 12110002                       uncharacterized LOC120101686
# 4039221                                                   -
# 11665344                                                  -
# 5160201                                                   -
# 11461466                            H3 clustered histone 10
# 4539803                                                   -
# 21587296                                                  -
# 8426051                                                   -
# 21572059                                                  -
# 8483836                                                   -
# 1722840                                                   -
# 10243380                                                  -
# 10355101                                                  -
# 21571241                                                  -
# 10364729                                                  -
# 10192922                            thioredoxin reductase 3
# 10318952                                WD repeat domain 86
# 11449718                            zinc finger protein 217
# 8424175                     carbonyl reductase 4 L homeolog
# 11948748                                                  -
# 10196559         long intergenic non-protein coding RNA 592
# 11660421                                                  -
# 10177973      beta-1,4-N-acetyl-galactosaminyltransferase 1
# 33161169                                                  -
# 21586208                                                  -
# 1723419                                                   -
# 4521954                                                   -
# 12096560          MLV-related proviral Env polyprotein-like
# 21567443                                                  -
# 8482759                  plasmanylethanolamine desaturase 1
# 9068353           aldehyde dehydrogenase 1 family member A1
# 11290644                          Rac family small GTPase 2
# 10195615         long intergenic non-protein coding RNA 504
# 17961415                                                  -
# 11674497                                                  -
# 11999822                         RIKEN cDNA E530011L22 gene
# 11497771                                                  -
# 6889919    cyclin D binding myb-like transcription factor 1
# 9090407                        uncharacterized LOC112529972
# 4509573                                                   -
# 9091193                        uncharacterized LOC112531843
# 10222395                                                  -
# 11815012                                                  -
# 1081163                                                   -
# 11298404                                                  -
# 11650849                                                  -
# 11946669                                                  -
# 10205391        phosphogluconate dehydrogenase pseudogene 2
# 11590357                                                  -
# 21567438                                                  -
# 21585505                                                  -
# 10325889                  spalt like transcription factor 4
# 1066855                                                   -
# 8432871                                                   -
# 8461829                                                   -
# 10187630  eukaryotic translation initiation factor 3 sub...
# 6885351                ATPase H+ transporting V1 subunit G1
# 10180117  procollagen-lysine,2-oxoglutarate 5-dioxygenase 2
# 17959581                                                  -
# 5159067                                                   -
# 6909842                                                   -
# 21584572                                                  -
# 11453724                               nucleolar protein 11
# 11651034                                                  -
# 4522537                                                   -
# 1695239                                                   -
# 6906422                          collagen, type V, alpha 3a
# 11966397  a disintegrin and metallopeptidase domain 12 (...
# 11492561                                                  -
# 5891444                          Transmembrane channel-like
# 8424480                GSK3B interacting protein L homeolog
# 1710547                                                   -
# 11584934                                                  -
# 12013367                   T cell receptor beta joining 1-6
#
#                                          other_designations  \
# 9078218            28S ribosomal protein S27, mitochondrial
# 9077413   1-phosphatidylinositol 4,5-bisphosphate phosph...
# 8422001   pinin, desmosome associated protein L homeolog...
# 11679835                                                  -
# 21575016  tRNA (guanine(26)-N(2))-dimethyltransferase|pr...
# 10322912  C-Jun-amino-terminal kinase-interacting protein 2
# 11985656                   uncharacterized protein LOC77378
# 33158216                                              Nop6p
# 12071296  tubulin alpha-1A chain|alpha-tubulin 1|tubulin...
# 1723690                                                   -
# 1732300                             uncharacterized protein
# 21572953                vacuolar iron transporter homolog 4
# 11557878                                           lamin-B1
# 1723882                                                   -
# 21591108               uncharacterized protein LOC110226171
# 1730302                                                   -
# 4541511                                                   -
# 6908176   uncharacterized protein KIAA0040|uncharacteriz...
# 12080637  glutathione S-transferase C-terminal domain-co...
# 8490089             calcium-dependent protein kinase C-like
# 4499699                             Uncharacterized protein
# 10331708  olfactory receptor family 52 subfamily AB memb...
# 12103754                                                  -
# 12097724  SH2 domain-containing protein 1B2-like|SH2 dom...
# 1727061                                                   -
# 9068313   oxysterols receptor LXR-alpha|liver X receptor...
# 12110002                                                  -
# 4039221   succinate dehydrogenase iron-sulfur subunit pr...
# 11665344                                                  -
# 5160201                                sorting nexin-2-like
# 11461466                                       histone H3.1
# 4539803                                                   -
# 21587296                 uncharacterized protein LOC9328762
# 8426051   T cell receptor beta variable 20-1|TCR VDJ BV2...
# 21572059                                                  -
# 8483836              nuclear receptor-interacting protein 3
# 1722840                                                   -
# 10243380                                                  -
# 10355101                                                  -
# 21571241  uncharacterized protein LOC9309575|monooxygena...
# 10364729                        olfactory receptor 6C2-like
# 10192922  thioredoxin reductase 3|TXNRD3 neighbor gene p...
# 10318952                    WD repeat-containing protein 86
# 11449718                            zinc finger protein 217
# 8424175   carbonyl reductase family member 4|3-ketoacyl-...
# 11948748                       olfactory receptor 10A5-like
# 10196559                                                  -
# 11660421                          60S ribosomal protein L12
# 10177973  beta-1,4 N-acetylgalactosaminyltransferase 1|G...
# 33161169                           deoxycytidyl transferase
# 21586208                 uncharacterized protein LOC9327517
# 1723419                                                   -
# 4521954                                                   -
# 12096560          MLV-related proviral Env polyprotein-like
# 21567443                           xanthine dehydrogenase 1
# 8482759                           transmembrane protein 189
# 9068353   aldehyde dehydrogenase 1A1|3-deoxyglucosone de...
# 11290644  ras-related C3 botulinum toxin substrate 2|ras...
# 10195615                                                  -
# 17961415                                                  -
# 11674497                      transcription factor E2-alpha
# 11999822                                                  -
# 11497771                                                  -
# 6889919    cyclin-D-binding Myb-like transcription factor 1
# 9090407                                                   -
# 4509573                             Uncharacterized protein
# 9091193                                                   -
# 10222395                                                  -
# 11815012                   epididymal-specific lipocalin-12
# 1081163                             uncharacterized protein
# 11298404                                                  -
# 11650849                     hydroperoxide isomerase ALOXE3
# 11946669       putative vomeronasal receptor-like protein 4
# 10205391                                                  -
# 11590357                     collagen alpha-1(I) chain-like
# 21567438                              beta-galactosidase 11
# 21585505                 uncharacterized protein LOC9326652
# 10325889                      sal-like protein 4|sal-like 4
# 1066855                             uncharacterized protein
# 8432871         gastrula zinc finger protein XlCGF52.1-like
# 8461829   cAMP-dependent protein kinase, catalytic subun...
# 10187630  eukaryotic translation initiation factor 3 sub...
# 6885351   V-type proton ATPase subunit G 1|ATPase, H+ tr...
# 10180117  procollagen-lysine,2-oxoglutarate 5-dioxygenas...
# 17959581                                                  -
# 5159067                uncharacterized protein LOC113798364
# 6909842                uncharacterized protein LOC101884596
# 21584572                               protein EFR3 homolog
# 11453724                               nucleolar protein 11
# 11651034                                                  -
# 4522537                                                   -
# 1695239   Interleukin-1 receptor-associated kinase 4 pro...
# 6906422   collagen alpha-3(V) chain|collagen, type V, al...
# 11966397  disintegrin and metalloproteinase domain-conta...
# 11492561                                                  -
# 5891444   transmembrane channel-like|CG46121-PC|CG46121-...
# 8424480                       GSK3-beta interaction protein
# 1710547                           Small GTP-binding protein
# 11584934                                                  -
# 12013367                                                  -
#
#                                                 description  \
# 9078218                 mitochondrial ribosomal protein S27
# 9077413                               phospholipase C eta 1
# 8422001      pinin, desmosome associated protein L homeolog
# 11679835                        small nucleolar RNA SNORA32
# 21575016        tRNA (guanine(26)-N(2))-dimethyltransferase
# 10322912  mitogen-activated protein kinase 8 interacting...
# 11985656                         RIKEN cDNA C030026M15 gene
# 33158216                                              Nop6p
# 12071296                                  tubulin, alpha 1A
# 1723690                                              pseudo
# 1732300                             uncharacterized protein
# 21572953                vacuolar iron transporter homolog 4
# 11557878                                           lamin B1
# 1723882                                              pseudo
# 21591108                       uncharacterized LOC110226171
# 1730302                                               ncRNA
# 4541511                                               ncRNA
# 6908176                                   KIAA0040 ortholog
# 12080637  glutathione S-transferase, C-terminal domain c...
# 8490089             calcium-dependent protein kinase C-like
# 4499699                             Uncharacterized protein
# 10331708  olfactory receptor family 52 subfamily AB memb...
# 12103754                                U1 spliceosomal RNA
# 12097724                          SH2 domain containing 1B2
# 1727061                                               ncRNA
# 9068313       nuclear receptor subfamily 1 group H member 3
# 12110002                       uncharacterized LOC120101686
# 4039221   succinate dehydrogenase iron-sulfur subunit pr...
# 11665344  sodium-dependent neutral amino acid transporte...
# 5160201                                sorting nexin-2-like
# 11461466                            H3 clustered histone 10
# 4539803                                               ncRNA
# 21587296                         uncharacterized LOC9328762
# 8426051                  T cell receptor beta variable 20-1
# 21572059                       vesicle transport v-SNARE 12
# 8483836              nuclear receptor interacting protein 3
# 1722840                                              pseudo
# 10243380                       uncharacterized LOC124902757
# 10355101           testis-specific Y-encoded protein 4-like
# 21571241                6-hydroxynicotinate 3-monooxygenase
# 10364729                        olfactory receptor 6C2-like
# 10192922                            thioredoxin reductase 3
# 10318952                                WD repeat domain 86
# 11449718                            zinc finger protein 217
# 8424175                     carbonyl reductase 4 L homeolog
# 11948748                       olfactory receptor 10A5-like
# 10196559         long intergenic non-protein coding RNA 592
# 11660421                              ribosomal protein L12
# 10177973      beta-1,4-N-acetyl-galactosaminyltransferase 1
# 33161169                           deoxycytidyl transferase
# 21586208                         uncharacterized LOC9327517
# 1723419                                              pseudo
# 4521954                                               ncRNA
# 12096560          MLV-related proviral Env polyprotein-like
# 21567443                           xanthine dehydrogenase 1
# 8482759                  plasmanylethanolamine desaturase 1
# 9068353           aldehyde dehydrogenase 1 family member A1
# 11290644                          Rac family small GTPase 2
# 10195615         long intergenic non-protein coding RNA 504
# 17961415               DNA-binding helix-turn-helix protein
# 11674497                             transcription factor 3
# 11999822                         RIKEN cDNA E530011L22 gene
# 11497771                                U2 spliceosomal RNA
# 6889919    cyclin D binding myb-like transcription factor 1
# 9090407                        uncharacterized LOC112529972
# 4509573                             Uncharacterized protein
# 9091193                        uncharacterized LOC112531843
# 10222395                       uncharacterized LOC105376010
# 11815012                                       lipocalin 12
# 1081163                             uncharacterized protein
# 11298404                       uncharacterized LOC102167132
# 11650849                        arachidonate lipoxygenase 3
# 11946669       putative vomeronasal receptor-like protein 4
# 10205391        phosphogluconate dehydrogenase pseudogene 2
# 11590357                     collagen alpha-1(I) chain-like
# 21567438                              beta-galactosidase 11
# 21585505                         uncharacterized LOC9326652
# 10325889                  spalt like transcription factor 4
# 1066855                             uncharacterized protein
# 8432871         gastrula zinc finger protein XlCGF52.1-like
# 8461829   cAMP-dependent protein kinase, catalytic subun...
# 10187630  eukaryotic translation initiation factor 3 sub...
# 6885351                ATPase H+ transporting V1 subunit G1
# 10180117  procollagen-lysine,2-oxoglutarate 5-dioxygenase 2
# 17959581                                         CoA-ligase
# 5159067                        uncharacterized LOC113798364
# 6909842                        uncharacterized LOC101884596
# 21584572                               protein EFR3 homolog
# 11453724                               nucleolar protein 11
# 11651034  mitochondrial amidoxime reducing component 2-like
# 4522537                                               ncRNA
# 1695239   Interleukin-1 receptor-associated kinase 4 pro...
# 6906422                          collagen, type V, alpha 3a
# 11966397  a disintegrin and metallopeptidase domain 12 (...
# 11492561        tripartite motif-containing protein 60-like
# 5891444                          Transmembrane channel-like
# 8424480                GSK3B interacting protein L homeolog
# 1710547                           Small GTP-binding protein
# 11584934                                U5 spliceosomal RNA
# 12013367                   T cell receptor beta joining 1-6
#
#                                                 all_symbols
# 9078218   MRPS27|MRPS27|mitochondrial ribosomal protein ...
# 9077413   PLCH1|PLCD4|PLCL3|PLCH1|phospholipase C eta 1|...
# 8422001   pnn.L|drs|drsp|mema|pinin|pnn|pnn-a|pnn-b|sdk2...
# 11679835                                       LOC127490866
# 21575016  LOC9314147|tRNA (guanine(26)-N(2))-dimethyltra...
# 10322912  MAPK8IP2|MAPK8IP2|mitogen-activated protein ki...
# 11985656  C030026M15Rik|C030026M15Rik|RIKEN cDNA C030026...
# 33158216                                         NOP6|Nop6p
# 12071296  Tuba1a|Tuba1|Tuba1a|tubulin, alpha 1A|tubulin ...
# 1723690                                           AT4G07917
# 1732300                   AT5G54043|uncharacterized protein
# 21572953     LOC9311681|vacuolar iron transporter homolog 4
# 11557878                                     LMNB1|lamin-B1
# 1723882                     AT4G09480|T15G18.100|T15G18_100
# 21591108  LOC110226171|uncharacterized protein LOC110226171
# 1730302   U6-1|60477.SNRNA00001|U6 small nucleolar RNA1|...
# 4541511                                            C04C11.9
# 6908176   kiaa0040|uncharacterized protein KIAA0040|unch...
# 12080637  Gstcd|RGD1311822|Gstcd|glutathione S-transfera...
# 8490089   LOC116408447|calcium-dependent protein kinase ...
# 4499699                      bigr-1|Uncharacterized protein
# 10331708  OR52AB4|OR52AB4|olfactory receptor family 52 s...
# 12103754   LOC120095438|U1|LOC120095438|U1 spliceosomal RNA
# 12097724  Sh2d1b2|Sh2d1b2|SH2 domain containing 1B2|SH2 ...
# 1727061                                           AT1G04003
# 9068313   NR1H3|LXR|LXRA|NR1H3|nuclear receptor subfamil...
# 12110002  LOC120101686|LOC120101686|uncharacterized LOC1...
# 4039221   sdh2|succinate dehydrogenase iron-sulfur subun...
# 11665344                                       LOC103345267
# 5160201                   LOC113799498|sorting nexin-2-like
# 11461466   H3C10|H3C10|H3 clustered histone 10|histone H3.1
# 4539803                                             T06F4.6
# 21587296      LOC9328762|uncharacterized protein LOC9328762
# 8426051   LOC444844|T cell receptor beta variable 20-1|T...
# 21572059                                         LOC9310525
# 8483836   LOC101732611|nuclear receptor-interacting prot...
# 1722840                                  AT3G31905|T1O13.10
# 10243380                                       LOC124902757
# 10355101                                       LOC119868734
# 21571241  LOC9309575|uncharacterized protein LOC9309575|...
# 10364729           LOC119878362|olfactory receptor 6C2-like
# 10192922  TXNRD3|TGR|TR2|TR2IT1|TRXR3|TXNRD3IT1|TXNRD3NB...
# 10318952  WDR86|WDR86|WD repeat domain 86|WD repeat-cont...
# 11449718  ZNF217|ZNF217|zinc finger protein 217|zinc fin...
# 8424175   cbr4.L|cbr4|cbr4.L|carbonyl reductase 4 L home...
# 11948748          LOC110298786|olfactory receptor 10A5-like
# 10196559  LINC00592|LINC00592|long intergenic non-protei...
# 11660421       LOC100353722|RPL12|60S ribosomal protein L12
# 10177973  B4GALNT1|GALGT|GALNACT|GalNAc-T|SPG26|B4GALNT1...
# 33161169                      REV1|deoxycytidyl transferase
# 21586208      LOC9327517|uncharacterized protein LOC9327517
# 1723419                         AT4G04140|T24H24.6|T24H24_6
# 4521954                                           21ur-8908
# 12096560  LOC102552104|LOC102552104|MLV-related proviral...
# 21567443         LOC9305190|ATXDH1|xanthine dehydrogenase 1
# 8482759   peds1|kua|tmem189|peds1|plasmanylethanolamine ...
# 9068353   ALDH1A1|GGADHR|ALDH1A1|aldehyde dehydrogenase ...
# 11290644  RAC2|RAC2|Rac family small GTPase 2|ras-relate...
# 10195615  LINC00504|LINC00504|long intergenic non-protei...
# 17961415                                       NECAME_17790
# 11674497         LOC127485528|transcription factor E2-alpha
# 11999822  E530011L22Rik|E530011L22Rik|RIKEN cDNA E530011...
# 11497771                                       LOC112446145
# 6889919   dmtf1|zgc:92448|dmtf1|cyclin D binding myb-lik...
# 9090407   LOC112529972|LOC112529972|uncharacterized LOC1...
# 4509573                    F42E11.3|Uncharacterized protein
# 9091193   LOC112531843|LOC112531843|uncharacterized LOC1...
# 10222395                                       LOC105376010
# 11815012             Lcn12|epididymal-specific lipocalin-12
# 1081163           CHLRE_15g639000v5|uncharacterized protein
# 11298404                                       LOC102167132
# 11650849  LOC100342323|ALOXE3|hydroperoxide isomerase AL...
# 11946669  LOC110296676|putative vomeronasal receptor-lik...
# 10205391  PGDP2|PGDP2|phosphogluconate dehydrogenase pse...
# 11590357        LOC121819492|collagen alpha-1(I) chain-like
# 21567438            LOC9305185|BGAL11|beta-galactosidase 11
# 21585505      LOC9326652|uncharacterized protein LOC9326652
# 10325889  SALL4|SALL4|spalt like transcription factor 4|...
# 1066855   CHLRE_04g228650v5|CHLREDRAFT_145881|uncharacte...
# 8432871   LOC108695541|gastrula zinc finger protein XlCG...
# 8461829   LOC121400564|cAMP-dependent protein kinase, ca...
# 10187630  EIF3L|EIF3EIP|EIF3S11|EIF3S6IP|HSPC021|HSPC025...
# 6885351   atp6v1g1|wu:fa12a02|wu:fq38h02|zgc:73282|atp6v...
# 10180117  PLOD2|BRKS2|LH2|TLH|PLOD2|procollagen-lysine,2...
# 17959581                                       NECAME_15955
# 5159067   LOC113798364|uncharacterized protein LOC113798364
# 6909842   LOC101884596|uncharacterized protein LOC101884596
# 21584572                    LOC9325643|protein EFR3 homolog
# 11453724  NOL11|NOL11|nucleolar protein 11|nucleolar pro...
# 11651034                                       LOC100342543
# 4522537                                            T19E7.23
# 1695239   AT2G17160|T23A1.2|T23A1_2|Interleukin-1 recept...
# 6906422   col5a3a|col11a1|col5a3|wu:fb54e07|col5a3a|coll...
# 11966397  Adam12|Mltna|Adam12|a disintegrin and metallop...
# 11492561                                       LOC107133003
# 5891444   Tmc|CG14177|CG3280|CG46121|DmTMC|Dmel\CG46121|...
# 8424480   gskip.L|c14orf129|gskip|gskip.L|GSK3B interact...
# 1710547   AT5G39900|MYH19.60|MYH19_60|Small GTP-binding ...
# 11584934                                       LOC114115961
# 12013367  Trbj1-6|Gm16651|Trbj1-6|T cell receptor beta j...

# %%
alias_to_entrez = defaultdict(set)
for geneid, synonyms in tqdm(geneid_to_synonym.items()):
    syns = set([x.strip() for x in synonyms.split('|')])
    for s in syns:
        alias_to_entrez[s].add(geneid)
# Out:
#   0%|          | 0/431643 [00:00<?, ?it/s]

# %%
len(entrez.geneid.unique())
# Out:
# 431643

# %%
with open('../data/alias_to_entrez.txt', 'w') as f:
    f.write('\n'.join([alias + '||' + '|'.join(str(curie)) for alias, curie in alias_to_entrez.items()]))

# %%
with open('../data/alias_to_entrez.txt', 'w') as f:
    f.write('\n'.join([str + '||' + '|'.join(str(curie)) for alias, curie in alias_to_entrez.items()]))

# %%
entrez_to_alias = defaultdict(set)
for alias, curie_set in alias_to_entrez.items():
    for curie in curie_set:
        entrez_to_alias[curie].add(alias)

with open('../data/entrez_to_alias.txt', 'w') as f:
    f.write('\n'.join(['ncbigene:' + str(curie) + '||' + alias for alias, curie_set in alias_to_entrez.items() for curie in curie_set]))



# max_len = 0
# for curie, alias_set in entrez_to_alias.items():
#     if len(alias_set) > max_len:
#         max_len = len(alias_set)
#         print(curie, alias_set)

# %%
print('Dmel\\CG9438')
# Out:
# Dmel\CG9438

# %% [markdown]
# # BigScience/Biomedical Demo Notebook
# ### 9/1/22
# ### Author: David Kartchner
#
# This notebook provides a

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import ujson

from bigbio.dataloader import BigBioConfigHelpers
from tqdm.auto import tqdm

import sys
sys.path.append('..')
from bigbio_utils import get_dataset_df

conhelps = BigBioConfigHelpers()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # TL;DR
# ### Get a dataset from BigBio preformatted, deduplicated, etc in a Pandas Dataframe

# %%
abbrev_dict = ujson.load(open('../data/abbreviations.json'))
data_df = get_dataset_df('ncbi_disease', abbrev_dict=abbrev_dict)
display(data_df.head())
data_df.to_dict(orient='records')[:5]
# Out:
# Found cached dataset ncbi_disease (/nethome/dkartchner3/.cache/huggingface/datasets/ncbi_disease/ncbi_disease_bigbio_kb/1.0.0/e6b217666a5647d5abc614785b2caad62f1d72a94d1631b86c0f615b75dcc865)
#   0%|          | 0/3 [00:00<?, ?it/s]
#   document_id         offsets                                     text  \
# 2    10021369      [[43, 76]]        adenomatous polyposis coli tumour
# 3    10021369     [[93, 132]]  adenomatous polyposis coli (APC) tumour
# 1    10021369    [[357, 372]]                          colon carcinoma
# 4    10021369    [[955, 970]]                          colon carcinoma
# 0    10021369  [[1090, 1096]]                                   cancer
#
#                 type          db_ids  split  mention_id  \
# 2         [Modifier]  [MESH:D011125]  train  10021369.1
# 3         [Modifier]  [MESH:D011125]  train  10021369.2
# 1         [Modifier]  [MESH:D003110]  train  10021369.3
# 4         [Modifier]  [MESH:D003110]  train  10021369.4
# 0  [SpecificDisease]  [MESH:D009369]  train  10021369.5
#
#                         deabbreviated_text
# 2        adenomatous polyposis coli tumour
# 3  adenomatous polyposis coli (APC) tumour
# 1                          colon carcinoma
# 4                          colon carcinoma
# 0                                   cancer
# [{'document_id': '10021369',
#   'offsets': [[43, 76]],
#   'text': 'adenomatous polyposis coli tumour',
#   'type': ['Modifier'],
#   'db_ids': ['MESH:D011125'],
#   'split': 'train',
#   'mention_id': '10021369.1',
#   'deabbreviated_text': 'adenomatous polyposis coli tumour'},
#  {'document_id': '10021369',
#   'offsets': [[93, 132]],
#   'text': 'adenomatous polyposis coli (APC) tumour',
#   'type': ['Modifier'],
#   'db_ids': ['MESH:D011125'],
#   'split': 'train',
#   'mention_id': '10021369.2',
#   'deabbreviated_text': 'adenomatous polyposis coli (APC) tumour'},
#  {'document_id': '10021369',
#   'offsets': [[357, 372]],
#   'text': 'colon carcinoma',
#   'type': ['Modifier'],
#   'db_ids': ['MESH:D003110'],
#   'split': 'train',
#   'mention_id': '10021369.3',
#   'deabbreviated_text': 'colon carcinoma'},
#  {'document_id': '10021369',
#   'offsets': [[955, 970]],
#   'text': 'colon carcinoma',
#   'type': ['Modifier'],
#   'db_ids': ['MESH:D003110'],
#   'split': 'train',
#   'mention_id': '10021369.4',
#   'deabbreviated_text': 'colon carcinoma'},
#  {'document_id': '10021369',
#   'offsets': [[1090, 1096]],
#   'text': 'cancer',
#   'type': ['SpecificDisease'],
#   'db_ids': ['MESH:D009369'],
#   'split': 'train',
#   'mention_id': '10021369.5',
#   'deabbreviated_text': 'cancer'}]

# %% [markdown]
# # Load a dataset
# **Example below uses MedMentions Full**
#
# Datasets we use in this project:
# * medmentions_full
# * medmentions_st21pv
# * bc5cdr
# * gnormplus
# * ncbi_disease
# * nlmchem
# * nlm_gene
#
# Soon to be included:
# * bc6id
# * plant_norm

# %%
data = conhelps.for_config_name(f"medmentions_full_bigbio_kb").load_dataset()
# Out:
# Reusing dataset medmentions (/home/dkartchner3/.cache/huggingface/datasets/medmentions/medmentions_full_bigbio_kb/1.0.0/3fc6b8a3681d540ae6c7497c238636b543b90764247b5ff3642d243474000794)
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
# Get a split of the data
train = data['train']
train
# Out:
# Dataset({
#     features: ['id', 'document_id', 'passages', 'entities', 'events', 'coreferences', 'relations'],
#     num_rows: 2635
# })

# %%
doc0 = train[0]
doc0
# Out:
# {'id': '0',
#  'document_id': '25763772',
#  'passages': [{'id': '110',
#    'type': 'title',
#    'text': ['DCTN4 as a modifier of chronic Pseudomonas aeruginosa infection in cystic fibrosis'],
#    'offsets': [[0, 82]]},
#   {'id': '111',
#    'type': 'abstract',
#    'text': ['Pseudomonas aeruginosa (Pa) infection in cystic fibrosis (CF) patients is associated with worse long-term pulmonary disease and shorter survival, and chronic Pa infection (CPA) is associated with reduced lung function, faster rate of lung decline, increased rates of exacerbations and shorter survival. By using exome sequencing and extreme phenotype design, it was recently shown that isoforms of dynactin 4 (DCTN4) may influence Pa infection in CF, leading to worse respiratory disease. The purpose of this study was to investigate the role of DCTN4 missense variants on Pa infection incidence, age at first Pa infection and chronic Pa infection incidence in a cohort of adult CF patients from a single centre. Polymerase chain reaction and direct sequencing were used to screen DNA samples for DCTN4 variants. A total of 121 adult CF patients from the Cochin Hospital CF centre have been included, all of them carrying two CFTR defects: 103 developed at least 1 pulmonary infection with Pa, and 68 patients of them had CPA. DCTN4 variants were identified in 24% (29/121) CF patients with Pa infection and in only 17% (3/18) CF patients with no Pa infection. Of the patients with CPA, 29% (20/68) had DCTN4 missense variants vs 23% (8/35) in patients without CPA. Interestingly, p.Tyr263Cys tend to be more frequently observed in CF patients with CPA than in patients without CPA (4/68 vs 0/35), and DCTN4 missense variants tend to be more frequent in male CF patients with CPA bearing two class II mutations than in male CF patients without CPA bearing two class II mutations (P = 0.06). Our observations reinforce that DCTN4 missense variants, especially p.Tyr263Cys, may be involved in the pathogenesis of CPA in male CF.'],
#    'offsets': [[83, 1809]]}],
#  'entities': [{'id': '1',
#    'type': 'T116',
#    'text': ['DCTN4'],
#    'offsets': [[0, 5]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C4308010'}]},
#   {'id': '2',
#    'type': 'T123',
#    'text': ['DCTN4'],
#    'offsets': [[0, 5]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C4308010'}]},
#   {'id': '3',
#    'type': 'T047',
#    'text': ['chronic Pseudomonas aeruginosa infection'],
#    'offsets': [[23, 63]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0854135'}]},
#   {'id': '4',
#    'type': 'T047',
#    'text': ['cystic fibrosis'],
#    'offsets': [[67, 82]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0010674'}]},
#   {'id': '5',
#    'type': 'T047',
#    'text': ['Pseudomonas aeruginosa (Pa) infection'],
#    'offsets': [[83, 120]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0854135'}]},
#   {'id': '6',
#    'type': 'T047',
#    'text': ['cystic fibrosis'],
#    'offsets': [[124, 139]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0010674'}]},
#   {'id': '7',
#    'type': 'T047',
#    'text': ['CF'],
#    'offsets': [[141, 143]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0010674'}]},
#   {'id': '8',
#    'type': 'T101',
#    'text': ['patients'],
#    'offsets': [[145, 153]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0030705'}]},
#   {'id': '9',
#    'type': 'T079',
#    'text': ['long-term'],
#    'offsets': [[179, 188]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0443252'}]},
#   {'id': '10',
#    'type': 'T047',
#    'text': ['pulmonary disease'],
#    'offsets': [[189, 206]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0024115'}]},
#   {'id': '11',
#    'type': 'T169',
#    'text': ['shorter survival'],
#    'offsets': [[211, 227]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0220921'}]},
#   {'id': '12',
#    'type': 'T047',
#    'text': ['chronic Pa infection'],
#    'offsets': [[233, 253]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0854135'}]},
#   {'id': '13',
#    'type': 'T047',
#    'text': ['CPA'],
#    'offsets': [[255, 258]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0854135'}]},
#   {'id': '14',
#    'type': 'T033',
#    'text': ['reduced lung function'],
#    'offsets': [[279, 300]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0847557'}]},
#   {'id': '15',
#    'type': 'T033',
#    'text': ['faster rate of lung decline'],
#    'offsets': [[302, 329]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C3160731'}]},
#   {'id': '16',
#    'type': 'T081',
#    'text': ['rates'],
#    'offsets': [[341, 346]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C1521828'}]},
#   {'id': '17',
#    'type': 'T033',
#    'text': ['exacerbations'],
#    'offsets': [[350, 363]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C4086268'}]},
#   {'id': '18',
#    'type': 'T169',
#    'text': ['shorter survival'],
#    'offsets': [[368, 384]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0220921'}]},
#   {'id': '19',
#    'type': 'T063',
#    'text': ['exome sequencing'],
#    'offsets': [[395, 411]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C3640077'}]},
#   {'id': '20',
#    'type': 'T052',
#    'text': ['extreme phenotype design'],
#    'offsets': [[416, 440]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C1707689'}]},
#   {'id': '21',
#    'type': 'T116',
#    'text': ['isoforms'],
#    'offsets': [[469, 477]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0597298'}]},
#   {'id': '22',
#    'type': 'T116',
#    'text': ['dynactin 4'],
#    'offsets': [[481, 491]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C4308010'}]},
#   {'id': '23',
#    'type': 'T123',
#    'text': ['dynactin 4'],
#    'offsets': [[481, 491]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C4308010'}]},
#   {'id': '24',
#    'type': 'T116',
#    'text': ['DCTN4'],
#    'offsets': [[493, 498]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C4308010'}]},
#   {'id': '25',
#    'type': 'T123',
#    'text': ['DCTN4'],
#    'offsets': [[493, 498]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C4308010'}]},
#   {'id': '26',
#    'type': 'T047',
#    'text': ['Pa infection'],
#    'offsets': [[514, 526]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0854135'}]},
#   {'id': '27',
#    'type': 'T047',
#    'text': ['CF'],
#    'offsets': [[530, 532]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0010674'}]},
#   {'id': '28',
#    'type': 'T047',
#    'text': ['respiratory disease'],
#    'offsets': [[551, 570]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0035204'}]},
#   {'id': '29',
#    'type': 'T062',
#    'text': ['study'],
#    'offsets': [[592, 597]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C2603343'}]},
#   {'id': '30',
#    'type': 'T169',
#    'text': ['investigate'],
#    'offsets': [[605, 616]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C1292732'}]},
#   {'id': '31',
#    'type': 'T116',
#    'text': ['DCTN4'],
#    'offsets': [[629, 634]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C4308010'}]},
#   {'id': '32',
#    'type': 'T123',
#    'text': ['DCTN4'],
#    'offsets': [[629, 634]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C4308010'}]},
#   {'id': '33',
#    'type': 'T033',
#    'text': ['missense'],
#    'offsets': [[635, 643]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C3845273'}]},
#   {'id': '34',
#    'type': 'T116',
#    'text': ['variants'],
#    'offsets': [[644, 652]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0597298'}]},
#   {'id': '35',
#    'type': 'T047',
#    'text': ['Pa infection'],
#    'offsets': [[656, 668]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0854135'}]},
#   {'id': '36',
#    'type': 'T081',
#    'text': ['incidence'],
#    'offsets': [[669, 678]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0021149'}]},
#   {'id': '37',
#    'type': 'T032',
#    'text': ['age'],
#    'offsets': [[680, 683]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0001779'}]},
#   {'id': '38',
#    'type': 'T047',
#    'text': ['Pa infection'],
#    'offsets': [[693, 705]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0854135'}]},
#   {'id': '39',
#    'type': 'T047',
#    'text': ['chronic Pa infection'],
#    'offsets': [[710, 730]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0854135'}]},
#   {'id': '40',
#    'type': 'T081',
#    'text': ['incidence'],
#    'offsets': [[731, 740]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0021149'}]},
#   {'id': '41',
#    'type': 'T098',
#    'text': ['cohort'],
#    'offsets': [[746, 752]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0599755'}]},
#   {'id': '42',
#    'type': 'T100',
#    'text': ['adult'],
#    'offsets': [[756, 761]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0001675'}]},
#   {'id': '43',
#    'type': 'T047',
#    'text': ['CF'],
#    'offsets': [[762, 764]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0010674'}]},
#   {'id': '44',
#    'type': 'T101',
#    'text': ['patients'],
#    'offsets': [[765, 773]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0030705'}]},
#   {'id': '45',
#    'type': 'T073',
#    'text': ['centre'],
#    'offsets': [[788, 794]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0475309'}]},
#   {'id': '46',
#    'type': 'T093',
#    'text': ['centre'],
#    'offsets': [[788, 794]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0475309'}]},
#   {'id': '47',
#    'type': 'T063',
#    'text': ['Polymerase chain reaction'],
#    'offsets': [[796, 821]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0032520'}]},
#   {'id': '48',
#    'type': 'T063',
#    'text': ['direct sequencing'],
#    'offsets': [[826, 843]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C3899368'}]},
#   {'id': '49',
#    'type': 'T026',
#    'text': ['DNA samples'],
#    'offsets': [[864, 875]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0444245'}]},
#   {'id': '50',
#    'type': 'T116',
#    'text': ['DCTN4'],
#    'offsets': [[880, 885]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C4308010'}]},
#   {'id': '51',
#    'type': 'T123',
#    'text': ['DCTN4'],
#    'offsets': [[880, 885]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C4308010'}]},
#   {'id': '52',
#    'type': 'T116',
#    'text': ['variants'],
#    'offsets': [[886, 894]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0597298'}]},
#   {'id': '53',
#    'type': 'T100',
#    'text': ['adult'],
#    'offsets': [[911, 916]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0001675'}]},
#   {'id': '54',
#    'type': 'T047',
#    'text': ['CF'],
#    'offsets': [[917, 919]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0010674'}]},
#   {'id': '55',
#    'type': 'T101',
#    'text': ['patients'],
#    'offsets': [[920, 928]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0030705'}]},
#   {'id': '56',
#    'type': 'T073',
#    'text': ['Cochin Hospital CF centre'],
#    'offsets': [[938, 963]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0019994'}]},
#   {'id': '57',
#    'type': 'T093',
#    'text': ['Cochin Hospital CF centre'],
#    'offsets': [[938, 963]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0019994'}]},
#   {'id': '58',
#    'type': 'T028',
#    'text': ['CFTR'],
#    'offsets': [[1009, 1013]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C1413365'}]},
#   {'id': '59',
#    'type': 'T169',
#    'text': ['defects'],
#    'offsets': [[1014, 1021]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0243067'}]},
#   {'id': '60',
#    'type': 'T047',
#    'text': ['pulmonary infection'],
#    'offsets': [[1048, 1067]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0876973'}]},
#   {'id': '61',
#    'type': 'T007',
#    'text': ['Pa'],
#    'offsets': [[1073, 1075]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0033809'}]},
#   {'id': '62',
#    'type': 'T101',
#    'text': ['patients'],
#    'offsets': [[1084, 1092]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0030705'}]},
#   {'id': '63',
#    'type': 'T047',
#    'text': ['CPA'],
#    'offsets': [[1105, 1108]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0854135'}]},
#   {'id': '64',
#    'type': 'T116',
#    'text': ['DCTN4'],
#    'offsets': [[1110, 1115]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C4308010'}]},
#   {'id': '65',
#    'type': 'T123',
#    'text': ['DCTN4'],
#    'offsets': [[1110, 1115]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C4308010'}]},
#   {'id': '66',
#    'type': 'T116',
#    'text': ['variants'],
#    'offsets': [[1116, 1124]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0597298'}]},
#   {'id': '67',
#    'type': 'T047',
#    'text': ['CF'],
#    'offsets': [[1157, 1159]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0010674'}]},
#   {'id': '68',
#    'type': 'T101',
#    'text': ['patients'],
#    'offsets': [[1160, 1168]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0030705'}]},
#   {'id': '69',
#    'type': 'T047',
#    'text': ['Pa infection'],
#    'offsets': [[1174, 1186]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0854135'}]},
#   {'id': '70',
#    'type': 'T047',
#    'text': ['CF'],
#    'offsets': [[1210, 1212]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0010674'}]},
#   {'id': '71',
#    'type': 'T101',
#    'text': ['patients'],
#    'offsets': [[1213, 1221]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0030705'}]},
#   {'id': '72',
#    'type': 'T047',
#    'text': ['Pa infection'],
#    'offsets': [[1230, 1242]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0854135'}]},
#   {'id': '73',
#    'type': 'T101',
#    'text': ['patients'],
#    'offsets': [[1251, 1259]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0030705'}]},
#   {'id': '74',
#    'type': 'T047',
#    'text': ['CPA'],
#    'offsets': [[1265, 1268]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0854135'}]},
#   {'id': '75',
#    'type': 'T116',
#    'text': ['DCTN4'],
#    'offsets': [[1286, 1291]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C4308010'}]},
#   {'id': '76',
#    'type': 'T123',
#    'text': ['DCTN4'],
#    'offsets': [[1286, 1291]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C4308010'}]},
#   {'id': '77',
#    'type': 'T033',
#    'text': ['missense'],
#    'offsets': [[1292, 1300]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C3845273'}]},
#   {'id': '78',
#    'type': 'T116',
#    'text': ['variants'],
#    'offsets': [[1301, 1309]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0597298'}]},
#   {'id': '79',
#    'type': 'T101',
#    'text': ['patients'],
#    'offsets': [[1327, 1335]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0030705'}]},
#   {'id': '80',
#    'type': 'T047',
#    'text': ['CPA'],
#    'offsets': [[1344, 1347]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0854135'}]},
#   {'id': '81',
#    'type': 'T116',
#    'text': ['p.Tyr263Cys'],
#    'offsets': [[1364, 1375]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0597298'}]},
#   {'id': '82',
#    'type': 'T047',
#    'text': ['CF'],
#    'offsets': [[1415, 1417]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0010674'}]},
#   {'id': '83',
#    'type': 'T101',
#    'text': ['patients'],
#    'offsets': [[1418, 1426]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0030705'}]},
#   {'id': '84',
#    'type': 'T047',
#    'text': ['CPA'],
#    'offsets': [[1432, 1435]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0854135'}]},
#   {'id': '85',
#    'type': 'T101',
#    'text': ['patients'],
#    'offsets': [[1444, 1452]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0030705'}]},
#   {'id': '86',
#    'type': 'T047',
#    'text': ['CPA'],
#    'offsets': [[1461, 1464]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0854135'}]},
#   {'id': '87',
#    'type': 'T116',
#    'text': ['DCTN4'],
#    'offsets': [[1485, 1490]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C4308010'}]},
#   {'id': '88',
#    'type': 'T123',
#    'text': ['DCTN4'],
#    'offsets': [[1485, 1490]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C4308010'}]},
#   {'id': '89',
#    'type': 'T033',
#    'text': ['missense'],
#    'offsets': [[1491, 1499]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C3845273'}]},
#   {'id': '90',
#    'type': 'T116',
#    'text': ['variants'],
#    'offsets': [[1500, 1508]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0597298'}]},
#   {'id': '91',
#    'type': 'T032',
#    'text': ['male'],
#    'offsets': [[1537, 1541]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0086582'}]},
#   {'id': '92',
#    'type': 'T047',
#    'text': ['CF'],
#    'offsets': [[1542, 1544]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0010674'}]},
#   {'id': '93',
#    'type': 'T101',
#    'text': ['patients'],
#    'offsets': [[1545, 1553]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0030705'}]},
#   {'id': '94',
#    'type': 'T047',
#    'text': ['CPA'],
#    'offsets': [[1559, 1562]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0854135'}]},
#   {'id': '95',
#    'type': 'T045',
#    'text': ['class II mutations'],
#    'offsets': [[1575, 1593]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0026882'}]},
#   {'id': '96',
#    'type': 'T032',
#    'text': ['male'],
#    'offsets': [[1602, 1606]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0086582'}]},
#   {'id': '97',
#    'type': 'T047',
#    'text': ['CF'],
#    'offsets': [[1607, 1609]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0010674'}]},
#   {'id': '98',
#    'type': 'T101',
#    'text': ['patients'],
#    'offsets': [[1610, 1618]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0030705'}]},
#   {'id': '99',
#    'type': 'T047',
#    'text': ['CPA'],
#    'offsets': [[1627, 1630]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0854135'}]},
#   {'id': '100',
#    'type': 'T045',
#    'text': ['class II mutations'],
#    'offsets': [[1643, 1661]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0026882'}]},
#   {'id': '101',
#    'type': 'T116',
#    'text': ['DCTN4'],
#    'offsets': [[1706, 1711]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C4308010'}]},
#   {'id': '102',
#    'type': 'T123',
#    'text': ['DCTN4'],
#    'offsets': [[1706, 1711]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C4308010'}]},
#   {'id': '103',
#    'type': 'T033',
#    'text': ['missense'],
#    'offsets': [[1712, 1720]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C3845273'}]},
#   {'id': '104',
#    'type': 'T116',
#    'text': ['variants'],
#    'offsets': [[1721, 1729]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0597298'}]},
#   {'id': '105',
#    'type': 'T116',
#    'text': ['p.Tyr263Cys'],
#    'offsets': [[1742, 1753]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0597298'}]},
#   {'id': '106',
#    'type': 'T046',
#    'text': ['pathogenesis'],
#    'offsets': [[1778, 1790]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0699748'}]},
#   {'id': '107',
#    'type': 'T047',
#    'text': ['CPA'],
#    'offsets': [[1794, 1797]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0854135'}]},
#   {'id': '108',
#    'type': 'T032',
#    'text': ['male'],
#    'offsets': [[1801, 1805]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0086582'}]},
#   {'id': '109',
#    'type': 'T047',
#    'text': ['CF'],
#    'offsets': [[1806, 1808]],
#    'normalized': [{'db_name': 'UMLS', 'db_id': 'C0010674'}]}],
#  'events': [],
#  'coreferences': [],
#  'relations': []}

# %% [markdown]
# ## Passages
# * id: Unique id of each passage
# * type: Type of passage (e.g. title, abstract, etc).  Not always meaningful
# * text: Text of passage.  Represented as list in case of multiple chunck of included text
# * offsets: offsets of each chunk of text in passage (as measured from beginning of entire document and assuming that there is exactly one space between passages)

# %%
doc0['passages']
# Out:
# [{'id': '110',
#   'type': 'title',
#   'text': ['DCTN4 as a modifier of chronic Pseudomonas aeruginosa infection in cystic fibrosis'],
#   'offsets': [[0, 82]]},
#  {'id': '111',
#   'type': 'abstract',
#   'text': ['Pseudomonas aeruginosa (Pa) infection in cystic fibrosis (CF) patients is associated with worse long-term pulmonary disease and shorter survival, and chronic Pa infection (CPA) is associated with reduced lung function, faster rate of lung decline, increased rates of exacerbations and shorter survival. By using exome sequencing and extreme phenotype design, it was recently shown that isoforms of dynactin 4 (DCTN4) may influence Pa infection in CF, leading to worse respiratory disease. The purpose of this study was to investigate the role of DCTN4 missense variants on Pa infection incidence, age at first Pa infection and chronic Pa infection incidence in a cohort of adult CF patients from a single centre. Polymerase chain reaction and direct sequencing were used to screen DNA samples for DCTN4 variants. A total of 121 adult CF patients from the Cochin Hospital CF centre have been included, all of them carrying two CFTR defects: 103 developed at least 1 pulmonary infection with Pa, and 68 patients of them had CPA. DCTN4 variants were identified in 24% (29/121) CF patients with Pa infection and in only 17% (3/18) CF patients with no Pa infection. Of the patients with CPA, 29% (20/68) had DCTN4 missense variants vs 23% (8/35) in patients without CPA. Interestingly, p.Tyr263Cys tend to be more frequently observed in CF patients with CPA than in patients without CPA (4/68 vs 0/35), and DCTN4 missense variants tend to be more frequent in male CF patients with CPA bearing two class II mutations than in male CF patients without CPA bearing two class II mutations (P = 0.06). Our observations reinforce that DCTN4 missense variants, especially p.Tyr263Cys, may be involved in the pathogenesis of CPA in male CF.'],
#   'offsets': [[83, 1809]]}]

# %% [markdown]
# ## Entity Annotations
# * type: Unique id assigned to entity annotation
# * type: Type of the entity.  Note that entities with multiple type annotations will be listed multiple times
# * text: Text of the entity.  Since some entities are discontiguous (may be split up), this is listed as a list of lists (see **Nuances** below)
# * offsets: Where in the text entity is located.  May have multiple sets of offsets for discontiguous entities (see **Nuances** below)
# * normalized: Database identifier to which entity is linked.  In some cases, the text could be linked to multiple entities (e.g. from separate databases)
#
# ### Nuances
# 1. If a data point has multiple types, it is included once for each type.  For example, "acetaminophen" could be both an `organic chemical` and a `pharmalogial substance`.  In this case, there will be two separate entries in the entity list, one with each type.
# 2. Some entities may be *noncontiguous*.  For example, the phrase `cardiovascular and pulmonary fibrosis` has two entities -- `cardiovascular fibrosis` and `pulmonary fibrosis`.  In this case, `cardiovascular fibrosis` will contain two sets of entity offsets

# %%
doc0['entities']
# Out:
# [{'id': '1',
#   'type': 'T116',
#   'text': ['DCTN4'],
#   'offsets': [[0, 5]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C4308010'}]},
#  {'id': '2',
#   'type': 'T123',
#   'text': ['DCTN4'],
#   'offsets': [[0, 5]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C4308010'}]},
#  {'id': '3',
#   'type': 'T047',
#   'text': ['chronic Pseudomonas aeruginosa infection'],
#   'offsets': [[23, 63]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0854135'}]},
#  {'id': '4',
#   'type': 'T047',
#   'text': ['cystic fibrosis'],
#   'offsets': [[67, 82]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0010674'}]},
#  {'id': '5',
#   'type': 'T047',
#   'text': ['Pseudomonas aeruginosa (Pa) infection'],
#   'offsets': [[83, 120]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0854135'}]},
#  {'id': '6',
#   'type': 'T047',
#   'text': ['cystic fibrosis'],
#   'offsets': [[124, 139]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0010674'}]},
#  {'id': '7',
#   'type': 'T047',
#   'text': ['CF'],
#   'offsets': [[141, 143]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0010674'}]},
#  {'id': '8',
#   'type': 'T101',
#   'text': ['patients'],
#   'offsets': [[145, 153]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0030705'}]},
#  {'id': '9',
#   'type': 'T079',
#   'text': ['long-term'],
#   'offsets': [[179, 188]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0443252'}]},
#  {'id': '10',
#   'type': 'T047',
#   'text': ['pulmonary disease'],
#   'offsets': [[189, 206]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0024115'}]},
#  {'id': '11',
#   'type': 'T169',
#   'text': ['shorter survival'],
#   'offsets': [[211, 227]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0220921'}]},
#  {'id': '12',
#   'type': 'T047',
#   'text': ['chronic Pa infection'],
#   'offsets': [[233, 253]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0854135'}]},
#  {'id': '13',
#   'type': 'T047',
#   'text': ['CPA'],
#   'offsets': [[255, 258]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0854135'}]},
#  {'id': '14',
#   'type': 'T033',
#   'text': ['reduced lung function'],
#   'offsets': [[279, 300]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0847557'}]},
#  {'id': '15',
#   'type': 'T033',
#   'text': ['faster rate of lung decline'],
#   'offsets': [[302, 329]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C3160731'}]},
#  {'id': '16',
#   'type': 'T081',
#   'text': ['rates'],
#   'offsets': [[341, 346]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C1521828'}]},
#  {'id': '17',
#   'type': 'T033',
#   'text': ['exacerbations'],
#   'offsets': [[350, 363]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C4086268'}]},
#  {'id': '18',
#   'type': 'T169',
#   'text': ['shorter survival'],
#   'offsets': [[368, 384]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0220921'}]},
#  {'id': '19',
#   'type': 'T063',
#   'text': ['exome sequencing'],
#   'offsets': [[395, 411]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C3640077'}]},
#  {'id': '20',
#   'type': 'T052',
#   'text': ['extreme phenotype design'],
#   'offsets': [[416, 440]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C1707689'}]},
#  {'id': '21',
#   'type': 'T116',
#   'text': ['isoforms'],
#   'offsets': [[469, 477]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0597298'}]},
#  {'id': '22',
#   'type': 'T116',
#   'text': ['dynactin 4'],
#   'offsets': [[481, 491]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C4308010'}]},
#  {'id': '23',
#   'type': 'T123',
#   'text': ['dynactin 4'],
#   'offsets': [[481, 491]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C4308010'}]},
#  {'id': '24',
#   'type': 'T116',
#   'text': ['DCTN4'],
#   'offsets': [[493, 498]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C4308010'}]},
#  {'id': '25',
#   'type': 'T123',
#   'text': ['DCTN4'],
#   'offsets': [[493, 498]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C4308010'}]},
#  {'id': '26',
#   'type': 'T047',
#   'text': ['Pa infection'],
#   'offsets': [[514, 526]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0854135'}]},
#  {'id': '27',
#   'type': 'T047',
#   'text': ['CF'],
#   'offsets': [[530, 532]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0010674'}]},
#  {'id': '28',
#   'type': 'T047',
#   'text': ['respiratory disease'],
#   'offsets': [[551, 570]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0035204'}]},
#  {'id': '29',
#   'type': 'T062',
#   'text': ['study'],
#   'offsets': [[592, 597]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C2603343'}]},
#  {'id': '30',
#   'type': 'T169',
#   'text': ['investigate'],
#   'offsets': [[605, 616]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C1292732'}]},
#  {'id': '31',
#   'type': 'T116',
#   'text': ['DCTN4'],
#   'offsets': [[629, 634]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C4308010'}]},
#  {'id': '32',
#   'type': 'T123',
#   'text': ['DCTN4'],
#   'offsets': [[629, 634]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C4308010'}]},
#  {'id': '33',
#   'type': 'T033',
#   'text': ['missense'],
#   'offsets': [[635, 643]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C3845273'}]},
#  {'id': '34',
#   'type': 'T116',
#   'text': ['variants'],
#   'offsets': [[644, 652]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0597298'}]},
#  {'id': '35',
#   'type': 'T047',
#   'text': ['Pa infection'],
#   'offsets': [[656, 668]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0854135'}]},
#  {'id': '36',
#   'type': 'T081',
#   'text': ['incidence'],
#   'offsets': [[669, 678]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0021149'}]},
#  {'id': '37',
#   'type': 'T032',
#   'text': ['age'],
#   'offsets': [[680, 683]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0001779'}]},
#  {'id': '38',
#   'type': 'T047',
#   'text': ['Pa infection'],
#   'offsets': [[693, 705]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0854135'}]},
#  {'id': '39',
#   'type': 'T047',
#   'text': ['chronic Pa infection'],
#   'offsets': [[710, 730]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0854135'}]},
#  {'id': '40',
#   'type': 'T081',
#   'text': ['incidence'],
#   'offsets': [[731, 740]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0021149'}]},
#  {'id': '41',
#   'type': 'T098',
#   'text': ['cohort'],
#   'offsets': [[746, 752]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0599755'}]},
#  {'id': '42',
#   'type': 'T100',
#   'text': ['adult'],
#   'offsets': [[756, 761]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0001675'}]},
#  {'id': '43',
#   'type': 'T047',
#   'text': ['CF'],
#   'offsets': [[762, 764]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0010674'}]},
#  {'id': '44',
#   'type': 'T101',
#   'text': ['patients'],
#   'offsets': [[765, 773]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0030705'}]},
#  {'id': '45',
#   'type': 'T073',
#   'text': ['centre'],
#   'offsets': [[788, 794]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0475309'}]},
#  {'id': '46',
#   'type': 'T093',
#   'text': ['centre'],
#   'offsets': [[788, 794]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0475309'}]},
#  {'id': '47',
#   'type': 'T063',
#   'text': ['Polymerase chain reaction'],
#   'offsets': [[796, 821]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0032520'}]},
#  {'id': '48',
#   'type': 'T063',
#   'text': ['direct sequencing'],
#   'offsets': [[826, 843]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C3899368'}]},
#  {'id': '49',
#   'type': 'T026',
#   'text': ['DNA samples'],
#   'offsets': [[864, 875]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0444245'}]},
#  {'id': '50',
#   'type': 'T116',
#   'text': ['DCTN4'],
#   'offsets': [[880, 885]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C4308010'}]},
#  {'id': '51',
#   'type': 'T123',
#   'text': ['DCTN4'],
#   'offsets': [[880, 885]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C4308010'}]},
#  {'id': '52',
#   'type': 'T116',
#   'text': ['variants'],
#   'offsets': [[886, 894]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0597298'}]},
#  {'id': '53',
#   'type': 'T100',
#   'text': ['adult'],
#   'offsets': [[911, 916]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0001675'}]},
#  {'id': '54',
#   'type': 'T047',
#   'text': ['CF'],
#   'offsets': [[917, 919]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0010674'}]},
#  {'id': '55',
#   'type': 'T101',
#   'text': ['patients'],
#   'offsets': [[920, 928]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0030705'}]},
#  {'id': '56',
#   'type': 'T073',
#   'text': ['Cochin Hospital CF centre'],
#   'offsets': [[938, 963]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0019994'}]},
#  {'id': '57',
#   'type': 'T093',
#   'text': ['Cochin Hospital CF centre'],
#   'offsets': [[938, 963]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0019994'}]},
#  {'id': '58',
#   'type': 'T028',
#   'text': ['CFTR'],
#   'offsets': [[1009, 1013]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C1413365'}]},
#  {'id': '59',
#   'type': 'T169',
#   'text': ['defects'],
#   'offsets': [[1014, 1021]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0243067'}]},
#  {'id': '60',
#   'type': 'T047',
#   'text': ['pulmonary infection'],
#   'offsets': [[1048, 1067]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0876973'}]},
#  {'id': '61',
#   'type': 'T007',
#   'text': ['Pa'],
#   'offsets': [[1073, 1075]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0033809'}]},
#  {'id': '62',
#   'type': 'T101',
#   'text': ['patients'],
#   'offsets': [[1084, 1092]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0030705'}]},
#  {'id': '63',
#   'type': 'T047',
#   'text': ['CPA'],
#   'offsets': [[1105, 1108]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0854135'}]},
#  {'id': '64',
#   'type': 'T116',
#   'text': ['DCTN4'],
#   'offsets': [[1110, 1115]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C4308010'}]},
#  {'id': '65',
#   'type': 'T123',
#   'text': ['DCTN4'],
#   'offsets': [[1110, 1115]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C4308010'}]},
#  {'id': '66',
#   'type': 'T116',
#   'text': ['variants'],
#   'offsets': [[1116, 1124]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0597298'}]},
#  {'id': '67',
#   'type': 'T047',
#   'text': ['CF'],
#   'offsets': [[1157, 1159]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0010674'}]},
#  {'id': '68',
#   'type': 'T101',
#   'text': ['patients'],
#   'offsets': [[1160, 1168]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0030705'}]},
#  {'id': '69',
#   'type': 'T047',
#   'text': ['Pa infection'],
#   'offsets': [[1174, 1186]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0854135'}]},
#  {'id': '70',
#   'type': 'T047',
#   'text': ['CF'],
#   'offsets': [[1210, 1212]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0010674'}]},
#  {'id': '71',
#   'type': 'T101',
#   'text': ['patients'],
#   'offsets': [[1213, 1221]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0030705'}]},
#  {'id': '72',
#   'type': 'T047',
#   'text': ['Pa infection'],
#   'offsets': [[1230, 1242]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0854135'}]},
#  {'id': '73',
#   'type': 'T101',
#   'text': ['patients'],
#   'offsets': [[1251, 1259]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0030705'}]},
#  {'id': '74',
#   'type': 'T047',
#   'text': ['CPA'],
#   'offsets': [[1265, 1268]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0854135'}]},
#  {'id': '75',
#   'type': 'T116',
#   'text': ['DCTN4'],
#   'offsets': [[1286, 1291]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C4308010'}]},
#  {'id': '76',
#   'type': 'T123',
#   'text': ['DCTN4'],
#   'offsets': [[1286, 1291]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C4308010'}]},
#  {'id': '77',
#   'type': 'T033',
#   'text': ['missense'],
#   'offsets': [[1292, 1300]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C3845273'}]},
#  {'id': '78',
#   'type': 'T116',
#   'text': ['variants'],
#   'offsets': [[1301, 1309]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0597298'}]},
#  {'id': '79',
#   'type': 'T101',
#   'text': ['patients'],
#   'offsets': [[1327, 1335]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0030705'}]},
#  {'id': '80',
#   'type': 'T047',
#   'text': ['CPA'],
#   'offsets': [[1344, 1347]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0854135'}]},
#  {'id': '81',
#   'type': 'T116',
#   'text': ['p.Tyr263Cys'],
#   'offsets': [[1364, 1375]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0597298'}]},
#  {'id': '82',
#   'type': 'T047',
#   'text': ['CF'],
#   'offsets': [[1415, 1417]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0010674'}]},
#  {'id': '83',
#   'type': 'T101',
#   'text': ['patients'],
#   'offsets': [[1418, 1426]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0030705'}]},
#  {'id': '84',
#   'type': 'T047',
#   'text': ['CPA'],
#   'offsets': [[1432, 1435]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0854135'}]},
#  {'id': '85',
#   'type': 'T101',
#   'text': ['patients'],
#   'offsets': [[1444, 1452]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0030705'}]},
#  {'id': '86',
#   'type': 'T047',
#   'text': ['CPA'],
#   'offsets': [[1461, 1464]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0854135'}]},
#  {'id': '87',
#   'type': 'T116',
#   'text': ['DCTN4'],
#   'offsets': [[1485, 1490]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C4308010'}]},
#  {'id': '88',
#   'type': 'T123',
#   'text': ['DCTN4'],
#   'offsets': [[1485, 1490]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C4308010'}]},
#  {'id': '89',
#   'type': 'T033',
#   'text': ['missense'],
#   'offsets': [[1491, 1499]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C3845273'}]},
#  {'id': '90',
#   'type': 'T116',
#   'text': ['variants'],
#   'offsets': [[1500, 1508]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0597298'}]},
#  {'id': '91',
#   'type': 'T032',
#   'text': ['male'],
#   'offsets': [[1537, 1541]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0086582'}]},
#  {'id': '92',
#   'type': 'T047',
#   'text': ['CF'],
#   'offsets': [[1542, 1544]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0010674'}]},
#  {'id': '93',
#   'type': 'T101',
#   'text': ['patients'],
#   'offsets': [[1545, 1553]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0030705'}]},
#  {'id': '94',
#   'type': 'T047',
#   'text': ['CPA'],
#   'offsets': [[1559, 1562]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0854135'}]},
#  {'id': '95',
#   'type': 'T045',
#   'text': ['class II mutations'],
#   'offsets': [[1575, 1593]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0026882'}]},
#  {'id': '96',
#   'type': 'T032',
#   'text': ['male'],
#   'offsets': [[1602, 1606]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0086582'}]},
#  {'id': '97',
#   'type': 'T047',
#   'text': ['CF'],
#   'offsets': [[1607, 1609]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0010674'}]},
#  {'id': '98',
#   'type': 'T101',
#   'text': ['patients'],
#   'offsets': [[1610, 1618]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0030705'}]},
#  {'id': '99',
#   'type': 'T047',
#   'text': ['CPA'],
#   'offsets': [[1627, 1630]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0854135'}]},
#  {'id': '100',
#   'type': 'T045',
#   'text': ['class II mutations'],
#   'offsets': [[1643, 1661]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0026882'}]},
#  {'id': '101',
#   'type': 'T116',
#   'text': ['DCTN4'],
#   'offsets': [[1706, 1711]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C4308010'}]},
#  {'id': '102',
#   'type': 'T123',
#   'text': ['DCTN4'],
#   'offsets': [[1706, 1711]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C4308010'}]},
#  {'id': '103',
#   'type': 'T033',
#   'text': ['missense'],
#   'offsets': [[1712, 1720]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C3845273'}]},
#  {'id': '104',
#   'type': 'T116',
#   'text': ['variants'],
#   'offsets': [[1721, 1729]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0597298'}]},
#  {'id': '105',
#   'type': 'T116',
#   'text': ['p.Tyr263Cys'],
#   'offsets': [[1742, 1753]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0597298'}]},
#  {'id': '106',
#   'type': 'T046',
#   'text': ['pathogenesis'],
#   'offsets': [[1778, 1790]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0699748'}]},
#  {'id': '107',
#   'type': 'T047',
#   'text': ['CPA'],
#   'offsets': [[1794, 1797]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0854135'}]},
#  {'id': '108',
#   'type': 'T032',
#   'text': ['male'],
#   'offsets': [[1801, 1805]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0086582'}]},
#  {'id': '109',
#   'type': 'T047',
#   'text': ['CF'],
#   'offsets': [[1806, 1808]],
#   'normalized': [{'db_name': 'UMLS', 'db_id': 'C0010674'}]}]

# %%
# %load_ext autoreload
# %autoreload 2

import pickle
import ujson
import sys
import os

import pandas as pd
import numpy as np

from tqdm import tqdm
from collections import defaultdict

from bigbio.dataloader import BigBioConfigHelpers
from bigbio.utils.constants import Tasks


sys.path.append('..')
from bigbio_utils import CUIS_TO_REMAP, CUIS_TO_EXCLUDE, DATASET_NAMES
from bigbio_utils import dataset_to_documents, dataset_to_df, resolve_abbreviation

conhelps = BigBioConfigHelpers()

pd.set_option('display.max_rows', 200)

# %%
def get_overlap(df, dataset_name=None, plot=False):
    """
    Overlap between train mentions and test mentions.

    Return both the % of entities that overlap and the % of mentions with eneities that appear in train set (since some entities appear more than once)
    """
    # Get unique entities in data splits
    train_df = df.query('split == "train"')
    test_df = df.query('split == "test"')
    train_valid_df = df.query('split != "test"')
    unique_train = set(train_df.db_id.unique())
    unique_test = set(test_df.db_id.unique())
    unique_train_valid = set(train_valid_df.db_id.unique())
    unique_ents = df.db_id.unique()

    # Get total number of unique entities by type
    ents_by_type = df.groupby("type").agg({"db_id": "nunique"}).to_dict()['db_id']
    mention_counts_by_type = df.groupby("type").agg({"db_id": "count"}).to_dict()['db_id']

    # Get distribution of entities
    if plot:
        test_df["in_train"] = test_df.db_id.isin(unique_train)
        curie_counts = (
            test_df.groupby("db_id")
            .agg({"mention_id": "count", "in_train": "first"})
            .rename({"mention_id": "cui_num_test_mentions"}, axis=1)
        )
        sns.displot(
            data=curie_counts, x="cui_num_test_mentions", hue="in_train", log_scale=True
        )
        if dataset_name is not None:
            plt.title(dataset_name)
        plt.show()

    # Get overlap of mentions
    train_test_ent_overlap = len(unique_test.intersection(unique_train)) / len(
        unique_test
    )
    test_ent_overlap = len(unique_test.intersection(unique_train_valid)) / len(
        unique_test
    )
    mention_overlap = test_df["db_id"].isin(unique_train).mean()
    return {
        "unique_ents": len(unique_ents),
        "ent_overlap": train_test_ent_overlap,
        "mention_overlap": mention_overlap,
        # "ent_counts_by_type": ents_by_type,
        # 'mention_counts_by_type': mention_counts_by_type,
        'unique_types': len(df.type.unique()),
        "total_documents": len(df.pmid.unique()),
        "train_documents": len(train_df.pmid.unique()),
        "test_documents": len(test_df.pmid.unique()),
        "total_mentions": df.shape[0],
        "train_mentions": train_df.shape[0],
        "test_mentions": test_df.shape[0],
        "has_validation_set": ("validation" in df.split.unique()),
    }


def dataset_to_df(dataset):
    '''
    Convert BigBio dataset to pandas DataFrame
    '''
    columns = [
        "pmid",
        "mention_id",
        "text",
        "type",
        "db_name",
        "db_id",
        "split",
    ]
    all_lines = []
    for split in dataset.keys():
        for doc in dataset[split]:
            pmid = doc["document_id"]
            for e in doc["entities"]:
                if len(e["normalized"]) == 0:
                    continue
                text = " ".join(e["text"])
                db_name = e["normalized"][0]["db_name"]
                db_id = e["normalized"][0]["db_id"]
                all_lines.append(
                    [pmid, e["id"], text, e["type"], db_name, db_id, split]
                )

    return pd.DataFrame(all_lines, columns=columns)



# Basic tests to see if functions work
# bc5cdr_df = dataset_to_df(bc5cdr_bigbio)
# get_overlap(bc5cdr_df)

# %%
all_stats = []
for dataset in tqdm(['medmentions_full','medmentions_st21pv','bc5cdr','gnormplus','ncbi_disease','nlmchem', 'nlm_gene']):
    data = conhelps.for_config_name(f"{dataset}_bigbio_kb").load_dataset()
    df = dataset_to_df(data)
    stats = get_overlap(df, dataset)
    stats['dataset'] = dataset
    all_stats.append(stats)
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]Reusing dataset med_mentions_dataset (/Users/david/.cache/huggingface/datasets/med_mentions_dataset/medmentions_full_bigbio_kb/1.0.0/b5c8691186d4701f9b18eddbe36d178ccf7e55761dcc6140c57f4410754511ac)
# 100%|██████████| 3/3 [00:00<00:00, 389.67it/s]
#  14%|█▍        | 1/7 [00:06<00:40,  6.77s/it]Reusing dataset med_mentions_dataset (/Users/david/.cache/huggingface/datasets/med_mentions_dataset/medmentions_st21pv_bigbio_kb/1.0.0/b5c8691186d4701f9b18eddbe36d178ccf7e55761dcc6140c57f4410754511ac)
# 100%|██████████| 3/3 [00:00<00:00, 286.54it/s]
#  29%|██▊       | 2/7 [00:10<00:25,  5.07s/it]Reusing dataset bc5cdr_dataset (/Users/david/.cache/huggingface/datasets/bc5cdr_dataset/bc5cdr_bigbio_kb/1.0.0/f01f16ea9b65ead985bedadf7335195c32297c8f1b09417fc607b102a6757d6f)
# 100%|██████████| 3/3 [00:00<00:00, 394.37it/s]
#  43%|████▎     | 3/7 [00:11<00:12,  3.20s/it]Reusing dataset gnormplus_dataset (/Users/david/.cache/huggingface/datasets/gnormplus_dataset/gnormplus_bigbio_kb/1.0.0/1bb16f1b4abf9394b9180cac70edc575cc5e7d32c697f8b9f69ba2f643d2fc95)
# 100%|██████████| 2/2 [00:00<00:00, 448.32it/s]
#  57%|█████▋    | 4/7 [00:11<00:06,  2.01s/it]Reusing dataset ncbi_disease_dataset (/Users/david/.cache/huggingface/datasets/ncbi_disease_dataset/ncbi_disease_bigbio_kb/1.0.0/10a393201e55b403e5d107701b719368f54f1bf3d3438a1233f99be0badeb034)
# 100%|██████████| 3/3 [00:00<00:00, 510.38it/s]
#  71%|███████▏  | 5/7 [00:11<00:02,  1.35s/it]Reusing dataset nlm_chem_dataset (/Users/david/.cache/huggingface/datasets/nlm_chem_dataset/nlmchem_bigbio_kb/1.0.0/d91131823c66b7dd1162027991ea47c342e478209b37cf261c5f122d30409594)
# 100%|██████████| 3/3 [00:00<00:00, 495.35it/s]
#  86%|████████▌ | 6/7 [00:13<00:01,  1.25s/it]Reusing dataset nlm_gene_dataset (/Users/david/.cache/huggingface/datasets/nlm_gene_dataset/nlm_gene_bigbio_kb/1.0.0/4291402c7589961b34294745522bffe7e289d8f6c11d99a66d93362c0d30187d)
# 100%|██████████| 2/2 [00:00<00:00, 384.46it/s]
# 100%|██████████| 7/7 [00:13<00:00,  1.91s/it]

# %%
all_stats
# Out:
# [{'unique_ents': 34724,
#   'ent_overlap': 0.6199371930107094,
#   'mention_overlap': 0.8221204512041217,
#   'unique_types': 127,
#   'total_documents': 4392,
#   'train_documents': 2635,
#   'test_documents': 879,
#   'total_mentions': 385098,
#   'train_mentions': 230591,
#   'test_mentions': 76861,
#   'has_validation_set': True,
#   'dataset': 'medmentions_full'},
#  {'unique_ents': 25419,
#   'ent_overlap': 0.5754995861416577,
#   'mention_overlap': 0.7740867096645666,
#   'unique_types': 21,
#   'total_documents': 4392,
#   'train_documents': 2635,
#   'test_documents': 879,
#   'total_mentions': 203282,
#   'train_mentions': 122241,
#   'test_mentions': 40157,
#   'has_validation_set': True,
#   'dataset': 'medmentions_st21pv'},
#  {'unique_ents': 2348,
#   'ent_overlap': 0.5300380228136882,
#   'mention_overlap': 0.7733048693707432,
#   'unique_types': 2,
#   'total_documents': 1500,
#   'train_documents': 500,
#   'test_documents': 500,
#   'total_mentions': 29044,
#   'train_mentions': 9494,
#   'test_mentions': 9837,
#   'has_validation_set': True,
#   'dataset': 'bc5cdr'},
#  {'unique_ents': 1353,
#   'ent_overlap': 0.07894736842105263,
#   'mention_overlap': 0.08377288240769469,
#   'unique_types': 2,
#   'total_documents': 533,
#   'train_documents': 279,
#   'test_documents': 254,
#   'total_mentions': 6252,
#   'train_mentions': 3029,
#   'test_mentions': 3223,
#   'has_validation_set': False,
#   'dataset': 'gnormplus'},
#  {'unique_ents': 789,
#   'ent_overlap': 0.6699507389162561,
#   'mention_overlap': 0.815625,
#   'unique_types': 4,
#   'total_documents': 792,
#   'train_documents': 592,
#   'test_documents': 100,
#   'total_mentions': 6881,
#   'train_mentions': 5134,
#   'test_mentions': 960,
#   'has_validation_set': True,
#   'dataset': 'ncbi_disease'},
#  {'unique_ents': 1787,
#   'ent_overlap': 0.4747225647348952,
#   'mention_overlap': 0.6228987993138937,
#   'unique_types': 1,
#   'total_documents': 150,
#   'train_documents': 80,
#   'test_documents': 50,
#   'total_mentions': 37999,
#   'train_mentions': 21044,
#   'test_mentions': 11660,
#   'has_validation_set': True,
#   'dataset': 'nlmchem'},
#  {'unique_ents': 3348,
#   'ent_overlap': 0.48191365227537925,
#   'mention_overlap': 0.5408348457350273,
#   'unique_types': 5,
#   'total_documents': 550,
#   'train_documents': 450,
#   'test_documents': 100,
#   'total_mentions': 15553,
#   'train_mentions': 12798,
#   'test_mentions': 2755,
#   'has_validation_set': False,
#   'dataset': 'nlm_gene'}]

# %%
dataset_to_doc_type = {
    "medmentions_full": "PubMed Abstracts",
    "medmentions_st21pv": "PubMed Abstracts",
    "bc5cdr": "PubMed Abstracts",
    "gnormplus": "PubMed Abstracts",
    "ncbi_disease": "PubMed Abstracts",
    "nlmchem": "PMC Full-Text",
    "craft": "PMC Full-Text",
    "bc6id": "PMC Figure Captions",
    "bc3gm": "PMC Full-Text",
    "plantnorm": "PubMed Abstracts",
    "nlm_gene": "PMC Full-Text",
}

dataset_to_ontology = {
    "medmentions_full": "UMLS",
    "medmentions_st21pv": "UMLS",
    "bc5cdr": "MeSH",
    "gnormplus": "Entrez",
    "ncbi_disease": "MeSH, OMIM",
    "nlmchem": "MeSH",
    "craft": "Many",
    "bc6id": "Many",
    "bc3gm": "Entrez",
    "plantnorm": "NCBI Taxonomy",
    'nlm_gene': 'Entrez',
}

dataset_to_pretty_name = {
    "medmentions_full": "MedMentions Full",
    "medmentions_st21pv": "MedMentions ST21PV",
    "bc5cdr": "BC5CDR",
    "gnormplus": "GNormPlus",
    "ncbi_disease": "NCBI Disease",
    "nlmchem": "NLM Chem",
    "craft": "CRAFT",
    "bc6id": "BC6ID",
    "bc3gm": "BC3GM",
    "plantnorm": "PlantNorm",
    'nlm_gene': "NLM Gene"
}

dataset_to_paper_url = {
    "medmentions_full": "[(Mohan and Li, 2019)](https://github.com/chanzuckerberg/MedMentions)",
    "medmentions_st21pv": "[(Mohan and Li, 2019)](https://github.com/chanzuckerberg/MedMentions)",
    "bc5cdr": "[(Li et al, 2016)](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4860626)",
    "gnormplus": "[(Wei et al, 2016)](https://www.ncbi.nlm.nih.gov/research/bionlp/Tools/gnormplus)",
    "ncbi_disease": "[(Dogan et al, 2014)](https://www.sciencedirect.com/science/article/pii/S1532046413001974?via%3Dihub)",
    "nlmchem": "[(Islamaj et al, 2021)](https://www.nature.com/articles/s41597-021-00875-1)",
    "craft": "[(Bada et al, 2012)](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3476437)",
    "bc6id": "[(Arighi et al, 2017)](https://bmcbioinformatics.biomedcentral.com/articles/10.1186/1471-2105-12-S8-S2)",
    "bc3gm": "[(Lu et al, 2011)](https://bmcbioinformatics.biomedcentral.com/articles/10.1186/1471-2105-12-S8-S2)",
    "plantnorm": "[(Cho et al, 2017)](https://pubmed.ncbi.nlm.nih.gov/29029598)",
    'nlm_gene': "[(Islamaj et al, 2021)](https://doi.org/10.1016/j.jbi.2021.103779)"
}

dataset_to_citation = {
    "medmentions_full": "mohan2019medmentions",
    "medmentions_st21pv": "mohan2019medmentions",
    "bc5cdr": "li2016bc5cdr",
    "gnormplus": "wei2015gnormplus",
    "ncbi_disease": "dougan2014ncbi",
    "nlmchem": "islamaj2021nlm_chem",
    "craft": "bada2012craft_concept",
    "bc6id": "arighi2017bc6id",
    "bc3gm": "lu2011bc3gn",
    "plantnorm": "cho2017plantnorm",
    'nlm_gene': "islamaj2021nlm_gene"
}

output = pd.DataFrame.from_records(all_stats)
output["source_documents"] = output.dataset.map(dataset_to_doc_type)
output["linked_ontology"] = output.dataset.map(dataset_to_ontology)
for col in ["unique_ents", "total_documents", "total_mentions"]:
    output[col] = output[col].map(lambda x: "{:,}".format(x))

output_subset = (
    output[
        [
            "dataset",
            "total_documents",
            "total_mentions",
            "unique_ents",
            'unique_types',
            "ent_overlap",
            "mention_overlap",
            "source_documents",
            "linked_ontology",
        ]
    ]
    .rename({"unique_ents": "unique_entities", "ent_overlap": "entity_overlap"}, axis=1)
    .round(4)
)



# Make Markdown Tables
markdown_output = output_subset.copy()
markdown_output["dataset"] = markdown_output.dataset.map(
    lambda x: dataset_to_pretty_name[x] + " " + dataset_to_paper_url[x]
)
markdown_output.columns = [
    " ".join(x.split("_")).title() for x in markdown_output.columns
]
print(markdown_output.to_markdown(index=False))


# Make Latex Tables
latex_output = output_subset.copy()
latex_output["dataset"] = latex_output.dataset.map(lambda x: dataset_to_pretty_name[x])
# latex_output['dataset'] = latex_output.dataset.map(lambda x: dataset_to_pretty_name[x] + ' ' + '\cite{%s}' % dataset_to_citation[x])
# latex_output.columns = [" ".join(x.split("_")).title() for x in latex_output.columns]

latex_output = latex_output.rename(
    {
        "dataset": "Dataset",
        "total_documents": "Num Docs",
        "total_mentions": "Mentions",
        "unique_entities": "Unique Ents",
        'unique_types': 'Ent Types',
        "entity_overlap": "Ent. Overlap",
        "mention_overlap": "Ment. Overlap",
        "source_documents": "Doc Type",
        "linked_ontology": "Ontology",
    },
    axis=1,
)
latex_output_1 = latex_output[["Dataset", "Num Docs", "Mentions","Unique Ents",'Ent Types', 'Doc Type', 'Ontology']]
latex_output_2 = latex_output[["Dataset", 'Ent. Overlap', "Ment. Overlap"]]

latex_output_1.columns = ["\textbf{" + x + '}' for x in latex_output_1.columns]
latex_output_2.columns = ["\textbf{" + x + '}' for x in latex_output_2.columns]

print(latex_output_1.to_latex(index=False, escape=False, bold_rows=True))
print(latex_output_2.to_latex(index=False, escape=False, bold_rows=True))
# Out:
# | Dataset                                                                                                            | Total Documents   | Total Mentions   | Unique Entities   |   Unique Types |   Entity Overlap |   Mention Overlap | Source Documents   | Linked Ontology   |
# |:-------------------------------------------------------------------------------------------------------------------|:------------------|:-----------------|:------------------|---------------:|-----------------:|------------------:|:-------------------|:------------------|
# | MedMentions Full [(Mohan and Li, 2019)](https://github.com/chanzuckerberg/MedMentions)                             | 4,392             | 385,098          | 34,724            |            127 |           0.6199 |            0.8221 | PubMed Abstracts   | UMLS              |
# | MedMentions ST21PV [(Mohan and Li, 2019)](https://github.com/chanzuckerberg/MedMentions)                           | 4,392             | 203,282          | 25,419            |             21 |           0.5755 |            0.7741 | PubMed Abstracts   | UMLS              |
# | BC5CDR [(Li et al, 2016)](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4860626)                                    | 1,500             | 29,044           | 2,348             |              2 |           0.53   |            0.7733 | PubMed Abstracts   | MeSH              |
# | GNormPlus [(Wei et al, 2016)](https://www.ncbi.nlm.nih.gov/research/bionlp/Tools/gnormplus)                        | 533               | 6,252            | 1,353             |              2 |           0.0789 |            0.0838 | PubMed Abstracts   | Entrez            |
# | NCBI Disease [(Dogan et al, 2014)](https://www.sciencedirect.com/science/article/pii/S1532046413001974?via%3Dihub) | 792               | 6,881            | 789               |              4 |           0.67   |            0.8156 | PubMed Abstracts   | MeSH, OMIM        |
# | NLM Chem [(Islamaj et al, 2021)](https://www.nature.com/articles/s41597-021-00875-1)                               | 150               | 37,999           | 1,787             |              1 |           0.4747 |            0.6229 | PMC Full-Text      | MeSH              |
# | NLM Gene [(Islamaj et al, 2021)](https://doi.org/10.1016/j.jbi.2021.103779)                                        | 550               | 15,553           | 3,348             |              5 |           0.4819 |            0.5408 | PMC Full-Text      | Entrez            |
# \begin{tabular}{llllrll}
# \toprule
#   \textbf{Dataset} & \textbf{Num Docs} & \textbf{Mentions} & \textbf{Unique Ents} &  \textbf{Ent Types} & \textbf{Doc Type} & \textbf{Ontology} \\
# \midrule
#   MedMentions Full &             4,392 &           385,098 &               34,724 &                 127 &  PubMed Abstracts &              UMLS \\
# MedMentions ST21PV &             4,392 &           203,282 &               25,419 &                  21 &  PubMed Abstracts &              UMLS \\
#             BC5CDR &             1,500 &            29,044 &                2,348 &                   2 &  PubMed Abstracts &              MeSH \\
#          GNormPlus &               533 &             6,252 &                1,353 &                   2 &  PubMed Abstracts &            Entrez \\
#       NCBI Disease &               792 &             6,881 &                  789 &                   4 &  PubMed Abstracts &        MeSH, OMIM \\
#           NLM Chem &               150 &            37,999 &                1,787 &                   1 &     PMC Full-Text &              MeSH \\
#           NLM Gene &               550 &            15,553 &                3,348 &                   5 &     PMC Full-Text &            Entrez \\
# \bottomrule
# \end{tabular}
#
# \begin{tabular}{lrr}
# \toprule
#   \textbf{Dataset} &  \textbf{Ent. Overlap} &  \textbf{Ment. Overlap} \\
# \midrule
#   MedMentions Full &                 0.6199 &                  0.8221 \\
# MedMentions ST21PV &                 0.5755 &                  0.7741 \\
#             BC5CDR &                 0.5300 &                  0.7733 \\
#          GNormPlus &                 0.0789 &                  0.0838 \\
#       NCBI Disease &                 0.6700 &                  0.8156 \\
#           NLM Chem &                 0.4747 &                  0.6229 \\
#           NLM Gene &                 0.4819 &                  0.5408 \\
# \bottomrule
# \end{tabular}

# %%
pd.DataFrame.to_latex?
# Out:
# Signature:
# pd.DataFrame.to_latex(
#     self,
#     buf=None,
#     columns=None,
#     col_space=None,
#     header=True,
#     index=True,
#     na_rep='NaN',
#     formatters=None,
#     float_format=None,
#     sparsify=None,
#     index_names=True,
#     bold_rows=False,
#     column_format=None,
#     longtable=None,
#     escape=None,
#     encoding=None,
#     decimal='.',
#     multicolumn=None,
#     multicolumn_format=None,
#     multirow=None,
#     caption=None,
#     label=None,
#     position=None,
# )
# Docstring:
# Render object to a LaTeX tabular, longtable, or nested table.
#
# Requires ``\usepackage{booktabs}``.  The output can be copy/pasted
# into a main LaTeX document or read from an external file
# with ``\input{table.tex}``.
#
# .. versionchanged:: 1.0.0
#    Added caption and label arguments.
#
# .. versionchanged:: 1.2.0
#    Added position argument, changed meaning of caption argument.
#
# Parameters
# ----------
# buf : str, Path or StringIO-like, optional, default None
#     Buffer to write to. If None, the output is returned as a string.
# columns : list of label, optional
#     The subset of columns to write. Writes all columns by default.
# col_space : int, optional
#     The minimum width of each column.
# header : bool or list of str, default True
#     Write out the column names. If a list of strings is given,
#     it is assumed to be aliases for the column names.
# index : bool, default True
#     Write row names (index).
# na_rep : str, default 'NaN'
#     Missing data representation.
# formatters : list of functions or dict of {str: function}, optional
#     Formatter functions to apply to columns' elements by position or
#     name. The result of each function must be a unicode string.
#     List must be of length equal to the number of columns.
# float_format : one-parameter function or str, optional, default None
#     Formatter for floating point numbers. For example
#     ``float_format="%.2f"`` and ``float_format="{:0.2f}".format`` will
#     both result in 0.1234 being formatted as 0.12.
# sparsify : bool, optional
#     Set to False for a DataFrame with a hierarchical index to print
#     every multiindex key at each row. By default, the value will be
#     read from the config module.
# index_names : bool, default True
#     Prints the names of the indexes.
# bold_rows : bool, default False
#     Make the row labels bold in the output.
# column_format : str, optional
#     The columns format as specified in `LaTeX table format
#     <https://en.wikibooks.org/wiki/LaTeX/Tables>`__ e.g. 'rcl' for 3
#     columns. By default, 'l' will be used for all columns except
#     columns of numbers, which default to 'r'.
# longtable : bool, optional
#     By default, the value will be read from the pandas config
#     module. Use a longtable environment instead of tabular. Requires
#     adding a \usepackage{longtable} to your LaTeX preamble.
# escape : bool, optional
#     By default, the value will be read from the pandas config
#     module. When set to False prevents from escaping latex special
#     characters in column names.
# encoding : str, optional
#     A string representing the encoding to use in the output file,
#     defaults to 'utf-8'.
# decimal : str, default '.'
#     Character recognized as decimal separator, e.g. ',' in Europe.
# multicolumn : bool, default True
#     Use \multicolumn to enhance MultiIndex columns.
#     The default will be read from the config module.
# multicolumn_format : str, default 'l'
#     The alignment for multicolumns, similar to `column_format`
#     The default will be read from the config module.
# multirow : bool, default False
#     Use \multirow to enhance MultiIndex rows. Requires adding a
#     \usepackage{multirow} to your LaTeX preamble. Will print
#     centered labels (instead of top-aligned) across the contained
#     rows, separating groups via clines. The default will be read
#     from the pandas config module.
# caption : str or tuple, optional
#     Tuple (full_caption, short_caption),
#     which results in ``\caption[short_caption]{full_caption}``;
#     if a single string is passed, no short caption will be set.
#
#     .. versionadded:: 1.0.0
#
#     .. versionchanged:: 1.2.0
#        Optionally allow caption to be a tuple ``(full_caption, short_caption)``.
#
# label : str, optional
#     The LaTeX label to be placed inside ``\label{}`` in the output.
#     This is used with ``\ref{}`` in the main ``.tex`` file.
#
#     .. versionadded:: 1.0.0
# position : str, optional
#     The LaTeX positional argument for tables, to be placed after
#     ``\begin{}`` in the output.
#
#     .. versionadded:: 1.2.0
#
#         Returns
#         -------
#         str or None
#             If buf is None, returns the result as a string. Otherwise returns
#             None.
#
# See Also
# --------
# Styler.to_latex : Render a DataFrame to LaTeX with conditional formatting.
# DataFrame.to_string : Render a DataFrame to a console-friendly
#     tabular output.
# DataFrame.to_html : Render a DataFrame as an HTML table.
#
# Examples
# --------
# >>> df = pd.DataFrame(dict(name=['Raphael', 'Donatello'],
# ...                   mask=['red', 'purple'],
# ...                   weapon=['sai', 'bo staff']))
# >>> print(df.to_latex(index=False))  # doctest: +SKIP
# \begin{tabular}{lll}
#  \toprule
#        name &    mask &    weapon \\
#  \midrule
#     Raphael &     red &       sai \\
#   Donatello &  purple &  bo staff \\
# \bottomrule
# \end{tabular}
# File:      ~/mambaforge/envs/bigbio/lib/python3.9/site-packages/pandas/core/generic.py
# Type:      function

# %% [markdown]
# ## Convert .csv into Markdown table about models

# %% [markdown]
# # Compare statistics of all datasets in BigBio

# %%
ner_helpers = conhelps.filtered(
    lambda x:
        x.is_bigbio_schema
        and x.is_local
        and "NAMED_ENTITY_DISAMBIGUATION" in x.tasks
        and not x.is_large
)

# %%
[(ch.dataset_name, ch.config.name, ch.tasks) for ch in ner_helpers]
# Out:
# [('msh_wsd', 'msh_wsd_bigbio_kb', {'NAMED_ENTITY_DISAMBIGUATION'}),
#  ('nlm_wsd',
#   'nlm_wsd_non_reviewed_bigbio_kb',
#   {'NAMED_ENTITY_DISAMBIGUATION'}),
#  ('nlm_wsd', 'nlm_wsd_reviewed_bigbio_kb', {'NAMED_ENTITY_DISAMBIGUATION'})]

# %%
all_statistics = []
for ch in ner_helpers:
    try:
        metadata = ner_helpers.for_config_name(ch.config.name).get_metadata()
        for split in metadata.keys():
            s = metadata[split].__dict__
            s['split'] = split
            s['config_name'] = ch.config.name
            s['dataset_name'] = ch.dataset_name
            s['display_name'] = ch.display_name
            all_statistics.append(s)
    except Exception as e:
        print("Exception!!!!")
        print(e)

df = pd.DataFrame(all_statistics)
df
# Out:
# Downloading builder script:   0%|          | 0.00/9.93k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/1.74k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/19.3k [00:00<?, ?B/s]
# Downloading and preparing dataset msh_wsd/msh_wsd_bigbio_kb to /nethome/dkartchner3/.cache/huggingface/datasets/bigbio___msh_wsd/msh_wsd_bigbio_kb/1.0.0/21843cdf3630cd9ffb7dfd324f296850bddfdf1c9cb125746eba43ccecb97116...
# Exception!!!!
# This is a local dataset. Please pass the data_dir kwarg to load_dataset.
# Downloading builder script:   0%|          | 0.00/14.5k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/1.77k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/19.3k [00:00<?, ?B/s]
# Downloading and preparing dataset nlm_wsd/nlm_wsd_non_reviewed_bigbio_kb to /nethome/dkartchner3/.cache/huggingface/datasets/bigbio___nlm_wsd/nlm_wsd_non_reviewed_bigbio_kb/1.0.0/d24f852bf92e5ec11cbf0973a22d3d58b88550a01b8e70295c169f324ae18d66...
# Exception!!!!
# This is a local dataset. Please pass the data_dir kwarg to load_dataset.
# Downloading and preparing dataset nlm_wsd/nlm_wsd_reviewed_bigbio_kb to /nethome/dkartchner3/.cache/huggingface/datasets/bigbio___nlm_wsd/nlm_wsd_reviewed_bigbio_kb/1.0.0/d24f852bf92e5ec11cbf0973a22d3d58b88550a01b8e70295c169f324ae18d66...
# Exception!!!!
# This is a local dataset. Please pass the data_dir kwarg to load_dataset.
# Empty DataFrame
# Columns: []
# Index: []

# %%
cols_to_keep = ['dataset_name', 'display_name', 'samples_count', 'passages_count', 'passages_char_count',
    'passages_type_counter', 'entities_count', 'entities_normalized_count',
    'entities_type_counter', 'entities_db_name_counter',
    'entities_unique_db_ids_count', 'split',]

def dict_agg(x):
    output = defaultdict(int)
    for d in x:
        for k, v in d.items():
            output[k] += v
    return dict(output)


# df.loc[~df.dataset_name.isin(['muchmore','twadrl','ask_a_patient', 'mantra_gsc']), cols_to_keep]

aggregated = df.groupby('config_name').agg({
    'display_name': 'first',
    'dataset_name': 'first',
    'samples_count': 'sum', 
    'passages_count': 'sum', 
    'passages_char_count': 'sum',
    'passages_type_counter': lambda x: dict_agg(x), 
    'entities_count': 'sum', 
    'entities_normalized_count': 'sum',
    'entities_type_counter': lambda x: dict_agg(x), 
    'entities_db_name_counter': lambda x: dict_agg(x),
    'entities_unique_db_ids_count': 'sum',
})

# aggregated.loc[~aggregated.dataset_name.isin(['muchmore','twadrl','ask_a_patient', 'mantra_gsc'])].to_excel('../collaboration/dataset_summary.xlsx')
# aggregated.loc[~aggregated.dataset_name.isin(['muchmore','twadrl','ask_a_patient', 'mantra_gsc'])]

aggregated
# Out:
#                                                         display_name  \
# config_name
# ask_a_patient_bigbio_kb                                  AskAPatient
# bc5cdr_bigbio_kb                                              BC5CDR
# bionlp_st_2019_bb_bigbio_kb                           BioNLP 2019 BB
# biorelex_bigbio_kb                                          BioRelEx
# cadec_bigbio_kb                                                CADEC
# cantemist_bigbio_kb                                        CANTEMIST
# citation_gia_test_collection_bigbio_kb  Citation GIA Test Collection
# codiesp_X_bigbio_kb                                          CodiEsp
# distemist_entities_bigbio_kb                               DisTEMIST
# distemist_linking_bigbio_kb                                DisTEMIST
# gnormplus_bigbio_kb                                        GNormPlus
# linnaeus_bigbio_kb                                          LINNAEUS
# linnaeus_filtered_bigbio_kb                                 LINNAEUS
# mantra_gsc_de_emea_bigbio_kb                              Mantra GSC
# mantra_gsc_de_medline_bigbio_kb                           Mantra GSC
# mantra_gsc_de_patents_bigbio_kb                           Mantra GSC
# mantra_gsc_en_emea_bigbio_kb                              Mantra GSC
# mantra_gsc_en_medline_bigbio_kb                           Mantra GSC
# mantra_gsc_en_patents_bigbio_kb                           Mantra GSC
# mantra_gsc_es_emea_bigbio_kb                              Mantra GSC
# mantra_gsc_es_medline_bigbio_kb                           Mantra GSC
# mantra_gsc_fr_emea_bigbio_kb                              Mantra GSC
# mantra_gsc_fr_medline_bigbio_kb                           Mantra GSC
# mantra_gsc_fr_patents_bigbio_kb                           Mantra GSC
# mantra_gsc_nl_emea_bigbio_kb                              Mantra GSC
# mantra_gsc_nl_medline_bigbio_kb                           Mantra GSC
# medmentions_full_bigbio_kb                               MedMentions
# medmentions_st21pv_bigbio_kb                             MedMentions
# mirna_bigbio_kb                                                miRNA
# muchmore_bigbio_kb                                          MuchMore
# muchmore_de_bigbio_kb                                       MuchMore
# muchmore_en_bigbio_kb                                       MuchMore
# ncbi_disease_bigbio_kb                                  NCBI Disease
# nlm_gene_bigbio_kb                                          NLM-Gene
# nlmchem_bigbio_kb                                           NLM-Chem
# osiris_bigbio_kb                                              OSIRIS
# pubtator_central_sample_bigbio_kb                   PubTator Central
# quaero_emea_bigbio_kb                                         QUAERO
# quaero_medline_bigbio_kb                                      QUAERO
# spl_adr_200db_train_bigbio_kb                                SPL ADR
# spl_adr_200db_unannotated_bigbio_kb                          SPL ADR
# thomas2011_bigbio_kb                                      SNP Corpus
# tmvar_v2_bigbio_kb                                          tmVar v2
# tmvar_v3_bigbio_kb                                          tmVar v3
# twadrl_bigbio_kb                                             TwADR-L
#
#                                                         dataset_name  \
# config_name
# ask_a_patient_bigbio_kb                                ask_a_patient
# bc5cdr_bigbio_kb                                              bc5cdr
# bionlp_st_2019_bb_bigbio_kb                        bionlp_st_2019_bb
# biorelex_bigbio_kb                                          biorelex
# cadec_bigbio_kb                                                cadec
# cantemist_bigbio_kb                                        cantemist
# citation_gia_test_collection_bigbio_kb  citation_gia_test_collection
# codiesp_X_bigbio_kb                                          codiesp
# distemist_entities_bigbio_kb                               distemist
# distemist_linking_bigbio_kb                                distemist
# gnormplus_bigbio_kb                                        gnormplus
# linnaeus_bigbio_kb                                          linnaeus
# linnaeus_filtered_bigbio_kb                                 linnaeus
# mantra_gsc_de_emea_bigbio_kb                              mantra_gsc
# mantra_gsc_de_medline_bigbio_kb                           mantra_gsc
# mantra_gsc_de_patents_bigbio_kb                           mantra_gsc
# mantra_gsc_en_emea_bigbio_kb                              mantra_gsc
# mantra_gsc_en_medline_bigbio_kb                           mantra_gsc
# mantra_gsc_en_patents_bigbio_kb                           mantra_gsc
# mantra_gsc_es_emea_bigbio_kb                              mantra_gsc
# mantra_gsc_es_medline_bigbio_kb                           mantra_gsc
# mantra_gsc_fr_emea_bigbio_kb                              mantra_gsc
# mantra_gsc_fr_medline_bigbio_kb                           mantra_gsc
# mantra_gsc_fr_patents_bigbio_kb                           mantra_gsc
# mantra_gsc_nl_emea_bigbio_kb                              mantra_gsc
# mantra_gsc_nl_medline_bigbio_kb                           mantra_gsc
# medmentions_full_bigbio_kb                               medmentions
# medmentions_st21pv_bigbio_kb                             medmentions
# mirna_bigbio_kb                                                mirna
# muchmore_bigbio_kb                                          muchmore
# muchmore_de_bigbio_kb                                       muchmore
# muchmore_en_bigbio_kb                                       muchmore
# ncbi_disease_bigbio_kb                                  ncbi_disease
# nlm_gene_bigbio_kb                                          nlm_gene
# nlmchem_bigbio_kb                                            nlmchem
# osiris_bigbio_kb                                              osiris
# pubtator_central_sample_bigbio_kb                   pubtator_central
# quaero_emea_bigbio_kb                                         quaero
# quaero_medline_bigbio_kb                                      quaero
# spl_adr_200db_train_bigbio_kb                          spl_adr_200db
# spl_adr_200db_unannotated_bigbio_kb                    spl_adr_200db
# thomas2011_bigbio_kb                                      thomas2011
# tmvar_v2_bigbio_kb                                          tmvar_v2
# tmvar_v3_bigbio_kb                                          tmvar_v3
# twadrl_bigbio_kb                                              twadrl
#
#                                         samples_count  passages_count  \
# config_name
# ask_a_patient_bigbio_kb                        173240          173240
# bc5cdr_bigbio_kb                                 1500            3000
# bionlp_st_2019_bb_bigbio_kb                       295             295
# biorelex_bigbio_kb                               1606            1606
# cadec_bigbio_kb                                  1250            1250
# cantemist_bigbio_kb                              1301            1301
# citation_gia_test_collection_bigbio_kb            151             302
# codiesp_X_bigbio_kb                              1000               0
# distemist_entities_bigbio_kb                      750             750
# distemist_linking_bigbio_kb                       583             583
# gnormplus_bigbio_kb                               543            1086
# linnaeus_bigbio_kb                                 95              95
# linnaeus_filtered_bigbio_kb                        84              84
# mantra_gsc_de_emea_bigbio_kb                      100             100
# mantra_gsc_de_medline_bigbio_kb                   100             100
# mantra_gsc_de_patents_bigbio_kb                    50              50
# mantra_gsc_en_emea_bigbio_kb                      100             100
# mantra_gsc_en_medline_bigbio_kb                   400             400
# mantra_gsc_en_patents_bigbio_kb                    50              50
# mantra_gsc_es_emea_bigbio_kb                      100             100
# mantra_gsc_es_medline_bigbio_kb                   100             100
# mantra_gsc_fr_emea_bigbio_kb                      100             100
# mantra_gsc_fr_medline_bigbio_kb                   100             100
# mantra_gsc_fr_patents_bigbio_kb                    50              50
# mantra_gsc_nl_emea_bigbio_kb                      100             100
# mantra_gsc_nl_medline_bigbio_kb                   100             100
# medmentions_full_bigbio_kb                       4392            8784
# medmentions_st21pv_bigbio_kb                     4392            8784
# mirna_bigbio_kb                                   301            2411
# muchmore_bigbio_kb                              15630           15630
# muchmore_de_bigbio_kb                            7808            7808
# muchmore_en_bigbio_kb                            7822            7822
# ncbi_disease_bigbio_kb                            792            1584
# nlm_gene_bigbio_kb                                550            1100
# nlmchem_bigbio_kb                                 150           10310
# osiris_bigbio_kb                                  105             210
# pubtator_central_sample_bigbio_kb                   4               8
# quaero_emea_bigbio_kb                              38              38
# quaero_medline_bigbio_kb                         2498            2498
# spl_adr_200db_train_bigbio_kb                     101             239
# spl_adr_200db_unannotated_bigbio_kb              2208            4311
# thomas2011_bigbio_kb                              296               0
# tmvar_v2_bigbio_kb                                158             316
# tmvar_v3_bigbio_kb                                500            1000
# twadrl_bigbio_kb                                50740           50740
#
#                                         passages_char_count  \
# config_name
# ask_a_patient_bigbio_kb                             2238807
# bc5cdr_bigbio_kb                                    1975456
# bionlp_st_2019_bb_bigbio_kb                          305827
# biorelex_bigbio_kb                                   270233
# cadec_bigbio_kb                                      575453
# cantemist_bigbio_kb                                 6344976
# citation_gia_test_collection_bigbio_kb               229882
# codiesp_X_bigbio_kb                                       0
# distemist_entities_bigbio_kb                        1758414
# distemist_linking_bigbio_kb                         1246383
# gnormplus_bigbio_kb                                  737897
# linnaeus_bigbio_kb                                  2612606
# linnaeus_filtered_bigbio_kb                         2464729
# mantra_gsc_de_emea_bigbio_kb                          12961
# mantra_gsc_de_medline_bigbio_kb                        7606
# mantra_gsc_de_patents_bigbio_kb                       17419
# mantra_gsc_en_emea_bigbio_kb                          10958
# mantra_gsc_en_medline_bigbio_kb                       27821
# mantra_gsc_en_patents_bigbio_kb                       16021
# mantra_gsc_es_emea_bigbio_kb                          12490
# mantra_gsc_es_medline_bigbio_kb                        7953
# mantra_gsc_fr_emea_bigbio_kb                          13331
# mantra_gsc_fr_medline_bigbio_kb                        7642
# mantra_gsc_fr_patents_bigbio_kb                       18123
# mantra_gsc_nl_emea_bigbio_kb                          12370
# mantra_gsc_nl_medline_bigbio_kb                        6332
# medmentions_full_bigbio_kb                          6945085
# medmentions_st21pv_bigbio_kb                        6945085
# mirna_bigbio_kb                                      385368
# muchmore_bigbio_kb                                 16009519
# muchmore_de_bigbio_kb                               8425551
# muchmore_en_bigbio_kb                               7583968
# ncbi_disease_bigbio_kb                              1014349
# nlm_gene_bigbio_kb                                   991536
# nlmchem_bigbio_kb                                   4861074
# osiris_bigbio_kb                                     172056
# pubtator_central_sample_bigbio_kb                     19454
# quaero_emea_bigbio_kb                                227811
# quaero_medline_bigbio_kb                             205903
# spl_adr_200db_train_bigbio_kb                       1769683
# spl_adr_200db_unannotated_bigbio_kb                28952558
# thomas2011_bigbio_kb                                      0
# tmvar_v2_bigbio_kb                                   258660
# tmvar_v3_bigbio_kb                                   811380
# twadrl_bigbio_kb                                     799570
#
#                                                                     passages_type_counter  \
# config_name
# ask_a_patient_bigbio_kb                                     {'social_media_text': 173240}
# bc5cdr_bigbio_kb                                        {'title': 1500, 'abstract': 1500}
# bionlp_st_2019_bb_bigbio_kb                                             {'abstract': 295}
# biorelex_bigbio_kb                                                     {'sentence': 1606}
# cadec_bigbio_kb                                                        {'abstract': 1250}
# cantemist_bigbio_kb                                                    {'abstract': 1301}
# citation_gia_test_collection_bigbio_kb                    {'title': 151, 'abstract': 151}
# codiesp_X_bigbio_kb                                                                    {}
# distemist_entities_bigbio_kb                                       {'clinical_case': 750}
# distemist_linking_bigbio_kb                                        {'clinical_case': 583}
# gnormplus_bigbio_kb                                       {'title': 543, 'abstract': 543}
# linnaeus_bigbio_kb                                                        {'Article': 95}
# linnaeus_filtered_bigbio_kb                                               {'Article': 84}
# mantra_gsc_de_emea_bigbio_kb                                            {'abstract': 100}
# mantra_gsc_de_medline_bigbio_kb                                         {'abstract': 100}
# mantra_gsc_de_patents_bigbio_kb                                          {'abstract': 50}
# mantra_gsc_en_emea_bigbio_kb                                            {'abstract': 100}
# mantra_gsc_en_medline_bigbio_kb                                         {'abstract': 400}
# mantra_gsc_en_patents_bigbio_kb                                          {'abstract': 50}
# mantra_gsc_es_emea_bigbio_kb                                            {'abstract': 100}
# mantra_gsc_es_medline_bigbio_kb                                         {'abstract': 100}
# mantra_gsc_fr_emea_bigbio_kb                                            {'abstract': 100}
# mantra_gsc_fr_medline_bigbio_kb                                         {'abstract': 100}
# mantra_gsc_fr_patents_bigbio_kb                                          {'abstract': 50}
# mantra_gsc_nl_emea_bigbio_kb                                            {'abstract': 100}
# mantra_gsc_nl_medline_bigbio_kb                                         {'abstract': 100}
# medmentions_full_bigbio_kb                              {'title': 4392, 'abstract': 4392}
# medmentions_st21pv_bigbio_kb                            {'title': 4392, 'abstract': 4392}
# mirna_bigbio_kb                                          {'abstract': 2133, 'title': 278}
# muchmore_bigbio_kb                                                    {'abstract': 15630}
# muchmore_de_bigbio_kb                                                  {'abstract': 7808}
# muchmore_en_bigbio_kb                                                  {'abstract': 7822}
# ncbi_disease_bigbio_kb                                    {'title': 792, 'abstract': 792}
# nlm_gene_bigbio_kb                                        {'title': 550, 'abstract': 550}
# nlmchem_bigbio_kb                       {'paragraph': 5136, 'title_2': 1549, 'fig_capt...
# osiris_bigbio_kb                                          {'title': 105, 'abstract': 105}
# pubtator_central_sample_bigbio_kb                             {'title': 4, 'abstract': 4}
# quaero_emea_bigbio_kb                                                    {'abstract': 38}
# quaero_medline_bigbio_kb                                               {'abstract': 2498}
# spl_adr_200db_train_bigbio_kb           {'adverse reactions': 101, 'warnings and preca...
# spl_adr_200db_unannotated_bigbio_kb     {'adverse reactions': 2267, 'warnings and prec...
# thomas2011_bigbio_kb                                                                   {}
# tmvar_v2_bigbio_kb                                        {'title': 158, 'abstract': 158}
# tmvar_v3_bigbio_kb                                        {'title': 500, 'abstract': 500}
# twadrl_bigbio_kb                                             {'social_media_text': 50740}
#
#                                         entities_count  \
# config_name
# ask_a_patient_bigbio_kb                         173240
# bc5cdr_bigbio_kb                                 29271
# bionlp_st_2019_bb_bigbio_kb                       3456
# biorelex_bigbio_kb                                7880
# cadec_bigbio_kb                                   9111
# cantemist_bigbio_kb                              16032
# citation_gia_test_collection_bigbio_kb            1382
# codiesp_X_bigbio_kb                              18435
# distemist_entities_bigbio_kb                      8065
# distemist_linking_bigbio_kb                       5136
# gnormplus_bigbio_kb                               9257
# linnaeus_bigbio_kb                                4259
# linnaeus_filtered_bigbio_kb                       2851
# mantra_gsc_de_emea_bigbio_kb                       425
# mantra_gsc_de_medline_bigbio_kb                    309
# mantra_gsc_de_patents_bigbio_kb                    348
# mantra_gsc_en_emea_bigbio_kb                       433
# mantra_gsc_en_medline_bigbio_kb                   1177
# mantra_gsc_en_patents_bigbio_kb                    353
# mantra_gsc_es_emea_bigbio_kb                       432
# mantra_gsc_es_medline_bigbio_kb                    324
# mantra_gsc_fr_emea_bigbio_kb                       431
# mantra_gsc_fr_medline_bigbio_kb                    279
# mantra_gsc_fr_patents_bigbio_kb                    342
# mantra_gsc_nl_emea_bigbio_kb                       434
# mantra_gsc_nl_medline_bigbio_kb                    243
# medmentions_full_bigbio_kb                      385098
# medmentions_st21pv_bigbio_kb                    203282
# mirna_bigbio_kb                                   8318
# muchmore_bigbio_kb                              345838
# muchmore_de_bigbio_kb                           112596
# muchmore_en_bigbio_kb                           233242
# ncbi_disease_bigbio_kb                            6881
# nlm_gene_bigbio_kb                               15553
# nlmchem_bigbio_kb                                38339
# osiris_bigbio_kb                                  1230
# pubtator_central_sample_bigbio_kb                  208
# quaero_emea_bigbio_kb                             7159
# quaero_medline_bigbio_kb                          9074
# spl_adr_200db_train_bigbio_kb                    15722
# spl_adr_200db_unannotated_bigbio_kb                  0
# thomas2011_bigbio_kb                               527
# tmvar_v2_bigbio_kb                                 674
# tmvar_v3_bigbio_kb                                7837
# twadrl_bigbio_kb                                 50740
#
#                                         entities_normalized_count  \
# config_name
# ask_a_patient_bigbio_kb                                    173240
# bc5cdr_bigbio_kb                                            29335
# bionlp_st_2019_bb_bigbio_kb                                  3628
# biorelex_bigbio_kb                                          10593
# cadec_bigbio_kb                                             15932
# cantemist_bigbio_kb                                         16032
# citation_gia_test_collection_bigbio_kb                       1382
# codiesp_X_bigbio_kb                                         18435
# distemist_entities_bigbio_kb                                    0
# distemist_linking_bigbio_kb                                  5374
# gnormplus_bigbio_kb                                          6430
# linnaeus_bigbio_kb                                           4259
# linnaeus_filtered_bigbio_kb                                  2851
# mantra_gsc_de_emea_bigbio_kb                                  425
# mantra_gsc_de_medline_bigbio_kb                               309
# mantra_gsc_de_patents_bigbio_kb                               348
# mantra_gsc_en_emea_bigbio_kb                                  433
# mantra_gsc_en_medline_bigbio_kb                              1177
# mantra_gsc_en_patents_bigbio_kb                               353
# mantra_gsc_es_emea_bigbio_kb                                  432
# mantra_gsc_es_medline_bigbio_kb                               324
# mantra_gsc_fr_emea_bigbio_kb                                  431
# mantra_gsc_fr_medline_bigbio_kb                               279
# mantra_gsc_fr_patents_bigbio_kb                               342
# mantra_gsc_nl_emea_bigbio_kb                                  434
# mantra_gsc_nl_medline_bigbio_kb                               243
# medmentions_full_bigbio_kb                                 385098
# medmentions_st21pv_bigbio_kb                               203282
# mirna_bigbio_kb                                              8318
# muchmore_bigbio_kb                                         399189
# muchmore_de_bigbio_kb                                      121306
# muchmore_en_bigbio_kb                                      277883
# ncbi_disease_bigbio_kb                                       7054
# nlm_gene_bigbio_kb                                          18056
# nlmchem_bigbio_kb                                           41300
# osiris_bigbio_kb                                             1230
# pubtator_central_sample_bigbio_kb                             208
# quaero_emea_bigbio_kb                                        7202
# quaero_medline_bigbio_kb                                     9079
# spl_adr_200db_train_bigbio_kb                                2417
# spl_adr_200db_unannotated_bigbio_kb                             0
# thomas2011_bigbio_kb                                          527
# tmvar_v2_bigbio_kb                                            625
# tmvar_v3_bigbio_kb                                           8884
# twadrl_bigbio_kb                                            50740
#
#                                                                     entities_type_counter  \
# config_name
# ask_a_patient_bigbio_kb                                     {'social_media_text': 173240}
# bc5cdr_bigbio_kb                                    {'Chemical': 15953, 'Disease': 13318}
# bionlp_st_2019_bb_bigbio_kb             {'Habitat': 1752, 'Microorganism': 1174, 'Phen...
# biorelex_bigbio_kb                      {'protein': 3730, 'protein-family': 1125, 'che...
# cadec_bigbio_kb                         {'ADR': 6318, 'Drug': 1800, 'Finding': 435, 'D...
# cantemist_bigbio_kb                                       {'MORFOLOGIA_NEOPLASIA': 16032}
# citation_gia_test_collection_bigbio_kb  {'Gene': 1205, 'FamilyName': 160, 'DomainMotif...
# codiesp_X_bigbio_kb                         {'DIAGNOSTICO': 14305, 'PROCEDIMIENTO': 4130}
# distemist_entities_bigbio_kb                                         {'ENFERMEDAD': 8065}
# distemist_linking_bigbio_kb                                          {'ENFERMEDAD': 5136}
# gnormplus_bigbio_kb                     {'Gene': 6251, 'FamilyName': 2367, 'DomainMoti...
# linnaeus_bigbio_kb                                                      {'species': 4259}
# linnaeus_filtered_bigbio_kb                                             {'species': 2851}
# mantra_gsc_de_emea_bigbio_kb            {'DISO': 151, 'CHEM': 99, 'PROC': 57, 'LIVB': ...
# mantra_gsc_de_medline_bigbio_kb         {'DISO': 77, 'PROC': 71, 'ANAT': 56, 'CHEM': 5...
# mantra_gsc_de_patents_bigbio_kb         {'CHEM': 149, 'DISO': 101, 'ANAT': 31, 'PROC':...
# mantra_gsc_en_emea_bigbio_kb            {'DISO': 150, 'CHEM': 100, 'PROC': 62, 'LIVB':...
# mantra_gsc_en_medline_bigbio_kb         {'DISO': 359, 'PROC': 250, 'LIVB': 157, 'ANAT'...
# mantra_gsc_en_patents_bigbio_kb         {'CHEM': 150, 'DISO': 104, 'ANAT': 31, 'PROC':...
# mantra_gsc_es_emea_bigbio_kb            {'DISO': 151, 'CHEM': 98, 'PROC': 66, 'LIVB': ...
# mantra_gsc_es_medline_bigbio_kb         {'DISO': 115, 'PROC': 63, 'LIVB': 42, 'ANAT': ...
# mantra_gsc_fr_emea_bigbio_kb            {'DISO': 151, 'CHEM': 101, 'PROC': 59, 'LIVB':...
# mantra_gsc_fr_medline_bigbio_kb         {'DISO': 86, 'PROC': 64, 'LIVB': 45, 'ANAT': 3...
# mantra_gsc_fr_patents_bigbio_kb         {'CHEM': 146, 'DISO': 103, 'ANAT': 31, 'PROC':...
# mantra_gsc_nl_emea_bigbio_kb            {'DISO': 159, 'CHEM': 101, 'PROC': 57, 'LIVB':...
# mantra_gsc_nl_medline_bigbio_kb         {'DISO': 74, 'PROC': 49, 'LIVB': 49, 'ANAT': 2...
# medmentions_full_bigbio_kb              {'T080': 31485, 'T169': 23661, 'T081': 19995, ...
# medmentions_st21pv_bigbio_kb            {'T038': 41422, 'T103': 37401, 'T058': 24306, ...
# mirna_bigbio_kb                         {'Diseases': 2161, 'Relation_Trigger': 1960, '...
# muchmore_bigbio_kb                                                   {'umlsterm': 345838}
# muchmore_de_bigbio_kb                                                {'umlsterm': 112596}
# muchmore_en_bigbio_kb                                                {'umlsterm': 233242}
# ncbi_disease_bigbio_kb                  {'SpecificDisease': 3929, 'Modifier': 1766, 'D...
# nlm_gene_bigbio_kb                      {'Gene': 9562, 'GENERIF': 3887, 'STARGENE': 19...
# nlmchem_bigbio_kb                                                     {'Chemical': 38339}
# osiris_bigbio_kb                                            {'gene': 689, 'variant': 541}
# pubtator_central_sample_bigbio_kb       {'Disease': 77, 'Chemical': 62, 'Species': 49,...
# quaero_emea_bigbio_kb                   {'DISO': 1510, 'CHEM': 2482, 'PROC': 952, 'LIV...
# quaero_medline_bigbio_kb                {'DISO': 2843, 'PROC': 1750, 'ANAT': 1499, 'CH...
# spl_adr_200db_train_bigbio_kb           {'AdverseReaction': 13795, 'Severity': 934, 'F...
# spl_adr_200db_unannotated_bigbio_kb                                                    {}
# thomas2011_bigbio_kb                    {'Protein Sequence Mutation': 283, 'Nucleotide...
# tmvar_v2_bigbio_kb                      {'ProteinMutation': 436, 'DNAMutation': 190, '...
# tmvar_v3_bigbio_kb                      {'['Gene']': 4059, '['Species']': 1756, '['Pro...
# twadrl_bigbio_kb                                             {'social_media_text': 50740}
#
#                                                                  entities_db_name_counter  \
# config_name
# ask_a_patient_bigbio_kb                                         {'SNOMED-CT|AMT': 173240}
# bc5cdr_bigbio_kb                                                          {'MESH': 29335}
# bionlp_st_2019_bb_bigbio_kb                  {'OntoBiotope': 2452, 'NCBI_Taxonomy': 1176}
# biorelex_bigbio_kb                      {'uniprot': 3190, 'hgnc': 2947, 'NCBI gene': 2...
# cadec_bigbio_kb                              {'Snomed CT': 8930, 'Meddra': 6222, '': 780}
# cantemist_bigbio_kb                                                 {'eCIE-O-3.1': 16032}
# citation_gia_test_collection_bigbio_kb                                         {'': 1382}
# codiesp_X_bigbio_kb                                {'ICD10-CM': 14305, 'ICD10-PCS': 4130}
# distemist_entities_bigbio_kb                                                           {}
# distemist_linking_bigbio_kb                                           {'SNOMED_CT': 5374}
# gnormplus_bigbio_kb                                                    {'NCBIGene': 6430}
# linnaeus_bigbio_kb                                                         {'ncbi': 4259}
# linnaeus_filtered_bigbio_kb                                                {'ncbi': 2851}
# mantra_gsc_de_emea_bigbio_kb                                                {'UMLS': 425}
# mantra_gsc_de_medline_bigbio_kb                                             {'UMLS': 309}
# mantra_gsc_de_patents_bigbio_kb                                             {'UMLS': 348}
# mantra_gsc_en_emea_bigbio_kb                                                {'UMLS': 433}
# mantra_gsc_en_medline_bigbio_kb                                            {'UMLS': 1177}
# mantra_gsc_en_patents_bigbio_kb                                             {'UMLS': 353}
# mantra_gsc_es_emea_bigbio_kb                                                {'UMLS': 432}
# mantra_gsc_es_medline_bigbio_kb                                             {'UMLS': 324}
# mantra_gsc_fr_emea_bigbio_kb                                                {'UMLS': 431}
# mantra_gsc_fr_medline_bigbio_kb                                             {'UMLS': 279}
# mantra_gsc_fr_patents_bigbio_kb                                             {'UMLS': 342}
# mantra_gsc_nl_emea_bigbio_kb                                                {'UMLS': 434}
# mantra_gsc_nl_medline_bigbio_kb                                             {'UMLS': 243}
# medmentions_full_bigbio_kb                                               {'UMLS': 385098}
# medmentions_st21pv_bigbio_kb                                             {'UMLS': 203282}
# mirna_bigbio_kb                                                    {'miRNA-corpus': 8318}
# muchmore_bigbio_kb                                                       {'UMLS': 399189}
# muchmore_de_bigbio_kb                                                    {'UMLS': 121306}
# muchmore_en_bigbio_kb                                                    {'UMLS': 277883}
# ncbi_disease_bigbio_kb                                        {'MESH': 6487, 'OMIM': 567}
# nlm_gene_bigbio_kb                                                    {'NCBIGene': 18056}
# nlmchem_bigbio_kb                                                         {'MESH': 41300}
# osiris_bigbio_kb                        {'NCBI Gene': 689, 'HGVS-like': 291, 'dbSNP': ...
# pubtator_central_sample_bigbio_kb       {'mesh': 139, 'ncbi_taxon': 49, 'ncbi_gene': 1...
# quaero_emea_bigbio_kb                                                      {'UMLS': 7202}
# quaero_medline_bigbio_kb                                                   {'UMLS': 9079}
# spl_adr_200db_train_bigbio_kb                                      {'MedDRA v18.1': 2417}
# spl_adr_200db_unannotated_bigbio_kb                                                    {}
# thomas2011_bigbio_kb                                                       {'dbSNP': 527}
# tmvar_v2_bigbio_kb                                                         {'dbsnp': 625}
# tmvar_v3_bigbio_kb                                     {'NCBI Gene': 6023, 'dbSNP': 2861}
# twadrl_bigbio_kb                                                       {'SIDER 4': 50740}
#
#                                         entities_unique_db_ids_count
# config_name
# ask_a_patient_bigbio_kb                                        16548
# bc5cdr_bigbio_kb                                                3907
# bionlp_st_2019_bb_bigbio_kb                                      834
# biorelex_bigbio_kb                                              3291
# cadec_bigbio_kb                                                 1736
# cantemist_bigbio_kb                                             1399
# citation_gia_test_collection_bigbio_kb                             1
# codiesp_X_bigbio_kb                                             5377
# distemist_entities_bigbio_kb                                       0
# distemist_linking_bigbio_kb                                     2430
# gnormplus_bigbio_kb                                             1465
# linnaeus_bigbio_kb                                               233
# linnaeus_filtered_bigbio_kb                                      233
# mantra_gsc_de_emea_bigbio_kb                                     299
# mantra_gsc_de_medline_bigbio_kb                                  259
# mantra_gsc_de_patents_bigbio_kb                                  223
# mantra_gsc_en_emea_bigbio_kb                                     301
# mantra_gsc_en_medline_bigbio_kb                                  884
# mantra_gsc_en_patents_bigbio_kb                                  227
# mantra_gsc_es_emea_bigbio_kb                                     295
# mantra_gsc_es_medline_bigbio_kb                                  285
# mantra_gsc_fr_emea_bigbio_kb                                     304
# mantra_gsc_fr_medline_bigbio_kb                                  242
# mantra_gsc_fr_patents_bigbio_kb                                  223
# mantra_gsc_nl_emea_bigbio_kb                                     304
# mantra_gsc_nl_medline_bigbio_kb                                  204
# medmentions_full_bigbio_kb                                     50720
# medmentions_st21pv_bigbio_kb                                   35620
# mirna_bigbio_kb                                                 8315
# muchmore_bigbio_kb                                             10004
# muchmore_de_bigbio_kb                                           5573
# muchmore_en_bigbio_kb                                           9176
# ncbi_disease_bigbio_kb                                          1015
# nlm_gene_bigbio_kb                                              3940
# nlmchem_bigbio_kb                                               2486
# osiris_bigbio_kb                                                 423
# pubtator_central_sample_bigbio_kb                                 58
# quaero_emea_bigbio_kb                                           1643
# quaero_medline_bigbio_kb                                        5616
# spl_adr_200db_train_bigbio_kb                                    637
# spl_adr_200db_unannotated_bigbio_kb                                0
# thomas2011_bigbio_kb                                             385
# tmvar_v2_bigbio_kb                                               275
# tmvar_v3_bigbio_kb                                              2161
# twadrl_bigbio_kb                                               23819

# %%
all_db_names = defaultdict(list)

aggregated[['dataset_name','']]

# %%
metadata = ner_helpers.for_config_name('bc5cdr_bigbio_kb').get_metadata()
# Out:
# Found cached dataset bc5cdr (/home/dkartchner3/.cache/huggingface/datasets/bc5cdr/bc5cdr_bigbio_kb/1.0.0/f01f16ea9b65ead985bedadf7335195c32297c8f1b09417fc607b102a6757d6f)
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
train = metadata['train']

# %%
metadata.keys()
# Out:
# dict_keys(['train', 'test', 'validation'])

# %%
train.__dict__
# Out:
# {'samples_count': 500,
#  'passages_count': 1000,
#  'passages_char_count': 652177,
#  'passages_type_counter': {'title': 500, 'abstract': 500},
#  'entities_count': 9570,
#  'entities_normalized_count': 9599,
#  'entities_type_counter': {'Chemical': 5207, 'Disease': 4363},
#  'entities_db_name_counter': {'MESH': 9599},
#  'entities_unique_db_ids_count': 1328,
#  'events_count': 0,
#  'events_type_counter': {},
#  'events_arguments_count': 0,
#  'events_arguments_role_counter': {},
#  'coreferences_count': 0,
#  'relations_count': 15072,
#  'relations_type_counter': {'CID': 15072},
#  'relations_db_name_counter': {},
#  'relations_unique_db_ids_count': 0}

# %%
df = pd.read_excel('../collaboration/dataset_summary.xlsx')

# %%
import ast
db_names = defaultdict(set)
for d in df.entities_db_name_counter.tolist():
    db_dict = ast.literal_eval(d)
    for x in db_dict.keys():
        db_names[x.lower()].add(x)

db_keys = list(db_names.keys())
db_keys.sort()
db_names = {key: list(db_names[key]) for key in db_keys}
for key, val in db_names.items():
    if len(val) > 1:
        print(key)
    for v in val:
        # if v == key:
        #     continue
        print(v)

with open('../collaboration/db_names.json', 'w') as f:
    f.write(ujson.dumps(list(db_names), indent=2))
# for x in sorted([x.lower() for x in db_names.keys()]):
#     print(x)
# Out:
# chemspider
# dbsnp
# dbsnp
# dbSNP
# DrugBank
# eCIE-O-3.1
# hgnc
# HGVS-like
# ICD10-CM
# ICD10-PCS
# intenz
# interpro
# kegg
# Meddra
# MedDRA v18.1
# mesh
# mesh
# MESH
# miRNA-corpus
# ncbi
# ncbi gene
# NCBI Gene
# NCBI gene
# ncbi_gene
# ncbi_taxon
# NCBI_Taxonomy
# NCBIGene
# OMIM
# OntoBiotope
# pfam
# pubchem:compound
# pubchem:substance
# Snomed CT
# SNOMED_CT
# tmVar
# UMLS
# uniprot

# %%
with open('../collaboration/db_names.txt', 'w') as f:
    f.write("\n".join())
# Out:
# ['', 'chemspider', 'dbsnp', 'drugbank', 'ecie-o-3.1', 'hgnc', 'hgvs-like', 'icd10-cm', 'icd10-pcs', 'intenz', 'interpro', 'kegg', 'meddra', 'meddra v18.1', 'mesh', 'mirna-corpus', 'ncbi', 'ncbi gene', 'ncbi_gene', 'ncbi_taxon', 'ncbi_taxonomy', 'ncbigene', 'omim', 'ontobiotope', 'pfam', 'pubchem:compound', 'pubchem:substance', 'snomed ct', 'snomed_ct', 'tmvar', 'umls', 'uniprot']

# %%
df.entities_db_name_counter.tolist()
# Out:
# ["{'MESH': 29335}",
#  "{'OntoBiotope': 2452, 'NCBI_Taxonomy': 1176}",
#  "{'uniprot': 3190, 'hgnc': 2947, 'NCBI gene': 2946, 'interpro': 816, 'pubchem:compound': 459, 'intenz': 116, 'pfam': 98, 'DrugBank': 13, 'pubchem:substance': 6, 'kegg': 1, 'chemspider': 1}",
#  "{'Snomed CT': 8930, 'Meddra': 6222, '': 780}",
#  "{'eCIE-O-3.1': 16032}",
#  "{'': 1382}",
#  "{'ICD10-CM': 14305, 'ICD10-PCS': 4130}",
#  '{}',
#  "{'SNOMED_CT': 5374}",
#  "{'NCBIGene': 6430}",
#  "{'ncbi': 4259}",
#  "{'ncbi': 2851}",
#  "{'UMLS': 385098}",
#  "{'UMLS': 203282}",
#  "{'miRNA-corpus': 8318}",
#  "{'MESH': 6487, 'OMIM': 567}",
#  "{'NCBIGene': 18056}",
#  "{'MESH': 41300}",
#  "{'NCBI Gene': 689, 'HGVS-like': 291, 'dbSNP': 250}",
#  "{'mesh': 139, 'ncbi_taxon': 49, 'ncbi_gene': 11, 'tmVar': 9}",
#  "{'UMLS': 7202}",
#  "{'UMLS': 9079}",
#  "{'MedDRA v18.1': 2417}",
#  '{}',
#  "{'dbSNP': 527}",
#  "{'dbsnp': 625}",
#  "{'NCBI Gene': 6023, 'dbSNP': 2861}"]

# %%
name_list = ujson.load(open('../collaboration/db_names.json'))
